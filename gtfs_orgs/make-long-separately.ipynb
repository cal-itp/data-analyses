# %%
import pandas as pd
import numpy as np
from calitp import to_snakecase

from siuba import *

from IPython.display import display, Markdown

# %%
df = to_snakecase(pd.read_csv(
    'gs://calitp-analytics-data/data-analyses/'
    'gtfs_compliance/organizations-AllOrganizations.csv'))

# %%
df.columns
# Out:
# Index(['name', 'organization_type', 'roles', 'record_creation_time', 'ntp_id',
#        'itp_id', 'opm_id_drmt', 'dotid', 'brand', 'alias', 'details',
#        'website', 'parent_organization', 'administrating_organization',
#        'mobility_services_managed', 'missing_static',
#        'funding_sources_for_managed_transportation',
#        'mobility_services_operated', 'gtfs_datasets_produced',
#        'service_type__from_mobility_services_managed_',
#        'currently_operating__from_mobility_services_managed_',
#        'currently_operating__from_mobility_services_operated_',
#        'service_type__from_mobility_services_operated_', 'headquarters_place',
#        'funding_programs', 'total_voms__ntd_', 'service_area_sq_miles__ntd_',
#        'service_area_population__ntd_', 'caltrans_district', 'mpo_rtpa',
#        'planning_authority', 'tracking_category', 'reporting_category',
#        'assist_category', 'eligibility_programs', 'gtfs_datasets',
#        'gtfs_dataset__from_mobility_services_managed_', 'fare_systems',
#        'gtfs_schedule_status', 'fares_v2_status', 'flex_status',
#        'services_needing_alerts',
#        'services_needing_tripupdates_or_vehiclepositions',
#        '#_of_fixed_route_services', '#_services_w__complete_rt_status',
#        '#_fixed_route_services_w__static_gtfs',
#        'complete_static_gtfs_coverage__1=yes_', 'complete_rt_coverage',
#        '>=1_gtfs_feed_for_any_service__1=yes_', '>=_1_complete_rt_set__1=yes_',
#        'service_availability_category__from_mobility_services_managed_',
#        '#_fixed_route_or_deviated_fixed_route_services',
#        '#_fixed_route_or_deviated_fixed_route_service_w__static_gtfs',
#        '#_services_with_missing_static_feed_for_fixed_route_or_deviated_fixed_route',
#        'county_geography', 'county_geography_3', 'gtfs_static_status',
#        'gtfs_realtime_status', 'service_availability', 'service___component'],
#       dtype='object')

# %%
managed_service_cols = [
    'mobility_services_managed', 
    # Do you need to keep info such as "check 3 out of 3"?
    #'currently_operating__from_mobility_services_managed_',
    'service_type__from_mobility_services_managed_',
]

operated_service_cols = [
    'mobility_services_operated', 
    #'currently_operating__from_mobility_services_operated_',
    'service_type__from_mobility_services_operated_', 
]

# %%
def make_long(df, keep_cols = [], category_name = "managed"):
    df1 = df[["name", "gtfs_schedule_status"] + keep_cols]
    
    for col_name in ["mobility_services", "service_type"]:
        df1 = df1.rename(columns=lambda c: col_name 
                        if c.startswith(col_name) else c)
    
    df1 = df1[["name", "gtfs_schedule_status", "mobility_services", "service_type"]]
    
    df2 = df1.assign(
        mobility_services = (df1.mobility_services.fillna("None")
                         .apply(lambda x: x.split(','))
                        )
    )
    
    # Cannot add service_type to explode
    # Service types do not match mobility_services (1 service can provide both flex and fixed route)
    # That's fine, maybe service type is not too important to keep anyway
    df3 = df2.explode("mobility_services")
    
    # New variable to track the category name. 
    # Within mobility services, there are 2 sub-categories, managed / operated
    df3 = df3.assign(
        category = category_name
    )
    
    return df3

# %%
managed = make_long(df, keep_cols = managed_service_cols, category_name = "managed")
managed
# Out:
#                                                   name gtfs_schedule_status  \
# 0                                        A-Paratransit                  NaN
# 1                                          ABC Shuttle               needed
# 2                                            Able Inc.                  NaN
# 3                                         Abrazar Inc.               needed
# 4                                      Access Services               needed
# ..                                                 ...                  ...
# 849                      Yuba-Sutter Transit Authority     ok,needed,needed
# 849                      Yuba-Sutter Transit Authority     ok,needed,needed
# 850  Yuma County Intergovernmental Public Transport...                   ok
# 851                                        Yurok Tribe               needed
# 852                                         Zonar Inc.                  NaN
#
#                       mobility_services  \
# 0                                  None
# 1                   ABC Airport Shuttle
# 2                             Able Inc.
# 3                               Abrazar
# 4                    LA Access Services
# ..                                  ...
# 849                  Sacramento Express
# 849  Yuba College Sutter Campus Shuttle
# 850            Yuma County Area Transit
# 851         Yurok Tribe Transit Service
# 852                                None
#
#                                           service_type category
# 0                                                  NaN  managed
# 1                                            on-demand  managed
# 2                                            on-demand  managed
# 3                                                 NEMT  managed
# 4                                      ADA paratransit  managed
# ..                                                 ...      ...
# 849  fixed-route,on-demand,deviated fixed-route,res...  managed
# 849  fixed-route,on-demand,deviated fixed-route,res...  managed
# 850                                        fixed-route  managed
# 851                             on-demand,reservations  managed
# 852                                                NaN  managed
#
# [1251 rows x 5 columns]

# %%
operated = make_long(df, keep_cols = operated_service_cols, category_name = "operated")
operated
# Out:
#                                                   name gtfs_schedule_status  \
# 0                                        A-Paratransit                  NaN
# 1                                          ABC Shuttle               needed
# 2                                            Able Inc.                  NaN
# 3                                         Abrazar Inc.               needed
# 4                                      Access Services               needed
# ..                                                 ...                  ...
# 849                      Yuba-Sutter Transit Authority     ok,needed,needed
# 849                      Yuba-Sutter Transit Authority     ok,needed,needed
# 850  Yuma County Intergovernmental Public Transport...                   ok
# 851                                        Yurok Tribe               needed
# 852                                         Zonar Inc.                  NaN
#
#                mobility_services  \
# 0           East Bay Paratransit
# 1            ABC Airport Shuttle
# 2                      Able Inc.
# 3                        Abrazar
# 4             LA Access Services
# ..                           ...
# 849      Yuba-Sutter Dial-A-Ride
# 849           Sacramento Express
# 850     Yuma County Area Transit
# 851  Yurok Tribe Transit Service
# 852                         None
#
#                                           service_type  category
# 0                                      ADA paratransit  operated
# 1                                            on-demand  operated
# 2                                            on-demand  operated
# 3                                                 NEMT  operated
# 4                                      ADA paratransit  operated
# ..                                                 ...       ...
# 849  fixed-route,on-demand,deviated fixed-route,res...  operated
# 849  fixed-route,on-demand,deviated fixed-route,res...  operated
# 850                                        fixed-route  operated
# 851                             on-demand,reservations  operated
# 852                                                NaN  operated
#
# [1247 rows x 5 columns]

# %%
operated[operated.name.str.contains("Anaheim")]
# Out:
#                                name gtfs_schedule_status  \
# 25   Anaheim Transportation Network     ok,needed,needed
# 25   Anaheim Transportation Network     ok,needed,needed
# 25   Anaheim Transportation Network     ok,needed,needed
# 106                 City of Anaheim               needed
#
#                               mobility_services  \
# 25                Anaheim Resort Transportation
# 25                                         FRAN
# 25   Anaheim Transportation Network Paratransit
# 106                               Senior Wheels
#
#                               service_type  category
# 25   fixed-route,on-demand,ADA paratransit  operated
# 25   fixed-route,on-demand,ADA paratransit  operated
# 25   fixed-route,on-demand,ADA paratransit  operated
# 106                 reservations,on-demand  operated

# %%
operated[operated.name.str.contains("Yuba")]
# Out:
#                               name gtfs_schedule_status  \
# 849  Yuba-Sutter Transit Authority     ok,needed,needed
# 849  Yuba-Sutter Transit Authority     ok,needed,needed
# 849  Yuba-Sutter Transit Authority     ok,needed,needed
# 849  Yuba-Sutter Transit Authority     ok,needed,needed
#
#              mobility_services  \
# 849        Yuba-Sutter Transit
# 849  Yuba-Sutter Rural Transit
# 849    Yuba-Sutter Dial-A-Ride
# 849         Sacramento Express
#
#                                           service_type  category
# 849  fixed-route,on-demand,deviated fixed-route,res...  operated
# 849  fixed-route,on-demand,deviated fixed-route,res...  operated
# 849  fixed-route,on-demand,deviated fixed-route,res...  operated
# 849  fixed-route,on-demand,deviated fixed-route,res...  operated

# %%
# They can just produce 1 GTFS dataset, but it seems like 
# gtfs_schedule_status also doesn't move closely with
# service_type_mobility_services_managed or mobility_services_managed
# Leave unexploded

df[df.name.str.contains("Anaheim")][
    ["name", "gtfs_schedule_status", "gtfs_dataset__from_mobility_services_managed_"]]
# Out:
#                                name gtfs_schedule_status  \
# 25   Anaheim Transportation Network     ok,needed,needed
# 106                 City of Anaheim               needed
#
#     gtfs_dataset__from_mobility_services_managed_
# 25                        Anaheim Resort Schedule
# 106                                           NaN

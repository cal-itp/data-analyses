# %% [markdown]
# ## Service Records

# %%
import pandas as pd
from siuba import *
import numpy as np

from calitp import to_snakecase

from IPython.display import display, Markdown

# %%
pd.set_option("display.max_columns", 100)

# %%
df = to_snakecase(pd.read_csv('gs://calitp-analytics-data/data-analyses/gtfs_compliance/services-AllRecords.csv'))

# %%
df.head()
# Out:
#                                      name  \
# 0   Laguna Niguel Senior Mobility Program
# 1                      Yountville Trolley
# 2                     ABC Airport Shuttle
# 3                               Able Inc.
# 4                                 Abrazar
#
#                                provider organization_type__from_provider_  \
# 0                 City of Laguna Niguel                         City/Town
# 1  Napa Valley Transportation Authority                Independent Agency
# 2                           ABC Shuttle                           Company
# 3                             Able Inc.           Non-Profit Organization
# 4                          Abrazar Inc.           Non-Profit Organization
#
#                                operator currently_operating alias  \
# 0                         Yellow Cab CA             checked   NaN
# 1  Napa Valley Transportation Authority             checked   NaN
# ...

# %%
df.gtfs_schedule_status.value_counts()
# Out:
# needed                     537
# ok                         224
# need long-term solution     21
# research                     7
# not public                   3
# Name: gtfs_schedule_status, dtype: int64

# %%
df>>filter(_.gtfs_schedule_status=='ok')>>count(_.service_type)>>arrange(-_.n)
# Out:
#                                          service_type    n
# 9                                         fixed-route  177
# 10                   fixed-route,deviated fixed-route    7
# 1                                deviated fixed-route    4
# 11   fixed-route,deviated fixed-route,ADA paratransit    4
# 15                           fixed-route,reservations    4
# 16                                          on-demand    3
# 3   deviated fixed-route,ADA paratransit,reservations    2
# 13                                  fixed-route,event    2
# 19                             on-demand,reservations    2
# 0    ADA paratransit,deviated fixed-route,fixed-route    1
# 2                deviated fixed-route,ADA paratransit    1
# 4                    deviated fixed-route,fixed-route    1
# 5    deviated fixed-route,fixed-route,ADA paratransit    1
# 6   deviated fixed-route,fixed-route,ADA paratrans...    1
# 7                      deviated fixed-route,on-demand    1
# ...

# %%
display(Markdown(f"There are {len(df>>filter(_.gtfs_schedule_status=='ok')>>filter(_.service_type.str.contains(',')))} "
                 f"organizations with multiple service types"))
# Out:
# There are 36 organizations with multiple service types

# %%
(df>>filter(_.gtfs_schedule_status=='ok')>>filter(_.service_type.str.contains(','))).sample(5)
# Out:
#                                        name  \
# 589                        Sage Stage Local
# 203            Dinuba Area Regional Transit
# 416             Mendocino Transit Authority
# 603  San Francisco Bay Ferry Giants Service
# 688                       St Helena Shuttle
#
#                                               provider  \
# 589                    Modoc Transportation Authority
# 203              Tulare County Regional Transit Agency
# 416                        Mendocino Transit Authority
# 603  San Francisco Bay Area Water Emergency Transit...
# 688               Napa Valley Transportation Authority
#
#     organization_type__from_provider_  \
# 589                Independent Agency
# 203               Joint Powers Agency
# 416                Independent Agency
# 603                Independent Agency
# 688                Independent Agency
#
#                                               operator currently_operating  \
# ...

# %%
df.realtime_status.value_counts()
# Out:
# Incomplete    733
# Complete      113
# Name: realtime_status, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 846 entries, 0 to 845
# Data columns (total 72 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   name                                           846 non-null    object
#  1   provider                                       840 non-null    object
#  2   organization_type__from_provider_              796 non-null    object
#  3   operator                                       806 non-null    object
#  4   currently_operating                            802 non-null    object
#  5   alias                                          39 non-null     object
#  6   mode                                           837 non-null    object
#  7   service_type                                   831 non-null    object
#  8   notes                                          672 non-null    object
# ...

# %%
df.gtfs_schedule_quality.value_counts()
# Out:
# 2 - GTFS data has active service              99
# 3 - GTFS data has zero validation errors      69
# 4 - GTFS data has zero validation warnings    66
# 0 - Does not have GTFS Schedule               61
# 1 - Has URL for GTFS downloading              20
# Name: gtfs_schedule_quality, dtype: int64

# %%
df>>filter(_.organizations.notnull())
# Out:
# Empty DataFrame
# ...

# %%
df>>filter(_.organizations_2.notnull())
# Out:
#                            name                    provider  \
# 542  Redding Area Bus Authority  Redding Area Bus Authority
#
#     organization_type__from_provider_                    operator  \
# 542                Independent Agency  Redding Area Bus Authority
#
#     currently_operating alias mode service_type notes funding_sources  \
# 542             checked   NaN  bus  fixed-route   NaN        Caltrans
#
#     funding_category service_area_type  service_area_buffer__miles_  \
# 542           public               NaN                          NaN
#
#     rider_requirements service_availability_category paratransit_for  \
# 542             Public                      Public\n             NaN
#
#     season_start season_end  \
# 542          NaN        NaN
#
#                                                website  \
# 542  https://www.cityofredding.org/departments/redd...
#
#                              gtfs_services_association  #_schedule_feeds  \
# ...

# %%
df>>filter(_.organizations_3.notnull())
# Out:
#             name provider organization_type__from_provider_ operator  \
# 147      Clipper      NaN                               NaN      NaN
# 165  Connectcard      NaN                               NaN      NaN
# 713      TAPcard      NaN                               NaN      NaN
#
#     currently_operating alias mode service_type notes funding_sources  \
# 147                 NaN   NaN  NaN          NaN   NaN             NaN
# 165                 NaN   NaN  NaN          NaN   NaN             NaN
# 713                 NaN   NaN  NaN          NaN   NaN             NaN
#
#     funding_category service_area_type  service_area_buffer__miles_  \
# 147              NaN               NaN                          NaN
# 165              NaN               NaN                          NaN
# 713              NaN               NaN                          NaN
#
#     rider_requirements service_availability_category paratransit_for  \
# ...

# %% [markdown]
# * Organizations columns (3) are almost all null.

# %%
df>>filter(_.eligibility_programs.notnull())
# Out:
#                    name         provider organization_type__from_provider_  \
# 347  LA Access Services  Access Services                               NaN
#
#             operator currently_operating alias         mode     service_type  \
# 347  Access Services             checked   NaN  bus,car/van  ADA paratransit
#
#     notes funding_sources funding_category service_area_type  \
# 347   NaN        Caltrans           public               NaN
#
#      service_area_buffer__miles_ rider_requirements  \
# 347                          NaN     ADA Disability
#
#     service_availability_category paratransit_for season_start season_end  \
# 347                   Conditional            DASH          NaN        NaN
#
#                    website gtfs_services_association  #_schedule_feeds  \
# 347  https://accessla.org/                       NaN                 0
#
#     gtfs_services_dataset gtfs_dataset_producers gtfs_dataset_publisher  \
# ...

# %%
df.eligibility_programs.value_counts()
# Out:
# LA Access Services Paratransit Eligibility    1
# Name: eligibility_programs, dtype: int64

# %%
df.season_end.value_counts()
# Out:
# September    2
# Labor Day    2
# October      1
# April        1
# August       1
# Name: season_end, dtype: int64

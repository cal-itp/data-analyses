# %%
# To SQL

# %%
from calitp.tables import tbl
from siuba import *
import pandas as pd

import utils
# Out:
# /opt/conda/lib/python3.10/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
from calitp import query_sql, magics

# %%
pd.set_option("display.max_columns", 100)

# %%
org_df = collect(tbl.airtable.california_transit_organizations())

# %%
org_df.sample()
# Out:
#        organization_id           name mobility_services_managed  \
# 294  reciCzrOhDk6HA194  City of Colma                      None
#
#     parent_organization organization_type headquarters_place  \
# 294                None         City/Town              Colma
#
#     caltrans_district planning_authority tracking_category reporting_category  \
# 294              None               None              None               None
#
#     assist_category headquarters_state_country      record_creation_time  \
# 294            None                       None  2022-01-10T20:39:47.000Z
#
#     service_type__from_mobility_services_managed_  \
# 294                                          None
#
#     currently_operating__from_mobility_services_managed_  \
# 294                                               None
#
#     funding_sources_for_managed_transportation  \
# 294                                       None
#
#      num_fixed_route_services_w_static_gtfs  \
# 294                                       0
#
#      at_least_one_gtfs_feed_for_any_service  \
# 294                                       0
#
#     service_availability_category__from_mobility_services_managed_  \
# 294                                               None
#
#      num_fixed_route_or_deviated_fixed_route_services  \
# 294                                                 0
#
#      num_fixed_route_or_deviated_fixed_route_service_w__static_gtfs  \
# 294                                                  0
#
#      num_services_with_missing_static_feed_for_fixed_route_or_deviated_fixed_route  \
# 294                                                  0
#
#      num_fixed_route_services  complete_static_gtfs_coverage  \
# 294                         0                              1
#
#     gtfs_static_status  num_services_w_complete_rt_status  \
# 294          Static OK                                  0
#
#      complete_rt_coverage  at_least_one_complete_rt_set gtfs_realtime_status  \
# 294                     1                             0        RT Incomplete
#
#     missing_static services_needing_alerts  \
# 294             []                      []
#
#     services_needing_tripupdates_or_vehiclepositions service_availability  \
# 294                                               []                 None
#
#     fixed_route_service_operator_type  schedule_datasets  itp_id  \
# 294                                []                  0     NaN
#
#     gtfs_datasets_produced mobility_services_operated ntp_id mpo_rtpa  \
# 294                   None                       None   None     None
#
#     gtfs_datasets_referenced gtfs_dataset__from_mobility_services_managed_  \
# 294                     None                                          None
#
#     total_voms__ntd_ service_area_population__ntd_  \
# 294             None                          None
#
#     service_area_sq_miles__ntd_  \
# 294                        None
#
#     currently_operating__from_mobility_services_operated_  \
# 294                                               None
#
#     service_type__from_mobility_services_operated_ gtfs_schedule_status  \
# 294                                           None                 None
#
#     flex_status immediate_gtfs_goals fares_v2_status details website  \
# 294        None                 None            None    None    None
#
#     funding_programs county_geography fare_systems drmt_organization_name  \
# 294             None             None         None                   None
#
#     drmt_reported_5310_vehicles opm_id_drmt alias service___component brand  \
# 294                        None        None  None                None  None
#
#     roles county_geography_3 dotid administrating_organization  \
# 294  None               None  None                        None
#
#     service_area_type__from_services_  \
# 294                              None
#
#     avl_rti_vendor__from_service_area_type__from_services__  \
# 294                                               None
#
#     currently_operating__from_service_area_type__from_services__ services  \
# 294                                               None               None
#
#     eligibility_programs
# 294                 None

# %%
# %%sql
#
# select count(*) from airtable.california_transit_organizations
# Out:
# /opt/conda/lib/python3.10/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
#    f0_
# 0  857

# %%
# testing new view

# %%
# %%sql
# with new_view as (
# select
#     name,
#     reporting_category,
#     organization_type,
#     caltrans_district,
#     ntp_id,
#     itp_id,
#     opm_id_drmt,
#     brand,
#     alias,
#     reporting_category,
#     fares_v2_status,
#     mobility_services_managed,
#     mobility_services_operated,
#     gtfs_datasets_produced,
#     service_type__from_mobility_services_managed_,
#     service_type__from_mobility_services_operated_,
#     currently_operating__from_mobility_services_managed_,
#     headquarters_place,
#     funding_sources_for_managed_transportation,
#     caltrans_district,
#     gtfs_dataset__from_mobility_services_managed_,
#     gtfs_schedule_status,
#     gtfs_static_status,
#     gtfs_realtime_status
# from airtable.california_transit_organizations
# )
#
# select * from new_view
# limit 10
# Out:
# /opt/conda/lib/python3.10/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
#                                       name reporting_category  \
# 0  Consolidated Tribal Health Project Inc.               None
# 1                               Everbridge               None
# 2                    City of Santa Barbara               None
# 3                          Connexionz Inc.               None
# 4                   Area 1 Agency on Aging               None
# 5                            City of Poway               None
# 6                    Empire Transportation               None
# 7                  Southland Transit, Inc.               None
# 8                                Interline               None
# 9                    City of National City               None
#
#          organization_type caltrans_district ntp_id  itp_id opm_id_drmt brand  \
# 0  Non-Profit Organization              None   None     NaN        None  None
# 1                     None              None   None     NaN        None  None
# 2                City/Town              None   None     NaN        None  None
# 3                  Company              None   None     NaN        None  None
# 4                     None              None   None   399.0        None  None
# 5                City/Town              None   None     NaN        None  None
# 6                     None              None   None     NaN        None  None
# 7                     None              None   None     NaN        None  None
# 8                  Company              None   None     NaN        None  None
# 9                City/Town              None   None     NaN        None  None
#
#   alias reporting_category_1 fares_v2_status mobility_services_managed  \
# 0  None                 None            None                      None
# 1  None                 None            None                      None
# 2  None                 None            None                      None
# 3  None                 None            None                      None
# 4  None                 None            None                      None
# 5  None                 None            None                      None
# 6  None                 None            None                      None
# 7  None                 None            None                      None
# 8  None                 None            None                      None
# 9  None                 None            None                      None
#
#   mobility_services_operated  \
# 0                       None
# 1                       None
# 2                       None
# 3                       None
# 4                       None
# 5                       None
# 6                       None
# 7                       None
# 8                       None
# 9                       None
#
#                               gtfs_datasets_produced  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  ['recHC7bwsgTPqLjX4', 'rec6hxEPTcBpIFWFX', 're...
# 4                                               None
# 5                                               None
# 6                                               None
# 7                                               None
# 8                                               None
# 9                                               None
#
#   service_type__from_mobility_services_managed_  \
# 0                                          None
# 1                                          None
# 2                                          None
# 3                                          None
# 4                                          None
# 5                                          None
# 6                                          None
# 7                                          None
# 8                                          None
# 9                                          None
#
#   service_type__from_mobility_services_operated_  \
# 0                                           None
# 1                                           None
# 2                                           None
# 3                                           None
# 4                                           None
# 5                                           None
# 6                                           None
# 7                                           None
# 8                                           None
# 9                                           None
#
#   currently_operating__from_mobility_services_managed_  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6                                               None
# 7                                               None
# 8                                               None
# 9                                               None
#
#           headquarters_place funding_sources_for_managed_transportation  \
# 0                       None                                       None
# 1                       None                                       None
# 2              Santa Barbara                                       None
# 3  Santa Clarita, California                                       None
# 4                       None                                       None
# 5                      Poway                                       None
# 6                       None                                       None
# 7                       None                                       None
# 8                    Alameda                                       None
# 9              National City                                       None
#
#   caltrans_district_1 gtfs_dataset__from_mobility_services_managed_  \
# 0                None                                          None
# 1                None                                          None
# 2                None                                          None
# 3                None                                          None
# 4                None                                          None
# 5                None                                          None
# 6                None                                          None
# 7                None                                          None
# 8                None                                          None
# 9                None                                          None
#
#   gtfs_schedule_status gtfs_static_status gtfs_realtime_status
# 0                 None          Static OK        RT Incomplete
# 1                 None          Static OK        RT Incomplete
# 2                 None          Static OK        RT Incomplete
# 3                 None          Static OK        RT Incomplete
# 4                 None          Static OK        RT Incomplete
# 5                 None          Static OK        RT Incomplete
# 6                 None          Static OK        RT Incomplete
# 7                 None          Static OK        RT Incomplete
# 8                 None          Static OK        RT Incomplete
# 9                 None          Static OK        RT Incomplete

# %%
# %%sql
# select
#     *
# from cal-itp-data-infra-staging.staging_views.airtable_org_subset
# where (reporting_category = 'Core'
#     or
#     reporting_category = 'Other Public Transit')
#      and (service_type__from_mobility_services_managed_ like '%fixed-route%'
#        or service_type__from_mobility_services_managed_ like '%deviated fixed-route%'
#          or  service_type__from_mobility_services_managed_ like '%on-demand fixed-route%')
#      and
#     funding_sources_for_managed_transportation like ('%public%')
#     and
#     currently_operating__from_mobility_services_managed_ like ('%True%')
# Out:
# /opt/conda/lib/python3.10/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
#                                                 name    reporting_category  \
# 0                                  City of Morro Bay  Other Public Transit
# 1                    San Diego International Airport  Other Public Transit
# 2    Santa Barbara County Association of Governments                  Core
# 3                                        Commute.org  Other Public Transit
# 4                                Menlo Park Shuttles  Other Public Transit
# ..                                               ...                   ...
# 184                    Marin County Transit District                  Core
# 185                                      Kern County                  Core
# 186      San Luis Obispo Regional Transit Authority                   Core
# 187                               Los Angeles County                  Core
# 188               Fresno County Rural Transit Agency                  Core
#
#       organization_type     caltrans_district                 ntp_id  itp_id  \
# 0             City/Town  05 - San Luis Obispo                   None   213.0
# 1    Independent Agency        11 - San Diego                   None   277.0
# 2                  None  05 - San Luis Obispo                   None   379.0
# 3                  None          04 - Oakland                   None    76.0
# 4                  None          04 - Oakland                   None   199.0
# ..                  ...                   ...                    ...     ...
# 184  Independent Agency          04 - Oakland  ['recgeJopomk1yuLGl']   194.0
# 185              County           06 - Fresno  ['rec0OKlbrwM9ujJrP']   146.0
# 186  Independent Agency  05 - San Luis Obispo  ['recEY3890s1LqT2b7']   289.0
# 187              County      07 - Los Angeles                   None   179.0
# 188  Independent Agency           06 - Fresno  ['rec0dqO63go6bMr2p']   117.0
#
#     opm_id_drmt              brand  \
# 0        540002  Morro Bay Transit
# 1          None               None
# 2        542006               None
# 3          None               None
# 4          None               None
# ..          ...                ...
# 184      421002               None
# 185      615006       Kern Transit
# 186      540005       SoCo Transit
# 187      719031               None
# 188      610004               None
#
#                                                  alias  reporting_category_1  \
# 0                                                 None  Other Public Transit
# 1                                              ['SAN']  Other Public Transit
# 2                                            ['SBCAG']                  Core
# 3                                                 None  Other Public Transit
# 4                                                 None  Other Public Transit
# ..                                                 ...                   ...
# 184                                               None                  Core
# 185                                               None                  Core
# 186                                         ['SLORTA']                  Core
# 187  ['LA DPW', 'LA County', 'Los Angeles DPW', 'Lo...                  Core
# 188                                          ['FCRTA']                  Core
#
#                                        fares_v2_status  \
# 0                               ['Unknown', 'Unknown']
# 1                                          ['Unknown']
# 2                               ['Provider published']
# 3                                 ['Vendor published']
# 4                              ['Provider to Publish']
# ..                                                 ...
# 184  ['Vendor published', 'Vendor published', 'Vend...
# 185                               ['Vendor published']
# 186  ['Provider published', 'Provider published', '...
# 187  ['Vendor published', 'Vendor published', 'Vend...
# 188  ['Unknown', 'Unknown', 'Unknown', 'Unknown', '...
#
#                              mobility_services_managed  \
# 0           ['recSp27U6s31QJSKN', 'recZslL9QXbd9kWoS']
# 1                                ['recrwkklZVuk57tIs']
# 2                                ['reckGaGjCuKV9WdPC']
# 3                                ['recIrgn5BhgpwnULH']
# 4                                ['recZHDDuxsj5gtRtW']
# ..                                                 ...
# 184  ['recIGK0lAob3SPAbL', 'recub3E01v5DjPVSx', 're...
# 185  ['recerP7m633Uw5v4z', 'recVGVlWZd7NCFBKv', 're...
# 186  ['recAvUfY0smr0BPel', 'recqNh8cK4CRyZNjx', 're...
# 187  ['rec1Vnz3gmw9TP7O2', 'rectLhNGCReNovxSm', 're...
# 188  ['recCJ9Jb4Jrr5Np9V', 'rechir3GPKKadXawT', 're...
#
#                             mobility_services_operated  \
# 0           ['recSp27U6s31QJSKN', 'recZslL9QXbd9kWoS']
# 1                                ['recrwkklZVuk57tIs']
# 2                                ['reckGaGjCuKV9WdPC']
# 3                                ['recIrgn5BhgpwnULH']
# 4                                                 None
# ..                                                 ...
# 184  ['recub3E01v5DjPVSx', 'recDXjxxSVSBlD6MR', 're...
# 185  ['recerP7m633Uw5v4z', 'recVGVlWZd7NCFBKv', 're...
# 186  ['recqNh8cK4CRyZNjx', 'recK0My4JUzrJrueY', 're...
# 187  ['rec1i8Iwnu6mo24zt', 'recCWXf3GLoXf3PFF', 're...
# 188                              ['recotdBBhu10g67V6']
#
#                                 gtfs_datasets_produced  \
# 0                                ['recakkevxj5vOACjk']
# 1                                                 None
# 2                                ['recLhUJUDjFXcmOte']
# 3                                ['recOdlAUeG1fIkFcr']
# 4                                ['recUbZwXK2rjDmiua']
# ..                                                 ...
# 184  ['recOKNFbyRBuF6OZE', 'recvs9EVakYTtIaNJ', 're...
# 185                              ['recQiWHhvE6MxozGV']
# 186                              ['recHC7bwsgTPqLjX4']
# 187                              ['recUjYd23khxh0r9v']
# 188                                               None
#
#          service_type__from_mobility_services_managed_  \
# 0    ['fixed-route', 'deviated fixed-route', 'fixed...
# 1                                      ['fixed-route']
# 2                                      ['fixed-route']
# 3                                      ['fixed-route']
# 4                         ['fixed-route', 'on-demand']
# ..                                                 ...
# 184  ['ADA paratransit', 'fixed-route', 'fixed-rout...
# 185  ['fixed-route', 'on-demand', 'ADA paratransit'...
# 186  ['fixed-route', 'deviated fixed-route', 'reser...
# 187  ['fixed-route', 'fixed-route', 'fixed-route', ...
# 188  ['on-demand', 'on-demand', 'reservations', 'on...
#
#         service_type__from_mobility_services_operated_  \
# 0    ['fixed-route', 'deviated fixed-route', 'fixed...
# 1                                      ['fixed-route']
# 2                                      ['fixed-route']
# 3                                      ['fixed-route']
# 4                                                 None
# ..                                                 ...
# 184  ['fixed-route', 'deviated fixed-route', 'ADA p...
# 185  ['fixed-route', 'on-demand', 'ADA paratransit'...
# 186  ['fixed-route', 'fixed-route', 'fixed-route', ...
# 187  ['fixed-route', 'fixed-route', 'fixed-route', ...
# 188                    ['fixed-route', 'reservations']
#
#     currently_operating__from_mobility_services_managed_   headquarters_place  \
# 0                                         [True, True]              Morro Bay
# 1                                               [True]              San Diego
# 2                                               [True]          Santa Barbara
# 3                                               [True]    South San Francisco
# 4                                               [True]             Menlo Park
# ..                                                 ...                    ...
# 184  [True, True, True, True, True, True, True, Tru...              San Rafae
# 185  [True, True, True, True, True, True, True, Tru...            Bakersfield
# 186  [True, True, True, None, True, True, True, Tru...        San Luis Obispo
# 187  [True, True, True, True, True, True, True, Tru...            Los Angeles
# 188  [True, True, True, True, True, True, True, Tru...                 Fresno
#
#             funding_sources_for_managed_transportation   caltrans_district_1  \
# 0                                 ['public', 'public']  05 - San Luis Obispo
# 1                                           ['public']        11 - San Diego
# 2                                           ['public']  05 - San Luis Obispo
# 3                                           ['public']          04 - Oakland
# 4                                           ['public']          04 - Oakland
# ..                                                 ...                   ...
# 184  ['public', 'public', 'public', 'public', 'publ...          04 - Oakland
# 185  ['public', 'public', 'public', 'public', 'publ...           06 - Fresno
# 186  ['public', 'public', 'public', 'public', 'publ...  05 - San Luis Obispo
# 187  ['public', 'public', 'public', 'public', 'publ...      07 - Los Angeles
# 188  ['public', 'public', 'public', 'public', 'publ...           06 - Fresno
#
#          gtfs_dataset__from_mobility_services_managed_  \
# 0           ['recakkevxj5vOACjk', 'recakkevxj5vOACjk']
# 1                                ['recfZ9iWkptccoONX']
# 2                                ['recLhUJUDjFXcmOte']
# 3                                ['rec9AyXUSMUHFnLsH']
# 4                                ['recUbZwXK2rjDmiua']
# ..                                                 ...
# 184  ['rec9AyXUSMUHFnLsH', 'recAQiomSPtajnjLy', 're...
# 185                              ['recQiWHhvE6MxozGV']
# 186  ['recHC7bwsgTPqLjX4', 'recHC7bwsgTPqLjX4', 're...
# 187  ['recUjYd23khxh0r9v', 'recUjYd23khxh0r9v', 're...
# 188  ['reck5oNvonO2H8iQo', 'reck5oNvonO2H8iQo', 're...
#
#                                   gtfs_schedule_status gtfs_static_status  \
# 0                                                 None          Static OK
# 1                                                 None          Static OK
# 2                                               ['ok']          Static OK
# 3                                               ['ok']          Static OK
# 4                                               ['ok']          Static OK
# ..                                                 ...                ...
# 184  ['needed', 'ok', 'needed', 'needed', 'needed',...  Static Incomplete
# 185  ['ok', 'needed', 'needed', 'needed', 'needed',...          Static OK
# 186  ['ok', 'ok', 'ok', 'needed', 'needed', 'needed...          Static OK
# 187  ['ok', 'ok', 'ok', 'ok', 'ok', 'needed', 'ok',...          Static OK
# 188  ['needed', 'needed', 'ok', 'ok', 'needed', 'ok...  Static Incomplete
#
#     gtfs_realtime_status
# 0          RT Incomplete
# 1          RT Incomplete
# 2          RT Incomplete
# 3          RT Incomplete
# 4          RT Incomplete
# ..                   ...
# 184                RT OK
# 185        RT Incomplete
# 186        RT Incomplete
# 187        RT Incomplete
# 188        RT Incomplete
#
# [189 rows x 24 columns]

# %%
# %%sql
# select
#     name,
#     currently_operating__from_mobility_services_managed_,
#     reporting_category,
#     service_type__from_mobility_services_managed_,
#     funding_sources_for_managed_transportation
# from cal-itp-data-infra-staging.staging_views.airtable_org_subset
# where (reporting_category = 'Core'
#     or
#     reporting_category = 'Other Public Transit')
#      and (service_type__from_mobility_services_managed_ like '%fixed-route%'
#        or service_type__from_mobility_services_managed_ like '%deviated fixed-route%'
#          or  service_type__from_mobility_services_managed_ like '%on-demand fixed-route%')
#      and
#     funding_sources_for_managed_transportation like ('%public%')
#     and
#     currently_operating__from_mobility_services_managed_ like ('%True%')
# Out:
# /opt/conda/lib/python3.10/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
#                                                 name  \
# 0                                  City of Morro Bay
# 1                    San Diego International Airport
# 2    Santa Barbara County Association of Governments
# 3                                        Commute.org
# 4                                Menlo Park Shuttles
# ..                                               ...
# 184                    Marin County Transit District
# 185                                      Kern County
# 186      San Luis Obispo Regional Transit Authority
# 187                               Los Angeles County
# 188               Fresno County Rural Transit Agency
#
#     currently_operating__from_mobility_services_managed_  \
# 0                                         [True, True]
# 1                                               [True]
# 2                                               [True]
# 3                                               [True]
# 4                                               [True]
# ..                                                 ...
# 184  [True, True, True, True, True, True, True, Tru...
# 185  [True, True, True, True, True, True, True, Tru...
# 186  [True, True, True, None, True, True, True, Tru...
# 187  [True, True, True, True, True, True, True, Tru...
# 188  [True, True, True, True, True, True, True, Tru...
#
#        reporting_category      service_type__from_mobility_services_managed_  \
# 0    Other Public Transit  ['fixed-route', 'deviated fixed-route', 'fixed...
# 1    Other Public Transit                                    ['fixed-route']
# 2                    Core                                    ['fixed-route']
# 3    Other Public Transit                                    ['fixed-route']
# 4    Other Public Transit                       ['fixed-route', 'on-demand']
# ..                    ...                                                ...
# 184                  Core  ['ADA paratransit', 'fixed-route', 'fixed-rout...
# 185                  Core  ['fixed-route', 'on-demand', 'ADA paratransit'...
# 186                  Core  ['fixed-route', 'deviated fixed-route', 'reser...
# 187                  Core  ['fixed-route', 'fixed-route', 'fixed-route', ...
# 188                  Core  ['on-demand', 'on-demand', 'reservations', 'on...
#
#             funding_sources_for_managed_transportation
# 0                                 ['public', 'public']
# 1                                           ['public']
# 2                                           ['public']
# 3                                           ['public']
# 4                                           ['public']
# ..                                                 ...
# 184  ['public', 'public', 'public', 'public', 'publ...
# 185  ['public', 'public', 'public', 'public', 'publ...
# 186  ['public', 'public', 'public', 'public', 'publ...
# 187  ['public', 'public', 'public', 'public', 'publ...
# 188  ['public', 'public', 'public', 'public', 'publ...
#
# [189 rows x 5 columns]

# %% [markdown]
# * Adding to GCS

# %%
## SERVICES
#tbl.airtable.california_transit_services()

# %%
## Check `currently_operating__from_mobility_services_managed_`

# %%
org_df>>count(_.currently_operating__from_mobility_services_managed_)
# Out:
#    currently_operating__from_mobility_services_managed_    n
# 0                            [None, True, True, None]      1
# 1                                  [None, True, True]      1
# 2                                        [None, True]      2
# 3                                              [None]     19
# 4          [True, None, True, True, True, True, True]      1
# 5                                  [True, None, True]      3
# 6                                        [True, None]      3
# 7                [True, True, None, True, True, True]      1
# 8                            [True, True, None, True]      2
# 9                                  [True, True, None]      1
# 10  [True, True, True, None, True, True, True, Tru...      1
# 11                     [True, True, True, True, None]      2
# 12  [True, True, True, True, True, True, True, Tru...      1
# 13  [True, True, True, True, True, True, True, Tru...      1
# 14  [True, True, True, True, True, True, True, Tru...      5
# 15   [True, True, True, True, True, True, True, True]      4
# 16         [True, True, True, True, True, True, True]      1
# 17               [True, True, True, True, True, True]      3
# 18                     [True, True, True, True, True]     10
# 19                           [True, True, True, True]      8
# 20                                 [True, True, True]     34
# 21                                       [True, True]     87
# 22                                             [True]    258

# %%
(
    org_df
    >> filter(_.currently_operating__from_mobility_services_managed_.str.contains("false"))
    >> select(_.name, _.currently_operating__from_mobility_services_managed_)
)
# Out:
# Empty DataFrame
# Columns: [name, currently_operating__from_mobility_services_managed_]
# Index: []

# %%
# %%sql
# select
#     name,
#     currently_operating__from_mobility_services_managed_
# from cal-itp-data-infra-staging.staging_views.airtable_org_subset
# Out:
# /opt/conda/lib/python3.10/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
#                                                 name  \
# 0                                         Everbridge
# 1                             Area 1 Agency on Aging
# 2                              Empire Transportation
# 3                            Southland Transit, Inc.
# 4    Siskiyou County Local Transportation Commission
# ..                                               ...
# 848                    Marin County Transit District
# 849                                      Kern County
# 850      San Luis Obispo Regional Transit Authority
# 851                               Los Angeles County
# 852               Fresno County Rural Transit Agency
#
#     currently_operating__from_mobility_services_managed_
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 848  [True, True, True, True, True, True, True, Tru...
# 849  [True, True, True, True, True, True, True, Tru...
# 850  [True, True, True, None, True, True, True, Tru...
# 851  [True, True, True, True, True, True, True, Tru...
# 852  [True, True, True, True, True, True, True, Tru...
#
# [853 rows x 2 columns]

# %%
# %%sql
# select
#     name,
#     gtfs_static_status,
#     complete_static_gtfs_coverage
# from  cal-itp-data-infra-staging.staging_views.airtable_orgs_filtered
# where complete_static_gtfs_coverage = 1
# limit 5
# Out:
# /opt/conda/lib/python3.10/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
#                            name gtfs_static_status  \
# 0               City of Shafter          Static OK
# 1  Colusa County Transit Agency          Static OK
# 2         City of Monterey Park          Static OK
# 3          City of San Clemente          Static OK
# 4               City of Lynwood          Static OK
#
#    complete_static_gtfs_coverage
# 0                              1
# 1                              1
# 2                              1
# 3                              1
# 4                              1

# %%
(
    org_df
    >> filter(_.complete_static_gtfs_coverage == 1)
    >> count(_.complete_static_gtfs_coverage)
    >> show_query()
)
# Out:
# No query to show for a DataFrame
#    complete_static_gtfs_coverage    n
# 0                              1  787

# %%
# q = (org_df
#   >> select(_.name, _.complete_static_gtfs_coverage)
#   >> mutate(pct = ((_.complete_static_gtfs_coverage==1).count) - _.complete_static_gtfs_coverage.count())
#   >> show_query()
# )

# %%
# %%sql
#
# WITH
#
# complete_status AS (
#     select
#         name,
#         complete_static_gtfs_coverage
#     from  cal-itp-data-infra-staging.staging_views.airtable_orgs_filtered
#     where (complete_static_gtfs_coverage = 1)
#     count(*) AS `count`
# ),
#
# all_status AS (
#     select
#         name,
#         complete_static_gtfs_coverage
#     from  cal-itp-data-infra-staging.staging_views.airtable_orgs_filtered
#     count(*) AS `count`
# )
#
# SELECT
#     100.0 * complete_status.count / all_status.count AS `percent`
# FROM all_status
# Out:
# /opt/conda/lib/python3.10/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/google/cloud/bigquery/dbapi/cursor.py:203, in Cursor._execute(self, formatted_operation, parameters, job_id, job_config, parameter_types)
#     202 try:
# --> 203     self._query_job.result()
#     204 except google.cloud.exceptions.GoogleCloudError as exc:
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/bigquery/job/query.py:1499, in QueryJob.result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1497         do_get_result = job_retry(do_get_result)
# -> 1499     do_get_result()
#    1501 except exceptions.GoogleAPICallError as exc:
#
# File /opt/conda/lib/python3.10/site-packages/google/api_core/retry.py:283, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     280 sleep_generator = exponential_sleep_generator(
#     281     self._initial, self._maximum, multiplier=self._multiplier
#     282 )
# --> 283 return retry_target(
#     284     target,
#     285     self._predicate,
#     286     sleep_generator,
#     287     self._deadline,
#     288     on_error=on_error,
#     289 )
#
# File /opt/conda/lib/python3.10/site-packages/google/api_core/retry.py:190, in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     189 try:
# --> 190     return target()
#     192 # pylint: disable=broad-except
#     193 # This function explicitly must deal with broad exceptions.
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/bigquery/job/query.py:1489, in QueryJob.result.<locals>.do_get_result()
#    1487     self._job_retry = job_retry
# -> 1489 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    1491 # Since the job could already be "done" (e.g. got a finished job
#    1492 # via client.get_job), the superclass call to done() might not
#    1493 # set the self._query_results cache.
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/bigquery/job/base.py:728, in _AsyncJob.result(self, retry, timeout)
#     727 kwargs = {} if retry is DEFAULT_RETRY else {"retry": retry}
# --> 728 return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/google/api_core/future/polling.py:137, in PollingFuture.result(self, timeout, retry)
#     134 if self._exception is not None:
#     135     # pylint: disable=raising-bad-type
#     136     # Pylint doesn't recognize that this is valid in this case.
# --> 137     raise self._exception
#     139 return self._result
#
# BadRequest: 400 Syntax error: Expected ")" but got identifier "count" at [10:5]
#
# Location: us-west2
# Job ID: 2b5e7c65-3b7d-4718-91a2-1fafd04c3828
#
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1802, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1801     if not evt_handled:
# -> 1802         self.dialect.do_execute(
#    1803             cursor, statement, parameters, context
#    1804         )
#    1806 if self._has_events or self.engine._has_events:
#
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/engine/default.py:719, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     718 def do_execute(self, cursor, statement, parameters, context=None):
# --> 719     cursor.execute(statement, parameters)
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/bigquery/dbapi/_helpers.py:494, in raise_on_closed.<locals>._raise_on_closed.<locals>.with_closed_check(self, *args, **kwargs)
#     493     raise exc_class(exc_msg)
# --> 494 return method(self, *args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/bigquery/dbapi/cursor.py:166, in Cursor.execute(self, operation, parameters, job_id, job_config)
#     165 formatted_operation, parameter_types = _format_operation(operation, parameters)
# --> 166 self._execute(
#     167     formatted_operation, parameters, job_id, job_config, parameter_types
#     168 )
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/bigquery/dbapi/cursor.py:205, in Cursor._execute(self, formatted_operation, parameters, job_id, job_config, parameter_types)
#     204 except google.cloud.exceptions.GoogleCloudError as exc:
# --> 205     raise exceptions.DatabaseError(exc)
#     207 query_results = self._query_job._query_results
#
# DatabaseError: 400 Syntax error: Expected ")" but got identifier "count" at [10:5]
#
# Location: us-west2
# Job ID: 2b5e7c65-3b7d-4718-91a2-1fafd04c3828
#
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('sql', '', '\nWITH\n\ncomplete_status AS (\n    select\n        name,\n        complete_static_gtfs_coverage\n    from  cal-itp-data-infra-staging.staging_views.airtable_orgs_filtered\n    where (complete_static_gtfs_coverage = 1)\n    count(*) AS `count`\n),\n\nall_status AS (\n    select\n        name,\n        complete_static_gtfs_coverage\n    from  cal-itp-data-infra-staging.staging_views.airtable_orgs_filtered\n    count(*) AS `count`\n)\n\nSELECT\n    100.0 * complete_status.count / all_status.count AS `percent`\nFROM all_status\n')
#
# File /opt/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2358, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2356 with self.builtin_trap:
#    2357     args = (magic_arg_s, cell)
# -> 2358     result = fn(*args, **kwargs)
#    2359 return result
#
# File /opt/conda/lib/python3.10/site-packages/calitp/magics.py:28, in sql(line, cell)
#      24 if args.markdown:
#      25     # print out a markdown object
#      26     display(Markdown(f"""```SQL\n{cell}\n```"""))
# ---> 28 res = query_sql(cell)
#      30 if args.output:
#      31     # if output variable specified, set it as the result in IPython
#      32     shell = get_ipython()
#
# File /opt/conda/lib/python3.10/site-packages/calitp/sql.py:142, in query_sql(fname, write_as, replace, dry_run, as_df)
#     139 engine = get_engine()
#     141 if as_df:
# --> 142     return pd.read_sql_query(sql_code, engine)
#     144 return engine.execute(sql_code)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/sql.py:399, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     341 """
#     342 Read SQL query into a DataFrame.
#     343
#    (...)
#     396 parameter will be converted to UTC.
#     397 """
#     398 pandas_sql = pandasSQL_builder(con)
# --> 399 return pandas_sql.read_query(
#     400     sql,
#     401     index_col=index_col,
#     402     params=params,
#     403     coerce_float=coerce_float,
#     404     parse_dates=parse_dates,
#     405     chunksize=chunksize,
#     406     dtype=dtype,
#     407 )
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/sql.py:1557, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1509 """
#    1510 Read SQL query into a DataFrame.
#    1511
#    (...)
#    1553
#    1554 """
#    1555 args = _convert_params(sql, params)
# -> 1557 result = self.execute(*args)
#    1558 columns = result.keys()
#    1560 if chunksize is not None:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/sql.py:1402, in SQLDatabase.execute(self, *args, **kwargs)
#    1400 def execute(self, *args, **kwargs):
#    1401     """Simple passthrough to SQLAlchemy connectable"""
# -> 1402     return self.connectable.execution_options().execute(*args, **kwargs)
#
# File <string>:2, in execute(self, statement, *multiparams, **params)
#
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/util/deprecations.py:401, in _decorate_with_warning.<locals>.warned(fn, *args, **kwargs)
#     399 if not skip_warning:
#     400     _warn_with_version(message, version, wtype, stacklevel=3)
# --> 401 return fn(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3139, in Engine.execute(self, statement, *multiparams, **params)
#    3121 """Executes the given construct and returns a
#    3122 :class:`_engine.CursorResult`.
#    3123
#    (...)
#    3136
#    3137 """
#    3138 connection = self.connect(close_with_result=True)
# -> 3139 return connection.execute(statement, *multiparams, **params)
#
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1274, in Connection.execute(self, statement, *multiparams, **params)
#    1265 if isinstance(statement, util.string_types):
#    1266     util.warn_deprecated_20(
#    1267         "Passing a string to Connection.execute() is "
#    1268         "deprecated and will be removed in version 2.0.  Use the "
#    (...)
#    1271         "driver-level SQL string."
#    1272     )
# -> 1274     return self._exec_driver_sql(
#    1275         statement,
#    1276         multiparams,
#    1277         params,
#    1278         _EMPTY_EXECUTION_OPTS,
#    1279         future=False,
#    1280     )
#    1282 try:
#    1283     meth = statement._execute_on_connection
#
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1578, in Connection._exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1568         (
#    1569             statement,
#    1570             distilled_params,
#    (...)
#    1574             statement, distilled_parameters, execution_options
#    1575         )
#    1577 dialect = self.dialect
# -> 1578 ret = self._execute_context(
#    1579     dialect,
#    1580     dialect.execution_ctx_cls._init_statement,
#    1581     statement,
#    1582     distilled_parameters,
#    1583     execution_options,
#    1584     statement,
#    1585     distilled_parameters,
#    1586 )
#    1588 if not future:
#    1589     if self._has_events or self.engine._has_events:
#
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1845, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1842             branched.close()
#    1844 except BaseException as e:
# -> 1845     self._handle_dbapi_exception(
#    1846         e, statement, parameters, cursor, context
#    1847     )
#    1849 return result
#
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2026, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2024     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2025 elif should_wrap:
# -> 2026     util.raise_(
#    2027         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2028     )
#    2029 else:
#    2030     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/util/compat.py:207, in raise_(***failed resolving arguments***)
#     204     exception.__cause__ = replace_context
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#     212     del exception, replace_context, from_, with_traceback
#
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1802, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1800                 break
#    1801     if not evt_handled:
# -> 1802         self.dialect.do_execute(
#    1803             cursor, statement, parameters, context
#    1804         )
#    1806 if self._has_events or self.engine._has_events:
#    1807     self.dispatch.after_cursor_execute(
#    1808         self,
#    1809         cursor,
#    (...)
#    1813         context.executemany,
#    1814     )
#
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/engine/default.py:719, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     718 def do_execute(self, cursor, statement, parameters, context=None):
# --> 719     cursor.execute(statement, parameters)
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/bigquery/dbapi/_helpers.py:494, in raise_on_closed.<locals>._raise_on_closed.<locals>.with_closed_check(self, *args, **kwargs)
#     492 if getattr(self, closed_attr_name):
#     493     raise exc_class(exc_msg)
# --> 494 return method(self, *args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/bigquery/dbapi/cursor.py:166, in Cursor.execute(self, operation, parameters, job_id, job_config)
#     131 """Prepare and execute a database operation.
#     132
#     133 .. note::
#    (...)
#     163         (Optional) Extra configuration options for the query job.
#     164 """
#     165 formatted_operation, parameter_types = _format_operation(operation, parameters)
# --> 166 self._execute(
#     167     formatted_operation, parameters, job_id, job_config, parameter_types
#     168 )
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/bigquery/dbapi/cursor.py:205, in Cursor._execute(self, formatted_operation, parameters, job_id, job_config, parameter_types)
#     203     self._query_job.result()
#     204 except google.cloud.exceptions.GoogleCloudError as exc:
# --> 205     raise exceptions.DatabaseError(exc)
#     207 query_results = self._query_job._query_results
#     208 self._set_rowcount(query_results)
#
# DatabaseError: (google.cloud.bigquery.dbapi.exceptions.DatabaseError) 400 Syntax error: Expected ")" but got identifier "count" at [10:5]
#
# Location: us-west2
# Job ID: 2b5e7c65-3b7d-4718-91a2-1fafd04c3828
#
# [SQL:
# WITH
#
# complete_status AS (
#     select
#         name,
#         complete_static_gtfs_coverage
#     from  cal-itp-data-infra-staging.staging_views.airtable_orgs_filtered
#     where (complete_static_gtfs_coverage = 1)
#     count(*) AS `count`
# ),
#
# all_status AS (
#     select
#         name,
#         complete_static_gtfs_coverage
#     from  cal-itp-data-infra-staging.staging_views.airtable_orgs_filtered
#     count(*) AS `count`
# )
#
# SELECT
#     100.0 * complete_status.count / all_status.count AS `percent`
# FROM all_status]
# (Background on this error at: https://sqlalche.me/e/14/4xp6)

# %%
# %%sql
# select count(*)
# where (complete_static_gtfs_coverage=1)
# from cal-itp-data-infra-staging.staging_views.airtable_orgs_filtered
# Out:
# /opt/conda/lib/python3.10/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/google/cloud/bigquery/dbapi/cursor.py:203, in Cursor._execute(self, formatted_operation, parameters, job_id, job_config, parameter_types)
#     202 try:
# --> 203     self._query_job.result()
#     204 except google.cloud.exceptions.GoogleCloudError as exc:
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/bigquery/job/query.py:1499, in QueryJob.result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1497         do_get_result = job_retry(do_get_result)
# -> 1499     do_get_result()
#    1501 except exceptions.GoogleAPICallError as exc:
#
# File /opt/conda/lib/python3.10/site-packages/google/api_core/retry.py:283, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     280 sleep_generator = exponential_sleep_generator(
#     281     self._initial, self._maximum, multiplier=self._multiplier
#     282 )
# --> 283 return retry_target(
#     284     target,
#     285     self._predicate,
#     286     sleep_generator,
#     287     self._deadline,
#     288     on_error=on_error,
#     289 )
#
# File /opt/conda/lib/python3.10/site-packages/google/api_core/retry.py:190, in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     189 try:
# --> 190     return target()
#     192 # pylint: disable=broad-except
#     193 # This function explicitly must deal with broad exceptions.
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/bigquery/job/query.py:1489, in QueryJob.result.<locals>.do_get_result()
#    1487     self._job_retry = job_retry
# -> 1489 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    1491 # Since the job could already be "done" (e.g. got a finished job
#    1492 # via client.get_job), the superclass call to done() might not
#    1493 # set the self._query_results cache.
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/bigquery/job/base.py:728, in _AsyncJob.result(self, retry, timeout)
#     727 kwargs = {} if retry is DEFAULT_RETRY else {"retry": retry}
# --> 728 return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/google/api_core/future/polling.py:137, in PollingFuture.result(self, timeout, retry)
#     134 if self._exception is not None:
#     135     # pylint: disable=raising-bad-type
#     136     # Pylint doesn't recognize that this is valid in this case.
# --> 137     raise self._exception
#     139 return self._result
#
# BadRequest: 400 Syntax error: Expected end of input but got keyword FROM at [3:1]
#
# Location: us-west2
# Job ID: 2c9e9aa1-1806-48ec-b85c-83b26942992a
#
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1802, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1801     if not evt_handled:
# -> 1802         self.dialect.do_execute(
#    1803             cursor, statement, parameters, context
#    1804         )
#    1806 if self._has_events or self.engine._has_events:
#
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/engine/default.py:719, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     718 def do_execute(self, cursor, statement, parameters, context=None):
# --> 719     cursor.execute(statement, parameters)
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/bigquery/dbapi/_helpers.py:494, in raise_on_closed.<locals>._raise_on_closed.<locals>.with_closed_check(self, *args, **kwargs)
#     493     raise exc_class(exc_msg)
# --> 494 return method(self, *args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/bigquery/dbapi/cursor.py:166, in Cursor.execute(self, operation, parameters, job_id, job_config)
#     165 formatted_operation, parameter_types = _format_operation(operation, parameters)
# --> 166 self._execute(
#     167     formatted_operation, parameters, job_id, job_config, parameter_types
#     168 )
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/bigquery/dbapi/cursor.py:205, in Cursor._execute(self, formatted_operation, parameters, job_id, job_config, parameter_types)
#     204 except google.cloud.exceptions.GoogleCloudError as exc:
# --> 205     raise exceptions.DatabaseError(exc)
#     207 query_results = self._query_job._query_results
#
# DatabaseError: 400 Syntax error: Expected end of input but got keyword FROM at [3:1]
#
# Location: us-west2
# Job ID: 2c9e9aa1-1806-48ec-b85c-83b26942992a
#
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('sql', '', 'select count(*)\nwhere (complete_static_gtfs_coverage=1)\nfrom cal-itp-data-infra-staging.staging_views.airtable_orgs_filtered\n')
#
# File /opt/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2358, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2356 with self.builtin_trap:
#    2357     args = (magic_arg_s, cell)
# -> 2358     result = fn(*args, **kwargs)
#    2359 return result
#
# File /opt/conda/lib/python3.10/site-packages/calitp/magics.py:28, in sql(line, cell)
#      24 if args.markdown:
#      25     # print out a markdown object
#      26     display(Markdown(f"""```SQL\n{cell}\n```"""))
# ---> 28 res = query_sql(cell)
#      30 if args.output:
#      31     # if output variable specified, set it as the result in IPython
#      32     shell = get_ipython()
#
# File /opt/conda/lib/python3.10/site-packages/calitp/sql.py:142, in query_sql(fname, write_as, replace, dry_run, as_df)
#     139 engine = get_engine()
#     141 if as_df:
# --> 142     return pd.read_sql_query(sql_code, engine)
#     144 return engine.execute(sql_code)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/sql.py:399, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     341 """
#     342 Read SQL query into a DataFrame.
#     343
#    (...)
#     396 parameter will be converted to UTC.
#     397 """
#     398 pandas_sql = pandasSQL_builder(con)
# --> 399 return pandas_sql.read_query(
#     400     sql,
#     401     index_col=index_col,
#     402     params=params,
#     403     coerce_float=coerce_float,
#     404     parse_dates=parse_dates,
#     405     chunksize=chunksize,
#     406     dtype=dtype,
#     407 )
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/sql.py:1557, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1509 """
#    1510 Read SQL query into a DataFrame.
#    1511
#    (...)
#    1553
#    1554 """
#    1555 args = _convert_params(sql, params)
# -> 1557 result = self.execute(*args)
#    1558 columns = result.keys()
#    1560 if chunksize is not None:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/sql.py:1402, in SQLDatabase.execute(self, *args, **kwargs)
#    1400 def execute(self, *args, **kwargs):
#    1401     """Simple passthrough to SQLAlchemy connectable"""
# -> 1402     return self.connectable.execution_options().execute(*args, **kwargs)
#
# File <string>:2, in execute(self, statement, *multiparams, **params)
#
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/util/deprecations.py:401, in _decorate_with_warning.<locals>.warned(fn, *args, **kwargs)
#     399 if not skip_warning:
#     400     _warn_with_version(message, version, wtype, stacklevel=3)
# --> 401 return fn(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3139, in Engine.execute(self, statement, *multiparams, **params)
#    3121 """Executes the given construct and returns a
#    3122 :class:`_engine.CursorResult`.
#    3123
#    (...)
#    3136
#    3137 """
#    3138 connection = self.connect(close_with_result=True)
# -> 3139 return connection.execute(statement, *multiparams, **params)
#
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1274, in Connection.execute(self, statement, *multiparams, **params)
#    1265 if isinstance(statement, util.string_types):
#    1266     util.warn_deprecated_20(
#    1267         "Passing a string to Connection.execute() is "
#    1268         "deprecated and will be removed in version 2.0.  Use the "
#    (...)
#    1271         "driver-level SQL string."
#    1272     )
# -> 1274     return self._exec_driver_sql(
#    1275         statement,
#    1276         multiparams,
#    1277         params,
#    1278         _EMPTY_EXECUTION_OPTS,
#    1279         future=False,
#    1280     )
#    1282 try:
#    1283     meth = statement._execute_on_connection
#
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1578, in Connection._exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1568         (
#    1569             statement,
#    1570             distilled_params,
#    (...)
#    1574             statement, distilled_parameters, execution_options
#    1575         )
#    1577 dialect = self.dialect
# -> 1578 ret = self._execute_context(
#    1579     dialect,
#    1580     dialect.execution_ctx_cls._init_statement,
#    1581     statement,
#    1582     distilled_parameters,
#    1583     execution_options,
#    1584     statement,
#    1585     distilled_parameters,
#    1586 )
#    1588 if not future:
#    1589     if self._has_events or self.engine._has_events:
#
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1845, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1842             branched.close()
#    1844 except BaseException as e:
# -> 1845     self._handle_dbapi_exception(
#    1846         e, statement, parameters, cursor, context
#    1847     )
#    1849 return result
#
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2026, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2024     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2025 elif should_wrap:
# -> 2026     util.raise_(
#    2027         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2028     )
#    2029 else:
#    2030     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/util/compat.py:207, in raise_(***failed resolving arguments***)
#     204     exception.__cause__ = replace_context
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#     212     del exception, replace_context, from_, with_traceback
#
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1802, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1800                 break
#    1801     if not evt_handled:
# -> 1802         self.dialect.do_execute(
#    1803             cursor, statement, parameters, context
#    1804         )
#    1806 if self._has_events or self.engine._has_events:
#    1807     self.dispatch.after_cursor_execute(
#    1808         self,
#    1809         cursor,
#    (...)
#    1813         context.executemany,
#    1814     )
#
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/engine/default.py:719, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     718 def do_execute(self, cursor, statement, parameters, context=None):
# --> 719     cursor.execute(statement, parameters)
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/bigquery/dbapi/_helpers.py:494, in raise_on_closed.<locals>._raise_on_closed.<locals>.with_closed_check(self, *args, **kwargs)
#     492 if getattr(self, closed_attr_name):
#     493     raise exc_class(exc_msg)
# --> 494 return method(self, *args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/bigquery/dbapi/cursor.py:166, in Cursor.execute(self, operation, parameters, job_id, job_config)
#     131 """Prepare and execute a database operation.
#     132
#     133 .. note::
#    (...)
#     163         (Optional) Extra configuration options for the query job.
#     164 """
#     165 formatted_operation, parameter_types = _format_operation(operation, parameters)
# --> 166 self._execute(
#     167     formatted_operation, parameters, job_id, job_config, parameter_types
#     168 )
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/bigquery/dbapi/cursor.py:205, in Cursor._execute(self, formatted_operation, parameters, job_id, job_config, parameter_types)
#     203     self._query_job.result()
#     204 except google.cloud.exceptions.GoogleCloudError as exc:
# --> 205     raise exceptions.DatabaseError(exc)
#     207 query_results = self._query_job._query_results
#     208 self._set_rowcount(query_results)
#
# DatabaseError: (google.cloud.bigquery.dbapi.exceptions.DatabaseError) 400 Syntax error: Expected end of input but got keyword FROM at [3:1]
#
# Location: us-west2
# Job ID: 2c9e9aa1-1806-48ec-b85c-83b26942992a
#
# [SQL: select count(*)
# where (complete_static_gtfs_coverage=1)
# from cal-itp-data-infra-staging.staging_views.airtable_orgs_filtered]
# (Background on this error at: https://sqlalche.me/e/14/4xp6)

# %%
# %%sql
#
# select
#     name,
#     complete_static_gtfs_coverage
# count(*)
# from  cal-itp-data-infra-staging.staging_views.airtable_orgs_filtered
# Out:
# /opt/conda/lib/python3.10/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/google/cloud/bigquery/dbapi/cursor.py:203, in Cursor._execute(self, formatted_operation, parameters, job_id, job_config, parameter_types)
#     202 try:
# --> 203     self._query_job.result()
#     204 except google.cloud.exceptions.GoogleCloudError as exc:
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/bigquery/job/query.py:1499, in QueryJob.result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1497         do_get_result = job_retry(do_get_result)
# -> 1499     do_get_result()
#    1501 except exceptions.GoogleAPICallError as exc:
#
# File /opt/conda/lib/python3.10/site-packages/google/api_core/retry.py:283, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     280 sleep_generator = exponential_sleep_generator(
#     281     self._initial, self._maximum, multiplier=self._multiplier
#     282 )
# --> 283 return retry_target(
#     284     target,
#     285     self._predicate,
#     286     sleep_generator,
#     287     self._deadline,
#     288     on_error=on_error,
#     289 )
#
# File /opt/conda/lib/python3.10/site-packages/google/api_core/retry.py:190, in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     189 try:
# --> 190     return target()
#     192 # pylint: disable=broad-except
#     193 # This function explicitly must deal with broad exceptions.
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/bigquery/job/query.py:1489, in QueryJob.result.<locals>.do_get_result()
#    1487     self._job_retry = job_retry
# -> 1489 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    1491 # Since the job could already be "done" (e.g. got a finished job
#    1492 # via client.get_job), the superclass call to done() might not
#    1493 # set the self._query_results cache.
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/bigquery/job/base.py:728, in _AsyncJob.result(self, retry, timeout)
#     727 kwargs = {} if retry is DEFAULT_RETRY else {"retry": retry}
# --> 728 return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/google/api_core/future/polling.py:137, in PollingFuture.result(self, timeout, retry)
#     134 if self._exception is not None:
#     135     # pylint: disable=raising-bad-type
#     136     # Pylint doesn't recognize that this is valid in this case.
# --> 137     raise self._exception
#     139 return self._result
#
# BadRequest: 400 Syntax error: Expected end of input but got "(" at [5:6]
#
# Location: us-west2
# Job ID: 4c264744-ec1f-42ca-802f-e1e759dd2d34
#
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1802, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1801     if not evt_handled:
# -> 1802         self.dialect.do_execute(
#    1803             cursor, statement, parameters, context
#    1804         )
#    1806 if self._has_events or self.engine._has_events:
#
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/engine/default.py:719, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     718 def do_execute(self, cursor, statement, parameters, context=None):
# --> 719     cursor.execute(statement, parameters)
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/bigquery/dbapi/_helpers.py:494, in raise_on_closed.<locals>._raise_on_closed.<locals>.with_closed_check(self, *args, **kwargs)
#     493     raise exc_class(exc_msg)
# --> 494 return method(self, *args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/bigquery/dbapi/cursor.py:166, in Cursor.execute(self, operation, parameters, job_id, job_config)
#     165 formatted_operation, parameter_types = _format_operation(operation, parameters)
# --> 166 self._execute(
#     167     formatted_operation, parameters, job_id, job_config, parameter_types
#     168 )
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/bigquery/dbapi/cursor.py:205, in Cursor._execute(self, formatted_operation, parameters, job_id, job_config, parameter_types)
#     204 except google.cloud.exceptions.GoogleCloudError as exc:
# --> 205     raise exceptions.DatabaseError(exc)
#     207 query_results = self._query_job._query_results
#
# DatabaseError: 400 Syntax error: Expected end of input but got "(" at [5:6]
#
# Location: us-west2
# Job ID: 4c264744-ec1f-42ca-802f-e1e759dd2d34
#
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('sql', '', '\nselect\n    name,\n    complete_static_gtfs_coverage\ncount(*)\nfrom  cal-itp-data-infra-staging.staging_views.airtable_orgs_filtered\n')
#
# File /opt/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2358, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2356 with self.builtin_trap:
#    2357     args = (magic_arg_s, cell)
# -> 2358     result = fn(*args, **kwargs)
#    2359 return result
#
# File /opt/conda/lib/python3.10/site-packages/calitp/magics.py:28, in sql(line, cell)
#      24 if args.markdown:
#      25     # print out a markdown object
#      26     display(Markdown(f"""```SQL\n{cell}\n```"""))
# ---> 28 res = query_sql(cell)
#      30 if args.output:
#      31     # if output variable specified, set it as the result in IPython
#      32     shell = get_ipython()
#
# File /opt/conda/lib/python3.10/site-packages/calitp/sql.py:142, in query_sql(fname, write_as, replace, dry_run, as_df)
#     139 engine = get_engine()
#     141 if as_df:
# --> 142     return pd.read_sql_query(sql_code, engine)
#     144 return engine.execute(sql_code)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/sql.py:399, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     341 """
#     342 Read SQL query into a DataFrame.
#     343
#    (...)
#     396 parameter will be converted to UTC.
#     397 """
#     398 pandas_sql = pandasSQL_builder(con)
# --> 399 return pandas_sql.read_query(
#     400     sql,
#     401     index_col=index_col,
#     402     params=params,
#     403     coerce_float=coerce_float,
#     404     parse_dates=parse_dates,
#     405     chunksize=chunksize,
#     406     dtype=dtype,
#     407 )
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/sql.py:1557, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1509 """
#    1510 Read SQL query into a DataFrame.
#    1511
#    (...)
#    1553
#    1554 """
#    1555 args = _convert_params(sql, params)
# -> 1557 result = self.execute(*args)
#    1558 columns = result.keys()
#    1560 if chunksize is not None:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/sql.py:1402, in SQLDatabase.execute(self, *args, **kwargs)
#    1400 def execute(self, *args, **kwargs):
#    1401     """Simple passthrough to SQLAlchemy connectable"""
# -> 1402     return self.connectable.execution_options().execute(*args, **kwargs)
#
# File <string>:2, in execute(self, statement, *multiparams, **params)
#
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/util/deprecations.py:401, in _decorate_with_warning.<locals>.warned(fn, *args, **kwargs)
#     399 if not skip_warning:
#     400     _warn_with_version(message, version, wtype, stacklevel=3)
# --> 401 return fn(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3139, in Engine.execute(self, statement, *multiparams, **params)
#    3121 """Executes the given construct and returns a
#    3122 :class:`_engine.CursorResult`.
#    3123
#    (...)
#    3136
#    3137 """
#    3138 connection = self.connect(close_with_result=True)
# -> 3139 return connection.execute(statement, *multiparams, **params)
#
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1274, in Connection.execute(self, statement, *multiparams, **params)
#    1265 if isinstance(statement, util.string_types):
#    1266     util.warn_deprecated_20(
#    1267         "Passing a string to Connection.execute() is "
#    1268         "deprecated and will be removed in version 2.0.  Use the "
#    (...)
#    1271         "driver-level SQL string."
#    1272     )
# -> 1274     return self._exec_driver_sql(
#    1275         statement,
#    1276         multiparams,
#    1277         params,
#    1278         _EMPTY_EXECUTION_OPTS,
#    1279         future=False,
#    1280     )
#    1282 try:
#    1283     meth = statement._execute_on_connection
#
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1578, in Connection._exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1568         (
#    1569             statement,
#    1570             distilled_params,
#    (...)
#    1574             statement, distilled_parameters, execution_options
#    1575         )
#    1577 dialect = self.dialect
# -> 1578 ret = self._execute_context(
#    1579     dialect,
#    1580     dialect.execution_ctx_cls._init_statement,
#    1581     statement,
#    1582     distilled_parameters,
#    1583     execution_options,
#    1584     statement,
#    1585     distilled_parameters,
#    1586 )
#    1588 if not future:
#    1589     if self._has_events or self.engine._has_events:
#
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1845, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1842             branched.close()
#    1844 except BaseException as e:
# -> 1845     self._handle_dbapi_exception(
#    1846         e, statement, parameters, cursor, context
#    1847     )
#    1849 return result
#
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2026, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2024     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2025 elif should_wrap:
# -> 2026     util.raise_(
#    2027         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2028     )
#    2029 else:
#    2030     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/util/compat.py:207, in raise_(***failed resolving arguments***)
#     204     exception.__cause__ = replace_context
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#     212     del exception, replace_context, from_, with_traceback
#
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1802, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1800                 break
#    1801     if not evt_handled:
# -> 1802         self.dialect.do_execute(
#    1803             cursor, statement, parameters, context
#    1804         )
#    1806 if self._has_events or self.engine._has_events:
#    1807     self.dispatch.after_cursor_execute(
#    1808         self,
#    1809         cursor,
#    (...)
#    1813         context.executemany,
#    1814     )
#
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/engine/default.py:719, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     718 def do_execute(self, cursor, statement, parameters, context=None):
# --> 719     cursor.execute(statement, parameters)
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/bigquery/dbapi/_helpers.py:494, in raise_on_closed.<locals>._raise_on_closed.<locals>.with_closed_check(self, *args, **kwargs)
#     492 if getattr(self, closed_attr_name):
#     493     raise exc_class(exc_msg)
# --> 494 return method(self, *args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/bigquery/dbapi/cursor.py:166, in Cursor.execute(self, operation, parameters, job_id, job_config)
#     131 """Prepare and execute a database operation.
#     132
#     133 .. note::
#    (...)
#     163         (Optional) Extra configuration options for the query job.
#     164 """
#     165 formatted_operation, parameter_types = _format_operation(operation, parameters)
# --> 166 self._execute(
#     167     formatted_operation, parameters, job_id, job_config, parameter_types
#     168 )
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/bigquery/dbapi/cursor.py:205, in Cursor._execute(self, formatted_operation, parameters, job_id, job_config, parameter_types)
#     203     self._query_job.result()
#     204 except google.cloud.exceptions.GoogleCloudError as exc:
# --> 205     raise exceptions.DatabaseError(exc)
#     207 query_results = self._query_job._query_results
#     208 self._set_rowcount(query_results)
#
# DatabaseError: (google.cloud.bigquery.dbapi.exceptions.DatabaseError) 400 Syntax error: Expected end of input but got "(" at [5:6]
#
# Location: us-west2
# Job ID: 4c264744-ec1f-42ca-802f-e1e759dd2d34
#
# [SQL:
# select
#     name,
#     complete_static_gtfs_coverage
# count(*)
# from  cal-itp-data-infra-staging.staging_views.airtable_orgs_filtered]
# (Background on this error at: https://sqlalche.me/e/14/4xp6)

# %%
# %%sql

# CREATE TABLE orgs(tbl.airtable.california_transit_organizations())

# %%
# test = query_sql("""
# SELECT
#     *
# FROM `airtable.california_transit_organizations`
# LIMIT 10""", as_df=True)

# %%
# query_sql(
#         """
#         SELECT 
#         *
#         FROM airtable.california_transit_organizations
#         WHERE reporting_category = 'Core' 
#             OR
#              reporting_category = 'Other Public Transit'
#         ;
#         """
#     )

# %%
# %%sql
# select 
#     name,
#     service_type__from_mobility_services_managed_
# from cal-itp-data-infra-staging.staging_views.airtable_org_subset
# where 'fixed-route' in unnest(service_type__from_mobility_services_managed_)

# %%
# %%sql

# select
#     name, 
#     service_type__from_mobility_services_managed_
# from airtable.california_transit_organizations
# where 
#     contains(service_type__from_mobility_services_managed_, "fixed-route")

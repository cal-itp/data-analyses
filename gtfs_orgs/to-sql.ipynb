# %%
# To SQL

# %%
from calitp.tables import tbl
from siuba import *
import pandas as pd

import utils
# Out:
# /opt/conda/lib/python3.10/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
from calitp import query_sql, magics

# %%
pd.set_option("display.max_columns", 100)

# %%
org_df = collect(tbl.airtable.california_transit_organizations())

# %%
org_df.sample()
# Out:
#       organization_id                          name mobility_services_managed  \
# 34  rec5K4l3XlE1cSwy4  Transportation Concepts Inc.                      None
#
#    parent_organization organization_type headquarters_place caltrans_district  \
# 34                None           Company               None              None
#
#    planning_authority tracking_category reporting_category assist_category  \
# 34               None              None               None            None
#
#    headquarters_state_country      record_creation_time  \
# 34                       None  2021-09-27T17:37:01.000Z
#
#    service_type__from_mobility_services_managed_  \
# 34                                          None
#
#    currently_operating__from_mobility_services_managed_  \
# 34                                               None
#
#    funding_sources_for_managed_transportation  num_fixed_route_services  \
# 34                                       None                         0
#
#     num_services_w_complete_rt_status  num_fixed_route_services_w_static_gtfs  \
# 34                                  0                                       0
#
#     complete_static_gtfs_coverage  complete_rt_coverage  \
# 34                              1                     1
#
#     at_least_one_gtfs_feed_for_any_service  at_least_one_complete_rt_set  \
# 34                                       0                             0
#
#    service_availability_category__from_mobility_services_managed_  \
# 34                                               None
#
#     num_fixed_route_or_deviated_fixed_route_services  \
# 34                                                 0
#
#     num_fixed_route_or_deviated_fixed_route_service_w__static_gtfs  \
# 34                                                  0
#
#     num_services_with_missing_static_feed_for_fixed_route_or_deviated_fixed_route  \
# 34                                                  0
#
#    gtfs_static_status gtfs_realtime_status missing_static  \
# 34          Static OK        RT Incomplete             []
#
#    services_needing_alerts services_needing_tripupdates_or_vehiclepositions  \
# 34                      []                                               []
#
#    service_availability fixed_route_service_operator_type  schedule_datasets  \
# 34                 None                                []                  0
#
#     itp_id gtfs_datasets_produced  \
# 34     NaN                   None
#
#                            mobility_services_operated ntp_id mpo_rtpa  \
# 34  ['rec2Yol256Rn0BgHF', 'recr3rQ6qKfk8SRP6', 're...   None     None
#
#    gtfs_datasets_referenced  \
# 34                     None
#
#    currently_operating__from_mobility_services_operated_  \
# 34                                 [True, True, True]
#
#        service_type__from_mobility_services_operated_ total_voms__ntd_  \
# 34  ['on-demand', 'fixed-route', 'ADA paratransit'...             None
#
#    service_area_sq_miles__ntd_ service_area_population__ntd_  \
# 34                        None                          None
#
#    gtfs_dataset__from_mobility_services_managed_ gtfs_schedule_status  \
# 34                                          None                 None
#
#    fares_v2_status flex_status immediate_gtfs_goals details website  \
# 34            None        None                 None    None    None
#
#    funding_programs county_geography fare_systems drmt_organization_name  \
# 34             None             None         None                   None
#
#    drmt_reported_5310_vehicles opm_id_drmt alias service___component brand  \
# 34                        None        None  None                None  None
#
#    roles county_geography_3 dotid administrating_organization  \
# 34  None               None  None                        None
#
#    service_area_type__from_services_  \
# 34                              None
#
#    avl_rti_vendor__from_service_area_type__from_services__  \
# 34                                               None
#
#    currently_operating__from_service_area_type__from_services__ services  \
# 34                                               None               None
#
#    eligibility_programs
# 34                 None

# %%
# %%sql
#
# select count(*) from airtable.california_transit_organizations
# Out:
# /opt/conda/lib/python3.10/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
#    f0_
# 0  857

# %%
# testing new view

# %%
# %%sql
# with new_view as (
# select
#     name,
#     reporting_category,
#     organization_type,
#     caltrans_district,
#     ntp_id,
#     itp_id,
#     opm_id_drmt,
#     brand,
#     alias,
#     reporting_category,
#     fares_v2_status,
#     mobility_services_managed,
#     mobility_services_operated,
#     gtfs_datasets_produced,
#     service_type__from_mobility_services_managed_,
#     service_type__from_mobility_services_operated_,
#     currently_operating__from_mobility_services_managed_,
#     headquarters_place,
#     funding_sources_for_managed_transportation,
#     caltrans_district,
#     gtfs_dataset__from_mobility_services_managed_,
#     gtfs_schedule_status,
#     gtfs_static_status,
#     gtfs_realtime_status
# from airtable.california_transit_organizations
# )
#
# select * from new_view
# limit 10
# Out:
# /opt/conda/lib/python3.10/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
#                                       name reporting_category  \
# 0  Consolidated Tribal Health Project Inc.               None
# 1                               Everbridge               None
# 2                    City of Santa Barbara               None
# 3                          Connexionz Inc.               None
# 4                   Area 1 Agency on Aging               None
# 5                            City of Poway               None
# 6                    Empire Transportation               None
# 7                  Southland Transit, Inc.               None
# 8                                Interline               None
# 9                    City of National City               None
#
#          organization_type caltrans_district ntp_id  itp_id opm_id_drmt brand  \
# 0  Non-Profit Organization              None   None     NaN        None  None
# 1                     None              None   None     NaN        None  None
# 2                City/Town              None   None     NaN        None  None
# 3                  Company              None   None     NaN        None  None
# 4                     None              None   None   399.0        None  None
# 5                City/Town              None   None     NaN        None  None
# 6                     None              None   None     NaN        None  None
# 7                     None              None   None     NaN        None  None
# 8                  Company              None   None     NaN        None  None
# 9                City/Town              None   None     NaN        None  None
#
#   alias reporting_category_1 fares_v2_status mobility_services_managed  \
# 0  None                 None            None                      None
# 1  None                 None            None                      None
# 2  None                 None            None                      None
# 3  None                 None            None                      None
# 4  None                 None            None                      None
# 5  None                 None            None                      None
# 6  None                 None            None                      None
# 7  None                 None            None                      None
# 8  None                 None            None                      None
# 9  None                 None            None                      None
#
#   mobility_services_operated  \
# 0                       None
# 1                       None
# 2                       None
# 3                       None
# 4                       None
# 5                       None
# 6                       None
# 7                       None
# 8                       None
# 9                       None
#
#                               gtfs_datasets_produced  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  ['recHC7bwsgTPqLjX4', 'rec6hxEPTcBpIFWFX', 're...
# 4                                               None
# 5                                               None
# 6                                               None
# 7                                               None
# 8                                               None
# 9                                               None
#
#   service_type__from_mobility_services_managed_  \
# 0                                          None
# 1                                          None
# 2                                          None
# 3                                          None
# 4                                          None
# 5                                          None
# 6                                          None
# 7                                          None
# 8                                          None
# 9                                          None
#
#   service_type__from_mobility_services_operated_  \
# 0                                           None
# 1                                           None
# 2                                           None
# 3                                           None
# 4                                           None
# 5                                           None
# 6                                           None
# 7                                           None
# 8                                           None
# 9                                           None
#
#   currently_operating__from_mobility_services_managed_  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6                                               None
# 7                                               None
# 8                                               None
# 9                                               None
#
#           headquarters_place funding_sources_for_managed_transportation  \
# 0                       None                                       None
# 1                       None                                       None
# 2              Santa Barbara                                       None
# 3  Santa Clarita, California                                       None
# 4                       None                                       None
# 5                      Poway                                       None
# 6                       None                                       None
# 7                       None                                       None
# 8                    Alameda                                       None
# 9              National City                                       None
#
#   caltrans_district_1 gtfs_dataset__from_mobility_services_managed_  \
# 0                None                                          None
# 1                None                                          None
# 2                None                                          None
# 3                None                                          None
# 4                None                                          None
# 5                None                                          None
# 6                None                                          None
# 7                None                                          None
# 8                None                                          None
# 9                None                                          None
#
#   gtfs_schedule_status gtfs_static_status gtfs_realtime_status
# 0                 None          Static OK        RT Incomplete
# 1                 None          Static OK        RT Incomplete
# 2                 None          Static OK        RT Incomplete
# 3                 None          Static OK        RT Incomplete
# 4                 None          Static OK        RT Incomplete
# 5                 None          Static OK        RT Incomplete
# 6                 None          Static OK        RT Incomplete
# 7                 None          Static OK        RT Incomplete
# 8                 None          Static OK        RT Incomplete
# 9                 None          Static OK        RT Incomplete

# %%
# %%sql
# select
#     *
# from cal-itp-data-infra-staging.staging_views.airtable_org_subset
# where (reporting_category = 'Core'
#     or
#     reporting_category = 'Other Public Transit')
#      and (service_type__from_mobility_services_managed_ like '%fixed-route%'
#        or service_type__from_mobility_services_managed_ like '%deviated fixed-route%'
#          or  service_type__from_mobility_services_managed_ like '%on-demand fixed-route%')
#      and
#     funding_sources_for_managed_transportation like ('%public%')
#     and
#     currently_operating__from_mobility_services_managed_ like ('%True%')
# Out:
# /opt/conda/lib/python3.10/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
#                                                 name    reporting_category  \
# 0                                  City of Morro Bay  Other Public Transit
# 1                    San Diego International Airport  Other Public Transit
# 2    Santa Barbara County Association of Governments                  Core
# 3                                        Commute.org  Other Public Transit
# 4                                Menlo Park Shuttles  Other Public Transit
# ..                                               ...                   ...
# 184                    Marin County Transit District                  Core
# 185                                      Kern County                  Core
# 186      San Luis Obispo Regional Transit Authority                   Core
# 187                               Los Angeles County                  Core
# 188               Fresno County Rural Transit Agency                  Core
#
#       organization_type     caltrans_district                 ntp_id  itp_id  \
# 0             City/Town  05 - San Luis Obispo                   None   213.0
# 1    Independent Agency        11 - San Diego                   None   277.0
# 2                  None  05 - San Luis Obispo                   None   379.0
# 3                  None          04 - Oakland                   None    76.0
# 4                  None          04 - Oakland                   None   199.0
# ..                  ...                   ...                    ...     ...
# 184  Independent Agency          04 - Oakland  ['recgeJopomk1yuLGl']   194.0
# 185              County           06 - Fresno  ['rec0OKlbrwM9ujJrP']   146.0
# 186  Independent Agency  05 - San Luis Obispo  ['recEY3890s1LqT2b7']   289.0
# 187              County      07 - Los Angeles                   None   179.0
# 188  Independent Agency           06 - Fresno  ['rec0dqO63go6bMr2p']   117.0
#
#     opm_id_drmt              brand  \
# 0        540002  Morro Bay Transit
# 1          None               None
# 2        542006               None
# 3          None               None
# 4          None               None
# ..          ...                ...
# 184      421002               None
# 185      615006       Kern Transit
# 186      540005       SoCo Transit
# 187      719031               None
# 188      610004               None
#
#                                                  alias  reporting_category_1  \
# 0                                                 None  Other Public Transit
# 1                                              ['SAN']  Other Public Transit
# 2                                            ['SBCAG']                  Core
# 3                                                 None  Other Public Transit
# 4                                                 None  Other Public Transit
# ..                                                 ...                   ...
# 184                                               None                  Core
# 185                                               None                  Core
# 186                                         ['SLORTA']                  Core
# 187  ['LA DPW', 'LA County', 'Los Angeles DPW', 'Lo...                  Core
# 188                                          ['FCRTA']                  Core
#
#                                        fares_v2_status  \
# 0                               ['Unknown', 'Unknown']
# 1                                          ['Unknown']
# 2                               ['Provider published']
# 3                                 ['Vendor published']
# 4                              ['Provider to Publish']
# ..                                                 ...
# 184  ['Vendor published', 'Vendor published', 'Vend...
# 185                               ['Vendor published']
# 186  ['Provider published', 'Provider published', '...
# 187  ['Vendor published', 'Vendor published', 'Vend...
# 188  ['Unknown', 'Unknown', 'Unknown', 'Unknown', '...
#
#                              mobility_services_managed  \
# 0           ['recSp27U6s31QJSKN', 'recZslL9QXbd9kWoS']
# 1                                ['recrwkklZVuk57tIs']
# 2                                ['reckGaGjCuKV9WdPC']
# 3                                ['recIrgn5BhgpwnULH']
# 4                                ['recZHDDuxsj5gtRtW']
# ..                                                 ...
# 184  ['recIGK0lAob3SPAbL', 'recub3E01v5DjPVSx', 're...
# 185  ['recerP7m633Uw5v4z', 'recVGVlWZd7NCFBKv', 're...
# 186  ['recAvUfY0smr0BPel', 'recqNh8cK4CRyZNjx', 're...
# 187  ['rec1Vnz3gmw9TP7O2', 'rectLhNGCReNovxSm', 're...
# 188  ['recCJ9Jb4Jrr5Np9V', 'rechir3GPKKadXawT', 're...
#
#                             mobility_services_operated  \
# 0           ['recSp27U6s31QJSKN', 'recZslL9QXbd9kWoS']
# 1                                ['recrwkklZVuk57tIs']
# 2                                ['reckGaGjCuKV9WdPC']
# 3                                ['recIrgn5BhgpwnULH']
# 4                                                 None
# ..                                                 ...
# 184  ['recub3E01v5DjPVSx', 'recDXjxxSVSBlD6MR', 're...
# 185  ['recerP7m633Uw5v4z', 'recVGVlWZd7NCFBKv', 're...
# 186  ['recqNh8cK4CRyZNjx', 'recK0My4JUzrJrueY', 're...
# 187  ['rec1i8Iwnu6mo24zt', 'recCWXf3GLoXf3PFF', 're...
# 188                              ['recotdBBhu10g67V6']
#
#                                 gtfs_datasets_produced  \
# 0                                ['recakkevxj5vOACjk']
# 1                                                 None
# 2                                ['recLhUJUDjFXcmOte']
# 3                                ['recOdlAUeG1fIkFcr']
# 4                                ['recUbZwXK2rjDmiua']
# ..                                                 ...
# 184  ['recOKNFbyRBuF6OZE', 'recvs9EVakYTtIaNJ', 're...
# 185                              ['recQiWHhvE6MxozGV']
# 186                              ['recHC7bwsgTPqLjX4']
# 187                              ['recUjYd23khxh0r9v']
# 188                                               None
#
#          service_type__from_mobility_services_managed_  \
# 0    ['fixed-route', 'deviated fixed-route', 'fixed...
# 1                                      ['fixed-route']
# 2                                      ['fixed-route']
# 3                                      ['fixed-route']
# 4                         ['fixed-route', 'on-demand']
# ..                                                 ...
# 184  ['ADA paratransit', 'fixed-route', 'fixed-rout...
# 185  ['fixed-route', 'on-demand', 'ADA paratransit'...
# 186  ['fixed-route', 'deviated fixed-route', 'reser...
# 187  ['fixed-route', 'fixed-route', 'fixed-route', ...
# 188  ['on-demand', 'on-demand', 'reservations', 'on...
#
#         service_type__from_mobility_services_operated_  \
# 0    ['fixed-route', 'deviated fixed-route', 'fixed...
# 1                                      ['fixed-route']
# 2                                      ['fixed-route']
# 3                                      ['fixed-route']
# 4                                                 None
# ..                                                 ...
# 184  ['fixed-route', 'deviated fixed-route', 'ADA p...
# 185  ['fixed-route', 'on-demand', 'ADA paratransit'...
# 186  ['fixed-route', 'fixed-route', 'fixed-route', ...
# 187  ['fixed-route', 'fixed-route', 'fixed-route', ...
# 188                    ['fixed-route', 'reservations']
#
#     currently_operating__from_mobility_services_managed_   headquarters_place  \
# 0                                         [True, True]              Morro Bay
# 1                                               [True]              San Diego
# 2                                               [True]          Santa Barbara
# 3                                               [True]    South San Francisco
# 4                                               [True]             Menlo Park
# ..                                                 ...                    ...
# 184  [True, True, True, True, True, True, True, Tru...              San Rafae
# 185  [True, True, True, True, True, True, True, Tru...            Bakersfield
# 186  [True, True, True, None, True, True, True, Tru...        San Luis Obispo
# 187  [True, True, True, True, True, True, True, Tru...            Los Angeles
# 188  [True, True, True, True, True, True, True, Tru...                 Fresno
#
#             funding_sources_for_managed_transportation   caltrans_district_1  \
# 0                                 ['public', 'public']  05 - San Luis Obispo
# 1                                           ['public']        11 - San Diego
# 2                                           ['public']  05 - San Luis Obispo
# 3                                           ['public']          04 - Oakland
# 4                                           ['public']          04 - Oakland
# ..                                                 ...                   ...
# 184  ['public', 'public', 'public', 'public', 'publ...          04 - Oakland
# 185  ['public', 'public', 'public', 'public', 'publ...           06 - Fresno
# 186  ['public', 'public', 'public', 'public', 'publ...  05 - San Luis Obispo
# 187  ['public', 'public', 'public', 'public', 'publ...      07 - Los Angeles
# 188  ['public', 'public', 'public', 'public', 'publ...           06 - Fresno
#
#          gtfs_dataset__from_mobility_services_managed_  \
# 0           ['recakkevxj5vOACjk', 'recakkevxj5vOACjk']
# 1                                ['recfZ9iWkptccoONX']
# 2                                ['recLhUJUDjFXcmOte']
# 3                                ['rec9AyXUSMUHFnLsH']
# 4                                ['recUbZwXK2rjDmiua']
# ..                                                 ...
# 184  ['rec9AyXUSMUHFnLsH', 'recAQiomSPtajnjLy', 're...
# 185                              ['recQiWHhvE6MxozGV']
# 186  ['recHC7bwsgTPqLjX4', 'recHC7bwsgTPqLjX4', 're...
# 187  ['recUjYd23khxh0r9v', 'recUjYd23khxh0r9v', 're...
# 188  ['reck5oNvonO2H8iQo', 'reck5oNvonO2H8iQo', 're...
#
#                                   gtfs_schedule_status gtfs_static_status  \
# 0                                                 None          Static OK
# 1                                                 None          Static OK
# 2                                               ['ok']          Static OK
# 3                                               ['ok']          Static OK
# 4                                               ['ok']          Static OK
# ..                                                 ...                ...
# 184  ['needed', 'ok', 'needed', 'needed', 'needed',...  Static Incomplete
# 185  ['ok', 'needed', 'needed', 'needed', 'needed',...          Static OK
# 186  ['ok', 'ok', 'ok', 'needed', 'needed', 'needed...          Static OK
# 187  ['ok', 'ok', 'ok', 'ok', 'ok', 'needed', 'ok',...          Static OK
# 188  ['needed', 'needed', 'ok', 'ok', 'needed', 'ok...  Static Incomplete
#
#     gtfs_realtime_status
# 0          RT Incomplete
# 1          RT Incomplete
# 2          RT Incomplete
# 3          RT Incomplete
# 4          RT Incomplete
# ..                   ...
# 184                RT OK
# 185        RT Incomplete
# 186        RT Incomplete
# 187        RT Incomplete
# 188        RT Incomplete
#
# [189 rows x 24 columns]

# %%
# %%sql
# select
#     name,
#     currently_operating__from_mobility_services_managed_,
#     reporting_category,
#     service_type__from_mobility_services_managed_,
#     funding_sources_for_managed_transportation
# from cal-itp-data-infra-staging.staging_views.airtable_org_subset
# where (reporting_category = 'Core'
#     or
#     reporting_category = 'Other Public Transit')
#      and (service_type__from_mobility_services_managed_ like '%fixed-route%'
#        or service_type__from_mobility_services_managed_ like '%deviated fixed-route%'
#          or  service_type__from_mobility_services_managed_ like '%on-demand fixed-route%')
#      and
#     funding_sources_for_managed_transportation like ('%public%')
#     and
#     currently_operating__from_mobility_services_managed_ like ('%True%')
# Out:
# /opt/conda/lib/python3.10/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
#                                                 name  \
# 0                                  City of Morro Bay
# 1                    San Diego International Airport
# 2    Santa Barbara County Association of Governments
# 3                                        Commute.org
# 4                                Menlo Park Shuttles
# ..                                               ...
# 184                    Marin County Transit District
# 185                                      Kern County
# 186      San Luis Obispo Regional Transit Authority
# 187                               Los Angeles County
# 188               Fresno County Rural Transit Agency
#
#     currently_operating__from_mobility_services_managed_  \
# 0                                         [True, True]
# 1                                               [True]
# 2                                               [True]
# 3                                               [True]
# 4                                               [True]
# ..                                                 ...
# 184  [True, True, True, True, True, True, True, Tru...
# 185  [True, True, True, True, True, True, True, Tru...
# 186  [True, True, True, None, True, True, True, Tru...
# 187  [True, True, True, True, True, True, True, Tru...
# 188  [True, True, True, True, True, True, True, Tru...
#
#        reporting_category      service_type__from_mobility_services_managed_  \
# 0    Other Public Transit  ['fixed-route', 'deviated fixed-route', 'fixed...
# 1    Other Public Transit                                    ['fixed-route']
# 2                    Core                                    ['fixed-route']
# 3    Other Public Transit                                    ['fixed-route']
# 4    Other Public Transit                       ['fixed-route', 'on-demand']
# ..                    ...                                                ...
# 184                  Core  ['ADA paratransit', 'fixed-route', 'fixed-rout...
# 185                  Core  ['fixed-route', 'on-demand', 'ADA paratransit'...
# 186                  Core  ['fixed-route', 'deviated fixed-route', 'reser...
# 187                  Core  ['fixed-route', 'fixed-route', 'fixed-route', ...
# 188                  Core  ['on-demand', 'on-demand', 'reservations', 'on...
#
#             funding_sources_for_managed_transportation
# 0                                 ['public', 'public']
# 1                                           ['public']
# 2                                           ['public']
# 3                                           ['public']
# 4                                           ['public']
# ..                                                 ...
# 184  ['public', 'public', 'public', 'public', 'publ...
# 185  ['public', 'public', 'public', 'public', 'publ...
# 186  ['public', 'public', 'public', 'public', 'publ...
# 187  ['public', 'public', 'public', 'public', 'publ...
# 188  ['public', 'public', 'public', 'public', 'publ...
#
# [189 rows x 5 columns]

# %% [markdown]
# * Adding to GCS

# %%
## SERVICES
#tbl.airtable.california_transit_services()

# %%
## Check `currently_operating__from_mobility_services_managed_`

# %%
org_df>>count(_.currently_operating__from_mobility_services_managed_)
# Out:
#    currently_operating__from_mobility_services_managed_    n
# 0                            [None, True, True, None]      1
# 1                                  [None, True, True]      1
# 2                                        [None, True]      2
# 3                                              [None]     19
# 4          [True, None, True, True, True, True, True]      1
# 5                                  [True, None, True]      3
# 6                                        [True, None]      3
# 7                [True, True, None, True, True, True]      1
# 8                            [True, True, None, True]      2
# 9                                  [True, True, None]      1
# 10  [True, True, True, None, True, True, True, Tru...      1
# 11                     [True, True, True, True, None]      2
# 12  [True, True, True, True, True, True, True, Tru...      1
# 13  [True, True, True, True, True, True, True, Tru...      1
# 14  [True, True, True, True, True, True, True, Tru...      5
# 15   [True, True, True, True, True, True, True, True]      4
# 16         [True, True, True, True, True, True, True]      1
# 17               [True, True, True, True, True, True]      3
# 18                     [True, True, True, True, True]     10
# 19                           [True, True, True, True]      8
# 20                                 [True, True, True]     34
# 21                                       [True, True]     87
# 22                                             [True]    259

# %%
(
    org_df
    >> filter(_.currently_operating__from_mobility_services_managed_.str.contains("false"))
    >> select(_.name, _.currently_operating__from_mobility_services_managed_)
)
# Out:
# Empty DataFrame
# Columns: [name, currently_operating__from_mobility_services_managed_]
# Index: []

# %%
# %%sql
# select
#     name,
#     currently_operating__from_mobility_services_managed_
# from cal-itp-data-infra-staging.staging_views.airtable_org_subset
# Out:
# /opt/conda/lib/python3.10/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
#                                                 name  \
# 0                                         Everbridge
# 1                             Area 1 Agency on Aging
# 2                              Empire Transportation
# 3                            Southland Transit, Inc.
# 4    Siskiyou County Local Transportation Commission
# ..                                               ...
# 848                    Marin County Transit District
# 849                                      Kern County
# 850      San Luis Obispo Regional Transit Authority
# 851                               Los Angeles County
# 852               Fresno County Rural Transit Agency
#
#     currently_operating__from_mobility_services_managed_
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 848  [True, True, True, True, True, True, True, Tru...
# 849  [True, True, True, True, True, True, True, Tru...
# 850  [True, True, True, None, True, True, True, Tru...
# 851  [True, True, True, True, True, True, True, Tru...
# 852  [True, True, True, True, True, True, True, Tru...
#
# [853 rows x 2 columns]

# %%
# %%sql
# select
#     name,
#     gtfs_static_status,
#     complete_static_gtfs_coverage
# from  cal-itp-data-infra-staging.staging_views.airtable_orgs_filtered
# where complete_static_gtfs_coverage = 1
# limit 5
# Out:
# /opt/conda/lib/python3.10/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
#                            name gtfs_static_status  \
# 0               City of Shafter          Static OK
# 1  Colusa County Transit Agency          Static OK
# 2         City of Monterey Park          Static OK
# 3          City of San Clemente          Static OK
# 4               City of Lynwood          Static OK
#
#    complete_static_gtfs_coverage
# 0                              1
# 1                              1
# 2                              1
# 3                              1
# 4                              1

# %%
(
    org_df
    >> filter(_.complete_static_gtfs_coverage == 1)
    >> count(_.complete_static_gtfs_coverage)
    >> show_query()
)
# Out:
# No query to show for a DataFrame
#    complete_static_gtfs_coverage    n
# 0                              1  788

# %%
# q = (org_df
#   >> select(_.name, _.complete_static_gtfs_coverage)
#   >> mutate(pct = ((_.complete_static_gtfs_coverage==1).count) - _.complete_static_gtfs_coverage.count())
#   >> show_query()
# )

# %%
# %%sql
#
# WITH
#
# complete_status AS (
#     select
#         count(*) AS `count`
#     from  cal-itp-data-infra-staging.staging_views.airtable_orgs_filtered
#     where (complete_static_gtfs_coverage = 1)
# ),
#
# all_status AS (
#     select
#         count(*) AS `count`
#     from  cal-itp-data-infra-staging.staging_views.airtable_orgs_filtered
# )
#
# SELECT
#     100.0 * (complete_status.count / all_status.count) AS `percent`
# FROM all_status cross join complete_status
# Out:
# /opt/conda/lib/python3.10/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
#      percent
# 0  84.126984

# %%
# %%sql
#
# WITH
#
# complete_status AS (
#     select
#         caltrans_district,
#         count(*) AS `count`
#     from  cal-itp-data-infra-staging.staging_views.airtable_orgs_filtered
#     where (complete_static_gtfs_coverage = 1)
#     group by caltrans_district
# ),
#
# all_status AS (
#     select
#         caltrans_district,
#         count(*) AS `count`
#     from  cal-itp-data-infra-staging.staging_views.airtable_orgs_filtered
#     group by caltrans_district
# )
#
# SELECT
#     caltrans_district,
#     all_status.count as `all_org`,
#     complete_status.count as `gtfs_compliant`,
#     100.0 * (complete_status.count / all_status.count) AS `percent`
# FROM all_status
# join complete_status
#     using (caltrans_district)
# Out:
# /opt/conda/lib/python3.10/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
#        caltrans_district  all_org  gtfs_compliant     percent
# 0       07 - Los Angeles       55              47   85.454545
# 1            06 - Fresno       14              12   85.714286
# 2        03 - Marysville       18              15   83.333333
# 3         11 - San Diego        6               4   66.666667
# 4           04 - Oakland       34              24   70.588235
# 5          10 - Stockton       14              13   92.857143
# 6           02 - Redding        8               7   87.500000
# 7   05 - San Luis Obispo       13              11   84.615385
# 8            12 - Irvine        6               6  100.000000
# 9    08 - San Bernardino       11              11  100.000000
# 10           09 - Bishop        2               2  100.000000
# 11           01 - Eureka        7               7  100.000000

# %%
# %%sql
#
# WITH
#
# complete_status AS (
#     select
#         caltrans_district,
#         count(*) AS `count`
#     from  cal-itp-data-infra-staging.staging_views.airtable_orgs_filtered
#     where (complete_static_gtfs_coverage = 1)
#     group by caltrans_district
# ),
#
# all_status AS (
#     select
#         caltrans_district,
#         count(*) AS `count`
#     from  cal-itp-data-infra-staging.staging_views.airtable_orgs_filtered
#     group by caltrans_district
# )
#
# SELECT
#     caltrans_district,
#     100.0 * (complete_status.count / all_status.count) AS `percent`
# FROM all_status
# join complete_status
#     using (caltrans_district)
# Out:
# /opt/conda/lib/python3.10/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
#        caltrans_district     percent
# 0       07 - Los Angeles   85.454545
# 1            06 - Fresno   85.714286
# 2        03 - Marysville   83.333333
# 3         11 - San Diego   66.666667
# 4           04 - Oakland   70.588235
# 5          10 - Stockton   92.857143
# 6           02 - Redding   87.500000
# 7   05 - San Luis Obispo   84.615385
# 8            12 - Irvine  100.000000
# 9    08 - San Bernardino  100.000000
# 10           09 - Bishop  100.000000
# 11           01 - Eureka  100.000000

# %%
# %%sql
# select count(*) as `count`
# from cal-itp-data-infra-staging.staging_views.airtable_orgs_filtered
# where (complete_static_gtfs_coverage=1)
# Out:
# /opt/conda/lib/python3.10/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
#    count
# 0    159

# %%
# %%sql

# select
#     complete_static_gtfs_coverage
#     count(*) as `count`
# from  cal-itp-data-infra-staging.staging_views.airtable_orgs_filtered
# group by complete_static_gtfs_coverage

# %%
# %%sql
# with fares_stat as (
# select
#     name,
#     caltrans_district,
#     fares_v2_status
# from cal-itp-data-infra-staging.staging_views.airtable_orgs_filtered
# )
#
# select *
# from fares_stat
# where (fares_v2_status like ('%Provider published%'))
# Out:
# /opt/conda/lib/python3.10/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
#                                               name     caltrans_district  \
# 0  Santa Barbara County Association of Governments  05 - San Luis Obispo
# 1    San Francisco Bay Area Rapid Transit District          04 - Oakland
# 2                       Los Angeles World Airports      07 - Los Angeles
# 3      San Luis Obispo Regional Transit Authority   05 - San Luis Obispo
# 4      Santa Barbara Metropolitan Transit District  05 - San Luis Obispo
# 5            Alameda-Contra Costa Transit District          04 - Oakland
#
#                                      fares_v2_status
# 0                             ['Provider published']
# 1         ['Vendor published', 'Provider published']
# 2                             ['Provider published']
# 3  ['Provider published', 'Provider published', '...
# 4                             ['Provider published']
# 5  ['Provider published', 'Vendor published', 'Pr...

# %%
# %%sql
#
# select
#     name,
#     caltrans_district,
#     fares_v2_status
# # ALTER TABLE airtable_orgs_filtered
# #   ADD COLUMN "fares_v2" BOOLEAN DEFAULT FALSE;
#     # CASE WHEN COUNT(VALUE1) = COUNT(*) THEN 1 ELSE 0 END AS fares_v2
# from cal-itp-data-infra-staging.staging_views.airtable_orgs_filtered
# Out:
# /opt/conda/lib/python3.10/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
#                                             name caltrans_district  \
# 0                                City of Artesia  07 - Los Angeles
# 1                                City of Maywood  07 - Los Angeles
# 2                               City of Cerritos  07 - Los Angeles
# 3                                City of Shafter       06 - Fresno
# 4                   Colusa County Transit Agency   03 - Marysville
# ..                                           ...               ...
# 184        Alameda-Contra Costa Transit District      04 - Oakland
# 185        San Joaquin Regional Transit District     10 - Stockton
# 186             Eastern Sierra Transit Authority       09 - Bishop
# 187         Sacramento Regional Transit District   03 - Marysville
# 188  Santa Clara Valley Transportation Authority      04 - Oakland
#
#                                        fares_v2_status
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 184  ['Provider published', 'Vendor published', 'Pr...
# 185  ['Provider to Publish', 'Provider to Publish',...
# 186  ['Vendor published', 'Vendor published', 'Vend...
# 187  ['Provider to Publish', 'Provider to Publish',...
# 188  ['Vendor published', 'Vendor published', 'Vend...
#
# [189 rows x 3 columns]

# %%
subset = (org_df >> select(_.name, _.caltrans_district, _.fares_v2_status))

# %%
subset>>filter(_.fares_v2_status.isnull())
# Out:
#                                         name caltrans_district fares_v2_status
# 0    Consolidated Tribal Health Project Inc.              None            None
# 1                                 Everbridge              None            None
# 2                      City of Santa Barbara              None            None
# 3                            Connexionz Inc.              None            None
# 4                     Area 1 Agency on Aging              None            None
# ..                                       ...               ...             ...
# 843                        City of La Puente  07 - Los Angeles            None
# 847    University of California, Los Angeles  07 - Los Angeles            None
# 851                             City of Brea       12 - Irvine            None
# 854                       City of El Segundo  07 - Los Angeles            None
# 855                          City of Fremont      04 - Oakland            None
#
# [693 rows x 3 columns]

# %%
subset>>filter(_.fares_v2_status.str.contains('Unknown'))
# Out:
#                                                   name     caltrans_district  \
# 555                            City of San Luis Obispo  05 - San Luis Obispo
# 556                                   Foothill Transit      07 - Los Angeles
# 562  Yuma County Intergovernmental Public Transport...        11 - San Diego
# 565                 San Joaquin Joint Powers Authority         10 - Stockton
# 585                                     City of Fresno           06 - Fresno
# 589                                   City of Glendale      07 - Los Angeles
# 649              San Diego Metropolitan Transit System        11 - San Diego
# 652                                City of Culver City      07 - Los Angeles
# 667                                   City of Torrance      07 - Los Angeles
# 668                              City of Monterey Park      07 - Los Angeles
# 670                           Riverside Transit Agency   08 - San Bernardino
# 686            Kings County Area Public Transit Agency           06 - Fresno
# 690             Orange County Transportation Authority           12 - Irvine
# 699                                          OmniTrans   08 - San Bernardino
# 703                      North County Transit District        11 - San Diego
# 707                 Fresno County Rural Transit Agency           06 - Fresno
# 708                                    City of Visalia           06 - Fresno
# 710        Santa Clara Valley Transportation Authority          04 - Oakland
# 720              Stanislaus Regional Transit Authority                  None
# 850                                  City of Morro Bay  05 - San Luis Obispo
# 856                                             Amtrak       03 - Marysville
#
#                                        fares_v2_status
# 555                                        ['Unknown']
# 556                                        ['Unknown']
# 562                                        ['Unknown']
# 565                                        ['Unknown']
# 585                                        ['Unknown']
# 589                                        ['Unknown']
# 649  ['Fares v2 updates in progress - Garnet', 'Unk...
# 652                                        ['Unknown']
# 667                                        ['Unknown']
# 668                                        ['Unknown']
# 670                                        ['Unknown']
# 686                                        ['Unknown']
# 690                             ['Unknown', 'Unknown']
# 699                             ['Unknown', 'Unknown']
# 703  ['Unknown', 'Unknown', 'Unknown', 'Unknown', '...
# 707  ['Unknown', 'Unknown', 'Unknown', 'Unknown', '...
# 708                                        ['Unknown']
# 710  ['Vendor published', 'Vendor published', 'Vend...
# 720                   ['Unknown', 'Unknown', 'Needed']
# 850                             ['Unknown', 'Unknown']
# 856                  ['Unknown', 'Unknown', 'Unknown']

# %%
subset['fares_v2_status'] = subset.fares_v2_status.fillna('Unknown')

# %%
subset>>filter(_.fares_v2_status.str.contains('Unknown'))
# Out:
#                                         name     caltrans_district  \
# 0    Consolidated Tribal Health Project Inc.                  None
# 1                                 Everbridge                  None
# 2                      City of Santa Barbara                  None
# 3                            Connexionz Inc.                  None
# 4                     Area 1 Agency on Aging                  None
# ..                                       ...                   ...
# 850                        City of Morro Bay  05 - San Luis Obispo
# 851                             City of Brea           12 - Irvine
# 854                       City of El Segundo      07 - Los Angeles
# 855                          City of Fremont          04 - Oakland
# 856                                   Amtrak       03 - Marysville
#
#                        fares_v2_status
# 0                              Unknown
# 1                              Unknown
# 2                              Unknown
# 3                              Unknown
# 4                              Unknown
# ..                                 ...
# 850             ['Unknown', 'Unknown']
# 851                            Unknown
# 854                            Unknown
# 855                            Unknown
# 856  ['Unknown', 'Unknown', 'Unknown']
#
# [714 rows x 3 columns]

# %%
PUBLISHED =['published']
IN_WORKS = ['to publish', 'in progress']
NOT_PUBLISHED=['blocked', 'needed']
UNKNOWN = ['unknown']

def categorize_project_descriptions(row):
    
    status = row.fares_v2_status.lower()

    published = 0
    in_works = 0
    not_published = 0
    unknown = 0
        
    if any(word in status for word in VEHICLE_PURCHASE):
        vehicle_purchase = 1
        
    if any(word in status for word in OPERATING_ASSISTANCE):
        operating_assistance = 1
        
    if any(word in status for word in MOBILITY_MANAGEMENT):
        mobility_management = 1
        
    return pd.Series(
        [vehicle_purchase, operating_assistance, mobility_management], 
        index=['vehicle_purchase', 'operating_assistance', 'mobility_management']
    )

# %%
# def fares_status_cat(subset):
#     if ((subset.fares_v2_status.str.contains('published'))):
#         return "Published"
#     elif ((subset.fares_v2_status.str.contains('to Publish')) or (subset.fares_v2_status.str.contains('in progress'))):
#         return "In works"
#     else:
#         return "Unknown"
# #subset["fares_status"] = subset.apply(lambda x: fares_status_cat(x), axis=1)
# subset["fares_status"] = subset.apply(fares_status_cat, axis = 1)

# %%
subset.fares_v2_status.value_counts()

# %%
# %%sql
#
# select
#     name,
#     caltrans_district,
#     fares_v2_status
# # ALTER TABLE airtable_orgs_filtered
# #   ADD COLUMN "fares_v2" BOOLEAN DEFAULT FALSE;
#     # CASE WHEN COUNT(VALUE1) = COUNT(*) THEN 1 ELSE 0 END AS fares_v2
# from cal-itp-data-infra-staging.staging_views.airtable_orgs_filtered
# Out:
# /opt/conda/lib/python3.10/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
#                                             name caltrans_district  \
# 0                                City of Artesia  07 - Los Angeles
# 1                                City of Maywood  07 - Los Angeles
# 2                               City of Cerritos  07 - Los Angeles
# 3                                City of Shafter       06 - Fresno
# 4                   Colusa County Transit Agency   03 - Marysville
# ..                                           ...               ...
# 184        Alameda-Contra Costa Transit District      04 - Oakland
# 185        San Joaquin Regional Transit District     10 - Stockton
# 186             Eastern Sierra Transit Authority       09 - Bishop
# 187         Sacramento Regional Transit District   03 - Marysville
# 188  Santa Clara Valley Transportation Authority      04 - Oakland
#
#                                        fares_v2_status
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 184  ['Provider published', 'Vendor published', 'Pr...
# 185  ['Provider to Publish', 'Provider to Publish',...
# 186  ['Vendor published', 'Vendor published', 'Vend...
# 187  ['Provider to Publish', 'Provider to Publish',...
# 188  ['Vendor published', 'Vendor published', 'Vend...
#
# [189 rows x 3 columns]

# %%
# %%sql

# CREATE TABLE orgs(tbl.airtable.california_transit_organizations())

# %%
# test = query_sql("""
# SELECT
#     *
# FROM `airtable.california_transit_organizations`
# LIMIT 10""", as_df=True)

# %%
# query_sql(
#         """
#         SELECT 
#         *
#         FROM airtable.california_transit_organizations
#         WHERE reporting_category = 'Core' 
#             OR
#              reporting_category = 'Other Public Transit'
#         ;
#         """
#     )

# %%
# %%sql
# select 
#     name,
#     service_type__from_mobility_services_managed_
# from cal-itp-data-infra-staging.staging_views.airtable_org_subset
# where 'fixed-route' in unnest(service_type__from_mobility_services_managed_)

# %%
# %%sql

# select
#     name, 
#     service_type__from_mobility_services_managed_
# from airtable.california_transit_organizations
# where 
#     contains(service_type__from_mobility_services_managed_, "fixed-route")

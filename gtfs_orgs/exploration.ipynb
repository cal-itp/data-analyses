# %% [markdown]
# # GTFS Operators

# %%
import pandas as pd
import numpy as np
from calitp import to_snakecase

# %%
pd.set_option("display.max_columns", 100)

# %%
df = to_snakecase(pd.read_csv('airtable_gtfs_service_data-Primary_Static_GTFS.csv'))

# %%
df
# Out:
#                                                   name  \
# 0      Santa Maria Area Transit – Santa Maria Schedule
# 1    Tahoe Truckee Area Regional Transportation – T...
# 2            North Lake Tahoe Express – Tahoe Schedule
# 3                       Metrolink – Metrolink Schedule
# 4                               DASH – LA DOT Schedule
# ..                                                 ...
# 276      the Link King Medical Center – LADPW Schedule
# 277                   the Link Lennox – LADPW Schedule
# 278               El Monte Transit – El Monte Schedule
# 279  UCLA/Westwood Commuter Express – Long Beach Sc...
# 280    MST Senior Shuttles – Monterey Salinas Schedule
#
#                                        services               gtfs_dataset  \
# 0                      Santa Maria Area Transit       Santa Maria Schedule
# 1    Tahoe Truckee Area Regional Transportation             Tahoe Schedule
# 2                      North Lake Tahoe Express             Tahoe Schedule
# 3                                     Metrolink         Metrolink Schedule
# 4                                          DASH            LA DOT Schedule
# ..                                          ...                        ...
# 276                the Link King Medical Center             LADPW Schedule
# 277                             the Link Lennox             LADPW Schedule
# 278                            El Monte Transit          El Monte Schedule
# 279              UCLA/Westwood Commuter Express        Long Beach Schedule
# 280                         MST Senior Shuttles  Monterey Salinas Schedule
#
#       dataset_type category agency_id network_id service_type__from_services_  \
# 0    GTFS Schedule  primary       NaN       SMAT                  fixed-route
# 1    GTFS Schedule  primary        16        NaN                  fixed-route
# 2    GTFS Schedule  primary       904        NaN     reservations,fixed-route
# 3    GTFS Schedule  primary       NaN        NaN                  fixed-route
# 4    GTFS Schedule  primary       NaN        NaN                  fixed-route
# ..             ...      ...       ...        ...                          ...
# 276  GTFS Schedule  primary       NaN        NaN                  fixed-route
# 277  GTFS Schedule  primary       NaN        NaN                  fixed-route
# 278  GTFS Schedule  primary       NaN        NaN                  fixed-route
# 279  GTFS Schedule  primary       NaN        NaN                  fixed-route
# 280  GTFS Schedule  primary       NaN        NaN                  fixed-route
#
#                                         provider  \
# 0                            City of Santa Maria
# 1                  Tahoe Transportation District
# 2                       North Lake Tahoe Express
# 3    Southern California Regional Rail Authority
# 4                            City of Los Angeles
# ..                                           ...
# 276                           Los Angeles County
# 277                           Los Angeles County
# 278                             City of El Monte
# 279                           Long Beach Transit
# 280                     Monterey-Salinas Transit
#
#                                         operator  \
# 0                            City of Santa Maria
# 1                  Tahoe Transportation District
# 2                                My Ride To Work
# 3    Southern California Regional Rail Authority
# 4                            City of Los Angeles
# ..                                           ...
# 276                           Los Angeles County
# 277                           Los Angeles County
# 278                             City of El Monte
# 279                           Long Beach Transit
# 280                     Monterey-Salinas Transit
#
#                  dataset_producers__from_gtfs_dataset_  \
# 0                    City of Santa Maria,TripShot Inc.
# 1    Tahoe Transportation District,Trillium Inc.,To...
# 2    Tahoe Transportation District,Trillium Inc.,To...
# 3          Southern California Regional Rail Authority
# 4            City of Los Angeles,Optibus,Trapeze Group
# ..                                                 ...
# 276                   Trillium Inc.,Los Angeles County
# 277                   Trillium Inc.,Los Angeles County
# 278                     Trillium Inc.,City of El Monte
# 279                                 Long Beach Transit
# 280                           Monterey-Salinas Transit
#
#     dataset_publisher__from_gtfs_dataset_ gtfs_dataset_type  pathways_status  \
# 0       City of Santa Maria,TripShot Inc.     GTFS Schedule              NaN
# 1                           Trillium Inc.     GTFS Schedule              NaN
# 2                           Trillium Inc.     GTFS Schedule              NaN
# 3                                     NaN     GTFS Schedule              NaN
# 4                     City of Los Angeles     GTFS Schedule              NaN
# ..                                    ...               ...              ...
# 276                         Trillium Inc.     GTFS Schedule              NaN
# 277                         Trillium Inc.     GTFS Schedule              NaN
# 278                         Trillium Inc.     GTFS Schedule              NaN
# 279                    Long Beach Transit     GTFS Schedule              NaN
# 280                                   NaN     GTFS Schedule              NaN
#
#          fares_v2_status         flex_status  \
# 0    Provider to Publish                 NaN
# 1       Vendor published                 NaN
# 2       Vendor published  Trillium - To code
# 3                 Needed                 NaN
# 4    Provider to Publish                 NaN
# ..                   ...                 ...
# 276     Vendor published                 NaN
# 277     Vendor published                 NaN
# 278     Vendor published                 NaN
# 279                  NaN                 NaN
# 280                  NaN                 NaN
#
#     schedule_comments__from_gtfs_dataset_ itp_activities__from_gtfs_dataset_  \
# 0                                     NaN                                NaN
# 1                                     NaN                                NaN
# 2                                     NaN                                NaN
# 3                                     NaN                                NaN
# 4                                     NaN                                NaN
# ..                                    ...                                ...
# 276                                   NaN                                NaN
# 277                                   NaN                                NaN
# 278                                   NaN                                NaN
# 279                                   NaN                                NaN
# 280                                   NaN                                NaN
#
#     itp_schedule_todo__from_gtfs_dataset_  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 276                                   NaN
# 277                                   NaN
# 278                                   NaN
# 279                                   NaN
# 280                                   NaN
#
#                        fares_notes__from_gtfs_dataset_             route_id  \
# 0                                                  NaN                  NaN
# 1                                Published by Trillium                  NaN
# 2                                Published by Trillium                  NaN
# 3    Will "circle back" once they sort out their RT...                  NaN
# 4    Jacob joined a peer working group. Their vendo...                    *
# ..                                                 ...                  ...
# 276                              Published by Trillium                13066
# 277                              Published by Trillium                13067
# 278                              Published by Trillium                    *
# 279  Is interested, but asked for us to engage them...                  405
# 280  We gave them the data in October. They need he...  091,092,093,094,095
#
#      reference_static_gtfs_service  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ..                             ...
# 276                            NaN
# 277                            NaN
# 278                            NaN
# 279                            NaN
# 280                            NaN
#
#                                                    uri  \
# 0    https://smrt.tripshot.com/v1/gtfs.zip?regionId...
# 1    http://data.trilliumtransit.com/gtfs/laketahoe...
# 2    http://data.trilliumtransit.com/gtfs/laketahoe...
# 3    https://www.metrolinktrains.com/globalassets/a...
# 4                            https://ladotbus.com/gtfs
# ..                                                 ...
# 276  http://data.trilliumtransit.com/gtfs/dpwlacoun...
# 277  http://data.trilliumtransit.com/gtfs/dpwlacoun...
# 278  http://data.trilliumtransit.com/gtfs/elmonte-c...
# 279  https://lbtransit.box.com/shared/static/aoyesk...
# 280       http://www.mst.org/google/google_transit.zip
#
#     currently_operating__from_services_ provider_reporting_category  \
# 0                    1 checked out of 1                        Core
# 1                    1 checked out of 1                        Core
# 2                    1 checked out of 1        Other Public Transit
# 3                    1 checked out of 1                        Core
# 4                    1 checked out of 1                        Core
# ..                                  ...                         ...
# 276                  1 checked out of 1                        Core
# 277                  1 checked out of 1                        Core
# 278                  1 checked out of 1                        Core
# 279                  1 checked out of 1                        Core
# 280                  1 checked out of 1                        Core
#
#      reference_static_feed
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ..                     ...
# 276                    NaN
# 277                    NaN
# 278                    NaN
# 279                    NaN
# 280                    NaN
#
# [281 rows x 26 columns]

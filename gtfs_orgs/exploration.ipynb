# %% [markdown]
# # GTFS Operators

# %%
import pandas as pd
import numpy as np
from calitp import to_snakecase

from siuba import *

from IPython.display import display, Markdown

# %%
pd.set_option("display.max_columns", 100)

# %%
#gtfs static data
df = to_snakecase(pd.read_csv('airtable_gtfs_service_data-Primary_Static_GTFS.csv'))

# %%
#all organizations
orgs = to_snakecase(pd.read_csv('organizations-AllOrganizations.csv'))

# %%
len(df)
# Out:
# 281

# %%
df.sample(5)
# Out:
#                                                   name  \
# 273                   the Link-Athens – LADPW Schedule
# 74       Huntington Park Express – Huntington Schedule
# 31           Tri Delta Transit – Bay Area 511 Schedule
# 243       COLT Santa Barbara Shuttle – Lompoc Schedule
# 192  Huron Inter-City Transit – Fresno County Schedule
#
#                        services            gtfs_dataset   dataset_type  \
# 273             the Link-Athens          LADPW Schedule  GTFS Schedule
# 74      Huntington Park Express     Huntington Schedule  GTFS Schedule
# 31            Tri Delta Transit   Bay Area 511 Schedule  GTFS Schedule
# 243  COLT Santa Barbara Shuttle         Lompoc Schedule  GTFS Schedule
# 192    Huron Inter-City Transit  Fresno County Schedule  GTFS Schedule
#
#     category agency_id network_id service_type__from_services_  \
# 273  primary       NaN        NaN                  fixed-route
# 74   primary       NaN        NaN                  fixed-route
# 31   primary        3D        NaN                  fixed-route
# 243  primary       NaN        NaN     fixed-route,reservations
# 192  primary       171        NaN                  fixed-route
#
#                                    provider                 operator  \
# 273                      Los Angeles County       Los Angeles County
# 74                  City of Huntington Park  City of Huntington Park
# 31   Eastern Contra Costa Transit Authority            First Transit
# 243                          City of Lompoc           City of Lompoc
# 192      Fresno County Rural Transit Agency        MV Transportation
#
#                  dataset_producers__from_gtfs_dataset_  \
# 273                   Trillium Inc.,Los Angeles County
# 74   Los Angeles County Metropolitan Transportation...
# 31              Metropolitan Transportation Commission
# 243                                     City of Lompoc
# 192                                      Trillium Inc.
#
#                  dataset_publisher__from_gtfs_dataset_ gtfs_dataset_type  \
# 273                                      Trillium Inc.     GTFS Schedule
# 74   Los Angeles County Metropolitan Transportation...     GTFS Schedule
# 31              Metropolitan Transportation Commission     GTFS Schedule
# 243                                     City of Lompoc     GTFS Schedule
# 192                                      Trillium Inc.     GTFS Schedule
#
#      pathways_status      fares_v2_status             flex_status  \
# 273              NaN     Vendor published                     NaN
# 74               NaN  Needs GTFS Schedule                     NaN
# 31               NaN     Vendor published                     NaN
# 243              NaN                  NaN  Needed - Existing GTFS
# 192              NaN              Unknown                     NaN
#
#     schedule_comments__from_gtfs_dataset_ itp_activities__from_gtfs_dataset_  \
# 273                                   NaN                                NaN
# 74                                    NaN             GTFS Schedule Creation
# 31                                    NaN                                NaN
# 243                                   NaN                                NaN
# 192                                   NaN                                NaN
#
#     itp_schedule_todo__from_gtfs_dataset_  \
# 273                                   NaN
# 74                        Get into google
# 31                                    NaN
# 243                                   NaN
# 192                                   NaN
#
#                        fares_notes__from_gtfs_dataset_ route_id  \
# 273                              Published by Trillium    13062
# 74                                                 NaN      NaN
# 31                                                 MTC      NaN
# 243           Ruth emailed r_fernbaugh@ci.lompoc.ca.us        7
# 192  A Trapeze client. Trapeze offered to facilitat...     1010
#
#      reference_static_gtfs_service  \
# 273                            NaN
# 74                             NaN
# 31                             NaN
# 243                            NaN
# 192                            NaN
#
#                                                    uri  \
# 273  http://data.trilliumtransit.com/gtfs/dpwlacoun...
# 74   https://github.com/LACMTA/los-angeles-regional...
# 31   http://api.511.org/transit/datafeeds?api_key={...
# 243  https://www.cityoflompoc.com/home/showdocument...
# 192  http://data.trilliumtransit.com/gtfs/fresnocou...
#
#     currently_operating__from_services_ provider_reporting_category  \
# 273                  1 checked out of 1                        Core
# 74                   1 checked out of 1        Other Public Transit
# 31                   1 checked out of 1                        Core
# 243                  1 checked out of 1                        Core
# 192                  1 checked out of 1                        Core
#
#      reference_static_feed
# 273                    NaN
# 74                     NaN
# 31                     NaN
# 243                    NaN
# 192                    NaN

# %%
orgs.sample(10)
# Out:
#                                              name        organization_type  \
# 440                      Forest Folk Incorporated  Non-Profit Organization
# 607                               Orange Cab Inc.                  Company
# 562                                  MobilityData  Non-Profit Organization
# 783                  Transportation Concepts Inc.                  Company
# 564  Modoc County Local Transportation Commission       Independent Agency
# 663              Sacramento International Airport                      NaN
# 301                             City of Riverside                City/Town
# 326                            City of Santa Rosa                City/Town
# 603              Open Transit Software Foundation  Non-Profit Organization
# 404                    Disneyland Shuttle Express                  Company
#
#                                        roles record_creation_time ntp_id  \
# 440                                      NaN    7/17/2021 12:45am    NaN
# 607                                      NaN    10/1/2021 11:48pm    NaN
# 562                                      NaN     4/8/2022 10:08pm    NaN
# 783                                      NaN     9/27/2021 5:37pm    NaN
# 564  Regional Transportation Planning Agency   10/11/2021 11:52pm    NaN
# 663                                      NaN    7/17/2021 12:45am    NaN
# 301                                      NaN     9/30/2021 5:25pm  90086
# 326                                      NaN     7/16/2021 9:30pm  90017
# 603                                      NaN     7/12/2021 9:12pm    NaN
# 404                                      NaN    7/17/2021 12:45am    NaN
#
#      itp_id  opm_id_drmt  dotid               brand alias  \
# 440   429.0          NaN    NaN                 NaN   NaN
# 607     NaN          NaN    NaN                 NaN   NaN
# 562     NaN          NaN    NaN                 NaN   NaN
# 783     NaN          NaN    NaN                 NaN   NaN
# 564     NaN          NaN    NaN                 NaN   NaN
# 663   272.0          NaN    NaN                 NaN   SMF
# 301   268.0     833006.0    NaN                 NaN   NaN
# 326   301.0     449002.0    NaN  Santa Rosa CityBus   NaN
# 603     NaN          NaN    NaN          OneBusAway   NaN
# 404   322.0          NaN    NaN                 NaN   NaN
#
#                       details                                    website  \
# 440                       NaN                                        NaN
# 607                       NaN                                        NaN
# 562                       NaN                           mobilitydata.org
# 783                       NaN                                        NaN
# 564                       NaN                                        NaN
# 663                       NaN                                        NaN
# 301                       NaN                                        NaN
# 326                       NaN                                        NaN
# 603                       NaN                                        NaN
# 404  Private shuttle service.  https://www.disneylandshuttleexpress.com/
#
#     parent_organization administrating_organization  \
# 440                 NaN                         NaN
# 607                 NaN                         NaN
# 562                 NaN                         NaN
# 783                 NaN                         NaN
# 564                 NaN                         NaN
# 663                 NaN                         NaN
# 301                 NaN                         NaN
# 326                 NaN                         NaN
# 603                 NaN                         NaN
# 404                 NaN                         NaN
#
#                              mobility_services_managed missing_static  \
# 440                              Idyllwild Shuttle Bus            NaN
# 607                                                NaN            NaN
# 562                                                NaN            NaN
# 783                                                NaN            NaN
# 564                                                NaN            NaN
# 663                                                NaN            NaN
# 301                                  Riverside Connect            NaN
# 326  Santa Rosa CityBus,Santa Rosa Call Ahead Servi...            NaN
# 603                                                NaN            NaN
# 404                                 Disneyland Shuttle            NaN
#
#     funding_sources_for_managed_transportation  \
# 440                                        NaN
# 607                                        NaN
# 562                                        NaN
# 783                                        NaN
# 564                                        NaN
# 663                                        NaN
# 301                                     public
# 326                       public,public,public
# 603                                        NaN
# 404                                    private
#
#                             mobility_services_operated gtfs_datasets_produced  \
# 440                              Idyllwild Shuttle Bus                    NaN
# 607                                  MST Taxi Vouchers                    NaN
# 562                                                NaN                    NaN
# 783  Avalon Dial-A-Ride,Avalon Community Transit,Av...                    NaN
# 564                                                NaN                    NaN
# 663                                                NaN                    NaN
# 301                                  Riverside Connect                    NaN
# 326   Santa Rosa CityBus,Santa Rosa Call Ahead Service                    NaN
# 603                                                NaN                    NaN
# 404                                 Disneyland Shuttle                    NaN
#
#          service_type__from_mobility_services_managed_  \
# 440                                     on-demand,NEMT
# 607                                                NaN
# 562                                                NaN
# 783                                                NaN
# 564                                                NaN
# 663                                                NaN
# 301             ADA paratransit,on-demand,reservations
# 326  fixed-route,deviated fixed-route,on-demand,res...
# 603                                                NaN
# 404                             reservations,on-demand
#
#     currently_operating__from_mobility_services_managed_  \
# 440                                 1 checked out of 1
# 607                                                NaN
# 562                                                NaN
# 783                                                NaN
# 564                                                NaN
# 663                                                NaN
# 301                                 1 checked out of 1
# 326                                 3 checked out of 3
# 603                                                NaN
# 404                                 1 checked out of 1
#
#     currently_operating__from_mobility_services_operated_  \
# 440                                 1 checked out of 1
# 607                                 1 checked out of 1
# 562                                                NaN
# 783                                 3 checked out of 3
# 564                                                NaN
# 663                                                NaN
# 301                                 1 checked out of 1
# 326                                 2 checked out of 2
# 603                                                NaN
# 404                                 1 checked out of 1
#
#         service_type__from_mobility_services_operated_    headquarters_place  \
# 440                                     on-demand,NEMT                   NaN
# 607                                          on-demand                   NaN
# 562                                                NaN  Montreal, Quebec, CA
# 783  on-demand,fixed-route,ADA paratransit,reservat...                   NaN
# 564                                                NaN                   NaN
# 663                                                NaN                   NaN
# 301             ADA paratransit,on-demand,reservations             Riverside
# 326  fixed-route,deviated fixed-route,on-demand,res...            Santa Rosa
# 603                                                NaN                   NaN
# 404                             reservations,on-demand                   NaN
#
#     funding_programs  total_voms__ntd_  service_area_sq_miles__ntd_  \
# 440              NaN               NaN                          NaN
# 607              NaN               NaN                          NaN
# 562              NaN               NaN                          NaN
# 783              NaN               NaN                          NaN
# 564              NaN               NaN                          NaN
# 663              NaN               NaN                          NaN
# 301              NaN              27.0                        545.0
# 326              NaN              36.0                         98.0
# 603              NaN               NaN                          NaN
# 404              NaN               NaN                          NaN
#
#      service_area_population__ntd_    caltrans_district  \
# 440                            NaN                  NaN
# 607                            NaN                  NaN
# 562                            NaN                  NaN
# 783                            NaN                  NaN
# 564                            NaN                  NaN
# 663                            NaN      03 - Marysville
# 301                      1932666.0  08 - San Bernardino
# 326                       308231.0         04 - Oakland
# 603                            NaN                  NaN
# 404                            NaN          12 - Irvine
#
#                                            mpo_rtpa  \
# 440                                             NaN
# 607                                             NaN
# 562                                             NaN
# 783                                             NaN
# 564                                             NaN
# 663                                             NaN
# 301  Southern California Association of Governments
# 326          Metropolitan Transportation Commission
# 603                                             NaN
# 404  Southern California Association of Governments
#
#                                  planning_authority tracking_category  \
# 440                                             NaN               NaN
# 607                                             NaN               NaN
# 562                                             NaN               NaN
# 783                                             NaN               NaN
# 564                                             NaN               NaN
# 663                                             NaN               NaN
# 301  Southern California Association of Governments            Active
# 326          Metropolitan Transportation Commission            Active
# 603                                             NaN               NaN
# 404  Southern California Association of Governments           Archive
#
#     reporting_category assist_category eligibility_programs gtfs_datasets  \
# 440                NaN         Limited                  NaN           NaN
# 607                NaN             NaN                  NaN           NaN
# 562                NaN             NaN                  NaN           NaN
# 783                NaN             NaN                  NaN           NaN
# 564                NaN             NaN                  NaN           NaN
# 663                NaN             NaN                  NaN           NaN
# 301               Core     White Glove                  NaN           NaN
# 326               Core     White Glove                  NaN           NaN
# 603                NaN             NaN                  NaN           NaN
# 404      Other Transit         Passive                  NaN           NaN
#
#          gtfs_dataset__from_mobility_services_managed_ fare_systems  \
# 440                                                NaN          NaN
# 607                                                NaN          NaN
# 562                                                NaN          NaN
# 783                                                NaN          NaN
# 564                                                NaN          NaN
# 663                                                NaN          NaN
# 301                                                NaN          NaN
# 326  Bay Area 511 Schedule,Bay Area 511 Alerts,Bay ...          NaN
# 603                                                NaN          NaN
# 404                                                NaN          NaN
#
#     gtfs_schedule_status   fares_v2_status  \
# 440               needed               NaN
# 607                  NaN               NaN
# 562                  NaN               NaN
# 783                  NaN               NaN
# 564                  NaN               NaN
# 663                  NaN               NaN
# 301               needed               NaN
# 326     ok,needed,needed  Vendor published
# 603                  NaN               NaN
# 404               needed               NaN
#
#                                            flex_status  \
# 440                            Needed - Public service
# 607                                                NaN
# 562                                                NaN
# 783                                                NaN
# 564                                                NaN
# 663                                                NaN
# 301                           Needed - Special service
# 326  Published - Needs Flex Additions,Needed - Exis...
# 603                                                NaN
# 404                                   Needed - Private
#
#                                services_needing_alerts  \
# 440                              Idyllwild Shuttle Bus
# 607                                                NaN
# 562                                                NaN
# 783                                                NaN
# 564                                                NaN
# 663                                                NaN
# 301                                  Riverside Connect
# 326  Santa Rosa Call Ahead Service, Santa Rosa Para...
# 603                                                NaN
# 404                                 Disneyland Shuttle
#
#       services_needing_tripupdates_or_vehiclepositions  \
# 440                              Idyllwild Shuttle Bus
# 607                                                NaN
# 562                                                NaN
# 783                                                NaN
# 564                                                NaN
# 663                                                NaN
# 301                                  Riverside Connect
# 326  Santa Rosa Call Ahead Service, Santa Rosa Para...
# 603                                                NaN
# 404                                 Disneyland Shuttle
#
#      #_of_fixed_route_services  #_services_w__complete_rt_status  \
# 440                          0                                 0
# 607                          0                                 0
# 562                          0                                 0
# 783                          0                                 0
# 564                          0                                 0
# 663                          0                                 0
# 301                          0                                 0
# 326                          1                                 1
# 603                          0                                 0
# 404                          0                                 0
#
#      #_fixed_route_services_w__static_gtfs  \
# 440                                      0
# 607                                      0
# 562                                      0
# 783                                      0
# 564                                      0
# 663                                      0
# 301                                      0
# 326                                      1
# 603                                      0
# 404                                      0
#
#      complete_static_gtfs_coverage__1=yes_  complete_rt_coverage  \
# 440                                      1                     1
# 607                                      1                     1
# 562                                      1                     1
# 783                                      1                     1
# 564                                      1                     1
# 663                                      1                     1
# 301                                      1                     1
# 326                                      1                     1
# 603                                      1                     1
# 404                                      1                     1
#
#      >=1_gtfs_feed_for_any_service__1=yes_  >=_1_complete_rt_set__1=yes_  \
# 440                                      0                             0
# 607                                      0                             0
# 562                                      0                             0
# 783                                      0                             0
# 564                                      0                             0
# 663                                      0                             0
# 301                                      0                             0
# 326                                      1                             1
# 603                                      0                             0
# 404                                      0                             0
#
#     service_availability_category__from_mobility_services_managed_  \
# 440                                           Public\n
# 607                                                NaN
# 562                                                NaN
# 783                                                NaN
# 564                                                NaN
# 663                                                NaN
# 301                                        Conditional
# 326                    Public\n, Public\n, Conditional
# 603                                                NaN
# 404                                           Public\n
#
#      #_fixed_route_or_deviated_fixed_route_services  \
# 440                                               0
# 607                                               0
# 562                                               0
# 783                                               0
# 564                                               0
# 663                                               0
# 301                                               0
# 326                                               1
# 603                                               0
# 404                                               0
#
#      #_fixed_route_or_deviated_fixed_route_service_w__static_gtfs  \
# 440                                                  0
# 607                                                  0
# 562                                                  0
# 783                                                  0
# 564                                                  0
# 663                                                  0
# 301                                                  0
# 326                                                  1
# 603                                                  0
# 404                                                  0
#
#      #_services_with_missing_static_feed_for_fixed_route_or_deviated_fixed_route  \
# 440                                                  0
# 607                                                  0
# 562                                                  0
# 783                                                  0
# 564                                                  0
# 663                                                  0
# 301                                                  0
# 326                                                  0
# 603                                                  0
# 404                                                  0
#
#     county_geography county_geography_3 gtfs_static_status  \
# 440              NaN                NaN          Static OK
# 607              NaN                NaN          Static OK
# 562              NaN                NaN          Static OK
# 783              NaN                NaN          Static OK
# 564            Modoc                NaN          Static OK
# 663              NaN                NaN          Static OK
# 301              NaN                NaN          Static OK
# 326              NaN                NaN          Static OK
# 603              NaN                NaN          Static OK
# 404              NaN                NaN          Static OK
#
#     gtfs_realtime_status             service_availability  \
# 440        RT Incomplete                         Public\n
# 607        RT Incomplete                              NaN
# 562        RT Incomplete                              NaN
# 783        RT Incomplete                              NaN
# 564        RT Incomplete                              NaN
# 663        RT Incomplete                              NaN
# 301        RT Incomplete                      Conditional
# 326                RT OK  Public\n, Public\n, Conditional
# 603        RT Incomplete                              NaN
# 404        RT Incomplete                         Public\n
#
#                                    service___component
# 440                                                NaN
# 607                                                NaN
# 562                                                NaN
# 783                                                NaN
# 564                                                NaN
# 663                                                NaN
# 301                                                NaN
# 326                                                NaN
# 603  "MTS Rapid, MTS Bus, San Diego Trolley-OneBusA...
# 404                                                NaN

# %%
df.gtfs_dataset_type.value_counts()
# Out:
# GTFS Schedule    281
# Name: gtfs_dataset_type, dtype: int64

# %% [markdown]
# ## Recreating screenshot filters:

# %%
orgs = (orgs>>select(_.name,
              _.organization_type,
              _.ntp_id,
              _.itp_id,
              _.opm_id_drmt,
             _.brand, 
              _.alias,
             _.reporting_category,
             _.fares_v2_status,
              _.mobility_services_managed,
              _.mobility_services_operated,
              _.gtfs_datasets_produced,
              _.service_type__from_mobility_services_managed_,
             _.service_type__from_mobility_services_operated_,
              _.currently_operating__from_mobility_services_managed_,
              _.headquarters_place,
              _.caltrans_district,
              _.gtfs_dataset__from_mobility_services_managed_,
              _.gtfs_schedule_status,
              _['#_of_fixed_route_services'],
              _['#_fixed_route_or_deviated_fixed_route_services'],
              _.gtfs_static_status,
              _.gtfs_realtime_status)
        )

# %% [markdown]
# ### Airtable filters

# %%
orgs.sample()
# Out:
#                 name organization_type ntp_id  itp_id  opm_id_drmt brand  \
# 124  City of Belmont         City/Town    NaN     NaN          NaN   NaN
#
#     alias reporting_category fares_v2_status  \
# 124   NaN                NaN             NaN
#
#                 mobility_services_managed  \
# 124  Belmont Twin Pines Senior Center Van
#
#                mobility_services_operated gtfs_datasets_produced  \
# 124  Belmont Twin Pines Senior Center Van                    NaN
#
#     service_type__from_mobility_services_managed_  \
# 124                                     on-demand
#
#     service_type__from_mobility_services_operated_  \
# 124                                      on-demand
#
#     currently_operating__from_mobility_services_managed_ headquarters_place  \
# 124                                 0 checked out of 1              Belmont
#
#     caltrans_district gtfs_dataset__from_mobility_services_managed_  \
# 124               NaN                                           NaN
#
#     gtfs_schedule_status  #_of_fixed_route_services  \
# 124               needed                          0
#
#      #_fixed_route_or_deviated_fixed_route_services gtfs_static_status  \
# 124                                               0          Static OK
#
#     gtfs_realtime_status
# 124        RT Incomplete

# %% [markdown]
# #### Filter: `reporting_category`

# %%
orgs_2 = ((orgs.query("reporting_category == ('Core') or reporting_category ==('Other Public Transit')"))
 >> filter(_.currently_operating__from_mobility_services_managed_.str.contains('checked'))
)

#orgs_2.query("service_type__from_mobility_services_managed_.str.contains('fixed-route') 
## or service_type__from_mobility_services_managed_.str.contains('deviated fixed-route')
## or service_type__from_mobility_services_managed_.str.contains('on-demand fixed-route')")

orgs_2.head()
# Out:
#                                      name   organization_type      ntp_id  \
# 4                         Access Services                 NaN       90157
# 11  Alameda-Contra Costa Transit District  Independent Agency       90014
# 14                          Alpine County              County  9R02-91116
# 18         Amador Regional Transit System  Independent Agency  9R02-91000
# 24                                 Amtrak  Federal Government         NaN
#
#     itp_id  opm_id_drmt brand       alias    reporting_category  \
# 4      1.0          NaN   NaN         NaN                  Core
# 11     4.0     401001.0   NaN  AC Transit                  Core
# 14     9.0    1002001.0   NaN         NaN                  Core
# 18    11.0    1003002.0   NaN         NaN                  Core
# 24    13.0          NaN   NaN         NaN  Other Public Transit
#
#                                       fares_v2_status  \
# 4                                                 NaN
# 11  Provider published,Vendor published,Provider p...
# 14                                                NaN
# 18                                   Vendor published
# 24                            Unknown,Unknown,Unknown
#
#                             mobility_services_managed  \
# 4                                  LA Access Services
# 11  AC Transit,Dumbarton Express,East Bay Paratran...
# 14                              Alpine County Transit
# 18          Amador Transit,Amador Transit Dial-A-Ride
# 24  Coast Starlight,California Zephyr,Thruway,Sout...
#
#                            mobility_services_operated  \
# 4                                  LA Access Services
# 11    AC Transit,AC Transit Transbay,AC Transit Tempo
# 14                              Alpine County Transit
# 18          Amador Transit,Amador Transit Dial-A-Ride
# 24  Coast Starlight,California Zephyr,Amtrak San J...
#
#                                gtfs_datasets_produced  \
# 4                                                 NaN
# 11  AC Transit Schedule,AC Transit VehiclePosition...
# 14                                                NaN
# 18                                    Amador Schedule
# 24                                    Amtrak Schedule
#
#         service_type__from_mobility_services_managed_  \
# 4                                     ADA paratransit
# 11  fixed-route,fixed-route,ADA paratransit,fixed-...
# 14                                          on-demand
# 18  fixed-route,deviated fixed-route,ADA paratrans...
# 24  fixed-route,fixed-route,fixed-route,fixed-rout...
#
#        service_type__from_mobility_services_operated_  \
# 4                                     ADA paratransit
# 11                fixed-route,fixed-route,fixed-route
# 14                                          on-demand
# 18  fixed-route,deviated fixed-route,ADA paratrans...
# 24  fixed-route,fixed-route,fixed-route,fixed-rout...
#
#    currently_operating__from_mobility_services_managed_ headquarters_place  \
# 4                                  1 checked out of 1             El Monte
# 11                                 5 checked out of 5              Oakland
# 14                                 1 checked out of 1         Markleeville
# 18                                 2 checked out of 2              Jackson
# 24                                 5 checked out of 6           Washington
#
#    caltrans_district      gtfs_dataset__from_mobility_services_managed_  \
# 4   07 - Los Angeles                                                NaN
# 11      04 - Oakland  Bay Area 511 TripUpdates,Bay Area 511 VehicleP...
# 14     10 - Stockton                                                NaN
# 18     10 - Stockton                                    Amador Schedule
# 24   03 - Marysville  Amtrak Schedule,Amtrak Schedule,Amtrak Schedul...
#
#    gtfs_schedule_status  #_of_fixed_route_services  \
# 4                needed                          0
# 11   ok,ok,needed,ok,ok                          4
# 14               needed                          0
# 18            ok,needed                          1
# 24             ok,ok,ok                          5
#
#     #_fixed_route_or_deviated_fixed_route_services gtfs_static_status  \
# 4                                                0          Static OK
# 11                                               4          Static OK
# 14                                               0          Static OK
# 18                                               1          Static OK
# 24                                               6          Static OK
#
#    gtfs_realtime_status
# 4         RT Incomplete
# 11                RT OK
# 14        RT Incomplete
# 18        RT Incomplete
# 24        RT Incomplete

# %% [markdown]
# #### Filter: `service_type__from_mobility_services_managed_`

# %%
orgs_2>>filter(_.service_type__from_mobility_services_managed_.str.contains("on-demand fixed-route"))
# Out:
#                 name organization_type      ntp_id  itp_id  opm_id_drmt brand  \
# 332  City of Shafter         City/Town  9R02-91120   303.0     615008.0   NaN
#
#     alias reporting_category fares_v2_status mobility_services_managed  \
# 332   NaN               Core             NaN       Shafter Dial-A-Ride
#
#     mobility_services_operated gtfs_datasets_produced  \
# 332        Shafter Dial-A-Ride                    NaN
#
#     service_type__from_mobility_services_managed_  \
# 332               on-demand,on-demand fixed-route
#
#     service_type__from_mobility_services_operated_  \
# 332                on-demand,on-demand fixed-route
#
#     currently_operating__from_mobility_services_managed_ headquarters_place  \
# 332                                 1 checked out of 1              Shafter
#
#     caltrans_district gtfs_dataset__from_mobility_services_managed_  \
# 332       06 - Fresno                                           NaN
#
#     gtfs_schedule_status  #_of_fixed_route_services  \
# 332               needed                          0
#
#      #_fixed_route_or_deviated_fixed_route_services gtfs_static_status  \
# 332                                               0          Static OK
#
#     gtfs_realtime_status
# 332        RT Incomplete

# %%
##doesnt work
#orgs_2.query('service_type__from_mobility_services_managed_.str.contains("fixed-route")')

# %%
fixed = orgs_2[
    (orgs_2["service_type__from_mobility_services_managed_"].str.contains("fixed-route")
    ) | (orgs_2["service_type__from_mobility_services_managed_"].str.contains("deviated fixed-route")
        ) | (orgs_2["service_type__from_mobility_services_managed_"].str.contains("on-demand fixed-route"))
]

# %%
print(f"There are {len(fixed)} organizations using a variation of fixed-route service")
# Out:
# There are 194 organizations using a variation of fixed-route service

# %%
fixed = (fixed>>select(_.name,
              _.organization_type,
              _.ntp_id,
              _.itp_id,
              _.opm_id_drmt,
              _.brand, 
              _.alias,
              _.mobility_services_managed,
              _.mobility_services_operated,
              _.gtfs_datasets_produced,
              _.service_type__from_mobility_services_managed_,
              _.currently_operating__from_mobility_services_managed_,
              _.headquarters_place,
              _.caltrans_district,
              _.gtfs_dataset__from_mobility_services_managed_,
              _.gtfs_schedule_status,
              _['#_of_fixed_route_services'],
              _['#_fixed_route_or_deviated_fixed_route_services'],
              _.fares_v2_status,
              _.gtfs_static_status,
              _.gtfs_realtime_status)
        )

# %%
fixed
# Out:
#                                                   name   organization_type  \
# 11               Alameda-Contra Costa Transit District  Independent Agency
# 18                      Amador Regional Transit System  Independent Agency
# 24                                              Amtrak  Federal Government
# 25                      Anaheim Transportation Network                 NaN
# 29                   Antelope Valley Transit Authority  Independent Agency
# ..                                                 ...                 ...
# 839             Western Contra Costa Transit Authority  Independent Agency
# 847                Yolo County Transportation District  Independent Agency
# 848       Yosemite Area Regional Transportation System  Independent Agency
# 849                      Yuba-Sutter Transit Authority  Independent Agency
# 850  Yuma County Intergovernmental Public Transport...  Independent Agency
#
#          ntp_id  itp_id  opm_id_drmt                brand       alias  \
# 11        90014     4.0     401001.0                  NaN  AC Transit
# 18   9R02-91000    11.0    1003002.0                  NaN         NaN
# 24          NaN    13.0          NaN                  NaN         NaN
# 25        90211    14.0    1230016.0                  NaN         NaN
# 29        90121    16.0     719002.0                  NaN         NaN
# ..          ...     ...          ...                  ...         ...
# 839       90159   368.0     407003.0              WestCAT         NaN
# 847       90090   372.0     357002.0              Yolobus         NaN
# 848  9R02-91070   374.0    1024004.0                  NaN       YARTS
# 849       90061   376.0     358001.0  Yuba-Sutter Transit         NaN
# 850       90233   386.0    1113004.0                  NaN         NaN
#
#                              mobility_services_managed  \
# 11   AC Transit,Dumbarton Express,East Bay Paratran...
# 18           Amador Transit,Amador Transit Dial-A-Ride
# 24   Coast Starlight,California Zephyr,Thruway,Sout...
# 25   Anaheim Resort Transportation,FRAN,Anaheim Tra...
# 29   Antelope Valley Dial-A-Ride,Antelope Valley Tr...
# ..                                                 ...
# 839  WestCAT Local,WestCAT Lynx Express,WestCAT Exp...
# 847                            Yolobus,Yolobus Special
# 848       Yosemite Area Regional Transportation System
# 849  Yuba-Sutter Transit,Yuba-Sutter Rural Transit,...
# 850                           Yuma County Area Transit
#
#                             mobility_services_operated  \
# 11     AC Transit,AC Transit Transbay,AC Transit Tempo
# 18           Amador Transit,Amador Transit Dial-A-Ride
# 24   Coast Starlight,California Zephyr,Amtrak San J...
# 25   Anaheim Resort Transportation,FRAN,Anaheim Tra...
# 29   Antelope Valley Dial-A-Ride,Antelope Valley Tr...
# ..                                                 ...
# 839  WestCAT Local,WestCAT Lynx Express,WestCAT Exp...
# 847        Yolobus,Yolobus Special,Causeway Connection
# 848       Yosemite Area Regional Transportation System
# 849  Yuba-Sutter Transit,Yuba-Sutter Rural Transit,...
# 850                           Yuma County Area Transit
#
#                                 gtfs_datasets_produced  \
# 11   AC Transit Schedule,AC Transit VehiclePosition...
# 18                                     Amador Schedule
# 24                                     Amtrak Schedule
# 25   Anaheim Resort Schedule,Anaheim Resort Vehicle...
# 29          Antelope Valley Transit Authority Schedule
# ..                                                 ...
# 839                                   WestCAT Schedule
# 847  Yolobus Schedule,Yolobus Vehicle Positions,Yol...
# 848                                     YARTS Schedule
# 849                               Yuba-Sutter Schedule
# 850                                      Yuma Schedule
#
#          service_type__from_mobility_services_managed_  \
# 11   fixed-route,fixed-route,ADA paratransit,fixed-...
# 18   fixed-route,deviated fixed-route,ADA paratrans...
# 24   fixed-route,fixed-route,fixed-route,fixed-rout...
# 25               fixed-route,on-demand,ADA paratransit
# 29               ADA paratransit,on-demand,fixed-route
# ..                                                 ...
# 839  fixed-route,fixed-route,fixed-route,on-demand,...
# 847  fixed-route,deviated fixed-route,ADA paratrans...
# 848                               seasonal,fixed-route
# 849  fixed-route,on-demand,deviated fixed-route,res...
# 850                                        fixed-route
#
#     currently_operating__from_mobility_services_managed_ headquarters_place  \
# 11                                  5 checked out of 5              Oakland
# 18                                  2 checked out of 2              Jackson
# 24                                  5 checked out of 6           Washington
# 25                                  3 checked out of 3              Anaheim
# 29                                  2 checked out of 2            Lancaster
# ..                                                 ...                  ...
# 839                                 5 checked out of 5               Pinole
# 847                                 2 checked out of 2             Woodland
# 848                                 1 checked out of 1               Merced
# 849                                 5 checked out of 5           Marysville
# 850                                 1 checked out of 1             Yuma, AZ
#
#     caltrans_district      gtfs_dataset__from_mobility_services_managed_  \
# 11       04 - Oakland  Bay Area 511 TripUpdates,Bay Area 511 VehicleP...
# 18      10 - Stockton                                    Amador Schedule
# 24    03 - Marysville  Amtrak Schedule,Amtrak Schedule,Amtrak Schedul...
# 25        12 - Irvine                            Anaheim Resort Schedule
# 29   07 - Los Angeles         Antelope Valley Transit Authority Schedule
# ..                ...                                                ...
# 839      04 - Oakland  Bay Area 511 Schedule,Bay Area 511 Schedule,Ba...
# 847   03 - Marysville  Yolobus Schedule,Yolobus Vehicle Positions,Yol...
# 848     10 - Stockton                                     YARTS Schedule
# 849   03 - Marysville  Yuba-Sutter Schedule,Yuba-Sutter Schedule,Yuba...
# 850    11 - San Diego                                      Yuma Schedule
#
#        gtfs_schedule_status  #_of_fixed_route_services  \
# 11       ok,ok,needed,ok,ok                          4
# 18                ok,needed                          1
# 24                 ok,ok,ok                          5
# 25         ok,needed,needed                          1
# 29                needed,ok                          1
# ..                      ...                        ...
# 839  ok,ok,ok,needed,needed                          3
# 847               ok,needed                          1
# 848                      ok                          1
# 849        ok,needed,needed                          3
# 850                      ok                          1
#
#      #_fixed_route_or_deviated_fixed_route_services  \
# 11                                                4
# 18                                                1
# 24                                                6
# 25                                                1
# 29                                                1
# ..                                              ...
# 839                                               3
# 847                                               1
# 848                                               1
# 849                                               4
# 850                                               1
#
#                                        fares_v2_status gtfs_static_status  \
# 11   Provider published,Vendor published,Provider p...          Static OK
# 18                                    Vendor published          Static OK
# 24                             Unknown,Unknown,Unknown          Static OK
# 25                                    Blocked - Vendor          Static OK
# 29                                                 NaN          Static OK
# ..                                                 ...                ...
# 839  Vendor published,Vendor published,Vendor publi...          Static OK
# 847                                Provider to Publish          Static OK
# 848                                   Vendor published          Static OK
# 849  Vendor published,Vendor published,Vendor publi...          Static OK
# 850                                            Unknown          Static OK
#
#     gtfs_realtime_status
# 11                 RT OK
# 18         RT Incomplete
# 24         RT Incomplete
# 25         RT Incomplete
# 29         RT Incomplete
# ..                   ...
# 839        RT Incomplete
# 847                RT OK
# 848        RT Incomplete
# 849        RT Incomplete
# 850        RT Incomplete
#
# [194 rows x 21 columns]

# %% [markdown]
# #### Filter: `currently_operating__from_mobility_services_managed_`

# %%
fixed.currently_operating__from_mobility_services_managed_.value_counts()
# Out:
# 2 checked out of 2      73
# 1 checked out of 1      42
# 3 checked out of 3      30
# 5 checked out of 5       8
# 4 checked out of 4       8
# 9 checked out of 9       5
# 8 checked out of 8       4
# 2 checked out of 3       4
# 0 checked out of 1       3
# 1 checked out of 2       3
# 6 checked out of 6       3
# 4 checked out of 5       2
# 3 checked out of 4       2
# 22 checked out of 22     1
# 16 checked out of 16     1
# 7 checked out of 7       1
# 6 checked out of 7       1
# 5 checked out of 6       1
# 2 checked out of 4       1
# 10 checked out of 11     1
# Name: currently_operating__from_mobility_services_managed_, dtype: int64

# %%
fixed = fixed[~fixed["currently_operating__from_mobility_services_managed_"].str.contains("0 checked out of")]

# %%
len(fixed)
# Out:
# 190

# %% [markdown]
# #### * `fixed` is a df with the agencies fitting the criteria specificed in [GitHub Issue #985](https://github.com/cal-itp/data-infra/issues/985)

# %% [markdown]
# #### Adding filters into a function for easier filtering

# %%
def add_airtable_filter(orgs):
    #narrow down the columns
    orgs = (orgs>>select(_.name,
                         _.organization_type,
                         _.ntp_id,
                         _.itp_id,
                         _.opm_id_drmt,
                         _.brand, 
                         _.alias,
                         _.reporting_category,
                         _.fares_v2_status,
                         _.mobility_services_managed,
                         _.mobility_services_operated,
                         _.gtfs_datasets_produced,
                         _.service_type__from_mobility_services_managed_,
                         _.service_type__from_mobility_services_operated_,
                         _.currently_operating__from_mobility_services_managed_,
                         _.headquarters_place,
                         _.caltrans_district,
                         _.gtfs_dataset__from_mobility_services_managed_,
                         _.gtfs_schedule_status,
                         _['#_of_fixed_route_services'],
                         _['#_fixed_route_or_deviated_fixed_route_services'],
                         _.gtfs_static_status,
                         _.gtfs_realtime_status)
        )
    
    # filter for reporting category
    orgs_2 = ((orgs.query("reporting_category == ('Core') or reporting_category ==('Other Public Transit')"))
              >> filter(_.currently_operating__from_mobility_services_managed_.str.contains('checked')))
    
    # filter for service type
    fixed = orgs_2[
        (orgs_2["service_type__from_mobility_services_managed_"].str.contains("fixed-route")
        ) | (orgs_2["service_type__from_mobility_services_managed_"].str.contains("deviated fixed-route")
            ) | (orgs_2["service_type__from_mobility_services_managed_"].str.contains("on-demand fixed-route"))
    ]
    
    # filter for currently operating
    fixed = fixed[~fixed["currently_operating__from_mobility_services_managed_"].str.contains("0 checked out of")]
    
    return fixed

# %%
filtered = add_airtable_filter(orgs)

# %%
filtered.head()
# Out:
#                                      name   organization_type      ntp_id  \
# 11  Alameda-Contra Costa Transit District  Independent Agency       90014
# 18         Amador Regional Transit System  Independent Agency  9R02-91000
# 24                                 Amtrak  Federal Government         NaN
# 25         Anaheim Transportation Network                 NaN       90211
# 29      Antelope Valley Transit Authority  Independent Agency       90121
#
#     itp_id  opm_id_drmt brand       alias    reporting_category  \
# 11     4.0     401001.0   NaN  AC Transit                  Core
# 18    11.0    1003002.0   NaN         NaN                  Core
# 24    13.0          NaN   NaN         NaN  Other Public Transit
# 25    14.0    1230016.0   NaN         NaN                  Core
# 29    16.0     719002.0   NaN         NaN                  Core
#
#                                       fares_v2_status  \
# 11  Provider published,Vendor published,Provider p...
# 18                                   Vendor published
# 24                            Unknown,Unknown,Unknown
# 25                                   Blocked - Vendor
# 29                                                NaN
#
#                             mobility_services_managed  \
# 11  AC Transit,Dumbarton Express,East Bay Paratran...
# 18          Amador Transit,Amador Transit Dial-A-Ride
# 24  Coast Starlight,California Zephyr,Thruway,Sout...
# 25  Anaheim Resort Transportation,FRAN,Anaheim Tra...
# 29  Antelope Valley Dial-A-Ride,Antelope Valley Tr...
#
#                            mobility_services_operated  \
# 11    AC Transit,AC Transit Transbay,AC Transit Tempo
# 18          Amador Transit,Amador Transit Dial-A-Ride
# 24  Coast Starlight,California Zephyr,Amtrak San J...
# 25  Anaheim Resort Transportation,FRAN,Anaheim Tra...
# 29  Antelope Valley Dial-A-Ride,Antelope Valley Tr...
#
#                                gtfs_datasets_produced  \
# 11  AC Transit Schedule,AC Transit VehiclePosition...
# 18                                    Amador Schedule
# 24                                    Amtrak Schedule
# 25  Anaheim Resort Schedule,Anaheim Resort Vehicle...
# 29         Antelope Valley Transit Authority Schedule
#
#         service_type__from_mobility_services_managed_  \
# 11  fixed-route,fixed-route,ADA paratransit,fixed-...
# 18  fixed-route,deviated fixed-route,ADA paratrans...
# 24  fixed-route,fixed-route,fixed-route,fixed-rout...
# 25              fixed-route,on-demand,ADA paratransit
# 29              ADA paratransit,on-demand,fixed-route
#
#        service_type__from_mobility_services_operated_  \
# 11                fixed-route,fixed-route,fixed-route
# 18  fixed-route,deviated fixed-route,ADA paratrans...
# 24  fixed-route,fixed-route,fixed-route,fixed-rout...
# 25              fixed-route,on-demand,ADA paratransit
# 29              ADA paratransit,on-demand,fixed-route
#
#    currently_operating__from_mobility_services_managed_ headquarters_place  \
# 11                                 5 checked out of 5              Oakland
# 18                                 2 checked out of 2              Jackson
# 24                                 5 checked out of 6           Washington
# 25                                 3 checked out of 3              Anaheim
# 29                                 2 checked out of 2            Lancaster
#
#    caltrans_district      gtfs_dataset__from_mobility_services_managed_  \
# 11      04 - Oakland  Bay Area 511 TripUpdates,Bay Area 511 VehicleP...
# 18     10 - Stockton                                    Amador Schedule
# 24   03 - Marysville  Amtrak Schedule,Amtrak Schedule,Amtrak Schedul...
# 25       12 - Irvine                            Anaheim Resort Schedule
# 29  07 - Los Angeles         Antelope Valley Transit Authority Schedule
#
#    gtfs_schedule_status  #_of_fixed_route_services  \
# 11   ok,ok,needed,ok,ok                          4
# 18            ok,needed                          1
# 24             ok,ok,ok                          5
# 25     ok,needed,needed                          1
# 29            needed,ok                          1
#
#     #_fixed_route_or_deviated_fixed_route_services gtfs_static_status  \
# 11                                               4          Static OK
# 18                                               1          Static OK
# 24                                               6          Static OK
# 25                                               1          Static OK
# 29                                               1          Static OK
#
#    gtfs_realtime_status
# 11                RT OK
# 18        RT Incomplete
# 24        RT Incomplete
# 25        RT Incomplete
# 29        RT Incomplete

# %%
len(filtered)
# Out:
# 190

# %%
filtered>>group_by(_.caltrans_district)>>summarize(number_agencies =_['name'].nunique())
# Out:
#        caltrans_district  number_agencies
# 0            01 - Eureka                7
# 1           02 - Redding                8
# 2        03 - Marysville               18
# 3           04 - Oakland               35
# 4   05 - San Luis Obispo               12
# 5            06 - Fresno               14
# 6       07 - Los Angeles               55
# 7    08 - San Bernardino               11
# 8            09 - Bishop                2
# 9          10 - Stockton               14
# 10        11 - San Diego                6
# 11           12 - Irvine                7

# %% [markdown]
# ### What percent of transit agencies have GTFS Schedule data?

# %%
skd_ok_expl = filtered>>select(_.name, _.gtfs_schedule_status)

# %%
skd_ok_expl.explode('gtfs_schedule_status')
# Out:
#                                                   name    gtfs_schedule_status
# 11               Alameda-Contra Costa Transit District      ok,ok,needed,ok,ok
# 18                      Amador Regional Transit System               ok,needed
# 24                                              Amtrak                ok,ok,ok
# 25                      Anaheim Transportation Network        ok,needed,needed
# 29                   Antelope Valley Transit Authority               needed,ok
# ..                                                 ...                     ...
# 839             Western Contra Costa Transit Authority  ok,ok,ok,needed,needed
# 847                Yolo County Transportation District               ok,needed
# 848       Yosemite Area Regional Transportation System                      ok
# 849                      Yuba-Sutter Transit Authority        ok,needed,needed
# 850  Yuma County Intergovernmental Public Transport...                      ok
#
# [190 rows x 2 columns]

# %%
skd_ok_expl = skd_ok_expl.assign(gtfs_schedule_status=skd_ok_expl.gtfs_schedule_status.str.split(','))

# %%
skd_ok_expl = skd_ok_expl.explode('gtfs_schedule_status')

# %%
skd_ok_expl>>filter(_.gtfs_schedule_status=='ok')>>count(_.name)
# Out:
#                                                   name  n
# 0                Alameda-Contra Costa Transit District  4
# 1                       Amador Regional Transit System  1
# 2                                               Amtrak  3
# 3                       Anaheim Transportation Network  1
# 4                    Antelope Valley Transit Authority  1
# ..                                                 ... ..
# 138             Western Contra Costa Transit Authority  3
# 139                Yolo County Transportation District  1
# 140       Yosemite Area Regional Transportation System  1
# 141                      Yuba-Sutter Transit Authority  1
# 142  Yuma County Intergovernmental Public Transport...  1
#
# [143 rows x 2 columns]

# %%
skd_ok_expl>>filter(_.gtfs_schedule_status=='needed')>>count(_.name)
# Out:
#                                                name  n
# 0             Alameda-Contra Costa Transit District  1
# 1                    Amador Regional Transit System  1
# 2                    Anaheim Transportation Network  2
# 3                 Antelope Valley Transit Authority  1
# 4                              Banning Pass Transit  1
# ..                                              ... ..
# 143                                    Walmart Inc.  1
# 144  West Berkeley Transportation Management Agency  1
# 145          Western Contra Costa Transit Authority  2
# 146             Yolo County Transportation District  1
# 147                   Yuba-Sutter Transit Authority  2
#
# [148 rows x 2 columns]

# %%
skd_ok_expl>>filter(_.gtfs_schedule_status=='need long-term solution')>>count(_.name)
# Out:
#                                                  name  n
# 0                                     City of Arcadia  1
# 1                                       City of Arvin  1
# 2                                City of Baldwin Park  1
# 3                                City of Bell Gardens  1
# 4                                  City of Bellflower  1
# 5                                   City of Calabasas  1
# 6                                   City of Camarillo  2
# 7                                     City of Compton  1
# 8                                      City of Cudahy  1
# 9                                      City of Downey  1
# 10                                 City of Ridgecrest  1
# 11                        City of San Juan Capistrano  1
# 12                               City of Sierra Madre  1
# 13                                 City of South Gate  1
# 14                                       City of Taft  1
# 15                                City of West Covina  1
# 16  San Francisco Bay Area Water Emergency Transit...  1

# %%
skd_ok_expl>>filter(_.gtfs_schedule_status=='research')>>count(_.name)
# Out:
#                                    name  n
# 0                       City of Burbank  1
# 1              Monterey-Salinas Transit  1
# 2       Morongo Basin Transit Authority  1
# 3  Napa Valley Transportation Authority  1
# 4                         Nevada County  1
# 5     San Mateo County Transit District  1

# %%
skd_ok_expl>>filter(_.gtfs_schedule_status=='not public')>>count(_.name)
# Out:
#                                name  n
# 0  University of California, Irvine  2

# %% [markdown]
# ***
# **NOTE** the probelm with this is that we cannot link the records back since Airtable nests the records
# ***

# %%
skd_ok = ((filtered[filtered["gtfs_schedule_status"].str.contains('needed')==False])
 >> select(_.name, _.organization_type, _.gtfs_schedule_status)
 >> filter(_.gtfs_schedule_status.str.contains('ok')))

# %%
print(f"Number of organizations with 'OK' (no 'needed') "
      f"status: {len(skd_ok)}")
# Out:
# Number of organizations with 'OK' (no 'needed') status: 37

# %%
#filtered2 =filtered[~filtered["gtfs_schedule_status"].str.contains('needed')]
skd_ok
# Out:
#                                                   name   organization_type  \
# 24                                              Amtrak  Federal Government
# 53                                 Blue Lake Rancheria               Tribe
# 77             Capitol Corridor Joint Powers Authority  Independent Agency
# 109                                     City of Arcata           City/Town
# 133                                    City of Burbank           City/Town
# 181                                     City of Eureka           City/Town
# 229                               City of Laguna Beach           City/Town
# 243                                    City of Lynwood           City/Town
# 272                                       City of Ojai           City/Town
# 298                                  City of Rio Vista           City/Town
# 299                                      City of Ripon           City/Town
# 313                            City of San Luis Obispo           City/Town
# 342                        City of South San Francisco           City/Town
# 379                                        Commute.org                 NaN
# 438                                   Foothill Transit  Independent Agency
# 461                     Golden Empire Transit District  Independent Agency
# 529                         Los Angeles World Airports  Independent Agency
# 551                                Menlo Park Shuttles                 NaN
# 565                    Modoc Transportation Authority   Independent Agency
# 574                    Morongo Basin Transit Authority  Independent Agency
# 585                                      Nevada County              County
# 594                           North Lake Tahoe Express                 NaN
# 613                   Palo Verde Valley Transit Agency  Independent Agency
# 621              Peninsula Corridor Joint Powers Board                 NaN
# 634                             Plumas Transit Systems  Independent Agency
# 681  San Francisco Bay Area Water Emergency Transit...  Independent Agency
# 682                San Francisco International Airport  Independent Agency
# 686                 San Joaquin Joint Powers Authority  Independent Agency
# 687               San Joaquin Regional Rail Commission  Independent Agency
# 697    Santa Barbara County Association of Governments                 NaN
# 698        Santa Barbara Metropolitan Transit District  Independent Agency
# 726                                    Siskiyou County              County
# 735            Sonoma-Marin Area Rail Transit District  Independent Agency
# 740        Southern California Regional Rail Authority  Independent Agency
# 787                                     Trinity County              County
# 848       Yosemite Area Regional Transportation System  Independent Agency
# 850  Yuma County Intergovernmental Public Transport...  Independent Agency
#
#            gtfs_schedule_status
# 24                     ok,ok,ok
# 53                           ok
# 77                           ok
# 109                          ok
# 133                 ok,research
# 181                          ok
# 229                          ok
# 243                          ok
# 272                          ok
# 298                          ok
# 299                          ok
# 313                          ok
# 342                          ok
# 379                          ok
# 438                          ok
# 461                       ok,ok
# 529                          ok
# 551                          ok
# 565                       ok,ok
# 574                 ok,research
# 585                 ok,research
# 594                          ok
# 613                          ok
# 621                       ok,ok
# 634                          ok
# 681  need long-term solution,ok
# 682                          ok
# 686                          ok
# 687                          ok
# 697                          ok
# 698                          ok
# 726                          ok
# 735                          ok
# 740                          ok
# 787                          ok
# 848                          ok
# 850                          ok

# %%
skd_needed = ((filtered[filtered["gtfs_schedule_status"].str.contains('need')==True])
 >> select(_.name, _.organization_type, _.gtfs_schedule_status)
             )

# %%
print(f"Number of organizations with 'needed' "
      f"status: {len(skd_needed)}")
# Out:
# Number of organizations with 'needed' status: 151

# %%
print(f"Number of organizations with 'needed' "
      f"status: {len(((filtered[filtered['gtfs_schedule_status'].str.contains('need long-term solution')==True])))}")
# Out:
# Number of organizations with 'needed' status: 17

# %%
filtered>>count(_.gtfs_schedule_status)>>filter(_.n>1)>>arrange(-_.n)
# Out:
#               gtfs_schedule_status   n
# 24                       ok,needed  44
# 23                              ok  29
# 25                ok,needed,needed  20
# 5                           needed  12
# 2   need long-term solution,needed  11
# 7                    needed,needed   7
# 8             needed,needed,needed   4
# 9      needed,needed,needed,needed   4
# 34                    ok,needed,ok   4
# 38                           ok,ok   3
# 50                     ok,research   3
# 0          need long-term solution   2
# 14                       needed,ok   2
# 15                needed,ok,needed   2
# 16         needed,ok,needed,needed   2
# 27  ok,needed,needed,needed,needed   2
# 39                    ok,ok,needed   2
# 46          ok,ok,ok,needed,needed   2

# %% [markdown]
# ### What percent of transit agencies have Fares v2?

# %%
filtered>>count(_.fares_v2_status)>>filter(_.n>1)>>arrange(-_.n)
# Out:
#                                       fares_v2_status   n
# 20                                   Vendor published  43
# 13                                            Unknown  20
# 3                                 Needs GTFS Schedule  11
# 24                  Vendor published,Vendor published  10
# 6                                 Provider to Publish   7
# 0                                    Blocked - Vendor   6
# 28  Vendor published,Vendor published,Vendor publi...   5
# 4                                  Provider published   3
# 15                                    Unknown,Unknown   3
# 17                            Unknown,Unknown,Unknown   3
# 26  Vendor published,Vendor published,Vendor publi...   3
# 7             Provider to Publish,Provider to Publish   2
# 21                  Vendor published,Blocked - Vendor   2
# 25  Vendor published,Vendor published,Needs GTFS S...   2
# 30  Vendor published,Vendor published,Vendor publi...   2

# %%
print(f"There are {len(filtered>>filter(_.fares_v2_status.str.contains('published')))} orgs with Fares v2 status as Published")
# Out:
# There are 81 orgs with Fares v2 status as Published

# %%
print(f"There are {len(filtered>>filter(_.fares_v2_status.str.contains('Unknown')))} orgs with Fares v2 status as Unknown")
# Out:
# There are 31 orgs with Fares v2 status as Unknown

# %%
print(f"There are {len(filtered>>filter(_.fares_v2_status.str.contains('Blocked')))} orgs with Fares v2 status as Blocked")
# Out:
# There are 10 orgs with Fares v2 status as Blocked

# %%
print(f"There are {len(filtered>>filter(_.fares_v2_status.str.contains('Needs')))} orgs with Fares v2 status as Needs")
# Out:
# There are 16 orgs with Fares v2 status as Needs

# %% [markdown]
# ### What percent of transit agencies are GTFS-compliant?

# %% [markdown]
# If we use `gtfs_static_status` or `gtfs_realtime_status` to determine if a transit agency is compliant, we are counting some of the needed GTFS static schedule data as "OK".
# <br>
#
# TO DO: Determine how the `gtfs_static_status` and `gtfs_realtime_status` columns are decided.

# %%
display(Markdown(f"There are {(len(filtered)) - (len(orgs>>filter(_.gtfs_datasets_produced.notnull())>>count(_.name)))} "
               f"fewer agencies that fit under the criteria for `orgs>>filter(_.gtfs_datasets_produced.notnull())>>count(_.name)` "
               f"than the specified filters in `fixed`"))
# Out:
# There are 38 fewer agencies that fit under the criteria for `orgs>>filter(_.gtfs_datasets_produced.notnull())>>count(_.name)` than the specified filters in `fixed`

# %%
display(Markdown(f" {'{:.1%}'.format(((len(filtered))/(len(orgs))))} of " 
                f"Organizations fit the criteria specified"))
# Out:
#  22.3% of Organizations fit the criteria specified

# %%
display(Markdown(f"There are **{len(filtered>>filter(_.gtfs_static_status==('Static Incomplete')))}** "
                 "organizations with Incomplete GTFS Static in the `Filtered` dataframe"
                ))
# Out:
# There are **33** organizations with Incomplete GTFS Static in the `Filtered` dataframe

# %%
display(Markdown(f"There are **{len(orgs>>filter(_.gtfs_static_status==('Static Incomplete')))}** "
                 "organizations with Incomplete GTFS Static in the `Airtable Organization` dataframe"
                ))
# Out:
# There are **70** organizations with Incomplete GTFS Static in the `Airtable Organization` dataframe

# %% [markdown]
# ### Going Forward
# * is it worth connecting Metabase GTFS veiws with Airtable Agencies? This way we could be able to determine which GTFS feeds are actually being read, rather than rely on other information in Airtable

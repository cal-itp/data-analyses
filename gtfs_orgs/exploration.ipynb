# %% [markdown]
# # GTFS Operators

# %%
import pandas as pd
import numpy as np
from calitp import to_snakecase

from siuba import *

from IPython.display import display, Markdown

# %%
pd.set_option("display.max_columns", 100)

# %%
#gtfs static data
df = to_snakecase(pd.read_csv('gs://calitp-analytics-data/data-analyses/gtfs_compliance/airtable_gtfs_service_data-Primary_Static_GTFS.csv'))
# Out:
# /opt/conda/lib/python3.10/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
#all organizations
orgs = to_snakecase(pd.read_csv('gs://calitp-analytics-data/data-analyses/gtfs_compliance/organizations-AllOrganizations.csv'))

# %%
len(df)
# Out:
# 281

# %%
df.sample(5)
# Out:
#                                        name              services  \
# 162   East Valinda Shuttle – LADPW Schedule  East Valinda Shuttle
# 104          PresidiGo – PresidiGo Schedule             PresidiGo
# 37           VCTC Intercity – VCTC Schedule        VCTC Intercity
# 258  Wasco Dial-a-Ride – Wasco DAR Schedule     Wasco Dial-a-Ride
# 20         SamTrans – Bay Area 511 Schedule              SamTrans
#
#               gtfs_dataset   dataset_type category agency_id network_id  \
# 162         LADPW Schedule  GTFS Schedule  primary       NaN        NaN
# 104     PresidiGo Schedule  GTFS Schedule  primary       NaN        NaN
# 37           VCTC Schedule  GTFS Schedule  primary       143        NaN
# 258     Wasco DAR Schedule  GTFS Schedule  primary       NaN        NaN
# 20   Bay Area 511 Schedule  GTFS Schedule  primary        SM        NaN
#
#                service_type__from_services_  \
# 162                             fixed-route
# 104                             fixed-route
# 37                              fixed-route
# 258  ADA paratransit,reservations,on-demand
# 20                              fixed-route
#
#                                      provider  \
# 162                        Los Angeles County
# 104                            Presidio Trust
# 37   Ventura County Transportation Commission
# 258                             City of Wasco
# 20          San Mateo County Transit District
#
#                                      operator  \
# 162                        Los Angeles County
# 104                            Presidio Trust
# 37   Ventura County Transportation Commission
# 258                             City of Wasco
# 20          San Mateo County Transit District
#
#                  dataset_producers__from_gtfs_dataset_  \
# 162                   Trillium Inc.,Los Angeles County
# 104                               GMV Syncromatics Inc
# 37   Ventura County Transportation Commission,Trill...
# 258               California Integrated Travel Project
# 20              Metropolitan Transportation Commission
#
#       dataset_publisher__from_gtfs_dataset_ gtfs_dataset_type  \
# 162                           Trillium Inc.     GTFS Schedule
# 104                    GMV Syncromatics Inc     GTFS Schedule
# 37                            Trillium Inc.     GTFS Schedule
# 258    California Integrated Travel Project     GTFS Schedule
# 20   Metropolitan Transportation Commission     GTFS Schedule
#
#      pathways_status   fares_v2_status       flex_status  \
# 162              NaN  Vendor published               NaN
# 104              NaN  Blocked - Vendor               NaN
# 37               NaN  Vendor published               NaN
# 258              NaN               NaN  DRMT - Published
# 20               NaN  Vendor published               NaN
#
#     schedule_comments__from_gtfs_dataset_ itp_activities__from_gtfs_dataset_  \
# 162                                   NaN                                NaN
# 104                                   NaN                                NaN
# 37                                    NaN                                NaN
# 258                                   NaN                                NaN
# 20                                    NaN                                NaN
#
#     itp_schedule_todo__from_gtfs_dataset_  \
# 162                                   NaN
# 104                                   NaN
# 37                                    NaN
# 258                                   NaN
# 20                                    NaN
#
#                        fares_notes__from_gtfs_dataset_ route_id  \
# 162                              Published by Trillium    13051
# 104  GMV is willing to facilitate in 2022. Ruth rea...      NaN
# 37                               Published by Trillium      NaN
# 258                                                NaN      NaN
# 20                                                 MTC        *
#
#      reference_static_gtfs_service  \
# 162                            NaN
# 104                            NaN
# 37                             NaN
# 258                            NaN
# 20                             NaN
#
#                                                    uri  \
# 162  http://data.trilliumtransit.com/gtfs/dpwlacoun...
# 104                       https://presidiobus.com/gtfs
# 37   http://data.trilliumtransit.com/gtfs/vctc-ca-u...
# 258     https://gtfs.calitp.org/WascoDialaRideFlex.zip
# 20   http://api.511.org/transit/datafeeds?api_key={...
#
#     currently_operating__from_services_ provider_reporting_category  \
# 162                  1 checked out of 1                        Core
# 104                  1 checked out of 1               Other Transit
# 37                   1 checked out of 1                        Core
# 258                  1 checked out of 1                        Core
# 20                   1 checked out of 1                        Core
#
#      reference_static_feed
# 162                    NaN
# 104                    NaN
# 37                     NaN
# 258                    NaN
# 20                     NaN

# %%
orgs.sample(10)
# Out:
#                                             name        organization_type  \
# 684           San Joaquin Council of Governments                      NaN
# 261                             City of Moorpark                City/Town
# 773                                     TouchNet                  Company
# 16                                 Amador County                   County
# 113                           City of Atascadero                City/Town
# 698  Santa Barbara Metropolitan Transit District       Independent Agency
# 476   Humboldt County Association of Governments                      NaN
# 808             University of California, Irvine      University - Public
# 533                     Lutheran Social Services  Non-Profit Organization
# 613             Palo Verde Valley Transit Agency       Independent Agency
#
#                                                  roles record_creation_time  \
# 684  Metropolitan Planning Organization,Census Affi...   10/11/2021 11:52pm
# 261                                                NaN     7/16/2021 9:30pm
# 773                                                NaN     7/12/2021 9:12pm
# 16                                                 NaN    1/10/2022 10:16pm
# 113                                                NaN    7/17/2021 12:45am
# 698                                                NaN     7/12/2021 8:12pm
# 476            Regional Transportation Planning Agency   10/11/2021 11:52pm
# 808                                                NaN     10/5/2021 5:54am
# 533                                                NaN    7/17/2021 12:45am
# 613                                                NaN    7/17/2021 12:17am
#
#     ntp_id  itp_id  opm_id_drmt  dotid brand  \
# 684  99422     NaN          NaN    NaN   NaN
# 261  90227   210.0     756005.0    NaN   NaN
# 773    NaN     NaN          NaN    NaN   NaN
# 16     NaN     NaN          NaN    NaN   NaN
# 113  90194    22.0     540001.0    NaN   NaN
# 698  90020   293.0     542004.0    NaN   NaN
# 476    NaN     NaN          NaN    NaN   NaN
# 808    NaN     NaN          NaN    NaN   NaN
# 533    NaN   439.0          NaN    NaN   NaN
# 613    NaN   238.0     833005.0    NaN   NaN
#
#                                                  alias  \
# 684                                                NaN
# 261                                                NaN
# 773                                                NaN
# 16                                                 NaN
# 113                                                NaN
# 698  "Santa Barbara MTD\trecswCrw6a6htmXJ4\t0\t\tMo...
# 476                                                NaN
# 808                                                NaN
# 533                                                NaN
# 613                            PVVTA,Desert Roadrunner
#
#                                                details  \
# 684                                                NaN
# 261                                                NaN
# 773                                                NaN
# 16                                                 NaN
# 113                                                NaN
# 698                                                NaN
# 476                                                NaN
# 808                                                NaN
# 533                                                NaN
# 613  The Palo Verde Valley Transit Agency is the so...
#
#                          website  \
# 684                    sjcog.org
# 261                          NaN
# 773  https://www.touchnet.com/en
# 16                           NaN
# 113                          NaN
# 698                          NaN
# 476                          NaN
# 808                          NaN
# 533                          NaN
# 613           https://pvvta.com/
#
#                                    parent_organization  \
# 684  City of Lathrop,City of Stockton,City of Lodi,...
# 261                                                NaN
# 773                                                NaN
# 16                                                 NaN
# 113                                                NaN
# 698                                                NaN
# 476                                                NaN
# 808                                                NaN
# 533                                                NaN
# 613                                                NaN
#
#     administrating_organization                    mobility_services_managed  \
# 684                         NaN                                          NaN
# 261                         NaN   Moorpark City Transit,Moorpark Dial-A-Ride
# 773                         NaN                                          NaN
# 16                          NaN                                          NaN
# 113                         NaN                       Atascadero Dial-A-Ride
# 698                         NaN  Santa Barbara Metropolitan Transit District
# 476                         NaN                                          NaN
# 808                         NaN  Anteater Express,UCI Medical Center Shuttle
# 533                         NaN                                          NaN
# 613                         NaN                            Desert Roadrunner
#
#                                    missing_static  \
# 684                                           NaN
# 261                                           NaN
# 773                                           NaN
# 16                                            NaN
# 113                                           NaN
# 698                                           NaN
# 476                                           NaN
# 808  Anteater Express, UCI Medical Center Shuttle
# 533                                           NaN
# 613                                           NaN
#
#     funding_sources_for_managed_transportation  \
# 684                                        NaN
# 261                              public,public
# 773                                        NaN
# 16                                         NaN
# 113                                     public
# 698                                     public
# 476                                        NaN
# 808                                    private
# 533                                        NaN
# 613                                     public
#
#                       mobility_services_operated      gtfs_datasets_produced  \
# 684                                          NaN                         NaN
# 261                        Moorpark City Transit           Moorpark Schedule
# 773                                          NaN                         NaN
# 16                                           NaN                         NaN
# 113                       Atascadero Dial-A-Ride                         NaN
# 698  Santa Barbara Metropolitan Transit District              SBMTD Schedule
# 476                                          NaN                         NaN
# 808  Anteater Express,UCI Medical Center Shuttle                         NaN
# 533                                          NaN                         NaN
# 613                            Desert Roadrunner  Desert Roadrunner Schedule
#
#          service_type__from_mobility_services_managed_  \
# 684                                                NaN
# 261  fixed-route,ADA paratransit,reservations,on-de...
# 773                                                NaN
# 16                                                 NaN
# 113                                          on-demand
# 698                                        fixed-route
# 476                                                NaN
# 808                            fixed-route,fixed-route
# 533                                                NaN
# 613                               deviated fixed-route
#
#     currently_operating__from_mobility_services_managed_  \
# 684                                                NaN
# 261                                 2 checked out of 2
# 773                                                NaN
# 16                                                 NaN
# 113                                 1 checked out of 1
# 698                                 1 checked out of 1
# 476                                                NaN
# 808                                 2 checked out of 2
# 533                                                NaN
# 613                                 1 checked out of 1
#
#     currently_operating__from_mobility_services_operated_  \
# 684                                                NaN
# 261                                 1 checked out of 1
# 773                                                NaN
# 16                                                 NaN
# 113                                 1 checked out of 1
# 698                                 1 checked out of 1
# 476                                                NaN
# 808                                 2 checked out of 2
# 533                                                NaN
# 613                                 1 checked out of 1
#
#     service_type__from_mobility_services_operated_ headquarters_place  \
# 684                                            NaN           Stockton
# 261                                    fixed-route           Moorpark
# 773                                            NaN         Lenexa, KS
# 16                                             NaN                NaN
# 113                                      on-demand         Atascadero
# 698                                    fixed-route      Santa Barbara
# 476                                            NaN                NaN
# 808                        fixed-route,fixed-route             Irvine
# 533                                            NaN                NaN
# 613                           deviated fixed-route                NaN
#
#     funding_programs  total_voms__ntd_  service_area_sq_miles__ntd_  \
# 684              NaN              56.0                         93.0
# 261              NaN               2.0                         86.0
# 773              NaN               NaN                          NaN
# 16               NaN               NaN                          NaN
# 113              NaN               3.0                         31.0
# 698              NaN              93.0                         56.0
# 476              NaN               NaN                          NaN
# 808              NaN               NaN                          NaN
# 533              NaN               NaN                          NaN
# 613              NaN               NaN                          NaN
#
#      service_area_population__ntd_     caltrans_district  \
# 684                       370583.0         10 - Stockton
# 261                       214811.0      07 - Los Angeles
# 773                            NaN                   NaN
# 16                             NaN                   NaN
# 113                        65088.0  05 - San Luis Obispo
# 698                       195861.0  05 - San Luis Obispo
# 476                            NaN                   NaN
# 808                            NaN           12 - Irvine
# 533                            NaN                   NaN
# 613                            NaN   08 - San Bernardino
#
#                                             mpo_rtpa  \
# 684                                              NaN
# 261   Southern California Association of Governments
# 773                                              NaN
# 16                                               NaN
# 113           San Luis Obispo Council of Governments
# 698  Santa Barbara County Association of Governments
# 476                                              NaN
# 808                                              NaN
# 533                                              NaN
# 613   Southern California Association of Governments
#
#                                   planning_authority tracking_category  \
# 684                                              NaN               NaN
# 261   Southern California Association of Governments            Active
# 773                                              NaN               NaN
# 16                                               NaN               NaN
# 113           San Luis Obispo Council of Governments            Active
# 698  Santa Barbara County Association of Governments            Active
# 476                                              NaN               NaN
# 808                                              NaN            Active
# 533                                              NaN               NaN
# 613   Southern California Association of Governments            Active
#
#        reporting_category assist_category eligibility_programs gtfs_datasets  \
# 684                   NaN             NaN                  NaN           NaN
# 261                  Core     White Glove                  NaN           NaN
# 773                   NaN             NaN                  NaN           NaN
# 16                    NaN             NaN                  NaN           NaN
# 113                  Core     White Glove                  NaN           NaN
# 698                  Core     White Glove                  NaN           NaN
# 476                   NaN             NaN                  NaN           NaN
# 808  Other Public Transit      Supportive                  NaN           NaN
# 533                   NaN             NaN                  NaN           NaN
# 613  Other Public Transit      Supportive                  NaN           NaN
#
#          gtfs_dataset__from_mobility_services_managed_  \
# 684                                                NaN
# 261  VCTC Schedule,VCTC Vehicle Positions,VCTC Trip...
# 773                                                NaN
# 16                                                 NaN
# 113                                                NaN
# 698  SBMTD Schedule,SBMTD VehiclePositions,SBMTD Al...
# 476                                                NaN
# 808                                                NaN
# 533                                                NaN
# 613                         Desert Roadrunner Schedule
#
#                fare_systems   gtfs_schedule_status  \
# 684                     NaN                    NaN
# 261                     NaN              ok,needed
# 773                     NaN                    NaN
# 16                      NaN                    NaN
# 113  Atascadero Dial-A-Ride                 needed
# 698                     NaN                     ok
# 476                     NaN                    NaN
# 808                     NaN  not public,not public
# 533                     NaN                    NaN
# 613                     NaN                     ok
#
#                        fares_v2_status              flex_status  \
# 684                                NaN                      NaN
# 261  Vendor published,Vendor published       Trillium - To code
# 773                                NaN                      NaN
# 16                                 NaN                      NaN
# 113                                NaN  Needed - Public service
# 698                 Provider published                      NaN
# 476                                NaN                      NaN
# 808                                NaN                      NaN
# 533                                NaN                      NaN
# 613                   Vendor published       Trillium - To code
#
#                           services_needing_alerts  \
# 684                                           NaN
# 261                          Moorpark Dial-A-Ride
# 773                                           NaN
# 16                                            NaN
# 113                        Atascadero Dial-A-Ride
# 698                                           NaN
# 476                                           NaN
# 808  Anteater Express, UCI Medical Center Shuttle
# 533                                           NaN
# 613                             Desert Roadrunner
#
#     services_needing_tripupdates_or_vehiclepositions  \
# 684                                              NaN
# 261                             Moorpark Dial-A-Ride
# 773                                              NaN
# 16                                               NaN
# 113                           Atascadero Dial-A-Ride
# 698                                              NaN
# 476                                              NaN
# 808     Anteater Express, UCI Medical Center Shuttle
# 533                                              NaN
# 613                                Desert Roadrunner
#
#      #_of_fixed_route_services  #_services_w__complete_rt_status  \
# 684                          0                                 0
# 261                          1                                 1
# 773                          0                                 0
# 16                           0                                 0
# 113                          0                                 0
# 698                          1                                 1
# 476                          0                                 0
# 808                          2                                 0
# 533                          0                                 0
# 613                          0                                 0
#
#      #_fixed_route_services_w__static_gtfs  \
# 684                                      0
# 261                                      1
# 773                                      0
# 16                                       0
# 113                                      0
# 698                                      1
# 476                                      0
# 808                                      0
# 533                                      0
# 613                                      0
#
#      complete_static_gtfs_coverage__1=yes_  complete_rt_coverage  \
# 684                                      1                     1
# 261                                      1                     1
# 773                                      1                     1
# 16                                       1                     1
# 113                                      1                     1
# 698                                      1                     1
# 476                                      1                     1
# 808                                      0                     0
# 533                                      1                     1
# 613                                      1                     1
#
#      >=1_gtfs_feed_for_any_service__1=yes_  >=_1_complete_rt_set__1=yes_  \
# 684                                      0                             0
# 261                                      1                             1
# 773                                      0                             0
# 16                                       0                             0
# 113                                      0                             0
# 698                                      1                             1
# 476                                      0                             0
# 808                                      0                             0
# 533                                      0                             0
# 613                                      0                             0
#
#     service_availability_category__from_mobility_services_managed_  \
# 684                                                NaN
# 261                              Public\n, Conditional
# 773                                                NaN
# 16                                                 NaN
# 113                                           Public\n
# 698                                           Public\n
# 476                                                NaN
# 808                                   Private, Private
# 533                                                NaN
# 613                                           Public\n
#
#      #_fixed_route_or_deviated_fixed_route_services  \
# 684                                               0
# 261                                               1
# 773                                               0
# 16                                                0
# 113                                               0
# 698                                               1
# 476                                               0
# 808                                               2
# 533                                               0
# 613                                               1
#
#      #_fixed_route_or_deviated_fixed_route_service_w__static_gtfs  \
# 684                                                  0
# 261                                                  1
# 773                                                  0
# 16                                                   0
# 113                                                  0
# 698                                                  1
# 476                                                  0
# 808                                                  0
# 533                                                  0
# 613                                                  1
#
#      #_services_with_missing_static_feed_for_fixed_route_or_deviated_fixed_route  \
# 684                                                  0
# 261                                                  0
# 773                                                  0
# 16                                                   0
# 113                                                  0
# 698                                                  0
# 476                                                  0
# 808                                                  2
# 533                                                  0
# 613                                                  0
#
#     county_geography county_geography_3 gtfs_static_status  \
# 684      San Joaquin        San Joaquin          Static OK
# 261              NaN                NaN          Static OK
# 773              NaN                NaN          Static OK
# 16               NaN                NaN          Static OK
# 113              NaN                NaN          Static OK
# 698              NaN                NaN          Static OK
# 476         Humboldt                NaN          Static OK
# 808              NaN                NaN  Static Incomplete
# 533              NaN                NaN          Static OK
# 613              NaN                NaN          Static OK
#
#     gtfs_realtime_status   service_availability service___component
# 684        RT Incomplete                    NaN                 NaN
# 261                RT OK  Public\n, Conditional                 NaN
# 773        RT Incomplete                    NaN                 NaN
# 16         RT Incomplete                    NaN                 NaN
# 113        RT Incomplete               Public\n                 NaN
# 698                RT OK               Public\n                 NaN
# 476        RT Incomplete                    NaN                 NaN
# 808        RT Incomplete       Private, Private                 NaN
# 533        RT Incomplete                    NaN                 NaN
# 613        RT Incomplete               Public\n                 NaN

# %%
df.gtfs_dataset_type.value_counts()
# Out:
# GTFS Schedule    281
# Name: gtfs_dataset_type, dtype: int64

# %% [markdown]
# ## Recreating screenshot filters:

# %%
orgs = (orgs>>select(_.name,
              _.organization_type,
              _.ntp_id,
              _.itp_id,
              _.opm_id_drmt,
             _.brand, 
              _.alias,
             _.reporting_category,
             _.fares_v2_status,
              _.mobility_services_managed,
              _.mobility_services_operated,
              _.gtfs_datasets_produced,
              _.service_type__from_mobility_services_managed_,
             _.service_type__from_mobility_services_operated_,
              _.currently_operating__from_mobility_services_managed_,
              _.headquarters_place,
              _.caltrans_district,
              _.gtfs_dataset__from_mobility_services_managed_,
              _.gtfs_schedule_status,
              _['#_of_fixed_route_services'],
              _['#_fixed_route_or_deviated_fixed_route_services'],
              _.gtfs_static_status,
              _.gtfs_realtime_status)
        )

# %% [markdown]
# ### Airtable filters

# %%
orgs.sample()
# Out:
#                name organization_type ntp_id  itp_id  opm_id_drmt brand alias  \
# 116  City of Avalon         City/Town  90249    24.0          NaN   NaN   NaN
#
#     reporting_category   fares_v2_status  \
# 116               Core  Vendor published
#
#                              mobility_services_managed  \
# 116  Avalon Community Transit,Avalon Dial-A-Ride,Av...
#
#     mobility_services_operated gtfs_datasets_produced  \
# 116                        NaN        Avalon Schedule
#
#          service_type__from_mobility_services_managed_  \
# 116  fixed-route,on-demand,ADA paratransit,reservat...
#
#     service_type__from_mobility_services_operated_  \
# 116                                            NaN
#
#     currently_operating__from_mobility_services_managed_ headquarters_place  \
# 116                                 3 checked out of 3               Avalon
#
#     caltrans_district      gtfs_dataset__from_mobility_services_managed_  \
# 116  07 - Los Angeles  Avalon Schedule,Avalon Alerts,Avalon Vehicle P...
#
#     gtfs_schedule_status  #_of_fixed_route_services  \
# 116     ok,needed,needed                          1
#
#      #_fixed_route_or_deviated_fixed_route_services gtfs_static_status  \
# 116                                               1          Static OK
#
#     gtfs_realtime_status
# 116                RT OK

# %% [markdown]
# #### Filter: `reporting_category`

# %%
orgs_2 = ((orgs.query("reporting_category == ('Core') or reporting_category ==('Other Public Transit')"))
 >> filter(_.currently_operating__from_mobility_services_managed_.str.contains('checked'))
)

#orgs_2.query("service_type__from_mobility_services_managed_.str.contains('fixed-route') 
## or service_type__from_mobility_services_managed_.str.contains('deviated fixed-route')
## or service_type__from_mobility_services_managed_.str.contains('on-demand fixed-route')")

orgs_2.head()
# Out:
#                                      name   organization_type      ntp_id  \
# 4                         Access Services                 NaN       90157
# 11  Alameda-Contra Costa Transit District  Independent Agency       90014
# 14                          Alpine County              County  9R02-91116
# 18         Amador Regional Transit System  Independent Agency  9R02-91000
# 24                                 Amtrak  Federal Government         NaN
#
#     itp_id  opm_id_drmt brand       alias    reporting_category  \
# 4      1.0          NaN   NaN         NaN                  Core
# 11     4.0     401001.0   NaN  AC Transit                  Core
# 14     9.0    1002001.0   NaN         NaN                  Core
# 18    11.0    1003002.0   NaN         NaN                  Core
# 24    13.0          NaN   NaN         NaN  Other Public Transit
#
#                                       fares_v2_status  \
# 4                                                 NaN
# 11  Provider published,Vendor published,Provider p...
# 14                                                NaN
# 18                                   Vendor published
# 24                            Unknown,Unknown,Unknown
#
#                             mobility_services_managed  \
# 4                                  LA Access Services
# 11  AC Transit,Dumbarton Express,East Bay Paratran...
# 14                              Alpine County Transit
# 18          Amador Transit,Amador Transit Dial-A-Ride
# 24  Coast Starlight,California Zephyr,Thruway,Sout...
#
#                            mobility_services_operated  \
# 4                                  LA Access Services
# 11    AC Transit,AC Transit Transbay,AC Transit Tempo
# 14                              Alpine County Transit
# 18          Amador Transit,Amador Transit Dial-A-Ride
# 24  Coast Starlight,California Zephyr,Amtrak San J...
#
#                                gtfs_datasets_produced  \
# 4                                                 NaN
# 11  AC Transit Schedule,AC Transit VehiclePosition...
# 14                                                NaN
# 18                                    Amador Schedule
# 24                                    Amtrak Schedule
#
#         service_type__from_mobility_services_managed_  \
# 4                                     ADA paratransit
# 11  fixed-route,fixed-route,ADA paratransit,fixed-...
# 14                                          on-demand
# 18  fixed-route,deviated fixed-route,ADA paratrans...
# 24  fixed-route,fixed-route,fixed-route,fixed-rout...
#
#        service_type__from_mobility_services_operated_  \
# 4                                     ADA paratransit
# 11                fixed-route,fixed-route,fixed-route
# 14                                          on-demand
# 18  fixed-route,deviated fixed-route,ADA paratrans...
# 24  fixed-route,fixed-route,fixed-route,fixed-rout...
#
#    currently_operating__from_mobility_services_managed_ headquarters_place  \
# 4                                  1 checked out of 1             El Monte
# 11                                 5 checked out of 5              Oakland
# 14                                 1 checked out of 1         Markleeville
# 18                                 2 checked out of 2              Jackson
# 24                                 5 checked out of 6           Washington
#
#    caltrans_district      gtfs_dataset__from_mobility_services_managed_  \
# 4   07 - Los Angeles                                                NaN
# 11      04 - Oakland  Bay Area 511 TripUpdates,Bay Area 511 VehicleP...
# 14     10 - Stockton                                                NaN
# 18     10 - Stockton                                    Amador Schedule
# 24   03 - Marysville  Amtrak Schedule,Amtrak Schedule,Amtrak Schedul...
#
#    gtfs_schedule_status  #_of_fixed_route_services  \
# 4                needed                          0
# 11   ok,ok,needed,ok,ok                          4
# 14               needed                          0
# 18            ok,needed                          1
# 24             ok,ok,ok                          5
#
#     #_fixed_route_or_deviated_fixed_route_services gtfs_static_status  \
# 4                                                0          Static OK
# 11                                               4          Static OK
# 14                                               0          Static OK
# 18                                               1          Static OK
# 24                                               6          Static OK
#
#    gtfs_realtime_status
# 4         RT Incomplete
# 11                RT OK
# 14        RT Incomplete
# 18        RT Incomplete
# 24        RT Incomplete

# %% [markdown]
# #### Filter: `service_type__from_mobility_services_managed_`

# %%
orgs_2>>filter(_.service_type__from_mobility_services_managed_.str.contains("on-demand fixed-route"))
# Out:
#                 name organization_type      ntp_id  itp_id  opm_id_drmt brand  \
# 332  City of Shafter         City/Town  9R02-91120   303.0     615008.0   NaN
#
#     alias reporting_category fares_v2_status mobility_services_managed  \
# 332   NaN               Core             NaN       Shafter Dial-A-Ride
#
#     mobility_services_operated gtfs_datasets_produced  \
# 332        Shafter Dial-A-Ride                    NaN
#
#     service_type__from_mobility_services_managed_  \
# 332               on-demand,on-demand fixed-route
#
#     service_type__from_mobility_services_operated_  \
# 332                on-demand,on-demand fixed-route
#
#     currently_operating__from_mobility_services_managed_ headquarters_place  \
# 332                                 1 checked out of 1              Shafter
#
#     caltrans_district gtfs_dataset__from_mobility_services_managed_  \
# 332       06 - Fresno                                           NaN
#
#     gtfs_schedule_status  #_of_fixed_route_services  \
# 332               needed                          0
#
#      #_fixed_route_or_deviated_fixed_route_services gtfs_static_status  \
# 332                                               0          Static OK
#
#     gtfs_realtime_status
# 332        RT Incomplete

# %%
##doesnt work
#orgs_2.query('service_type__from_mobility_services_managed_.str.contains("fixed-route")')

# %%
fixed = orgs_2[
    (orgs_2["service_type__from_mobility_services_managed_"].str.contains("fixed-route")
    ) | (orgs_2["service_type__from_mobility_services_managed_"].str.contains("deviated fixed-route")
        ) | (orgs_2["service_type__from_mobility_services_managed_"].str.contains("on-demand fixed-route"))
]

# %%
print(f"There are {len(fixed)} organizations using a variation of fixed-route service")
# Out:
# There are 194 organizations using a variation of fixed-route service

# %%
fixed = (fixed>>select(_.name,
              _.organization_type,
              _.ntp_id,
              _.itp_id,
              _.opm_id_drmt,
              _.brand, 
              _.alias,
              _.mobility_services_managed,
              _.mobility_services_operated,
              _.gtfs_datasets_produced,
              _.service_type__from_mobility_services_managed_,
              _.currently_operating__from_mobility_services_managed_,
              _.headquarters_place,
              _.caltrans_district,
              _.gtfs_dataset__from_mobility_services_managed_,
              _.gtfs_schedule_status,
              _['#_of_fixed_route_services'],
              _['#_fixed_route_or_deviated_fixed_route_services'],
              _.fares_v2_status,
              _.gtfs_static_status,
              _.gtfs_realtime_status)
        )

# %%
fixed
# Out:
#                                                   name   organization_type  \
# 11               Alameda-Contra Costa Transit District  Independent Agency
# 18                      Amador Regional Transit System  Independent Agency
# 24                                              Amtrak  Federal Government
# 25                      Anaheim Transportation Network                 NaN
# 29                   Antelope Valley Transit Authority  Independent Agency
# ..                                                 ...                 ...
# 839             Western Contra Costa Transit Authority  Independent Agency
# 847                Yolo County Transportation District  Independent Agency
# 848       Yosemite Area Regional Transportation System  Independent Agency
# 849                      Yuba-Sutter Transit Authority  Independent Agency
# 850  Yuma County Intergovernmental Public Transport...  Independent Agency
#
#          ntp_id  itp_id  opm_id_drmt                brand       alias  \
# 11        90014     4.0     401001.0                  NaN  AC Transit
# 18   9R02-91000    11.0    1003002.0                  NaN         NaN
# 24          NaN    13.0          NaN                  NaN         NaN
# 25        90211    14.0    1230016.0                  NaN         NaN
# 29        90121    16.0     719002.0                  NaN         NaN
# ..          ...     ...          ...                  ...         ...
# 839       90159   368.0     407003.0              WestCAT         NaN
# 847       90090   372.0     357002.0              Yolobus         NaN
# 848  9R02-91070   374.0    1024004.0                  NaN       YARTS
# 849       90061   376.0     358001.0  Yuba-Sutter Transit         NaN
# 850       90233   386.0    1113004.0                  NaN         NaN
#
#                              mobility_services_managed  \
# 11   AC Transit,Dumbarton Express,East Bay Paratran...
# 18           Amador Transit,Amador Transit Dial-A-Ride
# 24   Coast Starlight,California Zephyr,Thruway,Sout...
# 25   Anaheim Resort Transportation,FRAN,Anaheim Tra...
# 29   Antelope Valley Dial-A-Ride,Antelope Valley Tr...
# ..                                                 ...
# 839  WestCAT Local,WestCAT Lynx Express,WestCAT Exp...
# 847                            Yolobus,Yolobus Special
# 848       Yosemite Area Regional Transportation System
# 849  Yuba-Sutter Transit,Yuba-Sutter Rural Transit,...
# 850                           Yuma County Area Transit
#
#                             mobility_services_operated  \
# 11     AC Transit,AC Transit Transbay,AC Transit Tempo
# 18           Amador Transit,Amador Transit Dial-A-Ride
# 24   Coast Starlight,California Zephyr,Amtrak San J...
# 25   Anaheim Resort Transportation,FRAN,Anaheim Tra...
# 29   Antelope Valley Dial-A-Ride,Antelope Valley Tr...
# ..                                                 ...
# 839  WestCAT Local,WestCAT Lynx Express,WestCAT Exp...
# 847        Yolobus,Yolobus Special,Causeway Connection
# 848       Yosemite Area Regional Transportation System
# 849  Yuba-Sutter Transit,Yuba-Sutter Rural Transit,...
# 850                           Yuma County Area Transit
#
#                                 gtfs_datasets_produced  \
# 11   AC Transit Schedule,AC Transit VehiclePosition...
# 18                                     Amador Schedule
# 24                                     Amtrak Schedule
# 25   Anaheim Resort Schedule,Anaheim Resort Vehicle...
# 29          Antelope Valley Transit Authority Schedule
# ..                                                 ...
# 839                                   WestCAT Schedule
# 847  Yolobus Schedule,Yolobus Vehicle Positions,Yol...
# 848                                     YARTS Schedule
# 849                               Yuba-Sutter Schedule
# 850                                      Yuma Schedule
#
#          service_type__from_mobility_services_managed_  \
# 11   fixed-route,fixed-route,ADA paratransit,fixed-...
# 18   fixed-route,deviated fixed-route,ADA paratrans...
# 24   fixed-route,fixed-route,fixed-route,fixed-rout...
# 25               fixed-route,on-demand,ADA paratransit
# 29               ADA paratransit,on-demand,fixed-route
# ..                                                 ...
# 839  fixed-route,fixed-route,fixed-route,on-demand,...
# 847  fixed-route,deviated fixed-route,ADA paratrans...
# 848                               seasonal,fixed-route
# 849  fixed-route,on-demand,deviated fixed-route,res...
# 850                                        fixed-route
#
#     currently_operating__from_mobility_services_managed_ headquarters_place  \
# 11                                  5 checked out of 5              Oakland
# 18                                  2 checked out of 2              Jackson
# 24                                  5 checked out of 6           Washington
# 25                                  3 checked out of 3              Anaheim
# 29                                  2 checked out of 2            Lancaster
# ..                                                 ...                  ...
# 839                                 5 checked out of 5               Pinole
# 847                                 2 checked out of 2             Woodland
# 848                                 1 checked out of 1               Merced
# 849                                 5 checked out of 5           Marysville
# 850                                 1 checked out of 1             Yuma, AZ
#
#     caltrans_district      gtfs_dataset__from_mobility_services_managed_  \
# 11       04 - Oakland  Bay Area 511 TripUpdates,Bay Area 511 VehicleP...
# 18      10 - Stockton                                    Amador Schedule
# 24    03 - Marysville  Amtrak Schedule,Amtrak Schedule,Amtrak Schedul...
# 25        12 - Irvine                            Anaheim Resort Schedule
# 29   07 - Los Angeles         Antelope Valley Transit Authority Schedule
# ..                ...                                                ...
# 839      04 - Oakland  Bay Area 511 Schedule,Bay Area 511 Schedule,Ba...
# 847   03 - Marysville  Yolobus Schedule,Yolobus Vehicle Positions,Yol...
# 848     10 - Stockton                                     YARTS Schedule
# 849   03 - Marysville  Yuba-Sutter Schedule,Yuba-Sutter Schedule,Yuba...
# 850    11 - San Diego                                      Yuma Schedule
#
#        gtfs_schedule_status  #_of_fixed_route_services  \
# 11       ok,ok,needed,ok,ok                          4
# 18                ok,needed                          1
# 24                 ok,ok,ok                          5
# 25         ok,needed,needed                          1
# 29                needed,ok                          1
# ..                      ...                        ...
# 839  ok,ok,ok,needed,needed                          3
# 847               ok,needed                          1
# 848                      ok                          1
# 849        ok,needed,needed                          3
# 850                      ok                          1
#
#      #_fixed_route_or_deviated_fixed_route_services  \
# 11                                                4
# 18                                                1
# 24                                                6
# 25                                                1
# 29                                                1
# ..                                              ...
# 839                                               3
# 847                                               1
# 848                                               1
# 849                                               4
# 850                                               1
#
#                                        fares_v2_status gtfs_static_status  \
# 11   Provider published,Vendor published,Provider p...          Static OK
# 18                                    Vendor published          Static OK
# 24                             Unknown,Unknown,Unknown          Static OK
# 25                                    Blocked - Vendor          Static OK
# 29                                                 NaN          Static OK
# ..                                                 ...                ...
# 839  Vendor published,Vendor published,Vendor publi...          Static OK
# 847                                Provider to Publish          Static OK
# 848                                   Vendor published          Static OK
# 849  Vendor published,Vendor published,Vendor publi...          Static OK
# 850                                            Unknown          Static OK
#
#     gtfs_realtime_status
# 11                 RT OK
# 18         RT Incomplete
# 24         RT Incomplete
# 25         RT Incomplete
# 29         RT Incomplete
# ..                   ...
# 839        RT Incomplete
# 847                RT OK
# 848        RT Incomplete
# 849        RT Incomplete
# 850        RT Incomplete
#
# [194 rows x 21 columns]

# %% [markdown]
# #### Filter: `currently_operating__from_mobility_services_managed_`

# %%
fixed.currently_operating__from_mobility_services_managed_.value_counts()
# Out:
# 2 checked out of 2      73
# 1 checked out of 1      42
# 3 checked out of 3      30
# 5 checked out of 5       8
# 4 checked out of 4       8
# 9 checked out of 9       5
# 8 checked out of 8       4
# 2 checked out of 3       4
# 0 checked out of 1       3
# 1 checked out of 2       3
# 6 checked out of 6       3
# 4 checked out of 5       2
# 3 checked out of 4       2
# 22 checked out of 22     1
# 16 checked out of 16     1
# 7 checked out of 7       1
# 6 checked out of 7       1
# 5 checked out of 6       1
# 2 checked out of 4       1
# 10 checked out of 11     1
# Name: currently_operating__from_mobility_services_managed_, dtype: int64

# %%
fixed = fixed[~fixed["currently_operating__from_mobility_services_managed_"].str.contains("0 checked out of")]

# %%
len(fixed)
# Out:
# 190

# %% [markdown]
# #### * `fixed` is a df with the agencies fitting the criteria specificed in [GitHub Issue #985](https://github.com/cal-itp/data-infra/issues/985)

# %% [markdown]
# #### Adding filters into a function for easier filtering

# %%
def add_airtable_filter(orgs):
    #narrow down the columns
    orgs = (orgs>>select(_.name,
                         _.organization_type,
                         _.ntp_id,
                         _.itp_id,
                         _.opm_id_drmt,
                         _.brand, 
                         _.alias,
                         _.reporting_category,
                         _.fares_v2_status,
                         _.mobility_services_managed,
                         _.mobility_services_operated,
                         _.gtfs_datasets_produced,
                         _.service_type__from_mobility_services_managed_,
                         _.service_type__from_mobility_services_operated_,
                         _.currently_operating__from_mobility_services_managed_,
                         _.headquarters_place,
                         _.caltrans_district,
                         _.gtfs_dataset__from_mobility_services_managed_,
                         _.gtfs_schedule_status,
                         _['#_of_fixed_route_services'],
                         _['#_fixed_route_or_deviated_fixed_route_services'],
                         _.gtfs_static_status,
                         _.gtfs_realtime_status)
        )
    
    # filter for reporting category
    orgs_2 = ((orgs.query("reporting_category == ('Core') or reporting_category ==('Other Public Transit')"))
              >> filter(_.currently_operating__from_mobility_services_managed_.str.contains('checked')))
    
    # filter for service type
    fixed = orgs_2[
        (orgs_2["service_type__from_mobility_services_managed_"].str.contains("fixed-route")
        ) | (orgs_2["service_type__from_mobility_services_managed_"].str.contains("deviated fixed-route")
            ) | (orgs_2["service_type__from_mobility_services_managed_"].str.contains("on-demand fixed-route"))
    ]
    
    # filter for currently operating
    fixed = fixed[~fixed["currently_operating__from_mobility_services_managed_"].str.contains("0 checked out of")]
    
    return fixed

# %%
filtered = add_airtable_filter(orgs)

# %%
filtered.head()
# Out:
#                                      name   organization_type      ntp_id  \
# 11  Alameda-Contra Costa Transit District  Independent Agency       90014
# 18         Amador Regional Transit System  Independent Agency  9R02-91000
# 24                                 Amtrak  Federal Government         NaN
# 25         Anaheim Transportation Network                 NaN       90211
# 29      Antelope Valley Transit Authority  Independent Agency       90121
#
#     itp_id  opm_id_drmt brand       alias    reporting_category  \
# 11     4.0     401001.0   NaN  AC Transit                  Core
# 18    11.0    1003002.0   NaN         NaN                  Core
# 24    13.0          NaN   NaN         NaN  Other Public Transit
# 25    14.0    1230016.0   NaN         NaN                  Core
# 29    16.0     719002.0   NaN         NaN                  Core
#
#                                       fares_v2_status  \
# 11  Provider published,Vendor published,Provider p...
# 18                                   Vendor published
# 24                            Unknown,Unknown,Unknown
# 25                                   Blocked - Vendor
# 29                                                NaN
#
#                             mobility_services_managed  \
# 11  AC Transit,Dumbarton Express,East Bay Paratran...
# 18          Amador Transit,Amador Transit Dial-A-Ride
# 24  Coast Starlight,California Zephyr,Thruway,Sout...
# 25  Anaheim Resort Transportation,FRAN,Anaheim Tra...
# 29  Antelope Valley Dial-A-Ride,Antelope Valley Tr...
#
#                            mobility_services_operated  \
# 11    AC Transit,AC Transit Transbay,AC Transit Tempo
# 18          Amador Transit,Amador Transit Dial-A-Ride
# 24  Coast Starlight,California Zephyr,Amtrak San J...
# 25  Anaheim Resort Transportation,FRAN,Anaheim Tra...
# 29  Antelope Valley Dial-A-Ride,Antelope Valley Tr...
#
#                                gtfs_datasets_produced  \
# 11  AC Transit Schedule,AC Transit VehiclePosition...
# 18                                    Amador Schedule
# 24                                    Amtrak Schedule
# 25  Anaheim Resort Schedule,Anaheim Resort Vehicle...
# 29         Antelope Valley Transit Authority Schedule
#
#         service_type__from_mobility_services_managed_  \
# 11  fixed-route,fixed-route,ADA paratransit,fixed-...
# 18  fixed-route,deviated fixed-route,ADA paratrans...
# 24  fixed-route,fixed-route,fixed-route,fixed-rout...
# 25              fixed-route,on-demand,ADA paratransit
# 29              ADA paratransit,on-demand,fixed-route
#
#        service_type__from_mobility_services_operated_  \
# 11                fixed-route,fixed-route,fixed-route
# 18  fixed-route,deviated fixed-route,ADA paratrans...
# 24  fixed-route,fixed-route,fixed-route,fixed-rout...
# 25              fixed-route,on-demand,ADA paratransit
# 29              ADA paratransit,on-demand,fixed-route
#
#    currently_operating__from_mobility_services_managed_ headquarters_place  \
# 11                                 5 checked out of 5              Oakland
# 18                                 2 checked out of 2              Jackson
# 24                                 5 checked out of 6           Washington
# 25                                 3 checked out of 3              Anaheim
# 29                                 2 checked out of 2            Lancaster
#
#    caltrans_district      gtfs_dataset__from_mobility_services_managed_  \
# 11      04 - Oakland  Bay Area 511 TripUpdates,Bay Area 511 VehicleP...
# 18     10 - Stockton                                    Amador Schedule
# 24   03 - Marysville  Amtrak Schedule,Amtrak Schedule,Amtrak Schedul...
# 25       12 - Irvine                            Anaheim Resort Schedule
# 29  07 - Los Angeles         Antelope Valley Transit Authority Schedule
#
#    gtfs_schedule_status  #_of_fixed_route_services  \
# 11   ok,ok,needed,ok,ok                          4
# 18            ok,needed                          1
# 24             ok,ok,ok                          5
# 25     ok,needed,needed                          1
# 29            needed,ok                          1
#
#     #_fixed_route_or_deviated_fixed_route_services gtfs_static_status  \
# 11                                               4          Static OK
# 18                                               1          Static OK
# 24                                               6          Static OK
# 25                                               1          Static OK
# 29                                               1          Static OK
#
#    gtfs_realtime_status
# 11                RT OK
# 18        RT Incomplete
# 24        RT Incomplete
# 25        RT Incomplete
# 29        RT Incomplete

# %%
len(filtered)
# Out:
# 190

# %%
filtered>>group_by(_.caltrans_district)>>summarize(number_agencies =_['name'].nunique())
# Out:
#        caltrans_district  number_agencies
# 0            01 - Eureka                7
# 1           02 - Redding                8
# 2        03 - Marysville               18
# 3           04 - Oakland               35
# 4   05 - San Luis Obispo               12
# 5            06 - Fresno               14
# 6       07 - Los Angeles               55
# 7    08 - San Bernardino               11
# 8            09 - Bishop                2
# 9          10 - Stockton               14
# 10        11 - San Diego                6
# 11           12 - Irvine                7

# %% [markdown]
# ### What percent of transit agencies have GTFS Schedule data?

# %%
skd_ok_expl = filtered>>select(_.name, _.gtfs_schedule_status)

# %%
skd_ok_expl.explode('gtfs_schedule_status')
# Out:
#                                                   name    gtfs_schedule_status
# 11               Alameda-Contra Costa Transit District      ok,ok,needed,ok,ok
# 18                      Amador Regional Transit System               ok,needed
# 24                                              Amtrak                ok,ok,ok
# 25                      Anaheim Transportation Network        ok,needed,needed
# 29                   Antelope Valley Transit Authority               needed,ok
# ..                                                 ...                     ...
# 839             Western Contra Costa Transit Authority  ok,ok,ok,needed,needed
# 847                Yolo County Transportation District               ok,needed
# 848       Yosemite Area Regional Transportation System                      ok
# 849                      Yuba-Sutter Transit Authority        ok,needed,needed
# 850  Yuma County Intergovernmental Public Transport...                      ok
#
# [190 rows x 2 columns]

# %%
skd_ok_expl = skd_ok_expl.assign(gtfs_schedule_status=skd_ok_expl.gtfs_schedule_status.str.split(','))

# %%
skd_ok_expl = skd_ok_expl.explode('gtfs_schedule_status')

# %%
skd_ok_expl>>filter(_.gtfs_schedule_status=='ok')>>count(_.name)
# Out:
#                                                   name  n
# 0                Alameda-Contra Costa Transit District  4
# 1                       Amador Regional Transit System  1
# 2                                               Amtrak  3
# 3                       Anaheim Transportation Network  1
# 4                    Antelope Valley Transit Authority  1
# ..                                                 ... ..
# 138             Western Contra Costa Transit Authority  3
# 139                Yolo County Transportation District  1
# 140       Yosemite Area Regional Transportation System  1
# 141                      Yuba-Sutter Transit Authority  1
# 142  Yuma County Intergovernmental Public Transport...  1
#
# [143 rows x 2 columns]

# %%
skd_ok_expl>>filter(_.gtfs_schedule_status=='needed')>>count(_.name)
# Out:
#                                                name  n
# 0             Alameda-Contra Costa Transit District  1
# 1                    Amador Regional Transit System  1
# 2                    Anaheim Transportation Network  2
# 3                 Antelope Valley Transit Authority  1
# 4                              Banning Pass Transit  1
# ..                                              ... ..
# 143                                    Walmart Inc.  1
# 144  West Berkeley Transportation Management Agency  1
# 145          Western Contra Costa Transit Authority  2
# 146             Yolo County Transportation District  1
# 147                   Yuba-Sutter Transit Authority  2
#
# [148 rows x 2 columns]

# %%
skd_ok_expl>>filter(_.gtfs_schedule_status=='need long-term solution')>>count(_.name)
# Out:
#                                                  name  n
# 0                                     City of Arcadia  1
# 1                                       City of Arvin  1
# 2                                City of Baldwin Park  1
# 3                                City of Bell Gardens  1
# 4                                  City of Bellflower  1
# 5                                   City of Calabasas  1
# 6                                   City of Camarillo  2
# 7                                     City of Compton  1
# 8                                      City of Cudahy  1
# 9                                      City of Downey  1
# 10                                 City of Ridgecrest  1
# 11                        City of San Juan Capistrano  1
# 12                               City of Sierra Madre  1
# 13                                 City of South Gate  1
# 14                                       City of Taft  1
# 15                                City of West Covina  1
# 16  San Francisco Bay Area Water Emergency Transit...  1

# %%
skd_ok_expl>>filter(_.gtfs_schedule_status=='research')>>count(_.name)
# Out:
#                                    name  n
# 0                       City of Burbank  1
# 1              Monterey-Salinas Transit  1
# 2       Morongo Basin Transit Authority  1
# 3  Napa Valley Transportation Authority  1
# 4                         Nevada County  1
# 5     San Mateo County Transit District  1

# %%
skd_ok_expl>>filter(_.gtfs_schedule_status=='not public')>>count(_.name)
# Out:
#                                name  n
# 0  University of California, Irvine  2

# %% [markdown]
# ***
# **NOTE** the probelm with this is that we cannot link the records back since Airtable nests the records
# ***

# %%
skd_ok = ((filtered[filtered["gtfs_schedule_status"].str.contains('needed')==False])
 >> select(_.name, _.organization_type, _.gtfs_schedule_status)
 >> filter(_.gtfs_schedule_status.str.contains('ok')))

# %%
print(f"Number of organizations with 'OK' (no 'needed') "
      f"status: {len(skd_ok)}")
# Out:
# Number of organizations with 'OK' (no 'needed') status: 37

# %%
#filtered2 =filtered[~filtered["gtfs_schedule_status"].str.contains('needed')]
skd_ok
# Out:
#                                                   name   organization_type  \
# 24                                              Amtrak  Federal Government
# 53                                 Blue Lake Rancheria               Tribe
# 77             Capitol Corridor Joint Powers Authority  Independent Agency
# 109                                     City of Arcata           City/Town
# 133                                    City of Burbank           City/Town
# 181                                     City of Eureka           City/Town
# 229                               City of Laguna Beach           City/Town
# 243                                    City of Lynwood           City/Town
# 272                                       City of Ojai           City/Town
# 298                                  City of Rio Vista           City/Town
# 299                                      City of Ripon           City/Town
# 313                            City of San Luis Obispo           City/Town
# 342                        City of South San Francisco           City/Town
# 379                                        Commute.org                 NaN
# 438                                   Foothill Transit  Independent Agency
# 461                     Golden Empire Transit District  Independent Agency
# 529                         Los Angeles World Airports  Independent Agency
# 551                                Menlo Park Shuttles                 NaN
# 565                    Modoc Transportation Authority   Independent Agency
# 574                    Morongo Basin Transit Authority  Independent Agency
# 585                                      Nevada County              County
# 594                           North Lake Tahoe Express                 NaN
# 613                   Palo Verde Valley Transit Agency  Independent Agency
# 621              Peninsula Corridor Joint Powers Board                 NaN
# 634                             Plumas Transit Systems  Independent Agency
# 681  San Francisco Bay Area Water Emergency Transit...  Independent Agency
# 682                San Francisco International Airport  Independent Agency
# 686                 San Joaquin Joint Powers Authority  Independent Agency
# 687               San Joaquin Regional Rail Commission  Independent Agency
# 697    Santa Barbara County Association of Governments                 NaN
# 698        Santa Barbara Metropolitan Transit District  Independent Agency
# 726                                    Siskiyou County              County
# 735            Sonoma-Marin Area Rail Transit District  Independent Agency
# 740        Southern California Regional Rail Authority  Independent Agency
# 787                                     Trinity County              County
# 848       Yosemite Area Regional Transportation System  Independent Agency
# 850  Yuma County Intergovernmental Public Transport...  Independent Agency
#
#            gtfs_schedule_status
# 24                     ok,ok,ok
# 53                           ok
# 77                           ok
# 109                          ok
# 133                 ok,research
# 181                          ok
# 229                          ok
# 243                          ok
# 272                          ok
# 298                          ok
# 299                          ok
# 313                          ok
# 342                          ok
# 379                          ok
# 438                          ok
# 461                       ok,ok
# 529                          ok
# 551                          ok
# 565                       ok,ok
# 574                 ok,research
# 585                 ok,research
# 594                          ok
# 613                          ok
# 621                       ok,ok
# 634                          ok
# 681  need long-term solution,ok
# 682                          ok
# 686                          ok
# 687                          ok
# 697                          ok
# 698                          ok
# 726                          ok
# 735                          ok
# 740                          ok
# 787                          ok
# 848                          ok
# 850                          ok

# %%
skd_needed = ((filtered[filtered["gtfs_schedule_status"].str.contains('need')==True])
 >> select(_.name, _.organization_type, _.gtfs_schedule_status)
             )

# %%
print(f"Number of organizations with 'needed' "
      f"status: {len(skd_needed)}")
# Out:
# Number of organizations with 'needed' status: 151

# %%
print(f"Number of organizations with 'needed' "
      f"status: {len(((filtered[filtered['gtfs_schedule_status'].str.contains('need long-term solution')==True])))}")
# Out:
# Number of organizations with 'needed' status: 17

# %%
filtered>>count(_.gtfs_schedule_status)>>filter(_.n>1)>>arrange(-_.n)
# Out:
#               gtfs_schedule_status   n
# 24                       ok,needed  44
# 23                              ok  29
# 25                ok,needed,needed  20
# 5                           needed  12
# 2   need long-term solution,needed  11
# 7                    needed,needed   7
# 8             needed,needed,needed   4
# 9      needed,needed,needed,needed   4
# 34                    ok,needed,ok   4
# 38                           ok,ok   3
# 50                     ok,research   3
# 0          need long-term solution   2
# 14                       needed,ok   2
# 15                needed,ok,needed   2
# 16         needed,ok,needed,needed   2
# 27  ok,needed,needed,needed,needed   2
# 39                    ok,ok,needed   2
# 46          ok,ok,ok,needed,needed   2

# %% [markdown]
# ### What percent of transit agencies have Fares v2?

# %%
filtered>>count(_.fares_v2_status)>>filter(_.n>1)>>arrange(-_.n)
# Out:
#                                       fares_v2_status   n
# 20                                   Vendor published  43
# 13                                            Unknown  20
# 3                                 Needs GTFS Schedule  11
# 24                  Vendor published,Vendor published  10
# 6                                 Provider to Publish   7
# 0                                    Blocked - Vendor   6
# 28  Vendor published,Vendor published,Vendor publi...   5
# 4                                  Provider published   3
# 15                                    Unknown,Unknown   3
# 17                            Unknown,Unknown,Unknown   3
# 26  Vendor published,Vendor published,Vendor publi...   3
# 7             Provider to Publish,Provider to Publish   2
# 21                  Vendor published,Blocked - Vendor   2
# 25  Vendor published,Vendor published,Needs GTFS S...   2
# 30  Vendor published,Vendor published,Vendor publi...   2

# %%
print(f"There are {len(filtered>>filter(_.fares_v2_status.str.contains('published')))} orgs with Fares v2 status as Published")
# Out:
# There are 81 orgs with Fares v2 status as Published

# %%
print(f"There are {len(filtered>>filter(_.fares_v2_status.str.contains('Unknown')))} orgs with Fares v2 status as Unknown")
# Out:
# There are 31 orgs with Fares v2 status as Unknown

# %%
print(f"There are {len(filtered>>filter(_.fares_v2_status.str.contains('Blocked')))} orgs with Fares v2 status as Blocked")
# Out:
# There are 10 orgs with Fares v2 status as Blocked

# %%
print(f"There are {len(filtered>>filter(_.fares_v2_status.str.contains('Needs')))} orgs with Fares v2 status as Needs")
# Out:
# There are 16 orgs with Fares v2 status as Needs

# %% [markdown]
# ### What percent of transit agencies are GTFS-compliant?

# %% [markdown]
# If we use `gtfs_static_status` or `gtfs_realtime_status` to determine if a transit agency is compliant, we are counting some of the needed GTFS static schedule data as "OK".
# <br>
#
# TO DO: Determine how the `gtfs_static_status` and `gtfs_realtime_status` columns are decided.

# %%
display(Markdown(f"There are {(len(filtered)) - (len(orgs>>filter(_.gtfs_datasets_produced.notnull())>>count(_.name)))} "
               f"fewer agencies that fit under the criteria for `orgs>>filter(_.gtfs_datasets_produced.notnull())>>count(_.name)` "
               f"than the specified filters in `fixed`"))
# Out:
# There are 38 fewer agencies that fit under the criteria for `orgs>>filter(_.gtfs_datasets_produced.notnull())>>count(_.name)` than the specified filters in `fixed`

# %%
display(Markdown(f" {'{:.1%}'.format(((len(filtered))/(len(orgs))))} of " 
                f"Organizations fit the criteria specified"))
# Out:
#  22.3% of Organizations fit the criteria specified

# %%
display(Markdown(f"There are **{len(filtered>>filter(_.gtfs_static_status==('Static Incomplete')))}** "
                 "organizations with Incomplete GTFS Static in the `Filtered` dataframe"
                ))
# Out:
# There are **33** organizations with Incomplete GTFS Static in the `Filtered` dataframe

# %%
display(Markdown(f"There are **{len(orgs>>filter(_.gtfs_static_status==('Static Incomplete')))}** "
                 "organizations with Incomplete GTFS Static in the `Airtable Organization` dataframe"
                ))
# Out:
# There are **70** organizations with Incomplete GTFS Static in the `Airtable Organization` dataframe

# %% [markdown]
# ### Note: Going Forward
# * is it worth connecting Metabase GTFS veiws with Airtable Agencies? This way we could be able to determine which GTFS feeds are actually being read, rather than rely on other information in Airtable

# %% [markdown]
# ### By Services

# %%
f1.sample(3)
# Out:
#                                       name  \
# 363                 City of West Hollywood
# 176                     City of El Segundo
# 621  Peninsula Corridor Joint Powers Board
#
#                              mobility_services_managed  \
# 363  WeHo Shuttles,West Hollywood On Call Transport...
# 176  El Segundo Dial-A-Ride,El Segundo Doctor Dial-...
# 621                         Caltrain,Caltrain Shuttles
#
#                             mobility_services_operated  \
# 363                             WeHo Shuttles,Cityline
# 176  El Segundo Dial-A-Ride,El Segundo Doctor Dial-...
# 621                         Caltrain,Caltrain Shuttles
#
#                                        fares_v2_status gtfs_datasets_produced  \
# 363                                                NaN                    NaN
# 176                                                NaN                    NaN
# 621  Vendor published,Needs GTFS Schedule,Blocked -...      Caltrain Schedule
#
#          service_type__from_mobility_services_managed_  \
# 363        fixed-route,on-demand,on-demand,fixed-route
# 176  on-demand,reservations,NEMT,reservations,fixed...
# 621                            fixed-route,fixed-route
#
#         service_type__from_mobility_services_operated_  \
# 363                            fixed-route,fixed-route
# 176  on-demand,reservations,NEMT,reservations,fixed...
# 621                            fixed-route,fixed-route
#
#             gtfs_schedule_status
# 363  needed,needed,needed,needed
# 176  needed,needed,needed,needed
# 621                        ok,ok

# %%
f2 = f1.copy()

# %%
columns = ['mobility_services_managed','mobility_services_operated',
           'fares_v2_status', 'gtfs_datasets_produced',
          'service_type__from_mobility_services_managed_',
           'service_type__from_mobility_services_operated_',
           'gtfs_schedule_status']

### following does not work

# for col in columns: 
#     f2.assign(col=f2.col.str.split(','))

# %%
# f2.assign(mobility_services_managed=f1.mobility_services_managed.str.split(','))
# f2.assign(mobility_services_operated=f1.mobility_services_operated.str.split(','))
# f2.assign(fares_v2_status=f1.fares_v2_status.str.split(','))
# f2.assign(gtfs_datasets_produced=f1.gtfs_datasets_produced.str.split(','))
# f2.assign(service_type__from_mobility_services_managed_=f1.service_type__from_mobility_services_managed_.str.split(','))
# f2.assign(service_type__from_mobility_services_operated_=f1.service_type__from_mobility_services_operated_.str.split(','))
# f2.assign(gtfs_schedule_status=f2.gtfs_schedule_status.str.split(','))

# %%
f3 = f1.copy()

# %%
## above does not work for all cols, just takes the last one. 
## attempting this from stack overflow:
## https://stackoverflow.com/questions/12680754/split-explode-pandas-dataframe-string-entry-to-separate-rows

# lst_col = ['mobility_services_managed','mobility_services_operated',
#            'fares_v2_status', 'gtfs_datasets_produced',
#           'service_type__from_mobility_services_managed_',
#            'service_type__from_mobility_services_operated_',
#            'gtfs_schedule_status']

# x = f3.assign(**{lst_col:f3[lst_col].str.split(',')})

# pd.DataFrame({
#      col:np.repeat(x[col].values, x[lst_col].str.len())
#      for col in x.columns.difference([lst_col])
#  }).assign(**{lst_col:np.concatenate(x[lst_col].values)})[x.columns.tolist()]

# %%
## also does not work

# (f3.set_index(['name']) 
#    .apply(lambda col: col.str.split(',').explode())
#    .reset_index())

# %%
## apply alone does not work as well

#(f3.apply(lambda col: col.str.split(',').explode()))

# %% [markdown]
# **note:** getting an error for the above attempts that index `ValueError: cannot reindex on an axis with duplicate labels`
#
# * making sure the name column is not duplciated.

# %%
print(len(f3))
print(f3.name.nunique())
# Out:
# 190
# 190

# %%
f3 >> count(_.name) >> arrange(-_.n)
# Out:
#                                                   name  n
# 0                Alameda-Contra Costa Transit District  1
# 1                       Amador Regional Transit System  1
# 2                                               Amtrak  1
# 3                       Anaheim Transportation Network  1
# 4                    Antelope Valley Transit Authority  1
# ..                                                 ... ..
# 185             Western Contra Costa Transit Authority  1
# 186                Yolo County Transportation District  1
# 187       Yosemite Area Regional Transportation System  1
# 188                      Yuba-Sutter Transit Authority  1
# 189  Yuma County Intergovernmental Public Transport...  1
#
# [190 rows x 2 columns]

# %%
f3.sample()
# Out:
#                name          mobility_services_managed  \
# 155  City of Corona  Corona Cruiser,Corona Dial-A-Ride
#
#             mobility_services_operated   fares_v2_status  \
# 155  Corona Cruiser,Corona Dial-A-Ride  Vendor published
#
#     gtfs_datasets_produced service_type__from_mobility_services_managed_  \
# 155        Corona Schedule                   fixed-route,ADA paratransit
#
#     service_type__from_mobility_services_operated_ gtfs_schedule_status
# 155                    fixed-route,ADA paratransit            ok,needed

# %% [markdown]
# #### Another Attempt

# %%
for col in columns:
    f3[col] = f3[col].str.split(',')

# %%
f3.head(5)
# Out:
#                                      name  \
# 11  Alameda-Contra Costa Transit District
# 18         Amador Regional Transit System
# 24                                 Amtrak
# 25         Anaheim Transportation Network
# 29      Antelope Valley Transit Authority
#
#                             mobility_services_managed  \
# 11  [AC Transit, Dumbarton Express, East Bay Parat...
# 18       [Amador Transit, Amador Transit Dial-A-Ride]
# 24  [Coast Starlight, California Zephyr, Thruway, ...
# 25  [Anaheim Resort Transportation, FRAN, Anaheim ...
# 29  [Antelope Valley Dial-A-Ride, Antelope Valley ...
#
#                            mobility_services_operated  \
# 11  [AC Transit, AC Transit Transbay, AC Transit T...
# 18       [Amador Transit, Amador Transit Dial-A-Ride]
# 24  [Coast Starlight, California Zephyr, Amtrak Sa...
# 25  [Anaheim Resort Transportation, FRAN, Anaheim ...
# 29  [Antelope Valley Dial-A-Ride, Antelope Valley ...
#
#                                       fares_v2_status  \
# 11  [Provider published, Vendor published, Provide...
# 18                                 [Vendor published]
# 24                        [Unknown, Unknown, Unknown]
# 25                                 [Blocked - Vendor]
# 29                                                NaN
#
#                                gtfs_datasets_produced  \
# 11  [AC Transit Schedule, AC Transit VehiclePositi...
# 18                                  [Amador Schedule]
# 24                                  [Amtrak Schedule]
# 25  [Anaheim Resort Schedule, Anaheim Resort Vehic...
# 29       [Antelope Valley Transit Authority Schedule]
#
#         service_type__from_mobility_services_managed_  \
# 11  [fixed-route, fixed-route, ADA paratransit, fi...
# 18  [fixed-route, deviated fixed-route, ADA paratr...
# 24  [fixed-route, fixed-route, fixed-route, fixed-...
# 25          [fixed-route, on-demand, ADA paratransit]
# 29          [ADA paratransit, on-demand, fixed-route]
#
#        service_type__from_mobility_services_operated_  \
# 11            [fixed-route, fixed-route, fixed-route]
# 18  [fixed-route, deviated fixed-route, ADA paratr...
# 24  [fixed-route, fixed-route, fixed-route, fixed-...
# 25          [fixed-route, on-demand, ADA paratransit]
# 29          [ADA paratransit, on-demand, fixed-route]
#
#         gtfs_schedule_status
# 11  [ok, ok, needed, ok, ok]
# 18              [ok, needed]
# 24              [ok, ok, ok]
# 25      [ok, needed, needed]
# 29              [needed, ok]

# %%
# worked!

# %% [markdown]
# #### exploding for `services managed`

# %%
#explode all columns 
f3.set_index('name').apply(pd.Series.explode).reset_index()
# Out:
# /tmp/ipykernel_1093/1501248361.py:2: FutureWarning: reindexing with a non-unique Index is deprecated and will raise in a future version.
#   f3.set_index('name').apply(pd.Series.explode).reset_index()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [220], in <cell line: 2>()
#       1 #explode all columns
# ----> 2 f3.set_index('name').apply(pd.Series.explode).reset_index()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:8839, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8828 from pandas.core.apply import frame_apply
#    8830 op = frame_apply(
#    8831     self,
#    8832     func=func,
#    (...)
#    8837     kwargs=kwargs,
#    8838 )
# -> 8839 return op.apply().__finalize__(self, method="apply")
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/apply.py:727, in FrameApply.apply(self)
#     724 elif self.raw:
#     725     return self.apply_raw()
# --> 727 return self.apply_standard()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/apply.py:854, in FrameApply.apply_standard(self)
#     851 results, res_index = self.apply_series_generator()
#     853 # wrap results
# --> 854 return self.wrap_results(results, res_index)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/apply.py:880, in FrameApply.wrap_results(self, results, res_index)
#     878 # see if we can infer the results
#     879 if len(results) > 0 and 0 in results and is_sequence(results[0]):
# --> 880     return self.wrap_results_for_axis(results, res_index)
#     882 # dict of scalars
#     883
#     884 # the default dtype of an empty Series will be `object`, but this
#     885 # code can be hit by df.mean() where the result should have dtype
#     886 # float64 even if it's an empty Series.
#     887 constructor_sliced = self.obj._constructor_sliced
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/apply.py:948, in FrameRowApply.wrap_results_for_axis(self, results, res_index)
#     945     return res
#     947 try:
# --> 948     result = self.obj._constructor(data=results)
#     949 except ValueError as err:
#     950     if "All arrays must be of the same length" in str(err):
#     951         # e.g. result = [[2, 3], [1.5], ['foo', 'bar']]
#     952         #  see test_agg_listlike_result GH#29587
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
#     638     import numpy.ma.mrecords as mrecords
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/internals/construction.py:502, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     494     arrays = [
#     495         x
#     496         if not hasattr(x, "dtype") or not isinstance(x.dtype, ExtensionDtype)
#     497         else x.copy()
#     498         for x in arrays
#     499     ]
#     500     # TODO: can we get rid of the dt64tz special case above?
# --> 502 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/internals/construction.py:125, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     122         index = ensure_index(index)
#     124     # don't force copy because getting jammed in an ndarray anyway
# --> 125     arrays = _homogenize(arrays, index, dtype)
#     126     # _homogenize ensures
#     127     #  - all(len(x) == len(index) for x in arrays)
#     128     #  - all(x.ndim == 1 for x in arrays)
#    (...)
#     131
#     132 else:
#     133     index = ensure_index(index)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/internals/construction.py:607, in _homogenize(data, index, dtype)
#     603         val = val.astype(dtype, copy=False)
#     604     if val.index is not index:
#     605         # Forces alignment. No need to copy data since we
#     606         # are putting it into an ndarray later
# --> 607         val = val.reindex(index, copy=False)
#     609     val = val._values
#     610 else:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/series.py:4672, in Series.reindex(self, *args, **kwargs)
#    4668         raise TypeError(
#    4669             "'index' passed as both positional and keyword argument"
#    4670         )
#    4671     kwargs.update({"index": index})
# -> 4672 return super().reindex(**kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:4966, in NDFrame.reindex(self, *args, **kwargs)
#    4963     return self._reindex_multi(axes, copy, fill_value)
#    4965 # perform the reindex on the axes
# -> 4966 return self._reindex_axes(
#    4967     axes, level, limit, tolerance, method, fill_value, copy
#    4968 ).__finalize__(self, method="reindex")
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:4986, in NDFrame._reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4981 new_index, indexer = ax.reindex(
#    4982     labels, level=level, limit=limit, tolerance=tolerance, method=method
#    4983 )
#    4985 axis = self._get_axis_number(a)
# -> 4986 obj = obj._reindex_with_indexers(
#    4987     {axis: [new_index, indexer]},
#    4988     fill_value=fill_value,
#    4989     copy=copy,
#    4990     allow_dups=False,
#    4991 )
#    4992 # If we've made a copy once, no need to make another one
#    4993 copy = False
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:5032, in NDFrame._reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    5029     indexer = ensure_platform_int(indexer)
#    5031 # TODO: speed up on homogeneous DataFrame objects (see _reindex_multi)
# -> 5032 new_data = new_data.reindex_indexer(
#    5033     index,
#    5034     indexer,
#    5035     axis=baxis,
#    5036     fill_value=fill_value,
#    5037     allow_dups=allow_dups,
#    5038     copy=copy,
#    5039 )
#    5040 # If we've made a copy once, no need to make another one
#    5041 copy = False
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/internals/managers.py:679, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice, use_na_proxy)
#     677 # some axes don't allow reindexing with dups
#     678 if not allow_dups:
# --> 679     self.axes[axis]._validate_can_reindex(indexer)
#     681 if axis >= self.ndim:
#     682     raise IndexError("Requested axis not found in manager")
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:4107, in Index._validate_can_reindex(self, indexer)
#    4105 # trying to reindex on an axis with duplicates
#    4106 if not self._index_as_unique and len(indexer):
# -> 4107     raise ValueError("cannot reindex on an axis with duplicate labels")
#
# ValueError: cannot reindex on an axis with duplicate labels

# %%
#trying two columns 

f3.explode(['mobility_services_managed', 'gtfs_schedule_status'])

# %%
#explode just one column
f3.explode('mobility_services_managed')
# Out:
#                                                   name  \
# 11               Alameda-Contra Costa Transit District
# 11               Alameda-Contra Costa Transit District
# 11               Alameda-Contra Costa Transit District
# 11               Alameda-Contra Costa Transit District
# 11               Alameda-Contra Costa Transit District
# ..                                                 ...
# 849                      Yuba-Sutter Transit Authority
# 849                      Yuba-Sutter Transit Authority
# 849                      Yuba-Sutter Transit Authority
# 849                      Yuba-Sutter Transit Authority
# 850  Yuma County Intergovernmental Public Transport...
#
#               mobility_services_managed  \
# 11                           AC Transit
# 11                    Dumbarton Express
# 11                 East Bay Paratransit
# 11                  AC Transit Transbay
# 11                     AC Transit Tempo
# ..                                  ...
# 849           Yuba-Sutter Rural Transit
# 849             Yuba-Sutter Dial-A-Ride
# 849                  Sacramento Express
# 849  Yuba College Sutter Campus Shuttle
# 850            Yuma County Area Transit
#
#                             mobility_services_operated  \
# 11   [AC Transit, AC Transit Transbay, AC Transit T...
# 11   [AC Transit, AC Transit Transbay, AC Transit T...
# 11   [AC Transit, AC Transit Transbay, AC Transit T...
# 11   [AC Transit, AC Transit Transbay, AC Transit T...
# 11   [AC Transit, AC Transit Transbay, AC Transit T...
# ..                                                 ...
# 849  [Yuba-Sutter Transit, Yuba-Sutter Rural Transi...
# 849  [Yuba-Sutter Transit, Yuba-Sutter Rural Transi...
# 849  [Yuba-Sutter Transit, Yuba-Sutter Rural Transi...
# 849  [Yuba-Sutter Transit, Yuba-Sutter Rural Transi...
# 850                         [Yuma County Area Transit]
#
#                                        fares_v2_status  \
# 11   [Provider published, Vendor published, Provide...
# 11   [Provider published, Vendor published, Provide...
# 11   [Provider published, Vendor published, Provide...
# 11   [Provider published, Vendor published, Provide...
# 11   [Provider published, Vendor published, Provide...
# ..                                                 ...
# 849  [Vendor published, Vendor published, Vendor pu...
# 849  [Vendor published, Vendor published, Vendor pu...
# 849  [Vendor published, Vendor published, Vendor pu...
# 849  [Vendor published, Vendor published, Vendor pu...
# 850                                          [Unknown]
#
#                                 gtfs_datasets_produced  \
# 11   [AC Transit Schedule, AC Transit VehiclePositi...
# 11   [AC Transit Schedule, AC Transit VehiclePositi...
# 11   [AC Transit Schedule, AC Transit VehiclePositi...
# 11   [AC Transit Schedule, AC Transit VehiclePositi...
# 11   [AC Transit Schedule, AC Transit VehiclePositi...
# ..                                                 ...
# 849                             [Yuba-Sutter Schedule]
# 849                             [Yuba-Sutter Schedule]
# 849                             [Yuba-Sutter Schedule]
# 849                             [Yuba-Sutter Schedule]
# 850                                    [Yuma Schedule]
#
#          service_type__from_mobility_services_managed_  \
# 11   [fixed-route, fixed-route, ADA paratransit, fi...
# 11   [fixed-route, fixed-route, ADA paratransit, fi...
# 11   [fixed-route, fixed-route, ADA paratransit, fi...
# 11   [fixed-route, fixed-route, ADA paratransit, fi...
# 11   [fixed-route, fixed-route, ADA paratransit, fi...
# ..                                                 ...
# 849  [fixed-route, on-demand, deviated fixed-route,...
# 849  [fixed-route, on-demand, deviated fixed-route,...
# 849  [fixed-route, on-demand, deviated fixed-route,...
# 849  [fixed-route, on-demand, deviated fixed-route,...
# 850                                      [fixed-route]
#
#         service_type__from_mobility_services_operated_  \
# 11             [fixed-route, fixed-route, fixed-route]
# 11             [fixed-route, fixed-route, fixed-route]
# 11             [fixed-route, fixed-route, fixed-route]
# 11             [fixed-route, fixed-route, fixed-route]
# 11             [fixed-route, fixed-route, fixed-route]
# ..                                                 ...
# 849  [fixed-route, on-demand, deviated fixed-route,...
# 849  [fixed-route, on-demand, deviated fixed-route,...
# 849  [fixed-route, on-demand, deviated fixed-route,...
# 849  [fixed-route, on-demand, deviated fixed-route,...
# 850                                      [fixed-route]
#
#          gtfs_schedule_status
# 11   [ok, ok, needed, ok, ok]
# 11   [ok, ok, needed, ok, ok]
# 11   [ok, ok, needed, ok, ok]
# 11   [ok, ok, needed, ok, ok]
# 11   [ok, ok, needed, ok, ok]
# ..                        ...
# 849      [ok, needed, needed]
# 849      [ok, needed, needed]
# 849      [ok, needed, needed]
# 849      [ok, needed, needed]
# 850                      [ok]
#
# [544 rows x 8 columns]

# %%
f3
# Out:
#                                                   name  \
# 11               Alameda-Contra Costa Transit District
# 18                      Amador Regional Transit System
# 24                                              Amtrak
# 25                      Anaheim Transportation Network
# 29                   Antelope Valley Transit Authority
# ..                                                 ...
# 839             Western Contra Costa Transit Authority
# 847                Yolo County Transportation District
# 848       Yosemite Area Regional Transportation System
# 849                      Yuba-Sutter Transit Authority
# 850  Yuma County Intergovernmental Public Transport...
#
#                              mobility_services_managed  \
# 11   [AC Transit, Dumbarton Express, East Bay Parat...
# 18        [Amador Transit, Amador Transit Dial-A-Ride]
# 24   [Coast Starlight, California Zephyr, Thruway, ...
# 25   [Anaheim Resort Transportation, FRAN, Anaheim ...
# 29   [Antelope Valley Dial-A-Ride, Antelope Valley ...
# ..                                                 ...
# 839  [WestCAT Local, WestCAT Lynx Express, WestCAT ...
# 847                         [Yolobus, Yolobus Special]
# 848     [Yosemite Area Regional Transportation System]
# 849  [Yuba-Sutter Transit, Yuba-Sutter Rural Transi...
# 850                         [Yuma County Area Transit]
#
#                             mobility_services_operated  \
# 11   [AC Transit, AC Transit Transbay, AC Transit T...
# 18        [Amador Transit, Amador Transit Dial-A-Ride]
# 24   [Coast Starlight, California Zephyr, Amtrak Sa...
# 25   [Anaheim Resort Transportation, FRAN, Anaheim ...
# 29   [Antelope Valley Dial-A-Ride, Antelope Valley ...
# ..                                                 ...
# 839  [WestCAT Local, WestCAT Lynx Express, WestCAT ...
# 847    [Yolobus, Yolobus Special, Causeway Connection]
# 848     [Yosemite Area Regional Transportation System]
# 849  [Yuba-Sutter Transit, Yuba-Sutter Rural Transi...
# 850                         [Yuma County Area Transit]
#
#                                        fares_v2_status  \
# 11   [Provider published, Vendor published, Provide...
# 18                                  [Vendor published]
# 24                         [Unknown, Unknown, Unknown]
# 25                                  [Blocked - Vendor]
# 29                                                 NaN
# ..                                                 ...
# 839  [Vendor published, Vendor published, Vendor pu...
# 847                              [Provider to Publish]
# 848                                 [Vendor published]
# 849  [Vendor published, Vendor published, Vendor pu...
# 850                                          [Unknown]
#
#                                 gtfs_datasets_produced  \
# 11   [AC Transit Schedule, AC Transit VehiclePositi...
# 18                                   [Amador Schedule]
# 24                                   [Amtrak Schedule]
# 25   [Anaheim Resort Schedule, Anaheim Resort Vehic...
# 29        [Antelope Valley Transit Authority Schedule]
# ..                                                 ...
# 839                                 [WestCAT Schedule]
# 847  [Yolobus Schedule, Yolobus Vehicle Positions, ...
# 848                                   [YARTS Schedule]
# 849                             [Yuba-Sutter Schedule]
# 850                                    [Yuma Schedule]
#
#          service_type__from_mobility_services_managed_  \
# 11   [fixed-route, fixed-route, ADA paratransit, fi...
# 18   [fixed-route, deviated fixed-route, ADA paratr...
# 24   [fixed-route, fixed-route, fixed-route, fixed-...
# 25           [fixed-route, on-demand, ADA paratransit]
# 29           [ADA paratransit, on-demand, fixed-route]
# ..                                                 ...
# 839  [fixed-route, fixed-route, fixed-route, on-dem...
# 847  [fixed-route, deviated fixed-route, ADA paratr...
# 848                            [seasonal, fixed-route]
# 849  [fixed-route, on-demand, deviated fixed-route,...
# 850                                      [fixed-route]
#
#         service_type__from_mobility_services_operated_  \
# 11             [fixed-route, fixed-route, fixed-route]
# 18   [fixed-route, deviated fixed-route, ADA paratr...
# 24   [fixed-route, fixed-route, fixed-route, fixed-...
# 25           [fixed-route, on-demand, ADA paratransit]
# 29           [ADA paratransit, on-demand, fixed-route]
# ..                                                 ...
# 839  [fixed-route, fixed-route, fixed-route, on-dem...
# 847  [fixed-route, deviated fixed-route, ADA paratr...
# 848                            [seasonal, fixed-route]
# 849  [fixed-route, on-demand, deviated fixed-route,...
# 850                                      [fixed-route]
#
#              gtfs_schedule_status
# 11       [ok, ok, needed, ok, ok]
# 18                   [ok, needed]
# 24                   [ok, ok, ok]
# 25           [ok, needed, needed]
# 29                   [needed, ok]
# ..                            ...
# 839  [ok, ok, ok, needed, needed]
# 847                  [ok, needed]
# 848                          [ok]
# 849          [ok, needed, needed]
# 850                          [ok]
#
# [190 rows x 8 columns]

# %%
# calculating lengths of the lists in each column

# %%
columns = ['mobility_services_managed','mobility_services_operated',
           'fares_v2_status', 'gtfs_datasets_produced',
          'service_type__from_mobility_services_managed_',
           'service_type__from_mobility_services_operated_',
           'gtfs_schedule_status']

# %%
for col in columns: 
    f3[ 'len_' + col] = f3[col].str.len()

# %%
f3
# Out:
#                                                   name  \
# 11               Alameda-Contra Costa Transit District
# 18                      Amador Regional Transit System
# 24                                              Amtrak
# 25                      Anaheim Transportation Network
# 29                   Antelope Valley Transit Authority
# ..                                                 ...
# 839             Western Contra Costa Transit Authority
# 847                Yolo County Transportation District
# 848       Yosemite Area Regional Transportation System
# 849                      Yuba-Sutter Transit Authority
# 850  Yuma County Intergovernmental Public Transport...
#
#                              mobility_services_managed  \
# 11   [AC Transit, Dumbarton Express, East Bay Parat...
# 18        [Amador Transit, Amador Transit Dial-A-Ride]
# 24   [Coast Starlight, California Zephyr, Thruway, ...
# 25   [Anaheim Resort Transportation, FRAN, Anaheim ...
# 29   [Antelope Valley Dial-A-Ride, Antelope Valley ...
# ..                                                 ...
# 839  [WestCAT Local, WestCAT Lynx Express, WestCAT ...
# 847                         [Yolobus, Yolobus Special]
# 848     [Yosemite Area Regional Transportation System]
# 849  [Yuba-Sutter Transit, Yuba-Sutter Rural Transi...
# 850                         [Yuma County Area Transit]
#
#                             mobility_services_operated  \
# 11   [AC Transit, AC Transit Transbay, AC Transit T...
# 18        [Amador Transit, Amador Transit Dial-A-Ride]
# 24   [Coast Starlight, California Zephyr, Amtrak Sa...
# 25   [Anaheim Resort Transportation, FRAN, Anaheim ...
# 29   [Antelope Valley Dial-A-Ride, Antelope Valley ...
# ..                                                 ...
# 839  [WestCAT Local, WestCAT Lynx Express, WestCAT ...
# 847    [Yolobus, Yolobus Special, Causeway Connection]
# 848     [Yosemite Area Regional Transportation System]
# 849  [Yuba-Sutter Transit, Yuba-Sutter Rural Transi...
# 850                         [Yuma County Area Transit]
#
#                                        fares_v2_status  \
# 11   [Provider published, Vendor published, Provide...
# 18                                  [Vendor published]
# 24                         [Unknown, Unknown, Unknown]
# 25                                  [Blocked - Vendor]
# 29                                                 NaN
# ..                                                 ...
# 839  [Vendor published, Vendor published, Vendor pu...
# 847                              [Provider to Publish]
# 848                                 [Vendor published]
# 849  [Vendor published, Vendor published, Vendor pu...
# 850                                          [Unknown]
#
#                                 gtfs_datasets_produced  \
# 11   [AC Transit Schedule, AC Transit VehiclePositi...
# 18                                   [Amador Schedule]
# 24                                   [Amtrak Schedule]
# 25   [Anaheim Resort Schedule, Anaheim Resort Vehic...
# 29        [Antelope Valley Transit Authority Schedule]
# ..                                                 ...
# 839                                 [WestCAT Schedule]
# 847  [Yolobus Schedule, Yolobus Vehicle Positions, ...
# 848                                   [YARTS Schedule]
# 849                             [Yuba-Sutter Schedule]
# 850                                    [Yuma Schedule]
#
#          service_type__from_mobility_services_managed_  \
# 11   [fixed-route, fixed-route, ADA paratransit, fi...
# 18   [fixed-route, deviated fixed-route, ADA paratr...
# 24   [fixed-route, fixed-route, fixed-route, fixed-...
# 25           [fixed-route, on-demand, ADA paratransit]
# 29           [ADA paratransit, on-demand, fixed-route]
# ..                                                 ...
# 839  [fixed-route, fixed-route, fixed-route, on-dem...
# 847  [fixed-route, deviated fixed-route, ADA paratr...
# 848                            [seasonal, fixed-route]
# 849  [fixed-route, on-demand, deviated fixed-route,...
# 850                                      [fixed-route]
#
#         service_type__from_mobility_services_operated_  \
# 11             [fixed-route, fixed-route, fixed-route]
# 18   [fixed-route, deviated fixed-route, ADA paratr...
# 24   [fixed-route, fixed-route, fixed-route, fixed-...
# 25           [fixed-route, on-demand, ADA paratransit]
# 29           [ADA paratransit, on-demand, fixed-route]
# ..                                                 ...
# 839  [fixed-route, fixed-route, fixed-route, on-dem...
# 847  [fixed-route, deviated fixed-route, ADA paratr...
# 848                            [seasonal, fixed-route]
# 849  [fixed-route, on-demand, deviated fixed-route,...
# 850                                      [fixed-route]
#
#              gtfs_schedule_status  len_mobility_services_managed  \
# 11       [ok, ok, needed, ok, ok]                              5
# 18                   [ok, needed]                              2
# 24                   [ok, ok, ok]                              6
# 25           [ok, needed, needed]                              3
# 29                   [needed, ok]                              2
# ..                            ...                            ...
# 839  [ok, ok, ok, needed, needed]                              5
# 847                  [ok, needed]                              2
# 848                          [ok]                              1
# 849          [ok, needed, needed]                              5
# 850                          [ok]                              1
#
#      len_mobility_services_operated  len_fares_v2_status  \
# 11                              3.0                  4.0
# 18                              2.0                  1.0
# 24                              6.0                  3.0
# 25                              3.0                  1.0
# 29                              2.0                  NaN
# ..                              ...                  ...
# 839                             5.0                  6.0
# 847                             3.0                  1.0
# 848                             1.0                  1.0
# 849                             4.0                  4.0
# 850                             1.0                  1.0
#
#      len_gtfs_datasets_produced  \
# 11                          4.0
# 18                          1.0
# 24                          1.0
# 25                          2.0
# 29                          1.0
# ..                          ...
# 839                         1.0
# 847                         4.0
# 848                         1.0
# 849                         1.0
# 850                         1.0
#
#      len_service_type__from_mobility_services_managed_  \
# 11                                                   5
# 18                                                   4
# 24                                                   9
# 25                                                   3
# 29                                                   3
# ..                                                 ...
# 839                                                  8
# 847                                                  4
# 848                                                  2
# 849                                                  9
# 850                                                  1
#
#      len_service_type__from_mobility_services_operated_  \
# 11                                                 3.0
# 18                                                 4.0
# 24                                                 9.0
# 25                                                 3.0
# 29                                                 3.0
# ..                                                 ...
# 839                                                8.0
# 847                                                5.0
# 848                                                2.0
# 849                                                8.0
# 850                                                1.0
#
#      len_gtfs_schedule_status
# 11                        5.0
# 18                        2.0
# 24                        3.0
# 25                        3.0
# 29                        2.0
# ..                        ...
# 839                       5.0
# 847                       2.0
# 848                       1.0
# 849                       3.0
# 850                       1.0
#
# [190 rows x 15 columns]

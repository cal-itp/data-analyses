# %% [markdown]
# # Exercise 3:
# * Keep a subset of columns and clean up column names (no spaces, newlines, etc):
#     * columns related to identifying the agency
#     * population, passenger trips
#     * transit mode
#     * at least 3 service metric variables, normalized and not normalized
# * Deal with duplicates - what is the unit for each row? What is the unit for desired analysis? Should an agency appear multiple times, and if so, why?
# * Aggregate at least 2 ways and show an interesting comparison, after dealing with duplicates somehow (either aggregation and/or defining what the unit of analysis is)
# * Calculate weighted average after the aggregation for the service metrics
# * Decide on one type of chart to visualize, and generalize it as a function
# * Make charts using the function

# %% [markdown]
# ### Helpful Hints for Functions
# * Opportunities are from components that are generalizable in making a chart
# * Maybe these components need the same lines of code to clean them
# * You can always further define variables within a function
# * You can always use f-strings within functions to make slight modifications to the parameters you pass

# %% [markdown]
# ## Reading in my file & cleaning it up

# %%
import pandas as pd
import numpy as np
import shared_utils

pd.set_option('display.max_columns', None)

# %%
GCS_FILE_PATH = "gs://calitp-analytics-data/data-analyses/bus_service_increase/"
FILE_NAME = "ntd_metrics_2019.csv"
df2 = pd.read_csv(f"{GCS_FILE_PATH}{FILE_NAME}")

# %%
#cleaning up columns
df2.columns = df2.columns.str.strip().str.replace(' ', '_')

# %% [markdown]
# ## Subsetting for the 3 performance metrics & agency identifiers.
#
# <b> Just notes on the different abbreviations
# * TOS: Types of Service
#
# * MB: Driving a bus
#
# * DO: Vehicle Maintenance
#
# * VOMS: vehicles operated in annual maximum service

# %%
list(df2.columns)
# Out:
# ['Agency',
#  'City',
#  'State',
#  'Legacy_NTD_ID',
#  'NTD_ID',
#  'Organization_Type',
#  'Reporter_Type',
#  'Primary_UZA\n_Population',
#  'Agency_VOMS',
#  'Mode',
#  'TOS',
#  'Mode_VOMS',
#  'Ratios:',
#  'Fare_Revenues_per_Unlinked_Passenger_Trip',
#  'Fare_Revenues_per_Unlinked_Passenger_Trip_Questionable',
#  'Fare_Revenues_per_Total_Operating_Expense_(Recovery_Ratio)',
#  'Fare_Revenues_per_Total_Operating_Expense_(Recovery_Ratio)_Questionable',
#  'Cost_per\n_Hour',
#  'Cost_per_Hour_Questionable',
#  'Passengers_per_Hour',
#  'Passengers_per_Hour_Questionable',
#  'Cost_per_Passenger',
#  'Cost_per_Passenger_Questionable',
#  'Cost_per_Passenger_Mile',
#  'Cost_per_Passenger_Mile_Questionable',
#  'Source_Data:',
#  'Fare_Revenues_Earned',
#  'Fare_Revenues_Earned_Questionable',
#  'Total_Operating_Expenses',
#  'Total_Operating_Expenses_Questionable',
#  'Unlinked_Passenger_Trips',
#  'Unlinked_Passenger_Trips_Questionable',
#  'Vehicle_Revenue_Hours',
#  'Vehicle_Revenue_Hours_Questionable',
#  'Passenger_Miles',
#  'Passenger_Miles_Questionable',
#  'Vehicle_Revenue_Miles',
#  'Vehicle_Revenue_Miles_Questionable',
#  'Any_data_questionable?',
#  'Unnamed:_39',
#  'Unnamed:_40',
#  'Unnamed:_41',
#  '1',
#  'Unnamed:_43',
#  'Unnamed:_44']

# %%
df3 = df2[['Agency', 'City', 'State', 'Legacy_NTD_ID', 'NTD_ID',
    'Primary_UZA\n_Population', 'Mode','Cost_per\n_Hour','Passengers_per_Hour','Cost_per_Passenger','TOS','Unlinked_Passenger_Trips','Total_Operating_Expenses']]

# %% [markdown]
# #### I don't get this error message below?

# %%
df3.rename(columns = {'Primary_UZA\n_Population': 'Primary_Population', 'Cost_per\n_Hour': 'Cost_per_hour'}, inplace=True) #renaming columns
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
print(f"There are: {len(df3)} rows before any filtering")
# Out:
# There are: 3685 rows before any filtering

# %%
df3.head(2)
# Out:
#                       Agency      City State Legacy_NTD_ID NTD_ID  \
# 0  MTA New York City Transit  New York    NY          2008  20008
# 1  MTA New York City Transit  New York    NY          2008  20008
#
#   Primary_Population Mode Cost_per_hour Passengers_per_Hour  \
# 0        18,351,295    HR      $267.97               139.6
# 1        18,351,295    CB      $393.55                18.6
#
#   Cost_per_Passenger TOS Unlinked_Passenger_Trips Total_Operating_Expenses
# 0             $1.92   DO           2,712,521,697           $5,206,727,193
# 1            $21.13   DO              11,477,164             $242,520,835

# %% [markdown]
# ## Deal with Duplicates: What is the unit for each row? What is the unit for desired analysis? Should an agency appear multiple times, and if so, why?
#
# * The unit for each row is the mode of transportation by agency & geography, looking at the cost per hour of operating the vehicle, how many passengers boarded per hour, and cost per passenger.
#
# * Filtering out TOS for only Directly Operated vehicles to hopefully eliminate some duplicates and concentrate on analyzing a certain aspect first.
#
# * An agency should appear multiple times. Although I am not sure why LA has the same entry, below I saw that some agencies have similiar (or even the same) names from different states so these count as unique entries. I also guess that some agencies have multiple models of buses and might categorize them differently. I used to work on scheduling buses at UC Davis and remember they kept specific track of each bus and model when we rented them out, so maybe that's why it is split.

# %% [markdown]
# #### How do I drop these? Does dropna work?

# %%
#looking at duplicates...these are just NA values. 
duplicateRowsDF = df3[df3.duplicated()]
duplicateRowsDF
# Out:
#      Agency City State Legacy_NTD_ID NTD_ID Primary_Population Mode  \
# 3681    NaN  NaN   NaN           NaN    NaN                NaN  NaN
# 3682    NaN  NaN   NaN           NaN    NaN                NaN  NaN
# 3683    NaN  NaN   NaN           NaN    NaN                NaN  NaN
# 3684    NaN  NaN   NaN           NaN    NaN                NaN  NaN
#
#      Cost_per_hour Passengers_per_Hour Cost_per_Passenger  TOS  \
# 3681           NaN                 NaN                NaN  NaN
# 3682           NaN                 NaN                NaN  NaN
# 3683           NaN                 NaN                NaN  NaN
# 3684           NaN                 NaN                NaN  NaN
#
#      Unlinked_Passenger_Trips Total_Operating_Expenses
# 3681                      NaN                      NaN
# 3682                      NaN                      NaN
# 3683                      NaN                      NaN
# 3684                      NaN                      NaN

# %% [markdown]
# #### Question

# %%
#drop nas..do I have to do inplace= true here?
df3.dropna().head(2)
# Out:
#                       Agency      City State Legacy_NTD_ID NTD_ID  \
# 0  MTA New York City Transit  New York    NY          2008  20008
# 1  MTA New York City Transit  New York    NY          2008  20008
#
#   Primary_Population Mode Cost_per_hour Passengers_per_Hour  \
# 0        18,351,295    HR      $267.97               139.6
# 1        18,351,295    CB      $393.55                18.6
#
#   Cost_per_Passenger TOS Unlinked_Passenger_Trips Total_Operating_Expenses
# 0             $1.92   DO           2,712,521,697           $5,206,727,193
# 1            $21.13   DO              11,477,164             $242,520,835

# %%
print(f"Number of unique agencies after we deduplicate: {df3.Agency.nunique()}")
# Out:
# Number of unique agencies after we deduplicate: 2169

# %%
print(f"There are: {len(df3)} rows after any filtering")
# Out:
# There are: 3685 rows after any filtering

# %%
#checking for TOS 
df3.TOS.unique().tolist()
# Out:
# ['DO', 'PT', nan]

# %%
#filtering out for just DO 
df4 = df3[(df3["TOS"] == "DO")]

# %%
#checking duplicates again
duplicates = (df4.groupby(['Agency','Mode']).size() 
   .sort_values(ascending=False) 
   .reset_index(name='count'))

# %%
duplicates
# Out:
#                                                  Agency Mode  count
# 0                                  Union County Transit   DR      2
# 1                              Advance Transit, Inc. NH   DR      2
# 2                                        Jackson County   DR      2
# 3                                        Valley Transit   DR      2
# 4                                        Valley Transit   MB      2
# ...                                                 ...  ...    ...
# 2537  County of Miami-Dade , dba: Transportation & P...   MG      1
# 2538  County of Muskegon, dba: Muskegon Area Transit...   DR      1
# 2539  County of Muskegon, dba: Muskegon Area Transit...   MB      1
# 2540  County of Placer, dba: Placer County Departmen...   DR      1
# 2541                                        Zuni Pueblo   MB      1
#
# [2542 rows x 3 columns]

# %%
#looking at the few of the agencies that still have duplicates to see why...
df4[(df4.Agency.str.contains("Southern Teton Area Rapid Transit"))]
# Out:
#                                  Agency     City State Legacy_NTD_ID  \
# 1759  Southern Teton Area Rapid Transit  Jackson    WY      8R05-010
# 1761  Southern Teton Area Rapid Transit  Jackson    WY      8R05-010
# 3384  Southern Teton Area Rapid Transit  Jackson    WY      8R05-010
#
#           NTD_ID Primary_Population Mode Cost_per_hour Passengers_per_Hour  \
# 1759  8R05-80188                 0    DR       $22.40                 1.0
# 1761  8R05-80188                 0    MB       $71.66                20.3
# 3384  0R01-80188                 0    MB      $146.39                15.4
#
#      Cost_per_Passenger TOS Unlinked_Passenger_Trips Total_Operating_Expenses
# 1759            $21.46   DO                   5,244                 $112,528
# 1761             $3.53   DO               1,098,224               $3,875,238
# 3384             $9.52   DO                  33,383                 $317,816

# %%
#looking at the few of the agencies that still have duplicates to see why...
df4[(df4.Agency.str.contains("Union County Transit")) & (df4.Agency.notna()) & 
   (df4.Mode=="DR")]
# Out:
#                     Agency         City State Legacy_NTD_ID      NTD_ID  \
# 2849  Union County Transit      LIBERTY    IN      5R02-038  5R02-50387
# 3550  Union County Transit  Blairsville    GA      4R03-012  4R03-41145
#
#      Primary_Population Mode Cost_per_hour Passengers_per_Hour  \
# 2849                 0    DR       $34.50                 1.7
# 3550                 0    DR       $22.69                 1.6
#
#      Cost_per_Passenger TOS Unlinked_Passenger_Trips Total_Operating_Expenses
# 2849            $20.13   DO                  24,582                 $494,890
# 3550            $14.24   DO                   6,180                  $87,989

# %%
#some agencies have VERY similar names in different states...
df4[(df4.Agency.str.contains("Jackson County")) 
   & (df4.Agency.notna())
  ]
# Out:
#                                                  Agency        City State  \
# 1526                Jackson County Transportation, Inc.    Marianna    FL
# 1557                Jackson County Transportation, Inc.    Marianna    FL
# 1981  Delaware, Dubuque & Jackson County Regional Tr...     Dubuque    IA
# 2047               Jackson County Mass Transit District  Carbondale    IL
# 2614                                     Jackson County       Sylva    NC
# 2660                                     Jackson County       Sylva    NC
# 2953                    Jackson County Council on Aging  Scottsboro    AL
# 3370                                     Jackson County   Jefferson    GA
#
#      Legacy_NTD_ID      NTD_ID Primary_Population Mode Cost_per_hour  \
# 1526      4R02-019  4R02-41198                 0    DR       $52.98
# 1557      4R02-019  4R02-41198                 0    MB       $31.76
# 1981      7R01-008  7R01-70136                 0    DR       $66.81
# 2047          5204       50204            67,821    MB       $47.76
# 2614      4R06-023  4R06-41167                 0    DR       $47.40
# 2660      4R06-023  4R06-41167                 0    MB       $47.58
# 2953      4R01-016  4R01-41180                 0    DR       $40.65
# 3370      4R03-009  4R03-41154                 0    DR       $23.39
#
#      Passengers_per_Hour Cost_per_Passenger TOS Unlinked_Passenger_Trips  \
# 1526                1.4             $38.23   DO                  37,567
# 1557                2.8             $11.49   DO                   2,195
# 1981                3.6             $18.55   DO                  99,025
# 2047                3.3             $14.67   DO                  93,691
# 2614                1.6             $28.92   DO                  18,663
# 2660                3.0             $15.69   DO                   8,004
# 2953                2.9             $14.25   DO                  29,346
# 3370                1.7             $14.09   DO                  12,285
#
#      Total_Operating_Expenses
# 1526              $1,436,173
# 1557                 $25,216
# 1981              $1,837,191
# 2047              $1,374,554
# 2614                $539,672
# 2660                $125,576
# 2953                $418,250
# 3370                $173,101

# %%
#same thing
df4[(df4.Agency.str.contains("Valley Transit")) & (df4.Agency.notna()) ]
# Out:
#                                                  Agency          City State  \
# 688                              Tri-Valley Transit Inc    Middlebury    VT
# 689                              Tri-Valley Transit Inc    Middlebury    VT
# 690                              Tri-Valley Transit Inc    Middlebury    VT
# 771               City of Appleton, dba: Valley Transit      Appleton    WI
# 929                      Concho Valley Transit District    San Angelo    TX
# 932                      Concho Valley Transit District    San Angelo    TX
# 1326    City of Williamsport, dba: River Valley Transit  Williamsport    PA
# 1332    City of Williamsport, dba: River Valley Transit  Williamsport    PA
# 1598                            Treasure Valley Transit         Nampa    ID
# 1600                            Treasure Valley Transit         Nampa    ID
# 1632                  Suwannee Valley Transit Authority      Live Oak    FL
# 1663                  Suwannee Valley Transit Authority      Live Oak    FL
# 1669                      Cache Valley Transit District         Logan    UT
# 1683                  Colorado Valley Transit  District     Columbus     TX
# 1692                      Cache Valley Transit District         Logan    UT
# 1701                                     Valley Transit   Walla Walla    WA
# 1707                                     Valley Transit   Walla Walla    WA
# 1731                                     Valley Transit   Walla Walla    WA
# 1846                   Potomac Valley Transit Authority    Petersburg    WV
# 1885                   Potomac Valley Transit Authority    Petersburg    WV
# 1937  Mid-Ohio Valley Transit Authority, dba: Easy R...   Parkersburg    WV
# 1955  Mid-Ohio Valley Transit Authority, dba: Easy R...   Parkersburg    WV
# 1967      City of Simi Valley, dba: Simi Valley Transit   Simi Valley    CA
# 2005      City of Simi Valley, dba: Simi Valley Transit   Simi Valley    CA
# 2330                            Valley Transit District         Derby    CT
# 2480                                     Valley Transit       Wasilla    AK
# 2490                                     Valley Transit       Wasilla    AK
# 2984                     Minnesota River Valley Transit      St Peter    MN
# 3048                     Minnesota River Valley Transit      St Peter    MN
#
#      Legacy_NTD_ID      NTD_ID Primary_Population Mode Cost_per_hour  \
# 688       1R06-001  1R06-10143                 0    MB       $72.87
# 689       1R06-001  1R06-10143                 0    DR       $28.12
# 690       1R06-001  1R06-10143                 0    CB       $80.41
# 771           5001       50001           216,154    MB       $95.67
# 929           6102       60102            92,984    DR       $79.26
# 932           6102       60102            92,984    MB       $82.59
# 1326          3026       30026            56,142    MB      $141.67
# 1332          3026       30026            56,142    DR       $96.00
# 1598      0R01-012       00373           151,499    DR       $51.78
# 1600      0R01-012       00373           151,499    MB       $73.37
# 1632      4R02-005  4R02-41050                 0    DR       $67.59
# 1663      4R02-005  4R02-41050                 0    MB       $51.47
# 1669          8028       80028            94,983    DR       $89.12
# 1683      6R05-031  6R05-60238                 0    DR       $37.56
# 1692          8028       80028            94,983    MB       $96.17
# 1701          0064       00064            55,805    DR      $122.27
# 1707          0064       00064            55,805    VP      $107.08
# 1731          0064       00064            55,805    MB      $129.77
# 1846      3R05-018  3R05-30135                 0    DR       $69.04
# 1885      3R05-018  3R05-30135                 0    MB       $66.24
# 1937          3003       30003            67,229    MB       $78.58
# 1955          3003       30003            67,229    DR       $56.20
# 1967          9050       90050           125,206    MB      $149.03
# 2005          9050       90050           125,206    DR      $186.20
# 2330          1042       10042           923,311    DR       $96.60
# 2480      0R04-002  0R04-00327                 0    DR       $91.09
# 2490      0R04-002  0R04-00327                 0    MB       $80.70
# 2984           NaN  5R04-55325                 0    DR       $60.30
# 3048           NaN  5R04-55325                 0    MB       $64.72
#
#      Passengers_per_Hour Cost_per_Passenger TOS Unlinked_Passenger_Trips  \
# 688                 5.6             $13.02   DO                 105,277
# 689                 1.4             $20.29   DO                 119,556
# 690                 3.5             $23.27   DO                  57,918
# 771                15.9              $6.03   DO                 939,541
# 929                 2.0             $40.24   DO                  88,063
# 932                11.0              $7.48   DO                 211,728
# 1326               23.0              $6.15   DO               1,310,695
# 1332                1.4             $68.57   DO                       7
# 1598                1.9             $27.52   DO                  45,719
# 1600                4.5             $16.43   DO                  70,882
# 1632                2.4             $28.53   DO                  57,847
# 1663                8.6              $6.02   DO                   4,046
# 1669                2.4             $36.81   DO                  28,079
# 1683                2.4             $15.85   DO                  99,491
# 1692               26.7              $3.61   DO               1,424,788
# 1701                3.3             $37.55   DO                  44,945
# 1707                4.6             $23.52   DO                   6,459
# 1731               21.5              $6.02   DO                 613,298
# 1846                2.8             $24.49   DO                  22,892
# 1885                3.8             $17.57   DO                  73,946
# 1937               11.2              $7.01   DO                 485,494
# 1955                2.5             $22.07   DO                   7,097
# 1967               10.0             $14.93   DO                 266,718
# 2005                2.4             $78.90   DO                  40,651
# 2330                3.0             $31.90   DO                  48,529
# 2480                1.6             $56.71   DO                   9,545
# 2490                4.6             $17.41   DO                  51,456
# 2984                6.6              $9.14   DO                  73,260
# 3048                1.7             $38.85   DO                   3,550
#
#      Total_Operating_Expenses
# 688               $1,370,321
# 689               $2,425,301
# 690               $1,347,724
# 771               $5,661,984
# 929               $3,543,343
# 932               $1,584,665
# 1326              $8,063,312
# 1332                    $480
# 1598              $1,258,248
# 1600              $1,164,627
# 1632              $1,650,477
# 1663                 $24,346
# 1669              $1,033,540
# 1683              $1,577,080
# 1692              $5,141,255
# 1701              $1,687,852
# 1707                $151,942
# 1731              $3,693,781
# 1846                $560,551
# 1885              $1,299,360
# 1937              $3,403,144
# 1955                $156,630
# 1967              $3,983,229
# 2005              $3,207,494
# 2330              $1,548,038
# 2480                $541,318
# 2490                $895,818
# 2984                $669,778
# 3048                $137,912

# %% [markdown]
# ## Changing mode abbrevations
# * Mapping a few of the abbreviations to the full name for ease.
#
# * [Transit.dot.gov's data dictionary](https://www.transit.dot.gov/ntd/national-transit-database-ntd-glossary#C)

# %%
# Map values from abbreviations to the full name
MODE_NAMES = {
    'YR': 'Hybrid Rail', 
    'SR': 'Street Car',
     'MB': 'Bus', 
    'LR': 'Light Rail',
    'CB': 'Commuter Bus',
    'CC': 'Cable Car',
    'MG': 'Monorail and Automated Guideway'
}

# %% [markdown]
# #### Question, I guess there is a much neater way to have a catch all "other" group for the other abbreviations? I guess I could have written a if else statement?

# %%
#mapping "other" modes
MODE_NAMES.update(dict.fromkeys(['HR',
 'DR',
 'RB',
 'CR',
 'VP',
 'DT',
 'FB',
 'TB',
 'PB',
 'IP',
 'TR',
 'AR'], 'Other'))

# %%
df4 = df4.assign(
    mode_full_name = df4.Mode.map(MODE_NAMES)
)

# %%
df4.mode_full_name.value_counts()
# Out:
# Other                              1548
# Bus                                 870
# Commuter Bus                         95
# Light Rail                           21
# Street Car                           13
# Monorail and Automated Guideway       4
# Cable Car                             1
# Hybrid Rail                           1
# Name: mode_full_name, dtype: int64

# %%
#just checking for cable car
df4[(df4.mode_full_name.str.contains("Cable"))]
# Out:
#                                                 Agency           City State  \
# 121  City and County of San Francisco, dba: San Fra...  San Francisco    CA
#
#     Legacy_NTD_ID NTD_ID Primary_Population Mode Cost_per_hour  \
# 121          9015  90015         3,281,212    CC      $529.36
#
#     Passengers_per_Hour Cost_per_Passenger TOS Unlinked_Passenger_Trips  \
# 121               43.0             $12.32   DO               5,703,705
#
#     Total_Operating_Expenses mode_full_name
# 121             $70,277,173       Cable Car

# %% [markdown]
# ## Cleaning up columns

# %%
(df4.columns)
# Out:
# Index(['Agency', 'City', 'State', 'Legacy_NTD_ID', 'NTD_ID',
#        'Primary_Population', 'Mode', 'Cost_per_hour', 'Passengers_per_Hour',
#        'Cost_per_Passenger', 'TOS', 'Unlinked_Passenger_Trips',
#        'Total_Operating_Expenses', 'mode_full_name'],
#       dtype='object')

# %%
#cleaning up string columns
for i in ['Agency', 'City', 'State', 'mode_full_name']:
    df4[i] = df4[i].str.strip().replace(',', '').astype({i: str})

# %%
df4["Cost_per_Passenger"].replace({"1,218.00": "1218"}, inplace=True)

# %%
#cleaning up the numeric columns
for i in ['Primary_Population', 'Cost_per_hour', 'Passengers_per_Hour',
       'Cost_per_Passenger', 'Unlinked_Passenger_Trips', 'Total_Operating_Expenses']:
    df4[i] = df4[i].replace({'\$':''}, regex=True).replace(',','', regex= True).astype({i: float})

# %%
#making sure all the data types are accurate
df4.dtypes
# Out:
# Agency                       object
# City                         object
# State                        object
# Legacy_NTD_ID                object
# NTD_ID                       object
# Primary_Population          float64
# Mode                         object
# Cost_per_hour               float64
# Passengers_per_Hour         float64
# Cost_per_Passenger          float64
# TOS                          object
# Unlinked_Passenger_Trips    float64
# Total_Operating_Expenses    float64
# mode_full_name               object
# dtype: object

# %%
#dropping the old mode 
df4 = df4.drop(columns = ['Mode'])

# %%
df4.to_csv("./df4.csv", index= False) #just exporting to CSV so I can check it out

# %% [markdown]
# # Aggregation & Chart Making

# %%
#making my function for a chart
import altair as alt


def bar_chart(df, x, y):
    alt.Chart(df).mark_bar().encode(
    alt.X('x'),
    alt.Y('y'),
    color =alt.Color('State', scale=alt.Scale(
                                  range=altair_utils.FIVETHIRTYEIGHT_CATEGORY_COLORS)),
    tooltip = [alt.Tooltip('x'),
               alt.Tooltip('y')
              ]).interactive().properties( width=400,height=250)
    return chart

# %% [markdown]
# [Markdown reference](https://www.datacamp.com/community/tutorials/markdown-in-jupyter-notebook)

# %% [markdown]
# ### First Analysis...Why did filtering out for bus not work?

# %%
#filter out for other for mode
first = df4[df4["mode_full_name"] == "Bus"]

# %%
first= df4.drop_duplicates().groupby(['City', 'mode_full_name']).agg({'Passengers_per_Hour': 'median', 'Cost_per_Passenger': 'median' }).reset_index()
first.sort_values(by="Cost_per_Passenger", ascending= False)
# Out:
#                   City mode_full_name  Passengers_per_Hour  Cost_per_Passenger
# 1947         Vega Alta          Other                 1.10             1218.00
# 692          Ft. Myers            Bus                 2.40              438.44
# 624             Fallon            Bus                 1.65              376.25
# 1884         Texarkana   Commuter Bus                 0.30              312.38
# 456        Crow Agency          Other                 0.30              297.58
# ...                ...            ...                  ...                 ...
# 1878         Telluride   Commuter Bus                 4.00                1.20
# 1298  Mountain Village          Other                 9.10                1.15
# 821           Hastings            Bus                29.60                1.15
# 1504      Pigeon Forge            Bus                66.70                1.15
# 693          Ft. Myers          Other                 3.70                0.00
#
# [2115 rows x 4 columns]

# %% [markdown]
# # Funding Timeframes

# %% [markdown]
# How often to organizations apply for grants?
#
# - this notebook takes a look at the DLA data application

# %%
import pandas as pd
from siuba import *
import numpy as np

# %%
from IPython.display import Markdown

# %%
pd.set_option("display.max_columns", 100)
pd.set_option("display.max_colwidth", 1000)

# %%
from calitp.storage import get_fs
fs = get_fs()

GCS_FILE_PATH = 'gs://calitp-analytics-data/data-analyses/dla/e-76Obligated/'

pd.set_option('display.max_columns', None)
# Out:
# /opt/conda/lib/python3.9/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
df = pd.read_parquet(f"{GCS_FILE_PATH}dla_df.parquet")
# Out:
# /opt/conda/lib/python3.9/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
df.sample()
# Out:
#        location  prefix project_no agency prepared_date submit__to_hq_date  \
# 4493  Obligated  ATPCML  5286(023)  Ripon    2017-04-21         2017-04-21
#
#      hq_review_date submit_to_fhwa_date to_fmis_date  fed_requested  \
# 4493     2017-04-25          2017-04-26   2017-04-27       550000.0
#
#       ac_requested  total_requested status_comment locode  dist  \
# 4493           0.0         550000.0     Authorized   5286    10
#
#                                       status  dist_processing_days  \
# 4493  E-76 approved on Prepared on 2/14/2017                   0.0
#
#       hq_processing_days  fhwa_processing_days    ftip_no  \
# 4493                 5.0                   1.0  SJ14-8004
#
#                                        project_location  \
# 4493  River Road Sidewalk And Intersection Improvements
#
#                                                                 type_of_work  \
# 4493  The Project Is Designed To Provide Safe Pedestrian Access To Park View
#
#       seq date_request_initiated date_completed_request   mpo projectID  \
# 4493    1                    NaT                    NaT  SJCG      5286
#
#       prepared_y  process_days primary_agency_name  adjusted_total_requested  \
# 4493      2017.0           6.0               Ripon             608003.157014
#
#       adjusted_fed_requested  adjusted_ac_requested  active_transp  transit  \
# 4493           608003.157014                    0.0              1        0
#
#       bridge  street  freeway  infra_resiliency_er  congestion_relief  \
# 4493       0       0        0                    0                  0
#
#       work_categories
# 4493                1

# %%
#adding prepared_m, getting FY21, exporting to parquet

# %%
df["prepared_m"] = pd.DatetimeIndex(df["prepared_date"]).month

# %%
df

# %%
(df.query('prepared_y == 2021 or prepared_y == 2022'))>>count(_.prepared_y)
# Out:
#    prepared_y     n
# 0      2021.0  2317
# 1      2022.0   634

# %%
df_fy21_22 = (df.query('prepared_y == 2021 or prepared_y == 2022'))

# %%
# July 1, 2020 – June 30, 2021

# %%
df_fy21_22>>group_by(_.prepared_y)>>count(_.prepared_m)>>arrange(_.prepared_y, _.prepared_m)
# Out:
#     prepared_y  prepared_m    n
# 0       2021.0         1.0  175
# 1       2021.0         2.0  189
# 2       2021.0         3.0  235
# 3       2021.0         4.0  216
# 4       2021.0         5.0  203
# 5       2021.0         6.0  267
# 6       2021.0         7.0  152
# 7       2021.0         8.0  189
# 8       2021.0         9.0   92
# 9       2021.0        10.0  213
# 10      2021.0        11.0  194
# 11      2021.0        12.0  192
# 12      2022.0         1.0  168
# 13      2022.0         2.0  307
# 14      2022.0         3.0  159

# %%
(df_fy21_22.query('prepared_y == 2021 and prepared_m == [7,8,9,10,11,12]'))>>count(_.prepared_m)
# Out:
#    prepared_m    n
# 0         7.0  152
# 1         8.0  189
# 2         9.0   92
# 3        10.0  213
# 4        11.0  194
# 5        12.0  192

# %%
#adding FY column using copy of df

# %%
copy = df.copy()

# %%
#from https://stackoverflow.com/questions/59181855/get-the-financial-year-from-a-date-in-a-pandas-dataframe-and-add-as-new-column
copy['financial_year'] = copy['prepared_date'].map(lambda x: x.year if x.month > 3 else x.year-1)

# %%
#checking to see if that works
copy>>select(_.prepared_y,_.prepared_m, _.financial_year)>>filter(_.prepared_y==2018)
# Out:
#        prepared_y  prepared_m  financial_year
# 0          2018.0        12.0          2018.0
# 1          2018.0        12.0          2018.0
# 2          2018.0        12.0          2018.0
# 3          2018.0        12.0          2018.0
# 4          2018.0        12.0          2018.0
# ...           ...         ...             ...
# 17018      2018.0         7.0          2018.0
# 18342      2018.0         2.0          2017.0
# 18425      2018.0         8.0          2018.0
# 18426      2018.0         8.0          2018.0
# 19057      2018.0         8.0          2018.0
#
# [2819 rows x 3 columns]

# %%
## worked so using on full df

# %%
df['fy'] = df['prepared_date'].map(lambda x: x.year if x.month > 3 else x.year-1)

# %%
df['grant_type'] = 'dla'

# %%
df_21 = df>>filter(_.fy==2021)

# %%
#df_21.to_parquet('dla_21.parquet')

# %%
t = df >> select(
    _.primary_agency_name,
    _.locode,
    _.project_no,
    _.prefix,
    _.prepared_date,
    _.prepared_y,
)

# %%
t["prepared_m"] = pd.DatetimeIndex(t["prepared_date"]).month

# %%
t = t>>filter(_.prepared_date.notnull())

# %%
t
# Out:
#                                primary_agency_name locode project_no   prefix  \
# 0                                  Humboldt County   5904  5904(121)     BPMP
# 1                                 Mendocino County   5910  32D0(008)       ER
# 2                                  Humboldt County   5904  4820(004)       ER
# 3                                Sacramento County   5924  5924(244)      CML
# 4                                Sacramento County   5924  5924(214)      CML
# ...                                            ...    ...        ...      ...
# 21704  Santa Clara Valley Transportation Authority   6264  6264(091)  FTASTPL
# 21705      Alameda - Contra Costa Transit District   6002  6002(030)  FTASTPL
# 21706     Mountain Area Regional Transit Authority   6292  6292(016)   FTACML
# 21707              Morongo Basin Transit Authority   6235  6235(021)   FTACML
# 21708        San Diego Metropolitan Transit System   7503  7503(003)  FTASTPL
#
#       prepared_date  prepared_y  prepared_m
# 0        2018-12-18      2018.0        12.0
# 1        2018-12-17      2018.0        12.0
# 2        2018-12-07      2018.0        12.0
# 3        2018-12-11      2018.0        12.0
# 4        2018-12-05      2018.0        12.0
# ...             ...         ...         ...
# 21704    2021-11-22      2021.0        11.0
# 21705    2021-11-22      2021.0        11.0
# 21706    2022-02-18      2022.0         2.0
# 21707    2022-02-18      2022.0         2.0
# 21708    2022-01-25      2022.0         1.0
#
# [21087 rows x 7 columns]

# %%
(t>>group_by(_.prepared_y, _.primary_agency_name)>>count(_.primary_agency_name)>>arrange(-_.n)).head(10)
# Out:
#       prepared_y primary_agency_name    n
# 2100      2018.0     Humboldt County  171
# 2537      2019.0     Humboldt County  147
# 2305      2018.0   Santa Cruz County  109
# 2730      2019.0   Santa Cruz County  105
# 330       2014.0         Los Angeles   86
# 2170      2018.0             Modesto   85
# 2947      2020.0     Humboldt County   84
# 726       2015.0              Fresno   83
# 2578      2019.0  Los Angeles County   74
# 1120      2016.0            Caltrans   73

# %%
t2 =(
    t
    >> group_by(_.primary_agency_name, _.prepared_y)
    >> count(_.prepared_m)
#    >> filter(_.prepared_y == 2018)
    >> arrange(_.primary_agency_name, _.prepared_y, _.prepared_m)
)

# %%
t2.head(20)
# Out:
#    primary_agency_name  prepared_y  prepared_m  n
# 0      Access Services      2014.0         2.0  1
# 1      Access Services      2015.0         3.0  2
# 2      Access Services      2016.0         3.0  7
# 3      Access Services      2017.0         3.0  1
# 4      Access Services      2018.0         3.0  1
# 5      Access Services      2019.0         4.0  2
# 6      Access Services      2019.0        12.0  1
# 7      Access Services      2020.0         2.0  1
# 8      Access Services      2021.0         2.0  1
# 9      Access Services      2022.0         3.0  1
# 10        Agoura Hills      2014.0         2.0  1
# 11        Agoura Hills      2015.0         3.0  1
# 12        Agoura Hills      2016.0         8.0  1
# 13        Agoura Hills      2019.0         8.0  1
# 14        Agoura Hills      2022.0         3.0  1
# 15             Alameda      2014.0         1.0  1
# 16             Alameda      2014.0         2.0  3
# 17             Alameda      2014.0        10.0  1
# 18             Alameda      2014.0        11.0  1
# 19             Alameda      2015.0         3.0  1

# %%
(t2>>filter(_.prepared_y==2018)>>filter(_.primary_agency_name=='Alameda County'))
# Out:
#    primary_agency_name  prepared_y  prepared_m  n
# 66      Alameda County      2018.0         1.0  2
# 67      Alameda County      2018.0         2.0  3
# 68      Alameda County      2018.0         3.0  1
# 69      Alameda County      2018.0         4.0  4
# 70      Alameda County      2018.0         5.0  1
# 71      Alameda County      2018.0         6.0  1
# 72      Alameda County      2018.0         8.0  1
# 73      Alameda County      2018.0        10.0  2

# %%
((t2>>filter(_.prepared_y==2018)) >> group_by(_.primary_agency_name) >> summarize(n=_.prepared_m.nunique()) >> arrange(-_.n))
# Out:
#     primary_agency_name   n
# 185         Los Angeles  12
# 186  Los Angeles County  12
# 19          Bakersfield  11
# 99     El Dorado County  11
# 140     Humboldt County  11
# ..                  ...  ..
# 418           Waterford   1
# 419         Watsonville   1
# 426             Willows   1
# 428             Winters   1
# 429            Woodlake   1
#
# [438 rows x 2 columns]

# %% [markdown]
# ### Days Between Dates
# from https://towardsdatascience.com/all-the-pandas-shift-you-should-know-for-data-analysis-791c1692b5e

# %%
t
# Out:
#                                primary_agency_name locode project_no   prefix  \
# 0                                  Humboldt County   5904  5904(121)     BPMP
# 1                                 Mendocino County   5910  32D0(008)       ER
# 2                                  Humboldt County   5904  4820(004)       ER
# 3                                Sacramento County   5924  5924(244)      CML
# 4                                Sacramento County   5924  5924(214)      CML
# ...                                            ...    ...        ...      ...
# 21704  Santa Clara Valley Transportation Authority   6264  6264(091)  FTASTPL
# 21705      Alameda - Contra Costa Transit District   6002  6002(030)  FTASTPL
# 21706     Mountain Area Regional Transit Authority   6292  6292(016)   FTACML
# 21707              Morongo Basin Transit Authority   6235  6235(021)   FTACML
# 21708        San Diego Metropolitan Transit System   7503  7503(003)  FTASTPL
#
#       prepared_date  prepared_y  prepared_m
# 0        2018-12-18      2018.0        12.0
# 1        2018-12-17      2018.0        12.0
# 2        2018-12-07      2018.0        12.0
# 3        2018-12-11      2018.0        12.0
# 4        2018-12-05      2018.0        12.0
# ...             ...         ...         ...
# 21704    2021-11-22      2021.0        11.0
# 21705    2021-11-22      2021.0        11.0
# 21706    2022-02-18      2022.0         2.0
# 21707    2022-02-18      2022.0         2.0
# 21708    2022-01-25      2022.0         1.0
#
# [21087 rows x 7 columns]

# %%
t3 = (
    t
    >> filter(_.primary_agency_name == "Santa Cruz County")
    >> select(_.primary_agency_name, _.prepared_date, _.prepared_y, _.prepared_m)
    >> arrange(_.prepared_date)
)

# %%
t3
# Out:
#       primary_agency_name prepared_date  prepared_y  prepared_m
# 12604   Santa Cruz County    2014-02-06      2014.0         2.0
# 12564   Santa Cruz County    2014-02-27      2014.0         2.0
# 12337   Santa Cruz County    2014-03-19      2014.0         3.0
# 12424   Santa Cruz County    2014-03-25      2014.0         3.0
# 12121   Santa Cruz County    2014-04-16      2014.0         4.0
# ...                   ...           ...         ...         ...
# 21463   Santa Cruz County    2022-03-02      2022.0         3.0
# 21014   Santa Cruz County    2022-03-08      2022.0         3.0
# 21133   Santa Cruz County    2022-03-17      2022.0         3.0
# 21018   Santa Cruz County    2022-03-25      2022.0         3.0
# 21017   Santa Cruz County    2022-03-29      2022.0         3.0
#
# [482 rows x 4 columns]

# %%
t3
# Out:
#       primary_agency_name prepared_date  prepared_y  prepared_m
# 12604   Santa Cruz County    2014-02-06      2014.0         2.0
# 12564   Santa Cruz County    2014-02-27      2014.0         2.0
# 12337   Santa Cruz County    2014-03-19      2014.0         3.0
# 12424   Santa Cruz County    2014-03-25      2014.0         3.0
# 12121   Santa Cruz County    2014-04-16      2014.0         4.0
# ...                   ...           ...         ...         ...
# 21463   Santa Cruz County    2022-03-02      2022.0         3.0
# 21014   Santa Cruz County    2022-03-08      2022.0         3.0
# 21133   Santa Cruz County    2022-03-17      2022.0         3.0
# 21018   Santa Cruz County    2022-03-25      2022.0         3.0
# 21017   Santa Cruz County    2022-03-29      2022.0         3.0
#
# [482 rows x 4 columns]

# %%
t3['days_between'] = (t3['prepared_date'] - t3.shift(1)['prepared_date']).dt.days

# %%
t3
# Out:
#       primary_agency_name prepared_date  prepared_y  prepared_m  days_between
# 12604   Santa Cruz County    2014-02-06      2014.0         2.0           NaN
# 12564   Santa Cruz County    2014-02-27      2014.0         2.0          21.0
# 12337   Santa Cruz County    2014-03-19      2014.0         3.0          20.0
# 12424   Santa Cruz County    2014-03-25      2014.0         3.0           6.0
# 12121   Santa Cruz County    2014-04-16      2014.0         4.0          22.0
# ...                   ...           ...         ...         ...           ...
# 21463   Santa Cruz County    2022-03-02      2022.0         3.0          13.0
# 21014   Santa Cruz County    2022-03-08      2022.0         3.0           6.0
# 21133   Santa Cruz County    2022-03-17      2022.0         3.0           9.0
# 21018   Santa Cruz County    2022-03-25      2022.0         3.0           8.0
# 21017   Santa Cruz County    2022-03-29      2022.0         3.0           4.0
#
# [482 rows x 5 columns]

# %%
t6 =(
    t3
    >> group_by(_.primary_agency_name, _.prepared_y)
    >> summarize(avg_days=_.days_between.mean(),
                obs = _.prepared_date.count())
)

# %%
t6
# Out:
#   primary_agency_name  prepared_y   avg_days  obs
# 0   Santa Cruz County      2014.0  12.619048   22
# 1   Santa Cruz County      2015.0  14.482759   29
# 2   Santa Cruz County      2016.0  17.900000   20
# 3   Santa Cruz County      2017.0   4.916667   72
# 4   Santa Cruz County      2018.0   3.165138  109
# 5   Santa Cruz County      2019.0   3.819048  105
# 6   Santa Cruz County      2020.0   6.048387   62
# 7   Santa Cruz County      2021.0   8.325581   43
# 8   Santa Cruz County      2022.0   4.850000   20

# %% [markdown]
# ## Creating Loop for Some Agencies

# %%
agencies = [
    "Santa Cruz County",
    "Humboldt County",
    "Los Angeles",
    "Modesto",
    "Fresno",
    "Los Angeles County",
    "Caltrans"
]

for i in agencies:
    t4 = (
        t
        >> filter(_.primary_agency_name == i)
        >> select(_.primary_agency_name, _.prepared_date, _.prepared_y, _.prepared_m)
        >> arrange(_.prepared_date)
    )
    t4["days_between"] = (t4["prepared_date"] - t4.shift(1)["prepared_date"]).dt.days
    t4 = (
        t4
        >> group_by(_.primary_agency_name, _.prepared_y)
        >> summarize(avg_days=_.days_between.mean(),
                     number = _.prepared_date.count())
    )
    
    display(Markdown(f'**Average Days Between Projects in {i}**'))
    display(t4)
# Out:
# **Average Days Between Projects in Santa Cruz County**
#   primary_agency_name  prepared_y   avg_days  number
# 0   Santa Cruz County      2014.0  12.619048      22
# 1   Santa Cruz County      2015.0  14.482759      29
# 2   Santa Cruz County      2016.0  17.900000      20
# 3   Santa Cruz County      2017.0   4.916667      72
# 4   Santa Cruz County      2018.0   3.165138     109
# 5   Santa Cruz County      2019.0   3.819048     105
# 6   Santa Cruz County      2020.0   6.048387      62
# 7   Santa Cruz County      2021.0   8.325581      43
# 8   Santa Cruz County      2022.0   4.850000      20
# **Average Days Between Projects in Humboldt County**
#   primary_agency_name  prepared_y   avg_days  number
# 0     Humboldt County      2013.0        NaN       1
# 1     Humboldt County      2014.0   7.176471      51
# 2     Humboldt County      2015.0   6.865385      52
# 3     Humboldt County      2016.0  11.030303      33
# 4     Humboldt County      2017.0  12.214286      28
# 5     Humboldt County      2018.0   2.269006     171
# 6     Humboldt County      2019.0   2.476190     147
# 7     Humboldt County      2020.0   4.476190      84
# 8     Humboldt County      2021.0   4.816901      71
# 9     Humboldt County      2022.0   1.369863      73
# **Average Days Between Projects in Los Angeles**
#   primary_agency_name  prepared_y   avg_days  number
# 0         Los Angeles      2013.0  14.750000       5
# 1         Los Angeles      2014.0   4.418605      86
# 2         Los Angeles      2015.0   5.173913      69
# 3         Los Angeles      2016.0   5.112676      71
# 4         Los Angeles      2017.0   6.440000      50
# 5         Los Angeles      2018.0   8.019608      51
# 6         Los Angeles      2019.0   7.632653      49
# 7         Los Angeles      2020.0   6.135593      59
# 8         Los Angeles      2021.0   6.473684      57
# 9         Los Angeles      2022.0   8.500000      10
# **Average Days Between Projects in Modesto**
#   primary_agency_name  prepared_y   avg_days  number
# 0             Modesto      2014.0  16.333333      19
# 1             Modesto      2015.0  14.076923      26
# 2             Modesto      2016.0  14.318182      22
# 3             Modesto      2017.0  17.863636      22
# 4             Modesto      2018.0   4.435294      85
# 5             Modesto      2019.0  16.043478      23
# 6             Modesto      2020.0  17.428571      21
# 7             Modesto      2021.0  12.166667      30
# **Average Days Between Projects in Fresno**
#   primary_agency_name  prepared_y   avg_days  number
# 0              Fresno      2013.0  18.333333       4
# 1              Fresno      2014.0   6.500000      58
# 2              Fresno      2015.0   4.301205      83
# 3              Fresno      2016.0   6.200000      60
# 4              Fresno      2017.0   5.625000      56
# 5              Fresno      2018.0   6.960784      51
# 6              Fresno      2019.0   6.655738      61
# 7              Fresno      2020.0   7.720000      50
# 8              Fresno      2021.0   9.324324      37
# 9              Fresno      2022.0  11.250000       8
# **Average Days Between Projects in Los Angeles County**
#   primary_agency_name  prepared_y   avg_days  number
# 0  Los Angeles County      2013.0  56.600000       6
# 1  Los Angeles County      2014.0   6.313433      67
# 2  Los Angeles County      2015.0   9.097561      41
# 3  Los Angeles County      2016.0   9.421053      38
# 4  Los Angeles County      2017.0   6.228070      57
# 5  Los Angeles County      2018.0   5.625000      64
# 6  Los Angeles County      2019.0   5.094595      74
# 7  Los Angeles County      2020.0   5.267606      71
# 8  Los Angeles County      2021.0   7.458333      48
# 9  Los Angeles County      2022.0   5.111111      18
# **Average Days Between Projects in Caltrans**
#   primary_agency_name  prepared_y    avg_days  number
# 0            Caltrans      2015.0    6.111111      10
# 1            Caltrans      2016.0    5.013699      73
# 2            Caltrans      2017.0    9.571429      14
# 3            Caltrans      2021.0  536.666667       3
# 4            Caltrans      2022.0   58.666667       3

# %% [markdown]
# ## Shift For All Agencies

# %%
t
# Out:
#                                primary_agency_name locode project_no   prefix  \
# 0                                  Humboldt County   5904  5904(121)     BPMP
# 1                                 Mendocino County   5910  32D0(008)       ER
# 2                                  Humboldt County   5904  4820(004)       ER
# 3                                Sacramento County   5924  5924(244)      CML
# 4                                Sacramento County   5924  5924(214)      CML
# ...                                            ...    ...        ...      ...
# 21704  Santa Clara Valley Transportation Authority   6264  6264(091)  FTASTPL
# 21705      Alameda - Contra Costa Transit District   6002  6002(030)  FTASTPL
# 21706     Mountain Area Regional Transit Authority   6292  6292(016)   FTACML
# 21707              Morongo Basin Transit Authority   6235  6235(021)   FTACML
# 21708        San Diego Metropolitan Transit System   7503  7503(003)  FTASTPL
#
#       prepared_date  prepared_y  prepared_m
# 0        2018-12-18      2018.0        12.0
# 1        2018-12-17      2018.0        12.0
# 2        2018-12-07      2018.0        12.0
# 3        2018-12-11      2018.0        12.0
# 4        2018-12-05      2018.0        12.0
# ...             ...         ...         ...
# 21704    2021-11-22      2021.0        11.0
# 21705    2021-11-22      2021.0        11.0
# 21706    2022-02-18      2022.0         2.0
# 21707    2022-02-18      2022.0         2.0
# 21708    2022-01-25      2022.0         1.0
#
# [21087 rows x 7 columns]

# %%
sort_cols = ["primary_agency_name", "prepared_date"]
group_cols = ["primary_agency_name"]

# %%
shift = t.assign(
    previous_date=(
        t.sort_values(sort_cols)
        .groupby(group_cols)['prepared_date']
        .apply(lambda x: x.shift(1))
    )
)

# %%
#checking to see if it goes over to the next agency
(shift>>arrange(_.primary_agency_name, _.prepared_date)).head(20)
# Out:
#       primary_agency_name locode project_no    prefix prepared_date  \
# 12613     Access Services   6312  6312(019)   FTASTPL    2014-02-24
# 9663      Access Services   6312  6312(020)   FTASTPL    2015-03-16
# 9664      Access Services   6312  6312(020)   FTASTPL    2015-03-16
# 7096      Access Services   6312  6312(022)   FTASTPL    2016-03-02
# 7097      Access Services   6312  6312(022)   FTASTPL    2016-03-02
# 7098      Access Services   6312  6312(022)   FTASTPL    2016-03-02
# 7099      Access Services   6312  6312(022)   FTASTPL    2016-03-02
# 7192      Access Services   6312  6312(022)   FTASTPL    2016-03-02
# 7193      Access Services   6312  6312(022)   FTASTPL    2016-03-02
# 7194      Access Services   6312  6312(022)   FTASTPL    2016-03-02
# 4774      Access Services   6312  6312(023)  FTASTPLR    2017-03-13
# 1760      Access Services   6312  6312(024)   FTASTPL    2018-03-28
# 14359     Access Services   6312  6312(027)   FTASTPL    2019-04-08
# 14360     Access Services   6312  6312(027)   FTASTPL    2019-04-08
# 15605     Access Services   6312  6312(028)   FTASTPL    2019-12-10
# 16669     Access Services   6312  6312(029)   FTASTPL    2020-02-24
# 19484     Access Services   6312  6312(030)   FTASTPL    2021-02-24
# 21698     Access Services   6312  6312(031)   FTASTPL    2022-03-08
# 12726        Agoura Hills    nan  5435(010)     HPLUN    2014-02-20
# 9649         Agoura Hills    nan  5435(017)      BHLO    2015-03-18
#
#        prepared_y  prepared_m previous_date
# 12613      2014.0         2.0           NaT
# 9663       2015.0         3.0    2014-02-24
# 9664       2015.0         3.0    2015-03-16
# 7096       2016.0         3.0    2015-03-16
# 7097       2016.0         3.0    2016-03-02
# 7098       2016.0         3.0    2016-03-02
# 7099       2016.0         3.0    2016-03-02
# 7192       2016.0         3.0    2016-03-02
# 7193       2016.0         3.0    2016-03-02
# 7194       2016.0         3.0    2016-03-02
# 4774       2017.0         3.0    2016-03-02
# 1760       2018.0         3.0    2017-03-13
# 14359      2019.0         4.0    2018-03-28
# 14360      2019.0         4.0    2019-04-08
# 15605      2019.0        12.0    2019-04-08
# 16669      2020.0         2.0    2019-12-10
# 19484      2021.0         2.0    2020-02-24
# 21698      2022.0         3.0    2021-02-24
# 12726      2014.0         2.0           NaT
# 9649       2015.0         3.0    2014-02-20

# %%
shift["days_between"] = (shift["prepared_date"] - shift["previous_date"]).dt.days

# %%
shift.days_between.describe()
# Out:
# count    20464.000000
# mean        68.179681
# std        147.280712
# min          0.000000
# 25%          3.000000
# 50%         17.000000
# 75%         66.000000
# max       2366.000000
# Name: days_between, dtype: float64

# %%
(
    shift
    >> group_by(_.primary_agency_name)
    >> summarize(avg_app=_.days_between.mean())
    >> filter(_.avg_app.notnull())
    >> arrange(_.avg_app)
).head(20)
# Out:
#                         primary_agency_name    avg_app
# 16              Amador Rapid Transit System   0.000000
# 564  Tuolumne County Transportation Council   0.000000
# 210                         Humboldt County   4.223944
# 276                             Los Angeles   6.086957
# 486                       Santa Cruz County   6.180873
# 175                                  Fresno   6.548180
# 277                      Los Angeles County   6.942029
# 149                        El Dorado County  10.067742
# 228                             Kern County  10.148649
# 534                                Stockton  11.010949
# 458                      San Joaquin County  11.044118
# 176                           Fresno County  11.435252
# 35                              Bakersfield  11.472924
# 310                                 Modesto  11.518219
# 394                                 Portola  12.000000
# 297                        Mendocino County  12.270492
# 427                       Sacramento County  13.189655
# 533                       Stanislaus County  14.018868
# 562                           Tulare County  14.520737
# 381                           Placer County  16.245810

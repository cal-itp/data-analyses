# %%
pip install shared_utils
# Out:
# Requirement already satisfied: shared_utils in /opt/conda/lib/python3.11/site-packages (4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ["CALITP_BQ_MAX_BYTES"] = str(800_000_000_000)

import branca
import folium
from shared_utils import gtfs_utils_v2


import pandas as pd
import geopandas as gpd 

import datetime as dt
import time
import re
import google.auth
import os
import gcsfs
credentials, project = google.auth.default()
fs = gcsfs.GCSFileSystem()

# %%
import sys
sys.path.append('../rt_segment_speeds/segment_speed_utils')

from helpers import *

# %%
#Selecting Analysis Date and Agency
analysis_date = "2022-06-01"
agency_name = "Salinas"

# %%
get_trips = import_scheduled_trips(analysis_date=analysis_date, columns =[
        "gtfs_dataset_key", "feed_key", "name", "trip_id", 
        "shape_id", "shape_array_key", 
        "route_id", "route_key", "direction_id"
    ], get_pandas=True)

# %%
def compute_feed_key(agency_name):
    filtered = get_trips[get_trips['name'].str.contains(agency_name, na=False)]
    if not filtered.empty:
        return filtered.iloc[0]['feed_key']
    else:
        return None

# %%
feed_key = compute_feed_key(agency_name)

# %%
stops_data = import_scheduled_stops(analysis_date).drop_duplicates().reset_index(drop=True)
if feed_key is not None:
    stops_data = stops_data[stops_data['feed_key'].isin([feed_key])]

# %%
stops_data.columns
# Out:
# Index(['feed_key', 'service_date', 'feed_timezone',
#        'first_stop_arrival_datetime_pacific',
#        'last_stop_departure_datetime_pacific', 'stop_id', 'stop_key',
#        'stop_name', 'stop_event_count', 'route_type_0', 'route_type_1',
#        'route_type_2', 'route_type_3', 'route_type_4', 'route_type_5',
#        'route_type_6', 'route_type_7', 'route_type_11', 'route_type_12',
#        'missing_route_type', 'geometry'],
#       dtype='object')

# %%
GCS_FILE_PATH = 'gs://calitp-analytics-data/data-analyses/ahsc_grant/'
yr_mst_raw = pd.read_excel(f'{GCS_FILE_PATH}MST Stop Level Data 9.1.21-8.31.22.xlsx')

# %%
yr_mst_raw
# Out:
#       Stop_ID                   Stop_Name   Latitude   Longitude  \
# 0           2        DELMONTECENTER/GATE1  36.584641 -121.897424
# 1           2        DELMONTECENTER/GATE1  36.584644 -121.897400
# 2           2        DELMONTECENTER/GATE1  36.584670 -121.897378
# 3           3        DELMONTECENTER/GATE2  36.584786 -121.897339
# 4           3        DELMONTECENTER/GATE2  36.584781 -121.897337
# ...       ...                         ...        ...         ...
# 2747     9304  MARINATRANSITEXCHANGEGATE4  36.683744 -121.794475
# 2748     9304  MARINATRANSITEXCHANGEGATE4  36.683754 -121.794503
# 2749     9305  MARINATRANSITEXCHANGEGATE5  36.683734 -121.794164
# 2750     9305  MARINATRANSITEXCHANGEGATE5  36.683892 -121.794205
# 2751     9305  MARINATRANSITEXCHANGEGATE5  36.683738 -121.794242
#
#       Yearly_Boardings  Schedule
# 0                 9287   Weekday
# 1                 2240  Saturday
# 2                 1740    Sunday
# 3                 1757   Weekday
# 4                  616  Saturday
# ...                ...       ...
# 2747              1288  Saturday
# 2748              1044    Sunday
# 2749               251   Weekday
# 2750               616  Saturday
# 2751                 0    Sunday
#
# [2752 rows x 6 columns]

# %%
yr_mst_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2752 entries, 0 to 2751
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Stop_ID           2752 non-null   int64
#  1   Stop_Name         2752 non-null   object
#  2   Latitude          2752 non-null   float64
#  3   Longitude         2752 non-null   float64
#  4   Yearly_Boardings  2752 non-null   int64
#  5   Schedule          2752 non-null   object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 129.1+ KB

# %%
mst_stopnames = yr_mst_raw.drop_duplicates(subset = ['Stop_ID', 'Stop_Name']).copy()
mst_stopnames['Stop_ID'] = mst_stopnames['Stop_ID'].astype('int64').astype(str)
mst_stopnames.rename(columns={'Stop_ID': 'stop_id'}, inplace=True)

# %%
day_cols = {'Weekday': 'weekday_ons', 'Saturday': 'sat_ons', 'Sunday': 'sun_ons'}

yr_mst_raw['Stop_ID'] = yr_mst_raw['Stop_ID'].astype('int64').astype('str')
yr_mst_raw['DAY_TYPE'] = yr_mst_raw['Schedule'].map(day_cols)

yr_mst_grouped = (
    yr_mst_raw
    .groupby(['Stop_ID', 'DAY_TYPE'], as_index=False)
    .agg(stop_total_ons=('Yearly_Boardings', 'sum'))
)

# %%
yr_mst_grouped_wide = (
    yr_mst_grouped
    .pivot(index='Stop_ID', columns='DAY_TYPE', values='stop_total_ons')
    .reset_index()
    .rename(columns={'Stop_ID': 'stop_id'})
)

# %%
# Select only Stop_ID and Stop_Name columns, and drop duplicates from raw data to add stopnames column back 
mst_stopnames = (
    yr_mst_raw[['Stop_ID', 'Stop_Name']]
    .drop_duplicates(subset=['Stop_ID'])
    .copy()
)

# Renaming to match keys 
mst_stopnames['Stop_ID'] = mst_stopnames['Stop_ID'].astype(str)
mst_stopnames.rename(columns={'Stop_ID': 'stop_id', 'Stop_Name': 'stop_name'}, inplace=True)

# Merging only those two columns onto yr_mst_grouped_wide
yr_mst_grouped_wide = yr_mst_grouped_wide.merge(
    mst_stopnames[['stop_id', 'stop_name']],  
    on='stop_id',
    how='left'
)

# %%
yr_mst_grouped_wide['feed_key'] = feed_key
yr_mst_grouped_wide['name'] = 'Monterey Salinas Schedule'

# %%
len(yr_mst_grouped_wide)
# Out:
# 974

# %%
yr_mst_grouped_wide.head(20)
# Out:
#    stop_id  sat_ons  sun_ons  weekday_ons                stop_name  \
# 0     1001    112.0     58.0        753.0      FREMONT/HILBYAVENUE
# 1     1004    672.0    754.0       8534.0    FREMONT/TRINITYAVENUE
# 2     1007    112.0     58.0        753.0        FREMONT/ELMAVENUE
# 3     1010    224.0    232.0       1757.0         FREMONT/BROADWAY
# 4     1016    112.0    116.0       1004.0             FREMONT/ECHO
# 5     1022    952.0    812.0      11797.0      ORDGROVE/NOCHEBUENA
# 6     1025     56.0    116.0       1255.0          ORDGROVE/WARING
# 7     1028     56.0    174.0        502.0          ORDGROVE/LUZERN
# 8     1031     56.0     58.0       2259.0       ORDGROVE/MENDOCINO
# 9     1034     56.0     58.0       4267.0         YOSEMITE/LASALLE
# 10    1037    504.0    522.0       4267.0  YOSEMITE/SANPABLOAVENUE
# 11    1043    448.0    406.0       3514.0          SANPABLO/WARING
# 12    1046    392.0    406.0       4016.0   SANPABLOAVE/NOCHEBUENA
# 13    1049    224.0    232.0       2510.0         NOCHEBUENA/MINGO
# 14    1052    952.0    754.0       6777.0      NOCHEBUENA/BROADWAY
# 15    1055    336.0    232.0       3012.0  NOCHEBUENA/SONOMAAVENUE
# 16    1058    504.0    348.0       4267.0         NOCHEBUENA/WANDA
# 17    1061     56.0    116.0       2008.0   NOCHEBUENA/HILBYAVENUE
# 18    1064     56.0    174.0       1255.0     HILBY/SANLUCASSTREET
# 19    1067    224.0    116.0       2008.0            HILBY/WHEELER
#
#                             feed_key                       name
# 0   118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 1   118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 2   118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 3   118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 4   118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 5   118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 6   118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 7   118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 8   118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 9   118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 10  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 11  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 12  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 13  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 14  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 15  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 16  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 17  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 18  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 19  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule

# %%
yr_mst_grouped_wide.to_csv('yr_mst_grouped_wide.csv', index=False)

# %%
stops_to_join = stops_data[['feed_key', 'stop_id', 'stop_name', 'geometry']]

# %%
yr_mst_grouped_wide['stop_id'] = yr_mst_grouped_wide['stop_id'].astype(str).str.zfill(4)

# %%
#Now join on feed_key + stop_id as these are updated
yr_mst_joined = stops_to_join.merge(yr_mst_grouped_wide, on=['feed_key', 'stop_id'], how='inner')

# %%
yr_mst_joined.head(5)
# Out:
#                            feed_key stop_id                stop_name_x  \
# 0  118c3a62eab691ac449fe0c1c7505413    0002  Del Monte Center / Gate 1
# 1  118c3a62eab691ac449fe0c1c7505413    0003  Del Monte Center / Gate 2
# 2  118c3a62eab691ac449fe0c1c7505413    0004  Del Monte Center / Gate 3
# 3  118c3a62eab691ac449fe0c1c7505413    0006       6th / Mission Street
# 4  118c3a62eab691ac449fe0c1c7505413    0011            Northridge Mall
#
#                           geometry  sat_ons  sun_ons  weekday_ons  \
# 0  POINT (-169532.243 -157455.258)   2240.0   1740.0       9287.0
# 1  POINT (-169524.827 -157441.956)    616.0    348.0       1757.0
# 2  POINT (-169673.036 -157470.002)     56.0     58.0        502.0
# 3  POINT (-171687.391 -160632.627)   4312.0   4234.0      21837.0
# 4  POINT (-147895.267 -143297.134)   9128.0  13224.0      40662.0
#
#             stop_name_y                       name
# 0  DELMONTECENTER/GATE1  Monterey Salinas Schedule
# 1  DELMONTECENTER/GATE2  Monterey Salinas Schedule
# 2  DELMONTECENTER/GATE3  Monterey Salinas Schedule
# 3     6TH/MISSIONSTREET  Monterey Salinas Schedule
# 4        NORTHRIDGEMALL  Monterey Salinas Schedule

# %%
len(yr_mst_joined)
# Out:
# 926

# %%
yr_mst_joined = yr_mst_joined[['feed_key', 'stop_id', 'stop_name_x', 'geometry', 'sat_ons', 'sun_ons', 'weekday_ons', 'name']].rename(columns={'stop_name_x': 'stop_name'})

# %%
stops_remainder = stops_to_join.merge(
    yr_mst_grouped_wide[['feed_key', 'stop_id']],
    on=['feed_key', 'stop_id'],
    how='left',
    indicator=True
)

stops_remainder = stops_remainder[stops_remainder['_merge'] == 'left_only'].drop(columns=['_merge'])

len(stops_remainder)
# Out:
# 22

# %%
stops_remainder['stop_name']
# Out:
# 188                      Ardennes / Aachen Rd
# 189            Ardennes / 214 Ardennes Circle
# 190                Ardennes / Remagen (Fitch)
# 191                     Ardennes / Tunisia Rd
# 192                  Ardennes / 2775 Ardennes
# 193                           Ardennes / Metz
# 194                      Ardennes / Hatten Rd
# 469            San Miguel Canyon Rd /  # 1469
# 470    San Miguel Canyon Rd /  Woodland Hills
# 492             San Miguel Canyon Rd /  #1335
# 493             San Miguel Canyon Rd /  #1347
# 669                        Malmedy / Carentan
# 670                        Normandy / Malmedy
# 671                       Normandy / Carentan
# 672                        Normandy / Salerno
# 899                     Kit Carson / Bldg 614
# 900                     Kit Carson / Bldg 422
# 901                     Fitch / Stilwell -POM
# 907               CPL Ewing / Presidio Museum
# 908             Pvt Bolio Rd / Pvt Bolio Gate
# 909                    Pvt Bolio / Lighthouse
# 910                   Pvt Bolio Rd / Bldg 517
# Name: stop_name, dtype: object

# %%
yr_mst_remainder = yr_mst_grouped_wide.merge(
    stops_to_join[['feed_key', 'stop_id']],
    on=['feed_key', 'stop_id'],
    how='left',
    indicator=True
)

yr_mst_remainder = yr_mst_remainder[yr_mst_remainder['_merge'] == 'left_only'].drop(columns=['_merge'])

len(yr_mst_remainder)
# Out:
# 48

# %%
yr_mst_remainder['stop_name']
# Out:
# 22      INTERGARRISON/OTTERSPORTSCT
# 40      SCHILLING/COUNTYGOVERNMENTC
# 88        DELMONTE/CONFERENCECENTER
# 90              CANNERYROW/PRESCOTT
# 91         OLIVIER/FISHERMAN'SWHARF
# 92                FRANKLIN/ALVARADO
# 93                ALVARADO/FRANKLIN
# 94                 CANNERYROW/DRAKE
# 95              CANNERYROW/AQUARIUM
# 96                 CANNERYROW/DRAKE
# 97                     REESIDE/FOAM
# 98            WAVE/CR1PARKINGGARAGE
# 373           LAUREL/AMERICANLEGION
# 374                 LAUREL/PARKSIDE
# 386                   LAUREL/MARYAL
# 388                   LAUREL/MARYAL
# 391                  LAUREL/BALDWIN
# 422                    LAUREL/TYLER
# 423                    LAUREL/DAVIS
# 426                    LAUREL/TYLER
# 427                    LAUREL/DAVIS
# 428                 LAUREL/PARKSIDE
# 429                     LAUREL/MAIN
# 430              LAUREL/SANTATERESA
# 433                  LAUREL/GRANADA
# 443                  LAUREL/LINWOOD
# 444                 LAUREL/TAPADERO
# 446                   LAUREL/RAMONA
# 450                    LAUREL/ADAMS
# 492                   LAUREL/MONROE
# 644         EALISAL/SALINASFAIRWAYS
# 645    EALISAL/HARTNELLALISALCAMPUS
# 654                RIORD/CROSSROADS
# 675    HARTNELLCOLLEGEPARKINGGARAGE
# 854     AIRPORTROAD/NAVYANNEX(PENDI
# 903                2NDAVE/8THSTREET
# 904                    2NDAVE/6THST
# 906                    2NDAVE/5THST
# 907         2NDAVE/8THSTREET(NORTH)
# 909                    2NDAVE/6THST
# 911                    2NDAVE/5THST
# 913     2NDAVE/INTER-GARRISONRD(NOR
# 914       INTER-GARRISON/BUILDING90
# 915         2NDAVE/DIVARTYST(NORTH)
# 917     INTER-GARRISON/BUILDING82(O
# 946     MONTEREYTRANSITPLAZA/GATE5(
# 952      SALINASTRANSITCENTER/GATE6
# 962      MARINATRANSITEXCHANGEGATE5
# Name: stop_name, dtype: object

# %%
yr_mst_joined_zero = stops_remainder.merge(
    yr_mst_remainder,
    on = ['feed_key', 'stop_id'],
    how = 'inner',
    indicator = False
)

yr_mst_joined_zero.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 0 entries
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   feed_key     0 non-null      object
#  1   stop_id      0 non-null      object
#  2   stop_name_x  0 non-null      object
#  3   geometry     0 non-null      geometry
#  4   sat_ons      0 non-null      float64
#  5   sun_ons      0 non-null      float64
#  6   weekday_ons  0 non-null      float64
#  7   stop_name_y  0 non-null      object
#  8   name         0 non-null      object
# dtypes: float64(3), geometry(1), object(5)
# memory usage: 108.0+ bytes

# %%
stops_leftovers = stops_remainder.merge(
    yr_mst_remainder[['feed_key', 'stop_id']],
    on=['feed_key', 'stop_id'],
    how='left',
    indicator=True
)

stops_leftovers = stops_leftovers[stops_leftovers['_merge'] == 'left_only'].drop(columns=['_merge'])

stops_leftovers
# Out:
#                             feed_key stop_id  \
# 0   118c3a62eab691ac449fe0c1c7505413    1200
# 1   118c3a62eab691ac449fe0c1c7505413    1201
# 2   118c3a62eab691ac449fe0c1c7505413    1202
# 3   118c3a62eab691ac449fe0c1c7505413    1204
# 4   118c3a62eab691ac449fe0c1c7505413    1206
# 5   118c3a62eab691ac449fe0c1c7505413    1208
# 6   118c3a62eab691ac449fe0c1c7505413    1210
# 7   118c3a62eab691ac449fe0c1c7505413    2933
# 8   118c3a62eab691ac449fe0c1c7505413    2935
# 9   118c3a62eab691ac449fe0c1c7505413    2977
# 10  118c3a62eab691ac449fe0c1c7505413    2979
# 11  118c3a62eab691ac449fe0c1c7505413    4710
# 12  118c3a62eab691ac449fe0c1c7505413    4715
# 13  118c3a62eab691ac449fe0c1c7505413    4720
# 14  118c3a62eab691ac449fe0c1c7505413    4725
# 15  118c3a62eab691ac449fe0c1c7505413    6942
# 16  118c3a62eab691ac449fe0c1c7505413    6943
# 17  118c3a62eab691ac449fe0c1c7505413    6945
# 18  118c3a62eab691ac449fe0c1c7505413    6953
# 19  118c3a62eab691ac449fe0c1c7505413    6954
# 20  118c3a62eab691ac449fe0c1c7505413    6955
# 21  118c3a62eab691ac449fe0c1c7505413    6956
#
#                                  stop_name                         geometry
# 0                     Ardennes / Aachen Rd  POINT (-161583.473 -152082.519)
# 1           Ardennes / 214 Ardennes Circle  POINT (-161333.901 -152104.620)
# 2               Ardennes / Remagen (Fitch)  POINT (-161134.036 -152218.476)
# 3                    Ardennes / Tunisia Rd  POINT (-160847.861 -152467.362)
# 4                 Ardennes / 2775 Ardennes  POINT (-161076.437 -152693.118)
# 5                          Ardennes / Metz  POINT (-161527.050 -152565.923)
# 6                     Ardennes / Hatten Rd  POINT (-161757.659 -152527.616)
# 7           San Miguel Canyon Rd /  # 1469  POINT (-150146.190 -129409.199)
# 8   San Miguel Canyon Rd /  Woodland Hills  POINT (-150465.744 -128852.457)
# 9            San Miguel Canyon Rd /  #1335  POINT (-150441.815 -129039.087)
# 10           San Miguel Canyon Rd /  #1347  POINT (-150135.839 -129428.170)
# 11                      Malmedy / Carentan  POINT (-160907.029 -151478.015)
# 12                      Normandy / Malmedy  POINT (-160971.896 -151676.761)
# 13                     Normandy / Carentan  POINT (-161378.875 -151732.373)
# 14                      Normandy / Salerno  POINT (-161840.588 -151693.544)
# 15                   Kit Carson / Bldg 614  POINT (-170662.171 -155040.474)
# 16                   Kit Carson / Bldg 422  POINT (-170462.357 -155043.610)
# 17                   Fitch / Stilwell -POM  POINT (-170032.620 -154863.052)
# 18             CPL Ewing / Presidio Museum  POINT (-169394.613 -155029.688)
# 19           Pvt Bolio Rd / Pvt Bolio Gate  POINT (-169651.490 -154806.556)
# 20                  Pvt Bolio / Lighthouse  POINT (-169482.789 -154814.825)
# 21                 Pvt Bolio Rd / Bldg 517  POINT (-170616.634 -154957.798)

# %%
riders_leftovers = yr_mst_remainder.merge(
    stops_remainder[['feed_key', 'stop_id']],
    on=['feed_key', 'stop_id'],
    how='left',
    indicator=True
)

riders_leftovers = riders_leftovers[riders_leftovers['_merge'] == 'left_only'].drop(columns=['_merge'])

# %%
riders_leftovers_joined = riders_leftovers.merge(
    mst_stopnames[['stop_id', 'stop_name']],
    how='left',
    on='stop_id'
)

riders_leftovers_joined
# Out:
#    stop_id  sat_ons  sun_ons  weekday_ons                   stop_name_x  \
# 0     1101      0.0      0.0        251.0   INTERGARRISON/OTTERSPORTSCT
# 1     1394      0.0      NaN          0.0   SCHILLING/COUNTYGOVERNMENTC
# 2     1601   8680.0   8062.0      23343.0     DELMONTE/CONFERENCECENTER
# 3     1603  22624.0  22562.0      74296.0           CANNERYROW/PRESCOTT
# 4     1604  19936.0  17922.0      33634.0      OLIVIER/FISHERMAN'SWHARF
# 5     1611   1288.0   1856.0       5020.0             FRANKLIN/ALVARADO
# 6     1612    168.0     58.0        502.0             ALVARADO/FRANKLIN
# 7     1614   4480.0   4640.0      20582.0              CANNERYROW/DRAKE
# 8     1616  28952.0  31204.0      74045.0           CANNERYROW/AQUARIUM
# 9     1619   2408.0   2726.0       6526.0              CANNERYROW/DRAKE
# 10    1620   1512.0    754.0       2259.0                  REESIDE/FOAM
# 11    1623   2744.0   4408.0       7028.0         WAVE/CR1PARKINGGARAGE
# 12    3001      0.0     58.0          0.0         LAUREL/AMERICANLEGION
# 13    3004      0.0      0.0          NaN               LAUREL/PARKSIDE
# 14    3054      0.0      0.0          NaN                 LAUREL/MARYAL
# 15    3056     56.0      0.0       1004.0                 LAUREL/MARYAL
# 16    3079      0.0      0.0          0.0                LAUREL/BALDWIN
# 17    3204      0.0      0.0          NaN                  LAUREL/TYLER
# 18    3206      0.0      0.0          0.0                  LAUREL/DAVIS
# 19    3222      0.0      0.0          NaN                  LAUREL/TYLER
# 20    3224     56.0      0.0        251.0                  LAUREL/DAVIS
# 21    3225      0.0      0.0          NaN               LAUREL/PARKSIDE
# 22    3226    280.0    232.0        251.0                   LAUREL/MAIN
# 23    3227      0.0      0.0          0.0            LAUREL/SANTATERESA
# 24    3230      0.0    116.0        502.0                LAUREL/GRANADA
# 25    3285      0.0      0.0          NaN                LAUREL/LINWOOD
# 26    3286      0.0      0.0        502.0               LAUREL/TAPADERO
# 27    3289     56.0      0.0          NaN                 LAUREL/RAMONA
# 28    3305      0.0    116.0          NaN                  LAUREL/ADAMS
# 29    3385      0.0      0.0          NaN                 LAUREL/MONROE
# 30    4815      NaN      NaN          0.0       EALISAL/SALINASFAIRWAYS
# 31    4820      NaN      NaN       1757.0  EALISAL/HARTNELLALISALCAMPUS
# 32    0493      NaN      NaN          0.0              RIORD/CROSSROADS
# 33    5102      NaN      NaN       4267.0  HARTNELLCOLLEGEPARKINGGARAGE
# 34    6833      NaN      NaN          0.0   AIRPORTROAD/NAVYANNEX(PENDI
# 35    7135      0.0      0.0          NaN              2NDAVE/8THSTREET
# 36    7137      0.0      0.0          NaN                  2NDAVE/6THST
# 37    7139      0.0      0.0          NaN                  2NDAVE/5THST
# 38    7140    224.0      0.0        251.0       2NDAVE/8THSTREET(NORTH)
# 39    7144      0.0      0.0          NaN                  2NDAVE/6THST
# 40    7146      0.0      0.0          NaN                  2NDAVE/5THST
# 41    7148      0.0      0.0        251.0   2NDAVE/INTER-GARRISONRD(NOR
# 42    7149      0.0      0.0        502.0     INTER-GARRISON/BUILDING90
# 43    7152      NaN      NaN          0.0       2NDAVE/DIVARTYST(NORTH)
# 44    7161      0.0      0.0          0.0   INTER-GARRISON/BUILDING82(O
# 45    9105   4928.0   5510.0      13052.0   MONTEREYTRANSITPLAZA/GATE5(
# 46    9206      NaN      NaN          0.0    SALINASTRANSITCENTER/GATE6
# 47    9305    616.0      0.0        251.0    MARINATRANSITEXCHANGEGATE5
#
#                             feed_key                       name  \
# 0   118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 1   118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 2   118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 3   118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 4   118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 5   118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 6   118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 7   118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 8   118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 9   118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 10  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 11  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 12  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 13  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 14  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 15  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 16  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 17  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 18  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 19  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 20  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 21  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 22  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 23  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 24  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 25  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 26  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 27  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 28  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 29  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 30  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 31  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 32  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 33  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 34  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 35  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 36  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 37  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 38  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 39  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 40  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 41  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 42  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 43  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 44  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 45  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 46  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
# 47  118c3a62eab691ac449fe0c1c7505413  Monterey Salinas Schedule
#
#                      stop_name_y
# 0    INTERGARRISON/OTTERSPORTSCT
# 1    SCHILLING/COUNTYGOVERNMENTC
# 2      DELMONTE/CONFERENCECENTER
# 3            CANNERYROW/PRESCOTT
# 4       OLIVIER/FISHERMAN'SWHARF
# 5              FRANKLIN/ALVARADO
# 6              ALVARADO/FRANKLIN
# 7               CANNERYROW/DRAKE
# 8            CANNERYROW/AQUARIUM
# 9               CANNERYROW/DRAKE
# 10                  REESIDE/FOAM
# 11         WAVE/CR1PARKINGGARAGE
# 12         LAUREL/AMERICANLEGION
# 13               LAUREL/PARKSIDE
# 14                 LAUREL/MARYAL
# 15                 LAUREL/MARYAL
# 16                LAUREL/BALDWIN
# 17                  LAUREL/TYLER
# 18                  LAUREL/DAVIS
# 19                  LAUREL/TYLER
# 20                  LAUREL/DAVIS
# 21               LAUREL/PARKSIDE
# 22                   LAUREL/MAIN
# 23            LAUREL/SANTATERESA
# 24                LAUREL/GRANADA
# 25                LAUREL/LINWOOD
# 26               LAUREL/TAPADERO
# 27                 LAUREL/RAMONA
# 28                  LAUREL/ADAMS
# 29                 LAUREL/MONROE
# 30       EALISAL/SALINASFAIRWAYS
# 31  EALISAL/HARTNELLALISALCAMPUS
# 32                           NaN
# 33  HARTNELLCOLLEGEPARKINGGARAGE
# 34   AIRPORTROAD/NAVYANNEX(PENDI
# 35              2NDAVE/8THSTREET
# 36                  2NDAVE/6THST
# 37                  2NDAVE/5THST
# 38       2NDAVE/8THSTREET(NORTH)
# 39                  2NDAVE/6THST
# 40                  2NDAVE/5THST
# 41   2NDAVE/INTER-GARRISONRD(NOR
# 42     INTER-GARRISON/BUILDING90
# 43       2NDAVE/DIVARTYST(NORTH)
# 44   INTER-GARRISON/BUILDING82(O
# 45   MONTEREYTRANSITPLAZA/GATE5(
# 46    SALINASTRANSITCENTER/GATE6
# 47    MARINATRANSITEXCHANGEGATE5

# %%
# set tables together
gdfs = [yr_mst_joined_zero,yr_mst_joined]

yr_mst_geo_all = pd.concat(gdfs, ignore_index=True)

yr_mst_geo_all
# Out:
#                              feed_key stop_id stop_name_x  \
# 0    118c3a62eab691ac449fe0c1c7505413    0002         NaN
# 1    118c3a62eab691ac449fe0c1c7505413    0003         NaN
# 2    118c3a62eab691ac449fe0c1c7505413    0004         NaN
# 3    118c3a62eab691ac449fe0c1c7505413    0006         NaN
# 4    118c3a62eab691ac449fe0c1c7505413    0011         NaN
# ..                                ...     ...         ...
# 921  118c3a62eab691ac449fe0c1c7505413    9209         NaN
# 922  118c3a62eab691ac449fe0c1c7505413    9301         NaN
# 923  118c3a62eab691ac449fe0c1c7505413    9302         NaN
# 924  118c3a62eab691ac449fe0c1c7505413    9303         NaN
# 925  118c3a62eab691ac449fe0c1c7505413    9304         NaN
#
#                             geometry  sat_ons  sun_ons  weekday_ons  \
# 0    POINT (-169532.243 -157455.258)   2240.0   1740.0       9287.0
# 1    POINT (-169524.827 -157441.956)    616.0    348.0       1757.0
# 2    POINT (-169673.036 -157470.002)     56.0     58.0        502.0
# 3    POINT (-171687.391 -160632.627)   4312.0   4234.0      21837.0
# 4    POINT (-147895.267 -143297.134)   9128.0  13224.0      40662.0
# ..                               ...      ...      ...          ...
# 921  POINT (-147845.975 -147669.935)   1960.0   1914.0      13554.0
# 922  POINT (-160096.179 -146574.140)    952.0    754.0       7781.0
# 923  POINT (-160104.587 -146589.210)    896.0    812.0       7279.0
# 924  POINT (-160116.937 -146605.095)   2184.0   1798.0       7530.0
# 925  POINT (-160125.479 -146617.828)   1288.0   1044.0       6526.0
#
#     stop_name_y                       name                        stop_name
# 0           NaN  Monterey Salinas Schedule        Del Monte Center / Gate 1
# 1           NaN  Monterey Salinas Schedule        Del Monte Center / Gate 2
# 2           NaN  Monterey Salinas Schedule        Del Monte Center / Gate 3
# 3           NaN  Monterey Salinas Schedule             6th / Mission Street
# 4           NaN  Monterey Salinas Schedule                  Northridge Mall
# ..          ...                        ...                              ...
# 921         NaN  Monterey Salinas Schedule  Salinas Transit Center / Gate 9
# 922         NaN  Monterey Salinas Schedule   Marina Transit Exchange Gate 1
# 923         NaN  Monterey Salinas Schedule   Marina Transit Exchange Gate 2
# 924         NaN  Monterey Salinas Schedule   Marina Transit Exchange Gate 3
# 925         NaN  Monterey Salinas Schedule   Marina Transit Exchange Gate 4
#
# [926 rows x 10 columns]

# %%
# fill nan with 0
values = {"sat_ons": 0, "sun_ons": 0, "weekday_ons": 0}
yr_mst_geo_all = yr_mst_geo_all.fillna(value=values)

# %%
mst_0check = yr_mst_geo_all[yr_mst_geo_all['weekday_ons'] == 0]

# %%
mst_0check.explore("weekday_ons", legend=True)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_550e30e9976b4be7af2edf1a9a94b1f9%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.foliumtooltip%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.foliumtooltip%20table%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20margin%3A%20auto%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
def export_gdf(gdf, filename: str):
    
    gdf.to_parquet(f"{filename}.parquet")
    
    fs.put(
        f"{filename}.parquet",
        f"{GCS_FILE_PATH}/{filename}.parquet",
        token = credentials.token
    )
    
    os.remove(f"{filename}.parquet")
    print(f"saved {GCS_FILE_PATH}/{filename}.parquet")
    
    return

# %%
GCS_FILE_PATH  = 'gs://calitp-analytics-data/data-analyses/ahsc_grant'
export_gdf(yr_mst_joined, "ridership_mst_08_26_2024")
# Out:
# saved gs://calitp-analytics-data/data-analyses/ahsc_grant/ridership_mst_08_26_2024.parquet

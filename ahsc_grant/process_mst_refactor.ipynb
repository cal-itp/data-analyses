# %%
pip install shared_utils
# Out:
# Requirement already satisfied: shared_utils in /home/jovyan/data-analyses/_shared_utils (2.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ["CALITP_BQ_MAX_BYTES"] = str(800_000_000_000)

import branca
import folium
from shared_utils import gtfs_utils_v2

from siuba import *
import pandas as pd
import geopandas as gpd 

import datetime as dt
import time

import seaborn as sns
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append('../rt_segment_speeds/segment_speed_utils')

from helpers import *

# %%
#Selecting Analysis Date and Agency
analysis_date = "2022-03-15"
agency_name = "Salinas"

# %%
get_trips = import_scheduled_trips(analysis_date=analysis_date, columns =[
        "gtfs_dataset_key", "feed_key", "name", "trip_id", 
        "shape_id", "shape_array_key", 
        "route_id", "route_key", "direction_id"
    ], get_pandas=True)

# %%
def compute_feed_key(agency_name):
    filtered = get_trips[get_trips['name'].str.contains(agency_name, na=False)]
    if not filtered.empty:
        return filtered.iloc[0]['feed_key']
    else:
        return None

# %%
feed_key = compute_feed_key(agency_name)

# %%
stops_data = import_scheduled_stops(analysis_date).drop_duplicates().reset_index(drop=True)
if feed_key is not None:
    stops_data = stops_data[stops_data['feed_key'].isin([feed_key])]

# %%
GCS_FILE_PATH = 'gs://calitp-analytics-data/data-analyses/ahsc_grant/'
yr_mst_raw = pd.read_excel(f'{GCS_FILE_PATH}MST Stop Level Data 9.1.21-8.31.22.xlsx')

# %%
yr_mst_raw
# Out:
#       Stop_ID                   Stop_Name   Latitude   Longitude  \
# 0           2        DELMONTECENTER/GATE1  36.584641 -121.897424
# 1           2        DELMONTECENTER/GATE1  36.584644 -121.897400
# 2           2        DELMONTECENTER/GATE1  36.584670 -121.897378
# 3           3        DELMONTECENTER/GATE2  36.584786 -121.897339
# 4           3        DELMONTECENTER/GATE2  36.584781 -121.897337
# ...       ...                         ...        ...         ...
# 2747     9304  MARINATRANSITEXCHANGEGATE4  36.683744 -121.794475
# 2748     9304  MARINATRANSITEXCHANGEGATE4  36.683754 -121.794503
# 2749     9305  MARINATRANSITEXCHANGEGATE5  36.683734 -121.794164
# 2750     9305  MARINATRANSITEXCHANGEGATE5  36.683892 -121.794205
# 2751     9305  MARINATRANSITEXCHANGEGATE5  36.683738 -121.794242
#
#       Yearly_Boardings  Schedule
# 0                 9287   Weekday
# 1                 2240  Saturday
# 2                 1740    Sunday
# 3                 1757   Weekday
# 4                  616  Saturday
# ...                ...       ...
# 2747              1288  Saturday
# 2748              1044    Sunday
# 2749               251   Weekday
# 2750               616  Saturday
# 2751                 0    Sunday
#
# [2752 rows x 6 columns]

# %%
yr_mst_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2752 entries, 0 to 2751
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Stop_ID           2752 non-null   int64
#  1   Stop_Name         2752 non-null   object
#  2   Latitude          2752 non-null   float64
#  3   Longitude         2752 non-null   float64
#  4   Yearly_Boardings  2752 non-null   int64
#  5   Schedule          2752 non-null   object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 129.1+ KB

# %%
# stash id/name xwalk in environment - known dup name issue
mst_stopnames = (yr_mst_raw
                 >> distinct(_.Stop_ID,_.Stop_Name)
                 >> mutate(Stop_ID = _.Stop_ID.astype('int64').astype(str))
                 >> rename(stop_id = _.Stop_ID)
                )

# %%
day_cols = {'Weekday': 'weekday_ons', 'Saturday': 'sat_ons', 'Sunday': 'sun_ons'}

yr_mst_grouped = (yr_mst_raw
                 >> mutate(Stop_ID = _.Stop_ID.astype('int64').astype(str))
                 >> mutate(DAY_TYPE = _.Schedule.apply(lambda x: day_cols[x]))
                 >> group_by(_.Stop_ID, _.DAY_TYPE)
                 >> summarize(stop_total_ons = _.Yearly_Boardings.sum())
                )

# %%
yr_mst_grouped.head(3)
# Out:
#   Stop_ID     DAY_TYPE  stop_total_ons
# 0    1001      sat_ons             112
# 1    1001      sun_ons              58
# 2    1001  weekday_ons             753

# %%
yr_mst_grouped = (yr_mst_grouped
                     >> spread("DAY_TYPE", "stop_total_ons")
                     >> rename(stop_id = _.Stop_ID)
                     >> mutate(feed_key = feed_key)
                     >> mutate(name = 'Monterey Salinas Schedule')
                    )

# %%
yr_mst_grouped.head(3)
# Out:
#   stop_id  sat_ons  sun_ons  weekday_ons                          feed_key  \
# 0    1001    112.0     58.0        753.0  efb3d4ea58f58d541e2c452e253bec5d
# 1    1004    672.0    754.0       8534.0  efb3d4ea58f58d541e2c452e253bec5d
# 2    1007    112.0     58.0        753.0  efb3d4ea58f58d541e2c452e253bec5d
#
#                         name
# 0  Monterey Salinas Schedule
# 1  Monterey Salinas Schedule
# 2  Monterey Salinas Schedule

# %%
len(yr_mst_grouped)
# Out:
# 974

# %%
stops_to_join = (stops_data
                 >> select(_.feed_key, _.stop_id, _.stop_name, _.geometry)
                )

# %%
yr_mst_joined = stops_to_join >> inner_join(_, yr_mst_grouped, on = ['feed_key', 'stop_id'])

# %%
yr_mst_joined.head(3)
# Out:
#                            feed_key stop_id                 stop_name  \
# 0  efb3d4ea58f58d541e2c452e253bec5d    1001    Fremont / Hilby Avenue
# 1  efb3d4ea58f58d541e2c452e253bec5d    1004  Fremont / Trinity Avenue
# 2  efb3d4ea58f58d541e2c452e253bec5d    1007      Fremont / Elm Avenue
#
#                           geometry  sat_ons  sun_ons  weekday_ons  \
# 0  POINT (-165123.570 -155506.782)    112.0     58.0        753.0
# 1  POINT (-165043.149 -155309.483)    672.0    754.0       8534.0
# 2  POINT (-164902.027 -154954.295)    112.0     58.0        753.0
#
#                         name
# 0  Monterey Salinas Schedule
# 1  Monterey Salinas Schedule
# 2  Monterey Salinas Schedule

# %%
stops_remainder = (stops_to_join 
    >> anti_join(_, yr_mst_grouped, on = ['feed_key', 'stop_id'])
                    )

len(stops_remainder)
# Out:
# 185

# %%
yr_mst_remainder = (yr_mst_grouped 
    >> anti_join(_, stops_to_join, on = ['feed_key', 'stop_id'])
                    )


len(yr_mst_remainder)
# Out:
# 209

# %%
yr_mst_remainder = (yr_mst_remainder
                    >> mutate(stop_id = _.stop_id.apply(lambda x: x.zfill(4)))
                   )

# %%
# try join again
yr_mst_joined_zero = stops_remainder >> inner_join(_, yr_mst_remainder, on = ['feed_key', 'stop_id'])
yr_mst_joined_zero.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 163 entries, 0 to 162
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   feed_key     163 non-null    object
#  1   stop_id      163 non-null    object
#  2   stop_name    163 non-null    object
#  3   geometry     163 non-null    geometry
#  4   sat_ons      136 non-null    float64
#  5   sun_ons      136 non-null    float64
#  6   weekday_ons  163 non-null    float64
#  7   name         163 non-null    object
# dtypes: float64(3), geometry(1), object(4)
# memory usage: 11.5+ KB

# %%
# check out remainder not joined
stops_leftovers = stops_remainder >> anti_join(_, yr_mst_remainder, on = ['feed_key', 'stop_id'])
stops_leftovers
# Out:
#                                feed_key stop_id  \
# 16722  efb3d4ea58f58d541e2c452e253bec5d    1200
# 16723  efb3d4ea58f58d541e2c452e253bec5d    1201
# 16724  efb3d4ea58f58d541e2c452e253bec5d    1202
# 16725  efb3d4ea58f58d541e2c452e253bec5d    1204
# 16726  efb3d4ea58f58d541e2c452e253bec5d    1206
# 16727  efb3d4ea58f58d541e2c452e253bec5d    1208
# 16728  efb3d4ea58f58d541e2c452e253bec5d    1210
# 17003  efb3d4ea58f58d541e2c452e253bec5d    2933
# 17004  efb3d4ea58f58d541e2c452e253bec5d    2935
# 17026  efb3d4ea58f58d541e2c452e253bec5d    2977
# 17027  efb3d4ea58f58d541e2c452e253bec5d    2979
# 17202  efb3d4ea58f58d541e2c452e253bec5d    4710
# 17203  efb3d4ea58f58d541e2c452e253bec5d    4715
# 17204  efb3d4ea58f58d541e2c452e253bec5d    4720
# 17205  efb3d4ea58f58d541e2c452e253bec5d    4725
# 17435  efb3d4ea58f58d541e2c452e253bec5d    6942
# 17436  efb3d4ea58f58d541e2c452e253bec5d    6943
# 17437  efb3d4ea58f58d541e2c452e253bec5d    6945
# 17443  efb3d4ea58f58d541e2c452e253bec5d    6953
# 17444  efb3d4ea58f58d541e2c452e253bec5d    6954
# 17445  efb3d4ea58f58d541e2c452e253bec5d    6955
# 17446  efb3d4ea58f58d541e2c452e253bec5d    6956
#
#                                      stop_name  \
# 16722                     Ardennes / Aachen Rd
# 16723           Ardennes / 214 Ardennes Circle
# 16724               Ardennes / Remagen (Fitch)
# 16725                    Ardennes / Tunisia Rd
# 16726                 Ardennes / 2775 Ardennes
# 16727                          Ardennes / Metz
# 16728                     Ardennes / Hatten Rd
# 17003           San Miguel Canyon Rd /  # 1469
# 17004   San Miguel Canyon Rd /  Woodland Hills
# 17026            San Miguel Canyon Rd /  #1335
# 17027            San Miguel Canyon Rd /  #1347
# 17202                       Malmedy / Carentan
# 17203                       Normandy / Malmedy
# 17204                      Normandy / Carentan
# 17205                       Normandy / Salerno
# 17435    Kit Carson / Bldg 614 (Military Base)
# 17436    Kit Carson / Bldg 422 (Military Base)
# 17437     Fitch / Stilwell-POM (Military Base)
# 17443              CPL Ewing / Presidio Museum
# 17444            Pvt Bolio Rd / Pvt Bolio Gate
# 17445                   Pvt Bolio / Lighthouse
# 17446  Pvt Bolio Rd / Bldg 517 (Military Base)
#
#                               geometry
# 16722  POINT (-161587.746 -152086.439)
# 16723  POINT (-161338.819 -152109.640)
# 16724  POINT (-161134.083 -152220.921)
# 16725  POINT (-160847.306 -152466.372)
# 16726  POINT (-161070.900 -152688.444)
# 16727  POINT (-161520.892 -152566.152)
# 16728  POINT (-161755.732 -152529.654)
# 17003  POINT (-150143.829 -129411.686)
# 17004  POINT (-150465.732 -128846.788)
# 17026  POINT (-150474.871 -128839.843)
# 17027  POINT (-150151.026 -129415.672)
# 17202  POINT (-160908.327 -151480.547)
# 17203  POINT (-160973.288 -151679.513)
# 17204  POINT (-161377.820 -151733.283)
# 17205  POINT (-161841.902 -151696.854)
# 17435  POINT (-170664.671 -155040.424)
# 17436  POINT (-170417.126 -155033.738)
# 17437  POINT (-170032.890 -154863.158)
# 17443  POINT (-169395.586 -155033.670)
# 17444  POINT (-169651.055 -154807.120)
# 17445  POINT (-169505.877 -154807.694)
# 17446  POINT (-170610.985 -154956.800)

# %%
riders_leftovers = yr_mst_remainder >> anti_join(_, stops_remainder, on = ['feed_key', 'stop_id'])

# %%
riders_leftovers >> left_join(_,mst_stopnames)
# Out:
#    stop_id  sat_ons  sun_ons  weekday_ons                          feed_key  \
# 0     1101      0.0      0.0        251.0  efb3d4ea58f58d541e2c452e253bec5d
# 1     1101      0.0      0.0        251.0  efb3d4ea58f58d541e2c452e253bec5d
# 2     1394      0.0      NaN          0.0  efb3d4ea58f58d541e2c452e253bec5d
# 3     1601   8680.0   8062.0      23343.0  efb3d4ea58f58d541e2c452e253bec5d
# 4     1603  22624.0  22562.0      74296.0  efb3d4ea58f58d541e2c452e253bec5d
# 5     1604  19936.0  17922.0      33634.0  efb3d4ea58f58d541e2c452e253bec5d
# 6     1611   1288.0   1856.0       5020.0  efb3d4ea58f58d541e2c452e253bec5d
# 7     1612    168.0     58.0        502.0  efb3d4ea58f58d541e2c452e253bec5d
# 8     1614   4480.0   4640.0      20582.0  efb3d4ea58f58d541e2c452e253bec5d
# 9     1616  28952.0  31204.0      74045.0  efb3d4ea58f58d541e2c452e253bec5d
# 10    1619   2408.0   2726.0       6526.0  efb3d4ea58f58d541e2c452e253bec5d
# 11    1620   1512.0    754.0       2259.0  efb3d4ea58f58d541e2c452e253bec5d
# 12    1623   2744.0   4408.0       7028.0  efb3d4ea58f58d541e2c452e253bec5d
# 13    3001      0.0     58.0          0.0  efb3d4ea58f58d541e2c452e253bec5d
# 14    3004      0.0      0.0          NaN  efb3d4ea58f58d541e2c452e253bec5d
# 15    3054      0.0      0.0          NaN  efb3d4ea58f58d541e2c452e253bec5d
# 16    3056     56.0      0.0       1004.0  efb3d4ea58f58d541e2c452e253bec5d
# 17    3079      0.0      0.0          0.0  efb3d4ea58f58d541e2c452e253bec5d
# 18    3204      0.0      0.0          NaN  efb3d4ea58f58d541e2c452e253bec5d
# 19    3206      0.0      0.0          0.0  efb3d4ea58f58d541e2c452e253bec5d
# 20    3222      0.0      0.0          NaN  efb3d4ea58f58d541e2c452e253bec5d
# 21    3224     56.0      0.0        251.0  efb3d4ea58f58d541e2c452e253bec5d
# 22    3225      0.0      0.0          NaN  efb3d4ea58f58d541e2c452e253bec5d
# 23    3226    280.0    232.0        251.0  efb3d4ea58f58d541e2c452e253bec5d
# 24    3227      0.0      0.0          0.0  efb3d4ea58f58d541e2c452e253bec5d
# 25    3230      0.0    116.0        502.0  efb3d4ea58f58d541e2c452e253bec5d
# 26    3285      0.0      0.0          NaN  efb3d4ea58f58d541e2c452e253bec5d
# 27    3286      0.0      0.0        502.0  efb3d4ea58f58d541e2c452e253bec5d
# 28    3289     56.0      0.0          NaN  efb3d4ea58f58d541e2c452e253bec5d
# 29    3305      0.0    116.0          NaN  efb3d4ea58f58d541e2c452e253bec5d
# 30    3385      0.0      0.0          NaN  efb3d4ea58f58d541e2c452e253bec5d
# 31    3397    112.0     58.0        502.0  efb3d4ea58f58d541e2c452e253bec5d
# 32    0493      NaN      NaN          0.0  efb3d4ea58f58d541e2c452e253bec5d
# 33    6833      NaN      NaN          0.0  efb3d4ea58f58d541e2c452e253bec5d
# 34    7135      0.0      0.0          NaN  efb3d4ea58f58d541e2c452e253bec5d
# 35    7137      0.0      0.0          NaN  efb3d4ea58f58d541e2c452e253bec5d
# 36    7139      0.0      0.0          NaN  efb3d4ea58f58d541e2c452e253bec5d
# 37    7140    224.0      0.0        251.0  efb3d4ea58f58d541e2c452e253bec5d
# 38    7140    224.0      0.0        251.0  efb3d4ea58f58d541e2c452e253bec5d
# 39    7144      0.0      0.0          NaN  efb3d4ea58f58d541e2c452e253bec5d
# 40    7146      0.0      0.0          NaN  efb3d4ea58f58d541e2c452e253bec5d
# 41    7148      0.0      0.0        251.0  efb3d4ea58f58d541e2c452e253bec5d
# 42    7148      0.0      0.0        251.0  efb3d4ea58f58d541e2c452e253bec5d
# 43    7149      0.0      0.0        502.0  efb3d4ea58f58d541e2c452e253bec5d
# 44    7152      NaN      NaN          0.0  efb3d4ea58f58d541e2c452e253bec5d
# 45    7161      0.0      0.0          0.0  efb3d4ea58f58d541e2c452e253bec5d
# 46    7161      0.0      0.0          0.0  efb3d4ea58f58d541e2c452e253bec5d
# 47    9105   4928.0   5510.0      13052.0  efb3d4ea58f58d541e2c452e253bec5d
# 48    9206      NaN      NaN          0.0  efb3d4ea58f58d541e2c452e253bec5d
# 49    9305    616.0      0.0        251.0  efb3d4ea58f58d541e2c452e253bec5d
#
#                          name                     Stop_Name
# 0   Monterey Salinas Schedule   INTERGARRISON/OTTERSPORTSCT
# 1   Monterey Salinas Schedule  INTERGARRISON/OTTERSPORTSCTR
# 2   Monterey Salinas Schedule   SCHILLING/COUNTYGOVERNMENTC
# 3   Monterey Salinas Schedule     DELMONTE/CONFERENCECENTER
# 4   Monterey Salinas Schedule           CANNERYROW/PRESCOTT
# 5   Monterey Salinas Schedule      OLIVIER/FISHERMAN'SWHARF
# 6   Monterey Salinas Schedule             FRANKLIN/ALVARADO
# 7   Monterey Salinas Schedule             ALVARADO/FRANKLIN
# 8   Monterey Salinas Schedule              CANNERYROW/DRAKE
# 9   Monterey Salinas Schedule           CANNERYROW/AQUARIUM
# 10  Monterey Salinas Schedule              CANNERYROW/DRAKE
# 11  Monterey Salinas Schedule                  REESIDE/FOAM
# 12  Monterey Salinas Schedule         WAVE/CR1PARKINGGARAGE
# 13  Monterey Salinas Schedule         LAUREL/AMERICANLEGION
# 14  Monterey Salinas Schedule               LAUREL/PARKSIDE
# 15  Monterey Salinas Schedule                 LAUREL/MARYAL
# 16  Monterey Salinas Schedule                 LAUREL/MARYAL
# 17  Monterey Salinas Schedule                LAUREL/BALDWIN
# 18  Monterey Salinas Schedule                  LAUREL/TYLER
# 19  Monterey Salinas Schedule                  LAUREL/DAVIS
# 20  Monterey Salinas Schedule                  LAUREL/TYLER
# 21  Monterey Salinas Schedule                  LAUREL/DAVIS
# 22  Monterey Salinas Schedule               LAUREL/PARKSIDE
# 23  Monterey Salinas Schedule                   LAUREL/MAIN
# 24  Monterey Salinas Schedule            LAUREL/SANTATERESA
# 25  Monterey Salinas Schedule                LAUREL/GRANADA
# 26  Monterey Salinas Schedule                LAUREL/LINWOOD
# 27  Monterey Salinas Schedule               LAUREL/TAPADERO
# 28  Monterey Salinas Schedule                 LAUREL/RAMONA
# 29  Monterey Salinas Schedule                  LAUREL/ADAMS
# 30  Monterey Salinas Schedule                 LAUREL/MONROE
# 31  Monterey Salinas Schedule            ELAUREL/ST.EDWARDS
# 32  Monterey Salinas Schedule                           NaN
# 33  Monterey Salinas Schedule   AIRPORTROAD/NAVYANNEX(PENDI
# 34  Monterey Salinas Schedule              2NDAVE/8THSTREET
# 35  Monterey Salinas Schedule                  2NDAVE/6THST
# 36  Monterey Salinas Schedule                  2NDAVE/5THST
# 37  Monterey Salinas Schedule       2NDAVE/8THSTREET(NORTH)
# 38  Monterey Salinas Schedule              2NDAVE/8THSTREET
# 39  Monterey Salinas Schedule                  2NDAVE/6THST
# 40  Monterey Salinas Schedule                  2NDAVE/5THST
# 41  Monterey Salinas Schedule   2NDAVE/INTER-GARRISONRD(NOR
# 42  Monterey Salinas Schedule       2NDAVE/INTER-GARRISONRD
# 43  Monterey Salinas Schedule     INTER-GARRISON/BUILDING90
# 44  Monterey Salinas Schedule       2NDAVE/DIVARTYST(NORTH)
# 45  Monterey Salinas Schedule   INTER-GARRISON/BUILDING82(O
# 46  Monterey Salinas Schedule     INTER-GARRISON/BUILDING82
# 47  Monterey Salinas Schedule   MONTEREYTRANSITPLAZA/GATE5(
# 48  Monterey Salinas Schedule    SALINASTRANSITCENTER/GATE6
# 49  Monterey Salinas Schedule    MARINATRANSITEXCHANGEGATE5

# %%
# set tables together
gdfs = [yr_mst_joined_zero,yr_mst_joined]

yr_mst_geo_all = pd.concat(gdfs, ignore_index=True)

yr_mst_geo_all
# Out:
#                              feed_key stop_id  \
# 0    efb3d4ea58f58d541e2c452e253bec5d    0002
# 1    efb3d4ea58f58d541e2c452e253bec5d    0003
# 2    efb3d4ea58f58d541e2c452e253bec5d    0004
# 3    efb3d4ea58f58d541e2c452e253bec5d    0006
# 4    efb3d4ea58f58d541e2c452e253bec5d    0011
# ..                                ...     ...
# 923  efb3d4ea58f58d541e2c452e253bec5d    9209
# 924  efb3d4ea58f58d541e2c452e253bec5d    9301
# 925  efb3d4ea58f58d541e2c452e253bec5d    9302
# 926  efb3d4ea58f58d541e2c452e253bec5d    9303
# 927  efb3d4ea58f58d541e2c452e253bec5d    9304
#
#                            stop_name                         geometry  \
# 0          Del Monte Center / Gate 1  POINT (-169532.243 -157455.258)
# 1          Del Monte Center / Gate 2  POINT (-169524.827 -157441.956)
# 2          Del Monte Center / Gate 3  POINT (-169673.036 -157470.002)
# 3               6th / Mission Street  POINT (-171687.391 -160632.627)
# 4                    Northridge Mall  POINT (-147895.267 -143297.134)
# ..                               ...                              ...
# 923  Salinas Transit Center / Gate 9  POINT (-147849.267 -147674.435)
# 924   Marina Transit Exchange Gate 1  POINT (-160095.188 -146568.934)
# 925   Marina Transit Exchange Gate 2  POINT (-160106.261 -146588.067)
# 926   Marina Transit Exchange Gate 3  POINT (-160117.309 -146605.866)
# 927   Marina Transit Exchange Gate 4  POINT (-160122.042 -146615.448)
#
#      sat_ons  sun_ons  weekday_ons                       name
# 0     2240.0   1740.0       9287.0  Monterey Salinas Schedule
# 1      616.0    348.0       1757.0  Monterey Salinas Schedule
# 2       56.0     58.0        502.0  Monterey Salinas Schedule
# 3     4312.0   4234.0      21837.0  Monterey Salinas Schedule
# 4     9128.0  13224.0      40662.0  Monterey Salinas Schedule
# ..       ...      ...          ...                        ...
# 923   1960.0   1914.0      13554.0  Monterey Salinas Schedule
# 924    952.0    754.0       7781.0  Monterey Salinas Schedule
# 925    896.0    812.0       7279.0  Monterey Salinas Schedule
# 926   2184.0   1798.0       7530.0  Monterey Salinas Schedule
# 927   1288.0   1044.0       6526.0  Monterey Salinas Schedule
#
# [928 rows x 8 columns]

# %%
# fill nan with 0
values = {"sat_ons": 0, "sun_ons": 0, "weekday_ons": 0}
yr_mst_geo_all = yr_mst_geo_all.fillna(value=values)

# %%
# check 0s
mst_0check = (yr_mst_geo_all >>
                    filter(_.weekday_ons==0)
                   )
mst_0check.explore("weekday_ons", legend=True)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_de78ebba598040ed9a8ca05d0de14992%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.foliumtooltip%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.foliumtooltip%20table%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20margin%3A%20auto%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
GCS_FILE_PATH  = 'gs://calitp-analytics-data/data-analyses/ahsc_grant'
yr_mst_joined.to_parquet(f"{GCS_FILE_PATH}/ridership_mst_08_26_2024.parquet")

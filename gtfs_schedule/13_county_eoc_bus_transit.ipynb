# %%
import pandas as pd
import geopandas as gpd

from functools import cache

from calitp_data_analysis.gcs_geopandas import GCSGeoPandas
from calitp_data_analysis.geography_utils import WGS84, CA_NAD83Albers_m
from calitp_data_analysis.sql import query_sql

@cache
def gcs_geopandas():
    return GCSGeoPandas()

# %%
eocs = pd.read_excel('./County_EOCs.xlsx')
eocs.columns = eocs.columns.str.lower().str.replace(' ', '_')

# %%
eocs.head(3)
# Out:
#        oa                        physical_eoc_address  region        lat  \
# 0  Alpine           99 Water St Markleville, CA 96120  Inland  38.694530
# 1  Amador            700 Court St., Jackson, CA 95642  Inland  38.351547
# 2   Butte  205 Mira Loma Suite 30, Oroville, CA 95965  Inland  39.520803
#
#           lon
# 0 -119.778990
# 1 -120.769370
# 2 -121.552203

# %%
path = 'calitp-analytics-data/data-analyses/gtfs_schedule/county_eocs.parquet'

# %%
gcs_geopandas().geo_data_frame_to_parquet(eocs, path)

# %%
eocs = gpd.GeoDataFrame(eocs, geometry=gpd.points_from_xy(eocs.lon, eocs.lat), crs=WGS84)

# %%
# eocs.explore()

# %%
# https://gis.data.ca.gov/datasets/CDEGIS::california-counties-3/explore

counties = gpd.read_file("https://services3.arcgis.com/fdvHcZVgB2QSRNkL/arcgis/rest/services/California_Counties/FeatureServer/0/query?outFields=*&where=1%3D1&f=geojson")

# %%
counties
# Out:
#     OBJECTID  Year       CountyName   Shape__Area  Shape__Length COUNTY_FIPS  \
# 0        117  2023          Alameda  3.079162e+09   4.356248e+05         001
# 1        118  2023           Alpine  3.156006e+09   2.755654e+05         003
# 2        119  2023           Amador  2.562528e+09   3.595986e+05         005
# 3        120  2023           Colusa  4.990771e+09   3.860430e+05         011
# 4        121  2023        El Dorado  7.624183e+09   4.678001e+05         017
# 5        122  2023         Humboldt  1.617324e+10   8.034529e+05         013
# 6        123  2023             Inyo  4.108843e+10   1.058774e+06         027
# 7        124  2023             Kern  3.185411e+10   8.618423e+05         029
# 8        125  2023             Lake  5.719581e+09   4.685410e+05         085
# 9        126  2023           Lassen  2.127557e+10   7.767717e+05         035
# 10       127  2023      Los Angeles  1.537733e+10   7.435400e+05         037
# 11       128  2023           Madera  8.810369e+09   5.998289e+05         039
# 12       129  2023         Mariposa  6.043147e+09   4.277521e+05         043
# 13       130  2023            Modoc  1.947792e+10   5.663600e+05         049
# 14       131  2023             Mono  1.306297e+10   6.948077e+05         051
# 15       132  2023         Monterey  1.321701e+10   7.807230e+05         053
# 16       133  2023           Placer  6.462795e+09   5.332182e+05         061
# 17       134  2023        Riverside  2.742653e+10   9.114226e+05         065
# 18       135  2023       Sacramento  4.205478e+09   4.065626e+05         067
# 19       136  2023   San Bernardino  7.749414e+10   1.247144e+06         071
# 20       137  2023        San Diego  1.566543e+10   6.889039e+05         073
# 21       138  2023    San Francisco  1.954132e+08   1.265933e+05         075
# 6               7  POLYGON ((-117.83274 37.46493, -117.83150 37.4...
# 7              47  POLYGON ((-117.63430 35.79727, -117.63435 35.7...
# 8               7  POLYGON ((-122.73908 39.38327, -122.75112 39.3...
# 9              11  POLYGON ((-119.99988 41.18398, -119.99989 41.1...
# 10             83  MULTIPOLYGON (((-118.60606 33.47901, -118.6057...
# 11             10  POLYGON ((-119.26899 37.73924, -119.26859 37.7...
# 12              2  POLYGON ((-119.30901 37.77799, -119.31037 37.7...
# 13              3  POLYGON ((-119.99988 41.18398, -119.99990 41.1...
# 14              3  POLYGON ((-117.83274 37.46493, -117.83489 37.4...
# 15             25  POLYGON ((-121.64401 36.89400, -121.64401 36.8...
# 16             17  POLYGON ((-120.00247 39.06749, -120.01009 39.0...
# 17             25  POLYGON ((-114.43544 34.07973, -114.43592 34.0...
# 18             14  POLYGON ((-121.48441 38.73460, -121.48429 38.7...
# 19             34  POLYGON ((-115.64837 35.80922, -115.64833 35.8...
# 20             49  POLYGON ((-116.08518 33.42594, -116.08517 33.4...
# 21              4  MULTIPOLYGON (((-122.32793 37.78121, -122.3276...
# 22             15  POLYGON ((-120.99551 38.22541, -120.99551 38.2...
# 23             11  POLYGON ((-120.21399 35.78928, -120.20628 35.7...
# 24             13  POLYGON ((-121.58137 36.89916, -121.58597 36.9...
# 25             25  POLYGON ((-121.44651 41.18349, -121.41903 41.1...
# 26              7  MULTIPOLYGON (((-122.36657 38.15562, -122.3664...
# 27             41  POLYGON ((-122.82161 38.85014, -122.82105 38.8...
# 28             26  POLYGON ((-120.65329 37.83186, -120.65326 37.8...
# 29             10  POLYGON ((-122.49839 41.18268, -122.49836 41.1...
# 30             44  POLYGON ((-118.36060 36.74478, -118.36014 36.7...
# 31             12  POLYGON ((-119.63922 38.32689, -119.64014 38.3...
# 32              6  POLYGON ((-121.02210 39.39156, -121.02234 39.3...
# 33              6  POLYGON ((-121.83550 38.92449, -121.83389 38.9...
# 34             14  POLYGON ((-121.07671 39.59727, -121.07956 39.5...
# 35              5  POLYGON ((-120.01996 38.43353, -120.02021 38.4...
# 36             20  MULTIPOLYGON (((-122.35798 37.90113, -122.3513...
# 37              2  MULTIPOLYGON (((-124.20247 41.74367, -124.2035...
# 38             33  POLYGON ((-118.77503 37.46306, -118.77449 37.4...
# 39              9  POLYGON ((-122.04648 39.79765, -122.04560 39.7...
# 40             17  POLYGON ((-114.62714 33.43356, -114.62718 33.4...
# 41             14  POLYGON ((-119.53813 35.78990, -119.54350 35.7...
# 42             18  MULTIPOLYGON (((-122.42249 37.86713, -122.4204...
# 43             13  MULTIPOLYGON (((-123.53338 38.76841, -123.5334...
# 44             21  POLYGON ((-120.05207 37.18311, -120.05216 37.1...
# 45              6  MULTIPOLYGON (((-122.29848 38.21992, -122.2984...
# 46             10  POLYGON ((-120.00379 39.44506, -120.00379 39.4...
# 47             30  POLYGON ((-117.78326 33.94627, -117.78316 33.9...
# 48              2  POLYGON ((-121.32784 40.44537, -121.32341 40.4...
# 49             12  POLYGON ((-121.21542 36.96125, -121.21455 36.9...
# 50             24  POLYGON ((-122.39268 37.70834, -122.39269 37.7...
# 51             25  MULTIPOLYGON (((-120.65125 34.57609, -120.6517...
# 52             33  MULTIPOLYGON (((-122.09365 37.45453, -122.0933...
# 53             14  POLYGON ((-121.49765 40.44560, -121.49787 40.4...
# 54              1  POLYGON ((-120.14716 39.70766, -120.13579 39.7...
# 55             25  POLYGON ((-121.44755 41.99747, -121.44762 41.9...
# 56             13  POLYGON ((-121.62377 39.29563, -121.62372 39.2...
# 57             20  POLYGON ((-118.88042 34.78866, -118.88032 34.7...

# %%
bus_stops = query_sql(
'''
SELECT name, month_first_day, day_type, route_type_3 + route_type_11 AS bus_arrivals,
daily_stop_arrivals, stop_id, n_days, pt_geom
FROM `cal-itp-data-infra.mart_gtfs_rollup.fct_monthly_scheduled_stops`
WHERE year = 2025 AND month = 12
AND route_type_3 > 0 OR route_type_11 > 0
LIMIT 1000
'''
)

# %%
bus_stops = gpd.GeoDataFrame(bus_stops, geometry=gpd.GeoSeries.from_wkt(bus_stops.pt_geom), crs=WGS84).drop(columns=['pt_geom'])

# %%
bus_stops.head(10)
# Out:
#                       name month_first_day  day_type  bus_arrivals  \
# 0  Eastern Sierra Schedule      2023-11-01  Saturday         310.0
# 1  Eastern Sierra Schedule      2023-11-01   Weekday         317.4
# 2  Eastern Sierra Schedule      2023-12-01    Sunday         192.5
# 3  Eastern Sierra Schedule      2024-01-01   Weekday         477.2
# 4  Eastern Sierra Schedule      2024-03-01   Weekday        1216.0
# 5  Eastern Sierra Schedule      2024-03-01  Saturday        2432.0
# 6  Eastern Sierra Schedule      2024-04-01  Saturday         391.6
# 7  Eastern Sierra Schedule      2024-04-01    Sunday         530.1
# 8  Eastern Sierra Schedule      2024-05-01   Weekday          13.4
# 9  Eastern Sierra Schedule      2024-05-01    Sunday          31.0
#
#    daily_stop_arrivals  stop_id  n_days                     geometry
# 0                 16.0  2324950       3  POINT (-118.97099 37.63867)
# 1                 28.0    20302      21  POINT (-118.99126 37.64419)
# 2                312.4    20355       5  POINT (-118.97296 37.64022)
# 3                204.0    20300      23  POINT (-118.99542 37.64427)
# 4                200.0    20366      21  POINT (-118.98462 37.63668)
# 5               1400.0    20317       5  POINT (-118.96664 37.64075)
# 6                182.0    20302       4  POINT (-118.99126 37.64419)
# 7                189.0    20324       4  POINT (-118.97093 37.63721)
# 8                 92.3    20304      23  POINT (-118.98840 37.64582)
# 9                 21.0    20333       3  POINT (-118.95979 37.64756)

# %%
type(bus_stops)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
# bus_stops.drop(columns='month_first_day').explore()

# %% [markdown]
# # `route_id` changes
#
# The heuristic can be, if the `combined_name` is the same, select the latest `route_id`.
# * For Metro, let's parse out the suffix
# * For others, leave it
#
# When `route_id` is stable and there are different `combined_names`, use the name that is most prevalent. Do this first before addressing the first problem.

# %%
import pandas as pd

from segment_speed_utils import helpers
from segment_speed_utils.project_vars import SEGMENT_GCS
from shared_utils import rt_dates

months = [
    "mar", "apr", "may",
    "jun", "jul", "aug",
    "sep", "oct", "nov",
    "dec"
]

date_list = [
    rt_dates.DATES[f"{m}2023"] 
    for m in months
]

# %%
df = pd.concat([
    helpers.import_scheduled_trips(
        analysis_date,
        columns = ["gtfs_dataset_key", "name", "route_id", 
                   "route_long_name", "route_short_name", "route_desc"],
        get_pandas = True
    ).assign(
        service_date = pd.to_datetime(analysis_date)
    ) for analysis_date in date_list
], axis=0, ignore_index=True)

# %%
# Fill in missing values
df = df.assign(
    route_id = df.route_id.fillna(""),
    route_short_name = df.route_short_name.fillna(""),
    route_long_name = df.route_long_name.fillna(""),
    #route_desc = df.route_desc.fillna("None")
)

df = df.assign(
    combined_all = df.route_id + "_" + df.route_short_name + "_" + df.route_long_name,
    combined_name = df.route_short_name + "_" + df.route_long_name
)

# %%
n_days = len(date_list)
n_days
# Out:
# 10

# %%
operator_day_cols = ["schedule_gtfs_dataset_key", "service_date"]
route_day_cols = operator_day_cols + ["route_id"]
route_cols = ["schedule_gtfs_dataset_key", "route_id"]
route_name_cols = ["schedule_gtfs_dataset_key", "combined_name"]

daily_routes = (df.groupby(operator_day_cols)
                  .agg({"route_id": "nunique"})
                  .reset_index()
)

# %% [markdown]
# ## Problem 1: Count nunique route_ids if the combined name is the same
# * combination of `route_short_name`, `route_long_name`, and `route_desc` is the same, but `route_id` is different
# * find a couple of examples where over 8 different service dates, there are at least 3 variations

# %%
combinations_id = (df.groupby(route_name_cols)
                .agg({"route_id": "nunique"})
                .reset_index()
               )

# %%
combinations_id.route_id.value_counts()
# Out:
# 1     4836
# 3      159
# 2       93
# 4       37
# 43       1
# 39       1
# Name: route_id, dtype: int64

# %%
combinations_id.route_id.value_counts(normalize=True)
# Out:
# 1     0.943242
# 3     0.031012
# 2     0.018139
# 4     0.007217
# 43    0.000195
# 39    0.000195
# Name: route_id, dtype: float64

# %%
combinations_id[combinations_id.route_id==39]
# Out:
#              schedule_gtfs_dataset_key                       combined_name  \
# 4800  f449c9c8d400dd385d7bc216748d29da  _Amtrak Thruway Connecting Service
#
#       route_id
# 4800        39

# %%
df[df.schedule_gtfs_dataset_key=="f449c9c8d400dd385d7bc216748d29da"]
# Out:
#              schedule_gtfs_dataset_key             name route_id  \
# 498   f449c9c8d400dd385d7bc216748d29da  Amtrak Schedule    29498
# 499   f449c9c8d400dd385d7bc216748d29da  Amtrak Schedule    37329
# 500   f449c9c8d400dd385d7bc216748d29da  Amtrak Schedule    15159
# 501   f449c9c8d400dd385d7bc216748d29da  Amtrak Schedule    42949
# 502   f449c9c8d400dd385d7bc216748d29da  Amtrak Schedule    23565
# ...                                ...              ...      ...
# 2170  f449c9c8d400dd385d7bc216748d29da  Amtrak Schedule       91
# 2171  f449c9c8d400dd385d7bc216748d29da  Amtrak Schedule       70
# 2172  f449c9c8d400dd385d7bc216748d29da  Amtrak Schedule       81
# 2173  f449c9c8d400dd385d7bc216748d29da  Amtrak Schedule       58
# 2174  f449c9c8d400dd385d7bc216748d29da  Amtrak Schedule    36949
#
#                         route_long_name route_short_name route_desc  \
# 498   Amtrak Thruway Connecting Service                        None
# 499   Amtrak Thruway Connecting Service                        None
# 500   Amtrak Thruway Connecting Service                        None
# 501   Amtrak Thruway Connecting Service                        None
# 502   Amtrak Thruway Connecting Service                        None
# ...                                 ...              ...        ...
# 2170                      Silver Meteor                        None
# 2171                        Silver Star                        None
# 2172                 Lake Shore Limited                        None
# 2173                           Cardinal                        None
# 2174                Ethan Allen Express                        None
#
#      service_date                              combined_all  \
# 498    2023-03-15  29498__Amtrak Thruway Connecting Service
# 499    2023-03-15  37329__Amtrak Thruway Connecting Service
# 500    2023-03-15  15159__Amtrak Thruway Connecting Service
# 501    2023-03-15  42949__Amtrak Thruway Connecting Service
# 502    2023-03-15  23565__Amtrak Thruway Connecting Service
# ...           ...                                       ...
# 2170   2023-03-15                         91__Silver Meteor
# 2171   2023-03-15                           70__Silver Star
# 2172   2023-03-15                    81__Lake Shore Limited
# 2173   2023-03-15                              58__Cardinal
# 2174   2023-03-15                36949__Ethan Allen Express
#
#                            combined_name
# 498   _Amtrak Thruway Connecting Service
# 499   _Amtrak Thruway Connecting Service
# 500   _Amtrak Thruway Connecting Service
# 501   _Amtrak Thruway Connecting Service
# 502   _Amtrak Thruway Connecting Service
# ...                                  ...
# 2170                      _Silver Meteor
# 2171                        _Silver Star
# 2172                 _Lake Shore Limited
# 2173                           _Cardinal
# 2174                _Ethan Allen Express
#
# [83 rows x 9 columns]

# %%
combinations_id.query('route_id > 2').head(3)
# Out:
#             schedule_gtfs_dataset_key           combined_name  route_id
# 953  3f3f36b4c41cc6b5df3eb7f5d8ea6e3c  10/48_Metro Local Line         3
# 954  3f3f36b4c41cc6b5df3eb7f5d8ea6e3c    102_Metro Local Line         3
# 955  3f3f36b4c41cc6b5df3eb7f5d8ea6e3c    105_Metro Local Line         3

# %%
combinations_id[combinations_id.schedule_gtfs_dataset_key != 
                "4c6b107352b318297bb39173c796f357"].query('route_id > 2').head(3)
# Out:
#             schedule_gtfs_dataset_key           combined_name  route_id
# 953  3f3f36b4c41cc6b5df3eb7f5d8ea6e3c  10/48_Metro Local Line         3
# 954  3f3f36b4c41cc6b5df3eb7f5d8ea6e3c    102_Metro Local Line         3
# 955  3f3f36b4c41cc6b5df3eb7f5d8ea6e3c    105_Metro Local Line         3

# %%
def subset_by_operator_name(
    df: pd.DataFrame, 
    gtfs_key: str, 
    one_name: str,
):
    return df[(df.schedule_gtfs_dataset_key == gtfs_key) & 
              (df.combined_name==one_name)].drop(columns = ["route_long_name", "route_short_name", "route_desc"])

# %%
subset_by_operator_name(df, "4c6b107352b318297bb39173c796f357", "01_FAX Q")
# Out:
#               schedule_gtfs_dataset_key             name route_id  \
# 684    4c6b107352b318297bb39173c796f357  Fresno Schedule     3643
# 3031   4c6b107352b318297bb39173c796f357  Fresno Schedule     3643
# 7947   4c6b107352b318297bb39173c796f357  Fresno Schedule     3687
# 10413  4c6b107352b318297bb39173c796f357  Fresno Schedule     3687
# 12848  4c6b107352b318297bb39173c796f357  Fresno Schedule     3727
# 15488  4c6b107352b318297bb39173c796f357  Fresno Schedule     3727
# 18098  4c6b107352b318297bb39173c796f357  Fresno Schedule     3727
# 20752  4c6b107352b318297bb39173c796f357  Fresno Schedule     3745
# 23372  4c6b107352b318297bb39173c796f357  Fresno Schedule     3745
#
#       service_date   combined_all combined_name
# 684     2023-03-15  3643_01_FAX Q      01_FAX Q
# 3031    2023-04-12  3643_01_FAX Q      01_FAX Q
# 7947    2023-06-14  3687_01_FAX Q      01_FAX Q
# 10413   2023-07-12  3687_01_FAX Q      01_FAX Q
# 12848   2023-08-15  3727_01_FAX Q      01_FAX Q
# 15488   2023-09-13  3727_01_FAX Q      01_FAX Q
# 18098   2023-10-11  3727_01_FAX Q      01_FAX Q
# 20752   2023-11-15  3745_01_FAX Q      01_FAX Q
# 23372   2023-12-13  3745_01_FAX Q      01_FAX Q

# %%
# The route_id earlier will disappear later
df[(df.schedule_gtfs_dataset_key=="4c6b107352b318297bb39173c796f357") & 
   (df.route_id=="3687")
  ]
# Out:
#               schedule_gtfs_dataset_key             name route_id  \
# 7947   4c6b107352b318297bb39173c796f357  Fresno Schedule     3687
# 10413  4c6b107352b318297bb39173c796f357  Fresno Schedule     3687
#
#       route_long_name route_short_name route_desc service_date   combined_all  \
# 7947            FAX Q               01       None   2023-06-14  3687_01_FAX Q
# 10413           FAX Q               01       None   2023-07-12  3687_01_FAX Q
#
#       combined_name
# 7947       01_FAX Q
# 10413      01_FAX Q

# %%
subset_by_operator_name(df, "95cb514215c61ca578b01d885f35ec0a", "14_FONTANA-FOOTHILL-SAN BDNO")
# Out:
#               schedule_gtfs_dataset_key                name route_id  \
# 2970   95cb514215c61ca578b01d885f35ec0a  OmniTrans Schedule    10662
# 5379   95cb514215c61ca578b01d885f35ec0a  OmniTrans Schedule    10764
# 7887   95cb514215c61ca578b01d885f35ec0a  OmniTrans Schedule    10764
# 10354  95cb514215c61ca578b01d885f35ec0a  OmniTrans Schedule    10764
# 12788  95cb514215c61ca578b01d885f35ec0a  OmniTrans Schedule    10935
# 15428  95cb514215c61ca578b01d885f35ec0a  OmniTrans Schedule    10935
# 18037  95cb514215c61ca578b01d885f35ec0a  OmniTrans Schedule    10935
# 20691  95cb514215c61ca578b01d885f35ec0a  OmniTrans Schedule    10935
# 23311  95cb514215c61ca578b01d885f35ec0a  OmniTrans Schedule    10935
#
#       service_date                        combined_all  \
# 2970    2023-04-12  10662_14_FONTANA-FOOTHILL-SAN BDNO
# 5379    2023-05-17  10764_14_FONTANA-FOOTHILL-SAN BDNO
# 7887    2023-06-14  10764_14_FONTANA-FOOTHILL-SAN BDNO
# 10354   2023-07-12  10764_14_FONTANA-FOOTHILL-SAN BDNO
# 12788   2023-08-15  10935_14_FONTANA-FOOTHILL-SAN BDNO
# 15428   2023-09-13  10935_14_FONTANA-FOOTHILL-SAN BDNO
# 18037   2023-10-11  10935_14_FONTANA-FOOTHILL-SAN BDNO
# 20691   2023-11-15  10935_14_FONTANA-FOOTHILL-SAN BDNO
# 23311   2023-12-13  10935_14_FONTANA-FOOTHILL-SAN BDNO
#
#                       combined_name
# 2970   14_FONTANA-FOOTHILL-SAN BDNO
# 5379   14_FONTANA-FOOTHILL-SAN BDNO
# 7887   14_FONTANA-FOOTHILL-SAN BDNO
# 10354  14_FONTANA-FOOTHILL-SAN BDNO
# 12788  14_FONTANA-FOOTHILL-SAN BDNO
# 15428  14_FONTANA-FOOTHILL-SAN BDNO
# 18037  14_FONTANA-FOOTHILL-SAN BDNO
# 20691  14_FONTANA-FOOTHILL-SAN BDNO
# 23311  14_FONTANA-FOOTHILL-SAN BDNO

# %%
subset_by_operator_name(df, "3f3f36b4c41cc6b5df3eb7f5d8ea6e3c", "102_Metro Local Line")
# Out:
#               schedule_gtfs_dataset_key                   name   route_id  \
# 1506   3f3f36b4c41cc6b5df3eb7f5d8ea6e3c  LA Metro Bus Schedule  102-13167
# 3901   3f3f36b4c41cc6b5df3eb7f5d8ea6e3c  LA Metro Bus Schedule  102-13167
# 6317   3f3f36b4c41cc6b5df3eb7f5d8ea6e3c  LA Metro Bus Schedule  102-13167
# 8670   3f3f36b4c41cc6b5df3eb7f5d8ea6e3c  LA Metro Bus Schedule  102-13167
# 11196  3f3f36b4c41cc6b5df3eb7f5d8ea6e3c  LA Metro Bus Schedule  102-13168
# 13727  3f3f36b4c41cc6b5df3eb7f5d8ea6e3c  LA Metro Bus Schedule  102-13168
# 16310  3f3f36b4c41cc6b5df3eb7f5d8ea6e3c  LA Metro Bus Schedule  102-13168
# 18993  3f3f36b4c41cc6b5df3eb7f5d8ea6e3c  LA Metro Bus Schedule  102-13168
# 21681  3f3f36b4c41cc6b5df3eb7f5d8ea6e3c  LA Metro Bus Schedule  102-13168
# 24286  3f3f36b4c41cc6b5df3eb7f5d8ea6e3c  LA Metro Bus Schedule  102-13172
#
#       service_date                    combined_all         combined_name
# 1506    2023-03-15  102-13167_102_Metro Local Line  102_Metro Local Line
# 3901    2023-04-12  102-13167_102_Metro Local Line  102_Metro Local Line
# 6317    2023-05-17  102-13167_102_Metro Local Line  102_Metro Local Line
# 8670    2023-06-14  102-13167_102_Metro Local Line  102_Metro Local Line
# 11196   2023-07-12  102-13168_102_Metro Local Line  102_Metro Local Line
# 13727   2023-08-15  102-13168_102_Metro Local Line  102_Metro Local Line
# 16310   2023-09-13  102-13168_102_Metro Local Line  102_Metro Local Line
# 18993   2023-10-11  102-13168_102_Metro Local Line  102_Metro Local Line
# 21681   2023-11-15  102-13168_102_Metro Local Line  102_Metro Local Line
# 24286   2023-12-13  102-13172_102_Metro Local Line  102_Metro Local Line

# %% [markdown]
# ## Problem 2: Assume route_id is stable, find nunique combined_name
# * `route_id` for operator is same, but `combined_name` is different
# * this is probably easier to fix, we can designate the latest combined name to be what is displayed
# * fixing this will not address problem 1

# %%
# How many unique combinations are there
combinations = (df.groupby(route_cols)
                .agg({"combined_name": "nunique"})
                .reset_index()
               )

combinations.combined_name.value_counts()
# Out:
# 1    5012
# 2     351
# 3       5
# Name: combined_name, dtype: int64

# %%
(combinations
 .query('combined_name > 2')
).head(10)
# Out:
#              schedule_gtfs_dataset_key route_id  combined_name
# 3167  a37760dde6b9fdcb76b82e57afab7274     2512              3
# 3171  a37760dde6b9fdcb76b82e57afab7274     2590              3
# 3200  a37760dde6b9fdcb76b82e57afab7274    N2601              3
# 3567  b9473e19aebf7ee2ec18623eb35762a1    42947              3
# 5232  fb467982dcc77a7f9199bebe709bb700       52              3

# %%
def subset_by_operator_route(
    df: pd.DataFrame, 
    gtfs_key: str, 
    one_route: str,
):
    return df[(df.schedule_gtfs_dataset_key == gtfs_key) & 
              (df.route_id==one_route)].drop(columns = ["route_short_name", "route_long_name", "route_desc"])

# %%
subset_by_operator_route(
    df.drop_duplicates(subset = route_cols + ["combined_name"]), 
    "6b09003d3a547f37aba623fe8211b355", 
    "115"
)
# Out:
#               schedule_gtfs_dataset_key                    name route_id  \
# 1921   6b09003d3a547f37aba623fe8211b355  Redwood Coast Schedule      115
# 14142  6b09003d3a547f37aba623fe8211b355  Redwood Coast Schedule      115
#
#       service_date                                combined_all  \
# 1921    2023-03-15     115_1_Route 1-Blue Wal-Mart / El Dorado
# 14142   2023-08-15  115_1_Route 1-Blue Wal-Mart / DNHS College
#
#                                 combined_name
# 1921      1_Route 1-Blue Wal-Mart / El Dorado
# 14142  1_Route 1-Blue Wal-Mart / DNHS College

# %%
subset_by_operator_route(
    df,
    #df.drop_duplicates(subset = route_cols + ["combined_name"]), 
    "fb467982dcc77a7f9199bebe709bb700", 
    "55"
).combined_name.tolist()
# Out:
# ['55_Old Ironsides Station - De Anza College',
#  '55_Old Ironsides Station - De Anza College',
#  '55_Old Ironsides Stn - De Anza Coll',
#  '55_Old Ironsides Stn - De Anza Coll',
#  '55_Old Ironsides Stn - De Anza Coll',
#  '55_Old Ironsides Stn - De Anza Coll',
#  '55_Old Ironsides Stn - De Anza Coll',
#  '55_Old Ironsides Stn - De Anza Coll',
#  '55_Old Ironsides Stn - De Anza Coll']

# %% [markdown]
# ## Solutions
#
# Add functions to find most common and most recent **route_id or combined_name**.

# %%
def most_prevalent_route_info(
    df: pd.DataFrame, 
    group_cols: list, 
    route_col: str
) -> pd.DataFrame:
    most_prevalent = (df.groupby(group_cols)
                      [route_col].max()
                      .reset_index()
                      .rename(columns = {route_col: f"common_{route_col}"})
                     )
    
    df2 = pd.merge(
        df,
        most_prevalent,
        on = group_cols,
        how = "left"
    )
    
    return df2

def most_recent_route_info(
    df: pd.DataFrame,
    group_cols: list,
    route_col: str
) -> pd.DataFrame:
    
    sort_order = [True for c in group_cols]
    
    most_recent = (df.sort_values(group_cols + ["service_date"], 
                                  ascending = sort_order + [False])
                   .drop_duplicates(subset = group_cols)  
                   .rename(columns = {route_col: f"recent_{route_col}"})
                  )
    
    df2 = pd.merge(
        df,
        most_recent[group_cols + [f"recent_{route_col}"]],
        on = group_cols,
        how = "left"
    )
    
    return df2

# %%
most_recent_route_info(
    df,
    group_cols = ["name"] + route_cols,
    route_col = "combined_name"
).head(3)
# Out:
#           schedule_gtfs_dataset_key               name route_id  \
# 0  7e015887964432c82ce7e735c2753f86  VCTC GMV Schedule     3402
# 1  7e015887964432c82ce7e735c2753f86  VCTC GMV Schedule     3407
# 2  7e015887964432c82ce7e735c2753f86  VCTC GMV Schedule     3408
#
#   route_long_name route_short_name                          route_desc  \
# 0        Route 11         Route 11  PACIFIC VIEW MALL via TELEPHONE RD
# 1        Route 18         Route 18       OHS TRIPPER - C ST - DORIS ST
# 2        Route 21         Route 21  PACIFIC VIEW MALL via VICTORIA AVE
#
#   service_date            combined_all      combined_name recent_combined_name
# 0   2023-03-15  3402_Route 11_Route 11  Route 11_Route 11    Route 11_Route 11
# 1   2023-03-15  3407_Route 18_Route 18  Route 18_Route 18    Route 18_Route 18
# 2   2023-03-15  3408_Route 21_Route 21  Route 21_Route 21    Route 21_Route 21

# %%
most_prevalent_route_info(
    df,
    group_cols = ["name"] + route_name_cols,
    route_col = "route_id"
).query('route_id != common_route_id').head()
# Out:
#             schedule_gtfs_dataset_key                   name route_id  \
# 92   08862f6780e2bb5afce698a73f6974cc        LA DOT Schedule     1458
# 221  dbbe8ee4864a2715a40749605395d584  Big Blue Bus Schedule     3554
# 222  dbbe8ee4864a2715a40749605395d584  Big Blue Bus Schedule     3555
# 223  dbbe8ee4864a2715a40749605395d584  Big Blue Bus Schedule     3556
# 224  dbbe8ee4864a2715a40749605395d584  Big Blue Bus Schedule     3558
#
#                       route_long_name route_short_name  \
# 92                             CE438B             438B
# 221  Main St & Santa Monica Blvd/UCLA                1
# 222                Wilshire Blvd/UCLA                2
# 223                  Lincoln Blvd/LAX                3
# 224                      Olympic Blvd                5
#
#                                     route_desc service_date  \
# 92   Commuter Express 438B - Imperial-Aviation   2023-03-15
# 221                                       None   2023-03-15
# 222                                       None   2023-03-15
# 223                                       None   2023-03-15
# 224                                       None   2023-03-15
#
#                                 combined_all  \
# 92                          1458_438B_CE438B
# 221  3554_1_Main St & Santa Monica Blvd/UCLA
# 222                3555_2_Wilshire Blvd/UCLA
# 223                  3556_3_Lincoln Blvd/LAX
# 224                      3558_5_Olympic Blvd
#
#                           combined_name common_route_id
# 92                          438B_CE438B            4278
# 221  1_Main St & Santa Monica Blvd/UCLA            3629
# 222                2_Wilshire Blvd/UCLA            3630
# 223                  3_Lincoln Blvd/LAX            3631
# 224                      5_Olympic Blvd            3633

# %% [markdown]
# ### Parse for hyphens and underscores

# %%
routes_to_parse = df[df.route_id.str.contains("-")][["name", "route_id"]].drop_duplicates()
routes_to_parse2 = df[df.route_id.str.contains("_")][["name", "route_id"]].drop_duplicates()

# %%
OPERATORS_USE_HYPHENS = [
    "Monterey Salinas", "LA Metro",
    "BART", # Beige - N, Beige - S
    "MVGO", # B - AM, B - PM
]

OPERATORS_USE_UNDERSCORES = [
    "Roseville", # 5_AM, 5_PM
]

#for i in df.name.unique():
#    print(i)
#    print(df[(df.name == i)].route_id.unique())

# %%
inspect_more = ["Bay Area 511 ACE Schedule",
                
                # These have dashes, which may make it harder to link across time?
                "Yolobus", "Santa Maria",
                "BruinBus",
                "TCRTA", # some dashes
                "B-Line", "Anaheim Resort"
                
               ]

# %%
def parse_route_id(row, gtfs_name_col: str, route_col: str):
    
    word = row[route_col]
    
    OPERATORS_USE_HYPHENS = [
        "Monterey Salinas", "LA Metro",
        "BART", # Beige - N, Beige - S
        "MVGO", # B - AM, B - PM
    ]
    
    OPERATORS_USE_UNDERSCORES = [
        "Roseville", # 5_AM, 5_PM
    ]
    if any(word in row[gtfs_name_col] for word in OPERATORS_USE_HYPHENS): 
        word = word.split("-")[0]
    
    if any(word in row[gtfs_name_col] for word in OPERATORS_USE_UNDERSCORES):
        word = word.split("_")[0]
    
    
    word = word.strip()
    return word

# %%
routes_to_parse["route_id2"] = routes_to_parse.apply(
    lambda x: parse_route_id(x, "name", "route_id"), axis=1
)

# %%
routes_to_parse.name.unique()
# Out:
# array(['Monterey Salinas Schedule', 'Yolobus Schedule',
#        'Bay Area 511 BART Schedule', 'Bay Area 511 MVGO Schedule',
#        'LA Metro Bus Schedule', 'B-Line Schedule',
#        'Anaheim Resort Schedule', 'Santa Maria Schedule',
#        'BruinBus Schedule', 'Metrolink Schedule',
#        'TCRTA TripShot Schedule',
#        'Bay Area 511 Angel Island-Tiburon Ferry Schedule',
#        'Bay Area 511 Treasure Island Ferry Schedule',
#        'Bay Area 511 Santa Clara Transit Schedule', 'Lynwood Schedule'],
#       dtype=object)

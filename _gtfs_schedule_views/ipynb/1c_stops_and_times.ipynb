# %%
# %run 0_data_model.ipynb

pk_str = ["calitp_itp_id", "calitp_url_number"]
pk_col = (_.calitp_itp_id, _.calitp_url_number)

DATE_START = "2021-04-01"
DATE_END = "2021-05-01"

# %% [markdown]
# ## Table overview
#
# * gtfs_schedule_trips
#     * stops_and_times
#     * schedule_daily
#
# Tables used for questions:
#
# * **Stop times by location type** - stops_and_times
# * **Stops in service** - stops_and_times + (gtfs_schedule_trips + schedule_daily)

# %% [markdown]
# ## Stop times by location types
#
# It looks like stops are either not coded for location type or type 1 (stations).

# %%
(tbl_stops_and_times
  >> count(_.location_type)
)
# Out:
# # Source: lazy query
# # DB Conn: Engine(bigquery://cal-itp-data-infra/?maximum_bytes_billed=1000000000)
# # Preview:
#   location_type        n
# 0          None  5524733
# 1             0  4054292
# # .. may have more rows

# %% [markdown]
# ## Stop sequences

# %%
from siuba.dply.vector import dense_rank

(
    tbl_stops_and_times
    >> group_by(_.trip_id)
    >> mutate(
        stop_sequence=_.stop_sequence.astype(int),
        stop_order=dense_rank(_.stop_sequence, na_option="keep"),
    )
    >> ungroup()
    >> summarize(max=_.stop_order.max())
)
# Out:
# # Source: lazy query
# # DB Conn: Engine(bigquery://cal-itp-data-infra/?maximum_bytes_billed=1000000000)
# # Preview:
#    max
# 0  136
# # .. may have more rows

# %% [markdown]
# ## Stops in service on a specific day

# %%
recent_trip_stops = (
    tbl_stops_and_times
    >> inner_join(
        _,
        tbl.gtfs_schedule_trips() >> select(_.trip_id, _.service_id, _.route_id, *pk_col),
        [*pk_str, "trip_id"],
    )
    >> inner_join(_, tbl_schedule_daily >> filter(_.service_date == DATE_END), [*pk_str, "service_id"])
)

# %%
# counts number of stop *times*
recent_trip_stops >> count()
# Out:
# # Source: lazy query
# # DB Conn: Engine(bigquery://cal-itp-data-infra/?maximum_bytes_billed=1000000000)
# # Preview:
#          n
# 0  7023803
# # .. may have more rows

# %%
# counts stops that are being serviced. note that the distinct
# ensures we do not count a physical stop more than once
recent_agency_stops = recent_trip_stops >> distinct(*pk_col, _.stop_id)

# %%
recent_agency_stops >> count()
# Out:
# # Source: lazy query
# # DB Conn: Engine(bigquery://cal-itp-data-infra/?maximum_bytes_billed=1000000000)
# # Preview:
#        n
# 0  92222
# # .. may have more rows

# %%
recent_agency_stops >> count(*pk_col)
# Out:
# # Source: lazy query
# # DB Conn: Engine(bigquery://cal-itp-data-infra/?maximum_bytes_billed=1000000000)
# # Preview:
#    calitp_itp_id  calitp_url_number      n
# 0            182                  0  13283
# 1            142                  0   5171
# 2            235                  0   5171
# 3              4                  0   4579
# 4            278                  0   3427
# # .. may have more rows

# %% [markdown]
# ## Stops out of service

# %%
tbl_stops_and_times
# Out:
# # Source: lazy query
# # DB Conn: Engine(bigquery://cal-itp-data-infra/?maximum_bytes_billed=1000000000)
# # Preview:
#    calitp_itp_id  calitp_url_number            trip_id stop_id stop_sequence  \
# 0            111                  0             781444   11064            68
# 1            111                  0             781449   11160            63
# 2            111                  0             781375   11065            67
# 3            350                  1              40090   79013             0
# 4              2                  0  BCT109 NB_SAT.T10     163            67
#
#   arrival_time departure_time stop_headsign pickup_type drop_off_type  ...  \
# 0     16:10:00       16:10:00          None        None          None  ...
# 1     11:05:00       11:05:00          None        None          None  ...
# 2     11:09:00       11:09:00          None        None          None  ...
# 3     11:44:00       11:44:00          None           0             0  ...
# 4     16:35:30       16:35:30          None        None          None  ...
#
#   level_id        stop_timezone    stop_lon      stop_desc  \
# 0     None                 None -121.186693  Buses head NB
# 1     None                 None -121.202331  Buses head NB
# 2     None                 None -121.188730  Buses head NB
# 3     None  America/Los_Angeles -122.065656       Terminal
# 4     None                 None -118.387028           None
#
#   calitp_extracted_at_y wheelchair_boarding platform_code tts_stop_name  \
# 0            2021-04-16                None          None          None
# 1            2021-04-16                None          None          None
# 2            2021-04-16                None          None          None
# 3            2021-04-29                   1          None          None
# 4            2021-04-16                None          None          None
#
#                                            stop_name location_type
# 0     AMERICAN RIVER CANYON DR & GREY CANYON DR (NB)             0
# 1                        MAIN AVE & MADISON AVE (NB)             0
# 2  AMERICAN RIVER CANYON DR & BOULDER CANYON WAY ...             0
# 3                       Union Landing Transit Center             0
# 4                           Imperial Hwy. / Nash St.          None
#
# [5 rows x 30 columns]
# # .. may have more rows

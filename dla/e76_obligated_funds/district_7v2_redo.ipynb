# %% [markdown]
# # Obligations in District 7
#
# Using data from the Division of Local Assistance [Obligation list](https://dot.ca.gov/programs/local-assistance/reports/e-76-obligated)

# %%
import numpy as np
import pandas as pd
from siuba import *
import _clean_data
import altair as alt
import altair_saver
from calitp import *
from plotnine import *

from shared_utils import altair_utils
alt.themes.enable("fivethirtyeight")


import ipywidgets as widgets
from ipywidgets import *
from IPython.display import Markdown
from IPython.core.display import display
# Out:
# /opt/conda/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.9.1-CAPI-1.14.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
# /opt/conda/lib/python3.9/site-packages/google/auth/_default.py:73: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/

# %%
import _dla_utils

# %%
# df = _clean_data.read_data()
# df = _clean_data.clean_data(df)
# df = _clean_data.prefix_cleaning(df)
# df = _clean_data.clean_agency_names(df)

# %%
df= pd.read_parquet("dla_df.parquet")

# %%
df.sample()
# Out:
#         location   prefix project_no                              agency  \
# 14811  Obligated  RPSTCML  6088(068)  San Joaquin Council Of Governments
#
#       prepared_date submit__to_hq_date hq_review_date submit_to_fhwa_date  \
# 14811    2019-09-04         2019-09-04     2019-09-04          2019-09-04
#
#       to_fmis_date  fed_requested  ...    ftip_no  \
# 14811   2019-09-06      6539650.0  ...  SJ07-1003
#
#                                         project_location  \
# 14811  Near Tracy, I-205 From The Alameda County Line...
#
#                                             type_of_work seq  \
# 14811  I-205 Managed Lanes. Widen From 6 To 8 Lanes W...   1
#
#        date_request_initiated date_completed_request   mpo  projectID  \
# 14811              2019-06-26             2019-06-27  SJCG       6088
#
#        prepared_y                 primary_agency_name
# 14811      2019.0  San Joaquin Council of Governments
#
# [1 rows x 29 columns]

# %%
df1 = _dla_utils.count_all_years((df>>filter(_.dist==7)))

# %%
df1
# Out:
#     prepared_y  dist  ac_requested_sum  fed_requested_sum  \
# 10      2021.0     7     -1.982682e+07       4.442839e+08
# 9       2020.0     7     -2.785211e+07       4.189328e+08
# 8       2019.0     7     -1.299494e+07       3.632827e+08
# 0       2018.0     7     -5.915498e+07       3.335298e+08
# 1       2017.0     7     -6.039668e+07       3.115877e+08
# 2       2016.0     7     -9.384213e+07       4.303013e+08
# 3       2015.0     7      1.348315e+08       2.590450e+08
# 5       2014.0     7      2.349622e+08       2.915008e+08
# 6       2013.0     7      2.855137e+07       1.464760e+07
# 7       2012.0     7      0.000000e+00      -1.094570e+05
# 4          NaN     7               NaN                NaN
#
#     total_requested_sum  ac_requested_mean  fed_requested_mean  \
# 10         6.336926e+08      -82268.967718        1.843502e+06
# 9          9.588052e+08      -87037.856375        1.309165e+06
# 8          3.986935e+08      -37449.397695        1.046924e+06
# 0          3.346124e+08     -176056.483304        9.926483e+05
# 1          2.997071e+08     -184136.219878        9.499626e+05
# 2          4.903662e+08     -248918.123767        1.144418e+06
# 3          5.859364e+08      364409.335135        7.001215e+05
# 5          5.851461e+08      546423.818605        6.779089e+05
# 6         -2.300755e+07      892230.437500        4.577374e+05
# 7         -1.235050e+05           0.000000       -1.094570e+05
# 4                   NaN                NaN                 NaN
#
#     total_requested_mean  unique_mpo  unique_prefix  \
# 10          2.629430e+06         2.0           41.0
# 9           2.996266e+06         1.0           44.0
# 8           1.148973e+06         2.0           37.0
# 0           9.958701e+05         1.0           39.0
# 1           9.137411e+05         2.0           39.0
# 2           1.300706e+06         2.0           43.0
# 3           1.583612e+06         8.0           41.0
# 5           1.360805e+06        10.0           42.0
# 6          -7.189861e+05         4.0           20.0
# 7          -1.235050e+05         1.0            1.0
# 4                    NaN         NaN            NaN
#
#     unique_primary_agency_name  unique_project_location  unique_project_no  \
# 10                        62.0                    203.0              210.0
# 9                         60.0                    277.0              283.0
# 8                         67.0                    293.0              304.0
# 0                         63.0                    280.0              294.0
# 1                         73.0                    282.0              296.0
# 2                         76.0                    308.0              323.0
# 3                         85.0                    299.0              312.0
# 5                         77.0                    362.0              375.0
# 6                         18.0                     30.0               32.0
# 7                          1.0                      1.0                1.0
# 4                          NaN                      NaN                NaN
#
#     unique_type_of_work
# 10                196.0
# 9                 268.0
# 8                 285.0
# 0                 267.0
# 1                 266.0
# 2                 304.0
# 3                 269.0
# 5                 323.0
# 6                  31.0
# 7                   1.0
# 4                   NaN

# %%
df= (df>>filter(_.dist==7))

# %% [markdown]
# ## Adding Catalog Datasets

# %%
import intake
import geopandas as gpd

# %%
def read_catalog(df):    
    catalog = intake.open_catalog("catalog.yml")

    city_bound = catalog.ca_open_data.city_boundary.read()
    county_bound = catalog.ca_open_data.county_boundary.read()
 
    district_bound= catalog.district_bound.read()
    rtpa_bound= catalog.rtpa_bound.read()
    locode_df = pd.concat(pd.read_excel('gs://calitp-analytics-data/data-analyses/dla/e-76Obligated/locodes_updated7122021.xlsx', sheet_name=None), ignore_index=True)
    locode_df = to_snakecase(locode_df)

    #renaming
    county_bound['name'] =  county_bound['name'] + ' County'
    county_bound.rename(columns={'name': 'county_name', 'geometry': 'geometry2'}, inplace=True)

    # deleting Calaveras County because the location of the project is not in district 7
    delete_row = df[df["primary_agency_name"]== 'Calaveras County'].index
    df = df.drop(delete_row)

    new_df1 = pd.merge(df, locode_df,  how='left', left_on=['primary_agency_name'], right_on = ['agency_name'])
    new_df2 = pd.merge(new_df1, city_bound,  how='left', left_on=['primary_agency_name'], right_on = ['NAME'])
    new_df3 = left_join(new_df2, county_bound, on = "county_name")

    return new_df3

# %%
df_test = read_catalog(df)
# Out:
# /opt/conda/lib/python3.9/site-packages/google/auth/_default.py:73: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/

# %% [markdown]
# ## How Many Agencies are Cities?

# %%
df_test.NAME.notnull().value_counts()
# Out:
# True     1971
# False    1031
# Name: NAME, dtype: int64

# %% [markdown]
# ### number of unique agency names that are **cities**

# %%
len(df_test>>filter(_.NAME.notnull())>>count(_.primary_agency_name))
# Out:
# 87

# %% [markdown]
# ### number of unique agency names that are **not** cities

# %%
len(df_test>>filter(_.NAME.isnull())>>count(_.primary_agency_name))
# Out:
# 20

# %%
df_test>>filter(_.NAME.isnull())>>count(_.primary_agency_name)
# Out:
#                                   primary_agency_name    n
# 0                                     Access Services   17
# 1           Alameda Corridor Transportation Authority    1
# 2                   Antelope Valley Transit Authority    1
# 3                                            Caltrans  234
# 4                   Long Beach Transportation Company    2
# 5                                  Los Angeles County  451
# 6   Los Angeles County Metropolitan Transportation...   85
# 7                 Los Angeles Unified School District    2
# 8                                    Palos Verdes Est    2
# 9                                  Port Of Long Beach    2
# 10                                   San Buenaventura   35
# 11          San Gabriel Valley Council of Governments   18
# 12        South Coast Air Quality Management District    4
# 13                           South Coast Area Transit    7
# 14     Southern California Association of Governments   13
# 15        Southern California Regional Rail Authority    3
# 16                             Sunline Transit Agency    7
# 17      U.S. Forest Service, Pacific Southwest Region    1
# 18                                     Ventura County  115
# 19           Ventura County Transportation Commission   29

# %% [markdown]
# ### Cities with the most obligations

# %%
topten_city =(df_test>>filter(_.NAME.notnull())>>count(_.primary_agency_name)>>arrange(-_.n)).head(10)

# %%
topten_city.rename(columns={'primary_agency_name': 'Primary Agency Name', 'n': 'Count'}, inplace=True)

# %%
topten_city.style.set_caption('District 7 Cities with the Most Oblgiations')
# Out:
# <style type="text/css">
# </style>
# <table id="T_942d9_">
#   <caption>District 7 Cities with the Most Oblgiations</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Primary Agency Name</th>
#       <th class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_942d9_level0_row0" class="row_heading level0 row0" >43</th>
#       <td id="T_942d9_row0_col0" class="data row0 col0" >Los Angeles</td>
#       <td id="T_942d9_row0_col1" class="data row0 col1" >490</td>
#     </tr>
#     <tr>
#       <th id="T_942d9_level0_row1" class="row_heading level0 row1" >69</th>
#       <td id="T_942d9_row1_col0" class="data row1 col0" >Santa Clarita</td>
#       <td id="T_942d9_row1_col1" class="data row1 col1" >85</td>
#     </tr>
#     <tr>
#       <th id="T_942d9_level0_row2" class="row_heading level0 row2" >42</th>
#       <td id="T_942d9_row2_col0" class="data row2 col0" >Long Beach</td>
#       <td id="T_942d9_row2_col1" class="data row2 col1" >81</td>
#     </tr>
#     <tr>
#       <th id="T_942d9_level0_row3" class="row_heading level0 row3" >54</th>
#       <td id="T_942d9_row3_col0" class="data row3 col0" >Oxnard</td>
#       <td id="T_942d9_row3_col1" class="data row3 col1" >74</td>
#     </tr>
#     <tr>
#       <th id="T_942d9_level0_row4" class="row_heading level0 row4" >57</th>
#       <td id="T_942d9_row4_col0" class="data row4 col0" >Pasadena</td>
#       <td id="T_942d9_row4_col1" class="data row4 col1" >71</td>
#     </tr>
#     <tr>
#       <th id="T_942d9_level0_row5" class="row_heading level0 row5" >21</th>
#       <td id="T_942d9_row5_col0" class="data row5 col0" >Downey</td>
#       <td id="T_942d9_row5_col1" class="data row5 col1" >63</td>
#     </tr>
#     <tr>
#       <th id="T_942d9_level0_row6" class="row_heading level0 row6" >75</th>
#       <td id="T_942d9_row6_col0" class="data row6 col0" >Simi Valley</td>
#       <td id="T_942d9_row6_col1" class="data row6 col1" >61</td>
#     </tr>
#     <tr>
#       <th id="T_942d9_level0_row7" class="row_heading level0 row7" >40</th>
#       <td id="T_942d9_row7_col0" class="data row7 col0" >Lancaster</td>
#       <td id="T_942d9_row7_col1" class="data row7 col1" >57</td>
#     </tr>
#     <tr>
#       <th id="T_942d9_level0_row8" class="row_heading level0 row8" >55</th>
#       <td id="T_942d9_row8_col0" class="data row8 col0" >Palmdale</td>
#       <td id="T_942d9_row8_col1" class="data row8 col1" >46</td>
#     </tr>
#     <tr>
#       <th id="T_942d9_level0_row9" class="row_heading level0 row9" >58</th>
#       <td id="T_942d9_row9_col0" class="data row9 col0" >Pico Rivera</td>
#       <td id="T_942d9_row9_col1" class="data row9 col1" >40</td>
#     </tr>
#   </tbody>
# </table>

# %%
test= (df_test
       >>group_by(_.primary_agency_name)
       >>summarize(Total_Funds = _.total_requested.sum())
       >>arrange(-_.Total_Funds))

# %%
test.rename(columns={'primary_agency_name': 'Primary Agency Name', 'Total_Funds': 'Total Funds'}, inplace=True)

# %%
test.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_29436_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Primary Agency Name</th>
#       <th class="col_heading level0 col1" >Total Funds</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29436_level0_row0" class="row_heading level0 row0" >14</th>
#       <td id="T_29436_row0_col0" class="data row0 col0" >Caltrans</td>
#       <td id="T_29436_row0_col1" class="data row0 col1" >3632937185.670000</td>
#     </tr>
#     <tr>
#       <th id="T_29436_level0_row1" class="row_heading level0 row1" >50</th>
#       <td id="T_29436_row1_col0" class="data row1 col0" >Los Angeles County Metropolitan Transportation Authority</td>
#       <td id="T_29436_row1_col1" class="data row1 col1" >1441826242.940000</td>
#     </tr>
#     <tr>
#       <th id="T_29436_level0_row2" class="row_heading level0 row2" >48</th>
#       <td id="T_29436_row2_col0" class="data row2 col0" >Los Angeles</td>
#       <td id="T_29436_row2_col1" class="data row2 col1" >777759360.650000</td>
#     </tr>
#     <tr>
#       <th id="T_29436_level0_row3" class="row_heading level0 row3" >0</th>
#       <td id="T_29436_row3_col0" class="data row3 col0" >Access Services</td>
#       <td id="T_29436_row3_col1" class="data row3 col1" >561182617.000000</td>
#     </tr>
#     <tr>
#       <th id="T_29436_level0_row4" class="row_heading level0 row4" >46</th>
#       <td id="T_29436_row4_col0" class="data row4 col0" >Long Beach</td>
#       <td id="T_29436_row4_col1" class="data row4 col1" >386474097.640000</td>
#     </tr>
#     <tr>
#       <th id="T_29436_level0_row5" class="row_heading level0 row5" >49</th>
#       <td id="T_29436_row5_col0" class="data row5 col0" >Los Angeles County</td>
#       <td id="T_29436_row5_col1" class="data row5 col1" >192452850.830000</td>
#     </tr>
#     <tr>
#       <th id="T_29436_level0_row6" class="row_heading level0 row6" >79</th>
#       <td id="T_29436_row6_col0" class="data row6 col0" >San Gabriel Valley Council of Governments</td>
#       <td id="T_29436_row6_col1" class="data row6 col1" >48552755.850000</td>
#     </tr>
#     <tr>
#       <th id="T_29436_level0_row7" class="row_heading level0 row7" >83</th>
#       <td id="T_29436_row7_col0" class="data row7 col0" >Santa Monica</td>
#       <td id="T_29436_row7_col1" class="data row7 col1" >45649754.700000</td>
#     </tr>
#     <tr>
#       <th id="T_29436_level0_row8" class="row_heading level0 row8" >66</th>
#       <td id="T_29436_row8_col0" class="data row8 col0" >Pasadena</td>
#       <td id="T_29436_row8_col1" class="data row8 col1" >41592589.150000</td>
#     </tr>
#     <tr>
#       <th id="T_29436_level0_row9" class="row_heading level0 row9" >81</th>
#       <td id="T_29436_row9_col0" class="data row9 col0" >Santa Clarita</td>
#       <td id="T_29436_row9_col1" class="data row9 col1" >40362443.140000</td>
#     </tr>
#     <tr>
#       <th id="T_29436_level0_row10" class="row_heading level0 row10" >44</th>
#       <td id="T_29436_row10_col0" class="data row10 col0" >Lancaster</td>
#       <td id="T_29436_row10_col1" class="data row10 col1" >33095158.250000</td>
#     </tr>
#     <tr>
#       <th id="T_29436_level0_row11" class="row_heading level0 row11" >95</th>
#       <td id="T_29436_row11_col0" class="data row11 col0" >Sunline Transit Agency</td>
#       <td id="T_29436_row11_col1" class="data row11 col1" >32358158.460000</td>
#     </tr>
#     <tr>
#       <th id="T_29436_level0_row12" class="row_heading level0 row12" >25</th>
#       <td id="T_29436_row12_col0" class="data row12 col0" >Downey</td>
#       <td id="T_29436_row12_col1" class="data row12 col1" >27766595.830000</td>
#     </tr>
#     <tr>
#       <th id="T_29436_level0_row13" class="row_heading level0 row13" >94</th>
#       <td id="T_29436_row13_col0" class="data row13 col0" >Southern California Regional Rail Authority</td>
#       <td id="T_29436_row13_col1" class="data row13 col1" >25900300.000000</td>
#     </tr>
#     <tr>
#       <th id="T_29436_level0_row14" class="row_heading level0 row14" >100</th>
#       <td id="T_29436_row14_col0" class="data row14 col0" >Ventura County</td>
#       <td id="T_29436_row14_col1" class="data row14 col1" >24949254.550000</td>
#     </tr>
#     <tr>
#       <th id="T_29436_level0_row15" class="row_heading level0 row15" >63</th>
#       <td id="T_29436_row15_col0" class="data row15 col0" >Palmdale</td>
#       <td id="T_29436_row15_col1" class="data row15 col1" >21728242.150000</td>
#     </tr>
#     <tr>
#       <th id="T_29436_level0_row16" class="row_heading level0 row16" >97</th>
#       <td id="T_29436_row16_col0" class="data row16 col0" >Thousand Oaks</td>
#       <td id="T_29436_row16_col1" class="data row16 col1" >19703189.110000</td>
#     </tr>
#     <tr>
#       <th id="T_29436_level0_row17" class="row_heading level0 row17" >36</th>
#       <td id="T_29436_row17_col0" class="data row17 col0" >Industry</td>
#       <td id="T_29436_row17_col1" class="data row17 col1" >18972549.000000</td>
#     </tr>
#     <tr>
#       <th id="T_29436_level0_row18" class="row_heading level0 row18" >98</th>
#       <td id="T_29436_row18_col0" class="data row18 col0" >Torrance</td>
#       <td id="T_29436_row18_col1" class="data row18 col1" >17300912.830000</td>
#     </tr>
#     <tr>
#       <th id="T_29436_level0_row19" class="row_heading level0 row19" >87</th>
#       <td id="T_29436_row19_col0" class="data row19 col0" >Simi Valley</td>
#       <td id="T_29436_row19_col1" class="data row19 col1" >17164221.050000</td>
#     </tr>
#     <tr>
#       <th id="T_29436_level0_row20" class="row_heading level0 row20" >54</th>
#       <td id="T_29436_row20_col0" class="data row20 col0" >Manhattan Beach</td>
#       <td id="T_29436_row20_col1" class="data row20 col1" >16826249.530000</td>
#     </tr>
#     <tr>
#       <th id="T_29436_level0_row21" class="row_heading level0 row21" >106</th>
#       <td id="T_29436_row21_col0" class="data row21 col0" >Whittier</td>
#       <td id="T_29436_row21_col1" class="data row21 col1" >15947996.940000</td>
#     </tr>
#     <tr>
#       <th id="T_29436_level0_row22" class="row_heading level0 row22" >23</th>
#       <td id="T_29436_row22_col0" class="data row22 col0" >Culver City</td>
#       <td id="T_29436_row22_col1" class="data row22 col1" >15415007.260000</td>
#     </tr>
#     <tr>
#       <th id="T_29436_level0_row23" class="row_heading level0 row23" >67</th>
#       <td id="T_29436_row23_col0" class="data row23 col0" >Pico Rivera</td>
#       <td id="T_29436_row23_col1" class="data row23 col1" >14906201.920000</td>
#     </tr>
#     <tr>
#       <th id="T_29436_level0_row24" class="row_heading level0 row24" >89</th>
#       <td id="T_29436_row24_col0" class="data row24 col0" >South Coast Area Transit</td>
#       <td id="T_29436_row24_col1" class="data row24 col1" >14766238.000000</td>
#     </tr>
#     <tr>
#       <th id="T_29436_level0_row25" class="row_heading level0 row25" >101</th>
#       <td id="T_29436_row25_col0" class="data row25 col0" >Ventura County Transportation Commission</td>
#       <td id="T_29436_row25_col1" class="data row25 col1" >14008538.630000</td>
#     </tr>
#     <tr>
#       <th id="T_29436_level0_row26" class="row_heading level0 row26" >91</th>
#       <td id="T_29436_row26_col0" class="data row26 col0" >South Gate</td>
#       <td id="T_29436_row26_col1" class="data row26 col1" >13962908.210000</td>
#     </tr>
#     <tr>
#       <th id="T_29436_level0_row27" class="row_heading level0 row27" >30</th>
#       <td id="T_29436_row27_col0" class="data row27 col0" >Glendale</td>
#       <td id="T_29436_row27_col1" class="data row27 col1" >13197788.280000</td>
#     </tr>
#     <tr>
#       <th id="T_29436_level0_row28" class="row_heading level0 row28" >60</th>
#       <td id="T_29436_row28_col0" class="data row28 col0" >Norwalk</td>
#       <td id="T_29436_row28_col1" class="data row28 col1" >11762143.670000</td>
#     </tr>
#     <tr>
#       <th id="T_29436_level0_row29" class="row_heading level0 row29" >37</th>
#       <td id="T_29436_row29_col0" class="data row29 col0" >Inglewood</td>
#       <td id="T_29436_row29_col1" class="data row29 col1" >11427517.530000</td>
#     </tr>
#     <tr>
#       <th id="T_29436_level

# %%
#test['Total Funds'] = test['Total Funds'].map('${:,.2f}'.format)

# %%
test.style.format(precision=2, na_rep='MISSING', thousands=",")
# Out:
# <style type="text/css">
# </style>
# <table id="T_c5b65_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Primary Agency Name</th>
#       <th class="col_heading level0 col1" >Total Funds</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5b65_level0_row0" class="row_heading level0 row0" >14</th>
#       <td id="T_c5b65_row0_col0" class="data row0 col0" >Caltrans</td>
#       <td id="T_c5b65_row0_col1" class="data row0 col1" >3,632,937,185.67</td>
#     </tr>
#     <tr>
#       <th id="T_c5b65_level0_row1" class="row_heading level0 row1" >50</th>
#       <td id="T_c5b65_row1_col0" class="data row1 col0" >Los Angeles County Metropolitan Transportation Authority</td>
#       <td id="T_c5b65_row1_col1" class="data row1 col1" >1,441,826,242.94</td>
#     </tr>
#     <tr>
#       <th id="T_c5b65_level0_row2" class="row_heading level0 row2" >48</th>
#       <td id="T_c5b65_row2_col0" class="data row2 col0" >Los Angeles</td>
#       <td id="T_c5b65_row2_col1" class="data row2 col1" >777,759,360.65</td>
#     </tr>
#     <tr>
#       <th id="T_c5b65_level0_row3" class="row_heading level0 row3" >0</th>
#       <td id="T_c5b65_row3_col0" class="data row3 col0" >Access Services</td>
#       <td id="T_c5b65_row3_col1" class="data row3 col1" >561,182,617.00</td>
#     </tr>
#     <tr>
#       <th id="T_c5b65_level0_row4" class="row_heading level0 row4" >46</th>
#       <td id="T_c5b65_row4_col0" class="data row4 col0" >Long Beach</td>
#       <td id="T_c5b65_row4_col1" class="data row4 col1" >386,474,097.64</td>
#     </tr>
#     <tr>
#       <th id="T_c5b65_level0_row5" class="row_heading level0 row5" >49</th>
#       <td id="T_c5b65_row5_col0" class="data row5 col0" >Los Angeles County</td>
#       <td id="T_c5b65_row5_col1" class="data row5 col1" >192,452,850.83</td>
#     </tr>
#     <tr>
#       <th id="T_c5b65_level0_row6" class="row_heading level0 row6" >79</th>
#       <td id="T_c5b65_row6_col0" class="data row6 col0" >San Gabriel Valley Council of Governments</td>
#       <td id="T_c5b65_row6_col1" class="data row6 col1" >48,552,755.85</td>
#     </tr>
#     <tr>
#       <th id="T_c5b65_level0_row7" class="row_heading level0 row7" >83</th>
#       <td id="T_c5b65_row7_col0" class="data row7 col0" >Santa Monica</td>
#       <td id="T_c5b65_row7_col1" class="data row7 col1" >45,649,754.70</td>
#     </tr>
#     <tr>
#       <th id="T_c5b65_level0_row8" class="row_heading level0 row8" >66</th>
#       <td id="T_c5b65_row8_col0" class="data row8 col0" >Pasadena</td>
#       <td id="T_c5b65_row8_col1" class="data row8 col1" >41,592,589.15</td>
#     </tr>
#     <tr>
#       <th id="T_c5b65_level0_row9" class="row_heading level0 row9" >81</th>
#       <td id="T_c5b65_row9_col0" class="data row9 col0" >Santa Clarita</td>
#       <td id="T_c5b65_row9_col1" class="data row9 col1" >40,362,443.14</td>
#     </tr>
#     <tr>
#       <th id="T_c5b65_level0_row10" class="row_heading level0 row10" >44</th>
#       <td id="T_c5b65_row10_col0" class="data row10 col0" >Lancaster</td>
#       <td id="T_c5b65_row10_col1" class="data row10 col1" >33,095,158.25</td>
#     </tr>
#     <tr>
#       <th id="T_c5b65_level0_row11" class="row_heading level0 row11" >95</th>
#       <td id="T_c5b65_row11_col0" class="data row11 col0" >Sunline Transit Agency</td>
#       <td id="T_c5b65_row11_col1" class="data row11 col1" >32,358,158.46</td>
#     </tr>
#     <tr>
#       <th id="T_c5b65_level0_row12" class="row_heading level0 row12" >25</th>
#       <td id="T_c5b65_row12_col0" class="data row12 col0" >Downey</td>
#       <td id="T_c5b65_row12_col1" class="data row12 col1" >27,766,595.83</td>
#     </tr>
#     <tr>
#       <th id="T_c5b65_level0_row13" class="row_heading level0 row13" >94</th>
#       <td id="T_c5b65_row13_col0" class="data row13 col0" >Southern California Regional Rail Authority</td>
#       <td id="T_c5b65_row13_col1" class="data row13 col1" >25,900,300.00</td>
#     </tr>
#     <tr>
#       <th id="T_c5b65_level0_row14" class="row_heading level0 row14" >100</th>
#       <td id="T_c5b65_row14_col0" class="data row14 col0" >Ventura County</td>
#       <td id="T_c5b65_row14_col1" class="data row14 col1" >24,949,254.55</td>
#     </tr>
#     <tr>
#       <th id="T_c5b65_level0_row15" class="row_heading level0 row15" >63</th>
#       <td id="T_c5b65_row15_col0" class="data row15 col0" >Palmdale</td>
#       <td id="T_c5b65_row15_col1" class="data row15 col1" >21,728,242.15</td>
#     </tr>
#     <tr>
#       <th id="T_c5b65_level0_row16" class="row_heading level0 row16" >97</th>
#       <td id="T_c5b65_row16_col0" class="data row16 col0" >Thousand Oaks</td>
#       <td id="T_c5b65_row16_col1" class="data row16 col1" >19,703,189.11</td>
#     </tr>
#     <tr>
#       <th id="T_c5b65_level0_row17" class="row_heading level0 row17" >36</th>
#       <td id="T_c5b65_row17_col0" class="data row17 col0" >Industry</td>
#       <td id="T_c5b65_row17_col1" class="data row17 col1" >18,972,549.00</td>
#     </tr>
#     <tr>
#       <th id="T_c5b65_level0_row18" class="row_heading level0 row18" >98</th>
#       <td id="T_c5b65_row18_col0" class="data row18 col0" >Torrance</td>
#       <td id="T_c5b65_row18_col1" class="data row18 col1" >17,300,912.83</td>
#     </tr>
#     <tr>
#       <th id="T_c5b65_level0_row19" class="row_heading level0 row19" >87</th>
#       <td id="T_c5b65_row19_col0" class="data row19 col0" >Simi Valley</td>
#       <td id="T_c5b65_row19_col1" class="data row19 col1" >17,164,221.05</td>
#     </tr>
#     <tr>
#       <th id="T_c5b65_level0_row20" class="row_heading level0 row20" >54</th>
#       <td id="T_c5b65_row20_col0" class="data row20 col0" >Manhattan Beach</td>
#       <td id="T_c5b65_row20_col1" class="data row20 col1" >16,826,249.53</td>
#     </tr>
#     <tr>
#       <th id="T_c5b65_level0_row21" class="row_heading level0 row21" >106</th>
#       <td id="T_c5b65_row21_col0" class="data row21 col0" >Whittier</td>
#       <td id="T_c5b65_row21_col1" class="data row21 col1" >15,947,996.94</td>
#     </tr>
#     <tr>
#       <th id="T_c5b65_level0_row22" class="row_heading level0 row22" >23</th>
#       <td id="T_c5b65_row22_col0" class="data row22 col0" >Culver City</td>
#       <td id="T_c5b65_row22_col1" class="data row22 col1" >15,415,007.26</td>
#     </tr>
#     <tr>
#       <th id="T_c5b65_level0_row23" class="row_heading level0 row23" >67</th>
#       <td id="T_c5b65_row23_col0" class="data row23 col0" >Pico Rivera</td>
#       <td id="T_c5b65_row23_col1" class="data row23 col1" >14,906,201.92</td>
#     </tr>
#     <tr>
#       <th id="T_c5b65_level0_row24" class="row_heading level0 row24" >89</th>
#       <td id="T_c5b65_row24_col0" class="data row24 col0" >South Coast Area Transit</td>
#       <td id="T_c5b65_row24_col1" class="data row24 col1" >14,766,238.00</td>
#     </tr>
#     <tr>
#       <th id="T_c5b65_level0_row25" class="row_heading level0 row25" >101</th>
#       <td id="T_c5b65_row25_col0" class="data row25 col0" >Ventura County Transportation Commission</td>
#       <td id="T_c5b65_row25_col1" class="data row25 col1" >14,008,538.63</td>
#     </tr>
#     <tr>
#       <th id="T_c5b65_level0_row26" class="row_heading level0 row26" >91</th>
#       <td id="T_c5b65_row26_col0" class="data row26 col0" >South Gate</td>
#       <td id="T_c5b65_row26_col1" class="data row26 col1" >13,962,908.21</td>
#     </tr>
#     <tr>
#       <th id="T_c5b65_level0_row27" class="row_heading level0 row27" >30</th>
#       <td id="T_c5b65_row27_col0" class="data row27 col0" >Glendale</td>
#       <td id="T_c5b65_row27_col1" class="data row27 col1" >13,197,788.28</td>
#     </tr>
#     <tr>
#       <th id="T_c5b65_level0_row28" class="row_heading level0 row28" >60</th>
#       <td id="T_c5b65_row28_col0" class="data row28 col0" >Norwalk</td>
#       <td id="T_c5b65_row28_col1" class="data row28 col1" >11,762,143.67</td>
#     </tr>
#     <tr>
#       <th id="T_c5b65_level0_row29" class="row_heading level0 row29" >37</th>
#       <td id="T_c5b65_row29_col0" class="data row29 col0" >Inglewood</td>
#       <td id="T_c5b65_row29_col1" class="data row29 col1" >11,427,517.53</td>
#     </tr>
#     <tr>
#       <th id="T_c5b65_level0_row30" class="row_heading level0 row30" >75</th>
#       <

# %%
test.style.set_caption('District 7 Agencies with the most Obligation Amounts')
# Out:
# <style type="text/css">
# </style>
# <table id="T_7944f_">
#   <caption>District 7 Agencies with the most Obligation Amounts</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Primary Agency Name</th>
#       <th class="col_heading level0 col1" >Total Funds</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7944f_level0_row0" class="row_heading level0 row0" >14</th>
#       <td id="T_7944f_row0_col0" class="data row0 col0" >Caltrans</td>
#       <td id="T_7944f_row0_col1" class="data row0 col1" >3632937185.670000</td>
#     </tr>
#     <tr>
#       <th id="T_7944f_level0_row1" class="row_heading level0 row1" >50</th>
#       <td id="T_7944f_row1_col0" class="data row1 col0" >Los Angeles County Metropolitan Transportation Authority</td>
#       <td id="T_7944f_row1_col1" class="data row1 col1" >1441826242.940000</td>
#     </tr>
#     <tr>
#       <th id="T_7944f_level0_row2" class="row_heading level0 row2" >48</th>
#       <td id="T_7944f_row2_col0" class="data row2 col0" >Los Angeles</td>
#       <td id="T_7944f_row2_col1" class="data row2 col1" >777759360.650000</td>
#     </tr>
#     <tr>
#       <th id="T_7944f_level0_row3" class="row_heading level0 row3" >0</th>
#       <td id="T_7944f_row3_col0" class="data row3 col0" >Access Services</td>
#       <td id="T_7944f_row3_col1" class="data row3 col1" >561182617.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7944f_level0_row4" class="row_heading level0 row4" >46</th>
#       <td id="T_7944f_row4_col0" class="data row4 col0" >Long Beach</td>
#       <td id="T_7944f_row4_col1" class="data row4 col1" >386474097.640000</td>
#     </tr>
#     <tr>
#       <th id="T_7944f_level0_row5" class="row_heading level0 row5" >49</th>
#       <td id="T_7944f_row5_col0" class="data row5 col0" >Los Angeles County</td>
#       <td id="T_7944f_row5_col1" class="data row5 col1" >192452850.830000</td>
#     </tr>
#     <tr>
#       <th id="T_7944f_level0_row6" class="row_heading level0 row6" >79</th>
#       <td id="T_7944f_row6_col0" class="data row6 col0" >San Gabriel Valley Council of Governments</td>
#       <td id="T_7944f_row6_col1" class="data row6 col1" >48552755.850000</td>
#     </tr>
#     <tr>
#       <th id="T_7944f_level0_row7" class="row_heading level0 row7" >83</th>
#       <td id="T_7944f_row7_col0" class="data row7 col0" >Santa Monica</td>
#       <td id="T_7944f_row7_col1" class="data row7 col1" >45649754.700000</td>
#     </tr>
#     <tr>
#       <th id="T_7944f_level0_row8" class="row_heading level0 row8" >66</th>
#       <td id="T_7944f_row8_col0" class="data row8 col0" >Pasadena</td>
#       <td id="T_7944f_row8_col1" class="data row8 col1" >41592589.150000</td>
#     </tr>
#     <tr>
#       <th id="T_7944f_level0_row9" class="row_heading level0 row9" >81</th>
#       <td id="T_7944f_row9_col0" class="data row9 col0" >Santa Clarita</td>
#       <td id="T_7944f_row9_col1" class="data row9 col1" >40362443.140000</td>
#     </tr>
#     <tr>
#       <th id="T_7944f_level0_row10" class="row_heading level0 row10" >44</th>
#       <td id="T_7944f_row10_col0" class="data row10 col0" >Lancaster</td>
#       <td id="T_7944f_row10_col1" class="data row10 col1" >33095158.250000</td>
#     </tr>
#     <tr>
#       <th id="T_7944f_level0_row11" class="row_heading level0 row11" >95</th>
#       <td id="T_7944f_row11_col0" class="data row11 col0" >Sunline Transit Agency</td>
#       <td id="T_7944f_row11_col1" class="data row11 col1" >32358158.460000</td>
#     </tr>
#     <tr>
#       <th id="T_7944f_level0_row12" class="row_heading level0 row12" >25</th>
#       <td id="T_7944f_row12_col0" class="data row12 col0" >Downey</td>
#       <td id="T_7944f_row12_col1" class="data row12 col1" >27766595.830000</td>
#     </tr>
#     <tr>
#       <th id="T_7944f_level0_row13" class="row_heading level0 row13" >94</th>
#       <td id="T_7944f_row13_col0" class="data row13 col0" >Southern California Regional Rail Authority</td>
#       <td id="T_7944f_row13_col1" class="data row13 col1" >25900300.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7944f_level0_row14" class="row_heading level0 row14" >100</th>
#       <td id="T_7944f_row14_col0" class="data row14 col0" >Ventura County</td>
#       <td id="T_7944f_row14_col1" class="data row14 col1" >24949254.550000</td>
#     </tr>
#     <tr>
#       <th id="T_7944f_level0_row15" class="row_heading level0 row15" >63</th>
#       <td id="T_7944f_row15_col0" class="data row15 col0" >Palmdale</td>
#       <td id="T_7944f_row15_col1" class="data row15 col1" >21728242.150000</td>
#     </tr>
#     <tr>
#       <th id="T_7944f_level0_row16" class="row_heading level0 row16" >97</th>
#       <td id="T_7944f_row16_col0" class="data row16 col0" >Thousand Oaks</td>
#       <td id="T_7944f_row16_col1" class="data row16 col1" >19703189.110000</td>
#     </tr>
#     <tr>
#       <th id="T_7944f_level0_row17" class="row_heading level0 row17" >36</th>
#       <td id="T_7944f_row17_col0" class="data row17 col0" >Industry</td>
#       <td id="T_7944f_row17_col1" class="data row17 col1" >18972549.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7944f_level0_row18" class="row_heading level0 row18" >98</th>
#       <td id="T_7944f_row18_col0" class="data row18 col0" >Torrance</td>
#       <td id="T_7944f_row18_col1" class="data row18 col1" >17300912.830000</td>
#     </tr>
#     <tr>
#       <th id="T_7944f_level0_row19" class="row_heading level0 row19" >87</th>
#       <td id="T_7944f_row19_col0" class="data row19 col0" >Simi Valley</td>
#       <td id="T_7944f_row19_col1" class="data row19 col1" >17164221.050000</td>
#     </tr>
#     <tr>
#       <th id="T_7944f_level0_row20" class="row_heading level0 row20" >54</th>
#       <td id="T_7944f_row20_col0" class="data row20 col0" >Manhattan Beach</td>
#       <td id="T_7944f_row20_col1" class="data row20 col1" >16826249.530000</td>
#     </tr>
#     <tr>
#       <th id="T_7944f_level0_row21" class="row_heading level0 row21" >106</th>
#       <td id="T_7944f_row21_col0" class="data row21 col0" >Whittier</td>
#       <td id="T_7944f_row21_col1" class="data row21 col1" >15947996.940000</td>
#     </tr>
#     <tr>
#       <th id="T_7944f_level0_row22" class="row_heading level0 row22" >23</th>
#       <td id="T_7944f_row22_col0" class="data row22 col0" >Culver City</td>
#       <td id="T_7944f_row22_col1" class="data row22 col1" >15415007.260000</td>
#     </tr>
#     <tr>
#       <th id="T_7944f_level0_row23" class="row_heading level0 row23" >67</th>
#       <td id="T_7944f_row23_col0" class="data row23 col0" >Pico Rivera</td>
#       <td id="T_7944f_row23_col1" class="data row23 col1" >14906201.920000</td>
#     </tr>
#     <tr>
#       <th id="T_7944f_level0_row24" class="row_heading level0 row24" >89</th>
#       <td id="T_7944f_row24_col0" class="data row24 col0" >South Coast Area Transit</td>
#       <td id="T_7944f_row24_col1" class="data row24 col1" >14766238.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7944f_level0_row25" class="row_heading level0 row25" >101</th>
#       <td id="T_7944f_row25_col0" class="data row25 col0" >Ventura County Transportation Commission</td>
#       <td id="T_7944f_row25_col1" class="data row25 col1" >14008538.630000</td>
#     </tr>
#     <tr>
#       <th id="T_7944f_level0_row26" class="row_heading level0 row26" >91</th>
#       <td id="T_7944f_row26_col0" class="data row26 col0" >South Gate</td>
#       <td id="T_7944f_row26_col1" class="data row26 col1" >13962908.210000</td>
#     </tr>
#     <tr>
#       <th id="T_7944f_level0_row27" class="row_heading level0 row27" >30</th>
#       <td id="T_7944f_row27_col0" class="data row27 col0" >Glendale</td>
#       <td id="T_7944f_row27_col1" class="data row27 col1" >13197788.280000</td>
#     </tr>
#     <tr>
#       <th id="T_7944f_level0_row28" class="row_heading level0 row28" >60</th>
#       <td id="T_7944f_row28_col0" class="data row28 col0" >Norwalk</td>
#       <td id="T_7944f_row28_col1" class="data row28 col1" >11762143.670000</td>
#     </tr>
#     <tr>
#       <th id="T_7944f_level0_row29" class="row_heading level0 row29" >37</th>
#       <td id="T_7944f_row29_col0" class="data row29 col0" >Inglewood</td>
#       <td id="T_7944f_row29_col1" class="data row29

# %%
chart = (alt.Chart(test.head(20))
         .mark_bar()
         .encode(
             x=alt.X("Primary Agency Name", title="Agency Name"),
             y=alt.Y("Total Funds", title="Total Funds Obligated"),
             #column = "payment:N",
             color = alt.Color("Primary Agency Name", 
                              scale=alt.Scale(
                                  range=altair_utils.FIVETHIRTYEIGHT_DIVERGING_COLORS
                              )
                              )
         )
        .properties( 
                       title="District 7 Agencies with the Most Total Funds Obligated")

)


#chart.save("dist7chart.png")
chart
# Out:
# alt.Chart(...)

# %%
def calculate_sum(df, col, aggfunc="sum"):
    df = (df.groupby("primary_agency_name")
          .agg({col: aggfunc})
          .reset_index()
          .sort_values(col, ascending=False)
         )
    
    return df

shared_utils.geography_utils.aggregate_by_geography(df_test, 
                                                    group_cols=["primary_agency_name"], 
                                                    sum_cols=["fed_requested", "some_other"], nunique_cols=[])

df2 = calculate_sum(df_test, "fed_requested", aggfunc="sum")

test2= (df_test
       >>group_by(_.primary_agency_name)
       >>summarize(Total_fed_Funds = _.fed_requested.sum())
       >>arrange(-_.Total_fed_Funds))
test2.rename(columns={'primary_agency_name': 'Primary Agency Name', 'Total_fed_Funds': 'Total Federal Funds'}, inplace=True)

# %%
test2.style.format(precision=2, na_rep='MISSING', thousands=",")
# Out:
# <style type="text/css">
# </style>
# <table id="T_10e1f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Primary Agency Name</th>
#       <th class="col_heading level0 col1" >Total Federal Funds</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10e1f_level0_row0" class="row_heading level0 row0" >14</th>
#       <td id="T_10e1f_row0_col0" class="data row0 col0" >Caltrans</td>
#       <td id="T_10e1f_row0_col1" class="data row0 col1" >1,036,315,502.69</td>
#     </tr>
#     <tr>
#       <th id="T_10e1f_level0_row1" class="row_heading level0 row1" >50</th>
#       <td id="T_10e1f_row1_col0" class="data row1 col0" >Los Angeles County Metropolitan Transportation Authority</td>
#       <td id="T_10e1f_row1_col1" class="data row1 col1" >945,744,425.18</td>
#     </tr>
#     <tr>
#       <th id="T_10e1f_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_10e1f_row2_col0" class="data row2 col0" >Access Services</td>
#       <td id="T_10e1f_row2_col1" class="data row2 col1" >561,182,617.00</td>
#     </tr>
#     <tr>
#       <th id="T_10e1f_level0_row3" class="row_heading level0 row3" >48</th>
#       <td id="T_10e1f_row3_col0" class="data row3 col0" >Los Angeles</td>
#       <td id="T_10e1f_row3_col1" class="data row3 col1" >540,610,799.85</td>
#     </tr>
#     <tr>
#       <th id="T_10e1f_level0_row4" class="row_heading level0 row4" >49</th>
#       <td id="T_10e1f_row4_col0" class="data row4 col0" >Los Angeles County</td>
#       <td id="T_10e1f_row4_col1" class="data row4 col1" >126,796,237.25</td>
#     </tr>
#     <tr>
#       <th id="T_10e1f_level0_row5" class="row_heading level0 row5" >46</th>
#       <td id="T_10e1f_row5_col0" class="data row5 col0" >Long Beach</td>
#       <td id="T_10e1f_row5_col1" class="data row5 col1" >71,900,830.44</td>
#     </tr>
#     <tr>
#       <th id="T_10e1f_level0_row6" class="row_heading level0 row6" >101</th>
#       <td id="T_10e1f_row6_col0" class="data row6 col0" >Ventura County Transportation Commission</td>
#       <td id="T_10e1f_row6_col1" class="data row6 col1" >35,855,396.56</td>
#     </tr>
#     <tr>
#       <th id="T_10e1f_level0_row7" class="row_heading level0 row7" >95</th>
#       <td id="T_10e1f_row7_col0" class="data row7 col0" >Sunline Transit Agency</td>
#       <td id="T_10e1f_row7_col1" class="data row7 col1" >32,151,844.67</td>
#     </tr>
#     <tr>
#       <th id="T_10e1f_level0_row8" class="row_heading level0 row8" >83</th>
#       <td id="T_10e1f_row8_col0" class="data row8 col0" >Santa Monica</td>
#       <td id="T_10e1f_row8_col1" class="data row8 col1" >29,458,968.28</td>
#     </tr>
#     <tr>
#       <th id="T_10e1f_level0_row9" class="row_heading level0 row9" >81</th>
#       <td id="T_10e1f_row9_col0" class="data row9 col0" >Santa Clarita</td>
#       <td id="T_10e1f_row9_col1" class="data row9 col1" >29,207,795.98</td>
#     </tr>
#     <tr>
#       <th id="T_10e1f_level0_row10" class="row_heading level0 row10" >66</th>
#       <td id="T_10e1f_row10_col0" class="data row10 col0" >Pasadena</td>
#       <td id="T_10e1f_row10_col1" class="data row10 col1" >28,583,452.96</td>
#     </tr>
#     <tr>
#       <th id="T_10e1f_level0_row11" class="row_heading level0 row11" >44</th>
#       <td id="T_10e1f_row11_col0" class="data row11 col0" >Lancaster</td>
#       <td id="T_10e1f_row11_col1" class="data row11 col1" >26,056,387.35</td>
#     </tr>
#     <tr>
#       <th id="T_10e1f_level0_row12" class="row_heading level0 row12" >94</th>
#       <td id="T_10e1f_row12_col0" class="data row12 col0" >Southern California Regional Rail Authority</td>
#       <td id="T_10e1f_row12_col1" class="data row12 col1" >25,900,300.00</td>
#     </tr>
#     <tr>
#       <th id="T_10e1f_level0_row13" class="row_heading level0 row13" >100</th>
#       <td id="T_10e1f_row13_col0" class="data row13 col0" >Ventura County</td>
#       <td id="T_10e1f_row13_col1" class="data row13 col1" >17,992,731.18</td>
#     </tr>
#     <tr>
#       <th id="T_10e1f_level0_row14" class="row_heading level0 row14" >63</th>
#       <td id="T_10e1f_row14_col0" class="data row14 col0" >Palmdale</td>
#       <td id="T_10e1f_row14_col1" class="data row14 col1" >16,333,365.11</td>
#     </tr>
#     <tr>
#       <th id="T_10e1f_level0_row15" class="row_heading level0 row15" >87</th>
#       <td id="T_10e1f_row15_col0" class="data row15 col0" >Simi Valley</td>
#       <td id="T_10e1f_row15_col1" class="data row15 col1" >15,726,036.79</td>
#     </tr>
#     <tr>
#       <th id="T_10e1f_level0_row16" class="row_heading level0 row16" >25</th>
#       <td id="T_10e1f_row16_col0" class="data row16 col0" >Downey</td>
#       <td id="T_10e1f_row16_col1" class="data row16 col1" >15,019,572.22</td>
#     </tr>
#     <tr>
#       <th id="T_10e1f_level0_row17" class="row_heading level0 row17" >89</th>
#       <td id="T_10e1f_row17_col0" class="data row17 col0" >South Coast Area Transit</td>
#       <td id="T_10e1f_row17_col1" class="data row17 col1" >14,766,238.00</td>
#     </tr>
#     <tr>
#       <th id="T_10e1f_level0_row18" class="row_heading level0 row18" >23</th>
#       <td id="T_10e1f_row18_col0" class="data row18 col0" >Culver City</td>
#       <td id="T_10e1f_row18_col1" class="data row18 col1" >13,673,199.39</td>
#     </tr>
#     <tr>
#       <th id="T_10e1f_level0_row19" class="row_heading level0 row19" >60</th>
#       <td id="T_10e1f_row19_col0" class="data row19 col0" >Norwalk</td>
#       <td id="T_10e1f_row19_col1" class="data row19 col1" >11,067,985.00</td>
#     </tr>
#     <tr>
#       <th id="T_10e1f_level0_row20" class="row_heading level0 row20" >98</th>
#       <td id="T_10e1f_row20_col0" class="data row20 col0" >Torrance</td>
#       <td id="T_10e1f_row20_col1" class="data row20 col1" >11,052,284.21</td>
#     </tr>
#     <tr>
#       <th id="T_10e1f_level0_row21" class="row_heading level0 row21" >91</th>
#       <td id="T_10e1f_row21_col0" class="data row21 col0" >South Gate</td>
#       <td id="T_10e1f_row21_col1" class="data row21 col1" >10,860,870.54</td>
#     </tr>
#     <tr>
#       <th id="T_10e1f_level0_row22" class="row_heading level0 row22" >30</th>
#       <td id="T_10e1f_row22_col0" class="data row22 col0" >Glendale</td>
#       <td id="T_10e1f_row22_col1" class="data row22 col1" >10,506,697.78</td>
#     </tr>
#     <tr>
#       <th id="T_10e1f_level0_row23" class="row_heading level0 row23" >36</th>
#       <td id="T_10e1f_row23_col0" class="data row23 col0" >Industry</td>
#       <td id="T_10e1f_row23_col1" class="data row23 col1" >10,289,493.00</td>
#     </tr>
#     <tr>
#       <th id="T_10e1f_level0_row24" class="row_heading level0 row24" >54</th>
#       <td id="T_10e1f_row24_col0" class="data row24 col0" >Manhattan Beach</td>
#       <td id="T_10e1f_row24_col1" class="data row24 col1" >9,514,914.99</td>
#     </tr>
#     <tr>
#       <th id="T_10e1f_level0_row25" class="row_heading level0 row25" >106</th>
#       <td id="T_10e1f_row25_col0" class="data row25 col0" >Whittier</td>
#       <td id="T_10e1f_row25_col1" class="data row25 col1" >9,475,260.50</td>
#     </tr>
#     <tr>
#       <th id="T_10e1f_level0_row26" class="row_heading level0 row26" >97</th>
#       <td id="T_10e1f_row26_col0" class="data row26 col0" >Thousand Oaks</td>
#       <td id="T_10e1f_row26_col1" class="data row26 col1" >8,991,233.79</td>
#     </tr>
#     <tr>
#       <th id="T_10e1f_level0_row27" class="row_heading level0 row27" >67</th>
#       <td id="T_10e1f_row27_col0" class="data row27 col0" >Pico Rivera</td>
#       <td id="T_10e1f_row27_col1" class="data row27 col1" >8,822,049.54</td>
#     </tr>
#     <tr>
#       <th id="T_10e1f_level0_row28" class="row_heading level0 row28" >62</th>
#       <td id="T_10e1f_row28_col0" class="data row28 col0" >Oxnard</td>
#       <td id="T_10e1f_row28_col1" class="data row28 col1" >8,736,923.80</td>
#     </tr>
#     <tr>
#       <th id="T_10e1f_level0_row29" class="row_heading level0 row29" >78</th>
#       <td id="T_10e1f_row29_col0" class="data row29 col0" >San Gabriel</td>
#       <td id="T_10e1f_row29_col1" class="data row29 col1" >8,079,532.27</td>
#     </tr>
#     <tr>
#       <th id="T_10e1f_level0_row30" class="row_heading level0 row30" >75</th>
#       <td id="T_10e1f_row30_col0" class="

# %%
test3= (df_test
       >>group_by(_.primary_agency_name)
       >>summarize(Total_ac_Funds = _.ac_requested.sum())
       >>arrange(-_.Total_ac_Funds))
test3.rename(columns={'primary_agency_name': 'Primary Agency Name', 'Total_ac_Funds': 'Total Advance Construction Funds'}, inplace=True)

# %%
test3.style.format(precision=2, na_rep='MISSING', thousands=",")
# Out:
# <style type="text/css">
# </style>
# <table id="T_03975_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Primary Agency Name</th>
#       <th class="col_heading level0 col1" >Total Advance Construction Funds</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03975_level0_row0" class="row_heading level0 row0" >14</th>
#       <td id="T_03975_row0_col0" class="data row0 col0" >Caltrans</td>
#       <td id="T_03975_row0_col1" class="data row0 col1" >939,055,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_03975_level0_row1" class="row_heading level0 row1" >48</th>
#       <td id="T_03975_row1_col0" class="data row1 col0" >Los Angeles</td>
#       <td id="T_03975_row1_col1" class="data row1 col1" >54,175,401.08</td>
#     </tr>
#     <tr>
#       <th id="T_03975_level0_row2" class="row_heading level0 row2" >49</th>
#       <td id="T_03975_row2_col0" class="data row2 col0" >Los Angeles County</td>
#       <td id="T_03975_row2_col1" class="data row2 col1" >20,415,214.27</td>
#     </tr>
#     <tr>
#       <th id="T_03975_level0_row3" class="row_heading level0 row3" >102</th>
#       <td id="T_03975_row3_col0" class="data row3 col0" >Vernon</td>
#       <td id="T_03975_row3_col1" class="data row3 col1" >3,508,709.00</td>
#     </tr>
#     <tr>
#       <th id="T_03975_level0_row4" class="row_heading level0 row4" >0</th>
#       <td id="T_03975_row4_col0" class="data row4 col0" >Access Services</td>
#       <td id="T_03975_row4_col1" class="data row4 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_03975_level0_row5" class="row_heading level0 row5" >1</th>
#       <td id="T_03975_row5_col0" class="data row5 col0" >Agoura Hills</td>
#       <td id="T_03975_row5_col1" class="data row5 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_03975_level0_row6" class="row_heading level0 row6" >2</th>
#       <td id="T_03975_row6_col0" class="data row6 col0" >Alameda Corridor Transportation Authority</td>
#       <td id="T_03975_row6_col1" class="data row6 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_03975_level0_row7" class="row_heading level0 row7" >3</th>
#       <td id="T_03975_row7_col0" class="data row7 col0" >Alhambra</td>
#       <td id="T_03975_row7_col1" class="data row7 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_03975_level0_row8" class="row_heading level0 row8" >4</th>
#       <td id="T_03975_row8_col0" class="data row8 col0" >Antelope Valley Transit Authority</td>
#       <td id="T_03975_row8_col1" class="data row8 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_03975_level0_row9" class="row_heading level0 row9" >5</th>
#       <td id="T_03975_row9_col0" class="data row9 col0" >Arcadia</td>
#       <td id="T_03975_row9_col1" class="data row9 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_03975_level0_row10" class="row_heading level0 row10" >6</th>
#       <td id="T_03975_row10_col0" class="data row10 col0" >Artesia</td>
#       <td id="T_03975_row10_col1" class="data row10 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_03975_level0_row11" class="row_heading level0 row11" >7</th>
#       <td id="T_03975_row11_col0" class="data row11 col0" >Azusa</td>
#       <td id="T_03975_row11_col1" class="data row11 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_03975_level0_row12" class="row_heading level0 row12" >8</th>
#       <td id="T_03975_row12_col0" class="data row12 col0" >Baldwin Park</td>
#       <td id="T_03975_row12_col1" class="data row12 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_03975_level0_row13" class="row_heading level0 row13" >9</th>
#       <td id="T_03975_row13_col0" class="data row13 col0" >Bell</td>
#       <td id="T_03975_row13_col1" class="data row13 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_03975_level0_row14" class="row_heading level0 row14" >10</th>
#       <td id="T_03975_row14_col0" class="data row14 col0" >Bell Gardens</td>
#       <td id="T_03975_row14_col1" class="data row14 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_03975_level0_row15" class="row_heading level0 row15" >11</th>
#       <td id="T_03975_row15_col0" class="data row15 col0" >Bellflower</td>
#       <td id="T_03975_row15_col1" class="data row15 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_03975_level0_row16" class="row_heading level0 row16" >12</th>
#       <td id="T_03975_row16_col0" class="data row16 col0" >Burbank</td>
#       <td id="T_03975_row16_col1" class="data row16 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_03975_level0_row17" class="row_heading level0 row17" >13</th>
#       <td id="T_03975_row17_col0" class="data row17 col0" >Calabasas</td>
#       <td id="T_03975_row17_col1" class="data row17 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_03975_level0_row18" class="row_heading level0 row18" >15</th>
#       <td id="T_03975_row18_col0" class="data row18 col0" >Camarillo</td>
#       <td id="T_03975_row18_col1" class="data row18 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_03975_level0_row19" class="row_heading level0 row19" >17</th>
#       <td id="T_03975_row19_col0" class="data row19 col0" >Cerritos</td>
#       <td id="T_03975_row19_col1" class="data row19 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_03975_level0_row20" class="row_heading level0 row20" >18</th>
#       <td id="T_03975_row20_col0" class="data row20 col0" >Claremont</td>
#       <td id="T_03975_row20_col1" class="data row20 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_03975_level0_row21" class="row_heading level0 row21" >19</th>
#       <td id="T_03975_row21_col0" class="data row21 col0" >Commerce</td>
#       <td id="T_03975_row21_col1" class="data row21 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_03975_level0_row22" class="row_heading level0 row22" >20</th>
#       <td id="T_03975_row22_col0" class="data row22 col0" >Compton</td>
#       <td id="T_03975_row22_col1" class="data row22 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_03975_level0_row23" class="row_heading level0 row23" >21</th>
#       <td id="T_03975_row23_col0" class="data row23 col0" >Covina</td>
#       <td id="T_03975_row23_col1" class="data row23 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_03975_level0_row24" class="row_heading level0 row24" >22</th>
#       <td id="T_03975_row24_col0" class="data row24 col0" >Cudahy</td>
#       <td id="T_03975_row24_col1" class="data row24 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_03975_level0_row25" class="row_heading level0 row25" >23</th>
#       <td id="T_03975_row25_col0" class="data row25 col0" >Culver City</td>
#       <td id="T_03975_row25_col1" class="data row25 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_03975_level0_row26" class="row_heading level0 row26" >24</th>
#       <td id="T_03975_row26_col0" class="data row26 col0" >Diamond Bar</td>
#       <td id="T_03975_row26_col1" class="data row26 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_03975_level0_row27" class="row_heading level0 row27" >25</th>
#       <td id="T_03975_row27_col0" class="data row27 col0" >Downey</td>
#       <td id="T_03975_row27_col1" class="data row27 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_03975_level0_row28" class="row_heading level0 row28" >26</th>
#       <td id="T_03975_row28_col0" class="data row28 col0" >El Monte</td>
#       <td id="T_03975_row28_col1" class="data row28 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_03975_level0_row29" class="row_heading level0 row29" >27</th>
#       <td id="T_03975_row29_col0" class="data row29 col0" >El Segundo</td>
#       <td id="T_03975_row29_col1" class="data row29 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_03975_level0_row30" class="row_heading level0 row30" >28</th>
#       <td id="T_03975_row30_col0" class="data row30 col0" >Fillmore</td>
#       <td id="T_03975_row30_col1" class="data row30 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_03975_level0_row31" class="row_heading level0 row31" >29</th>
#       <td id="T_03975_row31_col0" class="data row31 col0" >Gardena</td>
#       <td id="T_03975_row31_col1" class="data row31 col1" >0.00</td>
#     </tr>

# %%
len(test2)
# Out:
# 107

# %%
all_sum = full_join(test, test2, on = "Primary Agency Name")

# %%
all_sum2 = full_join(all_sum, test3, on = "Primary Agency Name")

# %%
all_sum3 = full_join(all_sum, test3, on = "Primary Agency Name")

# %%
all_sum3['Totals']= all_sum2['Total Funds']+all_sum2['Total Federal Funds'] +all_sum2['Total Advance Construction Funds']

# %%
all_sum3 = all_sum3>>arrange(-_.Totals)

# %%
all_sum3.style.format(precision=2, na_rep='MISSING', thousands=",")
# Out:
# <style type="text/css">
# </style>
# <table id="T_97b19_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Primary Agency Name</th>
#       <th class="col_heading level0 col1" >Total Funds</th>
#       <th class="col_heading level0 col2" >Total Federal Funds</th>
#       <th class="col_heading level0 col3" >Total Advance Construction Funds</th>
#       <th class="col_heading level0 col4" >Totals</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97b19_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_97b19_row0_col0" class="data row0 col0" >Caltrans</td>
#       <td id="T_97b19_row0_col1" class="data row0 col1" >3,632,937,185.67</td>
#       <td id="T_97b19_row0_col2" class="data row0 col2" >1,036,315,502.69</td>
#       <td id="T_97b19_row0_col3" class="data row0 col3" >939,055,000.00</td>
#       <td id="T_97b19_row0_col4" class="data row0 col4" >5,608,307,688.36</td>
#     </tr>
#     <tr>
#       <th id="T_97b19_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_97b19_row1_col0" class="data row1 col0" >Los Angeles County Metropolitan Transportation Authority</td>
#       <td id="T_97b19_row1_col1" class="data row1 col1" >1,441,826,242.94</td>
#       <td id="T_97b19_row1_col2" class="data row1 col2" >945,744,425.18</td>
#       <td id="T_97b19_row1_col3" class="data row1 col3" >0.00</td>
#       <td id="T_97b19_row1_col4" class="data row1 col4" >2,387,570,668.12</td>
#     </tr>
#     <tr>
#       <th id="T_97b19_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_97b19_row2_col0" class="data row2 col0" >Los Angeles</td>
#       <td id="T_97b19_row2_col1" class="data row2 col1" >777,759,360.65</td>
#       <td id="T_97b19_row2_col2" class="data row2 col2" >540,610,799.85</td>
#       <td id="T_97b19_row2_col3" class="data row2 col3" >54,175,401.08</td>
#       <td id="T_97b19_row2_col4" class="data row2 col4" >1,372,545,561.58</td>
#     </tr>
#     <tr>
#       <th id="T_97b19_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_97b19_row3_col0" class="data row3 col0" >Access Services</td>
#       <td id="T_97b19_row3_col1" class="data row3 col1" >561,182,617.00</td>
#       <td id="T_97b19_row3_col2" class="data row3 col2" >561,182,617.00</td>
#       <td id="T_97b19_row3_col3" class="data row3 col3" >0.00</td>
#       <td id="T_97b19_row3_col4" class="data row3 col4" >1,122,365,234.00</td>
#     </tr>
#     <tr>
#       <th id="T_97b19_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_97b19_row4_col0" class="data row4 col0" >Long Beach</td>
#       <td id="T_97b19_row4_col1" class="data row4 col1" >386,474,097.64</td>
#       <td id="T_97b19_row4_col2" class="data row4 col2" >71,900,830.44</td>
#       <td id="T_97b19_row4_col3" class="data row4 col3" >0.00</td>
#       <td id="T_97b19_row4_col4" class="data row4 col4" >458,374,928.08</td>
#     </tr>
#     <tr>
#       <th id="T_97b19_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_97b19_row5_col0" class="data row5 col0" >Los Angeles County</td>
#       <td id="T_97b19_row5_col1" class="data row5 col1" >192,452,850.83</td>
#       <td id="T_97b19_row5_col2" class="data row5 col2" >126,796,237.25</td>
#       <td id="T_97b19_row5_col3" class="data row5 col3" >20,415,214.27</td>
#       <td id="T_97b19_row5_col4" class="data row5 col4" >339,664,302.35</td>
#     </tr>
#     <tr>
#       <th id="T_97b19_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_97b19_row6_col0" class="data row6 col0" >Santa Monica</td>
#       <td id="T_97b19_row6_col1" class="data row6 col1" >45,649,754.70</td>
#       <td id="T_97b19_row6_col2" class="data row6 col2" >29,458,968.28</td>
#       <td id="T_97b19_row6_col3" class="data row6 col3" >-1,543,000.00</td>
#       <td id="T_97b19_row6_col4" class="data row6 col4" >73,565,722.98</td>
#     </tr>
#     <tr>
#       <th id="T_97b19_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_97b19_row7_col0" class="data row7 col0" >Pasadena</td>
#       <td id="T_97b19_row7_col1" class="data row7 col1" >41,592,589.15</td>
#       <td id="T_97b19_row7_col2" class="data row7 col2" >28,583,452.96</td>
#       <td id="T_97b19_row7_col3" class="data row7 col3" >0.00</td>
#       <td id="T_97b19_row7_col4" class="data row7 col4" >70,176,042.11</td>
#     </tr>
#     <tr>
#       <th id="T_97b19_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_97b19_row8_col0" class="data row8 col0" >Santa Clarita</td>
#       <td id="T_97b19_row8_col1" class="data row8 col1" >40,362,443.14</td>
#       <td id="T_97b19_row8_col2" class="data row8 col2" >29,207,795.98</td>
#       <td id="T_97b19_row8_col3" class="data row8 col3" >0.00</td>
#       <td id="T_97b19_row8_col4" class="data row8 col4" >69,570,239.12</td>
#     </tr>
#     <tr>
#       <th id="T_97b19_level0_row9" class="row_heading level0 row9" >11</th>
#       <td id="T_97b19_row9_col0" class="data row9 col0" >Sunline Transit Agency</td>
#       <td id="T_97b19_row9_col1" class="data row9 col1" >32,358,158.46</td>
#       <td id="T_97b19_row9_col2" class="data row9 col2" >32,151,844.67</td>
#       <td id="T_97b19_row9_col3" class="data row9 col3" >0.00</td>
#       <td id="T_97b19_row9_col4" class="data row9 col4" >64,510,003.13</td>
#     </tr>
#     <tr>
#       <th id="T_97b19_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_97b19_row10_col0" class="data row10 col0" >Lancaster</td>
#       <td id="T_97b19_row10_col1" class="data row10 col1" >33,095,158.25</td>
#       <td id="T_97b19_row10_col2" class="data row10 col2" >26,056,387.35</td>
#       <td id="T_97b19_row10_col3" class="data row10 col3" >0.00</td>
#       <td id="T_97b19_row10_col4" class="data row10 col4" >59,151,545.60</td>
#     </tr>
#     <tr>
#       <th id="T_97b19_level0_row11" class="row_heading level0 row11" >6</th>
#       <td id="T_97b19_row11_col0" class="data row11 col0" >San Gabriel Valley Council of Governments</td>
#       <td id="T_97b19_row11_col1" class="data row11 col1" >48,552,755.85</td>
#       <td id="T_97b19_row11_col2" class="data row11 col2" >6,482,174.74</td>
#       <td id="T_97b19_row11_col3" class="data row11 col3" >-315,303.00</td>
#       <td id="T_97b19_row11_col4" class="data row11 col4" >54,719,627.59</td>
#     </tr>
#     <tr>
#       <th id="T_97b19_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_97b19_row12_col0" class="data row12 col0" >Southern California Regional Rail Authority</td>
#       <td id="T_97b19_row12_col1" class="data row12 col1" >25,900,300.00</td>
#       <td id="T_97b19_row12_col2" class="data row12 col2" >25,900,300.00</td>
#       <td id="T_97b19_row12_col3" class="data row12 col3" >0.00</td>
#       <td id="T_97b19_row12_col4" class="data row12 col4" >51,800,600.00</td>
#     </tr>
#     <tr>
#       <th id="T_97b19_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_97b19_row13_col0" class="data row13 col0" >Ventura County</td>
#       <td id="T_97b19_row13_col1" class="data row13 col1" >24,949,254.55</td>
#       <td id="T_97b19_row13_col2" class="data row13 col2" >17,992,731.18</td>
#       <td id="T_97b19_row13_col3" class="data row13 col3" >0.00</td>
#       <td id="T_97b19_row13_col4" class="data row13 col4" >42,941,985.73</td>
#     </tr>
#     <tr>
#       <th id="T_97b19_level0_row14" class="row_heading level0 row14" >12</th>
#       <td id="T_97b19_row14_col0" class="data row14 col0" >Downey</td>
#       <td id="T_97b19_row14_col1" class="data row14 col1" >27,766,595.83</td>
#       <td id="T_97b19_row14_col2" class="data row14 col2" >15,019,572.22</td>
#       <td id="T_97b19_row14_col3" class="data row14 col3" >0.00</td>
#       <td id="T_97b19_row14_col4" class="data row14 col4" >42,786,168.05</td>
#     </tr>
#     <tr>
#       <th id="T_97b19_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_97b19_row15_col0" class="data row15 col0" >Palmdale</td>
#       <td id="T_97b19_row15_col1" class="data row15 col1" >21,728,242.15</td>
#       <td id="T_97b19_row15_col2" class="data row15 col2" >16,333,365.11</td

# %%
all_sum2.style.format(precision=2, na_rep='MISSING', thousands=",")
# Out:
# <style type="text/css">
# </style>
# <table id="T_2703d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Primary Agency Name</th>
#       <th class="col_heading level0 col1" >Total Funds</th>
#       <th class="col_heading level0 col2" >Total Federal Funds</th>
#       <th class="col_heading level0 col3" >Total Advance Construction Funds</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2703d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2703d_row0_col0" class="data row0 col0" >Caltrans</td>
#       <td id="T_2703d_row0_col1" class="data row0 col1" >3,632,937,185.67</td>
#       <td id="T_2703d_row0_col2" class="data row0 col2" >1,036,315,502.69</td>
#       <td id="T_2703d_row0_col3" class="data row0 col3" >939,055,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_2703d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2703d_row1_col0" class="data row1 col0" >Los Angeles County Metropolitan Transportation Authority</td>
#       <td id="T_2703d_row1_col1" class="data row1 col1" >1,441,826,242.94</td>
#       <td id="T_2703d_row1_col2" class="data row1 col2" >945,744,425.18</td>
#       <td id="T_2703d_row1_col3" class="data row1 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_2703d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2703d_row2_col0" class="data row2 col0" >Los Angeles</td>
#       <td id="T_2703d_row2_col1" class="data row2 col1" >777,759,360.65</td>
#       <td id="T_2703d_row2_col2" class="data row2 col2" >540,610,799.85</td>
#       <td id="T_2703d_row2_col3" class="data row2 col3" >54,175,401.08</td>
#     </tr>
#     <tr>
#       <th id="T_2703d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2703d_row3_col0" class="data row3 col0" >Access Services</td>
#       <td id="T_2703d_row3_col1" class="data row3 col1" >561,182,617.00</td>
#       <td id="T_2703d_row3_col2" class="data row3 col2" >561,182,617.00</td>
#       <td id="T_2703d_row3_col3" class="data row3 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_2703d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2703d_row4_col0" class="data row4 col0" >Long Beach</td>
#       <td id="T_2703d_row4_col1" class="data row4 col1" >386,474,097.64</td>
#       <td id="T_2703d_row4_col2" class="data row4 col2" >71,900,830.44</td>
#       <td id="T_2703d_row4_col3" class="data row4 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_2703d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2703d_row5_col0" class="data row5 col0" >Los Angeles County</td>
#       <td id="T_2703d_row5_col1" class="data row5 col1" >192,452,850.83</td>
#       <td id="T_2703d_row5_col2" class="data row5 col2" >126,796,237.25</td>
#       <td id="T_2703d_row5_col3" class="data row5 col3" >20,415,214.27</td>
#     </tr>
#     <tr>
#       <th id="T_2703d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2703d_row6_col0" class="data row6 col0" >San Gabriel Valley Council of Governments</td>
#       <td id="T_2703d_row6_col1" class="data row6 col1" >48,552,755.85</td>
#       <td id="T_2703d_row6_col2" class="data row6 col2" >6,482,174.74</td>
#       <td id="T_2703d_row6_col3" class="data row6 col3" >-315,303.00</td>
#     </tr>
#     <tr>
#       <th id="T_2703d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2703d_row7_col0" class="data row7 col0" >Santa Monica</td>
#       <td id="T_2703d_row7_col1" class="data row7 col1" >45,649,754.70</td>
#       <td id="T_2703d_row7_col2" class="data row7 col2" >29,458,968.28</td>
#       <td id="T_2703d_row7_col3" class="data row7 col3" >-1,543,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_2703d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2703d_row8_col0" class="data row8 col0" >Pasadena</td>
#       <td id="T_2703d_row8_col1" class="data row8 col1" >41,592,589.15</td>
#       <td id="T_2703d_row8_col2" class="data row8 col2" >28,583,452.96</td>
#       <td id="T_2703d_row8_col3" class="data row8 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_2703d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2703d_row9_col0" class="data row9 col0" >Santa Clarita</td>
#       <td id="T_2703d_row9_col1" class="data row9 col1" >40,362,443.14</td>
#       <td id="T_2703d_row9_col2" class="data row9 col2" >29,207,795.98</td>
#       <td id="T_2703d_row9_col3" class="data row9 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_2703d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2703d_row10_col0" class="data row10 col0" >Lancaster</td>
#       <td id="T_2703d_row10_col1" class="data row10 col1" >33,095,158.25</td>
#       <td id="T_2703d_row10_col2" class="data row10 col2" >26,056,387.35</td>
#       <td id="T_2703d_row10_col3" class="data row10 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_2703d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2703d_row11_col0" class="data row11 col0" >Sunline Transit Agency</td>
#       <td id="T_2703d_row11_col1" class="data row11 col1" >32,358,158.46</td>
#       <td id="T_2703d_row11_col2" class="data row11 col2" >32,151,844.67</td>
#       <td id="T_2703d_row11_col3" class="data row11 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_2703d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2703d_row12_col0" class="data row12 col0" >Downey</td>
#       <td id="T_2703d_row12_col1" class="data row12 col1" >27,766,595.83</td>
#       <td id="T_2703d_row12_col2" class="data row12 col2" >15,019,572.22</td>
#       <td id="T_2703d_row12_col3" class="data row12 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_2703d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2703d_row13_col0" class="data row13 col0" >Southern California Regional Rail Authority</td>
#       <td id="T_2703d_row13_col1" class="data row13 col1" >25,900,300.00</td>
#       <td id="T_2703d_row13_col2" class="data row13 col2" >25,900,300.00</td>
#       <td id="T_2703d_row13_col3" class="data row13 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_2703d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_2703d_row14_col0" class="data row14 col0" >Ventura County</td>
#       <td id="T_2703d_row14_col1" class="data row14 col1" >24,949,254.55</td>
#       <td id="T_2703d_row14_col2" class="data row14 col2" >17,992,731.18</td>
#       <td id="T_2703d_row14_col3" class="data row14 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_2703d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_2703d_row15_col0" class="data row15 col0" >Palmdale</td>
#       <td id="T_2703d_row15_col1" class="data row15 col1" >21,728,242.15</td>
#       <td id="T_2703d_row15_col2" class="data row15 col2" >16,333,365.11</td>
#       <td id="T_2703d_row15_col3" class="data row15 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_2703d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_2703d_row16_col0" class="data row16 col0" >Thousand Oaks</td>
#       <td id="T_2703d_row16_col1" class="data row16 col1" >19,703,189.11</td>
#       <td id="T_2703d_row16_col2" class="data row16 col2" >8,991,233.79</td>
#       <td id="T_2703d_row16_col3" class="data row16 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_2703d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_2703d_row17_col0" class="data row17 col0" >Industry</td>
#       <td id="T_2703d_row17_col1" class="data row17 col1" >18,972,549.00</td>
#       <td id="T_2703d_row17_col2" class="data row17 col2" >10,289,493.00</td>
#       <td id="T_2703d_row17_col3" class="data row17 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_2703d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_2703d_row18_col0" class="data row18 col0" >Torrance</td>
#       <td id="T_2703d_row18_col1" class="data row18 col1" >17,300,912.83</td>
#       <td id="T_2703d_row18_col2" class="data row18 col2" >11,052,284.21</td>
#       <td id="T_2703d_row18_

# %%
chart = (alt.Chart(all_sum3.head(20))
         .mark_bar()
         .encode(
             x=alt.X("Primary Agency Name", title="Agency Name"),
             y=alt.Y("Totals", title="Sum of Funds Obligated"),
             #column = "payment:N",
             color = alt.Color("Primary Agency Name", 
                              scale=alt.Scale(
                                  range=altair_utils.FIVETHIRTYEIGHT_DIVERGING_COLORS
                              )
                              )
         )
        .properties( 
                       title="District 7 Agencies with the Highest Sum of Obligated Funds")

)


#chart.save("dist7chart.png")
chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Non-Cities with the most obligations

# %%
topten_noncity =(df_test
 >>filter(_.NAME.isnull())
 >>count(_.primary_agency_name)
 >>arrange(-_.n)).head(10)

# %%
topten_noncity.rename(columns={'primary_agency_name': 'Primary Agency Name', 'n': 'Count'}, inplace=True)

# %%
topten_noncity.style.set_caption('District 7 Agencies with the Most Oblgiations (non-city)')
# Out:
# <style type="text/css">
# </style>
# <table id="T_9189d_">
#   <caption>District 7 Agencies with the Most Oblgiations (non-city)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Primary Agency Name</th>
#       <th class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9189d_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_9189d_row0_col0" class="data row0 col0" >Los Angeles County</td>
#       <td id="T_9189d_row0_col1" class="data row0 col1" >451</td>
#     </tr>
#     <tr>
#       <th id="T_9189d_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_9189d_row1_col0" class="data row1 col0" >Caltrans</td>
#       <td id="T_9189d_row1_col1" class="data row1 col1" >234</td>
#     </tr>
#     <tr>
#       <th id="T_9189d_level0_row2" class="row_heading level0 row2" >18</th>
#       <td id="T_9189d_row2_col0" class="data row2 col0" >Ventura County</td>
#       <td id="T_9189d_row2_col1" class="data row2 col1" >115</td>
#     </tr>
#     <tr>
#       <th id="T_9189d_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T_9189d_row3_col0" class="data row3 col0" >Los Angeles County Metropolitan Transportation Authority</td>
#       <td id="T_9189d_row3_col1" class="data row3 col1" >85</td>
#     </tr>
#     <tr>
#       <th id="T_9189d_level0_row4" class="row_heading level0 row4" >10</th>
#       <td id="T_9189d_row4_col0" class="data row4 col0" >San Buenaventura</td>
#       <td id="T_9189d_row4_col1" class="data row4 col1" >35</td>
#     </tr>
#     <tr>
#       <th id="T_9189d_level0_row5" class="row_heading level0 row5" >19</th>
#       <td id="T_9189d_row5_col0" class="data row5 col0" >Ventura County Transportation Commission</td>
#       <td id="T_9189d_row5_col1" class="data row5 col1" >29</td>
#     </tr>
#     <tr>
#       <th id="T_9189d_level0_row6" class="row_heading level0 row6" >11</th>
#       <td id="T_9189d_row6_col0" class="data row6 col0" >San Gabriel Valley Council of Governments</td>
#       <td id="T_9189d_row6_col1" class="data row6 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_9189d_level0_row7" class="row_heading level0 row7" >0</th>
#       <td id="T_9189d_row7_col0" class="data row7 col0" >Access Services</td>
#       <td id="T_9189d_row7_col1" class="data row7 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_9189d_level0_row8" class="row_heading level0 row8" >14</th>
#       <td id="T_9189d_row8_col0" class="data row8 col0" >Southern California Association of Governments</td>
#       <td id="T_9189d_row8_col1" class="data row8 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_9189d_level0_row9" class="row_heading level0 row9" >13</th>
#       <td id="T_9189d_row9_col0" class="data row9 col0" >South Coast Area Transit</td>
#       <td id="T_9189d_row9_col1" class="data row9 col1" >7</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## OLD Which Agencies have Obligations

# %% [markdown]
# ### How many Unique Agencies

# %%
len(la_df>>count(_.primary_agency_name))
# Out:
# 107

# %% [markdown]
# ### Agencies with the most Obligations

# %%
(la_df>>count(_.primary_agency_name)>>arrange(-_.n)).head(10)
# Out:
#                                    primary_agency_name    n
# 48                                         Los Angeles  490
# 49                                  Los Angeles County  451
# 100                                     Ventura County  115
# 50   Los Angeles County Metropolitan Transportation...   85
# 81                                       Santa Clarita   85
# 46                                          Long Beach   81
# 62                                              Oxnard   74
# 66                                            Pasadena   71
# 25                                              Downey   63
# 87                                         Simi Valley   61

# %% [markdown]
# ### Agencies with the least Obligations

# %%
(la_df>>count(_.primary_agency_name)>>arrange(-_.n)).tail(10)
# Out:
#                               primary_agency_name  n
# 64                               Palos Verdes Est  2
# 70                             Port Of Long Beach  2
# 85                                   Sierra Madre  2
# 2       Alameda Corridor Transportation Authority  1
# 4               Antelope Valley Transit Authority  1
# 34                                  Hermosa Beach  1
# 35                                Huntington Park  1
# 69                                   Port Hueneme  1
# 73                          Rolling Hills Estates  1
# 99  U.S. Forest Service, Pacific Southwest Region  1

# %% [markdown]
# ### Charting

# %%
la_df_count = (la_df>>count(_.primary_agency_name)>>arrange(-_.n))

# %%
la_df_count.sample()
# Out:
#    primary_agency_name  n
# 45            Lawndale  3

# %%
chart = (alt.Chart(la_df_count)
         .mark_bar()
         .encode(
             x=alt.X("primary_agency_name", title="Agency Name"),
             y=alt.Y("n", title="Number of Obligations"),
             #column = "payment:N",
             color = alt.Color("n", 
                              scale=alt.Scale(
                                  range=altair_utils.FIVETHIRTYEIGHT_DIVERGING_COLORS
                              )
                              )
         )
        .properties( 
                       title="Number of Unique Prefixes by Agency in District 7")

)


#chart.save("dist7chart.png")
chart
# Out:
# alt.Chart(...)

# %%
la_df.sample()
# Out:
#      location prefix project_no      agency prepared_date submit__to_hq_date  \
# 44  Obligated  HSIPL  5108(178)  Long Beach    2018-12-11         2018-12-11
#
#    hq_review_date submit_to_fhwa_date to_fmis_date  fed_requested  \
# 44     2018-12-13          2018-12-14   2018-12-19       166500.0
#
#     ac_requested  total_requested status_comment locode  dist  \
# 44           0.0         366500.0     Authorized   5108     7
#
#               status  dist_processing_days  hq_processing_days  \
# 44  E-76 approved on                   0.0                 3.0
#
#     fhwa_processing_days  ftip_no  \
# 44                   5.0  SCAG015
#
#                                project_location  \
# 44  Anaheim Street: La River -pacific Coast Hwy
#
#                                          type_of_work  seq  \
# 44  Install Controller Access Medians, Signal Upgr...    1
#
#    date_request_initiated date_completed_request   mpo projectID  prepared_y  \
# 44             2018-12-11             2018-12-11  SCAG      5108      2018.0
#
#    primary_agency_name
# 44          Long Beach

# %%
(la_df>>count(_.prefix)>>arrange(-_.n)).head(20)
# Out:
#      prefix    n
# 65    HSIPL  705
# 87     STPL  441
# 22      CML  275
# 39       ER  175
# 60    HPLUL  143
# 5      ATPL  135
# 9      BHLS  101
# 48   FTACML   94
# 81    SRTSL   72
# 77   RPSTPL   63
# 18   BRLSZD   45
# 12    BPMPL   43
# 2     ACSTP   36
# 17     BRLS   36
# 57    HP21L   33
# 8      BHLO   20
# 82  SRTSLNI   20
# 40     ESPL   19
# 16     BRLO   18
# 53  FTASTPL   17

# %%
la_df>>group_by(_.primary_agency_name)>>count(_.prefix)>>arrange(-_.n)
# Out:
#     primary_agency_name prefix    n
# 218  Los Angeles County     ER  150
# 198         Los Angeles   STPL   84
# 224  Los Angeles County  HSIPL   81
# 192         Los Angeles  HSIPL   71
# 182         Los Angeles    CML   63
# ..                  ...    ...  ...
# 467              Vernon   HSIP    1
# 468              Vernon  HSIPL    1
# 470         West Covina  HPLUL    1
# 474    Westlake Village  HSIPL    1
# 480            Whittier  STPLH    1
#
# [481 rows x 3 columns]

# %% [markdown]
# ## Number of Unique Prefix Codes

# %%
la_df >> group_by(_.primary_agency_name) >> summarize(n=_.prefix.nunique()) >> arrange(-_.n)>>filter(_.n>=10)
# Out:
#                                    primary_agency_name   n
# 48                                         Los Angeles  34
# 49                                  Los Angeles County  31
# 46                                          Long Beach  18
# 50   Los Angeles County Metropolitan Transportation...  18
# 62                                              Oxnard  14
# 81                                       Santa Clarita  14
# 66                                            Pasadena  12
# 100                                     Ventura County  12

# %%
la_nunique= (la_df >> group_by(_.primary_agency_name) >> summarize(n=_.prefix.nunique()) >> arrange(-_.n)>>filter(_.n>=5))

# %%
chart = (alt.Chart(la_nunique)
         .mark_bar()
         .encode(
             x=alt.X("primary_agency_name", title="Agency Name"),
             y=alt.Y("n", title="Number of Unique Prefixes"),
             #column = "payment:N",
             color = alt.Color("n", 
                              scale=alt.Scale(
                                  range=altair_utils.FIVETHIRTYEIGHT_DIVERGING_COLORS
                              )
                              )
         )
         .properties( 
                      title="Number of Unique Prefixes by Agency in District 7")
)


#chart.save("dist7chart.png")
chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Most Common Types of Work by Agnecy

# %%
la_df>>group_by(_.prefix)>>count(_.type_of_work)>>arrange(-_.n)>>filter(_.n>=8)
# Out:
#        prefix                                       type_of_work   n
# 519    FTACML                                       FTA Transfer  93
# 435        ER                                  Emergency Opening  32
# 525   FTASTPL                                       FTA Transfer  17
# 1188     STPL                           Road Rehabilitation (tc)  17
# 144      BHLS                              Bridge Rehabilitation  15
# 207      BRLS                                 Bridge Replacement  14
# 848     HSIPL                        Traffic Signal Improvements  13
# 518   FTAATPL                                       FTA Transfer  12
# 899     HSIPL                                    Upgrade Signals  12
# 1187     STPL                                Road Rehabilitation  10
# 150      BHLS                     Bridge Rehabilitation/widening   9
# 651     HSIPL           Construct Roundabout Within Existing R/w   9
# 926     HSIPL  Upgrade Traffic Signals; Install Left-turn Pha...   9
# 178     BPMPL       Bridge Preventative Maintenance Program (tc)   8
# 202      BRLO                            Bridge Replacement (tc)   8
# 226    BRLSZD     Replace Struct Deficient Viaduct With New (tc)   8

# %%
la_df>>group_by(_.primary_agency_name)>>count(_.type_of_work)>>arrange(-_.n)>>filter(_.n>=8)
# Out:
#                                     primary_agency_name  \
# 800   Los Angeles County Metropolitan Transportation...
# 654                                  Los Angeles County
# 0                                       Access Services
# 1269           Ventura County Transportation Commission
# 351                                         Los Angeles
# 602                                  Los Angeles County
# 495                                         Los Angeles
# 178                                              Downey
# 262                                           Lancaster
# 353                                         Los Angeles
# 784                                  Los Angeles County
# 515                                         Los Angeles
# 610                                  Los Angeles County
# 622                                  Los Angeles County
# 623                                  Los Angeles County
# 671                                  Los Angeles County
# 772                                  Los Angeles County
#
#                                            type_of_work   n
# 800                                        FTA Transfer  58
# 654                                   Emergency Opening  25
# 0                                          FTA Transfer  17
# 1269                                       FTA Transfer  15
# 351                               Bridge Rehabilitation  11
# 602                         Bikeway Access Improvements  11
# 495                             Pedestrian Improvements  10
# 178   Upgrade Traffic Signals; Install Left-turn Pha...   9
# 262            Construct Roundabout Within Existing R/w   9
# 353                      Bridge Rehabilitation/widening   9
# 784                         Traffic Signal Improvements   9
# 515      Replace Struct Deficient Viaduct With New (tc)   8
# 610        Bridge Preventative Maintenance Program (tc)   8
# 622                                  Bridge Replacement   8
# 623                             Bridge Replacement (tc)   8
# 671                                  Eo: Debris Removal   8
# 772                                    Seismic Retrofit   8

# %% [markdown]
# ## Most Common Project Locations

# %%
la_df>>group_by(_.primary_agency_name)>>count(_.project_location)>>arrange(-_.n)>>filter(_.n>5)
# Out:
#                            primary_agency_name  \
# 545                                Los Angeles
# 1271  Ventura County Transportation Commission
# 544                                Los Angeles
# 137                                Culver City
# 798                         Los Angeles County
# 105                                     Carson
# 659                         Los Angeles County
# 978                                   Pasadena
# 1276                               West Covina
#
#                                        project_location   n
# 545   Sixth Street Viaduct Over La River, Us 101, An...  13
# 1271                       Within The County Of Ventura   9
# 544   Sixth Street Viaduct Over La River And East Sa...   8
# 137               Down Town Area Of City Of Culver City   7
# 798             Various Locations In Los Angeles County   7
# 105   Intersection Of Avalon Blvd And Carson St. In ...   6
# 659   Community Of Florence-firestone In Los Angeles...   6
# 978       Pasadena Ave./sr 210 Wb On-ramp At Walnut St.   6
# 1276  Amar Road Street Improvements: Officer Chiles ...   6

# %%
la_df.sample()
# Out:
#        location prefix project_no       agency prepared_date  \
# 2077  Obligated    CML  5006(873)  Los Angeles    2018-03-07
#
#      submit__to_hq_date hq_review_date submit_to_fhwa_date to_fmis_date  \
# 2077         2018-03-14     2018-03-22          2018-03-27   2018-04-02
#
#       fed_requested  ac_requested  total_requested status_comment locode  \
# 2077       337000.0           0.0         380662.0     Authorized   5006
#
#       dist            status  dist_processing_days  hq_processing_days  \
# 2077     7  E-76 approved on                  27.0                13.0
#
#       fhwa_processing_days  ftip_no                    project_location  \
# 2077                   6.0  LAF3647  Menlo Ave/mlk Vermont Expo Station
#
#                                            type_of_work  seq  \
# 2077  Pedestrian Improvements: Install Sidewaks, Lan...    1
#
#      date_request_initiated date_completed_request   mpo projectID  \
# 2077             2018-02-15             2018-03-13  SCAG      5006
#
#       prepared_y primary_agency_name
# 2077      2018.0         Los Angeles

# %% [markdown]
# ## Number of Obligations by Year

# %%
la_df>>group_by(_.primary_agency_name)>>count(_.prepared_date)>>arrange(-_.n)
# Out:
#                                     primary_agency_name prepared_date  n
# 1418  Los Angeles County Metropolitan Transportation...    2015-07-15  9
# 1440  Los Angeles County Metropolitan Transportation...    2018-05-31  9
# 2                                       Access Services    2016-03-02  7
# 925                                         Los Angeles    2019-02-07  7
# 1593                                             Oxnard    2016-06-24  6
# ...                                                 ...           ... ..
# 2431                                           Whittier    2020-05-21  1
# 2432                                           Whittier    2020-08-23  1
# 2433                                           Whittier    2020-09-03  1
# 2434                                           Whittier    2021-09-24  1
# 2435                                           Whittier    2021-10-20  1
#
# [2436 rows x 3 columns]

# %%
la_df>>group_by(_.primary_agency_name)>>count(_.prepared_y)>>arrange(-_.n)>>filter(_.n>10)
# Out:
#                                    primary_agency_name  prepared_y   n
# 252                                        Los Angeles      2014.0  86
# 266                                 Los Angeles County      2019.0  75
# 254                                        Los Angeles      2016.0  71
# 253                                        Los Angeles      2015.0  69
# 267                                 Los Angeles County      2020.0  69
# 261                                 Los Angeles County      2014.0  67
# 265                                 Los Angeles County      2018.0  64
# 258                                        Los Angeles      2020.0  59
# 264                                 Los Angeles County      2017.0  57
# 256                                        Los Angeles      2018.0  54
# 255                                        Los Angeles      2017.0  52
# 257                                        Los Angeles      2019.0  50
# 259                                        Los Angeles      2021.0  44
# 262                                 Los Angeles County      2015.0  41
# 263                                 Los Angeles County      2016.0  38
# 268                                 Los Angeles County      2021.0  34
# 545                                     Ventura County      2019.0  24
# 273  Los Angeles County Metropolitan Transportation...      2018.0  21
# 335                                             Oxnard      2016.0  21
# 543                                     Ventura County      2017.0  20
# 270  Los Angeles County Metropolitan Transportation...      2015.0  18
# 333                                             Oxnard      2014.0  17
# 436                                      Santa Clarita      2014.0  16
# 542                                     Ventura County      2016.0  16
# 244                                         Long Beach      2017.0  15
# 245                                         Long Beach      2018.0  15
# 469                                        Simi Valley      2014.0  14
# 540                                     Ventura County      2014.0  14
# 140                                             Downey      2016.0  13
# 143                                             Downey      2019.0  13
# 358                                           Pasadena      2018.0  13
# 246                                         Long Beach      2019.0  12
# 354                                           Pasadena      2014.0  12
# 355                                           Pasadena      2015.0  12
# 437                                      Santa Clarita      2015.0  12
# 439                                      Santa Clarita      2017.0  12
# 471                                        Simi Valley      2016.0  12
# 541                                     Ventura County      2015.0  12
# 72                                            Caltrans      2016.0  11
# 236                                          Lancaster      2021.0  11
# 241                                         Long Beach      2014.0  11
# 438                                      Santa Clarita      2016.0  11
# 440                                      Santa Clarita      2018.0  11
# 544                                     Ventura County      2018.0  11

# %%
la_df_year = (la_df>>group_by(_.primary_agency_name)>>count(_.prepared_y)>>arrange(-_.n)>>filter(_.n>10))

# %% [markdown]
# ### Chart

# %%
chart = (alt.Chart(la_df_year)
         .mark_bar()
         .encode(
             x=alt.X("prepared_y", title="Prepared Year"),
             y=alt.Y("n", title="Number of Obligations in each Year"),
             #column = "payment:N",
             color = alt.Color("primary_agency_name", 
                              scale=alt.Scale(
                                  range=altair_utils.FIVETHIRTYEIGHT_DIVERGING_COLORS
                              )
                              )
         )
         .properties( 
                      title="Number of Obliations per Year")
)


#chart.save("dist7chart.png")
chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Agencies with the most unique project numbers

# %%
la_df>>group_by(_.primary_agency_name, _.prefix)>>count(_.project_no)>>arrange(-_.n)>>filter(_.n>5)
# Out:
#                                     primary_agency_name   prefix project_no  n
# 367                                         Los Angeles   BRLSZD  5006(839)  9
# 828   Los Angeles County Metropolitan Transportation...  FTAATPL  6065(225)  9
# 836   Los Angeles County Metropolitan Transportation...   FTACML  6065(199)  9
# 363                                         Los Angeles   BRLSZD  5006(664)  8
# 2                                       Access Services  FTASTPL  6312(022)  7
# 141                                         Culver City      CML  5240(025)  7
# 109                                              Carson    HSIPL  5403(022)  6
# 285                                          Long Beach      CML  5108(181)  6
# 364                                         Los Angeles   BRLSZD  5006(811)  6
# 981                                            Pasadena    HSIPL  5064(075)  6
# 1285           Ventura County Transportation Commission   FTACML  6155(089)  6
# 1301                                        West Covina     STPL  5259(026)  6

# %% [markdown]
# ## Average Funds

# %%
(la_df>>group_by(_.primary_agency_name)>>summarize(avg_funds=_.total_requested.mean())>>arrange(-_.avg_funds)).head(20)
# Out:
#                                    primary_agency_name     avg_funds
# 0                                      Access Services  3.301074e+07
# 50   Los Angeles County Metropolitan Transportation...  1.696266e+07
# 14                                            Caltrans  1.552537e+07
# 94         Southern California Regional Rail Authority  8.633433e+06
# 36                                            Industry  6.324183e+06
# 46                                          Long Beach  4.771285e+06
# 95                              Sunline Transit Agency  4.622594e+06
# 79           San Gabriel Valley Council of Governments  2.697375e+06
# 4                    Antelope Valley Transit Authority  2.475103e+06
# 89                            South Coast Area Transit  2.109463e+06
# 35                                     Huntington Park  1.790354e+06
# 47                   Long Beach Transportation Company  1.764100e+06
# 83                                        Santa Monica  1.630348e+06
# 48                                         Los Angeles  1.587264e+06
# 54                                     Manhattan Beach  1.121750e+06
# 1                                         Agoura Hills  9.324801e+05
# 98                                            Torrance  8.238530e+05
# 76                                           San Dimas  8.005395e+05
# 102                                             Vernon  7.932742e+05
# 29                                             Gardena  7.479218e+05

# %% [markdown]
# ### Top 50 Agencies with highest funds

# %%
avg_funds_top = (la_df
                 >>group_by(_.primary_agency_name)
                 >>summarize(avg_funds=_.total_requested.mean())
                 >>arrange(-_.avg_funds)).head(50)

# %%
chart = (alt.Chart(avg_funds_top)
         .mark_bar()
         .encode(
             x=alt.X("primary_agency_name", title="Primary Agency Name"),
             y=alt.Y("avg_funds", title="Average Total Funds Requested"),
             #column = "payment:N",
             color = alt.Color("avg_funds", 
                              scale=alt.Scale(
                                  range=altair_utils.FIVETHIRTYEIGHT_DIVERGING_COLORS
                              )
                              )
         )
         .properties( 
                      title="Average Total Funds Requested by Agency: Top 50")
)


#chart.save("dist7chart.png")
chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Bottom 50 Agencies with lowest funds

# %%
avg_funds_bottom = (la_df
                    >>group_by(_.primary_agency_name)
                    >>summarize(avg_funds=_.total_requested.mean())
                    >>arrange(-_.avg_funds)).tail(50)

# %%
chart = (alt.Chart(avg_funds_bottom)
         .mark_bar()
         .encode(
             x=alt.X("primary_agency_name", title="Primary Agency Name"),
             y=alt.Y("avg_funds", title="Average Total Funds Requested"),
             #column = "payment:N",
             color = alt.Color("avg_funds", 
                              scale=alt.Scale(
                                  range=altair_utils.FIVETHIRTYEIGHT_DIVERGING_COLORS
                              )
                              )
         )
         .properties( 
                      title="Average Total Funds Requested by Agency: Bottom 50")
)


#chart.save("dist7chart.png")
chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Functions to look by Prefix and by Agency:

# %% [markdown]
# ### By Agency:

# %%
    @interact
    
    def dla_get_prefix(place=la_df.primary_agency_name.sort_values().unique().tolist()):
        
        agencies = la_df[la_df.primary_agency_name==place]
    
        prefix_count_n = agencies >> count(_.prefix)
    
        display(Markdown(f"**Summary Statistics for {place}**"))
        display(Markdown(f"The number of obligations {place} has is {len(agencies)}"))
        
        display(Markdown(f"The number of prefix codes {place} uses is {len(prefix_count_n)}"))
        
        
        
        # for the table- using one as some agencies only have one entry
        pd.set_option("display.max_columns", None)
        display(df[df.agency == place][['fed_requested','ac_requested','total_requested']].describe())
        
        display(Markdown(f"**Top Project Types in {place}**"))
        display((la_df[la_df.primary_agency_name == place] >> count(_.type_of_work) >> arrange(-_.n)).head(5)) 
        # graphs 
    
         
        ax1 = (prefix_count_n
            >> ggplot(aes("prefix", "n", fill="prefix")) 
               + geom_col() 
               + theme(axis_text_x = element_text(angle = 45 , hjust=1))
               + labs(title='Agency Program Codes', x='Program Codes', y='Number of Obligations', fill="Program Type")
               #+ scale_fill_manual(altair_utils.FIVETHIRTYEIGHT_CATEGORY_COLORS)
               #FIVETHIRTYEIGHT_CATEGORY_COLORS doesnt have enough colors for values 
        )
        return ax1
# Out:
# interactive(children=(Dropdown(description='place', options=('Access Services', 'Agoura Hills', 'Alameda Corri…

# %% [markdown]
# ### By Prefix:

# %%
@interact
def prefix_all_agencies_4(prefix=la_df.prefix.sort_values().unique().tolist()):
    
    
    # graphs 
    prefixes = la_df[la_df.prefix== prefix]
    
    prefix_count_num = (prefixes >> count(_.primary_agency_name) >> arrange(-_.n)).head(50)
    
    prefix_count = (prefixes >> count(_.primary_agency_name) >> arrange(-_.n)).head(20)
    
    display(Markdown(f"**The number of agencies using {prefix} is {len(prefix_count_num)}**"))
    
    # for the table- using one as some agencies only have one entry
    display(la_df[(la_df.prefix == prefix)].sample(1))
    
    
    ax1 = (prefix_count
            >> ggplot(aes("primary_agency_name", "n", fill="primary_agency_name")) 
                + geom_col() 
                + theme(axis_text_x = element_text(angle = 45 , hjust=1))
                + labs(title='Top Agencies using Prefix', x='Agency', y='Number of Obligations', fill="Agency")
            )    
    return ax1
# Out:
# interactive(children=(Dropdown(description='prefix', options=('ACNHPI', 'ACSTER', 'ACSTP', 'ATCMTD', 'ATPCML',…

# %% [markdown]
# ## Additional Information

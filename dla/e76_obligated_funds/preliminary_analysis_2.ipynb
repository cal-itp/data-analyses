# %% [markdown]
# # Preliminary Analysis of DLA Functions

# %%
import numpy as np
import pandas as pd
from siuba import *
import _clean_data
import altair as alt
import altair_saver
from plotnine import *

from shared_utils import altair_utils
alt.themes.enable("fivethirtyeight")
# Out:
# /opt/conda/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.9.1-CAPI-1.14.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
# /opt/conda/lib/python3.9/site-packages/google/auth/_default.py:73: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
# /opt/conda/lib/python3.9/site-packages/google/auth/_default.py:73: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
# ThemeRegistry.enable('fivethirtyeight')

# %%
import _dla_utils

# %%
df= pd.read_parquet("dla_df.parquet")

# %%
df.sample()
# Out:
#         location prefix project_no       agency prepared_date  \
# 13882  Obligated    CML  5006(779)  Los Angeles    2019-01-04
#
#       submit__to_hq_date hq_review_date submit_to_fhwa_date to_fmis_date  \
# 13882         2019-01-25     2019-01-28          2019-01-28   2019-01-30
#
#        fed_requested  ...  ftip_no  \
# 13882      1853000.0  ...  LAF3653
#
#                                         project_location  \
# 13882  Pasadena Ave Pedestrian Connection To Gold Lin...
#
#                                       type_of_work seq  \
# 13882  Side Walk Improvements, Safety Lighting Etc   2
#
#        date_request_initiated date_completed_request   mpo  projectID  \
# 13882              2018-12-19             2019-01-25  SCAG       5006
#
#        prepared_y primary_agency_name
# 13882      2019.0         Los Angeles
#
# [1 rows x 29 columns]

# %%
print("Number of Unique Agencies with uncleaned Data")
print(len(df>>count(_.agency)>>arrange(-_.n)))
print("Number of True Unique Agencies")
print(len(df>>count(_.primary_agency_name)>>arrange(-_.n)))
# Out:
# Number of Unique Agencies with uncleaned Data
# 671
# Number of True Unique Agencies
# 619

# %% [markdown]
# ## Get Aggs

# %%
df_agg =_dla_utils.count_all_years(df)

# %%
df_agg
# Out:
#      prepared_y  dist  ac_requested_sum  fed_requested_sum  \
# 120        2021     0      0.000000e+00      -1.140550e+03
# 106        2021     1      6.484611e+06       4.167653e+06
# 107        2021     2     -1.135074e+06       6.084834e+06
# 108        2021     3      1.035237e+08       1.089277e+08
# 109        2021     4      2.533793e+06       1.061114e+08
# ..          ...   ...               ...                ...
# 71         2010     8      0.000000e+00       3.400000e+05
# 118        <NA>     3               NaN                NaN
# 119        <NA>     4               NaN                NaN
# 36         <NA>     7               NaN                NaN
# 121        <NA>    11               NaN                NaN
#
#      total_requested_sum  ac_requested_mean  fed_requested_mean  \
# 120        -1.140550e+03           0.000000        -1140.550000
# 106         1.217239e+07       67548.033437        43413.056250
# 107         7.705425e+06      -15134.315867        81131.117467
# 108         2.378141e+08      417434.091169       439224.708387
# 109         1.602708e+08        7541.050387       315807.822321
# ..                   ...                ...                 ...
# 71          3.850000e+05           0.000000       340000.000000
# 118                  NaN                NaN                 NaN
# 119                  NaN                NaN                 NaN
# 36                   NaN                NaN                 NaN
# 121                  NaN                NaN                 NaN
#
#      total_requested_mean  unique_mpo  unique_prefix  \
# 120          -1140.550000         1.0            1.0
# 106         126795.768542         1.0           13.0
# 107         102739.006133         5.0           15.0
# 108         958927.647621         5.0           34.0
# 109         476996.483929         3.0           37.0
# ..                    ...         ...            ...
# 71          385000.000000         1.0            1.0
# 118                   NaN         NaN            NaN
# 119                   NaN         NaN            NaN
# 36                    NaN         NaN            NaN
# 121                   NaN         NaN            NaN
#
#      unique_primary_agency_name  unique_project_location  unique_project_no  \
# 120                         1.0                      1.0                1.0
# 106                         9.0                     86.0               85.0
# 107                        13.0                     69.0               69.0
# 108                        45.0                    191.0              198.0
# 109                        91.0                    272.0              277.0
# ..                          ...                      ...                ...
# 71                          1.0                      1.0                1.0
# 118                         NaN                      NaN                NaN
# 119                         NaN                      NaN                NaN
# 36                          NaN                      NaN                NaN
# 121                         NaN                      NaN                NaN
#
#      unique_type_of_work
# 120                  1.0
# 106                 49.0
# 107                 55.0
# 108                164.0
# 109                253.0
# ..                   ...
# 71                   1.0
# 118                  NaN
# 119                  NaN
# 36                   NaN
# 121                  NaN
#
# [122 rows x 14 columns]

# %%
df_top = _dla_utils.find_top(df)

# %%
df_top.sample()
# Out:
#                     value  count          variable
# 4  Throughout Kern County     22  project_location

# %% [markdown]
# ## By Dist

# %%
df_top>>filter(_.variable=='dist')
# Out:
#    value  count variable
# 0      4   3248     dist
# 1      6   3084     dist
# 2      7   2787     dist
# 3      3   2517     dist
# 4     10   2203     dist
# 5      5   1337     dist
# 6      8   1309     dist
# 7      1   1161     dist
# 8     11    920     dist
# 9     12    666     dist
# 10     2    614     dist
# 11     9    267     dist
# 12     0      4     dist

# %%
#using df_top

_dla_utils.basic_bar_chart((df_top>>filter(_.variable=='dist')), "value", "count").properties(
    title="Most Obligations by Agency")
# Out:
# alt.Chart(...)

# %%
df_top.sample()
# Out:
#    value  count variable
# 15  BHLS    261   prefix

# %%
dist_years1 = df >> group_by(_.prepared_y, _.dist) >> summarize(n=_.primary_agency_name.nunique()) >> arrange(-_.prepared_y)

# %%
dist_years1.rename(columns={'n': 'n_agency_unique'}, inplace=True)

# %%
dist_years1>>arrange(-_.n_agency_unique)
# Out:
#     prepared_y  dist  n_agency_unique
# 47      2016.0     4              113
# 34      2015.0     4              109
# 22      2014.0     4              108
# 60      2017.0     4               98
# 72      2018.0     4               97
# ..         ...   ...              ...
# 43      2016.0     0                1
# 5       2012.0     7                1
# 1       2011.0     4                1
# 3       2011.0    11                1
# 0       2010.0     8                1
#
# [118 rows x 3 columns]

# %%
chart = alt.Chart(dist_years1).mark_bar().encode(
        # x='prepared_y:O',
        # y='n_agency_unique:Q',
        #color='dist:N',
        column='dist:N',
        x=alt.X('prepared_y:O', title='Prepared Year'),
        y=alt.Y('n_agency_unique:Q', title='Number of Unique Agencies'),
        color = alt.Color("dist:N", 
                              scale=alt.Scale(
                                  range=altair_utils.FIVETHIRTYEIGHT_DIVERGING_COLORS),  
                               legend=alt.Legend(title="District")
                              )
                              ).properties( 
                       title="Number of Unique Agencies by District")

chart
# Out:
# alt.Chart(...)

# %%
_dla_utils.basic_scatter_chart(dist_years1,'n_agency_unique', 'prepared_y', 'dist')
# Out:
# alt.Chart(...)

# %%
chart = (alt.Chart(dist_years1)
         .mark_bar()
         .encode(
             x=alt.X("prepared_y", title="Year"),
             y=alt.Y("n_agency_unique", title="Number of Unique Agencies"),
             #column = "payment:N",
             color = alt.Color("dist", 
                              scale=alt.Scale(
                                  range=altair_utils.FIVETHIRTYEIGHT_DIVERGING_COLORS),  
                               legend=alt.Legend(title="District")
                              )
                              )
        .properties( 
                       title="Number of Obligations by District")

)


chart
# Out:
# alt.Chart(...)

# %%
_dla_utils.basic_bar_chart(dist_years1, "prepared_y", "n_agency_unique")
# Out:
# alt.Chart(...)

# %%
dist_years2 = df >> group_by(_.prepared_y, _.dist) >> summarize(n=_.prefix.nunique()) >> arrange(-_.prepared_y)

# %%
dist_years2.rename(columns={'n': 'n_prefix_unique'}, inplace=True)

# %%
dist_years2>>arrange(-_.n_prefix_unique)
# Out:
#     prepared_y  dist  n_prefix_unique
# 22      2014.0     4               52
# 83      2019.0     3               51
# 72      2018.0     4               51
# 47      2016.0     4               50
# 34      2015.0     4               48
# ..         ...   ...              ...
# 56      2017.0     0                1
# 5       2012.0     7                1
# 1       2011.0     4                1
# 3       2011.0    11                1
# 0       2010.0     8                1
#
# [118 rows x 3 columns]

# %%
chart = alt.Chart(dist_years2).mark_bar().encode(
        # x='prepared_y:O',
        # y='n_agency_unique:Q',
        #color='dist:N',
        column='dist:N',
        x=alt.X('prepared_y:O', title='Prepared Year'),
        y=alt.Y('n_prefix_unique:Q', title='Number of Unique Prefix Codes'),
        color = alt.Color("dist:N", 
                              scale=alt.Scale(
                                  range=altair_utils.FIVETHIRTYEIGHT_DIVERGING_COLORS),  
                               legend=alt.Legend(title="District"
                              )
                              )).properties( 
                       title="Number of Unique Prefix Codes by District")

chart
# Out:
# alt.Chart(...)

# %%
df>>count(_.prepared_y)>>arrange(-_.n)
# Out:
#     prepared_y     n
# 8       2018.0  2827
# 4       2014.0  2724
# 9       2019.0  2665
# 5       2015.0  2575
# 6       2016.0  2505
# 10      2020.0  2350
# 7       2017.0  2333
# 11      2021.0  1917
# 3       2013.0   193
# 2       2012.0     7
# 1       2011.0     5
# 0       2010.0     1

# %%
df_agg>>group_by(_.dist)>>summarize(sum_total_requested=_.total_requested_sum.sum())
# Out:
#     dist  sum_total_requested
# 0      0         3.152859e+06
# 1      1         1.751416e+08
# 2      2         2.288827e+08
# 3      3         1.561211e+09
# 4      4         2.817360e+09
# 5      5         4.926226e+08
# 6      6         1.597301e+09
# 7      7         4.263828e+09
# 8      8         2.589842e+09
# 9      9         5.607522e+07
# 10    10         1.069134e+09
# 11    11         1.158704e+09
# 12    12         2.858146e+09

# %% [markdown]
# ## Charts

# %%
#using df_tops 
_dla_utils.basic_bar_chart((df_top>>filter(_.variable=='primary_agency_name')), "value", "count")
# Out:
# alt.Chart(...)

# %%
_dla_utils.basic_bar_chart((df_top>>filter(_.variable=='primary_agency_name')), "value", "count").properties(
    title="Most Obligations by Agency")
# Out:
# alt.Chart(...)

# %%
_dla_utils.basic_bar_chart(df_top>>filter(_.variable=='prefix'), "value", "count").properties(
    title="Most Obligations by Prefix")
# Out:
# alt.Chart(...)

# %%
df>>filter(_.primary_agency_name=='Humboldt County')>>count(_.prefix)>>arrange(-_.n)
# Out:
#      prefix    n
# 9        ER  379
# 0    ACSTER   64
# 4      BPMP   50
# 1     ACSTP   31
# 5      BRLO   22
# 7      BRLS   20
# 12    HSIPL   19
# 13   RPSTPL   18
# 6    BRLOZB    9
# 2      ATPL    5
# 11    HRRRL    5
# 8    BRLSZD    2
# 3    ATPLNI    1
# 10   FBDLNI    1
# 14  SRTSLNI    1

# %%
#using df_tops

_dla_utils.basic_bar_chart(
    ((_dla_utils.find_top(
        df>>filter(_.primary_agency_name=='Humboldt County')))
    >>filter(_.variable=='prefix')), "value", "count").properties(title="Most Used Prefix Codes in Humboldt County")
# Out:
# alt.Chart(...)

# %%
#using df_tops
_dla_utils.basic_bar_chart((df_top>>filter(_.variable=='mpo')), "value", "count").properties(
    title="Most Obligations by MPO")
# Out:
# alt.Chart(...)

# %%
#using df_top
_dla_utils.basic_bar_chart((df_top>>filter(_.variable=='type_of_work')), "value", "count").properties(
    title="Most Used Type of Work")
# Out:
# alt.Chart(...)

# %%
# %%html
# <style>
# @import url('https://fonts.googleapis.com/css?family=Lato');
# </style>
# Out:
# <style>
# @import url('https://fonts.googleapis.com/css?family=Lato');
# </style>

# %%
#using df_top
_dla_utils.basic_bar_chart((df_top>>filter(_.variable=='project_location')), "value", "count").properties(
    title="Most Used Project Locations")
# Out:
# alt.Chart(...)

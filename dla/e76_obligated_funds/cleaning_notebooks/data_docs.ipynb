# %% [markdown]
# # Creating Data Crosswalks
# **3 categories:**
# 1. Exisiting Agencies
#     * For example, misspelled names
# 2. Null Agencies
# 3. Unmatched Agencies

# %%
import pandas as pd
from siuba import *

import numpy as np

from datetime import date
from IPython.display import Markdown, HTML, display_html

from calitp import *

# %% [markdown]
# #### Reading in the Obligated & Waiting Data

# %%
df = pd.read_csv('gs://calitp-analytics-data/data-analyses/dla/e-76Obligated/clean_obligated_waiting.csv', low_memory=False).drop('Unnamed: 0', axis=1)
# Out:
# /opt/conda/lib/python3.9/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
df.head()
# Out:
#     location prefix project_no             agency prepared_date  \
# 0  Obligated  BPMPL  5904(121)    Humboldt County    2018-12-18
# 1  Obligated     ER  32D0(008)   Mendocino County    2018-12-17
# 2  Obligated     ER  4820(004)    Humboldt County    2018-12-07
# 3  Obligated    CML  5924(244)  Sacramento County    2018-12-11
# 4  Obligated    CML  5924(214)  Sacramento County    2018-12-05
#
#   submit__to_hq_date hq_review_date submit_to_fhwa_date to_fmis_date  \
# 0         2018-12-18     2018-12-18          2018-12-18   2018-12-27
# 1         2018-12-19     2018-12-20          2018-12-20   2018-12-27
# 2         2018-12-21     2018-12-21          2018-12-21   2018-12-27
# 3         2018-12-11     2018-12-21          2018-12-27   2018-12-27
# 4         2018-12-11     2018-12-21          2018-12-27   2018-12-27
#
#    fed_requested  ...                                   project_location  \
# 0           0.00  ...                      14 Bridges In Humboldt County
# 1       11508.00  ...               Comptche Ukiah Road, Cr 223 Pm 17.25
# 2       45499.64  ...                                Mattole Rd Pm 43.17
# 3      207002.00  ...     Fair Oaks Blvd. Between Howe Ave And Munroe St
# 4           0.00  ...  Florin Rd Between Power Inn Rd. And Florin Per...
#
#                                         type_of_work seq  \
# 0        Bridge Preventive Maintenance - Deck Joints   3
# 1                              Permanent Restoration   3
# 2                              Permanent Restoration   5
# 3  Create A Smart Growth Corridor With Barrier Se...   1
# 4                                   Streetscape (tc)   3
#
#   date_request_initiated  date_completed_request      mpo  warning  projectID  \
# 0                    NaN                     NaN  NON-MPO      NaN       5904
# 1             2018-12-17              2018-12-18  NON-MPO      NaN       32D0
# 2             2018-12-06              2018-12-07  NON-MPO      NaN       4820
# 3             2018-12-07              2018-12-07    SACOG      NaN       5924
# 4             2018-11-28              2018-12-04    SACOG      NaN       5924
#
#    projectNO compare_id_locode
# 0        121              True
# 1          8             False
# 2          4             False
# 3        244              True
# 4        214              True
#
# [5 rows x 30 columns]

# %%
def get_num(x):
    try:
        return int(x)
    except Exception:
        try:
            return float(x)
        except Exception:
            return x

# %%
df['locode'] = df['locode'].apply(get_num)

# %%
df['projectID'] = df['projectID'].apply(get_num)

# %% [markdown]
# #### Reading in the Official Locode List

# %%
l_df = pd.concat(pd.read_excel('gs://calitp-analytics-data/data-analyses/dla/e-76Obligated/locodes_updated7122021.xlsx', sheet_name=None), ignore_index=True)

# %%
l_df = to_snakecase(l_df)

# %%
l_df['agency_locode'] = l_df['agency_locode'].apply(get_num)

# %%
l_df.head()
# Out:
#    agency_locode                                        agency_name  district  \
# 0           6302  Humboldt Bay Harbor Recreation & Conservation ...         1
# 1           6330           Willow Creek Community Services District         1
# 2           5036                                           Trinidad         1
# 3           5049                                              Ukiah         1
# 4           5082                                            Willits         1
#
#         county_name                                   rtpa_name mpo_name  \
# 0   Humboldt County  Humboldt County Association of Governments  NON-MPO
# 1   Humboldt County  Humboldt County Association of Governments  NON-MPO
# 2   Humboldt County  Humboldt County Association of Governments  NON-MPO
# 3  Mendocino County            Mendocino Council of Governments  NON-MPO
# 4  Mendocino County            Mendocino Council of Governments  NON-MPO
#
#   mpo_locode_fads active_e76s______7_12_2021_
# 0         NON-MPO                         NaN
# 1         NON-MPO                         NaN
# 2         NON-MPO                         NaN
# 3         NON-MPO                         Yes
# 4         NON-MPO                         NaN

# %% [markdown]
# ## Creating Crosswalk 1: Locode Agency Relationships

# %%
df>>count(_.agency, _.locode)
# Out:
#                                       agency locode    n
# 0                            Access Services   6312   17
# 1                               Agoura Hills   5435    2
# 2                            Ala-Con Costa T   6002    1
# 3                                    Alameda   5014   21
# 4    Alameda - Contra Costa Transit District   6002    6
# ..                                       ...    ...  ...
# 675                              Yuba County   5916  141
# 676                                  Yucaipa   5457   20
# 677                                  Yucaipa   5954    1
# 678                                  Yucaipa   NBIL    1
# 679                             Yucca Valley   5466   12
#
# [680 rows x 3 columns]

# %%
df_doc1 = (df>>count(_.agency, _.locode))

# %%
df_doc1 = df_doc1.drop('n', 1)
# Out:
# /tmp/ipykernel_5339/1601895059.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df_doc1 = df_doc1.drop('n', 1)

# %%
df_doc1 = df_doc1.rename(columns={'locode': 'agency_locode', 'agency':'agency_name'})

# %%
df_doc1
# Out:
#                                  agency_name agency_locode
# 0                            Access Services          6312
# 1                               Agoura Hills          5435
# 2                            Ala-Con Costa T          6002
# 3                                    Alameda          5014
# 4    Alameda - Contra Costa Transit District          6002
# ..                                       ...           ...
# 675                              Yuba County          5916
# 676                                  Yucaipa          5457
# 677                                  Yucaipa          5954
# 678                                  Yucaipa          NBIL
# 679                             Yucca Valley          5466
#
# [680 rows x 2 columns]

# %%
df_doc2 = l_df[['agency_name','agency_locode']].copy()

# %%
df_doc2 = df_doc2.rename(columns={'agency_name': 'primary_agency_name','agency_locode':'primary_agency_locode'})

# %%
df_doc2
# Out:
#                                     primary_agency_name  primary_agency_locode
# 0     Humboldt Bay Harbor Recreation & Conservation ...                   6302
# 1              Willow Creek Community Services District                   6330
# 2                                              Trinidad                   5036
# 3                                                 Ukiah                   5049
# 4                                               Willits                   5082
# ...                                                 ...                    ...
# 1036                                        Leave Blank                   5465
# 1037                     U.S. Fish and Wildlife Service                   6250
# 1038                 Tidewater Southern Railway Company                   6031
# 1039                   Tri-Counties Regional Park Group                   6176
# 1040                              Trust for Public Land                   6185
#
# [1041 rows x 2 columns]

# %% [markdown]
# ### Merging Official Locode List and unique agencies in Obligated List

# %%
data_doc = pd.merge(df_doc1, df_doc2, how='left', left_on='agency_locode', right_on='primary_agency_locode')

# %%
data_doc
# Out:
#                                  agency_name agency_locode  \
# 0                            Access Services          6312
# 1                               Agoura Hills          5435
# 2                            Ala-Con Costa T          6002
# 3                                    Alameda          5014
# 4    Alameda - Contra Costa Transit District          6002
# ..                                       ...           ...
# 675                              Yuba County          5916
# 676                                  Yucaipa          5457
# 677                                  Yucaipa          5954
# 678                                  Yucaipa          NBIL
# 679                             Yucca Valley          5466
#
#                          primary_agency_name  primary_agency_locode
# 0                            Access Services                 6312.0
# 1                               Agoura Hills                 5435.0
# 2    Alameda - Contra Costa Transit District                 6002.0
# 3                                    Alameda                 5014.0
# 4    Alameda - Contra Costa Transit District                 6002.0
# ..                                       ...                    ...
# 675                              Yuba County                 5916.0
# 676                                  Yucaipa                 5457.0
# 677                    San Bernardino County                 5954.0
# 678                                      NaN                    NaN
# 679                             Yucca Valley                 5466.0
#
# [680 rows x 4 columns]

# %% [markdown]
# ### Exceptions in Data

# %%
d = {'agency_name': ['Santa Barbara County', 'Calaveras','Los Angeles County', 'Palm Springs',
                'Marin County','Paradise','Trinity County','Humboldt','Alpine County','Monterey County',
                'Nevada County','Los Angeles County','Tehama County','Yucaipa','Cathedral City','Monterey County',
                'Solano County Transit','Tuolumne County'],
     'agency_locode': [5912, 5463, 5930, 5275, 5953, 5953, 5953, 5940, 5903, 
                5903, 5903, 5351, 5954, 5954, 5957, 5936, 6503, 5916],
     'primary_agency_name': ['Butte County', 'Calabasas','Calaveras County', 'Indio','Los Angeles County',
                             'Los Angeles County','Los Angeles County','Mariposa County','Modoc County','Modoc County',
                             'Modoc County','Pico Rivera','San Bernardino County','San Bernardino County',
                             'San Diego County','Santa Cruz County',
                             'Transbay Joint Powers Authority','Yuba County'],
     'primary_agency_locode': [5912, 5463, 5930, 5275, 5953, 5953, 5953, 5940, 5903, 5903,
                               5903, 5351, 5954, 5954, 5957, 5936, 6503, 5916]}

# %%
exceptions = pd.DataFrame(data=d)

# %%
exceptions
# Out:
#               agency_name  agency_locode              primary_agency_name  \
# 0    Santa Barbara County           5912                     Butte County
# 1               Calaveras           5463                        Calabasas
# 2      Los Angeles County           5930                 Calaveras County
# 3            Palm Springs           5275                            Indio
# 4            Marin County           5953               Los Angeles County
# 5                Paradise           5953               Los Angeles County
# 6          Trinity County           5953               Los Angeles County
# 7                Humboldt           5940                  Mariposa County
# 8           Alpine County           5903                     Modoc County
# 9         Monterey County           5903                     Modoc County
# 10          Nevada County           5903                     Modoc County
# 11     Los Angeles County           5351                      Pico Rivera
# 12          Tehama County           5954            San Bernardino County
# 13                Yucaipa           5954            San Bernardino County
# 14         Cathedral City           5957                 San Diego County
# 15        Monterey County           5936                Santa Cruz County
# 16  Solano County Transit           6503  Transbay Joint Powers Authority
# 17        Tuolumne County           5916                      Yuba County
#
#     primary_agency_locode
# 0                    5912
# 1                    5463
# 2                    5930
# 3                    5275
# 4                    5953
# 5                    5953
# 6                    5953
# 7                    5940
# 8                    5903
# 9                    5903
# 10                   5903
# 11                   5351
# 12                   5954
# 13                   5954
# 14                   5957
# 15                   5936
# 16                   6503
# 17                   5916

# %% [markdown]
# ### Removing entries that have NaN or contain wrong locodes/agencies for later

# %%
#saving as df for later use
unmatched1 = data_doc>>filter(_.primary_agency_name.isnull())

# %%
unmatched1
# Out:
#                      agency_name agency_locode primary_agency_name  \
# 40                       Banning          7500                 NaN
# 88                      Caltrans          7504                 NaN
# 190                       Fowler          7500                 NaN
# 204  Gold Coast Transit District          7505                 NaN
# 210                 Grass Valley          32L0                 NaN
# 266                    La Quinta          NBIL                 NaN
# 277                    Lancaster          7500                 NaN
# 299                  Los Angeles          7500                 NaN
# 300                  Los Angeles          38Y0                 NaN
# 325                    Mendocino          40A0                 NaN
# 399                     Palmdale          7500                 NaN
# 446                     Richmond          7500                 NaN
# 472               San Bernardino          38R0                 NaN
# 473               San Bernardino          40A0                 NaN
# 506              San Luis Obispo          7500                 NaN
# 513                    San Mateo          7500                 NaN
# 530                   Santa Cruz          40A0                 NaN
# 547                         Sgvc          7500                 NaN
# 585                     Stockton          7500                 NaN
# 591                       Sutter          7500                 NaN
# 634                      Ventura          7500                 NaN
# 678                      Yucaipa          NBIL                 NaN
#
#      primary_agency_locode
# 40                     NaN
# 88                     NaN
# 190                    NaN
# 204                    NaN
# 210                    NaN
# 266                    NaN
# 277                    NaN
# 299                    NaN
# 300                    NaN
# 325                    NaN
# 399                    NaN
# 446                    NaN
# 472                    NaN
# 473                    NaN
# 506                    NaN
# 513                    NaN
# 530                    NaN
# 547                    NaN
# 585                    NaN
# 591                    NaN
# 634                    NaN
# 678                    NaN

# %%
data_doc = data_doc[data_doc['primary_agency_name'].notna()]

# %%
data_doc>>filter(_.primary_agency_name.isnull())
# Out:
# Empty DataFrame
# Columns: [agency_name, agency_locode, primary_agency_name, primary_agency_locode]
# Index: []

# %% [markdown]
# ### Merging Exceptions and Data Doc to remove exceptions

# %%
# code help: https://stackoverflow.com/questions/28901683/pandas-get-rows-which-are-not-in-other-dataframe

# %%
df_all = data_doc.merge(exceptions.drop_duplicates(), on=['agency_name','agency_locode','primary_agency_name','primary_agency_locode'], 
                   how='left', indicator=True)
df_all
# Out:
#                                  agency_name agency_locode  \
# 0                            Access Services          6312
# 1                               Agoura Hills          5435
# 2                            Ala-Con Costa T          6002
# 3                                    Alameda          5014
# 4    Alameda - Contra Costa Transit District          6002
# ..                                       ...           ...
# 653                                Yuba City          5163
# 654                              Yuba County          5916
# 655                                  Yucaipa          5457
# 656                                  Yucaipa          5954
# 657                             Yucca Valley          5466
#
#                          primary_agency_name  primary_agency_locode     _merge
# 0                            Access Services                 6312.0  left_only
# 1                               Agoura Hills                 5435.0  left_only
# 2    Alameda - Contra Costa Transit District                 6002.0  left_only
# 3                                    Alameda                 5014.0  left_only
# 4    Alameda - Contra Costa Transit District                 6002.0  left_only
# ..                                       ...                    ...        ...
# 653                                Yuba City                 5163.0  left_only
# 654                              Yuba County                 5916.0  left_only
# 655                                  Yucaipa                 5457.0  left_only
# 656                    San Bernardino County                 5954.0       both
# 657                             Yucca Valley                 5466.0  left_only
#
# [658 rows x 5 columns]

# %%
df_all = (df_all>>filter(_._merge=='left_only'))

# %%
df_all.drop('_merge', axis=1, inplace=True)
# Out:
# /tmp/ipykernel_5339/2497191238.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all.drop('_merge', axis=1, inplace=True)

# %%
df_all
# Out:
#                                  agency_name agency_locode  \
# 0                            Access Services          6312
# 1                               Agoura Hills          5435
# 2                            Ala-Con Costa T          6002
# 3                                    Alameda          5014
# 4    Alameda - Contra Costa Transit District          6002
# ..                                       ...           ...
# 652                               Yreka City          5020
# 653                                Yuba City          5163
# 654                              Yuba County          5916
# 655                                  Yucaipa          5457
# 657                             Yucca Valley          5466
#
#                          primary_agency_name  primary_agency_locode
# 0                            Access Services                 6312.0
# 1                               Agoura Hills                 5435.0
# 2    Alameda - Contra Costa Transit District                 6002.0
# 3                                    Alameda                 5014.0
# 4    Alameda - Contra Costa Transit District                 6002.0
# ..                                       ...                    ...
# 652                               Yreka City                 5020.0
# 653                                Yuba City                 5163.0
# 654                              Yuba County                 5916.0
# 655                                  Yucaipa                 5457.0
# 657                             Yucca Valley                 5466.0
#
# [640 rows x 4 columns]

# %%
#df_all['primary_agency_locode'] = df_all['primary_agency_locode'].apply(get_num)
#df_all['agency_locode'] = df_all['agency_locode'].apply(get_num)

# %% [markdown]
# ### Compare agency names

# %%
compare_names = np.where(df_all["agency_name"] == df_all["primary_agency_name"], True, False)
df_all["compare_names"] = compare_names
# Out:
# /tmp/ipykernel_5339/2847587374.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all["compare_names"] = compare_names

# %%
df_all
# Out:
#                                  agency_name agency_locode  \
# 0                            Access Services          6312
# 1                               Agoura Hills          5435
# 2                            Ala-Con Costa T          6002
# 3                                    Alameda          5014
# 4    Alameda - Contra Costa Transit District          6002
# ..                                       ...           ...
# 652                               Yreka City          5020
# 653                                Yuba City          5163
# 654                              Yuba County          5916
# 655                                  Yucaipa          5457
# 657                             Yucca Valley          5466
#
#                          primary_agency_name  primary_agency_locode  \
# 0                            Access Services                 6312.0
# 1                               Agoura Hills                 5435.0
# 2    Alameda - Contra Costa Transit District                 6002.0
# 3                                    Alameda                 5014.0
# 4    Alameda - Contra Costa Transit District                 6002.0
# ..                                       ...                    ...
# 652                               Yreka City                 5020.0
# 653                                Yuba City                 5163.0
# 654                              Yuba County                 5916.0
# 655                                  Yucaipa                 5457.0
# 657                             Yucca Valley                 5466.0
#
#      compare_names
# 0             True
# 1             True
# 2            False
# 3             True
# 4             True
# ..             ...
# 652           True
# 653           True
# 654           True
# 655           True
# 657           True
#
# [640 rows x 5 columns]

# %%
df_all.compare_names.value_counts()
# Out:
# True     585
# False     55
# Name: compare_names, dtype: int64

# %%
df_all>>filter(_.compare_names==False)>>select(_.agency_name, _.primary_agency_name, _.primary_agency_locode)
# Out:
#                                            agency_name  \
# 2                                      Ala-Con Costa T
# 42                                         Bay Area Rt
# 62             Butte County Association Of Governments
# 65                    Calaveras Council Of Governments
# 106  City & County Of San Francisco, Mta/Parking & ...
# 107  City/County Association Of Governments Of San ...
# 115        Coachella Valley Association Of Governments
# 133               Council Of Fresno County Governments
# 134           Council Of San Benito County Governments
# 148                 Department Of Parks And Recreation
# 149                      Department Of Water Resources
# 229                                           Imperial
# 243                                               Kern
# 246                 Kern County Council Of Governments
# 247               Kern County Superintendent Of School
# 254                                        La Co M T A
# 291                                        Los Angeles
# 310                                           Mariposa
# 315                                               Mctd
# 321                                             Merced
# 323           Merced County Association Of Governments
# 325      Metropolitan Transportation Commission - Safe
# 353                    Napa County Office Of Education
# 373                                          Omnitrans
# 375                                    Ora Co Trans Au
# 394                                      Parks And Rec
# 418                              Port Of San Francisco
# 441                                          Riverside
# 451             Sacramento Area Council Of Governments
# 459                                     San Bernardino
# 464                                  San Buena Ventura
# 468                                          San Diego
# 469               San Diego Association Of Governments
# 471               San Diego Metropolitan Tranit System
# 479          San Francisco Department Of Public Health
# 481          San Gabriel Valley Council Of Governments
# 484                 San Joaquin Council Of Governments
# 492             San Luis Obispo Council Of Governments
# 508    Santa Barbara County Association Of Governments
# 532                                      Shasta County
# 533                                      Shasta County
# 547                                      Sonoma County
# 560     Southern California Association Of Governments
# 562                    Southwest Transportation Agency
# 564                  Stanislaus Council Of Governments
# 588          Transportation Agency For Monterey County
# 589                  Transportation Authority Of Marin
# 606                       United States Forest Service
# 608                   University Of California - Davis
# 609           University Of California - Santa Barbara
# 610          University Of California At San Francisco
# 611                                    Usda Forest Ser
# 622                                                Vta
# 646                                                Wta
# 650   Yosemite Area Regional Transportation System Jpa
#
#                                    primary_agency_name  primary_agency_locode
# 2              Alameda - Contra Costa Transit District                 6002.0
# 42       San Francisco Bay Area Rapid Transit District                 6000.0
# 62             Butte County Association of Governments                 6092.0
# 65                    Calaveras Council of Governments                 6128.0
# 106  City & County of San Francisco, MTA/Parking & ...                 6328.0
# 107  City/County Association of Governments of San ...                 6419.0
# 115        Coachella Valley Association of Governments                 6164.0
# 133               Council of Fresno County Governments                 6086.0
# 134           Council of San Benito County Governments                 6060.0
# 148                 Department of Parks and Recreation                 6081.0
# 149                      Department of Water Resources                 6248.0
# 229                                    Imperial County                 5958.0
# 243                           Kern County (District 9)                 5961.0
# 246                 Kern County Council of Governments                 6087.0
# 247              Kern County Superintendent of Schools                 6332.0
# 254  Los Angeles County Metropolitan Transportation...                 6065.0
# 291                                 Los Angeles County                 5953.0
# 310                                    Mariposa County                 5940.0
# 315                      Marin County Transit District                 6343.0
# 321                                      Merced County                 5939.0
# 323           Merced County Association of Governments                 6095.0
# 325      Metropolitan Transportation Commission - SAFE                 6160.0
# 353                    Napa County Office of Education                 6446.0
# 373                                          OmniTrans                 6046.0
# 375                                          Morro Bay                 5391.0
# 394                 Department of Parks and Recreation                 6081.0
# 418                              Port of San Francisco                 6169.0
# 441                                   Riverside County                 5956.0
# 451             Sacramento Area Council of Governments                 6085.0
# 459                              San Bernardino County                 5954.0
# 464                                   San Buenaventura                 5026.0
# 468                                   San Diego County                 5957.0
# 469               San Diego Association of Governments                 6066.0
# 471              San Diego Metropolitan Transit System                 7503.0
# 479          San Francisco Department of Public Health                 6447.0
# 481          San Gabriel Valley Council of Governments                 6303.0
# 484                 San Joaquin Council of Governments                 6088.0
# 492             San Luis Obispo Council of Governments                 6096.0
# 508    Santa Barbara County Association of Governments                 6090.0
# 532                                        Yuba County                 5916.0
# 533                                        Napa County                 5921.0
# 547                                         Yreka City                 5020.0
# 560     Southern California Association of Governments                 6049.0
# 562                    SouthWest Transportation Agency                 6338.0
# 564                  Stanislaus Council of Governments                 6089.0
# 588          Transportation Agency for Monterey County                 6143.0
# 589                  Transportation Authority of Marin                 6406.0
# 606      U.S. Forest Service, Pacific Southwest Region                 6190.0
# 608                   University of California - Davis                 6387.0
# 609           University of California - Santa Barbara                 6300.0
# 610          University of California at San Francisco                 6342.0
# 611      U.S. Forest Service, Pacific Southwest Region                 6190.0
# 622        Santa Clara Valley Transportation Authority                 6264.0
# 646     San Francisco Bay Area Water Transit Authority                 6365.0
# 650   Yosemite Area Regional Transportation System JPA                 6305.0

# %%
df_all >> group_by(_.primary_agency_name) >> summarize(n=_.agency_name.nunique()) >> arrange(-_.n) >>filter(_.n>1)
# Out:
#                                    primary_agency_name  n
# 557      U.S. Forest Service, Pacific Southwest Region  3
# 3              Alameda - Contra Costa Transit District  2
# 131                 Department of Parks and Recreation  2
# 211                                    Imperial County  2
# 225                           Kern County (District 9)  2
# 270                                 Los Angeles County  2
# 271  Los Angeles County Metropolitan Transportation...  2
# 283                      Marin County Transit District  2
# 285                                    Mariposa County  2
# 294                                      Merced County  2
# 317                                          Morro Bay  2
# 322                                        Napa County  2
# 406                                   Riverside County  2
# 424                              San Bernardino County  2
# 432                                   San Diego County  2
# 437      San Francisco Bay Area Rapid Transit District  2
# 438     San Francisco Bay Area Water Transit Authority  2
# 472        Santa Clara Valley Transportation Authority  2
# 602                                         Yreka City  2
# 604                                        Yuba County  2

# %%
#running through these matches and checking to make sure they are already documented in `issues_dla_data_locode.xlsx`
df_all >> filter(_.primary_agency_name=='Yreka City') >> arrange(_.agency_name)
# Out:
#        agency_name agency_locode primary_agency_name  primary_agency_locode  \
# 547  Sonoma County          5020          Yreka City                 5020.0
# 652     Yreka City          5020          Yreka City                 5020.0
#
#      compare_names
# 547          False
# 652           True

# %%
#looking at the locode count too
df_all>>count(_.agency_locode)>>arrange(-_.n)>>filter(_.n>=2)
# Out:
#      agency_locode  n
# 538           6190  3
# 17            5020  2
# 341           5391  2
# 440           5916  2
# 445           5921  2
# 463           5939  2
# 464           5940  2
# 477           5953  2
# 478           5954  2
# 480           5956  2
# 481           5957  2
# 482           5958  2
# 483           5961  2
# 484           6000  2
# 485           6002  2
# 499           6065  2
# 505           6081  2
# 566           6264  2
# 587           6343  2
# 591           6365  2

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 640 entries, 0 to 657
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   agency_name            640 non-null    object
#  1   agency_locode          640 non-null    object
#  2   primary_agency_name    640 non-null    object
#  3   primary_agency_locode  640 non-null    float64
#  4   compare_names          640 non-null    bool
# dtypes: bool(1), float64(1), object(3)
# memory usage: 25.6+ KB

# %%
df_all
# Out:
#                                  agency_name agency_locode  \
# 0                            Access Services          6312
# 1                               Agoura Hills          5435
# 2                            Ala-Con Costa T          6002
# 3                                    Alameda          5014
# 4    Alameda - Contra Costa Transit District          6002
# ..                                       ...           ...
# 652                               Yreka City          5020
# 653                                Yuba City          5163
# 654                              Yuba County          5916
# 655                                  Yucaipa          5457
# 657                             Yucca Valley          5466
#
#                          primary_agency_name  primary_agency_locode  \
# 0                            Access Services                 6312.0
# 1                               Agoura Hills                 5435.0
# 2    Alameda - Contra Costa Transit District                 6002.0
# 3                                    Alameda                 5014.0
# 4    Alameda - Contra Costa Transit District                 6002.0
# ..                                       ...                    ...
# 652                               Yreka City                 5020.0
# 653                                Yuba City                 5163.0
# 654                              Yuba County                 5916.0
# 655                                  Yucaipa                 5457.0
# 657                             Yucca Valley                 5466.0
#
#      compare_names
# 0             True
# 1             True
# 2            False
# 3             True
# 4             True
# ..             ...
# 652           True
# 653           True
# 654           True
# 655           True
# 657           True
#
# [640 rows x 5 columns]

# %% [markdown]
# #### `df_all` to CSV

# %%
#df_all.to_csv('agencylocode_primary_crosswalk_6.csv',index=False)

# %% [markdown]
# ## Crosswalk 2: Agencies with Null Locodes

# %% [markdown]
# ### Extract the obliations with the null lococde values

# %%
null = df>>filter(_.locode.isnull())

# %%
len(null)
# Out:
# 1499

# %%
null.agency.nunique()
# Out:
# 205

# %%
null_doc1 = (null>> count(_.agency, _.projectID)>>arrange(-_.n))

# %%
null_doc1 = null_doc1.drop('n', 1)
# Out:
# /tmp/ipykernel_5339/978838314.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   null_doc1 = null_doc1.drop('n', 1)

# %%
null_doc1.rename(columns={'agency': 'agency_name', 'projectID': 'agency_locode_id'}, inplace=True)

# %%
null_doc1
# Out:
#          agency_name agency_locode_id
# 163      San Joaquin             5929
# 103      Los Angeles             5006
# 187         Stockton             5008
# 186       Stanislaus             5938
# 115          Modesto             5059
# ..               ...              ...
# 193         Torrance             5249
# 197  Twentynine Palm             NBIL
# 198    Union Pacific             6020
# 208      Westmorland             5278
# 211      Yorba Linda             5402
#
# [215 rows x 2 columns]

# %%
df_doc2
# Out:
#                                     primary_agency_name  primary_agency_locode
# 0     Humboldt Bay Harbor Recreation & Conservation ...                   6302
# 1              Willow Creek Community Services District                   6330
# 2                                              Trinidad                   5036
# 3                                                 Ukiah                   5049
# 4                                               Willits                   5082
# ...                                                 ...                    ...
# 1036                                        Leave Blank                   5465
# 1037                     U.S. Fish and Wildlife Service                   6250
# 1038                 Tidewater Southern Railway Company                   6031
# 1039                   Tri-Counties Regional Park Group                   6176
# 1040                              Trust for Public Land                   6185
#
# [1041 rows x 2 columns]

# %% [markdown]
# ### Merge with Official Locode List

# %%
null_doc_full = pd.merge(null_doc1, df_doc2, how='left', left_on='agency_locode_id', right_on='primary_agency_locode')

# %%
null_doc_full
# Out:
#          agency_name agency_locode_id     primary_agency_name  \
# 0        San Joaquin             5929      San Joaquin County
# 1        Los Angeles             5006             Los Angeles
# 2           Stockton             5008                Stockton
# 3         Stanislaus             5938       Stanislaus County
# 4            Modesto             5059                 Modesto
# ..               ...              ...                     ...
# 210         Torrance             5249                Torrance
# 211  Twentynine Palm             NBIL                     NaN
# 212    Union Pacific             6020  Union Pacific Railroad
# 213      Westmorland             5278             Westmorland
# 214      Yorba Linda             5402             Yorba Linda
#
#      primary_agency_locode
# 0                   5929.0
# 1                   5006.0
# 2                   5008.0
# 3                   5938.0
# 4                   5059.0
# ..                     ...
# 210                 5249.0
# 211                    NaN
# 212                 6020.0
# 213                 5278.0
# 214                 5402.0
#
# [215 rows x 4 columns]

# %%
unmatched2 = null_doc_full>>filter(_.primary_agency_name.isnull())

# %%
#keeping for next part
unmatched2
# Out:
#                           agency_name agency_locode_id primary_agency_name  \
# 27                               Inyo             24M0                 NaN
# 163                           Yucaipa             NBIL                 NaN
# 166                           Anaheim             11CA                 NaN
# 184  La Jolla Band Of Luiseno Indians             X075                 NaN
# 205                            Sanbag              499                 NaN
# 211                   Twentynine Palm             NBIL                 NaN
#
#      primary_agency_locode
# 27                     NaN
# 163                    NaN
# 166                    NaN
# 184                    NaN
# 205                    NaN
# 211                    NaN

# %%
null_doc_full = null_doc_full[null_doc_full['primary_agency_name'].notna()]

# %%
null_doc_full
# Out:
#        agency_name agency_locode_id     primary_agency_name  \
# 0      San Joaquin             5929      San Joaquin County
# 1      Los Angeles             5006             Los Angeles
# 2         Stockton             5008                Stockton
# 3       Stanislaus             5938       Stanislaus County
# 4          Modesto             5059                 Modesto
# ..             ...              ...                     ...
# 209       Temecula             5459                Temecula
# 210       Torrance             5249                Torrance
# 212  Union Pacific             6020  Union Pacific Railroad
# 213    Westmorland             5278             Westmorland
# 214    Yorba Linda             5402             Yorba Linda
#
#      primary_agency_locode
# 0                   5929.0
# 1                   5006.0
# 2                   5008.0
# 3                   5938.0
# 4                   5059.0
# ..                     ...
# 209                 5459.0
# 210                 5249.0
# 212                 6020.0
# 213                 5278.0
# 214                 5402.0
#
# [209 rows x 4 columns]

# %%
#null_doc_full['primary_agency_locode'] = null_doc_full['primary_agency_locode'].apply(get_num)
#null_doc_full['agency_locode_id'] = null_doc_full['agency_locode_id'].apply(get_num)

# %%
null_doc_full
# Out:
#        agency_name agency_locode_id     primary_agency_name  \
# 0      San Joaquin             5929      San Joaquin County
# 1      Los Angeles             5006             Los Angeles
# 2         Stockton             5008                Stockton
# 3       Stanislaus             5938       Stanislaus County
# 4          Modesto             5059                 Modesto
# ..             ...              ...                     ...
# 209       Temecula             5459                Temecula
# 210       Torrance             5249                Torrance
# 212  Union Pacific             6020  Union Pacific Railroad
# 213    Westmorland             5278             Westmorland
# 214    Yorba Linda             5402             Yorba Linda
#
#      primary_agency_locode
# 0                   5929.0
# 1                   5006.0
# 2                   5008.0
# 3                   5938.0
# 4                   5059.0
# ..                     ...
# 209                 5459.0
# 210                 5249.0
# 212                 6020.0
# 213                 5278.0
# 214                 5402.0
#
# [209 rows x 4 columns]

# %% [markdown]
# ### Comparing the columns

# %%
compare_names2 = np.where(null_doc_full["agency_name"] == null_doc_full["primary_agency_name"], True, False)
null_doc_full["compare_names"] = compare_names2
# Out:
# /tmp/ipykernel_5339/2136139582.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   null_doc_full["compare_names"] = compare_names2

# %%
null_doc_full.compare_names.value_counts()
# Out:
# True     159
# False     50
# Name: compare_names, dtype: int64

# %%
null_doc_full>>filter(_.compare_names==False)
# Out:
#          agency_name agency_locode_id  \
# 0        San Joaquin             5929
# 3         Stanislaus             5938
# 5        Los Angeles             5953
# 7             Merced             5939
# 9             Sanbag             6053
# 11    San Bernardino             5954
# 14         Riverside             5956
# 15    Sd Assoc Gov'T             6066
# 16          Tuolumne             5932
# 18         Calaveras             5930
# 23          Imperial             5958
# 24          Mariposa             5940
# 25         San Diego             5957
# 28   Ora Co Trans Au             6071
# 32            Orange             5955
# 34           Ventura             5952
# 41              Inyo             5948
# 43            Amador             5926
# 51     Stan Area Aog             6089
# 55   Dst Hot Springs             5384
# 67   Huntington Beac             5181
# 74   Riv Co Trans Co             6054
# 78   Calaveras C T C             6128
# 85   La Canada-Flint             5417
# 88              Sgvc             6303
# 99      Gustine City             5230
# 104             Mono             5947
# 107  Ranchocucamonga             5420
# 111             Stpd             6349
# 113             Yrts             6305
# 119              Dwr             6248
# 124             Jpam             6308
# 129  San Joaquin Cog             6088
# 130  Sanbuenaventura             5026
# 131  Sanjuancapistra             5372
# 135     Westminister             5338
# 156              Rsm             5478
# 160  Usda Forest Ser             6190
# 171   Cap Soeast Con             6498
# 175  Coachella V A G             6164
# 179   Fthll/East Tca             6061
# 180  Hawaiian Garden             5387
# 191             Lgnw             5476
# 194    Merced Co Aog             6095
# 198  Ranchopalosverd             5413
# 200  Rollinghillsest             5349
# 202             Samd             6373
# 206   Santa Fe Sprgs             5340
# 208             Sjrt             6245
# 212    Union Pacific             6020
#
#                                   primary_agency_name  primary_agency_locode  \
# 0                                  San Joaquin County                 5929.0
# 3                                   Stanislaus County                 5938.0
# 5                                  Los Angeles County                 5953.0
# 7                                       Merced County                 5939.0
# 9               San Bernardino Associated Governments                 6053.0
# 11                              San Bernardino County                 5954.0
# 14                                   Riverside County                 5956.0
# 15               San Diego Association of Governments                 6066.0
# 16                                    Tuolumne County                 5932.0
# 18                                   Calaveras County                 5930.0
# 23                                    Imperial County                 5958.0
# 24                                    Mariposa County                 5940.0
# 25                                   San Diego County                 5957.0
# 28             Orange County Transportation Authority                 6071.0
# 32                                      Orange County                 5955.0
# 34                                     Ventura County                 5952.0
# 41                                        Inyo County                 5948.0
# 43                                      Amador County                 5926.0
# 51                  Stanislaus Council of Governments                 6089.0
# 55                                 Desert Hot Springs                 5384.0
# 67                                   Huntington Beach                 5181.0
# 74         Riverside County Transportation Commission                 6054.0
# 78                   Calaveras Council of Governments                 6128.0
# 85                               La Canada Flintridge                 5417.0
# 88          San Gabriel Valley Council of Governments                 6303.0
# 99                                            Gustine                 5230.0
# 104                                       Mono County                 5947.0
# 107                                  Rancho Cucamonga                 5420.0
# 111                            Stockton Port District                 6349.0
# 113  Yosemite Area Regional Transportation System JPA                 6305.0
# 119                     Department of Water Resources                 6248.0
# 124  Transit Joint Powers Authority For Merced County                 6308.0
# 129                San Joaquin Council of Governments                 6088.0
# 130                                  San Buenaventura                 5026.0
# 131                               San Juan Capistrano                 5372.0
# 135                                       Westminster                 5338.0
# 156                            Rancho Santa Margarita                 5478.0
# 160     U.S. Forest Service, Pacific Southwest Region                 6190.0
# 171                       Capital Southeast Connector                 6498.0
# 175       Coachella Valley Association of Governments                 6164.0
# 179          Foothill Eastern Transportation Corridor                 6061.0
# 180                                  Hawaiian Gardens                 5387.0
# 191                                      Laguna Woods                 5476.0
# 194          Merced County Association of Governments                 6095.0
# 198                               Rancho Palos Verdes                 5413.0
# 200                             Rolling Hills Estates                 5349.0
# 202       South Coast Air Quality Management District                 6373.0
# 206                                  Santa Fe Springs                 5340.0
# 208             San Joaquin Regional Transit District                 6245.0
# 212                            Union Pacific Railroad                 6020.0
#
#      compare_names
# 0            False
# 3            False
# 5            False
# 7            False
# 9            False
# 11           False
# 14           False
# 15           False
# 16           False
# 18           False
# 23           False
# 24           False
# 25           False
# 28           False
# 32           False
# 34           False
# 41           False
# 43           False
# 51           False
# 55           False
# 67           False
# 74           False
# 78           False
# 85           False
# 88           False
# 99           False
# 104          False
# 107          False
# 111          False
# 113          False
# 119          False
# 124          False
# 129          False
# 130          False
# 131          False
# 135          False
# 156          False
# 160          False
# 171          False
# 175          False
# 179          False
# 180          False
# 191          False
# 194          False
# 198          False
# 200          False
# 202          False
# 206          False
# 208          False
# 212          False

# %%
# good with these false values- none are new issues, but rather contain acronyms or correct spelling.

# %%
null_doc_full>>filter(_.compare_names==True)
# Out:
#      agency_name agency_locode_id primary_agency_name  primary_agency_locode  \
# 1    Los Angeles             5006         Los Angeles                 5006.0
# 2       Stockton             5008            Stockton                 5008.0
# 4        Modesto             5059             Modesto                 5059.0
# 6        Turlock             5165             Turlock                 5165.0
# 8         Merced             5085              Merced                 5085.0
# ..           ...              ...                 ...                    ...
# 207  Santa Paula             5121         Santa Paula                 5121.0
# 209     Temecula             5459            Temecula                 5459.0
# 210     Torrance             5249            Torrance                 5249.0
# 213  Westmorland             5278         Westmorland                 5278.0
# 214  Yorba Linda             5402         Yorba Linda                 5402.0
#
#      compare_names
# 1             True
# 2             True
# 4             True
# 6             True
# 8             True
# ..             ...
# 207           True
# 209           True
# 210           True
# 213           True
# 214           True
#
# [159 rows x 5 columns]

# %% [markdown]
# #### `null_doc_full` to CSV

# %%
#drop `compare_names` column first

# %%
null_doc_full = null_doc_full.drop('compare_names', 1)
# Out:
# /tmp/ipykernel_5339/1073568232.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   null_doc_full = null_doc_full.drop('compare_names', 1)

# %%
#null_doc_full.to_csv('null_doc_full1.csv',index=False)

# %% [markdown]
# ## Crosswalk 3: Unmatched

# %%
unmatched1
# Out:
#                      agency_name agency_locode primary_agency_name  \
# 40                       Banning          7500                 NaN
# 88                      Caltrans          7504                 NaN
# 190                       Fowler          7500                 NaN
# 204  Gold Coast Transit District          7505                 NaN
# 210                 Grass Valley          32L0                 NaN
# 266                    La Quinta          NBIL                 NaN
# 277                    Lancaster          7500                 NaN
# 299                  Los Angeles          7500                 NaN
# 300                  Los Angeles          38Y0                 NaN
# 325                    Mendocino          40A0                 NaN
# 399                     Palmdale          7500                 NaN
# 446                     Richmond          7500                 NaN
# 472               San Bernardino          38R0                 NaN
# 473               San Bernardino          40A0                 NaN
# 506              San Luis Obispo          7500                 NaN
# 513                    San Mateo          7500                 NaN
# 530                   Santa Cruz          40A0                 NaN
# 547                         Sgvc          7500                 NaN
# 585                     Stockton          7500                 NaN
# 591                       Sutter          7500                 NaN
# 634                      Ventura          7500                 NaN
# 678                      Yucaipa          NBIL                 NaN
#
#      primary_agency_locode
# 40                     NaN
# 88                     NaN
# 190                    NaN
# 204                    NaN
# 210                    NaN
# 266                    NaN
# 277                    NaN
# 299                    NaN
# 300                    NaN
# 325                    NaN
# 399                    NaN
# 446                    NaN
# 472                    NaN
# 473                    NaN
# 506                    NaN
# 513                    NaN
# 530                    NaN
# 547                    NaN
# 585                    NaN
# 591                    NaN
# 634                    NaN
# 678                    NaN

# %%
unmatched2 = unmatched2.rename(columns={'agency_locode_id': 'agency_locode'})

# %%
unmatched2
# Out:
#                           agency_name agency_locode primary_agency_name  \
# 27                               Inyo          24M0                 NaN
# 163                           Yucaipa          NBIL                 NaN
# 166                           Anaheim          11CA                 NaN
# 184  La Jolla Band Of Luiseno Indians          X075                 NaN
# 205                            Sanbag           499                 NaN
# 211                   Twentynine Palm          NBIL                 NaN
#
#      primary_agency_locode
# 27                     NaN
# 163                    NaN
# 166                    NaN
# 184                    NaN
# 205                    NaN
# 211                    NaN

# %%
unmatched_total = pd.concat([unmatched1, unmatched2], ignore_index=True)

# %%
unmatched_total>>arrange(_.agency_name)
# Out:
#                          agency_name agency_locode primary_agency_name  \
# 24                           Anaheim          11CA                 NaN
# 0                            Banning          7500                 NaN
# 1                           Caltrans          7504                 NaN
# 2                             Fowler          7500                 NaN
# 3        Gold Coast Transit District          7505                 NaN
# 4                       Grass Valley          32L0                 NaN
# 22                              Inyo          24M0                 NaN
# 25  La Jolla Band Of Luiseno Indians          X075                 NaN
# 5                          La Quinta          NBIL                 NaN
# 6                          Lancaster          7500                 NaN
# 7                        Los Angeles          7500                 NaN
# 8                        Los Angeles          38Y0                 NaN
# 9                          Mendocino          40A0                 NaN
# 10                          Palmdale          7500                 NaN
# 11                          Richmond          7500                 NaN
# 12                    San Bernardino          38R0                 NaN
# 13                    San Bernardino          40A0                 NaN
# 14                   San Luis Obispo          7500                 NaN
# 15                         San Mateo          7500                 NaN
# 26                            Sanbag           499                 NaN
# 16                        Santa Cruz          40A0                 NaN
# 17                              Sgvc          7500                 NaN
# 18                          Stockton          7500                 NaN
# 19                            Sutter          7500                 NaN
# 27                   Twentynine Palm          NBIL                 NaN
# 20                           Ventura          7500                 NaN
# 21                           Yucaipa          NBIL                 NaN
# 23                           Yucaipa          NBIL                 NaN
#
#     primary_agency_locode
# 24                    NaN
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# 22                    NaN
# 25                    NaN
# 5                     NaN
# 6                     NaN
# 7                     NaN
# 8                     NaN
# 9                     NaN
# 10                    NaN
# 11                    NaN
# 12                    NaN
# 13                    NaN
# 14                    NaN
# 15                    NaN
# 26                    NaN
# 16                    NaN
# 17                    NaN
# 18                    NaN
# 19                    NaN
# 27                    NaN
# 20                    NaN
# 21                    NaN
# 23                    NaN

# %%
unmatched_total= unmatched_total.drop('primary_agency_name', 1)
unmatched_total= unmatched_total.drop('primary_agency_locode', 1)
# Out:
# /tmp/ipykernel_5339/2713099181.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   unmatched_total= unmatched_total.drop('primary_agency_name', 1)
# /tmp/ipykernel_5339/2713099181.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   unmatched_total= unmatched_total.drop('primary_agency_locode', 1)

# %% [markdown]
# ### Merge onto Official List on Agency Name
# * Assuming that the agency name are the same

# %%
unmatched_est = pd.merge(unmatched_total, df_doc2, how='left', left_on='agency_name', right_on='primary_agency_name')

unmatched_est
# Out:
#                          agency_name agency_locode primary_agency_name  \
# 0                            Banning          7500             Banning
# 1                           Caltrans          7504            Caltrans
# 2                           Caltrans          7504            Caltrans
# 3                           Caltrans          7504            Caltrans
# 4                           Caltrans          7504            Caltrans
# 5                           Caltrans          7504            Caltrans
# 6                           Caltrans          7504            Caltrans
# 7                           Caltrans          7504            Caltrans
# 8                           Caltrans          7504            Caltrans
# 9                           Caltrans          7504            Caltrans
# 10                          Caltrans          7504            Caltrans
# 11                          Caltrans          7504            Caltrans
# 12                          Caltrans          7504            Caltrans
# 13                          Caltrans          7504            Caltrans
# 14                            Fowler          7500              Fowler
# 15       Gold Coast Transit District          7505                 NaN
# 16                      Grass Valley          32L0        Grass Valley
# 17                         La Quinta          NBIL           La Quinta
# 18                         Lancaster          7500           Lancaster
# 19                       Los Angeles          7500         Los Angeles
# 20                       Los Angeles          38Y0         Los Angeles
# 21                         Mendocino          40A0                 NaN
# 22                          Palmdale          7500            Palmdale
# 23                          Richmond          7500            Richmond
# 24                    San Bernardino          38R0      San Bernardino
# 25                    San Bernardino          40A0      San Bernardino
# 26                   San Luis Obispo          7500     San Luis Obispo
# 27                         San Mateo          7500           San Mateo
# 28                        Santa Cruz          40A0          Santa Cruz
# 29                              Sgvc          7500                 NaN
# 30                          Stockton          7500            Stockton
# 31                            Sutter          7500                 NaN
# 32                           Ventura          7500                 NaN
# 33                           Yucaipa          NBIL             Yucaipa
# 34                              Inyo          24M0                 NaN
# 35                           Yucaipa          NBIL             Yucaipa
# 36                           Anaheim          11CA             Anaheim
# 37  La Jolla Band Of Luiseno Indians          X075                 NaN
# 38                            Sanbag           499                 NaN
# 39                   Twentynine Palm          NBIL                 NaN
#
#     primary_agency_locode
# 0                  5214.0
# 1                  6201.0
# 2                  6202.0
# 3                  6203.0
# 4                  6204.0
# 5                  6205.0
# 6                  6206.0
# 7                  6207.0
# 8                  6208.0
# 9                  6209.0
# 10                 6210.0
# 11                 6211.0
# 12                 6212.0
# 13                 6200.0
# 14                 5173.0
# 15                    NaN
# 16                 5023.0
# 17                 5433.0
# 18                 5419.0
# 19                 5006.0
# 20                 5006.0
# 21                    NaN
# 22                 5378.0
# 23                 5137.0
# 24                 5033.0
# 25                 5033.0
# 26                 5016.0
# 27                 5102.0
# 28                 5025.0
# 29                    NaN
# 30                 5008.0
# 31                    NaN
# 32                    NaN
# 33                 5457.0
# 34                    NaN
# 35                 5457.0
# 36                 5055.0
# 37                    NaN
# 38                    NaN
# 39                    NaN

# %%
#unmatched_est['primary_agency_locode'] = unmatched_est['primary_agency_locode'].apply(get_num)

# %%
unmatched_est
# Out:
#                          agency_name agency_locode primary_agency_name  \
# 0                            Banning          7500             Banning
# 1                           Caltrans          7504            Caltrans
# 2                           Caltrans          7504            Caltrans
# 3                           Caltrans          7504            Caltrans
# 4                           Caltrans          7504            Caltrans
# 5                           Caltrans          7504            Caltrans
# 6                           Caltrans          7504            Caltrans
# 7                           Caltrans          7504            Caltrans
# 8                           Caltrans          7504            Caltrans
# 9                           Caltrans          7504            Caltrans
# 10                          Caltrans          7504            Caltrans
# 11                          Caltrans          7504            Caltrans
# 12                          Caltrans          7504            Caltrans
# 13                          Caltrans          7504            Caltrans
# 14                            Fowler          7500              Fowler
# 15       Gold Coast Transit District          7505                 NaN
# 16                      Grass Valley          32L0        Grass Valley
# 17                         La Quinta          NBIL           La Quinta
# 18                         Lancaster          7500           Lancaster
# 19                       Los Angeles          7500         Los Angeles
# 20                       Los Angeles          38Y0         Los Angeles
# 21                         Mendocino          40A0                 NaN
# 22                          Palmdale          7500            Palmdale
# 23                          Richmond          7500            Richmond
# 24                    San Bernardino          38R0      San Bernardino
# 25                    San Bernardino          40A0      San Bernardino
# 26                   San Luis Obispo          7500     San Luis Obispo
# 27                         San Mateo          7500           San Mateo
# 28                        Santa Cruz          40A0          Santa Cruz
# 29                              Sgvc          7500                 NaN
# 30                          Stockton          7500            Stockton
# 31                            Sutter          7500                 NaN
# 32                           Ventura          7500                 NaN
# 33                           Yucaipa          NBIL             Yucaipa
# 34                              Inyo          24M0                 NaN
# 35                           Yucaipa          NBIL             Yucaipa
# 36                           Anaheim          11CA             Anaheim
# 37  La Jolla Band Of Luiseno Indians          X075                 NaN
# 38                            Sanbag           499                 NaN
# 39                   Twentynine Palm          NBIL                 NaN
#
#     primary_agency_locode
# 0                  5214.0
# 1                  6201.0
# 2                  6202.0
# 3                  6203.0
# 4                  6204.0
# 5                  6205.0
# 6                  6206.0
# 7                  6207.0
# 8                  6208.0
# 9                  6209.0
# 10                 6210.0
# 11                 6211.0
# 12                 6212.0
# 13                 6200.0
# 14                 5173.0
# 15                    NaN
# 16                 5023.0
# 17                 5433.0
# 18                 5419.0
# 19                 5006.0
# 20                 5006.0
# 21                    NaN
# 22                 5378.0
# 23                 5137.0
# 24                 5033.0
# 25                 5033.0
# 26                 5016.0
# 27                 5102.0
# 28                 5025.0
# 29                    NaN
# 30                 5008.0
# 31                    NaN
# 32                    NaN
# 33                 5457.0
# 34                    NaN
# 35                 5457.0
# 36                 5055.0
# 37                    NaN
# 38                    NaN
# 39                    NaN

# %%
#some of these are located in other crosswalks. 
## Ex. "Sgvc" and "Sanbag" are already documented. 
## This crosswalk addressed the agencies that have locodes other than those listed in `agency_locode`.

# %%
no_official = unmatched_est>>filter(_.primary_agency_name.isnull())

# %%
no_official
# Out:
#                          agency_name agency_locode primary_agency_name  \
# 15       Gold Coast Transit District          7505                 NaN
# 21                         Mendocino          40A0                 NaN
# 29                              Sgvc          7500                 NaN
# 31                            Sutter          7500                 NaN
# 32                           Ventura          7500                 NaN
# 34                              Inyo          24M0                 NaN
# 37  La Jolla Band Of Luiseno Indians          X075                 NaN
# 38                            Sanbag           499                 NaN
# 39                   Twentynine Palm          NBIL                 NaN
#
#     primary_agency_locode
# 15                    NaN
# 21                    NaN
# 29                    NaN
# 31                    NaN
# 32                    NaN
# 34                    NaN
# 37                    NaN
# 38                    NaN
# 39                    NaN

# %% [markdown]
# #### Exporting Unmatched NaN values for manipulation in Excel

# %%
# will correct these manually in excel 
## exporting to do that

#no_official.to_csv('unmatched_no_officials.csv',index=False)

# %% [markdown]
# #### `unmatched_est` to CSV

# %%
unmatched_est = unmatched_est[unmatched_est['primary_agency_name'].notna()]

# %%
#unmatched_est.to_csv('unmatched_estimate.csv',index=False)

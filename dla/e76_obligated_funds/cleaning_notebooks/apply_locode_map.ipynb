# %% [markdown]
# # Finding another way to change locode

# %% [markdown]
# Stackoverflow questions and answers that may help:
# * [Replace Column Values in one Dataframe by Values of Another Dataframe](https://stackoverflow.com/questions/36413993/replace-column-values-in-one-dataframe-by-values-of-another-dataframe)
#     * similar to [Replace Column Values Based on Partial String Match From Another Dataframe](https://stackoverflow.com/questions/54808130/replace-column-values-based-on-partial-string-match-from-another-dataframe-pytho)
# * [Based on Partial String Match Fill one Dataframe Column from Another Dataframe](https://stackoverflow.com/questions/61811137/based-on-partial-string-match-fill-one-data-frame-column-from-another-dataframe)

# %%
import pandas as pd
from siuba import *

import numpy as np

from datetime import date
from IPython.display import Markdown, HTML, display_html

from calitp import *

# %%
from dla_utils import clean_data
# Out:
# /opt/conda/lib/python3.9/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /opt/conda/lib/python3.9/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /home/jovyan/data-analyses/dla/dla_utils/dla_utils/clean_data.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nullagency['primary_agency_name2'] = df_nullagency['agency'].map(locode_map3)

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('gs://calitp-analytics-data/data-analyses/dla/e-76Obligated/clean_obligated_waiting.csv', low_memory=False).drop('Unnamed: 0', axis=1)

# %%
df.head()
# Out:
#     location prefix project_no             agency prepared_date  \
# 0  Obligated  BPMPL  5904(121)    Humboldt County    2018-12-18
# 1  Obligated     ER  32D0(008)   Mendocino County    2018-12-17
# 2  Obligated     ER  4820(004)    Humboldt County    2018-12-07
# 3  Obligated    CML  5924(244)  Sacramento County    2018-12-11
# 4  Obligated    CML  5924(214)  Sacramento County    2018-12-05
#
#   submit__to_hq_date hq_review_date submit_to_fhwa_date to_fmis_date  \
# 0         2018-12-18     2018-12-18          2018-12-18   2018-12-27
# 1         2018-12-19     2018-12-20          2018-12-20   2018-12-27
# 2         2018-12-21     2018-12-21          2018-12-21   2018-12-27
# 3         2018-12-11     2018-12-21          2018-12-27   2018-12-27
# 4         2018-12-11     2018-12-21          2018-12-27   2018-12-27
#
#    fed_requested  ac_requested  total_requested status_comment locode  dist  \
# 0           0.00           0.0             0.00     Authorized   5904     1
# 1       11508.00           0.0         13000.00     Authorized   5910     1
# 2       45499.64           0.0         51394.58     Authorized   5904     1
# 3      207002.00           0.0        247002.00     Authorized   5924     3
# 4           0.00     5680921.0       5702041.00     Authorized   5924     3
#
#              status  dist_processing_days  hq_processing_days  \
# 0  E-76 approved on                   NaN                 0.0
# 1  E-76 approved on                   1.0                 1.0
# 2  E-76 approved on                  14.0                 0.0
# 3  E-76 approved on                   4.0                16.0
# 4  E-76 approved on                   7.0                16.0
#
#    fhwa_processing_days   ftip_no  \
# 0                   9.0  HBPLOCAL
# 1                   7.0       NaN
# 2                   6.0       NaN
# 3                   0.0  SAC25086
# 4                   0.0  SAC24753
#
#                                     project_location  \
# 0                      14 Bridges In Humboldt County
# 1               Comptche Ukiah Road, Cr 223 Pm 17.25
# 2                                Mattole Rd Pm 43.17
# 3     Fair Oaks Blvd. Between Howe Ave And Munroe St
# 4  Florin Rd Between Power Inn Rd. And Florin Per...
#
#                                         type_of_work  seq  \
# 0        Bridge Preventive Maintenance - Deck Joints    3
# 1                              Permanent Restoration    3
# 2                              Permanent Restoration    5
# 3  Create A Smart Growth Corridor With Barrier Se...    1
# 4                                   Streetscape (tc)    3
#
#   date_request_initiated date_completed_request      mpo warning projectID  \
# 0                    NaN                    NaN  NON-MPO     NaN      5904
# 1             2018-12-17             2018-12-18  NON-MPO     NaN      32D0
# 2             2018-12-06             2018-12-07  NON-MPO     NaN      4820
# 3             2018-12-07             2018-12-07    SACOG     NaN      5924
# 4             2018-11-28             2018-12-04    SACOG     NaN      5924
#
#    projectNO  compare_id_locode
# 0        121               True
# 1          8              False
# 2          4              False
# 3        244               True
# 4        214               True

# %%
len(df>>count(_.agency))
# Out:
# 671

# %%
def get_num(x):
    try:
        return int(x)
    except Exception:
        try:
            return float(x)
        except Exception:
            return x

# %%
df['locode'] = df['locode'].apply(get_num)

# %%
df['locode'] = clean_data.get_num(df['locode'])

# %% [markdown]
# ## Read in Agency Locode Crosswalk

# %%
ldf = pd.read_csv('gs://calitp-analytics-data/data-analyses/dla/e-76Obligated/agencylocode_primary_crosswalk1.csv')

# %%
ldf.head()
# Out:
#    agency_name  agency_locode primary_agency_name  primary_agency_locode
# 0   Sacramento           5002          Sacramento                   5002
# 1      Benicia           5003             Benicia                   5003
# 2    San Diego           5004           San Diego                   5004
# 3     San Jose           5005            San Jose                   5005
# 4  Los Angeles           5006         Los Angeles                   5006

# %%
#should return no values
ldf>>filter(_.agency_locode==7500)
# Out:
# Empty DataFrame
# Columns: [agency_name, agency_locode, primary_agency_name, primary_agency_locode]
# Index: []

# %% [markdown]
# ## Match Dataframe with the Crosswalk
#
# * To fix inccorect agency names

# %% [markdown]
# ### Run 1
# * Code help from top answer in [Replace Column Values in one Dataframe by Values of Another Dataframe](https://stackoverflow.com/questions/36413993/replace-column-values-in-one-dataframe-by-values-of-another-dataframe)
# * fill the NaN results: [Remap values in pandas column with a dict, preserve NaNs](https://stackoverflow.com/questions/20250771/remap-values-in-pandas-column-with-a-dict-preserve-nans)

# %%
df1 = df.copy()

# %%
df1.agency.isna().sum()
# Out:
# 0

# %%
df1.agency.nunique()
# Out:
# 671

# %%
# code help from: https://towardsdatascience.com/state-name-to-state-abbreviation-crosswalks-6936250976c
locode_map = dict(zip(ldf['primary_agency_locode'], 
                          ldf['primary_agency_name']))

# %%
df1['primary_agency_name'] = df1['locode'].map(locode_map)

# %%
df1
# Out:
#         location   prefix project_no             agency prepared_date  \
# 0      Obligated    BPMPL  5904(121)    Humboldt County    2018-12-18
# 1      Obligated       ER  32D0(008)   Mendocino County    2018-12-17
# 2      Obligated       ER  4820(004)    Humboldt County    2018-12-07
# 3      Obligated      CML  5924(244)  Sacramento County    2018-12-11
# 4      Obligated      CML  5924(214)  Sacramento County    2018-12-05
# ...          ...      ...        ...                ...           ...
# 20112   DISTRICT  FTACRRS  6000(069)        Bay Area Rt           NaN
# 20113   DISTRICT  FTASTPL  6343(006)               Mctd           NaN
# 20114   DISTRICT  FTASTPL  6264(091)                Vta           NaN
# 20115   DISTRICT  FTASTPL  6002(030)    Ala-Con Costa T           NaN
# 20116   DISTRICT     HSIP  7504(001)           Caltrans           NaN
#
#       submit__to_hq_date hq_review_date submit_to_fhwa_date to_fmis_date  \
# 0             2018-12-18     2018-12-18          2018-12-18   2018-12-27
# 1             2018-12-19     2018-12-20          2018-12-20   2018-12-27
# 2             2018-12-21     2018-12-21          2018-12-21   2018-12-27
# 3             2018-12-11     2018-12-21          2018-12-27   2018-12-27
# 4             2018-12-11     2018-12-21          2018-12-27   2018-12-27
# ...                  ...            ...                 ...          ...
# 20112                NaN            NaN                 NaN          NaN
# 20113                NaN            NaN                 NaN          NaN
# 20114                NaN            NaN                 NaN          NaN
# 20115                NaN            NaN                 NaN          NaN
# 20116                NaN            NaN                 NaN          NaN
#
#        fed_requested  ac_requested  total_requested  status_comment locode  \
# 0               0.00           0.0             0.00      Authorized   5904
# 1           11508.00           0.0         13000.00      Authorized   5910
# 2           45499.64           0.0         51394.58      Authorized   5904
# 3          207002.00           0.0        247002.00      Authorized   5924
# 4               0.00     5680921.0       5702041.00      Authorized   5924
# ...              ...           ...              ...             ...    ...
# 20112           0.00           0.0             0.00     prog code     6000
# 20113           0.00           0.0             0.00     prog code     6343
# 20114           0.00           0.0             0.00     prog code     6264
# 20115           0.00           0.0             0.00     prog code     6002
# 20116      351200.00           0.0        351200.00  prog code Z300   7504
#
#        dist                               status  dist_processing_days  \
# 0         1                     E-76 approved on                   NaN
# 1         1                     E-76 approved on                   1.0
# 2         1                     E-76 approved on                  14.0
# 3         3                     E-76 approved on                   4.0
# 4         3                     E-76 approved on                   7.0
# ...     ...                                  ...                   ...
# 20112     4  FTA transferred waiting at DISTRICT                   NaN
# 20113     4  FTA transferred waiting at DISTRICT                   NaN
# 20114     4  FTA transferred waiting at DISTRICT                   NaN
# 20115     4  FTA transferred waiting at DISTRICT                   NaN
# 20116    11  FTA transferred waiting at DISTRICT                   NaN
#
#        hq_processing_days  fhwa_processing_days   ftip_no  \
# 0                     0.0                   9.0  HBPLOCAL
# 1                     1.0                   7.0       NaN
# 2                     0.0                   6.0       NaN
# 3                    16.0                   0.0  SAC25086
# 4                    16.0                   0.0  SAC24753
# ...                   ...                   ...       ...
# 20112                 0.0                   0.0       NaN
# 20113                 0.0                   0.0       NaN
# 20114                 0.0                   0.0       NaN
# 20115                 0.0                   0.0       NaN
# 20116                 0.0                   0.0       NaN
#
#                                         project_location  \
# 0                          14 Bridges In Humboldt County
# 1                   Comptche Ukiah Road, Cr 223 Pm 17.25
# 2                                    Mattole Rd Pm 43.17
# 3         Fair Oaks Blvd. Between Howe Ave And Munroe St
# 4      Florin Rd Between Power Inn Rd. And Florin Per...
# ...                                                  ...
# 20112                                       FTA transfer
# 20113                                       FTA transfer
# 20114                                       FTA transfer
# 20115                                       FTA transfer
# 20116                                       FTA transfer
#
#                                             type_of_work  seq  \
# 0            Bridge Preventive Maintenance - Deck Joints    3
# 1                                  Permanent Restoration    3
# 2                                  Permanent Restoration    5
# 3      Create A Smart Growth Corridor With Barrier Se...    1
# 4                                       Streetscape (tc)    3
# ...                                                  ...  ...
# 20112                     Bart Fare Collection Equipment    1
# 20113                              Bus Stops Improvement    1
# 20114          Electronic Locker Upgrade And Replacement    1
# 20115            Quick Builds And Tempo Lane Delineation    1
# 20116                           Guardrail Var. Locations    1
#
#       date_request_initiated date_completed_request      mpo warning  \
# 0                        NaN                    NaN  NON-MPO     NaN
# 1                 2018-12-17             2018-12-18  NON-MPO     NaN
# 2                 2018-12-06             2018-12-07  NON-MPO     NaN
# 3                 2018-12-07             2018-12-07    SACOG     NaN
# 4                 2018-11-28             2018-12-04    SACOG     NaN
# ...                      ...                    ...      ...     ...
# 20112                    NaN                    NaN      MTC     NaN
# 20113                    NaN                    NaN      MTC     NaN
# 20114                    NaN                    NaN      MTC     NaN
# 20115                    NaN                    NaN      MTC     NaN
# 20116                    NaN                    NaN      NaN     NaN
#
#       projectID  projectNO  compare_id_locode  \
# 0          5904        121               True
# 1          32D0          8              False
# 2          4820          4              False
# 3          5924        244               True
# 4          5924        214               True
# ...         ...        ...                ...
# 20112      6000         69               True
# 20113      6343          6               True
# 20114      6264         91               True
# 20115      6002         30               True
# 20116      7504          1               True
#
#                                  primary_agency_name
# 0                                    Humboldt County
# 1                                   Mendocino County
# 2                                    Humboldt County
# 3                                  Sacramento County
# 4                                  Sacramento County
# ...                                              ...
# 20112  San Francisco Bay Area Rapid Transit District
# 20113                  Marin County Transit District
# 20114    Santa Clara Valley Transportation Authority
# 20115        Alameda - Contra Costa Transit District
# 20116                                            NaN
#
# [20117 rows x 31 columns]

# %%
df1.primary_agency_name.nunique()
# Out:
# 607

# %% [markdown]
# * lowest unique agency count to date (12/13/21)

# %% [markdown]
# ### Checking to see if it worked

# %%
#should return no values
df1>>filter(_.primary_agency_name==('Riv Co Trans Co'))
# Out:
# Empty DataFrame
# Columns: [location, prefix, project_no, agency, prepared_date, submit__to_hq_date, hq_review_date, submit_to_fhwa_date, to_fmis_date, fed_requested, ac_requested, total_requested, status_comment, locode, dist, status, dist_processing_days, hq_processing_days, fhwa_processing_days, ftip_no, project_location, type_of_work, seq, date_request_initiated, date_completed_request, mpo, warning, projectID, projectNO, compare_id_locode, primary_agency_name]
# Index: []

# %%
# worked to correct the spelling typos

# %%
#should retrun more three counties 
df1>>filter(_.locode==5940)>>count(_.agency)
# Out:
#             agency   n
# 0         Humboldt   1
# 1         Mariposa   4
# 2  Mariposa County  37

# %%
#should return Mariposa as Mariposa County
df1>>filter(_.locode==5940)>>count(_.agency, _.primary_agency_name)
# Out:
#             agency primary_agency_name   n
# 0         Humboldt     Mariposa County   1
# 1         Mariposa     Mariposa County   4
# 2  Mariposa County     Mariposa County  37

# %%
df1>>filter(_.locode==5940)>>count(_.primary_agency_name)
# Out:
#   primary_agency_name   n
# 0     Mariposa County  42

# %%
# should be showing one Humboldt County... based on previous attempt to correct the data

# %%
df1>>filter(_.locode==5940)>>filter(_.agency.str.contains('Humboldt'))
# Out:
#        location prefix project_no    agency prepared_date submit__to_hq_date  \
# 8186  Obligated     ER  20H0(001)  Humboldt    2015-10-06         2015-10-06
#
#      hq_review_date submit_to_fhwa_date to_fmis_date  fed_requested  \
# 8186     2015-10-06          2015-10-06   2015-10-09            0.0
#
#       ac_requested  total_requested status_comment locode  dist  \
# 8186           0.0        -11002.15     Authorized   5940    10
#
#                                  status  dist_processing_days  \
# 8186  E-76 approved on E-76 approved on                   0.0
#
#       hq_processing_days  fhwa_processing_days ftip_no project_location  \
# 8186                 0.0                   3.0     NaN     Ben Hur Road
#
#                           type_of_work  seq date_request_initiated  \
# 8186  Temporary Restoration Of Erosion    2                    NaN
#
#      date_completed_request      mpo warning projectID  projectNO  \
# 8186                    NaN  NON-MPO     NaN      20H0          1
#
#       compare_id_locode primary_agency_name
# 8186              False     Mariposa County

# %%
# agency is wrong, locode is right

# %%
df1>>filter(_.locode==5953)>>count(_.primary_agency_name)
# Out:
#   primary_agency_name    n
# 0  Los Angeles County  424

# %%
df1>>filter(_.locode==5953)>>filter(_.primary_agency_name==('Pico Rivera'))
# Out:
# Empty DataFrame
# Columns: [location, prefix, project_no, agency, prepared_date, submit__to_hq_date, hq_review_date, submit_to_fhwa_date, to_fmis_date, fed_requested, ac_requested, total_requested, status_comment, locode, dist, status, dist_processing_days, hq_processing_days, fhwa_processing_days, ftip_no, project_location, type_of_work, seq, date_request_initiated, date_completed_request, mpo, warning, projectID, projectNO, compare_id_locode, primary_agency_name]
# Index: []

# %%
df1>>filter(_.agency.str.contains('Los Angeles'))>>group_by(_.agency, _.primary_agency_name)>>count(_.locode)
# Out:
#                                               agency  \
# 0                                        Los Angeles
# 1                                        Los Angeles
# 2                                 Los Angeles County
# 3                                 Los Angeles County
# 4                                 Los Angeles County
# 5  Los Angeles County Metropolitan Transportation...
# 6                Los Angeles Unified School District
#
#                                  primary_agency_name locode    n
# 0                                        Los Angeles   5006  423
# 1                                 Los Angeles County   5953   12
# 2                                   Calaveras County   5930    1
# 3                                 Los Angeles County   5953  404
# 4                                        Pico Rivera   5351    3
# 5  Los Angeles County Metropolitan Transportation...   6065   84
# 6                Los Angeles Unified School District   6508    2

# %% [markdown]
# ### Comparing names

# %%
compare_names = np.where(df1["agency"] == df1["primary_agency_name"], True, False)
df1["compare_names"] = compare_names

# %%
df1.compare_names.value_counts()
# Out:
# True     17885
# False     2232
# Name: compare_names, dtype: int64

# %%
df1>>filter(_.compare_names==False)>>select(_.agency, _.primary_agency_name, _.locode)
# Out:
#                                                   agency  \
# 50        Southern California Association Of Governments
# 78     City/County Association Of Governments Of San ...
# 128    City & County Of San Francisco, Mta/Parking & ...
# 140                                    San Buena Ventura
# 219                 San Diego Association Of Governments
# ...                                                  ...
# 20112                                        Bay Area Rt
# 20113                                               Mctd
# 20114                                                Vta
# 20115                                    Ala-Con Costa T
# 20116                                           Caltrans
#
#                                      primary_agency_name locode
# 50        Southern California Association of Governments   6049
# 78     City/County Association of Governments of San ...   6419
# 128    City & County of San Francisco, MTA/Parking & ...   6328
# 140                                     San Buenaventura   5026
# 219                 San Diego Association of Governments   6066
# ...                                                  ...    ...
# 20112      San Francisco Bay Area Rapid Transit District   6000
# 20113                      Marin County Transit District   6343
# 20114        Santa Clara Valley Transportation Authority   6264
# 20115            Alameda - Contra Costa Transit District   6002
# 20116                                                NaN   7504
#
# [2232 rows x 3 columns]

# %%
unmatched = df1>>filter(_.compare_names==False)>>select(_.agency, _.primary_agency_name, _.locode)

# %%
unmatched.primary_agency_name.unique()
# Out:
# array(['Southern California Association of Governments',
#        'City/County Association of Governments of San Mateo County',
#        'City & County of San Francisco, MTA/Parking & Traffic',
#        'San Buenaventura', 'San Diego Association of Governments',
#        'Kern County Council of Governments', 'Modoc County',
#        'Yuba County', 'Butte County',
#        'Sacramento Area Council of Governments',
#        'Stanislaus Council of Governments',
#        'Transportation Agency for Monterey County',
#        'Coachella Valley Association of Governments',
#        'San Gabriel Valley Council of Governments',
#        'San Joaquin Council of Governments',
#        'Department of Water Resources',
#        'Yosemite Area Regional Transportation System JPA',
#        'Merced County Association of Governments', 'OmniTrans',
#        'University of California - Davis', 'Santa Cruz County',
#        'San Luis Obispo Council of Governments',
#        'Department of Parks and Recreation',
#        'SouthWest Transportation Agency',
#        'Transportation Authority of Marin', nan, 'Calabasas',
#        'Butte County Association of Governments',
#        'University of California at San Francisco',
#        'Santa Barbara County Association of Governments',
#        'University of California - Santa Barbara',
#        'Metropolitan Transportation Commission - SAFE',
#        'San Francisco Department of Public Health',
#        'Council of Fresno County Governments',
#        'Calaveras Council of Governments', 'Los Angeles County',
#        'Mariposa County', 'Morro Bay', 'San Bernardino County',
#        'Kern County Superintendent of Schools', 'Merced County',
#        'U.S. Forest Service, Pacific Southwest Region',
#        'San Diego County', 'Imperial County',
#        'Council of San Benito County Governments', 'Riverside County',
#        'Napa County Office of Education', 'Kern County (District 9)',
#        'Pico Rivera', 'Port of San Francisco',
#        'San Diego Metropolitan Transit System',
#        'San Francisco Bay Area Water Transit Authority',
#        'Los Angeles County Metropolitan Transportation Authority',
#        'Yreka City', 'Napa County', 'Indio', 'Calaveras County',
#        'San Francisco Bay Area Rapid Transit District',
#        'Marin County Transit District',
#        'Santa Clara Valley Transportation Authority',
#        'Alameda - Contra Costa Transit District'], dtype=object)

# %%
unmatched >> group_by(_.primary_agency_name) >> summarize(n=_.agency.nunique()) >> arrange(-_.n) >>filter(_.n>1)
# Out:
#                               primary_agency_name  n
# 18                             Los Angeles County  4
# 25                                   Modoc County  3
# 34                          San Bernardino County  3
# 11             Department of Parks and Recreation  2
# 21                                Mariposa County  2
# 37                               San Diego County  2
# 53  U.S. Forest Service, Pacific Southwest Region  2
# 59                                    Yuba County  2

# %%
#running through these matches and checking to make sure they are already documented in `issues_dla_data_locode.xlsx`
unmatched >> filter(_.primary_agency_name=='Yuba County') >> arrange(_.agency)
# Out:
#                 agency primary_agency_name locode
# 14515    Shasta County         Yuba County   5916
# 15282    Shasta County         Yuba County   5916
# 19517    Shasta County         Yuba County   5916
# 273    Tuolumne County         Yuba County   5916
# 14100  Tuolumne County         Yuba County   5916
# 16358  Tuolumne County         Yuba County   5916

# %% [markdown]
# #### Adding
# *  Tuolumne County/Yuba County

# %%
## looking at the agencies with 1 match

# %%
unmatched >> group_by(_.primary_agency_name) >> summarize(n=_.agency.nunique()) >> arrange(-_.n) >>filter(_.n==1)
# Out:
#                                   primary_agency_name  n
# 0             Alameda - Contra Costa Transit District  1
# 1                                        Butte County  1
# 2             Butte County Association of Governments  1
# 3                                           Calabasas  1
# 4                    Calaveras Council of Governments  1
# 5                                    Calaveras County  1
# 6   City & County of San Francisco, MTA/Parking & ...  1
# 7   City/County Association of Governments of San ...  1
# 8         Coachella Valley Association of Governments  1
# 9                Council of Fresno County Governments  1
# 10           Council of San Benito County Governments  1
# 12                      Department of Water Resources  1
# 13                                    Imperial County  1
# 14                                              Indio  1
# 15                           Kern County (District 9)  1
# 16                 Kern County Council of Governments  1
# 17              Kern County Superintendent of Schools  1
# 19  Los Angeles County Metropolitan Transportation...  1
# 20                      Marin County Transit District  1
# 22                                      Merced County  1
# 23           Merced County Association of Governments  1
# 24      Metropolitan Transportation Commission - SAFE  1
# 26                                          Morro Bay  1
# 27                                        Napa County  1
# 28                    Napa County Office of Education  1
# 29                                          OmniTrans  1
# 30                                        Pico Rivera  1
# 31                              Port of San Francisco  1
# 32                                   Riverside County  1
# 33             Sacramento Area Council of Governments  1
# 35                                   San Buenaventura  1
# 36               San Diego Association of Governments  1
# 38              San Diego Metropolitan Transit System  1
# 39      San Francisco Bay Area Rapid Transit District  1
# 40     San Francisco Bay Area Water Transit Authority  1
# 41          San Francisco Department of Public Health  1
# 42          San Gabriel Valley Council of Governments  1
# 43                 San Joaquin Council of Governments  1
# 44             San Luis Obispo Council of Governments  1
# 45    Santa Barbara County Association of Governments  1
# 46        Santa Clara Valley Transportation Authority  1
# 47                                  Santa Cruz County  1
# 48                    SouthWest Transportation Agency  1
# 49     Southern California Association of Governments  1
# 50                  Stanislaus Council of Governments  1
# 51          Transportation Agency for Monterey County  1
# 52                  Transportation Authority of Marin  1
# 54                   University of California - Davis  1
# 55           University of California - Santa Barbara  1
# 56          University of California at San Francisco  1
# 57   Yosemite Area Regional Transportation System JPA  1
# 58                                         Yreka City  1

# %%
unmatched >> filter(_.primary_agency_name=='Yreka City') >> arrange(_.agency)
# Out:
#               agency primary_agency_name locode
# 18987  Sonoma County          Yreka City   5020
# 18988  Sonoma County          Yreka City   5020
# 18989  Sonoma County          Yreka City   5020

# %% [markdown]
# #### Adding to Unmatched:
# * Sonoma County/Yreka City
# * Shasta County/Napa County
# * Ora Co Trans Au/Morro Bay

# %%
## Checking for the true location of the

# %%
len(df1>>filter(_.agency=='Solano County Transit')>>filter(_.locode==6503))
# Out:
# 1

# %%
df1>>filter(_.agency=='Solano County Transit')>>filter(_.locode==6503)
# Out:
#              location  prefix project_no                 agency prepared_date  \
# 8617  FTA Transferred  FTACML  6503(001)  Solano County Transit    2015-06-02
#
#      submit__to_hq_date hq_review_date submit_to_fhwa_date to_fmis_date  \
# 8617         2015-06-02     2015-06-02          2015-07-16   2015-07-23
#
#       fed_requested  ac_requested  total_requested  status_comment locode  \
# 8617      6000000.0           0.0        6000000.0  Prog Code M0E3   6503
#
#       dist                        status  dist_processing_days  \
# 8617     4  FTA transferred on 7/23/2015                   0.0
#
#       hq_processing_days  fhwa_processing_days ftip_no project_location  \
# 8617                44.0                   7.0     NaN              NaN
#
#       type_of_work  seq date_request_initiated date_completed_request  mpo  \
# 8617  FTA Transfer    1                    NaN                    NaN  MTC
#
#      warning projectID  projectNO  compare_id_locode primary_agency_name  \
# 8617     NaN      6503          1               True                 NaN
#
#       compare_names
# 8617          False

# %% [markdown]
# ## Finding agencies and string locodes

# %%
errors = (df[df['locode'].apply(lambda x: isinstance(x, str))])

# %%
print(len(errors))
# Out:
# 9

# %%
errors>>count(_.locode)>>arrange(-_.n)
# Out:
#   locode  n
# 3   40A0  3
# 4   NBIL  3
# 0   32L0  1
# 1   38R0  1
# 2   38Y0  1

# %%
errors>>count(_.projectID)>>arrange(-_.n)
# Out:
#   projectID  n
# 3      40A0  3
# 4      NBIL  3
# 0      32L0  1
# 1      38R0  1
# 2      38Y0  1

# %%
errors2 = (df[df['projectID'].apply(lambda x: isinstance(x, str))])

# %%
print(len(errors2))
# Out:
# 20117

# %%
errors2>>count(_.projectID)>>arrange(-_.n)
# Out:
#     projectID     n
# 39       32L0  1136
# 77       5006   479
# 125      5060   459
# 551      5950   276
# 171      5109   270
# ..        ...   ...
# 704       769     1
# 705       804     1
# 709      NBIS     1
# 710      TC03     1
# 711      X075     1
#
# [712 rows x 2 columns]

# %%
errors2>>count(_.locode)>>arrange(-_.n)
# Out:
#     locode    n
# 428   5904  627
# 53    5060  459
# 460   5936  446
# 477   5953  424
# 4     5006  423
# ..     ...  ...
# 614   6503    1
# 621   7504    1
# 623   32L0    1
# 624   38R0    1
# 625   38Y0    1
#
# [628 rows x 2 columns]

# %%
errors_total = pd.concat([errors, errors2], ignore_index=True)

# %%
errors_total.head()
# Out:
#     location prefix project_no       agency prepared_date submit__to_hq_date  \
# 0  Obligated     BR  NBIL(537)    La Quinta    2019-04-10         2019-04-10
# 1  Obligated  ACSTP  40A0(038)    Mendocino    2019-12-20         2019-12-20
# 2  Obligated     BR  NBIL(537)    La Quinta    2020-11-16         2020-12-22
# 3  Obligated  ACSTP  38Y0(002)  Los Angeles    2021-02-03         2021-02-22
# 4  Obligated     BR  NBIL(546)      Yucaipa    2020-08-11         2021-01-19
#
#   hq_review_date submit_to_fhwa_date to_fmis_date  fed_requested  \
# 0     2019-04-11          2019-04-11   2019-04-24       482489.0
# 1     2020-01-10          2020-01-17   2020-01-22            0.0
# 2     2021-01-12          2021-01-14   2021-01-19       684337.0
# 3     2021-02-24          2021-03-09   2021-03-18            0.0
# 4     2021-02-24          2021-02-25   2021-03-09            0.0
#
#    ac_requested  total_requested status_comment locode  dist  \
# 0          0.00        545000.00     Authorized   NBIL     8
# 1      31039.00         35060.00     Authorized   40A0     1
# 2          0.00       1003409.00     Authorized   NBIL     8
# 3    2967985.57       3330361.43     Authorized   38Y0     7
# 4     663975.00        750000.00     Authorized   NBIL     8
#
#               status  dist_processing_days  hq_processing_days  \
# 0  E-76 approved on                    0.0                 1.0
# 1  E-76 approved on                    2.0                28.0
# 2  E-76 approved on                   36.0                23.0
# 3  E-76 approved on                   19.0                15.0
# 4  E-76 approved on                  183.0                37.0
#
#    fhwa_processing_days    ftip_no  \
# 0                  13.0  RIV121202
# 1                   5.0        NaN
# 2                   5.0  RIV121202
# 3                   9.0        NaN
# 4                  12.0    SBDLS08
#
#                                     project_location  \
# 0  Dune Palms Road Over Coachella Valley Stormwat...
# 1                 Mountain View Road Pm 1.65, Cr 510
# 2  Dune Palms Road Over Coachella Valley Stormwat...
# 3              Mulholland Highway Over Triunfo Creek
# 4  Fremont Street Over Wilson Creek From Oak Glen...
#
#                                         type_of_work  seq  \
# 0  Replace A 3-lane Low Water Crossing With A 4-l...    1
# 1  Excavate Slide Material, Stabilize With Rsp An...    1
# 2    Replace Low Water Crossing With A 4-lane Bridge    2
# 3  Demolition And Removal Of Burnt Bridge; Instal...    1
# 4  Environmental Mitigation As A Component Of Nbi...    1
#
#   date_request_initiated date_completed_request      mpo warning projectID  \
# 0             2019-04-10             2019-04-10     SCAG     NaN      NBIL
# 1             2019-12-18             2019-12-20  NON-MPO     NaN      40A0
# 2             2020-11-16             2020-11-16     SCAG     NaN      NBIL
# 3             2021-02-03             2021-02-03     SCAG     NaN      38Y0
# 4             2020-07-20             2020-12-10     SCAG     NaN      NBIL
#
#    projectNO  compare_id_locode
# 0        537               True
# 1         38               True
# 2        537               True
# 3          2               True
# 4        546               True

# %%
errors_total.duplicated().sum()
# Out:
# 9

# %%
errors_total.drop_duplicates(inplace=True)

# %%
compare_locode = np.where(errors_total["locode"] == errors_total["projectID"], True, False)
errors_total["compare_error_locodes"] = compare_locode

# %%
errors_total.compare_error_locodes.value_counts()
# Out:
# False    20108
# True         9
# Name: compare_error_locodes, dtype: int64

# %%
errors_total >> filter(_.compare_error_locodes==True)>>count(_.agency, _.prefix)
# Out:
#            agency prefix  n
# 0    Grass Valley  ACSTP  1
# 1       La Quinta     BR  2
# 2     Los Angeles  ACSTP  1
# 3       Mendocino  ACSTP  1
# 4  San Bernardino  ACSTP  2
# 5      Santa Cruz  ACSTP  1
# 6         Yucaipa     BR  1

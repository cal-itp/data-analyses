# %% [markdown]
# # Obligations in District 10
#
# Using data from the Division of Local Assistance [Obligation list](https://dot.ca.gov/programs/local-assistance/reports/e-76-obligated)

# %%
import numpy as np
import pandas as pd
from siuba import *

import altair as alt
import altair_saver
from plotnine import *

from IPython.display import Markdown

from shared_utils import altair_utils
from shared_utils import geography_utils
from shared_utils import calitp_color_palette as cp
from shared_utils import styleguide

from calitp import to_snakecase
import intake

import clean_data
import _dla_utils

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
#df = _clean_data.make_clean_data()
df= pd.read_parquet("dla_df.parquet")

# %%
#parameters cell
subset = 10

# %%
df.sample()
# Out:
#         location  prefix project_no             agency prepared_date  \
# 18522  Obligated  STPCML  5924(222)  Sacramento County    2021-03-03
#
#       submit__to_hq_date hq_review_date submit_to_fhwa_date to_fmis_date  \
# 18522         2021-03-03     2021-03-03          2021-03-03   2021-03-05
#
#        fed_requested  ...   ftip_no  \
# 18522           0.00  ...  SAC24625
#
#                                         project_location  \
# 18522  Hazel Ave Btwn Curragh Downs Drive And Sunset ...
#
#                                 type_of_work seq  date_request_initiated  \
# 18522  Road Widening And Ped/bike Facilities   2              2021-02-25
#
#       date_completed_request    mpo  projectID  prepared_y primary_agency_name
# 18522             2021-02-26  SACOG       5924    2,021.00   Sacramento County
#
# [1 rows x 29 columns]

# %%
df = (df>>filter(_.dist==subset))

# %%
df_years = _dla_utils.count_all_years(df)

# %%
df_years
# Out:
#    prepared_y  dist  ac_requested_sum  fed_requested_sum  total_requested_sum  \
# 8        2021    10      2,157,720.70      41,198,040.68        52,975,882.79
# 7        2020    10     -3,478,058.76      85,299,546.72       350,173,497.15
# 6        2019    10      9,112,268.45     128,604,727.82       146,082,897.87
# 0        2018    10      5,279,122.45      69,297,099.88        90,357,990.92
# 1        2017    10     15,847,048.00      87,032,288.52       115,556,868.50
# 2        2016    10    -20,717,404.00     125,715,796.11       123,437,079.25
# 3        2015    10     -2,522,131.00      55,833,316.99        76,113,056.95
# 4        2014    10     23,239,535.00      70,565,097.42       114,193,397.20
# 5        2013    10              0.00         339,817.00           243,494.00
#
#    ac_requested_mean  fed_requested_mean  total_requested_mean  unique_mpo  \
# 8          10,373.66          198,067.50            254,691.74           6
# 7         -13,124.75          321,885.08          1,321,409.42           5
# 6          32,428.00          457,668.07            519,867.96           6
# 0          15,758.57          206,857.01            269,725.35           6
# 1          57,209.56          314,195.99            417,172.81           5
# 2         -75,336.01          457,148.35            448,862.11           4
# 3          -9,663.34          213,920.75            291,620.91          11
# 4          78,511.94          238,395.60            385,788.50          11
# 5               0.00           67,963.40             48,698.80           2
#
#    unique_prefix  unique_primary_agency_name  unique_project_location  \
# 8             25                          35                      167
# 7             25                          38                      219
# 6             31                          44                      242
# 0             27                          44                      243
# 1             26                          39                      220
# 2             23                          39                      243
# 3             29                          40                      226
# 4             30                          42                      258
# 5              4                           5                        5
#
#    unique_project_no  unique_type_of_work
# 8                171                  147
# 7                234                  196
# 6                246                  205
# 0                257                  216
# 1                225                  174
# 2                254                  196
# 3                230                  186
# 4                263                  205
# 5                  5                    5

# %%
df_top = _dla_utils.find_top(df)

# %%
df_top
# Out:
#         value  count             variable
# 0         CML    755               prefix
# 1        STPL    377               prefix
# 2       HSIPL    219               prefix
# 3        BRLO    207               prefix
# 4        BRLS    103               prefix
# ..        ...    ...                  ...
# 16    Oakdale     31  primary_agency_name
# 17  Patterson     31  primary_agency_name
# 18    Gustine     22  primary_agency_name
# 19    Jackson     22  primary_agency_name
# 0          10   2203                 dist
#
# [134 rows x 3 columns]

# %% [markdown]
# ## Which Agencies have Obligations

# %% [markdown]
# ### How many Unique Agencies

# %%
_dla_utils.calculate_data_all(df, 'primary_agency_name', aggfunc="nunique")
# Out:
#    dist  primary_agency_name
# 0    10                   56

# %%
df>>count(_.primary_agency_name)>>arrange(-_.n)
# Out:
#                                  primary_agency_name    n
# 38                                San Joaquin County  266
# 44                                          Stockton  261
# 29                                           Modesto  243
# 43                                 Stanislaus County  202
# 9                                   Calaveras County  120
# 27                                     Merced County  119
# 51                                           Turlock   87
# 11                                             Ceres   86
# 49                                   Tuolumne County   82
# 26                                            Merced   62
# 25                                   Mariposa County   58
# 36                                         Riverbank   43
# 42                 Stanislaus Council of Governments   40
# 47                                             Tracy   40
# 2                                      Amador County   36
# 6                                            Atwater   31
# 32                                           Oakdale   31
# 33                                         Patterson   31
# 15                                           Gustine   22
# 18                                           Jackson   22
# 20                                        Livingston   22
# 31                                            Newman   21
# 37                San Joaquin Council of Governments   19
# 24                                           Manteca   18
# 16                                           Hughson   17
# 21                                              Lodi   16
# 35                                             Ripon   16
# 54  Yosemite Area Regional Transportation System JPA   16
# 48  Transit Joint Powers Authority For Merced County   15
# 46                                      Sutter Creek   14
# 5                                             Angels   13
# 34                                          Plymouth   13
# 23                                         Los Banos   12
# 28          Merced County Association of Governments   10
# 39              San Joaquin Regional Rail Commission    9
# 0                                      Alpine County    8
# 45                            Stockton Port District    8
# 53                                         Waterford    8
# 7                                          Calabasas    7
# 41                                            Sonora    7
# 8                   Calaveras Council of Governments    6
# 13                                         Dos Palos    6
# 40             San Joaquin Regional Transit District    6
# 12                     Department of Water Resources    5
# 14                                           Escalon    4
# 19                                           Lathrop    3
# 30                                      Modoc County    3
# 52     U.S. Forest Service, Pacific Southwest Region    3
# 55                                       Yuba County    3
# 1                                        Amador City    2
# 3            Amador County Transportation Commission    2
# 4                        Amador Rapid Transit System    2
# 17                                              Ione    2
# 22                      Lodi Unified School District    2
# 50            Tuolumne County Transportation Council    2
# 10                                          Caltrans    1

# %% [markdown]
# ### Agencies with the most Obligations

# %%
df_top>>filter(_.variable == 'primary_agency_name')
# Out:
#                                 value  count             variable
# 0                  San Joaquin County    266  primary_agency_name
# 1                            Stockton    261  primary_agency_name
# 2                             Modesto    243  primary_agency_name
# 3                   Stanislaus County    202  primary_agency_name
# 4                    Calaveras County    120  primary_agency_name
# 5                       Merced County    119  primary_agency_name
# 6                             Turlock     87  primary_agency_name
# 7                               Ceres     86  primary_agency_name
# 8                     Tuolumne County     82  primary_agency_name
# 9                              Merced     62  primary_agency_name
# 10                    Mariposa County     58  primary_agency_name
# 11                          Riverbank     43  primary_agency_name
# 12  Stanislaus Council of Governments     40  primary_agency_name
# 13                              Tracy     40  primary_agency_name
# 14                      Amador County     36  primary_agency_name
# 15                            Atwater     31  primary_agency_name
# 16                            Oakdale     31  primary_agency_name
# 17                          Patterson     31  primary_agency_name
# 18                            Gustine     22  primary_agency_name
# 19                            Jackson     22  primary_agency_name

# %% [markdown]
# ### Agencies with the least Obligations

# %%
(df>>count(_.primary_agency_name)>>arrange(-_.n)).tail(10)
# Out:
#                               primary_agency_name  n
# 30                                   Modoc County  3
# 52  U.S. Forest Service, Pacific Southwest Region  3
# 55                                    Yuba County  3
# 1                                     Amador City  2
# 3         Amador County Transportation Commission  2
# 4                     Amador Rapid Transit System  2
# 17                                           Ione  2
# 22                   Lodi Unified School District  2
# 50         Tuolumne County Transportation Council  2
# 10                                       Caltrans  1

# %%
df>>filter(_.prefix=="CML")>>select(_.primary_agency_name,_.type_of_work)>>count(_.type_of_work)>>arrange(-_.n)>>filter(_.n<4)
# Out:
#                                           type_of_work  n
# 19                              Class I Bike Trail(tc)  3
# 22                         Construct A Right Turn Lane  3
# 31   Construct Curb, Gutter, Sidewalk, Drainage, An...  3
# 35                  Construct New Traffic Signals (tc)  3
# 40                        Construct Pedestrian Infills  3
# ..                                                 ... ..
# 280                      Transit Fare Subsidy Program.  1
# 281  Transit Fare Subsidy(tfs) Start/max Employee R...  1
# 284  Transportation Management Center Equipment. - ...  1
# 290  Upgrade The Atms Software And Communications F...  1
# 291  Upgrade Traffic Signal Systems With Communicat...  1
#
# [243 rows x 2 columns]

# %% [markdown]
# ## Transit Funding

# %%
transit = df[df['type_of_work'].str.contains(
              'Transit|tranist|bus|Bus|Yarts|Rideshare',
              case=False, na=False)]

# %%
print(f"Out of {len(df)} obligations, {len(transit)} are transit related")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1604/2567789183.py in <module>
# ----> 1 print(f"Out of {len(df)} obligations, {len(transit)} are transit related")
#
# NameError: name 'df' is not defined

# %%
len(transit)
# Out:
# 126

# %%
transit>>count(_.primary_agency_name)>>arrange(-_.n)
# Out:
#                                  primary_agency_name   n
# 4                                            Modesto  23
# 9                                  Stanislaus County  22
# 8                  Stanislaus Council of Governments  18
# 13  Yosemite Area Regional Transportation System JPA  13
# 10                                          Stockton  12
# 11  Transit Joint Powers Authority For Merced County  12
# 6                 San Joaquin Council of Governments   8
# 7                                             Sonora   4
# 12                                   Tuolumne County   4
# 2                                    Mariposa County   3
# 0                                   Calaveras County   2
# 1                       Lodi Unified School District   2
# 5                                              Ripon   2
# 3                                             Merced   1

# %%
#transit>>group_by(_.prefix)>>count(_.type_of_work)>>arrange(-_.n)

# %%
transit>>count(_.type_of_work)>>arrange(-_.n)
# Out:
#                                          type_of_work   n
# 17                         Regional Rideshare Program  13
# 13   Public Outreach And Marketing For "the Bus" (tc)   9
# 23                                  Rideshare Program   6
# 24                             Rideshare Program (tc)   6
# 43           Yarts Public Outreach And Marketing (tc)   6
# 1       Const Ped,transit Facility And Traffic Improv   4
# 27  San Joaquin County And Merced County Regional ...   4
# 6                                 Install Bus Turnout   3
# 7                            Install Bus Turnout (tc)   3
# 10  New Stanislaus Regional Transit Commuter Expre...   3
# 15  Purchase Of Alterative Fuel School Bus With Cm...   3
# 20  Regional Rideshare Program For City Of Modesto...   3
# 22                                     Rideshare (tc)   3
# 31  Signal Prioritization Equipment For Bus Rapid ...   3
# 32                Stanislaus County Rideshare Program   3
# 33                Tdm Regional Rideshare Program (tc)   3
# 36                       Transit Fare Subsidy Program   3
# 37  Transit Fare Subsidy Program Start/max Employe...   3
# 4   Guardrail. Upgrade The Existing Guardrails Wit...   2
# 5   Install And Implement Signal Prioritization Eq...   2
# 8   Install Guardrail, Transition Railing And Cush...   2
# 9   Install Guardrail, Transition Railing And Cush...   2
# 14       Public Outreach And Marketing For Yarts (tc)   2
# 18                    Regional Rideshare Program (ni)   2
# 21                   Regional Rideshare Program. (tc)   2
# 28                             School Bus Replacement   2
# 29  Sidewalks, Curb&gutter, Bus Stop, Crosswalks (tc)   2
# 30  Sidewalks, Curb, Gutter, Bus Stops, And Crossw...   2
# 35  Transit Fare Subsidy (tfs) Start/max Employee ...   2
# 40        Transit Fare Subsidy- Employee Ride Program   2
# 41  Transit Related - Purchase Of One Cng Solid Wa...   2
# 42  Upgrade Existing Guardrails, End Caps/flared E...   2
# 45  Yosemite Area Regional Transportation System (...   2
# 46  Yosemite Area Regional Transportation System (...   2
# 0          Accuring Bus Wraps For Public Outreach(tc)   1
# 2   Design And Construction Of Parking Area And Tr...   1
# 3   Guardrail. Upgrade The Existing Guardrails Wit...   1
# 11  New Stanislaus Regional Transit Express Bus Route   1
# 12  Public Outreach & Marketing For "the Bus" Tran...   1
# 16        Regional Rideshare Includes Public Outreach   1
# 19    Regional Rideshare Program (non-infrastructure)   1
# 25            Rideshare Program City Of Modesto. (tc)   1
# 26                    Rideshare Program For Employees   1
# 34  Tjpamc: Public Outreach & Marketing For "the B...   1
# 38                      Transit Fare Subsidy Program.   1
# 39  Transit Fare Subsidy(tfs) Start/max Employee R...   1
# 44  Yarts: Public Outreach And Marketing (yosemite...   1

# %%
transit>>count(_.prefix)>>arrange(-_.n)
# Out:
#    prefix    n
# 0     CML  104
# 3   HSIPL    9
# 1   CMLNI    8
# 4  RPSTPL    4
# 2  DEM06U    1

# %%
transit_agencies = df[df['primary_agency_name'].str.contains(
              'Transit|tranist|Rail',
              case=False, na=False)]

# %%
transit_agencies>>count(_.primary_agency_name)
# Out:
#                                 primary_agency_name   n
# 0                       Amador Rapid Transit System   2
# 1              San Joaquin Regional Rail Commission   9
# 2             San Joaquin Regional Transit District   6
# 3  Transit Joint Powers Authority For Merced County  15

# %%
transit_agencies>>count(_.type_of_work)>>arrange(-_.n)
#using this to determine how many FTA transfers there are
# Out:
#                                         type_of_work   n
# 1                                       FTA Transfer  17
# 6   Public Outreach And Marketing For "the Bus" (tc)   9
# 0         Accuring Bus Wraps For Public Outreach(tc)   1
# 2  In Stockton, Near The Robert J. Cabral Station...   1
# 3  In Stockton, Near The Robert J. Cabral Station...   1
# 4         Install Decorative Bike Racks At Brt Stops   1
# 5  Public Outreach & Marketing For "the Bus" Tran...   1
# 7  Tjpamc: Public Outreach & Marketing For "the B...   1

# %%
_dla_utils.calculate_data_all(transit_agencies, 'total_requested', aggregate_by='primary_agency_name', aggfunc="mean")
# Out:
#                                 primary_agency_name  total_requested
# 2             San Joaquin Regional Transit District     3.748224e+06
# 1              San Joaquin Regional Rail Commission     2.244211e+06
# 3  Transit Joint Powers Authority For Merced County     2.722599e+05
# 0                       Amador Rapid Transit System     2.111300e+05

# %% [markdown]
# ### Charting

# %%
_dla_utils.basic_bar_chart((df_top>>filter(_.variable=='primary_agency_name')), 'value', 'count', 'value', subset, 'Agencies With The Most Obligations')
# Out:
# alt.Chart(...)

# %%
df_top>>filter(_.variable=='prefix')
# Out:
#      value  count variable
# 0      CML    755   prefix
# 1     STPL    377   prefix
# 2    HSIPL    219   prefix
# 3     BRLO    207   prefix
# 4     BRLS    103   prefix
# 5       ER     82   prefix
# 6    HRRRL     76   prefix
# 7    BPMPL     61   prefix
# 8     ATPL     31   prefix
# 9   RPSTPL     31   prefix
# 10   HPLUL     26   prefix
# 11  FTACML     19   prefix
# 12    BPMP     18   prefix
# 13   CMLNI     18   prefix
# 14  ATPCML     16   prefix
# 15   ACSTP     12   prefix
# 16   FERPL     12   prefix
# 17   SRTSL     11   prefix
# 18  STPCML     10   prefix
# 19    BHLS      7   prefix

# %%
df>>group_by(_.primary_agency_name)>>count(_.prefix)>>arrange(-_.n)
# Out:
#                                   primary_agency_name  prefix    n
# 107                                           Modesto     CML  138
# 197                                          Stockton   HSIPL   90
# 192                                          Stockton     CML   84
# 157                                San Joaquin County    STPL   75
# 177                                 Stanislaus County     CML   66
# ..                                                ...     ...  ...
# 216                                             Tracy  DEM03L    1
# 217                                             Tracy  FTACML    1
# 220  Transit Joint Powers Authority For Merced County   CMLNI    1
# 223                                   Tuolumne County    BPMP    1
# 242  Yosemite Area Regional Transportation System JPA   CMLNI    1
#
# [244 rows x 3 columns]

# %% [markdown]
# ## Number of Unique Prefix Codes

# %%
_dla_utils.get_nunique(df, 'prefix', 'primary_agency_name')
# Out:
#                                  primary_agency_name   n
# 44                                          Stockton  23
# 29                                           Modesto  17
# 43                                 Stanislaus County  15
# 9                                   Calaveras County  11
# 27                                     Merced County  11
# 38                                San Joaquin County  11
# 25                                   Mariposa County  10
# 49                                   Tuolumne County  10
# 2                                      Amador County   8
# 11                                             Ceres   7
# 18                                           Jackson   6
# 47                                             Tracy   6
# 26                                            Merced   5
# 35                                             Ripon   5
# 37                San Joaquin Council of Governments   5
# 42                 Stanislaus Council of Governments   5
# 51                                           Turlock   5
# 0                                      Alpine County   4
# 8                   Calaveras Council of Governments   4
# 21                                              Lodi   4
# 28          Merced County Association of Governments   4
# 33                                         Patterson   4
# 39              San Joaquin Regional Rail Commission   4
# 5                                             Angels   3
# 16                                           Hughson   3
# 19                                           Lathrop   3
# 23                                         Los Banos   3
# 24                                           Manteca   3
# 32                                           Oakdale   3
# 36                                         Riverbank   3
# 46                                      Sutter Creek   3
# 48  Transit Joint Powers Authority For Merced County   3
# 6                                            Atwater   2
# 12                     Department of Water Resources   2
# 15                                           Gustine   2
# 31                                            Newman   2
# 34                                          Plymouth   2
# 40             San Joaquin Regional Transit District   2
# 45                            Stockton Port District   2
# 53                                         Waterford   2
# 54  Yosemite Area Regional Transportation System JPA   2
# 1                                        Amador City   1
# 3            Amador County Transportation Commission   1
# 4                        Amador Rapid Transit System   1
# 7                                          Calabasas   1
# 10                                          Caltrans   1
# 13                                         Dos Palos   1
# 14                                           Escalon   1
# 17                                              Ione   1
# 20                                        Livingston   1
# 22                      Lodi Unified School District   1
# 30                                      Modoc County   1
# 41                                            Sonora   1
# 50            Tuolumne County Transportation Council   1
# 52     U.S. Forest Service, Pacific Southwest Region   1
# 55                                       Yuba County   1

# %%
_dla_utils.basic_bar_chart(((_dla_utils.get_nunique(df, 'prefix', 'primary_agency_name')).head(30)),
                            'primary_agency_name', 'n', 'primary_agency_name', subset, 'Agencies With The Most Unique Prefix Codes')
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Most Common Types of Work by Agnecy

# %%
_dla_utils.get_nunique(df, 'primary_agency_name', 'type_of_work')
# Out:
#                                           type_of_work   n
# 58                                  Bridge Replacement  14
# 59                             Bridge Replacement (tc)  10
# 182                                       FTA Transfer   8
# 47                       Bridge Preventive Maintenance   6
# 51                               Bridge Rehabilitation   5
# ..                                                 ...  ..
# 806  Widening Road, C&g, Lights, Landscape, Restris...   1
# 807           Yarts Public Outreach And Marketing (tc)   1
# 808  Yarts: Public Outreach And Marketing (yosemite...   1
# 809  Yosemite Area Regional Transportation System (...   1
# 810  Yosemite Area Regional Transportation System (...   1
#
# [811 rows x 2 columns]

# %%
_dla_utils.calculate_data_head(df, "primary_agency_name",'type_of_work', aggfunc="count")
# Out:
#                                          type_of_work  primary_agency_name
# 59                            Bridge Replacement (tc)                  171
# 58                                 Bridge Replacement                   59
# 47                      Bridge Preventive Maintenance                   43
# 414                      Pavement Rehabilitation (tc)                   32
# 182                                      FTA Transfer                   24
# 671                                        Roundabout                   15
# 563         Repairs To Existing Scour Countermeasures                   15
# 506                        Regional Rideshare Program                   13
# 54                         Bridge Rehabilitation (tc)                   13
# 413                           Pavement Rehabilitation                   12
# 689                                  Seismic Retrofit                   11
# 19                      Asphalt Concrete Overlay (tc)                   11
# 352                    Intersection Improvements (tc)                   10
# 74                       Complete Street Upgrade (tc)                   10
# 348                          Intersection Improvement                   10
# 654       Roadway Resurfacing And Rehabilitation (tc)                    9
# 302                      Install Right Turn Lane (tc)                    9
# 469  Public Outreach And Marketing For "the Bus" (tc)                    9
# 51                              Bridge Rehabilitation                    9
# 18                           Asphalt Concrete Overlay                    9

# %%
df>>group_by(_.primary_agency_name)>>count(_.type_of_work)>>arrange(-_.n)>>filter(_.n>=8)
# Out:
#                                   primary_agency_name  \
# 271                                     Merced County
# 466                                San Joaquin County
# 570                                 Stanislaus County
# 461                                San Joaquin County
# 53                                   Calaveras County
# 352                                           Modesto
# 512                                San Joaquin County
# 802                                   Tuolumne County
# 225                                   Mariposa County
# 270                                     Merced County
# 465                                San Joaquin County
# 559                 Stanislaus Council of Governments
# 456                                San Joaquin County
# 799                                   Tuolumne County
# 7                                       Amador County
# 174                                           Jackson
# 273                                     Merced County
# 421                                          Plymouth
# 847                                           Turlock
# 124                                             Ceres
# 136                                             Ceres
# 223                                   Mariposa County
# 338                                           Modesto
# 534                                San Joaquin County
# 797  Transit Joint Powers Authority For Merced County
# 170                                           Hughson
# 277                                     Merced County
# 381                                           Modesto
# 552                 Stanislaus Council of Governments
# 842                                           Turlock
#
#                                           type_of_work   n
# 271                            Bridge Replacement (tc)  34
# 466                            Bridge Replacement (tc)  28
# 570                            Bridge Replacement (tc)  28
# 461                      Bridge Preventive Maintenance  25
# 53                             Bridge Replacement (tc)  22
# 352                       Pavement Rehabilitation (tc)  21
# 512          Repairs To Existing Scour Countermeasures  15
# 802                            Bridge Replacement (tc)  15
# 225                            Bridge Replacement (tc)  14
# 270                                 Bridge Replacement  14
# 465                                 Bridge Replacement  14
# 559                         Regional Rideshare Program  13
# 456                      Asphalt Concrete Overlay (tc)  11
# 799                      Bridge Preventive Maintenance  11
# 7                              Bridge Replacement (tc)  10
# 174                            Bridge Replacement (tc)  10
# 273                       Complete Street Upgrade (tc)  10
# 421                           Intersection Improvement  10
# 847                     Intersection Improvements (tc)  10
# 124                                      Bike/ped Path   9
# 136                                            Overlay   9
# 223                         Bridge Rehabilitation (tc)   9
# 338                       Install Right Turn Lane (tc)   9
# 534        Roadway Resurfacing And Rehabilitation (tc)   9
# 797   Public Outreach And Marketing For "the Bus" (tc)   9
# 170    Reconfigure Intersection, Reconstruct Road (tc)   8
# 277                Expanded Pedestrian Sidewalk Infill   8
# 381                       Upgrade Traffic Signals (tc)   8
# 552                 Planning And Monitoring Activities   8
# 842  Installation Of Traffic Signal And Related Int...   8

# %% [markdown]
# ## Most Common Project Locations

# %%
df_top>>filter(_.variable=='project_location')
# Out:
#                                                 value  count          variable
# 0                                In Stanislaus County     12  project_location
# 1                                   Stanislaus County     12  project_location
# 2                                     City Of Atwater     11  project_location
# 3                                     City Of Modesto     10  project_location
# 4                        Throughout Stanislaus County     10  project_location
# 5               Wb D Street To Nb 9th Street (sr 132)      9  project_location
# 6            Tully Rd. From Santa Fe To Whitmore Ave.      8  project_location
# 7   11th Street - East Tracy Overhead (bridge 29c0...      7  project_location
# 8     Baxter Road Over Deadman Creek (bridge 39c0230)      7  project_location
# 9                                    In Merced County      7  project_location
# 10           Intersection Of Main St/sr49 At Plymouth      7  project_location
# 11  Jackson Gate Road At China Graveyard Road, Jac...      7  project_location
# 12             1) Mchenry Ave (sr108) And Grecian Ave      6  project_location
# 13  Along El Dorado Street Between Duncan Avenue A...      6  project_location
# 14  Austin Road Over Nf South Little Johns Creek (...      6  project_location
# 15      Claribel Road At Roselle Avenue Intersection.      6  project_location
# 16  College Ave. To The Intersection Of Stoddard A...      6  project_location
# 17  Dickenson Ferry Road Over Bear Creek (bridge 3...      6  project_location
# 18  Dr. Martin Luther King Jr. Blvd From Fresno Av...      6  project_location
# 19     Golden State Blvd And Fulkerth Rd Intersection      6  project_location

# %% [markdown]
# ## Number of Obligations by Year

# %%
df_top>>filter(_.variable=='prepared_y')
# Out:
#     value  count    variable
# 0  2018.0    335  prepared_y
# 1  2014.0    296  prepared_y
# 2  2019.0    281  prepared_y
# 3  2017.0    277  prepared_y
# 4  2016.0    275  prepared_y
# 5  2020.0    265  prepared_y
# 6  2015.0    261  prepared_y
# 7  2021.0    208  prepared_y
# 8  2013.0      5  prepared_y

# %%
df>>group_by(_.primary_agency_name)>>count(_.prepared_date)>>arrange(-_.n)
# Out:
#                                    primary_agency_name prepared_date   n
# 166                                   Calaveras County    2020-11-04  15
# 702                                            Modesto    2018-04-09  12
# 708                                            Modesto    2018-05-08  11
# 715                                            Modesto    2018-06-05   9
# 719                                            Modesto    2018-06-18   6
# ...                                                ...           ...  ..
# 1843  Yosemite Area Regional Transportation System JPA    2019-07-31   1
# 1844  Yosemite Area Regional Transportation System JPA    2020-01-08   1
# 1845                                       Yuba County    2018-08-15   1
# 1846                                       Yuba County    2019-04-25   1
# 1847                                       Yuba County    2020-04-06   1
#
# [1848 rows x 3 columns]

# %% [markdown]
# ### Chart

# %%
_dla_utils.basic_line_chart((df_top>>filter(_.variable=='prepared_y')), 'value', 'count', subset, 'Obligations by Year')
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Agencies with the most unique project numbers

# %%
df>>group_by(_.primary_agency_name, _.prefix)>>count(_.project_no)>>arrange(-_.n)>>filter(_.n>5)
# Out:
#         primary_agency_name  prefix project_no  n
# 283           Merced County    BRLS  5939(078)  9
# 341                 Modesto     CML  5059(198)  9
# 161                 Hughson    STPL  5411(014)  8
# 273           Merced County    BRLO  5939(084)  7
# 347                 Modesto     CML  5059(207)  7
# 443                Plymouth   HPLUL  5236(003)  7
# 793                   Tracy    BHLS  5192(020)  7
# 841         Tuolumne County   HSIPL  5932(083)  7
# 9             Amador County    BRLO  5926(031)  6
# 119                   Ceres     CML  5241(056)  6
# 169                 Jackson      ER  32L0(148)  6
# 182              Livingston     CML  5256(016)  6
# 313                 Modesto    ATPL  5059(209)  6
# 337                 Modesto     CML  5059(190)  6
# 340                 Modesto     CML  5059(197)  6
# 424                 Oakdale    STPL  5153(035)  6
# 444                Plymouth   HRRRL  5236(004)  6
# 454               Riverbank     CML  5255(051)  6
# 481      San Joaquin County   BPMPL  5929(223)  6
# 482      San Joaquin County   BPMPL  5929(224)  6
# 483      San Joaquin County   BPMPL  5929(226)  6
# 495      San Joaquin County    BRLO  5929(217)  6
# 504      San Joaquin County    BRLS  5929(166)  6
# 513      San Joaquin County  BRNBIF  5929(154)  6
# 558      San Joaquin County    STPL  5929(269)  6
# 623       Stanislaus County    BRLO  5938(196)  6
# 630       Stanislaus County    BRLS  5938(188)  6
# 639       Stanislaus County     CML  5938(181)  6
# 649       Stanislaus County     CML  5938(222)  6
# 651       Stanislaus County     CML  5938(224)  6
# 655       Stanislaus County     CML  5938(239)  6
# 680       Stanislaus County    STPL  5938(220)  6
# 708                Stockton     CML  5008(123)  6
# 744                Stockton   HSIPL  5008(133)  6
# 746                Stockton   HSIPL  5008(135)  6
# 748                Stockton   HSIPL  5008(137)  6
# 779                Stockton    STPL  5008(142)  6
# 787  Stockton Port District    BRLS  6349(002)  6
# 789            Sutter Creek    BRLO  5215(012)  6
# 830         Tuolumne County    BRLS  5932(078)  6
# 831         Tuolumne County     CML  5932(084)  6
# 856                 Turlock     CML  5165(080)  6
# 860                 Turlock     CML  5165(086)  6

# %% [markdown]
# ## Funding Amounts

# %%
_dla_utils.calculate_data_all(df, 'total_requested', 'primary_agency_name', aggfunc="mean")
# Out:
#                                  primary_agency_name  total_requested
# 40             San Joaquin Regional Transit District     3.748224e+06
# 10                                          Caltrans     2.964646e+06
# 45                            Stockton Port District     2.760150e+06
# 39              San Joaquin Regional Rail Commission     2.244211e+06
# 43                                 Stanislaus County     2.180271e+06
# 19                                           Lathrop     1.689527e+06
# 21                                              Lodi     1.390685e+06
# 47                                             Tracy     1.329912e+06
# 22                      Lodi Unified School District     1.148058e+06
# 37                San Joaquin Council of Governments     9.236537e+05
# 7                                          Calabasas     8.854667e+05
# 0                                      Alpine County     7.900634e+05
# 24                                           Manteca     7.750622e+05
# 46                                      Sutter Creek     5.943349e+05
# 34                                          Plymouth     5.282350e+05
# 38                                San Joaquin County     4.383967e+05
# 35                                             Ripon     3.744252e+05
# 41                                            Sonora     3.478895e+05
# 50            Tuolumne County Transportation Council     3.251720e+05
# 2                                      Amador County     2.996500e+05
# 29                                           Modesto     2.884719e+05
# 48  Transit Joint Powers Authority For Merced County     2.722599e+05
# 27                                     Merced County     2.653219e+05
# 15                                           Gustine     2.622074e+05
# 33                                         Patterson     2.466650e+05
# 23                                         Los Banos     2.151776e+05
# 4                        Amador Rapid Transit System     2.111300e+05
# 51                                           Turlock     2.082919e+05
# 25                                   Mariposa County     1.973716e+05
# 49                                   Tuolumne County     1.962135e+05
# 44                                          Stockton     1.888295e+05
# 31                                            Newman     1.688335e+05
# 11                                             Ceres     1.655987e+05
# 32                                           Oakdale     1.423800e+05
# 26                                            Merced     1.407559e+05
# 6                                            Atwater     1.220286e+05
# 36                                         Riverbank     1.187888e+05
# 9                                   Calaveras County     1.178873e+05
# 42                 Stanislaus Council of Governments     1.021031e+05
# 20                                        Livingston     8.999331e+04
# 18                                           Jackson     8.659768e+04
# 5                                             Angels     8.435222e+04
# 53                                         Waterford     6.180084e+04
# 14                                           Escalon     5.608388e+04
# 16                                           Hughson     4.806859e+04
# 54  Yosemite Area Regional Transportation System JPA     4.249680e+04
# 28          Merced County Association of Governments     3.840580e+04
# 17                                              Ione     2.766005e+04
# 55                                       Yuba County     2.696798e+04
# 30                                      Modoc County     1.742033e+04
# 13                                         Dos Palos     1.651150e+04

# %%
df.describe()
# Out:
#        fed_requested   ac_requested  total_requested     dist  \
# count       2,203.00       2,203.00         2,203.00 2,203.00
# mean      301,355.30      13,126.69       485,308.29    10.00
# std     1,221,377.70     909,865.61     5,817,909.82     0.00
# min    -4,494,094.27 -18,568,334.00   -22,294,827.23    10.00
# 25%             0.00           0.00             0.00    10.00
# 50%        12,000.00           0.00        40,000.00    10.00
# 75%       229,775.00           0.00       272,790.00    10.00
# max    20,000,000.00  23,239,535.00   259,547,213.00    10.00
#
#        dist_processing_days  hq_processing_days  fhwa_processing_days  \
# count              2,023.00            2,194.00              2,194.00
# mean                  13.05               16.56                  4.82
# std                   36.21               26.78                  5.52
# min                  -99.00                0.00                  0.00
# 25%                    0.00                0.00                  2.00
# 50%                    3.00                8.00                  4.00
# 75%                   12.00               17.00                  7.00
# max                1,096.00              261.00                141.00
#
#            seq  prepared_y
# count 2,203.00    2,203.00
# mean      3.01    2,017.37
# std       1.91        2.23
# min       1.00    2,013.00
# 25%       2.00    2,015.00
# 50%       3.00    2,017.00
# 75%       4.00    2,019.00
# max      14.00    2,021.00

# %%
transit.describe()
# Out:
#        fed_requested  ac_requested  total_requested   dist  \
# count         126.00        126.00           126.00 126.00
# mean      129,595.99      5,119.05       159,279.34  10.00
# std       317,638.37    128,866.22       439,094.89   0.00
# min      -183,102.22   -911,000.00    -1,297,265.00  10.00
# 25%             0.00          0.00             0.00  10.00
# 50%         6,000.00          0.00         9,037.35  10.00
# 75%       100,000.00          0.00       111,250.00  10.00
# max     2,032,749.00    911,000.00     2,296,116.00  10.00
#
#        dist_processing_days  hq_processing_days  fhwa_processing_days    seq  \
# count                112.00              126.00                126.00 126.00
# mean                   7.14               14.60                  4.53   2.00
# std                   10.91               23.45                  3.93   1.11
# min                    0.00                0.00                  0.00   1.00
# 25%                    0.00                0.00                  2.00   1.00
# 50%                    3.00                6.00                  4.00   2.00
# 75%                    8.00               16.75                  6.00   2.00
# max                   51.00              122.00                 30.00   7.00
#
#        prepared_y
# count      126.00
# mean     2,017.66
# std          2.19
# min      2,014.00
# 25%      2,016.00
# 50%      2,018.00
# 75%      2,019.00
# max      2,021.00

# %% [markdown]
# ### Top 50 Agencies with highest funds

# %%
((_dla_utils.calculate_data_all(df, 'total_requested', 'primary_agency_name', aggfunc="mean"))>>arrange(-_.total_requested)).head(50)
# Out:
#                                  primary_agency_name  total_requested
# 40             San Joaquin Regional Transit District     3.748224e+06
# 10                                          Caltrans     2.964646e+06
# 45                            Stockton Port District     2.760150e+06
# 39              San Joaquin Regional Rail Commission     2.244211e+06
# 43                                 Stanislaus County     2.180271e+06
# 19                                           Lathrop     1.689527e+06
# 21                                              Lodi     1.390685e+06
# 47                                             Tracy     1.329912e+06
# 22                      Lodi Unified School District     1.148058e+06
# 37                San Joaquin Council of Governments     9.236537e+05
# 7                                          Calabasas     8.854667e+05
# 0                                      Alpine County     7.900634e+05
# 24                                           Manteca     7.750622e+05
# 46                                      Sutter Creek     5.943349e+05
# 34                                          Plymouth     5.282350e+05
# 38                                San Joaquin County     4.383967e+05
# 35                                             Ripon     3.744252e+05
# 41                                            Sonora     3.478895e+05
# 50            Tuolumne County Transportation Council     3.251720e+05
# 2                                      Amador County     2.996500e+05
# 29                                           Modesto     2.884719e+05
# 48  Transit Joint Powers Authority For Merced County     2.722599e+05
# 27                                     Merced County     2.653219e+05
# 15                                           Gustine     2.622074e+05
# 33                                         Patterson     2.466650e+05
# 23                                         Los Banos     2.151776e+05
# 4                        Amador Rapid Transit System     2.111300e+05
# 51                                           Turlock     2.082919e+05
# 25                                   Mariposa County     1.973716e+05
# 49                                   Tuolumne County     1.962135e+05
# 44                                          Stockton     1.888295e+05
# 31                                            Newman     1.688335e+05
# 11                                             Ceres     1.655987e+05
# 32                                           Oakdale     1.423800e+05
# 26                                            Merced     1.407559e+05
# 6                                            Atwater     1.220286e+05
# 36                                         Riverbank     1.187888e+05
# 9                                   Calaveras County     1.178873e+05
# 42                 Stanislaus Council of Governments     1.021031e+05
# 20                                        Livingston     8.999331e+04
# 18                                           Jackson     8.659768e+04
# 5                                             Angels     8.435222e+04
# 53                                         Waterford     6.180084e+04
# 14                                           Escalon     5.608388e+04
# 16                                           Hughson     4.806859e+04
# 54  Yosemite Area Regional Transportation System JPA     4.249680e+04
# 28          Merced County Association of Governments     3.840580e+04
# 17                                              Ione     2.766005e+04
# 55                                       Yuba County     2.696798e+04
# 30                                      Modoc County     1.742033e+04

# %%
_dla_utils.basic_bar_chart((((_dla_utils.calculate_data_all(df, 'total_requested', 'primary_agency_name', aggfunc="mean"))
                          >>arrange(-_.total_requested)).head(30)
                        ), 'primary_agency_name','total_requested', 'primary_agency_name', subset,
                           'Average Total Requested Funds by Agency'
                       )
# Out:
# alt.Chart(...)

# %%
_dla_utils.basic_bar_chart((((_dla_utils.calculate_data_all(transit, 'total_requested', 'primary_agency_name', aggfunc="mean"))
                          >>arrange(-_.total_requested)).head(30)
                        ), 'primary_agency_name','total_requested', 'primary_agency_name', subset,
                           'Average Total Requested Funds by Agency: Transit Related Funding'
                       )
# Out:
# alt.Chart(...)

# %%
_dla_utils.basic_bar_chart((_dla_utils.calculate_data_all(transit_agencies, 'total_requested', aggregate_by='primary_agency_name', aggfunc="mean")),
                           'primary_agency_name', 'total_requested', 'primary_agency_name', subset,
                           'Transit Agencies Average Funding')
# Out:
# alt.Chart(...)

# %%
df>>filter(_.primary_agency_name=='San Joaquin Regional Transit District')>>count(_.type_of_work)
# Out:
#                                  type_of_work  n
# 0                                FTA Transfer  5
# 1  Install Decorative Bike Racks At Brt Stops  1

# %%
df>>filter(_.primary_agency_name=='San Joaquin Regional Transit District')>>count(_.prefix)
# Out:
#    prefix  n
# 0  FTACML  5
# 1  RPSTPL  1

# %% [markdown]
# ### Bottom 50 Agencies with lowest funds

# %%
avg_funds_bottom = (df>>group_by(_.primary_agency_name)>>summarize(avg_funds=_.total_requested.mean())>>arrange(-_.avg_funds)).tail(50)

# %%
avg_funds_bottom
# Out:
#                                  primary_agency_name     avg_funds
# 21                                              Lodi  1.390685e+06
# 47                                             Tracy  1.329912e+06
# 22                      Lodi Unified School District  1.148058e+06
# 37                San Joaquin Council of Governments  9.236537e+05
# 7                                          Calabasas  8.854667e+05
# 0                                      Alpine County  7.900634e+05
# 24                                           Manteca  7.750622e+05
# 46                                      Sutter Creek  5.943349e+05
# 34                                          Plymouth  5.282350e+05
# 38                                San Joaquin County  4.383967e+05
# 35                                             Ripon  3.744252e+05
# 41                                            Sonora  3.478895e+05
# 50            Tuolumne County Transportation Council  3.251720e+05
# 2                                      Amador County  2.996500e+05
# 29                                           Modesto  2.884719e+05
# 48  Transit Joint Powers Authority For Merced County  2.722599e+05
# 27                                     Merced County  2.653219e+05
# 15                                           Gustine  2.622074e+05
# 33                                         Patterson  2.466650e+05
# 23                                         Los Banos  2.151776e+05
# 4                        Amador Rapid Transit System  2.111300e+05
# 51                                           Turlock  2.082919e+05
# 25                                   Mariposa County  1.973716e+05
# 49                                   Tuolumne County  1.962135e+05
# 44                                          Stockton  1.888295e+05
# 31                                            Newman  1.688335e+05
# 11                                             Ceres  1.655987e+05
# 32                                           Oakdale  1.423800e+05
# 26                                            Merced  1.407559e+05
# 6                                            Atwater  1.220286e+05
# 36                                         Riverbank  1.187888e+05
# 9                                   Calaveras County  1.178873e+05
# 42                 Stanislaus Council of Governments  1.021031e+05
# 20                                        Livingston  8.999331e+04
# 18                                           Jackson  8.659768e+04
# 5                                             Angels  8.435222e+04
# 53                                         Waterford  6.180084e+04
# 14                                           Escalon  5.608388e+04
# 16                                           Hughson  4.806859e+04
# 54  Yosemite Area Regional Transportation System JPA  4.249680e+04
# 28          Merced County Association of Governments  3.840580e+04
# 17                                              Ione  2.766005e+04
# 55                                       Yuba County  2.696798e+04
# 30                                      Modoc County  1.742033e+04
# 13                                         Dos Palos  1.651150e+04
# 3            Amador County Transportation Commission -7.497800e+02
# 52     U.S. Forest Service, Pacific Southwest Region -4.224893e+03
# 8                   Calaveras Council of Governments -1.414778e+04
# 12                     Department of Water Resources -5.206798e+04
# 1                                        Amador City -9.367351e+04

# %%
_dla_utils.basic_bar_chart((avg_funds_bottom.tail(40)), 'primary_agency_name','avg_funds', 'primary_agency_name', subset, 
                          'Lowest Average Total Funds by Agency')
# Out:
# WARN Symbol legend count exceeds limit, filtering items.
# alt.Chart(...)

# %%
((
    _dla_utils.calculate_data_all(
        df, 'total_requested', 'primary_agency_name', aggfunc="mean"))
>>arrange(-_.total_requested)).tail(50)
# Out:
#                                  primary_agency_name  total_requested
# 10                                          Caltrans     2.964646e+06
# 45                            Stockton Port District     2.760150e+06
# 39              San Joaquin Regional Rail Commission     2.244211e+06
# 43                                 Stanislaus County     2.180271e+06
# 19                                           Lathrop     1.689527e+06
# 21                                              Lodi     1.390685e+06
# 47                                             Tracy     1.329912e+06
# 22                      Lodi Unified School District     1.148058e+06
# 37                San Joaquin Council of Governments     9.236537e+05
# 7                                          Calabasas     8.854667e+05
# 0                                      Alpine County     7.900634e+05
# 24                                           Manteca     7.750622e+05
# 46                                      Sutter Creek     5.943349e+05
# 34                                          Plymouth     5.282350e+05
# 38                                San Joaquin County     4.383967e+05
# 35                                             Ripon     3.744252e+05
# 41                                            Sonora     3.478895e+05
# 50            Tuolumne County Transportation Council     3.251720e+05
# 2                                      Amador County     2.996500e+05
# 29                                           Modesto     2.884719e+05
# 48  Transit Joint Powers Authority For Merced County     2.722599e+05
# 27                                     Merced County     2.653219e+05
# 15                                           Gustine     2.622074e+05
# 33                                         Patterson     2.466650e+05
# 23                                         Los Banos     2.151776e+05
# 4                        Amador Rapid Transit System     2.111300e+05
# 51                                           Turlock     2.082919e+05
# 25                                   Mariposa County     1.973716e+05
# 49                                   Tuolumne County     1.962135e+05
# 44                                          Stockton     1.888295e+05
# 31                                            Newman     1.688335e+05
# 11                                             Ceres     1.655987e+05
# 32                                           Oakdale     1.423800e+05
# 26                                            Merced     1.407559e+05
# 6                                            Atwater     1.220286e+05
# 36                                         Riverbank     1.187888e+05
# 9                                   Calaveras County     1.178873e+05
# 42                 Stanislaus Council of Governments     1.021031e+05
# 20                                        Livingston     8.999331e+04
# 18                                           Jackson     8.659768e+04
# 5                                             Angels     8.435222e+04
# 53                                         Waterford     6.180084e+04
# 14                                           Escalon     5.608388e+04
# 16                                           Hughson     4.806859e+04
# 54  Yosemite Area Regional Transportation System JPA     4.249680e+04
# 28          Merced County Association of Governments     3.840580e+04
# 17                                              Ione     2.766005e+04
# 55                                       Yuba County     2.696798e+04
# 30                                      Modoc County     1.742033e+04
# 13                                         Dos Palos     1.651150e+04

# %%
_dla_utils.basic_bar_chart((((_dla_utils.calculate_data_all(df, 'total_requested', 'primary_agency_name', aggfunc="mean"))
                          >>arrange(-_.total_requested)).tail(50)
                        ), 'primary_agency_name','total_requested', 'total_requested', subset
                       )
# Out:
# alt.Chart(...)

# %%
df.sample()
# Out:
#         location prefix project_no                             agency  \
# 14830  Obligated   STPL  6089(076)  Stanislaus Council Of Governments
#
#       prepared_date submit__to_hq_date hq_review_date submit_to_fhwa_date  \
# 14830    2019-08-29         2019-08-29     2019-08-29          2019-08-29
#
#       to_fmis_date  fed_requested  ac_requested  total_requested  \
# 14830   2019-09-04            0.0           0.0        118038.44
#
#       status_comment locode  dist             status  dist_processing_days  \
# 14830     Authorized   6089    10  E-76 approved on                    7.0
#
#        hq_processing_days  fhwa_processing_days    ftip_no  \
# 14830                 0.0                   6.0  05STA002R
#
#           project_location                           type_of_work  seq  \
# 14830  In Stanilaus County  Planning, Programming, And Monitoring    2
#
#       date_request_initiated date_completed_request      mpo projectID  \
# 14830             2019-08-22             2019-08-23  STANCOG      6089
#
#        prepared_y                primary_agency_name
# 14830      2019.0  Stanislaus Council of Governments

# %% [markdown]
# ## Prefix Code Funding

# %%
_dla_utils.basic_bar_chart((((_dla_utils.calculate_data_all(df, 'total_requested', 'prefix', aggfunc="mean"))
                          >>arrange(-_.total_requested)).head(30)
                        ), 'prefix','total_requested', 'prefix', subset,
                           'Average Total Requested Funds by Prefix'
                       )
# Out:
# alt.Chart(...)

# %%
_dla_utils.basic_bar_chart((((_dla_utils.calculate_data_all(df, 'fed_requested', 'prefix', aggfunc="mean"))
                          >>arrange(-_.fed_requested)).head(30)
                        ), 'prefix','fed_requested', 'prefix', subset,
                           'Average Federal Requested Funds by Prefix'
                       )
# Out:
# alt.Chart(...)

# %%
_dla_utils.basic_bar_chart((((_dla_utils.calculate_data_all(df, 'ac_requested', 'prefix', aggfunc="mean"))
                          >>arrange(-_.ac_requested)).head(30)
                        ), 'prefix','ac_requested', 'prefix', subset,
                           'Average Advanced Construction Requested Funds by Prefix'
                       )
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Functions to look by Prefix and by Agency:

# %% [markdown]
# ### By Agency:

# %%
_dla_utils.interactive_widget(df, 'primary_agency_name')
# Out:
# Dropdown(description='Primary_Agency_Name', options=('Alpine County', 'Amador City', 'Amador County', 'Amador …
# Output()

# %% [markdown]
# ### By Prefix:

# %%
_dla_utils.interactive_widget(df, 'prefix')
# Out:
# Dropdown(description='Prefix', options=('ACSTER', 'ACSTP', 'ATPCML', 'ATPL', 'ATPLNI', 'ATPSTPL', 'BDGL', 'BHL…
# Output()

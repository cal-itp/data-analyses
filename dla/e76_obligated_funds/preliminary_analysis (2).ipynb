# %% [markdown]
# # Preliminary Analysis of DLA Functions

# %%
import numpy as np
import pandas as pd
from siuba import *
import _clean_data
import altair as alt
import altair_saver
from plotnine import *

from shared_utils import altair_utils
alt.themes.enable("fivethirtyeight")
# Out:
# /opt/conda/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.9.1-CAPI-1.14.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
# /opt/conda/lib/python3.9/site-packages/google/auth/_default.py:73: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
# ThemeRegistry.enable('fivethirtyeight')

# %%
df = _clean_data.read_data()
df = _clean_data.clean_data(df)
df = _clean_data.prefix_cleaning(df)
df = _clean_data.clean_agency_names(df)
# Out:
# /opt/conda/lib/python3.9/site-packages/google/auth/_default.py:73: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
# /home/jovyan/data-analyses/dla/e76_obligated_funds/_clean_data.py:168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.sample()
# Out:
#              location   prefix project_no  \
# 1703  FTA Transferred  FTASTPL  6429(023)
#
#                                           agency prepared_date  \
# 1703  Napa County Transportation Planning Agency    2018-04-05
#
#      submit__to_hq_date hq_review_date submit_to_fhwa_date to_fmis_date  \
# 1703         2018-04-05     2018-04-05          2018-05-04   2018-05-07
#
#       fed_requested  ac_requested  total_requested  status_comment locode  \
# 1703       89685.61           0.0         89685.61  Prog Code M23E   6429
#
#       dist                       status  dist_processing_days  \
# 1703     4  FTA transferred on 5/7/2018                   NaN
#
#       hq_processing_days  fhwa_processing_days ftip_no project_location  \
# 1703                29.0                   3.0     NaN              NaN
#
#       type_of_work  seq date_request_initiated date_completed_request  mpo  \
# 1703  FTA Transfer    1                    NaT                    NaT  MTC
#
#      projectID  prepared_y                         primary_agency_name
# 1703      6429      2018.0  Napa County Transportation Planning Agency

# %%
print("Number of Unique Agencies with uncleaned Data")
print(len(df>>count(_.agency)>>arrange(-_.n)))
print("Number of True Unique Agencies")
print(len(df>>count(_.primary_agency_name)>>arrange(-_.n)))
# Out:
# Number of Unique Agencies with uncleaned Data
# 671
# Number of True Unique Agencies
# 619

# %% [markdown]
# ## By District

# %%
dist = df>>count(_.dist)>>arrange(-_.n)

# %%
dist
# Out:
#     dist     n
# 4      4  3248
# 6      6  3084
# 7      7  2787
# 3      3  2517
# 10    10  2203
# 5      5  1337
# 8      8  1309
# 1      1  1161
# 11    11   920
# 12    12   666
# 2      2   614
# 9      9   267
# 0      0     4

# %%
dist.rename(columns={'n': 'total_obligations'}, inplace=True)

# %%
dist_agencyn = (df >> group_by(_.dist) >> summarize(n=_.primary_agency_name.nunique()) >> arrange(-_.n))

# %%
dist_agencyn.rename(columns={'n': 'n_agency_unique'}, inplace=True)

# %%
dist_prefixn = (df >> group_by(_.dist) >> summarize(n=_.prefix.nunique()) >> arrange(-_.n))

# %%
dist_prefixn.rename(columns={'n': 'n_prefix_unique'}, inplace=True)

# %%
dist = full_join(dist, dist_agencyn, on = "dist")

# %%
dist = full_join(dist, dist_prefixn, on = "dist")

# %%
dist
# Out:
#     dist  total_obligations  n_agency_unique  n_prefix_unique
# 0      4               3248              151              110
# 1      6               3084               55               71
# 2      7               2787              108              107
# 3      3               2517               62               98
# 4     10               2203               56               65
# 5      5               1337               39               63
# 6      8               1309               64               92
# 7      1               1161               20               25
# 8     11                920               31               70
# 9     12                666               36               41
# 10     2                614               25               31
# 11     9                267                9               16
# 12     0                  4                1                2

# %%
chart = (alt.Chart(dist)
         .mark_bar()
         .encode(
             x=alt.X("dist", title="District", scale=alt.Scale(domain=(0, 12))),
             y=alt.Y("total_obligations", title="Number of Obligations"),
             #column = "payment:N",
             color = alt.Color("dist",
                              scale=alt.Scale(
                                  range=altair_utils.FIVETHIRTYEIGHT_DIVERGING_COLORS),  
                               legend=alt.Legend(title="District")
                              )
         )
        .properties( 
                       title="Number of Obligations by District")

)



chart.mark_bar(size=20)
# Out:
# alt.Chart(...)

# %%
dist_years1 = df >> group_by(_.prepared_y, _.dist) >> summarize(n=_.primary_agency_name.nunique()) >> arrange(-_.prepared_y)

# %%
dist_years1.rename(columns={'n': 'n_agency_unique'}, inplace=True)

# %%
dist_years1>>arrange(-_.n_agency_unique)
# Out:
#     prepared_y  dist  n_agency_unique
# 47      2016.0     4              113
# 34      2015.0     4              109
# 22      2014.0     4              108
# 60      2017.0     4               98
# 72      2018.0     4               97
# ..         ...   ...              ...
# 43      2016.0     0                1
# 5       2012.0     7                1
# 1       2011.0     4                1
# 3       2011.0    11                1
# 0       2010.0     8                1
#
# [118 rows x 3 columns]

# %%
chart = alt.Chart(dist_years1).mark_bar().encode(
        # x='prepared_y:O',
        # y='n_agency_unique:Q',
        #color='dist:N',
        column='dist:N',
        x=alt.X('prepared_y:O', title='Prepared Year'),
        y=alt.Y('n_agency_unique:Q', title='Number of Unique Agencies'),
        color = alt.Color("dist:N", 
                              scale=alt.Scale(
                                  range=altair_utils.FIVETHIRTYEIGHT_DIVERGING_COLORS),  
                               legend=alt.Legend(title="District")
                              )
                              ).properties( 
                       title="Number of Unique Agencies by District")

chart
# Out:
# alt.Chart(...)

# %%
chart = (alt.Chart(dist_years1)
         .mark_bar()
         .encode(
             x=alt.X("prepared_y", title="Year"),
             y=alt.Y("n_agency_unique", title="Number of Unique Agencies"),
             #column = "payment:N",
             color = alt.Color("dist", 
                              scale=alt.Scale(
                                  range=altair_utils.FIVETHIRTYEIGHT_DIVERGING_COLORS),  
                               legend=alt.Legend(title="District")
                              )
                              )
        .properties( 
                       title="Number of Obligations by District")

)


chart
# Out:
# alt.Chart(...)

# %%
dist_years2 = df >> group_by(_.prepared_y, _.dist) >> summarize(n=_.prefix.nunique()) >> arrange(-_.prepared_y)

# %%
dist_years2.rename(columns={'n': 'n_prefix_unique'}, inplace=True)

# %%
dist_years2>>arrange(-_.n_prefix_unique)
# Out:
#     prepared_y  dist  n_prefix_unique
# 22      2014.0     4               52
# 83      2019.0     3               51
# 72      2018.0     4               51
# 47      2016.0     4               50
# 34      2015.0     4               48
# ..         ...   ...              ...
# 56      2017.0     0                1
# 5       2012.0     7                1
# 1       2011.0     4                1
# 3       2011.0    11                1
# 0       2010.0     8                1
#
# [118 rows x 3 columns]

# %%
chart = alt.Chart(dist_years2).mark_bar().encode(
        # x='prepared_y:O',
        # y='n_agency_unique:Q',
        #color='dist:N',
        column='dist:N',
        x=alt.X('prepared_y:O', title='Prepared Year'),
        y=alt.Y('n_prefix_unique:Q', title='Number of Unique Prefix Codes'),
        color = alt.Color("dist:N", 
                              scale=alt.Scale(
                                  range=altair_utils.FIVETHIRTYEIGHT_DIVERGING_COLORS),  
                               legend=alt.Legend(title="District"
                              )
                              )).properties( 
                       title="Number of Unique Prefix Codes by District")

chart
# Out:
# alt.Chart(...)

# %%
df>>count(_.prepared_y)>>arrange(-_.n)
# Out:
#     prepared_y     n
# 8       2018.0  2827
# 4       2014.0  2724
# 9       2019.0  2665
# 5       2015.0  2575
# 6       2016.0  2505
# 10      2020.0  2350
# 7       2017.0  2333
# 11      2021.0  1917
# 3       2013.0   193
# 2       2012.0     7
# 1       2011.0     5
# 0       2010.0     1

# %%
sum_funds = df>>group_by(_.dist)>>summarize(n=_.total_requested.sum()) >> arrange(-_.n)
sum_funds.style.format(precision=2, na_rep='MISSING', thousands=",")
# Out:
# <style type="text/css">
# </style>
# <table id="T_61507_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >dist</th>
#       <th class="col_heading level0 col1" >n</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61507_level0_row0" class="row_heading level0 row0" >7</th>
#       <td id="T_61507_row0_col0" class="data row0 col0" >7</td>
#       <td id="T_61507_row0_col1" class="data row0 col1" >4,264,832,122.16</td>
#     </tr>
#     <tr>
#       <th id="T_61507_level0_row1" class="row_heading level0 row1" >12</th>
#       <td id="T_61507_row1_col0" class="data row1 col0" >12</td>
#       <td id="T_61507_row1_col1" class="data row1 col1" >2,858,146,336.25</td>
#     </tr>
#     <tr>
#       <th id="T_61507_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_61507_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_61507_row2_col1" class="data row2 col1" >2,820,381,522.31</td>
#     </tr>
#     <tr>
#       <th id="T_61507_level0_row3" class="row_heading level0 row3" >8</th>
#       <td id="T_61507_row3_col0" class="data row3 col0" >8</td>
#       <td id="T_61507_row3_col1" class="data row3 col1" >2,589,841,597.99</td>
#     </tr>
#     <tr>
#       <th id="T_61507_level0_row4" class="row_heading level0 row4" >6</th>
#       <td id="T_61507_row4_col0" class="data row4 col0" >6</td>
#       <td id="T_61507_row4_col1" class="data row4 col1" >1,597,301,076.08</td>
#     </tr>
#     <tr>
#       <th id="T_61507_level0_row5" class="row_heading level0 row5" >3</th>
#       <td id="T_61507_row5_col0" class="data row5 col0" >3</td>
#       <td id="T_61507_row5_col1" class="data row5 col1" >1,561,960,671.34</td>
#     </tr>
#     <tr>
#       <th id="T_61507_level0_row6" class="row_heading level0 row6" >11</th>
#       <td id="T_61507_row6_col0" class="data row6 col0" >11</td>
#       <td id="T_61507_row6_col1" class="data row6 col1" >1,159,054,839.35</td>
#     </tr>
#     <tr>
#       <th id="T_61507_level0_row7" class="row_heading level0 row7" >10</th>
#       <td id="T_61507_row7_col0" class="data row7 col0" >10</td>
#       <td id="T_61507_row7_col1" class="data row7 col1" >1,069,134,164.63</td>
#     </tr>
#     <tr>
#       <th id="T_61507_level0_row8" class="row_heading level0 row8" >5</th>
#       <td id="T_61507_row8_col0" class="data row8 col0" >5</td>
#       <td id="T_61507_row8_col1" class="data row8 col1" >492,622,627.53</td>
#     </tr>
#     <tr>
#       <th id="T_61507_level0_row9" class="row_heading level0 row9" >2</th>
#       <td id="T_61507_row9_col0" class="data row9 col0" >2</td>
#       <td id="T_61507_row9_col1" class="data row9 col1" >228,882,744.46</td>
#     </tr>
#     <tr>
#       <th id="T_61507_level0_row10" class="row_heading level0 row10" >1</th>
#       <td id="T_61507_row10_col0" class="data row10 col0" >1</td>
#       <td id="T_61507_row10_col1" class="data row10 col1" >175,141,642.34</td>
#     </tr>
#     <tr>
#       <th id="T_61507_level0_row11" class="row_heading level0 row11" >9</th>
#       <td id="T_61507_row11_col0" class="data row11 col0" >9</td>
#       <td id="T_61507_row11_col1" class="data row11 col1" >56,075,221.51</td>
#     </tr>
#     <tr>
#       <th id="T_61507_level0_row12" class="row_heading level0 row12" >0</th>
#       <td id="T_61507_row12_col0" class="data row12 col0" >0</td>
#       <td id="T_61507_row12_col1" class="data row12 col1" >3,152,859.45</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Charts

# %%
df_agency = (df>>count(_.primary_agency_name)>>arrange(-_.n)).head(50)

# %%
barchart = (alt.Chart(df_agency)
         .mark_bar()
         .encode(
             x=alt.X("primary_agency_name", title="Agency Name"),
             y=alt.Y("n", title="Number of Obligations"),
             #column = "payment:N",
             color = alt.Color("n", 
                              scale=alt.Scale(
                                  range=altair_utils.FIVETHIRTYEIGHT_DIVERGING_COLORS
                              )
                              )
         )
        .properties( 
                       title="Most Obligations by Agency")

)
text = barchart.mark_text(
    align='left',
    baseline='middle',
     dx=3  # Nudges text to right so it doesn't appear on top of the bar
).encode(
    text='n:Q'
)

    
chart = (barchart + text).properties(height=900)


chart
# Out:
# alt.LayerChart(...)

# %%
df>>filter(_.primary_agency_name=='Humboldt County')>>count(_.prefix)>>arrange(-_.n)
# Out:
#      prefix    n
# 9        ER  379
# 0    ACSTER   64
# 4      BPMP   50
# 1     ACSTP   31
# 5      BRLO   22
# 7      BRLS   20
# 12    HSIPL   19
# 13   RPSTPL   18
# 6    BRLOZB    9
# 2      ATPL    5
# 11    HRRRL    5
# 8    BRLSZD    2
# 3    ATPLNI    1
# 10   FBDLNI    1
# 14  SRTSLNI    1

# %%
humboldt = df>>filter(_.primary_agency_name=='Humboldt County')>>count(_.prefix)>>arrange(-_.n)

# %%
chart = (alt.Chart(humboldt)
         .mark_bar()
         .encode(
             x=alt.X("prefix", title="Prefix"),
             y=alt.Y("n", title="Number of Obligations"),
             #column = "payment:N",
             color = alt.Color("n", 
                              scale=alt.Scale(
                                  range=altair_utils.FIVETHIRTYEIGHT_DIVERGING_COLORS
                              )
                              )
         )
        .properties( 
                       title="Prefixes used by Humboldt County")

)


chart
# Out:
# alt.Chart(...)

# %%
mpo = df>>count(_.mpo)>>arrange(-_.n)

# %%
chart = (alt.Chart(mpo)
         .mark_bar()
         .encode(
             x=alt.X("mpo", title="MPOs"),
             y=alt.Y("n", title="Number of Obligations"),
             #column = "payment:N",
             color = alt.Color("n", 
                              scale=alt.Scale(
                                  range=altair_utils.FIVETHIRTYEIGHT_DIVERGING_COLORS
                              )
                              )
         )
        .properties( 
                       title="Obligations by MPO")

)


chart
# Out:
# alt.Chart(...)

# %%
prefix = df>>count(_.prefix)>>arrange(-_.n)

# %%
prefix.head(10)
# Out:
#      prefix     n
# 68      CML  3293
# 208   HSIPL  3282
# 306    STPL  2779
# 128      ER  1590
# 40     BRLO  1402
# 46     BRLS   904
# 10     ATPL   587
# 269  RPSTPL   576
# 194   HPLUL   332
# 284   SRTSL   331

# %%
df>>filter(_.prefix=='FTACML')
# Out:
#               location  prefix project_no  \
# 732    FTA Transferred  FTACML  5108(186)
# 829    FTA Transferred  FTACML  5107(048)
# 910    FTA Transferred  FTACML  6065(231)
# 911    FTA Transferred  FTACML  6046(015)
# 1030   FTA Transferred  FTACML  5132(048)
# ...                ...     ...        ...
# 19819  FTA Transferred  FTACML  7505(001)
# 19820  FTA Transferred  FTACML  7505(002)
# 19821  FTA Transferred  FTACML  6187(008)
# 19822  FTA Transferred  FTACML  6261(025)
# 19823  FTA Transferred  FTACML  6262(021)
#
#                                                   agency prepared_date  \
# 732                                           Long Beach    2018-07-17
# 829                                         Santa Monica    2018-07-09
# 910    Los Angeles County Metropolitan Transportation...    2018-07-03
# 911                                            Omnitrans    2018-07-02
# 1030                                           Fairfield    2018-04-24
# ...                                                  ...           ...
# 19819                        Gold Coast Transit District    2021-07-01
# 19820                        Gold Coast Transit District    2021-07-06
# 19821        Southern California Regional Rail Authority    2021-07-26
# 19822                    Victor Valley Transit Authority    2021-07-19
# 19823               San Joaquin Regional Rail Commission    2021-06-30
#
#       submit__to_hq_date hq_review_date submit_to_fhwa_date to_fmis_date  \
# 732           2018-07-17     2018-07-17          2018-08-02   2018-08-24
# 829           2018-07-09     2018-07-09          2018-07-25   2018-08-09
# 910           2018-07-03     2018-07-03          2018-07-24   2018-07-26
# 911           2018-07-02     2018-07-02          2018-07-23   2018-07-26
# 1030          2018-04-24     2018-04-24          2018-07-03   2018-07-16
# ...                  ...            ...                 ...          ...
# 19819         2021-07-01     2021-07-01          2021-07-22   2021-08-03
# 19820         2021-07-06     2021-07-06          2021-07-22   2021-08-03
# 19821         2021-07-26     2021-07-26          2021-08-03   2021-08-03
# 19822         2021-07-19     2021-07-19          2021-08-02   2021-08-03
# 19823         2021-06-30     2021-06-30          2021-07-27   2021-08-03
#
#        fed_requested  ac_requested  total_requested  status_comment locode  \
# 732        2102405.0           0.0        2102405.0  Prog Code Z400   5108
# 829        1765344.0           0.0        1765344.0  Prog Code Z400   5107
# 910       25000000.0           0.0       25000000.0  Prog Code Z400   6065
# 911       17818000.0           0.0       17818000.0  Prog Code Z400   6046
# 1030       1333719.0           0.0        1333719.0  Prog Code Z003   5132
# ...              ...           ...              ...             ...    ...
# 19819      4587076.0           0.0        4587076.0  Prog Code Z40E   7505
# 19820        77000.0           0.0          77000.0  Prog Code Z40E   7505
# 19821     25000000.0           0.0       25000000.0  Prog Code Z40E   6187
# 19822      5115000.0           0.0        5115000.0  Prog Code Z400   6261
# 19823      7500000.0           0.0        7500000.0  Prog Code Z0E3   6262
#
#        dist                        status  dist_processing_days  \
# 732       7  FTA transferred on 8/24/2018                   NaN
# 829       7   FTA transferred on 8/9/2018                   NaN
# 910       7  FTA transferred on 7/26/2018                   NaN
# 911       8  FTA transferred on 7/26/2018                   NaN
# 1030      4  FTA transferred on 7/16/2018                   NaN
# ...     ...                           ...                   ...
# 19819     7   FTA transferred on 8/3/2021                   NaN
# 19820     7   FTA transferred on 8/3/2021                   NaN
# 19821     7   FTA transferred on 8/3/2021                   NaN
# 19822     8   FTA transferred on 8/3/2021                   NaN
# 19823    10   FTA transferred on 8/3/2021                   NaN
#
#        hq_processing_days  fhwa_processing_days ftip_no project_location  \
# 732                  16.0                  22.0     NaN              NaN
# 829                  16.0                  15.0     NaN              NaN
# 910                  21.0                   2.0     NaN              NaN
# 911                  21.0                   3.0     NaN              NaN
# 1030                 70.0                  13.0     NaN              NaN
# ...                   ...                   ...     ...              ...
# 19819                21.0                  12.0     NaN              NaN
# 19820                16.0                  12.0     NaN              NaN
# 19821                 8.0                   0.0     NaN              NaN
# 19822                14.0                   1.0     NaN              NaN
# 19823                27.0                   7.0     NaN              NaN
#
#        type_of_work  seq date_request_initiated date_completed_request  \
# 732    FTA Transfer    1                    NaT                    NaT
# 829    FTA Transfer    1                    NaT                    NaT
# 910    FTA Transfer    1                    NaT                    NaT
# 911    FTA Transfer    1                    NaT                    NaT
# 1030   FTA Transfer    1                    NaT                    NaT
# ...             ...  ...                    ...                    ...
# 19819  FTA Transfer    1                    NaT                    NaT
# 19820  FTA Transfer    1                    NaT                    NaT
# 19821  FTA Transfer    1                    NaT                    NaT
# 19822  FTA Transfer    1                    NaT                    NaT
# 19823  FTA Transfer    1                    NaT                    NaT
#
#            mpo projectID  prepared_y  \
# 732       SCAG      5108      2018.0
# 829       SCAG      5107      2018.0
# 910       SCAG      6065      2018.0
# 911    NON-MPO      6046      2018.0
# 1030       MTC      5132      2018.0
# ...        ...       ...         ...
# 19819     SCAG      7505      2021.0
# 19820     SCAG      7505      2021.0
# 19821     SCAG      6187      2021.0
# 19822     SCAG      6261      2021.0
# 19823     SJCG      6262      2021.0
#
#                                      primary_agency_name
# 732                                           Long Beach
# 829                                         Santa Monica
# 910    Los Angeles County Metropolitan Transportation...
# 911                                            OmniTrans
# 1030                                           Fairfield
# ...                                                  ...
# 19819                                                NaN
# 19820                                                NaN
# 19821        Southern California Regional Rail Authority
# 19822                    Victor Valley Transit Authority
# 19823               San Joaquin Regional Rail Commission
#
# [267 rows x 29 columns]

# %%
df>>count(_.type_of_work)>>arrange(-_.n)
# Out:
#                                            type_of_work    n
# 592                             Bridge Replacement (tc)  679
# 582                                  Bridge Replacement  519
# 2014                                       FTA Transfer  462
# 3979                              Permanent Restoration  282
# 5289                                Road Rehabilitation  269
# ...                                                 ...  ...
# 6873  Work Occur In 2 Road Segments; 1st Segment Is ...    1
# 6874  Work Zone Data Exchange Demonstration Project....    1
# 6877  Yarts: Public Outreach And Marketing (yosemite...    1
# 6878  Years 2 To 5 Environmental Compliance (mitigat...    1
# 6881                         _const. Class I Bike Trail    1
#
# [6882 rows x 2 columns]

# %%
type_of_work = (df>>count(_.type_of_work)>>arrange(-_.n)).head(20)

# %%
chart = (alt.Chart(type_of_work)
         .mark_bar()
         .encode(
             x=alt.X("type_of_work", title="Type of Work"),
             y=alt.Y("n", title="Number of Obligations"),
             #column = "payment:N",
             color = alt.Color("n", 
                              scale=alt.Scale(
                                  range=altair_utils.FIVETHIRTYEIGHT_DIVERGING_COLORS
                              )
                              )
         )
        .properties( 
                       title="Most Used Types of Work")

)


chart
# Out:
# alt.Chart(...)

# %%
project_location = (df>>count(_.project_location)>>arrange(-_.n)).head(20)

# %%
chart = (alt.Chart(project_location)
         .mark_bar()
         .encode(
             x=alt.X("project_location", title="Project Location"),
             y=alt.Y("n", title="Number of Obligations"),
             #column = "payment:N",
             color = alt.Color("n", 
                              scale=alt.Scale(
                                  range=altair_utils.FIVETHIRTYEIGHT_DIVERGING_COLORS
                              )
                              )
         )
        .properties( 
                       title="Project Locations Most Used")

)

chart
# Out:
# alt.Chart(...)

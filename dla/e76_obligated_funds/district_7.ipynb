# %% [markdown]
# # Obligations in District 7
#
# Using data from the Division of Local Assistance [Obligation list](https://dot.ca.gov/programs/local-assistance/reports/e-76-obligated)

# %%
import numpy as np
import pandas as pd
from siuba import *
import clean_data
import altair as alt
import altair_saver
from plotnine import *

from shared_utils import altair_utils
alt.themes.enable("fivethirtyeight")


import ipywidgets as widgets
from ipywidgets import *
from IPython.display import Markdown
from IPython.core.display import display

# %%
df = clean_data.read_data()
df = clean_data.clean_data(df)
df = clean_data.prefix_cleaning(df)
df = clean_data.clean_agency_names(df)
# Out:
# /opt/conda/lib/python3.9/site-packages/google/auth/_default.py:73: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /home/jovyan/data-analyses/dla/e76_obligated_funds/clean_data.py:168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nullagency['primary_agency_name2'] = df_nullagency['agency'].map(locode_map3)

# %%
df.sample()
# Out:
#         location  prefix project_no   agency prepared_date submit__to_hq_date  \
# 11215  Obligated  RPSTPL  5242(030)  Manteca    2014-07-15         2014-07-15
#
#       hq_review_date submit_to_fhwa_date to_fmis_date  fed_requested  \
# 11215     2014-07-28          2014-07-28   2014-07-29       680000.0
#
#        ac_requested  total_requested status_comment locode  dist  \
# 11215           0.0         860000.0     Authorized    NaN    10
#
#                                   status  dist_processing_days  \
# 11215  E-76 approved on E-76 approved on                   0.0
#
#        hq_processing_days  fhwa_processing_days    ftip_no  \
# 11215                13.0                   1.0  SJ07-3071
#
#                                         project_location  \
# 11215  In Manteca On Louise Ave. Between Airport Way ...
#
#                                             type_of_work  seq  \
# 11215  Median Beautification & Bicycle Enhancements. ...    2
#
#       date_request_initiated date_completed_request      mpo projectID  \
# 11215                    NaT                    NaT  STANCOG      5242
#
#        prepared_y primary_agency_name
# 11215      2014.0             Manteca

# %%
la_df = df>>filter(_.dist==7)

# %%
la_df
# Out:
#         location  prefix project_no  \
# 11     Obligated   HSIPL  5378(045)
# 12     Obligated   BPMPL  5953(674)
# 26     Obligated  ATPCML  5251(026)
# 27     Obligated    STPL  5006(563)
# 28     Obligated  BRLSZD  5006(839)
# ...          ...     ...        ...
# 20377  Obligated  DEM08L  5006(719)
# 20378  Obligated     CML  5210(022)
# 20379  Obligated   HSIPL  5952(190)
# 20380  Obligated  BRLSZD  5006(266)
# 20381  Obligated   HP21L  6303(032)
#
#                                           agency prepared_date  \
# 11                                      Palmdale    2018-12-11
# 12                            Los Angeles County    2018-11-16
# 26                                          Ojai    2018-11-19
# 27                                   Los Angeles    2018-12-10
# 28                                   Los Angeles    2018-12-07
# ...                                          ...           ...
# 20377                                Los Angeles    2021-10-15
# 20378                                   El Monte    2021-09-22
# 20379                             Ventura County    2021-10-13
# 20380                                Los Angeles    2021-10-06
# 20381  San Gabriel Valley Council Of Governments    2021-10-18
#
#       submit__to_hq_date hq_review_date submit_to_fhwa_date to_fmis_date  \
# 11            2018-12-18     2018-12-27          2018-12-27   2018-12-27
# 12            2018-12-12     2018-12-26          2018-12-27   2018-12-27
# 26            2018-11-29     2018-12-17          2018-12-17   2018-12-21
# 27            2018-12-10     2018-12-17          2018-12-17   2018-12-21
# 28            2018-12-11     2018-12-14          2018-12-17   2018-12-21
# ...                  ...            ...                 ...          ...
# 20377         2021-10-15     2021-10-15          2021-10-15   2021-10-22
# 20378         2021-09-22     2021-10-05          2021-10-05   2021-10-13
# 20379         2021-10-13     2021-10-13          2021-10-13   2021-10-19
# 20380         2021-10-06     2021-10-06          2021-10-12   2021-10-18
# 20381         2021-10-18     2021-10-18          2021-10-18   2021-10-26
#
#        fed_requested  ac_requested  total_requested status_comment locode  \
# 11         545800.00           0.0        735764.00     Authorized   5378
# 12         222100.00           0.0        218169.00     Authorized   5953
# 26         330000.00           0.0        330000.00     Authorized   5251
# 27         441000.00           0.0        500170.00     Authorized   5006
# 28       22122724.00   -22122724.0             0.00     Authorized   5006
# ...              ...           ...              ...            ...    ...
# 20377      -13545.20           0.0           294.68     Authorized   5006
# 20378      -39471.65           0.0        -78943.30     Authorized   5210
# 20379          -0.02           0.0         68497.96     Authorized   5952
# 20380          -0.18           0.0        983000.07     Authorized   5006
# 20381          -0.15           0.0      -2791152.44     Authorized   6303
#
#        dist             status  dist_processing_days  hq_processing_days  \
# 11        7   E-76 approved on                   8.0                 9.0
# 12        7   E-76 approved on                   8.0                15.0
# 26        7   E-76 approved on                  13.0                18.0
# 27        7   E-76 approved on                   3.0                 7.0
# 28        7   E-76 approved on                   4.0                 6.0
# ...     ...                ...                   ...                 ...
# 20377     7  E-76 approved on                    8.0                 0.0
# 20378     7  E-76 approved on                    9.0                13.0
# 20379     7  E-76 approved on                    6.0                 0.0
# 20380     7  E-76 approved on                    6.0                 6.0
# 20381     7  E-76 approved on                    4.0                 0.0
#
#        fhwa_processing_days    ftip_no  \
# 11                      0.0    SCAG015
# 12                      0.0   LA000800
# 26                      4.0  VEN170113
# 27                      4.0   LA0C8086
# 28                      4.0    LA0G104
# ...                     ...        ...
# 20377                   7.0    LA0G686
# 20378                   8.0    LAF3125
# 20379                   6.0    SCAG015
# 20380                   6.0        NaN
# 20381                   8.0   LA990359
#
#                                         project_location  \
# 11                           Various Locations Citywide.
# 12     30 Bridge Various Locations In Los Angeles Cou...
# 26     Bike And Pedestrian Improvements On Sr 33 And ...
# 27     Phase 2 (street Realignment) Of North Spring S...
# 28     Sixth Street Viaduct Over La River, Us 101, An...
# ...                                                  ...
# 20377  Highland Park Along Figueroa Between Ave 50 An...
# 20378      Ramona Corridor Transit Center Access Project
# 20379  Pleasant Valley Road Between Dodge Road Hailes...
# 20380      North Main St. Br. Over La River  Br# 53c1010
# 20381         Nogales St. At Railroad Street/uprr(scrra)
#
#                                             type_of_work  seq  \
# 11                 Upgrade Guard Rail And End Treatments    2
# 12               Bridge Preventive Maintenance Work (tc)    3
# 26     Adding A Clasii Bike Lane In Each Direction Fo...    1
# 27                                    Street Realignment    4
# 28                              Cmgc Package #5  Viaduct    5
# ...                                                  ...  ...
# 20377                            Pedestrian Improvements    5
# 20378                Construct A New Underpass Structure    5
# 20379  Pavement Widening And Striping For Installatio...    5
# 20380                             Seismic Retrofit Cat-1    8
# 20381                                   Grade Seperation   11
#
#       date_request_initiated date_completed_request   mpo projectID  \
# 11                2018-12-04             2018-12-10  SCAG      5378
# 12                2018-06-28             2018-12-04  SCAG      5953
# 26                2018-10-24             2018-11-16  SCAG      5251
# 27                2018-09-11             2018-12-07  SCAG      5006
# 28                2018-11-05             2018-12-07  SCAG      5006
# ...                      ...                    ...   ...       ...
# 20377             2021-10-07             2021-10-08  SCAG      5006
# 20378             2021-09-13             2021-09-22  SCAG      5210
# 20379             2021-10-07             2021-10-08  SCAG      5952
# 20380             2021-09-30             2021-10-01  SCAG      5006
# 20381             2021-10-14             2021-10-15  SCAG      6303
#
#        prepared_y                        primary_agency_name
# 11         2018.0                                   Palmdale
# 12         2018.0                         Los Angeles County
# 26         2018.0                                       Ojai
# 27         2018.0                                Los Angeles
# 28         2018.0                                Los Angeles
# ...           ...                                        ...
# 20377      2021.0                                Los Angeles
# 20378      2021.0                                   El Monte
# 20379      2021.0                             Ventura County
# 20380      2021.0                                Los Angeles
# 20381      2021.0  San Gabriel Valley Council of Governments
#
# [2787 rows x 29 columns]

# %% [markdown]
# ## Which Agencies have Obligations

# %% [markdown]
# ### How many Unique Agencies

# %%
len(la_df>>count(_.primary_agency_name))
# Out:
# 108

# %% [markdown]
# ### Agencies with the most Obligations

# %%
(la_df>>count(_.primary_agency_name)>>arrange(-_.n)).head(10)
# Out:
#                                    primary_agency_name    n
# 49                                         Los Angeles  490
# 50                                  Los Angeles County  451
# 101                                     Ventura County  115
# 51   Los Angeles County Metropolitan Transportation...   85
# 82                                       Santa Clarita   85
# 47                                          Long Beach   81
# 63                                              Oxnard   74
# 67                                            Pasadena   71
# 26                                              Downey   63
# 88                                         Simi Valley   61

# %% [markdown]
# ### Agencies with the least Obligations

# %%
(la_df>>count(_.primary_agency_name)>>arrange(-_.n)).tail(10)
# Out:
#                                primary_agency_name  n
# 71                              Port Of Long Beach  2
# 86                                    Sierra Madre  2
# 2        Alameda Corridor Transportation Authority  1
# 4                Antelope Valley Transit Authority  1
# 14                                Calaveras County  1
# 35                                   Hermosa Beach  1
# 36                                 Huntington Park  1
# 70                                    Port Hueneme  1
# 74                           Rolling Hills Estates  1
# 100  U.S. Forest Service, Pacific Southwest Region  1

# %% [markdown]
# ### Charting

# %%
la_df_count = (la_df>>count(_.primary_agency_name)>>arrange(-_.n))

# %%
la_df_count.sample()
# Out:
#    primary_agency_name   n
# 87         Signal Hill  12

# %%
chart = (alt.Chart(la_df_count)
         .mark_bar()
         .encode(
             x=alt.X("primary_agency_name", title="Agency Name"),
             y=alt.Y("n", title="Number of Obligations"),
             #column = "payment:N",
             color = alt.Color("n", 
                              scale=alt.Scale(
                                  range=altair_utils.FIVETHIRTYEIGHT_DIVERGING_COLORS
                              )
                              )
         )
        .properties( 
                       title="Number of Unique Prefixes by Agency in District 7")

)


#chart.save("dist7chart.png")
chart
# Out:
# alt.Chart(...)

# %%
la_df.sample()
# Out:
#         location prefix project_no       agency prepared_date  \
# 15253  Obligated    CML  5006(896)  Los Angeles    2019-10-02
#
#       submit__to_hq_date hq_review_date submit_to_fhwa_date to_fmis_date  \
# 15253         2019-10-15     2019-10-21          2019-11-01   2019-11-08
#
#        fed_requested  ac_requested  total_requested status_comment locode  \
# 15253       424000.0           0.0         647000.0     Authorized   5006
#
#        dist             status  dist_processing_days  hq_processing_days  \
# 15253     7  E-76 approved on                   12.0                17.0
#
#        fhwa_processing_days  ftip_no  \
# 15253                   7.0  LAF3656
#
#                                         project_location  \
# 15253  Central Ave Between Washington Blvd And Slauso...
#
#                                             type_of_work  seq  \
# 15253  Pedestrian Enhancements Including Pedestrian S...    1
#
#       date_request_initiated date_completed_request   mpo projectID  \
# 15253             2019-10-03             2019-10-03  SCAG      5006
#
#        prepared_y primary_agency_name
# 15253      2019.0         Los Angeles

# %%
(la_df>>count(_.prefix)>>arrange(-_.n)).head(20)
# Out:
#      prefix    n
# 65    HSIPL  705
# 87     STPL  441
# 22      CML  275
# 39       ER  175
# 60    HPLUL  143
# 5      ATPL  135
# 9      BHLS  101
# 48   FTACML   94
# 81    SRTSL   72
# 77   RPSTPL   63
# 18   BRLSZD   45
# 12    BPMPL   43
# 2     ACSTP   37
# 17     BRLS   36
# 57    HP21L   33
# 8      BHLO   20
# 82  SRTSLNI   20
# 40     ESPL   19
# 16     BRLO   18
# 53  FTASTPL   17

# %%
la_df>>group_by(_.primary_agency_name)>>count(_.prefix)>>arrange(-_.n)
# Out:
#     primary_agency_name prefix    n
# 219  Los Angeles County     ER  150
# 199         Los Angeles   STPL   84
# 225  Los Angeles County  HSIPL   81
# 193         Los Angeles  HSIPL   71
# 183         Los Angeles    CML   63
# ..                  ...    ...  ...
# 468              Vernon   HSIP    1
# 469              Vernon  HSIPL    1
# 471         West Covina  HPLUL    1
# 475    Westlake Village  HSIPL    1
# 481            Whittier  STPLH    1
#
# [482 rows x 3 columns]

# %% [markdown]
# ## Number of Unique Prefix Codes

# %%
la_df >> group_by(_.primary_agency_name) >> summarize(n=_.prefix.nunique()) >> arrange(-_.n)>>filter(_.n>=10)
# Out:
#                                    primary_agency_name   n
# 49                                         Los Angeles  34
# 50                                  Los Angeles County  31
# 47                                          Long Beach  18
# 51   Los Angeles County Metropolitan Transportation...  18
# 63                                              Oxnard  14
# 82                                       Santa Clarita  14
# 67                                            Pasadena  12
# 101                                     Ventura County  12

# %%
la_nunique= (la_df >> group_by(_.primary_agency_name) >> summarize(n=_.prefix.nunique()) >> arrange(-_.n)>>filter(_.n>=5))

# %%
chart = (alt.Chart(la_nunique)
         .mark_bar()
         .encode(
             x=alt.X("primary_agency_name", title="Agency Name"),
             y=alt.Y("n", title="Number of Unique Prefixes"),
             #column = "payment:N",
             color = alt.Color("n", 
                              scale=alt.Scale(
                                  range=altair_utils.FIVETHIRTYEIGHT_DIVERGING_COLORS
                              )
                              )
         )
         .properties( 
                      title="Number of Unique Prefixes by Agency in District 7")
)


#chart.save("dist7chart.png")
chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Most Common Types of Work by Agnecy

# %%
la_df>>group_by(_.primary_agency_name)>>count(_.type_of_work)>>arrange(-_.n)>>filter(_.n>=8)
# Out:
#                                     primary_agency_name  \
# 801   Los Angeles County Metropolitan Transportation...
# 655                                  Los Angeles County
# 0                                       Access Services
# 1270           Ventura County Transportation Commission
# 352                                         Los Angeles
# 603                                  Los Angeles County
# 496                                         Los Angeles
# 179                                              Downey
# 263                                           Lancaster
# 354                                         Los Angeles
# 785                                  Los Angeles County
# 516                                         Los Angeles
# 611                                  Los Angeles County
# 623                                  Los Angeles County
# 624                                  Los Angeles County
# 672                                  Los Angeles County
# 773                                  Los Angeles County
#
#                                            type_of_work   n
# 801                                        FTA Transfer  58
# 655                                   Emergency Opening  25
# 0                                          FTA Transfer  17
# 1270                                       FTA Transfer  15
# 352                               Bridge Rehabilitation  11
# 603                         Bikeway Access Improvements  11
# 496                             Pedestrian Improvements  10
# 179   Upgrade Traffic Signals; Install Left-turn Pha...   9
# 263            Construct Roundabout Within Existing R/w   9
# 354                      Bridge Rehabilitation/widening   9
# 785                         Traffic Signal Improvements   9
# 516      Replace Struct Deficient Viaduct With New (tc)   8
# 611        Bridge Preventative Maintenance Program (tc)   8
# 623                                  Bridge Replacement   8
# 624                             Bridge Replacement (tc)   8
# 672                                  Eo: Debris Removal   8
# 773                                    Seismic Retrofit   8

# %% [markdown]
# ## Most Common Project Locations

# %%
la_df>>group_by(_.primary_agency_name)>>count(_.project_location)>>arrange(-_.n)>>filter(_.n>5)
# Out:
#                            primary_agency_name  \
# 546                                Los Angeles
# 1272  Ventura County Transportation Commission
# 545                                Los Angeles
# 138                                Culver City
# 799                         Los Angeles County
# 106                                     Carson
# 660                         Los Angeles County
# 979                                   Pasadena
# 1277                               West Covina
#
#                                        project_location   n
# 546   Sixth Street Viaduct Over La River, Us 101, An...  13
# 1272                       Within The County Of Ventura   9
# 545   Sixth Street Viaduct Over La River And East Sa...   8
# 138               Down Town Area Of City Of Culver City   7
# 799             Various Locations In Los Angeles County   7
# 106   Intersection Of Avalon Blvd And Carson St. In ...   6
# 660   Community Of Florence-firestone In Los Angeles...   6
# 979       Pasadena Ave./sr 210 Wb On-ramp At Walnut St.   6
# 1277  Amar Road Street Improvements: Officer Chiles ...   6

# %%
la_df.sample()
# Out:
#         location prefix project_no               agency prepared_date  \
# 14790  Obligated  HSIPL  5413(014)  Rancho Palos Verdes    2019-09-10
#
#       submit__to_hq_date hq_review_date submit_to_fhwa_date to_fmis_date  \
# 14790         2019-09-10     2019-09-10          2019-09-10   2019-09-13
#
#        fed_requested  ac_requested  total_requested status_comment locode  \
# 14790            0.0           0.0           1101.0     Authorized   5413
#
#        dist             status  dist_processing_days  hq_processing_days  \
# 14790     7  E-76 approved on                    5.0                 0.0
#
#        fhwa_processing_days  ftip_no  \
# 14790                   3.0  SCAG015
#
#                                         project_location  \
# 14790  Hawthorne Blvd Intersection @highbridge Rd, Gr...
#
#                                             type_of_work  seq  \
# 14790  Synchrinize 7 Traffic Signals, Install Ped Cou...    5
#
#       date_request_initiated date_completed_request   mpo projectID  \
# 14790             2019-09-05             2019-09-06  SCAG      5413
#
#        prepared_y  primary_agency_name
# 14790      2019.0  Rancho Palos Verdes

# %% [markdown]
# ## Number of Obligations by Year

# %%
la_df>>group_by(_.primary_agency_name)>>count(_.prepared_date)>>arrange(-_.n)
# Out:
#                                     primary_agency_name prepared_date  n
# 1419  Los Angeles County Metropolitan Transportation...    2015-07-15  9
# 1441  Los Angeles County Metropolitan Transportation...    2018-05-31  9
# 2                                       Access Services    2016-03-02  7
# 926                                         Los Angeles    2019-02-07  7
# 1594                                             Oxnard    2016-06-24  6
# ...                                                 ...           ... ..
# 2432                                           Whittier    2020-05-21  1
# 2433                                           Whittier    2020-08-23  1
# 2434                                           Whittier    2020-09-03  1
# 2435                                           Whittier    2021-09-24  1
# 2436                                           Whittier    2021-10-20  1
#
# [2437 rows x 3 columns]

# %%
la_df>>group_by(_.primary_agency_name)>>count(_.prepared_y)>>arrange(-_.n)>>filter(_.n>10)
# Out:
#                                    primary_agency_name  prepared_y   n
# 253                                        Los Angeles      2014.0  86
# 267                                 Los Angeles County      2019.0  75
# 255                                        Los Angeles      2016.0  71
# 254                                        Los Angeles      2015.0  69
# 268                                 Los Angeles County      2020.0  69
# 262                                 Los Angeles County      2014.0  67
# 266                                 Los Angeles County      2018.0  64
# 259                                        Los Angeles      2020.0  59
# 265                                 Los Angeles County      2017.0  57
# 257                                        Los Angeles      2018.0  54
# 256                                        Los Angeles      2017.0  52
# 258                                        Los Angeles      2019.0  50
# 260                                        Los Angeles      2021.0  44
# 263                                 Los Angeles County      2015.0  41
# 264                                 Los Angeles County      2016.0  38
# 269                                 Los Angeles County      2021.0  34
# 546                                     Ventura County      2019.0  24
# 274  Los Angeles County Metropolitan Transportation...      2018.0  21
# 336                                             Oxnard      2016.0  21
# 544                                     Ventura County      2017.0  20
# 271  Los Angeles County Metropolitan Transportation...      2015.0  18
# 334                                             Oxnard      2014.0  17
# 437                                      Santa Clarita      2014.0  16
# 543                                     Ventura County      2016.0  16
# 245                                         Long Beach      2017.0  15
# 246                                         Long Beach      2018.0  15
# 470                                        Simi Valley      2014.0  14
# 541                                     Ventura County      2014.0  14
# 141                                             Downey      2016.0  13
# 144                                             Downey      2019.0  13
# 359                                           Pasadena      2018.0  13
# 247                                         Long Beach      2019.0  12
# 355                                           Pasadena      2014.0  12
# 356                                           Pasadena      2015.0  12
# 438                                      Santa Clarita      2015.0  12
# 440                                      Santa Clarita      2017.0  12
# 472                                        Simi Valley      2016.0  12
# 542                                     Ventura County      2015.0  12
# 73                                            Caltrans      2016.0  11
# 237                                          Lancaster      2021.0  11
# 242                                         Long Beach      2014.0  11
# 439                                      Santa Clarita      2016.0  11
# 441                                      Santa Clarita      2018.0  11
# 545                                     Ventura County      2018.0  11

# %%
la_df_year = (la_df>>group_by(_.primary_agency_name)>>count(_.prepared_y)>>arrange(-_.n)>>filter(_.n>10))

# %% [markdown]
# ### Chart

# %%
chart = (alt.Chart(la_df_year)
         .mark_bar()
         .encode(
             x=alt.X("prepared_y", title="Prepared Year"),
             y=alt.Y("n", title="Number of Obligations in each Year"),
             #column = "payment:N",
             color = alt.Color("primary_agency_name", 
                              scale=alt.Scale(
                                  range=altair_utils.FIVETHIRTYEIGHT_DIVERGING_COLORS
                              )
                              )
         )
         .properties( 
                      title="Number of Obliations per Year")
)


#chart.save("dist7chart.png")
chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Agencies with the most unique project numbers

# %%
la_df>>group_by(_.primary_agency_name, _.prefix)>>count(_.project_no)>>arrange(-_.n)>>filter(_.n>5)
# Out:
#                                     primary_agency_name   prefix project_no  n
# 368                                         Los Angeles   BRLSZD  5006(839)  9
# 829   Los Angeles County Metropolitan Transportation...  FTAATPL  6065(225)  9
# 837   Los Angeles County Metropolitan Transportation...   FTACML  6065(199)  9
# 364                                         Los Angeles   BRLSZD  5006(664)  8
# 2                                       Access Services  FTASTPL  6312(022)  7
# 142                                         Culver City      CML  5240(025)  7
# 110                                              Carson    HSIPL  5403(022)  6
# 286                                          Long Beach      CML  5108(181)  6
# 365                                         Los Angeles   BRLSZD  5006(811)  6
# 982                                            Pasadena    HSIPL  5064(075)  6
# 1286           Ventura County Transportation Commission   FTACML  6155(089)  6
# 1302                                        West Covina     STPL  5259(026)  6

# %% [markdown]
# ## Average Funds

# %%
(la_df>>group_by(_.primary_agency_name)>>summarize(avg_funds=_.total_requested.mean())>>arrange(-_.avg_funds)).head(20)
# Out:
#                                    primary_agency_name     avg_funds
# 0                                      Access Services  3.301074e+07
# 51   Los Angeles County Metropolitan Transportation...  1.696266e+07
# 15                                            Caltrans  1.552537e+07
# 95         Southern California Regional Rail Authority  8.633433e+06
# 37                                            Industry  6.324183e+06
# 47                                          Long Beach  4.771285e+06
# 96                              Sunline Transit Agency  4.622594e+06
# 80           San Gabriel Valley Council of Governments  2.697375e+06
# 4                    Antelope Valley Transit Authority  2.475103e+06
# 90                            South Coast Area Transit  2.109463e+06
# 36                                     Huntington Park  1.790354e+06
# 48                   Long Beach Transportation Company  1.764100e+06
# 84                                        Santa Monica  1.630348e+06
# 49                                         Los Angeles  1.587264e+06
# 55                                     Manhattan Beach  1.121750e+06
# 14                                    Calaveras County  9.684000e+05
# 1                                         Agoura Hills  9.324801e+05
# 99                                            Torrance  8.238530e+05
# 77                                           San Dimas  8.005395e+05
# 103                                             Vernon  7.932742e+05

# %% [markdown]
# ### Top 50 Agencies with highest funds

# %%
avg_funds_top = (la_df>>group_by(_.primary_agency_name)>>summarize(avg_funds=_.total_requested.mean())>>arrange(-_.avg_funds)).head(50)

# %%
chart = (alt.Chart(avg_funds_top)
         .mark_bar()
         .encode(
             x=alt.X("primary_agency_name", title="Primary Agency Name"),
             y=alt.Y("avg_funds", title="Average Total Funds Requested"),
             #column = "payment:N",
             color = alt.Color("avg_funds", 
                              scale=alt.Scale(
                                  range=altair_utils.FIVETHIRTYEIGHT_DIVERGING_COLORS
                              )
                              )
         )
         .properties( 
                      title="Average Total Funds Requested by Agency: Top 50")
)


#chart.save("dist7chart.png")
chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Bottom 50 Agencies with lowest funds

# %%
avg_funds_bottom = (la_df>>group_by(_.primary_agency_name)>>summarize(avg_funds=_.total_requested.mean())>>arrange(-_.avg_funds)).tail(50)

# %%
chart = (alt.Chart(avg_funds_bottom)
         .mark_bar()
         .encode(
             x=alt.X("primary_agency_name", title="Primary Agency Name"),
             y=alt.Y("avg_funds", title="Average Total Funds Requested"),
             #column = "payment:N",
             color = alt.Color("avg_funds", 
                              scale=alt.Scale(
                                  range=altair_utils.FIVETHIRTYEIGHT_DIVERGING_COLORS
                              )
                              )
         )
         .properties( 
                      title="Average Total Funds Requested by Agency: Bottom 50")
)


#chart.save("dist7chart.png")
chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Functions to look by Prefix and by Agency:

# %% [markdown]
# ### By Agency:

# %%
    @interact
    
    def dla_get_prefix(place=la_df.primary_agency_name.sort_values().unique().tolist()):
        
        agencies = la_df[la_df.primary_agency_name==place]
    
        prefix_count_n = agencies >> count(_.prefix)
    
        display(Markdown(f"**Summary Statistics for {place}**"))
        display(Markdown(f"The number of obligations {place} has is {len(agencies)}"))
        
        display(Markdown(f"The number of prefix codes {place} uses is {len(prefix_count_n)}"))
        
        
        
        # for the table- using one as some agencies only have one entry
        pd.set_option("display.max_columns", None)
        display(df[df.agency == place][['fed_requested','ac_requested','total_requested']].describe())
        
        display(Markdown(f"**Top Project Types in {place}**"))
        display((la_df[la_df.primary_agency_name == place] >> count(_.type_of_work) >> arrange(-_.n)).head(5)) 
        # graphs 
    
         
        ax1 = (prefix_count_n
            >> ggplot(aes("prefix", "n", fill="prefix")) 
               + geom_col() 
               + theme(axis_text_x = element_text(angle = 45 , hjust=1))
               + labs(title='Agency Program Codes', x='Program Codes', y='Number of Obligations', fill="Program Type")
               #+ scale_fill_manual(altair_utils.FIVETHIRTYEIGHT_CATEGORY_COLORS)
               #FIVETHIRTYEIGHT_CATEGORY_COLORS doesnt have enough colors for values 
        )
        return ax1
# Out:
# interactive(children=(Dropdown(description='place', options=('Access Services', 'Agoura Hills', 'Alameda Corri…

# %% [markdown]
# ### By Prefix:

# %%
@interact
def prefix_all_agencies_4(prefix=la_df.prefix.sort_values().unique().tolist()):
    
    
    # graphs 
    prefixes = la_df[la_df.prefix== prefix]
    
    prefix_count_num = (prefixes >> count(_.primary_agency_name) >> arrange(-_.n)).head(50)
    
    prefix_count = (prefixes >> count(_.primary_agency_name) >> arrange(-_.n)).head(20)
    
    display(Markdown(f"**The number of agencies using {prefix} is {len(prefix_count_num)}**"))
    
    # for the table- using one as some agencies only have one entry
    display(la_df[(la_df.prefix == prefix)].sample(1))
    
    
    ax1 = (prefix_count
            >> ggplot(aes("primary_agency_name", "n", fill="primary_agency_name")) 
                + geom_col() 
                + theme(axis_text_x = element_text(angle = 45 , hjust=1))
                + labs(title='Top Agencies using Prefix', x='Agency', y='Number of Obligations', fill="Agency")
            )    
    return ax1
# Out:
# interactive(children=(Dropdown(description='prefix', options=('ACNHPI', 'ACSTER', 'ACSTP', 'ATCMTD', 'ATPCML',…

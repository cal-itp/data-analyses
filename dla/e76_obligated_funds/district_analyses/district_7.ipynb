# %% [markdown]
# # Obligations in District 7
#
# Using data from the Division of Local Assistance [Obligation list](https://dot.ca.gov/programs/local-assistance/reports/e-76-obligated)

# %%
import numpy as np
import pandas as pd
from siuba import *

import altair as alt
import altair_saver
from plotnine import *

from shared_utils import altair_utils
alt.themes.enable("fivethirtyeight")


import clean_data
import _dla_utils

import ipywidgets as widgets
from ipywidgets import *
from IPython.display import Markdown
from IPython.core.display import display

# %%
#df = _clean_data.make_clean_data()
df= pd.read_parquet("dla_df.parquet")

# %%
df.sample()
# Out:
#         location   prefix project_no agency prepared_date submit__to_hq_date  \
# 12160  Obligated  SRTSLNI  5193(034)   Taft    2013-12-31         2014-03-25
#
#       hq_review_date submit_to_fhwa_date to_fmis_date  fed_requested  ...  \
# 12160     2014-03-25          2014-04-15   2014-04-15       409650.0  ...
#
#          ftip_no                        project_location  \
# 12160  KER110602  Various Locations (site Plan Attached)
#
#                                            type_of_work seq  \
# 12160  Install Ramps, Speed Signs, In-pavement Lighting   2
#
#        date_request_initiated date_completed_request   mpo  projectID  \
# 12160                     NaT                    NaT  KCOG       5193
#
#        prepared_y primary_agency_name
# 12160      2013.0                Taft
#
# [1 rows x 29 columns]

# %%
df = df>>filter(_.dist==7)

# %%
df_years = _dla_utils.count_all_years(df)

# %%
df_years
# Out:
#     prepared_y  dist  ac_requested_sum  fed_requested_sum  \
# 10        2021     7     -1.982682e+07       4.442839e+08
# 9         2020     7     -2.785211e+07       4.189328e+08
# 8         2019     7     -1.299494e+07       3.632827e+08
# 0         2018     7     -5.915498e+07       3.335298e+08
# 1         2017     7     -6.039668e+07       3.115877e+08
# 2         2016     7     -9.384213e+07       4.303013e+08
# 3         2015     7      1.348315e+08       2.590450e+08
# 5         2014     7      2.349622e+08       2.915008e+08
# 6         2013     7      2.855137e+07       1.464760e+07
# 7         2012     7      0.000000e+00      -1.094570e+05
# 4         <NA>     7               NaN                NaN
#
#     total_requested_sum  ac_requested_mean  fed_requested_mean  \
# 10         6.336926e+08      -82268.967718        1.843502e+06
# 9          9.588052e+08      -87037.856375        1.309165e+06
# 8          3.986935e+08      -37449.397695        1.046924e+06
# 0          3.346124e+08     -176056.483304        9.926483e+05
# 1          2.997071e+08     -184136.219878        9.499626e+05
# 2          4.903662e+08     -248918.123767        1.144418e+06
# 3          5.859364e+08      364409.335135        7.001215e+05
# 5          5.851461e+08      546423.818605        6.779089e+05
# 6         -2.300755e+07      892230.437500        4.577374e+05
# 7         -1.235050e+05           0.000000       -1.094570e+05
# 4                   NaN                NaN                 NaN
#
#     total_requested_mean  unique_mpo  unique_prefix  \
# 10          2.629430e+06         2.0           41.0
# 9           2.996266e+06         1.0           44.0
# 8           1.148973e+06         2.0           37.0
# 0           9.958701e+05         1.0           39.0
# 1           9.137411e+05         2.0           39.0
# 2           1.300706e+06         2.0           43.0
# 3           1.583612e+06         8.0           41.0
# 5           1.360805e+06        10.0           42.0
# 6          -7.189861e+05         4.0           20.0
# 7          -1.235050e+05         1.0            1.0
# 4                    NaN         NaN            NaN
#
#     unique_primary_agency_name  unique_project_location  unique_project_no  \
# 10                        62.0                    203.0              210.0
# 9                         60.0                    277.0              283.0
# 8                         67.0                    293.0              304.0
# 0                         63.0                    280.0              294.0
# 1                         73.0                    282.0              296.0
# 2                         76.0                    308.0              323.0
# 3                         85.0                    299.0              312.0
# 5                         77.0                    362.0              375.0
# 6                         18.0                     30.0               32.0
# 7                          1.0                      1.0                1.0
# 4                          NaN                      NaN                NaN
#
#     unique_type_of_work
# 10                196.0
# 9                 268.0
# 8                 285.0
# 0                 267.0
# 1                 266.0
# 2                 304.0
# 3                 269.0
# 5                 323.0
# 6                  31.0
# 7                   1.0
# 4                   NaN

# %%
df_top = _dla_utils.find_top(df)

# %%
df_top
# Out:
#                                        value  count             variable
# 0                                      HSIPL    705               prefix
# 1                                       STPL    441               prefix
# 2                                        CML    275               prefix
# 3                                         ER    175               prefix
# 4                                      HPLUL    143               prefix
# ..                                       ...    ...                  ...
# 16                               Culver City     32  primary_agency_name
# 17                                   Burbank     30  primary_agency_name
# 18                                  Glendale     30  primary_agency_name
# 19  Ventura County Transportation Commission     29  primary_agency_name
# 0                                          7   2787                 dist
#
# [140 rows x 3 columns]

# %% [markdown]
# ## Which Agencies have Obligations

# %% [markdown]
# ### How many Unique Agencies

# %%
_dla_utils.calculate_data_all(df, 'primary_agency_name', aggfunc="nunique")
# Out:
#    dist  primary_agency_name
# 0     7                  108

# %% [markdown]
# ### Agencies with the most Obligations

# %%
df_top>>filter(_.variable == 'primary_agency_name')
# Out:
#                                                 value  count  \
# 0                                         Los Angeles    490
# 1                                  Los Angeles County    451
# 2                                      Ventura County    115
# 3   Los Angeles County Metropolitan Transportation...     85
# 4                                       Santa Clarita     85
# 5                                          Long Beach     81
# 6                                              Oxnard     74
# 7                                            Pasadena     71
# 8                                              Downey     63
# 9                                         Simi Valley     61
# 10                                          Lancaster     57
# 11                                           Palmdale     46
# 12                                        Pico Rivera     40
# 13                                      Thousand Oaks     39
# 14                                   San Buenaventura     35
# 15                                          Camarillo     33
# 16                                        Culver City     32
# 17                                            Burbank     30
# 18                                           Glendale     30
# 19           Ventura County Transportation Commission     29
#
#                variable
# 0   primary_agency_name
# 1   primary_agency_name
# 2   primary_agency_name
# 3   primary_agency_name
# 4   primary_agency_name
# 5   primary_agency_name
# 6   primary_agency_name
# 7   primary_agency_name
# 8   primary_agency_name
# 9   primary_agency_name
# 10  primary_agency_name
# 11  primary_agency_name
# 12  primary_agency_name
# 13  primary_agency_name
# 14  primary_agency_name
# 15  primary_agency_name
# 16  primary_agency_name
# 17  primary_agency_name
# 18  primary_agency_name
# 19  primary_agency_name

# %% [markdown]
# ### Agencies with the least Obligations

# %%
(df>>count(_.primary_agency_name)>>arrange(-_.n)).tail(10)
# Out:
#                                primary_agency_name  n
# 71                              Port Of Long Beach  2
# 86                                    Sierra Madre  2
# 2        Alameda Corridor Transportation Authority  1
# 4                Antelope Valley Transit Authority  1
# 14                                Calaveras County  1
# 35                                   Hermosa Beach  1
# 36                                 Huntington Park  1
# 70                                    Port Hueneme  1
# 74                           Rolling Hills Estates  1
# 100  U.S. Forest Service, Pacific Southwest Region  1

# %% [markdown]
# ### Charting

# %%
_dla_utils.basic_bar_chart((df_top>>filter(_.variable=='primary_agency_name')), 'value', 'count')
# Out:
# alt.Chart(...)

# %%
df_top>>filter(_.variable=='prefix')
# Out:
#       value  count variable
# 0     HSIPL    705   prefix
# 1      STPL    441   prefix
# 2       CML    275   prefix
# 3        ER    175   prefix
# 4     HPLUL    143   prefix
# 5      ATPL    135   prefix
# 6      BHLS    101   prefix
# 7    FTACML     94   prefix
# 8     SRTSL     72   prefix
# 9    RPSTPL     63   prefix
# 10   BRLSZD     45   prefix
# 11    BPMPL     43   prefix
# 12    ACSTP     37   prefix
# 13     BRLS     36   prefix
# 14    HP21L     33   prefix
# 15     BHLO     20   prefix
# 16  SRTSLNI     20   prefix
# 17     ESPL     19   prefix
# 18     BRLO     18   prefix
# 19  FTASTPL     17   prefix

# %%
df>>group_by(_.primary_agency_name)>>count(_.prefix)>>arrange(-_.n)
# Out:
#     primary_agency_name prefix    n
# 219  Los Angeles County     ER  150
# 199         Los Angeles   STPL   84
# 225  Los Angeles County  HSIPL   81
# 193         Los Angeles  HSIPL   71
# 183         Los Angeles    CML   63
# ..                  ...    ...  ...
# 468              Vernon   HSIP    1
# 469              Vernon  HSIPL    1
# 471         West Covina  HPLUL    1
# 475    Westlake Village  HSIPL    1
# 481            Whittier  STPLH    1
#
# [482 rows x 3 columns]

# %% [markdown]
# ## Number of Unique Prefix Codes

# %%
_dla_utils.get_nunique(df, 'prefix', 'primary_agency_name')
# Out:
#                                    primary_agency_name   n
# 49                                         Los Angeles  34
# 50                                  Los Angeles County  31
# 47                                          Long Beach  18
# 51   Los Angeles County Metropolitan Transportation...  18
# 63                                              Oxnard  14
# ..                                                 ...  ..
# 90                            South Coast Area Transit   1
# 91                                      South El Monte   1
# 95         Southern California Regional Rail Authority   1
# 100      U.S. Forest Service, Pacific Southwest Region   1
# 104                                             Walnut   1
#
# [108 rows x 2 columns]

# %%
_dla_utils.basic_bar_chart(((_dla_utils.get_nunique(df, 'prefix', 'primary_agency_name')).head(30)),
                            'primary_agency_name', 'n')
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Most Common Types of Work by Agnecy

# %%
_dla_utils.get_nunique(df, 'primary_agency_name', 'type_of_work')
# Out:
#                                            type_of_work   n
# 342                                        FTA Transfer  16
# 920                            Road Rehabilitation (tc)   7
# 306                                   Emergency Opening   6
# 91                                Bridge Rehabilitation   5
# 1161                                    Upgrade Signals   5
# ...                                                 ...  ..
# 1225  Widening Wilmington Ave + I-405 Ramp Modification   1
# 1226                     Widening, Right Turn Lanes, La   1
# 1227  Widening,install Sidewalks, Traffic Improvements,   1
# 1228   Widenning Roadway(install Right Turn Lanes, Etc)   1
# 1229  Xwalks; Ped Heads; Flash Beacons; Signs; Bulb ...   1
#
# [1230 rows x 2 columns]

# %%
_dla_utils.calculate_data_head(df, "primary_agency_name",'type_of_work', aggfunc="count")
# Out:
#                                            type_of_work  primary_agency_name
# 342                                        FTA Transfer                  130
# 306                                   Emergency Opening                   34
# 920                            Road Rehabilitation (tc)                   20
# 103                                  Bridge Replacement                   19
# 91                                Bridge Rehabilitation                   18
# 1096                        Traffic Signal Improvements                   13
# 727                             Pedestrian Improvements                   13
# 104                             Bridge Replacement (tc)                   12
# 1161                                    Upgrade Signals                   12
# 59                          Bikeway Access Improvements                   11
# 919                                 Road Rehabilitation                   10
# 100                      Bridge Rehabilitation/widening                    9
# 214            Construct Roundabout Within Existing R/w                    9
# 738                                  Pedestrian Walkway                    9
# 1191  Upgrade Traffic Signals; Install Left-turn Pha...                    9
# 972                                    Seismic Retrofit                    9
# 72         Bridge Preventative Maintenance Program (tc)                    8
# 862      Replace Struct Deficient Viaduct With New (tc)                    8
# 327                                  Eo: Debris Removal                    8
# 232                                        Construction                    7

# %%
la_df>>group_by(_.primary_agency_name)>>count(_.type_of_work)>>arrange(-_.n)>>filter(_.n>=8)
# Out:
#                                     primary_agency_name  \
# 801   Los Angeles County Metropolitan Transportation...
# 655                                  Los Angeles County
# 0                                       Access Services
# 1270           Ventura County Transportation Commission
# 352                                         Los Angeles
# 603                                  Los Angeles County
# 496                                         Los Angeles
# 179                                              Downey
# 263                                           Lancaster
# 354                                         Los Angeles
# 785                                  Los Angeles County
# 516                                         Los Angeles
# 611                                  Los Angeles County
# 623                                  Los Angeles County
# 624                                  Los Angeles County
# 672                                  Los Angeles County
# 773                                  Los Angeles County
#
#                                            type_of_work   n
# 801                                        FTA Transfer  58
# 655                                   Emergency Opening  25
# 0                                          FTA Transfer  17
# 1270                                       FTA Transfer  15
# 352                               Bridge Rehabilitation  11
# 603                         Bikeway Access Improvements  11
# 496                             Pedestrian Improvements  10
# 179   Upgrade Traffic Signals; Install Left-turn Pha...   9
# 263            Construct Roundabout Within Existing R/w   9
# 354                      Bridge Rehabilitation/widening   9
# 785                         Traffic Signal Improvements   9
# 516      Replace Struct Deficient Viaduct With New (tc)   8
# 611        Bridge Preventative Maintenance Program (tc)   8
# 623                                  Bridge Replacement   8
# 624                             Bridge Replacement (tc)   8
# 672                                  Eo: Debris Removal   8
# 773                                    Seismic Retrofit   8

# %% [markdown]
# ## Most Common Project Locations

# %%
df_top>>filter(_.variable=='project_location')
# Out:
#                                                 value  count          variable
# 0   Sixth Street Viaduct Over La River, Us 101, An...     13  project_location
# 1                        Within The County Of Ventura      9  project_location
# 2                                            Citywide      8  project_location
# 3   Sixth Street Viaduct Over La River And East Sa...      8  project_location
# 4               Down Town Area Of City Of Culver City      7  project_location
# 5             Various Locations In Los Angeles County      7  project_location
# 6   Amar Road Street Improvements: Officer Chiles ...      6  project_location
# 7   Community Of Florence-firestone In Los Angeles...      6  project_location
# 8   Intersection Of Avalon Blvd And Carson St. In ...      6  project_location
# 9       Pasadena Ave./sr 210 Wb On-ramp At Walnut St.      6  project_location
# 10  1st St Br Over Glendale/beverly Blvd, Br# 53c0045      5  project_location
# 11  524 Various Locations Within Unincorporated Ar...      5  project_location
# 12  Along Hollywood And Sunset Blbd. Bet'n Gower &...      5  project_location
# 13           Atlantic Bl Br Over La River, Br#53c0252      5  project_location
# 14  Ave. L And Challenger Way (10th St. E.) Inters...      5  project_location
# 15  Dolores Huerta Es, 28th Street Es And Quincy J...      5  project_location
# 16  Five Bridges In The City Of Santa Clarita (see...      5  project_location
# 17   Hyperion Viaduct Over La River Bridge # 53c-1881      5  project_location
# 18  In Ventura County, On Central Ave. From Joan W...      5  project_location
# 19  Inglewood Ave At: Imperial Hwy, 118th St, 120t...      5  project_location

# %% [markdown]
# ## Number of Obligations by Year

# %%
df_top>>filter(_.variable=='prepared_y')
# Out:
#     value  count    variable
# 0  2014.0    430  prepared_y
# 1  2016.0    377  prepared_y
# 2  2015.0    370  prepared_y
# 3  2019.0    347  prepared_y
# 4  2018.0    336  prepared_y
# 5  2017.0    328  prepared_y
# 6  2020.0    320  prepared_y
# 7  2021.0    241  prepared_y
# 8  2013.0     32  prepared_y
# 9  2012.0      1  prepared_y

# %%
la_df>>group_by(_.primary_agency_name)>>count(_.prepared_date)>>arrange(-_.n)
# Out:
#                                     primary_agency_name prepared_date  n
# 1419  Los Angeles County Metropolitan Transportation...    2015-07-15  9
# 1441  Los Angeles County Metropolitan Transportation...    2018-05-31  9
# 2                                       Access Services    2016-03-02  7
# 926                                         Los Angeles    2019-02-07  7
# 1594                                             Oxnard    2016-06-24  6
# ...                                                 ...           ... ..
# 2432                                           Whittier    2020-05-21  1
# 2433                                           Whittier    2020-08-23  1
# 2434                                           Whittier    2020-09-03  1
# 2435                                           Whittier    2021-09-24  1
# 2436                                           Whittier    2021-10-20  1
#
# [2437 rows x 3 columns]

# %% [markdown]
# ### Chart

# %%
_dla_utils.basic_line_chart((df_top>>filter(_.variable=='prepared_y')), 'value', 'count')
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Agencies with the most unique project numbers

# %%
la_df>>group_by(_.primary_agency_name, _.prefix)>>count(_.project_no)>>arrange(-_.n)>>filter(_.n>5)
# Out:
#                                     primary_agency_name   prefix project_no  n
# 368                                         Los Angeles   BRLSZD  5006(839)  9
# 829   Los Angeles County Metropolitan Transportation...  FTAATPL  6065(225)  9
# 837   Los Angeles County Metropolitan Transportation...   FTACML  6065(199)  9
# 364                                         Los Angeles   BRLSZD  5006(664)  8
# 2                                       Access Services  FTASTPL  6312(022)  7
# 142                                         Culver City      CML  5240(025)  7
# 110                                              Carson    HSIPL  5403(022)  6
# 286                                          Long Beach      CML  5108(181)  6
# 365                                         Los Angeles   BRLSZD  5006(811)  6
# 982                                            Pasadena    HSIPL  5064(075)  6
# 1286           Ventura County Transportation Commission   FTACML  6155(089)  6
# 1302                                        West Covina     STPL  5259(026)  6

# %% [markdown]
# ## Average Funds

# %%
_dla_utils.calculate_data_all(df, 'total_requested', 'primary_agency_name', aggfunc="mean")
# Out:
#                                    primary_agency_name  total_requested
# 0                                      Access Services     3.301074e+07
# 51   Los Angeles County Metropolitan Transportation...     1.696266e+07
# 15                                            Caltrans     1.552537e+07
# 95         Southern California Regional Rail Authority     8.633433e+06
# 37                                            Industry     6.324183e+06
# ..                                                 ...              ...
# 13                                           Calabasas     7.658333e+03
# 70                                        Port Hueneme     6.841710e+03
# 106                                   Westlake Village     6.042513e+03
# 60                                            Moorpark     5.751582e+03
# 56                                             Maywood     1.058800e+02
#
# [96 rows x 2 columns]

# %% [markdown]
# ### Top 50 Agencies with highest funds

# %%
((_dla_utils.calculate_data_all(df, 'total_requested', 'primary_agency_name', aggfunc="mean"))>>arrange(-_.total_requested)).head(50)
# Out:
#                                    primary_agency_name  total_requested
# 0                                      Access Services     3.301074e+07
# 51   Los Angeles County Metropolitan Transportation...     1.696266e+07
# 15                                            Caltrans     1.552537e+07
# 95         Southern California Regional Rail Authority     8.633433e+06
# 37                                            Industry     6.324183e+06
# 47                                          Long Beach     4.771285e+06
# 96                              Sunline Transit Agency     4.622594e+06
# 80           San Gabriel Valley Council of Governments     2.697375e+06
# 4                    Antelope Valley Transit Authority     2.475103e+06
# 90                            South Coast Area Transit     2.109463e+06
# 36                                     Huntington Park     1.790354e+06
# 48                   Long Beach Transportation Company     1.764100e+06
# 84                                        Santa Monica     1.630348e+06
# 49                                         Los Angeles     1.587264e+06
# 55                                     Manhattan Beach     1.121750e+06
# 14                                    Calaveras County     9.684000e+05
# 1                                         Agoura Hills     9.324801e+05
# 99                                            Torrance     8.238530e+05
# 77                                           San Dimas     8.005395e+05
# 103                                             Vernon     7.932742e+05
# 30                                             Gardena     7.479218e+05
# 52                 Los Angeles Unified School District     6.795000e+05
# 57                                            Monrovia     5.932498e+05
# 67                                            Pasadena     5.858111e+05
# 45                                           Lancaster     5.806168e+05
# 92                                          South Gate     5.585163e+05
# 5                                              Arcadia     5.529435e+05
# 107                                           Whittier     5.499309e+05
# 89         South Coast Air Quality Management District     5.467780e+05
# 85                                         Santa Paula     5.461772e+05
# 79                                         San Gabriel     5.455978e+05
# 34                                           Hawthorne     5.286239e+05
# 3                                             Alhambra     5.239460e+05
# 98                                       Thousand Oaks     5.052100e+05
# 38                                           Inglewood     4.968486e+05
# 94      Southern California Association of Governments     4.958109e+05
# 20                                            Commerce     4.903470e+05
# 102           Ventura County Transportation Commission     4.830531e+05
# 24                                         Culver City     4.817190e+05
# 82                                       Santa Clarita     4.748523e+05
# 64                                            Palmdale     4.723531e+05
# 61                                             Norwalk     4.523901e+05
# 53                                             Lynwood     4.514277e+05
# 26                                              Downey     4.407396e+05
# 31                                            Glendale     4.399263e+05
# 50                                  Los Angeles County     4.267247e+05
# 22                                              Covina     3.964122e+05
# 78                                        San Fernando     3.920817e+05
# 40                                La Canada Flintridge     3.766277e+05
# 68                                         Pico Rivera     3.726550e+05

# %%
_dla_utils.basic_bar_chart((((_dla_utils.calculate_data_all(df, 'total_requested', 'primary_agency_name', aggfunc="mean"))
                          >>arrange(-_.total_requested)).head(50)
                        ), 'primary_agency_name','total_requested'
                       )
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Bottom 50 Agencies with lowest funds

# %%
avg_funds_bottom = (df>>group_by(_.primary_agency_name)>>summarize(avg_funds=_.total_requested.mean())>>arrange(-_.avg_funds)).tail(50)

# %%
avg_funds_bottom
# Out:
#                                primary_agency_name     avg_funds
# 43                                        La Verne  2.675626e+05
# 59                                   Monterey Park  2.669155e+05
# 65                                Palos Verdes Est  2.512439e+05
# 39                                       Irwindale  2.372913e+05
# 101                                 Ventura County  2.169500e+05
# 25                                     Diamond Bar  2.100808e+05
# 42                                       La Puente  2.066813e+05
# 18                                        Cerritos  2.040920e+05
# 66                                       Paramount  2.037486e+05
# 58                                      Montebello  1.864869e+05
# 75                                        Rosemead  1.810697e+05
# 86                                    Sierra Madre  1.767775e+05
# 9                                             Bell  1.761151e+05
# 27                                        El Monte  1.678948e+05
# 23                                          Cudahy  1.380673e+05
# 91                                  South El Monte  1.293904e+05
# 41                                       La Mirada  1.293139e+05
# 10                                    Bell Gardens  1.221117e+05
# 62                                            Ojai  1.178314e+05
# 17                                          Carson  1.166179e+05
# 72                             Rancho Palos Verdes  1.150797e+05
# 32                                        Glendora  1.139149e+05
# 105                                    West Covina  1.086327e+05
# 33                                Hawaiian Gardens  1.059088e+05
# 19                                       Claremont  9.429196e+04
# 6                                          Artesia  8.144668e+04
# 7                                            Azusa  8.124723e+04
# 93                                  South Pasadena  7.074766e+04
# 81                                      San Marino  6.672017e+04
# 97                                     Temple City  6.499566e+04
# 29                                        Fillmore  4.570718e+04
# 35                                   Hermosa Beach  3.317973e+04
# 21                                         Compton  1.949623e+04
# 13                                       Calabasas  7.658333e+03
# 70                                    Port Hueneme  6.841710e+03
# 106                               Westlake Village  6.042513e+03
# 60                                        Moorpark  5.751582e+03
# 56                                         Maywood  1.058800e+02
# 28                                      El Segundo  0.000000e+00
# 71                              Port Of Long Beach  0.000000e+00
# 100  U.S. Forest Service, Pacific Southwest Region  0.000000e+00
# 54                                          Malibu -6.975843e+03
# 46                                        Lawndale -1.979988e+04
# 63                                          Oxnard -2.536796e+04
# 87                                     Signal Hill -8.204652e+04
# 104                                         Walnut -1.285305e+05
# 74                           Rolling Hills Estates -1.918213e+05
# 69                                          Pomona -2.755195e+06
# 83                                Santa Fe Springs -9.764168e+06
# 2        Alameda Corridor Transportation Authority -1.581832e+07

# %%
_dla_utils.basic_bar_chart(avg_funds_bottom, 'primary_agency_name','avg_funds')
# Out:
# alt.Chart(...)

# %%
((
    _dla_utils.calculate_data_all(
        df, 'total_requested', 'primary_agency_name', aggfunc="mean"))
>>arrange(-_.total_requested)).tail(50)
# Out:
#       primary_agency_name  total_requested
# 22                 Covina    396412.200000
# 78           San Fernando    392081.732727
# 40   La Canada Flintridge    376627.693000
# 68            Pico Rivera    372655.048000
# 73          Redondo Beach    362835.530000
# 8            Baldwin Park    315742.857143
# 76       San Buenaventura    292454.708286
# 12                Burbank    281775.839667
# 88            Simi Valley    281380.672951
# 44               Lakewood    279118.160000
# 11             Bellflower    275618.658889
# 16              Camarillo    270489.567879
# 43               La Verne    267562.644667
# 59          Monterey Park    266915.492500
# 65       Palos Verdes Est    251243.850000
# 39              Irwindale    237291.325000
# 101        Ventura County    216950.039565
# 25            Diamond Bar    210080.798571
# 42              La Puente    206681.293333
# 18               Cerritos    204092.022000
# 66              Paramount    203748.562857
# 58             Montebello    186486.872353
# 75               Rosemead    181069.704545
# 86           Sierra Madre    176777.500000
# 9                    Bell    176115.128333
# 27               El Monte    167894.794706
# 23                 Cudahy    138067.333333
# 91         South El Monte    129390.437619
# 41              La Mirada    129313.880000
# 10           Bell Gardens    122111.685200
# 62                   Ojai    117831.387778
# 17                 Carson    116617.880909
# 72    Rancho Palos Verdes    115079.691905
# 32               Glendora    113914.931250
# 105           West Covina    108632.724667
# 33       Hawaiian Gardens    105908.806667
# 19              Claremont     94291.955000
# 6                 Artesia     81446.685000
# 7                   Azusa     81247.228824
# 93         South Pasadena     70747.657500
# 81             San Marino     66720.170000
# 97            Temple City     64995.657778
# 29               Fillmore     45707.176667
# 35          Hermosa Beach     33179.730000
# 21                Compton     19496.231250
# 13              Calabasas      7658.333333
# 70           Port Hueneme      6841.710000
# 106      Westlake Village      6042.513333
# 60               Moorpark      5751.582222
# 56                Maywood       105.880000

# %%
_dla_utils.basic_bar_chart((((_dla_utils.calculate_data_all(df, 'total_requested', 'primary_agency_name', aggfunc="mean"))
                          >>arrange(-_.total_requested)).tail(50)
                        ), 'primary_agency_name','total_requested'
                       )
# Out:
# alt.Chart(...)

# %%
#intersting that these are very different charts.

# %% [markdown]
# ## Functions to look by Prefix and by Agency:

# %% [markdown]
# ### By Agency:

# %%
_dla_utils.interactive_widget(df, 'primary_agency_name')
# Out:
# Dropdown(description='Primary_Agency_Name', options=('Access Services', 'Agoura Hills', 'Alameda Corridor Tran…
# Output()

# %% [markdown]
# ### By Prefix:

# %%
_dla_utils.interactive_widget(df, 'prefix')
# Out:
# Dropdown(description='Prefix', options=('ACNHPI', 'ACSTER', 'ACSTP', 'ATCMTD', 'ATPCML', 'ATPL', 'ATPLNI', 'AT…
# Output()

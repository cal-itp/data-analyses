# %% [markdown]
# # Obligations in District 7
#
# Using data from the Division of Local Assistance [Obligation list](https://dot.ca.gov/programs/local-assistance/reports/e-76-obligated)

# %%
import numpy as np
import pandas as pd
from siuba import *

import altair as alt
import altair_saver
from plotnine import *

from shared_utils import altair_utils
alt.themes.enable("fivethirtyeight")

from dla_utils import _dla_utils

from IPython.display import Markdown
from IPython.core.display import display
# Out:
# /opt/conda/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
# /opt/conda/lib/python3.9/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
# /opt/conda/lib/python3.9/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
# /opt/conda/lib/python3.9/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
# /tmp/ipykernel_4387/4153313253.py:15: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display

# %%
df= pd.read_parquet("gs://calitp-analytics-data/data-analyses/dla/e-76Obligated/dla_df.parquet")

# %%
df.sample()
# Out:
#         location prefix project_no    agency prepared_date submit__to_hq_date  \
# 15859  Obligated  HSIPL  5008(162)  Stockton    2020-01-10         2020-01-10
#
#       hq_review_date submit_to_fhwa_date to_fmis_date  fed_requested  ...  \
# 15859     2020-01-17          2020-01-21   2020-01-23     435,870.00  ...
#
#        adjusted_ac_requested  obligation_cat active_transp transit  bridge  \
# 15859                   0.00           Large             0       0       0
#
#       street  freeway  infra_resiliency_er  congestion_relief work_categories
# 15859      1        0                    0                  0               1
#
# [1 rows x 42 columns]

# %%
subset = 7

# %%
df = df>>filter(_.dist==subset)

# %%
df_years = _dla_utils.count_all_years(df)

# %%
df_years
# Out:
#     prepared_y  dist  adjusted_ac_requested_x  adjusted_fed_requested_x  \
# 11        2022     7           -11,026,947.22            262,002,155.55
# 10        2021     7            -8,394,078.23            453,907,980.82
# 9         2020     7           -30,590,342.62            439,813,880.26
# 8         2019     7           -13,773,273.82            355,599,947.26
# 0         2018     7           -63,834,279.07            357,599,773.31
# 1         2017     7           -66,766,131.25            343,468,449.65
# 2         2016     7          -105,948,519.78            474,523,581.35
# 3         2015     7           154,146,238.84            296,153,503.82
# 5         2014     7           268,939,567.03            333,654,043.83
# 6         2013     7            33,210,263.09             17,037,728.82
# 7         2012     7                     0.00               -129,182.70
#
#     adjusted_total_requested_x  adjusted_ac_requested_y  \
# 11              262,454,620.78              -119,858.12
# 10              665,165,684.86               -29,247.66
# 9             1,003,589,707.82               -95,894.49
# 8               388,486,894.55               -40,390.83
# 0               355,523,531.33              -191,694.53
# 1               330,425,191.26              -204,804.08
# 2               532,576,409.01              -281,777.98
# 3               669,872,521.76               416,611.46
# 5               669,762,642.12               625,440.85
# 6               -26,761,827.54             1,037,820.72
# 7                  -145,762.35                     0.00
#
#     adjusted_fed_requested_y  adjusted_total_requested_y  unique_mpo  \
# 11              2,847,849.52                2,852,767.62        2.00
# 10              1,581,560.91                2,317,650.47        2.00
# 9               1,378,726.90                3,146,049.24        1.00
# 8               1,042,815.09                1,139,257.76        1.00
# 0               1,073,873.19                1,067,638.23        1.00
# 1               1,053,584.20                1,013,574.21        2.00
# 2               1,265,396.22                1,416,426.62        2.00
# 3                 800,414.88                1,810,466.28        8.00
# 5                 775,939.64                1,557,587.54       10.00
# 6                 532,429.03                 -836,307.11        4.00
# 7                -129,182.70                 -145,762.35        1.00
#
#     unique_prefix  unique_primary_agency_name  unique_project_location  \
# 11          22.00                       39.00                    85.00
# 10          44.00                       63.00                   239.00
# 9           43.00                       60.00                   276.00
# 8           36.00                       65.00                   287.00
# 0           39.00                       63.00                   277.00
# 1           38.00                       73.00                   280.00
# 2           43.00                       75.00                   307.00
# 3           41.00                       85.00                   299.00
# 5           42.00                       77.00                   362.00
# 6           20.00                       18.00                    30.00
# 7            1.00                        1.00                     1.00
#
#     unique_project_no  unique_type_of_work
# 11              86.00                84.00
# 10             247.00               227.00
# 9              282.00               266.00
# 8              298.00               279.00
# 0              291.00               264.00
# 1              294.00               265.00
# 2              322.00               304.00
# 3              312.00               269.00
# 5              375.00               323.00
# 6               32.00                31.00
# 7                1.00                 1.00

# %%
df_top = _dla_utils.find_top(df)

# %%
df_top
# Out:
#           value  count             variable
# 0         HSIPL    745               prefix
# 1          STPL    451               prefix
# 2           CML    290               prefix
# 3            ER    187               prefix
# 4          ATPL    150               prefix
# ..          ...    ...                  ...
# 16    Camarillo     35  primary_agency_name
# 17  Culver City     32  primary_agency_name
# 18      Burbank     31  primary_agency_name
# 19     Whittier     31  primary_agency_name
# 0             7   2912                 dist
#
# [141 rows x 3 columns]

# %% [markdown]
# ## Which Agencies have Obligations

# %% [markdown]
# ### How many Unique Agencies

# %%
_dla_utils.calculate_data_all(df, 'primary_agency_name', aggfunc="nunique")
# Out:
#    dist  primary_agency_name
# 0     7                  108

# %% [markdown]
# ### Agencies with the most Obligations

# %%
df_top>>filter(_.variable == 'primary_agency_name')
# Out:
#                                                 value  count  \
# 0                                         Los Angeles    508
# 1                                  Los Angeles County    481
# 2                                      Ventura County    120
# 3   Los Angeles County Metropolitan Transportation...     88
# 4                                       Santa Clarita     88
# 5                                          Long Beach     84
# 6                                              Oxnard     76
# 7                                            Pasadena     75
# 8                                              Downey     64
# 9                                           Lancaster     63
# 10                                        Simi Valley     61
# 11                                           Palmdale     47
# 12                                        Pico Rivera     40
# 13                                      Thousand Oaks     40
# 14                                           Glendale     36
# 15                                   San Buenaventura     36
# 16                                          Camarillo     35
# 17                                        Culver City     32
# 18                                            Burbank     31
# 19                                           Whittier     31
#
#                variable
# 0   primary_agency_name
# 1   primary_agency_name
# 2   primary_agency_name
# 3   primary_agency_name
# 4   primary_agency_name
# 5   primary_agency_name
# 6   primary_agency_name
# 7   primary_agency_name
# 8   primary_agency_name
# 9   primary_agency_name
# 10  primary_agency_name
# 11  primary_agency_name
# 12  primary_agency_name
# 13  primary_agency_name
# 14  primary_agency_name
# 15  primary_agency_name
# 16  primary_agency_name
# 17  primary_agency_name
# 18  primary_agency_name
# 19  primary_agency_name

# %% [markdown]
# ### Agencies with the least Obligations

# %%
(df>>count(_.primary_agency_name)>>arrange(-_.n)).tail(10)
# Out:
#                                primary_agency_name  n
# 56                                         Maywood  2
# 65                                Palos Verdes Est  2
# 71                              Port Of Long Beach  2
# 86                                    Sierra Madre  2
# 2        Alameda Corridor Transportation Authority  1
# 4                Antelope Valley Transit Authority  1
# 35                                   Hermosa Beach  1
# 70                                    Port Hueneme  1
# 74                           Rolling Hills Estates  1
# 100  U.S. Forest Service, Pacific Southwest Region  1

# %% [markdown]
# ### Charting

# %%
_dla_utils.basic_bar_chart((df_top>>filter(_.variable=='primary_agency_name')), 'value', 'count', 'value', subset, 'Agencies With The Most Obligations')
# Out:
# alt.Chart(...)

# %%
df_top>>filter(_.variable=='prefix')
# Out:
#       value  count variable
# 0     HSIPL    745   prefix
# 1      STPL    451   prefix
# 2       CML    290   prefix
# 3        ER    187   prefix
# 4      ATPL    150   prefix
# 5     HPLUL    147   prefix
# 6      BHLS    100   prefix
# 7    FTACML     95   prefix
# 8     SRTSL     71   prefix
# 9    RPSTPL     63   prefix
# 10    BPMPL     46   prefix
# 11   BRLSZD     45   prefix
# 12     BRLS     43   prefix
# 13    ACSTP     39   prefix
# 14    HP21L     34   prefix
# 15     BHLO     22   prefix
# 16  SRTSLNI     21   prefix
# 17     BRLO     20   prefix
# 18     ESPL     19   prefix
# 19    STPLR     19   prefix

# %%
df>>group_by(_.primary_agency_name)>>count(_.prefix)>>arrange(-_.n)
# Out:
#     primary_agency_name prefix    n
# 222  Los Angeles County     ER  160
# 202         Los Angeles   STPL   91
# 228  Los Angeles County  HSIPL   85
# 196         Los Angeles  HSIPL   75
# 185         Los Angeles    CML   69
# ..                  ...    ...  ...
# 475              Vernon   HSIP    1
# 476              Vernon  HSIPL    1
# 478         West Covina  HPLUL    1
# 482    Westlake Village  HSIPL    1
# 488            Whittier  STPLH    1
#
# [489 rows x 3 columns]

# %% [markdown]
# ## Number of Unique Prefix Codes

# %%
_dla_utils.get_nunique(df, 'prefix', 'primary_agency_name')
# Out:
#                                    primary_agency_name   n
# 49                                         Los Angeles  35
# 50                                  Los Angeles County  31
# 47                                          Long Beach  19
# 51   Los Angeles County Metropolitan Transportation...  18
# 63                                              Oxnard  14
# ..                                                 ...  ..
# 89         South Coast Air Quality Management District   1
# 90                            South Coast Area Transit   1
# 91                                      South El Monte   1
# 100      U.S. Forest Service, Pacific Southwest Region   1
# 104                                             Walnut   1
#
# [108 rows x 2 columns]

# %%
_dla_utils.basic_bar_chart(((_dla_utils.get_nunique(df, 'prefix', 'primary_agency_name')).head(30)),
                            'primary_agency_name', 'n','primary_agency_name', subset, 'Agencies With The Most Unique Prefix Codes')
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Most Common Types of Work by Agnecy

# %%
_dla_utils.get_nunique(df, 'primary_agency_name', 'type_of_work')
# Out:
#                                            type_of_work   n
# 356                                        FTA Transfer  16
# 943                            Road Rehabilitation (tc)   7
# 320                                   Emergency Opening   6
# 95                                Bridge Rehabilitation   5
# 1183                                    Upgrade Signals   5
# ...                                                 ...  ..
# 1249                     Widening, Right Turn Lanes, La   1
# 1250  Widening,install Sidewalks, Traffic Improvements,   1
# 1251   Widenning Roadway(install Right Turn Lanes, Etc)   1
# 1252  Xwalks; Ped Heads; Flash Beacons; Signs; Bulb ...   1
# 59                                              Bikeway   0
#
# [1253 rows x 2 columns]

# %%
_dla_utils.calculate_data_head(df, "primary_agency_name",'type_of_work', aggfunc="count")
# Out:
#                                            type_of_work  primary_agency_name
# 356                                        FTA Transfer                  131
# 320                                   Emergency Opening                   35
# 107                                  Bridge Replacement                   24
# 943                            Road Rehabilitation (tc)                   20
# 95                                Bridge Rehabilitation                   18
# 109                             Bridge Replacement (tc)                   15
# 1120                        Traffic Signal Improvements                   13
# 747                             Pedestrian Improvements                   13
# 1183                                    Upgrade Signals                   12
# 61                          Bikeway Access Improvements                   11
# 942                                 Road Rehabilitation                   10
# 221            Construct Roundabout Within Existing R/w                   10
# 104                      Bridge Rehabilitation/widening                    9
# 1213  Upgrade Traffic Signals; Install Left-turn Pha...                    9
# 757                                  Pedestrian Walkway                    9
# 995                                    Seismic Retrofit                    9
# 884      Replace Struct Deficient Viaduct With New (tc)                    8
# 341                                  Eo: Debris Removal                    8
# 75         Bridge Preventative Maintenance Program (tc)                    8
# 510   Install Temporary Traffic Signs, Remove And Re...                    8

# %%
df>>group_by(_.primary_agency_name)>>count(_.type_of_work)>>arrange(-_.n)>>filter(_.n>=8)
# Out:
#                                     primary_agency_name  \
# 814   Los Angeles County Metropolitan Transportation...
# 665                                  Los Angeles County
# 0                                       Access Services
# 1294           Ventura County Transportation Commission
# 630                                  Los Angeles County
# 359                                         Los Angeles
# 610                                  Los Angeles County
# 266                                           Lancaster
# 501                                         Los Angeles
# 631                                  Los Angeles County
# 181                                              Downey
# 361                                         Los Angeles
# 798                                  Los Angeles County
# 521                                         Los Angeles
# 618                                  Los Angeles County
# 682                                  Los Angeles County
# 710                                  Los Angeles County
# 786                                  Los Angeles County
#
#                                            type_of_work   n
# 814                                        FTA Transfer  58
# 665                                   Emergency Opening  26
# 0                                          FTA Transfer  18
# 1294                                       FTA Transfer  15
# 630                                  Bridge Replacement  12
# 359                               Bridge Rehabilitation  11
# 610                         Bikeway Access Improvements  11
# 266            Construct Roundabout Within Existing R/w  10
# 501                             Pedestrian Improvements  10
# 631                             Bridge Replacement (tc)  10
# 181   Upgrade Traffic Signals; Install Left-turn Pha...   9
# 361                      Bridge Rehabilitation/widening   9
# 798                         Traffic Signal Improvements   9
# 521      Replace Struct Deficient Viaduct With New (tc)   8
# 618        Bridge Preventative Maintenance Program (tc)   8
# 682                                  Eo: Debris Removal   8
# 710   Install Temporary Traffic Signs, Remove And Re...   8
# 786                                    Seismic Retrofit   8

# %% [markdown]
# ## Most Common Project Locations

# %%
df_top>>filter(_.variable=='project_location')
# Out:
#                                                 value  count          variable
# 0   Sixth Street Viaduct Over La River, Us 101, An...     13  project_location
# 1                        Within The County Of Ventura      9  project_location
# 2                                            Citywide      8  project_location
# 3   Sixth Street Viaduct Over La River And East Sa...      8  project_location
# 4             Various Locations In Los Angeles County      7  project_location
# 5   10th Str. West  Road Diet And Bikeway Improvem...      6  project_location
# 6   Amar Road Street Improvements: Officer Chiles ...      6  project_location
# 7   Community Of Florence-firestone In Los Angeles...      6  project_location
# 8               Down Town Area Of City Of Culver City      6  project_location
# 9   Intersection Of Avalon Blvd And Carson St. In ...      6  project_location
# 10    Montebello Blvd. And Montebello Way / Truck Way      6  project_location
# 11      Pasadena Ave./sr 210 Wb On-ramp At Walnut St.      6  project_location
# 12  1st St Br Over Glendale/beverly Blvd, Br# 53c0045      5  project_location
# 13  524 Various Locations Within Unincorporated Ar...      5  project_location
# 14  Along Hollywood And Sunset Blbd. Bet'n Gower &...      5  project_location
# 15           Atlantic Bl Br Over La River, Br#53c0252      5  project_location
# 16  Ave. L And Challenger Way (10th St. E.) Inters...      5  project_location
# 17  Five Bridges In The City Of Santa Clarita (see...      5  project_location
# 18   Hyperion Viaduct Over La River Bridge # 53c-1881      5  project_location
# 19  In Ventura County, On Central Ave. From Joan W...      5  project_location

# %% [markdown]
# ## Number of Obligations by Year

# %%
df_top>>filter(_.variable=='prepared_y')
# Out:
#       value  count    variable
# 0  2,014.00    430  prepared_y
# 1  2,016.00    376  prepared_y
# 2  2,015.00    370  prepared_y
# 3  2,019.00    341  prepared_y
# 4  2,018.00    333  prepared_y
# 5  2,017.00    326  prepared_y
# 6  2,020.00    319  prepared_y
# 7  2,021.00    287  prepared_y
# 8  2,022.00     92  prepared_y
# 9  2,013.00     32  prepared_y
# 10 2,012.00      1  prepared_y

# %%
df>>group_by(_.primary_agency_name)>>count(_.prepared_date)>>arrange(-_.n)
# Out:
#                                     primary_agency_name prepared_date  n
# 1488  Los Angeles County Metropolitan Transportation...    2015-07-15  9
# 1510  Los Angeles County Metropolitan Transportation...    2018-05-31  9
# 2                                       Access Services    2016-03-02  7
# 957                                         Los Angeles    2019-02-07  7
# 1669                                             Oxnard    2016-06-24  6
# ...                                                 ...           ... ..
# 2537                                           Whittier    2020-09-03  1
# 2538                                           Whittier    2021-09-24  1
# 2539                                           Whittier    2021-10-20  1
# 2540                                           Whittier    2021-12-14  1
# 2541                                           Whittier    2022-03-10  1
#
# [2542 rows x 3 columns]

# %% [markdown]
# ### Chart

# %%
_dla_utils.basic_line_chart((df_top>>filter(_.variable=='prepared_y')), 'value', 'count', subset, 'Obligations by Year')
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Agencies with the most unique project numbers

# %%
df>>group_by(_.primary_agency_name, _.prefix)>>count(_.project_no)>>arrange(-_.n)>>filter(_.n>5)
# Out:
#                                     primary_agency_name   prefix project_no  n
# 377                                         Los Angeles   BRLSZD  5006(839)  9
# 849   Los Angeles County Metropolitan Transportation...  FTAATPL  6065(225)  9
# 857   Los Angeles County Metropolitan Transportation...   FTACML  6065(199)  9
# 373                                         Los Angeles   BRLSZD  5006(664)  8
# 2                                       Access Services  FTASTPL  6312(022)  7
# 62                                              Burbank      CML  5200(046)  6
# 114                                              Carson    HSIPL  5403(022)  6
# 146                                         Culver City      CML  5240(025)  6
# 255                                           Lancaster     ATPL  5419(049)  6
# 294                                          Long Beach      CML  5108(181)  6
# 374                                         Los Angeles   BRLSZD  5006(811)  6
# 907                                          Montebello    HSIPL  5247(020)  6
# 1007                                           Pasadena    HSIPL  5064(075)  6
# 1316           Ventura County Transportation Commission   FTACML  6155(089)  6
# 1332                                        West Covina     STPL  5259(026)  6

# %% [markdown]
# ## Average Funds

# %%
_dla_utils.calculate_data_all(df, 'total_requested', 'primary_agency_name', aggfunc="mean")
# Out:
#                                    primary_agency_name  total_requested
# 0                                      Access Services    35,232,367.61
# 51   Los Angeles County Metropolitan Transportation...    18,368,332.19
# 15                                            Caltrans    15,656,801.78
# 95         Southern California Regional Rail Authority     7,468,825.00
# 47                                          Long Beach     4,726,597.42
# ..                                                 ...              ...
# 35                                       Hermosa Beach        33,179.73
# 13                                           Calabasas         7,658.33
# 70                                        Port Hueneme         6,841.71
# 106                                   Westlake Village         6,042.51
# 56                                             Maywood           105.88
#
# [95 rows x 2 columns]

# %% [markdown]
# ### Top 50 Agencies with highest funds

# %%
((_dla_utils.calculate_data_all(df, 'total_requested', 'primary_agency_name', aggfunc="mean"))>>arrange(-_.total_requested)).head(50)
# Out:
#                                    primary_agency_name  total_requested
# 0                                      Access Services    35,232,367.61
# 51   Los Angeles County Metropolitan Transportation...    18,368,332.19
# 15                                            Caltrans    15,656,801.78
# 95         Southern California Regional Rail Authority     7,468,825.00
# 47                                          Long Beach     4,726,597.42
# 96                              Sunline Transit Agency     4,622,594.07
# 80           San Gabriel Valley Council of Governments     2,697,375.33
# 4                    Antelope Valley Transit Authority     2,475,103.00
# 90                            South Coast Area Transit     2,109,462.57
# 48                   Long Beach Transportation Company     1,764,100.50
# 84                                        Santa Monica     1,608,526.02
# 49                                         Los Angeles     1,550,186.28
# 60                                            Moorpark     1,424,416.57
# 55                                     Manhattan Beach     1,121,749.97
# 36                                     Huntington Park       895,177.00
# 1                                         Agoura Hills       861,124.45
# 77                                           San Dimas       800,539.46
# 103                                             Vernon       793,274.24
# 99                                            Torrance       763,910.93
# 30                                             Gardena       733,129.62
# 52                 Los Angeles Unified School District       679,500.00
# 79                                         San Gabriel       629,039.42
# 67                                            Pasadena       618,254.60
# 107                                           Whittier       586,770.45
# 92                                          South Gate       574,692.78
# 45                                           Lancaster       557,859.93
# 14                                    Calaveras County       556,180.00
# 89         South Coast Air Quality Management District       546,778.00
# 85                                         Santa Paula       546,177.17
# 34                                           Hawthorne       528,623.89
# 3                                             Alhambra       523,946.03
# 64                                            Palmdale       522,948.00
# 38                                           Inglewood       496,848.59
# 94      Southern California Association of Governments       495,810.89
# 98                                       Thousand Oaks       492,579.73
# 24                                         Culver City       491,781.45
# 5                                              Arcadia       490,627.14
# 102           Ventura County Transportation Commission       483,053.06
# 82                                       Santa Clarita       458,619.83
# 61                                             Norwalk       452,390.14
# 26                                              Downey       433,853.06
# 53                                             Lynwood       426,348.35
# 22                                              Covina       396,412.20
# 50                                  Los Angeles County       392,010.26
# 40                                La Canada Flintridge       376,643.36
# 73                                       Redondo Beach       362,835.53
# 68                                         Pico Rivera       348,192.55
# 20                                            Commerce       332,105.41
# 78                                        San Fernando       331,761.47
# 31                                            Glendale       325,208.90

# %%
_dla_utils.basic_bar_chart((((_dla_utils.calculate_data_all(df, 'total_requested', 'primary_agency_name', aggfunc="mean"))
                          >>arrange(-_.total_requested)).head(30)
                        ), 'primary_agency_name','total_requested', 'primary_agency_name', subset,
                           'Average Total Requested Funds by Agency'
                       )
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Bottom 50 Agencies with lowest funds

# %%
avg_funds_bottom = (df>>group_by(_.primary_agency_name)>>summarize(avg_funds=_.total_requested.mean())>>arrange(-_.avg_funds)).tail(50)

# %%
avg_funds_bottom
# Out:
#                                primary_agency_name      avg_funds
# 43                                        La Verne     242,217.88
# 8                                     Baldwin Park     242,026.12
# 101                                 Ventura County     219,162.13
# 16                                       Camarillo     212,175.88
# 25                                     Diamond Bar     210,080.80
# 42                                       La Puente     206,681.29
# 66                                       Paramount     203,748.56
# 18                                        Cerritos     183,759.84
# 75                                        Rosemead     181,069.70
# 86                                    Sierra Madre     176,777.50
# 12                                         Burbank     176,267.30
# 9                                             Bell     176,115.13
# 27                                        El Monte     167,894.79
# 58                                      Montebello     163,826.58
# 37                                        Industry     163,500.00
# 39                                       Irwindale     145,804.33
# 32                                        Glendora     145,180.83
# 23                                          Cudahy     138,067.33
# 41                                       La Mirada     129,313.88
# 91                                  South El Monte     125,008.15
# 10                                    Bell Gardens     122,111.69
# 62                                            Ojai     117,831.39
# 72                             Rancho Palos Verdes     115,079.69
# 105                                    West Covina     108,632.72
# 17                                          Carson      98,575.74
# 19                                       Claremont      94,291.96
# 6                                          Artesia      81,446.68
# 7                                            Azusa      68,079.46
# 81                                      San Marino      66,720.17
# 97                                     Temple City      64,995.66
# 93                                  South Pasadena      62,886.81
# 29                                        Fillmore      45,707.18
# 35                                   Hermosa Beach      33,179.73
# 13                                       Calabasas       7,658.33
# 70                                    Port Hueneme       6,841.71
# 106                               Westlake Village       6,042.51
# 56                                         Maywood         105.88
# 28                                      El Segundo           0.00
# 71                              Port Of Long Beach           0.00
# 100  U.S. Forest Service, Pacific Southwest Region           0.00
# 54                                          Malibu      -6,975.84
# 21                                         Compton     -13,106.03
# 46                                        Lawndale     -19,799.88
# 63                                          Oxnard     -24,700.38
# 87                                     Signal Hill    -105,504.48
# 104                                         Walnut    -128,530.47
# 74                           Rolling Hills Estates    -191,821.33
# 69                                          Pomona  -2,755,194.83
# 83                                Santa Fe Springs  -9,764,168.39
# 2        Alameda Corridor Transportation Authority -15,818,321.18

# %%
_dla_utils.basic_bar_chart(avg_funds_bottom, 'primary_agency_name','avg_funds', 'primary_agency_name', subset, 
                          'Lowest Average Total Funds by Agency')
# Out:
# alt.Chart(...)

# %%
((
    _dla_utils.calculate_data_all(
        df, 'total_requested', 'primary_agency_name', aggfunc="mean"))
>>arrange(-_.total_requested)).tail(50)
# Out:
#      primary_agency_name  total_requested
# 73         Redondo Beach       362,835.53
# 68           Pico Rivera       348,192.55
# 20              Commerce       332,105.41
# 78          San Fernando       331,761.47
# 31              Glendale       325,208.90
# 76      San Buenaventura       292,997.63
# 88           Simi Valley       281,380.67
# 44              Lakewood       279,118.16
# 11            Bellflower       275,618.66
# 59         Monterey Park       266,915.49
# 57              Monrovia       252,817.75
# 65      Palos Verdes Est       251,243.85
# 33      Hawaiian Gardens       246,245.28
# 43              La Verne       242,217.88
# 8           Baldwin Park       242,026.12
# 101       Ventura County       219,162.13
# 16             Camarillo       212,175.88
# 25           Diamond Bar       210,080.80
# 42             La Puente       206,681.29
# 66             Paramount       203,748.56
# 18              Cerritos       183,759.84
# 75              Rosemead       181,069.70
# 86          Sierra Madre       176,777.50
# 12               Burbank       176,267.30
# 9                   Bell       176,115.13
# 27              El Monte       167,894.79
# 58            Montebello       163,826.58
# 37              Industry       163,500.00
# 39             Irwindale       145,804.33
# 32              Glendora       145,180.83
# 23                Cudahy       138,067.33
# 41             La Mirada       129,313.88
# 91        South El Monte       125,008.15
# 10          Bell Gardens       122,111.69
# 62                  Ojai       117,831.39
# 72   Rancho Palos Verdes       115,079.69
# 105          West Covina       108,632.72
# 17                Carson        98,575.74
# 19             Claremont        94,291.96
# 6                Artesia        81,446.68
# 7                  Azusa        68,079.46
# 81            San Marino        66,720.17
# 97           Temple City        64,995.66
# 93        South Pasadena        62,886.81
# 29              Fillmore        45,707.18
# 35         Hermosa Beach        33,179.73
# 13             Calabasas         7,658.33
# 70          Port Hueneme         6,841.71
# 106     Westlake Village         6,042.51
# 56               Maywood           105.88

# %%
_dla_utils.basic_bar_chart((((_dla_utils.calculate_data_all(df, 'total_requested', 'primary_agency_name', aggfunc="mean"))
                          >>arrange(-_.total_requested)).tail(50)
                        ), 'primary_agency_name','total_requested', 'total_requested', subset
                       )
# Out:
# alt.Chart(...)

# %%
#intersting that these are very different charts.

# %% [markdown]
# ## Functions to look by Prefix and by Agency:

# %% [markdown]
# ### By Agency:

# %%
_dla_utils.interactive_widget(df, 'primary_agency_name')
# Out:
# Dropdown(description='Primary_Agency_Name', options=('Access Services', 'Agoura Hills', 'Alameda Corridor Tran…
# Output()

# %% [markdown]
# ### By Prefix:

# %%
_dla_utils.interactive_widget(df, 'prefix')
# Out:
# Dropdown(description='Prefix', options=('ACNHPI', 'ACSTER', 'ACSTP', 'ATCMTD', 'ATPCML', 'ATPL', 'ATPLNI', 'AT…
# Output()

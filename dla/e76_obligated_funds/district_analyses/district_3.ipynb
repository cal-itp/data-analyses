# %% [markdown]
# # Obligations in District 3
#
# Using data from the Division of Local Assistance [Obligation list](https://dot.ca.gov/programs/local-assistance/reports/e-76-obligated)

# %%
import numpy as np
import pandas as pd
from siuba import *

import altair as alt
import altair_saver
from plotnine import *

from IPython.display import Markdown

from shared_utils import altair_utils
from shared_utils import geography_utils
from shared_utils import calitp_color_palette as cp
from shared_utils import styleguide

from calitp import to_snakecase
import intake

import _clean_data
import _dla_utils
# Out:
# /opt/conda/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.9.1-CAPI-1.14.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
# /opt/conda/lib/python3.9/site-packages/google/auth/_default.py:73: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
# /opt/conda/lib/python3.9/site-packages/google/auth/_default.py:73: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
#df = _clean_data.make_clean_data()
df= pd.read_parquet("dla_df.parquet")

# %%
#parameters cell
subset = 3

# %%
df.sample(10)
# Out:
#         location  prefix project_no                                  agency  \
# 13350  Obligated    BRLO  5917(082)                           Nevada County
# 17452  Obligated   HSIPL  5403(022)                                  Carson
# 14900  Obligated   HSIPL  5917(103)                           Nevada County
# 7270   Obligated     CML  5950(406)                             Kern County
# 20639  Obligated    STPL  5060(320)                                  Fresno
# 6001   Obligated    STPL  6085(068)  Sacramento Area Council Of Governments
# 4856   Obligated    BRLS  5479(012)                               Elk Grove
# 19878  Obligated   HSIPL  5919(127)                           Placer County
# 14716  Obligated  ACSTER  32L0(342)                       Santa Cruz County
# 11798  Obligated    BHLS  5042(042)                                    Napa
#
#       prepared_date submit__to_hq_date hq_review_date submit_to_fhwa_date  \
# 13350    2019-01-03         2019-01-03     2019-01-03          2019-01-03
# 17452    2020-10-15         2020-10-15     2020-10-15          2020-10-15
# 14900    2019-07-02         2019-10-07     2019-10-07          2019-10-07
# 7270     2016-02-22         2016-02-23     2016-02-24          2016-02-25
# 20639    2022-01-06         2022-01-06     2022-01-06          2022-01-13
# 6001     2016-08-02         2016-08-08     2016-08-10          2016-08-16
# 4856     2017-02-23         2017-02-23     2017-02-28          2017-03-02
# 19878    2021-08-24         2021-08-24     2021-08-28          2021-08-31
# 14716    2019-09-05         2019-09-09     2019-09-18          2019-09-18
# 11798    2014-05-01         2014-05-01     2014-05-16          2014-05-30
#
#       to_fmis_date  fed_requested  ac_requested  total_requested  \
# 13350   2019-01-10           0.00          0.00             0.00
# 17452   2020-10-22    -637,596.00          0.00      -708,440.00
# 14900   2019-10-11      27,023.00          0.00        27,023.00
# 7270    2016-03-07     200,000.00          0.00       225,912.00
# 20639   2022-01-18     -66,800.68          0.00       -66,635.19
# 6001    2016-08-17     330,000.00          0.00       780,000.00
# 4856    2017-03-09     769,963.00          0.00     1,199,312.00
# 19878   2021-09-09           0.00          0.00      -238,397.71
# 14716   2019-09-19           0.00    294,416.00       348,720.00
# 11798   2014-06-04     398,385.00          0.00       499,524.00
#
#       status_comment locode  dist                                   status  \
# 13350     Authorized   5917  3.00                        E-76 approved on
# 17452     Authorized   5403  7.00                        E-76 approved on
# 14900     Authorized   5917  3.00                        E-76 approved on
# 7270      Authorized   5950  6.00   E-76 approved on Prepared on 10/6/2015
# 20639     Authorized   5060  6.00                        E-76 approved on
# 6001      Authorized   6085  3.00  E-76 approved on Prepared on 10/12/2015
# 4856      Authorized   5479  3.00   E-76 approved on Prepared on 2/14/2017
# 19878     Authorized   5919  3.00                        E-76 approved on
# 14716     Authorized   5936  5.00                        E-76 approved on
# 11798     Authorized   5042  4.00        E-76 approved on E-76 approved on
#
#        dist_processing_days  hq_processing_days  fhwa_processing_days  \
# 13350                   NaN                0.00                  7.00
# 17452                  7.00                0.00                  7.00
# 14900                 97.00                0.00                  4.00
# 7270                   1.00                2.00                 11.00
# 20639                  7.00                7.00                  5.00
# 6001                   6.00                8.00                  1.00
# 4856                   0.00                7.00                  7.00
# 19878                 33.00                7.00                  9.00
# 14716                  4.00                9.00                  1.00
# 11798                  0.00               29.00                  5.00
#
#          ftip_no                                   project_location  \
# 13350    HBP_NEV  Garden Bar Rd At Little Wolf Creek #2; ~4.3 Mi...
# 17452    SCAG015  Intersection Of Avalon Blvd And Carson St. In ...
# 14900  HSIP_RURL  Curves Along Greenhorn, Dog Bar, Red Dog, Roug...
# 7270   KER140506                        Fruitvale Ave And Meany Ave
# 20639  FRE090611  Sb Friant Road From Champlain Drive To Shepher...
# 6001    VAR56193                                       Sacog Region
# 4856    SAC24072      Bradshaw & Sheldon At Laguna Crk Br #24c-0308
# 19878   PLA25650  19 Intersections Throughout Southwest Placer C...
# 14716        nan  In The County Of Santa Cruz On Highland Way Pm...
# 11798        nan             Trancas Street Bridge Over Napa River.
#
#                                             type_of_work  seq  \
# 13350                            Bridge Replacement (tc) 6.00
# 17452  Construct Two Right Turn Lanes,modigy Traffic ... 7.00
# 14900        Apply High Friction Surface Treatment (tc). 1.00
# 7270             Construct New Signal And Road Widening. 1.00
# 20639  Ac Overlay, Curb Ramp Installation, Signal Loo... 4.00
# 6001                 Its Master Plan, Non-infrastructure 1.00
# 4856                                  Bridge Replacement 4.00
# 19878  Installation Of Lighting, Upgraded Pavement Ma... 6.00
# 14716       Stabilize Embankment And Reconstruct Roadway 2.00
# 11798                               Scour Countermeasure 7.00
#
#       date_request_initiated date_completed_request      mpo projectID  \
# 13350                    NaT                    NaT  NON-MPO      5917
# 17452             2020-10-08             2020-10-09     SCAG      5403
# 14900             2019-07-02             2019-07-02  NON-MPO      5917
# 7270                     NaT                    NaT     KCOG      5950
# 20639             2021-12-30             2021-12-31     CFCG      5060
# 6001                     NaT                    NaT    SACOG      6085
# 4856                     NaT                    NaT    SACOG      5479
# 19878             2021-07-22             2021-08-23    SACOG      5919
# 14716             2019-09-05             2019-09-09    AMBAG      32L0
# 11798                    NaT                    NaT      MTC      5042
#
#        prepared_y                     primary_agency_name  \
# 13350    2,019.00                           Nevada County
# 17452    2,020.00                                  Carson
# 14900    2,019.00                           Nevada County
# 7270     2,016.00                             Kern County
# 20639    2,022.00                                  Fresno
# 6001     2,016.00  Sacramento Area Council of Governments
# 4856     2,017.00                               Elk Grove
# 19878    2,021.00                           Placer County
# 14716    2,019.00                       Santa Cruz County
# 11798    2,014.00                                    Napa
#
#        adjusted_total_requested  adjusted_fed_requested  adjusted_ac_requested
# 13350                      0.00                    0.00                   0.00
# 17452               -741,722.23             -667,550.01                   0.00
# 14900                 28,641.54               28,641.54                   0.00
# 7270                 255,056.46              225,801.60                   0.00
# 20639                -64,222.89              -64,382.39                   0.00
# 6001                 880,626.25              372,572.64                   0.00
# 4856               1,325,791.79              851,163.52                   0.00
# 19878               -238,397.91                    0.00                   0.00
# 14716                369,606.61                    0.00             312,050.07
# 11798                571,758.96              455,994.50                   0.00

# %%
df = (df>>filter(_.dist==subset))

# %%
df_years = _dla_utils.count_all_years(df)

# %%
df_years
# Out:
#     prepared_y  dist  ac_requested_sum  fed_requested_sum  \
# 10        2022  3.00    -45,370,485.16      65,052,441.85
# 8         2021  3.00    105,660,024.75     109,863,151.66
# 7         2020  3.00     -6,858,256.96     154,216,361.75
# 6         2019  3.00    -10,332,571.22     180,078,967.43
# 0         2018  3.00     25,276,742.79     135,271,258.47
# 1         2017  3.00     48,434,871.21     171,321,935.87
# 2         2016  3.00        723,015.00     126,715,479.57
# 3         2015  3.00     -3,169,509.00      95,224,789.05
# 4         2014  3.00     -8,798,279.00     134,341,351.39
# 5         2013  3.00        210,000.00       6,672,364.35
#
#     total_requested_sum  ac_requested_mean  fed_requested_mean  \
# 10        24,709,355.21        -840,194.17        1,204,674.85
# 8        236,413,763.18         389,889.39          405,399.08
# 7        237,037,716.92         -22,937.31          515,773.79
# 6        211,567,234.92         -25,831.43          450,197.42
# 0        190,472,825.93          73,693.13          394,376.85
# 1        201,490,921.47         156,747.16          554,439.92
# 2        162,393,401.73           2,362.79          414,102.87
# 3        114,306,557.12         -11,652.61          350,091.14
# 4        182,470,406.22         -27,580.81          421,132.76
# 5         21,777,253.42          17,500.00          556,030.36
#
#     total_requested_mean  unique_mpo  unique_prefix  \
# 10            457,580.65        4.00          17.00
# 8             872,375.51        5.00          34.00
# 7             792,768.28        5.00          37.00
# 6             528,918.09        4.00          51.00
# 0             555,314.36        4.00          38.00
# 1             652,074.18        4.00          42.00
# 2             530,697.39        4.00          44.00
# 3             420,244.70        4.00          36.00
# 4             572,007.54        6.00          34.00
# 5           1,814,771.12        2.00          11.00
#
#     unique_primary_agency_name  unique_project_location  unique_project_no  \
# 10                       23.00                    53.00              52.00
# 8                        45.00                   204.00             210.00
# 7                        43.00                   221.00             229.00
# 6                        46.00                   316.00             321.00
# 0                        47.00                   277.00             282.00
# 1                        44.00                   266.00             270.00
# 2                        47.00                   257.00             269.00
# 3                        46.00                   223.00             232.00
# 4                        43.00                   254.00             264.00
# 5                        10.00                    12.00              12.00
#
#     unique_type_of_work
# 10                51.00
# 8                174.00
# 7                186.00
# 6                254.00
# 0                219.00
# 1                220.00
# 2                218.00
# 3                184.00
# 4                200.00
# 5                 11.00

# %%
df_top = _dla_utils.find_top(df)

# %%
df_top
# Out:
#                                            value  count             variable
# 0                                            CML    403               prefix
# 1                                          HSIPL    392               prefix
# 2                                           BRLO    389               prefix
# 3                                           STPL    283               prefix
# 4                                             ER    177               prefix
# ..                                           ...    ...                  ...
# 16  Placer County Transportation Planning Agency     45  primary_agency_name
# 17                                  Glenn County     41  primary_agency_name
# 18                                        Folsom     40  primary_agency_name
# 19                                         Chico     38  primary_agency_name
# 0                                           3.00   2588                 dist
#
# [131 rows x 3 columns]

# %% [markdown]
# ## Which Agencies have Obligations

# %% [markdown]
# ### How many Unique Agencies

# %%
_dla_utils.calculate_data_all(df, 'primary_agency_name', aggfunc="nunique")
# Out:
#    dist  primary_agency_name
# 0  3.00                   62

# %%
len(df>>count(_.primary_agency_name)>>arrange(-_.n))
# Out:
# 62

# %% [markdown]
# ### Agencies with the most Obligations

# %%
df_top>>filter(_.variable == 'primary_agency_name')
# Out:
#                                            value  count             variable
# 0                               El Dorado County    297  primary_agency_name
# 1                              Sacramento County    228  primary_agency_name
# 2                                     Sacramento    187  primary_agency_name
# 3                                  Placer County    180  primary_agency_name
# 4                                    Yuba County    143  primary_agency_name
# 5                                   Butte County    141  primary_agency_name
# 6                                  Nevada County    140  primary_agency_name
# 7                                    Yolo County     91  primary_agency_name
# 8                                      Elk Grove     68  primary_agency_name
# 9                                  Sierra County     62  primary_agency_name
# 10                                      Paradise     61  primary_agency_name
# 11                                Rancho Cordova     58  primary_agency_name
# 12        Sacramento Area Council of Governments     57  primary_agency_name
# 13                                   Placerville     52  primary_agency_name
# 14                                     Roseville     52  primary_agency_name
# 15                                 Sutter County     48  primary_agency_name
# 16  Placer County Transportation Planning Agency     45  primary_agency_name
# 17                                  Glenn County     41  primary_agency_name
# 18                                        Folsom     40  primary_agency_name
# 19                                         Chico     38  primary_agency_name

# %% [markdown]
# ### Agencies with the least Obligations

# %%
(df>>count(_.primary_agency_name)>>arrange(-_.n)).tail(10)
# Out:
#                               primary_agency_name  n
# 27                                   Modoc County  4
# 51  U.S. Forest Service, Pacific Southwest Region  4
# 52               University of California - Davis  4
# 7                     Capital Southeast Connector  3
# 31                                         Orland  3
# 5                    California Tahoe Conservancy  2
# 26                                     Marysville  2
# 14                                          Dixon  1
# 28                Natomas Unified School District  1
# 48                 Tahoe Regional Planning Agency  1

# %% [markdown]
# ## Transit Funding

# %%
transit = df[df['type_of_work'].str.contains(
              'Transit|bus|Rideshare',
              case=False, na=False)]

# %%
print(f"Out of {len(df)} obligations, {len(transit)} are transit related")
# Out:
# Out of 2588 obligations, 21 are transit related

# %%
transit>>count(_.primary_agency_name)>>arrange(-_.n)
# Out:
#                       primary_agency_name   n
# 4           Tahoe Transportation District  10
# 0                                Caltrans   3
# 1                                   Chico   2
# 2                          Citrus Heights   2
# 3  Sacramento Area Council of Governments   2
# 5                         West Sacramento   2

# %%
#transit>>group_by(_.prefix)>>count(_.type_of_work)>>arrange(-_.n)

# %%
transit>>count(_.type_of_work)>>arrange(-_.n)
# Out:
#                                          type_of_work  n
# 5   Realign Roadway, Reduce Lanes And Transit-bike...  5
# 2                      Bus/carpool Lane/comm. Enhancm  2
# 3   Operational And Safety Improvements To The Heg...  2
# 4   Pa&ed Only For New Bridge - Includes Auto, Bik...  2
# 6   Spare The Air / Free Bus Rides (non-infrastruc...  2
# 8   Transit Operating Assistance - Develop A Proje...  2
# 9                      Universal Transit Fare Card Pr  2
# 0   Analyze Transit Service And Asset Management F...  1
# 1   Analyze Transit Service And Asset Management F...  1
# 7   Transit Operating Assistance - Develop A Proje...  1
# 10  Widen And Construct Bus/carpool Lanes, Transit...  1

# %%
transit>>count(_.prefix)>>arrange(-_.n)
# Out:
#     prefix  n
# 4    STPLN  6
# 1      CML  4
# 5   STPLNI  3
# 0   CMHIPL  2
# 2     CMLN  2
# 3     STPL  2
# 6   TGR2DG  1
# 7  TGR2DGL  1

# %%
transit_agencies = df[df['primary_agency_name'].str.contains(
              'Transit|tranist|Rail',
              case=False, na=False)]

# %%
transit_agencies>>count(_.primary_agency_name)
# Out:
#                     primary_agency_name   n
# 0  Sacramento Regional Transit District  30

# %%
transit_agencies>>count(_.type_of_work)>>arrange(-_.n)
#using this to determine how many FTA transfers there are
# Out:
#    type_of_work   n
# 0  FTA Transfer  30

# %%
_dla_utils.calculate_data_all(transit_agencies, 'total_requested', aggregate_by='primary_agency_name', aggfunc="mean")
# Out:
#                     primary_agency_name  total_requested
# 0  Sacramento Regional Transit District     2,585,441.17

# %% [markdown]
# ### Charting

# %%
_dla_utils.basic_bar_chart((df_top>>filter(_.variable=='primary_agency_name')), 'value', 'count', 'value', subset, 'Agencies With The Most Obligations')
# Out:
# alt.Chart(...)

# %%
df_top>>filter(_.variable=='prefix')
# Out:
#       value  count variable
# 0       CML    396   prefix
# 1      BRLO    384   prefix
# 2     HSIPL    378   prefix
# 3      STPL    276   prefix
# 4        ER    158   prefix
# 5      BRLS    151   prefix
# 6    RPSTPL     65   prefix
# 7     HRRRL     60   prefix
# 8      BPMP     50   prefix
# 9     ACSTP     43   prefix
# 10     ATPL     42   prefix
# 11   STPCML     37   prefix
# 12    CMLNI     36   prefix
# 13   FTACML     34   prefix
# 14    SRTSL     29   prefix
# 15   ATPCML     28   prefix
# 16   ACSTER     26   prefix
# 17    HPLUL     26   prefix
# 18  FTASTPL     14   prefix
# 19    HP21L     14   prefix

# %%
_dla_utils.basic_bar_chart((df_top>>filter(_.variable=='prefix')), 'value', 'count', 'value', subset, 'Most used Prefix Codes')
# Out:
# alt.Chart(...)

# %%
(df>>group_by(_.primary_agency_name)>>count(_.prefix)>>arrange(-_.n))
# Out:
#     primary_agency_name   prefix   n
# 71     El Dorado County     BRLO  67
# 141       Nevada County     BRLO  63
# 162       Placer County     BRLO  58
# 232          Sacramento    HSIPL  54
# 260   Sacramento County    HSIPL  53
# ..                  ...      ...  ..
# 316             Winters    HPLUL   1
# 319            Woodland  ATPSB1L   1
# 323            Woodland   RPSTPL   1
# 328         Yolo County   BRLOZE   1
# 353         Yuba County   STPCML   1
#
# [355 rows x 3 columns]

# %% [markdown]
# ## Number of Unique Prefix Codes

# %%
(_dla_utils.get_nunique(df, 'prefix', 'primary_agency_name'))
# Out:
#                  primary_agency_name   n
# 15                  El Dorado County  21
# 40                        Sacramento  18
# 42                 Sacramento County  18
# 34                     Placer County  14
# 2                       Butte County  13
# ..                               ...  ..
# 28   Natomas Unified School District   1
# 31                            Orland   1
# 48    Tahoe Regional Planning Agency   1
# 52  University of California - Davis   1
# 55                           Willows   1
#
# [62 rows x 2 columns]

# %%
(_dla_utils.get_nunique(df, 'primary_agency_name', 'prefix'))
# Out:
#       prefix   n
# 21       CML  35
# 85      STPL  27
# 57     HSIPL  24
# 72    RPSTPL  17
# 14      BRLO  16
# ..       ...  ..
# 92     STPLR   1
# 93     STPLZ   1
# 95    TGR2DG   1
# 96   TGR2DGL   1
# 97  USFSSTPL   1
#
# [98 rows x 2 columns]

# %%
_dla_utils.basic_bar_chart(((_dla_utils.get_nunique(df, 'prefix', 'primary_agency_name')).head(30)),
                            'primary_agency_name', 'n', 'primary_agency_name', subset, 'Agencies With The Most Unique Prefix Codes')
# Out:
# alt.Chart(...)

# %%
df_top>>filter(_.variable=="prefix")
# Out:
#       value  count variable
# 0       CML    396   prefix
# 1      BRLO    384   prefix
# 2     HSIPL    378   prefix
# 3      STPL    276   prefix
# 4        ER    158   prefix
# 5      BRLS    151   prefix
# 6    RPSTPL     65   prefix
# 7     HRRRL     60   prefix
# 8      BPMP     50   prefix
# 9     ACSTP     43   prefix
# 10     ATPL     42   prefix
# 11   STPCML     37   prefix
# 12    CMLNI     36   prefix
# 13   FTACML     34   prefix
# 14    SRTSL     29   prefix
# 15   ATPCML     28   prefix
# 16   ACSTER     26   prefix
# 17    HPLUL     26   prefix
# 18  FTASTPL     14   prefix
# 19    HP21L     14   prefix

# %% [markdown]
# ## Most Common Types of Work by Agnecy

# %%
_dla_utils.get_nunique(df, 'primary_agency_name', 'type_of_work')
# Out:
#                                          type_of_work   n
# 89                                 Bridge Replacement  17
# 90                            Bridge Replacement (tc)  15
# 307                                      FTA Transfer  10
# 82                              Bridge Rehabilitation   6
# 83                         Bridge Rehabilitation (tc)   6
# ..                                                ...  ..
# 818       Widen Travel Lanes; Construct Drainage (tc)   1
# 819  Widen Travel Lanes; Construct Drainage Imprvmnts   1
# 820                     Widen/aux. Lanes, On/off Ramp   1
# 821    Widening, Trainl And Intersection Improvements   1
# 822                        _const. Class I Bike Trail   1
#
# [823 rows x 2 columns]

# %%
_dla_utils.calculate_data_head(df, "primary_agency_name",'type_of_work', aggfunc="count")
# Out:
#                                           type_of_work  primary_agency_name
# 90                             Bridge Replacement (tc)                  250
# 89                                  Bridge Replacement                  126
# 307                                       FTA Transfer                   57
# 82                               Bridge Rehabilitation                   22
# 83                          Bridge Rehabilitation (tc)                   22
# 441  New Engineered Embankment System Will Need To ...                   18
# 49                                      Bike Path (tc)                   11
# 275                                  Emergency Opening                   10
# 513                           Preventative Maintenance                    9
# 488                           Pedestrian And Bike Path                    9
# 579      Replace 1 Lane Bridge With 2 Lane Bridge (tc)                    9
# 311  Flood Monitoring, Road Closure Management, And...                    9
# 227                                 Construct Sidewalk                    9
# 489                      Pedestrian And Bike Path (tc)                    9
# 79                       Bridge Preventive Maintenance                    8
# 86                           Bridge Rehabilitation(tc)                    8
# 139  Conduct Roadway Safety Signing Audit/upgrade S...                    8
# 537                   Realign Roadway, Widen Shoulders                    8
# 66         Br Preventive Maintenance (see Comment Tab)                    8
# 703                           Sidewalk & Ped Path (tc)                    8

# %%
df>>group_by(_.primary_agency_name)>>count(_.type_of_work)>>arrange(-_.n)>>filter(_.n>=8)
# Out:
#                               primary_agency_name  \
# 148                              El Dorado County
# 718          Sacramento Regional Transit District
# 863                                   Yuba County
# 315                                 Nevada County
# 821                                   Yolo County
# 381                                 Placer County
# 147                              El Dorado County
# 633                             Sacramento County
# 749                                 Sutter County
# 380                                 Placer County
# 632                             Sacramento County
# 728                                 Sierra County
# 257                                  Glenn County
# 9                                    Butte County
# 521                                    Sacramento
# 197                              El Dorado County
# 260                                  Glenn County
# 335                                 Nevada County
# 849                                     Yuba City
# 23                                   Butte County
# 141                              El Dorado County
# 143                              El Dorado County
# 145                              El Dorado County
# 200                              El Dorado County
# 322                                 Nevada County
# 343                                 Nevada County
# 390                                 Placer County
# 429  Placer County Transportation Planning Agency
# 519                                    Sacramento
# 723                                 Sierra County
# 827                                   Yolo County
#
#                                           type_of_work   n
# 148                            Bridge Replacement (tc)  45
# 718                                       FTA Transfer  30
# 863                            Bridge Replacement (tc)  29
# 315                            Bridge Replacement (tc)  28
# 821                            Bridge Replacement (tc)  27
# 381                            Bridge Replacement (tc)  25
# 147                                 Bridge Replacement  22
# 633                            Bridge Replacement (tc)  21
# 749                            Bridge Replacement (tc)  20
# 380                                 Bridge Replacement  19
# 632                                 Bridge Replacement  19
# 728  New Engineered Embankment System Will Need To ...  18
# 257                            Bridge Replacement (tc)  15
# 9                                   Bridge Replacement  14
# 521                                 Bridge Replacement  11
# 197                           Preventative Maintenance   9
# 260  Flood Monitoring, Road Closure Management, And...   9
# 335      Replace 1 Lane Bridge With 2 Lane Bridge (tc)   9
# 849                            Bridge Replacement (tc)   9
# 23   Emergency Force Account Agreement With Apex Fe...   8
# 141                                     Bike Path (tc)   8
# 143        Br Preventive Maintenance (see Comment Tab)   8
# 145                          Bridge Rehabilitation(tc)   8
# 200                   Realign Roadway, Widen Shoulders   8
# 322  Conduct Roadway Safety Signing Audit/upgrade S...   8
# 343                           Sidewalk & Ped Path (tc)   8
# 390                                   Hma Overlay (tc)   8
# 429                             Freeway Service Patrol   8
# 519                              Bridge Rehabilitation   8
# 723                            Bridge Replacement (tc)   8
# 827                                  Emergency Opening   8

# %% [markdown]
# ## Most Common Project Locations

# %%
df_top>>filter(_.variable=='project_location')
# Out:
#                                                 value  count          variable
# 0                                        Sacog Region     29  project_location
# 1                    Various Locations (see Comments)     10  project_location
# 2   5th Street At 2nd Street And 5th Street Over F...      9  project_location
# 3                4 Corridors In Western Nevada County      8  project_location
# 4   Along Newtown Road Between Hwy 49 And Beckvill...      8  project_location
# 5    El Dorado Trail From Los Trampas Dr To Halcon Rd      8  project_location
# 6   Nevada City Highway Starting At Banner Lava Ca...      8  project_location
# 7                                        Pctpa Region      8  project_location
# 8       Bradshaw & Sheldon At Laguna Crk Br #24c-0308      7  project_location
# 9   Ed Hills Csd From The West End Of Ny Trail Eas...      7  project_location
# 10                                 Palermo Rd Pm 1.46      7  project_location
# 11  Pennington Road At Sheldon Slough ~0.5 Mi East...      7  project_location
# 12  Rio Linda Blvd. At Magpie Creek ~1.0 Mile N. O...      7  project_location
# 13                          See State Comments Screen      7  project_location
# 14          Sierra Bl From Palmira Ave To Barbara Ave      7  project_location
# 15  19 Intersections Throughout Southwest Placer C...      6  project_location
# 16       Al Tahoe Blvd From Johnson Blvd To The Us 50      6  project_location
# 17            At Various Locations In Eldorado County      6  project_location
# 18        Clay Street At Hangtown Crk Br. No. 25c-117      6  project_location
# 19  Cook Riolo Road From Creekview Ranch Middle Sc...      6  project_location

# %% [markdown]
# ## Number of Obligations by Year

# %%
df_top>>filter(_.variable=='prepared_y')
# Out:
#      value  count    variable
# 0 2,019.00    400  prepared_y
# 1 2,018.00    343  prepared_y
# 2 2,014.00    319  prepared_y
# 3 2,017.00    309  prepared_y
# 4 2,016.00    306  prepared_y
# 5 2,020.00    305  prepared_y
# 6 2,015.00    272  prepared_y
# 7 2,021.00    248  prepared_y
# 8 2,013.00     12  prepared_y

# %%
df>>group_by(_.primary_agency_name)>>count(_.prepared_date)>>arrange(-_.n)
# Out:
#                        primary_agency_name prepared_date  n
# 1617                     Sacramento County    2018-10-18  9
# 1739  Sacramento Regional Transit District    2020-04-16  8
# 888                          Nevada County    2020-10-08  7
# 863                          Nevada County    2019-03-20  6
# 1357                            Sacramento    2016-04-29  6
# ...                                    ...           ... ..
# 2211                           Yuba County    2021-04-30  1
# 2212                           Yuba County    2021-06-30  1
# 2213                           Yuba County    2021-08-05  1
# 2214                           Yuba County    2021-08-19  1
# 2215                           Yuba County    2021-10-05  1
#
# [2216 rows x 3 columns]

# %% [markdown]
# ### Chart

# %%
_dla_utils.basic_line_chart((df_top>>filter(_.variable=='prepared_y')), 'value', 'count', subset, 'Obligations by Year')
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Agencies with the most unique project numbers

# %%
df>>group_by(_.primary_agency_name, _.prefix)>>count(_.project_no)>>arrange(-_.n)>>filter(_.n>5)
# Out:
#     primary_agency_name  prefix project_no  n
# 370       Nevada County    BRLO  5917(081)  9
# 941           Yuba City    BRLS  5163(027)  9
# 172    El Dorado County    BRLO  5925(095)  8
# 195    El Dorado County     CML  5925(125)  8
# 197    El Dorado County     CML  5925(130)  8
# 250           Elk Grove    BRLS  5479(012)  8
# 369       Nevada County    BRLO  5917(080)  8
# 371       Nevada County    BRLO  5917(082)  8
# 378       Nevada County     CML  5917(070)  8
# 379       Nevada County     CML  5917(090)  8
# 386       Nevada County   HRRRL  5917(088)  8
# 457       Placer County     CML  5919(124)  8
# 588          Sacramento    BRLS  5002(134)  8
# 28         Butte County    BRLS  5912(060)  7
# 185    El Dorado County    BRLS  5925(046)  7
# 198    El Dorado County     CML  5925(131)  7
# 352         Nevada City    BRLS  5018(012)  7
# 364       Nevada County    BRLO  5917(045)  7
# 365       Nevada County    BRLO  5917(069)  7
# 368       Nevada County    BRLO  5917(079)  7
# 372       Nevada County    BRLO  5917(083)  7
# 448       Placer County    BRLO  5919(116)  7
# 451       Placer County    BRLS  5919(097)  7
# 471       Placer County   HSIPL  5919(119)  7
# 527      Rancho Cordova    ATPL  5482(034)  7
# 832       Sutter County    BRLO  5918(076)  7
# 966         Yuba County    BRLO  5916(084)  7
# 24         Butte County    BRLO  5912(068)  6
# 169    El Dorado County    BRLO  5925(091)  6
# 171    El Dorado County    BRLO  5925(094)  6
# 186    El Dorado County    BRLS  5925(050)  6
# 229    El Dorado County   HSIPL  5925(147)  6
# 241    El Dorado County    STPL  5925(160)  6
# 249           Elk Grove    ATPL  5479(051)  6
# 272           Elk Grove    STPL  5479(049)  6
# 329             Lincoln    BRLO  5089(017)  6
# 387       Nevada County   HRRRL  5917(093)  6
# 424            Paradise   HSIPL  5425(025)  6
# 439       Placer County    BRLO  5919(074)  6
# 466       Placer County   HSIPL  5919(096)  6
# 472       Placer County   HSIPL  5919(127)  6
# 485       Placer County    TCSP  E2CA(018)  6
# 511         Placerville  BRCMLO  5015(011)  6
# 551             Rocklin     CML  5095(023)  6
# 563           Roseville     CML  5182(063)  6
# 644          Sacramento    STPL  5002(196)  6
# 821    South Lake Tahoe  ATPCML  5398(012)  6
# 822    South Lake Tahoe    ATPL  5398(011)  6
# 857             Truckee   HSIPL  5473(019)  6
# 913         Yolo County    BRLO  5922(078)  6
# 914         Yolo County    BRLO  5922(098)  6
# 990         Yuba County   HRRRL  5916(110)  6

# %% [markdown]
# ## Funding Amounts

# %%
_dla_utils.calculate_data_all(df, 'total_requested', 'primary_agency_name', aggfunc="mean")
# Out:
#                                   primary_agency_name  total_requested
# 44               Sacramento Regional Transit District     2,585,441.17
# 60                                          Yuba City     2,415,526.06
# 52                   University of California - Davis     1,916,020.75
# 57                                           Woodland     1,707,936.00
# 26                                         Marysville     1,609,720.50
# 59                Yolo County Transportation District     1,541,053.60
# 17                                             Folsom     1,248,165.28
# 43  Sacramento Metropolitan Air Quality Management...     1,187,538.65
# 42                                  Sacramento County     1,050,558.72
# 53                                    West Sacramento       988,185.56
# 39                                          Roseville       934,194.66
# 49                      Tahoe Transportation District       892,835.12
# 0                                              Auburn       845,729.93
# 40                                         Sacramento       827,545.68
# 16                                          Elk Grove       776,587.48
# 7                         Capital Southeast Connector       759,034.31
# 12                                              Davis       750,910.52
# 37                                     Rancho Cordova       731,999.95
# 22                                            Lincoln       704,903.97
# 50                                            Truckee       671,955.93
# 13                 Department of Parks and Recreation       670,868.59
# 18                                               Galt       657,627.30
# 15                                   El Dorado County       623,627.08
# 36                                        Placerville       599,657.23
# 8                                               Chico       566,867.94
# 9                                      Citrus Heights       549,440.89
# 2                                        Butte County       543,460.59
# 46                                   South Lake Tahoe       520,457.84
# 61                                        Yuba County       454,191.01
# 38                                            Rocklin       417,881.25
# 10                                             Colfax       415,102.05
# 6                                            Caltrans       407,505.96
# 34                                      Placer County       360,005.29
# 24                                             Loomis       356,579.98
# 41             Sacramento Area Council of Governments       340,071.35
# 56                                            Winters       325,321.15
# 58                                        Yolo County       299,823.74
# 32                                           Oroville       285,326.31
# 33                                           Paradise       273,969.31
# 35       Placer County Transportation Planning Agency       271,742.14
# 27                                       Modoc County       210,352.80
# 51      U.S. Forest Service, Pacific Southwest Region       184,901.54
# 3             Butte County Association of Governments       184,129.92
# 30                                      Nevada County       179,650.73
# 47                                      Sutter County       175,212.75
# 55                                            Willows       153,256.43
# 1                                               Biggs       151,782.51
# 54                                          Wheatland       126,077.06
# 4             California State University, Sacramento       105,363.44
# 45                                      Sierra County        77,815.47
# 19                                       Glenn County        76,867.57
# 23                                           Live Oak        54,121.18
# 29                                        Nevada City        51,221.11
# 21                                            Gridley        44,043.22
# 25                                 Los Angeles County        35,750.00
# 31                                             Orland         8,333.33

# %%
_dla_utils.calculate_data_all(df, 'total_requested', 'type_of_work', aggfunc="mean")
# Out:
#                                           type_of_work  total_requested
# 149  Construct 4 Lane Road With 8 Foot Shoulders.  ...    31,201,500.00
# 534  Realign And Widen From 2-4 Lanes And Signalize...    22,278,000.00
# 329                     Hov Lanes And I/c Reconstructi    15,065,434.00
# 639              Road Widening And Ped/bike Facilities    10,296,788.06
# 99   Bridge Replacement. Toll Credits For Stbgp Fun...     9,962,583.50
# ..                                                 ...              ...
# 760                     Traffic Safety Educational Pro         2,259.00
# 290  Emergency Opening And Restoration.  Damage To ...         2,003.46
# 129                                 Cmaq Program Admin            30.53
# 728  Spare The Air Voluntary Driving Curtailment Pr...             0.35
# 516          Programming And Monitoring (rstp) Phase 2             0.27
#
# [683 rows x 2 columns]

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
df.describe()
# Out:
#        fed_requested   ac_requested  total_requested     dist  \
# count       2,517.00       2,517.00         2,517.00 2,517.00
# mean      442,762.63      59,201.30       620,564.43     3.00
# std     1,431,678.51   2,314,056.64     3,107,301.55     0.00
# min    -7,338,664.05 -18,714,357.00   -52,762,263.75     3.00
# 25%             0.00           0.00             0.00     3.00
# 50%        10,442.00           0.00        60,000.00     3.00
# 75%       312,000.00           0.00       432,001.00     3.00
# max    24,669,621.91  70,500,000.00    70,500,000.00     3.00
#
#        dist_processing_days  hq_processing_days  fhwa_processing_days  \
# count              2,306.00            2,495.00              2,495.00
# mean                  16.02               12.99                  4.72
# std                   74.31               17.89                  4.27
# min                  -90.00                0.00                  0.00
# 25%                    0.00                1.00                  2.00
# 50%                    3.00                8.00                  4.00
# 75%                   12.00               16.50                  6.00
# max                3,177.00              177.00                 45.00
#
#            seq  prepared_y
# count 2,517.00    2,514.00
# mean      3.23    2,017.48
# std       2.05        2.23
# min       1.00    2,013.00
# 25%       2.00    2,016.00
# 50%       3.00    2,018.00
# 75%       4.00    2,019.00
# max      13.00    2,021.00

# %%
transit.describe()
# Out:
#        fed_requested  ac_requested  total_requested  dist  \
# count          21.00         21.00            21.00 21.00
# mean      669,953.33    -18,636.81       730,728.08  3.00
# std     1,106,214.66     88,147.85     1,426,353.04  0.00
# min       -36,277.43   -391,373.00    -2,206,077.53  3.00
# 25%             0.00          0.00             0.00  3.00
# 50%       183,300.00          0.00        66,645.00  3.00
# 75%     1,041,000.00          0.00     1,110,000.00  3.00
# max     4,000,000.00     69,000.00     4,000,000.00  3.00
#
#        dist_processing_days  hq_processing_days  fhwa_processing_days   seq  \
# count                 20.00               21.00                 21.00 21.00
# mean                  11.25               16.95                  6.29  2.67
# std                   19.96               27.53                  6.30  1.83
# min                    0.00                0.00                  0.00  1.00
# 25%                    0.00                0.00                  3.00  1.00
# 50%                    1.50               12.00                  5.00  2.00
# 75%                   10.00               19.00                  8.00  4.00
# max                   77.00              125.00                 29.00  7.00
#
#        prepared_y
# count       21.00
# mean     2,018.00
# std          2.30
# min      2,014.00
# 25%      2,016.00
# 50%      2,018.00
# 75%      2,020.00
# max      2,021.00

# %% [markdown]
# ### Top 50 Agencies with highest funds

# %%
((_dla_utils.calculate_data_all(df, 'total_requested', 'primary_agency_name', aggfunc="mean"))>>arrange(-_.total_requested)).head(50)
# Out:
#                                   primary_agency_name  total_requested
# 44               Sacramento Regional Transit District     2,585,441.17
# 60                                          Yuba City     2,415,526.06
# 52                   University of California - Davis     1,916,020.75
# 57                                           Woodland     1,854,886.80
# 26                                         Marysville     1,609,720.50
# 59                Yolo County Transportation District     1,541,053.60
# 17                                             Folsom     1,239,564.15
# 43  Sacramento Metropolitan Air Quality Management...     1,187,538.65
# 42                                  Sacramento County     1,068,964.51
# 53                                    West Sacramento     1,007,069.30
# 0                                              Auburn       995,759.76
# 49                      Tahoe Transportation District       892,835.12
# 39                                          Roseville       877,868.99
# 40                                         Sacramento       803,820.36
# 7                         Capital Southeast Connector       759,034.31
# 12                                              Davis       750,910.52
# 37                                     Rancho Cordova       734,859.60
# 22                                            Lincoln       723,955.43
# 16                                          Elk Grove       716,788.26
# 6                                            Caltrans       714,147.43
# 50                                            Truckee       671,955.93
# 13                 Department of Parks and Recreation       670,868.59
# 18                                               Galt       657,627.30
# 15                                   El Dorado County       635,924.14
# 36                                        Placerville       611,415.21
# 8                                               Chico       601,562.61
# 2                                        Butte County       579,258.77
# 46                                   South Lake Tahoe       559,010.28
# 9                                      Citrus Heights       539,302.74
# 61                                        Yuba County       445,445.77
# 38                                            Rocklin       417,881.25
# 10                                             Colfax       415,102.05
# 34                                      Placer County       357,891.36
# 24                                             Loomis       356,579.98
# 41             Sacramento Area Council of Governments       340,071.35
# 32                                           Oroville       326,463.69
# 56                                            Winters       325,321.15
# 58                                        Yolo County       306,615.05
# 33                                           Paradise       298,372.74
# 35       Placer County Transportation Planning Agency       264,784.21
# 27                                       Modoc County       210,352.80
# 30                                      Nevada County       187,446.73
# 51      U.S. Forest Service, Pacific Southwest Region       184,901.54
# 3             Butte County Association of Governments       184,129.92
# 47                                      Sutter County       184,083.47
# 55                                            Willows       153,256.43
# 1                                               Biggs       151,782.51
# 4             California State University, Sacramento       145,957.30
# 54                                          Wheatland       126,077.06
# 19                                       Glenn County        82,936.06

# %%
_dla_utils.basic_bar_chart((((_dla_utils.calculate_data_all(df, 'total_requested', 'primary_agency_name', aggfunc="mean"))
                          >>arrange(-_.total_requested)).head(30)
                        ), 'primary_agency_name','total_requested', 'primary_agency_name', subset,
                           'Average Total Requested Funds by Agency'
                       )
# Out:
# alt.Chart(...)

# %%
_dla_utils.basic_bar_chart((((_dla_utils.calculate_data_all(transit, 'total_requested', 'primary_agency_name', aggfunc="mean"))
                          >>arrange(-_.total_requested)).head(30)
                        ), 'primary_agency_name','total_requested', 'primary_agency_name', subset,
                           'Average Total Requested Funds by Agency: Transit Related Funding'
                       )
# Out:
# alt.Chart(...)

# %%
_dla_utils.basic_bar_chart((_dla_utils.calculate_data_all(transit_agencies, 'total_requested', aggregate_by='primary_agency_name', aggfunc="mean")),
                           'primary_agency_name', 'total_requested', 'primary_agency_name', subset,
                           'Transit Agencies Average Funding')
# Out:
# alt.Chart(...)

# %%
df>>filter(_.primary_agency_name=='San Joaquin Regional Transit District')>>count(_.type_of_work)
# Out:
# Empty DataFrame
# Columns: [type_of_work, n]
# Index: []

# %%
df>>filter(_.primary_agency_name=='San Joaquin Regional Transit District')>>count(_.prefix)
# Out:
# Empty DataFrame
# Columns: [prefix, n]
# Index: []

# %% [markdown]
# ### Bottom 50 Agencies with lowest funds

# %%
avg_funds_bottom = (df>>group_by(_.primary_agency_name)>>summarize(avg_funds=_.total_requested.mean())>>arrange(-_.avg_funds)).tail(50)

# %%
avg_funds_bottom
# Out:
#                               primary_agency_name     avg_funds
# 39                                      Roseville    877,868.99
# 40                                     Sacramento    803,820.36
# 7                     Capital Southeast Connector    759,034.31
# 12                                          Davis    750,910.52
# 37                                 Rancho Cordova    734,859.60
# 22                                        Lincoln    723,955.43
# 16                                      Elk Grove    716,788.26
# 6                                        Caltrans    714,147.43
# 50                                        Truckee    671,955.93
# 13             Department of Parks and Recreation    670,868.59
# 18                                           Galt    657,627.30
# 15                               El Dorado County    635,924.14
# 36                                    Placerville    611,415.21
# 8                                           Chico    601,562.61
# 2                                    Butte County    579,258.77
# 46                               South Lake Tahoe    559,010.28
# 9                                  Citrus Heights    539,302.74
# 61                                    Yuba County    445,445.77
# 38                                        Rocklin    417,881.25
# 10                                         Colfax    415,102.05
# 34                                  Placer County    357,891.36
# 24                                         Loomis    356,579.98
# 41         Sacramento Area Council of Governments    340,071.35
# 32                                       Oroville    326,463.69
# 56                                        Winters    325,321.15
# 58                                    Yolo County    306,615.05
# 33                                       Paradise    298,372.74
# 35   Placer County Transportation Planning Agency    264,784.21
# 27                                   Modoc County    210,352.80
# 30                                  Nevada County    187,446.73
# 51  U.S. Forest Service, Pacific Southwest Region    184,901.54
# 3         Butte County Association of Governments    184,129.92
# 47                                  Sutter County    184,083.47
# 55                                        Willows    153,256.43
# 1                                           Biggs    151,782.51
# 4         California State University, Sacramento    145,957.30
# 54                                      Wheatland    126,077.06
# 19                                   Glenn County     82,936.06
# 45                                  Sierra County     80,676.10
# 23                                       Live Oak     54,121.18
# 29                                    Nevada City     53,118.19
# 21                                        Gridley     44,043.22
# 25                             Los Angeles County     35,750.00
# 31                                         Orland      8,333.33
# 5                    California Tahoe Conservancy          0.00
# 48                 Tahoe Regional Planning Agency          0.00
# 28                Natomas Unified School District       -435.58
# 11                                  Colusa County     -4,619.51
# 20                                   Grass Valley   -830,322.05
# 14                                          Dixon -1,290,872.86

# %%
_dla_utils.basic_bar_chart((avg_funds_bottom.tail(40)), 'primary_agency_name','avg_funds', 'primary_agency_name', subset, 
                          'Lowest Average Total Funds by Agency')
# Out:
# WARN Symbol legend count exceeds limit, filtering items.
# alt.Chart(...)

# %%
((
    _dla_utils.calculate_data_all(
        df, 'total_requested', 'primary_agency_name', aggfunc="mean"))
>>arrange(-_.total_requested)).tail(50)
# Out:
#                                   primary_agency_name  total_requested
# 17                                             Folsom     1,239,564.15
# 43  Sacramento Metropolitan Air Quality Management...     1,187,538.65
# 42                                  Sacramento County     1,068,964.51
# 53                                    West Sacramento     1,007,069.30
# 0                                              Auburn       995,759.76
# 49                      Tahoe Transportation District       892,835.12
# 39                                          Roseville       877,868.99
# 40                                         Sacramento       803,820.36
# 7                         Capital Southeast Connector       759,034.31
# 12                                              Davis       750,910.52
# 37                                     Rancho Cordova       734,859.60
# 22                                            Lincoln       723,955.43
# 16                                          Elk Grove       716,788.26
# 6                                            Caltrans       714,147.43
# 50                                            Truckee       671,955.93
# 13                 Department of Parks and Recreation       670,868.59
# 18                                               Galt       657,627.30
# 15                                   El Dorado County       635,924.14
# 36                                        Placerville       611,415.21
# 8                                               Chico       601,562.61
# 2                                        Butte County       579,258.77
# 46                                   South Lake Tahoe       559,010.28
# 9                                      Citrus Heights       539,302.74
# 61                                        Yuba County       445,445.77
# 38                                            Rocklin       417,881.25
# 10                                             Colfax       415,102.05
# 34                                      Placer County       357,891.36
# 24                                             Loomis       356,579.98
# 41             Sacramento Area Council of Governments       340,071.35
# 32                                           Oroville       326,463.69
# 56                                            Winters       325,321.15
# 58                                        Yolo County       306,615.05
# 33                                           Paradise       298,372.74
# 35       Placer County Transportation Planning Agency       264,784.21
# 27                                       Modoc County       210,352.80
# 30                                      Nevada County       187,446.73
# 51      U.S. Forest Service, Pacific Southwest Region       184,901.54
# 3             Butte County Association of Governments       184,129.92
# 47                                      Sutter County       184,083.47
# 55                                            Willows       153,256.43
# 1                                               Biggs       151,782.51
# 4             California State University, Sacramento       145,957.30
# 54                                          Wheatland       126,077.06
# 19                                       Glenn County        82,936.06
# 45                                      Sierra County        80,676.10
# 23                                           Live Oak        54,121.18
# 29                                        Nevada City        53,118.19
# 21                                            Gridley        44,043.22
# 25                                 Los Angeles County        35,750.00
# 31                                             Orland         8,333.33

# %%
_dla_utils.basic_bar_chart((((_dla_utils.calculate_data_all(df, 'total_requested', 'primary_agency_name', aggfunc="mean"))
                          >>arrange(-_.total_requested)).tail(50)
                        ), 'primary_agency_name','total_requested', 'total_requested', subset,
                           'Average Total Requested Funds by Agency'
                       )
# Out:
# alt.Chart(...)

# %%
df.sample()
# Out:
#        location prefix project_no     agency prepared_date submit__to_hq_date  \
# 6408  Obligated    CML  5182(063)  Roseville    2016-06-14         2016-06-14
#
#      hq_review_date submit_to_fhwa_date to_fmis_date  fed_requested  ...  \
# 6408     2016-06-27          2016-06-27   2016-07-05     767,044.00  ...
#
#        ftip_no              project_location              type_of_work seq  \
# 6408  PLA25469  Lincoln Street To Royer Park  Extend Class I Bike Path   3
#
#       date_request_initiated date_completed_request    mpo  projectID  \
# 6408                     NaT                    NaT  SACOG       5182
#
#       prepared_y primary_agency_name
# 6408    2,016.00           Roseville
#
# [1 rows x 29 columns]

# %% [markdown]
# ## Prefix Code Funding

# %%
_dla_utils.basic_bar_chart((((_dla_utils.calculate_data_all(df, 'total_requested', 'prefix', aggfunc="mean"))
                          >>arrange(-_.total_requested)).head(30)
                        ), 'prefix','total_requested', 'prefix', subset,
                           'Average Total Requested Funds by Prefix'
                       )
# Out:
# alt.Chart(...)

# %%
_dla_utils.basic_bar_chart((((_dla_utils.calculate_data_all(df, 'fed_requested', 'prefix', aggfunc="mean"))
                          >>arrange(-_.fed_requested)).head(30)
                        ), 'prefix','fed_requested', 'prefix', subset,
                           'Average Federal Requested Funds by Prefix'
                       )
# Out:
# alt.Chart(...)

# %%
_dla_utils.basic_bar_chart((((_dla_utils.calculate_data_all(df, 'ac_requested', 'prefix', aggfunc="mean"))
                          >>arrange(-_.ac_requested)).head(30)
                        ), 'prefix','ac_requested', 'prefix', subset,
                           'Average Advanced Construction Requested Funds by Prefix'
                       )
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Functions to look by Prefix and by Agency:

# %% [markdown]
# ### By Agency:

# %%
_dla_utils.interactive_widget(df, 'primary_agency_name')
# Out:
# Dropdown(description='Primary_Agency_Name', options=('Auburn', 'Biggs', 'Butte County', 'Butte County Associat…
# Output()

# %% [markdown]
# ### By Prefix:

# %%
_dla_utils.interactive_widget(df, 'prefix')
# Out:
# Dropdown(description='Prefix', options=('ACSTER', 'ACSTP', 'ATPCML', 'ATPL', 'ATPLNI', 'ATPSB1L', 'ATPSTC', 'A…
# Output()

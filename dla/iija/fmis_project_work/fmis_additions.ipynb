# %% [markdown]
# # Add Agency and Agency Information to FMIS IIJA

# %%
# ! pip install nltk
# ! pip install textblob

# %%
import numpy as np
import pandas as pd
from siuba import *

from dla_utils import _dla_utils

from calitp import to_snakecase

import utils
# Out:
# /opt/conda/lib/python3.10/site-packages/geopandas/_compat.py:112: UserWarning: The Shapely GEOS version (3.10.3-CAPI-1.16.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.

# %%
pd.set_option("display.max_columns", 100)
pd.set_option('display.max_colwidth', None)

# %%
GCS_FILE_PATH  = 'gs://calitp-analytics-data/data-analyses/dla/dla-iija'

# %% [markdown]
# ## Read In Data

# %%
## other county locodes

# county = to_snakecase(pd.read_excel(f"{GCS_FILE_PATH}/Copy of County.xlsx",
#                                    sheet_name='locode1',
#                                    header=[0]))

# %%
proj = to_snakecase(pd.read_excel(f"{GCS_FILE_PATH}/CopyofFMIS_Projects_Universe_IIJA_Reporting_4.xls", 
                           # sheet_name='FMIS 5 Projects  ', header=[3]
                           sheet_name='IIJA-combined',
                           # sheet_name='FMIS 5 Projects  ',
                           ))

# %%
# number of entries in the county locode list
len(county)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [7], line 2
#       1 # number of entries in the county locode list
# ----> 2 len(county)
#
# NameError: name 'county' is not defined

# %%
county.sample(4)

# %%
proj.drop(columns =['unnamed:_0', 'unnamed:_13', 'total'], axis=1, inplace=True)

# %%
proj.sample()

# %% [markdown]
# ## Get Locode Substring

# %%
string = proj['summary_recipient_defined_text_field_1_value'].iloc[0]

# %%
string

# %%
print(string.find('5'))
print(string.find('3'))

# %%
# need to extract string from position 1-4.

# %%
#proj['locode'] = proj.summary_recipient_defined_text_field_1_value.apply(lambda x: x[1:5])

# %%
#proj.head()

# %%
county.sample()
# Out:
#      agency_locode                                agency_name  district  mpo  \
# 776           6229  Hayward Area Recreation And Park District      4.00  MTC
#
#              county
# 776  Alameda County

# %% [markdown]
# ## Merge data on Locode

# %%
proj_all = utils.add_name_from_locode(proj, 'summary_recipient_defined_text_field_1_value')

# %%
proj_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 330 entries, 0 to 329
# Data columns (total 21 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   unnamed:_0                                    0 non-null      float64
#  1   fmis_transaction_date                         330 non-null    datetime64[ns]
#  2   program_code                                  330 non-null    object
#  3   program_code_description                      330 non-null    object
#  4   project_number                                330 non-null    object
#  5   recipient_project_number                      330 non-null    object
#  6   project_title                                 330 non-null    object
#  7   county_code                                   330 non-null    int64
#  8   congressional_district                        330 non-null    object
#  9   improvement_type                              330 non-null    object
#  10  improvement_type_description                  330 non-null    object
#  11  obligations_amount                            330 non-null    float64
#  12  summary_recipient_defined_text_field_1_value  330 non-null    object
#  13  unnamed:_13                                   0 non-null      float64
#  14  total                                         0 non-null      float64
#  15  implementing_agency_locode                    329 non-null    float64
#  16  implementing_agency                           329 non-null    object
#  17  district                                      329 non-null    float64
#  18  county_name                                   329 non-null    object
#  19  rtpa_name                                     329 non-null    object
#  20  mpo_name                                      329 non-null    object
# dtypes: datetime64[ns](1), float64(6), int64(1), object(13)
# memory usage: 56.7+ KB

# %%
proj_all
# Out:
#      unnamed:_0 fmis_transaction_date            program_code  \
# 0           NaN            2022-06-01              YS30//YS30
# 1           NaN            2022-09-15                    Y001
# 2           NaN            2022-07-25              YS30//YS30
# 3           NaN            2022-03-07  Y233//Y233//Y233//Y233
# 4           NaN            2022-07-18              YS30//YS30
# ..          ...                   ...                     ...
# 325         NaN            2022-03-24              Y001//Y001
# 326         NaN            2022-08-08              Y400//Y400
# 327         NaN            2022-05-05              Y301//Y301
# 328         NaN            2022-08-02              Y233//Y233
# 329         NaN            2022-08-24                    Y400
#
#           program_code_description project_number recipient_project_number  \
# 0     HIGHWAY SAFETY IMP PROG IIJA        5253021              0720000168L
# 1       NATIONAL HIGHWAY PERF IIJA        NBIL539              0815000215L
# 2     HIGHWAY SAFETY IMP PROG IIJA        5132050              0421000374L
# 3      STBG IIJA OFF-SYSTEM BRIDGE        5914078              0100020461L
# 4     HIGHWAY SAFETY IMP PROG IIJA        5094071              0419000558L
# ..                             ...            ...                      ...
# 325     NATIONAL HIGHWAY PERF IIJA        5275021                08925183L
# 326     CONGESTION MITIGATION IIJA        5170063              0621000158L
# 327  TRANS ALTERNATIVES >200K IIJA        5063195              1219000022L
# 328    STBG IIJA OFF-SYSTEM BRIDGE        5929235              1012000103L
# 329     CONGESTION MITIGATION IIJA        5284014              0620000119L
#
#                                                                                                                                              project_title  \
# 0           120TH STREET FROM PRAIRIE AVENUE TO FELTON AVENUE. TRAFFIC SIGNAL UPGRADES AT NINE SIGNALIZED INTERSECTIONS AND IMPROVE CROSSINGS AND SIGNAGE.
# 1                           13TH STREET OVER WILSON CREEK FROM OAK GLEN ROAD TO KENTUCKY STREET, LWC 00L0017 REPLACE LOW WATER CROSSING WITH 2-LANE BRIDGE
# 2         16 LOCATIONS IN THE CITY OF FAIRFIELD INSTALL ADAPTIVE SIGNAL TIMING AND ADVANCED DILEMMA-ZONE DETECTION, AND ENHANCE THE VISIBILITY OF SIGNALS.
# 3                                         2.2 MILES NORTH OF STATE ROUTE 20 ON WITTER SPRINGS ROAD OVER COOPER CREEK. BR.# 14C0119 BRIDGE REPLACEMENT (TC)
# 4    21 INTERSECTIONS; ON ALAMO DRIVE FROM MERCHANT STREET TO NUT TREE ROAD AND ON PEABODY ROAD FROM ELMIRA ROAD TO FOXBORO PARKWAY IMPROVE SIGNAL HARDWAR
# ..                                                                                                                                                     ...
# 325                                           WESTBOUND INDIO BOULEVARD OVER WHITEWATER RIVER, BR. NO. 56C-0292 SEISMIC RETROFIT AND SCOUR COUNTERMEASURES
# 326                                                                             WESTSIDE OF 18TH AVE FROM STROUD AVE TO KLEPPER ST CONSTRUCT NEW SIDEWALKS
# 327    WILLITS STREET FROM FAIRVIEW STREET TO E/S OF RAITT STREET INSTALL MEDIAN, PARKING-PROTECTED BICYCLE LANES, AND DEDICATED BICYCLE SIGNAL HEADS (TC)
# 328                                                                     WIMER ROAD OVER INDIAN CREEK NORTH BRANCH (BRIDGE 29C0303) BRIDGE REPLACEMENT (TC)
# 329                                                                  WOODLAKE AT THE INTERSECTION OF SIERRA AVE AND CASTLE ROCK STREET NEW ROUNDABOUT (TC)
#
#      county_code congressional_district improvement_type  \
# 0             37           Cong Dist 43           17//21
# 1             71            Cong Dist 8               44
# 2             95            Cong Dist 3           17//21
# 3             33            Cong Dist 3   11//15//16//17
# 4             95            Cong Dist 3           17//21
# ..           ...                    ...              ...
# 325           65           Cong Dist 36           14//17
# 326           19           Cong Dist 21           17//28
# 327           59           Cong Dist 46           17//28
# 328           77            Cong Dist 9           11//17
# 329          107           Cong Dist 22               24
#
#                                                                                 improvement_type_description  \
# 0                                                                           Construction Engineering//Safety
# 1                                                                                                      Other
# 2                                                                           Construction Engineering//Safety
# 3    Bridge Replacement - No Added Capacity//Preliminary Engineering//Right of Way//Construction Engineering
# 4                                                                           Construction Engineering//Safety
# ..                                                                                                       ...
# 325                                      Bridge Rehabilitation - No Added Capacity//Construction Engineering
# 326                                        Construction Engineering//Facilities for Pedestrians and Bicycles
# 327                                        Construction Engineering//Facilities for Pedestrians and Bicycles
# 328                                         Bridge Replacement - No Added Capacity//Construction Engineering
# 329                                                                     Traffic Management/Engineering - HOV
#
#      obligations_amount summary_recipient_defined_text_field_1_value  \
# 0          1,305,800.00                                    L5253SCAG
# 1            301,838.32                                    L5457SCAG
# 2            935,150.00                                     L5132MTC
# 3          1,615,000.00                                 L5914NON-MPO
# 4          2,027,700.00                                     L5094MTC
# ..                  ...                                          ...
# 325        1,291,254.00                                    L5275SCAG
# 326          120,400.00                                    L5170FCOG
# 327        1,735,951.12                                    L5063SCAG
# 328        2,748,840.00                                   L5929SJCOG
# 329          250,000.00                                    L5284TCAG
#
#      unnamed:_13  total  implementing_agency_locode implementing_agency  \
# 0            NaN    NaN                    5,253.00           Hawthorne
# 1            NaN    NaN                    5,457.00             Yucaipa
# 2            NaN    NaN                    5,132.00           Fairfield
# 3            NaN    NaN                    5,914.00         Lake County
# 4            NaN    NaN                    5,094.00           Vacaville
# ..           ...    ...                         ...                 ...
# 325          NaN    NaN                    5,275.00               Indio
# 326          NaN    NaN                    5,170.00           Kingsburg
# 327          NaN    NaN                    5,063.00           Santa Ana
# 328          NaN    NaN                    5,929.00  San Joaquin County
# 329          NaN    NaN                    5,284.00            Woodlake
#
#      district            county_name  \
# 0        7.00     Los Angeles County
# 1        8.00  San Bernardino County
# 2        4.00          Solano County
# 3        1.00            Lake County
# 4        4.00          Solano County
# ..        ...                    ...
# 325      8.00       Riverside County
# 326      6.00          Fresno County
# 327     12.00          Orange County
# 328     10.00     San Joaquin County
# 329      6.00          Tulare County
#
#                                                 rtpa_name  \
# 0    Los Angeles County Metropolitan Transportation Auth.
# 1                   San Bernardino Associated Governments
# 2                  Metropolitan Transportation Commission
# 3                  Lake County/City Area Planning Council
# 4                  Metropolitan Transportation Commission
# ..                                                    ...
# 325            Riverside County Transportation Commission
# 326                  Council of Fresno County Governments
# 327                Orange County Transportation Authority
# 328                    San Joaquin Council of Governments
# 329              Tulare County Association of Governments
#
#                                            mpo_name
# 0    Southern California Association Of Governments
# 1    Southern California Association Of Governments
# 2            Metropolitan Transportation Commission
# 3                                           NON-MPO
# 4            Metropolitan Transportation Commission
# ..                                              ...
# 325  Southern California Association Of Governments
# 326             Council Of Fresno County Goverments
# 327  Southern California Association Of Governments
# 328               San Joaquin Council Of Goverments
# 329        Tulare County Association Of Governments
#
# [330 rows x 21 columns]

# %%
# one locode did not match
proj_all>>filter(_.implementing_agency_locode.isnull())
# Out:
#     fmis_transaction_date program_code    program_code_description  \
# 284            2022-04-26         Y001  NATIONAL HIGHWAY PERF IIJA
#
#     project_number recipient_project_number  \
# 284        NBIS522             0000001453L5
#
#                                                                                            project_title  \
# 284  STATEWIDE - IN SERVICE BRIDGES OWNED BY LOCAL AGENCIES FEDERALLY MANDATED BRIDGE INSPECTION PROGRAM
#
#      county_code congressional_district improvement_type  \
# 284           67            Cong Dist 3               49
#
#                       improvement_type_description  obligations_amount  \
# 284  Bridge Inspection and Bridge Related Training       14,164,800.00
#
#     summary_recipient_defined_text_field_1_value  implementing_agency_locode  \
# 284                                 S    NON-MPO                         NaN
#
#     implementing_agency  district county_name rtpa_name mpo_name
# 284                 NaN       NaN         NaN       NaN      NaN

# %%
list(proj_all.implementing_agency.unique())
# Out:
# ['Hawthorne',
#  'Yucaipa',
#  'Fairfield',
#  'Lake County',
#  'Vacaville',
#  'Benicia',
#  'Pico Rivera',
#  'Marin County',
#  'Los Banos',
#  'Santa Clara County',
#  'Santa Barbara County',
#  'Fresno County',
#  'Santa Ana',
#  'Stockton',
#  'Caltrans',
#  'Sacramento',
#  'San Benito County',
#  'Pinole',
#  'Sacramento County',
#  'Merced County',
#  'Shasta County',
#  'Livingston',
#  'El Dorado County',
#  'Sanger',
#  'Palmdale',
#  'Tulare County',
#  'Coachella',
#  'Bakersfield',
#  'Colton',
#  'Visalia',
#  'Rialto',
#  'Metropolitan Transportation Commission',
#  'Bellflower',
#  'Belmont',
#  'Larkspur',
#  'Monterey County',
#  'Madera County',
#  'Moraga',
#  'Orinda',
#  'Redding',
#  'Cathedral City',
#  'Alameda',
#  'Clovis',
#  'Gardena',
#  'Mission Viejo',
#  'Pleasanton',
#  'Fresno',
#  'Butte County',
#  'Rohnert Park',
#  'Alameda County Transportation Commission',
#  'Yolo County',
#  'Stanislaus County',
#  'Placer County',
#  'Contra Costa County',
#  'Mariposa County',
#  'Santa Barbara',
#  'Nevada County',
#  'Calaveras County',
#  'Long Beach',
#  'Los Angeles',
#  'Dublin',
#  'Chico',
#  'Rancho Santa Margarita',
#  'Morgan Hill',
#  'Hanford',
#  'Kingsburg',
#  'Coachella Valley Association of Governments',
#  'La Puente',
#  'San Joaquin County',
#  'Fullerton',
#  'South San Francisco',
#  'Sunnyvale',
#  'Indio',
#  'Modesto',
#  'Vallejo',
#  'San Bernardino',
#  'Santa Cruz County',
#  'Orange Cove',
#  'Fremont',
#  'Jackson',
#  'San Luis Obispo County',
#  'San Diego',
#  'Lathrop',
#  'Riverside County',
#  'Sonoma County',
#  'Santa Rosa',
#  'Hercules',
#  'Twentynine Palms',
#  'San Mateo',
#  'San Bernardino County Transportation Authority',
#  'Elk Grove',
#  'Alameda County',
#  'Citrus Heights',
#  'Humboldt County',
#  'Mendocino County',
#  'Merced',
#  'Placerville',
#  'Sacramento Metropolitan Air Quality Management District',
#  'San Diego Association of Governments',
#  'Folsom',
#  'Galt',
#  'Roseville',
#  'Los Angeles County',
#  'Newman',
#  'Yuba County',
#  'El Cajon',
#  'Oakland',
#  'Brentwood',
#  'South Gate',
#  'Santa Monica',
#  'Orange County',
#  'San Jose',
#  'Shasta Lake',
#  'San Bernardino County',
#  'Barstow',
#  'Lassen County',
#  'St Helena',
#  'Ukiah',
#  'San Francisco County Transportation Authority',
#  'Sierra County',
#  'Hemet',
#  'Live Oak',
#  'Tehachapi',
#  'Corona',
#  'Kern County',
#  'Woodside',
#  'Napa Valley Transportation Authority',
#  'West Sacramento',
#  'Palm Springs',
#  'Del Norte County',
#  'Redwood City',
#  'Sacramento Area Council of Governments',
#  'San Mateo County',
#  'San Diego County',
#  'Napa County',
#  'Solano Transportation Authority',
#  'Patterson',
#  'Lodi',
#  'Sebastopol',
#  'Orange County Transportation Authority',
#  'Riverside County Transportation Commission',
#  nan,
#  'Lake Elsinore',
#  'Encinitas',
#  'San Leandro',
#  'Vista',
#  'San Rafael',
#  'Los Angeles County Metropolitan Transportation Authority',
#  'Tahoe Transportation District',
#  'Huntington Beach',
#  'Fountain Valley',
#  'Concord',
#  'Victorville',
#  'Angels',
#  'Jurupa Valley',
#  'Redlands',
#  'Riverside',
#  'Anaheim',
#  'Pasadena',
#  'Trinity County',
#  'Windsor',
#  'Inglewood',
#  'San Marcos',
#  'Tuolumne County',
#  'Woodlake']

# %% [markdown]
# ## Writing to GCS

# %%
#proj_all.to_csv(f"{GCS_FILE_PATH}/FMIS_projects_wip.csv")

# %% [markdown]
# ## Adding Place Names (can do)
# * we have a list of city names to county from [Caltrans PlaceNames](https://dot.ca.gov/-/media/dot-media/programs/research-innovation-system-information/documents/place-names/2019-place-names-in-california-a11y.pdf)

# %%
# city_place_names = (to_snakecase(pd.read_excel('gs://calitp-analytics-data/data-analyses/dla/e-76Obligated/2020-place-names-locode.xlsx', sheet_name=0)))

# %%
# city_place_names.sample()

# %%
# city_place_names.drop(columns =['unnamed:_1', 'unnamed:_3', 'unnamed:_4','unnamed:_6','unnamed:_7', 'date_of_incorporation',
#                                'city_name_abbr_','name','dist_', 'co_'], axis=1, inplace=True)

# %%
# (pd.merge(proj_all, city_place_names, left_on='agency_locode', right_on='ct_city_code', how='left', indicator=True))._merge.value_counts()

# %%
# proj_all1 = (pd.merge(proj_all, city_place_names, left_on='agency_locode', right_on='ct_city_code', how='left', indicator='City'))

# %%
# proj_all1.sample(2)

# %%
# proj_all1>>filter(_.City!='both')

# %%
# county_place_names = (to_snakecase(pd.read_excel('gs://calitp-analytics-data/data-analyses/dla/e-76Obligated/2020-place-names-locode.xlsx', sheet_name=1)))

# %%
# county_place_names

# %% [markdown]
# ## Project Location

# %%
location = (proj_all>>select(_.implementing_agency, _.county_name, _.project_title))

# %%
location.sample()
# Out:
#     implementing_agency    county_name  \
# 256       Sierra County  Sierra County
#
#                                                                                                  project_title
# 256  SALMON LAKE ROAD AT SALMON CREEK ~ 300 FT WEST OF GOLD LAKE HIGHWAY. BR.# 13C0053 BRIDGE REPLACEMENT (TC)

# %%
len(location)
# Out:
# 330

# %% [markdown]
# ## Project Title

# %%
#phrase extraction maybe: https://stackoverflow.com/questions/70995812/extract-keyword-from-sentences-in-a-pandas-text-column-using-nltk-and-or-regex

# %%
import nltk
from textblob import TextBlob
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
import re

# %%
#subset df to work on title
title = proj_all>>select(_.implementing_agency, _.program_code_description, _.project_title, _.program_code)

# %%
title
# Out:
#     implementing_agency       program_code_description  \
# 0             Hawthorne   HIGHWAY SAFETY IMP PROG IIJA
# 1               Yucaipa     NATIONAL HIGHWAY PERF IIJA
# 2             Fairfield   HIGHWAY SAFETY IMP PROG IIJA
# 3           Lake County    STBG IIJA OFF-SYSTEM BRIDGE
# 4             Vacaville   HIGHWAY SAFETY IMP PROG IIJA
# ..                  ...                            ...
# 325               Indio     NATIONAL HIGHWAY PERF IIJA
# 326           Kingsburg     CONGESTION MITIGATION IIJA
# 327           Santa Ana  TRANS ALTERNATIVES >200K IIJA
# 328  San Joaquin County    STBG IIJA OFF-SYSTEM BRIDGE
# 329            Woodlake     CONGESTION MITIGATION IIJA
#
#                                                                                                                                              project_title  \
# 0           120TH STREET FROM PRAIRIE AVENUE TO FELTON AVENUE. TRAFFIC SIGNAL UPGRADES AT NINE SIGNALIZED INTERSECTIONS AND IMPROVE CROSSINGS AND SIGNAGE.
# 1                           13TH STREET OVER WILSON CREEK FROM OAK GLEN ROAD TO KENTUCKY STREET, LWC 00L0017 REPLACE LOW WATER CROSSING WITH 2-LANE BRIDGE
# 2         16 LOCATIONS IN THE CITY OF FAIRFIELD INSTALL ADAPTIVE SIGNAL TIMING AND ADVANCED DILEMMA-ZONE DETECTION, AND ENHANCE THE VISIBILITY OF SIGNALS.
# 3                                         2.2 MILES NORTH OF STATE ROUTE 20 ON WITTER SPRINGS ROAD OVER COOPER CREEK. BR.# 14C0119 BRIDGE REPLACEMENT (TC)
# 4    21 INTERSECTIONS; ON ALAMO DRIVE FROM MERCHANT STREET TO NUT TREE ROAD AND ON PEABODY ROAD FROM ELMIRA ROAD TO FOXBORO PARKWAY IMPROVE SIGNAL HARDWAR
# ..                                                                                                                                                     ...
# 325                                           WESTBOUND INDIO BOULEVARD OVER WHITEWATER RIVER, BR. NO. 56C-0292 SEISMIC RETROFIT AND SCOUR COUNTERMEASURES
# 326                                                                             WESTSIDE OF 18TH AVE FROM STROUD AVE TO KLEPPER ST CONSTRUCT NEW SIDEWALKS
# 327    WILLITS STREET FROM FAIRVIEW STREET TO E/S OF RAITT STREET INSTALL MEDIAN, PARKING-PROTECTED BICYCLE LANES, AND DEDICATED BICYCLE SIGNAL HEADS (TC)
# 328                                                                     WIMER ROAD OVER INDIAN CREEK NORTH BRANCH (BRIDGE 29C0303) BRIDGE REPLACEMENT (TC)
# 329                                                                  WOODLAKE AT THE INTERSECTION OF SIERRA AVE AND CASTLE ROCK STREET NEW ROUNDABOUT (TC)
#
#                program_code
# 0                YS30//YS30
# 1                      Y001
# 2                YS30//YS30
# 3    Y233//Y233//Y233//Y233
# 4                YS30//YS30
# ..                      ...
# 325              Y001//Y001
# 326              Y400//Y400
# 327              Y301//Y301
# 328              Y233//Y233
# 329                    Y400
#
# [330 rows x 4 columns]

# %%
title.program_code_description.value_counts()
# Out:
# HIGHWAY SAFETY IMP PROG IIJA      75
# STBG-URBANIZED >200K IIJA         61
# NATIONAL HIGHWAY PERF IIJA        59
# STBG IIJA OFF-SYSTEM BRIDGE       49
# CONGESTION MITIGATION IIJA        37
# SURFAC TRNSP BLK GRTS-FLX IIJA    18
# TRANS ALTERNATIVES >200K IIJA     14
# PROJ TO REDUCE PM 2.5 EMI IIJA    12
# TRANSP ALTERNATIVES FLEX IIJA      4
# TRANS ALTERN 50K-200K POP IIJA     1
# Name: program_code_description, dtype: int64

# %%
clean_type_list_df = utils.get_list_of_words(title, "project_title")
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
clean_type_list_df.value_counts()
# Out:
# bridge     178
# road       142
# avenue     115
# ave         77
# street      75
#           ...
# jamacha      1
# bellota      1
# belmont      1
# j            1
# 00           1
# Length: 1729, dtype: int64

# %%
clean_type_list_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4910 entries, 0 to 4909
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       4910 non-null   object
# dtypes: object(1)
# memory usage: 38.5+ KB

# %%
clean_type_list_df.value_counts()
# Out:
# bridge     178
# road       142
# avenue     115
# ave         77
# street      75
#           ...
# jamacha      1
# bellota      1
# belmont      1
# j            1
# 00           1
# Length: 1729, dtype: int64

# %%
#splitting up the types of words based on the most common words appearing in title name

fix_type = ['REPLACEMENT', 'INSTALL', 'CONSTRUCT', 'REPLACE', 'SIGNAL', 'TRAFFIC',
           'IMPROVEMENT', 'PEDESTRIAN', 'LANES', 'NEW', 'REHABILITATION',
           'UPGRADE', 'CLASS', 'BIKE', 'WIDEN', 'LANDSCAPING', 'SAFETY', 'RAISED', 
            'SEISMIC', 'SIGNAGE', 'RETROFIT', 'ADD', 'PLANNING', 'PAVE'
           'PREVENTIVE','MAINTENANCE', 'REHAB', 'RESURFACE', 'REPAIR', 'ROUNDABOUT']

area_type = ['BRIDGE', 'ROAD', 'RD', 'AVENUE', 'AVE', 'STREET' , 'ST',
             'FRACTURED', 'LANE', 'DRIVE', 'boulevard', 'BLVD',
             'INTERSECTION', 'intersections', 'WAY', 'DR', 'CURB', 'ROADWAY',
             'TRAIL', 'PATH', 'CREEK', 'RIVER', 'SIDEWALK', 'CORRIDOR', 'PARKWAY',
            'RAMPS', 'GUARDRAIL']

jurisdiction = ['CITY', 'COUNTY', 'STATE', 'UNINCORPORATED']

other = ['TC', 'EXISTING']

# %%
def tokenize(texts):
    return [nltk.tokenize.word_tokenize(t) for t in texts]

# %% [markdown]
# ### using  np.concatenate

# %%
#! pip install more-itertools

# %%
#from more_itertools import split_after

# %%
title.sample()
# Out:
#     implementing_agency      program_code_description  \
# 289             Benicia  HIGHWAY SAFETY IMP PROG IIJA
#
#                                                                                                                                              project_title  \
# 289  THE INTERSECTIONS OF MILITARY WEST AND WEST 5TH ST. AND HASTINGS DR. AND LONDON DR. PEDESTRIAN CROSSING IMPROVEMENTS, INCLUDING: ADA RAMPS RRFB SYSTE
#
#     program_code
# 289   YS30//YS30

# %%
text = title>>select (_.project_title)

# %%
text['summary'] = utils.key_word_intersection(text, 'project_title')

# %%
text.sample(10)
# Out:
#                                                                                                                                              project_title  \
# 253  SACOG REGION - IN SACRAMENTO, SUTTER, YOLO AND YUBA COUNTIES CONDUCT NECESSARY PLANNING, STATE AND FEDERAL PROGRAMMING, AND MONITORING ACTIVITIES, IN
# 178                         JENSEN AVE. FROM ELM AVENUE TO TEMPERANCE AVENUE INSTALL ITS ADAPTIVE SYSTEM, UPGRADE DETECTION AND SYNCHRONIZE CORRIDOR. (TC)
# 189                      MATTOLE ROAD OVER MATTOLE RIVER (HONEYDEW), EAST OF WILDER RIDGE ROAD AND.MATTOLE ROAD JUNCTION BRIDGE REPLACEMENT (BR # 04C0055)
# 255                                             SALEM STREET AT LITTLE CHICO CREEK BRIDGE BR. # 12C-336 ~0.1 M NORTH OF 10TH ST BRIDGE REHABILITATION (TC)
# 6     3/8 MI WEST OF PARAMOUNT BLVDWASHINGTON BLVD OVER RIO HONDO.LOCAL BRIDGE # 53C0471 BRIDGE REPLACEMENT  (DEMOLISH THE EXISTING 6 LANNE SUPERSTRUCTURE
# 52                                                   BRIDGE NO. 28C0331, BEAR CREEK RD, OVER SAN PABLO CREEK, 0.2 MI EAST OF CAMINO PABLO SEISMIC RETROFIT
# 247                                                               REQUA ROAD OVER HUNTER CREEK, 0.1 MI. WEST OF SR-101 REPLACE EXISTING 2-LANE BRIDGE (TC)
# 312                                                               VARIOUS LOCATIONS THROUGHOUT THE WEST SIDE OF THE CITY. REPAIR EXISTING DAMAGED GUARDRAI
# 289  THE INTERSECTIONS OF MILITARY WEST AND WEST 5TH ST. AND HASTINGS DR. AND LONDON DR. PEDESTRIAN CROSSING IMPROVEMENTS, INCLUDING: ADA RAMPS RRFB SYSTE
# 170  INTERSECTIONS OF 65TH ST EXPWY AT 21ST AVE, 65TH ST EXPWY AT FRUITRIDGE RD, ARDEN WAY AT HERITAGE LN, ARDEN WAY AT CHALLENGE WAY, HOWE AVE. AT SWARTH
#
#                               summary
# 253                 [PLANNING, STATE]
# 178                [INSTALL, UPGRADE]
# 189                          [BRIDGE]
# 255  [BRIDGE, BRIDGE, REHABILITATION]
# 6                    [BRIDGE, BRIDGE]
# 52        [BRIDGE, SEISMIC, RETROFIT]
# 247                 [REPLACE, BRIDGE]
# 312                    [CITY, REPAIR]
# 289       [INTERSECTIONS, PEDESTRIAN]
# 170                   [INTERSECTIONS]

# %%
text>>filter(_.project_title.str.contains('COMPLETE STREET'))
# Out:
#                                                                                                                                              project_title  \
# 23   ARDEN WAY FROM ETHAN WAY TO MORSE AVENUE.  ARDEN WAY, FROM FULTON AVENUE TO MORSE AVENUE COMPLETE STREET IMPROVEMENTS INCLUDING SEPARATED SIDEWALK, C
# 29         AVE R  BETWEEN SIERRA HIGHWAY AND 25TH STREET. AVE R COMPLETE STREET WITH SIDEWALKS GAP CLOSURES, BIKE LANES, ADA RAMPS AND ENHANCED CROSSWALKS
# 99                                                                            EL CAMINO REAL (SR82) FROM ARROYO TO KAISER WAY COMPLETE STREET IMPROVEMENTS
# 129                                                               HEALDSBURG AVENUE BETWEEN POWELL AVENUE AND PASSALAQUA ROAD COMPLETE STREET IMPROVEMENTS
# 290   THE TOWNSITE DRIVE COMPLETE STREETS PROJECT IS LOCATED IN THE CITY OF VISTA ALONG THE SEGMENT OF NORTH DRIVE FROM JUST NORTHWEST OF THE INTERSECTION
#
#                   summary
# 23             [SIDEWALK]
# 29          [BIKE, LANES]
# 99                     []
# 129                    []
# 290  [CITY, INTERSECTION]

# %%
text>>filter(_.project_title.str.contains('BRIDGE REPLACEMENT'))
# Out:
#                                                                                                                                              project_title  \
# 3                                         2.2 MILES NORTH OF STATE ROUTE 20 ON WITTER SPRINGS ROAD OVER COOPER CREEK. BR.# 14C0119 BRIDGE REPLACEMENT (TC)
# 6     3/8 MI WEST OF PARAMOUNT BLVDWASHINGTON BLVD OVER RIO HONDO.LOCAL BRIDGE # 53C0471 BRIDGE REPLACEMENT  (DEMOLISH THE EXISTING 6 LANNE SUPERSTRUCTURE
# 10                                                                         ALAMITOS RD. BRIDGE @ ALAMITOS CK (37C0159) BRIDGE REPLACEMENT/SEISMIC RET (TC)
# 24                                                                            ARROYA AVENUE OVER WEST DELTA CANAL (BRIDGE 39C0275) BRIDGE REPLACEMENT (TC)
# 25                                                                          ASH CREEK ROAD AT SACRAMENTO RIVER OVERFLOW, BRIDGE 06C0233 BRIDGE REPLACEMENT
# 41                                                                    BON AIR BRIDGE (BON AIR RD OVER CORTE MADERA CREEK). BR.# 27C0028 BRIDGE REPLACEMENT
# 53                                                                                           BUCK AVENUE OVER ALAMO CREEKBR NO. 23C0011 BRIDGE REPLACEMENT
# 54                                                                                                CANYON RD @ ACID CANAL. BR. # 06C0307 BRIDGE REPLACEMENT
# 55                                                                            CASSEL FALL RIVER ROAD BRIDGE AT PIT RIVER. BR. # 06C0039 BRIDGE REPLACEMENT
# 68          CR 40 OVER CACHE CREEK, 0.12 MILES SOUTH OF SR 16 BRIDGE REPLACEMENT. REPLACE EXISTING 1 LANE BRIDGE WITH A NEW 1 LANE BRIDGE. BR#22C0091 (TC)
# 69                                                                                   CRABTREE ROAD OVER DRY CREEK (BRIDGE 38C0009) BRIDGE REPLACEMENT (TC)
# 73                                                                                   DARRAH ROAD OVER CHOWCHILLA RIVER (BRIDGE 40C0033) BRIDGE REPLACEMENT
# 74                                            DE LA GUERRA ST AT MISSION CREEK IN SANTA BARBARA BRIDGE REPLACEMENT - ENVIRONMENTAL MITIGATION & MONITORING
# 77                                                                                 DOGTOWN ROAD OVER INDIAN CREEK (BRIDGE 30C0051) BRIDGE REPLACEMENT (TC)
# 78                                                                                DOGTOWN ROAD OVER MAXWELL CREEK (BRIDGE 40C0038) BRIDGE REPLACEMENT (TC)
# 79                                                                                DOGTOWN ROAD OVER MAXWELL CREEK (BRIDGE 40C0039) BRIDGE REPLACEMENT (TC)
# 89                                                   EAST RIO BONITO RD AT SUTTER BUTTES CANAL 0.8 MI EAST OF SR99 - BR. #12C-0165 BRIDGE REPLACEMENT (TC)
# 100                                                                            ESCALON BELLOTA ROAD OVER MORMON SLOUGH (BRIDGE 29C0051) BRIDGE REPLACEMENT
# 102                                                           FERNALD PT. LN. BRIDGE #51C0137 @ ROMERO CRK IN SANTA BARBARA COUNTY BRIDGE REPLACEMENT (TC)
# 117                                                                                            FRANKLIN BLVD AT LOST SLOUGH BR# 24C0155 BRIDGE REPLACEMENT
# 121                                                     FRENCH BAR ROAD (BRIDGE 26C0035) OVER SF JACKSON CREEK, .1 MILES E/O SR 49 BRIDGE REPLACEMENT (TC)
# 123                                           GAS POINT ROAD BRIDGE (06C-0183) OVER  NO NAME DITCH, 1.9 MILES WEST OF I-5. BR.# 06C0183 BRIDGE REPLACEMENT
# 128                                                                                                           HARTNELL ROAD BRIDGE BRIDGE REPLACEMENT (TC)
# 154                                                                                              IN SONOMA COUNTY AT WATMAUGH RD BRIDGE BRIDGE REPLACEMENT
# 175                                                     IOWA CITY ROAD AT JACK SLOUGH BR. # 16C0077 ~0.3 MI. EAST OF FRUITLAND RD. BRIDGE REPLACEMENT (TC)
# 186                                                                              LOS CERRITOS ROAD OVER DRY CREEK (BRIDGE 39C0225) BRIDGE REPLACEMENT (TC)
# 187                                                       LOS VERJELES RD AT HONCUT CREEK ON THE YUBA/BUTTE COUNTY LINE. BR. # 16C0026. BRIDGE REPLACEMENT
# 189                      MATTOLE ROAD OVER MATTOLE RIVER (HONEYDEW), EAST OF WILDER RIDGE ROAD AND.MATTOLE ROAD JUNCTION BRIDGE REPLACEMENT (BR # 04C0055)
# 193                                                  MIDWAY RD @ BUTTE CREEK 3.9 MILES SOUTH OF NELSON RD. BRIDGE NO. 12C0052 & 12C0053 BRIDGE REPLACEMENT
# 196                                         MISSION BOULEVARD / BUENA VISTA AVENUE OVER THE SANTA ANA RIVER, BR. NO. 56C-0071 BRIDGE REPLACEMENT (SEISMIC)
# 197                MODJESKA CANYON ROAD OVER SANTIAGO CREEK APPROXIMATELY 0.1 MILES NORTH OF MODJESKA GRADE ROAD, BR. NO. 55C-0172 BRIDGE REPLACEMENT (TC)
# 199                                                                                           MOODY CREEK BR (06C-0060) ON CASCADE BLVD BRIDGE REPLACEMENT
# 200                                                 MOSQUITO RD OVER SOUTH FORK AMERICAN RIVER 5.7 MILES NORTH OF US 50 BR#25C0061 BRIDGE REPLACEMENT (TC)
# 201     MOUNT VERNON AVENUE OVERHEAD AT THE BURLINGTON NORTHERN SANTA FE RAILROAD YARD FROM KING STREET TO 5TH STREET, BR. NO. 54C-0066 BRIDGE REPLACEMENT
# 203                                                              NATIONAL TRAILS HIGHWAY AT DOLA DITCH NEAR CHAMBLESS, BR. NO. 54C-0285 BRIDGE REPLACEMENT
# 206                                        NORTH 1ST AVENUE OVER THE BNSF RAILROAD FROM CLARK STREET TO CROOKS AVENUE, BR. NO. 54C-0088 BRIDGE REPLACEMENT
# 212                                                                                      OAK RIDGE DRIVE AT LINDA CREEK BR#19C0180 BRIDGE REPLACEMENT (TC)
# 219                                               ON NEWTON RD OVER SOUTH FORK OF WEBER CREEK 0.7 MILES WEST OF SNOWS RD. BR.# 25C0033. BRIDGE REPLACEMENT
# 228                                                                                      ORWOOD BRIDGE (28C-0024) AT INDIAN SLOUGH BRIDGE REPLACEMENT (TC)
# 232                                                                                                PANOCHE ROAD BRIDGE #43C0027 BRIDGE REPLACEMENT PROJECT
# 235                                                              PINE HILL ROAD BRIDGE OVER SWAIN SLOUGH 04C0173 BRIDGE REPLACEMENT WITH TOLL CREDITS (TC)
# 239                                                                                   PORTOLA ROAD OVER ALEMBIQUE CREEK (BR #: 35C0055) BRIDGE REPLACEMENT
# 250                                                                           ROCK SPRINGS ROAD OVER THE MOJAVE RIVER, BR. NO. 54C-0670 BRIDGE REPLACEMENT
# 256                                              SALMON LAKE ROAD AT SALMON CREEK ~ 300 FT WEST OF GOLD LAKE HIGHWAY. BR.# 13C0053 BRIDGE REPLACEMENT (TC)
# 261                                                                                 SCHADD ROAD OVER FOREST CREEK (BRIDGE 30C0084) BRIDGE REPLACEMENT (TC)
# 262                                                                                 SEVENTH STREET OVER TUOLUMNE RIVER (BRIDGE 38C0023) BRIDGE REPLACEMENT
# 263                                             SEXTON ROAD OVER S. SAN JOAQUIN IRRIGATION DISTRICT (SSJID) CANAL (BRIDGE 29C0319) BRIDGE REPLACEMENT (TC)
# 285                                                       TEMESCAL CANYON ROAD OVER TEMESCAL WASH WEST OF LAKE STREET, BR. NO. 56C-0050 BRIDGE REPLACEMENT
# 292                                                                                  TIM BELL ROAD OVER DRY CREEK (BRIDGE 38C0073) BRIDGE REPLACEMENT (TC)
# 305  VARIOUS LOCATIONS IN THE CITY OF LARKSPUR OFFSITE WORK TO MITIGATE FOR IMPACTS FROM BON AIR BRIDGE REPLACEMENT.  MITIGATION INCLUDES RESTORATION OF T
# 321                                                                                      W MISSION BAY DRIVE/SAN DIEGO RIVER BRIDGE REPLACEMENT (57C-0023)
# 322                                                                             WARDS FERRY ROAD OVER DEER CREEK. (BRIDGE 32C0003) BRIDGE REPLACEMENT (TC)
# 323                                                                WATT AVE OVER DRY CREEK 0.4 MILES NORTH OF P.F.E. ROAD. BR.# 19C0084 BRIDGE REPLACEMENT
# 328                                                                     WIMER ROAD OVER INDIAN CREEK NORTH BRANCH (BRIDGE 29C0303) BRIDGE REPLACEMENT (TC)
#
#                                     summary
# 3                           [STATE, BRIDGE]
# 6                          [BRIDGE, BRIDGE]
# 10                         [BRIDGE, BRIDGE]
# 24                         [BRIDGE, BRIDGE]
# 25                         [BRIDGE, BRIDGE]
# 41                         [BRIDGE, BRIDGE]
# 53                                 [BRIDGE]
# 54                                 [BRIDGE]
# 55                         [BRIDGE, BRIDGE]
# 68   [BRIDGE, REPLACE, BRIDGE, NEW, BRIDGE]
# 69                         [BRIDGE, BRIDGE]
# 73                         [BRIDGE, BRIDGE]
# 74                                 [BRIDGE]
# 77                         [BRIDGE, BRIDGE]
# 78                         [BRIDGE, BRIDGE]
# 79                         [BRIDGE, BRIDGE]
# 89                                 [BRIDGE]
# 100                        [BRIDGE, BRIDGE]
# 102                [BRIDGE, COUNTY, BRIDGE]
# 117                                [BRIDGE]
# 121                        [BRIDGE, BRIDGE]
# 123                        [BRIDGE, BRIDGE]
# 128                        [BRIDGE, BRIDGE]
# 154                [COUNTY, BRIDGE, BRIDGE]
# 175                          [CITY, BRIDGE]
# 186                        [BRIDGE, BRIDGE]
# 187                        [COUNTY, BRIDGE]
# 189                                [BRIDGE]
# 193                        [BRIDGE, BRIDGE]
# 196                       [BRIDGE, SEISMIC]
# 197                                [BRIDGE]
# 199                                [BRIDGE]
# 200                                [BRIDGE]
# 201                                [BRIDGE]
# 203                                [BRIDGE]
# 206                                [BRIDGE]
# 212                                [BRIDGE]
# 219                                [BRIDGE]
# 228                        [BRIDGE, BRIDGE]
# 232                        [BRIDGE, BRIDGE]
# 235                        [BRIDGE, BRIDGE]
# 239                                [BRIDGE]
# 250                                [BRIDGE]
# 256                                [BRIDGE]
# 261                        [BRIDGE, BRIDGE]
# 262                        [BRIDGE, BRIDGE]
# 263                        [BRIDGE, BRIDGE]
# 285                                [BRIDGE]
# 292                        [BRIDGE, BRIDGE]
# 305                          [CITY, BRIDGE]
# 321                                [BRIDGE]
# 322                        [BRIDGE, BRIDGE]
# 323                                [BRIDGE]
# 328                        [BRIDGE, BRIDGE]

# %%
text>>filter(_.project_title.str.contains('WIDEN'))
# Out:
#                                                                                                                                              project_title  \
# 81    DOWNTOWN LOS ANGELES, BROADWAY BETWEEN 4TH AND 6TH STREETS PEDESTRIAN SAFETY IMPROVEMENTS INCLUDING CURB EXTENSIONS, WIDENED SIDEWALK, CROSSWALK AND
# 104  FIRST STREET BETWEEN FLOWER ST AND STANDARD AVE WIDEN EXISTING SIDEWALKS BY 3FT, NARROW VEHICLE LANES, AND CONSTRUCT ADA IMPROVEMENTS ON SIDEWALKS AN
# 156  IN STOCKTON, PARALLEL TO MARCH LANE IN THE EAST BAY MUD CORRIDOR BETWEEN BROOKSIDE ROAD AND HILLSBORO WAY. RECONSTRUCT, WIDEN AND IMPROVE EXISTING PA
# 158  IN THE CITY OF GALT ON KOST ROAD AT UNION PACIFIC RAILROAD CROSSING, WEST OF JOY DR., EAST OF MARIA WAY. WIDEN 400 FEET OF KOST RD. ON EACH SIDE OF T
# 181                                                                             LA PAZ ROAD: MUIRLANDS BLVD. TO CRISANTA DR. WIDEN TWO OVERHEADS OVER BNSF
# 194                                                                          MILLERTON ROAD FROM FRIANT ROAD TO MARINA DRIVE WIDEN ROADWAY FROM 2LU TO 4LD
# 204  NEES AVENUE FROM MINNEWAWA AVENUE TO CLOVIS AVENUE ROAD WIDENING AND RECONSTRUCTION, INSTALLATION OF CURB AND GUTTERS, SIDEWALK, BICYCLE LANES, MODIF
# 220                                        ON OLD OREGON TRAIL BETWEEN PASO ROBLES AVENUE AND BEAR MOUNTAIN ROAD WIDEN SHOULDERS AND UPGRADE DRAINAGE (TC)
# 233  PARK ROAD  FROM 250 FT SOUTH OF OAK ROAD TO BAYSHORE ROAD REHAB./RESURFACE  ROADWAY AND WIDEN ROAD TO INSTALL ASPHALT CONCRETE PAVED CLASS II/V BICYC
# 241   POWER INN ROAD FROM ELSIE AVENUE TO ABOUT 400 FEET NORTH OF MACFADDEN DRIVE. INSTALL CURB, GUTTER, SIDEWALK INFILL AND CURB RAMPS; WIDEN SUBSTANDARD
# 244                                  RAMON ROAD FROM SAN LUIS REY DRIVE TO LANDAU BOULEVARD, BR. NO. 56C-0287 REHABILITATE AND WIDEN BRIDGE AND APPROACHES
# 249  RIVERLAND DRIVE FROM KNIGHTON RD TO 2 MILES SOUTH IN THE UNINCORPORATED AREA OF SHASTA COUNTY WIDEN EXISTING ROADWAY BY PAVING SHOULDERS TO ACCOMMODA
# 280  SR-51 (CAPITAL CITY) CORRIDOR IMPROVEMENTS FROM J ST TO ARDEN WAY. WIDEN AND CONSTRUCT BUS/CARPOOL LANES, TRANSITION/AUXILIARY & NB CLASS I BIKE PATH
# 293  TULARE STREET FROM SIXTH STREET TO CEDAR AVENUE. INSTALL AND WIDEN SIDEWALKS ALONG THE SOUTH SIDE OF TULARE STREET, UPGRADE CURB RAMPS, RE-STRIPE ROA
# 296  US-395 (HESPERIA, VICTORVILLE, & ADELANTO) FROM 0.16 MI N/O INTERSTATE ROUTE 15 JUNCTION TO SR18 WIDEN FROM 2-4 LANES AND ADD LEFT TURN CHANNELIZATIO
#
#                                           summary
# 81                 [PEDESTRIAN, SAFETY, SIDEWALK]
# 104                     [WIDEN, LANES, CONSTRUCT]
# 156                                       [WIDEN]
# 158                                 [CITY, WIDEN]
# 181                                       [WIDEN]
# 194                                       [WIDEN]
# 204                             [SIDEWALK, LANES]
# 220                              [WIDEN, UPGRADE]
# 233                       [WIDEN, INSTALL, CLASS]
# 241                    [INSTALL, SIDEWALK, WIDEN]
# 244                               [WIDEN, BRIDGE]
# 249               [UNINCORPORATED, COUNTY, WIDEN]
# 280  [CITY, WIDEN, CONSTRUCT, LANES, CLASS, BIKE]
# 293                     [INSTALL, WIDEN, UPGRADE]
# 296                           [WIDEN, LANES, ADD]

# %%
type(text['summary'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### using if statement

# %%
title.sample()
# Out:
#    implementing_agency      program_code_description  \
# 59             Gardena  HIGHWAY SAFETY IMP PROG IIJA
#
#                                                                                                                                             project_title  \
# 59  CITY OF GARDENA, VERMONT AVENUE JUST NORTH OF 133RD STREET. INSTALL A PEDESTRIAN CROSSWALK WITH A PEDESTRIAN HYBRID BEACON (PHB) OR HIGH-INTENSITY AC
#
#    program_code
# 59   YS30//YS30

# %%
type_list = ['BRIDGE REPLACEMENT', 'COMPLETE STREET', 'VIDEO DETECTION EQUIPMENT', 'SYNCHRONIZE CORRIDOR', 'ROADWAY REALIGNMENTS']

# %%
text>>filter(
            _.project_title.str.contains('UPGRADE')| _.project_title.str.contains('IMPROVE')
            )
# Out:
#                                                                                                                                              project_title  \
# 0           120TH STREET FROM PRAIRIE AVENUE TO FELTON AVENUE. TRAFFIC SIGNAL UPGRADES AT NINE SIGNALIZED INTERSECTIONS AND IMPROVE CROSSINGS AND SIGNAGE.
# 4    21 INTERSECTIONS; ON ALAMO DRIVE FROM MERCHANT STREET TO NUT TREE ROAD AND ON PEABODY ROAD FROM ELMIRA ROAD TO FOXBORO PARKWAY IMPROVE SIGNAL HARDWAR
# 5                                                                          21 LOCATIONS IN CITY OF BENICIA UPGRADE EXISTING GUARDRAILS AND END TREATMENTS.
# 20                                                                               AMERICAN AVENUE FROM MADERA AVENUE TO PLACER AVENUE SHOULDER IMPROVEMENTS
# 22   APPIAN WAY AND MARLESTA ROAD INTERSECTION SAFETY IMPROVEMENTS: INSTALLATION OF A TRAFFIC SIGNAL AND TRAFFIC SIGNAGE, INCLUDING ADVANCED WARNING SIGNS
# 23   ARDEN WAY FROM ETHAN WAY TO MORSE AVENUE.  ARDEN WAY, FROM FULTON AVENUE TO MORSE AVENUE COMPLETE STREET IMPROVEMENTS INCLUDING SEPARATED SIDEWALK, C
# 26                                                                   AT MAX FOSTER SPORTS COMPLEX AREA IN LIVINGSTON CONSTRUCT MULTI-USE PATH IMPROVEMENTS
# 81    DOWNTOWN LOS ANGELES, BROADWAY BETWEEN 4TH AND 6TH STREETS PEDESTRIAN SAFETY IMPROVEMENTS INCLUDING CURB EXTENSIONS, WIDENED SIDEWALK, CROSSWALK AND
# 85                                                        E. 20TH STREET FROM THE MALL TO THE END OF BUSINESS LANE (ADJACENT TO SR99) BIKEWAY IMPROVEMENTS
# 99                                                                            EL CAMINO REAL (SR82) FROM ARROYO TO KAISER WAY COMPLETE STREET IMPROVEMENTS
# 104  FIRST STREET BETWEEN FLOWER ST AND STANDARD AVE WIDEN EXISTING SIDEWALKS BY 3FT, NARROW VEHICLE LANES, AND CONSTRUCT ADA IMPROVEMENTS ON SIDEWALKS AN
# 116                                                                        FOWLER AVE & OLIVE AVE INTERSECTION TRAFFIC SIGNAL AND ROADWAY IMPROVEMENTS(TC)
# 129                                                               HEALDSBURG AVENUE BETWEEN POWELL AVENUE AND PASSALAQUA ROAD COMPLETE STREET IMPROVEMENTS
# 137  IN AND NEAR GRIDLEY, FROM HOLLIS LANE TO NORTH OF FORD AVENUE. DIST-CO-RTE: 03-BUT-99 PM/PM: R3.1/5.0 REHABILITATE PAVEMENT, UPGRADE TRANSPORTATION M
# 143  IN ELK GROVE ON GRANT LINE ROAD FROM SHERMAN OAKS CT. TO ALEILANI LANE. INTERSECTION OPERATIONAL IMPROVEMENTS IN THE FORM OF EITHER SIGNAL MODIFICATI
# 144                                      IN FRANKLIN/BEACHWOOD ON BEACHWOOD DRIVE BETWEEN DAN WARD ROAD AND CABOT AVENUE CONSTRUCT PEDESTRIAN IMPROVEMENTS
# 148                                                 IN MERCED ON MOTEL DRIVE BETWEEN CAROL AVENUE AND MERCED AVENUE CONSTRUCT PEDESTRIAN/BIKE IMPROVEMENTS
# 156  IN STOCKTON, PARALLEL TO MARCH LANE IN THE EAST BAY MUD CORRIDOR BETWEEN BROOKSIDE ROAD AND HILLSBORO WAY. RECONSTRUCT, WIDEN AND IMPROVE EXISTING PA
# 159    IN THE CITY OF GALT ON WALNUT AVE, FROM CARILLION TO ELK HILLS DR. OVERLAY THE STREET AND UPGRADE THE BIKE LANES TO HIGH-VISIBILITY GREEN STANDARD.
# 172  INTERSECTIONS OF EL DORADO STREET AND ROBINHOOD DRIVE, EL DORADO STREET AND BENJAMIN HOLT DRIVE, AND MARCH LANE AND MCGAW STREET. UPGRADE TRAFFIC SIG
# 178                         JENSEN AVE. FROM ELM AVENUE TO TEMPERANCE AVENUE INSTALL ITS ADAPTIVE SYSTEM, UPGRADE DETECTION AND SYNCHRONIZE CORRIDOR. (TC)
# 179                                                                                   JENSEN AVENUE FROM DICKERSEN TO MADERA AVENUES SHOULDER IMPROVEMENTS
# 192                                                                                        MICHIGAN AVE. BETWEEN 19TH & 20TH STREET BIKE PATH IMPROVEMENTS
# 198                                                                 MONTEREY ROAD FROM COTTLE ROAD TO METCALF ROAD UPGRADE GUARDRAILS TO CURRENT STANDARDS
# 218  ON MCKEE ROAD BETWEEN ROUTE 101 AND TOYON AVENUE IMPLEMENT SAFETY IMPROVEMENTS INCLUDING MEDIAN ISLANDS, ADA CURB RAMP, SPEED RADAR SIGN, ENHANCED CR
# 220                                        ON OLD OREGON TRAIL BETWEEN PASO ROBLES AVENUE AND BEAR MOUNTAIN ROAD WIDEN SHOULDERS AND UPGRADE DRAINAGE (TC)
# 238  PORTIONS OF LAKE ISABELLA BOULEVARD AND ERSKINE CREEK ROAD CONSTRUCT BICYCLE AND PEDESTRIAN IMPROVEMENTS; BIKE BATH, BIKE LANES, CURB RAMPS AND SIDEW
# 251  ROOSEVELT AVENUE, EL CAMINO REAL TO ALAMEDA DE LAS PULGAS, REDWOOD CITY, CA THE CITY OF REDWOOD CITY PROPOSES INSTALLATION OF QUICK-BUILD IMPROVEMENT
# 260  SANTA ROSA IN DOWNTOWN AND RAILROAD SQUARE: UPGRADE THE EXISTING TRAFFIC SIGNAL INTERCONNECT INFRASTRUCTURE FROM COPPER WIRING MEDIA TO A FIBER OPTIC
# 267            SILVERADO TRAIL FROM TRANCAS STREET INTERSECTION (MM 0.0)  TO 11 MILES NORTH (MM 11.0) UPGRADE EXISTING GUARDRAIL TO MEET CURRENT STANDARDS
# 275   SOUTHWORTH RD, GOLD STRIKE RD, POOL STATION RD, GARABALDI ST, MURPHYS GRADE RD, COPPER COVE DR, AND  O'BYRNES FERRY RD. UPGRADE EXISTING GUARDRAILS,
# 278  SR 99/TURNER ROAD INTERCHANGE OPERATIONAL IMPROVEMENTS (IN LODI, AT THE SR99/TURNER ROAD INTERSECTION. REALIGN THE EXISTING SOUTHBOUND OFF- AND ONRAM
# 280  SR-51 (CAPITAL CITY) CORRIDOR IMPROVEMENTS FROM J ST TO ARDEN WAY. WIDEN AND CONSTRUCT BUS/CARPOOL LANES, TRANSITION/AUXILIARY & NB CLASS I BIKE PATH
# 282  STATE ROUTE 55 FROM INTERSTATE 5 TO STATE ROUTE 91 ADD A MIXED-FLOW LANE IN EACH DIRECTION AND FIX CHOKEPOINTS FROM I-5 TO SR-22 AND OTHER IMPROVEMEN
# 286                                             TESLA ROAD BETWEEN EAGLES RUN ROAD AND MCLAUGHLIN ROAD. GUARDRAIL UPGRADES AT 13 LOCATIONS ALONG TESLA RD.
# 288  THE INTERSECTION OF WICKS BLVD AND MANOR BLVD. INSTALL SOUTHBOUND AND NORTHBOUND LEFT-TURN SIGNALS; UPGRADE SIGNAL HEADS AND SIGNAL EQUIPMENT; INSTAL
# 289  THE INTERSECTIONS OF MILITARY WEST AND WEST 5TH ST. AND HASTINGS DR. AND LONDON DR. PEDESTRIAN CROSSING IMPROVEMENTS, INCLUDING: ADA RAMPS RRFB SYSTE
# 291          THIRD STREET AT THE THE INTERSECTIONS OF LINDARO STREET, LINCOLN AVENUE, TAMALPAIS AVENUE, IRWIN STREET AND GRAND AVENUE. SAFETY IMPROVEMENTS
# 293  TULARE STREET FROM SIXTH STREET TO CEDAR AVENUE. INSTALL AND WIDEN SIDEWALKS ALONG THE SOUTH SIDE OF TULARE STREET, UPGRADE CURB RAMPS, RE-STRIPE ROA
# 294    TWO HUNDRED AND TWENTY-FOUR (224) SIGNALIZED INTERSECTIONS ON VARIOUS ARTERIALS WITHININ THE CITY OF SAN BERNARDINO UPGRADE TRAFFIC SIGNAL HARDWARE
# 303        VARIOUS LOCATION IN THE CITY OF CONCORD (52 INTERSECTIONS) IMPROVE SIGNAL HARDWARE, UPGRADE CABINET EQUIPMENT, CONTROLLERS, AND MODIFY PHASING.
# 308  VARIOUS LOCATIONS THROUGHOUT THE CITY OF JURUPA VALLEY UPGRADE EXISTING METAL GUARDRAILS TO CURRENT CALTRANS MIDWEST GUARDRAIL SYSTEM (MGS) STANDARDS
# 315   VARIOUS ROAD CORRIDORS IN WESTERN NEVADA COUNTY. CONDUCT GUARDRAIL SAFETY AUDIT, IDENTIFY DEFICIENCIES, AND REPAIR OR UPGRADE GUARDRAIL AS NECESSARY
#
#                                                        summary
# 0                    [TRAFFIC, SIGNAL, INTERSECTIONS, SIGNAGE]
# 4                                      [INTERSECTIONS, SIGNAL]
# 5                                              [CITY, UPGRADE]
# 20                                                          []
# 22   [INTERSECTION, SAFETY, TRAFFIC, SIGNAL, TRAFFIC, SIGNAGE]
# 23                                                  [SIDEWALK]
# 26                                                 [CONSTRUCT]
# 81                              [PEDESTRIAN, SAFETY, SIDEWALK]
# 85                                                          []
# 99                                                          []
# 104                                  [WIDEN, LANES, CONSTRUCT]
# 116                            [INTERSECTION, TRAFFIC, SIGNAL]
# 129                                                         []
# 137                                                  [UPGRADE]
# 143                                     [INTERSECTION, SIGNAL]
# 144                                    [CONSTRUCT, PEDESTRIAN]
# 148                                                [CONSTRUCT]
# 156                                                    [WIDEN]
# 159                               [CITY, UPGRADE, BIKE, LANES]
# 172                          [INTERSECTIONS, UPGRADE, TRAFFIC]
# 178                                         [INSTALL, UPGRADE]
# 179                                                         []
# 192                                                     [BIKE]
# 198                                                  [UPGRADE]
# 218                                                   [SAFETY]
# 220                                           [WIDEN, UPGRADE]
# 238                 [CONSTRUCT, PEDESTRIAN, BIKE, BIKE, LANES]
# 251                            [CITY, CITY, CITY, IMPROVEMENT]
# 260                                 [UPGRADE, TRAFFIC, SIGNAL]
# 267                                    [INTERSECTION, UPGRADE]
# 275                                                  [UPGRADE]
# 278                                             [INTERSECTION]
# 280               [CITY, WIDEN, CONSTRUCT, LANES, CLASS, BIKE]
# 282                                        [STATE, STATE, ADD]
# 286                                                         []
# 288  [INTERSECTION, INSTALL, SIGNALS, UPGRADE, SIGNAL, SIGNAL]
# 289                                [INTERSECTIONS, PEDESTRIAN]
# 291                                    [INTERSECTIONS, SAFETY]
# 293                                  [INSTALL, WIDEN, UPGRADE]
# 294            [INTERSECTIONS, CITY, UPGRADE, TRAFFIC, SIGNAL]
# 303                     [CITY, INTERSECTIONS, SIGNAL, UPGRADE]
# 308                                            [CITY, UPGRADE]
# 315                          [COUNTY, SAFETY, REPAIR, UPGRADE]

# %%
text.sample(10)
# Out:
#                                                                                                                                              project_title  \
# 316   VARIOUS ROAD SEGMENTS THROUGHOUT CALAVERAS COUNTY (EXCLUDING STATE ROUTES AND THE CITY OF ANGELS CAMP) CONDUCT A ROADWAY SAFETY SIGNAGE AUDIT (RSSA)
# 228                                                                                      ORWOOD BRIDGE (28C-0024) AT INDIAN SLOUGH BRIDGE REPLACEMENT (TC)
# 2         16 LOCATIONS IN THE CITY OF FAIRFIELD INSTALL ADAPTIVE SIGNAL TIMING AND ADVANCED DILEMMA-ZONE DETECTION, AND ENHANCE THE VISIBILITY OF SIGNALS.
# 276                                  SPERRY AVENUE FROM AMERICAN EAGLE AVENUE TO WARD AVENUE. ROAD REHABILITATION / RECONSTRUCTION WITH DIG OUTS AS NEEDED
# 289  THE INTERSECTIONS OF MILITARY WEST AND WEST 5TH ST. AND HASTINGS DR. AND LONDON DR. PEDESTRIAN CROSSING IMPROVEMENTS, INCLUDING: ADA RAMPS RRFB SYSTE
# 218  ON MCKEE ROAD BETWEEN ROUTE 101 AND TOYON AVENUE IMPLEMENT SAFETY IMPROVEMENTS INCLUDING MEDIAN ISLANDS, ADA CURB RAMP, SPEED RADAR SIGN, ENHANCED CR
# 4    21 INTERSECTIONS; ON ALAMO DRIVE FROM MERCHANT STREET TO NUT TREE ROAD AND ON PEABODY ROAD FROM ELMIRA ROAD TO FOXBORO PARKWAY IMPROVE SIGNAL HARDWAR
# 329                                                                  WOODLAKE AT THE INTERSECTION OF SIERRA AVE AND CASTLE ROCK STREET NEW ROUNDABOUT (TC)
# 300  VARIOUS  LOCAL STREETS WITHIN THE CITY OF LOS ANGELES TO RE-SURFACE  LOCAL STREETS OF APPROXIMATELY 45 MILE IN TOTAL LENGTH  AND CONSTRUCT ACCESS RAM
# 103                                                      FIFTEEN (15) SIGNALIZED INTERSECTIONS THROUGHOUT THE CITY INSTALL ADVANCED DILEMMA ZONE DETECTION
#
#                                     summary
# 316  [COUNTY, STATE, CITY, SAFETY, SIGNAGE]
# 228                        [BRIDGE, BRIDGE]
# 2          [CITY, INSTALL, SIGNAL, SIGNALS]
# 276                        [REHABILITATION]
# 289             [INTERSECTIONS, PEDESTRIAN]
# 218                                [SAFETY]
# 4                   [INTERSECTIONS, SIGNAL]
# 329                     [INTERSECTION, NEW]
# 300                       [CITY, CONSTRUCT]
# 103          [INTERSECTIONS, CITY, INSTALL]

# %% [markdown]
# ### Function for getting project types using np.where
# (str format)

# %%
#using subset of full data
proj_sub = proj_all>>select(_.implementing_agency,
                            _.program_code_description,
                            _.project_title,
                            _.program_code,
                            _.improvement_type_description)

# %%
proj_sub.sample()
# Out:
#                        implementing_agency   program_code_description  \
# 37  Metropolitan Transportation Commission  STBG-URBANIZED >200K IIJA
#
#                                                                                                                                       project_title  \
# 37  BAY AREA REGIONAL: REGIONAL PLANNING ACTIVITIES AND PLANNING, PROGRAMMING AND MONITORING (PPM). PRIOR YEAR FUNDING PROGRAMMED ON REG170001 (TC)
#
#         program_code improvement_type_description
# 37  Y230//Y230//Y230          Other//Other//Other

# %%
#sample of function
((utils.add_description(proj_sub, 'project_title'))).head(10)
# Out:
#   implementing_agency      program_code_description  \
# 0           Hawthorne  HIGHWAY SAFETY IMP PROG IIJA
# 1             Yucaipa    NATIONAL HIGHWAY PERF IIJA
# 2           Fairfield  HIGHWAY SAFETY IMP PROG IIJA
# 3         Lake County   STBG IIJA OFF-SYSTEM BRIDGE
# 4           Vacaville  HIGHWAY SAFETY IMP PROG IIJA
# 5             Benicia  HIGHWAY SAFETY IMP PROG IIJA
# 6         Pico Rivera    NATIONAL HIGHWAY PERF IIJA
# 7        Marin County     STBG-URBANIZED >200K IIJA
# 8        Marin County  HIGHWAY SAFETY IMP PROG IIJA
# 9           Los Banos    CONGESTION MITIGATION IIJA
#
#                                                                                                                                            project_title  \
# 0         120TH STREET FROM PRAIRIE AVENUE TO FELTON AVENUE. TRAFFIC SIGNAL UPGRADES AT NINE SIGNALIZED INTERSECTIONS AND IMPROVE CROSSINGS AND SIGNAGE.
# 1                         13TH STREET OVER WILSON CREEK FROM OAK GLEN ROAD TO KENTUCKY STREET, LWC 00L0017 REPLACE LOW WATER CROSSING WITH 2-LANE BRIDGE
# 2       16 LOCATIONS IN THE CITY OF FAIRFIELD INSTALL ADAPTIVE SIGNAL TIMING AND ADVANCED DILEMMA-ZONE DETECTION, AND ENHANCE THE VISIBILITY OF SIGNALS.
# 3                                       2.2 MILES NORTH OF STATE ROUTE 20 ON WITTER SPRINGS ROAD OVER COOPER CREEK. BR.# 14C0119 BRIDGE REPLACEMENT (TC)
# 4  21 INTERSECTIONS; ON ALAMO DRIVE FROM MERCHANT STREET TO NUT TREE ROAD AND ON PEABODY ROAD FROM ELMIRA ROAD TO FOXBORO PARKWAY IMPROVE SIGNAL HARDWAR
# 5                                                                        21 LOCATIONS IN CITY OF BENICIA UPGRADE EXISTING GUARDRAILS AND END TREATMENTS.
# 6   3/8 MI WEST OF PARAMOUNT BLVDWASHINGTON BLVD OVER RIO HONDO.LOCAL BRIDGE # 53C0471 BRIDGE REPLACEMENT  (DEMOLISH THE EXISTING 6 LANNE SUPERSTRUCTURE
# 7  4 AT TERNERS DRIVE @ DRIVEWAY ENTRANCES TO MULTI-FAMILY HOUSING CLOSEST TO DONAHUE, 4 AT TERNERS DRIVE @ TERRACE WAY, 4 AT TERNERS DRIVE @ TERRACE DR
# 8  59 TRAFFIC SIGNAL COUNTYWIDE.  JURISDICTIONS INCLUDE CORTE MADERA, FAIRFAX, MILL VALLEY, NOVATO, SAN ANSELMO, SAN RAFAEL, SAUSALITO, MARIN COUNTY, LA
# 9               5-MILES STRETCH OF SR-152 SYNCHRONIZATION OF 14 TRAFFIC SIGNALS ON A FIVE MILE STRETCH OF SR-152 WITH INSTALLATION OF CCTV CAMERAS. (TC)
#
#              program_code  \
# 0              YS30//YS30
# 1                    Y001
# 2              YS30//YS30
# 3  Y233//Y233//Y233//Y233
# 4              YS30//YS30
# 5              YS30//YS30
# 6                    Y001
# 7                    Y230
# 8              YS30//YS30
# 9              Y400//Y400
#
#                                                                               improvement_type_description  \
# 0                                                                         Construction Engineering//Safety
# 1                                                                                                    Other
# 2                                                                         Construction Engineering//Safety
# 3  Bridge Replacement - No Added Capacity//Preliminary Engineering//Right of Way//Construction Engineering
# 4                                                                         Construction Engineering//Safety
# 5                                                                         Construction Engineering//Safety
# 6                                                                                  Preliminary Engineering
# 7                                                                                  Preliminary Engineering
# 8                                                                         Construction Engineering//Safety
# 9                                           Construction Engineering//Traffic Management/Engineering - HOV
#
#   project_method     project_type           other
# 0        Upgrade  Traffic Signals  Other Projects
# 1        Replace           Bridge  Other Projects
# 2        Install          Signals  Other Projects
# 3        Replace           Bridge  Other Projects
# 4        Improve          Signals  Other Projects
# 5        Upgrade       Guardrails  Other Projects
# 6        Replace           Bridge  Other Projects
# 7                         Project  Other Projects
# 8                 Traffic Signals  Other Projects
# 9        Install  Traffic Signals  Other Projects

# %%
#how many entries with no tags
len((utils.add_description(proj_sub, 'project_title'))>>filter(_.project_type==('Project')))
# Out:
# 97

# %%
#entries with no tag
((utils.add_description(proj_sub, 'project_title'))>>filter(_.project_type==('Project'))>>arrange(-_.project_method)).head(40)
# Out:
#                             implementing_agency  \
# 34                                       Colton
# 269                                 Los Angeles
# 281      Orange County Transportation Authority
# 93                                       Fresno
# 213                                     Oakland
# 19                                   Sacramento
# 15                                Fresno County
# 17                                     Stockton
# 96                                    La Puente
# 108                                  Sacramento
# 165                                     Modesto
# 233                                     Benicia
# 251                                Redwood City
# 320                                      Clovis
# 278                                        Lodi
# 282      Orange County Transportation Authority
# 16                                    Santa Ana
# 26                                   Livingston
# 36                                       Rialto
# 65                                  Bakersfield
# 90                             El Dorado County
# 118                                     Fremont
# 139                              Citrus Heights
# 146                                  Livingston
# 150                                    Caltrans
# 156                                    Stockton
# 185                                  South Gate
# 208                                      Merced
# 216                                  South Gate
# 252                                    Caltrans
# 276                                   Patterson
# 283  Riverside County Transportation Commission
# 297                                      Folsom
# 300                                 Los Angeles
# 7                                  Marin County
# 18                                     Caltrans
# 32                                     Palmdale
# 35                                      Visalia
# 37       Metropolitan Transportation Commission
# 38                                   Sacramento
#
#            program_code_description  \
# 34       NATIONAL HIGHWAY PERF IIJA
# 269      NATIONAL HIGHWAY PERF IIJA
# 281       STBG-URBANIZED >200K IIJA
# 93    TRANSP ALTERNATIVES FLEX IIJA
# 213   TRANS ALTERNATIVES >200K IIJA
# 19       CONGESTION MITIGATION IIJA
# 15    TRANS ALTERNATIVES >200K IIJA
# 17     HIGHWAY SAFETY IMP PROG IIJA
# 96     HIGHWAY SAFETY IMP PROG IIJA
# 108       STBG-URBANIZED >200K IIJA
# 165      CONGESTION MITIGATION IIJA
# 233  PROJ TO REDUCE PM 2.5 EMI IIJA
# 251  SURFAC TRNSP BLK GRTS-FLX IIJA
# 320       STBG-URBANIZED >200K IIJA
# 278       STBG-URBANIZED >200K IIJA
# 282       STBG-URBANIZED >200K IIJA
# 16    TRANS ALTERNATIVES >200K IIJA
# 26       CONGESTION MITIGATION IIJA
# 36     HIGHWAY SAFETY IMP PROG IIJA
# 65       CONGESTION MITIGATION IIJA
# 90        STBG-URBANIZED >200K IIJA
# 118  SURFAC TRNSP BLK GRTS-FLX IIJA
# 139      CONGESTION MITIGATION IIJA
# 146  PROJ TO REDUCE PM 2.5 EMI IIJA
# 150       STBG-URBANIZED >200K IIJA
# 156   TRANS ALTERNATIVES >200K IIJA
# 185    HIGHWAY SAFETY IMP PROG IIJA
# 208      CONGESTION MITIGATION IIJA
# 216    HIGHWAY SAFETY IMP PROG IIJA
# 252      CONGESTION MITIGATION IIJA
# 276  SURFAC TRNSP BLK GRTS-FLX IIJA
# 283       STBG-URBANIZED >200K IIJA
# 297       STBG-URBANIZED >200K IIJA
# 300       STBG-URBANIZED >200K IIJA
# 7         STBG-URBANIZED >200K IIJA
# 18        STBG-URBANIZED >200K IIJA
# 32     HIGHWAY SAFETY IMP PROG IIJA
# 35        STBG-URBANIZED >200K IIJA
# 37        STBG-URBANIZED >200K IIJA
# 38        STBG-URBANIZED >200K IIJA
#
#                                                                                                                                              project_title  \
# 34   BARTON ROAD OVERHEAD AT UNION PACIFIC RAILROAD, 0.25 MILE WEST OF I-215, BR. NO. 54C-0379 REPLACE OVERHEAD WITH TWO-LANE ROAD ACROSS DISCONTINUED RAI
# 269                                 SIXTH STREET VIADUCT OVER LA RIVER AND EAST SANTA ANNA FREEWAY, 53C1880 REPLACE STRUCT DEFICIENT VIADUCT WITH NEW (TC)
# 281            STATE ROUTE 55 FROM INTERSTATE 405 TO INTERSTATE 5 ADD ONE MIXED-FLOW AND HIGH-OCCUPANCY LANE IN EACH DIRECTION AND REPAIR CHOKEPOINTS (TC)
# 93   EASTBOUND MCKINLEY FROM MILLBROOK AVENUE TO CLOVIS AVENUE ALONG THE NORTH BANK OF THE MILL DITCH CANAL. PAVED PATH, LIGHTING, BENCHES,FENCING, IRRIGA
# 213  OAKLAND - 14TH STREET SAFE ROUTES IN THE CITY. ON 14TH ST BETWEEN BRUSH ST AND OAK ST REDUCE TRAVEL LANES FROM 4 TO 2, ADD PAVED CLASS IV PROTECTED B
# 19   ALONG UNUSED RAIL CORRIDOR NEAR FREEPORT BLVD FROM SUTTERVILLE ROAD TO SOUTH OF MEADOWVIEW/POCKET ROAD (4.5 MILES) RAILS TO TRAILS PROJECT ; NEW CLAS
# 15   ALONG GROVE AVENUE FROM PROSPECT AVENUE TO VALENTINE AVENUE, AND ALONG VALENTINE AVENUE FROM GROVE AVENUE TO NORTH AVENUE INSTALL AN ASPHALT CONCRETE
# 17                                                           ALONG PACIFIC AVE. FROM CALAVERAS RIVER TRAIL TO WEST HAMMER LANE. INSTALL RAISED MEDIAN CURB
# 96   EIGHT (8) CROSSWALK LOCATIONS THROUGHOUT THE CITY OF LA PUENTE. INSTALL RECTANGULAR RAPID FLASHING BEACONS (RRFBS), CURB EXTENSIONS, ADVANCED PAVEMEN
# 108  FLORIN ROAD BETWEEN GREENHAVEN DRIVE AND LUTHER DRIVE. CONVERT FROM PEDESTAL MOUNTED TO MAST ARMS AT 7 INTERSECTIONS; INSTALL ADVANCED DETECTION AT F
# 165   INTERSECTION OF PELANDALE AVENUE AND SR 99 IN MODESTO, CA TO INSTALL A SECOND LEFT TURN LANE FROM EASTBOUND PELANDALE AVENUE TO NORTHBOUND SISK ROAD
# 233  PARK ROAD  FROM 250 FT SOUTH OF OAK ROAD TO BAYSHORE ROAD REHAB./RESURFACE  ROADWAY AND WIDEN ROAD TO INSTALL ASPHALT CONCRETE PAVED CLASS II/V BICYC
# 251  ROOSEVELT AVENUE, EL CAMINO REAL TO ALAMEDA DE LAS PULGAS, REDWOOD CITY, CA THE CITY OF REDWOOD CITY PROPOSES INSTALLATION OF QUICK-BUILD IMPROVEMENT
# 320  VILLA AVENUE BETWEEN BULLARD AVENUE AND BARSTOW AVENUE ROAD REHABILITATION INCLUDING GRINDING, PAVING, CONCRETE, INSTALLING TRAFFIC DEVICES AND RESTR
# 278  SR 99/TURNER ROAD INTERCHANGE OPERATIONAL IMPROVEMENTS (IN LODI, AT THE SR99/TURNER ROAD INTERSECTION. REALIGN THE EXISTING SOUTHBOUND OFF- AND ONRAM
# 282  STATE ROUTE 55 FROM INTERSTATE 5 TO STATE ROUTE 91 ADD A MIXED-FLOW LANE IN EACH DIRECTION AND FIX CHOKEPOINTS FROM I-5 TO SR-22 AND OTHER IMPROVEMEN
# 16   ALONG NEIGHBORHOOD STREETS ADJACENT TO DAVIS ELEMENTARY SCHOOL FROM 14TH STREET TO 15TH STREET. CONSTRUCT BULB-OUT AT CROSSINGS NEAR DAVIS ELEMENTARY
# 26                                                                   AT MAX FOSTER SPORTS COMPLEX AREA IN LIVINGSTON CONSTRUCT MULTI-USE PATH IMPROVEMENTS
# 36                                                BASELINE ROAD - WILLOW AVENUE TO MERIDIAN AVENUE CONSTRUCT A 12' WIDE RAISED CENTER MEDIAN AND ADA RAMP.
# 65   CONSTRUCT A MULTI-USE PATH (6 MILES) ALONG THE FRIANT-KERN CANAL IN BAKERSFIELD: BOUNDED BY 7TH STANDARD ROAD AND KERN RIVER PARKWAY. CONSTRUCT CLASS
# 90   EAST SAN BERNARDINO AVE FROM WEST OF UPPER TRUCKEE RIVER TO TAHOE PARADISE PARK IN THE COMMUNITY OF MYERS CONSTRUCT APPROXIMATELY 0.37 MILES OF CLASS
# 118                                                                     FREMONT BLVD. / GRIMMER AND FREMONT BLVD./EUGENE CONSTRUCT PROTECTED INTERSECTIONS
# 139                           IN CITRUS HEIGHTS, BETWEEN ARCADE CREEK PARK PRESERVE AND WACHTEL WAY. CONSTRUCT A 2.9 MILE LONG CLASS 1 MULTI-USE TRAIL. TC
# 146  IN LIVINGSTON, CONSTRUCT PHASE 2 MAX FOSTER MULTIUSE PATH (ALONG DWIGHT WAY, BETWEEN NORTH TRIGGER LN & TEHAMA DR,) CONSTRUCT A CONCRETE MULTIUSE PAT
# 150  IN ROCKLIN: BETWEEN SR-65 (PM 4.1) AND ROCKLIN RD. (PM 6.0); CONSTRUCT I-80 EASTBOUND AUXILIARY LANE, INCLUDING TWO-LANE OFF-RAMP. IN ROSEVILLE:  BET
# 156  IN STOCKTON, PARALLEL TO MARCH LANE IN THE EAST BAY MUD CORRIDOR BETWEEN BROOKSIDE ROAD AND HILLSBORO WAY. RECONSTRUCT, WIDEN AND IMPROVE EXISTING PA
# 185                                                                          LONG BEACH BLVD. FROM SANTA ANA ST. TO TWEEDY BLVD. CONSTRUCT RAISED MEDIANS.
# 208  NORTH SIDE OF CHILDS AVE (FROM GOLDEN VALLEY HIGH SCHOOL TO COFFEE ST. (WEAVER MIDDLE SCHOOL)). CONSTRUCT A CLASS I (FULLY-SEPARATED). "SAFE ROUTES T
# 216                                         ON GARFIELD AVE. BETWEEN SOUTHERN AVE. AND HOWERY ST. IN THE CITY OF SOUTH GATE CONSTRUCT RAISED CENTER MEDIAN
# 252                                                                        RT. 10 : FROM CITRUS AVE. TO RT. 57 CONSTRUCT HOV LANE IN BOTH DIRECTIONS. (TC)
# 276                                  SPERRY AVENUE FROM AMERICAN EAGLE AVENUE TO WARD AVENUE. ROAD REHABILITATION / RECONSTRUCTION WITH DIG OUTS AS NEEDED
# 283                                                                                STATE ROUTE 71/91 INTERCHANGE REPLACE CONNECTOR & RECONSTRUCT RAMP (TC)
# 297                                                                                           US-50 AT EMPIRE RANCH ROAD CONSTRUCT 4 LANE INTERCHANGE (TC)
# 300  VARIOUS  LOCAL STREETS WITHIN THE CITY OF LOS ANGELES TO RE-SURFACE  LOCAL STREETS OF APPROXIMATELY 45 MILE IN TOTAL LENGTH  AND CONSTRUCT ACCESS RAM
# 7    4 AT TERNERS DRIVE @ DRIVEWAY ENTRANCES TO MULTI-FAMILY HOUSING CLOSEST TO DONAHUE, 4 AT TERNERS DRIVE @ TERRACE WAY, 4 AT TERNERS DRIVE @ TERRACE DR
# 18   ALONG THE I-880 CORRIDOR SF BAY AREA: REGIONWIDE: IMPLEMENT A COLLECTIVE APPROACH TO FREEWAY OPERATIONS AND MANAGEMENT, INCLUDING COMMUNICATIONS NETW
# 32     AVENUE S-8 AND 40TH STREET EAST. CONVERT AN EXISTING FOUR WAY STOP TO A ROUDABOUT AT THE INTERSECTION OF AVENUE S-8 AND 40TH STREET EAST..   ORIGIO
# 35   BASE BID: GOSHEN AVE FROM EAST OF SHIRK ST. TO WEST OF AKERS ALTERNATE BID NO. 1: GOSHEN AVE FROM AKERS TO WEST OF DEMAREE ALTERNATE BID NO. 2: GOSHE
# 37         BAY AREA REGIONAL: REGIONAL PLANNING ACTIVITIES AND PLANNING, PROGRAMMING AND MONITORING (PPM). PRIOR YEAR FUNDING PROGRAMMED ON REG170001 (TC)
# 38                                                                                 BELL AVE. FROM BOLLENBACHER AVE. TO ASTORIA ST ROAD REHABILITATION (TC)
#
#                                                    program_code  \
# 34                                                   Y001//Y001
# 269                                                        Y001
# 281                                            Y230//Y230//Y400
# 93                                                   Y300//Y300
# 213                                                        Y301
# 19                                                         Y400
# 15                                                   Y301//Y301
# 17                                                         YS30
# 96                                                         YS30
# 108                                Y230//Y230//Y240//YS30//YS30
# 165                                                        Y400
# 233                                            Y003//Y240//Y240
# 251                                                        Y240
# 320                                                        Y230
# 278                                                        Y230
# 282                                                  Y230//Y230
# 16                                                         Y301
# 26                                                   Y400//Y400
# 36                                                   YS30//YS30
# 65                                                         Y400
# 90                                       Y230//Y230//Y400//Y400
# 118                                                  Y240//Y240
# 139                                                        Y400
# 146                                                  Y003//Y003
# 150                                                        Y230
# 156                                                        Y301
# 185                                                  YS30//YS30
# 208                                                        Y400
# 216                                                  YS30//YS30
# 252                          Y400//Y400//Y400//Y400//Y400//Y400
# 276                                                        Y240
# 283                                                        Y230
# 297                                                        Y230
# 300  Y230//Y230//Y230//Y230//Y230//Y230//Y230//Y230//Y230//Y230
# 7                                                          Y230
# 18                                                         Y230
# 32                                                   YS30//YS30
# 35                                                   Y230//Y230
# 37                                             Y230//Y230//Y230
# 38                                                   Y230//Y230
#
#                                                                                                                                                                                                                                                                                              improvement_type_description  \
# 34                                                                                                                                                                                                                                                                                  Preliminary Engineering//Right of Way
# 269                                                                                                                                                                                                                                                                                                          Right of Way
# 281                                                                                                                                                                                                                                                                                 Right of Way//Utilities//Right of Way
# 93                                                                                                                                                                                                                                                      Construction Engineering//Facilities for Pedestrians and Bicycles
# 213                                                                                                                                                                                                                                                                               Facilities for Pedestrians and Bicycles
# 19                                                                                                                                                                                                                                                                                Facilities for Pedestrians and Bicycles
# 15                                                                                                                                                                                                                                                      Construction Engineering//Facilities for Pedestrians and Bicycles
# 17                                                                                                                                                                                                                                                                                                                 Safety
# 96                                                                                                                                                                                                                                                                                                                 Safety
# 108                                                                                                                                                                                                            4R - No Added Capacity//Construction Engineering//4R - No Added Capacity//Construction Engineering//Safety
# 165                                                                                                                                                                                                                                                                                                   4R - Added Capacity
# 233                                                                                                                                                                                                                        4R - Restoration & Rehabilitation//4R - Restoration & Rehabilitation//Construction Engineering
# 251                                                                                                                                                                                                                                                                               Facilities for Pedestrians and Bicycles
# 320                                                                                                                                                                                                                                                                                     4R - Restoration & Rehabilitation
# 278                                                                                                                                                                                                                                                                                             New  Construction Roadway
# 282                                                                                                                                                                                                                                                                      Preliminary Engineering//Preliminary Engineering
# 16                                                                                                                                                                                                                                                                                               Construction Engineering
# 26                                                                                                                                                                                                                                                      Construction Engineering//Facilities for Pedestrians and Bicycles
# 36                                                                                                                                                                                                                                                                                       Construction Engineering//Safety
# 65                                                                                                                                                                                                                                                                                Facilities for Pedestrians and Bicycles
# 90                                                                                                                                                                                   Construction Engineering//Facilities for Pedestrians and Bicycles//Construction Engineering//Facilities for Pedestrians and Bicycles
# 118                                                                                                                                                                                                                                                                                      Construction Engineering//Safety
# 139                                                                                                                                                                                                                                                                               Facilities for Pedestrians and Bicycles
# 146                                                                                                                                                                                                                                                     Construction Engineering//Facilities for Pedestrians and Bicycles
# 150                                                                                                                                                                                                                                                                                                4R - No Added Capacity
# 156                                                                                                                                                                                                                                                                               Facilities for Pedestrians and Bicycles
# 185                                                                                                                                                                                                                                                           4R - Restoration & Rehabilitation//Construction Engineering
# 208                                                                                                                                                                                                                                                                                               Preliminary Engineering
# 216                                                                                                                                                                                                                                                                                      Construction Engineering//Safety
# 252                                                                                                                                                         New  Construction Roadway//Construction Engineering//New  Construction Roadway//Construction Engineering//New  Construction Roadway//Construction Engineering
# 276                                                                                                                                                                                                                                                                                     4R - Restoration & Rehabilitation
# 283                                                                                                                                                                                                                                                                                                   4R - Added Capacity
# 297                                                                                                                                                                                                                                                                                               Preliminary Engineering
# 300  4R - Maintenance  Resurfacing//4R - Maintenance  Resurfacing//4R - Maintenance  Resurfacing//4R - Maintenance  Resurfacing//4R - Maintenance  Resurfacing//4R - Maintenance  Resurfacing//4R - Maintenance  Resurfacing//4R - Maintenance  Resurfacing//4R - Maintenance  Resurfacing//4R - Maintenance  Resurfacing
# 7                                                                                                                                                                                                                                                                                                 Preliminary Engineering
# 18                                                                                                                                                                                                                                                                                                Preliminary Engineering
# 32                                                                                                                                                                                                                                                                                       Construction Engineering//Safety
# 35                                                                                                                                                                                                                                                                4R - Maintenance  Resurfacing//Construction Engineering
# 37                                                                                                                                                                                                                                                                                                    Other//Other//Other
# 38                                                                                                                                                                                                                                                                       4R - No Added Capacity//Construction Engineering
#
#     project_method project_type           other
# 34         Replace      Project  Other Projects
# 269        Replace      Project  Other Projects
# 281         Repair      Project  Other Projects
# 93            Pave      Project  Other Projects
# 213           Pave      Project  Other Projects
# 19             New      Project  Other Projects
# 15         Install      Project  Other Projects
# 17         Install      Project  Other Projects
# 96         Install      Project  Other Projects
# 108        Install      Project  Other Projects
# 165        Install      Project  Other Projects
# 233        Install      Project  Other Projects
# 251        Install      Project  Other Projects
# 320        Install      Project  Other Projects
# 278        Improve      Project  Other Projects
# 282        Improve      Project  Other Projects
# 16       Construct      Project  Other Projects
# 26       Construct      Project  Other Projects
# 36       Construct      Project  Other Projects
# 65       Construct      Project  Other Projects
# 90       Construct      Project  Other Projects
# 118      Construct      Project  Other Projects
# 139      Construct      Project  Other Projects
# 146      Construct      Project  Other Projects
# 150      Construct      Project  Other Projects
# 156      Construct      Project  Other Projects
# 185      Construct      Project  Other Projects
# 208      Construct      Project  Other Projects
# 216      Construct      Project  Other Projects
# 252      Construct      Project  Other Projects
# 276      Construct      Project  Other Projects
# 283      Construct      Project  Other Projects
# 297      Construct      Project  Other Projects
# 300      Construct      Project  Other Projects
# 7                       Project  Other Projects
# 18                      Project  Other Projects
# 32                      Project  Other Projects
# 35                      Project  Other Projects
# 37                      Project  Other Projects
# 38                      Project  Other Projects

# %%
#checking remaining common words for no project tags
((utils.get_list_of_words(((utils.add_description(proj_sub, 'project_title'))>>filter(_.project_type=='Project')), "project_title")).value_counts()).head(60)
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# avenue           51
# st               44
# ave              39
# road             36
# city             23
# blvd             20
# street           18
# east             17
# construct        17
# north            15
# rd               15
# county           14
# intersections    13
# south            13
# drive            12
# along            12
# west             11
# san              11
# area             10
# way              10
# dr                9
# lane              9
# tc                9
# path              8
# bay               8
# river             7
# parkway           7
# regional          6
# install           6
# redwood           6
# trail             6
# streets           6
# creek             6
# widen             6
# mile              6
# 4                 6
# state             6
# including         6
# project           6
# 2                 6
# corridor          6
# park              6
# class             6
# multiuse          5
# interstate        5
# pacific           5
# sacramento        5
# alameda           5
# la                5
# route             5
# intersection      5
# palm              5
# grove             5
# various           5
# planning          5
# school            5
# program           5
# valley            4
# lanes             4
# provide           4
# dtype: int64

# %%
#sample of some descriptions that got cut off
((utils.add_description(proj_sub, 'project_title')))>>filter(_.project_type=='Project')>>filter(_.project_title.str.contains('AVENUE'))
# Out:
#                                 implementing_agency  \
# 15                                    Fresno County
# 32                                         Palmdale
# 36                                           Rialto
# 40                                          Belmont
# 67                                Sacramento County
# 87                                      Morgan Hill
# 92                                        Fairfield
# 93                                           Fresno
# 122                                          Fresno
# 130                                      Santa Rosa
# 132                                Twentynine Palms
# 134                                        Caltrans
# 135  San Bernardino County Transportation Authority
# 140                                       Sunnyvale
# 141                                El Dorado County
# 153            San Diego Association of Governments
# 165                                         Modesto
# 169                              Los Angeles County
# 251                                    Redwood City
# 276                                       Patterson
# 279                                      Sebastopol
# 320                                          Clovis
#
#            program_code_description  \
# 15    TRANS ALTERNATIVES >200K IIJA
# 32     HIGHWAY SAFETY IMP PROG IIJA
# 36     HIGHWAY SAFETY IMP PROG IIJA
# 40        STBG-URBANIZED >200K IIJA
# 67     HIGHWAY SAFETY IMP PROG IIJA
# 87        STBG-URBANIZED >200K IIJA
# 92   PROJ TO REDUCE PM 2.5 EMI IIJA
# 93    TRANSP ALTERNATIVES FLEX IIJA
# 122    HIGHWAY SAFETY IMP PROG IIJA
# 130       STBG-URBANIZED >200K IIJA
# 132    HIGHWAY SAFETY IMP PROG IIJA
# 134       STBG-URBANIZED >200K IIJA
# 135       STBG-URBANIZED >200K IIJA
# 140  PROJ TO REDUCE PM 2.5 EMI IIJA
# 141       STBG-URBANIZED >200K IIJA
# 153       STBG-URBANIZED >200K IIJA
# 165      CONGESTION MITIGATION IIJA
# 169    HIGHWAY SAFETY IMP PROG IIJA
# 251  SURFAC TRNSP BLK GRTS-FLX IIJA
# 276  SURFAC TRNSP BLK GRTS-FLX IIJA
# 279  SURFAC TRNSP BLK GRTS-FLX IIJA
# 320       STBG-URBANIZED >200K IIJA
#
#                                                                                                                                              project_title  \
# 15   ALONG GROVE AVENUE FROM PROSPECT AVENUE TO VALENTINE AVENUE, AND ALONG VALENTINE AVENUE FROM GROVE AVENUE TO NORTH AVENUE INSTALL AN ASPHALT CONCRETE
# 32     AVENUE S-8 AND 40TH STREET EAST. CONVERT AN EXISTING FOUR WAY STOP TO A ROUDABOUT AT THE INTERSECTION OF AVENUE S-8 AND 40TH STREET EAST..   ORIGIO
# 36                                                BASELINE ROAD - WILLOW AVENUE TO MERIDIAN AVENUE CONSTRUCT A 12' WIDE RAISED CENTER MEDIAN AND ADA RAMP.
# 40   BELMONT: CHULA VISTA FROM ALAMEDA DE LAS PULGAS TO RALSTON AVE, 6TH AVENUE FROM RALSTON AVENUE TO HILL STREET, 6TH AVENUE FROM EMMETT AVENUE TO HARBO
# 67    COYLE AVENUE FROM WOODLEIGH TO DEWEY, HILLSDALE BOULEVARD FROM FRIZELL AVENUE TO MCCLOUD DRIVE, AND WATT AVENUE FROM ELKHORN BOULEVARD TO 700' NORTH
# 87   EAST DUNNE AVENUE BETWEEN LOWER THOMAS GRADE AND THE EASTERN CITY LIMIT. FEDERAL PARTICIPATING LOCATION SEGMENTS: 1) LOWER THOMAS GRADE TO FLAMING OA
# 92   EAST TABOR AVENUE ( BETWEEN DOVER  AVENUE AND CLAY BANK ROAD) AND SUNSET AVENUE ( BETWEEN EAST TABOR AVENUE AND TRAVIS BOULEVARD) IMPLEMENT PEDESTRIA
# 93   EASTBOUND MCKINLEY FROM MILLBROOK AVENUE TO CLOVIS AVENUE ALONG THE NORTH BANK OF THE MILL DITCH CANAL. PAVED PATH, LIGHTING, BENCHES,FENCING, IRRIGA
# 122  FRESNO STREET AND THOMAS AVENUE INTERSECTIONS, FRESNO STREET AND SAN JOSE AVENUE INTERSECTION, FRESNO AND R STREETS INTERSECTION, FRESNO STREET AND C
# 130   HEARN AVENUE BETWEEN STONY POINT ROAD, DUTTON AVENUE AND RANGE AVENUE BETWEEN GUERNEVILLE ROAD AND JENNINGS AVENUE, AND RANGE AVENUE BETWEEN RUSSELL
# 132  HIGH-SPEED RURAL RESIDENTIAL AREAS BORDERED BY TWO MILE ROAD ON THE NORTH, BASELINE ROAD ON THE SOUTH, ENCELIA DRIVE TO THE WEST, AND ELM AVENUE ON T
# 134  I-10 CORRIDOR CONTRACT 2: THE PROJECT WILL PROVIDE ONE EXPRESS LANES IN EACH DIRECTION FROM JUST EAST OF I-15 TOPEPPER AVENUE IN COLTON, CONNECTING T
# 135  I-10 CORRIDOR CONTRACT 2: THE PROJECT WILL PROVIDE ONE EXPRESS LANES IN EACH DIRECTION FROM JUST EAST OF I-15 TOPEPPER AVENUE IN COLTON, CONNECTING T
# 140  IN EAST SUNNYVALE SENSE OF PLACE PLAN AREA: ON DUANE AVENUE FROM FAIR OAKS AVENUE TO LAWRENCE EXPRESSWAY, STEWART DRIVE FROM WOLFE ROAD TO DUANE AVEN
# 141  IN EASTERN EI DORADO COUNTY, IN THE TAHOE BASIN, IN THE CITY OF SOUTH LAKE TAHOE AT EAST END OF SOUTH AVENUE, OVER THE UPPER TRUCKEE RIVER, THEN NORT
# 153  IN SAN DIEGO, JUST NORTH OF SAN YSIDRO LAND PORT OF ENTRY TO INGRID AVENUE AND SATURN BOULEVARD IN IMPERIAL BEACH. ALONG PALM AVENUE, 7TH STREET, ELM
# 165   INTERSECTION OF PELANDALE AVENUE AND SR 99 IN MODESTO, CA TO INSTALL A SECOND LEFT TURN LANE FROM EASTBOUND PELANDALE AVENUE TO NORTHBOUND SISK ROAD
# 169  INTERSECTIONS OF 120TH STREET AT NORMANDIE AVENUE AND 120TH STREET AT COMPTON AVENUE, LOCATED IN THE UNINCORPORATED COUNTY AREAS OF WEST ATHENS AND W
# 251  ROOSEVELT AVENUE, EL CAMINO REAL TO ALAMEDA DE LAS PULGAS, REDWOOD CITY, CA THE CITY OF REDWOOD CITY PROPOSES INSTALLATION OF QUICK-BUILD IMPROVEMENT
# 276                                  SPERRY AVENUE FROM AMERICAN EAGLE AVENUE TO WARD AVENUE. ROAD REHABILITATION / RECONSTRUCTION WITH DIG OUTS AS NEEDED
# 279  SR-116 INTERSECTIONS: @ HURLBUT AVE; @ CLEVELAND AVE; @ N MAIN ST; @ WALLACE ST.BODEGA AVENUE INTERSECTIONS: @ FLORENCE AVE; @ ROBINSON RD THE CITY O
# 320  VILLA AVENUE BETWEEN BULLARD AVENUE AND BARSTOW AVENUE ROAD REHABILITATION INCLUDING GRINDING, PAVING, CONCRETE, INSTALLING TRAFFIC DEVICES AND RESTR
#
#                program_code  \
# 15               Y301//Y301
# 32               YS30//YS30
# 36               YS30//YS30
# 40                     Y230
# 67               YS30//YS30
# 87               Y230//Y230
# 92         Y003//Y003//Y240
# 93               Y300//Y300
# 122              YS30//YS30
# 130                    Y230
# 132                    YS30
# 134                    Y230
# 135                    Y230
# 140              Y003//Y003
# 141                    Y230
# 153        Y230//Y230//Y300
# 165                    Y400
# 169  YS30//YS30//YS30//YS30
# 251                    Y240
# 276                    Y240
# 279                    Y240
# 320                    Y230
#
#                                                                                    improvement_type_description  \
# 15                                            Construction Engineering//Facilities for Pedestrians and Bicycles
# 32                                                                             Construction Engineering//Safety
# 36                                                                             Construction Engineering//Safety
# 40                                                                            4R - Restoration & Rehabilitation
# 67                                                                             Construction Engineering//Safety
# 87                                                  4R - Restoration & Rehabilitation//Construction Engineering
# 92   Construction Engineering//Facilities for Pedestrians and Bicycles//Facilities for Pedestrians and Bicycles
# 93                                            Construction Engineering//Facilities for Pedestrians and Bicycles
# 122                                                                            Construction Engineering//Safety
# 130                                                                               4R - Maintenance  Resurfacing
# 132                                                                                                      Safety
# 134                                                                                     Preliminary Engineering
# 135                                                                                     Preliminary Engineering
# 140                                                 4R - Restoration & Rehabilitation//Construction Engineering
# 141                                                                                     Preliminary Engineering
# 153                              New  Construction Roadway//Construction Engineering//New  Construction Roadway
# 165                                                                                         4R - Added Capacity
# 169                                          Construction Engineering//Safety//Construction Engineering//Safety
# 251                                                                     Facilities for Pedestrians and Bicycles
# 276                                                                           4R - Restoration & Rehabilitation
# 279                                                                     Facilities for Pedestrians and Bicycles
# 320                                                                           4R - Restoration & Rehabilitation
#
#     project_method project_type           other
# 15         Install      Project  Other Projects
# 32                      Project  Other Projects
# 36       Construct      Project  Other Projects
# 40                      Project  Other Projects
# 67                      Project  Other Projects
# 87                      Project  Other Projects
# 92                      Project  Other Projects
# 93            Pave      Project  Other Projects
# 122                     Project  Other Projects
# 130                     Project  Other Projects
# 132                     Project  Other Projects
# 134                     Project  Other Projects
# 135                     Project  Other Projects
# 140                     Project  Other Projects
# 141                     Project  Other Projects
# 153                     Project  Other Projects
# 165        Install      Project  Other Projects
# 169                     Project  Other Projects
# 251        Install      Project  Other Projects
# 276      Construct      Project  Other Projects
# 279                     Project  Other Projects
# 320        Install      Project  Other Projects

# %%
## sample of what third colum, `other` captures
((utils.add_description(proj_sub, 'project_title')))>>filter(_.other!='Other Projects')
# Out:
#                         implementing_agency        program_code_description  \
# 27                         El Dorado County       STBG-URBANIZED >200K IIJA
# 29                                 Palmdale       STBG-URBANIZED >200K IIJA
# 39                               Bellflower    HIGHWAY SAFETY IMP PROG IIJA
# 57                                  Alameda   TRANS ALTERNATIVES >200K IIJA
# 81                              Los Angeles   TRANSP ALTERNATIVES FLEX IIJA
# 85                                    Chico      CONGESTION MITIGATION IIJA
# 95                                   Fresno   TRANS ALTERNATIVES >200K IIJA
# 119                                 Fremont  SURFAC TRNSP BLK GRTS-FLX IIJA
# 120  Metropolitan Transportation Commission       STBG-URBANIZED >200K IIJA
# 142                        El Dorado County      CONGESTION MITIGATION IIJA
# 148                                  Merced  PROJ TO REDUCE PM 2.5 EMI IIJA
# 159                                    Galt       STBG-URBANIZED >200K IIJA
# 192                            Santa Monica   TRANS ALTERNATIVES >200K IIJA
# 204                                  Clovis       STBG-URBANIZED >200K IIJA
# 207                             Yuba County       STBG-URBANIZED >200K IIJA
# 210                                  Merced  PROJ TO REDUCE PM 2.5 EMI IIJA
# 231                                   Hemet   TRANSP ALTERNATIVES FLEX IIJA
# 236                               Tehachapi      CONGESTION MITIGATION IIJA
# 238                             Kern County   TRANS ALTERNATIVES >200K IIJA
# 241                       Sacramento County    HIGHWAY SAFETY IMP PROG IIJA
# 254                                 Vallejo       STBG-URBANIZED >200K IIJA
# 280                                Caltrans      CONGESTION MITIGATION IIJA
# 293                                  Fresno      CONGESTION MITIGATION IIJA
# 298           Tahoe Transportation District       STBG-URBANIZED >200K IIJA
# 314                                 Windsor  SURFAC TRNSP BLK GRTS-FLX IIJA
#
#                                                                                                                                              project_title  \
# 27                       AT MISSOURI FLAT RD 0.8 MILES SOUTH OF GOLDEN CENTER DRIVE CONSTRUCT BIKE TRAIL CONNECTION, EXTEND CURB, GUTTER, AND SIDEWALK. TC
# 29         AVE R  BETWEEN SIERRA HIGHWAY AND 25TH STREET. AVE R COMPLETE STREET WITH SIDEWALKS GAP CLOSURES, BIKE LANES, ADA RAMPS AND ENHANCED CROSSWALKS
# 39   BELLFLOWER BOULEVARD FROM ARTESIA BOULEVARD TO SOUTH CITY LIMITS (350' SOUTH OF ROSE STREET). INSTALLING CLASS II BIKE LANES, RAISED MEDIAN, BULB-OUT
# 57    CENTRAL BETWEEN PACIFIC AVENUE/MAIN STREET AND SHERMAN STREET/ENCINAL AVENUE. REDUCE ROADWAY FROM 4 TO 3 LANES FOR BIKE LANES AND SEPARATED BIKEWAY,
# 81    DOWNTOWN LOS ANGELES, BROADWAY BETWEEN 4TH AND 6TH STREETS PEDESTRIAN SAFETY IMPROVEMENTS INCLUDING CURB EXTENSIONS, WIDENED SIDEWALK, CROSSWALK AND
# 85                                                        E. 20TH STREET FROM THE MALL TO THE END OF BUSINESS LANE (ADJACENT TO SR99) BIKEWAY IMPROVEMENTS
# 95   EASTSIDE OF BARTON AVENUE FROM CHURCH TO FLORENCE AND FLORENCE AVENUE FROM BARTON TO APPROXIMATELY 105 FT WEST OF JACKSON. INSTALL SIDEWALK, CURB RAM
# 119                                      FREMONT BLVD. AND WALNUT AVE. INTERSECTION CONNECT TO EXISTING ELEVATED/SEPARATED CLASS IV BIKEWAYS AND SIDEWALKS
# 120                                            FREMONT, RICHMOND, AND MARIN AND SONOMA COUNTIES, ALONG THE SMART CORRIDOR. BIKE SHARE CAPITAL PROGRAM (TC)
# 142  IN EL DORADO COUNTY, IN THE COMMUNITY OF POLLOCK PINES, PONY EXPRESS TRAIL, FROM SANDERS DRIVE TO SLY PARK ROAD. INSTALL 1.7 MILES OF CLASS 2 BIKE LA
# 148                                                 IN MERCED ON MOTEL DRIVE BETWEEN CAROL AVENUE AND MERCED AVENUE CONSTRUCT PEDESTRIAN/BIKE IMPROVEMENTS
# 159    IN THE CITY OF GALT ON WALNUT AVE, FROM CARILLION TO ELK HILLS DR. OVERLAY THE STREET AND UPGRADE THE BIKE LANES TO HIGH-VISIBILITY GREEN STANDARD.
# 192                                                                                        MICHIGAN AVE. BETWEEN 19TH & 20TH STREET BIKE PATH IMPROVEMENTS
# 204  NEES AVENUE FROM MINNEWAWA AVENUE TO CLOVIS AVENUE ROAD WIDENING AND RECONSTRUCTION, INSTALLATION OF CURB AND GUTTERS, SIDEWALK, BICYCLE LANES, MODIF
# 207  NORTH BEALE RD.,FROM HAMMONTON-SMARTSVILLE RD. TO LINDA AVE. CONSTRUCT BICYCLE LANES, CURB AND GUTTER, SIDEWALKS, DRAINAGE FACILITIES, LIGHTING AND O
# 210  NOTTINGHAM LANE (FROM OLIVE TO HANSON), TAMWORTH CT, BUCKINGHAM CT, AND ALEXANDER AVE. INSTALL FIVE-FOOT SIDEWALK ADJACENT TO EXISTING CURB AND GUTTE
# 231  PALM AVENUE, WHITTIER AVENUE, JOHNSTON AVENUE, GILBERT STREET, CHAMBERS STREET, STATE STREET INSTALLATION OF CLASS II AND CLASS III BIKE LANES, INFIL
# 236                                 PINON STREET FROM BRANDON LANE EAST TO DENNISON ROAD PAVE AN UNPAVED PORTION OF ROAD AND INSTALL A CLASS II BIKE LANE.
# 238  PORTIONS OF LAKE ISABELLA BOULEVARD AND ERSKINE CREEK ROAD CONSTRUCT BICYCLE AND PEDESTRIAN IMPROVEMENTS; BIKE BATH, BIKE LANES, CURB RAMPS AND SIDEW
# 241   POWER INN ROAD FROM ELSIE AVENUE TO ABOUT 400 FEET NORTH OF MACFADDEN DRIVE. INSTALL CURB, GUTTER, SIDEWALK INFILL AND CURB RAMPS; WIDEN SUBSTANDARD
# 254  SACRAMENTO ST FROM TENNESSEE ST TO CAPITAL  ST IMPLEMENT ROAD DIET PROJECT . INSTALL NEW DESIGNATED CLASS 2 BIKE LANE  OR BIKE SHARROWS, WITH CORRESP
# 280  SR-51 (CAPITAL CITY) CORRIDOR IMPROVEMENTS FROM J ST TO ARDEN WAY. WIDEN AND CONSTRUCT BUS/CARPOOL LANES, TRANSITION/AUXILIARY & NB CLASS I BIKE PATH
# 293  TULARE STREET FROM SIXTH STREET TO CEDAR AVENUE. INSTALL AND WIDEN SIDEWALKS ALONG THE SOUTH SIDE OF TULARE STREET, UPGRADE CURB RAMPS, RE-STRIPE ROA
# 298                                       US-50 FROM STATELINE AVENUE TO PIONEER TRAIL REALIGN ROADWAY, REDUCE LANES AND TRANSIT-BIKE-PEDESTRIAN LANE (TC)
# 314   VARIOUS LOCATIONS WITHIN THE CITY OF HEADSBURG. NON-INFRASTRUCTURE PROJECT TO SET UP AND OPERATE A 3 YEAR E-BIKE SHARE PILOT PROGRAM.  WORK INCLUDES
#
#          program_code  \
# 27         Y230//Y230
# 29               Y230
# 39         YS30//YS30
# 57               Y301
# 81         Y300//Y300
# 85               Y400
# 95         Y301//Y301
# 119        Y240//Y240
# 120              Y230
# 142        Y400//Y400
# 148              Y003
# 159              Y230
# 192              Y301
# 204              Y230
# 207              Y230
# 210              Y003
# 231        Y300//Y300
# 236  Y400//Y400//Y400
# 238              Y301
# 241              YS30
# 254              Y230
# 280              Y400
# 293        Y400//Y400
# 298              Y230
# 314              Y240
#
#                                           improvement_type_description  \
# 27                    4R - No Added Capacity//Construction Engineering
# 29                                           New  Construction Roadway
# 39                                    Construction Engineering//Safety
# 57                                             Preliminary Engineering
# 81                                    Construction Engineering//Safety
# 85                                            Construction Engineering
# 95   Construction Engineering//Facilities for Pedestrians and Bicycles
# 119                                   Construction Engineering//Safety
# 120                                                              Other
# 142                              Preliminary Engineering//Right of Way
# 148                            Facilities for Pedestrians and Bicycles
# 159                                            Preliminary Engineering
# 192                            Facilities for Pedestrians and Bicycles
# 204                                                4R - Added Capacity
# 207                                             4R - No Added Capacity
# 210                            Facilities for Pedestrians and Bicycles
# 231                New  Construction Roadway//Construction Engineering
# 236         New  Construction Roadway//Construction Engineering//Other
# 238                                            Preliminary Engineering
# 241                                                             Safety
# 254                                  4R - Restoration & Rehabilitation
# 280                                            Preliminary Engineering
# 293  Construction Engineering//Facilities for Pedestrians and Bicycles
# 298                                            Preliminary Engineering
# 314                                                              Other
#
#     project_method                            project_type          other
# 27       Construct                                Sidewalk  Multiple Road
# 29                                        Complete Streets  Multiple Road
# 39         Install                              Bike Lanes  Multiple Road
# 57                                              Bike Lanes  Multiple Road
# 81         Improve                                Sidewalk  Multiple Road
# 85         Improve                              Bike Lanes  Multiple Road
# 95         Install                                Sidewalk  Multiple Road
# 119                                               Sidewalk  Multiple Road
# 120                                     Bike Share Program  Multiple Road
# 142        Install                              Bike Lanes  Multiple Road
# 148      Construct  Pedestrian  & Bike Safety Improvements  Multiple Road
# 159        Upgrade                              Bike Lanes  Multiple Road
# 192        Improve                              Bike Lanes  Multiple Road
# 204        Install                                Sidewalk  Multiple Road
# 207      Construct                                Sidewalk  Multiple Road
# 210        Install                                Sidewalk  Multiple Road
# 231        Install                              Bike Lanes  Multiple Road
# 236        Install                              Bike Lanes  Multiple Road
# 238      Construct  Pedestrian  & Bike Safety Improvements  Multiple Road
# 241        Install                                Sidewalk  Multiple Road
# 254        Install                              Bike Lanes  Multiple Road
# 280      Construct                              Bike Lanes  Multiple Road
# 293        Install                                Sidewalk  Multiple Road
# 298                 Pedestrian  & Bike Safety Improvements  Multiple Road
# 314                                     Bike Share Program  Multiple Road

# %% [markdown]
# ## Combine for Public friendly title

# %%
title_new = (utils.add_description(proj_sub, 'project_title'))

# %%
title_new.head()
# Out:
#   implementing_agency      program_code_description  \
# 0           Hawthorne  HIGHWAY SAFETY IMP PROG IIJA
# 1             Yucaipa    NATIONAL HIGHWAY PERF IIJA
# 2           Fairfield  HIGHWAY SAFETY IMP PROG IIJA
# 3         Lake County   STBG IIJA OFF-SYSTEM BRIDGE
# 4           Vacaville  HIGHWAY SAFETY IMP PROG IIJA
#
#                                                                                                                                            project_title  \
# 0         120TH STREET FROM PRAIRIE AVENUE TO FELTON AVENUE. TRAFFIC SIGNAL UPGRADES AT NINE SIGNALIZED INTERSECTIONS AND IMPROVE CROSSINGS AND SIGNAGE.
# 1                         13TH STREET OVER WILSON CREEK FROM OAK GLEN ROAD TO KENTUCKY STREET, LWC 00L0017 REPLACE LOW WATER CROSSING WITH 2-LANE BRIDGE
# 2       16 LOCATIONS IN THE CITY OF FAIRFIELD INSTALL ADAPTIVE SIGNAL TIMING AND ADVANCED DILEMMA-ZONE DETECTION, AND ENHANCE THE VISIBILITY OF SIGNALS.
# 3                                       2.2 MILES NORTH OF STATE ROUTE 20 ON WITTER SPRINGS ROAD OVER COOPER CREEK. BR.# 14C0119 BRIDGE REPLACEMENT (TC)
# 4  21 INTERSECTIONS; ON ALAMO DRIVE FROM MERCHANT STREET TO NUT TREE ROAD AND ON PEABODY ROAD FROM ELMIRA ROAD TO FOXBORO PARKWAY IMPROVE SIGNAL HARDWAR
#
#              program_code  \
# 0              YS30//YS30
# 1                    Y001
# 2              YS30//YS30
# 3  Y233//Y233//Y233//Y233
# 4              YS30//YS30
#
#                                                                               improvement_type_description  \
# 0                                                                         Construction Engineering//Safety
# 1                                                                                                    Other
# 2                                                                         Construction Engineering//Safety
# 3  Bridge Replacement - No Added Capacity//Preliminary Engineering//Right of Way//Construction Engineering
# 4                                                                         Construction Engineering//Safety
#
#   project_method     project_type           other
# 0        Upgrade  Traffic Signals  Other Projects
# 1        Replace           Bridge  Other Projects
# 2        Install          Signals  Other Projects
# 3        Replace           Bridge  Other Projects
# 4        Improve          Signals  Other Projects

# %%
#replacing with function
# title_new['project_name_new'] = title_new["project_method"] + " " + title_new["project_type"] + " in " + title_new["implementing_agency"]

# %%
title_new = utils.add_new_title(title_new, 'project_method', 'project_type', 'implementing_agency')

# %%
title_new.head()
# Out:
#   implementing_agency      program_code_description  \
# 0           Hawthorne  HIGHWAY SAFETY IMP PROG IIJA
# 1             Yucaipa    NATIONAL HIGHWAY PERF IIJA
# 2           Fairfield  HIGHWAY SAFETY IMP PROG IIJA
# 3         Lake County   STBG IIJA OFF-SYSTEM BRIDGE
# 4           Vacaville  HIGHWAY SAFETY IMP PROG IIJA
#
#                                                                                                                                            project_title  \
# 0         120TH STREET FROM PRAIRIE AVENUE TO FELTON AVENUE. TRAFFIC SIGNAL UPGRADES AT NINE SIGNALIZED INTERSECTIONS AND IMPROVE CROSSINGS AND SIGNAGE.
# 1                         13TH STREET OVER WILSON CREEK FROM OAK GLEN ROAD TO KENTUCKY STREET, LWC 00L0017 REPLACE LOW WATER CROSSING WITH 2-LANE BRIDGE
# 2       16 LOCATIONS IN THE CITY OF FAIRFIELD INSTALL ADAPTIVE SIGNAL TIMING AND ADVANCED DILEMMA-ZONE DETECTION, AND ENHANCE THE VISIBILITY OF SIGNALS.
# 3                                       2.2 MILES NORTH OF STATE ROUTE 20 ON WITTER SPRINGS ROAD OVER COOPER CREEK. BR.# 14C0119 BRIDGE REPLACEMENT (TC)
# 4  21 INTERSECTIONS; ON ALAMO DRIVE FROM MERCHANT STREET TO NUT TREE ROAD AND ON PEABODY ROAD FROM ELMIRA ROAD TO FOXBORO PARKWAY IMPROVE SIGNAL HARDWAR
#
#              program_code  \
# 0              YS30//YS30
# 1                    Y001
# 2              YS30//YS30
# 3  Y233//Y233//Y233//Y233
# 4              YS30//YS30
#
#                                                                               improvement_type_description  \
# 0                                                                         Construction Engineering//Safety
# 1                                                                                                    Other
# 2                                                                         Construction Engineering//Safety
# 3  Bridge Replacement - No Added Capacity//Preliminary Engineering//Right of Way//Construction Engineering
# 4                                                                         Construction Engineering//Safety
#
#   project_method     project_type           other  \
# 0        Upgrade  Traffic Signals  Other Projects
# 1        Replace           Bridge  Other Projects
# 2        Install          Signals  Other Projects
# 3        Replace           Bridge  Other Projects
# 4        Improve          Signals  Other Projects
#
#                        project_name_new
# 0  Upgrade Traffic Signals in Hawthorne
# 1             Replace Bridge in Yucaipa
# 2          Install Signals in Fairfield
# 3         Replace Bridge in Lake County
# 4          Improve Signals in Vacaville

# %% [markdown]
# ### Export Sample Data with all columns

# %%
test_df = (utils.add_description(proj_all, 'project_title'))

# %%
test_df = utils.add_new_title(test_df, 'project_method', 'project_type', 'implementing_agency')

# %%
test_df = utils.title_column_names(test_df)

# %% [markdown]
# #### Export progress

# %%
# test_df.to_csv(f"{GCS_FILE_PATH}/FMIS_projects_wip2.csv")

# %% [markdown]
# ### Using another column `improvement_type_description`

# %%
# def update_no_matched(df, flag_col, desc_col):
#     """
#     function to itreate over projects that did not match the first time
#     using an existing project's short description of project type. 
#     """
    
#     if df[flag_col] == "Project":
#         return 
    
    
#     return df

# %%
no_match = ((utils.add_description(proj_sub, 'project_title'))>>filter(_.project_type==('Project')))

# %%
## using improvement type description
clean_type_list_df = utils.get_list_of_words(no_match, "improvement_type_description")
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
(clean_type_list_df.value_counts()).head(30)
# Out:
# construction                     34
# engineering                      28
# 4r                               23
# pedestrians                      20
# bicycles                         18
# maintenance                      14
# engineeringsafety                13
# preliminary                      12
# restoration                      12
# engineeringfacilities            11
# added                             9
# resurfacing4r                     9
# safety                            8
# facilities                        8
# engineeringsafetyconstruction     8
# rehabilitationconstruction        7
# rehabilitation                    5
# capacity                          5
# roadwayconstruction               4
# capacityconstruction              4
# new                               4
# engineeringpreliminary            3
# resurfacingconstruction           3
# roadway                           3
# engineeringnew                    3
# way                               3
# right                             3
# otherotherother                   2
# resurfacing                       2
# rehabilitation4r                  1
# dtype: int64

# %%
no_match.head()
# Out:
#    implementing_agency       program_code_description  \
# 7         Marin County      STBG-URBANIZED >200K IIJA
# 15       Fresno County  TRANS ALTERNATIVES >200K IIJA
# 16           Santa Ana  TRANS ALTERNATIVES >200K IIJA
# 17            Stockton   HIGHWAY SAFETY IMP PROG IIJA
# 18            Caltrans      STBG-URBANIZED >200K IIJA
#
#                                                                                                                                             project_title  \
# 7   4 AT TERNERS DRIVE @ DRIVEWAY ENTRANCES TO MULTI-FAMILY HOUSING CLOSEST TO DONAHUE, 4 AT TERNERS DRIVE @ TERRACE WAY, 4 AT TERNERS DRIVE @ TERRACE DR
# 15  ALONG GROVE AVENUE FROM PROSPECT AVENUE TO VALENTINE AVENUE, AND ALONG VALENTINE AVENUE FROM GROVE AVENUE TO NORTH AVENUE INSTALL AN ASPHALT CONCRETE
# 16  ALONG NEIGHBORHOOD STREETS ADJACENT TO DAVIS ELEMENTARY SCHOOL FROM 14TH STREET TO 15TH STREET. CONSTRUCT BULB-OUT AT CROSSINGS NEAR DAVIS ELEMENTARY
# 17                                                          ALONG PACIFIC AVE. FROM CALAVERAS RIVER TRAIL TO WEST HAMMER LANE. INSTALL RAISED MEDIAN CURB
# 18  ALONG THE I-880 CORRIDOR SF BAY AREA: REGIONWIDE: IMPLEMENT A COLLECTIVE APPROACH TO FREEWAY OPERATIONS AND MANAGEMENT, INCLUDING COMMUNICATIONS NETW
#
#    program_code  \
# 7          Y230
# 15   Y301//Y301
# 16         Y301
# 17         YS30
# 18         Y230
#
#                                          improvement_type_description  \
# 7                                             Preliminary Engineering
# 15  Construction Engineering//Facilities for Pedestrians and Bicycles
# 16                                           Construction Engineering
# 17                                                             Safety
# 18                                            Preliminary Engineering
#
#    project_method project_type           other  \
# 7                      Project  Other Projects
# 15        Install      Project  Other Projects
# 16      Construct      Project  Other Projects
# 17        Install      Project  Other Projects
# 18                     Project  Other Projects
#
#                     project_name_new
# 7            Project in Marin County
# 15  Install Project in Fresno County
# 16    Construct Project in Santa Ana
# 17       Install Project in Stockton
# 18               Project in Caltrans

# %%
no_match>>count(_.improvement_type_description)>>filter(_.n>1)>>arrange(-_.n)
# Out:
#                                          improvement_type_description   n
# 17                                   Construction Engineering//Safety  10
# 29                                            Preliminary Engineering   9
# 12  Construction Engineering//Facilities for Pedestrians and Bicycles   8
# 21                            Facilities for Pedestrians and Bicycles   8
# 35                                                             Safety   7
# 9         4R - Restoration & Rehabilitation//Construction Engineering   6
# 25                                                              Other   6
# 7                                   4R - Restoration & Rehabilitation   4
# 3             4R - Maintenance  Resurfacing//Construction Engineering   3
# 4                                              4R - No Added Capacity   3
# 0                                                 4R - Added Capacity   2
# 11                                           Construction Engineering   2
# 22                                          New  Construction Roadway   2
# 26                                                Other//Other//Other   2
# 30                   Preliminary Engineering//Preliminary Engineering   2

# %%
no_match>>filter(_.improvement_type_description.str.contains('Pedestrians and Bicycles'))
# Out:
#                                           implementing_agency  \
# 15                                              Fresno County
# 19                                                 Sacramento
# 26                                                 Livingston
# 65                                                Bakersfield
# 82                                                Los Angeles
# 90                                           El Dorado County
# 92                                                  Fairfield
# 93                                                     Fresno
# 139                                            Citrus Heights
# 146                                                Livingston
# 156                                                  Stockton
# 213                                                   Oakland
# 240                      Napa Valley Transportation Authority
# 251                                              Redwood City
# 258                                          San Mateo County
# 274                                                Sacramento
# 279                                                Sebastopol
# 295  Los Angeles County Metropolitan Transportation Authority
#
#            program_code_description  \
# 15    TRANS ALTERNATIVES >200K IIJA
# 19       CONGESTION MITIGATION IIJA
# 26       CONGESTION MITIGATION IIJA
# 65       CONGESTION MITIGATION IIJA
# 82    TRANS ALTERNATIVES >200K IIJA
# 90        STBG-URBANIZED >200K IIJA
# 92   PROJ TO REDUCE PM 2.5 EMI IIJA
# 93    TRANSP ALTERNATIVES FLEX IIJA
# 139      CONGESTION MITIGATION IIJA
# 146  PROJ TO REDUCE PM 2.5 EMI IIJA
# 156   TRANS ALTERNATIVES >200K IIJA
# 213   TRANS ALTERNATIVES >200K IIJA
# 240  SURFAC TRNSP BLK GRTS-FLX IIJA
# 251  SURFAC TRNSP BLK GRTS-FLX IIJA
# 258  SURFAC TRNSP BLK GRTS-FLX IIJA
# 274      CONGESTION MITIGATION IIJA
# 279  SURFAC TRNSP BLK GRTS-FLX IIJA
# 295   TRANSP ALTERNATIVES FLEX IIJA
#
#                                                                                                                                              project_title  \
# 15   ALONG GROVE AVENUE FROM PROSPECT AVENUE TO VALENTINE AVENUE, AND ALONG VALENTINE AVENUE FROM GROVE AVENUE TO NORTH AVENUE INSTALL AN ASPHALT CONCRETE
# 19   ALONG UNUSED RAIL CORRIDOR NEAR FREEPORT BLVD FROM SUTTERVILLE ROAD TO SOUTH OF MEADOWVIEW/POCKET ROAD (4.5 MILES) RAILS TO TRAILS PROJECT ; NEW CLAS
# 26                                                                   AT MAX FOSTER SPORTS COMPLEX AREA IN LIVINGSTON CONSTRUCT MULTI-USE PATH IMPROVEMENTS
# 65   CONSTRUCT A MULTI-USE PATH (6 MILES) ALONG THE FRIANT-KERN CANAL IN BAKERSFIELD: BOUNDED BY 7TH STANDARD ROAD AND KERN RIVER PARKWAY. CONSTRUCT CLASS
# 82   DTLA ARTS DISTRICT AREA FROM 2ND STREET ON THE NORTH, 7TH STREET ON THE SOUTH, ALAMEDA STREET ON THE WEST AND THE LA RIVER ON THE EAST WITH A FOCUS O
# 90   EAST SAN BERNARDINO AVE FROM WEST OF UPPER TRUCKEE RIVER TO TAHOE PARADISE PARK IN THE COMMUNITY OF MYERS CONSTRUCT APPROXIMATELY 0.37 MILES OF CLASS
# 92   EAST TABOR AVENUE ( BETWEEN DOVER  AVENUE AND CLAY BANK ROAD) AND SUNSET AVENUE ( BETWEEN EAST TABOR AVENUE AND TRAVIS BOULEVARD) IMPLEMENT PEDESTRIA
# 93   EASTBOUND MCKINLEY FROM MILLBROOK AVENUE TO CLOVIS AVENUE ALONG THE NORTH BANK OF THE MILL DITCH CANAL. PAVED PATH, LIGHTING, BENCHES,FENCING, IRRIGA
# 139                           IN CITRUS HEIGHTS, BETWEEN ARCADE CREEK PARK PRESERVE AND WACHTEL WAY. CONSTRUCT A 2.9 MILE LONG CLASS 1 MULTI-USE TRAIL. TC
# 146  IN LIVINGSTON, CONSTRUCT PHASE 2 MAX FOSTER MULTIUSE PATH (ALONG DWIGHT WAY, BETWEEN NORTH TRIGGER LN & TEHAMA DR,) CONSTRUCT A CONCRETE MULTIUSE PAT
# 156  IN STOCKTON, PARALLEL TO MARCH LANE IN THE EAST BAY MUD CORRIDOR BETWEEN BROOKSIDE ROAD AND HILLSBORO WAY. RECONSTRUCT, WIDEN AND IMPROVE EXISTING PA
# 213  OAKLAND - 14TH STREET SAFE ROUTES IN THE CITY. ON 14TH ST BETWEEN BRUSH ST AND OAK ST REDUCE TRAVEL LANES FROM 4 TO 2, ADD PAVED CLASS IV PROTECTED B
# 240  POST MILE 29.2 TO EAST OF 37.22 ALONG SR 29  FROM THE CITY OF ST HELENA TO THE CITY OF CALISTOGA. THE PROJECT PROPOSES TO PROVIDE BICYCLISTS AND PEDE
# 251  ROOSEVELT AVENUE, EL CAMINO REAL TO ALAMEDA DE LAS PULGAS, REDWOOD CITY, CA THE CITY OF REDWOOD CITY PROPOSES INSTALLATION OF QUICK-BUILD IMPROVEMENT
# 258  SAN MATEO COUNTY: SOUTH PARK PLAZA DR, 87TH AT CORNERS OF S. PARK PLAZA AND WASHINGTON ST, 87TH ST FROM SOUTHGATE TO SULLIVAN AVE SAN MATEO COUNTY: O
# 274  SOUTH SACRAMENTO PARKWAY TRAIL- WEST. IN THE CITY OF SACRAMENTO, ADJACENT TO NORTHBOUND INTERSTATE 5, SOUTH OF POCKET ROAD/MEADOWVIEW ROAD AND FREEPO
# 279  SR-116 INTERSECTIONS: @ HURLBUT AVE; @ CLEVELAND AVE; @ N MAIN ST; @ WALLACE ST.BODEGA AVENUE INTERSECTIONS: @ FLORENCE AVE; @ ROBINSON RD THE CITY O
# 295   UNION STATION/ DOWNTOWN LOS ANGELES COMMUNITIES UNION STATION MASTER PLAN:ALAMEDA ESPLANADE.  ALAMEDA ESPLANADE WILL CREATE A MULTI-MODAL CONNECTION
#
#                program_code  \
# 15               Y301//Y301
# 19                     Y400
# 26               Y400//Y400
# 65                     Y400
# 82               Y301//Y301
# 90   Y230//Y230//Y400//Y400
# 92         Y003//Y003//Y240
# 93               Y300//Y300
# 139                    Y400
# 146              Y003//Y003
# 156                    Y301
# 213                    Y301
# 240                    Y240
# 251                    Y240
# 258              Y240//Y240
# 274              Y400//Y400
# 279                    Y240
# 295              Y300//Y300
#
#                                                                                                              improvement_type_description  \
# 15                                                                      Construction Engineering//Facilities for Pedestrians and Bicycles
# 19                                                                                                Facilities for Pedestrians and Bicycles
# 26                                                                      Construction Engineering//Facilities for Pedestrians and Bicycles
# 65                                                                                                Facilities for Pedestrians and Bicycles
# 82                                                                      Construction Engineering//Facilities for Pedestrians and Bicycles
# 90   Construction Engineering//Facilities for Pedestrians and Bicycles//Construction Engineering//Facilities for Pedestrians and Bicycles
# 92                             Construction Engineering//Facilities for Pedestrians and Bicycles//Facilities for Pedestrians and Bicycles
# 93                                                                      Construction Engineering//Facilities for Pedestrians and Bicycles
# 139                                                                                               Facilities for Pedestrians and Bicycles
# 146                                                                     Construction Engineering//Facilities for Pedestrians and Bicycles
# 156                                                                                               Facilities for Pedestrians and Bicycles
# 213                                                                                               Facilities for Pedestrians and Bicycles
# 240                                                                                               Facilities for Pedestrians and Bicycles
# 251                                                                                               Facilities for Pedestrians and Bicycles
# 258                                                                     Construction Engineering//Facilities for Pedestrians and Bicycles
# 274                                                                     Construction Engineering//Facilities for Pedestrians and Bicycles
# 279                                                                                               Facilities for Pedestrians and Bicycles
# 295                                                                     Construction Engineering//Facilities for Pedestrians and Bicycles
#
#     project_method project_type           other  \
# 15         Install      Project  Other Projects
# 19             New      Project  Other Projects
# 26       Construct      Project  Other Projects
# 65       Construct      Project  Other Projects
# 82                      Project  Other Projects
# 90       Construct      Project  Other Projects
# 92                      Project  Other Projects
# 93            Pave      Project  Other Projects
# 139      Construct      Project  Other Projects
# 146      Construct      Project  Other Projects
# 156      Construct      Project  Other Projects
# 213           Pave      Project  Other Projects
# 240                     Project  Other Projects
# 251        Install      Project  Other Projects
# 258                     Project  Other Projects
# 274                     Project  Other Projects
# 279                     Project  Other Projects
# 295                     Project  Other Projects
#
#                                                          project_name_new
# 15                                       Install Project in Fresno County
# 19                                              New Project in Sacramento
# 26                                        Construct Project in Livingston
# 65                                       Construct Project in Bakersfield
# 82                                                 Project in Los Angeles
# 90                                  Construct Project in El Dorado County
# 92                                                   Project in Fairfield
# 93                                                 Pave Project in Fresno
# 139                                   Construct Project in Citrus Heights
# 146                                       Construct Project in Livingston
# 156                                         Construct Project in Stockton
# 213                                               Pave Project in Oakland
# 240                       Project in Napa Valley Transportation Authority
# 251                                       Install Project in Redwood City
# 258                                           Project in San Mateo County
# 274                                                 Project in Sacramento
# 279                                                 Project in Sebastopol
# 295   Project in Los Angeles County Metropolitan Transportation Authority

# %%
no_match['improvement_type_description'] = no_match['improvement_type_description'].str.upper()
# Out:
# /tmp/ipykernel_2261/1491882977.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
test = utils.add_description(no_match, 'improvement_type_description')
# Out:
# /home/jovyan/data-analyses/dla/agency_mapping/utils.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/jovyan/data-analyses/dla/agency_mapping/utils.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/jovyan/data-analyses/dla/agency_mapping/utils.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
test.head()
# Out:
#    implementing_agency       program_code_description  \
# 7         Marin County      STBG-URBANIZED >200K IIJA
# 15       Fresno County  TRANS ALTERNATIVES >200K IIJA
# 16           Santa Ana  TRANS ALTERNATIVES >200K IIJA
# 17            Stockton   HIGHWAY SAFETY IMP PROG IIJA
# 18            Caltrans      STBG-URBANIZED >200K IIJA
#
#                                                                                                                                             project_title  \
# 7   4 AT TERNERS DRIVE @ DRIVEWAY ENTRANCES TO MULTI-FAMILY HOUSING CLOSEST TO DONAHUE, 4 AT TERNERS DRIVE @ TERRACE WAY, 4 AT TERNERS DRIVE @ TERRACE DR
# 15  ALONG GROVE AVENUE FROM PROSPECT AVENUE TO VALENTINE AVENUE, AND ALONG VALENTINE AVENUE FROM GROVE AVENUE TO NORTH AVENUE INSTALL AN ASPHALT CONCRETE
# 16  ALONG NEIGHBORHOOD STREETS ADJACENT TO DAVIS ELEMENTARY SCHOOL FROM 14TH STREET TO 15TH STREET. CONSTRUCT BULB-OUT AT CROSSINGS NEAR DAVIS ELEMENTARY
# 17                                                          ALONG PACIFIC AVE. FROM CALAVERAS RIVER TRAIL TO WEST HAMMER LANE. INSTALL RAISED MEDIAN CURB
# 18  ALONG THE I-880 CORRIDOR SF BAY AREA: REGIONWIDE: IMPLEMENT A COLLECTIVE APPROACH TO FREEWAY OPERATIONS AND MANAGEMENT, INCLUDING COMMUNICATIONS NETW
#
#    program_code  \
# 7          Y230
# 15   Y301//Y301
# 16         Y301
# 17         YS30
# 18         Y230
#
#                                          improvement_type_description  \
# 7                                             PRELIMINARY ENGINEERING
# 15  CONSTRUCTION ENGINEERING//FACILITIES FOR PEDESTRIANS AND BICYCLES
# 16                                           CONSTRUCTION ENGINEERING
# 17                                                             SAFETY
# 18                                            PRELIMINARY ENGINEERING
#
#    project_method                    project_type           other  \
# 7                                         Project  Other Projects
# 15      Construct  Pedestrian Safety Improvements  Other Projects
# 16      Construct                         Project  Other Projects
# 17                                        Project  Other Projects
# 18                                        Project  Other Projects
#
#                     project_name_new
# 7            Project in Marin County
# 15  Install Project in Fresno County
# 16    Construct Project in Santa Ana
# 17       Install Project in Stockton
# 18               Project in Caltrans

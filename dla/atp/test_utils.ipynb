# %%
import altair as alt
import altair_saver
import intake
import ipywidgets as widgets
import numpy as np
import pandas as pd
from calitp import to_snakecase
from dla_utils import _dla_utils
from IPython.display import HTML, Image, Markdown
from ipywidgets import interact, interactive
from plotnine import *
from shared_utils import altair_utils, styleguide
from siuba import *
# Out:
# /opt/conda/lib/python3.10/site-packages/geopandas/_compat.py:112: UserWarning: The Shapely GEOS version (3.10.3-CAPI-1.16.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
import utils

# %%
df = utils.read_in_data()

# %%
utils.clean_data(df)
# Out:
#      a1_imp_agcy_city a1_imp_agcy_fed_ma_num a1_imp_agcy_ma  \
# 0              Merced               10-5939R            Yes
# 1           Santa Ana                12-5063            Yes
# 2    City of Pacifica            04-5350-F15            Yes
# 3          Santa Ana                 12-5063            Yes
# 4           Santa Ana                12-5063            Yes
# ..                ...                    ...            ...
# 877     Thousand Oaks             07-5292F15            Yes
# 878    South El Monte                    NaN            Yes
# 879          San Jose             04-5005F15            Yes
# 880     Santa Barbara               05-5951R            Yes
# 881           Salinas                056143R            Yes
#
#                               a1_imp_agcy_name a1_imp_agcy_state_ma_num  \
# 0                                Merced County                   00033S
# 1                           Santa Ana, City of                   00289S
# 2                            Pacifica, City of                      NaN
# 3                           Santa Ana, City of                   00289S
# 4                           Santa Ana, City of                   00289S
# ..                                         ...                      ...
# 877                     Thousand Oaks, City of                    00252
# 878                    South El Monte, City of               07-5352S21
# 879                          San Jose, City of                   00200S
# 880                       Santa Barbara County                   00100S
# 881  Transportation Agency for Monterey County                  74A0797
#
#               a1_imp_agcy_street                   a1_imp_agcy_title  \
# 0            345 west 7th street                     Deputy Director
# 1    20 Civic Center Plaza, M-43               Senior Civil Engineer
# 2              151 Milagra Drive            Associate Civil Engineer
# 3    20 Civic Center Plaza, M-43               Senior Civil Engineer
# 4    20 Civic Center Plaza, M-43               Senior Civil Engineer
# ..                           ...                                 ...
# 877     2100 Thousand Oaks Blvd.              Transportation Planner
# 878     1415 Santa Anita Avenue       Community Development Director
# 879         200 E Santa Clara St    Senior Transportation Specialist
# 880            123 E. Anapuma St  Alternative Transportation Manager
# 881            55-B Plaza Circle              Transportation Planner
#
#      a1_imp_agcy_zip                  a1_letter_of_intent  \
# 0              95340                                  NaN
# 1              92702                                  NaN
# 2              94044                                  NaN
# 3              92702                                  NaN
# 4              92702                                  NaN
# ..               ...                                  ...
# 877            91362                                  NaN
# 878            91733  Partner Agency Letter of Intent.pdf
# 879            95113                                  NaN
# 880            93101                                  NaN
# 881            93901        FORTAG LOS-City of Marina.pdf
#
#     a1_proj_partner_agcy  ... a4_plan_bike a4_plan_atp  a4_plan_school_routes  \
# 0                    NaN  ...            N           N                      N
# 1                    NaN  ...            N           N                      N
# 2                    NaN  ...            N           N                      N
# 3                    NaN  ...            N           N                      N
# 4                    NaN  ...            N           N                      N
# ..                   ...  ...          ...         ...                    ...
# 877                  NaN  ...            N           N                      N
# 878    City of El Monte   ...            N           N                      N
# 879                  NaN  ...            N           N                      N
# 880                  NaN  ...            N           N                      N
# 881       City of Marina  ...            N           N                      N
#
#      a4_row_open_street_demo  awarded_y  matches  assembly_district  \
# 0                         No          N     both                 21
# 1                         No          N     both                 69
# 2                         No          N     both                 22
# 3                         No          N     both                 69
# 4                         No          N     both                 69
# ..                       ...        ...      ...                ...
# 877                       No          N     both                 44
# 878                       No          N     both                 49
# 879                       No          N     both                 25
# 880                       No          N     both                 37
# 881                       No          N     both                 30
#
#      congressional_district senate_district                     geometry
# 0                        16              12   POINT (120.31282 37.29159)
# 1                        46              34   POINT (117.86443 33.73947)
# 2                        14              13  POINT (-122.49178 37.64730)
# 3                        46              34   POINT (117.89494 33.71126)
# 4                        46              34   POINT (117.86884 33.73240)
# ..                      ...             ...                          ...
# 877                      26              27                  POINT EMPTY
# 878                      32              22                  POINT EMPTY
# 879                      19              15                  POINT EMPTY
# 880                      24              19                  POINT EMPTY
# 881                      20              17                  POINT EMPTY
#
# [882 rows x 215 columns]

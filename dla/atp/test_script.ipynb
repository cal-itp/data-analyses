# %%
import intake
import numpy as np
import pandas as pd
from calitp import to_snakecase
from dla_utils import _dla_utils
from IPython.display import HTML, Image, Markdown
from siuba import *
# Out:
# /opt/conda/lib/python3.10/site-packages/geopandas/_compat.py:112: UserWarning: The Shapely GEOS version (3.10.3-CAPI-1.16.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
import utils

# %%
pd.set_option("display.max_columns", 220)

# %%
df = utils.read_in_data()

# %%
clean_df = utils.clean_data(df)
# Out:
# /home/jovyan/data-analyses/dla/atp/utils.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/jovyan/data-analyses/dla/atp/utils.py:192: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
# /home/jovyan/data-analyses/dla/atp/utils.py:200: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
clean_df.head()
# Out:
#    a1_imp_agcy_city a1_imp_agcy_fed_ma_num a1_imp_agcy_ma    a1_imp_agcy_name  \
# 0            Merced               10-5939R            Yes       Merced County
# 1         Santa Ana                12-5063            Yes  Santa Ana, City of
# 2  City of Pacifica            04-5350-F15            Yes   Pacifica, City of
# 3        Santa Ana                 12-5063            Yes  Santa Ana, City of
# 4         Santa Ana                12-5063            Yes  Santa Ana, City of
#
#   a1_imp_agcy_state_ma_num           a1_imp_agcy_street  \
# 0                   00033S          345 west 7th street
# 1                   00289S  20 Civic Center Plaza, M-43
# 2                      NaN            151 Milagra Drive
# 3                   00289S  20 Civic Center Plaza, M-43
# 4                   00289S  20 Civic Center Plaza, M-43
#
#           a1_imp_agcy_title  a1_imp_agcy_zip a1_letter_of_intent  \
# 0           Deputy Director            95340                 NaN
# ...

# %%
clean_df.project_cycle.value_counts()
# Out:
# CYCLE 5    448
# CYCLE 6    434
# Name: project_cycle, dtype: int64

# %%
df= to_snakecase(pd.read_excel("gs://calitp-analytics-data/data-analyses/dla/atp/needs_assistance/needs_assistance_districts.xlsx"))

# %%
df
# Out:
#     unnamed:_0 a1_imp_agcy_city                          a1_imp_agcy_name  \
# 0            0    San Bernardio                    San Bernardio, City of
# 1            1          Hayward                            Alameda County
# 2            2           Fresno                           Fresno, City of
# 3            3           Fresno                           Fresno, City of
# 4            4   Rancho Cordova                   Rancho Cordova, City of
# 5            5           Fresno                           Fresno, City of
# 6            6         Woodland                               Yolo County
# 7            7          Oakland  Alameda County Transportation Commission
# 8            8          Lynwood                          Lynwood, City of
# 9            9   Rancho Cordova                   Rancho Cordova, City of
# 10          10          Oakland  Alameda County Transportation Commission
# 11          11   San Bernardino                   San Bernardino, City of
# ...

# %%
pd.read_excel('gs://calitp-analytics-data/data-analyses/dla/atp/Master_AllData_Cycle5FieldMapping.xls', sheet_name='Statewide SUR Details')
# Out:
#    Unnamed: 0     Unnamed: 1  Unnamed: 2 Unnamed: 3        ATP ID Unnamed: 5  \
# 0     Awarded  Project Cycle  A2 Ct Dist          #        ATP ID       PPNO
# 1           Y              5           5        NaN  ATP5-05-001R       3057
# 2           Y              5           7        NaN  ATP5-07-002S       5858
# 3           Y              5           4        NaN  ATP5-04-003S      2343A
# 4           Y              5           5        NaN  ATP5-05-004S      3058A
# 5           Y              5          11        NaN  ATP5-11-005S       1442
# 6           Y              5           6        NaN  ATP5-06-006S       7074
# 7           Y              5          10        NaN  ATP5-10-007S       3513
# 8           Y              5           5        NaN  ATP5-05-008S       3060
# 9           Y              5           2        NaN  ATP5-02-009R        NaN
# 10          Y              5           6        NaN  ATP5-06-010S       7075
# ...

# %% [markdown]
# # Creating Crosswalk with DLA Locode, NTD ID and ITP ID

# %%
import pandas as pd
from siuba import *
import numpy as np
from calitp import *

# %%
GCS_FILE_PATH = 'gs://calitp-analytics-data/data-analyses/dla/e-76Obligated/'

pd.set_option('display.max_columns', None)

# %%
dla = pd.read_excel(f"{GCS_FILE_PATH}locodes_updated7122021.xlsx")
# Out:
# /opt/conda/lib/python3.9/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
dla = to_snakecase(dla)
dla = dla.rename(columns = {'agency_name':'name', 'agency_locode':'ct_code'})

# %%
dla.sample(1)
# Out:
#      ct_code         name  district  county_name  \
# 807     5948  Inyo County         9  Inyo County
#
#                                  rtpa_name mpo_name mpo_locode_fads  \
# 807  Inyo County Transportation Commission  NON-MPO         NON-MPO
#
#     active_e76s______7_12_2021_
# 807                         Yes

# %%
dla = dla>>select(_.ct_code, _.name, _.district)

# %% [markdown]
# ### Reading in [Place Names](https://dot.ca.gov/-/media/dot-media/programs/research-innovation-system-information/documents/place-names/2020-place-names-in-california-a11y.pdf)

# %%
pl_city = pd.read_excel(f"{GCS_FILE_PATH}2020-place-names-locode.xlsx", sheet_name=0)
pl_county = pd.read_excel(f"{GCS_FILE_PATH}2020-place-names-locode.xlsx", sheet_name=1)

# %%
pl_city = to_snakecase(pl_city)
pl_county = to_snakecase(pl_county)

# %%
pl_city = pl_city.drop(columns={'unnamed:_1','unnamed:_3','unnamed:_4','unnamed:_6','unnamed:_7', 'date_of_incorporation', 'urban_area_no_'})
pl_county = pl_county.drop(columns={'unnamed:_1','unnamed:_3','unnamed:_4','unnamed:_6','unnamed:_9'})

# %%
pl_city = pl_city.rename(columns={'ct_city_code':'ct_code', 'city_name_abbr_':'abbr', 'dist_':'district', 'co_':'county'})
pl_county = pl_county.rename(columns={'ct_co__code':'ct_code', 'county_name':'name', 'co__name_abbr_':'abbr'})

# %%
pl_city['organization_type']= ('City/Town')
pl_county['organization_type']= ('County')

# %%
pl_county['name'] = pl_county['name'].astype(str) + ' County'

# %%
pl_county.ct_code.fillna(pl_county['unnamed:_8'], inplace=True)
pl_county = pl_county.drop(columns = {'unnamed:_8'})

# %%
plnames = pd.concat([pl_city, pl_county])

# %%
plnames
# Out:
#                name  abbr district county  ct_code organization_type  co__fips
# 0          Adelanto  Adel        8    SBd   5408.0         City/Town       NaN
# 1      Agoura Hills  AgrH        7     LA   5435.0         City/Town       NaN
# 2           Alameda   Ala        4    Ala   5014.0         City/Town       NaN
# 3            Albany   Alb        4    Ala   5178.0         City/Town       NaN
# 4          Alhambra   Alh        7     LA   5130.0         City/Town       NaN
# ..              ...   ...      ...    ...      ...               ...       ...
# 53    Tulare County   Tul        6    NaN   5946.0            County     107.0
# 54  Tuolumne County   Tuo       10    NaN   5932.0            County     109.0
# 55   Ventura County   Ven        7    NaN   5952.0            County     111.0
# 56      Yolo County   Yol        3    NaN   5922.0            County     113.0
# 57      Yuba County   Yub        3    NaN   5916.0            County     115.0
#
# [540 rows x 7 columns]

# %%
plnames.county.fillna(plnames.abbr, inplace=True)

# %%
fips_map = dict(zip(pl_county['abbr'], 
                          pl_county['co__fips']))

# %%
plnames['co__fips'] = plnames['county'].map(fips_map)

# %%
type_map = dict(zip(plnames['ct_code'], 
                          plnames['organization_type']))

# %%
dla['organization_type'] = dla['ct_code'].map(type_map)

# %%
mask1 = (dla['name'].str.contains('Council of Governments'))
mask2 = (dla['name'].str.contains('Tribe')) 
mask3 = (dla['name'].str.contains('University'))
mask4 = (dla['name'].str.contains('RTPA'))
mask5 = (dla['name'].str.contains('JPA'))

dla.loc[dla['organization_type'].isnull() & mask1, 'organization_type'] = 'Council of Governments'
dla.loc[dla['organization_type'].isnull() & mask2, 'organization_type'] = 'Tribe'
dla.loc[dla['organization_type'].isnull() & mask3, 'organization_type'] = 'University - Public'
dla.loc[dla['organization_type'].isnull() & mask4, 'organization_type'] = 'MPO/RTPA'
dla.loc[dla['organization_type'].isnull() & mask5, 'organization_type'] = 'Joint Powers Agency'

# %%
#dla.to_csv('dla_placenames.csv')

# %% [markdown]
# ### READ ITP

# %%
import calitp
from calitp.tables import tbl

# %%
itp = pd.read_csv(f"{GCS_FILE_PATH}organizations-All Organizations_0427.csv")

# %%
itp = to_snakecase(itp)

# %%
itp = itp>>select(_.name, _.ntp_id, _.itp_id, _.organization_type)

# %%
itp = itp.rename(columns = {"ntp_id":"ntd_id"})

# %%
itp
# Out:
#                                                   name      ntd_id  itp_id  \
# 0                                        A-Paratransit         NaN     NaN
# 1                                          ABC Shuttle         NaN     NaN
# 2                                            Able Inc.         NaN     NaN
# 3                                         Abrazar Inc.         NaN     NaN
# 4                                      Access Services       90157     1.0
# ..                                                 ...         ...     ...
# 836       Yosemite Area Regional Transportation System  9R02-91070   374.0
# 837                      Yuba-Sutter Transit Authority       90061   376.0
# 838  Yuma County Intergovernmental Public Transport...       90233   386.0
# 839                                        Yurok Tribe       99262   377.0
# 840                                         Zonar Inc.         NaN     NaN
#
#            organization_type
# 0                        NaN
# 1                    Company
# 2    Non-Profit Organization
# 3    Non-Profit Organization
# 4                        NaN
# ..                       ...
# 836       Independent Agency
# 837       Independent Agency
# 838       Independent Agency
# 839                    Tribe
# 840                  Company
#
# [841 rows x 4 columns]

# %% [markdown]
# ## Merging

# %%
ids = pd.merge(itp, dla, on='name', how="outer", indicator=True)

# %%
ids._merge.value_counts()
# Out:
# right_only    923
# left_only     723
# both          118
# Name: _merge, dtype: int64

# %% [markdown]
# * right only is DLA
# * left only is ITP/NTD ID

# %%
ids>>count(_.name)>>arrange(-_.n)>>filter(_.n>1)
# Out:
#                           name   n
# 189                   Caltrans  13
# 1106          North East Trees   2
# 1661  Urban Corps of San Diego   2

# %%
ids>>filter(_.name=='North East Trees')
# Out:
#                   name ntd_id  itp_id organization_type_x  ct_code  district  \
# 1379  North East Trees    NaN     NaN                 NaN   6118.0       7.0
# 1380  North East Trees    NaN     NaN                 NaN   6434.0       7.0
#
#      organization_type_y      _merge
# 1379                 NaN  right_only
# 1380                 NaN  right_only

# %%
ids>>filter(_.name=='Urban Corps of San Diego')
# Out:
#                           name ntd_id  itp_id organization_type_x  ct_code  \
# 1629  Urban Corps of San Diego    NaN     NaN                 NaN   6490.0
# 1630  Urban Corps of San Diego    NaN     NaN                 NaN   6233.0
#
#       district organization_type_y      _merge
# 1629      11.0                 NaN  right_only
# 1630      11.0                 NaN  right_only

# %%
#duplicates expected
ids>>filter(_.name=='Caltrans')
# Out:
#          name ntd_id  itp_id organization_type_x  ct_code  district  \
# 858  Caltrans    NaN     NaN                 NaN   6201.0       1.0
# 859  Caltrans    NaN     NaN                 NaN   6202.0       2.0
# 860  Caltrans    NaN     NaN                 NaN   6203.0       3.0
# 861  Caltrans    NaN     NaN                 NaN   6204.0       4.0
# 862  Caltrans    NaN     NaN                 NaN   6205.0       5.0
# 863  Caltrans    NaN     NaN                 NaN   6206.0       6.0
# 864  Caltrans    NaN     NaN                 NaN   6207.0       7.0
# 865  Caltrans    NaN     NaN                 NaN   6208.0       8.0
# 866  Caltrans    NaN     NaN                 NaN   6209.0       9.0
# 867  Caltrans    NaN     NaN                 NaN   6210.0      10.0
# 868  Caltrans    NaN     NaN                 NaN   6211.0      11.0
# 869  Caltrans    NaN     NaN                 NaN   6212.0      12.0
# 870  Caltrans    NaN     NaN                 NaN   6200.0      53.0
#
#     organization_type_y      _merge
# 858                 NaN  right_only
# 859                 NaN  right_only
# 860                 NaN  right_only
# 861                 NaN  right_only
# 862                 NaN  right_only
# 863                 NaN  right_only
# 864                 NaN  right_only
# 865                 NaN  right_only
# 866                 NaN  right_only
# 867                 NaN  right_only
# 868                 NaN  right_only
# 869                 NaN  right_only
# 870                 NaN  right_only

# %%
#interesting that DLA Locode has some duplciates... will investigate
#caltrans duplicates expected

# %% [markdown]
# #### Adding Organization Types

# %%
ids.organization_type_y.fillna(ids['organization_type_x'], inplace=True)

# %%
ids = ids.rename(columns={'organization_type_y':'organization_type'})
ids.drop(columns=('organization_type_x'), inplace=True)

# %%
ids
# Out:
#                                     name ntd_id  itp_id  ct_code  district  \
# 0                          A-Paratransit    NaN     NaN      NaN       NaN
# 1                            ABC Shuttle    NaN     NaN      NaN       NaN
# 2                              Able Inc.    NaN     NaN      NaN       NaN
# 3                           Abrazar Inc.    NaN     NaN      NaN       NaN
# 4                        Access Services  90157     1.0   6312.0       7.0
# ...                                  ...    ...     ...      ...       ...
# 1759                         Leave Blank    NaN     NaN   5465.0      53.0
# 1760      U.S. Fish and Wildlife Service    NaN     NaN   6250.0      53.0
# 1761  Tidewater Southern Railway Company    NaN     NaN   6031.0      53.0
# 1762    Tri-Counties Regional Park Group    NaN     NaN   6176.0      53.0
# 1763               Trust for Public Land    NaN     NaN   6185.0      59.0
#
#             organization_type      _merge
# 0                         NaN   left_only
# 1                     Company   left_only
# 2     Non-Profit Organization   left_only
# 3     Non-Profit Organization   left_only
# 4                         NaN        both
# ...                       ...         ...
# 1759                      NaN  right_only
# 1760                      NaN  right_only
# 1761                      NaN  right_only
# 1762                      NaN  right_only
# 1763                      NaN  right_only
#
# [1764 rows x 7 columns]

# %%
mask1 = (ids['name'].str.contains('Council of Governments'))
mask2 = (ids['name'].str.contains('Association of Governments')) 
mask4 = (ids['name'].str.contains('Transportation Commission'))
mask5 = (ids['name'].str.contains('Joint Powers Agency'))
mask6 = (ids['name'].str.contains('Transportation Agency'))
mask8 = (ids['name'].str.contains('Port Hueneme'))
mask9 = (ids['name'].str.contains('Access Services'))
mask10 = (ids['name'].str.contains('County Transportation Authority'))


ids.loc[ids['organization_type'].isnull() & mask1, 'organization_type'] = 'Council of Governments'
ids.loc[ids['organization_type'].isnull() & mask2, 'organization_type'] = 'Council of Governments'
ids.loc[ids['organization_type'].isnull() & mask4, 'organization_type'] = 'Transportation Commission'
ids.loc[ids['organization_type'].isnull() & mask5, 'organization_type'] = 'Joint Powers Agency'
ids.loc[ids['organization_type'].isnull() & mask6, 'organization_type'] = 'MPO/RTPA'
ids.loc[ids['organization_type'].isnull() & mask8, 'organization_type'] = 'City/Town'
ids.loc[ids['organization_type'].isnull() & mask9, 'organization_type'] = 'Independent Agency'
ids.loc[ids['organization_type'].isnull() & mask10, 'organization_type'] = 'Transportation Commission'

# %%
mask11 = (ids['name'].str.contains('Regional'))

# %%
ids.organization_type.value_counts()
# Out:
# City/Town                    755
# Company                      159
# Non-Profit Organization       94
# Independent Agency            75
# County                        58
# Transportation Commission     39
# University - Public           34
# Council of Governments        22
# Joint Powers Agency            7
# Tribe                          7
# MPO/RTPA                       6
# University - Private           5
# Federal Government             2
# Community College              2
# Name: organization_type, dtype: int64

# %%
(
    ids
    >> filter(_.organization_type.isnull())
    >> filter(_.name.str.contains("Governments"))
)
# Out:
#                                               name ntd_id  itp_id  ct_code  \
# 384       Council of San Benito County Governments    NaN     NaN   6060.0
# 1239  Association Of Monterey Bay Area Governments    NaN     NaN   6091.0
# 1272          Council of Fresno County Governments    NaN     NaN   6086.0
# 1475      Western Riverside Council Of Governments    NaN     NaN   6107.0
# 1476         San Bernardino Associated Governments    NaN     NaN   6053.0
#
#       district organization_type      _merge
# 384        5.0               NaN        both
# 1239       5.0               NaN  right_only
# 1272       6.0               NaN  right_only
# 1475       8.0               NaN  right_only
# 1476       8.0               NaN  right_only

# %% [markdown]
# #### Subset for Orgs that matched

# %%
both = (ids>>filter(_._merge=='both'))

# %%
both = both.drop(columns=['_merge'])

# %%
both
# Out:
#                                          name      ntd_id  itp_id  ct_code  \
# 4                             Access Services       90157     1.0   6312.0
# 13                              Alpine County  9R02-91116     9.0   5931.0
# 15                              Amador County         NaN     NaN   5926.0
# 16    Amador County Transportation Commission         NaN     NaN   6127.0
# 28          Antelope Valley Transit Authority       90121    16.0   6166.0
# ..                                        ...         ...     ...      ...
# 810  Ventura County Transportation Commission       90164   380.0   6155.0
# 815           Victor Valley Transit Authority       90148   360.0   6261.0
# 828    Western Contra Costa Transit Authority       90159   368.0   6226.0
# 835       Yolo County Transportation District       90090   372.0   6195.0
# 837             Yuba-Sutter Transit Authority       90061   376.0   6224.0
#
#      district          organization_type
# 4         7.0         Independent Agency
# 13       10.0                     County
# 15       10.0                     County
# 16       10.0  Transportation Commission
# 28        7.0         Independent Agency
# ..        ...                        ...
# 810       7.0  Transportation Commission
# 815       8.0         Independent Agency
# 828       4.0         Independent Agency
# 835       3.0         Independent Agency
# 837       3.0         Independent Agency
#
# [118 rows x 6 columns]

# %%
both.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118 entries, 4 to 837
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               118 non-null    object
#  1   ntd_id             57 non-null     object
#  2   itp_id             66 non-null     float64
#  3   ct_code            118 non-null    float64
#  4   district           118 non-null    float64
#  5   organization_type  112 non-null    object
# dtypes: float64(3), object(3)
# memory usage: 6.5+ KB

# %%
both['organization_type'].value_counts()
# Out:
# Independent Agency           42
# County                       36
# Transportation Commission    15
# Council of Governments       12
# Joint Powers Agency           3
# MPO/RTPA                      2
# City/Town                     1
# Community College             1
# Name: organization_type, dtype: int64

# %%
nomatch = ids>>filter(_._merge!='both')

# %%
nomatch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1646 entries, 0 to 1763
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               1646 non-null   object
#  1   ntd_id             142 non-null    object
#  2   itp_id             309 non-null    float64
#  3   ct_code            923 non-null    float64
#  4   district           923 non-null    float64
#  5   organization_type  1153 non-null   object
#  6   _merge             1646 non-null   category
# dtypes: category(1), float64(3), object(3)
# memory usage: 91.8+ KB

# %%
nomatch>>count(_._merge)
# Out:
#        _merge    n
# 0   left_only  723
# 1  right_only  923
# 2        both    0

# %%
(nomatch.query('itp_id.notnull() and ntd_id.notnull()')).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 135 entries, 10 to 839
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               135 non-null    object
#  1   ntd_id             135 non-null    object
#  2   itp_id             135 non-null    float64
#  3   ct_code            0 non-null      float64
#  4   district           0 non-null      float64
#  5   organization_type  128 non-null    object
#  6   _merge             135 non-null    category
# dtypes: category(1), float64(3), object(3)
# memory usage: 7.6+ KB

# %%
nomatch.query('itp_id.isnull() or ntd_id.isnull() or ct_code.isnull()')
# Out:
#                                     name ntd_id  itp_id  ct_code  district  \
# 0                          A-Paratransit    NaN     NaN      NaN       NaN
# 1                            ABC Shuttle    NaN     NaN      NaN       NaN
# 2                              Able Inc.    NaN     NaN      NaN       NaN
# 3                           Abrazar Inc.    NaN     NaN      NaN       NaN
# 5                            ACE Parking    NaN     NaN      NaN       NaN
# ...                                  ...    ...     ...      ...       ...
# 1759                         Leave Blank    NaN     NaN   5465.0      53.0
# 1760      U.S. Fish and Wildlife Service    NaN     NaN   6250.0      53.0
# 1761  Tidewater Southern Railway Company    NaN     NaN   6031.0      53.0
# 1762    Tri-Counties Regional Park Group    NaN     NaN   6176.0      53.0
# 1763               Trust for Public Land    NaN     NaN   6185.0      59.0
#
#             organization_type      _merge
# 0                         NaN   left_only
# 1                     Company   left_only
# 2     Non-Profit Organization   left_only
# 3     Non-Profit Organization   left_only
# 5                         NaN   left_only
# ...                       ...         ...
# 1759                      NaN  right_only
# 1760                      NaN  right_only
# 1761                      NaN  right_only
# 1762                      NaN  right_only
# 1763                      NaN  right_only
#
# [1646 rows x 7 columns]

# %%
no_ids = nomatch>>filter(_.itp_id.isnull())>>filter(_.ntd_id.isnull())

# %%
no_ids>>filter(_.ct_code.isnull())
# Out:
#                                                   name ntd_id  itp_id  \
# 0                                        A-Paratransit    NaN     NaN
# 1                                          ABC Shuttle    NaN     NaN
# 2                                            Able Inc.    NaN     NaN
# 3                                         Abrazar Inc.    NaN     NaN
# 5                                          ACE Parking    NaN     NaN
# ..                                                 ...    ...     ...
# 830  Westminster on Wheels Senior Transportation Pr...    NaN     NaN
# 831                               Willits Seniors Inc.    NaN     NaN
# 833                                           Worldpay    NaN     NaN
# 834                                      Yellow Cab CA    NaN     NaN
# 840                                         Zonar Inc.    NaN     NaN
#
#      ct_code  district        organization_type     _merge
# 0        NaN       NaN                      NaN  left_only
# 1        NaN       NaN                  Company  left_only
# 2        NaN       NaN  Non-Profit Organization  left_only
# 3        NaN       NaN  Non-Profit Organization  left_only
# 5        NaN       NaN                      NaN  left_only
# ..       ...       ...                      ...        ...
# 830      NaN       NaN                      NaN  left_only
# 831      NaN       NaN  Non-Profit Organization  left_only
# 833      NaN       NaN                  Company  left_only
# 834      NaN       NaN                  Company  left_only
# 840      NaN       NaN                  Company  left_only
#
# [407 rows x 7 columns]

# %%
both.query('itp_id.isnull() or ntd_id.isnull()')
# Out:
#                                           name ntd_id  itp_id  ct_code  \
# 15                               Amador County    NaN     NaN   5926.0
# 16     Amador County Transportation Commission    NaN     NaN   6127.0
# 57                                Butte County    NaN     NaN   5912.0
# 61            Calaveras Council of Governments    NaN     NaN   6128.0
# 373    Colusa County Transportation Commission    NaN     NaN   6129.0
# ..                                         ...    ...     ...      ...
# 771  Transportation Agency for Monterey County    NaN     NaN   6143.0
# 777   Trinity County Transportation Commission    NaN     NaN   6153.0
# 780                              Tulare County    NaN     NaN   5946.0
# 782   Tulare County Association of Governments    NaN     NaN   6094.0
# 786     Tuolumne County Transportation Council    NaN     NaN   6154.0
#
#      district          organization_type
# 15       10.0                     County
# 16       10.0  Transportation Commission
# 57        3.0                     County
# 61       10.0     Council of Governments
# 373       3.0  Transportation Commission
# ..        ...                        ...
# 771       5.0                   MPO/RTPA
# 777       2.0  Transportation Commission
# 780       6.0                     County
# 782       6.0        Joint Powers Agency
# 786      10.0                        NaN
#
# [64 rows x 6 columns]

# %%
both.query('organization_type.isnull()')
# Out:
#                                                   name ntd_id  itp_id  \
# 384           Council of San Benito County Governments    NaN     NaN
# 505             Lake County/City Area Planning Council    NaN     NaN
# 618       Placer County Transportation Planning Agency    NaN     NaN
# 705  Shasta County Regional Transportation Planning...    NaN     NaN
# 751                     Tahoe Regional Planning Agency    NaN     NaN
# 786             Tuolumne County Transportation Council    NaN     NaN
#
#      ct_code  district organization_type
# 384   6060.0       5.0               NaN
# 505   6136.0       1.0               NaN
# 618   6158.0       3.0               NaN
# 705   6093.0       2.0               NaN
# 751   6125.0       3.0               NaN
# 786   6154.0      10.0               NaN

# %%
# Most Agency types that are null are Transportation Commissions, or COGs.

# %%
print(f"Out of {(len(ids>>filter(_.ct_code.notnull())))} organizations in the Official Locode List, {(len(ids>>filter(_.ct_code.notnull())>>filter(_.organization_type.notnull())))} have an Organization Type listed in Airtable")
# Out:
# Out of 1041 organizations in the Official Locode List, 660 have an Organization Type listed in Airtable

# %%
ids.organization_type.value_counts()
# Out:
# City/Town                    755
# Company                      159
# Non-Profit Organization       94
# Independent Agency            75
# County                        58
# Transportation Commission     39
# University - Public           34
# Council of Governments        22
# Joint Powers Agency            7
# Tribe                          7
# MPO/RTPA                       6
# University - Private           5
# Federal Government             2
# Community College              2
# Name: organization_type, dtype: int64

# %%
# There is a `Council of Governments` option available

# %%
(both.query('organization_type.isnull()'))
# Out:
#                                                   name ntd_id  itp_id  \
# 384           Council of San Benito County Governments    NaN     NaN
# 505             Lake County/City Area Planning Council    NaN     NaN
# 618       Placer County Transportation Planning Agency    NaN     NaN
# 705  Shasta County Regional Transportation Planning...    NaN     NaN
# 751                     Tahoe Regional Planning Agency    NaN     NaN
# 786             Tuolumne County Transportation Council    NaN     NaN
#
#      ct_code  district organization_type
# 384   6060.0       5.0               NaN
# 505   6136.0       1.0               NaN
# 618   6158.0       3.0               NaN
# 705   6093.0       2.0               NaN
# 751   6125.0       3.0               NaN
# 786   6154.0      10.0               NaN

# %%
both>>filter(_.ntd_id.isnull())
# Out:
#                                           name ntd_id  itp_id  ct_code  \
# 15                               Amador County    NaN     NaN   5926.0
# 16     Amador County Transportation Commission    NaN     NaN   6127.0
# 57                                Butte County    NaN     NaN   5912.0
# 61            Calaveras Council of Governments    NaN     NaN   6128.0
# 373    Colusa County Transportation Commission    NaN     NaN   6129.0
# ..                                         ...    ...     ...      ...
# 771  Transportation Agency for Monterey County    NaN     NaN   6143.0
# 777   Trinity County Transportation Commission    NaN     NaN   6153.0
# 780                              Tulare County    NaN     NaN   5946.0
# 782   Tulare County Association of Governments    NaN     NaN   6094.0
# 786     Tuolumne County Transportation Council    NaN     NaN   6154.0
#
#      district          organization_type
# 15       10.0                     County
# 16       10.0  Transportation Commission
# 57        3.0                     County
# 61       10.0     Council of Governments
# 373       3.0  Transportation Commission
# ..        ...                        ...
# 771       5.0                   MPO/RTPA
# 777       2.0  Transportation Commission
# 780       6.0                     County
# 782       6.0        Joint Powers Agency
# 786      10.0                        NaN
#
# [61 rows x 6 columns]

# %%
both>>filter(_.itp_id.isnull())
# Out:
#                                                   name      ntd_id  itp_id  \
# 15                                       Amador County         NaN     NaN
# 16             Amador County Transportation Commission         NaN     NaN
# 57                                        Butte County         NaN     NaN
# 61                    Calaveras Council of Governments         NaN     NaN
# 373            Colusa County Transportation Commission         NaN     NaN
# 384           Council of San Benito County Governments         NaN     NaN
# 410         El Dorado County Transportation Commission         NaN     NaN
# 436                      Fresno Council of Governments         NaN     NaN
# 437                                      Fresno County         NaN     NaN
# 449             Glenn County Transportation Commission         NaN     NaN
# 469         Humboldt County Association of Governments         NaN     NaN
# 475                                    Imperial County         NaN     NaN
# 487                                        Inyo County         NaN     NaN
# 503            Kings County Association of Governments         NaN     NaN
# 505             Lake County/City Area Planning Council         NaN     NaN
# 507            Lassen County Transportation Commission         NaN     NaN
# 526            Madera County Transportation Commission         NaN     NaN
# 539                   Mendocino Council of Governments         NaN     NaN
# 542           Merced County Association of Governments         NaN     NaN
# 556                                        Mono County         NaN     NaN
# 558                                    Monterey County         NaN     NaN
# 576            Nevada County Transportation Commission         NaN     NaN
# 598                                      Orange County         NaN     NaN
# 618       Placer County Transportation Planning Agency         NaN     NaN
# 622                                      Plumas County  9R02-91119     NaN
# 623            Plumas County Transportation Commission         NaN     NaN
# 627                                       Port Hueneme         NaN     NaN
# 642                                   Riverside County         NaN     NaN
# 658                                  San Benito County         NaN     NaN
# 660                              San Bernardino County         NaN     NaN
# 663                                   San Diego County         NaN     NaN
# 673                 San Joaquin Council of Governments       99422     NaN
# 674                                 San Joaquin County         NaN     NaN
# 680                             San Luis Obispo County         NaN     NaN
# 682                                   San Mateo County         NaN     NaN
# 684                         Santa Barbara City College         NaN     NaN
# 685                               Santa Barbara County         NaN     NaN
# 689                                  Santa Cruz County         NaN     NaN
# 690  Santa Cruz County Regional Transportation Comm...         NaN     NaN
# 704                                      Shasta County  9R02-99438     NaN
# 705  Shasta County Regional Transportation Planning...         NaN     NaN
# 720                    Solano Transportation Authority         NaN     NaN
# 728     Southern California Association of Governments         NaN     NaN
# 739                  Stanislaus Council of Governments         NaN     NaN
# 740                                  Stanislaus County         NaN     NaN
# 751                     Tahoe Regional Planning Agency         NaN     NaN
# 754            Tehama County Transportation Commission         NaN     NaN
# 771          Transportation Agency for Monterey County         NaN     NaN
# 777           Trinity County Transportation Commission         NaN     NaN
# 780                                      Tulare County         NaN     NaN
# 782           Tulare County Association of Governments         NaN     NaN
# 786             Tuolumne County Transportation Council         NaN     NaN
#
#      ct_code  district          organization_type
# 15    5926.0      10.0                     County
# 16    6127.0      10.0  Transportation Commission
# 57    5912.0       3.0                     County
# 61    6128.0      10.0     Council of Governments
# 373   6129.0       3.0  Transportation Commission
# 384   6060.0       5.0                        NaN
# 410   6157.0       3.0  Transportation Commission
# 436   6504.0       6.0     Council of Governments
# 437   5942.0       6.0                     County
# 449   6132.0       3.0  Transportation Commission
# 469   6133.0       1.0     Council of Governments
# 475   5958.0      11.0                     County
# 487   5948.0       9.0                     County
# 503   6408.0       6.0     Council of Governments
# 505   6136.0       1.0                        NaN
# 507   6137.0       2.0  Transportation Commission
# 526   6409.0       6.0  Transportation Commission
# 539   6140.0       1.0     Council of Governments
# 542   6095.0      10.0     Council of Governments
# 556   5947.0       9.0                     County
# 558   5944.0       5.0                     County
# 576   6144.0       3.0  Transportation Commission
# 598   5955.0      12.0                     County
# 618   6158.0       3.0                        NaN
# 622   5909.0       2.0                     County
# 623   6147.0       2.0  Transportation Commission
# 627   5302.0       7.0                  City/Town
# 642   5956.0       8.0                     County
# 658   5943.0       5.0                     County
# 660   5954.0       8.0                     County
# 663   5957.0      11.0                     County
# 673   6088.0      10.0     Council of Governments
# 674   5929.0      10.0                     County
# 680   5949.0       5.0                     County
# 682   5935.0       4.0                     County
# 684   6173.0       5.0          Community College
# 685   5951.0       5.0                     County
# 689   5936.0       5.0                     County
# 690   6149.0       5.0  Transportation Commission
# 704   5906.0       2.0                     County
# 705   6093.0       2.0                        NaN
# 720   6249.0       4.0         Independent Agency
# 728   6049.0      53.0        Joint Powers Agency
# 739   6089.0      10.0     Council of Governments
# 740   5938.0      10.0                     County
# 751   6125.0       3.0                        NaN
# 754   6152.0       2.0  Transportation Commission
# 771   6143.0       5.0                   MPO/RTPA
# 777   6153.0       2.0  Transportation Commission
# 780   5946.0       6.0                     County
# 782   6094.0       6.0        Joint Powers Agency
# 786   6154.0      10.0                        NaN

# %%
# many in both have blank NTD and ITP ids but are still identified in Airtable

# %%
print(f"Out of the {(len(both))} organizations that matched, {(len(both.query('itp_id.notnull() and ntd_id.notnull() and organization_type.notnull()')))} have all id fields filled (ITP/NTD/Locode)")
# Out:
# Out of the 118 organizations that matched, 54 have all id fields filled (ITP/NTD/Locode)

# %%
#the 54 with all fields filled out
(both.query('itp_id.notnull() and ntd_id.notnull() and organization_type.notnull()'))
# Out:
#                                                   name      ntd_id  itp_id  \
# 4                                      Access Services       90157     1.0
# 13                                       Alpine County  9R02-91116     9.0
# 28                   Antelope Valley Transit Authority       90121    16.0
# 58             Butte County Association of Governments       90208    47.0
# 62                                    Calaveras County  9R02-91063    50.0
# 409                 El Dorado County Transit Authority       90229   101.0
# 438                 Fresno County Rural Transit Agency  9R02-91007   117.0
# 448                                       Glenn County  9R02-91088   122.0
# 454                     Golden Empire Transit District       90004   126.0
# 472                         Humboldt Transit Authority  9R02-91036   135.0
# 476          Imperial County Transportation Commission       90226   138.0
# 500                                        Kern County  9R02-91059   146.0
# 502            Kings County Area Public Transit Agency       90200   148.0
# 506                             Lake Transit Authority  9R02-91053   159.0
# 509                      Lassen Transit Service Agency  9R02-91098   162.0
# 517  Los Angeles County Metropolitan Transportation...       90154   182.0
# 525                                      Madera County  9R02-91005   188.0
# 529                      Marin County Transit District       90234   194.0
# 540                        Mendocino Transit Authority  9R02-91047   198.0
# 564                    Morongo Basin Transit Authority  9R02-91090   212.0
# 565           Mountain Area Regional Transit Authority  9R02-91012   214.0
# 572               Napa Valley Transportation Authority       90088   218.0
# 575                                      Nevada County  9R02-91095   221.0
# 582                      North County Transit District       90030   226.0
# 590                                          OmniTrans       90029   232.0
# 599             Orange County Transportation Authority       90036   235.0
# 617                                      Placer County       90196   251.0
# 626             Pomona Valley Transportation Authority       99425    69.0
# 636                    Redwood Coast Transit Authority  9R02-91097   261.0
# 643         Riverside County Transportation Commission       90218   267.0
# 644                           Riverside Transit Agency       90031   269.0
# 653               Sacramento Regional Transit District       90019   273.0
# 662               San Diego Association of Governments       90095   276.0
# 665              San Diego Metropolitan Transit System       90026   278.0
# 669      San Francisco Bay Area Rapid Transit District       90003   279.0
# 676               San Joaquin Regional Rail Commission       90182    10.0
# 679             San Luis Obispo Council of Governments       90297   288.0
# 683                  San Mateo County Transit District       90009   290.0
# 687        Santa Barbara Metropolitan Transit District       90020   293.0
# 688        Santa Clara Valley Transportation Authority       90013   294.0
# 691           Santa Cruz Metropolitan Transit District       90006   296.0
# 710            Sierra County Transportation Commission  9R02-91038   304.0
# 715                                    Siskiyou County  9R02-91048    83.0
# 719                              Solano County Transit       90232   310.0
# 722                                      Sonoma County       90089   314.0
# 729        Southern California Regional Rail Authority       90151   323.0
# 753                                      Tehama County  9R02-91089   334.0
# 776                                     Trinity County  9R02-91035   344.0
# 809                                     Ventura County       90298    84.0
# 810           Ventura County Transportation Commission       90164   380.0
# 815                    Victor Valley Transit Authority       90148   360.0
# 828             Western Contra Costa Transit Authority       90159   368.0
# 835                Yolo County Transportation District       90090   372.0
# 837                      Yuba-Sutter Transit Authority       90061   376.0
#
#      ct_code  district          organization_type
# 4     6312.0       7.0         Independent Agency
# 13    5931.0      10.0                     County
# 28    6166.0       7.0         Independent Agency
# 58    6092.0       3.0        Joint Powers Agency
# 62    5930.0      10.0                     County
# 409   6225.0       3.0         Independent Agency
# 438   6194.0       6.0         Independent Agency
# 448   5911.0       3.0                     County
# 454   6013.0       6.0         Independent Agency
# 472   6162.0       1.0         Independent Agency
# 476   6471.0      11.0         Independent Agency
# 500   5950.0       6.0                     County
# 502   6198.0       6.0         Independent Agency
# 506   6436.0       1.0         Independent Agency
# 509   6427.0       2.0         Independent Agency
# 517   6065.0       7.0         Independent Agency
# 525   5941.0       6.0                     County
# 529   6343.0       4.0         Independent Agency
# 540   6241.0       1.0         Independent Agency
# 564   6235.0       8.0         Independent Agency
# 565   6292.0       8.0         Independent Agency
# 572   6510.0       4.0         Independent Agency
# 575   5917.0       3.0                     County
# 582   6376.0      11.0         Independent Agency
# 590   6046.0       8.0         Independent Agency
# 599   6071.0      12.0         Independent Agency
# 617   5919.0       3.0                     County
# 626   6339.0       7.0         Independent Agency
# 636   6428.0       1.0         Independent Agency
# 643   6054.0       8.0  Transportation Commission
# 644   6165.0       8.0         Independent Agency
# 653   6005.0       3.0         Independent Agency
# 662   6066.0      11.0     Council of Governments
# 665   7503.0      11.0         Independent Agency
# 669   6000.0       4.0         Independent Agency
# 676   6262.0      10.0         Independent Agency
# 679   6096.0       5.0     Council of Governments
# 683   6014.0       4.0         Independent Agency
# 687   6007.0       5.0         Independent Agency
# 688   6264.0       4.0         Independent Agency
# 691   6004.0       5.0         Independent Agency
# 710   6150.0       3.0  Transportation Commission
# 715   5902.0       2.0                     County
# 719   6497.0       4.0         Independent Agency
# 722   5920.0       4.0                     County
# 729   6187.0       7.0         Independent Agency
# 753   5908.0       2.0                     County
# 776   5905.0       2.0                     County
# 809   5952.0       7.0                     County
# 810   6155.0       7.0  Transportation Commission
# 815   6261.0       8.0         Independent Agency
# 828   6226.0       4.0         Independent Agency
# 835   6195.0       3.0         Independent Agency
# 837   6224.0       3.0         Independent Agency

# %%
print(f"If we just look at completed Locodes (no ITP/NTD), we now have organization type info for {(len(both.query('ct_code.notnull() and organization_type.notnull()')))} organizations")
# Out:
# If we just look at completed Locodes (no ITP/NTD), we now have organization type info for 112 organizations

# %%
#both.to_parquet(f"{GCS_FILE_PATH}ITP_NTD_Locode_crosswalk.parquet")

#this just has the Agency Locode, NTD ID, ITP ID and Agency Locode

# %% [markdown]
# ## Full Merged Data

# %%
ids
# Out:
#                                     name ntd_id  itp_id  ct_code  district  \
# 0                          A-Paratransit    NaN     NaN      NaN       NaN
# 1                            ABC Shuttle    NaN     NaN      NaN       NaN
# 2                              Able Inc.    NaN     NaN      NaN       NaN
# 3                           Abrazar Inc.    NaN     NaN      NaN       NaN
# 4                        Access Services  90157     1.0   6312.0       7.0
# ...                                  ...    ...     ...      ...       ...
# 1759                         Leave Blank    NaN     NaN   5465.0      53.0
# 1760      U.S. Fish and Wildlife Service    NaN     NaN   6250.0      53.0
# 1761  Tidewater Southern Railway Company    NaN     NaN   6031.0      53.0
# 1762    Tri-Counties Regional Park Group    NaN     NaN   6176.0      53.0
# 1763               Trust for Public Land    NaN     NaN   6185.0      59.0
#
#             organization_type      _merge
# 0                         NaN   left_only
# 1                     Company   left_only
# 2     Non-Profit Organization   left_only
# 3     Non-Profit Organization   left_only
# 4          Independent Agency        both
# ...                       ...         ...
# 1759                      NaN  right_only
# 1760                      NaN  right_only
# 1761                      NaN  right_only
# 1762                      NaN  right_only
# 1763                      NaN  right_only
#
# [1764 rows x 7 columns]

# %%
print(f"Althought we still have {len(ids>>filter(_.organization_type.isnull()))} without Organization Types")
# Out:
# Althought we still have 499 without Organization Types

# %%
ids>>filter(_.name.str.contains('Council'))>>select(_.name, _.organization_type)
# Out:
#                                            name        organization_type
# 61             Calaveras Council of Governments   Council of Governments
# 73                    Cambria Community Council  Non-Profit Organization
# 384    Council of San Benito County Governments                      NaN
# 436               Fresno Council of Governments   Council of Governments
# 499                 Kern Council of Governments   Council of Governments
# 505      Lake County/City Area Planning Council                      NaN
# 539            Mendocino Council of Governments   Council of Governments
# 650      Sacramento Area Council of Governments   Council of Governments
# 673          San Joaquin Council of Governments   Council of Governments
# 679      San Luis Obispo Council of Governments   Council of Governments
# 695   Saratoga Area Senior Coordinating Council  Non-Profit Organization
# 739           Stanislaus Council of Governments   Council of Governments
# 786      Tuolumne County Transportation Council                      NaN
# 814    Victor Valley Community Services Council  Non-Profit Organization
# 910           Mohawk Valley Stewardship Council                      NaN
# 1035     Oakland Private Industry Council, Inc.                      NaN
# 1272       Council of Fresno County Governments                      NaN
# 1316         Kern County Council of Governments   Council of Governments
# 1328  San Gabriel Valley Council of Governments   Council of Governments
# 1362    South Bay Cities Council of Governments   Council of Governments
# 1458      Gateway Cities Council of Governments   Council of Governments
# 1475   Western Riverside Council Of Governments                      NaN
# 1673       Orange County Council of Governments   Council of Governments
# 1717       Council for Tribal Employment Rights                      NaN

# %%
#all
ids
# Out:
#                                     name ntd_id  itp_id  ct_code  district  \
# 0                          A-Paratransit    NaN     NaN      NaN       NaN
# 1                            ABC Shuttle    NaN     NaN      NaN       NaN
# 2                              Able Inc.    NaN     NaN      NaN       NaN
# 3                           Abrazar Inc.    NaN     NaN      NaN       NaN
# 4                        Access Services  90157     1.0   6312.0       7.0
# ...                                  ...    ...     ...      ...       ...
# 1759                         Leave Blank    NaN     NaN   5465.0      53.0
# 1760      U.S. Fish and Wildlife Service    NaN     NaN   6250.0      53.0
# 1761  Tidewater Southern Railway Company    NaN     NaN   6031.0      53.0
# 1762    Tri-Counties Regional Park Group    NaN     NaN   6176.0      53.0
# 1763               Trust for Public Land    NaN     NaN   6185.0      59.0
#
#             organization_type      _merge
# 0                         NaN   left_only
# 1                     Company   left_only
# 2     Non-Profit Organization   left_only
# 3     Non-Profit Organization   left_only
# 4          Independent Agency        both
# ...                       ...         ...
# 1759                      NaN  right_only
# 1760                      NaN  right_only
# 1761                      NaN  right_only
# 1762                      NaN  right_only
# 1763                      NaN  right_only
#
# [1764 rows x 7 columns]

# %%
import pandas as pd
from siuba import *
import numpy as np
from calitp import *

# %%
dla = pd.read_csv('gs://calitp-analytics-data/data-analyses/dla/dla_placenames.csv', index_col=[0])

# %%
dla
# Out:
#       ct_code                                           dla_name data_origin  \
# 0        6302  Humboldt Bay Harbor Recreation & Conservation ...  DLA Locode
# 1        6330           Willow Creek Community Services District  DLA Locode
# 2        5036                                           Trinidad  DLA Locode
# 3        5049                                              Ukiah  DLA Locode
# 4        5082                                            Willits  DLA Locode
# ...       ...                                                ...         ...
# 1036     5465                                        Leave Blank  DLA Locode
# 1037     6250                     U.S. Fish and Wildlife Service  DLA Locode
# 1038     6031                 Tidewater Southern Railway Company  DLA Locode
# 1039     6176                   Tri-Counties Regional Park Group  DLA Locode
# 1040     6185                              Trust for Public Land  DLA Locode
#
#      organization_type
# 0                  NaN
# 1                  NaN
# 2            City/Town
# 3            City/Town
# 4            City/Town
# ...                ...
# 1036               NaN
# 1037               NaN
# 1038               NaN
# 1039               NaN
# 1040               NaN
#
# [1041 rows x 4 columns]

# %%
dla = dla>>select(_.ct_code, _.dla_name, _.data_origin)

# %%
## importing previous NTD/ITP merge from 5310 analysis

# %%
m1 = pd.read_csv("gs://calitp-analytics-data/data-analyses/dla/ntd_itp_merge_.csv")
m1.ntd_id_x.fillna(m1["ntd_id_y"], inplace=True)
m1 = m1>>select(_.ntd_id_x,
                _.agency_name_ntd,
               _.name_airtable,
               _.doing_business_as,
                _.mobility_services_operated,
                _.itp_id, 
                _._merge
)
m1['_merge'].replace({"right_only":"In Airtable", "left_only":"In NTD", "both":"In NTD, Airtable"}, inplace=True)
m1 = m1.rename(columns={'_merge':'data_origin', 'ntd_id_x':'ntd_id'})

# %%
m1.sample()
# Out:
#    ntd_id agency_name_ntd   name_airtable doing_business_as  \
# 45  90238  City of Delano  City of Delano               NaN
#
#                       mobility_services_operated  itp_id       data_origin
# 45  Delano Area Rapid Transit,Delano Dial-A-Ride    91.0  In NTD, Airtable

# %%
#should come up blank
m1>>count(_.agency_name_ntd)>>arrange(-_.n)>>filter(_.n>1)
# Out:
# Empty DataFrame
# Columns: [agency_name_ntd, n]
# Index: []

# %%
m1.sample()
# Out:
#     ntd_id agency_name_ntd                    name_airtable doing_business_as  \
# 757    NaN             NaN  Solano Transportation Authority               NaN
#
#                   mobility_services_operated  itp_id  data_origin
# 757  Solano Mobility Local Taxi Card Program     NaN  In Airtable

# %%
m1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 853 entries, 0 to 852
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ntd_id                      242 non-null    object
#  1   agency_name_ntd             238 non-null    object
#  2   name_airtable               825 non-null    object
#  3   doing_business_as           86 non-null     object
#  4   mobility_services_operated  442 non-null    object
#  5   itp_id                      372 non-null    float64
#  6   data_origin                 853 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 46.8+ KB

# %%
# condensing agency name column. using NTD first, then filling in blanks with Airtable

# %%
m1.agency_name_ntd.fillna(m1['name_airtable'], inplace=True)

# %%
m1 = m1.rename(columns={'agency_name_ntd':'name'}).drop(columns={'name_airtable'})

# %% [markdown]
# ## Merging with DLA Locode

# %% [markdown]
# ##### first on `name`

# %%
cw1 = (pd.merge(dla, m1, left_on='dla_name', right_on='name', how='outer', indicator='merge_status'))

# %%
cw1.merge_status.value_counts()
# Out:
# left_only     936
# right_only    747
# both          106
# Name: merge_status, dtype: int64

# %%
cw1
# Out:
#       ct_code                                           dla_name  \
# 0      6302.0  Humboldt Bay Harbor Recreation & Conservation ...
# 1      6330.0           Willow Creek Community Services District
# 2      5036.0                                           Trinidad
# 3      5049.0                                              Ukiah
# 4      5082.0                                            Willits
# ...       ...                                                ...
# 1784      NaN                                                NaN
# 1785      NaN                                                NaN
# 1786      NaN                                                NaN
# 1787      NaN                                                NaN
# 1788      NaN                                                NaN
#
#      data_origin_x ntd_id                  name doing_business_as  \
# 0       DLA Locode    NaN                   NaN               NaN
# 1       DLA Locode    NaN                   NaN               NaN
# 2       DLA Locode    NaN                   NaN               NaN
# 3       DLA Locode    NaN                   NaN               NaN
# 4       DLA Locode    NaN                   NaN               NaN
# ...            ...    ...                   ...               ...
# 1784           NaN    NaN   Willits Seniors Inc               NaN
# 1785           NaN    NaN  Work Training Center               NaN
# 1786           NaN    NaN              Worldpay               NaN
# 1787           NaN    NaN         Yellow Cab CA               NaN
# 1788           NaN    NaN             Zonar Inc               NaN
#
#                              mobility_services_operated  itp_id data_origin_y  \
# 0                                                   NaN     NaN           NaN
# 1                                                   NaN     NaN           NaN
# 2                                                   NaN     NaN           NaN
# 3                                                   NaN     NaN           NaN
# 4                                                   NaN     NaN           NaN
# ...                                                 ...     ...           ...
# 1784   Willits Paratransit,Willits Harrah Senior Center     NaN   In Airtable
# 1785                                                NaN   471.0   In Airtable
# 1786                                                NaN     NaN   In Airtable
# 1787  Aliso Viejo Senior Mobility Program,Garden Gro...     NaN   In Airtable
# 1788                                                NaN     NaN   In Airtable
#
#      merge_status
# 0       left_only
# 1       left_only
# 2       left_only
# 3       left_only
# 4       left_only
# ...           ...
# 1784   right_only
# 1785   right_only
# 1786   right_only
# 1787   right_only
# 1788   right_only
#
# [1789 rows x 10 columns]

# %%
cw_nomatch_dla = (cw1>>filter(_.merge_status=='left_only')>>select(_.ct_code,
                                                                     _.dla_name, _.data_origin_x))

# %%
cw1 = (cw1>>filter(_.merge_status=='both'))
cw1.merge_status.replace({"both":"DLA match on name"}, inplace=True)
# Out:
# /tmp/ipykernel_2245/2744787579.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cw1.merge_status.replace({"both":"DLA match on name"}, inplace=True)

# %%
cw1.sample()
# Out:
#      ct_code            dla_name data_origin_x ntd_id                name  \
# 642   5953.0  Los Angeles County    DLA Locode    NaN  Los Angeles County
#
#                                      doing_business_as  \
# 642  LA DPW,LA County,Los Angeles DPW,Los Angeles C...
#
#                             mobility_services_operated  itp_id data_origin_y  \
# 642  the Link Florence-Firestone/Walnut Park,the Li...   179.0   In Airtable
#
#           merge_status
# 642  DLA match on name

# %% [markdown]
# ##### second on `doing_business_as`

# %%
cw2 = (pd.merge(cw_nomatch_dla, m1, left_on='dla_name', right_on='doing_business_as', how='outer', indicator='merge_status'))

# %%
cw2.merge_status.value_counts()
# Out:
# left_only     932
# right_only    849
# both            4
# Name: merge_status, dtype: int64

# %%
add1 = (cw2>>filter(_.merge_status=='both'))
add1['merge_status']= add1['merge_status'].replace({"both":"DLA match on doing business as"})
# Out:
# /tmp/ipykernel_2245/1161878024.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   add1['merge_status']= add1['merge_status'].replace({"both":"DLA match on doing business as"})

# %%
add1
# Out:
#      ct_code               dla_name data_origin_x ntd_id  \
# 237   6039.0       Petaluma Transit    DLA Locode  90213
# 289   6331.0  Sonoma County Transit    DLA Locode  90089
# 291   6341.0      Tri Delta Transit    DLA Locode  90162
# 490   6008.0    Fresno Area Express    DLA Locode  90027
#
#                                            name      doing_business_as  \
# 237                            City of Petaluma       Petaluma Transit
# 289                            County of Sonoma  Sonoma County Transit
# 291  The Eastern Contra Costa Transit Authority      Tri Delta Transit
# 490                              City of Fresno    Fresno Area Express
#
#                             mobility_services_operated  itp_id  \
# 237              Petaluma Transit,Petaluma Paratransit   247.0
# 289  Sonoma County Transit,Healdsburg Shuttle,Sonom...   314.0
# 291                                                NaN   336.0
# 490                 Fresno Area Express,FAX Handy Ride   116.0
#
#           data_origin                    merge_status
# 237  In NTD, Airtable  DLA match on doing business as
# 289  In NTD, Airtable  DLA match on doing business as
# 291  In NTD, Airtable  DLA match on doing business as
# 490  In NTD, Airtable  DLA match on doing business as

# %%
cw_nomatch_dla_2 = (cw2>>filter(_.merge_status=='left_only')>>select(_.ct_code,
                                                                     _.dla_name, _.data_origin_x))

# %% [markdown]
# ##### third on `mobility_services_operated`

# %%
cw3 = (pd.merge(cw_nomatch_dla_2, m1, left_on='dla_name', right_on='mobility_services_operated', how='outer', indicator='merge_status'))

# %%
cw3.merge_status.value_counts()
# Out:
# left_only     931
# right_only    852
# both            1
# Name: merge_status, dtype: int64

# %%
add2 = (cw3>>filter(_.merge_status=='both'))

# %%
add2['merge_status']= add2['merge_status'].replace({"both":"DLA match on mobility services operated"})
# Out:
# /tmp/ipykernel_2245/3105742984.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   add2['merge_status']= add2['merge_status'].replace({"both":"DLA match on mobility services operated"})

# %%
add2
# Out:
#      ct_code          dla_name data_origin_x ntd_id  \
# 301   6295.0  Capitol Corridor    DLA Locode    NaN
#
#                                         name doing_business_as  \
# 301  Capitol Corridor Joint Powers Authority               NaN
#
#     mobility_services_operated  itp_id  data_origin  \
# 301           Capitol Corridor    56.0  In Airtable
#
#                                 merge_status
# 301  DLA match on mobility services operated

# %%
nomatch = (cw3>>filter(_.merge_status!='both'))

# %%
nomatch['merge_status']= nomatch['merge_status'].replace({"left_only":"No Match", "right_only":"No Match"})
# Out:
# /tmp/ipykernel_2245/1410011296.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nomatch['merge_status']= nomatch['merge_status'].replace({"left_only":"No Match", "right_only":"No Match"})

# %%
nomatch
# Out:
#       ct_code                                           dla_name  \
# 0      6302.0  Humboldt Bay Harbor Recreation & Conservation ...
# 1      6330.0           Willow Creek Community Services District
# 2      5036.0                                           Trinidad
# 3      5049.0                                              Ukiah
# 4      5082.0                                            Willits
# ...       ...                                                ...
# 1779      NaN                                                NaN
# 1780      NaN                                                NaN
# 1781      NaN                                                NaN
# 1782      NaN                                                NaN
# 1783      NaN                                                NaN
#
#      data_origin_x ntd_id                                            name  \
# 0       DLA Locode    NaN                                             NaN
# 1       DLA Locode    NaN                                             NaN
# 2       DLA Locode    NaN                                             NaN
# 3       DLA Locode    NaN                                             NaN
# 4       DLA Locode    NaN                                             NaN
# ...            ...    ...                                             ...
# 1779           NaN    NaN                                     Vivalon Inc
# 1780           NaN    NaN             Volunteer Transportation Center Inc
# 1781           NaN    NaN  West Berkeley Transportation Management Agency
# 1782           NaN    NaN                             Willits Seniors Inc
# 1783           NaN    NaN                                   Yellow Cab CA
#
#      doing_business_as                         mobility_services_operated  \
# 0                  NaN                                                NaN
# 1                  NaN                                                NaN
# 2                  NaN                                                NaN
# 3                  NaN                                                NaN
# 4                  NaN                                                NaN
# ...                ...                                                ...
# 1779               NaN                    Golden Gate Transit Paratransit
# 1780               NaN                               Volunteers on the Go
# 1781               NaN                              West Berkeley Shuttle
# 1782               NaN   Willits Paratransit,Willits Harrah Senior Center
# 1783               NaN  Aliso Viejo Senior Mobility Program,Garden Gro...
#
#       itp_id  data_origin merge_status
# 0        NaN          NaN     No Match
# 1        NaN          NaN     No Match
# 2        NaN          NaN     No Match
# 3        NaN          NaN     No Match
# 4        NaN          NaN     No Match
# ...      ...          ...          ...
# 1779     NaN  In Airtable     No Match
# 1780     NaN  In Airtable     No Match
# 1781   365.0  In Airtable     No Match
# 1782     NaN  In Airtable     No Match
# 1783     NaN  In Airtable     No Match
#
# [1783 rows x 10 columns]

# %% [markdown]
# ### Concating all matches

# %%
cw = pd.concat([cw1, add1], ignore_index=True, sort=False)
cw_match = pd.concat([cw, add2], ignore_index=True, sort=False)

# %%
cw_match.sample(5)
# Out:
#     ct_code                                 dla_name data_origin_x ntd_id  \
# 79   6165.0                 Riverside Transit Agency    DLA Locode  90031
# 32   6497.0                    Solano County Transit    DLA Locode  90232
# 83   5948.0                              Inyo County    DLA Locode    NaN
# 1    6140.0         Mendocino Council of Governments    DLA Locode    NaN
# 16   6129.0  Colusa County Transportation Commission    DLA Locode    NaN
#
#                                        name doing_business_as  \
# 79                 Riverside Transit Agency               NaN
# 32                    Solano County Transit               NaN
# 83                              Inyo County               NaN
# 1          Mendocino Council of Governments               NaN
# 16  Colusa County Transportation Commission               NaN
#
#                           mobility_services_operated  itp_id  \
# 79   Riverside Transit,Riverside Transit Dial-A-Ride   269.0
# 32  Solano Express,SolTrans,SolTrans ADA Paratransit   310.0
# 83                                               NaN     NaN
# 1                                                NaN     NaN
# 16                                               NaN     NaN
#
#        data_origin_y       merge_status data_origin
# 79  In NTD, Airtable  DLA match on name         NaN
# 32  In NTD, Airtable  DLA match on name         NaN
# 83       In Airtable  DLA match on name         NaN
# 1        In Airtable  DLA match on name         NaN
# 16       In Airtable  DLA match on name         NaN

# %%
cw_match.data_origin_y.fillna(cw_match['data_origin'], inplace=True)

# %%
cw_match = cw_match.drop(columns='data_origin')

# %%
cw_match.data_origin_y.value_counts()
# Out:
# In Airtable         57
# In NTD, Airtable    53
# In NTD               1
# Name: data_origin_y, dtype: int64

# %%
cw_match['data_origin'] = cw_match['data_origin_y'].astype(str) + ' and DLA'

# %%
cw_match = cw_match.drop(columns={'data_origin_x','data_origin_y'})

# %%
cw_match.sample(5)
# Out:
#     ct_code                                       dla_name      ntd_id  \
# 62   6094.0       Tulare County Association of Governments         NaN
# 71   5953.0                             Los Angeles County         NaN
# 35   6000.0  San Francisco Bay Area Rapid Transit District       90003
# 59   6285.0                          Kern Regional Transit  9R02-91059
# 54   5949.0                         San Luis Obispo County         NaN
#
#                                              name  \
# 62       Tulare County Association of Governments
# 71                             Los Angeles County
# 35  San Francisco Bay Area Rapid Transit District
# 59                          Kern Regional Transit
# 54                         San Luis Obispo County
#
#                                     doing_business_as  \
# 62                                                NaN
# 71  LA DPW,LA County,Los Angeles DPW,Los Angeles C...
# 35                                                NaN
# 59                                                NaN
# 54                                                NaN
#
#                            mobility_services_operated  itp_id  \
# 62                                                NaN     NaN
# 71  the Link Florence-Firestone/Walnut Park,the Li...   179.0
# 35                             Bay Area Rapid Transit   279.0
# 59  Kern Transit,Mojave Dial-A-Ride,Rosamonde Dial...   146.0
# 54                                                NaN     NaN
#
#          merge_status               data_origin
# 62  DLA match on name       In Airtable and DLA
# 71  DLA match on name       In Airtable and DLA
# 35  DLA match on name  In NTD, Airtable and DLA
# 59  DLA match on name  In NTD, Airtable and DLA
# 54  DLA match on name       In Airtable and DLA

# %%
#cw_match.to_csv(f"{GCS_FILE_PATH}dla_ntd_itp_matches.csv')

# %%
#concating to have all records
cw_all = pd.concat([cw_match, nomatch], ignore_index=True, sort=False)

# %%
cw_all.sample(5)
# Out:
#       ct_code                              dla_name ntd_id  \
# 405    6257.0         Crockett Communuty Foundation    NaN
# 1748      NaN                                   NaN    NaN
# 737    6438.0  Koreatown Youth and Community Center    NaN
# 1255      NaN                                   NaN    NaN
# 566    5044.0                               Visalia    NaN
#
#                     name doing_business_as  mobility_services_operated  \
# 405                  NaN               NaN                         NaN
# 1748             Ecolane               NaN  RTD Van Go!,Cruz On-demand
# 737                  NaN               NaN                         NaN
# 1255  Cloverdale Transit               NaN                         NaN
# 566                  NaN               NaN                         NaN
#
#       itp_id merge_status  data_origin data_origin_x
# 405      NaN     No Match          NaN    DLA Locode
# 1748     NaN     No Match  In Airtable           NaN
# 737      NaN     No Match          NaN    DLA Locode
# 1255     NaN     No Match  In Airtable           NaN
# 566      NaN     No Match          NaN    DLA Locode

# %%
cw_all.data_origin.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1894 entries, 0 to 1893
# Series name: data_origin
# Non-Null Count  Dtype
# --------------  -----
# 963 non-null    object
# dtypes: object(1)
# memory usage: 14.9+ KB

# %%
cw_all.data_origin.fillna(cw_all['data_origin_x'], inplace=True)
cw_all.name.fillna(cw_all['dla_name'], inplace=True)
cw_all = cw_all.drop(columns={'data_origin_x', 'dla_name'})

# %%
cw_all.data_origin.value_counts()
# Out:
# DLA Locode                  931
# In Airtable                 615
# In NTD, Airtable            209
# In Airtable and DLA          57
# In NTD, Airtable and DLA     53
# In NTD                       28
# In NTD and DLA                1
# Name: data_origin, dtype: int64

# %%
cw_all>>filter(_.data_origin.isnull())
# Out:
# Empty DataFrame
# Columns: [ct_code, ntd_id, name, doing_business_as, mobility_services_operated, itp_id, merge_status, data_origin]
# Index: []

# %%
cw_all.sample(5)
# Out:
#      ct_code ntd_id                                         name  \
# 524   5146.0    NaN                                     Coalinga
# 903   6468.0    NaN                 San Elijo Lagoon Conservancy
# 558   6265.0    NaN  Kern County Parks and Recreation Department
# 345   6057.0    NaN                              Port Of Oakland
# 957   5410.0    NaN                                       Irvine
#
#     doing_business_as mobility_services_operated  itp_id merge_status  \
# 524               NaN                        NaN     NaN     No Match
# 903               NaN                        NaN     NaN     No Match
# 558               NaN                        NaN     NaN     No Match
# 345               NaN                        NaN     NaN     No Match
# 957               NaN                        NaN     NaN     No Match
#
#     data_origin
# 524  DLA Locode
# 903  DLA Locode
# 558  DLA Locode
# 345  DLA Locode
# 957  DLA Locode

# %%
cw_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1894 entries, 0 to 1893
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ct_code                     1042 non-null   float64
#  1   ntd_id                      298 non-null    object
#  2   name                        1894 non-null   object
#  3   doing_business_as           99 non-null     object
#  4   mobility_services_operated  497 non-null    object
#  5   itp_id                      433 non-null    float64
#  6   merge_status                1894 non-null   object
#  7   data_origin                 1894 non-null   object
# dtypes: float64(2), object(6)
# memory usage: 118.5+ KB

# %%
cw_all>>filter(_.mobility_services_operated.notnull())
# Out:
#       ct_code      ntd_id                                            name  \
# 0      6241.0  9R02-91047                     Mendocino Transit Authority
# 3      6428.0  9R02-91097                 Redwood Coast Transit Authority
# 4      6436.0  9R02-91053                          Lake Transit Authority
# 5      6162.0  9R02-91036                      Humboldt Transit Authority
# 6      5908.0  9R02-91089                                   Tehama County
# ...       ...         ...                                             ...
# 1889      NaN         NaN                                     Vivalon Inc
# 1890      NaN         NaN             Volunteer Transportation Center Inc
# 1891      NaN         NaN  West Berkeley Transportation Management Agency
# 1892      NaN         NaN                             Willits Seniors Inc
# 1893      NaN         NaN                                   Yellow Cab CA
#
#      doing_business_as                         mobility_services_operated  \
# 0                  NaN  Mendocino Transit Authority,Ukiah Dial-A-Ride,...
# 3                  NaN    Redwood Coast Transit,Redwood Coast Dial-A-Ride
# 4                  NaN  Lake Transit,Clearlake/Lower Lake Dial-A-Ride,...
# 5                  NaN  Humboldt Transit Authority Dial-A-Ride,Redwood...
# 6                  NaN                 Tehama Rural Area eXpress,ParaTRAX
# ...                ...                                                ...
# 1889               NaN                    Golden Gate Transit Paratransit
# 1890               NaN                               Volunteers on the Go
# 1891               NaN                              West Berkeley Shuttle
# 1892               NaN   Willits Paratransit,Willits Harrah Senior Center
# 1893               NaN  Aliso Viejo Senior Mobility Program,Garden Gro...
#
#       itp_id       merge_status               data_origin
# 0      198.0  DLA match on name  In NTD, Airtable and DLA
# 3      261.0  DLA match on name  In NTD, Airtable and DLA
# 4      159.0  DLA match on name  In NTD, Airtable and DLA
# 5      135.0  DLA match on name  In NTD, Airtable and DLA
# 6      334.0  DLA match on name  In NTD, Airtable and DLA
# ...      ...                ...                       ...
# 1889     NaN           No Match               In Airtable
# 1890     NaN           No Match               In Airtable
# 1891   365.0           No Match               In Airtable
# 1892     NaN           No Match               In Airtable
# 1893     NaN           No Match               In Airtable
#
# [497 rows x 8 columns]

# %%
cw_all.data_origin.value_counts()
# Out:
# DLA Locode                  931
# In Airtable                 615
# In NTD, Airtable            209
# In Airtable and DLA          57
# In NTD, Airtable and DLA     53
# In NTD                       28
# In NTD and DLA                1
# Name: data_origin, dtype: int64

# %%
cw_all.merge_status.value_counts()
# Out:
# No Match                                   1783
# DLA match on name                           106
# DLA match on doing business as                4
# DLA match on mobility services operated       1
# Name: merge_status, dtype: int64

# %%
cw_all>>filter(_.merge_status=='DLA match on mobility services operated')
# Out:
#      ct_code ntd_id                                     name  \
# 110   6295.0    NaN  Capitol Corridor Joint Powers Authority
#
#     doing_business_as mobility_services_operated  itp_id  \
# 110               NaN           Capitol Corridor    56.0
#
#                                 merge_status          data_origin
# 110  DLA match on mobility services operated  In Airtable and DLA

# %%
cw_all>>filter(_.doing_business_as.notnull())>>filter(_.merge_status=='DLA match on doing business as')
# Out:
#      ct_code ntd_id                                        name  \
# 106   6039.0  90213                            City of Petaluma
# 107   6331.0  90089                            County of Sonoma
# 108   6341.0  90162  The Eastern Contra Costa Transit Authority
# 109   6008.0  90027                              City of Fresno
#
#          doing_business_as                         mobility_services_operated  \
# 106       Petaluma Transit              Petaluma Transit,Petaluma Paratransit
# 107  Sonoma County Transit  Sonoma County Transit,Healdsburg Shuttle,Sonom...
# 108      Tri Delta Transit                                                NaN
# 109    Fresno Area Express                 Fresno Area Express,FAX Handy Ride
#
#      itp_id                    merge_status               data_origin
# 106   247.0  DLA match on doing business as  In NTD, Airtable and DLA
# 107   314.0  DLA match on doing business as  In NTD, Airtable and DLA
# 108   336.0  DLA match on doing business as  In NTD, Airtable and DLA
# 109   116.0  DLA match on doing business as  In NTD, Airtable and DLA

# %%
cw_all = cw_all[['ct_code', 'ntd_id', 'itp_id', 'name', 'merge_status', 'data_origin']]

# %%
cw_all
# Out:
#       ct_code      ntd_id  itp_id  \
# 0      6241.0  9R02-91047   198.0
# 1      6140.0         NaN     NaN
# 2      6133.0         NaN     NaN
# 3      6428.0  9R02-91097   261.0
# 4      6436.0  9R02-91053   159.0
# ...       ...         ...     ...
# 1889      NaN         NaN     NaN
# 1890      NaN         NaN     NaN
# 1891      NaN         NaN   365.0
# 1892      NaN         NaN     NaN
# 1893      NaN         NaN     NaN
#
#                                                 name       merge_status  \
# 0                        Mendocino Transit Authority  DLA match on name
# 1                   Mendocino Council of Governments  DLA match on name
# 2         Humboldt County Association of Governments  DLA match on name
# 3                    Redwood Coast Transit Authority  DLA match on name
# 4                             Lake Transit Authority  DLA match on name
# ...                                              ...                ...
# 1889                                     Vivalon Inc           No Match
# 1890             Volunteer Transportation Center Inc           No Match
# 1891  West Berkeley Transportation Management Agency           No Match
# 1892                             Willits Seniors Inc           No Match
# 1893                                   Yellow Cab CA           No Match
#
#                    data_origin
# 0     In NTD, Airtable and DLA
# 1          In Airtable and DLA
# 2          In Airtable and DLA
# 3     In NTD, Airtable and DLA
# 4     In NTD, Airtable and DLA
# ...                        ...
# 1889               In Airtable
# 1890               In Airtable
# 1891               In Airtable
# 1892               In Airtable
# 1893               In Airtable
#
# [1894 rows x 6 columns]

# %%
#cw_all.to_csv(f"{GCS_FILE_PATH}dla_ntd_itp_crosswalk.csv")

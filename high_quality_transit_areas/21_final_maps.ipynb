# %% [markdown]
# # Final Maps

# %% [markdown]
# ## Data Flow

# %%
from IPython.display import IFrame 
import calitp_data_analysis.magics

# %%
# %%capture_parameters
#
# hq_stops_url = 'https://gis.data.ca.gov/datasets/f6c30480f0e84be699383192c099a6a4_0/explore?'
# hq_stops_url

# %% [markdown]
# ## [High Quality Transit Stops]({hq_stops_url})

# %%
IFrame(hq_stops_url, 1000, 500)

# %%
# %%capture_parameters
#
# hq_areas_url = 'https://gis.data.ca.gov/datasets/863e61eacbf3463ab239beb3cee4a2c3_0/explore'
# hq_areas_url

# %% [markdown]
# ## [High Quality Transit Areas]({hq_areas_url})

# %%
IFrame(hq_areas_url, 1000, 500)

# %% [markdown]
# # Whittier HQ transit stops

# %%
import pandas as pd
import geopandas as gpd
import intake
import shapely

catalog = intake.open_catalog("*.yml")
# Out:
# /opt/conda/lib/python3.9/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(
# /tmp/ipykernel_393/3791979869.py:2: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd

# %%
df = catalog.hqta_points.read()

# %%
df.columns
# Out:
# Index(['agency_name_primary', 'hqta_type', 'stop_id', 'route_id',
#        'hqta_details', 'agency_name_secondary', 'base64_url_primary',
#        'base64_url_secondary', 'geometry'],
#       dtype='object')

# %%
agencies = ["LA Metro", "Foothill", "Montebello", "OCTA", "LADPW"]
df = df[(df.agency_name_primary.isin(agencies))]

# %%
centroid = (-118.030246, 33.965747)

whittier_centroid = gpd.GeoSeries(
    shapely.geometry.Point(centroid), crs="EPSG:4326"
).to_frame(name="geometry")

# %%
whittier_buffered = whittier_centroid.assign(
    geometry = whittier_centroid.geometry.to_crs("EPSG:2229").buffer(
        5280*5)
)

# %%
df2 = gpd.sjoin(
    df.to_crs("EPSG:2229"),
    whittier_buffered,
    how = "inner",
    predicate = "intersects"
).drop(columns = "index_right")

# %%
df2.hqta_type.value_counts()
# Out:
# hq_corridor_bus    309
# major_stop_bus      90
# Name: hqta_type, dtype: int64

# %%
df2.hqta_details.value_counts()
# Out:
# stop_along_hq_bus_corridor_single_operator       309
# intersection_2_bus_routes_same_operator           56
# intersection_2_bus_routes_different_operators     34
# Name: hqta_details, dtype: int64

# %%
df3 = df2[(df2.hqta_details.isin(
    ["intersection_2_bus_routes_same_operator", 
    "intersection_2_bus_routes_different_operator"]))]

# %%
df3
# Out:
#       agency_name_primary       hqta_type  stop_id   route_id  \
# 8643             Foothill  major_stop_bus     1398        281
# 8644             Foothill  major_stop_bus     1399        281
# 8645             Foothill  major_stop_bus     1406        282
# 8646             Foothill  major_stop_bus     1407        281
# 8647             Foothill  major_stop_bus     1411        281
# 8648             Foothill  major_stop_bus     1412        282
# 8668             Foothill  major_stop_bus     1666        185
# 8669             Foothill  major_stop_bus     1672        185
# 8670             Foothill  major_stop_bus     1678        282
# 8671             Foothill  major_stop_bus     1679        185
# 8674             Foothill  major_stop_bus     1685        185
# 8675             Foothill  major_stop_bus     1692        282
# 8676             Foothill  major_stop_bus     1693        282
# 8752             Foothill  major_stop_bus     2694        285
# 8773             Foothill  major_stop_bus     3022        282
# 8774             Foothill  major_stop_bus     3025        185
# 8776             Foothill  major_stop_bus     3035        281
# 8779             Foothill  major_stop_bus     3130        282
# 22126            LA Metro  major_stop_bus        1  108-13167
# 22306            LA Metro  major_stop_bus    11145  460-13167
# 22312            LA Metro  major_stop_bus    11158  460-13167
# 22574            LA Metro  major_stop_bus    12564   62-13167
# 22575            LA Metro  major_stop_bus    12567  120-13167
# 22602            LA Metro  major_stop_bus    12763  108-13167
# 22604            LA Metro  major_stop_bus    12766  265-13167
# 22607            LA Metro  major_stop_bus    12843  460-13167
# 22608            LA Metro  major_stop_bus    12844  460-13167
# 23137            LA Metro  major_stop_bus    14850   62-13167
# 23140            LA Metro  major_stop_bus    14870   62-13167
# 24011            LA Metro  major_stop_bus     2628  460-13167
# 24169            LA Metro  major_stop_bus    32121  108-13167
# 24396            LA Metro  major_stop_bus     4066   62-13167
# 24399            LA Metro  major_stop_bus     4078   62-13167
# 24444            LA Metro  major_stop_bus     4291  265-13167
# 24447            LA Metro  major_stop_bus     4299  108-13167
# 24449            LA Metro  major_stop_bus     4305  265-13167
# 24454            LA Metro  major_stop_bus     4384  460-13167
# 24455            LA Metro  major_stop_bus     4385  460-13167
# 24648            LA Metro  major_stop_bus     5140   62-13167
# 24769            LA Metro  major_stop_bus     5627  265-13167
# 24905            LA Metro  major_stop_bus     6494  265-13167
# 25280            LA Metro  major_stop_bus     8307  266-13167
# 25281            LA Metro  major_stop_bus     8308  266-13167
# 25972               LADPW  major_stop_bus  2525394      13059
# 25973               LADPW  major_stop_bus  2525395      13059
# 26101               LADPW  major_stop_bus  2574356      13058
# 28625          Montebello  major_stop_bus     1004         10
# 28632          Montebello  major_stop_bus    10125         10
# 28633          Montebello  major_stop_bus    10127         10
# 28641          Montebello  major_stop_bus     1036         50
# 28643          Montebello  major_stop_bus     1061         60
# 28644          Montebello  major_stop_bus     1063         60
# 28647          Montebello  major_stop_bus     1074         10
# 28649          Montebello  major_stop_bus     1097         10
# 28734          Montebello  major_stop_bus     6043         60
# 28735          Montebello  major_stop_bus     6047         60
#
#                                   hqta_details agency_name_secondary  \
# 8643   intersection_2_bus_routes_same_operator              Foothill
# 8644   intersection_2_bus_routes_same_operator              Foothill
# 8645   intersection_2_bus_routes_same_operator              Foothill
# 8646   intersection_2_bus_routes_same_operator              Foothill
# 8647   intersection_2_bus_routes_same_operator              Foothill
# 8648   intersection_2_bus_routes_same_operator              Foothill
# 8668   intersection_2_bus_routes_same_operator              Foothill
# 8669   intersection_2_bus_routes_same_operator              Foothill
# 8670   intersection_2_bus_routes_same_operator              Foothill
# 8671   intersection_2_bus_routes_same_operator              Foothill
# 8674   intersection_2_bus_routes_same_operator              Foothill
# 8675   intersection_2_bus_routes_same_operator              Foothill
# 8676   intersection_2_bus_routes_same_operator              Foothill
# 8752   intersection_2_bus_routes_same_operator              Foothill
# 8773   intersection_2_bus_routes_same_operator              Foothill
# 8774   intersection_2_bus_routes_same_operator              Foothill
# 8776   intersection_2_bus_routes_same_operator              Foothill
# 8779   intersection_2_bus_routes_same_operator              Foothill
# 22126  intersection_2_bus_routes_same_operator              LA Metro
# 22306  intersection_2_bus_routes_same_operator              LA Metro
# 22312  intersection_2_bus_routes_same_operator              LA Metro
# 22574  intersection_2_bus_routes_same_operator              LA Metro
# 22575  intersection_2_bus_routes_same_operator              LA Metro
# 22602  intersection_2_bus_routes_same_operator              LA Metro
# 22604  intersection_2_bus_routes_same_operator              LA Metro
# 22607  intersection_2_bus_routes_same_operator              LA Metro
# 22608  intersection_2_bus_routes_same_operator              LA Metro
# 23137  intersection_2_bus_routes_same_operator              LA Metro
# 23140  intersection_2_bus_routes_same_operator              LA Metro
# 24011  intersection_2_bus_routes_same_operator              LA Metro
# 24169  intersection_2_bus_routes_same_operator              LA Metro
# 24396  intersection_2_bus_routes_same_operator              LA Metro
# 24399  intersection_2_bus_routes_same_operator              LA Metro
# 24444  intersection_2_bus_routes_same_operator              LA Metro
# 24447  intersection_2_bus_routes_same_operator              LA Metro
# 24449  intersection_2_bus_routes_same_operator              LA Metro
# 24454  intersection_2_bus_routes_same_operator              LA Metro
# 24455  intersection_2_bus_routes_same_operator              LA Metro
# 24648  intersection_2_bus_routes_same_operator              LA Metro
# 24769  intersection_2_bus_routes_same_operator              LA Metro
# 24905  intersection_2_bus_routes_same_operator              LA Metro
# 25280  intersection_2_bus_routes_same_operator              LA Metro
# 25281  intersection_2_bus_routes_same_operator              LA Metro
# 25972  intersection_2_bus_routes_same_operator                 LADPW
# 25973  intersection_2_bus_routes_same_operator                 LADPW
# 26101  intersection_2_bus_routes_same_operator                 LADPW
# 28625  intersection_2_bus_routes_same_operator            Montebello
# 28632  intersection_2_bus_routes_same_operator            Montebello
# 28633  intersection_2_bus_routes_same_operator            Montebello
# 28641  intersection_2_bus_routes_same_operator            Montebello
# 28643  intersection_2_bus_routes_same_operator            Montebello
# 28644  intersection_2_bus_routes_same_operator            Montebello
# 28647  intersection_2_bus_routes_same_operator            Montebello
# 28649  intersection_2_bus_routes_same_operator            Montebello
# 28734  intersection_2_bus_routes_same_operator            Montebello
# 28735  intersection_2_bus_routes_same_operator            Montebello
#
#                                       base64_url_primary  \
# 8643   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8644   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8645   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8646   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8647   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8648   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8668   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8669   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8670   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8671   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8674   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8675   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8676   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8752   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8773   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8774   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8776   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8779   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 22126  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 22306  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 22312  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 22574  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 22575  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 22602  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 22604  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 22607  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 22608  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 23137  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 23140  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 24011  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 24169  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 24396  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 24399  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 24444  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 24447  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 24449  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 24454  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 24455  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 24648  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 24769  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 24905  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 25280  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 25281  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 25972  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...
# 25973  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...
# 26101  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...
# 28625  aHR0cHM6Ly9tYmwucmlkZXJhbGVydHMuY29tL2luZm9wb2...
# 28632  aHR0cHM6Ly9tYmwucmlkZXJhbGVydHMuY29tL2luZm9wb2...
# 28633  aHR0cHM6Ly9tYmwucmlkZXJhbGVydHMuY29tL2luZm9wb2...
# 28641  aHR0cHM6Ly9tYmwucmlkZXJhbGVydHMuY29tL2luZm9wb2...
# 28643  aHR0cHM6Ly9tYmwucmlkZXJhbGVydHMuY29tL2luZm9wb2...
# 28644  aHR0cHM6Ly9tYmwucmlkZXJhbGVydHMuY29tL2luZm9wb2...
# 28647  aHR0cHM6Ly9tYmwucmlkZXJhbGVydHMuY29tL2luZm9wb2...
# 28649  aHR0cHM6Ly9tYmwucmlkZXJhbGVydHMuY29tL2luZm9wb2...
# 28734  aHR0cHM6Ly9tYmwucmlkZXJhbGVydHMuY29tL2luZm9wb2...
# 28735  aHR0cHM6Ly9tYmwucmlkZXJhbGVydHMuY29tL2luZm9wb2...
#
#                                     base64_url_secondary  \
# 8643   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8644   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8645   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8646   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8647   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8648   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8668   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8669   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8670   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8671   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8674   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8675   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8676   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8752   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8773   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8774   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8776   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 8779   aHR0cHM6Ly9mb290aGlsbHRyYW5zaXQucmlkZXJhbGVydH...
# 22126  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 22306  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 22312  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 22574  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 22575  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 22602  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 22604  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 22607  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 22608  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 23137  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 23140  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 24011  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 24169  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 24396  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 24399  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 24444  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 24447  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 24449  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 24454  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 24455  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 24648  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 24769  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 24905  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 25280  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 25281  aHR0cHM6Ly9naXRsYWIuY29tL0xBQ01UQS9ndGZzX2J1cy...
# 25972  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...
# 25973  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...
# 26101  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...
# 28625  aHR0cHM6Ly9tYmwucmlkZXJhbGVydHMuY29tL2luZm9wb2...
# 28632  aHR0cHM6Ly9tYmwucmlkZXJhbGVydHMuY29tL2luZm9wb2...
# 28633  aHR0cHM6Ly9tYmwucmlkZXJhbGVydHMuY29tL2luZm9wb2...
# 28641  aHR0cHM6Ly9tYmwucmlkZXJhbGVydHMuY29tL2luZm9wb2...
# 28643  aHR0cHM6Ly9tYmwucmlkZXJhbGVydHMuY29tL2luZm9wb2...
# 28644  aHR0cHM6Ly9tYmwucmlkZXJhbGVydHMuY29tL2luZm9wb2...
# 28647  aHR0cHM6Ly9tYmwucmlkZXJhbGVydHMuY29tL2luZm9wb2...
# 28649  aHR0cHM6Ly9tYmwucmlkZXJhbGVydHMuY29tL2luZm9wb2...
# 28734  aHR0cHM6Ly9tYmwucmlkZXJhbGVydHMuY29tL2luZm9wb2...
# 28735  aHR0cHM6Ly9tYmwucmlkZXJhbGVydHMuY29tL2luZm9wb2...
#
#                               geometry
# 8643   POINT (6570548.556 1827200.287)
# 8644   POINT (6570681.319 1827115.168)
# 8645   POINT (6567803.855 1828438.394)
# 8646   POINT (6567721.428 1828435.103)
# 8647   POINT (6569082.234 1827816.011)
# 8648   POINT (6569068.305 1827769.426)
# 8668   POINT (6572988.116 1826439.774)
# 8669   POINT (6571570.438 1821651.543)
# 8670   POINT (6571891.059 1822756.148)
# 8671   POINT (6571850.685 1822942.097)
# 8674   POINT (6571300.866 1821033.883)
# 8675   POINT (6572330.030 1824243.277)
# 8676   POINT (6572233.956 1824232.690)
# 8752   POINT (6561966.322 1802952.753)
# 8773   POINT (6572784.480 1826380.380)
# 8774   POINT (6572819.385 1826237.008)
# 8776   POINT (6573039.102 1826247.643)
# 8779   POINT (6571514.443 1821402.967)
# 22126  POINT (6527371.018 1812665.827)
# 22306  POINT (6532946.128 1792276.055)
# 22312  POINT (6536755.024 1792274.161)
# 22574  POINT (6539684.129 1793635.892)
# 22575  POINT (6539653.132 1801127.987)
# 22602  POINT (6527085.036 1811270.875)
# 22604  POINT (6527467.128 1812662.079)
# 22607  POINT (6536902.131 1790727.004)
# 22608  POINT (6536668.876 1789334.825)
# 23137  POINT (6539541.962 1801328.953)
# 23140  POINT (6526583.928 1810305.964)
# 24011  POINT (6532996.103 1792183.935)
# 24169  POINT (6526538.087 1810521.822)
# 24396  POINT (6539697.876 1791240.177)
# 24399  POINT (6539573.093 1801177.174)
# 24444  POINT (6527168.980 1811231.112)
# 24447  POINT (6527341.132 1812511.922)
# 24449  POINT (6526683.868 1810463.063)
# 24454  POINT (6536694.057 1789700.911)
# 24455  POINT (6536808.910 1792127.820)
# 24648  POINT (6539591.202 1793510.770)
# 24769  POINT (6536585.646 1822765.848)
# 24905  POINT (6526453.033 1810390.180)
# 25280  POINT (6536324.881 1823009.162)
# 25281  POINT (6536151.997 1822504.913)
# 25972  POINT (6542720.382 1815029.916)
# 25973  POINT (6542591.800 1814972.133)
# 26101  POINT (6542045.661 1814313.055)
# 28625  POINT (6563259.299 1802346.499)
# 28632  POINT (6561626.632 1802965.124)
# 28633  POINT (6562148.308 1802352.284)
# 28641  POINT (6551781.646 1814043.043)
# 28643  POINT (6536344.647 1822802.810)
# 28644  POINT (6536949.101 1822443.117)
# 28647  POINT (6536039.699 1823046.157)
# 28649  POINT (6551722.873 1814180.624)
# 28734  POINT (6537687.144 1821663.009)
# 28735  POINT (6536303.049 1822998.263)

# %%
stops_to_keep = df3.stop_id.unique().tolist()
from update_vars import COMPILED_CACHED_VIEWS, analysis_date

# %%
associated_feeds = [
    "1dce186c157f55ed353f9bd8bf6f43b6",
    "c7fac53170126479badfad5499f6048b",
    "ea4e5e79c2750d68d5d275df8a972ddd",
    "8a47f5aa51f481e9ddc7c497bd72d264",
    "415e0bd29d751e845b8b9dab3ba66b3e"
]

# %%
stop_times = pd.read_parquet(
    f"{COMPILED_CACHED_VIEWS}st_{analysis_date}.parquet", 
    filters = [[("stop_id", "in", stops_to_keep), 
               ("feed_key", "in", associated_feeds)]]
)

# %%
trips = pd.read_parquet(
    f"{COMPILED_CACHED_VIEWS}trips_{analysis_date}.parquet", 
    filters = [[("feed_key", "in", associated_feeds)]])

# %%
stop_times[(stop_times.stop_id=="1398") & 
           (stop_times.feed_key.isin(associated_feeds))].groupby(
    ["feed_key", "stop_id", "arrival_hour"]).agg(
    {"stop_sequence": "count"}).reset_index()
# Out:
#                             feed_key stop_id  arrival_hour  stop_sequence
# 0   8a47f5aa51f481e9ddc7c497bd72d264    1398             5              1
# 1   8a47f5aa51f481e9ddc7c497bd72d264    1398             6              2
# 2   8a47f5aa51f481e9ddc7c497bd72d264    1398             7              1
# 3   8a47f5aa51f481e9ddc7c497bd72d264    1398             8              1
# 4   8a47f5aa51f481e9ddc7c497bd72d264    1398             9              2
# 5   8a47f5aa51f481e9ddc7c497bd72d264    1398            10              1
# 6   8a47f5aa51f481e9ddc7c497bd72d264    1398            11              2
# 7   8a47f5aa51f481e9ddc7c497bd72d264    1398            12              1
# 8   8a47f5aa51f481e9ddc7c497bd72d264    1398            13              1
# 9   8a47f5aa51f481e9ddc7c497bd72d264    1398            14              2
# 10  8a47f5aa51f481e9ddc7c497bd72d264    1398            15              1
# 11  8a47f5aa51f481e9ddc7c497bd72d264    1398            16              2
# 12  8a47f5aa51f481e9ddc7c497bd72d264    1398            17              1
# 13  8a47f5aa51f481e9ddc7c497bd72d264    1398            18              2
# 14  8a47f5aa51f481e9ddc7c497bd72d264    1398            19              1
# 15  8a47f5aa51f481e9ddc7c497bd72d264    1398            20              2
# 16  8a47f5aa51f481e9ddc7c497bd72d264    1398            21              1
# 17  8a47f5aa51f481e9ddc7c497bd72d264    1398            22              1
# 18  c7fac53170126479badfad5499f6048b    1398             0              1
# 19  c7fac53170126479badfad5499f6048b    1398             5              4
# 20  c7fac53170126479badfad5499f6048b    1398             6              3
# 21  c7fac53170126479badfad5499f6048b    1398             7              4
# 22  c7fac53170126479badfad5499f6048b    1398             8              4
# 23  c7fac53170126479badfad5499f6048b    1398             9              5
# 24  c7fac53170126479badfad5499f6048b    1398            10              3
# 25  c7fac53170126479badfad5499f6048b    1398            11              3
# 26  c7fac53170126479badfad5499f6048b    1398            12              3
# 27  c7fac53170126479badfad5499f6048b    1398            13              4
# 28  c7fac53170126479badfad5499f6048b    1398            14              4
# 29  c7fac53170126479badfad5499f6048b    1398            15              3
# 30  c7fac53170126479badfad5499f6048b    1398            16              4
# 31  c7fac53170126479badfad5499f6048b    1398            17              4
# 32  c7fac53170126479badfad5499f6048b    1398            18              4
# 33  c7fac53170126479badfad5499f6048b    1398            19              5
# 34  c7fac53170126479badfad5499f6048b    1398            20              3
# 35  c7fac53170126479badfad5499f6048b    1398            21              2
# 36  c7fac53170126479badfad5499f6048b    1398            22              1

# %%
feeds[feeds.name.str.contains("LADPW") & feeds.name.notna()]
# Out:
#                             feed_key            name
# 28  415e0bd29d751e845b8b9dab3ba66b3e  LADPW Schedule

# %%
names = feeds[feeds.name.notna()].name.tolist()
names2 = [i.replace(' Schedule', '') for i in names]

# %%
agencies
# Out:
# ['LA Metro', 'Foothill', 'Montebello', 'OCTA', 'LADPW']

# %%
df2.explore("hqta_details", tiles='CartoDB Positron')

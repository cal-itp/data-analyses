# %%
import os
os.environ["CALITP_BQ_MAX_BYTES"] = str(800_000_000_000) ## 800GB?

from calitp.tables import tbl
from calitp import query_sql
import calitp.magics
import branca

import shared_utils

from siuba import *
import pandas as pd

import datetime as dt
import time
from zoneinfo import ZoneInfo

import importlib

import gcsfs
fs = gcsfs.GCSFileSystem()

from tqdm import tqdm_notebook
from tqdm.notebook import trange, tqdm

from IPython.display import display, Markdown
# Out:
# /opt/conda/lib/python3.10/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /opt/conda/lib/python3.10/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /opt/conda/lib/python3.10/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/

# %%
import utils

# %%
import altair as alt

# %%
pd.set_option("display.max_columns", 100)

# %%
itp_id = 300
analysis_date = '2022-05-07'

# %%
gtfs_daily = (
        tbl.views.gtfs_schedule_fact_daily_trips()
        >> filter(_.calitp_itp_id == itp_id)
        >> filter(_.service_date == analysis_date)
        >> filter(_.is_in_service == True)
        >> collect()
    )

# %%
rt = query_sql(
        f"""
        SELECT * FROM `cal-itp-data-infra-staging.natalie_views.gtfs_rt_distinct_trips`
        WHERE date = '{analysis_date}'
        """
    )
# Out:
# /opt/conda/lib/python3.10/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/

# %%
gtfs_daily.head()
# Out:
#               feed_key             trip_key trip_id route_id  calitp_itp_id  \
# 0  4100255323842349957 -5585888450776936120  880900     3480            300
# 1  4100255323842349957  3883255093367516135  882173     3487            300
# 2  4100255323842349957 -3566541802341487484  882202     3487            300
# 3  4100255323842349957 -8929781102916408381  880960     3480            300
# 4  4100255323842349957 -2569246778384901640  882691     3490            300
#
#    calitp_url_number service_id service_date service_indicator  \
# 0                  0          1   2022-05-07                 1
# 1                  0          1   2022-05-07                 1
# 2                  0          1   2022-05-07                 1
# 3                  0          1   2022-05-07                 1
# 4                  0          1   2022-05-07                 1
#
#   service_start_date service_end_date service_inclusion service_exclusion  \
# 0         2022-03-27       2022-08-13              None              None
# 1         2022-03-27       2022-08-13              None              None
# 2         2022-03-27       2022-08-13              None              None
# 3         2022-03-27       2022-08-13              None              None
# 4         2022-03-27       2022-08-13              None              None
#
#    is_in_service calitp_extracted_at calitp_deleted_at  n_stops  n_stop_times  \
# 0           True          2022-03-29        2022-07-18       28            28
# 1           True          2022-03-29        2022-07-18       30            30
# 2           True          2022-03-29        2022-07-18       32            32
# 3           True          2022-03-29        2022-07-18       33            33
# 4           True          2022-03-29        2022-07-18       34            34
#
#    trip_first_departure_ts  trip_last_arrival_ts  service_hours
# 0                    67200                 69420       0.616667
# 1                    62700                 64596       0.526667
# 2                    45791                 47640       0.513611
# 3                    39960                 42180       0.616667
# 4                    59940                 62100       0.600000

# %%
gtfs_daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 870 entries, 0 to 869
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   feed_key                 870 non-null    int64
#  1   trip_key                 870 non-null    int64
#  2   trip_id                  870 non-null    object
#  3   route_id                 870 non-null    object
#  4   calitp_itp_id            870 non-null    int64
#  5   calitp_url_number        870 non-null    int64
#  6   service_id               870 non-null    object
#  7   service_date             870 non-null    object
#  8   service_indicator        870 non-null    object
#  9   service_start_date       870 non-null    object
#  10  service_end_date         870 non-null    object
#  11  service_inclusion        0 non-null      object
#  12  service_exclusion        0 non-null      object
#  13  is_in_service            870 non-null    bool
#  14  calitp_extracted_at      870 non-null    object
#  15  calitp_deleted_at        870 non-null    object
#  16  n_stops                  870 non-null    int64
#  17  n_stop_times             870 non-null    int64
#  18  trip_first_departure_ts  870 non-null    int64
#  19  trip_last_arrival_ts     870 non-null    int64
#  20  service_hours            870 non-null    float64
# dtypes: bool(1), float64(1), int64(8), object(11)
# memory usage: 136.9+ KB

# %%
rt.head()
# Out:
#    calitp_itp_id  calitp_url_number        date trip_id vehicle_id
# 0            300                  0  2022-05-07  882162       1301
# 1            300                  0  2022-05-07  882096       1301
# 2            300                  0  2022-05-07  882158       1301
# 3            300                  0  2022-05-07  882114       1301
# 4            300                  0  2022-05-07  882099       1301

# %%
#right: rt 
#left: scheudle 
join = (pd.merge(gtfs_daily, rt, how='outer', on='trip_id', indicator='have_rt'))

# %%
join.have_rt.value_counts()
# Out:
# both          608
# right_only    395
# left_only     266
# Name: have_rt, dtype: int64

# %%
join["first_departure"] = pd.to_datetime(join.trip_first_departure_ts, unit='s').dt.time

# %%
join
# Out:
#           feed_key      trip_key trip_id route_id  calitp_itp_id_x  \
# 0     4.100255e+18 -5.585888e+18  880900     3480            300.0
# 1     4.100255e+18  3.883255e+18  882173     3487            300.0
# 2     4.100255e+18 -3.566542e+18  882202     3487            300.0
# 3     4.100255e+18 -8.929781e+18  880960     3480            300.0
# 4     4.100255e+18 -2.569247e+18  882691     3490            300.0
# ...            ...           ...     ...      ...              ...
# 1264           NaN           NaN  881509      NaN              NaN
# 1265           NaN           NaN  881448      NaN              NaN
# 1266           NaN           NaN  881516      NaN              NaN
# 1267           NaN           NaN  881442      NaN              NaN
# 1268           NaN           NaN  881499      NaN              NaN
#
#       calitp_url_number_x service_id service_date service_indicator  \
# 0                     0.0          1   2022-05-07                 1
# 1                     0.0          1   2022-05-07                 1
# 2                     0.0          1   2022-05-07                 1
# 3                     0.0          1   2022-05-07                 1
# 4                     0.0          1   2022-05-07                 1
# ...                   ...        ...          ...               ...
# 1264                  NaN        NaN          NaN               NaN
# 1265                  NaN        NaN          NaN               NaN
# 1266                  NaN        NaN          NaN               NaN
# 1267                  NaN        NaN          NaN               NaN
# 1268                  NaN        NaN          NaN               NaN
#
#      service_start_date service_end_date service_inclusion service_exclusion  \
# 0            2022-03-27       2022-08-13              None              None
# 1            2022-03-27       2022-08-13              None              None
# 2            2022-03-27       2022-08-13              None              None
# 3            2022-03-27       2022-08-13              None              None
# 4            2022-03-27       2022-08-13              None              None
# ...                 ...              ...               ...               ...
# 1264                NaN              NaN               NaN               NaN
# 1265                NaN              NaN               NaN               NaN
# 1266                NaN              NaN               NaN               NaN
# 1267                NaN              NaN               NaN               NaN
# 1268                NaN              NaN               NaN               NaN
#
#      is_in_service calitp_extracted_at calitp_deleted_at  n_stops  \
# 0             True          2022-03-29        2022-07-18     28.0
# 1             True          2022-03-29        2022-07-18     30.0
# 2             True          2022-03-29        2022-07-18     32.0
# 3             True          2022-03-29        2022-07-18     33.0
# 4             True          2022-03-29        2022-07-18     34.0
# ...            ...                 ...               ...      ...
# 1264           NaN                 NaN               NaN      NaN
# 1265           NaN                 NaN               NaN      NaN
# 1266           NaN                 NaN               NaN      NaN
# 1267           NaN                 NaN               NaN      NaN
# 1268           NaN                 NaN               NaN      NaN
#
#       n_stop_times  trip_first_departure_ts  trip_last_arrival_ts  \
# 0             28.0                  67200.0               69420.0
# 1             30.0                  62700.0               64596.0
# 2             32.0                  45791.0               47640.0
# 3             33.0                  39960.0               42180.0
# 4             34.0                  59940.0               62100.0
# ...            ...                      ...                   ...
# 1264           NaN                      NaN                   NaN
# 1265           NaN                      NaN                   NaN
# 1266           NaN                      NaN                   NaN
# 1267           NaN                      NaN                   NaN
# 1268           NaN                      NaN                   NaN
#
#       service_hours  calitp_itp_id_y  calitp_url_number_y        date  \
# 0          0.616667              NaN                  NaN         NaN
# 1          0.526667              NaN                  NaN         NaN
# 2          0.513611            300.0                  0.0  2022-05-07
# 3          0.616667            300.0                  0.0  2022-05-07
# 4          0.600000            300.0                  0.0  2022-05-07
# ...             ...              ...                  ...         ...
# 1264            NaN            300.0                  0.0  2022-05-07
# 1265            NaN            300.0                  0.0  2022-05-07
# 1266            NaN            300.0                  0.0  2022-05-07
# 1267            NaN            300.0                  0.0  2022-05-07
# 1268            NaN            300.0                  0.0  2022-05-07
#
#      vehicle_id     have_rt first_departure
# 0           NaN   left_only        18:40:00
# 1           NaN   left_only        17:25:00
# 2          1503        both        12:43:11
# 3          1335        both        11:06:00
# 4          1823        both        16:39:00
# ...         ...         ...             ...
# 1264       5317  right_only             NaT
# 1265       5317  right_only             NaT
# 1266       5317  right_only             NaT
# 1267       5317  right_only             NaT
# 1268       5317  right_only             NaT
#
# [1269 rows x 27 columns]

# %%
#rt leftover
rt_lo =(join>>filter(_.have_rt=='right_only'))

# %%
rt_lo
# Out:
#       feed_key  trip_key trip_id route_id  calitp_itp_id_x  \
# 874        NaN       NaN  882162      NaN              NaN
# 875        NaN       NaN  882096      NaN              NaN
# 876        NaN       NaN  882158      NaN              NaN
# 877        NaN       NaN  882114      NaN              NaN
# 878        NaN       NaN  882099      NaN              NaN
# ...        ...       ...     ...      ...              ...
# 1264       NaN       NaN  881509      NaN              NaN
# 1265       NaN       NaN  881448      NaN              NaN
# 1266       NaN       NaN  881516      NaN              NaN
# 1267       NaN       NaN  881442      NaN              NaN
# 1268       NaN       NaN  881499      NaN              NaN
#
#       calitp_url_number_x service_id service_date service_indicator  \
# 874                   NaN        NaN          NaN               NaN
# 875                   NaN        NaN          NaN               NaN
# 876                   NaN        NaN          NaN               NaN
# 877                   NaN        NaN          NaN               NaN
# 878                   NaN        NaN          NaN               NaN
# ...                   ...        ...          ...               ...
# 1264                  NaN        NaN          NaN               NaN
# 1265                  NaN        NaN          NaN               NaN
# 1266                  NaN        NaN          NaN               NaN
# 1267                  NaN        NaN          NaN               NaN
# 1268                  NaN        NaN          NaN               NaN
#
#      service_start_date service_end_date service_inclusion service_exclusion  \
# 874                 NaN              NaN               NaN               NaN
# 875                 NaN              NaN               NaN               NaN
# 876                 NaN              NaN               NaN               NaN
# 877                 NaN              NaN               NaN               NaN
# 878                 NaN              NaN               NaN               NaN
# ...                 ...              ...               ...               ...
# 1264                NaN              NaN               NaN               NaN
# 1265                NaN              NaN               NaN               NaN
# 1266                NaN              NaN               NaN               NaN
# 1267                NaN              NaN               NaN               NaN
# 1268                NaN              NaN               NaN               NaN
#
#      is_in_service calitp_extracted_at calitp_deleted_at  n_stops  \
# 874            NaN                 NaN               NaN      NaN
# 875            NaN                 NaN               NaN      NaN
# 876            NaN                 NaN               NaN      NaN
# 877            NaN                 NaN               NaN      NaN
# 878            NaN                 NaN               NaN      NaN
# ...            ...                 ...               ...      ...
# 1264           NaN                 NaN               NaN      NaN
# 1265           NaN                 NaN               NaN      NaN
# 1266           NaN                 NaN               NaN      NaN
# 1267           NaN                 NaN               NaN      NaN
# 1268           NaN                 NaN               NaN      NaN
#
#       n_stop_times  trip_first_departure_ts  trip_last_arrival_ts  \
# 874            NaN                      NaN                   NaN
# 875            NaN                      NaN                   NaN
# 876            NaN                      NaN                   NaN
# 877            NaN                      NaN                   NaN
# 878            NaN                      NaN                   NaN
# ...            ...                      ...                   ...
# 1264           NaN                      NaN                   NaN
# 1265           NaN                      NaN                   NaN
# 1266           NaN                      NaN                   NaN
# 1267           NaN                      NaN                   NaN
# 1268           NaN                      NaN                   NaN
#
#       service_hours  calitp_itp_id_y  calitp_url_number_y        date  \
# 874             NaN            300.0                  0.0  2022-05-07
# 875             NaN            300.0                  0.0  2022-05-07
# 876             NaN            300.0                  0.0  2022-05-07
# 877             NaN            300.0                  0.0  2022-05-07
# 878             NaN            300.0                  0.0  2022-05-07
# ...             ...              ...                  ...         ...
# 1264            NaN            300.0                  0.0  2022-05-07
# 1265            NaN            300.0                  0.0  2022-05-07
# 1266            NaN            300.0                  0.0  2022-05-07
# 1267            NaN            300.0                  0.0  2022-05-07
# 1268            NaN            300.0                  0.0  2022-05-07
#
#      vehicle_id     have_rt first_departure
# 874        1301  right_only             NaT
# 875        1301  right_only             NaT
# 876        1301  right_only             NaT
# 877        1301  right_only             NaT
# 878        1301  right_only             NaT
# ...         ...         ...             ...
# 1264       5317  right_only             NaT
# 1265       5317  right_only             NaT
# 1266       5317  right_only             NaT
# 1267       5317  right_only             NaT
# 1268       5317  right_only             NaT
#
# [395 rows x 27 columns]

# %%
#schedule
sched_lo = (join>>filter(_.have_rt=='left_only'))

# %%
sched_lo
# Out:
#          feed_key      trip_key trip_id route_id  calitp_itp_id_x  \
# 0    4.100255e+18 -5.585888e+18  880900     3480            300.0
# 1    4.100255e+18  3.883255e+18  882173     3487            300.0
# 8    4.100255e+18  1.516650e+18  881122     3481            300.0
# 10   4.100255e+18 -2.414144e+18  880520     3479            300.0
# 11   4.100255e+18 -5.922786e+18  881975     3486            300.0
# ..            ...           ...     ...      ...              ...
# 863  4.100255e+18  7.598714e+18  882194     3487            300.0
# 866  4.100255e+18  6.060578e+18  881132     3481            300.0
# 867  4.100255e+18  6.932988e+18  880586     3479            300.0
# 868  4.100255e+18  3.630855e+18  880533     3479            300.0
# 872  4.100255e+18  1.850189e+18  881556     3485            300.0
#
#      calitp_url_number_x service_id service_date service_indicator  \
# 0                    0.0          1   2022-05-07                 1
# 1                    0.0          1   2022-05-07                 1
# 8                    0.0          1   2022-05-07                 1
# 10                   0.0          1   2022-05-07                 1
# 11                   0.0          1   2022-05-07                 1
# ..                   ...        ...          ...               ...
# 863                  0.0          1   2022-05-07                 1
# 866                  0.0          1   2022-05-07                 1
# 867                  0.0          1   2022-05-07                 1
# 868                  0.0          1   2022-05-07                 1
# 872                  0.0          1   2022-05-07                 1
#
#     service_start_date service_end_date service_inclusion service_exclusion  \
# 0           2022-03-27       2022-08-13              None              None
# 1           2022-03-27       2022-08-13              None              None
# 8           2022-03-27       2022-08-13              None              None
# 10          2022-03-27       2022-08-13              None              None
# 11          2022-03-27       2022-08-13              None              None
# ..                 ...              ...               ...               ...
# 863         2022-03-27       2022-08-13              None              None
# 866         2022-03-27       2022-08-13              None              None
# 867         2022-03-27       2022-08-13              None              None
# 868         2022-03-27       2022-08-13              None              None
# 872         2022-03-27       2022-08-13              None              None
#
#     is_in_service calitp_extracted_at calitp_deleted_at  n_stops  \
# 0            True          2022-03-29        2022-07-18     28.0
# 1            True          2022-03-29        2022-07-18     30.0
# 8            True          2022-03-29        2022-07-18     36.0
# 10           True          2022-03-29        2022-07-18     42.0
# 11           True          2022-03-29        2022-07-18     44.0
# ..            ...                 ...               ...      ...
# 863          True          2022-03-29        2022-07-18     32.0
# 866          True          2022-03-29        2022-07-18     36.0
# 867          True          2022-03-29        2022-07-18     45.0
# 868          True          2022-03-29        2022-07-18     45.0
# 872          True          2022-03-29        2022-07-18     53.0
#
#      n_stop_times  trip_first_departure_ts  trip_last_arrival_ts  \
# 0            28.0                  67200.0               69420.0
# 1            30.0                  62700.0               64596.0
# 8            36.0                  80700.0               83220.0
# 10           42.0                  69960.0               72780.0
# 11           44.0                  78300.0               81000.0
# ..            ...                      ...                   ...
# 863          32.0                  69611.0               71400.0
# 866          36.0                  69600.0               72780.0
# 867          45.0                  68580.0               71400.0
# 868          45.0                  81840.0               83880.0
# 872          53.0                  75000.0               78478.0
#
#      service_hours  calitp_itp_id_y  calitp_url_number_y date vehicle_id  \
# 0         0.616667              NaN                  NaN  NaN        NaN
# 1         0.526667              NaN                  NaN  NaN        NaN
# 8         0.700000              NaN                  NaN  NaN        NaN
# 10        0.783333              NaN                  NaN  NaN        NaN
# 11        0.750000              NaN                  NaN  NaN        NaN
# ..             ...              ...                  ...  ...        ...
# 863       0.496944              NaN                  NaN  NaN        NaN
# 866       0.883333              NaN                  NaN  NaN        NaN
# 867       0.783333              NaN                  NaN  NaN        NaN
# 868       0.566667              NaN                  NaN  NaN        NaN
# 872       0.966111              NaN                  NaN  NaN        NaN
#
#        have_rt first_departure
# 0    left_only        18:40:00
# 1    left_only        17:25:00
# 8    left_only        22:25:00
# 10   left_only        19:26:00
# 11   left_only        21:45:00
# ..         ...             ...
# 863  left_only        19:20:11
# 866  left_only        19:20:00
# 867  left_only        19:03:00
# 868  left_only        22:44:00
# 872  left_only        20:50:00
#
# [266 rows x 27 columns]

# %%
rt_stime = query_sql(
        f"""
        SELECT * FROM `cal-itp-data-infra-staging.natalie_views.test_rt_trips_05072022`
        WHERE date = '{analysis_date}'
        """
    )
# Out:
# /opt/conda/lib/python3.10/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/

# %%
rt_stime["start_time"] = pd.to_datetime(rt_stime.start_time, unit='s').dt.time

# %%
rt_stime
# Out:
#      calitp_itp_id  calitp_url_number        date trip_id start_time
# 0              300                  0  2022-05-07  883191   15:40:48
# 1              300                  0  2022-05-07  882394   17:14:40
# 2              300                  0  2022-05-07  881160   18:57:04
# 3              300                  0  2022-05-07  880812   04:05:20
# 4              300                  0  2022-05-07  882407   22:51:44
# ..             ...                ...         ...     ...        ...
# 994            300                  0  2022-05-07  882333   14:15:27
# 995            300                  0  2022-05-07  881174   15:32:15
# 996            300                  0  2022-05-07  882316   02:27:11
# 997            300                  0  2022-05-07  881648   20:52:15
# 998            300                  0  2022-05-07  880948   21:56:15
#
# [999 rows x 5 columns]

# %%
#joining the leftover realtime and join

test_sched = (pd.merge(sched_lo, rt_stime, on='trip_id', how='outer', indicator='_merge'))

# %%
test_sched
# Out:
#           feed_key      trip_key trip_id route_id  calitp_itp_id_x  \
# 0     4.100255e+18 -5.585888e+18  880900     3480            300.0
# 1     4.100255e+18  3.883255e+18  882173     3487            300.0
# 2     4.100255e+18  1.516650e+18  881122     3481            300.0
# 3     4.100255e+18 -2.414144e+18  880520     3479            300.0
# 4     4.100255e+18 -5.922786e+18  881975     3486            300.0
# ...            ...           ...     ...      ...              ...
# 1260           NaN           NaN  882333      NaN              NaN
# 1261           NaN           NaN  881174      NaN              NaN
# 1262           NaN           NaN  882316      NaN              NaN
# 1263           NaN           NaN  881648      NaN              NaN
# 1264           NaN           NaN  880948      NaN              NaN
#
#       calitp_url_number_x service_id service_date service_indicator  \
# 0                     0.0          1   2022-05-07                 1
# 1                     0.0          1   2022-05-07                 1
# 2                     0.0          1   2022-05-07                 1
# 3                     0.0          1   2022-05-07                 1
# 4                     0.0          1   2022-05-07                 1
# ...                   ...        ...          ...               ...
# 1260                  NaN        NaN          NaN               NaN
# 1261                  NaN        NaN          NaN               NaN
# 1262                  NaN        NaN          NaN               NaN
# 1263                  NaN        NaN          NaN               NaN
# 1264                  NaN        NaN          NaN               NaN
#
#      service_start_date service_end_date service_inclusion service_exclusion  \
# 0            2022-03-27       2022-08-13              None              None
# 1            2022-03-27       2022-08-13              None              None
# 2            2022-03-27       2022-08-13              None              None
# 3            2022-03-27       2022-08-13              None              None
# 4            2022-03-27       2022-08-13              None              None
# ...                 ...              ...               ...               ...
# 1260                NaN              NaN               NaN               NaN
# 1261                NaN              NaN               NaN               NaN
# 1262                NaN              NaN               NaN               NaN
# 1263                NaN              NaN               NaN               NaN
# 1264                NaN              NaN               NaN               NaN
#
#      is_in_service calitp_extracted_at calitp_deleted_at  n_stops  \
# 0             True          2022-03-29        2022-07-18     28.0
# 1             True          2022-03-29        2022-07-18     30.0
# 2             True          2022-03-29        2022-07-18     36.0
# 3             True          2022-03-29        2022-07-18     42.0
# 4             True          2022-03-29        2022-07-18     44.0
# ...            ...                 ...               ...      ...
# 1260           NaN                 NaN               NaN      NaN
# 1261           NaN                 NaN               NaN      NaN
# 1262           NaN                 NaN               NaN      NaN
# 1263           NaN                 NaN               NaN      NaN
# 1264           NaN                 NaN               NaN      NaN
#
#       n_stop_times  trip_first_departure_ts  trip_last_arrival_ts  \
# 0             28.0                  67200.0               69420.0
# 1             30.0                  62700.0               64596.0
# 2             36.0                  80700.0               83220.0
# 3             42.0                  69960.0               72780.0
# 4             44.0                  78300.0               81000.0
# ...            ...                      ...                   ...
# 1260           NaN                      NaN                   NaN
# 1261           NaN                      NaN                   NaN
# 1262           NaN                      NaN                   NaN
# 1263           NaN                      NaN                   NaN
# 1264           NaN                      NaN                   NaN
#
#       service_hours  calitp_itp_id_y  calitp_url_number_y date_x vehicle_id  \
# 0          0.616667              NaN                  NaN    NaN        NaN
# 1          0.526667              NaN                  NaN    NaN        NaN
# 2          0.700000              NaN                  NaN    NaN        NaN
# 3          0.783333              NaN                  NaN    NaN        NaN
# 4          0.750000              NaN                  NaN    NaN        NaN
# ...             ...              ...                  ...    ...        ...
# 1260            NaN              NaN                  NaN    NaN        NaN
# 1261            NaN              NaN                  NaN    NaN        NaN
# 1262            NaN              NaN                  NaN    NaN        NaN
# 1263            NaN              NaN                  NaN    NaN        NaN
# 1264            NaN              NaN                  NaN    NaN        NaN
#
#         have_rt first_departure  calitp_itp_id  calitp_url_number      date_y  \
# 0     left_only        18:40:00            NaN                NaN         NaN
# 1     left_only        17:25:00            NaN                NaN         NaN
# 2     left_only        22:25:00            NaN                NaN         NaN
# 3     left_only        19:26:00            NaN                NaN         NaN
# 4     left_only        21:45:00            NaN                NaN         NaN
# ...         ...             ...            ...                ...         ...
# 1260        NaN             NaN          300.0                0.0  2022-05-07
# 1261        NaN             NaN          300.0                0.0  2022-05-07
# 1262        NaN             NaN          300.0                0.0  2022-05-07
# 1263        NaN             NaN          300.0                0.0  2022-05-07
# 1264        NaN             NaN          300.0                0.0  2022-05-07
#
#      start_time      _merge
# 0           NaN   left_only
# 1           NaN   left_only
# 2           NaN   left_only
# 3           NaN   left_only
# 4           NaN   left_only
# ...         ...         ...
# 1260   14:15:27  right_only
# 1261   15:32:15  right_only
# 1262   02:27:11  right_only
# 1263   20:52:15  right_only
# 1264   21:56:15  right_only
#
# [1265 rows x 32 columns]

# %%
test_sched._merge.value_counts()
# Out:
# right_only    999
# left_only     266
# both            0
# Name: _merge, dtype: int64

# %%
#leftover schedule
test_rt = (pd.merge(rt_lo, rt_stime, on='trip_id', how='outer', indicator='_merge'))

# %%
test_rt
# Out:
#      feed_key  trip_key trip_id route_id  calitp_itp_id_x  \
# 0         NaN       NaN  882162      NaN              NaN
# 1         NaN       NaN  882096      NaN              NaN
# 2         NaN       NaN  882158      NaN              NaN
# 3         NaN       NaN  882114      NaN              NaN
# 4         NaN       NaN  882099      NaN              NaN
# ..        ...       ...     ...      ...              ...
# 994       NaN       NaN  881604      NaN              NaN
# 995       NaN       NaN  882333      NaN              NaN
# 996       NaN       NaN  881174      NaN              NaN
# 997       NaN       NaN  881648      NaN              NaN
# 998       NaN       NaN  880948      NaN              NaN
#
#      calitp_url_number_x service_id service_date service_indicator  \
# 0                    NaN        NaN          NaN               NaN
# 1                    NaN        NaN          NaN               NaN
# 2                    NaN        NaN          NaN               NaN
# 3                    NaN        NaN          NaN               NaN
# 4                    NaN        NaN          NaN               NaN
# ..                   ...        ...          ...               ...
# 994                  NaN        NaN          NaN               NaN
# 995                  NaN        NaN          NaN               NaN
# 996                  NaN        NaN          NaN               NaN
# 997                  NaN        NaN          NaN               NaN
# 998                  NaN        NaN          NaN               NaN
#
#     service_start_date service_end_date service_inclusion service_exclusion  \
# 0                  NaN              NaN               NaN               NaN
# 1                  NaN              NaN               NaN               NaN
# 2                  NaN              NaN               NaN               NaN
# 3                  NaN              NaN               NaN               NaN
# 4                  NaN              NaN               NaN               NaN
# ..                 ...              ...               ...               ...
# 994                NaN              NaN               NaN               NaN
# 995                NaN              NaN               NaN               NaN
# 996                NaN              NaN               NaN               NaN
# 997                NaN              NaN               NaN               NaN
# 998                NaN              NaN               NaN               NaN
#
#     is_in_service calitp_extracted_at calitp_deleted_at  n_stops  \
# 0             NaN                 NaN               NaN      NaN
# 1             NaN                 NaN               NaN      NaN
# 2             NaN                 NaN               NaN      NaN
# 3             NaN                 NaN               NaN      NaN
# 4             NaN                 NaN               NaN      NaN
# ..            ...                 ...               ...      ...
# 994           NaN                 NaN               NaN      NaN
# 995           NaN                 NaN               NaN      NaN
# 996           NaN                 NaN               NaN      NaN
# 997           NaN                 NaN               NaN      NaN
# 998           NaN                 NaN               NaN      NaN
#
#      n_stop_times  trip_first_departure_ts  trip_last_arrival_ts  \
# 0             NaN                      NaN                   NaN
# 1             NaN                      NaN                   NaN
# 2             NaN                      NaN                   NaN
# 3             NaN                      NaN                   NaN
# 4             NaN                      NaN                   NaN
# ..            ...                      ...                   ...
# 994           NaN                      NaN                   NaN
# 995           NaN                      NaN                   NaN
# 996           NaN                      NaN                   NaN
# 997           NaN                      NaN                   NaN
# 998           NaN                      NaN                   NaN
#
#      service_hours  calitp_itp_id_y  calitp_url_number_y      date_x  \
# 0              NaN            300.0                  0.0  2022-05-07
# 1              NaN            300.0                  0.0  2022-05-07
# 2              NaN            300.0                  0.0  2022-05-07
# 3              NaN            300.0                  0.0  2022-05-07
# 4              NaN            300.0                  0.0  2022-05-07
# ..             ...              ...                  ...         ...
# 994            NaN              NaN                  NaN         NaN
# 995            NaN              NaN                  NaN         NaN
# 996            NaN              NaN                  NaN         NaN
# 997            NaN              NaN                  NaN         NaN
# 998            NaN              NaN                  NaN         NaN
#
#     vehicle_id     have_rt first_departure  calitp_itp_id  calitp_url_number  \
# 0         1301  right_only             NaT            300                  0
# 1         1301  right_only             NaT            300                  0
# 2         1301  right_only             NaT            300                  0
# 3         1301  right_only             NaT            300                  0
# 4         1301  right_only             NaT            300                  0
# ..         ...         ...             ...            ...                ...
# 994        NaN         NaN             NaN            300                  0
# 995        NaN         NaN             NaN            300                  0
# 996        NaN         NaN             NaN            300                  0
# 997        NaN         NaN             NaN            300                  0
# 998        NaN         NaN             NaN            300                  0
#
#          date_y start_time      _merge
# 0    2022-05-07   00:41:44        both
# 1    2022-05-07   04:11:57        both
# 2    2022-05-07   04:47:44        both
# 3    2022-05-07   02:17:06        both
# 4    2022-05-07   23:58:11        both
# ..          ...        ...         ...
# 994  2022-05-07   13:32:46  right_only
# 995  2022-05-07   14:15:27  right_only
# 996  2022-05-07   15:32:15  right_only
# 997  2022-05-07   20:52:15  right_only
# 998  2022-05-07   21:56:15  right_only
#
# [999 rows x 32 columns]

# %%
test_rt._merge.value_counts()
# Out:
# right_only    604
# both          395
# left_only       0
# Name: _merge, dtype: int64

# %%
test_rt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 999 entries, 0 to 998
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   feed_key                 0 non-null      float64
#  1   trip_key                 0 non-null      float64
#  2   trip_id                  999 non-null    object
#  3   route_id                 0 non-null      object
#  4   calitp_itp_id_x          0 non-null      float64
#  5   calitp_url_number_x      0 non-null      float64
#  6   service_id               0 non-null      object
#  7   service_date             0 non-null      object
#  8   service_indicator        0 non-null      object
#  9   service_start_date       0 non-null      object
#  10  service_end_date         0 non-null      object
#  11  service_inclusion        0 non-null      object
#  12  service_exclusion        0 non-null      object
#  13  is_in_service            0 non-null      object
#  14  calitp_extracted_at      0 non-null      object
#  15  calitp_deleted_at        0 non-null      object
#  16  n_stops                  0 non-null      float64
#  17  n_stop_times             0 non-null      float64
#  18  trip_first_departure_ts  0 non-null      float64
#  19  trip_last_arrival_ts     0 non-null      float64
#  20  service_hours            0 non-null      float64
#  21  calitp_itp_id_y          395 non-null    float64
#  22  calitp_url_number_y      395 non-null    float64
#  23  date_x                   395 non-null    object
#  24  vehicle_id               395 non-null    object
#  25  have_rt                  395 non-null    category
#  26  first_departure          0 non-null      object
#  27  calitp_itp_id            999 non-null    int64
#  28  calitp_url_number        999 non-null    int64
#  29  date_y                   999 non-null    object
#  30  start_time               999 non-null    object
#  31  _merge                   999 non-null    category
# dtypes: category(2), float64(11), int64(2), object(17)
# memory usage: 244.2+ KB

# %%
(test_rt>>filter(_._merge=='both')
 >>select(_.trip_id,
          _.calitp_itp_id_y,
          _.calitp_url_number_y,
          _.have_rt,
          _.calitp_itp_id,
          _.calitp_url_number,
          _.date_y,
          _.start_time,
          _._merge)
)
# Out:
#     trip_id  calitp_itp_id_y  calitp_url_number_y     have_rt  calitp_itp_id  \
# 0    882162            300.0                  0.0  right_only            300
# 1    882096            300.0                  0.0  right_only            300
# 2    882158            300.0                  0.0  right_only            300
# 3    882114            300.0                  0.0  right_only            300
# 4    882099            300.0                  0.0  right_only            300
# ..      ...              ...                  ...         ...            ...
# 390  881509            300.0                  0.0  right_only            300
# 391  881448            300.0                  0.0  right_only            300
# 392  881516            300.0                  0.0  right_only            300
# 393  881442            300.0                  0.0  right_only            300
# 394  881499            300.0                  0.0  right_only            300
#
#      calitp_url_number      date_y start_time _merge
# 0                    0  2022-05-07   00:41:44   both
# 1                    0  2022-05-07   04:11:57   both
# 2                    0  2022-05-07   04:47:44   both
# 3                    0  2022-05-07   02:17:06   both
# 4                    0  2022-05-07   23:58:11   both
# ..                 ...         ...        ...    ...
# 390                  0  2022-05-07   01:53:44   both
# 391                  0  2022-05-07   04:53:15   both
# 392                  0  2022-05-07   04:01:02   both
# 393                  0  2022-05-07   03:10:10   both
# 394                  0  2022-05-07   23:58:13   both
#
# [395 rows x 9 columns]

# %%
test_sched
# Out:
#           feed_key      trip_key trip_id route_id  calitp_itp_id_x  \
# 0     4.100255e+18 -5.585888e+18  880900     3480            300.0
# 1     4.100255e+18  3.883255e+18  882173     3487            300.0
# 2     4.100255e+18  1.516650e+18  881122     3481            300.0
# 3     4.100255e+18 -2.414144e+18  880520     3479            300.0
# 4     4.100255e+18 -5.922786e+18  881975     3486            300.0
# ...            ...           ...     ...      ...              ...
# 1260           NaN           NaN  882333      NaN              NaN
# 1261           NaN           NaN  881174      NaN              NaN
# 1262           NaN           NaN  882316      NaN              NaN
# 1263           NaN           NaN  881648      NaN              NaN
# 1264           NaN           NaN  880948      NaN              NaN
#
#       calitp_url_number_x service_id service_date service_indicator  \
# 0                     0.0          1   2022-05-07                 1
# 1                     0.0          1   2022-05-07                 1
# 2                     0.0          1   2022-05-07                 1
# 3                     0.0          1   2022-05-07                 1
# 4                     0.0          1   2022-05-07                 1
# ...                   ...        ...          ...               ...
# 1260                  NaN        NaN          NaN               NaN
# 1261                  NaN        NaN          NaN               NaN
# 1262                  NaN        NaN          NaN               NaN
# 1263                  NaN        NaN          NaN               NaN
# 1264                  NaN        NaN          NaN               NaN
#
#      service_start_date service_end_date service_inclusion service_exclusion  \
# 0            2022-03-27       2022-08-13              None              None
# 1            2022-03-27       2022-08-13              None              None
# 2            2022-03-27       2022-08-13              None              None
# 3            2022-03-27       2022-08-13              None              None
# 4            2022-03-27       2022-08-13              None              None
# ...                 ...              ...               ...               ...
# 1260                NaN              NaN               NaN               NaN
# 1261                NaN              NaN               NaN               NaN
# 1262                NaN              NaN               NaN               NaN
# 1263                NaN              NaN               NaN               NaN
# 1264                NaN              NaN               NaN               NaN
#
#      is_in_service calitp_extracted_at calitp_deleted_at  n_stops  \
# 0             True          2022-03-29        2022-07-18     28.0
# 1             True          2022-03-29        2022-07-18     30.0
# 2             True          2022-03-29        2022-07-18     36.0
# 3             True          2022-03-29        2022-07-18     42.0
# 4             True          2022-03-29        2022-07-18     44.0
# ...            ...                 ...               ...      ...
# 1260           NaN                 NaN               NaN      NaN
# 1261           NaN                 NaN               NaN      NaN
# 1262           NaN                 NaN               NaN      NaN
# 1263           NaN                 NaN               NaN      NaN
# 1264           NaN                 NaN               NaN      NaN
#
#       n_stop_times  trip_first_departure_ts  trip_last_arrival_ts  \
# 0             28.0                  67200.0               69420.0
# 1             30.0                  62700.0               64596.0
# 2             36.0                  80700.0               83220.0
# 3             42.0                  69960.0               72780.0
# 4             44.0                  78300.0               81000.0
# ...            ...                      ...                   ...
# 1260           NaN                      NaN                   NaN
# 1261           NaN                      NaN                   NaN
# 1262           NaN                      NaN                   NaN
# 1263           NaN                      NaN                   NaN
# 1264           NaN                      NaN                   NaN
#
#       service_hours  calitp_itp_id_y  calitp_url_number_y date_x vehicle_id  \
# 0          0.616667              NaN                  NaN    NaN        NaN
# 1          0.526667              NaN                  NaN    NaN        NaN
# 2          0.700000              NaN                  NaN    NaN        NaN
# 3          0.783333              NaN                  NaN    NaN        NaN
# 4          0.750000              NaN                  NaN    NaN        NaN
# ...             ...              ...                  ...    ...        ...
# 1260            NaN              NaN                  NaN    NaN        NaN
# 1261            NaN              NaN                  NaN    NaN        NaN
# 1262            NaN              NaN                  NaN    NaN        NaN
# 1263            NaN              NaN                  NaN    NaN        NaN
# 1264            NaN              NaN                  NaN    NaN        NaN
#
#         have_rt first_departure  calitp_itp_id  calitp_url_number      date_y  \
# 0     left_only        18:40:00            NaN                NaN         NaN
# 1     left_only        17:25:00            NaN                NaN         NaN
# 2     left_only        22:25:00            NaN                NaN         NaN
# 3     left_only        19:26:00            NaN                NaN         NaN
# 4     left_only        21:45:00            NaN                NaN         NaN
# ...         ...             ...            ...                ...         ...
# 1260        NaN             NaN          300.0                0.0  2022-05-07
# 1261        NaN             NaN          300.0                0.0  2022-05-07
# 1262        NaN             NaN          300.0                0.0  2022-05-07
# 1263        NaN             NaN          300.0                0.0  2022-05-07
# 1264        NaN             NaN          300.0                0.0  2022-05-07
#
#      start_time      _merge
# 0           NaN   left_only
# 1           NaN   left_only
# 2           NaN   left_only
# 3           NaN   left_only
# 4           NaN   left_only
# ...         ...         ...
# 1260   14:15:27  right_only
# 1261   15:32:15  right_only
# 1262   02:27:11  right_only
# 1263   20:52:15  right_only
# 1264   21:56:15  right_only
#
# [1265 rows x 32 columns]

# %%
(test_sched>>filter(_._merge=='left_only')
 >>select(_.trip_id,
          _.route_id,
          _.route_id,
          _.first_departure,
          _.calitp_itp_id_x,
          _.calitp_url_number_x,
          _.have_rt,
          _.calitp_itp_id,
          _.calitp_url_number,
          _.date_x,
          _.start_time,
          _._merge)
)
# Out:
#     trip_id route_id first_departure  calitp_itp_id_x  calitp_url_number_x  \
# 0    880900     3480        18:40:00            300.0                  0.0
# 1    882173     3487        17:25:00            300.0                  0.0
# 2    881122     3481        22:25:00            300.0                  0.0
# 3    880520     3479        19:26:00            300.0                  0.0
# 4    881975     3486        21:45:00            300.0                  0.0
# ..      ...      ...             ...              ...                  ...
# 261  882194     3487        19:20:11            300.0                  0.0
# 262  881132     3481        19:20:00            300.0                  0.0
# 263  880586     3479        19:03:00            300.0                  0.0
# 264  880533     3479        22:44:00            300.0                  0.0
# 265  881556     3485        20:50:00            300.0                  0.0
#
#        have_rt  calitp_itp_id  calitp_url_number date_x start_time     _merge
# 0    left_only            NaN                NaN    NaN        NaN  left_only
# 1    left_only            NaN                NaN    NaN        NaN  left_only
# 2    left_only            NaN                NaN    NaN        NaN  left_only
# 3    left_only            NaN                NaN    NaN        NaN  left_only
# 4    left_only            NaN                NaN    NaN        NaN  left_only
# ..         ...            ...                ...    ...        ...        ...
# 261  left_only            NaN                NaN    NaN        NaN  left_only
# 262  left_only            NaN                NaN    NaN        NaN  left_only
# 263  left_only            NaN                NaN    NaN        NaN  left_only
# 264  left_only            NaN                NaN    NaN        NaN  left_only
# 265  left_only            NaN                NaN    NaN        NaN  left_only
#
# [266 rows x 11 columns]

# %%
test_sched.sample()
# Out:
#      feed_key  trip_key trip_id route_id  calitp_itp_id_x  \
# 400       NaN       NaN  881937      NaN              NaN
#
#      calitp_url_number_x service_id service_date service_indicator  \
# 400                  NaN        NaN          NaN               NaN
#
#     service_start_date service_end_date service_inclusion service_exclusion  \
# 400                NaN              NaN               NaN               NaN
#
#     is_in_service calitp_extracted_at calitp_deleted_at  n_stops  \
# 400           NaN                 NaN               NaN      NaN
#
#      n_stop_times  trip_first_departure_ts  trip_last_arrival_ts  \
# 400           NaN                      NaN                   NaN
#
#      service_hours  calitp_itp_id_y  calitp_url_number_y date_x vehicle_id  \
# 400            NaN              NaN                  NaN    NaN        NaN
#
#     have_rt first_departure  calitp_itp_id  calitp_url_number      date_y  \
# 400     NaN             NaN          300.0                0.0  2022-05-07
#
#     start_time      _merge
# 400   04:39:56  right_only

# %%
test_sched>>count(_.route_id)>>arrange(_.n)
# Out:
#    route_id   n
# 10     3498   2
# 8      3493  10
# 9      3494  11
# 5      3487  12
# 7      3490  19
# 4      3486  22
# 1      3480  23
# 6      3489  25
# 3      3485  42
# 2      3481  48
# 0      3479  52

# %%
alt.Chart((test_sched>>count(_.route_id))).mark_bar().encode(
    x='route_id',
    y='n'
)
# Out:
# alt.Chart(...)

# %%
test_sched>>select(_.trip_id,
                  _.first_departure)>>filter(_.first_departure.notnull())
# Out:
#     trip_id first_departure
# 0    880900        18:40:00
# 1    882173        17:25:00
# 2    881122        22:25:00
# 3    880520        19:26:00
# 4    881975        21:45:00
# ..      ...             ...
# 261  882194        19:20:11
# 262  881132        19:20:00
# 263  880586        19:03:00
# 264  880533        22:44:00
# 265  881556        20:50:00
#
# [266 rows x 2 columns]

# %%
# alt.Chart((test_sched)).mark_circle().encode(
#     x='route_id',
#     y='first_departure:T'
# )

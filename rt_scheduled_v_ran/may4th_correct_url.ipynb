# %% [markdown]
# # All Agencies

# %% [markdown]
# * using a sample of data from May 4th with all operators

# %%
import utils
from shared_utils import portfolio_utils

from siuba import *
import pandas as pd

import altair as alt

import os
os.environ["CALITP_BQ_MAX_BYTES"] = str(800_000_000_000) ## 800GB?

from calitp_data_analysis import query_sql
# Out:
# /opt/conda/lib/python3.10/site-packages/geopandas/_compat.py:112: UserWarning: The Shapely GEOS version (3.10.3-CAPI-1.16.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
# may4 = query_sql(f'''
# SELECT * FROM `cal-itp-data-infra-staging.natalie_views.gtfs_rt_vs_schedule_trips_may4_sample`
# ''')

## alternatively 
may4 = query_sql(f'''
SELECT * FROM `cal-itp-data-infra.views.gtfs_rt_vs_schedule_trips_may4_sample`
''')

# %%
may4['service_date'] = pd.to_datetime(may4['service_date'])
may4['weekday'] = pd.Series(may4.service_date).dt.day_name()    
may4['month'] =  pd.Series(may4.service_date).dt.month_name()

# %%
itpid_district = portfolio_utils.add_caltrans_district()
may4 = pd.merge(may4, itpid_district, on='calitp_itp_id', how='left')

# %%
may4.head()
# Out:
#    calitp_itp_id        agency_name  calitp_url_number route_id  \
# 0            200  County Connection                  0    CC:28
# 1            289   RTA - SCT - Paso                  0      15N
# 2            289   RTA - SCT - Paso                  0       24
# 3            289   RTA - SCT - Paso                  0       9N
# 4            289   RTA - SCT - Paso                  0      12S
#
#   route_short_name service_date calitp_extracted_at calitp_deleted_at  \
# 0               28   2022-05-04          2021-11-15        2099-01-01
# 1              15N   2022-05-04          2021-11-18        2099-01-01
# 2               24   2022-05-04          2021-11-18        2099-01-01
# 3               9N   2022-05-04          2021-11-18        2099-01-01
# 4              12S   2022-05-04          2021-11-18        2099-01-01
#
#    num_sched  num_vp  pct_w_vp    weekday month     caltrans_district  \
# 0         23      21      0.91  Wednesday   May                  None
# 1          5       0      0.00  Wednesday   May  05 - San Luis Obispo
# 2         14       0      0.00  Wednesday   May  05 - San Luis Obispo
# 3         16       0      0.00  Wednesday   May  05 - San Luis Obispo
# 4         16       0      0.00  Wednesday   May  05 - San Luis Obispo
#
#    multiple_url drop_record
# 0         False        None
# 1         False        None
# 2         False        None
# 3         False        None
# 4         False        None

# %%
#note: after filtering out some of the url numbers for certain agencies, we now get a lower count of agencies.
may4.agency_name.nunique()
# Out:
# 188

# %%
may4.calitp_itp_id.nunique()
# Out:
# 167

# %%
may4>>count(_.agency_name)>>arrange(-_.n)
# Out:
#                                        agency_name    n
# 1                                       AC TRANSIT  387
# 173                                            VTA  201
# 142  San Francisco Municipal Transportation Agency  183
# 114         Orange County Transportation Authority  174
# 85                                       LA Go Bus  171
# ..                                             ...  ...
# 161                                       The Lift    1
# 177                           Van Galder Coach USA    1
# 178                                Vegas Airporter    1
# 180                             Vermont Translines    1
# 185   Yosemite Area Regional Transportation System    1
#
# [188 rows x 2 columns]

# %%
may4>>group_by(_.calitp_itp_id)>>summarize(n=_.calitp_url_number.nunique())>>arrange(-_.n)
# Out:
#      calitp_itp_id  n
# 40             106  3
# 133            315  3
# 148            350  3
# 0                4  2
# 2               10  2
# ..             ... ..
# 162            473  1
# 163            474  1
# 164            482  1
# 165            483  1
# 166            484  1
#
# [167 rows x 2 columns]

# %%
may4>>filter(_.calitp_itp_id==106)
# Out:
#       calitp_itp_id     agency_name  calitp_url_number           route_id  \
# 1474            106  Emery Go-Round                  1  Shellmound/Powell
# 1475            106  Emery Go-Round                  1             Hollis
# 2948            106  Emery Go-Round                  2               4820
# 2949            106  Emery-Go-Round                  0               2080
# 2950            106  Emery Go-Round                  2               4817
# 2951            106  Emery-Go-Round                  0               2094
#
#        route_short_name service_date calitp_extracted_at calitp_deleted_at  \
# 1474  Shellmound/Powell   2022-05-04          2021-05-13        2099-01-01
# 1475             Hollis   2022-05-04          2021-05-13        2099-01-01
# 2948               None   2022-05-04          2022-04-06        2099-01-01
# 2949  Shellmound/Powell   2022-05-04          2022-04-06        2099-01-01
# 2950               None   2022-05-04          2022-04-06        2099-01-01
# 2951             Hollis   2022-05-04          2022-04-06        2099-01-01
#
#       num_sched  num_vp  pct_w_vp    weekday month caltrans_district
# 1474         65      65      1.00  Wednesday   May      04 - Oakland
# 1475         68      68      1.00  Wednesday   May      04 - Oakland
# 2948         65       0      0.00  Wednesday   May      04 - Oakland
# 2949         65      64      0.98  Wednesday   May      04 - Oakland
# 2950         68       0      0.00  Wednesday   May      04 - Oakland
# 2951         68      68      1.00  Wednesday   May      04 - Oakland

# %%
utils.agg_by_date(may4, 'num_sched', 'num_vp')
# Out:
#      calitp_itp_id                                        agency_name  \
# 0                4                                         AC TRANSIT
# 1                4                                         AC TRANSIT
# 2                6                         Alhambra Community Transit
# 3               10                          Altamont Corridor Express
# 4               10                          Altamont Corridor Express
# ..             ...                                                ...
# 272            389  North Lake Tahoe Express - 24 hour advance res...
# 273            389                Tahoe Truckee Area Regional Transit
# 274            474              Tulare County Regional Transit Agency
# 275            483                          Tulare InterModal Express
# 276            484                                            StanRTA
#
#      calitp_url_number service_date    weekday month  total_num_sched  \
# 0                    0   2022-05-04  Wednesday   May             5378
# 1                    1   2022-05-04  Wednesday   May             5378
# 2                    0   2022-05-04  Wednesday   May              101
# 3                    0   2022-05-04  Wednesday   May                6
# 4                    1   2022-05-04  Wednesday   May                6
# ..                 ...          ...        ...   ...              ...
# 272                  0   2022-05-04  Wednesday   May               19
# 273                  0   2022-05-04  Wednesday   May               90
# 274                  0   2022-05-04  Wednesday   May              517
# 275                  0   2022-05-04  Wednesday   May              180
# 276                  0   2022-05-04  Wednesday   May             1075
#
#      total_num_vp  pct_w_vp
# 0            4933      0.92
# 1            4932      0.92
# 2               0      0.00
# 3               0      0.00
# 4               0      0.00
# ..            ...       ...
# 272             0      0.00
# 273             0      0.00
# 274             0      0.00
# 275            74      0.41
# 276           922      0.86
#
# [277 rows x 9 columns]

# %% [markdown]
# ## By District

# %%
(utils.get_agg_pct(may4,
                groupings = ['caltrans_district'],
                sum_sched = 'num_sched',
                sum_vp = 'num_vp',
               ))>>select(_.caltrans_district, _.avg)
# Out:
#        caltrans_district  avg
# 0                   None  NaN
# 1   05 - San Luis Obispo 0.27
# 2       07 - Los Angeles 0.69
# 3           04 - Oakland 0.50
# 4          10 - Stockton 0.68
# 5        03 - Marysville 0.04
# 6         11 - San Diego 0.96
# 7           02 - Redding 0.30
# 8    08 - San Bernardino 0.43
# 9            06 - Fresno 0.39
# 10           09 - Bishop 0.63
# 11           01 - Eureka 0.26
# 12           12 - Irvine 0.33

# %% [markdown]
# ### Checking District 5 with one of the lowest percent average

# %%
may4>>filter(_.caltrans_district=='05 - San Luis Obispo',
            _.num_vp==0)>>count(_.agency_name)
# Out:
#                        agency_name   n
# 0                        A11214029   2
# 1  City of San Luis Obispo Transit   6
# 2                  Guadalupe Flyer   1
# 3                 RTA - SCT - Paso  16
# 4        San Benito County Express   3

# %%
may4>>filter( _.agency_name=='A11214029')
# Out:
#     calitp_itp_id agency_name  calitp_url_number route_id route_short_name  \
# 71            312   A11214029                  0   ROUTEA             None
# 72            312   A11214029                  0   ROUTEB             None
#
#    service_date calitp_extracted_at calitp_deleted_at  num_sched  num_vp  \
# 71   2022-05-04          2021-12-03        2099-01-01         64       0
# 72   2022-05-04          2021-12-03        2099-01-01          8       0
#
#     pct_w_vp    weekday month     caltrans_district
# 71      0.00  Wednesday   May  05 - San Luis Obispo
# 72      0.00  Wednesday   May  05 - San Luis Obispo

# %%
may4>>filter( _.agency_name=='City of San Luis Obispo Transit')
# Out:
#       calitp_itp_id                      agency_name  calitp_url_number  \
# 1694            287  City of San Luis Obispo Transit                  0
# 1695            287  City of San Luis Obispo Transit                  0
# 1696            287  City of San Luis Obispo Transit                  0
# 1697            287  City of San Luis Obispo Transit                  0
# 1698            287  City of San Luis Obispo Transit                  0
# 1699            287  City of San Luis Obispo Transit                  0
#
#       route_id route_short_name service_date calitp_extracted_at  \
# 1694  10866895               2A   2022-05-04          2022-01-30
# 1695  10866849               3B   2022-05-04          2022-01-30
# 1696  10867637               4B   2022-05-04          2022-01-30
# 1697  10867636               4A   2022-05-04          2022-01-30
# 1698  10866892               1A   2022-05-04          2022-01-30
# 1699  10866897               3A   2022-05-04          2022-01-30
#
#      calitp_deleted_at  num_sched  num_vp  pct_w_vp    weekday month  \
# 1694        2099-01-01         16       0      0.00  Wednesday   May
# 1695        2099-01-01         12       0      0.00  Wednesday   May
# 1696        2099-01-01         17       0      0.00  Wednesday   May
# 1697        2099-01-01          6       0      0.00  Wednesday   May
# 1698        2099-01-01         16       0      0.00  Wednesday   May
# 1699        2099-01-01         14       0      0.00  Wednesday   May
#
#          caltrans_district
# 1694  05 - San Luis Obispo
# 1695  05 - San Luis Obispo
# 1696  05 - San Luis Obispo
# 1697  05 - San Luis Obispo
# 1698  05 - San Luis Obispo
# 1699  05 - San Luis Obispo

# %%
may4>>filter( _.agency_name=='Guadalupe Flyer')
# Out:
#       calitp_itp_id      agency_name  calitp_url_number route_id  \
# 3809            129  Guadalupe Flyer                  0     3278
#
#      route_short_name service_date calitp_extracted_at calitp_deleted_at  \
# 3809             None   2022-05-04          2021-10-20        2022-05-19
#
#       num_sched  num_vp  pct_w_vp    weekday month     caltrans_district
# 3809         22       0      0.00  Wednesday   May  05 - San Luis Obispo

# %%
may4>>filter( _.agency_name=='RTA - SCT - Paso')
# Out:
#       calitp_itp_id       agency_name  calitp_url_number route_id  \
# 1               289  RTA - SCT - Paso                  0      15N
# 2               289  RTA - SCT - Paso                  0       24
# 3               289  RTA - SCT - Paso                  0       9N
# 4               289  RTA - SCT - Paso                  0      12S
# 5               289  RTA - SCT - Paso                  0      10N
# 6               289  RTA - SCT - Paso                  0        B
# 7               289  RTA - SCT - Paso                  0       21
# 8               289  RTA - SCT - Paso                  0        A
# 9               289  RTA - SCT - Paso                  0      12N
# 10              289  RTA - SCT - Paso                  0       28
# 11              289  RTA - SCT - Paso                  0      10S
# 12              289  RTA - SCT - Paso                  0      15S
# 13              289  RTA - SCT - Paso                  0       9S
# 1145            289  RTA - SCT - Paso                  0      14N
# 1146            289  RTA - SCT - Paso                  0       27
# 1147            289  RTA - SCT - Paso                  0      14S
#
#      route_short_name service_date calitp_extracted_at calitp_deleted_at  \
# 1                 15N   2022-05-04          2021-11-18        2099-01-01
# 2                  24   2022-05-04          2021-11-18        2099-01-01
# 3                  9N   2022-05-04          2021-11-18        2099-01-01
# 4                 12S   2022-05-04          2021-11-18        2099-01-01
# 5                 10N   2022-05-04          2021-11-18        2099-01-01
# 6                   B   2022-05-04          2021-11-18        2099-01-01
# 7                  21   2022-05-04          2021-11-18        2099-01-01
# 8                   A   2022-05-04          2021-11-18        2099-01-01
# 9                 12N   2022-05-04          2021-11-18        2099-01-01
# 10                 28   2022-05-04          2021-11-18        2099-01-01
# 11                10S   2022-05-04          2021-11-18        2099-01-01
# 12                15S   2022-05-04          2021-11-18        2099-01-01
# 13                 9S   2022-05-04          2021-11-18        2099-01-01
# 1145              14N   2022-05-04          2021-12-31        2022-08-12
# 1146               27   2022-05-04          2021-12-31        2099-01-01
# 1147              14S   2022-05-04          2021-12-31        2099-01-01
#
#       num_sched  num_vp  pct_w_vp    weekday month     caltrans_district
# 1             5       0      0.00  Wednesday   May  05 - San Luis Obispo
# 2            14       0      0.00  Wednesday   May  05 - San Luis Obispo
# 3            16       0      0.00  Wednesday   May  05 - San Luis Obispo
# 4            16       0      0.00  Wednesday   May  05 - San Luis Obispo
# 5            15       0      0.00  Wednesday   May  05 - San Luis Obispo
# 6            13       0      0.00  Wednesday   May  05 - San Luis Obispo
# 7            14       0      0.00  Wednesday   May  05 - San Luis Obispo
# 8            13       0      0.00  Wednesday   May  05 - San Luis Obispo
# 9            15       0      0.00  Wednesday   May  05 - San Luis Obispo
# 10           14       0      0.00  Wednesday   May  05 - San Luis Obispo
# 11           15       0      0.00  Wednesday   May  05 - San Luis Obispo
# 12            5       0      0.00  Wednesday   May  05 - San Luis Obispo
# 13           18       0      0.00  Wednesday   May  05 - San Luis Obispo
# 1145          1       0      0.00  Wednesday   May  05 - San Luis Obispo
# 1146         15       0      0.00  Wednesday   May  05 - San Luis Obispo
# 1147          1       0      0.00  Wednesday   May  05 - San Luis Obispo

# %%
may4>>filter( _.agency_name=='San Benito County Express')
# Out:
#      calitp_itp_id                agency_name  calitp_url_number route_id  \
# 113            274  San Benito County Express                  0      610
# 114            274  San Benito County Express                  0      606
# 115            274  San Benito County Express                  0      607
#
#     route_short_name service_date calitp_extracted_at calitp_deleted_at  \
# 113             None   2022-05-04          2021-12-17        2022-08-10
# 114             None   2022-05-04          2021-12-17        2022-08-10
# 115             None   2022-05-04          2021-12-17        2022-08-10
#
#      num_sched  num_vp  pct_w_vp    weekday month     caltrans_district
# 113         26       0      0.00  Wednesday   May  05 - San Luis Obispo
# 114          4       0      0.00  Wednesday   May  05 - San Luis Obispo
# 115          5       0      0.00  Wednesday   May  05 - San Luis Obispo

# %% [markdown]
# * most agencies with 0 pct ran have null vehicle positions data according to agencies.yml
# * Exception: `calitp_itp_id` 312: Santa Ynez Valley Transit

# %% [markdown]
# ## URL Numbers

# %% [markdown]
# * how many feeds with no vehicle position data have multiple calitp_url_numbers

# %%
may4>>group_by(_.calitp_itp_id, _.agency_name)>>filter(_.num_vp==0)>>summarize(n_urls = _.calitp_url_number.nunique())>>arrange(-_.n_urls)
# Out:
#      calitp_itp_id                                        agency_name  n_urls
# 0                4                                         AC TRANSIT       2
# 2               10                          Altamont Corridor Express       2
# 60              56            Capitol Corridor Joint Powers Authority       2
# 132            218                                       VINE Transit       2
# 155            264                             Rio Vista Delta Breeze       2
# ..             ...                                                ...     ...
# 203            386  Yuma County Intergovernmental Public Transport...       1
# 204            389  North Lake Tahoe Express - 24 hour advance res...       1
# 205            389                Tahoe Truckee Area Regional Transit       1
# 206            474              Tulare County Regional Transit Agency       1
# 207            484                                            StanRTA       1
#
# [208 rows x 3 columns]

# %%
#which ones have multiple? might need to identify specific calitp_url_numbers
may4>>group_by(_.calitp_itp_id, _.agency_name)>>summarize(n_urls = _.calitp_url_number.nunique())>>filter(_.n_urls>1)
# Out:
#      calitp_itp_id                                    agency_name  n_urls
# 0                4                                     AC TRANSIT       2
# 2               10                      Altamont Corridor Express       2
# 62              56        Capitol Corridor Joint Powers Authority       2
# 82             106                                 Emery Go-Round       2
# 89             110                   Fairfield and Suisun Transit       2
# 126            194                                  Marin Transit       2
# 166            218                                   VINE Transit       2
# 180            235         Orange County Transportation Authority       2
# 184            246                                       Caltrain       2
# 192            264                         Rio Vista Delta Breeze       2
# 201            280                        San Francisco Bay Ferry       2
# 203            282  San Francisco Municipal Transportation Agency       2
# 208            294                                            VTA       2
# 214            310                                       SolTrans       2
# 216            314                          Sonoma County Transit       2
# 218            315                 Sonoma Marin Area Rail Transit       2
# 237            350                             Union City Transit       3
# 239            356                           Vacaville City Coach       2
# 240            360                Victor Valley Transit Authority       2
# 243            368                 WestCat (Western Contra Costa)       2

# %%
#may4>>filter(_.calitp_itp_id==235)

# %%
#may4>>filter(_.calitp_itp_id==56)

# %% [markdown]
# * might just be some certain routes that dont have vehicle postitons

# %%
may4>>filter(_.num_vp==0)>>group_by(_.calitp_itp_id, _.agency_name)>>summarize(num_routes_novp = _.route_id.nunique())>>arrange(-_.num_routes_novp)
# Out:
#      calitp_itp_id                                        agency_name  \
# 169            294                                                VTA
# 158            273                        Sacramento Regional Transit
# 168            290                                           SamTrans
# 165            282      San Francisco Municipal Transportation Agency
# 91             142             Orange County Transportation Authority
# ..             ...                                                ...
# 171            305                         Sierra Madre Gateway Coach
# 175            315                     Sonoma Marin Area Rail Transit
# 179            329  Susanville Indian Rancheria Public Transportat...
# 183            334  Susanville Indian Rancheria Public Transportat...
# 198            374       Yosemite Area Regional Transportation System
#
#      num_routes_novp
# 169               70
# 158               68
# 168               66
# 165               61
# 91                58
# ..               ...
# 171                1
# 175                1
# 179                1
# 183                1
# 198                1
#
# [208 rows x 3 columns]

# %%
may4>>filter(_.num_vp==0, _.calitp_itp_id==294)>>arrange(_.calitp_url_number)
# Out:
#       calitp_itp_id agency_name  calitp_url_number    route_id  \
# 781             294         VTA                  0          70
# 782             294         VTA                  0          59
# 783             294         VTA                  0          71
# 3587            294         VTA                  0          26
# 3588            294         VTA                  0          87
# ...             ...         ...                ...         ...
# 3736            294         VTA                  0       SCVMC
# 3737            294         VTA                  0         568
# 1006            294         VTA                  1     ACE Red
# 1038            294         VTA                  1   ACE Green
# 1056            294         VTA                  1  ACE Yellow
#
#      route_short_name service_date calitp_extracted_at calitp_deleted_at  \
# 781                70   2022-05-04          2021-12-27        2022-05-14
# 782                59   2022-05-04          2021-12-27        2022-05-14
# 783                71   2022-05-04          2021-12-27        2022-05-14
# 3587               26   2022-05-04          2021-09-15        2022-05-14
# 3588               87   2022-05-04          2021-09-15        2022-05-14
# ...               ...          ...                 ...               ...
# 3736            SCVMC   2022-05-04          2021-10-05        2022-05-14
# 3737        Rapid 568   2022-05-04          2021-10-05        2022-05-14
# 1006          ACE Red   2022-05-04          2021-12-29        2099-01-01
# 1038        ACE Green   2022-05-04          2021-12-29        2099-01-01
# 1056       ACE Yellow   2022-05-04          2021-12-29        2099-01-01
#
#       num_sched  num_vp  pct_w_vp    weekday month caltrans_district
# 781         129       0      0.00  Wednesday   May      04 - Oakland
# 782          60       0      0.00  Wednesday   May      04 - Oakland
# 783          64       0      0.00  Wednesday   May      04 - Oakland
# 3587        114       0      0.00  Wednesday   May      04 - Oakland
# 3588         14       0      0.00  Wednesday   May      04 - Oakland
# ...         ...     ...       ...        ...   ...               ...
# 3736         17       0      0.00  Wednesday   May      04 - Oakland
# 3737         54       0      0.00  Wednesday   May      04 - Oakland
# 1006          8       0      0.00  Wednesday   May      04 - Oakland
# 1038          8       0      0.00  Wednesday   May      04 - Oakland
# 1056          8       0      0.00  Wednesday   May      04 - Oakland
#
# [70 rows x 14 columns]

# %%
may4>>filter(_.calitp_itp_id==294)>>group_by(_.calitp_url_number)>>summarize(n_routeid= _.route_id.nunique())
# Out:
#    calitp_url_number  n_routeid
# 0                  0         67
# 1                  1         67

# %%
(may4>>filter(_.calitp_itp_id==294)>>arrange(_.route_id)).head(30)
# Out:
#       calitp_itp_id agency_name  calitp_url_number route_id route_short_name  \
# 3589            294         VTA                  0      101      Express 101
# 3631            294         VTA                  0      102      Express 102
# 3618            294         VTA                  0      103      Express 103
# 3639            294         VTA                  0      104      Express 104
# 1015            294         VTA                  1       20               20
# 3610            294         VTA                  0       20               20
# 1055            294         VTA                  1       21               21
# 3602            294         VTA                  0       21               21
# 1044            294         VTA                  1       22               22
# 3622            294         VTA                  0       22               22
# 1050            294         VTA                  1       23               23
# 3632            294         VTA                  0       23               23
# 3635            294         VTA                  0      246       School 246
# 3593            294         VTA                  0      247       School 247
# 996             294         VTA                  1       25               25
# 3621            294         VTA                  0       25               25
# 3647            294         VTA                  0      256       School 256
# 1000            294         VTA                  1       26               26
# 3587            294         VTA                  0       26               26
# 1020            294         VTA                  1       27               27
# 3594            294         VTA                  0       27               27
# 3592            294         VTA                  0      270       School 270
# 3644            294         VTA                  0      287       School 287
# 3634            294         VTA                  0      288       School 288
# 3641            294         VTA                  0     288L      School 288L
# 3612            294         VTA                  0     288M      School 288M
# 1017            294         VTA                  1       31               31
# 3598            294         VTA                  0       31               31
# 1001            294         VTA                  1       37               37
# 3633            294         VTA                  0       37               37
#
#      service_date calitp_extracted_at calitp_deleted_at  num_sched  num_vp  \
# 3589   2022-05-04          2021-09-15        2022-05-14          4       0
# 3631   2022-05-04          2021-09-15        2022-05-14         10       0
# 3618   2022-05-04          2021-09-15        2022-05-14          6       0
# 3639   2022-05-04          2021-09-15        2022-05-14          4       0
# 1015   2022-05-04          2021-12-29        2099-01-01         54      54
# 3610   2022-05-04          2021-09-15        2022-05-14         54       0
# 1055   2022-05-04          2021-12-29        2099-01-01         59      59
# 3602   2022-05-04          2021-09-15        2022-05-14         59       0
# 1044   2022-05-04          2021-12-29        2099-01-01        146     144
# 3622   2022-05-04          2021-09-15        2022-05-14        146       0
# 1050   2022-05-04          2021-12-29        2099-01-01        131     131
# 3632   2022-05-04          2021-09-15        2022-05-14        131       0
# 3635   2022-05-04          2021-09-15        2022-05-14          5       0
# 3593   2022-05-04          2021-09-15        2022-05-14          2       0
# 996    2022-05-04          2021-12-29        2099-01-01        151     144
# 3621   2022-05-04          2021-09-15        2022-05-14        151       0
# 3647   2022-05-04          2021-09-15        2022-05-14          3       0
# 1000   2022-05-04          2021-12-29        2099-01-01        114     113
# 3587   2022-05-04          2021-09-15        2022-05-14        114       0
# 1020   2022-05-04          2021-12-29        2099-01-01         58      58
# 3594   2022-05-04          2021-09-15        2022-05-14         58       0
# 3592   2022-05-04          2021-09-15        2022-05-14          2       0
# 3644   2022-05-04          2021-09-15        2022-05-14          1       0
# 3634   2022-05-04          2021-09-15        2022-05-14          3       0
# 3641   2022-05-04          2021-09-15        2022-05-14          2       0
# 3612   2022-05-04          2021-09-15        2022-05-14          2       0
# 1017   2022-05-04          2021-12-29        2099-01-01         57      56
# 3598   2022-05-04          2021-09-15        2022-05-14         57       0
# 1001   2022-05-04          2021-12-29        2099-01-01         27      27
# 3633   2022-05-04          2021-09-15        2022-05-14         27       0
#
#       pct_w_vp    weekday month caltrans_district
# 3589      0.00  Wednesday   May      04 - Oakland
# 3631      0.00  Wednesday   May      04 - Oakland
# 3618      0.00  Wednesday   May      04 - Oakland
# 3639      0.00  Wednesday   May      04 - Oakland
# 1015      1.00  Wednesday   May      04 - Oakland
# 3610      0.00  Wednesday   May      04 - Oakland
# 1055      1.00  Wednesday   May      04 - Oakland
# 3602      0.00  Wednesday   May      04 - Oakland
# 1044      0.99  Wednesday   May      04 - Oakland
# 3622      0.00  Wednesday   May      04 - Oakland
# 1050      1.00  Wednesday   May      04 - Oakland
# 3632      0.00  Wednesday   May      04 - Oakland
# 3635      0.00  Wednesday   May      04 - Oakland
# 3593      0.00  Wednesday   May      04 - Oakland
# 996       0.95  Wednesday   May      04 - Oakland
# 3621      0.00  Wednesday   May      04 - Oakland
# 3647      0.00  Wednesday   May      04 - Oakland
# 1000      0.99  Wednesday   May      04 - Oakland
# 3587      0.00  Wednesday   May      04 - Oakland
# 1020      1.00  Wednesday   May      04 - Oakland
# 3594      0.00  Wednesday   May      04 - Oakland
# 3592      0.00  Wednesday   May      04 - Oakland
# 3644      0.00  Wednesday   May      04 - Oakland
# 3634      0.00  Wednesday   May      04 - Oakland
# 3641      0.00  Wednesday   May      04 - Oakland
# 3612      0.00  Wednesday   May      04 - Oakland
# 1017      0.98  Wednesday   May      04 - Oakland
# 3598      0.00  Wednesday   May      04 - Oakland
# 1001      1.00  Wednesday   May      04 - Oakland
# 3633      0.00  Wednesday   May      04 - Oakland

# %%
d4_multiple = (may4
 >>filter(_.caltrans_district=='04 - Oakland')
 >>group_by(_.calitp_itp_id, _.agency_name)
 >>summarize(n_itp_url = _.calitp_url_number.nunique())
 >>filter(_.n_itp_url>1))

# %%
(d4_multiple)
# Out:
#     calitp_itp_id                                    agency_name  n_itp_url
# 0               4                                     AC TRANSIT          2
# 1              56        Capitol Corridor Joint Powers Authority          2
# 6             106                                 Emery Go-Round          2
# 8             110                   Fairfield and Suisun Transit          2
# 11            194                                  Marin Transit          2
# 14            218                                   VINE Transit          2
# 15            246                                       Caltrain          2
# 19            264                         Rio Vista Delta Breeze          2
# 21            280                        San Francisco Bay Ferry          2
# 23            282  San Francisco Municipal Transportation Agency          2
# 25            294                                            VTA          2
# 27            310                                       SolTrans          2
# 28            314                          Sonoma County Transit          2
# 30            315                 Sonoma Marin Area Rail Transit          2
# 33            350                             Union City Transit          3
# 34            356                           Vacaville City Coach          2
# 35            368                 WestCat (Western Contra Costa)          2

# %%
all_multiple = (may4
 >>group_by(_.calitp_itp_id, _.agency_name)
 >>summarize(n_itp_url = _.calitp_url_number.nunique())
 >>filter(_.n_itp_url>1))
all_multiple
# Out:
#      calitp_itp_id                                    agency_name  n_itp_url
# 0                4                                     AC TRANSIT          2
# 2               10                      Altamont Corridor Express          2
# 62              56        Capitol Corridor Joint Powers Authority          2
# 82             106                                 Emery Go-Round          2
# 89             110                   Fairfield and Suisun Transit          2
# 126            194                                  Marin Transit          2
# 166            218                                   VINE Transit          2
# 180            235         Orange County Transportation Authority          2
# 184            246                                       Caltrain          2
# 192            264                         Rio Vista Delta Breeze          2
# 201            280                        San Francisco Bay Ferry          2
# 203            282  San Francisco Municipal Transportation Agency          2
# 208            294                                            VTA          2
# 214            310                                       SolTrans          2
# 216            314                          Sonoma County Transit          2
# 218            315                 Sonoma Marin Area Rail Transit          2
# 237            350                             Union City Transit          3
# 239            356                           Vacaville City Coach          2
# 240            360                Victor Valley Transit Authority          2
# 243            368                 WestCat (Western Contra Costa)          2

# %%
all_multiple_agencies = all_multiple.calitp_itp_id.to_list()

# %%
# d4_multiple_agencies = d4_multiple.calitp_itp_id.to_list()

# %%
# # check to see which urls have no vp positions and which do for D4
# ## want to make sure url #1 is the right one...
# (utils.get_agg_pct((may4[may4['calitp_itp_id'].isin(d4_multiple_agencies)]),
#                 groupings= ['calitp_itp_id', 'agency_name', 'calitp_url_number'],
#                 sum_sched = 'num_sched',
#                 sum_vp = 'num_vp'
#                ))>>arrange(_.calitp_itp_id, _.calitp_url_number)

# %%
# check to see which urls have no vp positions and which do for all
## want to make sure url #1 is the right one...
(utils.get_agg_pct((may4[may4['calitp_itp_id'].isin(all_multiple_agencies)]),
                groupings= ['calitp_itp_id', 'agency_name', 'calitp_url_number'],
                sum_sched = 'num_sched',
                sum_vp = 'num_vp'
               ))>>arrange(_.calitp_itp_id, _.calitp_url_number)
# Out:
#     calitp_itp_id                                    agency_name  \
# 28              4                                     AC TRANSIT
# 27              4                                     AC TRANSIT
# 0              10                      Altamont Corridor Express
# 10             10                      Altamont Corridor Express
# 1              56        Capitol Corridor Joint Powers Authority
# 12             56        Capitol Corridor Joint Powers Authority
# 41            106                                 Emery-Go-Round
# 22            106                                 Emery Go-Round
# 40            106                                 Emery Go-Round
# 24            110                   Fairfield and Suisun Transit
# 23            110                   Fairfield and Suisun Transit
# 30            194                                  Marin Transit
# 16            194                                  Marin Transit
# 26            218                                   VINE Transit
# 17            218                                   VINE Transit
# 7             235         Orange County Transportation Authority
# 20            235         Orange County Transportation Authority
# 31            246                                       Caltrain
# 18            246                                       Caltrain
# 29            264                         Rio Vista Delta Breeze
# 9             264                         Rio Vista Delta Breeze
# 32            280                        San Francisco Bay Ferry
# 33            280                        San Francisco Bay Ferry
# 42            282  San Francisco Municipal Transportation Agency
# 25            282  San Francisco Municipal Transportation Agency
# 5             294                                            VTA
# 11            294                                            VTA
# 19            310                                       SolTrans
# 21            310                                       SolTrans
# 2             314                          Sonoma County Transit
# 13            314                          Sonoma County Transit
# 34            315                                          SMART
# 14            315                 Sonoma Marin Area Rail Transit
# 35            315                 Sonoma Marin Area Rail Transit
# 37            350                             Union City Transit
# 6             350                             Union City Transit
# 36            350                             Union City Transit
# 3             356                           Vacaville City Coach
# 15            356                           Vacaville City Coach
# 38            360                Victor Valley Transit Authority
# 39            360                Victor Valley Transit Authority
# 4             368                 WestCat (Western Contra Costa)
# 8             368                 WestCat (Western Contra Costa)
#
#     calitp_url_number  num_sched  num_vp  avg
# 28                  0       5378    4933 0.92
# 27                  1       5378    4932 0.92
# 0                   0          6       0 0.00
# 10                  1          6       0 0.00
# 1                   0         51       0 0.00
# 12                  1         51       0 0.00
# 41                  0        133     132 0.99
# 22                  1        133     133 1.00
# 40                  2        133       0 0.00
# 24                  0        317       0 0.00
# 23                  1        317     317 1.00
# 30                  0        704     644 0.91
# 16                  1        704     635 0.90
# 26                  0        216       0 0.00
# 17                  1        216     182 0.84
# 7                   0       3183       0 0.00
# 20                  1       3183    3171 1.00
# 31                  0         88       0 0.00
# 18                  1         88      68 0.77
# 29                  0          8       0 0.00
# 9                   1          8       0 0.00
# 32                  0        141       0 0.00
# 33                  1        141       0 0.00
# 42                  0       8707       0 0.00
# 25                  1       8707    8268 0.95
# 5                   0       3657       0 0.00
# 11                  1       3657    3560 0.97
# 19                  0        402     349 0.87
# 21                  1        402     349 0.87
# 2                   0        251       0 0.00
# 13                  1        251       0 0.00
# 34                  0        252     176 0.70
# 14                  1         26      26 1.00
# 35                  2         26       0 0.00
# 37                  0        236     124 0.53
# 6                   1        270     124 0.46
# 36                  2        270       0 0.00
# 3                   0        123       0 0.00
# 15                  1        123       0 0.00
# 38                  0        535     525 0.98
# 39                  1        658       0 0.00
# 4                   0        555       0 0.00
# 8                   1        555       0 0.00

# %% [markdown]
# * Most correct urls are 1
# * ones to check
#     * SMART / Sonoma Marin Area Rail Transit: itp_id 315
#     * Marin Transit: itp_id 194
# * Many also have no vehicle position data
# * Victor Valley Transit Authority: itp_id= 360 is 0

# %%
may4['multiple_url'] = may4['calitp_itp_id'].isin(all_multiple_agencies)

# %%
(may4>>filter(_.multiple_url==True)>>group_by(_.calitp_itp_id, _.agency_name)>>summarize(n_url = _.calitp_url_number.nunique())>>arrange(-_.n_url))
# Out:
#     calitp_itp_id                                    agency_name  n_url
# 18            350                             Union City Transit      3
# 0               4                                     AC TRANSIT      2
# 1              10                      Altamont Corridor Express      2
# 2              56        Capitol Corridor Joint Powers Authority      2
# 3             106                                 Emery Go-Round      2
# 5             110                   Fairfield and Suisun Transit      2
# 6             194                                  Marin Transit      2
# 7             218                                   VINE Transit      2
# 8             235         Orange County Transportation Authority      2
# 9             246                                       Caltrain      2
# 10            264                         Rio Vista Delta Breeze      2
# 11            280                        San Francisco Bay Ferry      2
# 12            282  San Francisco Municipal Transportation Agency      2
# 13            294                                            VTA      2
# 14            310                                       SolTrans      2
# 15            314                          Sonoma County Transit      2
# 17            315                 Sonoma Marin Area Rail Transit      2
# 19            356                           Vacaville City Coach      2
# 20            360                Victor Valley Transit Authority      2
# 21            368                 WestCat (Western Contra Costa)      2
# 4             106                                 Emery-Go-Round      1
# 16            315                                          SMART      1

# %%
# check to see which urls have no vp positions and which do for all
## want to make sure url #1 is the right one...
(utils.get_agg_pct((may4[may4['calitp_itp_id'].isin(all_multiple_agencies)]),
                groupings= ['calitp_itp_id', 'agency_name', 'calitp_url_number'],
                sum_sched = 'num_sched',
                sum_vp = 'num_vp'
               ))>>arrange(_.calitp_itp_id, _.calitp_url_number)
# Out:
#     calitp_itp_id                                    agency_name  \
# 28              4                                     AC TRANSIT
# 27              4                                     AC TRANSIT
# 0              10                      Altamont Corridor Express
# 10             10                      Altamont Corridor Express
# 1              56        Capitol Corridor Joint Powers Authority
# 12             56        Capitol Corridor Joint Powers Authority
# 41            106                                 Emery-Go-Round
# 22            106                                 Emery Go-Round
# 40            106                                 Emery Go-Round
# 24            110                   Fairfield and Suisun Transit
# 23            110                   Fairfield and Suisun Transit
# 30            194                                  Marin Transit
# 16            194                                  Marin Transit
# 26            218                                   VINE Transit
# 17            218                                   VINE Transit
# 7             235         Orange County Transportation Authority
# 20            235         Orange County Transportation Authority
# 31            246                                       Caltrain
# 18            246                                       Caltrain
# 29            264                         Rio Vista Delta Breeze
# 9             264                         Rio Vista Delta Breeze
# 32            280                        San Francisco Bay Ferry
# 33            280                        San Francisco Bay Ferry
# 42            282  San Francisco Municipal Transportation Agency
# 25            282  San Francisco Municipal Transportation Agency
# 5             294                                            VTA
# 11            294                                            VTA
# 19            310                                       SolTrans
# 21            310                                       SolTrans
# 2             314                          Sonoma County Transit
# 13            314                          Sonoma County Transit
# 34            315                                          SMART
# 14            315                 Sonoma Marin Area Rail Transit
# 35            315                 Sonoma Marin Area Rail Transit
# 37            350                             Union City Transit
# 6             350                             Union City Transit
# 36            350                             Union City Transit
# 3             356                           Vacaville City Coach
# 15            356                           Vacaville City Coach
# 38            360                Victor Valley Transit Authority
# 39            360                Victor Valley Transit Authority
# 4             368                 WestCat (Western Contra Costa)
# 8             368                 WestCat (Western Contra Costa)
#
#     calitp_url_number  num_sched  num_vp  avg
# 28                  0       5378    4933 0.92
# 27                  1       5378    4932 0.92
# 0                   0          6       0 0.00
# 10                  1          6       0 0.00
# 1                   0         51       0 0.00
# 12                  1         51       0 0.00
# 41                  0        133     132 0.99
# 22                  1        133     133 1.00
# 40                  2        133       0 0.00
# 24                  0        317       0 0.00
# 23                  1        317     317 1.00
# 30                  0        704     644 0.91
# 16                  1        704     635 0.90
# 26                  0        216       0 0.00
# 17                  1        216     182 0.84
# 7                   0       3183       0 0.00
# 20                  1       3183    3171 1.00
# 31                  0         88       0 0.00
# 18                  1         88      68 0.77
# 29                  0          8       0 0.00
# 9                   1          8       0 0.00
# 32                  0        141       0 0.00
# 33                  1        141       0 0.00
# 42                  0       8707       0 0.00
# 25                  1       8707    8268 0.95
# 5                   0       3657       0 0.00
# 11                  1       3657    3560 0.97
# 19                  0        402     349 0.87
# 21                  1        402     349 0.87
# 2                   0        251       0 0.00
# 13                  1        251       0 0.00
# 34                  0        252     176 0.70
# 14                  1         26      26 1.00
# 35                  2         26       0 0.00
# 37                  0        236     124 0.53
# 6                   1        270     124 0.46
# 36                  2        270       0 0.00
# 3                   0        123       0 0.00
# 15                  1        123       0 0.00
# 38                  0        535     525 0.98
# 39                  1        658       0 0.00
# 4                   0        555       0 0.00
# 8                   1        555       0 0.00

# %% [markdown]
# * Most correct urls are 1
# * ones to check
#     * SMART / Sonoma Marin Area Rail Transit: itp_id 315
#     * Marin Transit: itp_id 194
#     * Victor Valley Transit Authority: itp_id= 360 is 0
# * Agencies with 3:
#     * Union City Transit itp_id 350 : drop 0 & 2
#     * SMART itp_id 315: drop 1 & 2
#     * Emery Go-Round itp_id 106: drop 0 & 2
# * Many also have no vehicle position data

# %%
# def get_correct_url(df):
    
#     all_multiple = (df>>group_by(_.calitp_itp_id, _.agency_name)>>summarize(n_itp_url = _.calitp_url_number.nunique()) >>filter(_.n_itp_url>1))
    
#     all_multiple_agencies = all_multiple.calitp_itp_id.to_list()
    
#     df['multiple_url'] = df['calitp_itp_id'].isin(all_multiple_agencies)

#     if (df.multiple_url==True) & (df.calitp_itp_id == 106):
#         df = df.drop(df[(df.calitp_itp_id == 315) & (df.calitp_url_number == 0)| (df.calitp_url_number == 2)].index)
        
#     elif (df.multiple_url==True) & (df.calitp_itp_id == 235):
#         df = df.drop(df[(df.calitp_itp_id == 235) & (df.calitp_url_number == 0)].index)
   
#     elif (df.multiple_url==True) & (df.calitp_itp_id == 315):
#         df = df.drop(df[(df.calitp_itp_id == 315) & (df.calitp_url_number == 1)| (df.calitp_url_number == 2)].index)
        
#     elif (df.multiple_url==True) & (df.calitp_itp_id == 350):
#         df = df.drop(df[(df.calitp_itp_id == 350) & (df.calitp_url_number == 0)| (df.calitp_url_number == 2)].index)
    
#     elif (df.multiple_url==True) & (df.calitp_itp_id == 360):
#         df = df.drop(df[(df.calitp_itp_id == 360) & (df.calitp_url_number == 1)].index)
    
#     elif (df.multiple_url==True):
#         # drop others with only two: 
#         df = df.drop(df[(df.multiple_url==True) & (df.calitp_url_number == 0)].index)
    
#     df = df.drop(columns = ['multiple_url'])
    
#     return df

# %% [markdown]
# ## Correct Function

# %%
def get_correct_url(df):
    
    all_multiple = (df>>group_by(_.calitp_itp_id, _.agency_name)>>summarize(n_itp_url = _.calitp_url_number.nunique()) >>filter(_.n_itp_url>1))
    
    all_multiple_agencies = all_multiple.calitp_itp_id.to_list()
    
    df['multiple_url'] = df['calitp_itp_id'].isin(all_multiple_agencies)

    def remove_rows(row):
        
        #Emery Go-Round
        if (row.multiple_url == True) and (row.calitp_itp_id == 106) and (row.calitp_url_number == 2):
            return "drop"        
        
        #SMART or Sonoma Marin Area Rail Transit
        if (row.multiple_url == True) and (row.calitp_itp_id == 315) and (row.calitp_url_number == 2):
            return "drop"
        
        #  Union City Transit
        elif (row.multiple_url == True) and (row.calitp_itp_id == 350) and (row.calitp_url_number == 2):
            return "drop"
        
        # Victor Valley Transit Authority
        elif (row.multiple_url == True) and (row.calitp_itp_id == 360) and (row.calitp_url_number == 1):
            return "drop"
        
        # drop others with only two: 
        elif (row.multiple_url == True) and (row.calitp_url_number == 0):
            return "drop"

    df['drop_record'] = df.apply(lambda x: remove_rows(x), axis=1)
    
    ##commenting out 106 since we are maininging 511 MTC
    #df.loc[((df['calitp_itp_id']==106) & (df['calitp_url_number'] == 1)), 'drop_record']  = ""
    df.loc[((df['calitp_itp_id']==360) & (df['calitp_url_number'] == 0)), 'drop_record']  = ""    
    
    return df

# %%
may4_url_nbtest = get_correct_url(may4)

# %%
#check 
(utils.get_agg_pct((may4_url_nbtest>>filter(_.drop_record=='drop')),
                groupings = ['calitp_itp_id', 'agency_name', 'calitp_url_number'],
                sum_sched = 'num_sched',
                sum_vp = 'num_vp'
               )>>arrange(_.calitp_itp_id, _.calitp_url_number))
# Out:
#     calitp_itp_id                                    agency_name  \
# 10              4                                     AC TRANSIT
# 0              10                      Altamont Corridor Express
# 1              56        Capitol Corridor Joint Powers Authority
# 21            106                                 Emery-Go-Round
# 20            106                                 Emery Go-Round
# 8             110                   Fairfield and Suisun Transit
# 12            194                                  Marin Transit
# 9             218                                   VINE Transit
# 6             235         Orange County Transportation Authority
# 13            246                                       Caltrain
# 11            264                         Rio Vista Delta Breeze
# 14            280                        San Francisco Bay Ferry
# 22            282  San Francisco Municipal Transportation Agency
# 5             294                                            VTA
# 7             310                                       SolTrans
# 2             314                          Sonoma County Transit
# 15            315                                          SMART
# 16            315                 Sonoma Marin Area Rail Transit
# 18            350                             Union City Transit
# 17            350                             Union City Transit
# 3             356                           Vacaville City Coach
# 19            360                Victor Valley Transit Authority
# 4             368                 WestCat (Western Contra Costa)
#
#     calitp_url_number  num_sched  num_vp  avg
# 10                  0       5378    4933 0.92
# 0                   0          6       0 0.00
# 1                   0         51       0 0.00
# 21                  0        133     132 0.99
# 20                  2        133       0 0.00
# 8                   0        317       0 0.00
# 12                  0        704     644 0.91
# 9                   0        216       0 0.00
# 6                   0       3183       0 0.00
# 13                  0         88       0 0.00
# 11                  0          8       0 0.00
# 14                  0        141       0 0.00
# 22                  0       8707       0 0.00
# 5                   0       3657       0 0.00
# 7                   0        402     349 0.87
# 2                   0        251       0 0.00
# 15                  0        252     176 0.70
# 16                  2         26       0 0.00
# 18                  0        236     124 0.53
# 17                  2        270       0 0.00
# 3                   0        123       0 0.00
# 19                  1        658       0 0.00
# 4                   0        555       0 0.00

# %%
## the following agnency name has two calitp_itp_ids
may4>>filter(_.agency_name.str.contains('Redding'))
# Out:
#      calitp_itp_id                 agency_name  calitp_url_number route_id  \
# 128            259  Redding Area Bus Authority                  0      153
# 129            259  Redding Area Bus Authority                  0     1888
# 130            259  Redding Area Bus Authority                  0     6790
# 131            259  Redding Area Bus Authority                  0     6446
# 132            259  Redding Area Bus Authority                  0     1889
# 133            259  Redding Area Bus Authority                  0      160
# 134            259  Redding Area Bus Authority                  0     1886
# 135            259  Redding Area Bus Authority                  0      151
# 136            259  Redding Area Bus Authority                  0      154
# 137            259  Redding Area Bus Authority                  0      157
# 138            259  Redding Area Bus Authority                  0     1885
# 139            259  Redding Area Bus Authority                  0     1887
# 140            259  Redding Area Bus Authority                  0     6460
# 141            259  Redding Area Bus Authority                  0      161
# 142            259  Redding Area Bus Authority                  0      159
# 143            259  Redding Area Bus Authority                  0      155
# 339             82  Redding Area Bus Authority                  0      160
# 340             82  Redding Area Bus Authority                  0     6460
# 341             82  Redding Area Bus Authority                  0      159
# 342             82  Redding Area Bus Authority                  0     1887
# 343             82  Redding Area Bus Authority                  0      154
# 344             82  Redding Area Bus Authority                  0     1888
# 345             82  Redding Area Bus Authority                  0      151
# 346             82  Redding Area Bus Authority                  0     1885
# 347             82  Redding Area Bus Authority                  0     6790
# 348             82  Redding Area Bus Authority                  0      161
# 349             82  Redding Area Bus Authority                  0      157
# 350             82  Redding Area Bus Authority                  0     1889
# 351             82  Redding Area Bus Authority                  0     1886
# 352             82  Redding Area Bus Authority                  0      155
# 353             82  Redding Area Bus Authority                  0      153
# 354             82  Redding Area Bus Authority                  0     6446
#
#     route_short_name service_date calitp_extracted_at calitp_deleted_at  \
# 128                3   2022-05-04          2021-04-15        2099-01-01
# 129               6N   2022-05-04          2021-04-15        2099-01-01
# 130              CTE   2022-05-04          2021-04-15        2099-01-01
# 131                9   2022-05-04          2021-04-15        2099-01-01
# 132               6S   2022-05-04          2021-04-15        2099-01-01
# 133               14   2022-05-04          2021-04-15        2099-01-01
# 134               2W   2022-05-04          2021-04-15        2099-01-01
# 135                1   2022-05-04          2021-04-15        2099-01-01
# 136                4   2022-05-04          2021-04-15        2099-01-01
# 137                7   2022-05-04          2021-04-15        2099-01-01
# 138               SE   2022-05-04          2021-04-15        2099-01-01
# 139               2E   2022-05-04          2021-04-15        2099-01-01
# 140               AC   2022-05-04          2021-04-15        2099-01-01
# 141               BE   2022-05-04          2021-04-15        2099-01-01
# 142               11   2022-05-04          2021-04-15        2099-01-01
# 143                5   2022-05-04          2021-04-15        2099-01-01
# 339               14   2022-05-04          2021-04-15        2099-01-01
# 340               AC   2022-05-04          2021-04-15        2099-01-01
# 341               11   2022-05-04          2021-04-15        2099-01-01
# 342               2E   2022-05-04          2021-04-15        2099-01-01
# 343                4   2022-05-04          2021-04-15        2099-01-01
# 344               6N   2022-05-04          2021-04-15        2099-01-01
# 345                1   2022-05-04          2021-04-15        2099-01-01
# 346               SE   2022-05-04          2021-04-15        2099-01-01
# 347              CTE   2022-05-04          2021-04-15        2099-01-01
# 348               BE   2022-05-04          2021-04-15        2099-01-01
# 349                7   2022-05-04          2021-04-15        2099-01-01
# 350               6S   2022-05-04          2021-04-15        2099-01-01
# 351               2W   2022-05-04          2021-04-15        2099-01-01
# 352                5   2022-05-04          2021-04-15        2099-01-01
# 353                3   2022-05-04          2021-04-15        2099-01-01
# 354                9   2022-05-04          2021-04-15        2099-01-01
#
#      num_sched  num_vp  pct_w_vp    weekday month caltrans_district  \
# 128         26      26      1.00  Wednesday   May      02 - Redding
# 129         24      24      1.00  Wednesday   May      02 - Redding
# 130         32      10      0.31  Wednesday   May      02 - Redding
# 131         15      10      0.67  Wednesday   May      02 - Redding
# 132         26      25      0.96  Wednesday   May      02 - Redding
# 133         13      11      0.85  Wednesday   May      02 - Redding
# 134         13       6      0.46  Wednesday   May      02 - Redding
# 135         14      14      1.00  Wednesday   May      02 - Redding
# 136         26      26      1.00  Wednesday   May      02 - Redding
# 137         24      24      1.00  Wednesday   May      02 - Redding
# 138          2       2      1.00  Wednesday   May      02 - Redding
# 139         13       6      0.46  Wednesday   May      02 - Redding
# 140          2       2      1.00  Wednesday   May      02 - Redding
# 141          6       0      0.00  Wednesday   May      02 - Redding
# 142         13      13      1.00  Wednesday   May      02 - Redding
# 143         26      23      0.88  Wednesday   May      02 - Redding
# 339         13       0      0.00  Wednesday   May      02 - Redding
# 340          2       0      0.00  Wednesday   May      02 - Redding
# 341         13       0      0.00  Wednesday   May      02 - Redding
# 342         13       0      0.00  Wednesday   May      02 - Redding
# 343         26       0      0.00  Wednesday   May      02 - Redding
# 344         24       0      0.00  Wednesday   May      02 - Redding
# 345         14       0      0.00  Wednesday   May      02 - Redding
# 346          2       0      0.00  Wednesday   May      02 - Redding
# 347         32       0      0.00  Wednesday   May      02 - Redding
# 348          6       0      0.00  Wednesday   May      02 - Redding
# 349         24       0      0.00  Wednesday   May      02 - Redding
# 350         26       0      0.00  Wednesday   May      02 - Redding
# 351         13       0      0.00  Wednesday   May      02 - Redding
# 352         26       0      0.00  Wednesday   May      02 - Redding
# 353         26       0      0.00  Wednesday   May      02 - Redding
# 354         15       0      0.00  Wednesday   May      02 - Redding
#
#      multiple_url drop_record
# 128         False        None
# 129         False        None
# 130         False        None
# 131         False        None
# 132         False        None
# 133         False        None
# 134         False        None
# 135         False        None
# 136         False        None
# 137         False        None
# 138         False        None
# 139         False        None
# 140         False        None
# 141         False        None
# 142         False        None
# 143         False        None
# 339         False        None
# 340         False        None
# 341         False        None
# 342         False        None
# 343         False        None
# 344         False        None
# 345         False        None
# 346         False        None
# 347         False        None
# 348         False        None
# 349         False        None
# 350         False        None
# 351         False        None
# 352         False        None
# 353         False        None
# 354         False        None

# %%
## actual using utils

may4_url = utils.get_correct_url(may4)

# %% [markdown]
# ### Overall average

# %%
### likey to increase once urls with no vp are removed (for those with more than one url)
((may4 >>summarize(tot_sched =_.num_sched.sum(), tot_vp = _.num_vp.sum())) >> mutate(avg = _.tot_vp/_.tot_sched))
# Out:
#    tot_sched  tot_vp  avg
# 0     155648   88500 0.57

# %%
#same with no duplicates
#((may4_url >>summarize(tot_sched =_.num_sched.sum(), tot_vp = _.num_vp.sum())) >> mutate(avg = _.tot_vp/_.tot_sched))

# %%
##should return 0
# (may4>>group_by(_.calitp_itp_id, _.agency_name)
#  >>summarize(n_urls = _.calitp_url_number.nunique())
#  >>filter(_.n_urls>1))

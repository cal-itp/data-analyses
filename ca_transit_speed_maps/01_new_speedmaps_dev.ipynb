# %%
# %%capture
import warnings
warnings.filterwarnings('ignore')
import calitp_data_analysis.magics

import speedmap_utils
from shared_utils import webmap_utils
import pandas as pd
import datetime as dt

# %%
#  parameters cell

analysis_name = 'Alameda-Contra Costa Transit District'
# district = '' #  not used but silences portfolio script warning

# %%
# %%capture

speedmap_segs, this_shn = speedmap_utils.read_segments_shn(analysis_name=analysis_name)
org_shapes = speedmap_utils.read_shapes(speedmap_segs)
analysis_date = speedmap_segs.analysis_date.iloc[0]

# %%
# %%capture_parameters
# human_date = dt.date.fromisoformat(analysis_date).strftime('%B %d %Y (%A)')
# human_date
# Out:
# {"human_date": "August 12 2026 (Wednesday)"}

# %% [markdown]
# # Dev

# %%
speedmap_segs
# Out:
#                schedule_gtfs_dataset_key    shape_id  \
# 342184  a6137888630c9c9468fde0c3ba0043be   shp-1T-51
# 345605  a6137888630c9c9468fde0c3ba0043be   shp-1T-09
# 345611  a6137888630c9c9468fde0c3ba0043be   shp-1T-09
# 345614  a6137888630c9c9468fde0c3ba0043be   shp-1T-09
# 345617  a6137888630c9c9468fde0c3ba0043be   shp-1T-09
# ...                                  ...         ...
# 355074  a6137888630c9c9468fde0c3ba0043be   shp-62-53
# 355080  a6137888630c9c9468fde0c3ba0043be   shp-62-53
# 355086  a6137888630c9c9468fde0c3ba0043be   shp-62-53
# 355092  a6137888630c9c9468fde0c3ba0043be   shp-62-53
# 371457  a6137888630c9c9468fde0c3ba0043be  shp-689-51
#
#                          shape_array_key route_id  direction_id     stop_pair  \
# 342184  874d5f95056c5b30943f0174c09275e5       1T           0.0  52591__52573
# 345605  0deeb0df5fb2b904af3c132302ae0c5a       1T           1.0  52404__52414
# 345611  0deeb0df5fb2b904af3c132302ae0c5a       1T           1.0  52414__52426
# 345614  0deeb0df5fb2b904af3c132302ae0c5a       1T           1.0  52414__52426
# 345617  0deeb0df5fb2b904af3c132302ae0c5a       1T           1.0  52426__52428
# ...                                  ...      ...           ...           ...
# 355074  fc95e4886cf4cc63330c124627673f4f       62           0.0  55337__50899
# 355080  fc95e4886cf4cc63330c124627673f4f       62           0.0  50899__56695
# 355086  fc95e4886cf4cc63330c124627673f4f       62           0.0  56695__55424
# 355092  fc95e4886cf4cc63330c124627673f4f       62           0.0  55424__51717
# 371457  a632c3dcd13b21fd02895ae6bd3ae89b      689           0.0  51971__55118
#
#            segment_id                                     stop_pair_name  \
# 342184  52591-52573-1                            Harrison SB__Madison SB
# 345605  52404-52414-1  Downtown San Leandro NB__San Leandro Civic Cen...
# 345611  52414-52426-1        San Leandro Civic Center NB__Georgia Way NB
# 345614  52414-52426-1        San Leandro Civic Center NB__Georgia Way NB
# 345617  52426-52428-1                      Georgia Way NB__Durant Avenue
# ...               ...                                                ...
# 355074  55337-50899-1  E 31st St & Stuart St (Opp. Highland Hospital)...
# 355080  50899-56695-1  E 31st St & Vallecito Pl__13th Av & Bella Vist...
# 355086  56695-55424-1      13th Av & Bella Vista Av__13th Av & E 25th St
# 355092  55424-51717-1           13th Av & E 25th St__E 24th St & 12th Av
# 371457  51971-55118-1         22nd St & Nevin Av__Macdonald Av & 21st St
#
#        time_of_day  p50_mph  ...  trips_hr_sch  route_short_name  \
# 342184     AM Peak      8.7  ...           6.0                1T
# 345605     AM Peak     11.4  ...           6.0                1T
# 345611     AM Peak     16.1  ...           6.0                1T
# 345614      Midday     13.8  ...           6.0                1T
# 345617     AM Peak     13.8  ...           6.0                1T
# ...            ...      ...  ...           ...               ...
# 355074         Owl     17.1  ...           0.2                62
# 355080         Owl     11.8  ...           0.2                62
# 355086         Owl     18.1  ...           0.2                62
# 355092         Owl     13.3  ...           0.2                62
# 371457     PM Peak     18.2  ...           0.2               689
#
#                                                  geometry  \
# 342184  POLYGON ((-199367.029 -21634.726, -199364.617 ...
# 345605  POLYGON ((-189825.814 -30142.867, -189942.247 ...
# 345611  POLYGON ((-189991.980 -29826.879, -190154.652 ...
# 345614  POLYGON ((-189991.980 -29826.879, -190154.652 ...
# 345617  POLYGON ((-190192.015 -29468.742, -190193.551 ...
# ...                                                   ...
# 355074  POLYGON ((-196275.585 -21788.212, -196277.327 ...
# 355080  POLYGON ((-196382.350 -21760.130, -196383.886 ...
# 355086  POLYGON ((-196679.151 -22000.483, -196679.928 ...
# 355092  POLYGON ((-196727.850 -22060.679, -196728.865 ...
# 371457  POLYGON ((-206135.356 -6382.080, -206135.526 -...
#
#                                     name  \
# 342184  Bay Area 511 AC Transit Schedule
# 345605  Bay Area 511 AC Transit Schedule
# 345611  Bay Area 511 AC Transit Schedule
# 345614  Bay Area 511 AC Transit Schedule
# 345617  Bay Area 511 AC Transit Schedule
# ...                                  ...
# 355074  Bay Area 511 AC Transit Schedule
# 355080  Bay Area 511 AC Transit Schedule
# 355086  Bay Area 511 AC Transit Schedule
# 355092  Bay Area 511 AC Transit Schedule
# 371457  Bay Area 511 AC Transit Schedule
#
#                                                base64_url  \
# 342184  aHR0cHM6Ly9hcGkuNTExLm9yZy90cmFuc2l0L2RhdGFmZW...
# 345605  aHR0cHM6Ly9hcGkuNTExLm9yZy90cmFuc2l0L2RhdGFmZW...
# 345611  aHR0cHM6Ly9hcGkuNTExLm9yZy90cmFuc2l0L2RhdGFmZW...
# 345614  aHR0cHM6Ly9hcGkuNTExLm9yZy90cmFuc2l0L2RhdGFmZW...
# 345617  aHR0cHM6Ly9hcGkuNTExLm9yZy90cmFuc2l0L2RhdGFmZW...
# ...                                                   ...
# 355074  aHR0cHM6Ly9hcGkuNTExLm9yZy90cmFuc2l0L2RhdGFmZW...
# 355080  aHR0cHM6Ly9hcGkuNTExLm9yZy90cmFuc2l0L2RhdGFmZW...
# 355086  aHR0cHM6Ly9hcGkuNTExLm9yZy90cmFuc2l0L2RhdGFmZW...
# 355092  aHR0cHM6Ly9hcGkuNTExLm9yZy90cmFuc2l0L2RhdGFmZW...
# 371457  aHR0cHM6Ly9hcGkuNTExLm9yZy90cmFuc2l0L2RhdGFmZW...
#
#               caltrans_district                          analysis_name  \
# 342184  04 - Bay Area / Oakland  Alameda-Contra Costa Transit District
# 345605  04 - Bay Area / Oakland  Alameda-Contra Costa Transit District
# 345611  04 - Bay Area / Oakland  Alameda-Contra Costa Transit District
# 345614  04 - Bay Area / Oakland  Alameda-Contra Costa Transit District
# 345617  04 - Bay Area / Oakland  Alameda-Contra Costa Transit District
# ...                         ...                                    ...
# 355074  04 - Bay Area / Oakland  Alameda-Contra Costa Transit District
# 355080  04 - Bay Area / Oakland  Alameda-Contra Costa Transit District
# 355086  04 - Bay Area / Oakland  Alameda-Contra Costa Transit District
# 355092  04 - Bay Area / Oakland  Alameda-Contra Costa Transit District
# 371457  04 - Bay Area / Oakland  Alameda-Contra Costa Transit District
#
#          source_record_id fast_slow_ratio analysis_date
# 342184  recJjD8JT53sK302o             2.2    2026-08-12
# 345605  recJjD8JT53sK302o             1.4    2026-08-12
# 345611  recJjD8JT53sK302o             1.7    2026-08-12
# 345614  recJjD8JT53sK302o             1.8    2026-08-12
# 345617  recJjD8JT53sK302o             1.4    2026-08-12
# ...                   ...             ...           ...
# 355074  recJjD8JT53sK302o             1.0    2026-08-12
# 355080  recJjD8JT53sK302o             1.0    2026-08-12
# 355086  recJjD8JT53sK302o             1.0    2026-08-12
# 355092  recJjD8JT53sK302o             1.0    2026-08-12
# 371457  recJjD8JT53sK302o             1.0    2026-08-12
#
# [33618 rows x 24 columns]

# %% [markdown]
# # Existing

# %% [markdown]
# ## About These Maps:
#
# * Each map shows bus (and rail, if applicable) speeds for {analysis_name}, with a map each for the AM Peak, Midday, and PM Peak periods on {human_date}.
# * On the map, routes are split into segments corresponding to the distance between two stops, allowing you to focus on specific portions of the route experiencing a slowdown.
# * Route segments are arrow-shaped to indicate direction of travel. Thicker segments indicate more frequent transit routes.
# * State Highway Network routes are outlined in gray.
# * Hover over, a segment with your mouse to see the exact speed, route name, and transit service frequency in that segment.
#     * Higher-frequency routes (3+ trips per hour) are especially important, since those slowdowns correspond to more vehicles, and riders, delayed in traffic.
# * Route segments with no data are now shown as thin, dark gray or black segments. These may be due to the route not running at that time of day, or a data availability or processing issue.

# %% [markdown]
# ## AM Peak (07:00-10:00)

# %% [markdown]
# ### 20th Percentile Speeds by Segment

# %%
# %%capture
link, title = speedmap_utils.map_time_period(district_gdf=this_shn, speedmap_segs=speedmap_segs, org_shapes=org_shapes,
                                      analysis_date=analysis_date, time_of_day='AM Peak', map_type='new_speedmap')

# %%
if link: webmap_utils.render_spa_link(link)

# %%
if link: webmap_utils.display_spa_map(link, title = title)

# %% [markdown]
# ### Variation in Speeds by Segment
#
# * This visualization shows variation as the ratio between the 80th percentile and 20th percentile speeds in each segment
# * Segments with high variation in speeds make it difficult for transit operators to set accurate schedules, and can cause inconsistent service for riders

# %%
# %%capture
link, title = speedmap_utils.map_time_period(district_gdf=this_shn, speedmap_segs=speedmap_segs, org_shapes=org_shapes,
                                      analysis_date=analysis_date, time_of_day='AM Peak', map_type='new_speed_variation')

# %%
if link: webmap_utils.render_spa_link(link)

# %%
if link: webmap_utils.display_spa_map(link, title = title)

# %% [markdown]
# ## Midday (10:00-15:00)

# %% [markdown]
# ### 20th Percentile Speeds by Segment

# %%
# %%capture
link, title = speedmap_utils.map_time_period(district_gdf=this_shn, speedmap_segs=speedmap_segs, org_shapes=org_shapes,
                                      analysis_date=analysis_date, time_of_day='Midday', map_type='new_speedmap')

# %%
if link: webmap_utils.render_spa_link(link)

# %%
if link: webmap_utils.display_spa_map(link, title = title)

# %% [markdown]
# ### Variation in Speeds by Segment
#
# * This visualization shows variation as the ratio between the 80th percentile and 20th percentile speeds in each segment
# * Segments with high variation in speeds make it difficult for transit operators to set accurate schedules, and can cause inconsistent service for riders

# %%
# %%capture
link, title = speedmap_utils.map_time_period(district_gdf=this_shn, speedmap_segs=speedmap_segs, org_shapes=org_shapes,
                                      analysis_date=analysis_date, time_of_day='Midday', map_type='new_speed_variation')

# %%
if link: webmap_utils.render_spa_link(link)

# %%
if link: webmap_utils.display_spa_map(link)

# %% [markdown]
# ## PM Peak (15:00-20:00)

# %% [markdown]
# ### 20th Percentile Speeds by Segment

# %%
# %%capture
link, title = speedmap_utils.map_time_period(district_gdf=this_shn, speedmap_segs=speedmap_segs, org_shapes=org_shapes,
                                      analysis_date=analysis_date, time_of_day='PM Peak', map_type='new_speedmap')

# %%
if link: webmap_utils.render_spa_link(link)

# %%
if link: webmap_utils.display_spa_map(link, title = title)

# %% [markdown]
# ### Variation in Speeds by Segment
#
# * This visualization shows variation as the ratio between the 80th percentile and 20th percentile speeds in each segment
# * Segments with high variation in speeds make it difficult for transit operators to set accurate schedules, and can cause inconsistent service for riders

# %%
# %%capture
link, title = speedmap_utils.map_time_period(district_gdf=this_shn, speedmap_segs=speedmap_segs, org_shapes=org_shapes,
                                      analysis_date=analysis_date, time_of_day='PM Peak', map_type='new_speed_variation')

# %%
if link: webmap_utils.render_spa_link(link)

# %%
if link: webmap_utils.display_spa_map(link, title = title)

# %% [markdown]
# ## Daily Speed Patterns
#
# * This chart shows the distribution of segment speeds in each time of day. It can help find times of day where transit riders experience the slowest overall speeds, or highest variation in speeds.

# %%
speedmap_utils.chart_speeds_by_time_period(speedmap_segs)

# %% [markdown]
# ## Additional Time Periods
#
# These links provide speed and speed variation maps outside the AM Peak, Midday, and PM Peak periods, if available.
#
# * Evening is 20:00-24:00
# * Owl is 00:00-04:00
# * Early AM is 04:00-07:00

# %%
# %%capture

additional_periods = [period for period in speedmap_segs.time_of_day.unique() if period not in ['AM Peak', 'Midday', 'PM Peak']]
if additional_periods:
    additional_maps = {}
    for period in additional_periods:
        additional_maps[period] = {'speeds': speedmap_utils.map_time_period(district_gdf=this_shn, speedmap_segs=speedmap_segs, org_shapes=org_shapes,
                                          analysis_date=analysis_date, time_of_day=period, map_type='new_speedmap')[0],
                                   'variation': speedmap_utils.map_time_period(district_gdf=this_shn, speedmap_segs=speedmap_segs, org_shapes=org_shapes,
                                          analysis_date=analysis_date, time_of_day=period, map_type='new_speed_variation')[0]
                                  }

# %%
if additional_periods:
    for period in additional_periods:
        webmap_utils.render_spa_link(additional_maps[period]['speeds'], text=f"{period} Speeds")
        webmap_utils.render_spa_link(additional_maps[period]['variation'], text=f"{period} Speed Variation")

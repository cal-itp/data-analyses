# %%
import pandas as pd
import geopandas as gpd
from calitp_data_analysis.sql import query_sql
from calitp_data_analysis.gcs_geopandas import GCSGeoPandas
from calitp_data_analysis.geography_utils import CA_NAD83Albers_m, WGS84
gcsgp = GCSGeoPandas()
from shared_utils import gtfs_utils_v2
from shared_utils.rt_utils import show_full_df

import utils

# %% [markdown]
# # Special Handling for SF - Emeryville Route
#
# * Check that trips in SJJPA and CC feeds do not overlap

# %%
analysis_date = '2025-08-18'

# %%
ca = gcsgp.read_parquet('gs://calitp-analytics-data/data-analyses/high_quality_transit_areas/ca_boundary.parquet')

# %% [markdown]
# ## New SJJPA San Joaquins feed

# %%
feeds = gtfs_utils_v2.schedule_daily_feed_to_gtfs_dataset_name(analysis_date)

# %%
sanj = feeds.query('name.str.contains("Amtrak San Joaquins")')
sanj
# Out:
#                                  key       date  \
# 82  a04bf510313ab925aa37eea637a18bec 2025-08-18
#
#                             feed_key        feed_timezone  \
# 82  d9e1e77d0754b712fc608741ae3836f5  America/Los_Angeles
#
#                                            base64_url  \
# 82  aHR0cHM6Ly9kMzR0aXc2NG41ejRvaC5jbG91ZGZyb250Lm...
#
#                     gtfs_dataset_key                          name      type  \
# 82  524ea6209600e9a2de34a02cf9068729  Amtrak San Joaquins Schedule  schedule
#
#    regional_feed_type
# 82               None

# %%
sanj_shapes = gtfs_utils_v2.get_shapes(analysis_date, operator_feeds=sanj.feed_key, shape_cols=utils.shape_cols)
# Out:
# /opt/conda/lib/python3.11/site-packages/sqlalchemy_bigquery/_types.py:101: SAWarning: Did not recognize type 'GEOGRAPHY' of column 'pt_array'
#   sqlalchemy.util.warn(

# %%
sanj_trips = gtfs_utils_v2.get_trips(analysis_date, operator_feeds=sanj.feed_key, trip_cols=utils.trip_cols)

# %%
sanj_stops = gtfs_utils_v2.get_stops(analysis_date, operator_feeds=sanj.feed_key, stop_cols=utils.stop_cols)
# Out:
# /opt/conda/lib/python3.11/site-packages/sqlalchemy_bigquery/_types.py:101: SAWarning: Did not recognize type 'GEOGRAPHY' of column 'pt_geom'
#   sqlalchemy.util.warn(

# %%
sanj_st = gtfs_utils_v2.get_stop_times(analysis_date, operator_feeds=sanj.feed_key, get_df=True,
                                      trip_df = sanj_trips, stop_time_cols=utils.stop_time_cols)
# Out:
# /opt/conda/lib/python3.11/site-packages/sqlalchemy_bigquery/_types.py:101: SAWarning: Did not recognize type 'INTERVAL' of column 'arrival_time_interval'
#   sqlalchemy.util.warn(
# /opt/conda/lib/python3.11/site-packages/sqlalchemy_bigquery/_types.py:101: SAWarning: Did not recognize type 'INTERVAL' of column 'departure_time_interval'
#   sqlalchemy.util.warn(
# /opt/conda/lib/python3.11/site-packages/sqlalchemy_bigquery/_types.py:101: SAWarning: Did not recognize type 'INTERVAL' of column 'start_pickup_drop_off_window_interval'
#   sqlalchemy.util.warn(
# /opt/conda/lib/python3.11/site-packages/sqlalchemy_bigquery/_types.py:101: SAWarning: Did not recognize type 'INTERVAL' of column 'end_pickup_drop_off_window_interval'
#   sqlalchemy.util.warn(

# %%
sanj_sf_emy = sanj_trips.query('route_short_name == "Route 99"')

# %%
import importlib
importlib.reload(utils)
# Out:
# <module 'utils' from '/home/jovyan/data-analyses/thruway_intercity_bus/utils.py'>

# %%
sanj_st_merged = sanj_stops.merge(sanj_st, on = ['feed_key', 'stop_id']).merge(sanj_sf_emy, on = ['feed_key', 'trip_id'])

# %%
sanj_st_merged.shape
# Out:
# (20, 31)

# %%
# utils.format_stop_times(sanj_st_merged)

# %% [markdown]
# ## Capitol Corridor

# %%
cc_feed = feeds.query('name.str.contains("Capitol")')

# %%
cc_shapes = gtfs_utils_v2.get_shapes(analysis_date, operator_feeds=cc_feed.feed_key, shape_cols=shape_cols)
# Out:
# /opt/conda/lib/python3.11/site-packages/sqlalchemy_bigquery/_types.py:101: SAWarning: Did not recognize type 'GEOGRAPHY' of column 'pt_array'
#   sqlalchemy.util.warn(

# %%
cc_trips = gtfs_utils_v2.get_trips(analysis_date, operator_feeds=cc_feed.feed_key, trip_cols=trip_cols)

# %%
# cc_trips[['route_short_name', 'route_long_name', 'trip_instance_key']].groupby(['route_short_name', 'route_long_name']).count()

# %%
cc_stops = gtfs_utils_v2.get_stops(analysis_date, operator_feeds=cc_feed.feed_key, stop_cols=utils.stop_cols)
# Out:
# /opt/conda/lib/python3.11/site-packages/sqlalchemy_bigquery/_types.py:101: SAWarning: Did not recognize type 'GEOGRAPHY' of column 'pt_geom'
#   sqlalchemy.util.warn(

# %%
cc_st = gtfs_utils_v2.get_stop_times(analysis_date, operator_feeds=cc_feed.feed_key, get_df=True,
                                      trip_df = cc_trips, stop_time_cols=utils.stop_time_cols)
# Out:
# /opt/conda/lib/python3.11/site-packages/sqlalchemy_bigquery/_types.py:101: SAWarning: Did not recognize type 'INTERVAL' of column 'arrival_time_interval'
#   sqlalchemy.util.warn(
# /opt/conda/lib/python3.11/site-packages/sqlalchemy_bigquery/_types.py:101: SAWarning: Did not recognize type 'INTERVAL' of column 'departure_time_interval'
#   sqlalchemy.util.warn(
# /opt/conda/lib/python3.11/site-packages/sqlalchemy_bigquery/_types.py:101: SAWarning: Did not recognize type 'INTERVAL' of column 'start_pickup_drop_off_window_interval'
#   sqlalchemy.util.warn(
# /opt/conda/lib/python3.11/site-packages/sqlalchemy_bigquery/_types.py:101: SAWarning: Did not recognize type 'INTERVAL' of column 'end_pickup_drop_off_window_interval'
#   sqlalchemy.util.warn(

# %%
cc_sf_emy = cc_trips.query('route_short_name == "SF"')

# %%
cc_st_merged = cc_stops.merge(cc_st, on = ['feed_key', 'stop_id']).merge(cc_sf_emy, on = ['feed_key', 'trip_id'])

# %%
cc_st_merged.shape
# Out:
# (52, 31)

# %%
# utils.format_stop_times(cc_st_merged)

# %%
both_st_merged = pd.concat([sanj_st_merged, cc_st_merged])

# %%
both_trip_ix = both_st_merged[['trip_id', 'direction_id', 'arrival_sec']].groupby(['trip_id', 'direction_id']).min().reset_index().sort_values(['direction_id', 'arrival_sec']).reset_index(drop=True)

# %%
both_trip_ix['sort_trip_id'] = range(both_trip_ix.shape[0])
both_trip_ix = both_trip_ix.drop(columns=['arrival_sec'])

# %%
both_st_merged = both_st_merged.merge(both_trip_ix, on=['trip_id', 'direction_id'])

# %% [markdown]
# ### Merged Timetable
#
# https://www.capitolcorridor.org//trainschedule/Train_Schedules.pdf?v=05082025
#
# https://amtraksanjoaquins.com/route-99-oakland-emeryville-san-francisco/
#
# * CC trip_id 526E is probably incorrect in GTFS and should be 7:55a SF -> 8:25a EMY (see pdf schedule for train 526)
# * CC trip_id 524E and SJ trip_id 6610 seem like two buses going to the same place at about the same time... do we need the capacity and could they be consolidated to one run?
# * other CC and SJ trips are spaced out enough that consolidation would slow travel times, especially vs BART connection at Richmond

# %%
show_full_df(utils.format_stop_times(both_st_merged).sort_values(['direction_id', 'sort_trip_id', 'arrival_sec']))
# Out:
#    route_short_name                   route_long_name  direction_id stop_id  \
# 63               SF                        Shuttle_SF             0   74732
# 62               SF                        Shuttle_SF             0   74369
# 61               SF                        Shuttle_SF             0   74732
# 60               SF                        Shuttle_SF             0   74369
# 17         Route 99  Oakland-Emeryville-San Francisco             0    bSFC
# 16         Route 99  Oakland-Emeryville-San Francisco             0    bEMY
# 19         Route 99  Oakland-Emeryville-San Francisco             0    bSFC
# 18         Route 99  Oakland-Emeryville-San Francisco             0    bEMY
# 71               SF                        Shuttle_SF             0   74732
# 70               SF                        Shuttle_SF             0   74369
# 3          Route 99  Oakland-Emeryville-San Francisco             0    bSFC
# 2          Route 99  Oakland-Emeryville-San Francisco             0    bEMY
# 25               SF                        Shuttle_SF             0   74732
# 24               SF                        Shuttle_SF             0   74369
# 5          Route 99  Oakland-Emeryville-San Francisco             0    bSFC
# 4          Route 99  Oakland-Emeryville-San Francisco             0    bEMY
# 31               SF                        Shuttle_SF             0   74732
# 30               SF                        Shuttle_SF             0   74369
# 33               SF                        Shuttle_SF             0   74732
# 32               SF                        Shuttle_SF             0   74369
# 37               SF                        Shuttle_SF             0   74732
# 36               SF                        Shuttle_SF             0   74369
# 39               SF                        Shuttle_SF             0   74732
# 38               SF                        Shuttle_SF             0   74369
# 41               SF                        Shuttle_SF             0   74732
# 40               SF                        Shuttle_SF             0   74369
# 9          Route 99  Oakland-Emeryville-San Francisco             0    bSFC
# 8          Route 99  Oakland-Emeryville-San Francisco             0    bEMY
# 45               SF                        Shuttle_SF             0   74732
# 44               SF                        Shuttle_SF             0   74369
# 49               SF                        Shuttle_SF             0   74732
# 48               SF                        Shuttle_SF             0   74369
# 53               SF                        Shuttle_SF             0   74732
# 52               SF                        Shuttle_SF             0   74369
# 56               SF                        Shuttle_SF             1   74369
# 57               SF                        Shuttle_SF             1   74732
# 58               SF                        Shuttle_SF             1   74369
# 59               SF                        Shuttle_SF             1   74732
# 64               SF                        Shuttle_SF             1   74369
# 65               SF                        Shuttle_SF             1   74732
# 66               SF                        Shuttle_SF             1   74369
# 67               SF                        Shuttle_SF             1   74732
# 68               SF                        Shuttle_SF             1   74369
# 69               SF                        Shuttle_SF             1   74732
# 0          Route 99  Oakland-Emeryville-San Francisco             1    bEMY
# 1          Route 99  Oakland-Emeryville-San Francisco             1    bSFC
# 20               SF                        Shuttle_SF             1   74369
# 21               SF                        Shuttle_SF             1   74732
# 22               SF                        Shuttle_SF             1   74369
# 23               SF                        Shuttle_SF             1   74732
# 26               SF                        Shuttle_SF             1   74369
# 27               SF                        Shuttle_SF             1   74732
# 28               SF                        Shuttle_SF             1   74369
# 29               SF                        Shuttle_SF             1   74732
# 6          Route 99  Oakland-Emeryville-San Francisco             1    bEMY
# 7          Route 99  Oakland-Emeryville-San Francisco             1    bSFC
# 34               SF                        Shuttle_SF             1   74369
# 35               SF                        Shuttle_SF             1   74732
# 42               SF                        Shuttle_SF             1   74369
# 43               SF                        Shuttle_SF             1   74732
# 10         Route 99  Oakland-Emeryville-San Francisco             1    bEMY
# 11         Route 99  Oakland-Emeryville-San Francisco             1    bSFC
# 46               SF                        Shuttle_SF             1   74369
# 47               SF                        Shuttle_SF             1   74732
# 50               SF                        Shuttle_SF             1   74369
# 51               SF                        Shuttle_SF             1   74732
# 12         Route 99  Oakland-Emeryville-San Francisco             1    bEMY
# 13         Route 99  Oakland-Emeryville-San Francisco             1    bSFC
# 54               SF                        Shuttle_SF             1   74369
# 55               SF                        Shuttle_SF             1   74732
# 14         Route 99  Oakland-Emeryville-San Francisco             1    bEMY
# 15         Route 99  Oakland-Emeryville-San Francisco             1    bSFC
#
#                                      stop_name trip_id  stop_sequence  \
# 63           San Francisco - Transbay Terminal    524E              0
# 62                                  Emeryville    524E              1
# 61           San Francisco - Transbay Terminal    526E              0
# 60                                  Emeryville    526E              1
# 3             Amtrak San Joaquins Schedule        39600             5
# 2             Amtrak San Joaquins Schedule        41400             5
# 25  Bay Area 511 Capitol Corridor Schedule        42300             6
# 24  Bay Area 511 Capitol Corridor Schedule        44100             6
# 5             Amtrak San Joaquins Schedule        46200             7
# 4             Amtrak San Joaquins Schedule        48000             7
# 31  Bay Area 511 Capitol Corridor Schedule        48900             8
# 30  Bay Area 511 Capitol Corridor Schedule        50700             8
# 33  Bay Area 511 Capitol Corridor Schedule        52500             9
# 32  Bay Area 511 Capitol Corridor Schedule        54300             9
# 37  Bay Area 511 Capitol Corridor Schedule        55500            10
# 36  Bay Area 511 Capitol Corridor Schedule        57300            10
# 39  Bay Area 511 Capitol Corridor Schedule        58200            11
# 38  Bay Area 511 Capitol Corridor Schedule        60000            11
# 41  Bay Area 511 Capitol Corridor Schedule        60000            12
# 40  Bay Area 511 Capitol Corridor Schedule        62100            12
# 9             Amtrak San Joaquins Schedule        60000            13
# 8             Amtrak San Joaquins Schedule        62100            13
# 45  Bay Area 511 Capitol Corridor Schedule        63600            14
# 44  Bay Area 511 Capitol Corridor Schedule        65700            14
# 49  Bay Area 511 Capitol Corridor Schedule        66600            15
# 48  Bay Area 511 Capitol Corridor Schedule        68700            15
# 53  Bay Area 511 Capitol Corridor Schedule        70200            16
# 52  Bay Area 511 Capitol Corridor Schedule        72300            16
# 56  Bay Area 511 Capitol Corridor Schedule        21000            17
# 57  Bay Area 511 Capitol Corridor Schedule        22800            17
# 58  Bay Area 511 Capitol Corridor Schedule        24600            18
# 59  Bay Area 511 Capitol Corridor Schedule        27000            18
# 64  Bay Area 511 Capitol Corridor Schedule        28200            19
# 65  Bay Area 511 Capitol Corridor Schedule        30600            19
# 66  Bay Area 511 Capitol Corridor Schedule        30300            20
# 67  Bay Area 511 Capitol Corridor Schedule        32400            20
# 68  Bay Area 511 Capitol Corridor Schedule        33600            21
# 69  Bay Area 511 Capitol Corridor Schedule        35700            21
# 0             Amtrak San Joaquins Schedule        36900            22
# 1             Amtrak San Joaquins Schedule        38700            22
# 20  Bay Area 511 Capitol Corridor Schedule        38100            23
# 21  Bay Area 511 Capitol Corridor Schedule        39900            23
# 22  Bay Area 511 Capitol Corridor Schedule        41700            24
# 23  Bay Area 511 Capitol Corridor Schedule        43500            24
# 26  Bay Area 511 Capitol Corridor Schedule        45420            25
# 27  Bay Area 511 Capitol Corridor Schedule        47400            25
# 28  Bay Area 511 Capitol Corridor Schedule        48900            26
# 29  Bay Area 511 Capitol Corridor Schedule        50700            26
# 6             Amtrak San Joaquins Schedule        51600            27
# 7             Amtrak San Joaquins Schedule        53400            27
# 34  Bay Area 511 Capitol Corridor Schedule        56400            28
# 35  Bay Area 511 Capitol Corridor Schedule        58200            28
# 42  Bay Area 511 Capitol Corridor Schedule        63600            29
# 43  Bay Area 511 Capitol Corridor Schedule        65400            29
# 10            Amtrak San Joaquins Schedule        66300            30
# 11            Amtrak San Joaquins Schedule        68100            30
# 46  Bay Area 511 Capitol Corridor Schedule        67500            31
# 47  Bay Area 511 Capitol Corridor Schedule        69300            31
# 50  Bay Area 511 Capitol Corridor Schedule        70800            32
# 51  Bay Area 511 Capitol Corridor Schedule        72600            32

# %%
import geopandas as gpd
import pandas as pd
from calitp_data_analysis.gcs_geopandas import GCSGeoPandas
from shared_utils import catalog_utils, rt_dates, portfolio_utils
from segment_speed_utils import helpers
g = GCSGeoPandas()

# %% [markdown]
# # Copy speedmaps data into public bucket to support MTC

# %%
date_keys = ["sep2025c", "oct2025c", "oct2025d", "oct2025e", "oct2025f", "oct2025g"]
# date_keys = ["sep2025a", "sep2025", "sep2025b", "oct2025a", "oct2025", "oct2025b"]

# %%
relevant_dates = [
    rt_dates.DATES[i]
    for i in date_keys
]
relevant_dates
# Out:
# ['2025-09-30',
#  '2025-10-01',
#  '2025-10-02',
#  '2025-10-07',
#  '2025-10-08',
#  '2025-10-09']

# %%
gtfs_yml = catalog_utils.get_catalog("gtfs_analytics_data")
aggregated_parent = (
    f"{gtfs_yml.speedmap_segments.dir}{gtfs_yml.speedmap_segments.segment_timeofday}"
)
trip_speeds_parent = (
    f"{gtfs_yml.speedmap_segments.dir}{gtfs_yml.speedmap_segments.stage4}"
)

# %%
# Get aggregated speedmaps segments paths
aggregated_uris = [f"{aggregated_parent}_{date}.parquet" for date in relevant_dates]
aggregated_uris
# Out:
# ['gs://calitp-analytics-data/data-analyses/rt_segment_speeds/rollup_singleday/speeds_shape_timeofday_speedmap_segments_2025-09-30.parquet',
#  'gs://calitp-analytics-data/data-analyses/rt_segment_speeds/rollup_singleday/speeds_shape_timeofday_speedmap_segments_2025-10-01.parquet',
#  'gs://calitp-analytics-data/data-analyses/rt_segment_speeds/rollup_singleday/speeds_shape_timeofday_speedmap_segments_2025-10-02.parquet',
#  'gs://calitp-analytics-data/data-analyses/rt_segment_speeds/rollup_singleday/speeds_shape_timeofday_speedmap_segments_2025-10-07.parquet',
#  'gs://calitp-analytics-data/data-analyses/rt_segment_speeds/rollup_singleday/speeds_shape_timeofday_speedmap_segments_2025-10-08.parquet',
#  'gs://calitp-analytics-data/data-analyses/rt_segment_speeds/rollup_singleday/speeds_shape_timeofday_speedmap_segments_2025-10-09.parquet']

# %%
# Get trip level speeds paths
# trip_speeds_uris = [f"{trip_speeds_parent}_{date}.parquet" for date in relevant_dates]
trip_speeds_uris = [{"date": date, "uri": f"{trip_speeds_parent}_{date}.parquet"} for date in relevant_dates]
trip_speeds_uris
# Out:
# [{'date': '2025-09-30',
#   'uri': 'gs://calitp-analytics-data/data-analyses/rt_segment_speeds/speedmap/speeds_2025-09-30.parquet'},
#  {'date': '2025-10-01',
#   'uri': 'gs://calitp-analytics-data/data-analyses/rt_segment_speeds/speedmap/speeds_2025-10-01.parquet'},
#  {'date': '2025-10-02',
#   'uri': 'gs://calitp-analytics-data/data-analyses/rt_segment_speeds/speedmap/speeds_2025-10-02.parquet'},
#  {'date': '2025-10-07',
#   'uri': 'gs://calitp-analytics-data/data-analyses/rt_segment_speeds/speedmap/speeds_2025-10-07.parquet'},
#  {'date': '2025-10-08',
#   'uri': 'gs://calitp-analytics-data/data-analyses/rt_segment_speeds/speedmap/speeds_2025-10-08.parquet'},
#  {'date': '2025-10-09',
#   'uri': 'gs://calitp-analytics-data/data-analyses/rt_segment_speeds/speedmap/speeds_2025-10-09.parquet'}]

# %% [markdown]
# ### validation
#
# Doesn't exactly match script aggregation but we're comfortable these are the right files. Could be revised.

# %%
# # Validate that aggregated speeds match trip speeds in a majority of cases
# GROUP_COLUMNS = ["time_of_day", "segment_id", "shape_id"]
# quantile_to_speed_column = {0.2: "p20_mph", 0.5: "p50_mph", 0.8: "p80_mph"}
# for aggregated_uri, trip_speeds_uri in zip(aggregated_uris, trip_speeds_uris):
#     # read aggregated and precursor data
#     aggregated = g.read_parquet(aggregated_uri)
#     trip_speeds = pd.read_parquet(trip_speeds_uri)
#     # reindex aggregated_speeds and group trip_speeds_grouped so they theoretically have the same data
#     aggregated_speeds = aggregated.set_index(GROUP_COLUMNS)[
#         list(quantile_to_speed_column.values())
#     ]
#     trip_speeds_grouped = trip_speeds.groupby(GROUP_COLUMNS)
#     trip_speeds_percentiles = pd.concat(
#         [
#             trip_speeds_grouped["speed_mph"].quantile(q).rename(name).round(2)
#             for q, name in quantile_to_speed_column.items()
#         ],
#         axis=1,
#     )
#     # the aggregated data appears to contain a subset of the trip speeds data, so only look at that subset
#     trip_speeds_percentiles_subset = trip_speeds_percentiles.loc[
#         aggregated_speeds.index
#     ]
#     # find the rows where at least one speed doesn't match
#     non_equal = (trip_speeds_percentiles_subset != aggregated_speeds).any(axis=1)
    
#     print(
#         f"for {aggregated_uri}, {non_equal.sum()} out of {len(aggregated_speeds.index)} speeds did not match"
#     )

# %% [markdown]
# ## export

# %%
# Map source uris to output uris
output_aggregated_uris = {
    old_uri: f"gs://calitp-publish-data-analysis/mtc_collab_2025/speeds/{old_uri.split('/')[-1]}"
    for old_uri in aggregated_uris
}
# output_trip_speeds_uris = {
#     old_uri['uri']: f"gs://calitp-publish-data-analysis/mtc_collab_2025/speeds/{old_uri.split('/')[-1]}"
#     for old_uri in trip_speeds_uris
# }

# %%
for entry in trip_speeds_uris: entry['output_uri'] = f"gs://calitp-publish-data-analysis/mtc_collab_2025/speeds/{entry['uri'].split('/')[-1]}"

# %%
trip_speeds_uris
# Out:
# [{'date': '2025-09-30',
#   'uri': 'gs://calitp-analytics-data/data-analyses/rt_segment_speeds/speedmap/speeds_2025-09-30.parquet',
#   'output_uri': 'gs://calitp-publish-data-analysis/mtc_collab_2025/speeds/speeds_2025-09-30.parquet'},
#  {'date': '2025-10-01',
#   'uri': 'gs://calitp-analytics-data/data-analyses/rt_segment_speeds/speedmap/speeds_2025-10-01.parquet',
#   'output_uri': 'gs://calitp-publish-data-analysis/mtc_collab_2025/speeds/speeds_2025-10-01.parquet'},
#  {'date': '2025-10-02',
#   'uri': 'gs://calitp-analytics-data/data-analyses/rt_segment_speeds/speedmap/speeds_2025-10-02.parquet',
#   'output_uri': 'gs://calitp-publish-data-analysis/mtc_collab_2025/speeds/speeds_2025-10-02.parquet'},
#  {'date': '2025-10-07',
#   'uri': 'gs://calitp-analytics-data/data-analyses/rt_segment_speeds/speedmap/speeds_2025-10-07.parquet',
#   'output_uri': 'gs://calitp-publish-data-analysis/mtc_collab_2025/speeds/speeds_2025-10-07.parquet'},
#  {'date': '2025-10-08',
#   'uri': 'gs://calitp-analytics-data/data-analyses/rt_segment_speeds/speedmap/speeds_2025-10-08.parquet',
#   'output_uri': 'gs://calitp-publish-data-analysis/mtc_collab_2025/speeds/speeds_2025-10-08.parquet'},
#  {'date': '2025-10-09',
#   'uri': 'gs://calitp-analytics-data/data-analyses/rt_segment_speeds/speedmap/speeds_2025-10-09.parquet',
#   'output_uri': 'gs://calitp-publish-data-analysis/mtc_collab_2025/speeds/speeds_2025-10-09.parquet'}]

# %%
def add_speeds_identifiers(speeds_df, analysis_date):
    trips = helpers.import_scheduled_trips(analysis_date, columns=['trip_instance_key', 'trip_id', 'gtfs_dataset_key'])
    speeds_df = (speeds_df.merge(trips, on=['trip_instance_key', 'schedule_gtfs_dataset_key'])
                 .pipe(portfolio_utils.standardize_operator_info_for_exports, date=analysis_date)
                )
    return speeds_df

# %%
# Copy files from the private bucket to the public / mtc-visible bucket
fs = g.gcs_filesystem
# for old_uri, new_uri in output_aggregated_uris.items():
#     fs.copy(old_uri, new_uri)
for uri_group in trip_speeds_uris:
    speeds_df = pd.read_parquet(uri_group['uri'])
    speeds_df = add_speeds_identifiers(speeds_df, analysis_date=uri_group['date'])
    speeds_df.to_parquet(uri_group['output_uri'])
    print(uri_group['output_uri'])
# Out:
# gs://calitp-publish-data-analysis/mtc_collab_2025/speeds/speeds_2025-09-30.parquet
# gs://calitp-publish-data-analysis/mtc_collab_2025/speeds/speeds_2025-10-01.parquet
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 6
#       3 # for old_uri, new_uri in output_aggregated_uris.items():
#       4 #     fs.copy(old_uri, new_uri)
#       5 for uri_group in trip_speeds_uris:
# ----> 6     speeds_df = pd.read_parquet(uri_group['uri'])
#       7     speeds_df = add_speeds_identifiers(speeds_df, analysis_date=uri_group['date'])
#       8     speeds_df.to_parquet(uri_group['output_uri'])
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/parquet.py:503, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, **kwargs)
#     456 """
#     457 Load a parquet object from the file path, returning a DataFrame.
#     458
#    (...)
#     499 DataFrame
#     500 """
#     501 impl = get_engine(engine)
# --> 503 return impl.read(
#     504     path,
#     505     columns=columns,
#     506     storage_options=storage_options,
#     507     use_nullable_dtypes=use_nullable_dtypes,
#     508     **kwargs,
#     509 )
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/parquet.py:251, in PyArrowImpl.read(self, path, columns, use_nullable_dtypes, storage_options, **kwargs)
#     244 path_or_handle, handles, kwargs["filesystem"] = _get_path_or_handle(
#     245     path,
#     246     kwargs.pop("filesystem", None),
#     247     storage_options=storage_options,
#     248     mode="rb",
#     249 )
#     250 try:
# --> 251     result = self.api.parquet.read_table(
#     252         path_or_handle, columns=columns, **kwargs
#     253     ).to_pandas(**to_pandas_kwargs)
#     254     if manager == "array":
#     255         result = result._as_manager("array", copy=False)
#
# File /opt/conda/lib/python3.11/site-packages/pyarrow/parquet/core.py:1843, in read_table(source, columns, use_threads, schema, use_pandas_metadata, read_dictionary, binary_type, list_type, memory_map, buffer_size, partitioning, filesystem, filters, ignore_prefixes, pre_buffer, coerce_int96_timestamp_unit, decryption_properties, thrift_string_size_limit, thrift_container_size_limit, page_checksum_verification, arrow_extensions_enabled)
#    1831 def read_table(source, *, columns=None, use_threads=True,
#    1832                schema=None, use_pandas_metadata=False, read_dictionary=None,
#    1833                binary_type=None, list_type=None, memory_map=False, buffer_size=0,
#    (...)
#    1839                page_checksum_verification=False,
#    1840                arrow_extensions_enabled=True):
#    1842     try:
# -> 1843         dataset = ParquetDataset(
#    1844             source,
#    1845             schema=schema,
#    1846             filesystem=filesystem,
#    1847             partitioning=partitioning,
#    1848             memory_map=memory_map,
#    1849             read_dictionary=read_dictionary,
#    1850             binary_type=binary_type,
#    1851             list_type=list_type,
#    1852             buffer_size=buffer_size,
#    1853             filters=filters,
#    1854             ignore_prefixes=ignore_prefixes,
#    1855             pre_buffer=pre_buffer,
#    1856             coerce_int96_timestamp_unit=coerce_int96_timestamp_unit,
#    1857             decryption_properties=decryption_properties,
#    1858             thrift_string_size_limit=thrift_string_size_limit,
#    1859             thrift_container_size_limit=thrift_container_size_limit,
#    1860             page_checksum_verification=page_checksum_verification,
#    1861             arrow_extensions_enabled=arrow_extensions_enabled,
#    1862         )
#    1863     except ImportError:
#    1864         # fall back on ParquetFile for simple cases when pyarrow.dataset
#    1865         # module is not available
#    1866         if filters is not None:
#
# File /opt/conda/lib/python3.11/site-packages/pyarrow/parquet/core.py:1424, in ParquetDataset.__init__(self, path_or_paths, filesystem, schema, filters, read_dictionary, binary_type, list_type, memory_map, buffer_size, partitioning, ignore_prefixes, pre_buffer, coerce_int96_timestamp_unit, decryption_properties, thrift_string_size_limit, thrift_container_size_limit, page_checksum_verification, arrow_extensions_enabled)
#    1420 if partitioning == "hive":
#    1421     partitioning = ds.HivePartitioning.discover(
#    1422         infer_dictionary=True)
# -> 1424 self._dataset = ds.dataset(path_or_paths, filesystem=filesystem,
#    1425                            schema=schema, format=parquet_format,
#    1426                            partitioning=partitioning,
#    1427                            ignore_prefixes=ignore_prefixes)
#
# File /opt/conda/lib/python3.11/site-packages/pyarrow/dataset.py:790, in dataset(source, schema, format, filesystem, partitioning, partition_base_dir, exclude_invalid_files, ignore_prefixes)
#     779 kwargs = dict(
#     780     schema=schema,
#     781     filesystem=filesystem,
#    (...)
#     786     selector_ignore_prefixes=ignore_prefixes
#     787 )
#     789 if _is_path_like(source):
# --> 790     return _filesystem_dataset(source, **kwargs)
#     791 elif isinstance(source, (tuple, list)):
#     792     if all(_is_path_like(elem) or isinstance(elem, FileInfo) for elem in source):
#
# File /opt/conda/lib/python3.11/site-packages/pyarrow/dataset.py:472, in _filesystem_dataset(source, schema, filesystem, partitioning, format, partition_base_dir, exclude_invalid_files, selector_ignore_prefixes)
#     470         fs, paths_or_selector = _ensure_multiple_sources(source, filesystem)
#     471 else:
# --> 472     fs, paths_or_selector = _ensure_single_source(source, filesystem)
#     474 options = FileSystemFactoryOptions(
#     475     partitioning=partitioning,
#     476     partition_base_dir=partition_base_dir,
#     477     exclude_invalid_files=exclude_invalid_files,
#     478     selector_ignore_prefixes=selector_ignore_prefixes
#     479 )
#     480 factory = FileSystemDatasetFactory(fs, paths_or_selector, format, options)
#
# File /opt/conda/lib/python3.11/site-packages/pyarrow/dataset.py:437, in _ensure_single_source(path, filesystem)
#     435     paths_or_selector = [path]
#     436 else:
# --> 437     raise FileNotFoundError(path)
#     439 return filesystem, paths_or_selector
#
# FileNotFoundError: calitp-analytics-data/data-analyses/rt_segment_speeds/speedmap/speeds_2025-10-02.parquet

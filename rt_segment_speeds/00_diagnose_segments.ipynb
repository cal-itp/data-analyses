# %%
import dask.dataframe as dd
import dask_geopandas as dg

import pandas as pd
import geopandas as gpd
from siuba import *

from shared_utils import rt_dates

import gcsfs
fs = gcsfs.GCSFileSystem()
# Out:
# /opt/conda/lib/python3.9/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.10.3-CAPI-1.16.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
analysis_date = rt_dates.DATES['jan2023']

# %%
analysis_date
# Out:
# '2023-01-18'

# %%
partition_speeds = f'gs://calitp-analytics-data/data-analyses/rt_segment_speeds/speeds_{analysis_date}'

# %%
ddf = dd.read_parquet(partition_speeds)

# %%
ddf
# Out:
# Dask DataFrame Structure:
#               gtfs_dataset_key _gtfs_dataset_name trip_id route_dir_identifier segment_sequence             min_time             max_time min_dist max_dist meters_elapsed sec_elapsed speed_mph
# npartitions=6
#                         object             object  object                int64           object  datetime64[ns, UTC]  datetime64[ns, UTC]  float64  float64        float64     float64   float64
#                            ...                ...     ...                  ...              ...                  ...                  ...      ...      ...            ...         ...       ...
# ...                        ...                ...     ...                  ...              ...                  ...                  ...      ...      ...            ...         ...       ...
#                            ...                ...     ...                  ...              ...                  ...                  ...      ...      ...            ...         ...       ...
#                            ...                ...     ...                  ...              ...                  ...                  ...      ...      ...            ...         ...       ...
# Dask Name: read-parquet, 1 graph layer

# %%
ddf.isna().min_time.value_counts().compute()
# Out:
# False    1311292
# Name: min_time, dtype: int64

# %%
ddf.isna().max_time.value_counts().compute()
# Out:
# False    1311292
# Name: max_time, dtype: int64

# %%
ddf.info()
# Out:
# <class 'dask.dataframe.core.DataFrame'>
# Columns: 12 entries, gtfs_dataset_key to speed_mph
# dtypes: datetime64[ns, UTC](2), object(4), float64(5), int64(1)

# %%
ddf.max().compute()
# Out:
# gtfs_dataset_key        f1497340b654f3ce925f8b8c2f83e1c2
# _gtfs_dataset_name             Yolobus Vehicle Positions
# trip_id                              t_97725_b_2397_tn_9
# route_dir_identifier                          4292426728
# segment_sequence                                      99
# min_time                       2023-01-18 23:59:42+00:00
# max_time                       2023-01-18 23:59:43+00:00
# min_dist                                          1000.0
# max_dist                                          1000.0
# meters_elapsed                                    1000.0
# sec_elapsed                                     174950.0
# speed_mph                                     983.242342
# dtype: object

# %%
ddf.min().compute()
# Out:
# gtfs_dataset_key                         02af2d11f5bd44434c581540e9e857d8
# _gtfs_dataset_name      Antelope Valley Transit Authority Vehicle Posi...
# trip_id                              0049829c-505d-42db-965b-9ebd61bf1280
# route_dir_identifier                                              1525250
# segment_sequence                                                        0
# min_time                                        2023-01-16 18:01:21+00:00
# max_time                                        2023-01-17 01:46:02+00:00
# min_dist                                                              0.0
# max_dist                                                              0.0
# meters_elapsed                                                        0.0
# sec_elapsed                                                           0.0
# speed_mph                                                             0.0
# dtype: object

# %%
no_motion = ddf[ddf.meters_elapsed == 0.0].compute()

# %%
no_motion >> head(3)
# Out:
#                      gtfs_dataset_key       _gtfs_dataset_name     trip_id  \
# 63   02af2d11f5bd44434c581540e9e857d8  LA DOT VehiclePositions  45-2086817
# 156  02af2d11f5bd44434c581540e9e857d8  LA DOT VehiclePositions  45-2086824
# 159  02af2d11f5bd44434c581540e9e857d8  LA DOT VehiclePositions  45-2086821
#
#      route_dir_identifier segment_sequence                  min_time  \
# 63             3142909629               19 2023-01-18 00:26:19+00:00
# 156            3142909629               27 2023-01-18 02:39:38+00:00
# 159            3142909629               27 2023-01-18 01:29:39+00:00
#
#                      max_time    min_dist    max_dist  meters_elapsed  \
# 63  2023-01-18 00:26:19+00:00  482.207808  482.207808             0.0
# 156 2023-01-18 02:39:38+00:00  452.950162  452.950162             0.0
# 159 2023-01-18 01:29:39+00:00  482.337272  482.337272             0.0
#
#      sec_elapsed  speed_mph
# 63           0.0        NaN
# 156          0.0        NaN
# 159          0.0        NaN

# %%
no_motion.isna().speed_mph.value_counts()
# Out:
# True     68646
# False    16735
# Name: speed_mph, dtype: int64

# %%
no_motion >> count(_._gtfs_dataset_name) >> arrange (-_.n)
# Out:
#                         _gtfs_dataset_name      n
# 40          LA Metro Bus Vehicle Positions  22260
# 55             San Diego Vehicle Positions   9128
# 11      Bay Area 511 Muni VehiclePositions   4847
# 41         LA Metro Rail Vehicle Positions   4635
# 34              Foothill Vehicle Positions   3858
# ..                                     ...    ...
# 51              PresidiGo VehiclePositions     23
# 68                  WeHo Vehicle Positions     17
# 60  Tahoe Transportation Vehicle Positions     12
# 28              BruinBus Vehicle Positions      5
# 48               Norwalk Vehicle Positions      4
#
# [70 rows x 2 columns]

# %% [markdown]
# ## Notes
#
# * insufficient data segments aren't min_dist/max_dist nan, they're min_dist == max_dist
# * if min_time also == max_time, speed_mph is nan, otherwise speed_mph is 0.0
#     * about 75% nan, 25% zero speeds
#     * zero speeds -- breakdowns, end of trips, etc...??
# * approximately _6%_ of segments have insufficient data based on 1/18/23 data
#     * much higher, ~30%, in prior 10/12/22 data

# %%
no_motion_count = no_motion.shape[0]
no_motion_count
# Out:
# 85381

# %%
all_count = ddf.shape[0].compute()
all_count
# Out:
# 1311292

# %%
no_motion_count / all_count
# Out:
# 0.0651121184297624

# %% [markdown]
# ## Speeds?

# %%
all_speeds = ddf.speed_mph.compute()

# %%
to_chart = all_speeds[all_speeds < 100]

# %%
to_chart.hist()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import geopandas as gpd
from siuba import *

from shared_utils import gtfs_utils_v2

import os
os.environ["CALITP_BQ_MAX_BYTES"] = str(1_000_000_000_000) ## 1TB?

# %%
gtfs_utils_v2?
# Out:
# Type:        module
# String form: <module 'shared_utils.gtfs_utils_v2' from '/home/jovyan/data-analyses/_shared_utils/shared_utils/gtfs_utils_v2.py'>
# File:        ~/data-analyses/_shared_utils/shared_utils/gtfs_utils_v2.py
# Docstring:   GTFS utils for v2 warehouse

# %%
from calitp_data_analysis.tables import tbls

# %%
tbls.mart_transit_database.dim_gtfs_datasets() >> collect() >> filter(_.name.str.contains("Kings"))
# Out:
#                                    key   source_record_id  \
# 115   e4562c470fe672741a94acda93746ddd  recwzZhQIinNX1KRp
# 331   ca71fca800b4ddeeb95b3376be1749a1  recwzZhQIinNX1KRp
# 536   d58ff78d051be44f34bcbb2a168981db  recwzZhQIinNX1KRp
# 752   7863d3bb7214ea16fcb086e98cb23775  recwzZhQIinNX1KRp
# 1176  35932f2fc427b51841379d8fd178a394  recwzZhQIinNX1KRp
# 1461  5c54e396094863c9db18039fd5cc817f  recwzZhQIinNX1KRp
# 1838  a1d3e0db25b97c0aa87ece9d7c2de00d  recRJR8m0zlyHgLme
# 1863  69bf336494c273a143088764be02bf0b  recRJR8m0zlyHgLme
# 1952  55e824e4c88c4dfca7996b2c97f791c2  recRJR8m0zlyHgLme
# 2164  df187f048ef355f1017be80cb2ee4e12  recRJR8m0zlyHgLme
# 2232  4971708790c9e37220a7f30dfd30399b  recRJR8m0zlyHgLme
# 2418  017b99e6321c3674ebba00d567ba9c26  recRJR8m0zlyHgLme
# 2503  ce28c574ccdda0e28620ab9371e1bffb  rec6hxEPTcBpIFWFX
# 2521  474dfaf4c4fc5db34b423194a3fdff71  rec6hxEPTcBpIFWFX
# 2596  7fd3b96d001f6de1ea01c9554c8c0458  rec6hxEPTcBpIFWFX
# 2686  3517a93a42706130a6dc2e1323b036a1  rec6hxEPTcBpIFWFX
# 2723  3d305a2b0cc96e5288088ddb31dc6caf  rec6hxEPTcBpIFWFX
# 2835  bfbd0bd5a65b74e1149133a608bfbc03  rec6hxEPTcBpIFWFX
# 2990  5a7c12ef7fb4cdb3c1acb339592d9c18  recJeKrreKQLpuZyn
# 3068  04edd6271bf176fae12a0bd3c0c17522  recJeKrreKQLpuZyn
# 3196  aa9fe79adc8edf93ebfb1ab83c8acc69  recJeKrreKQLpuZyn
# 3330  622d099cf0351840597ad5a0078ef95d  recJeKrreKQLpuZyn
# 3429  6f6413c27bbf1875b3fdafadc0a1f295  recJeKrreKQLpuZyn
# 3560  8b212c3b75dbefeac2b7a35e7f35dfd9  recJeKrreKQLpuZyn
#
#                          name               type regional_feed_type  \
# 115            Kings Schedule           schedule               None
# 331            Kings Schedule           schedule               None
# 536            Kings Schedule           schedule               None
# 752            Kings Schedule           schedule               None
# 1176           Kings Schedule           schedule               None
# 1461           Kings Schedule           schedule               None
# 1838       Kings Trip Updates       trip_updates               None
# 1863       Kings Trip Updates       trip_updates               None
# 1952       Kings Trip Updates       trip_updates               None
# 2164       Kings Trip Updates       trip_updates               None
# 2232       Kings Trip Updates       trip_updates               None
# 2418       Kings Trip Updates       trip_updates               None
# 2503             Kings Alerts     service_alerts               None
# 2521             Kings Alerts     service_alerts               None
# 2596             Kings Alerts     service_alerts               None
# 2686             Kings Alerts     service_alerts               None
# 2723             Kings Alerts     service_alerts               None
# 2835             Kings Alerts     service_alerts               None
# 2990  Kings Vehicle Positions  vehicle_positions               None
# 3068  Kings Vehicle Positions  vehicle_positions               None
# 3196  Kings Vehicle Positions  vehicle_positions               None
# 3330  Kings Vehicle Positions  vehicle_positions               None
# 3429  Kings Vehicle Positions  vehicle_positions               None
# 3560  Kings Vehicle Positions  vehicle_positions               None
#
#                                                     uri future_uri  \
# 115   https://kart.connexionz.net/rtt/public/utility...       None
# 331   https://kart.connexionz.net/rtt/public/utility...       None
# 536   http://kart.connexionz.net/rtt/public/utility/...       None
# 752   https://kart.connexionz.net/rtt/public/utility...       None
# 1176  http://kart.connexionz.net/rtt/public/utility/...       None
# 1461  http://kart.connexionz.net/rtt/public/utility/...       None
# 1838  https://kart.connexionz.net/rtt/public/utility...       None
# 1863  http://kart.connexionz.net/rtt/public/utility/...       None
# 1952  https://kart.connexionz.net/rtt/public/utility...       None
# 2164  https://kart.connexionz.net/rtt/public/utility...       None
# 2232  http://kart.connexionz.net/rtt/public/utility/...       None
# 2418  http://kart.connexionz.net/rtt/public/utility/...       None
# 2503  https://kart.connexionz.net/rtt/public/utility...       None
# 2521  http://kart.connexionz.net/rtt/public/utility/...       None
# 2596  https://kart.connexionz.net/rtt/public/utility...       None
# 2686  https://kart.connexionz.net/rtt/public/utility...       None
# 2723  http://kart.connexionz.net/rtt/public/utility/...       None
# 2835  http://kart.connexionz.net/rtt/public/utility/...       None
# 2990  https://kart.connexionz.net/rtt/public/utility...       None
# 3068  http://kart.connexionz.net/rtt/public/utility/...       None
# 3196  https://kart.connexionz.net/rtt/public/utility...       None
# 3330  https://kart.connexionz.net/rtt/public/utility...       None
# 3429  http://kart.connexionz.net/rtt/public/utility/...       None
# 3560  http://kart.connexionz.net/rtt/public/utility/...       None
#
#      deprecated_date data_quality_pipeline  \
# 115             None                  True
# 331             None                  True
# 536             None                  True
# 752             None                  True
# 1176            None                  True
# 1461            None                  True
# 1838            None                  True
# 1863            None                  True
# 1952            None                  True
# 2164            None                  True
# 2232            None                  True
# 2418            None                  True
# 2503            None                  True
# 2521            None                  True
# 2596            None                  True
# 2686            None                  True
# 2723            None                  True
# 2835            None                  True
# 2990            None                  True
# 3068            None                  True
# 3196            None                  True
# 3330            None                  True
# 3429            None                  True
# 3560            None                  True
#
#      manual_check__link_to_dataset_on_website  \
# 115                                   Unknown
# 331                                   Unknown
# 536                                   Unknown
# 752                                   Unknown
# 1176                                     None
# 1461                                     None
# 1838                                  Unknown
# 1863                                  Unknown
# 1952                                  Unknown
# 2164                                  Unknown
# 2232                                     None
# 2418                                     None
# 2503                                  Unknown
# 2521                                  Unknown
# 2596                                  Unknown
# 2686                                  Unknown
# 2723                                     None
# 2835                                     None
# 2990                                  Unknown
# 3068                                  Unknown
# 3196                                  Unknown
# 3330                                  Unknown
# 3429                                     None
# 3560                                     None
#
#                 manual_check__accurate_shapes manual_check__data_license  \
# 115                                       Yes                    Missing
# 331                                   Unknown                    Unknown
# 536                                   Unknown                    Unknown
# 752                                   Unknown                    Missing
# 1176                                     None                       None
# 1461                                     None                       None
# 1838                                  Unknown                    Unknown
# 1863                                  Unknown                    Unknown
# 1952  N/A - dataset type is not GTFS Schedule                    Missing
# 2164                                  Unknown                    Missing
# 2232                                     None                       None
# 2418                                     None                       None
# 2503                                  Unknown                    Unknown
# 2521                                  Unknown                    Unknown
# 2596  N/A - dataset type is not GTFS Schedule                    Missing
# 2686                                  Unknown                    Missing
# 2723                                     None                       None
# 2835                                     None                       None
# 2990                                  Unknown                    Unknown
# 3068                                  Unknown                    Unknown
# 3196  N/A - dataset type is not GTFS Schedule                    Missing
# 3330                                  Unknown                    Missing
# 3429                                     None                       None
# 3560                                     None                       None
#
#      manual_check__authentication_acceptable manual_check__stable_url  \
# 115                                      Yes     Yes - Vendor Website
# 331                                      Yes                      Yes
# 536                                      Yes                      Yes
# 752                                      Yes     Yes - Vendor Website
# 1176                                    None                     None
# 1461                                    None                     None
# 1838                                     Yes                      Yes
# 1863                                     Yes                      Yes
# 1952                                     Yes     Yes - Vendor Website
# 2164                                     Yes     Yes - Vendor Website
# 2232                                    None                     None
# 2418                                    None                     None
# 2503                                     Yes                      Yes
# 2521                                     Yes                      Yes
# 2596                                     Yes     Yes - Vendor Website
# 2686                                     Yes     Yes - Vendor Website
# 2723                                    None                     None
# 2835                                    None                     None
# 2990                                     Yes                      Yes
# 3068                                     Yes                      Yes
# 3196                                     Yes     Yes - Vendor Website
# 3330                                     Yes     Yes - Vendor Website
# 3429                                    None                     None
# 3560                                    None                     None
#
#              manual_check__localized_stop_tts  \
# 115                                   Unknown
# 331                                   Unknown
# 536                                   Unknown
# 752                                   Unknown
# 1176                                     None
# 1461                                     None
# 1838                                  Unknown
# 1863                                  Unknown
# 1952  N/A - dataset type is not GTFS Schedule
# 2164                                  Unknown
# 2232                                     None
# 2418                                     None
# 2503                                  Unknown
# 2521                                  Unknown
# 2596  N/A - dataset type is not GTFS Schedule
# 2686                                  Unknown
# 2723                                     None
# 2835                                     None
# 2990                                  Unknown
# 3068                                  Unknown
# 3196  N/A - dataset type is not GTFS Schedule
# 3330                                  Unknown
# 3429                                     None
# 3560                                     None
#
#               manual_check__grading_scheme_v1  \
# 115                                   Unknown
# 331                                   Unknown
# 536                                   Unknown
# 752                                   Unknown
# 1176                                     None
# 1461                                     None
# 1838                                  Unknown
# 1863                                  Unknown
# 1952  N/A - dataset type is not GTFS Schedule
# 2164                                  Unknown
# 2232                                     None
# 2418                                     None
# 2503                                  Unknown
# 2521                                  Unknown
# 2596  N/A - dataset type is not GTFS Schedule
# 2686                                  Unknown
# 2723                                     None
# 2835                                     None
# 2990                                  Unknown
# 3068                                  Unknown
# 3196  N/A - dataset type is not GTFS Schedule
# 3330                                  Unknown
# 3429                                     None
# 3560                                     None
#
#                                              base64_url  _is_current  \
# 115   aHR0cHM6Ly9rYXJ0LmNvbm5leGlvbnoubmV0L3J0dC9wdW...         True
# 331   aHR0cHM6Ly9rYXJ0LmNvbm5leGlvbnoubmV0L3J0dC9wdW...        False
# 536   aHR0cDovL2thcnQuY29ubmV4aW9uei5uZXQvcnR0L3B1Ym...        False
# 752   aHR0cHM6Ly9rYXJ0LmNvbm5leGlvbnoubmV0L3J0dC9wdW...        False
# 1176  aHR0cDovL2thcnQuY29ubmV4aW9uei5uZXQvcnR0L3B1Ym...        False
# 1461  aHR0cDovL2thcnQuY29ubmV4aW9uei5uZXQvcnR0L3B1Ym...        False
# 1838  aHR0cHM6Ly9rYXJ0LmNvbm5leGlvbnoubmV0L3J0dC9wdW...        False
# 1863  aHR0cDovL2thcnQuY29ubmV4aW9uei5uZXQvcnR0L3B1Ym...        False
# 1952  aHR0cHM6Ly9rYXJ0LmNvbm5leGlvbnoubmV0L3J0dC9wdW...         True
# 2164  aHR0cHM6Ly9rYXJ0LmNvbm5leGlvbnoubmV0L3J0dC9wdW...        False
# 2232  aHR0cDovL2thcnQuY29ubmV4aW9uei5uZXQvcnR0L3B1Ym...        False
# 2418  aHR0cDovL2thcnQuY29ubmV4aW9uei5uZXQvcnR0L3B1Ym...        False
# 2503  aHR0cHM6Ly9rYXJ0LmNvbm5leGlvbnoubmV0L3J0dC9wdW...        False
# 2521  aHR0cDovL2thcnQuY29ubmV4aW9uei5uZXQvcnR0L3B1Ym...        False
# 2596  aHR0cHM6Ly9rYXJ0LmNvbm5leGlvbnoubmV0L3J0dC9wdW...         True
# 2686  aHR0cHM6Ly9rYXJ0LmNvbm5leGlvbnoubmV0L3J0dC9wdW...        False
# 2723  aHR0cDovL2thcnQuY29ubmV4aW9uei5uZXQvcnR0L3B1Ym...        False
# 2835  aHR0cDovL2thcnQuY29ubmV4aW9uei5uZXQvcnR0L3B1Ym...        False
# 2990  aHR0cHM6Ly9rYXJ0LmNvbm5leGlvbnoubmV0L3J0dC9wdW...        False
# 3068  aHR0cDovL2thcnQuY29ubmV4aW9uei5uZXQvcnR0L3B1Ym...        False
# 3196  aHR0cHM6Ly9rYXJ0LmNvbm5leGlvbnoubmV0L3J0dC9wdW...         True
# 3330  aHR0cHM6Ly9rYXJ0LmNvbm5leGlvbnoubmV0L3J0dC9wdW...        False
# 3429  aHR0cDovL2thcnQuY29ubmV4aW9uei5uZXQvcnR0L3B1Ym...        False
# 3560  aHR0cDovL2thcnQuY29ubmV4aW9uei5uZXQvcnR0L3B1Ym...        False
#
#                    _valid_from                        _valid_to
# 115  2023-01-19 00:00:00+00:00 2098-12-31 23:59:59.999999+00:00
# 331  2022-10-26 00:00:00+00:00 2022-11-21 23:59:59.999999+00:00
# 536  2022-10-18 00:00:00+00:00 2022-10-25 23:59:59.999999+00:00
# 752  2022-11-22 00:00:00+00:00 2023-01-18 23:59:59.999999+00:00
# 1176 2022-06-29 00:00:00+00:00 2022-08-08 23:59:59.999999+00:00
# 1461 2022-08-09 00:00:00+00:00 2022-10-17 23:59:59.999999+00:00
# 1838 2022-10-26 00:00:00+00:00 2022-11-21 23:59:59.999999+00:00
# 1863 2022-10-18 00:00:00+00:00 2022-10-25 23:59:59.999999+00:00
# 1952 2023-01-14 00:00:00+00:00 2098-12-31 23:59:59.999999+00:00
# 2164 2022-11-22 00:00:00+00:00 2023-01-13 23:59:59.999999+00:00
# 2232 2022-06-29 00:00:00+00:00 2022-08-08 23:59:59.999999+00:00
# 2418 2022-08-09 00:00:00+00:00 2022-10-17 23:59:59.999999+00:00
# 2503 2022-10-26 00:00:00+00:00 2022-11-21 23:59:59.999999+00:00
# 2521 2022-10-18 00:00:00+00:00 2022-10-25 23:59:59.999999+00:00
# 2596 2023-01-14 00:00:00+00:00 2098-12-31 23:59:59.999999+00:00
# 2686 2022-11-22 00:00:00+00:00 2023-01-13 23:59:59.999999+00:00
# 2723 2022-06-29 00:00:00+00:00 2022-08-08 23:59:59.999999+00:00
# 2835 2022-08-09 00:00:00+00:00 2022-10-17 23:59:59.999999+00:00
# 2990 2022-10-26 00:00:00+00:00 2022-11-21 23:59:59.999999+00:00
# 3068 2022-10-18 00:00:00+00:00 2022-10-25 23:59:59.999999+00:00
# 3196 2023-01-14 00:00:00+00:00 2098-12-31 23:59:59.999999+00:00
# 3330 2022-11-22 00:00:00+00:00 2023-01-13 23:59:59.999999+00:00
# 3429 2022-06-29 00:00:00+00:00 2022-08-08 23:59:59.999999+00:00
# 3560 2022-08-09 00:00:00+00:00 2022-10-17 23:59:59.999999+00:00

# %%
kings = gtfs_utils_v2.schedule_daily_feed_to_organization(selected_date = '2023-02-07') >> filter(_.name.str.contains("Kings"))
kings
# Out:
#                                   key       date  \
# 130  b7212792b389a0df398c7bff6559b324 2023-02-07
#
#                              feed_key  \
# 130  99fca48844312a4b68af992be4f7ee43
#
#                                             base64_url  \
# 130  aHR0cHM6Ly9rYXJ0LmNvbm5leGlvbnoubmV0L3J0dC9wdW...
#
#                      gtfs_dataset_key  is_future            name  \
# 130  e4562c470fe672741a94acda93746ddd      False  Kings Schedule
#
#     regional_feed_type      type
# 130               None  schedule

# %%
gtfs_utils_v2.get_trips(selected_date= '2023-02-07', operator_feeds=kings.feed_key.to_list())
# Out:
# ---------------------------------------------------------------------------
# InternalServerError                       Traceback (most recent call last)
# File /opt/conda/lib/python3.9/site-packages/google/cloud/bigquery/dbapi/cursor.py:203, in Cursor._execute(self, formatted_operation, parameters, job_id, job_config, parameter_types)
#     202 try:
# --> 203     self._query_job.result()
#     204 except google.cloud.exceptions.GoogleCloudError as exc:
#
# File /opt/conda/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py:1499, in QueryJob.result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1497         do_get_result = job_retry(do_get_result)
# -> 1499     do_get_result()
#    1501 except exceptions.GoogleAPICallError as exc:
#
# File /opt/conda/lib/python3.9/site-packages/google/api_core/retry.py:283, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     280 sleep_generator = exponential_sleep_generator(
#     281     self._initial, self._maximum, multiplier=self._multiplier
#     282 )
# --> 283 return retry_target(
#     284     target,
#     285     self._predicate,
#     286     sleep_generator,
#     287     self._deadline,
#     288     on_error=on_error,
#     289 )
#
# File /opt/conda/lib/python3.9/site-packages/google/api_core/retry.py:190, in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     189 try:
# --> 190     return target()
#     192 # pylint: disable=broad-except
#     193 # This function explicitly must deal with broad exceptions.
#
# File /opt/conda/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py:1489, in QueryJob.result.<locals>.do_get_result()
#    1487     self._job_retry = job_retry
# -> 1489 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    1491 # Since the job could already be "done" (e.g. got a finished job
#    1492 # via client.get_job), the superclass call to done() might not
#    1493 # set the self._query_results cache.
#
# File /opt/conda/lib/python3.9/site-packages/google/cloud/bigquery/job/base.py:728, in _AsyncJob.result(self, retry, timeout)
#     727 kwargs = {} if retry is DEFAULT_RETRY else {"retry": retry}
# --> 728 return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#
# File /opt/conda/lib/python3.9/site-packages/google/api_core/future/polling.py:137, in PollingFuture.result(self, timeout, retry)
#     134 if self._exception is not None:
#     135     # pylint: disable=raising-bad-type
#     136     # Pylint doesn't recognize that this is valid in this case.
# --> 137     raise self._exception
#     139 return self._result
#
# InternalServerError: 500 Query exceeded limit for bytes billed: 5000000000. 38576062464 or higher required.
#
# Location: us-west2
# Job ID: 31a7475d-651d-4cd7-a750-5d3e8e42efbe
#
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# File /opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1802, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1801     if not evt_handled:
# -> 1802         self.dialect.do_execute(
#    1803             cursor, statement, parameters, context
#    1804         )
#    1806 if self._has_events or self.engine._has_events:
#
# File /opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/default.py:719, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     718 def do_execute(self, cursor, statement, parameters, context=None):
# --> 719     cursor.execute(statement, parameters)
#
# File /opt/conda/lib/python3.9/site-packages/google/cloud/bigquery/dbapi/_helpers.py:494, in raise_on_closed.<locals>._raise_on_closed.<locals>.with_closed_check(self, *args, **kwargs)
#     493     raise exc_class(exc_msg)
# --> 494 return method(self, *args, **kwargs)
#
# File /opt/conda/lib/python3.9/site-packages/google/cloud/bigquery/dbapi/cursor.py:166, in Cursor.execute(self, operation, parameters, job_id, job_config)
#     165 formatted_operation, parameter_types = _format_operation(operation, parameters)
# --> 166 self._execute(
#     167     formatted_operation, parameters, job_id, job_config, parameter_types
#     168 )
#
# File /opt/conda/lib/python3.9/site-packages/google/cloud/bigquery/dbapi/cursor.py:205, in Cursor._execute(self, formatted_operation, parameters, job_id, job_config, parameter_types)
#     204 except google.cloud.exceptions.GoogleCloudError as exc:
# --> 205     raise exceptions.DatabaseError(exc)
#     207 query_results = self._query_job._query_results
#
# DatabaseError: 500 Query exceeded limit for bytes billed: 5000000000. 38576062464 or higher required.
#
# Location: us-west2
# Job ID: 31a7475d-651d-4cd7-a750-5d3e8e42efbe
#
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 shared_utils.gtfs_utils_v2.get_trips(selected_date= '2023-02-07', operator_feeds=kings.feed_key.to_list())
#
# File ~/data-analyses/_shared_utils/shared_utils/gtfs_utils_v2.py:373, in get_trips(selected_date, operator_feeds, trip_cols, get_df, custom_filtering)
#     368         trips = pd.concat(
#     369             [not_metrolink_trips, corrected_metrolink], axis=0, ignore_index=True
#     370         )[trip_cols].reset_index(drop=True)
#     372     elif metrolink_feed_key not in operator_feeds:
# --> 373         trips = trips >> subset_cols(trip_cols) >> collect()
#     375 return trips >> subset_cols(trip_cols)
#
# File /opt/conda/lib/python3.9/site-packages/siuba/siu/calls.py:214, in Call.__rrshift__(self, x)
#     210 if isinstance(strip_symbolic(x), (Call)):
#     211     # only allow non-calls (i.e. data) on the left.
#     212     raise TypeError()
# --> 214 return self(x)
#
# File /opt/conda/lib/python3.9/site-packages/siuba/siu/calls.py:189, in Call.__call__(self, x)
#     187     return operator.getitem(inst, *rest)
#     188 elif self.func == "__call__":
# --> 189     return getattr(inst, self.func)(*rest, **kwargs)
#     191 # in normal case, get method to call, and then call it
#     192 f_op = getattr(operator, self.func)
#
# File /opt/conda/lib/python3.9/site-packages/siuba/siu/dispatchers.py:167, in verb_dispatch.<locals>.wrapper(*args, **kwargs)
#     164 if not args:
#     165     return dispatch_func(NoArgs(), **strip_kwargs)
# --> 167 return dispatch_func(*strip_args, **strip_kwargs)
#
# File /opt/conda/lib/python3.9/functools.py:888, in singledispatch.<locals>.wrapper(*args, **kw)
#     884 if not args:
#     885     raise TypeError(f'{funcname} requires at least '
#     886                     '1 positional argument')
# --> 888 return dispatch(args[0].__class__)(*args, **kw)
#
# File /opt/conda/lib/python3.9/site-packages/siuba/sql/verbs/compute.py:46, in _collect(__data, as_df)
#      43         return duckdb_con.query(str(compiled)).to_df()
#      44     else:
#      45         #
# ---> 46         return sql_db.read_sql(compiled)
#      48 return conn.execute(compiled)
#
# File /opt/conda/lib/python3.9/site-packages/pandas/io/sql.py:1579, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1531 """
#    1532 Read SQL query into a DataFrame.
#    1533
#    (...)
#    1575
#    1576 """
#    1577 args = _convert_params(sql, params)
# -> 1579 result = self.execute(*args)
#    1580 columns = result.keys()
#    1582 if chunksize is not None:
#
# File /opt/conda/lib/python3.9/site-packages/siuba/sql/utils.py:85, in _FixedSqlDatabase.execute(self, *args, **kwargs)
#      84 def execute(self, *args, **kwargs):
# ---> 85     return self.connectable.execute(*args, **kwargs)
#
# File /opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1289, in Connection.execute(self, statement, *multiparams, **params)
#    1285     util.raise_(
#    1286         exc.ObjectNotExecutableError(statement), replace_context=err
#    1287     )
#    1288 else:
# -> 1289     return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#
# File /opt/conda/lib/python3.9/site-packages/sqlalchemy/sql/elements.py:325, in ClauseElement._execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     321 def _execute_on_connection(
#     322     self, connection, multiparams, params, execution_options, _force=False
#     323 ):
#     324     if _force or self.supports_execution:
# --> 325         return connection._execute_clauseelement(
#     326             self, multiparams, params, execution_options
#     327         )
#     328     else:
#     329         raise exc.ObjectNotExecutableError(self)
#
# File /opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1481, in Connection._execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1469 compiled_cache = execution_options.get(
#    1470     "compiled_cache", self.engine._compiled_cache
#    1471 )
#    1473 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1474     dialect=dialect,
#    1475     compiled_cache=compiled_cache,
#    (...)
#    1479     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1480 )
# -> 1481 ret = self._execute_context(
#    1482     dialect,
#    1483     dialect.execution_ctx_cls._init_compiled,
#    1484     compiled_sql,
#    1485     distilled_params,
#    1486     execution_options,
#    1487     compiled_sql,
#    1488     distilled_params,
#    1489     elem,
#    1490     extracted_params,
#    1491     cache_hit=cache_hit,
#    1492 )
#    1493 if has_events:
#    1494     self.dispatch.after_execute(
#    1495         self,
#    1496         elem,
#    (...)
#    1500         ret,
#    1501     )
#
# File /opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1845, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1842             branched.close()
#    1844 except BaseException as e:
# -> 1845     self._handle_dbapi_exception(
#    1846         e, statement, parameters, cursor, context
#    1847     )
#    1849 return result
#
# File /opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py:2026, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2024     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2025 elif should_wrap:
# -> 2026     util.raise_(
#    2027         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2028     )
#    2029 else:
#    2030     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File /opt/conda/lib/python3.9/site-packages/sqlalchemy/util/compat.py:207, in raise_(***failed resolving arguments***)
#     204     exception.__cause__ = replace_context
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#     212     del exception, replace_context, from_, with_traceback
#
# File /opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1802, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1800                 break
#    1801     if not evt_handled:
# -> 1802         self.dialect.do_execute(
#    1803             cursor, statement, parameters, context
#    1804         )
#    1806 if self._has_events or self.engine._has_events:
#    1807     self.dispatch.after_cursor_execute(
#    1808         self,
#    1809         cursor,
#    (...)
#    1813         context.executemany,
#    1814     )
#
# File /opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/default.py:719, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     718 def do_execute(self, cursor, statement, parameters, context=None):
# --> 719     cursor.execute(statement, parameters)
#
# File /opt/conda/lib/python3.9/site-packages/google/cloud/bigquery/dbapi/_helpers.py:494, in raise_on_closed.<locals>._raise_on_closed.<locals>.with_closed_check(self, *args, **kwargs)
#     492 if getattr(self, closed_attr_name):
#     493     raise exc_class(exc_msg)
# --> 494 return method(self, *args, **kwargs)
#
# File /opt/conda/lib/python3.9/site-packages/google/cloud/bigquery/dbapi/cursor.py:166, in Cursor.execute(self, operation, parameters, job_id, job_config)
#     131 """Prepare and execute a database operation.
#     132
#     133 .. note::
#    (...)
#     163         (Optional) Extra configuration options for the query job.
#     164 """
#     165 formatted_operation, parameter_types = _format_operation(operation, parameters)
# --> 166 self._execute(
#     167     formatted_operation, parameters, job_id, job_config, parameter_types
#     168 )
#
# File /opt/conda/lib/python3.9/site-packages/google/cloud/bigquery/dbapi/cursor.py:205, in Cursor._execute(self, formatted_operation, parameters, job_id, job_config, parameter_types)
#     203     self._query_job.result()
#     204 except google.cloud.exceptions.GoogleCloudError as exc:
# --> 205     raise exceptions.DatabaseError(exc)
#     207 query_results = self._query_job._query_results
#     208 self._set_rowcount(query_results)
#
# DatabaseError: (google.cloud.bigquery.dbapi.exceptions.DatabaseError) 500 Query exceeded limit for bytes billed: 5000000000. 38576062464 or higher required.
#
# Location: us-west2
# Job ID: 31a7475d-651d-4cd7-a750-5d3e8e42efbe
#
# [SQL: SELECT `anon_1`.`key`, `anon_1`.`service_date`, `anon_1`.`feed_key`, `anon_1`.`service_id`, `anon_1`.`name`, `anon_1`.`regional_feed_type`, `anon_1`.`trip_key`, `anon_1`.`trip_id`, `anon_1`.`trip_short_name`, `anon_1`.`direction_id`, `anon_1`.`block_id`, `anon_1`.`route_key`, `anon_1`.`route_id`, `anon_1`.`route_type`, `anon_1`.`route_short_name`, `anon_1`.`route_long_name`, `anon_1`.`route_desc`, `anon_1`.`agency_id`, `anon_1`.`network_id`, `anon_1`.`shape_array_key`, `anon_1`.`gtfs_dataset_key`, `anon_1`.`shape_id`, `anon_1`.`contains_warning_duplicate_trip_primary_key`, `anon_1`.`n_stops`, `anon_1`.`n_stop_times`, `anon_1`.`trip_first_departure_sec`, `anon_1`.`trip_last_arrival_sec`, `anon_1`.`service_hours`, `anon_1`.`contains_warning_duplicate_stop_times_primary_key`, `anon_1`.`contains_warning_missing_foreign_key_stop_id`
# FROM (SELECT `anon_2`.`key` AS `key`, `anon_2`.`service_date` AS `service_date`, `anon_2`.`feed_key` AS `feed_key`, `anon_2`.`service_id` AS `service_id`, `anon_2`.`name` AS `name`, `anon_2`.`regional_feed_type` AS `regional_feed_type`, `anon_2`.`trip_key` AS `trip_key`, `anon_2`.`trip_id` AS `trip_id`, `anon_2`.`trip_short_name` AS `trip_short_name`, `anon_2`.`direction_id` AS `direction_id`, `anon_2`.`block_id` AS `block_id`, `anon_2`.`route_key` AS `route_key`, `anon_2`.`route_id` AS `route_id`, `anon_2`.`route_type` AS `route_type`, `anon_2`.`route_short_name` AS `route_short_name`, `anon_2`.`route_long_name` AS `route_long_name`, `anon_2`.`route_desc` AS `route_desc`, `anon_2`.`agency_id` AS `agency_id`, `anon_2`.`network_id` AS `network_id`, `anon_2`.`shape_array_key` AS `shape_array_key`, `anon_2`.`gtfs_dataset_key` AS `gtfs_dataset_key`, `anon_2`.`shape_id` AS `shape_id`, `anon_2`.`contains_warning_duplicate_trip_primary_key` AS `contains_warning_duplicate_trip_primary_key`, `anon_2`.`n_stops` AS `n_stops`, `anon_2`.`n_stop_times` AS `n_stop_times`, `anon_2`.`trip_first_departure_sec` AS `trip_first_departure_sec`, `anon_2`.`trip_last_arrival_sec` AS `trip_last_arrival_sec`, `anon_2`.`service_hours` AS `service_hours`, `anon_2`.`contains_warning_duplicate_stop_times_primary_key` AS `contains_warning_duplicate_stop_times_primary_key`, `anon_2`.`contains_warning_missing_foreign_key_stop_id` AS `contains_warning_missing_foreign_key_stop_id`
# FROM (SELECT `anon_3`.`key` AS `key`, `anon_3`.`service_date` AS `service_date`, `anon_3`.`feed_key` AS `feed_key`, `anon_3`.`service_id` AS `service_id`, `anon_3`.`name` AS `name`, `anon_3`.`regional_feed_type` AS `regional_feed_type`, `anon_3`.`trip_key` AS `trip_key`, `anon_3`.`trip_id` AS `trip_id`, `anon_3`.`trip_short_name` AS `trip_short_name`, `anon_3`.`direction_id` AS `direction_id`, `anon_3`.`block_id` AS `block_id`, `anon_3`.`route_key` AS `route_key`, `anon_3`.`route_id` AS `route_id`, `anon_3`.`route_type` AS `route_type`, `anon_3`.`route_short_name` AS `route_short_name`, `anon_3`.`route_long_name` AS `route_long_name`, `anon_3`.`route_desc` AS `route_desc`, `anon_3`.`agency_id` AS `agency_id`, `anon_3`.`network_id` AS `network_id`, `anon_3`.`shape_array_key` AS `shape_array_key`, `anon_3`.`gtfs_dataset_key` AS `gtfs_dataset_key`, `anon_3`.`shape_id` AS `shape_id`, `anon_3`.`contains_warning_duplicate_trip_primary_key` AS `contains_warning_duplicate_trip_primary_key`, `anon_3`.`n_stops` AS `n_stops`, `anon_3`.`n_stop_times` AS `n_stop_times`, `anon_3`.`trip_first_departure_sec` AS `trip_first_departure_sec`, `anon_3`.`trip_last_arrival_sec` AS `trip_last_arrival_sec`, `anon_3`.`service_hours` AS `service_hours`, `anon_3`.`contains_warning_duplicate_stop_times_primary_key` AS `contains_warning_duplicate_stop_times_primary_key`, `anon_3`.`contains_warning_missing_foreign_key_stop_id` AS `contains_warning_missing_foreign_key_stop_id`
# FROM (SELECT `mart_gtfs.fct_daily_scheduled_trips_1`.`key` AS `key`, `mart_gtfs.fct_daily_scheduled_trips_1`.`service_date` AS `service_date`, `mart_gtfs.fct_daily_scheduled_trips_1`.`feed_key` AS `feed_key`, `mart_gtfs.fct_daily_scheduled_trips_1`.`service_id` AS `service_id`, `mart_gtfs.fct_daily_scheduled_trips_1`.`name` AS `name`, `mart_gtfs.fct_daily_scheduled_trips_1`.`regional_feed_type` AS `regional_feed_type`, `mart_gtfs.fct_daily_scheduled_trips_1`.`trip_key` AS `trip_key`, `mart_gtfs.fct_daily_scheduled_trips_1`.`trip_id` AS `trip_id`, `mart_gtfs.fct_daily_scheduled_trips_1`.`trip_short_name` AS `trip_short_name`, `mart_gtfs.fct_daily_scheduled_trips_1`.`direction_id` AS `direction_id`, `mart_gtfs.fct_daily_scheduled_trips_1`.`block_id` AS `block_id`, `mart_gtfs.fct_daily_scheduled_trips_1`.`route_key` AS `route_key`, `mart_gtfs.fct_daily_scheduled_trips_1`.`route_id` AS `route_id`, `mart_gtfs.fct_daily_scheduled_trips_1`.`route_type` AS `route_type`, `mart_gtfs.fct_daily_scheduled_trips_1`.`route_short_name` AS `route_short_name`, `mart_gtfs.fct_daily_scheduled_trips_1`.`route_long_name` AS `route_long_name`, `mart_gtfs.fct_daily_scheduled_trips_1`.`route_desc` AS `route_desc`, `mart_gtfs.fct_daily_scheduled_trips_1`.`agency_id` AS `agency_id`, `mart_gtfs.fct_daily_scheduled_trips_1`.`network_id` AS `network_id`, `mart_gtfs.fct_daily_scheduled_trips_1`.`shape_array_key` AS `shape_array_key`, `mart_gtfs.fct_daily_scheduled_trips_1`.`gtfs_dataset_key` AS `gtfs_dataset_key`, `mart_gtfs.fct_daily_scheduled_trips_1`.`shape_id` AS `shape_id`, `mart_gtfs.fct_daily_scheduled_trips_1`.`contains_warning_duplicate_trip_primary_key` AS `contains_warning_duplicate_trip_primary_key`, `mart_gtfs.fct_daily_scheduled_trips_1`.`n_stops` AS `n_stops`, `mart_gtfs.fct_daily_scheduled_trips_1`.`n_stop_times` AS `n_stop_times`, `mart_gtfs.fct_daily_scheduled_trips_1`.`trip_first_departure_sec` AS `trip_first_departure_sec`, `mart_gtfs.fct_daily_scheduled_trips_1`.`trip_last_arrival_sec` AS `trip_last_arrival_sec`, `mart_gtfs.fct_daily_scheduled_trips_1`.`service_hours` AS `service_hours`, `mart_gtfs.fct_daily_scheduled_trips_1`.`contains_warning_duplicate_stop_times_primary_key` AS `contains_warning_duplicate_stop_times_primary_key`, `mart_gtfs.fct_daily_scheduled_trips_1`.`contains_warning_missing_foreign_key_stop_id` AS `contains_warning_missing_foreign_key_stop_id`
# FROM `mart_gtfs.fct_daily_scheduled_trips` AS `mart_gtfs.fct_daily_scheduled_trips_1`
# WHERE `mart_gtfs.fct_daily_scheduled_trips_1`.`service_date` = %(service_date_1:STRING)s) AS `anon_3`
# WHERE `anon_3`.`feed_key` IN UNNEST(%(feed_key_1:STRING)s) OR `anon_3`.`name` IN UNNEST(%(name_1:STRING)s)) AS `anon_2`) AS `anon_1`]
# [parameters: {'service_date_1': '2023-02-07', 'feed_key_1': ['99fca48844312a4b68af992be4f7ee43'], 'name_1': ['99fca48844312a4b68af992be4f7ee43']}]
# (Background on this error at: https://sqlalche.me/e/14/4xp6)

# %% [markdown]
# # Set up different segments for nearest neighbors

# %%
import geopandas as gpd
import pandas as pd
import shapely

from calitp_data_analysis import geography_utils
from segment_speed_utils import helpers, neighbor
from shared_utils import rt_dates

from segment_speed_utils.project_vars import GTFS_DATA_DICT, SEGMENT_GCS

import sys 
sys.path.append('scripts/')

analysis_date = rt_dates.DATES["mar2024"]

# %%
'''
operator_name = "Big Blue Bus Schedule"

r10_df = helpers.import_scheduled_trips(
    analysis_date,
    columns = ["gtfs_dataset_key", "name",
               "trip_instance_key",],
    filters = [[("name", "==", operator_name),
                ("route_short_name", "==", "R10")]],
    get_pandas = True
)

operator_key = r10_df.schedule_gtfs_dataset_key.iloc[0]
operator_trip_keys = r10_df.trip_instance_key.unique().tolist()

operator_name, operator_key, operator_trip_keys
'''

# %%
operator_name = 'Big Blue Bus Schedule'
operator_key = 'efbbd5293be71f7a5de0cf82b59febe1'
operator_trip_keys = [
    'd98e5cc1fb62e6e5ed0030934ef8a396',
    'c3577c96a714df975f5525b246987e41',
    'f1866ab43b90dd43adb557fe527177d2',
    '8a452661390b69cd00fdcde92066cc4a',
    '5d3dc572ce27ef902024f6f135cf59c2',
    '3505bf6a20e8d29e83e545784a421bc7'
]

# %%
stop_segments = gpd.read_parquet(
    f"{SEGMENT_GCS}segment_options/stop_segments_{analysis_date}.parquet",
    filters = [[("trip_instance_key", "in", operator_trip_keys)]]
)

# %%
stop_segments.dtypes

# %%
stop_segments.head(2)

# %% [markdown]
# Need to have `stop_primary_direction` column. Use `ffill` whenever we set up our own "stops"

# %% [markdown]
# ## Regular stop times

# %%
stop_times = helpers.import_scheduled_stop_times(
    analysis_date,
    columns = ["trip_instance_key", "shape_array_key",
               "stop_sequence", "stop_id", "stop_pair", 
               "stop_primary_direction",
               "geometry"],
    filters = [[("trip_instance_key", "in", operator_trip_keys)]],
    with_direction = True,
    get_pandas = True,
    crs = "EPSG:4326"
)

stop_times.dtypes

# %%
stop_times.head()

# %%
gdf = neighbor.merge_stop_vp_for_nearest_neighbor(
    stop_times, analysis_date)

gdf.dtypes

# %%
gdf.head(2)

# %%
results = neighbor.add_nearest_neighbor_result(gdf, analysis_date)

results.dtypes

# %%
results.head()

# %% [markdown]
# ## Interpolated segments

# %%
speedmap_stops = gpd.read_parquet(
    f"{SEGMENT_GCS}stop_time_expansion/"
    f"speedmap_stop_times_{analysis_date}.parquet",
    filters = [[("trip_instance_key", "in", operator_trip_keys)]]
)
speedmap_stops.dtypes
# Out:
# trip_instance_key           object
# shape_array_key             object
# stop_sequence                int64
# stop_id                     object
# stop_pair                   object
# stop_primary_direction      object
# geometry                  geometry
# stop_sequence1             float64
# dtype: object

# %%
gdf_speedmap = neighbor.merge_stop_vp_for_nearest_neighbor(
    speedmap_stops, analysis_date)

gdf_speedmap.dtypes
# Out:
# trip_instance_key           object
# shape_array_key             object
# stop_sequence                int64
# stop_id                     object
# stop_pair                   object
# stop_primary_direction      object
# stop_geometry             geometry
# stop_sequence1             float64
# vp_geometry               geometry
# vp_idx                      object
# dtype: object

# %%
# look at our decimal stop_sequence1 values specifically
gdf_speedmap[
    gdf_speedmap.stop_sequence != gdf_speedmap.stop_sequence1
]
# Out:
#                     trip_instance_key                   shape_array_key  \
# 27   3505bf6a20e8d29e83e545784a421bc7  37468c4ffbbbab83f270b8fcecb6de61
# 28   3505bf6a20e8d29e83e545784a421bc7  37468c4ffbbbab83f270b8fcecb6de61
# 29   3505bf6a20e8d29e83e545784a421bc7  37468c4ffbbbab83f270b8fcecb6de61
# 30   3505bf6a20e8d29e83e545784a421bc7  37468c4ffbbbab83f270b8fcecb6de61
# 31   3505bf6a20e8d29e83e545784a421bc7  37468c4ffbbbab83f270b8fcecb6de61
# ..                                ...                               ...
# 218  f1866ab43b90dd43adb557fe527177d2  d78657863e0bc2635c13d67785cb8b03
# 219  f1866ab43b90dd43adb557fe527177d2  d78657863e0bc2635c13d67785cb8b03
# 220  f1866ab43b90dd43adb557fe527177d2  d78657863e0bc2635c13d67785cb8b03
# 221  f1866ab43b90dd43adb557fe527177d2  d78657863e0bc2635c13d67785cb8b03
# 222  f1866ab43b90dd43adb557fe527177d2  d78657863e0bc2635c13d67785cb8b03
#
#      stop_sequence stop_id stop_pair stop_primary_direction  \
# 27              18     228  228__106              Eastbound
# 28              18     228  228__106              Eastbound
# 29              18     228  228__106              Eastbound
# 30              18     228  228__106              Eastbound
# 31              18     228  228__106              Eastbound
# ..             ...     ...       ...                    ...
# 218             15     111  111__229             Southbound
# 219             15     111  111__229             Southbound
# 220             15     111  111__229             Southbound
# 221             15     111  111__229             Southbound
# 222             15     111  111__229             Southbound
#
#                    stop_geometry  stop_sequence1  \
# 27   POINT (-118.44098 34.03014)           18.06
# 28   POINT (-118.43030 34.03158)           18.11
# 29   POINT (-118.41947 34.03168)           18.17
# 30   POINT (-118.40896 34.03007)           18.23
# 31   POINT (-118.39820 34.02911)           18.28
# ..                           ...             ...
# 218  POINT (-118.40166 34.02959)           15.74
# 219  POINT (-118.41225 34.03119)           15.79
# 220  POINT (-118.42295 34.03187)           15.85
# 221  POINT (-118.43373 34.03133)           15.91
# 222  POINT (-118.44436 34.02965)           15.96
#
#                                            vp_geometry  \
# 27   LINESTRING (-118.49104 34.01601, -118.49265 34...
# 28   LINESTRING (-118.49104 34.01601, -118.49265 34...
# 29   LINESTRING (-118.49104 34.01601, -118.49265 34...
# 30   LINESTRING (-118.49104 34.01601, -118.49265 34...
# 31   LINESTRING (-118.49104 34.01601, -118.49265 34...
# ..                                                 ...
# 218  LINESTRING (-118.48973 34.01560, -118.48820 34...
# 219  LINESTRING (-118.48973 34.01560, -118.48820 34...
# 220  LINESTRING (-118.48973 34.01560, -118.48820 34...
# 221  LINESTRING (-118.48973 34.01560, -118.48820 34...
# 222  LINESTRING (-118.48973 34.01560, -118.48820 34...
#
#                                                 vp_idx
# 27   [6163904, 6163908, 6163909, 6163910, 6163911, ...
# 28   [6163904, 6163908, 6163909, 6163910, 6163911, ...
# 29   [6163904, 6163908, 6163909, 6163910, 6163911, ...
# 30   [6163904, 6163908, 6163909, 6163910, 6163911, ...
# 31   [6163904, 6163908, 6163909, 6163910, 6163911, ...
# ..                                                 ...
# 218  [6164031, 6164032, 6164033, 6164034, 6164036, ...
# 219  [6164031, 6164032, 6164033, 6164034, 6164036, ...
# 220  [6164031, 6164032, 6164033, 6164034, 6164036, ...
# 221  [6164031, 6164032, 6164033, 6164034, 6164036, ...
# 222  [6164031, 6164032, 6164033, 6164034, 6164036, ...
#
# [85 rows x 10 columns]

# %%
results_speedmap = neighbor.add_nearest_neighbor_result(gdf_speedmap, analysis_date)

results_speedmap.dtypes
# Out:
# trip_instance_key                  object
# shape_array_key                    object
# stop_sequence                       int64
# stop_id                            object
# stop_pair                          object
# stop_primary_direction             object
# stop_geometry                    geometry
# stop_sequence1                    float64
# nearest_vp_idx                      int64
# vp_idx_trio                        object
# location_timestamp_local_trio      object
# vp_coords_trio                   geometry
# dtype: object

# %%
results_speedmap[
    results_speedmap.stop_sequence != results_speedmap.stop_sequence1
]
# Out:
#                     trip_instance_key                   shape_array_key  \
# 27   3505bf6a20e8d29e83e545784a421bc7  37468c4ffbbbab83f270b8fcecb6de61
# 28   3505bf6a20e8d29e83e545784a421bc7  37468c4ffbbbab83f270b8fcecb6de61
# 29   3505bf6a20e8d29e83e545784a421bc7  37468c4ffbbbab83f270b8fcecb6de61
# 30   3505bf6a20e8d29e83e545784a421bc7  37468c4ffbbbab83f270b8fcecb6de61
# 31   3505bf6a20e8d29e83e545784a421bc7  37468c4ffbbbab83f270b8fcecb6de61
# ..                                ...                               ...
# 218  f1866ab43b90dd43adb557fe527177d2  d78657863e0bc2635c13d67785cb8b03
# 219  f1866ab43b90dd43adb557fe527177d2  d78657863e0bc2635c13d67785cb8b03
# 220  f1866ab43b90dd43adb557fe527177d2  d78657863e0bc2635c13d67785cb8b03
# 221  f1866ab43b90dd43adb557fe527177d2  d78657863e0bc2635c13d67785cb8b03
# 222  f1866ab43b90dd43adb557fe527177d2  d78657863e0bc2635c13d67785cb8b03
#
#      stop_sequence stop_id stop_pair stop_primary_direction  \
# 27              18     228  228__106              Eastbound
# 28              18     228  228__106              Eastbound
# 29              18     228  228__106              Eastbound
# 30              18     228  228__106              Eastbound
# 31              18     228  228__106              Eastbound
# ..             ...     ...       ...                    ...
# 218             15     111  111__229             Southbound
# 219             15     111  111__229             Southbound
# 220             15     111  111__229             Southbound
# 221             15     111  111__229             Southbound
# 222             15     111  111__229             Southbound
#
#                    stop_geometry  stop_sequence1  nearest_vp_idx  \
# 27   POINT (-118.44098 34.03014)           18.06         6163925
# 28   POINT (-118.43030 34.03158)           18.11         6163926
# 29   POINT (-118.41947 34.03168)           18.17         6163926
# 30   POINT (-118.40896 34.03007)           18.23         6163927
# 31   POINT (-118.39820 34.02911)           18.28         6163928
# ..                           ...             ...             ...
# 218  POINT (-118.40166 34.02959)           15.74         6164044
# 219  POINT (-118.41225 34.03119)           15.79         6164041
# 220  POINT (-118.42295 34.03187)           15.85         6164109
# 221  POINT (-118.43373 34.03133)           15.91         6164110
# 222  POINT (-118.44436 34.02965)           15.96         6164038
#
#                      vp_idx_trio  \
# 27   [6163924, 6163925, 6163926]
# 28   [6163925, 6163926, 6163927]
# 29   [6163925, 6163926, 6163927]
# 30   [6163926, 6163927, 6163928]
# 31   [6163927, 6163928, 6163929]
# ..                           ...
# 218  [6164043, 6164044, 6164045]
# 219  [6164040, 6164041, 6164042]
# 220  [6164108, 6164109, 6164110]
# 221  [6164109, 6164110, 6164111]
# 222  [6164037, 6164038, 6164039]
#
#                          location_timestamp_local_trio  \
# 27   [2024-03-13T07:22:06.000000, 2024-03-13T07:22:...
# 28   [2024-03-13T07:22:51.000000, 2024-03-13T07:24:...
# 29   [2024-03-13T07:22:51.000000, 2024-03-13T07:24:...
# 30   [2024-03-13T07:24:20.000000, 2024-03-13T07:25:...
# 31   [2024-03-13T07:25:05.000000, 2024-03-13T07:25:...
# ..                                                 ...
# 218  [2024-03-13T14:43:40.000000, 2024-03-13T14:45:...
# 219  [2024-03-13T14:40:42.000000, 2024-03-13T14:42:...
# 220  [2024-03-13T16:19:02.000000, 2024-03-13T16:19:...
# 221  [2024-03-13T16:19:46.000000, 2024-03-13T16:21:...
# 222  [2024-03-13T14:37:30.000000, 2024-03-13T14:38:...
#
#                                         vp_coords_trio
# 27   LINESTRING (-118.44891 34.02792, -118.44260 34...
# 28   LINESTRING (-118.44260 34.02987, -118.42242 34...
# 29   LINESTRING (-118.44260 34.02987, -118.42242 34...
# 30   LINESTRING (-118.42242 34.03169, -118.41077 34...
# 31   LINESTRING (-118.41077 34.03050, -118.39928 34...
# ..                                                 ...
# 218  LINESTRING (-118.40574 34.02985, -118.40142 34...
# 219  LINESTRING (-118.41893 34.03175, -118.41304 34...
# 220  LINESTRING (-118.41968 34.03191, -118.42393 34...
# 221  LINESTRING (-118.42393 34.03187, -118.43489 34...
# 222  LINESTRING (-118.45029 34.02793, -118.43986 34...
#
# [85 rows x 12 columns]

# %% [markdown]
# TODO: probably if it can make it through the first nearest neighbor script, the other scripts will be fine, but some of the `group_cols` will change.
# Still need to test that out.

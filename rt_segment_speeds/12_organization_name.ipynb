# %% [markdown]
# # From `gtfs_dataset_key` to `organization_source_record_id` for open data portal
#
# * Move to what Caltrans is trying to implement: `agency_id`.
# * Our closest equivalent is `organization_source_record_id`
# * Need new Airtable column that reflects this and isn't going to create fanout
# * There are a couple of `gtfs_dataset_key` values that have multiple organizations associated
#    * if it's combined feed (VCTC), it needs to reflect one organization for export
#    * Bay Area combined feed is not used for RT, we are using agency subfeeds already
#    * Foothill Transit / Duarte is another one that should appear as Foothill

# %%
import pandas as pd

from calitp_data_analysis.tables import tbls
from siuba import *

from segment_speed_utils.project_vars import SEGMENT_GCS, analysis_date
# Out:
# /opt/conda/lib/python3.9/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(
# /opt/conda/lib/python3.9/site-packages/google/cloud/bigquery/table.py:43: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas  # type: ignore

# %%
df = pd.read_parquet(
    f"{SEGMENT_GCS}speeds_stop_segments_{analysis_date}",
    columns = ["gtfs_dataset_key", "_gtfs_dataset_name"]
).drop_duplicates().rename(
    columns = {
        "gtfs_dataset_key": "vehicle_positions_gtfs_dataset_key",
        "_gtfs_dataset_name": "vehicle_positions_gtfs_dataset_name",
    }
).reset_index(drop=True)

# %%
date = analysis_date

dim_provider_gtfs_data = (
    tbls.mart_transit_database.dim_provider_gtfs_data()
    >> filter(_._valid_from <= pd.to_datetime(date), 
              _._valid_to >= pd.to_datetime(date))
    >> distinct()
    >> collect()
)

# %%
merge_cols = ["vehicle_positions_gtfs_dataset_key", 
              "vehicle_positions_gtfs_dataset_name"]
m1 = pd.merge(
    df,
    dim_provider_gtfs_data,
    on = merge_cols,
    how = "inner",
)

# %%
col = "vehicle_positions_gtfs_dataset_key"
m1[col].value_counts()
# Out:
# 80e31832b8c72f53603cccacc8a6a798    7
# ffc0b223d9f943ba43042e1c971d435d    4
# a4f6fd5552107e05fe9743ac7cce2c55    4
# db56b50ab86b5f7a4ae2fc2dd9889bbe    3
# 1aec012cf85cb59b80880a01b2d1b1ef    2
#                                    ..
# 80f95367c74099550bc2183071aaec5c    1
# 81d2fa06f6a09cc1de83a9f473cd38db    1
# 8f1995938bd76ab2ad8a23bd71ecb51b    1
# 95352b6a2439549874658b29d4df56e7    1
# ddc9965fcbf3beaba6d2cb40a3e67c1e    1
# Name: vehicle_positions_gtfs_dataset_key, Length: 77, dtype: int64

# %%
dups = m1[m1[col].duplicated()][col].unique().tolist()

# %%
m1[m1[col].isin(dups)][
    merge_cols + 
    [
        "_valid_from", "_valid_to", "_is_current", 
        "regional_feed_type",
        "organization_name", "organization_source_record_id",  
        "service_name", 
        "public_customer_facing_or_regional_subfeed_fixed_route"
    ]
].sort_values(col)
# Out:
#    vehicle_positions_gtfs_dataset_key  \
# 0    00accf770009aafd5dc103ff2eeddb37
# 1    00accf770009aafd5dc103ff2eeddb37
# 12   1aec012cf85cb59b80880a01b2d1b1ef
# 13   1aec012cf85cb59b80880a01b2d1b1ef
# 37   7342e9ab4e268b54f9cce8cc25f11345
# 38   7342e9ab4e268b54f9cce8cc25f11345
# 47   80e31832b8c72f53603cccacc8a6a798
# 46   80e31832b8c72f53603cccacc8a6a798
# 45   80e31832b8c72f53603cccacc8a6a798
# 43   80e31832b8c72f53603cccacc8a6a798
# 42   80e31832b8c72f53603cccacc8a6a798
# 41   80e31832b8c72f53603cccacc8a6a798
# 44   80e31832b8c72f53603cccacc8a6a798
# 54   a2710c46937c4d17f3b41568a2d67f05
# 55   a2710c46937c4d17f3b41568a2d67f05
# 59   a4f6fd5552107e05fe9743ac7cce2c55
# 58   a4f6fd5552107e05fe9743ac7cce2c55
# 57   a4f6fd5552107e05fe9743ac7cce2c55
# 56   a4f6fd5552107e05fe9743ac7cce2c55
# 60   b1066abb2de3f1766e9b1d9f3cab720e
# 61   b1066abb2de3f1766e9b1d9f3cab720e
# 62   b5500483b27d66c91929ace2eeed2001
# 63   b5500483b27d66c91929ace2eeed2001
# 64   be1cafe7dc9530edda16d3982319a189
# 65   be1cafe7dc9530edda16d3982319a189
# 66   c0e3039da063db95ebabd3fe4ee611a4
# 67   c0e3039da063db95ebabd3fe4ee611a4
# 71   db56b50ab86b5f7a4ae2fc2dd9889bbe
# 72   db56b50ab86b5f7a4ae2fc2dd9889bbe
# 73   db56b50ab86b5f7a4ae2fc2dd9889bbe
# 79   ffc0b223d9f943ba43042e1c971d435d
# 80   ffc0b223d9f943ba43042e1c971d435d
# 81   ffc0b223d9f943ba43042e1c971d435d
# 82   ffc0b223d9f943ba43042e1c971d435d
#
#                   vehicle_positions_gtfs_dataset_name  \
# 0   Bay Area 511 Sonoma County Transit Vehicle Pos...
# 1   Bay Area 511 Sonoma County Transit Vehicle Pos...
# 12             Bay Area 511 SolTrans VehiclePositions
# 13             Bay Area 511 SolTrans VehiclePositions
# 37                         Foothill Vehicle Positions
# 38                         Foothill Vehicle Positions
# 47                             VCTC Vehicle Positions
# 46                             VCTC Vehicle Positions
# 45                             VCTC Vehicle Positions
# 43                             VCTC Vehicle Positions
# 42                             VCTC Vehicle Positions
# 41                             VCTC Vehicle Positions
# 44                             VCTC Vehicle Positions
# 54  Bay Area 511 Santa Clara Transit VehiclePositions
# 55  Bay Area 511 Santa Clara Transit VehiclePositions
# 59                        San Diego Vehicle Positions
# 58                        San Diego Vehicle Positions
# 57                        San Diego Vehicle Positions
# 56                        San Diego Vehicle Positions
# 60                     North County Vehicle Positions
# 61                     North County Vehicle Positions
# 62                              OCTA VehiclePositions
# 63                              OCTA VehiclePositions
# 64                          Redding Vehicle Positions
# 65                          Redding Vehicle Positions
# 66                 Bay Area 511 Muni VehiclePositions
# 67                 Bay Area 511 Muni VehiclePositions
# 71                       Sacramento Vehicle Positions
# 72                       Sacramento Vehicle Positions
# 73                       Sacramento Vehicle Positions
# 79                         Humboldt Vehicle Positions
# 80                         Humboldt Vehicle Positions
# 81                         Humboldt Vehicle Positions
# 82                         Humboldt Vehicle Positions
#
#                  _valid_from                        _valid_to  _is_current  \
# 0  2023-03-31 00:00:00+00:00 2023-04-27 23:59:59.999999+00:00        False
# 1  2023-04-05 00:00:00+00:00 2023-04-27 23:59:59.999999+00:00        False
# 12 2023-03-15 00:00:00+00:00 2023-04-27 23:59:59.999999+00:00        False
# 13 2023-03-24 00:00:00+00:00 2023-04-27 23:59:59.999999+00:00        False
# 37 2023-03-14 00:00:00+00:00 2023-04-27 23:59:59.999999+00:00        False
# 38 2023-03-14 00:00:00+00:00 2023-04-27 23:59:59.999999+00:00        False
# 47 2023-03-31 00:00:00+00:00 2023-04-27 23:59:59.999999+00:00        False
# 46 2023-04-06 00:00:00+00:00 2023-04-27 23:59:59.999999+00:00        False
# 45 2023-03-25 00:00:00+00:00 2023-04-27 23:59:59.999999+00:00        False
# 43 2023-03-25 00:00:00+00:00 2023-04-27 23:59:59.999999+00:00        False
# 42 2023-04-06 00:00:00+00:00 2023-04-27 23:59:59.999999+00:00        False
# 41 2023-03-25 00:00:00+00:00 2023-04-27 23:59:59.999999+00:00        False
# 44 2023-03-25 00:00:00+00:00 2023-04-27 23:59:59.999999+00:00        False
# 54 2023-03-31 00:00:00+00:00 2023-04-27 23:59:59.999999+00:00        False
# 55 2023-04-05 00:00:00+00:00 2023-04-27 23:59:59.999999+00:00        False
# 59 2023-04-05 00:00:00+00:00 2023-04-17 23:59:59.999999+00:00        False
# 58 2023-03-28 00:00:00+00:00 2023-04-17 23:59:59.999999+00:00        False
# 57 2023-03-28 00:00:00+00:00 2023-04-27 23:59:59.999999+00:00        False
# 56 2023-03-28 00:00:00+00:00 2023-04-27 23:59:59.999999+00:00        False
# 60 2023-04-05 00:00:00+00:00 2023-04-27 23:59:59.999999+00:00        False
# 61 2023-03-23 00:00:00+00:00 2023-04-27 23:59:59.999999+00:00        False
# 62 2023-04-05 00:00:00+00:00 2023-04-12 23:59:59.999999+00:00        False
# 63 2023-04-05 00:00:00+00:00 2023-04-12 23:59:59.999999+00:00        False
# 64 2023-03-15 00:00:00+00:00 2023-04-27 23:59:59.999999+00:00        False
# 65 2023-03-15 00:00:00+00:00 2023-04-27 23:59:59.999999+00:00        False
# 66 2023-03-25 00:00:00+00:00 2023-04-27 23:59:59.999999+00:00        False
# 67 2023-04-05 00:00:00+00:00 2023-04-27 23:59:59.999999+00:00        False
# 71 2023-03-30 00:00:00+00:00 2023-04-27 23:59:59.999999+00:00        False
# 72 2023-03-30 00:00:00+00:00 2023-04-27 23:59:59.999999+00:00        False
# 73 2023-04-05 00:00:00+00:00 2023-04-27 23:59:59.999999+00:00        False
# 79 2023-03-31 00:00:00+00:00 2023-04-27 23:59:59.999999+00:00        False
# 80 2023-03-28 00:00:00+00:00 2023-04-27 23:59:59.999999+00:00        False
# 81 2023-03-31 00:00:00+00:00 2023-04-27 23:59:59.999999+00:00        False
# 82 2023-03-28 00:00:00+00:00 2023-04-27 23:59:59.999999+00:00        False
#
#         regional_feed_type                            organization_name  \
# 0         Regional Subfeed                           Cloverdale Transit
# 1         Regional Subfeed                                Sonoma County
# 12        Regional Subfeed                        Solano County Transit
# 13        Regional Subfeed              Solano Transportation Authority
# 37                    None                               City of Duarte
# 38                    None                             Foothill Transit
# 47  Combined Regional Feed                            City of Camarillo
# 46  Combined Regional Feed                        City of Thousand Oaks
# 45  Combined Regional Feed                             City of Moorpark
# 43  Combined Regional Feed                           Gold Coast Transit
# 42  Combined Regional Feed     Ventura County Transportation Commission
# 41  Combined Regional Feed                                 City of Ojai
# 44  Combined Regional Feed                          City of Simi Valley
# 54        Regional Subfeed  Santa Clara Valley Transportation Authority
# 55        Regional Subfeed  Santa Clara Valley Transportation Authority
# 59                    None        San Diego Metropolitan Transit System
# 58                    None        San Diego Metropolitan Transit System
# 57                    None              San Diego International Airport
# 56                    None             Flagship Cruises and Events Inc.
# 60                    None                North County Transit District
# 61                    None                North County Transit District
# 62                    None       Orange County Transportation Authority
# 63                    None       Orange County Transportation Authority
# 64                    None                                Shasta County
# 65                    None                   Redding Area Bus Authority
# 66        Regional Subfeed             City and County of San Francisco
# 67        Regional Subfeed             City and County of San Francisco
# 71                    None                       City of Rancho Cordova
# 72                    None         Sacramento Regional Transit District
# 73                    None         Sacramento Regional Transit District
# 79                    None                          Blue Lake Rancheria
# 80                    None                               City of Eureka
# 81                    None                   Humboldt Transit Authority
# 82                    None                               City of Arcata
#
#    organization_source_record_id                                 service_name  \
# 0              recRM3c9Zfaft4V2B                           Cloverdale Transit
# 1              recDupUxInMUgxeiz                        Sonoma County Transit
# 12             reclLbvvKE1V4zsZg                                     SolTrans
# 13             rec7ShjfgRPLU0yjY                               Solano Express
# 37             recZm8PD8WIdcDL0M                               Duarte Transit
# 38             recSqgaa8QiQ8CRjl                             Foothill Transit
# 47             recD4Vzt0EDC3VY7I                       Camarillo Area Transit
# 46             recPJULRJk1Yn824N                        Thousand Oaks Transit
# 45             recojKzQsBzE1hjVu                        Moorpark City Transit
# 43             recS7GnKTcQVX20HE                           Gold Coast Transit
# 42             rec7EN71rsZxDFxZd                               VCTC Intercity
# 41             reckQmUdXUzHFmlVf                                 Ojai Trolley
# 44             rec1ErIn9gG1Isk5W                          Simi Valley Transit
# 54             recC5CT95EufmQCXr                               VTA Light Rail
# 55             recC5CT95EufmQCXr  Santa Clara Valley Transportation Authority
# 59             recZALk4vysuoTVjF        San Diego Metropolitan Transit System
# 58             recZALk4vysuoTVjF                            San Diego Trolley
# 57             recfbLFdDnCxgIfAB                              San Diego Flyer
# 56             rech5YtfjpQvVIBAF                               Coronado Ferry
# 60             recRBcrX4ZvTyvSnm                                    NCTD Rail
# 61             recRBcrX4ZvTyvSnm                                  NCTD BREEZE
# 62             recfma7GNR5lQTTTg                                       OC Bus
# 63             recfma7GNR5lQTTTg       Orange County Transportation Authority
# 64             recx4ZG2lvZb7kGAL                               Burney Express
# 65             recI1fuNpr306H0hw                   Redding Area Bus Authority
# 66             rechaapWbeffO33OX                                     Muni Bus
# 67             rechaapWbeffO33OX                              Muni Metro Rail
# 71             rec43oyrfhtPDdRHj                              Rancho CordoVan
# 72             recX9lccSE1jmjsmG                             SacRT Light Rail
# 73             recX9lccSE1jmjsmG     Sacramento Regional Transit District Bus
# 79             rec0xQaeDukHT3ODl                          Blue Lake Rancheria
# 80             recynxkqEoo9dJEvw                       Eureka Transit Service
# 81             recaa3naoNR4a5RsJ                   Humboldt Transit Authority
# 82             recaaoqEDvwhcmIVT          Arcata and Mad River Transit System
#
#     public_customer_facing_or_regional_subfeed_fixed_route
# 0                                                True
# 1                                                True
# 12                                               True
# 13                                               True
# 37                                               True
# 38                                               True
# 47                                               True
# 46                                               True
# 45                                               True
# 43                                               True
# 42                                               True
# 41                                               True
# 44                                               True
# 54                                               True
# 55                                               True
# 59                                               True
# 58                                               True
# 57                                               True
# 56                                              False
# 60                                               True
# 61                                               True
# 62                                               True
# 63                                               True
# 64                                              False
# 65                                               True
# 66                                               True
# 67                                               True
# 71                                               True
# 72                                               True
# 73                                               True
# 79                                               True
# 80                                               True
# 81                                               True
# 82                                               True

# %%
m1.columns
# Out:
# Index(['vehicle_positions_gtfs_dataset_key',
#        'vehicle_positions_gtfs_dataset_name', 'key',
#        'public_customer_facing_fixed_route',
#        'public_customer_facing_or_regional_subfeed_fixed_route',
#        'organization_key', 'organization_name', 'organization_itp_id',
#        'organization_hubspot_company_record_id', 'organization_ntd_id',
#        'organization_source_record_id', 'service_key', 'service_name',
#        'service_source_record_id', 'gtfs_service_data_customer_facing',
#        'regional_feed_type', 'associated_schedule_gtfs_dataset_key',
#        'schedule_gtfs_dataset_name', 'schedule_source_record_id',
#        'service_alerts_gtfs_dataset_name', 'service_alerts_source_record_id',
#        'vehicle_positions_source_record_id', 'trip_updates_gtfs_dataset_name',
#        'trip_updates_source_record_id', 'schedule_gtfs_dataset_key',
#        'service_alerts_gtfs_dataset_key', 'trip_updates_gtfs_dataset_key',
#        '_valid_from', '_valid_to', '_is_current'],
#       dtype='object')

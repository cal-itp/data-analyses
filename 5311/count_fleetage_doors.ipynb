# %% [markdown]
# # Adding & Calulating Door Data for 5311 Agencies

# %% [markdown]
# ### Script work and analysis for caculating fleet age and doors for agencies
#
# * adding door counts using [Eric Dasmalchi's Notebook](https://github.com/cal-itp/data-analyses/blob/572e255f997e7fa0969c88caf23a7791070ad28a/lossan_validators/lossan_validators.ipynb) count for the known 5311 Agencies
#
#
# `({'bus':2, 'articulated_bus':3,
# 'over_the_road_bus':1,
# 'vintage_historic_trolley':2,
# 'trolleybus':2,
# 'van':1,
# 'cutaway':1,
# 'automobile':1,
# minivan':1,
# 'sport_utility_vehicle:':1,
# 'lrt_stn':6, 'hrt_stn':15,
# 'la_union_stn':40,
# 'commuter_rail_stn':6,
# 'interchange':20, ## interchange is for places like 7th/Metro
# 'ferry_stn':4})`

# %%
import numpy as np
import pandas as pd
from siuba import *
import altair as alt
import altair_saver
from calitp import *
from plotnine import *
import intake
# Out:
# /opt/conda/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.9.1-CAPI-1.14.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.

# %%
from shared_utils import geography_utils
# Out:
# /opt/conda/lib/python3.9/site-packages/google/auth/_default.py:73: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/

# %%
import data_prep

# %%
#df = data_prep.load_grantprojects()
vehicles = data_prep.load_vehiclesdata()
cw1 = pd.read_parquet("test_crosswalk_both.parquet")
# Out:
# /opt/conda/lib/python3.9/site-packages/google/auth/_default.py:73: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
# /home/jovyan/data-analyses/5311/data_prep.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/jovyan/data-analyses/5311/data_prep.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
vehicles.sample()
# Out:
#                                       agency             city state  \
# 4449  San Luis Obispo Council of Governments  San Luis Obispo    CA
#
#      legacy_ntd_id ntd_id                  organization_type  \
# 4449           NaN  90297  MPO, COG or Other Planning Agency
#
#          reporter_type  primary_uza_population  agency_voms  \
# 4449  Reduced Reporter                   59219           13
#
#                 vehicle_type  years_old:  _13_15  _16_20  _21_25  _26_30  \
# 4449  Sports Utility Vehicle         NaN       0       0       0       0
#
#       _31_60  _60+  total_vehicles  average_age_of_fleet__in_years_  \
# 4449       0     0               3                         1.333333
#
#       average_lifetime_miles_per_vehicle  _0_9  _10_12 vehicle_groups
# 4449                          30471.3333     3       0    Automobiles

# %%
vehicles.primary_uza_population.unique()
# Out:
# array([12150996,  3281212,  2956746,    87941,  1664496,  1723634,
#          328454,  1932666,   654628,   615968,   370583,   114237,
#          163703,   345580,   277634,   195861,   523994,   341219,
#          258653,        0,   367260,   308231,   358172,   136969,
#           59219,    83913,    98176,   219454,   133683,   165074,
#           72794,   116719,   130447,   214811,   107672,   117731,
#           78413,   583681,    71772,   125206,    93141,    68738,
#           64078,    87569,    70272,    51509,    99904,    54372,
#           83578,    65088])

# %%
vehicles>>group_by(_.reporter_type)>>summarize(n=_.agency.nunique()) >> arrange(-_.n)
# Out:
#             reporter_type   n
# 1           Full Reporter  82
# 3        Reduced Reporter  76
# 4          Rural Reporter  52
# 2  Reduced Asset Reporter   7
# 0      Asset Subrecipient   1

# %%
cw1.head()
# Out:
#                               agency_x      ntd_id  itp_id
# 41  Fresno County Rural Transit Agency  9R02-91007   117.0
# 58    Eastern Sierra Transit Authority  9R02-91062    99.0
# 61               Kern Regional Transit  9R02-91059   146.0
# 73              Lake Transit Authority  9R02-91053   159.0
# 81         Mendocino Transit Authority  9R02-91047   198.0

# %%
cw1 = cw1.rename(columns={"agency_x": "agency"})

# %%
df = cw1.merge(vehicles, how="outer", on="agency", indicator=True)

# %%
df>>count(_._merge)
# Out:
#        _merge    n
# 0   left_only    0
# 1  right_only  587
# 2        both  120

# %%
df>>filter(_._merge=="right_only")>>count(_.agency)
# Out:
#                                                 agency  n
# 0                                    Access Services    6
# 1    Alameda-Contra Costa Transit District, dba: AC...  8
# 2                            Altamont Corridor Express  5
# 3                       Anaheim Transportation Network  4
# 4                    Antelope Valley Transit Authority  6
# ..                                                 ... ..
# 169                                     Wasco, City of  2
# 170             Western Contra Costa Transit Authority  6
# 171  Yolo County Transportation District, dba: Yolobus  5
# 172                      Yuba-Sutter Transit Authority  4
# 173                                        Yurok Tribe  4
#
# [174 rows x 2 columns]

# %%
df>>filter(_._merge=="both")>>count(_.agency)>>arrange(-_.n)
# Out:
#                                                agency  n
# 24                 Fresno County Rural Transit Agency  6
# 1                      Amador Regional Transit System  5
# 20                       Colusa County Transit Agency  5
# 23                   Eastern Sierra Transit Authority  5
# 33  Mountain Area Regional Transit Authority, dba:...  5
# 38                                      Tehama County  5
# 2                                      City of Arcata  4
# 8                                      City of Dinuba  4
# 22   County of Siskiyou, dba: Siskiyou County Transit  4
# 26                         Humboldt Transit Authority  4
# 27                              Kern Regional Transit  4
# 32                    Morongo Basin Transit Authority  4
# 34                     Nevada County Transit Services  4
# 36                    Redwood Coast Transit Authority  4
# 3                                       City of Arvin  3
# 4                                      City of Auburn  3
# 28                             Lake Transit Authority  3
# 29                      Lassen Transit Service Agency  3
# 31                        Mendocino Transit Authority  3
# 40                                     Trinity County  3
# 42                            Tuolumne County Transit  3
# 0       Alpine County Local Transportation Commission  2
# 7        City of Corcoran, dba: Corcoran Area Transit  2
# 9                        City of Escalon, dba: eTrans  2
# 11                                  City of Guadalupe  2
# 12                                  City of McFarland  2
# 14                                       City of Ojai  2
# 15     City of Rio Vista, dba: Rio Vista Delta Breeze  2
# 16          City of Shafter, dba: Shafter Dial-A-Ride  2
# 18               City of Taft, dba: Taft Area Transit  2
# 25                              Glenn Transit Service  2
# 30  Madera County, dba: Madera County Connection T...  2
# 35            Plumas County Transportation Commission  2
# 37            Sierra County Transportation Commission  2
# 5                             City of California City  1
# 6   City of Chowchilla, dba: Chowchilla Area Transit   1
# 10        City of Eureka, dba: Eureka Transit Service  1
# 13         City of Needles, dba: Needles Area Transit  1
# 17                                    City of Solvang  1
# 19                                   City of Woodlake  1
# 21        County of Shasta Department of Public Works  1
# 39                                    Town of Truckee  1
# 41                         Tulare County Area Transit  1
# 43       Yosemite Area Regional Transportation System  1

# %% [markdown]
# ## Put it in a script:

# %%
def get_age_and_doors(df):   
    d = {
        'Articulated Bus':3,
        'Automobile':1,
        'Automated Guideway Vehicle':2,
        'Automobiles (Service)':0,
        'Bus':2,
        'Cable Car':2,
        'Commuter Rail Locomotive':0,
        'Commuter Rail Passenger Coach':2,
        'Commuter Rail Self-Propelled Passenger Car':2,
        'Cutaway':1,
        'Double Decker Bus':2,
        'Ferryboat':2,
        'Heavy Rail Passenger Car':2,
        'Light Rail Vehicle':2,
        'Minivan':1,
        'Other':0,
        'Over-the-road Bus':1,
        'Sports Utility Vehicle':1,
        'Steel Wheel Vehicles (Service)':0,
        'Trolleybus':2,
        'Trucks and other Rubber Tire Vehicles (Service)':0,
        'Van':1,
        'Vintage Trolley':2
    }

    age = geography_utils.aggregate_by_geography(df, 
                           group_cols = ["agency"],
                           sum_cols = ["total_vehicles", "_0_9","_10_12", "_13_15", "_16_20","_21_25","_26_30","_31_60","_60+"],
                           mean_cols = ["average_age_of_fleet__in_years_", "average_lifetime_miles_per_vehicle"]
                                          ).sort_values(["agency","total_vehicles"], ascending=[True, True])
    age = age.rename(columns={'_60+': '_60plus'})

    older = (age.query('_21_25 != 0 or _26_30 != 0 or _31_60 != 0 or _60plus!=0'))
    older["sum_15plus"] = older[["_16_20","_21_25","_26_30","_31_60","_60plus"]].sum(axis=1)
    older = (older>>select(_.agency, _.sum_15plus))

    age = pd.merge(age, older, on=['agency'], how='left')

    df['doortype'] = (df['vehicle_type'].map(d))
    df['door_count']= df['total_vehicles']*df['doortype']

    doors = geography_utils.aggregate_by_geography(df, 
                           group_cols = ["agency"],
                           sum_cols = ["door_count"],
                           mean_cols = ["door_count"], 
                           nunique_cols = ["vehicle_type"])
    doors.rename(columns={'door_count_x': 'sum_doors', 'door_count_y': 'avg_doors'}, inplace=True)

    agency_counts = pd.merge(age, doors, on=['agency'], how='left')

    return agency_counts

# %%
agency_counts = get_age_and_doors(vehicles)
# Out:
# /tmp/ipykernel_1032/3319872166.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#agency_counts.to_parquet("agency_door_vehicle_counts.parquet")

# %%
agency_counts
# Out:
#                                                 agency  _0_9  _10_12  _13_15  \
# 0                                    Access Services     918       9       2
# 1    Alameda-Contra Costa Transit District, dba: AC...   708     109     103
# 2        Alpine County Local Transportation Commission     1       1       0
# 3                            Altamont Corridor Express     8       4       5
# 4                       Amador Regional Transit System    18       3       1
# ..                                                 ...   ...     ...     ...
# 213             Western Contra Costa Transit Authority    56      12       7
# 214  Yolo County Transportation District, dba: Yolobus    48      21       0
# 215       Yosemite Area Regional Transportation System     9       1       0
# 216                      Yuba-Sutter Transit Authority    48       3       0
# 217                                        Yurok Tribe     6       2       0
#
#      _16_20  _21_25  _26_30  _31_60  _60plus  total_vehicles  \
# 0         0       0       0       0        0             929
# 1       112       8       2       0        0            1042
# 2         0       0       0       0        0               2
# 3        16      10       0       0        0              43
# 4         1       1       0       0        0              24
# ..      ...     ...     ...     ...      ...             ...
# 213       6       1       0       0        0              82
# 214       8       8       0       0        0              85
# 215       0       0       0       0        0              10
# 216       1       0       0       0        0              52
# 217       0       0       0       0        0               8
#
#      average_age_of_fleet__in_years_  average_lifetime_miles_per_vehicle  \
# 0                           5.964027                       154171.849925
# 1                           8.244583                       256035.690100
# 2                           9.000000                            0.000000
# 3                          19.000000                       499140.935350
# 4                           4.065359                            0.000000
# ..                               ...                                 ...
# 213                         7.480000                       223090.097300
# 214                         7.554598                       328419.482767
# 215                         7.600000                            0.000000
# 216                         4.035256                       134500.657200
# 217                         6.000000                            0.000000
#
#      sum_15plus  sum_doors  avg_doors  vehicle_type
# 0           NaN        912     152.00             6
# 1         122.0       1568     196.00             8
# 2           NaN          2       1.00             2
# 3          26.0         58      11.60             5
# 4           2.0         21       4.20             5
# ..          ...        ...        ...           ...
# 213         7.0        117      19.50             6
# 214        16.0        134      26.80             5
# 215         NaN         10      10.00             1
# 216         NaN         73      18.25             4
# 217         NaN         11       2.75             4
#
# [218 rows x 16 columns]

# %% [markdown]
# ## Script work

# %% [markdown]
# ### How many agencies have vehicles over 15 years old?

# %%
# summary of the vehicle counts

# %%
age =geography_utils.aggregate_by_geography(vehicles, 
                       group_cols = ["agency"],
                       sum_cols = ["total_vehicles", "_0_9","_10_12", "_13_15", "_16_20","_21_25","_26_30","_31_60","_60+"],
                       mean_cols = ["average_age_of_fleet__in_years_", "average_lifetime_miles_per_vehicle"]
                                      ).sort_values(["agency","total_vehicles"], ascending=[True, True])

# %%
age = age.rename(columns={'_60+': '_60plus'})

# %%
age
# Out:
#                                                 agency  _0_9  _10_12  _13_15  \
# 2                                    Access Services     918       9       2
# 6    Alameda-Contra Costa Transit District, dba: AC...   708     109     103
# 203      Alpine County Local Transportation Commission     1       1       0
# 67                           Altamont Corridor Express     8       4       5
# 125                     Amador Regional Transit System    18       3       1
# ..                                                 ...   ...     ...     ...
# 47              Western Contra Costa Transit Authority    56      12       7
# 50   Yolo County Transportation District, dba: Yolobus    48      21       0
# 132       Yosemite Area Regional Transportation System     9       1       0
# 66                       Yuba-Sutter Transit Authority    48       3       0
# 173                                        Yurok Tribe     6       2       0
#
#      _16_20  _21_25  _26_30  _31_60  _60plus  total_vehicles  \
# 2         0       0       0       0        0             929
# 6       112       8       2       0        0            1042
# 203       0       0       0       0        0               2
# 67       16      10       0       0        0              43
# 125       1       1       0       0        0              24
# ..      ...     ...     ...     ...      ...             ...
# 47        6       1       0       0        0              82
# 50        8       8       0       0        0              85
# 132       0       0       0       0        0              10
# 66        1       0       0       0        0              52
# 173       0       0       0       0        0               8
#
#      average_age_of_fleet__in_years_  average_lifetime_miles_per_vehicle
# 2                           5.964027                       154171.849925
# 6                           8.244583                       256035.690100
# 203                         9.000000                            0.000000
# 67                         19.000000                       499140.935350
# 125                         4.065359                            0.000000
# ..                               ...                                 ...
# 47                          7.480000                       223090.097300
# 50                          7.554598                       328419.482767
# 132                         7.600000                            0.000000
# 66                          4.035256                       134500.657200
# 173                         6.000000                            0.000000
#
# [218 rows x 12 columns]

# %%
age>>select(_.agency,_.average_age_of_fleet__in_years_)>>arrange(-_.average_age_of_fleet__in_years_)
# Out:
#                                                 agency  \
# 25   Peninsula Corridor Joint Powers Board, dba: Ca...
# 3    City and County of San Francisco, dba: San Fra...
# 8          Santa Clara Valley Transportation Authority
# 4                San Diego Metropolitan Transit System
# 67                           Altamont Corridor Express
# ..                                                 ...
# 26                                 San Joaquin Council
# 157                               City of Bell Gardens
# 199                               Elk Valley Rancheria
# 7                 San Diego Association of Governments
# 40          Riverside County Transportation Commission
#
#      average_age_of_fleet__in_years_
# 25                         28.864771
# 3                          20.247938
# 8                          19.841354
# 4                          19.713625
# 67                         19.000000
# ..                               ...
# 26                          1.034883
# 157                         1.000000
# 199                         1.000000
# 7                           0.783883
# 40                          0.674603
#
# [218 rows x 2 columns]

# %%
print(f"the average fleet age of Rural Operators in California is {age.average_age_of_fleet__in_years_.mean()}")
# Out:
# the average fleet age of Rural Operators in California is 7.0317539832406135

# %%
print(f"there are {(len(age>>filter(_.average_age_of_fleet__in_years_<=5)))} rural operators with an average fleet age less than 5 years in California")
# Out:
# there are 58 rural operators with an average fleet age less than 5 years in California

# %%
print(f"there are {(len(age>>filter(_.average_age_of_fleet__in_years_>=10)))} rural operators with an average fleet age more than 5 years in California")
# Out:
# there are 31 rural operators with an average fleet age more than 5 years in California

# %%
age>>filter(_.average_age_of_fleet__in_years_>=10)>>select(_.agency)
# Out:
#                                                 agency
# 67                           Altamont Corridor Express
# 197                            Chemehuevi Indian Tribe
# 3    City and County of San Francisco, dba: San Fra...
# 167                                 City of Bellflower
# 168                              City of Beverly Hills
# 188                            City of California City
# 97                                    City of Cerritos
# 151       City of Corcoran, dba: Corcoran Area Transit
# 149                                     City of Cudahy
# 215                                 City of El Segundo
# 93                             City of Huntington Park
# 195                                City of Pico Rivera
# 160               City of Ridgecrest, dba: Ridgerunner
# 217                               City of San Fernando
# 214                               City of Sierra Madre
# 211                             City of South El Monte
# 187                                   City of Woodlake
# 154                       Colusa County Transit Agency
# 14                                    Foothill Transit
# 23   Golden Gate Bridge, Highway and Transportation...
# 17                       North County Transit District
# 25   Peninsula Corridor Joint Powers Board, dba: Ca...
# 12   Sacramento Regional Transit District, dba: Sac...
# 4                San Diego Metropolitan Transit System
# 9        San Francisco Bay Area Rapid Transit District
# 126  San Francisco Bay Area Water Emergency Transpo...
# 119    Santa Barbara County Association of Governments
# 8          Santa Clara Valley Transportation Authority
# 31            Santa Cruz Metropolitan Transit District
# 19   Southern California Regional Rail Authority, d...
# 65      University of California, Davis, dba: Unitrans

# %%
older = (age.query('_21_25 != 0 or _26_30 != 0 or _31_60 != 0 or _60plus!=0'))

# %%
print(f"There are {len(older>>count(_.agency))} agencies with vehicles over 15 years old")
# Out:
# There are 36 agencies with vehicles over 15 years old

# %%
older.describe()
# Out:
#               _0_9      _10_12      _13_15      _16_20      _21_25     _26_30  \
# count    36.000000   36.000000   36.000000   36.000000   36.000000  36.000000
# mean    283.166667   58.027778   23.361111   28.694444   16.138889   6.361111
# std     650.194059  134.723948   56.848245   61.278670   40.300410  16.542850
# min       1.000000    0.000000    0.000000    0.000000    0.000000   0.000000
# 25%      21.000000    4.750000    1.000000    0.750000    1.000000   0.000000
# 50%      52.000000   19.500000    6.500000    3.000000    2.000000   0.500000
# 75%     178.000000   53.250000   16.000000   32.750000    8.500000   1.250000
# max    3668.000000  798.000000  324.000000  283.000000  218.000000  84.000000
#
#            _31_60    _60plus  total_vehicles  average_age_of_fleet__in_years_  \
# count   36.000000  36.000000       36.000000                        36.000000
# mean    19.388889   2.305556      437.444444                        10.537363
# std     82.316906  12.644184      919.584951                         5.521069
# min      0.000000   0.000000        3.000000                         3.439955
# 25%      0.000000   0.000000       41.500000                         6.996267
# 50%      0.000000   0.000000       84.500000                         8.726812
# 75%      1.000000   0.000000      384.250000                        12.676372
# max    479.000000  76.000000     5142.000000                        28.864771
#
#        average_lifetime_miles_per_vehicle
# count                        3.600000e+01
# mean                         2.868121e+05
# std                          2.580767e+05
# min                          0.000000e+00
# 25%                          1.490488e+05
# 50%                          2.533389e+05
# 75%                          3.443827e+05
# max                          1.293594e+06

# %%
older["sum_15plus"] = older[["_16_20","_21_25","_26_30","_31_60","_60plus"]].sum(axis=1)
# Out:
# /tmp/ipykernel_888/2365723039.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
older>>select(_.agency, _.sum_15plus)>>arrange(-_.sum_15plus)
# Out:
#                                                 agency  sum_15plus
# 9        San Francisco Bay Area Rapid Transit District         624
# 3    City and County of San Francisco, dba: San Fra...         385
# 0    Los Angeles County Metropolitan Transportation...         352
# 8          Santa Clara Valley Transportation Authority         319
# 25   Peninsula Corridor Joint Powers Board, dba: Ca...         217
# 19   Southern California Regional Rail Authority, d...         149
# 6    Alameda-Contra Costa Transit District, dba: AC...         122
# 12   Sacramento Regional Transit District, dba: Sac...         114
# 17                       North County Transit District         100
# 4                San Diego Metropolitan Transit System          60
# 31            Santa Cruz Metropolitan Transit District          47
# 67                           Altamont Corridor Express          26
# 50   Yolo County Transportation District, dba: Yolobus          16
# 45          City of Modesto, dba: Modesto Area Express          15
# 23   Golden Gate Bridge, Highway and Transportation...          12
# 46         Livermore / Amador Valley Transit Authority           8
# 16                                           Omnitrans           7
# 47              Western Contra Costa Transit Authority           7
# 92       City of Simi Valley, dba: Simi Valley Transit           5
# 28               San Joaquin Regional Transit District           5
# 136   County of Siskiyou, dba: Siskiyou County Transit           4
# 126  San Francisco Bay Area Water Emergency Transpo...           4
# 51                        City of Gardena, dba: GTrans           3
# 100            City of Petaluma, dba: Petaluma Transit           3
# 125                     Amador Regional Transit System           2
# 24   Central Contra Costa Transit Authority, dba: C...           2
# 197                            Chemehuevi Indian Tribe           2
# 116  City of El Monte, dba: City of El Monte Transp...           2
# 30       City of Montebello, dba: Montebello Bus Lines           2
# 81                         Mendocino Transit Authority           2
# 27                                   Paratransit, Inc.           2
# 65      University of California, Davis, dba: Unitrans           2
# 211                             City of South El Monte           1
# 71                  El Dorado County Transit Authority           1
# 164                      Lassen Transit Service Agency           1
# 78                          Redding Area Bus Authority           1

# %% [markdown]
# * Nine agencies have more than 100 vehicles older than 15 years

# %%
older = (older>>select(_.agency, _.sum_15plus))

# %%
age = pd.merge(age, older, on=['agency'], how='left')

# %%
age
# Out:
#                                                 agency  _0_9  _10_12  _13_15  \
# 0                                    Access Services     918       9       2
# 1    Alameda-Contra Costa Transit District, dba: AC...   708     109     103
# 2        Alpine County Local Transportation Commission     1       1       0
# 3                            Altamont Corridor Express     8       4       5
# 4                       Amador Regional Transit System    18       3       1
# ..                                                 ...   ...     ...     ...
# 213             Western Contra Costa Transit Authority    56      12       7
# 214  Yolo County Transportation District, dba: Yolobus    48      21       0
# 215       Yosemite Area Regional Transportation System     9       1       0
# 216                      Yuba-Sutter Transit Authority    48       3       0
# 217                                        Yurok Tribe     6       2       0
#
#      _16_20  _21_25  _26_30  _31_60  _60plus  total_vehicles  \
# 0         0       0       0       0        0             929
# 1       112       8       2       0        0            1042
# 2         0       0       0       0        0               2
# 3        16      10       0       0        0              43
# 4         1       1       0       0        0              24
# ..      ...     ...     ...     ...      ...             ...
# 213       6       1       0       0        0              82
# 214       8       8       0       0        0              85
# 215       0       0       0       0        0              10
# 216       1       0       0       0        0              52
# 217       0       0       0       0        0               8
#
#      average_age_of_fleet__in_years_  average_lifetime_miles_per_vehicle  \
# 0                           5.964027                       154171.849925
# 1                           8.244583                       256035.690100
# 2                           9.000000                            0.000000
# 3                          19.000000                       499140.935350
# 4                           4.065359                            0.000000
# ..                               ...                                 ...
# 213                         7.480000                       223090.097300
# 214                         7.554598                       328419.482767
# 215                         7.600000                            0.000000
# 216                         4.035256                       134500.657200
# 217                         6.000000                            0.000000
#
#      sum_15plus
# 0           NaN
# 1         122.0
# 2           NaN
# 3          26.0
# 4           2.0
# ..          ...
# 213         7.0
# 214        16.0
# 215         NaN
# 216         NaN
# 217         NaN
#
# [218 rows x 13 columns]

# %% [markdown]
# ### Get a count of doors

# %%
vehicles.sample()
# Out:
#                                          agency       city state  \
# 2794  Imperial County Transportation Commission  El Centro    CA
#
#      legacy_ntd_id ntd_id                                  organization_type  \
# 2794          9226  90226  Independent Public Agency or Authority of Tran...
#
#       reporter_type  primary_uza_population  agency_voms vehicle_type  \
# 2794  Full Reporter                  107672           28      Cutaway
#
#       years_old:  _13_15  _16_20  _21_25  _26_30  _31_60  _60+  \
# 2794         NaN       0       0       0       0       0     0
#
#       total_vehicles  average_age_of_fleet__in_years_  \
# 2794              26                         3.807692
#
#       average_lifetime_miles_per_vehicle  _0_9  _10_12 vehicle_groups  \
# 2794                         115903.7308    26       0           Vans
#
#       doortype  door_count
# 2794         1          26

# %%
vehicles>>count(_.vehicle_type)>>arrange(-_.n)
# Out:
#                                        vehicle_type    n
# 9                                           Cutaway  170
# 4                                               Bus  133
# 20  Trucks and other Rubber Tire Vehicles (Service)   94
# 3                             Automobiles (Service)   79
# 21                                              Van   64
# 14                                          Minivan   63
# 16                                Over-the-road Bus   24
# 0                                   Articulated Bus   16
# 2                                        Automobile   11
# 17                           Sports Utility Vehicle   10
# 18                   Steel Wheel Vehicles (Service)    9
# 13                               Light Rail Vehicle    6
# 6                          Commuter Rail Locomotive    4
# 7                     Commuter Rail Passenger Coach    4
# 10                                Double Decker Bus    4
# 11                                        Ferryboat    4
# 8        Commuter Rail Self-Propelled Passenger Car    2
# 12                         Heavy Rail Passenger Car    2
# 22                                  Vintage Trolley    2
# 1                        Automated Guideway Vehicle    1
# 5                                         Cable Car    1
# 15                                            Other    1
# 19                                       Trolleybus    1

# %%
#counting the number of doors on each individual vehicle. 
d = {
    'Articulated Bus':3,
    'Automobile':1,
    'Automated Guideway Vehicle':2,
    'Automobiles (Service)':0,
    'Bus':2,
    'Cable Car':2,
    'Commuter Rail Locomotive':0,
    'Commuter Rail Passenger Coach':2,
    'Commuter Rail Self-Propelled Passenger Car':2,
    'Cutaway':1,
    'Double Decker Bus':2,
    'Ferryboat':2,
    'Heavy Rail Passenger Car':2,
    'Light Rail Vehicle':2,
    'Minivan':1,
    'Other':0,
    'Over-the-road Bus':1,
    'Sports Utility Vehicle':1,
    'Steel Wheel Vehicles (Service)':0,
    'Trolleybus':2,
    'Trucks and other Rubber Tire Vehicles (Service)':0,
    'Van':1,
    'Vintage Trolley':2
}

# dictionary = {
#     'Articulated Bus':'articulated_bus',
#     'Automobiles':'automobile',
#     'Automated Guideway Vehicle':'automated_guideway_vehicle',
#     'Automobiles (Service)':'automobile_service',
#     'Bus':'bus',
#     'Cable Car':'cable_car',
#     'Commuter Rail Locomotive':'commuter_rail_locomotive',
#     'Commuter Rail Passenger Coach':'commuter_rail_passenger_coach',
#     'Commuter Rail Self-Propelled Passenger Car':'commuter_rail_selfp_passenger_coach',
#     'Cutaway':'cutaway',
#     'Double Decker Bus':'double_decker_bus',
#     'Ferryboat':'ferryboat',
#     'Heavy Rail Passenger Car':'heavy_rail_passenger_car',
#     'Light Rail Vehicle':'light_rail_vehicle',
#     'Minivan':'minivan',
#     'Other':'other',
#     'Over-the-road Bus':'over_the_road_bus',
#     'Sports Utility Vehicle':'sport_utility_vehicle',
#     'Steel Wheel Vehicles (Service)':'steel_wheel_vehicles_service',
#     'Trolleybus':'trolleybus',
#     'Trucks and other Rubber Tire Vehicles (Service)':'trucks_and_other_rubber_tire_vehicles_service',
#     'Van':'van',
#     'Vintage Trolley':'vintage_historic_trolley'
# }

# %%
vehicles['doortype'] = (vehicles['vehicle_type'].map(d))

# %%
#pd.to_numeric(vehicles['doortype'])

# %%
vehicles['door_count']= vehicles['total_vehicles']*vehicles['doortype']

# %%
vehicles.sample()
# Out:
#                       agency        city state legacy_ntd_id      ntd_id  \
# 2728  Lake Transit Authority  Lower Lake    CA      9R02-001  9R02-91053
#
#                                       organization_type   reporter_type  \
# 2728  Independent Public Agency or Authority of Tran...  Rural Reporter
#
#       primary_uza_population  agency_voms vehicle_type  years_old:  _13_15  \
# 2728                       0           29      Minivan         NaN       0
#
#       _16_20  _21_25  _26_30  _31_60  _60+  total_vehicles  \
# 2728       0       0       0       0     0               4
#
#       average_age_of_fleet__in_years_  average_lifetime_miles_per_vehicle  \
# 2728                              4.0                                 0.0
#
#       _0_9  _10_12 vehicle_groups  doortype  door_count
# 2728     4       0           Vans         1           4

# %%
doors = geography_utils.aggregate_by_geography(vehicles, 
                       group_cols = ["agency"],
                       sum_cols = ["door_count"],
                       mean_cols = ["door_count"], 
                       nunique_cols = ["vehicle_type"])
doors.rename(columns={'door_count_x': 'sum_doors', 'door_count_y': 'avg_doors'}, inplace=True)

# %%
doors.sample(5)
# Out:
#                                                 agency  sum_doors  avg_doors  \
# 94   Mountain Area Regional Transit Authority, dba:...         39        7.8
# 125                     Amador Regional Transit System         21        4.2
# 119    Santa Barbara County Association of Governments         17       17.0
# 121                    Morongo Basin Transit Authority         56       14.0
# 187                                   City of Woodlake          3        3.0
#
#      vehicle_type
# 94              5
# 125             5
# 119             1
# 121             4
# 187             1

# %% [markdown]
# ### Adding dfs together

# %%
agency_counts = pd.merge(age, doors, on=['agency'], how='left')

# %%
agency_counts
# Out:
#                                                 agency  _0_9  _10_12  _13_15  \
# 0                                    Access Services     918       9       2
# 1    Alameda-Contra Costa Transit District, dba: AC...   708     109     103
# 2        Alpine County Local Transportation Commission     1       1       0
# 3                            Altamont Corridor Express     8       4       5
# 4                       Amador Regional Transit System    18       3       1
# ..                                                 ...   ...     ...     ...
# 213             Western Contra Costa Transit Authority    56      12       7
# 214  Yolo County Transportation District, dba: Yolobus    48      21       0
# 215       Yosemite Area Regional Transportation System     9       1       0
# 216                      Yuba-Sutter Transit Authority    48       3       0
# 217                                        Yurok Tribe     6       2       0
#
#      _16_20  _21_25  _26_30  _31_60  _60plus  total_vehicles  \
# 0         0       0       0       0        0             929
# 1       112       8       2       0        0            1042
# 2         0       0       0       0        0               2
# 3        16      10       0       0        0              43
# 4         1       1       0       0        0              24
# ..      ...     ...     ...     ...      ...             ...
# 213       6       1       0       0        0              82
# 214       8       8       0       0        0              85
# 215       0       0       0       0        0              10
# 216       1       0       0       0        0              52
# 217       0       0       0       0        0               8
#
#      average_age_of_fleet__in_years_  average_lifetime_miles_per_vehicle  \
# 0                           5.964027                       154171.849925
# 1                           8.244583                       256035.690100
# 2                           9.000000                            0.000000
# 3                          19.000000                       499140.935350
# 4                           4.065359                            0.000000
# ..                               ...                                 ...
# 213                         7.480000                       223090.097300
# 214                         7.554598                       328419.482767
# 215                         7.600000                            0.000000
# 216                         4.035256                       134500.657200
# 217                         6.000000                            0.000000
#
#      sum_15plus  sum_doors  avg_doors  vehicle_type
# 0           NaN        912     152.00             6
# 1         122.0       1568     196.00             8
# 2           NaN          2       1.00             2
# 3          26.0         58      11.60             5
# 4           2.0         21       4.20             5
# ..          ...        ...        ...           ...
# 213         7.0        117      19.50             6
# 214        16.0        134      26.80             5
# 215         NaN         10      10.00             1
# 216         NaN         73      18.25             4
# 217         NaN         11       2.75             4
#
# [218 rows x 16 columns]

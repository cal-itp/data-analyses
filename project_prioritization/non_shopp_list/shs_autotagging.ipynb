# %% [markdown]
# ## Autotagging projects
# * Who is the lead agency?
#     * Agency in this project = the entity who is receiving funding for this project.
# * Is this project on or off the SHS or both?
# * Create a sentence to summarize this.

# %%
import pandas as pd

# Settings
pd.options.display.max_columns = 100
pd.set_option("display.max_rows", 100)
pd.set_option("display.max_colwidth", None)
pd.options.display.float_format = "{:,.2f}".format

GCS_FILE_PATH = "gs://calitp-analytics-data/data-analyses/project_prioritization/"
FILE = "fake_data.xlsx"

# My utilities
import _shs_tagging_utils
from calitp import *
# Out:
# /opt/conda/lib/python3.10/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.10.3-CAPI-1.16.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.

# %%
# String manipulation
import re
from collections import Counter

import matplotlib.pyplot as plt  # plot package
import seaborn as sns  # statist graph package
import wordcloud  # will use for the word cloud plot
from nltk import ngrams
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
from wordcloud import (  # optional to filter out the stopwords
    STOPWORDS,
    ImageColorGenerator,
    WordCloud,
)

# %% [markdown]
# ### Preliminary Clean Up

# %%
# Read in file
df = to_snakecase(pd.read_excel(f"{GCS_FILE_PATH}{FILE}", sheet_name="fake"))

# %%
# Subset to columns I want.
df2 = df[
    [
        "project_name",
        "lead_agency",
        "project_description",
        "primary_mode",
        "secondary_mode_s",
        "shs_capacity_increase_detail",
        "route",
        
    ]
]

# %%
# Fill NA values in Route with None
df2.route = df2.route.fillna('None')
# Out:
# /tmp/ipykernel_1384/594308062.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2.route.value_counts().head()
# Out:
# Off     251
# None    243
# 005      32
# 099      26
# 010      20
# Name: route, dtype: int64

# %% [markdown]
# #### Count Combos

# %%
# Count combos
combos = (
    df2.groupby(["primary_mode", "secondary_mode_s", "shs_capacity_increase_detail"])
    .size()
    .reset_index()
    .rename(columns={0: "count"})
)

# %%
f"Total of {len(combos)} different combinations."
# Out:
# 'Total of 190 different combinations.'

# %%
# Find most commmon combos
combos.sort_values(["count"], ascending=False).head()
# Out:
#          primary_mode secondary_mode_s shs_capacity_increase_detail  count
# 171  Rail (Passenger)             None                         None    111
# 78            Highway             None         General Purpose Lane     62
# 10    Bike/Pedestrian             None                         None     57
# 37     Grade Crossing             None                         None     29
# 164    Rail (Freight)             None                         None     28

# %% [markdown]
# #### Count "None" Values for each column
# * Around 2/3 of values are none in secondary_mode & SHS.
# * Around 1/3 of values are none for lead agencies.

# %%
# How many none values are in the three columns
for i in [
    "primary_mode",
    "secondary_mode_s",
    "shs_capacity_increase_detail",
    "lead_agency",
    "project_description",
    "route"
]:
    print((len((df2.loc[df2[i] == "None"])) / len(df2) * 100))
# Out:
# 0.13458950201884254
# 66.21803499327052
# 62.0457604306864
# 31.090174966352624
# 6.191117092866756
# 32.70524899057873

# %% [markdown]
# ### Are values in a column "highway related?"
# * Search through primary mode, secondary mode, and SHS to see if they have highway-adjacent tags before searching through project descriptions.

# %%
def tagging_columns(
    df,
    tagging_col: str,
    new_col: str,
    keyword_list: list,
    true_keyword: str,
    false_keyword: str,
):
    """
    Search through a column for keywords.

    Args
    df: the dataframe.
    tagging_col (str): the column to search for the appearance of keywords.
    new_col (str): input whether or not the keyword was found.
    keyword_list (list): list of keywords to search through.
    true_keyword (str): replace "true" with a phrase that is more detailed.
    false_keyword (str): same as above, but with false.

    Returns: a dataframe with a new column stating whether
    the keyword(s) were found or not.
    """
    # Delinate items in keywords list using |.
    keywords = f"({'|'.join(keyword_list)})"

    # Lower the strings + strip excess white spaces.
    df[tagging_col] = df[tagging_col].str.lower().str.strip()

    # Create a new column that captures whether or not the keyword appears
    # Using str contains so interchange (new) and interchange (modifying) will appear.
    df["keyword_appears_bool"] = df[tagging_col].str.contains(keywords)

    # Function to categorize whether keyword was found.
    def keyword_found(row):
        if row["keyword_appears_bool"] == True:
            return true_keyword
        else:
            return false_keyword

    # Apply function and save results in a new column.
    df[new_col] = df.apply(lambda x: keyword_found(x), axis=1)

    # IF the original column wasn't populated and just says "none", replace the value in the
    # new column to accurately reflect this.
    df.loc[(df[tagging_col] == "none"), new_col] = "none"

    # Drop keyword col.
    df = df.drop(columns=["keyword_appears_bool"])

    return df

# %%
# Search through primary mode.
df3 = tagging_columns(
    df2,
    "primary_mode",
    "primary_mode_SHS",
    [
        "highway",
        "its",
        "interchange",
        "separation",
    ],
    "highway related",
    "not highway related",
)
# Out:
# /tmp/ipykernel_1384/4108280031.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /tmp/ipykernel_1384/4108280031.py:31: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
# /tmp/ipykernel_1384/4108280031.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /tmp/ipykernel_1384/4108280031.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Preview that this is correct
df3[["primary_mode", "primary_mode_SHS"]].drop_duplicates()
# Out:
#                    primary_mode     primary_mode_SHS
# 0              complete streets  not highway related
# 1               bike/pedestrian  not highway related
# 2                       transit  not highway related
# 3                       highway      highway related
# 5                           its      highway related
# 10            interchange (new)      highway related
# 12                       bridge  not highway related
# 14                          zev  not highway related
# 26                local roadway  not highway related
# 30   interchange (modification)      highway related
# 43             rail (passenger)  not highway related
# 56       interchange (widening)      highway related
# 64                         port  not highway related
# 75               grade crossing  not highway related
# 92                   roundabout  not highway related
# 186               truck parking  not highway related
# 305            grade separation      highway related
# 316              rail (freight)  not highway related
# 742                        none                 none

# %%
# Search through secondary mode.
df3 = tagging_columns(
    df3,
    "secondary_mode_s",
    "secondary_mode_SHS",
    ["highway", "lane", "interchange", "its", "separation"],
    "highway related",
    "not highway related",
)
# Out:
# /tmp/ipykernel_1384/4108280031.py:31: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.

# %%
# Preview
df3[["secondary_mode_s", "secondary_mode_SHS"]].drop_duplicates()
# Out:
#                                                                                       secondary_mode_s  \
# 0                                                                                      bike/pedestrian
# 1                                                                                                 none
# 2                                                                                              highway
# 4                                                                    bike/pedestrian\ncomplete streets
# 5                                                                                                  its
# 7                                                                                                  zev
# 12                                                                                              bridge
# 13                                                                                    complete streets
# 18                                                                             bike/pedestrian\nbridge
# 19                                                     bike/pedestrian\ncomplete streets\nits\ntransit
# 36                                                                               complete streets\nits
# 38                                                          bike/pedestrian\ncomplete streets\ntransit
# 39                                                                                          roundabout
# 49                                                                 grade separation\ninterchange (new)
# 51                                                                                bike/pedestrian\nits
# 60                                                                            bike/pedestrian\nhighway
# 74                                                                       bike/pedestrian\nits\ntransit
# 83                                                          bike/pedestrian\ncomplete streets\nhighway
# 85                                                         bike/pedestrian\ninterchange (modification)
# 88                                                                                             transit
# 110                                                                     bike/pedestrian\nlocal roadway
# 116                   bike/pedestrian\ncomplete streets\ngrade crossing\nport\nrail (freight)\ntransit
# 122                                                                                               cvef
# 129                                                bike/pedestrian\ncomplete streets\nrail (passenger)
# 131                                           bike/pedestrian\ngrade crossing\nrail (freight)\ntransit
# 133                                      bike/pedestrian\ngrade crossing\nits\nrail (freight)\ntransit
# 140                                                                         highway\nits\ntransit\nzev
# 149  bike/pedestrian\ncomplete streets\ngrade crossing\nits\nrail (freight)\nrail (passenger)\ntransit
# 152                                                                                  wildlife crossing
# 161                                           bike/pedestrian\ncomplete streets\nhighway\nits\ntransit
# 237                                                                           bike/pedestrian\ntransit
# 256                                                          bike/pedestrian\nbridge\ncomplete streets
# 278                                                                          rail (passenger)\ntransit
# 291                                                                                      local roadway
# 295                                                                               bike/pedestrian\nzev
# 306                         bike/pedestrian\ncomplete streets\ngrade crossing\nhighway\nrail (freight)
# 307                                                bike/pedestrian\ncomplete streets\nhighway\ntransit
# 314                                                            grade crossing\nhighway\nrail (freight)
# 320                                                                            grade crossing\nhighway
# 332                                                    bike/pedestrian\ngrade crossing\nrail (freight)
# 334                                                                                           its\nzev
# 352                                                                                     rail (freight)
# 367                       bike/pedestrian\ncomplete streets\nrail (freight)\nrail (passenger)\ntransit
# 378                                                                                       highway\nzev
# 383                                                                                      truck parking
# 394                                                                  bike/pedestrian\nrail (passenger)
# 467                                                                                       highway\nits
# 469              bike/pedestrian\ncomplete streets\ngrade crossing\nits\nport\nrail (freight)\ntransit
# 486                                                                          complete streets\nhighway
# 516                                                                                       its\ntransit
# 518                                                                                               port
# 537                                                                                   rail (passenger)
# 664                                                                                   grade separation
#
#       secondary_mode_SHS
# 0    not highway related
# 1                   none
# 2        highway related
# 4    not highway related
# 5        highway related
# 7    not highway related
# 12   not highway related
# 13   not highway related
# 18   not highway related
# 19       highway related
# 36       highway related
# 38   not highway related
# 39   not highway related
# 49       highway related
# 51       highway related
# 60       highway related
# 74       highway related
# 83       highway related
# 85       highway related
# 88   not highway related
# 110  not highway related
# 116  not highway related
# 122  not highway related
# 129  not highway related
# 131  not highway related
# 133      highway related
# 140      highway related
# 149      highway related
# 152  not highway related
# 161      highway related
# 237  not highway related
# 256  not highway related
# 278  not highway related
# 291  not highway related
# 295  not highway related
# 306      highway related
# 307      highway related
# 314      highway related
# 320      highway related
# 332  not highway related
# 334      highway related
# 352  not highway related
# 367  not highway related
# 378      highway related
# 383  not highway related
# 394  not highway related
# 467      highway related
# 469      highway related
# 486      highway related
# 516      highway related
# 518  not highway related
# 537  not highway related
# 664      highway related

# %%
# Search through SHS Capacity Detail.
df3 = tagging_columns(
    df3,
    "shs_capacity_increase_detail",
    "shs_capacity_increase_detail_SHS",
    ["highway", "lane", "interchange"],
    "highway related",
    "not highway related",
)
# Out:
# /tmp/ipykernel_1384/4108280031.py:31: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.

# %%
df3[
    [
        "shs_capacity_increase_detail",
        "shs_capacity_increase_detail_SHS",
    ]
].drop_duplicates()
# Out:
#                                                   shs_capacity_increase_detail  \
# 0                                                                         none
# 3                                                               auxiliary lane
# 6                                                         general purpose lane
# 8                                             transit/bus-only lane (addition)
# 10                                                           interchange (new)
# 27                                                                managed lane
# 44                                                   managed lane (conversion)
# 45                                                   express lane (conversion)
# 51                                     auxiliary lane\nmanaged lane (addition)
# 52                                                      managed lanes addition
# 56                                                      interchange (widening)
# 65                                                  interchange (modification)
# 78                                                                express lane
# 83                                                          new connector road
# 106                                                    express lane (addition)
# 124                         express lane (addition)\nexpress lane (conversion)
# 137                               general purpose lane\ninterchange (widening)
# 156                                            auxiliary lane\nbus on shoulder
# 157                auxiliary lane\nbus on shoulder\ninterchange (modification)
# 158                                    general purpose lane\ninterchange (new)
# 224                                     auxiliary lane\ninterchange (widening)
# 250                           general purpose lane\ninterchange (modification)
# 251                                 auxiliary lane\ninterchange (modification)
# 260                                                              local roadway
# 268                                       auxiliary lane\ngeneral purpose lane
# 287                 general purpose lane\ninterchange (widening)\nmanaged lane
# 298                                  auxiliary lane\nbridge\ninterchange (new)
# 299                                                            truck-only lane
# 306                                         general purpose lane\nmanaged lane
# 341  general purpose lane\nmanaged lane (addition)\ntruck-only lane (addition)
# 353                      auxiliary lane\ninterchange (widening)\nlocal roadway
# 360                                       interchange (widening)\nmanaged lane
# 376                                          auxiliary lane\ninterchange (new)
# 378                                    auxiliary lane\nexpress lane (addition)
# 384                                                        truck climbing lane
# 423                           auxiliary lane\ninterchange (new)\nlocal roadway
# 426               auxiliary lane\ngeneral purpose lane\ninterchange (widening)
# 428                                  interchange (modification)\nlocal roadway
# 451                                                    managed lane (addition)
# 470                                        auxiliary lane\ntruck climbing lane
# 484                                  general purpose lane\ntruck climbing lane
# 684                                                 truck-only lane (addition)
#
#     shs_capacity_increase_detail_SHS
# 0                               none
# 3                    highway related
# 6                    highway related
# 8                    highway related
# 10                   highway related
# 27                   highway related
# 44                   highway related
# 45                   highway related
# 51                   highway related
# 52                   highway related
# 56                   highway related
# 65                   highway related
# 78                   highway related
# 83               not highway related
# 106                  highway related
# 124                  highway related
# 137                  highway related
# 156                  highway related
# 157                  highway related
# 158                  highway related
# 224                  highway related
# 250                  highway related
# 251                  highway related
# 260              not highway related
# 268                  highway related
# 287                  highway related
# 298                  highway related
# 299                  highway related
# 306                  highway related
# 341                  highway related
# 353                  highway related
# 360                  highway related
# 376                  highway related
# 378                  highway related
# 384                  highway related
# 423                  highway related
# 426                  highway related
# 428                  highway related
# 451                  highway related
# 470                  highway related
# 484                  highway related
# 684                  highway related

# %% [markdown]
# ### Check Out None Values
# * As seen above, Secondary Mode & SHS Detail are missing 2/3 of their values.
# * However, primary mode is almost complete filled out.
# * Evaluate how "complete" each project/row is for these 3 columns
#     * 45% of rows have one none value, 41% have 2...

# %%
# https://stackoverflow.com/questions/60446836/highlight-text-string-type-in-pandas-df-matching-text
# https://stackoverflow.com/questions/73839250/count-number-of-occurrences-of-text-over-row-python-pandas
# Count number of times "none" appears.
df3["none_count"] = df3[
    ["shs_capacity_increase_detail_SHS", "secondary_mode_SHS", "primary_mode_SHS"]
].apply(
    lambda x: sum([i.lower().count("none") for i in x if isinstance(i, str)]), axis=1
)

# %%
df3[["shs_capacity_increase_detail_SHS", "secondary_mode_SHS", "primary_mode_SHS","none_count"]].sample(3)
# Out:
#     shs_capacity_increase_detail_SHS   secondary_mode_SHS  \
# 42                              none  not highway related
# 293                  highway related                 none
# 205                  highway related                 none
#
#         primary_mode_SHS  none_count
# 42   not highway related           1
# 293      highway related           1
# 205      highway related           1

# %%
(df3.none_count.value_counts() / len(df3)) * 100
# Out:
# 1   45.36
# 2   41.32
# 0   13.19
# 3    0.13
# Name: none_count, dtype: float64

# %% [markdown]
# ### 1st Round of Tagging
# * Determine who is the lead agency.
# * Using the three categorical cols, try to tag whether this project is on/off the SHS.

# %%
# Tag if the lead agency is Caltrans or a partner or unknown.
def CT_or_partner(row):
    # If partner is none, return Unknown.
    if row.lead_agency == "None":
        return "unknown"
        # If only Caltrans, return Caltrans
    if row.lead_agency == "Caltrans":
        return "Caltrans"
        # Everything else is a partner agency
    else:
        return "a partner"

# %%
# Apply the function
df3["caltrans_or_partner"] = df3.apply(CT_or_partner, axis=1)

# %%
def tagging_primary_secondary_SHS(df):

    """
    After applying the tagging_columns() to the three categorical columns (SHS Capacity Increase Detail,
    Secondary Mode SHS, and Primary Mode SHS), use the new true/false columsn
    to determine whether or not projects are on/off the SHS. If there are too many 'none' values,
    skip over tagging to combing through project descriptions.

    Args
    df: the dataframe.

    Returns: a dataframe tagging projects.
    """
    # Count number of times "none" appears for the three categorical columns by each project/row.
    # https://stackoverflow.com/questions/73839250/count-number-of-occurrences-of-text-over-row-python-pandas
    df["none_count"] = df[
        ["shs_capacity_increase_detail_SHS", "secondary_mode_SHS", "primary_mode_SHS"]
    ].apply(
        lambda x: sum([i.lower().count("none") for i in x if isinstance(i, str)]),
        axis=1,
    )

    # Begin tagging based on the three columns
    def on_SHS(row):
        
        # If primary mode is highway related, route col says "Off", and one other column is not highway related: not on the SHS
        if (row.primary_mode_SHS == "not highway related") and (row.route == "Off") and ((row.shs_capacity_increase_detail_SHS == "not highway related")|(row.secondary_mode_SHS == "not highway related")):
            return "not on the SHS"
        
         # If primary mode is highway related, route col is NOT off or none, and one other column is highway related: on the SHS
        elif (row.primary_mode_SHS == "highway related") and ((row.route != "Off")|(row.route != "None")) and ((row.shs_capacity_increase_detail_SHS == "highway related")|(row.secondary_mode_SHS == "highway related")):
            return "on the SHS"
        
        # Everything else: 
        else:
            return "not enough info"

    # Apply the function
    df["on_off_shs_category_tags"] = df.apply(on_SHS, axis=1)

    return df

# %%
df4 = tagging_primary_secondary_SHS(df3)

# %%
# Check value counts.
(df4.caltrans_or_partner.value_counts() / len(df4)) * 100
# Out:
# a partner   47.11
# unknown     31.09
# Caltrans    21.80
# Name: caltrans_or_partner, dtype: float64

# %%
# Check value counts.
df4.on_off_shs_category_tags.value_counts()
# Out:
# not enough info    415
# on the SHS         274
# not on the SHS      54
# Name: on_off_shs_category_tags, dtype: int64

# %%
# Check value counts.
df4.on_off_shs_category_tags.value_counts() / len(df4) * 100
# Out:
# not enough info   55.85
# on the SHS        36.88
# not on the SHS     7.27
# Name: on_off_shs_category_tags, dtype: float64

# %%
combos5 = (
    df4.groupby(
        [
            "on_off_shs_category_tags",
            "shs_capacity_increase_detail_SHS",
            "primary_mode_SHS",
            "secondary_mode_SHS",
        ]
    )
    .agg({"project_description": "count"})
    .reset_index()
    .rename(columns={"project_description": "total projects"})
    .reset_index(drop=True)
)

# %%
# https://stackoverflow.com/questions/60446836/highlight-text-string-type-in-pandas-df-matching-text
# https://stackoverflow.com/questions/73839250/count-number-of-occurrences-of-text-over-row-python-pandas
# Count number of times "none" appears.
combos5["none_count"] = combos5.apply(
    lambda x: sum([i.lower().count("none") for i in x if isinstance(i, str)]), axis=1
)

# %%
combos5.sort_values(by = ['on_off_shs_category_tags', 'total projects'], ascending = False).style.where(lambda val: "none" in str(val), "color: red")
# Out:
# /tmp/ipykernel_1384/85571598.py:1: FutureWarning: this method is deprecated in favour of `Styler.applymap()`
# <style type="text/css">
# #T_0eefb_row0_col3, #T_0eefb_row3_col1, #T_0eefb_row5_col1, #T_0eefb_row6_col1, #T_0eefb_row6_col3, #T_0eefb_row7_col1, #T_0eefb_row7_col3, #T_0eefb_row8_col1, #T_0eefb_row9_col1, #T_0eefb_row10_col1, #T_0eefb_row11_col3, #T_0eefb_row14_col1, #T_0eefb_row14_col2, #T_0eefb_row14_col3, #T_0eefb_row15_col3 {
#   color: red;
# }
# </style>
# <table id="T_0eefb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0eefb_level0_col0" class="col_heading level0 col0" >on_off_shs_category_tags</th>
#       <th id="T_0eefb_level0_col1" class="col_heading level0 col1" >shs_capacity_increase_detail_SHS</th>
#       <th id="T_0eefb_level0_col2" class="col_heading level0 col2" >primary_mode_SHS</th>
#       <th id="T_0eefb_level0_col3" class="col_heading level0 col3" >secondary_mode_SHS</th>
#       <th id="T_0eefb_level0_col4" class="col_heading level0 col4" >total projects</th>
#       <th id="T_0eefb_level0_col5" class="col_heading level0 col5" >none_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0eefb_level0_row0" class="row_heading level0 row0" >13</th>
#       <td id="T_0eefb_row0_col0" class="data row0 col0" >on the SHS</td>
#       <td id="T_0eefb_row0_col1" class="data row0 col1" >highway related</td>
#       <td id="T_0eefb_row0_col2" class="data row0 col2" >highway related</td>
#       <td id="T_0eefb_row0_col3" class="data row0 col3" >none</td>
#       <td id="T_0eefb_row0_col4" class="data row0 col4" >178</td>
#       <td id="T_0eefb_row0_col5" class="data row0 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_0eefb_level0_row1" class="row_heading level0 row1" >12</th>
#       <td id="T_0eefb_row1_col0" class="data row1 col0" >on the SHS</td>
#       <td id="T_0eefb_row1_col1" class="data row1 col1" >highway related</td>
#       <td id="T_0eefb_row1_col2" class="data row1 col2" >highway related</td>
#       <td id="T_0eefb_row1_col3" class="data row1 col3" >highway related</td>
#       <td id="T_0eefb_row1_col4" class="data row1 col4" >59</td>
#       <td id="T_0eefb_row1_col5" class="data row1 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0eefb_level0_row2" class="row_heading level0 row2" >14</th>
#       <td id="T_0eefb_row2_col0" class="data row2 col0" >on the SHS</td>
#       <td id="T_0eefb_row2_col1" class="data row2 col1" >highway related</td>
#       <td id="T_0eefb_row2_col2" class="data row2 col2" >highway related</td>
#       <td id="T_0eefb_row2_col3" class="data row2 col3" >not highway related</td>
#       <td id="T_0eefb_row2_col4" class="data row2 col4" >28</td>
#       <td id="T_0eefb_row2_col5" class="data row2 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0eefb_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_0eefb_row3_col0" class="data row3 col0" >on the SHS</td>
#       <td id="T_0eefb_row3_col1" class="data row3 col1" >none</td>
#       <td id="T_0eefb_row3_col2" class="data row3 col2" >highway related</td>
#       <td id="T_0eefb_row3_col3" class="data row3 col3" >highway related</td>
#       <td id="T_0eefb_row3_col4" class="data row3 col4" >6</td>
#       <td id="T_0eefb_row3_col5" class="data row3 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_0eefb_level0_row4" class="row_heading level0 row4" >16</th>
#       <td id="T_0eefb_row4_col0" class="data row4 col0" >on the SHS</td>
#       <td id="T_0eefb_row4_col1" class="data row4 col1" >not highway related</td>
#       <td id="T_0eefb_row4_col2" class="data row4 col2" >highway related</td>
#       <td id="T_0eefb_row4_col3" class="data row4 col3" >highway related</td>
#       <td id="T_0eefb_row4_col4" class="data row4 col4" >3</td>
#       <td id="T_0eefb_row4_col5" class="data row4 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0eefb_level0_row5" class="row_heading level0 row5" >11</th>
#       <td id="T_0eefb_row5_col0" class="data row5 col0" >not on the SHS</td>
#       <td id="T_0eefb_row5_col1" class="data row5 col1" >none</td>
#       <td id="T_0eefb_row5_col2" class="data row5 col2" >not highway related</td>
#       <td id="T_0eefb_row5_col3" class="data row5 col3" >not highway related</td>
#       <td id="T_0eefb_row5_col4" class="data row5 col4" >54</td>
#       <td id="T_0eefb_row5_col5" class="data row5 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_0eefb_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_0eefb_row6_col0" class="data row6 col0" >not enough info</td>
#       <td id="T_0eefb_row6_col1" class="data row6 col1" >none</td>
#       <td id="T_0eefb_row6_col2" class="data row6 col2" >not highway related</td>
#       <td id="T_0eefb_row6_col3" class="data row6 col3" >none</td>
#       <td id="T_0eefb_row6_col4" class="data row6 col4" >258</td>
#       <td id="T_0eefb_row6_col5" class="data row6 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_0eefb_level0_row7" class="row_heading level0 row7" >3</th>
#       <td id="T_0eefb_row7_col0" class="data row7 col0" >not enough info</td>
#       <td id="T_0eefb_row7_col1" class="data row7 col1" >none</td>
#       <td id="T_0eefb_row7_col2" class="data row7 col2" >highway related</td>
#       <td id="T_0eefb_row7_col3" class="data row7 col3" >none</td>
#       <td id="T_0eefb_row7_col4" class="data row7 col4" >49</td>
#       <td id="T_0eefb_row7_col5" class="data row7 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_0eefb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0eefb_row8_col0" class="data row8 col0" >not enough info</td>
#       <td id="T_0eefb_row8_col1" class="data row8 col1" >none</td>
#       <td id="T_0eefb_row8_col2" class="data row8 col2" >not highway related</td>
#       <td id="T_0eefb_row8_col3" class="data row8 col3" >not highway related</td>
#       <td id="T_0eefb_row8_col4" class="data row8 col4" >44</td>
#       <td id="T_0eefb_row8_col5" class="data row8 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_0eefb_level0_row9" class="row_heading level0 row9" >6</th>
#       <td id="T_0eefb_row9_col0" class="data row9 col0" >not enough info</td>
#       <td id="T_0eefb_row9_col1" class="data row9 col1" >none</td>
#       <td id="T_0eefb_row9_col2" class="data row9 col2" >not highway related</td>
#       <td id="T_0eefb_row9_col3" class="data row9 col3" >highway related</td>
#       <td id="T_0eefb_row9_col4" class="data row9 col4" >25</td>
#       <td id="T_0eefb_row9_col5" class="data row9 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_0eefb_level0_row10" class="row_heading level0 row10" >4</th>
#       <td id="T_0eefb_row10_col0" class="data row10 col0" >not enough info</td>
#       <td id="T_0eefb_row10_col1" class="data row10 col1" >none</td>
#       <td id="T_0eefb_row10_col2" class="data row10 col2" >highway related</td>
#       <td id="T_0eefb_row10_col3" class="data row10 col3" >not highway related</td>
#       <td id="T_0eefb_row10_col4" class="data row10 col4" >24</td>
#       <td id="T_0eefb_row10_col5" class="data row10 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_0eefb_level0_row11" class="row_heading level0 row11" >1</th>
#       <td id="T_0eefb_row11_col0" class="data row11 col0" >not enough info</td>
#       <td id="T_0eefb_row11_col1" class="data row11 col1" >highway related</td>
#       <td id="T_0eefb_row11_col2" class="data row11 col2" >not highway related</td>
#       <td id="T_0eefb_row11_col3" class="data row11 col3" >none</td>
#       <td id="T_0eefb_row11_col4" class="data row11 col4" >5</td>
#       <td id="T_0eefb_row11_col5" class="data row11 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_0eefb_level0_row12" class="row_heading level0 row12" >2</th>
#       <td id="T_0eefb_row12_col0" class="data row12 col0" >not enough info</td>
#       <td id="T_0eefb_row12_col1" class="data row12 col1" >highway related</td>
#       <td id="T_0eefb_row12_col2" class="data row12 col2" >not highway related</td>
#       <td id="T_0eefb_row12_col3" class="data row12 col3" >not highway related</td>
#       <td id="T_0eefb_row12_col4" class="data row12 col4" >4</td>
#       <td id="T_0eefb_row12_col5" class="data row12 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0eefb_level0_row13" class="row_heading level

# %% [markdown]
# ### Investigation:
# * Around 1/2 of rows have not enough info.
# * Discern potential patterns in the three columns for these projects.

# %% [markdown]
# #### Most Common Words: Word Cloud
# * https://www.kaggle.com/code/olgaberezovsky/word-cloud-using-python-pandas/notebook

# %%
extra_stop_words = [
    "project",
    "new",
    "improvement",
    "improve",
    "construct",
    "along",
    "improvements",
    "include",
    "will",
    "caltrans",
    "exist",
    "los angeles",
    "san diego",
    "near",
    "area",
    "south",
    "north" "street",
]

# %%
# Make a wordcloud of the top 100 words without certain stop words
_shs_tagging_utils.wordcloud(df4, "project_description", 200, extra_stop_words)

# %% [markdown]
# #### Most Common Phrases
# * Look through common phrases, in addition to single words.

# %%
# Look for 2 word phrases through project desc
phrases = _shs_tagging_utils.get_list_of_words(df4, "project_description", extra_stop_words)

# %%
df_phrases = _shs_tagging_utils.common_phrases(df4, phrases, 2)

# %%
df_phrases.head(10)
# Out:
#    index                phrases  total
# 0    435            state route     49
# 1   8681            los angeles     40
# 2     25                 us 101     40
# 3    299             bike lanes     37
# 4     28  active transportation     33
# 5   1357         passenger rail     30
# 6    756     bicycle pedestrian     28
# 7  11011       grade separation     28
# 8    297               class ii     26
# 9   1589            county line     24

# %% [markdown]
# ### Search through for SHS related words in project description

# %%
# Keywords related to SHS - based on word cloud/common phrases results
SHS_keywords_list = [
    "sr",
    "state highway",
    "sr-",
    "state route",
    "sr ",
    "highway 1",
    "interstate",
    "us 101",
    "route 99",
    "sr 99",
    "i-",
    "us-",
    "u.s.",
    "101",
]

# %%
# Search through project description for keywords above
df5 = tagging_columns(
    df4,
    "project_description",
    "contains_SR_reference",
    SHS_keywords_list,
    "contains SHS keyword(s)",
    "does not contain SHS keyword(s)",
)
# Out:
# /tmp/ipykernel_1384/4108280031.py:31: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.

# %%
df5.contains_SR_reference.value_counts()
# Out:
# contains SHS keyword(s)            366
# does not contain SHS keyword(s)    331
# none                                46
# Name: contains_SR_reference, dtype: int64

# %%
# 46 projects have missing descriptions.
len(
    df5[["project_name", "project_description", "contains_SR_reference"]].loc[
        df5["contains_SR_reference"] == "none"
    ]
)
# Out:
# 46

# %% [markdown]
# #### Investigate: projects that contain SHS keywords vs. those that don't.

# %%
# Extract keywords from project description that are in the list into a new col to double check results
# https://stackoverflow.com/questions/67746078/how-to-highlight-and-count-specific-keywords-in-a-pandas-dataframe
df5["SHS_keyword_match"] = df5["project_description"].str.findall(
    rf"\b(?:{'|'.join(SHS_keywords_list)})\b"
)

# %%
# Subset for a smaller df
subset_cols = [
    "project_name",
    "lead_agency",
    "project_description",
    "SHS_keyword_match",
    "on_off_shs_category_tags",
    "primary_mode",
    "contains_SR_reference",
    "SHS_keyword_match",
]

# %%
# Subset for projects with SHS keywords
SHS_keywords_df = (
    df5[subset_cols].loc[df5["contains_SR_reference"] == "contains SHS keyword(s)"]
).reset_index(drop=True)

# %%
# See which "not on the SHS" projects contain SHS keywords
len(SHS_keywords_df.loc[SHS_keywords_df["on_off_shs_category_tags"] == "not on the SHS"])
# Out:
# 17

# %%
# Filter for values in SHS Keyword Match that are actually empty
# Replace this with "does not contain SHS Keywords"
# (SHS_keywords_df[SHS_keywords_df["SHS_keyword_match"].str.len() == 0])
# df.loc[(df["name"] == "Butte County Association of Governments"), "ntd_id"] = "90208"
# SHS_keywords_df.loc[ (SHS_keywords_df["SHS_keyword_match"].str.len() == 0), "contains_SR_reference"] = "does not contain SHS keyword(s)"

# %%
# Subset for projects without SHS keywords
no_SHS_keywords_df = (
    df5[subset_cols].loc[
        df5["contains_SR_reference"] == "does not contain SHS keyword(s)"
    ]
).reset_index(drop=True)

# %%
# Investigate why some "on the SHS" don't contain any SHS keywords in it's description...
len(no_SHS_keywords_df.loc[no_SHS_keywords_df['on_off_shs_category_tags'] == 'on the SHS'])
# Out:
# 78

# %%
# no_SHS_keywords_df.loc[no_SHS_keywords_df['on_off_shs_category_tags'] == 'on the SHS']

# %% [markdown]
# ### Retag using project descriptions

# %%
def SHS_project_description_tag(df):
    
    # Tag if a project's desc has a SHS keyword/SHS keywords or not
    def keywords(row):
        
        if ((row.on_off_shs_category_tags == "not on the SHS")|(row.on_off_shs_category_tags == "not enough info")) and (row.contains_SR_reference == "does not contain SHS keyword(s)"): 
            return "not on the SHS"
        
        elif ((row.on_off_shs_category_tags == "on the SHS")|(row.on_off_shs_category_tags == "not enough info")) and (row.route != "Off") and (row.contains_SR_reference == "contains SHS keyword(s)"):  
            return "on the SHS"
          
        # Some non SHS projects coincidentally include SHS keywords
        elif (row.on_off_shs_category_tags == "not on the SHS") and (row.contains_SR_reference == "contains SHS keyword(s)"):
            return "not on the SHS"
        
        # Some SHS projects don't have any SHS keywords in its description
        elif (row.on_off_shs_category_tags == "on the SHS") and (row.contains_SR_reference == "does not contain SHS keyword(s)"):
            return "on the SHS"
        
        # Everything else is not enough info
        else:
            return "not enough info"

    # Apply the function
    df["on_shs_project_desc_tag"] = df.apply(keywords, axis=1)
    
    # Function for writing out the sentence
    def summary_sentence(row): 
        if row.on_shs_project_desc_tag == "on the SHS":
            return f"The lead agency is {row.caltrans_or_partner} and the project is on Route {row.route}."
        else:
            return  f"The lead agency is {row.caltrans_or_partner} and the project is {row.on_shs_project_desc_tag}."
    
    # Apply sentence function
    df.sentence = df.apply(summary_sentence, axis=1)
    return df

# %%
df6 = SHS_project_description_tag(df5)

# %%
# df6.sentence.value_counts()

# %% [markdown]
# #### Compare first attempt of the sentence versus second attempt.

# %%
# First round of tagging's results 
df5.on_off_shs_category_tags.value_counts()
# Out:
# not enough info    415
# on the SHS         274
# not on the SHS      54
# Name: on_off_shs_category_tags, dtype: int64

# %%
# Second round of tagging's results
df6.on_shs_project_desc_tag.value_counts()
# Out:
# on the SHS         392
# not on the SHS     270
# not enough info     81
# Name: on_shs_project_desc_tag, dtype: int64

# %%
# Goal to get rid of possibly on the SHS category?
(df6.on_shs_project_desc_tag.value_counts() / len(df6)) * 100
# Out:
# on the SHS        52.76
# not on the SHS    36.34
# not enough info   10.90
# Name: on_shs_project_desc_tag, dtype: float64

# %%
# Cols for subsetting the df 
subset = [
       
          "SHS_keyword_match",
        "sentence",
        "primary_mode",
        "shs_capacity_increase_detail",
        "secondary_mode_s",
        "contains_SR_reference",
        "on_off_shs_category_tags",
        "on_shs_project_desc_tag",
    
  
    ]

# %%
combos6 = (
    df6.groupby(
        [ "on_shs_project_desc_tag","on_off_shs_category_tags", "contains_SR_reference"]
    )
    .size()
    .reset_index()
    .rename(columns={0: "count"})
)

# %%
# Compare first round with second round 
combos6["did_both_tagging_functions_give_same_result"] = (
    combos6["on_shs_project_desc_tag"] == combos6["on_off_shs_category_tags"]
)

# %%
combos6["did_both_tagging_functions_give_same_result"].value_counts()
# Out:
# True     6
# False    5
# Name: did_both_tagging_functions_give_same_result, dtype: int64

# %%
# First col is the new results after 2nd round of tagging 
combos6.sort_values(by = ["on_shs_project_desc_tag","count"], ascending=False)
# Out:
#    on_shs_project_desc_tag on_off_shs_category_tags  \
# 9               on the SHS               on the SHS
# 8               on the SHS          not enough info
# 10              on the SHS               on the SHS
# 5           not on the SHS          not enough info
# 7           not on the SHS           not on the SHS
# 6           not on the SHS           not on the SHS
# 1          not enough info          not enough info
# 0          not enough info          not enough info
# 2          not enough info           not on the SHS
# 4          not enough info               on the SHS
# 3          not enough info               on the SHS
#
#               contains_SR_reference  count  \
# 9           contains SHS keyword(s)    191
# 8           contains SHS keyword(s)    123
# 10  does not contain SHS keyword(s)     78
# 5   does not contain SHS keyword(s)    223
# 7   does not contain SHS keyword(s)     30
# 6           contains SHS keyword(s)     17
# 1                              none     35
# 0           contains SHS keyword(s)     34
# 2                              none      7
# 4                              none      4
# 3           contains SHS keyword(s)      1
#
#     did_both_tagging_functions_give_same_result
# 9                                          True
# 8                                         False
# 10                                         True
# 5                                         False
# 7                                          True
# 6                                          True
# 1                                          True
# 0                                          True
# 2                                         False
# 4                                         False
# 3                                         False

# %% [markdown]
# #### Check out some combos.
# * Projects that were tagged as "not on the SHS" at first  but "contains SHS keywords"
# * Projects that were tagged as "on the SHS" but "does not conatin SHS keywords"

# %%
df6[subset].sample(5)
# Out:
#     SHS_keyword_match  \
# 401                []
# 613                []
# 140      [sr, sr, sr]
# 307          [sr, sr]
# 719             [101]
#
#                                                             sentence  \
# 401    The lead agency is unknown and the project is not on the SHS.
# 613  The lead agency is a partner and the project is not on the SHS.
# 140    The lead agency is Caltrans and the project is on Route None.
# 307     The lead agency is Caltrans and the project is on Route 091.
# 719     The lead agency is unknown and the project is on Route None.
#
#          primary_mode shs_capacity_increase_detail  \
# 401   bike/pedestrian                         none
# 613  rail (passenger)                         none
# 140  complete streets                         none
# 307           highway                local roadway
# 719   bike/pedestrian                         none
#
#                                         secondary_mode_s  \
# 401                                                 none
# 613                                                 none
# 140                           highway\nits\ntransit\nzev
# 307  bike/pedestrian\ncomplete streets\nhighway\ntransit
# 719                                                 none
#
#                contains_SR_reference on_off_shs_category_tags  \
# 401  does not contain SHS keyword(s)          not enough info
# 613  does not contain SHS keyword(s)          not enough info
# 140          contains SHS keyword(s)          not enough info
# 307          contains SHS keyword(s)               on the SHS
# 719          contains SHS keyword(s)          not enough info
#
#     on_shs_project_desc_tag
# 401          not on the SHS
# 613          not on the SHS
# 140              on the SHS
# 307              on the SHS
# 719              on the SHS

# %%
(df6[subset][
    ((df6.on_off_shs_category_tags == "not on the SHS") & (df6.contains_SR_reference == "contains SHS keyword(s)" ))
]).sample(2)
# Out:
#     SHS_keyword_match  \
# 54           [i-, i-]
# 518                []
#
#                                                             sentence  \
# 54   The lead agency is a partner and the project is not on the SHS.
# 518  The lead agency is a partner and the project is not on the SHS.
#
#          primary_mode shs_capacity_increase_detail  \
# 54   complete streets                         none
# 518              port                         none
#
#                       secondary_mode_s    contains_SR_reference  \
# 54   bike/pedestrian\ncomplete streets  contains SHS keyword(s)
# 518                               port  contains SHS keyword(s)
#
#     on_off_shs_category_tags on_shs_project_desc_tag
# 54            not on the SHS          not on the SHS
# 518           not on the SHS          not on the SHS

# %%
(df6[subset][
    ((df6.on_off_shs_category_tags == "on the SHS") & (df6.contains_SR_reference == "does not contain SHS keyword(s)" ))
]).sample(2)
# Out:
#     SHS_keyword_match  \
# 460                []
# 358                []
#
#                                                         sentence primary_mode  \
# 460  The lead agency is unknown and the project is on Route 005.      highway
# 358  The lead agency is unknown and the project is on Route 015.      highway
#
#     shs_capacity_increase_detail secondary_mode_s  \
# 460                 express lane             none
# 358               auxiliary lane             none
#
#                contains_SR_reference on_off_shs_category_tags  \
# 460  does not contain SHS keyword(s)               on the SHS
# 358  does not contain SHS keyword(s)               on the SHS
#
#     on_shs_project_desc_tag
# 460              on the SHS
# 358              on the SHS

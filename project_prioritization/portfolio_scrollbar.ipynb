# %% [markdown]
# # Additional styling to a dataframe.
# * By default, bool is False and will return original dataframe without a scrollbar.
# * When bool is true, will return a dataframe with a scrollbar for any overflow content.
# * You can change the height, width, and font size based.

# %%
import pandas as pd
import pandas.io.formats.style
from IPython.display import HTML, Image, Markdown, display, display_html

# %%
GCS_FILE_PATH = "gs://calitp-analytics-data/data-analyses/project_prioritization/"
FILE = "fake_data.xlsx"

# %%
df = pd.read_excel(f"{GCS_FILE_PATH}{FILE}", sheet_name="fake")

# %%
df = df[
    [
        "county",
        "district_full_name",
        "district_rank",
        "project_name",
        "total_project_cost__$1,000_",
        "reduction_in_fatal_and_injury_crashes",
        "statewide_rank",
    ]
].sample(20)

# %%
def edited_style_table(
    df: pd.DataFrame,
    rename_cols: dict = {},
    drop_cols: list = [],
    integer_cols: list = [],
    one_decimal_cols: list = [],
    two_decimal_cols: list = [],
    three_decimal_cols: list = [],
    currency_cols: list = [],
    percent_cols: list = [],
    left_align_cols: list = "first",  # by default, left align first col
    center_align_cols: list = "all",  # by default, center align all other cols
    right_align_cols: list = [],
    custom_format_cols: dict = {},
    display_table: bool = True,
    display_scrollbar: bool = False,
    scrollbar_font: str = "12px",
    scrollbar_height: str = "400px",
    scrollbar_width: str = "fit-content",
) -> pd.io.formats.style.Styler:
    """
    Returns a pandas Styler object with some basic formatting.
    Even if display_table is True, pandas Styler object returned,
    just with a display() happening in the notebook cell.
    Any other tweaks for currency, percentages, etc should be done before / after,
    if it can't be put into custom_format_cols.

    custom_format_cols = {
        '{:,.1%}': ['colA', 'colB']
    }

    Generalize with dict comprehension or list comprehension
    list comprehension: df.style.format(subset=percent_cols,  **{'formatter': '{:,.2%}'})
    dict comprehension: df.style.format(formatter = {c: '{:,.2%}' for c in percent_cols})
    """
    df = df.drop(columns=drop_cols).rename(columns=rename_cols)

    if len(integer_cols) > 0:
        df = df.astype({c: "Int64" for c in integer_cols})

    if left_align_cols == "first":
        left_align_cols = list(df.columns)[0]
    if center_align_cols == "all":
        center_align_cols = list(df.columns)
        # all other columns except first one is center aligned
        center_align_cols = [c for c in center_align_cols if c not in left_align_cols]

    df_style = (
        df.style.format(formatter={c: "{:,g}" for c in integer_cols})
        .format(formatter={c: "{:,.1f}" for c in one_decimal_cols})
        .format(formatter={c: "{:,.2f}" for c in two_decimal_cols})
        .format(formatter={c: "{:,.3f}" for c in three_decimal_cols})
        .format(formatter={c: "{:,.2%}" for c in percent_cols})
        .format(formatter={c: "$ {:,.2f}" for c in currency_cols})
        .set_properties(subset=left_align_cols, **{"text-align": "left"})
        .set_properties(subset=center_align_cols, **{"text-align": "center"})
        .set_properties(subset=right_align_cols, **{"text-align": "right"})
        .set_table_styles([dict(selector="th", props=[("text-align", "center")])])
        .hide(axis="index")
    )

    def add_custom_format(
        df_style: pd.io.formats.style.Styler,
        format_str: str,
        cols_to_format: list,
    ) -> pd.io.formats.style.Styler:
        """
        Appends any additional formatting needs.
            key: format string, such as '{:.1%}'
            value: list of columns to apply that formatter to.
        """
        new_styler = df_style.format(formatter={c: format_str for c in cols_to_format})

        return new_styler

    if len(list(custom_format_cols.keys())) > 0:
        for format_str, cols_to_format in custom_format_cols.items():
            df_style = add_custom_format(df_style, format_str, cols_to_format)

    if display_table is True:
        if display_scrollbar is True:
            display(
                HTML(
                    f"<div style='height: {scrollbar_height}; overflow: auto; width: {scrollbar_width}'>"
                    + (
                        (df_style)
                        .set_properties(
                            **{
                                "font-size": scrollbar_font,
                            }
                        )
                        .render()
                    )
                    + "</div>"
                )
            )
        else:
            display(HTML(df_style.to_html()))

    return df_style

# %% [markdown]
# #### When you turn on "true" for scrollbar and input your own arguments.

# %%
test1 = edited_style_table(
    df,
    {"district_full_name": "renamed1", "project_name": "renamed2"},
    ["reduction_in_fatal_and_injury_crashes"],
    ["district_rank"],
    ["fake_benefit_score"],
    [],
    [],
    ["total_project_cost__$1,000_"],
    ["statewide_rank"],
    [],
    [],
    [],
    {},
    True,
    True,
    "9px",
    "250px",
    "650px",
)
# Out:
# /tmp/ipykernel_1831/1914679036.py:92: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   .render()
# <div style='height: 250px; overflow: auto; width: 650px'><style type="text/css">
# #T_db5a8 th {
#   text-align: center;
# }
# #T_db5a8_row0_col0, #T_db5a8_row0_col1, #T_db5a8_row0_col2, #T_db5a8_row0_col3, #T_db5a8_row0_col4, #T_db5a8_row0_col5, #T_db5a8_row1_col0, #T_db5a8_row1_col1, #T_db5a8_row1_col2, #T_db5a8_row1_col3, #T_db5a8_row1_col4, #T_db5a8_row1_col5, #T_db5a8_row2_col0, #T_db5a8_row2_col1, #T_db5a8_row2_col2, #T_db5a8_row2_col3, #T_db5a8_row2_col4, #T_db5a8_row2_col5, #T_db5a8_row3_col0, #T_db5a8_row3_col1, #T_db5a8_row3_col2, #T_db5a8_row3_col3, #T_db5a8_row3_col4, #T_db5a8_row3_col5, #T_db5a8_row4_col0, #T_db5a8_row4_col1, #T_db5a8_row4_col2, #T_db5a8_row4_col3, #T_db5a8_row4_col4, #T_db5a8_row4_col5, #T_db5a8_row5_col0, #T_db5a8_row5_col1, #T_db5a8_row5_col2, #T_db5a8_row5_col3, #T_db5a8_row5_col4, #T_db5a8_row5_col5, #T_db5a8_row6_col0, #T_db5a8_row6_col1, #T_db5a8_row6_col2, #T_db5a8_row6_col3, #T_db5a8_row6_col4, #T_db5a8_row6_col5, #T_db5a8_row7_col0, #T_db5a8_row7_col1, #T_db5a8_row7_col2, #T_db5a8_row7_col3, #T_db5a8_row7_col4, #T_db5a8_row7_col5, #T_db5a8_row8_col0, #T_db5a8_row8_col1, #T_db5a8_row8_col2, #T_db5a8_row8_col3, #T_db5a8_row8_col4, #T_db5a8_row8_col5, #T_db5a8_row9_col0, #T_db5a8_row9_col1, #T_db5a8_row9_col2, #T_db5a8_row9_col3, #T_db5a8_row9_col4, #T_db5a8_row9_col5, #T_db5a8_row10_col0, #T_db5a8_row10_col1, #T_db5a8_row10_col2, #T_db5a8_row10_col3, #T_db5a8_row10_col4, #T_db5a8_row10_col5, #T_db5a8_row11_col0, #T_db5a8_row11_col1, #T_db5a8_row11_col2, #T_db5a8_row11_col3, #T_db5a8_row11_col4, #T_db5a8_row11_col5, #T_db5a8_row12_col0, #T_db5a8_row12_col1, #T_db5a8_row12_col2, #T_db5a8_row12_col3, #T_db5a8_row12_col4, #T_db5a8_row12_col5, #T_db5a8_row13_col0, #T_db5a8_row13_col1, #T_db5a8_row13_col2, #T_db5a8_row13_col3, #T_db5a8_row13_col4, #T_db5a8_row13_col5, #T_db5a8_row14_col0, #T_db5a8_row14_col1, #T_db5a8_row14_col2, #T_db5a8_row14_col3, #T_db5a8_row14_col4, #T_db5a8_row14_col5, #T_db5a8_row15_col0, #T_db5a8_row15_col1, #T_db5a8_row15_col2, #T_db5a8_row15_col3, #T_db5a8_row15_col4, #T_db5a8_row15_col5, #T_db5a8_row16_col0, #T_db5a8_row16_col1, #T_db5a8_row16_col2, #T_db5a8_row16_col3, #T_db5a8_row16_col4, #T_db5a8_row16_col5, #T_db5a8_row17_col0, #T_db5a8_row17_col1, #T_db5a8_row17_col2, #T_db5a8_row17_col3, #T_db5a8_row17_col4, #T_db5a8_row17_col5, #T_db5a8_row18_col0, #T_db5a8_row18_col1, #T_db5a8_row18_col2, #T_db5a8_row18_col3, #T_db5a8_row18_col4, #T_db5a8_row18_col5, #T_db5a8_row19_col0, #T_db5a8_row19_col1, #T_db5a8_row19_col2, #T_db5a8_row19_col3, #T_db5a8_row19_col4, #T_db5a8_row19_col5 {
#   font-size: 9px;
# }
# </style>
# <table id="T_db5a8">
#   <thead>
#     <tr>
#       <th id="T_db5a8_level0_col0" class="col_heading level0 col0" >county</th>
#       <th id="T_db5a8_level0_col1" class="col_heading level0 col1" >renamed1</th>
#       <th id="T_db5a8_level0_col2" class="col_heading level0 col2" >district_rank</th>
#       <th id="T_db5a8_level0_col3" class="col_heading level0 col3" >renamed2</th>
#       <th id="T_db5a8_level0_col4" class="col_heading level0 col4" >total_project_cost__$1,000_</th>
#       <th id="T_db5a8_level0_col5" class="col_heading level0 col5" >statewide_rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_db5a8_row0_col0" class="data row0 col0" >ORA</td>
#       <td id="T_db5a8_row0_col1" class="data row0 col1" >12 - Irvine</td>
#       <td id="T_db5a8_row0_col2" class="data row0 col2" >33</td>
#       <td id="T_db5a8_row0_col3" class="data row0 col3" >Rt-55 Costa Mesa Improve Mobility</td>
#       <td id="T_db5a8_row0_col4" class="data row0 col4" >$ 888,888.00</td>
#       <td id="T_db5a8_row0_col5" class="data row0 col5" >455</td>
#     </tr>
#     <tr>
#       <td id="T_db5a8_row1_col0" class="data row1 col0" >MEN</td>
#       <td id="T_db5a8_row1_col1" class="data row1 col1" >01 - Eureka</td>
#       <td id="T_db5a8_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_db5a8_row1_col3" class="data row1 col3" >Gualala Downtown Streetscape Enhacement</td>
#       <td id="T_db5a8_row1_col4" class="data row1 col4" >$ 9,039.00</td>
#       <td id="T_db5a8_row1_col5" class="data row1 col5" >82</td>
#     </tr>
#     <tr>
#       <td id="T_db5a8_row2_col0" class="data row2 col0" >LA</td>
#       <td id="T_db5a8_row2_col1" class="data row2 col1" >07 - Los Angeles</td>
#       <td id="T_db5a8_row2_col2" class="data row2 col2" >115</td>
#       <td id="T_db5a8_row2_col3" class="data row2 col3" >Grade Separation -- Industry/La County</td>
#       <td id="T_db5a8_row2_col4" class="data row2 col4" >$ 86,200.00</td>
#       <td id="T_db5a8_row2_col5" class="data row2 col5" >689</td>
#     </tr>
#     <tr>
#       <td id="T_db5a8_row3_col0" class="data row3 col0" >SAC, SJ, ALA, CC, STA, MER, MAD, FRE, KIN, TUL, KER</td>
#       <td id="T_db5a8_row3_col1" class="data row3 col1" >75 - HQ</td>
#       <td id="T_db5a8_row3_col2" class="data row3 col2" >21</td>
#       <td id="T_db5a8_row3_col3" class="data row3 col3" >Water System Upgrade On California Cars</td>
#       <td id="T_db5a8_row3_col4" class="data row3 col4" >$ 200.00</td>
#       <td id="T_db5a8_row3_col5" class="data row3 col5" >505</td>
#     </tr>
#     <tr>
#       <td id="T_db5a8_row4_col0" class="data row4 col0" >LA</td>
#       <td id="T_db5a8_row4_col1" class="data row4 col1" >07 - Los Angeles</td>
#       <td id="T_db5a8_row4_col2" class="data row4 col2" >9</td>
#       <td id="T_db5a8_row4_col3" class="data row4 col3" >I-405 Active Traffic Management (Atm) And Integrated Corridor Management (Icm) Project</td>
#       <td id="T_db5a8_row4_col4" class="data row4 col4" >$ 61,473.00</td>
#       <td id="T_db5a8_row4_col5" class="data row4 col5" >76</td>
#     </tr>
#     <tr>
#       <td id="T_db5a8_row5_col0" class="data row5 col0" >SD</td>
#       <td id="T_db5a8_row5_col1" class="data row5 col1" >11 - San Diego</td>
#       <td id="T_db5a8_row5_col2" class="data row5 col2" >11</td>
#       <td id="T_db5a8_row5_col3" class="data row5 col3" >Lossan Sd Intermodal Improvement Program
# Lossan/Coaster Commuter Rail Bluff Stablization Project</td>
#       <td id="T_db5a8_row5_col4" class="data row5 col4" >$ 888,888.00</td>
#       <td id="T_db5a8_row5_col5" class="data row5 col5" >187</td>
#     </tr>
#     <tr>
#       <td id="T_db5a8_row6_col0" class="data row6 col0" >SOL</td>
#       <td id="T_db5a8_row6_col1" class="data row6 col1" >04 - Oakland</td>
#       <td id="T_db5a8_row6_col2" class="data row6 col2" >37</td>
#       <td id="T_db5a8_row6_col3" class="data row6 col3" >Solano County Transit (Soltrans) Charging Infrastructure</td>
#       <td id="T_db5a8_row6_col4" class="data row6 col4" >$ 1,900.00</td>
#       <td id="T_db5a8_row6_col5" class="data row6 col5" >205</td>
#     </tr>
#     <tr>
#       <td id="T_db5a8_row7_col0" class="data row7 col0" >RIV</td>
#       <td id="T_db5a8_row7_col1" class="data row7 col1" >08 - San Bernardino</td>
#       <td id="T_db5a8_row7_col2" class="data row7 col2" >54</td>
#       <td id="T_db5a8_row7_col3" class="data row7 col3" >Riv 60 Rubidoux Blvd Interchange Improvements</td>
#       <td id="T_db5a8_row7_col4" class="data row7 col4" >$ 888,888.00</td>
#       <td id="T_db5a8_row7_col5" class="data row7 col5" >494</td>
#     </tr>
#     <tr>
#       <td id="T_db5a8_row8_col0" class="data row8 col0" >SBD</td>
#       <td id="T_db5a8_row8_col1" class="data row8 col1" >08 - San Bernardino</td>
#       <td id="T_db5a8_row8_col2" class="data row8 col2" >62</td>
#       <td id="T_db5a8_row8_col3" class="data row8 col3" >Sr-138 Widening - Segment 1</td>
#       <td id="T_db5a8_row8_col4" class="data row8 col4" >$ 8,000.00</td>
#       <td id="T_db5a8_row8_col5" class="data row8 col5" >587</td>
#     </tr>
#     <tr>
#       <td id="T_db5a8_row9_col0" class="data row9 col0" >SD</td>
#       <td id="T_db5a8_row9_col1" class="data row9 col1" >11 - San Diego</td>
#       <td id="T_db5a8_row9_col2" class="data row9 col2" >15</td>
#       <td id="T_db5a8_row9_col3" class="data row9 col3" >Del Mar Bluffs Phase 5 And 6</td>
#       <td id="T_db5a8_row9_col4" class="data row9 col4" >$ 70,000.00</td>
#       <td id="T_db5a8_row9_col5" class="data row9 co

# %% [markdown]
# #### When you turn on "true" for scrollbar and leave default args

# %%
test2 = edited_style_table(
    df,
    {"district_full_name": "renamed1", "project_name": "renamed2"},
    ["reduction_in_fatal_and_injury_crashes"],
    ["district_rank"],
    ["fake_benefit_score"],
    [],
    [],
    ["total_project_cost__$1,000_"],
    ["statewide_rank"],
    [],
    [],
    [],
    {},
    True,
    True,

)
# Out:
# /tmp/ipykernel_1831/1914679036.py:92: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   .render()
# <div style='height: 400px; overflow: auto; width: fit-content'><style type="text/css">
# #T_5451e th {
#   text-align: center;
# }
# #T_5451e_row0_col0, #T_5451e_row0_col1, #T_5451e_row0_col2, #T_5451e_row0_col3, #T_5451e_row0_col4, #T_5451e_row0_col5, #T_5451e_row1_col0, #T_5451e_row1_col1, #T_5451e_row1_col2, #T_5451e_row1_col3, #T_5451e_row1_col4, #T_5451e_row1_col5, #T_5451e_row2_col0, #T_5451e_row2_col1, #T_5451e_row2_col2, #T_5451e_row2_col3, #T_5451e_row2_col4, #T_5451e_row2_col5, #T_5451e_row3_col0, #T_5451e_row3_col1, #T_5451e_row3_col2, #T_5451e_row3_col3, #T_5451e_row3_col4, #T_5451e_row3_col5, #T_5451e_row4_col0, #T_5451e_row4_col1, #T_5451e_row4_col2, #T_5451e_row4_col3, #T_5451e_row4_col4, #T_5451e_row4_col5, #T_5451e_row5_col0, #T_5451e_row5_col1, #T_5451e_row5_col2, #T_5451e_row5_col3, #T_5451e_row5_col4, #T_5451e_row5_col5, #T_5451e_row6_col0, #T_5451e_row6_col1, #T_5451e_row6_col2, #T_5451e_row6_col3, #T_5451e_row6_col4, #T_5451e_row6_col5, #T_5451e_row7_col0, #T_5451e_row7_col1, #T_5451e_row7_col2, #T_5451e_row7_col3, #T_5451e_row7_col4, #T_5451e_row7_col5, #T_5451e_row8_col0, #T_5451e_row8_col1, #T_5451e_row8_col2, #T_5451e_row8_col3, #T_5451e_row8_col4, #T_5451e_row8_col5, #T_5451e_row9_col0, #T_5451e_row9_col1, #T_5451e_row9_col2, #T_5451e_row9_col3, #T_5451e_row9_col4, #T_5451e_row9_col5, #T_5451e_row10_col0, #T_5451e_row10_col1, #T_5451e_row10_col2, #T_5451e_row10_col3, #T_5451e_row10_col4, #T_5451e_row10_col5, #T_5451e_row11_col0, #T_5451e_row11_col1, #T_5451e_row11_col2, #T_5451e_row11_col3, #T_5451e_row11_col4, #T_5451e_row11_col5, #T_5451e_row12_col0, #T_5451e_row12_col1, #T_5451e_row12_col2, #T_5451e_row12_col3, #T_5451e_row12_col4, #T_5451e_row12_col5, #T_5451e_row13_col0, #T_5451e_row13_col1, #T_5451e_row13_col2, #T_5451e_row13_col3, #T_5451e_row13_col4, #T_5451e_row13_col5, #T_5451e_row14_col0, #T_5451e_row14_col1, #T_5451e_row14_col2, #T_5451e_row14_col3, #T_5451e_row14_col4, #T_5451e_row14_col5, #T_5451e_row15_col0, #T_5451e_row15_col1, #T_5451e_row15_col2, #T_5451e_row15_col3, #T_5451e_row15_col4, #T_5451e_row15_col5, #T_5451e_row16_col0, #T_5451e_row16_col1, #T_5451e_row16_col2, #T_5451e_row16_col3, #T_5451e_row16_col4, #T_5451e_row16_col5, #T_5451e_row17_col0, #T_5451e_row17_col1, #T_5451e_row17_col2, #T_5451e_row17_col3, #T_5451e_row17_col4, #T_5451e_row17_col5, #T_5451e_row18_col0, #T_5451e_row18_col1, #T_5451e_row18_col2, #T_5451e_row18_col3, #T_5451e_row18_col4, #T_5451e_row18_col5, #T_5451e_row19_col0, #T_5451e_row19_col1, #T_5451e_row19_col2, #T_5451e_row19_col3, #T_5451e_row19_col4, #T_5451e_row19_col5 {
#   font-size: 12px;
# }
# </style>
# <table id="T_5451e">
#   <thead>
#     <tr>
#       <th id="T_5451e_level0_col0" class="col_heading level0 col0" >county</th>
#       <th id="T_5451e_level0_col1" class="col_heading level0 col1" >renamed1</th>
#       <th id="T_5451e_level0_col2" class="col_heading level0 col2" >district_rank</th>
#       <th id="T_5451e_level0_col3" class="col_heading level0 col3" >renamed2</th>
#       <th id="T_5451e_level0_col4" class="col_heading level0 col4" >total_project_cost__$1,000_</th>
#       <th id="T_5451e_level0_col5" class="col_heading level0 col5" >statewide_rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5451e_row0_col0" class="data row0 col0" >ORA</td>
#       <td id="T_5451e_row0_col1" class="data row0 col1" >12 - Irvine</td>
#       <td id="T_5451e_row0_col2" class="data row0 col2" >33</td>
#       <td id="T_5451e_row0_col3" class="data row0 col3" >Rt-55 Costa Mesa Improve Mobility</td>
#       <td id="T_5451e_row0_col4" class="data row0 col4" >$ 888,888.00</td>
#       <td id="T_5451e_row0_col5" class="data row0 col5" >455</td>
#     </tr>
#     <tr>
#       <td id="T_5451e_row1_col0" class="data row1 col0" >MEN</td>
#       <td id="T_5451e_row1_col1" class="data row1 col1" >01 - Eureka</td>
#       <td id="T_5451e_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_5451e_row1_col3" class="data row1 col3" >Gualala Downtown Streetscape Enhacement</td>
#       <td id="T_5451e_row1_col4" class="data row1 col4" >$ 9,039.00</td>
#       <td id="T_5451e_row1_col5" class="data row1 col5" >82</td>
#     </tr>
#     <tr>
#       <td id="T_5451e_row2_col0" class="data row2 col0" >LA</td>
#       <td id="T_5451e_row2_col1" class="data row2 col1" >07 - Los Angeles</td>
#       <td id="T_5451e_row2_col2" class="data row2 col2" >115</td>
#       <td id="T_5451e_row2_col3" class="data row2 col3" >Grade Separation -- Industry/La County</td>
#       <td id="T_5451e_row2_col4" class="data row2 col4" >$ 86,200.00</td>
#       <td id="T_5451e_row2_col5" class="data row2 col5" >689</td>
#     </tr>
#     <tr>
#       <td id="T_5451e_row3_col0" class="data row3 col0" >SAC, SJ, ALA, CC, STA, MER, MAD, FRE, KIN, TUL, KER</td>
#       <td id="T_5451e_row3_col1" class="data row3 col1" >75 - HQ</td>
#       <td id="T_5451e_row3_col2" class="data row3 col2" >21</td>
#       <td id="T_5451e_row3_col3" class="data row3 col3" >Water System Upgrade On California Cars</td>
#       <td id="T_5451e_row3_col4" class="data row3 col4" >$ 200.00</td>
#       <td id="T_5451e_row3_col5" class="data row3 col5" >505</td>
#     </tr>
#     <tr>
#       <td id="T_5451e_row4_col0" class="data row4 col0" >LA</td>
#       <td id="T_5451e_row4_col1" class="data row4 col1" >07 - Los Angeles</td>
#       <td id="T_5451e_row4_col2" class="data row4 col2" >9</td>
#       <td id="T_5451e_row4_col3" class="data row4 col3" >I-405 Active Traffic Management (Atm) And Integrated Corridor Management (Icm) Project</td>
#       <td id="T_5451e_row4_col4" class="data row4 col4" >$ 61,473.00</td>
#       <td id="T_5451e_row4_col5" class="data row4 col5" >76</td>
#     </tr>
#     <tr>
#       <td id="T_5451e_row5_col0" class="data row5 col0" >SD</td>
#       <td id="T_5451e_row5_col1" class="data row5 col1" >11 - San Diego</td>
#       <td id="T_5451e_row5_col2" class="data row5 col2" >11</td>
#       <td id="T_5451e_row5_col3" class="data row5 col3" >Lossan Sd Intermodal Improvement Program
# Lossan/Coaster Commuter Rail Bluff Stablization Project</td>
#       <td id="T_5451e_row5_col4" class="data row5 col4" >$ 888,888.00</td>
#       <td id="T_5451e_row5_col5" class="data row5 col5" >187</td>
#     </tr>
#     <tr>
#       <td id="T_5451e_row6_col0" class="data row6 col0" >SOL</td>
#       <td id="T_5451e_row6_col1" class="data row6 col1" >04 - Oakland</td>
#       <td id="T_5451e_row6_col2" class="data row6 col2" >37</td>
#       <td id="T_5451e_row6_col3" class="data row6 col3" >Solano County Transit (Soltrans) Charging Infrastructure</td>
#       <td id="T_5451e_row6_col4" class="data row6 col4" >$ 1,900.00</td>
#       <td id="T_5451e_row6_col5" class="data row6 col5" >205</td>
#     </tr>
#     <tr>
#       <td id="T_5451e_row7_col0" class="data row7 col0" >RIV</td>
#       <td id="T_5451e_row7_col1" class="data row7 col1" >08 - San Bernardino</td>
#       <td id="T_5451e_row7_col2" class="data row7 col2" >54</td>
#       <td id="T_5451e_row7_col3" class="data row7 col3" >Riv 60 Rubidoux Blvd Interchange Improvements</td>
#       <td id="T_5451e_row7_col4" class="data row7 col4" >$ 888,888.00</td>
#       <td id="T_5451e_row7_col5" class="data row7 col5" >494</td>
#     </tr>
#     <tr>
#       <td id="T_5451e_row8_col0" class="data row8 col0" >SBD</td>
#       <td id="T_5451e_row8_col1" class="data row8 col1" >08 - San Bernardino</td>
#       <td id="T_5451e_row8_col2" class="data row8 col2" >62</td>
#       <td id="T_5451e_row8_col3" class="data row8 col3" >Sr-138 Widening - Segment 1</td>
#       <td id="T_5451e_row8_col4" class="data row8 col4" >$ 8,000.00</td>
#       <td id="T_5451e_row8_col5" class="data row8 col5" >587</td>
#     </tr>
#     <tr>
#       <td id="T_5451e_row9_col0" class="data row9 col0" >SD</td>
#       <td id="T_5451e_row9_col1" class="data row9 col1" >11 - San Diego</td>
#       <td id="T_5451e_row9_col2" class="data row9 col2" >15</td>
#       <td id="T_5451e_row9_col3" class="data row9 col3" >Del Mar Bluffs Phase 5 And 6</td>
#       <td id="T_5451e_row9_col4" class="data row9 col4" >$ 70,000.00</td>
#       <td id="T_5451e_row9_col5" class="data

# %% [markdown]
# #### Default is false: runs original style_table function

# %%
test3 = edited_style_table(
    df,
    {"district_full_name": "renamed1", "project_name": "renamed2"},
    ["reduction_in_fatal_and_injury_crashes"],
    ["district_rank"],
    ["fake_benefit_score"],
    [],
    [],
    ["total_project_cost__$1,000_"],
    ["statewide_rank"],
    [],
    [],
    [],
    {},
    True,
)
# Out:
# <style type="text/css">
# #T_bf93e th {
#   text-align: center;
# }
# </style>
# <table id="T_bf93e">
#   <thead>
#     <tr>
#       <th id="T_bf93e_level0_col0" class="col_heading level0 col0" >county</th>
#       <th id="T_bf93e_level0_col1" class="col_heading level0 col1" >renamed1</th>
#       <th id="T_bf93e_level0_col2" class="col_heading level0 col2" >district_rank</th>
#       <th id="T_bf93e_level0_col3" class="col_heading level0 col3" >renamed2</th>
#       <th id="T_bf93e_level0_col4" class="col_heading level0 col4" >total_project_cost__$1,000_</th>
#       <th id="T_bf93e_level0_col5" class="col_heading level0 col5" >statewide_rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bf93e_row0_col0" class="data row0 col0" >ORA</td>
#       <td id="T_bf93e_row0_col1" class="data row0 col1" >12 - Irvine</td>
#       <td id="T_bf93e_row0_col2" class="data row0 col2" >33</td>
#       <td id="T_bf93e_row0_col3" class="data row0 col3" >Rt-55 Costa Mesa Improve Mobility</td>
#       <td id="T_bf93e_row0_col4" class="data row0 col4" >$ 888,888.00</td>
#       <td id="T_bf93e_row0_col5" class="data row0 col5" >455</td>
#     </tr>
#     <tr>
#       <td id="T_bf93e_row1_col0" class="data row1 col0" >MEN</td>
#       <td id="T_bf93e_row1_col1" class="data row1 col1" >01 - Eureka</td>
#       <td id="T_bf93e_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_bf93e_row1_col3" class="data row1 col3" >Gualala Downtown Streetscape Enhacement</td>
#       <td id="T_bf93e_row1_col4" class="data row1 col4" >$ 9,039.00</td>
#       <td id="T_bf93e_row1_col5" class="data row1 col5" >82</td>
#     </tr>
#     <tr>
#       <td id="T_bf93e_row2_col0" class="data row2 col0" >LA</td>
#       <td id="T_bf93e_row2_col1" class="data row2 col1" >07 - Los Angeles</td>
#       <td id="T_bf93e_row2_col2" class="data row2 col2" >115</td>
#       <td id="T_bf93e_row2_col3" class="data row2 col3" >Grade Separation -- Industry/La County</td>
#       <td id="T_bf93e_row2_col4" class="data row2 col4" >$ 86,200.00</td>
#       <td id="T_bf93e_row2_col5" class="data row2 col5" >689</td>
#     </tr>
#     <tr>
#       <td id="T_bf93e_row3_col0" class="data row3 col0" >SAC, SJ, ALA, CC, STA, MER, MAD, FRE, KIN, TUL, KER</td>
#       <td id="T_bf93e_row3_col1" class="data row3 col1" >75 - HQ</td>
#       <td id="T_bf93e_row3_col2" class="data row3 col2" >21</td>
#       <td id="T_bf93e_row3_col3" class="data row3 col3" >Water System Upgrade On California Cars</td>
#       <td id="T_bf93e_row3_col4" class="data row3 col4" >$ 200.00</td>
#       <td id="T_bf93e_row3_col5" class="data row3 col5" >505</td>
#     </tr>
#     <tr>
#       <td id="T_bf93e_row4_col0" class="data row4 col0" >LA</td>
#       <td id="T_bf93e_row4_col1" class="data row4 col1" >07 - Los Angeles</td>
#       <td id="T_bf93e_row4_col2" class="data row4 col2" >9</td>
#       <td id="T_bf93e_row4_col3" class="data row4 col3" >I-405 Active Traffic Management (Atm) And Integrated Corridor Management (Icm) Project</td>
#       <td id="T_bf93e_row4_col4" class="data row4 col4" >$ 61,473.00</td>
#       <td id="T_bf93e_row4_col5" class="data row4 col5" >76</td>
#     </tr>
#     <tr>
#       <td id="T_bf93e_row5_col0" class="data row5 col0" >SD</td>
#       <td id="T_bf93e_row5_col1" class="data row5 col1" >11 - San Diego</td>
#       <td id="T_bf93e_row5_col2" class="data row5 col2" >11</td>
#       <td id="T_bf93e_row5_col3" class="data row5 col3" >Lossan Sd Intermodal Improvement Program
# Lossan/Coaster Commuter Rail Bluff Stablization Project</td>
#       <td id="T_bf93e_row5_col4" class="data row5 col4" >$ 888,888.00</td>
#       <td id="T_bf93e_row5_col5" class="data row5 col5" >187</td>
#     </tr>
#     <tr>
#       <td id="T_bf93e_row6_col0" class="data row6 col0" >SOL</td>
#       <td id="T_bf93e_row6_col1" class="data row6 col1" >04 - Oakland</td>
#       <td id="T_bf93e_row6_col2" class="data row6 col2" >37</td>
#       <td id="T_bf93e_row6_col3" class="data row6 col3" >Solano County Transit (Soltrans) Charging Infrastructure</td>
#       <td id="T_bf93e_row6_col4" class="data row6 col4" >$ 1,900.00</td>
#       <td id="T_bf93e_row6_col5" class="data row6 col5" >205</td>
#     </tr>
#     <tr>
#       <td id="T_bf93e_row7_col0" class="data row7 col0" >RIV</td>
#       <td id="T_bf93e_row7_col1" class="data row7 col1" >08 - San Bernardino</td>
#       <td id="T_bf93e_row7_col2" class="data row7 col2" >54</td>
#       <td id="T_bf93e_row7_col3" class="data row7 col3" >Riv 60 Rubidoux Blvd Interchange Improvements</td>
#       <td id="T_bf93e_row7_col4" class="data row7 col4" >$ 888,888.00</td>
#       <td id="T_bf93e_row7_col5" class="data row7 col5" >494</td>
#     </tr>
#     <tr>
#       <td id="T_bf93e_row8_col0" class="data row8 col0" >SBD</td>
#       <td id="T_bf93e_row8_col1" class="data row8 col1" >08 - San Bernardino</td>
#       <td id="T_bf93e_row8_col2" class="data row8 col2" >62</td>
#       <td id="T_bf93e_row8_col3" class="data row8 col3" >Sr-138 Widening - Segment 1</td>
#       <td id="T_bf93e_row8_col4" class="data row8 col4" >$ 8,000.00</td>
#       <td id="T_bf93e_row8_col5" class="data row8 col5" >587</td>
#     </tr>
#     <tr>
#       <td id="T_bf93e_row9_col0" class="data row9 col0" >SD</td>
#       <td id="T_bf93e_row9_col1" class="data row9 col1" >11 - San Diego</td>
#       <td id="T_bf93e_row9_col2" class="data row9 col2" >15</td>
#       <td id="T_bf93e_row9_col3" class="data row9 col3" >Del Mar Bluffs Phase 5 And 6</td>
#       <td id="T_bf93e_row9_col4" class="data row9 col4" >$ 70,000.00</td>
#       <td id="T_bf93e_row9_col5" class="data row9 col5" >232</td>
#     </tr>
#     <tr>
#       <td id="T_bf93e_row10_col0" class="data row10 col0" >LA</td>
#       <td id="T_bf93e_row10_col1" class="data row10 col1" >07 - Los Angeles</td>
#       <td id="T_bf93e_row10_col2" class="data row10 col2" >5</td>
#       <td id="T_bf93e_row10_col3" class="data row10 col3" >La-Sb Dedicated Passenger Corridor: Early Start On 4Th Main Hobart Through Commerce</td>
#       <td id="T_bf93e_row10_col4" class="data row10 col4" >$ 777,100.00</td>
#       <td id="T_bf93e_row10_col5" class="data row10 col5" >50</td>
#     </tr>
#     <tr>
#       <td id="T_bf93e_row11_col0" class="data row11 col0" >ALA</td>
#       <td id="T_bf93e_row11_col1" class="data row11 col1" >04 - Oakland</td>
#       <td id="T_bf93e_row11_col2" class="data row11 col2" >20</td>
#       <td id="T_bf93e_row11_col3" class="data row11 col3" >Oakland Gateway Zero Emission Drayage Truck Infrastructure Development Project</td>
#       <td id="T_bf93e_row11_col4" class="data row11 col4" >$ 12,000.00</td>
#       <td id="T_bf93e_row11_col5" class="data row11 col5" >135</td>
#     </tr>
#     <tr>
#       <td id="T_bf93e_row12_col0" class="data row12 col0" >LA</td>
#       <td id="T_bf93e_row12_col1" class="data row12 col1" >07 - Los Angeles</td>
#       <td id="T_bf93e_row12_col2" class="data row12 col2" >111</td>
#       <td id="T_bf93e_row12_col3" class="data row12 col3" >La 405 South Hov To Hot Express Lane Conversion</td>
#       <td id="T_bf93e_row12_col4" class="data row12 col4" >$ 888,888.00</td>
#       <td id="T_bf93e_row12_col5" class="data row12 col5" >672</td>
#     </tr>
#     <tr>
#       <td id="T_bf93e_row13_col0" class="data row13 col0" >HUM</td>
#       <td id="T_bf93e_row13_col1" class="data row13 col1" >01 - Eureka</td>
#       <td id="T_bf93e_row13_col2" class="data row13 col2" >2</td>
#       <td id="T_bf93e_row13_col3" class="data row13 col3" >Eureka Adaptive Signals Project</td>
#       <td id="T_bf93e_row13_col4" class="data row13 col4" >$ 1,500.00</td>
#       <td id="T_bf93e_row13_col5" class="data row13 col5" >46</td>
#     </tr>
#     <tr>
#       <td id="T_bf93e_row14_col0" class="data row14 col0" >SBD</td>
#       <td id="T_bf93e_row14_col1" class="data row14 col1" >08 - San Bernardino</td>
#       <td id="T_bf93e_row14_col2" class="data row14 col2" >71</td>
#       <td id="T_bf93e_row14_col3" class="data row14 col3" >Sbd 15 Express Lanes</td>
#       <td id="T_bf93e_row14_col4" class="data row14 col4" >$ 888,888.00</td>
#       <td id="T_bf93e_row14_col5" class="data row14 col5" >703</td>
#     </tr>
#     <tr>
#       <td id="T_bf93e_row15_col0" c

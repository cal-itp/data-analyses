# %% [markdown]
# # Additional styling to a dataframe.
# * By default, bool is False and will return original dataframe without a scrollbar.
# * When bool is true, will return a dataframe with a scrollbar for any overflow content.
# * You can change the height, width, and font size based.

# %%
import pandas as pd
import pandas.io.formats.style
from IPython.display import HTML, Image, Markdown, display, display_html

# %%
GCS_FILE_PATH = "gs://calitp-analytics-data/data-analyses/project_prioritization/"
FILE = "fake_data.xlsx"

# %%
df = pd.read_excel(f"{GCS_FILE_PATH}{FILE}", sheet_name="fake")

# %%
df = df[
    [
        "county",
        "district_full_name",
        "district_rank",
        "project_name",
        "total_project_cost__$1,000_",
        "reduction_in_fatal_and_injury_crashes",
        "statewide_rank",
    ]
].sample(20)

# %%
def edited_style_table(
    df: pd.DataFrame,
    rename_cols: dict = {},
    drop_cols: list = [],
    integer_cols: list = [],
    one_decimal_cols: list = [],
    two_decimal_cols: list = [],
    three_decimal_cols: list = [],
    currency_cols: list = [],
    percent_cols: list = [],
    left_align_cols: list = "first",  # by default, left align first col
    center_align_cols: list = "all",  # by default, center align all other cols
    right_align_cols: list = [],
    custom_format_cols: dict = {},
    display_table: bool = True,
    display_scrollbar: bool = False,
    scrollbar_font: str = "10px",
    scrollbar_height: str = "400px",
    scrollbar_width: str = "fit-content",
) -> pd.io.formats.style.Styler:
    """
    Returns a pandas Styler object with some basic formatting.
    Even if display_table is True, pandas Styler object returned,
    just with a display() happening in the notebook cell.
    Any other tweaks for currency, percentages, etc should be done before / after,
    if it can't be put into custom_format_cols.

    custom_format_cols = {
        '{:,.1%}': ['colA', 'colB']
    }

    Generalize with dict comprehension or list comprehension
    list comprehension: df.style.format(subset=percent_cols,  **{'formatter': '{:,.2%}'})
    dict comprehension: df.style.format(formatter = {c: '{:,.2%}' for c in percent_cols})
    """
    df = df.drop(columns=drop_cols).rename(columns=rename_cols)

    if len(integer_cols) > 0:
        df = df.astype({c: "Int64" for c in integer_cols})

    if left_align_cols == "first":
        left_align_cols = list(df.columns)[0]
    if center_align_cols == "all":
        center_align_cols = list(df.columns)
        # all other columns except first one is center aligned
        center_align_cols = [c for c in center_align_cols if c not in left_align_cols]

    df_style = (
        df.style.format(formatter={c: "{:,g}" for c in integer_cols})
        .format(formatter={c: "{:,.1f}" for c in one_decimal_cols})
        .format(formatter={c: "{:,.2f}" for c in two_decimal_cols})
        .format(formatter={c: "{:,.3f}" for c in three_decimal_cols})
        .format(formatter={c: "{:,.2%}" for c in percent_cols})
        .format(formatter={c: "$ {:,.2f}" for c in currency_cols})
        .set_properties(subset=left_align_cols, **{"text-align": "left"})
        .set_properties(subset=center_align_cols, **{"text-align": "center"})
        .set_properties(subset=right_align_cols, **{"text-align": "right"})
        .set_table_styles([dict(selector="th", props=[("text-align", "center")])])
        .hide(axis="index")
    )

    def add_custom_format(
        df_style: pd.io.formats.style.Styler,
        format_str: str,
        cols_to_format: list,
    ) -> pd.io.formats.style.Styler:
        """
        Appends any additional formatting needs.
            key: format string, such as '{:.1%}'
            value: list of columns to apply that formatter to.
        """
        new_styler = df_style.format(formatter={c: format_str for c in cols_to_format})

        return new_styler

    if len(list(custom_format_cols.keys())) > 0:
        for format_str, cols_to_format in custom_format_cols.items():
            df_style = add_custom_format(df_style, format_str, cols_to_format)

    if display_table is True:
        if display_scrollbar is True:
            display(
                HTML(
                    f"<div style='height: {scrollbar_height}; overflow: auto; width: {scrollbar_width}'>"
                    + (
                        (df_style)
                        .set_properties(
                            **{
                                "font-size": scrollbar_font,
                            }
                        )
                        .render()
                    )
                    + "</div>"
                )
            )
        else:
            display(HTML(df_style.to_html()))

    return df_style

# %% [markdown]
# #### When you turn on "true" for scrollbar and input your own arguments.

# %%
test1 = edited_style_table(
    df,
    {"district_full_name": "renamed1", "project_name": "renamed2"},
    ["reduction_in_fatal_and_injury_crashes"],
    ["district_rank"],
    ["fake_benefit_score"],
    [],
    [],
    ["total_project_cost__$1,000_"],
    ["statewide_rank"],
    [],
    [],
    [],
    {},
    True,
    True,
    "9px",
    "250px",
    "650px",
)
# Out:
# /tmp/ipykernel_1831/95536299.py:92: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   .render()
# <div style='height: 250px; overflow: auto; width: 650px'><style type="text/css">
# #T_6709b th {
#   text-align: center;
# }
# #T_6709b_row0_col0, #T_6709b_row0_col1, #T_6709b_row0_col2, #T_6709b_row0_col3, #T_6709b_row0_col4, #T_6709b_row0_col5, #T_6709b_row1_col0, #T_6709b_row1_col1, #T_6709b_row1_col2, #T_6709b_row1_col3, #T_6709b_row1_col4, #T_6709b_row1_col5, #T_6709b_row2_col0, #T_6709b_row2_col1, #T_6709b_row2_col2, #T_6709b_row2_col3, #T_6709b_row2_col4, #T_6709b_row2_col5, #T_6709b_row3_col0, #T_6709b_row3_col1, #T_6709b_row3_col2, #T_6709b_row3_col3, #T_6709b_row3_col4, #T_6709b_row3_col5, #T_6709b_row4_col0, #T_6709b_row4_col1, #T_6709b_row4_col2, #T_6709b_row4_col3, #T_6709b_row4_col4, #T_6709b_row4_col5, #T_6709b_row5_col0, #T_6709b_row5_col1, #T_6709b_row5_col2, #T_6709b_row5_col3, #T_6709b_row5_col4, #T_6709b_row5_col5, #T_6709b_row6_col0, #T_6709b_row6_col1, #T_6709b_row6_col2, #T_6709b_row6_col3, #T_6709b_row6_col4, #T_6709b_row6_col5, #T_6709b_row7_col0, #T_6709b_row7_col1, #T_6709b_row7_col2, #T_6709b_row7_col3, #T_6709b_row7_col4, #T_6709b_row7_col5, #T_6709b_row8_col0, #T_6709b_row8_col1, #T_6709b_row8_col2, #T_6709b_row8_col3, #T_6709b_row8_col4, #T_6709b_row8_col5, #T_6709b_row9_col0, #T_6709b_row9_col1, #T_6709b_row9_col2, #T_6709b_row9_col3, #T_6709b_row9_col4, #T_6709b_row9_col5, #T_6709b_row10_col0, #T_6709b_row10_col1, #T_6709b_row10_col2, #T_6709b_row10_col3, #T_6709b_row10_col4, #T_6709b_row10_col5, #T_6709b_row11_col0, #T_6709b_row11_col1, #T_6709b_row11_col2, #T_6709b_row11_col3, #T_6709b_row11_col4, #T_6709b_row11_col5, #T_6709b_row12_col0, #T_6709b_row12_col1, #T_6709b_row12_col2, #T_6709b_row12_col3, #T_6709b_row12_col4, #T_6709b_row12_col5, #T_6709b_row13_col0, #T_6709b_row13_col1, #T_6709b_row13_col2, #T_6709b_row13_col3, #T_6709b_row13_col4, #T_6709b_row13_col5, #T_6709b_row14_col0, #T_6709b_row14_col1, #T_6709b_row14_col2, #T_6709b_row14_col3, #T_6709b_row14_col4, #T_6709b_row14_col5, #T_6709b_row15_col0, #T_6709b_row15_col1, #T_6709b_row15_col2, #T_6709b_row15_col3, #T_6709b_row15_col4, #T_6709b_row15_col5, #T_6709b_row16_col0, #T_6709b_row16_col1, #T_6709b_row16_col2, #T_6709b_row16_col3, #T_6709b_row16_col4, #T_6709b_row16_col5, #T_6709b_row17_col0, #T_6709b_row17_col1, #T_6709b_row17_col2, #T_6709b_row17_col3, #T_6709b_row17_col4, #T_6709b_row17_col5, #T_6709b_row18_col0, #T_6709b_row18_col1, #T_6709b_row18_col2, #T_6709b_row18_col3, #T_6709b_row18_col4, #T_6709b_row18_col5, #T_6709b_row19_col0, #T_6709b_row19_col1, #T_6709b_row19_col2, #T_6709b_row19_col3, #T_6709b_row19_col4, #T_6709b_row19_col5 {
#   font-size: 9px;
# }
# </style>
# <table id="T_6709b">
#   <thead>
#     <tr>
#       <th id="T_6709b_level0_col0" class="col_heading level0 col0" >county</th>
#       <th id="T_6709b_level0_col1" class="col_heading level0 col1" >renamed1</th>
#       <th id="T_6709b_level0_col2" class="col_heading level0 col2" >district_rank</th>
#       <th id="T_6709b_level0_col3" class="col_heading level0 col3" >renamed2</th>
#       <th id="T_6709b_level0_col4" class="col_heading level0 col4" >total_project_cost__$1,000_</th>
#       <th id="T_6709b_level0_col5" class="col_heading level0 col5" >statewide_rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6709b_row0_col0" class="data row0 col0" >STA</td>
#       <td id="T_6709b_row0_col1" class="data row0 col1" >10 - Stockton</td>
#       <td id="T_6709b_row0_col2" class="data row0 col2" >38</td>
#       <td id="T_6709b_row0_col3" class="data row0 col3" >North County Corridor Tully Rd To Sr-120 (New Sr-108)</td>
#       <td id="T_6709b_row0_col4" class="data row0 col4" >$ 163,000.00</td>
#       <td id="T_6709b_row0_col5" class="data row0 col5" >372</td>
#     </tr>
#     <tr>
#       <td id="T_6709b_row1_col0" class="data row1 col0" >LA</td>
#       <td id="T_6709b_row1_col1" class="data row1 col1" >07 - Los Angeles</td>
#       <td id="T_6709b_row1_col2" class="data row1 col2" >115</td>
#       <td id="T_6709b_row1_col3" class="data row1 col3" >Grade Separation -- Industry/La County</td>
#       <td id="T_6709b_row1_col4" class="data row1 col4" >$ 86,200.00</td>
#       <td id="T_6709b_row1_col5" class="data row1 col5" >689</td>
#     </tr>
#     <tr>
#       <td id="T_6709b_row2_col0" class="data row2 col0" >SBD</td>
#       <td id="T_6709b_row2_col1" class="data row2 col1" >08 - San Bernardino</td>
#       <td id="T_6709b_row2_col2" class="data row2 col2" >44</td>
#       <td id="T_6709b_row2_col3" class="data row2 col3" >Sbd-210 Construct Victoria Ave Ic</td>
#       <td id="T_6709b_row2_col4" class="data row2 col4" >$ 888,888.00</td>
#       <td id="T_6709b_row2_col5" class="data row2 col5" >407</td>
#     </tr>
#     <tr>
#       <td id="T_6709b_row3_col0" class="data row3 col0" >MER</td>
#       <td id="T_6709b_row3_col1" class="data row3 col1" >10 - Stockton</td>
#       <td id="T_6709b_row3_col2" class="data row3 col2" >29</td>
#       <td id="T_6709b_row3_col3" class="data row3 col3" >Altamont Corridor Vision</td>
#       <td id="T_6709b_row3_col4" class="data row3 col4" >$ 888,888.00</td>
#       <td id="T_6709b_row3_col5" class="data row3 col5" >297</td>
#     </tr>
#     <tr>
#       <td id="T_6709b_row4_col0" class="data row4 col0" >LA</td>
#       <td id="T_6709b_row4_col1" class="data row4 col1" >07 - Los Angeles</td>
#       <td id="T_6709b_row4_col2" class="data row4 col2" >24</td>
#       <td id="T_6709b_row4_col3" class="data row4 col3" >Aux Lane Construction</td>
#       <td id="T_6709b_row4_col4" class="data row4 col4" >$ 888,888.00</td>
#       <td id="T_6709b_row4_col5" class="data row4 col5" >165</td>
#     </tr>
#     <tr>
#       <td id="T_6709b_row5_col0" class="data row5 col0" >SAC</td>
#       <td id="T_6709b_row5_col1" class="data row5 col1" >03 - Marysville</td>
#       <td id="T_6709b_row5_col2" class="data row5 col2" >40</td>
#       <td id="T_6709b_row5_col3" class="data row5 col3" >State Route 51 Corridor Improvements: J Street To Arden Way
# Capital City Freeway Managed Lanes</td>
#       <td id="T_6709b_row5_col4" class="data row5 col4" >$ 437,400.00</td>
#       <td id="T_6709b_row5_col5" class="data row5 col5" >705</td>
#     </tr>
#     <tr>
#       <td id="T_6709b_row6_col0" class="data row6 col0" >VEN</td>
#       <td id="T_6709b_row6_col1" class="data row6 col1" >07 - Los Angeles</td>
#       <td id="T_6709b_row6_col2" class="data row6 col2" >46</td>
#       <td id="T_6709b_row6_col3" class="data row6 col3" >Port Capacity Expansion - Ln Widening</td>
#       <td id="T_6709b_row6_col4" class="data row6 col4" >$ 7,000.00</td>
#       <td id="T_6709b_row6_col5" class="data row6 col5" >300</td>
#     </tr>
#     <tr>
#       <td id="T_6709b_row7_col0" class="data row7 col0" >SJ</td>
#       <td id="T_6709b_row7_col1" class="data row7 col1" >10 - Stockton</td>
#       <td id="T_6709b_row7_col2" class="data row7 col2" >8</td>
#       <td id="T_6709b_row7_col3" class="data row7 col3" >Sr 120/Guthmiller Rd. Interchange Improvement</td>
#       <td id="T_6709b_row7_col4" class="data row7 col4" >$ 888,888.00</td>
#       <td id="T_6709b_row7_col5" class="data row7 col5" >57</td>
#     </tr>
#     <tr>
#       <td id="T_6709b_row8_col0" class="data row8 col0" >SBD</td>
#       <td id="T_6709b_row8_col1" class="data row8 col1" >08 - San Bernardino</td>
#       <td id="T_6709b_row8_col2" class="data row8 col2" >40</td>
#       <td id="T_6709b_row8_col3" class="data row8 col3" >Fontana Truck Parking</td>
#       <td id="T_6709b_row8_col4" class="data row8 col4" >$ 25,950.00</td>
#       <td id="T_6709b_row8_col5" class="data row8 col5" >334</td>
#     </tr>
#     <tr>
#       <td id="T_6709b_row9_col0" class="data row9 col0" >SD</td>
#       <td id="T_6709b_row9_col1" class="data row9 col1" >11 - San Diego</td>
#       <td id="T_6709b_row9_col2" class="data row9 col2" >22</td>
#       <td id="T_6709b_row9_col3" class="data row9 col3" >Central Mobility Hub</td>
#       <td id="T_6709b_row9_col4" class="data row9 col4" >$ 888,888.00</td>
#       <td id="T_6709b_row9_col5" class="data row9 col5" >340</td>
#     </tr>
#     <tr>
#       <td id="T_6709b_row10_col0" class="data row10 col0" >HUM</td>
#       <td id="T_6709b_

# %% [markdown]
# #### Default is false: runs original style_table function

# %%
test2 = edited_style_table(
    df,
    {"district_full_name": "renamed1", "project_name": "renamed2"},
    ["reduction_in_fatal_and_injury_crashes"],
    ["district_rank"],
    ["fake_benefit_score"],
    [],
    [],
    ["total_project_cost__$1,000_"],
    ["statewide_rank"],
    [],
    [],
    [],
    {},
    True,
)
# Out:
# <style type="text/css">
# #T_46d93 th {
#   text-align: center;
# }
# </style>
# <table id="T_46d93">
#   <thead>
#     <tr>
#       <th id="T_46d93_level0_col0" class="col_heading level0 col0" >county</th>
#       <th id="T_46d93_level0_col1" class="col_heading level0 col1" >renamed1</th>
#       <th id="T_46d93_level0_col2" class="col_heading level0 col2" >district_rank</th>
#       <th id="T_46d93_level0_col3" class="col_heading level0 col3" >renamed2</th>
#       <th id="T_46d93_level0_col4" class="col_heading level0 col4" >total_project_cost__$1,000_</th>
#       <th id="T_46d93_level0_col5" class="col_heading level0 col5" >statewide_rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_46d93_row0_col0" class="data row0 col0" >STA</td>
#       <td id="T_46d93_row0_col1" class="data row0 col1" >10 - Stockton</td>
#       <td id="T_46d93_row0_col2" class="data row0 col2" >38</td>
#       <td id="T_46d93_row0_col3" class="data row0 col3" >North County Corridor Tully Rd To Sr-120 (New Sr-108)</td>
#       <td id="T_46d93_row0_col4" class="data row0 col4" >$ 163,000.00</td>
#       <td id="T_46d93_row0_col5" class="data row0 col5" >372</td>
#     </tr>
#     <tr>
#       <td id="T_46d93_row1_col0" class="data row1 col0" >LA</td>
#       <td id="T_46d93_row1_col1" class="data row1 col1" >07 - Los Angeles</td>
#       <td id="T_46d93_row1_col2" class="data row1 col2" >115</td>
#       <td id="T_46d93_row1_col3" class="data row1 col3" >Grade Separation -- Industry/La County</td>
#       <td id="T_46d93_row1_col4" class="data row1 col4" >$ 86,200.00</td>
#       <td id="T_46d93_row1_col5" class="data row1 col5" >689</td>
#     </tr>
#     <tr>
#       <td id="T_46d93_row2_col0" class="data row2 col0" >SBD</td>
#       <td id="T_46d93_row2_col1" class="data row2 col1" >08 - San Bernardino</td>
#       <td id="T_46d93_row2_col2" class="data row2 col2" >44</td>
#       <td id="T_46d93_row2_col3" class="data row2 col3" >Sbd-210 Construct Victoria Ave Ic</td>
#       <td id="T_46d93_row2_col4" class="data row2 col4" >$ 888,888.00</td>
#       <td id="T_46d93_row2_col5" class="data row2 col5" >407</td>
#     </tr>
#     <tr>
#       <td id="T_46d93_row3_col0" class="data row3 col0" >MER</td>
#       <td id="T_46d93_row3_col1" class="data row3 col1" >10 - Stockton</td>
#       <td id="T_46d93_row3_col2" class="data row3 col2" >29</td>
#       <td id="T_46d93_row3_col3" class="data row3 col3" >Altamont Corridor Vision</td>
#       <td id="T_46d93_row3_col4" class="data row3 col4" >$ 888,888.00</td>
#       <td id="T_46d93_row3_col5" class="data row3 col5" >297</td>
#     </tr>
#     <tr>
#       <td id="T_46d93_row4_col0" class="data row4 col0" >LA</td>
#       <td id="T_46d93_row4_col1" class="data row4 col1" >07 - Los Angeles</td>
#       <td id="T_46d93_row4_col2" class="data row4 col2" >24</td>
#       <td id="T_46d93_row4_col3" class="data row4 col3" >Aux Lane Construction</td>
#       <td id="T_46d93_row4_col4" class="data row4 col4" >$ 888,888.00</td>
#       <td id="T_46d93_row4_col5" class="data row4 col5" >165</td>
#     </tr>
#     <tr>
#       <td id="T_46d93_row5_col0" class="data row5 col0" >SAC</td>
#       <td id="T_46d93_row5_col1" class="data row5 col1" >03 - Marysville</td>
#       <td id="T_46d93_row5_col2" class="data row5 col2" >40</td>
#       <td id="T_46d93_row5_col3" class="data row5 col3" >State Route 51 Corridor Improvements: J Street To Arden Way
# Capital City Freeway Managed Lanes</td>
#       <td id="T_46d93_row5_col4" class="data row5 col4" >$ 437,400.00</td>
#       <td id="T_46d93_row5_col5" class="data row5 col5" >705</td>
#     </tr>
#     <tr>
#       <td id="T_46d93_row6_col0" class="data row6 col0" >VEN</td>
#       <td id="T_46d93_row6_col1" class="data row6 col1" >07 - Los Angeles</td>
#       <td id="T_46d93_row6_col2" class="data row6 col2" >46</td>
#       <td id="T_46d93_row6_col3" class="data row6 col3" >Port Capacity Expansion - Ln Widening</td>
#       <td id="T_46d93_row6_col4" class="data row6 col4" >$ 7,000.00</td>
#       <td id="T_46d93_row6_col5" class="data row6 col5" >300</td>
#     </tr>
#     <tr>
#       <td id="T_46d93_row7_col0" class="data row7 col0" >SJ</td>
#       <td id="T_46d93_row7_col1" class="data row7 col1" >10 - Stockton</td>
#       <td id="T_46d93_row7_col2" class="data row7 col2" >8</td>
#       <td id="T_46d93_row7_col3" class="data row7 col3" >Sr 120/Guthmiller Rd. Interchange Improvement</td>
#       <td id="T_46d93_row7_col4" class="data row7 col4" >$ 888,888.00</td>
#       <td id="T_46d93_row7_col5" class="data row7 col5" >57</td>
#     </tr>
#     <tr>
#       <td id="T_46d93_row8_col0" class="data row8 col0" >SBD</td>
#       <td id="T_46d93_row8_col1" class="data row8 col1" >08 - San Bernardino</td>
#       <td id="T_46d93_row8_col2" class="data row8 col2" >40</td>
#       <td id="T_46d93_row8_col3" class="data row8 col3" >Fontana Truck Parking</td>
#       <td id="T_46d93_row8_col4" class="data row8 col4" >$ 25,950.00</td>
#       <td id="T_46d93_row8_col5" class="data row8 col5" >334</td>
#     </tr>
#     <tr>
#       <td id="T_46d93_row9_col0" class="data row9 col0" >SD</td>
#       <td id="T_46d93_row9_col1" class="data row9 col1" >11 - San Diego</td>
#       <td id="T_46d93_row9_col2" class="data row9 col2" >22</td>
#       <td id="T_46d93_row9_col3" class="data row9 col3" >Central Mobility Hub</td>
#       <td id="T_46d93_row9_col4" class="data row9 col4" >$ 888,888.00</td>
#       <td id="T_46d93_row9_col5" class="data row9 col5" >340</td>
#     </tr>
#     <tr>
#       <td id="T_46d93_row10_col0" class="data row10 col0" >HUM</td>
#       <td id="T_46d93_row10_col1" class="data row10 col1" >01 - Eureka</td>
#       <td id="T_46d93_row10_col2" class="data row10 col2" >9</td>
#       <td id="T_46d93_row10_col3" class="data row10 col3" >Equitable And Sustainable Public Transit Planning For Rural America</td>
#       <td id="T_46d93_row10_col4" class="data row10 col4" >$ 3,000.00</td>
#       <td id="T_46d93_row10_col5" class="data row10 col5" >239</td>
#     </tr>
#     <tr>
#       <td id="T_46d93_row11_col0" class="data row11 col0" >SAC</td>
#       <td id="T_46d93_row11_col1" class="data row11 col1" >03 - Marysville</td>
#       <td id="T_46d93_row11_col2" class="data row11 col2" >1</td>
#       <td id="T_46d93_row11_col3" class="data row11 col3" >Pollock Siding To South Sacramento Siding Extension</td>
#       <td id="T_46d93_row11_col4" class="data row11 col4" >$ 30,000.00</td>
#       <td id="T_46d93_row11_col5" class="data row11 col5" >7</td>
#     </tr>
#     <tr>
#       <td id="T_46d93_row12_col0" class="data row12 col0" >SUT</td>
#       <td id="T_46d93_row12_col1" class="data row12 col1" >03 - Marysville</td>
#       <td id="T_46d93_row12_col2" class="data row12 col2" >35</td>
#       <td id="T_46d93_row12_col3" class="data row12 col3" >Roadway Grade Separations: Catlett Road/Uprr Sacramento Sub</td>
#       <td id="T_46d93_row12_col4" class="data row12 col4" >$ 35,000.00</td>
#       <td id="T_46d93_row12_col5" class="data row12 col5" >576</td>
#     </tr>
#     <tr>
#       <td id="T_46d93_row13_col0" class="data row13 col0" >STA</td>
#       <td id="T_46d93_row13_col1" class="data row13 col1" >10 - Stockton</td>
#       <td id="T_46d93_row13_col2" class="data row13 col2" >48</td>
#       <td id="T_46d93_row13_col3" class="data row13 col3" >Fresno Subdivision (Ceres To Turlock) Double Tracking</td>
#       <td id="T_46d93_row13_col4" class="data row13 col4" >$ 133,400.00</td>
#       <td id="T_46d93_row13_col5" class="data row13 col5" >537</td>
#     </tr>
#     <tr>
#       <td id="T_46d93_row14_col0" class="data row14 col0" >KER</td>
#       <td id="T_46d93_row14_col1" class="data row14 col1" >06 - Fresno</td>
#       <td id="T_46d93_row14_col2" class="data row14 col2" >79</td>
#       <td id="T_46d93_row14_col3" class="data row14 col3" >Sr 204 Slope Paving, Sidewalk Gap Closures, And Artwork</td>
#       <td id="T_46d93_row14_col4" class="data row14 col4" >$ 3,174.00</td>
#       <td id="T_46d93_row14_col5" class="data row14 col5" >669</td>
#     </tr>
#     <tr>
#       <td id="T_46d93_row15_col0" class="data row15 col0" >TEH</td>
#       <td id="T_46d93_row15_col1" class="data row15 col1" >02 - Redding</td

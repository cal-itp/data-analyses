# %% [markdown]
# # Add ATP Projects to Project List

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
from calitp import to_snakecase
from dla_utils import _dla_utils
from IPython.display import HTML, Markdown
from siuba import *
# Out:
# /opt/conda/lib/python3.9/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.10.3-CAPI-1.16.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
pd.set_option("display.max_columns",500)

# %%
atp = pd.read_csv('gs://calitp-analytics-data/data-analyses/dla/atp/cleaned_atp_010323.csv', index_col=[0])
# Out:
# /opt/conda/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3433: DtypeWarning: Columns (12,13,14,74,92,93,95,102,104,106,110,121,134,139,141,151,152,161,170,172,224,225,226,227,228,229,230,231,232,235,237,239,241,243,251,258,261,265,272,274,275,283,284,285,286,287) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
atp_funded = atp>>filter(_.awarded=='Y')

# %%
len(atp)
# Out:
# 2762

# %%
len(atp_funded)
# Out:
# 49

# %%
## old
# shopp = to_snakecase(pd.read_excel('gs://calitp-analytics-data/data-analyses/project_prioritization/fake_data.xlsx'))

## updated
shopp = to_snakecase(pd.read_excel('gs://calitp-analytics-data/data-analyses/project_prioritization/cleaned_data_with_fake_metrics.xlsx'))

# %%
shopp.sample()
# Out:
#     rail_project_id  _10_year_plan ct_project_id  update_complete    ea  ppno  \
# 672         NC_0092              0          None                1  None  None
#
#                 project_name  district county route  \
# 672  Turlock-Denair Bus Loop        75    STA   Off
#
#                                    project_description current_phase  \
# 672  A dedicated bus loop to allow for a passenger ...     COMPLETED
#
#     con_existing_source_s__of_funds con_anticipated_source_of_funds  \
# 672                            None                            None
#
#     target_opening_year beg_pm end_pm      primary_mode  \
# 672                None   None   None  Rail (Passenger)
#
#                 previous_caltrans_nominations urban_rural  \
# 672  DRMT Consolidated Statewide Project List       Urban
#
#                                                 notes  lead_agency  \
# 672  Final Design coordinating with Stanislaus County  Sjjpa/Sjrrc
#
#     pid_approval_date__m010 target_pa_ed__m200  rtl_date__m460  \
# 672          datetime64[ns]               None  datetime64[ns]
#
#     con_start_date__m500  funding_need_phase_s  pa_ed_cost__$1,000  \
# 672       datetime64[ns]                     0                   0
#
#      ps_e_cost__$1,000  row_cost__$1,000  con_support_cost__$1,000  \
# 672                  0                 0                         0
#
#      non_infrastructure___plan_cost__$1,000  total_unfunded_need__$1,000  \
# 672                                       0                         0.00
#
#     previous_funding_request_phase  last_scored    csis_alignment  \
# 672                           None            0  Not Well-Aligned
#
#      csis_total_score__out_of_45  mode_shift__csis__score  \
# 672                            0                        0
#
#     mode_shift__csis__comment  vmt__csis__score vmt__csis__comment  \
# 672                      None                 0               None
#
#      public_engagement__csis__score public_engagement__csis__comment  \
# 672                               0                             None
#
#      dac_local_community_needs__csis__score  \
# 672                                       0
#
#      dac_local_community_needs__csis__comment  safety__csis__score  \
# 672                                         0                    0
#
#     safety__csis__comment  zev__csis__score zev__csis__comment  \
# 672                  None                 0               None
#
#      climate_resiliency__csis__score climate_resiliency__csis__comment  \
# 672                                0                              None
#
#      natural_resources_and_ecosystems__csis__score  \
# 672                                              0
#
#     natural_resources_and_ecosystems__csis__comment  \
# 672                                            None
#
#      infill_development_and_land_use__csis__score  \
# 672                                             0
#
#     infill_development_and_land_use__csis__comment  \
# 672                                           None
#
#      benefits_to_dac_and_advancing_equity__atp__score  \
# 672                                                 0
#
#      community_need__atp__score  safety__atp__score  \
# 672                           0                   0
#
#      public_participation__atp__score  community_feedback__atp__score  \
# 672                                 0                               0
#
#      continued_engagement__atp__score  \
# 672                                 0
#
#      context_sensitive_and_innovation__atp__score  transformative__atp__score  \
# 672                                             0                           0
#
#      atp_total_score__out_of_100     atp_alignment access_alignment  \
# 672                            0  Not Well-Aligned             None
#
#     previous_funding_request            modified                 modified_by  \
# 672                     None 2022-12-29 11:44:17  madison.buccola@dot.ca.gov
#
#      purpose___need parcel_counts  total_project_cost__$1,000  \
# 672               0          None                      600.00
#
#      con_capital_cost__$1,000  hq_priority  district_priority  \
# 672                         0            0                  0
#
#     potential_funding_program_s located_in_dac shs_capacity_increase_detail  \
# 672  Crisi\nIntercity Pass Rail           None                         None
#
#     secondary_mode_s full_county_name               detailed_project_title  \
# 672             None       Stanislaus  District 75-Turlock-Denair Bus Loop
#
#     district_full_name  increase_peak_person_throughput  \
# 672            75 - HQ                             5.63
#
#      reduction_in_peak_period_delay  reduction_in_fatal_and_injury_crashes  \
# 672                            6.40                                   4.14
#
#      reduction_in_injury_rates  increase_access_to_jobs  \
# 672                      19.62                    35.95
#
#      increase_access_jobs_to_dac  commercial_dev_developed  \
# 672                         1.70                     31.71
#
#      tons_of_goods_impacted  improve_air_quality  impact_natural_resources  \
# 672                    7.75                32.39                     17.70
#
#      support_of_transportation  fake_benefit_score  statewide_rank  \
# 672                      45.26                1.32          710.00
#
#      district_rank fake_benefit_score_statewide_percentile  \
# 672            199                         75th percentile
#
#      district_district_median  total_project_cost__$1,000__district_median  \
# 672                        75                                    42,000.00
#
#      fake_benefit_score_district_median  \
# 672                                1.71
#
#      total_unfunded_need__$1,000__district_median  \
# 672                                         20000
#
#      csis_total_score__out_of_45__district_median  \
# 672                                             0
#
#      atp_total_score__out_of_100__district_median
# 672                                             0

# %%
## checking if atp is in the caltrans nominations
list(shopp['previous_caltrans_nominations'])
# Out:
# ['SHOPP',
#  'CA Coastal Trail Candidate Projects (Coastal Commission)',
#  'CA Coastal Trail Candidate Projects (Coastal Commission)',
#  'RAISE 2021 LOS Signed',
#  'FY 22-23 Non-SHOPP PID Priority List',
#  'MONSTER',
#  'FY 21-22 Non-SHOPP PID Nomination (New)',
#  'MONSTER',
#  'FY 22-23 Non-SHOPP PID Priority List',
#  'SHOPP',
#  'Federal Community Projects 2021 Sponsored\nStimulus Drill',
#  'SHOPP',
#  'Programmed State Transportation Improvement Program (STIP)\nMONSTER',
#  '2020 STIP (RIP)',
#  'Programmed State Transportation Improvement Program (STIP)\nMONSTER',
#  'ATP Cycle 6 Intake \nReconnecting Communities 2022 Nomination Rank 3',
#  'CA Coastal Trail Candidate Projects (Coastal Commission)',
#  'CA Coastal Trail Candidate Projects (Coastal Commission)',
#  'ATP Cycle 6 Partner Application',
#  'MONSTER',
#  'None',
#  'MONSTER',
#  'RAISE 2021 LOS Signed\nRAISE 2022 LOS Signed',
#  'MONSTER',
#  'FY 21-22 Non-SHOPP PID Nomination (Carryover)',
#  'SHOPP',
#  'RAISE 2021 LOS (Rank 31 of 41)\nStimulus Drill 2021\nTCEP Cycle 2 Priority 26 of 26 (No award)\n2022 ITIP (Carryover)\nACCESS Project List',
#  'RURAL 2022 (MPDG) Caltrans Application; did not move forward.\nRAISE 2021 LOS Maybe\nTCEP Cycle 2 Priority 26 of 26 (No award)\nTCEP Cycle 3 Priority 18 of 24\n2018 STIP (PS&E)\nStimulus Drill 2021\nACCESS Project List',
#  'SHOPP',
#  'CA Coastal Trail Candidate Projects (Coastal Commission)',
#  'CA Coastal Trail Candidate Projects (Coastal Commission)',
#  'MONSTER\nSHOPP ID',
#  'FY 21-22 Non-SHOPP PID Nomination (Carryover)',
#  'RAISE 2021 Nominations\nTCEP Cycle 1 Award \nTCEP Cycle 2 Priority 16 of 26 (Awarded)\nTCEP Cycle 3 Priority 19 of 24\nACCESS Project List\nPFIP 2022 Application',
#  'INFRA 2022 (MPDG) Caltrans Application / Cover Letter\nFY 21-22 Non-SHOPP PID Nomination (Carryover)',
#  'TCEP Cycle 2 Nomination (was not submitted)',
#  'None',
#  'None',
#  'FY 21-22 Non-SHOPP PID Nomination (Carryover)',
#  'Federal Community Projects 2021 Sponsored\nStimulus Drill 2021\nATP Cycle 5 Application - 2\nBUILD 2021 Nomination',
#  'FY 22-23 Non-SHOPP PID Priority List',
#  'MPDG 2022 Signed LOS                   \nRAISE 2022 Signed LOS',
#  '2020 ITIP',
#  'MPDG 2022 Signed LOS\nRAISE 2022 Signed LOS',
#  'FY 21-22 Non-SHOPP PID Nominations (New)',
#  'ACCESS Project List\nTCEP Cycle 3 Not Recommended\n2020 STIP (RIP)',
#  'TCEP Cycle 3 Not Recommended\n2022 ATP Cycle 6 App\n2022 MPDG Letter of Commitment     \nStimulus Drill 2021\nACCESS Project List',
#  'ATP Cycle 6 Nomination Rank 4. Did not move forward to application.',
#  'ACCESS Project List',
#  'Stimulus Drill 2021',
#  '2019 ATP 4 App\n2022 ATP 6 App (Partner Application) Nomination Rank 1\nFederal Community Projects 2021 Sponsored\nStimulus Drill 2021',
#  'TCEP Cycle 2 Priority 20 of 26 (Awarded)',
#  'ATP Cycle 6 Nomination Rank 3. Did not move forward to application.\nReconnecting Communities 2022 LOS',
#  '2022 ATP 6 Application',
#  'FY 21-22 Non-SHOPP PID Nomination (New)\nACCESS Project List',
#  'FY 21-22 Non-SHOPP PID Nomination (New)\nACCESS Project List',
#  'SCCP Cycle 3 Priority 09 of 14',
#  'SCCP Cycle 3 Priority 09 of 14',
#  'ATP Cycle 6 Nomination Rank 12 (Partner App)',
#  'RAISE 2022 LOS Signed',
#  '2020 STIP (RIP)\nSCCP Cycle 2 Priority 3 of 10 (Awarded)\nTCEP Cycle 2 Nomination (was not submitted)\nStimulus Drill 2021',
#  'None',
#  'SCCP Cycle 3 Not Recommended\nTCEP Cycle 3 Priority 24 of 24\nINFRA 2021 Award (not Caltrans); INFRA 2021 LOS Not Signed\nACCESS Project List',
#  'TCEP Cycle 3 Not Recommended\nSCCP Cycle 3 Not Recommended\nRAISE 2021 LOS Maybe\nINFRA 2021 LOS Not Signed\nACCESS Project List',
#  'Stimulus Drill 2021',
#  'FY 22-23 Non-SHOPP PID Priority List',
#  'ATP Cycle 6 Nomination Rank 8. Did not move forward to application.\nRAISE 2021 Nominations\nStimulus Drill',
#  'SCCP Cycle 3 Priority 10 of 14\nStimulus Drill 2021\nReconnecting Communities 2022 Nomination Joint App-Removed App',
#  'CA Coastal Trail Candidate Projects (Coastal Commission)',
#  'ACCESS Project List',
#  'CA Coastal Trail Candidate Projects (Coastal Commission)',
#  'CA Coastal Trail Candidate Projects (Coastal Commission)',
#  'TCEP Cycle 3 Not Recommended\nSCCP Cycle 3 Priority 11 of 14\nMPDG 2022 LOS  Signed\nStimulus Drill 2021\nRAISE 2022 LOS Signed\nACCESS Project List',
#  'RAISE 2021 LOS Signed\nRAISE 2022 Signed LOS\nFederal Community Projects 2021 LOS provided\nBUILD 2021 Nomination',
#  'Reconnecting Communities 2022 Nomination Rank 17',
#  'Stimulus Drill 2021',
#  'Reconnecting Communities 2022 Nomination Rank 1',
#  'FY 22-23 Non-SHOPP PID Priority List\nStimulus Drill 2021\nFederal Community Projects 2021 Sponsored',
#  'DRMT Consolidated Statewide Project List\nStimulus Drill 2021\nTCEP Potential Nomination',
#  'Stimulus Drill 2021\nFederal Community Projects LOS Signed\nATP 2021 Cycle 5 Application - 3',
#  'ACCESS Project List',
#  'Reconnecting Communities 2022 Joint App LOS',
#  'Federal Community Projects 2021',
#  'SCCP Potential Nomination',
#  'RAISE 2022 LOS Not signed',
#  'ACCESS Project List',
#  'FY 21-22 Non-SHOPP PID Nomination (New)',
#  'SCCP Cycle 2 Priority 7 of 10 (Awarded)\nINFRA 2021 LOS Not Signed',
#  'None',
#  '2022 ITIP Complete Streets Reserve',
#  '2022 ITIP Complete Streets Reserve',
#  '2022 ITIP Complete Streets Reserve',
#  'Reconnecting Communities 2022 LOS',
#  'ACCESS Project List',
#  'FY 21-22 Non-SHOPP PID Nomination (New)',
#  'ACCESS Project List',
#  'TCEP Cycle 3 Priority 21 of 24',
#  'Reconnecting Communities Nomination Joint App 2022',
#  'TCEP Cycle 3 Priority 01 of 24\nSupply Chain Resilience and Port Infrastructure Investment',
#  'DRMT Consolidated Statewide Project List\nStimulus Drill 2021\nTCEP Cycle 2 Nomination (was not submitted)',
#  'RAISE 2022 LOS Signed\nDRMT Consolidated Statewide Project List\nSCCP Cycle 2 Priority 2 of 10 (Awarded)',
#  'RAISE 2021 LOS Not signed',
#  'RAISE 2022 LOS Signed\nDOTP innovative concept',
#  'ACCESS Project List',
#  'Reconnecting Communities 2022 LOS--Removed LOS',
#  'Reconnecting Communities 2022 Joint App LOS',
#  'Reconnecting Communities 2022 LOS',
#  'USDOT Emerging Projects Agreement',
#  'USDOT Emerging Projects Agreement',
#  'USDOT Emerging Projects Agreement',
#  'RAISE 2021 LOS Not Signed\nStimulus Drill 2021\nTCEP Cycle 2 submittal by Contra Costa TA (Awarded)',
#  'Reconnecting Communities 2022 LOS--Removed LOS',
#  'RAISE 2021 LOS Signed\nRAISE 2021 Nominations\nRAISE 2022 LOS Signed\nFederal Community Project LOS provided',
#  'Reconnecting Communities 2022 LOS--Removed LOS',
#  'SCCP Cycle 3 Priority 08 of 14\nATP Cycle 5 (Bay Area Toll Authority); no award',
#  'SCCP Cycle 2 Priority 9 of 10 (Not Awarded)\nStimulus Drill 2021\nACCESS Project List',
#  'ACCESS Project List',
#  'RAISE 2022 LOS NOT Signed\nACCESS Project List',
#  'ACCESS Project List',
#  'TCEP Cycle 2 Priority 10 of 26 (Awarded)\nTCEP Cycle 3 Advanced Programming\nTCEP Cycle 3 Priority 10 of 24\nMPDG 2022 Signed LOS',
#  'SCCP Cycle 2 Priority 8 of 10 (Not Awarded)\nSCCP Cycle 3 Not Recommended\nMPDG 2022 LOS (not signed)\nStimulus Drill 2021\nACCESS Project List',
#  'TCEP Cycle 2 Priority 12 of 26 (Awarded)',
#  'ACCESS Project List',
#  'FY 22-23 Non-SHOPP PID Remainder List\nFY 21-22 Non-SHOPP PID Nomination (New)',
#  'Reconnecting Communities 2022 LOS-Not recommended',
#  'Reconnecting Communities 2022 Joint App LOS',
#  'Reconnecting Communities 2022 LOS Not recommended',
#  'Reconnecting Communities 2022 LOS',
#  'Reconnecting Communities 2022 Joint App LOS',
#  'CA Coastal Trail Candidate Projects (Coastal Commission)',
#  'CA Coastal Trail Candidate Projects (Coastal Commission)',
#  'CA Coastal Trail Candidate Projects (Coastal Commission)',
#  'DRMT Consolidated Statewide Project List\nStimulus Drill 2021\nSCCP Cycle 3 Not Recommended',
#  'RAISE 2021 LOS Signed       \nRAISE 2022 LOS Signed\nRAISE 2022 Award (SFMTA, not Caltrans)\nATP Cycle 6',
#  'Stimulus Drill 2021',
#  '2022 PIDP',
#  'SCCP Cycle 3 Priority 08 of 14\nATP Cycle 5 (Bay Area Toll Authority); no award',
#  'SCCP Cycle 3 Priority 08 of 14\nATP Cycle 5 (Bay Area Toll Authority); no award',
#  'CA Coastal Trail Candidate Projects (Coastal Commission)',
#  'CA Coastal Trail Candidate Projects (Coastal Commission)',
#  'Federal Community Projects 2021 LOS Signed',
#  'RAISE 2021 Nominations\nRAISE 2022 LOS Signed\nFederal Community Projects 2021 LOS Signed',
#  'ACCESS Project List',
#  'RAISE 2021 LOS Not recommended\nReconnecting Communities 2022 LOS Not recommended',
#  'CA Coastal Trail Candidate Projects (Coastal Commission)',
#  'TCEP Cycle 3 Priority 22 of 24\nACCESS Project List',
#  'FY 21-22 Non-SHOPP PID Nomination (New)',
#  'RAISE 2022 LOS Signed\nReconnecting Communities 2022 LOS',
#  'RAISE 2021 LOS Signed',
#  'RAISE 2022 LOS Signed\nFederal Community Projects 2021 LOS Signed',
#  'ACCESS Project List',
#  'RAISE 2022 LOS Signed\nSCCP Cycle 3 Priority 14 of 14',
#  'RURAL 2022 (MPDG) Caltrans Application / Cover Letter\nSCCP Cycle 2 submittal by SCCRTC (Awarded)\nSCCP Cycle 3 Priority 02 of 14\nStimulus Drill 2021\nACCESS Project List',
#  'RAISE 2022 LOS Signed',
#  'ACCESS Project List\nClimate Change Priority Project',
#  'None',
#  'USDOT 2022 Low or No Emission (Bus) Grant',
#  'SCCP Cycle 2 submittal by SLOCOG (No award)\nTCEP Cycle 2 (Caltrans as implementing agency); no award.\nTCEP Cycle 3 Not Recommended\nSCCP Cycle 3 Not Recommended\nFederal Community Projects 2021 LOS signed\nACCESS Project List',
#  'Stimulus Drill 2021',
#  'Reconnecting Communities 2022 Nomination Rank 4',
#  'FY 21-22 Non-SHOPP PID Nomination (New)',
#  'Stimulus Drill 2021',
#  'RURAL 2022 (MPDG) Caltrans Application / Cover Letter\nSCCP Cycle 2 submittal by SCCRTC (Awarded)\nSCCP Cycle 3 Priority 02 of 14\nStimulus Drill 2021\nACCESS Project List',
#  'None',
#  'None',
#  'None',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'Reconnecting Communities 2022 Nomination Rank 6',
#  'ACCESS Project List',
#  'TCEP Cycle 2 Priority 25 of 26 (Awarded)\nTCEP Cycle 3 Priority 17 of 24\n2022 ITIP Needs\nFederal Community Projects 2021\nRAISE 2021 LOS Maybe\nRAISE 2021 Nominations\nStimulus Drill 2021\nRAISE 2022 Letter of Commitment\nMPDG 2022 Letter of Commitment\nFederal Community Projects 2021 LOS Provided\nACCESS Project List',
#  'RURAL 2022 (MPDG) Caltrans Application / Cover Letter\nSCCP Cycle 2 submittal by SCCRTC (Awarded)\nSCCP Cycle 3 Priority 02 of 14\nStimulus Drill 2021\nACCESS Project List',
#  'Federal Community Projects 2021 LOS Signed\nACCESS Project List',
#  'CA Coastal Trail Candidate Projects (Coastal Commission)',
#  '2020 STIP (RIP)\nACCESS Project List',
#  '2019 ATP 4 App\n2021 ATP 5 Application - 4\n2022 ATP 6 Caltrans Lead Application\nFederal Community Projects 2021 Sponsored\nStimulus Drill 2021',
#  'None',
#  'CA Coastal Trail Candidate Projects (Coastal Commission)',
#  'Federal Community Projects 2021 LOS Signed\nACCESS Project List',
#  'ACCESS Project List',
#  'FY 22-23 Non-SHOPP PID Priority List',
#  'ACCESS Project List',
#  'CA Coastal Trail Candidate Projects (Coastal Commission)',
#  'CA Coastal Trail Candidate Projects (Coastal Commission)',
#  'CA Coastal Trail Candidate Projects (Coastal Commission)',
#  'CA Coastal Trail Candidate Projects (Coastal Commission)',
#  'Awarded SCCP Cycle 1 funds (SBCAG and Caltrans)\nTCEP Cycle 2 Submittal by SBCAG; not recommended\nINFRA 2021 LOS Signed LOS\nSCCP Cycle 2 Priority 5 of 10 (Not Awarded)\nStimulus Drill 2021\nSCCP Cycle 3 Priority 06 of 14\nMPDG 2022 Letter of Commitment\nACCESS Project List',
#  'TCEP Cycle 2 Priority 9 of 26 (Awarded)\nSCCP Cycle 2 submittal by Transportation Agency for Monterey County (No Award; Recommended for TCEP)',
#  'Awarded SCCP Cycle 1 funds (SBCAG and Caltrans)\nTCEP Cycle 2 Submittal by SBCAG; not recommended\nTCEP Cycle 3 Priority 16 of 24\nINFRA 2021 LOS Signed LOS\nSCCP Cycle 2 Priority 5 of 10 (Not Awarded)\nStimulus Drill 2021\nSCCP Cycle 3 Priority 06 of 14\nMPDG 2022 Letter of Commitment\nACCESS Project List',
#  'ACCESS Project List',
#  'CA Coastal Trail Candidate Projects (Coastal Commission)',
#  'RAISE 2021 Application\nStimulus Drill\nRAISE 2022 Lead Application\nFederal Community Projects 2021 LOS Signed\nStimulus Drill 2021',
#  'Federal Community Projects 2021 LOS Signed\nACCESS Project List',
#  'PID Completed\nACCESS Project List',
#  '2020 STIP (IIP)',
#  '2020 STIP (IIP)\nRAISE 2022 Letter of Commitment',
#  'ACCESS Project List',
#  'BUILD 2021 Nomination\nFederal Community Projects 2021 LOS signed',
#  'RAISE 2022 LOS Not Signed\nFederal Community Projects 2021 LOS Not signed\nACCESS Project List',
#  'None',
#  'Reconnecting Communities 2022 Nomination Rank 16',
#  'Stimulus Drill 2021',
#  'Reconnecting Communities 2022 Joint App LOS',
#  'None',
#  'RURAL 2022 (MPDG) Caltrans Application / Cover Letter\nTCEP Cycle 2 Priority 23 of 26 (No Award)\nTCEP Cycle 3 Priority 08 of 24\nACCESS Project List',
#  'Reconnecting Communities 2022 Joint App LOS',
#  'Reconnecting Communities 2022 Nomination Rank 13\nACCESS Project List',
#  'Reconnecting Communities 2022 Nomination Rank 18',
#  'ACCESS Project List',
#  '2022 ITIP Needs\nFederal Community Projects 2021 LOS provided\nRAISE 2021 LOS Maybe\nTCEP Cycle 2 Priority 14 of 26 (Awarded)\nACCESS Project List',
#  'None',
#  'None',
#  'None',
#  '2022 ITIP Needs\nFederal Community Projects 2021 LOS Not signed\nACCESS Project List',
#  'ATP Cycle 6 Nomination Rank 5; Moved to State Sponsored Non-SHOPP PID\nFY 22-23 Non-SHOPP PID Priority List',
#  'None',
#  'None',
#  'None',
#  'ACCESS Project List',
#  'None',
#  'None',
#  'None',
#  'None',
#  'ACCESS Project List',
#  'None',
#  'RAISE 2021 - Letter of commitment (letter from Caltrans needed if funded through RAISE  - Caltrans is the implementing agency)\nINFRA 2021 LOS Signed\nRAISE 2022 Letter of Commitment\nMPDG 2022  Letter of Commitment\nACCESS Project List',
#  'ACCESS Project List',
#  'Reconnecting Communities 2022 LOS',
#  'None',
#  'None',
#  'None',
#  'None',
#  'FY 21-22 Non-SHOPP PID Nomination (New)',
#  'ATP 2021 Cycle 5 Application - 7\nFederal Community Projects 2021 Sponsored\nStimulus Drill 2021',
#  'None',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  '2022 ITIP Needs\nTCEP Cycle 2 Priority 15 of 26 (Not Awarded)\nTCEP Cycle 3 Priority 20 of 24\nStimulus Drill 2021\nACCESS Project List',
#  'None',
#  'Federal Community Projects 2021 LOS Signed\nACCESS Project List',
#  'None',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'ACCESS Project List\nReconnecting Communities 2022 Joint App LOS',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'None',
#  '2022 ITIP Needs\nStimulus Drill\nACCESS Project List',
#  'TCEP Cycle 2 Priority 13 of 26 (Awarded)\nACCESS Project List',
#  '2022 ITIP Needs\nTCEP Cycle 2 Nomination (was not submitted)',
#  '2020 STIP (IIP)',
#  'ACCESS Project List',
#  'Reconnecting Communities 2022 Nomination Rank 15',
#  'Stimulus Drill 2021',
#  'FY 22-23 Non-SHOPP PID Priority List',
#  'Reconnecting Communities 2022 Joint App LOS',
#  'INFRA 2021\nRAISE 2021 LOS',
#  'None',
#  'Reconnecting Communities 2022 LOS Not recommended',
#  'None',
#  'None',
#  'FY 22-23 Non-SHOPP PID Remainder List',
#  'Reconnecting Communities 2022 Joint App',
#  'Stimulus Drill 2021',
#  'Reconnecting Communities 2022 LOS',
#  'RAISE 2021 Signed',
#  'Reconnecting Communities 2022 LOS',
#  'FY 21-22 Non-SHOPP PID Nomination (New)',
#  'RAISE 2021 LOS Signed',
#  'None',
#  'ATP Cycle 6 Intake\nReconnecting Communities 2022 Nomination Rank 7',
#  'None',
#  'RAISE 2021 Nominations',
#  'None',
#  'USDOT Emerging Projects Agreement',
#  'USDOT Emerging Projects Agreement',
#  'USDOT Emerging Projects Agreement',
#  'USDOT Emerging Projects Agreement',
#  'USDOT Emerging Projects Agreement',
#  'USDOT Emerging Projects Agreement',
#  'USDOT Emerging Projects Agreement',
#  'RAISE 2021 Nominations',
#  '28x28',
#  'Build Back Better Regional Challenge (BBBRC) Phase 1 - US Economic Development Administration',
#  'FY 21-22 Non-SHOPP PID Nomination (New)\nStimulus Drill',
#  '2022 PIDP\nINFRA 2022 (MPDG) Caltrans Application / Cover Letter\nTCEP Cycle 3 Priority 12 of 24\nRAISE 2022 Award (POLA, not Caltrans)',
#  'None',
#  'SCCP Cycle 3 Priority 13 of 14\nNot awarded TIRCP',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'Received partial funding TCEP Cycle 1\nTCEP Cycle 2 Submittal, Priority 3 of 26 (Awarded)\n28x28\nINFRA 2021 LOS Not Signed\nFederal Community Projects 2021 LOS Signed\nACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'TCEP Cycle 1 Award (LAMTC)\nTCEP Cycles 2 and 3 - Not Recommended\nStimulus Drill 2021\nACCESS Project List',
#  'TCEP Cycle 3 Deleted\nACCESS Project List',
#  '2020 STIP (RIP)',
#  'TCEP Cycle 2 Priority 18 of 26 (Awarded)\nACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'DRMT Consolidated Statewide Project List\nStimulus Drill 2021',
#  'ACCESS Project List',
#  'TIRCP Award was downscaled\nSCCP Cycle 3 Priority 05 of 14\nAwarded RAISE 2022 (not Caltrans)',
#  'USDOT Emerging Projects Agreement',
#  'CA Coastal Trail Candidate Projects (Coastal Commission)',
#  'CA Coastal Trail Candidate Projects (Coastal Commission)',
#  'USDOT Emerging Projects Agreement',
#  'USDOT Emerging Projects Agreement',
#  'USDOT Emerging Projects Agreement',
#  'USDOT Emerging Projects Agreement',
#  'USDOT Emerging Projects Agreement',
#  'None',
#  'USDOT Emerging Projects Agreement',
#  'SCCP Cycle 3 Priority 01 of 14',
#  'FY 22-23 Non-SHOPP PID Priority List',
#  'FY 21-22 Non-SHOPP PID Nomination (New)',
#  'RAISE 2022 Letter of Commitment\nFederal Community Projects 2021 LOS Signed\nACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'SCCP Cycle 2 Priority 4 of 10 (Awarded)\nMPDG 2022 LOS Not Signed\nRAISE 2022 LOS Not Signed\nACCESS Project List',
#  'ACCESS Project List.',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List. SHOPP Project.',
#  'FY 22-23 Non-SHOPP PID Priority List',
#  'TCEP Cycle 3 Not Recommended\nACCESS Project List',
#  'ACCESS Project List',
#  'Federal Community Projects 2021 Sponsored\nStimulus Drill 2021\nTCEP Cycle 2 Priority 22 of 26 (Not Awarded)\nTCEP Cycle 3 Priority 23 of 24',
#  'FY 21-22 Non-SHOPP PID Nomination (New)',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'USDOT Emerging Projects Agreement',
#  'INFRA 2022 Caltrans co-application',
#  '2022 PIDP',
#  'None',
#  'Reconnecting Communities 2022 Nomination Rank 8',
#  'INFRA 2021, awarded $18 M\nINFRA 2021 Signed',
#  'SCCP Cycle 3 Not Recommended',
#  'ATP Cycle 6 Nomination Rank 6. Did not move forward to application.',
#  'ACCESS Project List',
#  'USDOT Emerging Projects Agreement',
#  'TCEP Cycle 2 Award\nACCESS Project List',
#  'FY 22-23 Non-SHOPP PID Priority List',
#  'ACCESS Project List',
#  'USDOT Emerging Projects Agreement',
#  'ACCESS Project List',
#  'SCCP Cycle 3 Not Recommended',
#  'ACCESS Project List',
#  'ACCESS Project List\nATP 2021 Cycle 5 Application - 1\nBUILD 2021 Nomination\nRAISE 2021 Nominations\nStimulus Drill 2021',
#  'ACCESS Project List',
#  'TCEP Cycle  3 Nomination - Deleted',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'TCEP Cycle 2 Priority 19 of 26 (Awarded)\nSubmitted to SCCP Cycle 2 by RCTC (No Award; Recommended TCEP)\nACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'Federal Community Projects 2021 LOS Signed\nACCESS Project List',
#  'ACCESS Project List',
#  'USDOT Emerging Projects Agreement',
#  'Stimulus Drill 2021',
#  'Reconnecting Communities 2022 Joint App LOS',
#  'Reconnecting Communities 2022 Joint App LOS',
#  'RAISE 2021 LOS Signed',
#  'Submitted to TCEP Cycle 2 by City of Riverside; no award',
#  'TCEP Cycle 3 Not Recommended',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'TCEP Cycle 2 submittal by City of Murrieta; no award\nACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'Reconnecting Communities 2022 Nomination Rank 11',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'Stimulus Drill 2021',
#  'SCCP Cycle 2 Recommendation\nSCCP Cycle 3 Priority 04 of 14',
#  'Stimulus Drill 2021',
#  'SCCP Cycle 3 Not Recommended\nRAISE 2022 LOS Signed\nACCESS Project List',
#  'Stimulus Drill 2021',
#  'Reconnecting Communities 2022 LOS',
#  'BUILD 2019 Lead Applicant\nRAISE 2021 LOS Signed',
#  'BUILD 2021 Nomination',
#  '2022 ITIP Needs\nStimulus Drill 2021',
#  'FY 22-23 Non-SHOPP PID Priority List',
#  'ATP 2021 Cycle 5 Application - 5\n2022 RAISE Caltrans Lead Application\nBUILD 2021 Nomination\nFederal Community Projects 2021 Sponsored\nStimulus Drill 2021\nATP Cycle 6 Nomination Rank 2; Moved to RAISE 2022\nFY 21-22 Non-SHOPP PID Nomination (New)',
#  'ACCESS Project List',
#  'TCEP Cycle 3 Deleted\nSCCP Cycle 3 Not Recommended\nContract 1 awarded TCEP Cycle 1 funds (Caltrans/SBCTA)\nMPDG 2022 LOS Not Signed',
#  'FY 22-23 Non-SHOPP PID Reminder List',
#  'USDOT Emerging Projects Agreement',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'TCEP Cycle 2 Priority 17 of 26 (Awarded)',
#  'USDOT Emerging Projects Agreement\nACCESS Project List',
#  'USDOT Emerging Projects Agreement',
#  'ACCESS Project List',
#  'TCEP Cycle 2 Priority 21 of 26 (Awarded)\nSubmitted SCCP Cycle 2 by SBCTA (No award; recommended TCEP)\nACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'USDOT Emerging Projects Agreement\nACCESS Project List',
#  'TCEP Cycle 3 Deleted',
#  'ACCESS Project List',
#  'TCEP Cycle 2 submittal by City of Coachella; no award\nTCEP Cycle 3 Not Recommended\nINFRA 2021 LOS Not Signed',
#  '2022 ITIP Needs\nStimulus Drill 2021',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  '2020 STIP (IIP)',
#  'Federal Community Projects 2021 Sponsored',
#  'Stimulus Drill 2021',
#  'FY 21-22 Non-SHOPP PID Nomination (New)',
#  'ATP 2021 Cycle 5 Application - 6\nBUILD 2021 Nomination',
#  'ACCESS Project List\nPID Completed\nPA&ED Not Eligible for TCEP Cycle 3',
#  'None',
#  'Reconnecting Communities 2022 Nomination Rank 10',
#  'RAISE 2021 LOS Signed\nTCEP Cycle 2 submital by Merced County; not recommended.',
#  'ATP Cycle 6 Nomination Rank 11. Did not move forward to application.\nATP Cycle 5 Application - 1\nFederal Community Projects 2021 LOS Signed',
#  'ACCESS Project List\nATP Cycle 5 (Non-Caltrans Project)',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'Submitted to TCEP Cycle 2 by Calaveras County COG; funded by other program\nFederal Community Projects 2021 LOS Signed\nACCESS Project List',
#  'SCCP Potential Nomination\nFederal Community Projects 2021 LOS Signed\nACCESS Project List',
#  'SCCP Potential Nomination\nFederal Community Projects 2021 LOS Signed',
#  'ACCESS Project List',
#  'FY 22-23 Non-SHOPP PID Priority List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'None',
#  'ACCESS Project List',
#  'TCEP Cycle 2 submittal by City of Corona; awarded\nACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List\nTCEP Potential Nomination',
#  'RAISE 2021 LOS Signed\nTCEP Cycle 2 Priority 11 of 26 (Awarded $25 M)\nACCESS Project List',
#  'ACCESS Project List\nStimulus Drill 2021\nTCEP Cycle 2 Nomination (was not submitted)',
#  'ACCESS Project List',
#  'Reconnecting Communities 2022 Nomination Rank 5',
#  'ACCESS Project List',
#  '2022 ITIP Needs\nStimulus Drill 2021\nTCEP Cycle 2 Nomination (submitted by Stanislaus COG; awarded)',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'None',
#  'TIRCP 2021  Application - Pending Award\nINFRA 2022 Application - Pending Award\nTCEP Cycle 3 Priority 04 of 24\nMPDG LOS 2022 Signed',
#  'SCCP Potential Nomination\nACCESS Project List',
#  'ACCESS Project List',
#  'Reconnecting Communities 2022 Nomination Rank 9',
#  'MEGA 2022 (MPDG) Caltrans Application / Cover Letter\nTCEP Cycle 3 Priority 05 of 24\nBIP 2022 Caltrans Application',
#  '2020 STIP (IIP)',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'Stimulus Drill 2021',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'TCEP Cycle 2 Nomination (submitted by Imperial CTC; awarded)',
#  'TCEP Cycle 2 Nomination (was not submitted)',
#  'MPDG 2022 Letter of Commitment\nRAISE 2021 LOS Not Signed\nINFRA 2021 LOS Not Signed',
#  'ACCESS Project List',
#  'Stimulus Drill 2021',
#  'TCEP Cycle 3 Priority 02 of 24\nFederal Community Projects 2021 LOS Signed\nFY 21-22 Non-SHOPP PID Nomination (New)',
#  'RAISE 2021 Nominations; no award\nFY 21-22 Non-SHOPP PID Nomination (Carryover)',
#  'CA Coastal Trail Candidate Projects (Coastal Commission)',
#  'CA Coastal Trail Candidate Projects (Coastal Commission)',
#  'TCEP Cycle 2 Priority 1 of 26 (Awarded)\nTCEP Cycle 3 Priority 07 of 24\nINFRA 2021 Caltrans Application; no award      \nINFRA 2021 Cover Letter\nMPDG 2022 Cover Letter (INFRA 2022 Caltrans Application)\nFederal Community Projects 2021 Sponsored\nStimulus Drill 2021',
#  'RAISE 2022 LOS Signed',
#  'None',
#  'INFRA 2021 LOS Not Signed',
#  'Reconnecting Communities 2022 LOS--Removed LOS',
#  'USDOT Emerging Projects Agreement',
#  'USDOT Emerging Projects Agreement',
#  'USDOT Emerging Projects Agreement',
#  'Reconnecting Communities 2022 Nomination Rank 12',
#  'Stimulus Drill 2021',
#  'ACCESS Project List',
#  '2022 PIDP',
#  'INFRA 2021 Caltrans Application\nSCCP Potential Nomination\nStimulus Drill\nTCEP Potential Nomination',
#  'ATP Cycle 6 Nomination Rank 9',
#  'ATP Cycle 6',
#  'Reconnecting Communities 2022 Nomination Rank 14',
#  'SCCP Cycle 3 Priority 12 of 14',
#  'Stimulus Drill 2021',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'TCEP Cycle 3 Priority 02 of 24 (Combined with Harbor Drive)\nACCESS Project List',
#  'RAISE 2021 Nominations\nFederal Community Projects 2021 Sponsored\nStimulus Drill 2021',
#  'None',
#  'TCEP Cycle 3 Ineligible\nACCESS Project List',
#  'SCCP Cycle 3 and TCEP Cycle 3 Not Recommended\nACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'RAISE 2021 Nominations',
#  'SCCP Cycle 3 Nomination - Ineligible',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'SCCP Cycle 2 Nomination',
#  'None',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'ACCESS Project List',
#  'Reconnecting Communities 2022 CON Request',
#  'FY 22-23 Non-SHOPP PID Remainder List',
#  'ACCESS Project List',
#  'SCCP Cycle 3 Deleted (was Priority 15 of 15)\nACCESS Project List',
#  'ACCESS Project List',
#  'None',
#  'None',
#  'ATP Cycle 6 Nomination. Did not move forward to application.',
#  'SCCP Cycle 3 Priority 07 of 14\nACCESS Project List',
#  'FY 22-23 Non-SHOPP PID Priority List',
#  'None',
#  'RAISE 2021 LOS Signed\nTCEP Cycle 3 Priority 14 of 24\nRAISE 2022 LOS Signed',
#  'PFIP 2022',
#  '2022 RAISE App',
#  'TCEP Cycle 3 Priority 15 of 24',
#  'PFIP 2022',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'None',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'None',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'SCCP Cycle 3 Priority 09 of 14',
#  'MEGA 2022 (MPDG) Caltrans Application/ Cover Letter\nDRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List\nStimulus Drill 2021',
#  'DRMT Consolidated Statewide Project List',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'None',
#  'USDOT Emerging Projects Agreement',
#  'None',
#  'None',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'None',
#  'None',
#  'USDOT Emerging Projects Agreement',
#  'None',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List\nTCEP Cycle 2 Priority 4 of 26 (Awarded)',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'USDOT Emerging Projects Agreement',
#  'DRMT Consolidated Statewide Project List\nMPDG 2022 Signed LOS',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List\nTCEP Cycle 2 Priority 5 of 26 (Awarded)',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List\nTCEP Cycle 2 Nomination (was not submitted)',
#  'DRMT Consolidated Statewide Project List',
#  'USDOT Emerging Projects Agreement',
#  'USDOT Emerging Projects Agreement',
#  'TCEP Cycle 2 Submittal by POLA; no award\nTCEP Cycle 3 Priority 13 of 24',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'USDOT Emerging Projects Agreement',
#  'DRMT Consolidated Statewide Project List\nStimulus Drill 2021\nTCEP Cycle 2 Nomination (was not submitted)',
#  'DRMT Consolidated Statewide Project List\nTCEP Cycle 2 Nomination (was not submitted)',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List\nFederal Community Projects 2021 LOS Signed',
#  'RAISE 2022 LOS Signed\nRAISE 2021 Co-Applicant',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'RAISE 2021 LOS\nTCEP Cycle 3 Priority 03 of 24\nDRMT Consolidated Statewide Project List\nStimulus Drill 2021\nTCEP Cycle 2 Nomination (was not submitted)\nMPDG 2022 Co-Applicant / Cover Letter',
#  'RAISE 2021 LOS\nTCEP Cycle 3 Priority 03 of 24\nDRMT Consolidated Statewide Project List\nStimulus Drill 2021\nTCEP Cycle 2 Nomination (was not submitted)\nMPDG 2022 Co-Applicant / Cover Letter',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List\nStimulus Drill 2021',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List\nStimulus Drill 2021',
#  'USDOT Emerging Projects Agreement',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List\nSCCP Cycle 2 submittal by SANDAG (No award)',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'TCEP Cycle 3 Deleted\nPFIP 2022 Application',
#  'RAISE 2021 Co-Applicant\nTCEP Cycle 2 Priority 8 of 26 (Not Awarded)\nTCEP Cycle 3 Priority 11 of 24\nRAISE 2022 Signed LOS     \nCRISI 2022 Signed LOS\nFederal Community Projects 2021 Sponsored\nStimulus Drill 2022',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'RAISE 2021 LOS Signed\nRAISE 2022 LOS Signed\nTCEP Cycle 2 Nomination (was not submitted)',
#  'USDOT Emerging Projects Agreement',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List\nStimulus Drill 2021',
#  'USDOT Emerging Projects Agreement',
#  'USDOT Emerging Projects Agreement',
#  'DRMT Consolidated Statewide Project List\nINFRA 2021 Caltrans Application\nStimulus Drill 2021\nTCEP Cycle 2 Priority 6 of 26 (Not Awarded)',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List\nStimulus Drill 2021',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List\nFederal Community Projects 2021 LOS Signed',
#  'DRMT Consolidated Statewide Project List',
#  'Reconnecting Communities 2022 LOS--Removed LOS',
#  'DRMT Consolidated Statewide Project List',
#  'USDOT Emerging Projects Agreement',
#  'USDOT Emerging Projects Agreement',
#  'USDOT Emerging Projects Agreement',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List\nTCEP Cycle 2 Priority 7 of 26 (Awarded)',
#  'USDOT Emerging Projects Agreement',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List\nTCEP Cycle 2 Priority 2 of 26 (Awarded)\nFederal Community Projects 2021 LOS Signed',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List\nStimulus Drill 2021',
#  'DRMT Consolidated Statewide Project List\nStimulus Drill 2021',
#  'TCEP Cycle 3 Priority 06 of 24\nDRMT Consolidated Statewide Project List\nStimulus Drill\nTCEP Cycle 2 Nomination (was not submitted)\nPFIP 2022 Application',
#  'DRMT Consolidated Statewide Project List\nStimulus Drill 2021\nTCEP Cycle 2 Nomination (was not submitted)',
#  'TCEP Cycle 3 Priority 09 of 24',
#  'DRMT Consolidated Statewide Project List\nSCCP Cycle 2 Priority 1 of 10 (Awarded)\nFederal Community Projects 2021 LOS Signed',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'RAISE 2022 Co-Lead\nMPDG 2022 Signed LOS',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'SCCP Cycle 3 Priority 03 of 14\n2022 ITIP\nRAISE 2021 Caltrans Application; no award\nCRISI 2021 Signed LOS\nCRISI 2022 Signed LOS\nRAISE 2022 Caltrans Lead Application',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List\nStimulus Drill 2021',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'USDOT Emerging Projects Agreement',
#  'USDOT Emerging Projects Agreement',
#  'USDOT Emerging Projects Agreement',
#  'USDOT Emerging Projects Agreement',
#  'USDOT Emerging Projects Agreement',
#  'USDOT Emerging Projects Agreement',
#  'USDOT Emerging Projects Agreement',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List\nStimulus Drill 2021',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List\nStimulus Drill 2021\nTCEP Cycle 2 Nomination (was not submitted)\nSCCP Cycle 3 Deleted\nPFIP 2022 Application',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List\nStimulus Drill 2021',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List\nTCEP Cycle 2 Nomination (was not submitted)',
#  'DRMT Consolidated Statewide Project List\nStimulus Drill 2021',
#  'DRMT Consolidated Statewide Project List\nStimulus Drill 2021',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List\nStimulus Drill 2021',
#  'DRMT Consolidated Statewide Project List\nStimulus Drill 2021',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List',
#  'DRMT Consolidated Statewide Project List']

# %%
sorted((shopp>>filter(_.previous_caltrans_nominations.str.contains('ATP'))))
# Out:
# ['_10_year_plan',
#  'access_alignment',
#  'atp_alignment',
#  'atp_total_score__out_of_100',
#  'atp_total_score__out_of_100__district_median',
#  'beg_pm',
#  'benefits_to_dac_and_advancing_equity__atp__score',
#  'climate_resiliency__csis__comment',
#  'climate_resiliency__csis__score',
#  'commercial_dev_developed',
#  'community_feedback__atp__score',
#  'community_need__atp__score',
#  'con_anticipated_source_of_funds',
#  'con_capital_cost__$1,000',
#  'con_existing_source_s__of_funds',
#  'con_start_date__m500',
#  'con_support_cost__$1,000',
#  'context_sensitive_and_innovation__atp__score',
#  'continued_engagement__atp__score',
#  'county',
#  'csis_alignment',
#  'csis_total_score__out_of_45',
#  'csis_total_score__out_of_45__district_median',
#  'ct_project_id',
#  'current_phase',
#  'dac_local_community_needs__csis__comment',
#  'dac_local_community_needs__csis__score',
#  'detailed_project_title',
#  'district',
#  'district_district_median',
#  'district_full_name',
#  'district_priority',
#  'district_rank',
#  'ea',
#  'end_pm',
#  'fake_benefit_score',
#  'fake_benefit_score_district_median',
#  'fake_benefit_score_statewide_percentile',
#  'full_county_name',
#  'funding_need_phase_s',
#  'hq_priority',
#  'impact_natural_resources',
#  'improve_air_quality',
#  'increase_access_jobs_to_dac',
#  'increase_access_to_jobs',
#  'increase_peak_person_throughput',
#  'infill_development_and_land_use__csis__comment',
#  'infill_development_and_land_use__csis__score',
#  'last_scored',
#  'lead_agency',
#  'located_in_dac',
#  'mode_shift__csis__comment',
#  'mode_shift__csis__score',
#  'modified',
#  'modified_by',
#  'natural_resources_and_ecosystems__csis__comment',
#  'natural_resources_and_ecosystems__csis__score',
#  'non_infrastructure___plan_cost__$1,000',
#  'notes',
#  'pa_ed_cost__$1,000',
#  'parcel_counts',
#  'pid_approval_date__m010',
#  'potential_funding_program_s',
#  'ppno',
#  'previous_caltrans_nominations',
#  'previous_funding_request',
#  'previous_funding_request_phase',
#  'primary_mode',
#  'project_description',
#  'project_name',
#  'ps_e_cost__$1,000',
#  'public_engagement__csis__comment',
#  'public_engagement__csis__score',
#  'public_participation__atp__score',
#  'purpose___need',
#  'rail_project_id',
#  'reduction_in_fatal_and_injury_crashes',
#  'reduction_in_injury_rates',
#  'reduction_in_peak_period_delay',
#  'route',
#  'row_cost__$1,000',
#  'rtl_date__m460',
#  'safety__atp__score',
#  'safety__csis__comment',
#  'safety__csis__score',
#  'secondary_mode_s',
#  'shs_capacity_increase_detail',
#  'statewide_rank',
#  'support_of_transportation',
#  'target_opening_year',
#  'target_pa_ed__m200',
#  'tons_of_goods_impacted',
#  'total_project_cost__$1,000',
#  'total_project_cost__$1,000__district_median',
#  'total_unfunded_need__$1,000',
#  'total_unfunded_need__$1,000__district_median',
#  'transformative__atp__score',
#  'update_complete',
#  'urban_rural',
#  'vmt__csis__comment',
#  'vmt__csis__score',
#  'zev__csis__comment',
#  'zev__csis__score']

# %%
sorted(list(atp_funded['a2_info_proj_name']))
# Out:
# ['7th Street Connection Project',
#  '9th St Active Transportation Corridor',
#  'ATP-5 SRTS Intersection Enhancement and NI Work Plan',
#  'Active and Safe Routes to a Healthier City ',
#  'Arcata Annie & Mary Trail Connectivity Project',
#  'Bell Gardens Complete Streets Improvements - Phase 1',
#  'Biola Community Sidewalks',
#  'Broadway Ave Complete Street Corridor',
#  'Butterfield Stage Corridor (W North Grand Ave to College Ave)',
#  'City of Huron Bicyclist and Pedestrian Safety Improvement Project',
#  'City of Maywood Active Transportation Plan',
#  'City of Perris Bike and Pedestrian Network Project ',
#  'Connecting Canoga Park Through Safety and Urban Cooling Improvements',
#  'Corcoran Safe Routes to School',
#  'Cottonwood Active Transportation Trunk Line Express (CATTLE) Network',
#  'Dam Road Extension & South Center Drive Bike/Pedestrian Improvements',
#  'Downtown Long Beach Walkable Corners',
#  'East Oakland Neighborhood Bike Routes',
#  'El Rio Pedestrian Improvement and Safe Route to School Project',
#  'Franklin Boulevard Complete Street Project',
#  'Happy Camp Complete Streets Project',
#  'Highland Avenue Inter-City Bike Connection',
#  'Jamestown Community Connectivity Project',
#  'Kids Crossing: Safe Routes to School in South Fresno',
#  'Laurel Elementary Safe Routes to School',
#  'Mariposa Creek Parkway',
#  'Mariposa Elementary School Connectivity Project',
#  'Muscoy Area Safe Routes to School Pedestrian Improvements Project',
#  'North Bailey Road Active Transportation Corridor',
#  'Orange Family Friendly Street Project',
#  'Pacific Avenue Cycle Track',
#  'Pollock Pines - Pony Express Trail Bicycle and Pedestrian Improvements',
#  'Riverside County Safe Routes for All - San Jacinto',
#  'SRTS Berendo Middle and 3 Feeder Elementary Schools Safety Project ',
#  'SRTS Carver Middle, Ascot Avenue and Harmony Elementary Schools Project',
#  'SRTS Panorama City Elementary School Project ',
#  'Safer Access to Pajaro Valley High School and Beyond',
#  'San Luis Obispo County-Bob Jones Trail Gap Closure',
#  'Santa Cruz Rail Trail Segment 7 Phase 2 Construction',
#  'Siskiyou- Regional Active Transportation Plan',
#  'South El Monte Safe Routes to School Pedestrian Safety Project',
#  'South Sacramento County Safe Routes to School Project ',
#  'Stewart-Pennsylvania Safety Enhancement Project',
#  'Sycamore Trail (Phase 2) Bicycle/Pedestrian Overcrossing',
#  'Turtle Bay to Downtown Gap Completion Project',
#  'Upper De La Vina Street Gap Closure and Safe Crossings ',
#  'Victor Ave & Cypress Ave Active Transportation (VCAT) Project',
#  'Vine Ave & B St Bike Boulevard Project',
#  'West Texas Street Complete Streets Project']

# %%
sorted(list((shopp>>filter(_.previous_caltrans_nominations.str.contains('ATP'))).project_name))
# Out:
# ['Active Transportation Community Connections And Coastal Access For Mid Coast Corridor Stations',
#  'Arcata Cap & Humboldt Area Rapid Transit (Not In Ctips)',
#  'Bay Skyway Bike Path, Phase 1 - Treasure Island Electric Ferry Infrastructure (No Identifiers)',
#  'Bay Skyway Bike Path, Phase 1 - West Oakland Link (No Identifiers)',
#  'Bay Skyway Bike Path, Phase 1 - Yerba Buena Multi-Use Path (No Identifiers)',
#  'Groveland Bike And Pedestrian Improvement Project',
#  'Gualala Downtown Streetscape Enhacement',
#  'Howard Streetscape Project (No Identifiers)',
#  'I-80/Central Ave Uc Ped & Bike (Not In Ctips)',
#  'Ivanhoe Safe Route To School',
#  'Kettleman City Class I Bikeway/Shared Use Path',
#  'Laguna Creek Inter-Regional Trail Crossing At State Route 99',
#  'Linking Neighborhoods Of La Jolla Reservation With Bike/Walking Trail On The State Route 76',
#  'Los Alamos Connected Community Project',
#  'Marshlands Road: Dumbarton Transbay And Bay Trail Gap Closure (No Identifiers)',
#  'Re-Envisioning/ Imagining For Route 66 Complete Street Planning\nReimagining And Reconnecting Route 66 \nRoute 66 / Fifth Street Complete Streets Improvements',
#  'Reconnecting Neighborhoods Along The Southern I-710 Stub\nSr 710 Northern Stub Re-Envisioning',
#  'Rosemead Boulevard Protected Bikeway Project',
#  'Sr 133 Bike/Ped Trail',
#  'Sr 174/49/20 Roundabout And Active Transportation Safety Project',
#  'Sr-168 (W. Line Street) Sidewalk Extension - Bishop Ca',
#  'State Route 110 (Sr-110) / Figueroa Multi-Modal Mobility And Operational Improvements',
#  'State Route 128/Interstate-505 Overcrossing Bicycle & Pedestrian Improvement Project, City Of Winters\nState Route 128/Interstate 505 Overcrossing (Br. 22-0110)/Russell Boulevard Bicycle And Pedestrian Improvements\nWinters/El Rio Villas Active Transportation Connection: Sr128/I505 Overcrossing',
#  'State Route 49 Corridor Improvement Project',
#  'State Route 89 / Fanny Bridge Community Revitalization Project',
#  'State Route-152 Pioneer Road Corridor Intersection Improvements/ Pioneer Road Regional Path/ Pioneer Road Improvement Project',
#  'Tehama Mineral Multi Use Path / Mineral Multi Use Path (Mineral Bike/Ped Pathway Atp)',
#  'Zinfandel Drive Bicycle And Pedestrian Crossing']

# %%
## project names do mot match up or are even remotely close

# %%
#list(shopp['lead_agency']) #atp_funded.a2_county.value_counts()

# %%
# list(atp_funded)

# %%
atp_keep_cols = ['ppno', 'ppno1', 'project_cycle',
                 'a2_county', 'a2_ct_dist',
                 'a1_imp_agcy_name', 'imp_agency_name_new', 'a2_mop_uza_population', 
                'a2_info_proj_name', 'a2_info_proj_descr', 
                 'a3_plan_other_desc', 'a2_output_outcome', 'a3_proj_type_x', 
                'a2_past_proj', 'a2_past_proj_qty',
                'total_project_cost', 'original_prog__amt___pa_ed_', 'original_prog__amt___ps_e_',
                 'orignal_prog__amt___con_', 'original_prog__amt___con_ni_',
                # '', '', '', '', '', ''
                ]

# %%
atp_funded_subset = atp_funded[atp_keep_cols]

# %% [markdown]
# ## Test Merges

# %%
## merge on project name 
## trying even though we already identified that none of the project names are matching right
(pd.merge(shopp, atp_funded_subset, how='outer', left_on = 'project_name', right_on ='a2_info_proj_name', indicator=True))._merge.value_counts()
# Out:
# left_only     765
# right_only     49
# both            0
# Name: _merge, dtype: int64

# %%
## merging on ppno numbers
## manual checks show that we have some similar ppno # but not same projects or in same districts
(pd.merge(shopp, atp_funded_subset, how='outer', on = 'ppno', indicator=True))._merge.value_counts()
# Out:
# left_only     765
# right_only     49
# both            0
# Name: _merge, dtype: int64

# %%
## merging on project descriptions
(pd.merge(shopp, atp_funded_subset, how='outer', left_on = 'project_description', right_on ='a2_info_proj_descr', indicator=True))._merge.value_counts()
# Out:
# left_only     765
# right_only     49
# both            0
# Name: _merge, dtype: int64

# %%
## Manual PPNO check

# %%
atp_funded_subset>>arrange(_.ppno)
# Out:
#      ppno  ppno1 project_cycle        a2_county a2_ct_dist  \
# 33  0413A    NaN             5       Santa Cruz          5
# 22   1228    NaN             5        El Dorado          3
# 34  1273A    NaN             5        Riverside          8
# 45  1274A    NaN             5   San Bernardino          8
# 16   1275    NaN             5   San Bernardino          8
# 19   1277    NaN             5        Riverside          8
# 43   1440    NaN             5        San Diego         11
# 23   1441    NaN             5        San Diego         11
# 4    1442    NaN             5        San Diego         11
# 13   1443    NaN             5        San Diego         11
# 27   2213    NaN             5       Sacramento          3
# 11   2214    NaN             5       Sacramento          3
# 39   2215    NaN             5             Yolo          3
# 10   2342    NaN             5          Alameda          4
# 2   2343A  2343B             5           Solano          4
# 29   2344    NaN             5     Contra Costa          4
# 14   2345    NaN             5      Santa Clara          4
# 32   2346    NaN             5          Alameda          4
# 18   2548    NaN             5         Humboldt          1
# 12   2606    NaN             5           Shasta          2
# 37   2607    NaN             5           Shasta          2
# 47   2608    NaN             5         Siskiyou          2
# 30   2610    NaN             5           Shasta          2
# 0    3057    NaN             5    Santa Barbara          5
# 3   3058A    NaN             5       Santa Cruz          5
# 17  3059A    NaN             5         Monterey          5
# 7    3060    NaN             5  San Luis Obispo          5
# 21   3204    NaN             5             Lake          1
# 38   3512    NaN             5         Tuolumne         10
# 6    3513    NaN             5         Mariposa         10
# 28   3514    NaN             5         Mariposa         10
# 1    5858    NaN             5      Los Angeles          7
# 15   5859    NaN             5      Los Angeles          7
# 20   5860    NaN             5      Los Angeles          7
# 24  5861A  5861B             5      Los Angeles          7
# 31   5862    NaN             5      Los Angeles          7
# 35   5863    NaN             5          Ventura          7
# 36   5864    NaN             5      Los Angeles          7
# 40  5865A  5865B             5      Los Angeles          7
# 42   5866    NaN             5      Los Angeles          7
# 44  5867A  5867B             5      Los Angeles          7
# 46   5868    NaN             5      Los Angeles          7
# 5    7074    NaN             5           Fresno          6
# 9    7075    NaN             5             Kern          6
# 25   7077    NaN             5           Tulare          6
# 26   7078    NaN             5           Fresno          6
# 41   7079    NaN             5           Fresno          6
# 48   7080    NaN             5            Kings          6
# 8     NaN    NaN             5         Siskiyou          2
#
#                                  a1_imp_agcy_name  \
# 33                           Watsonville, City of
# 22                               El Dorado County
# 34                                Perris, City of
# 45                          San Bernardino County
# 16                               Ontario, City of
# 19                               Riverside County
# 43                        Imperial Beach, City of
# 23                         National City, City of
# 4                              Oceanside, City of
# 13  San Diego Association of Governments (SANDAG)
# 27                            Sacramento, City of
# 11                              Sacramento County
# 39                       West Sacramento, City of
# 10                               Oakland, City of
# 2                              Fairfield, City of
# 29                            Contra Costa County
# 14                             Santa Clara County
# 32                               Oakland, City of
# 18                                Arcata, City of
# 12                               Redding, City of
# 37                                  Shasta County
# 47      Siskiyou County Transportation Commission
# 30                               Redding, City of
# 0                          Santa Barbara, City of
# 3                             Santa Cruz, City of
# 17                               Seaside, City of
# 7                          San Luis Obispo County
# 21                             Clearlake, City of
# 38                                Tuolumne County
# 6                                 Mariposa County
# 28                                Mariposa County
# 1                         South El Monte, City of
# 15                           Los Angeles, City of
# 20                               Maywood, City of
# 24                          Santa Monica, City of
# 31                           Los Angeles, City of
# 35                                 Ventura County
# 36                           Los Angeles, City of
# 40                            Long Beach, City of
# 42                           Los Angeles, City of
# 44                            Long Beach, City of
# 46                          Bell Gardens, City of
# 5                                 Fresno, City of
# 9                                 Delano, City of
# 25                           Porterville, City of
# 26                                  Fresno County
# 41                                 Huron, City of
# 48                              Corcoran, City of
# 8                                     Karuk Tribe
#
#                               imp_agency_name_new  \
# 33                            City of Watsonville
# 22                                            NaN
# 34                                 City of Perris
# 45                          San Bernardino County
# 16                                City of Ontario
# 19                               Riverside County
# 43                         City of Imperial Beach
# 23                          City of National City
# 4                               City of Oceanside
# 13  San Diego Association of Governments (SANDAG)
# 27                             City of Sacramento
# 11                              Sacramento County
# 39                        City of West Sacramento
# 10                                City of Oakland
# 2                               City of Fairfield
# 29                            Contra Costa County
# 14                             Santa Clara County
# 32                                City of Oakland
# 18                                 City of Arcata
# 12                                City of Redding
# 37                                  Shasta County
# 47      Siskiyou County Transportation Commission
# 30                                City of Redding
# 0                           City of Santa Barbara
# 3                              City of Santa Cruz
# 17                                City of Seaside
# 7                          San Luis Obispo County
# 21                              City of Clearlake
# 38                                Tuolumne County
# 6                                 Mariposa County
# 28                                Mariposa County
# 1                          City of South El Monte
# 15                            City of Los Angeles
# 20                                City of Maywood
# 24                           City of Santa Monica
# 31                            City of Los Angeles
# 35                                 Ventura County
# 36                            City of Los Angeles
# 40                             City of Long Beach
# 42                            City of Los Angeles
# 44                             City of Long Beach
# 46                           City of Bell Gardens
# 5                                  City of Fresno
# 9                                  City of Delano
# 25                            City of Porterville
# 26                                  Fresno County
# 41                                  City of Huron
# 48                               City of Corcoran
# 8                                     Karuk Tribe
#
#                                 a2_mop_uza_population  \
# 33  Project is located outside one of the ten larg...
# 22  Project is located within one of the ten large...
# 34  Project is located within one of the ten large...
# 45  Project is located within one of the ten large...
# 16  Project is located within one of the ten large...
# 19  Project is located within one of the ten large...
# 43  Project is located within one of the ten large...
# 23  Project is located within one of the ten large...
# 4   Project is located within one of the ten large...
# 13  Project is located within one of the ten large...
# 27  Project is located within one of the ten large...
# 11  Project is located within one of the ten large...
# 39  Project is located within one of the ten large...
# 10  Project is located within one of the ten large...
# 2   Project is located within one of the ten large...
# 29  Project is located within one of the ten large...
# 14  Project is located within one of the ten large...
# 32  Project is located within one of the ten large...
# 18  Project is located outside one of the ten larg...
# 12  Project is located outside one of the ten larg...
# 37  Project is located outside one of the ten larg...
# 47  Project is located outside one of the ten larg...
# 30  Project is located outside one of the ten larg...
# 0   Project is located outside one of the ten larg...
# 3   Project is located outside one of the ten larg...
# 17  Project is located outside one of the ten larg...
# 7   Project is located outside one of the ten larg...
# 21  Project is located outside one of the ten larg...
# 38  Project is located outside one of the ten larg...
# 6   Project is located outside one of the ten larg...
# 28  Project is located outside one of the ten larg...
# 1   Project is located within one of the ten large...
# 15  Project is located within one of the ten large...
# 20  Project is located within one of the ten large...
# 24  Project is located within one of the ten large...
# 31  Project is located within one of the ten large...
# 35  Project is located within one of the ten large...
# 36  Project is located within one of the ten large...
# 40  Project is located within one of the ten large...
# 42  Project is located within one of the ten large...
# 44  Project is located within one of the ten large...
# 46  Project is located within one of the ten large...
# 5   Project is located within one of the ten large...
# 9   Project is located within one of the ten large...
# 25  Project is located within one of the ten large...
# 26  Project is located within one of the ten large...
# 41  Project is located within one of the ten large...
# 48  Project is located outside one of the ten larg...
# 8   Project is located outside one of the ten larg...
#
#                                     a2_info_proj_name  \
# 33  Safer Access to Pajaro Valley High School and ...
# 22  Pollock Pines - Pony Express Trail Bicycle and...
# 34  City of Perris Bike and Pedestrian Network Pro...
# 45  Muscoy Area Safe Routes to School Pedestrian I...
# 16             Vine Ave & B St Bike Boulevard Project
# 19  Riverside County Safe Routes for All - San Jac...
# 43              9th St Active Transportation Corridor
# 23         Highland Avenue Inter-City Bike Connection
# 4             Laurel Elementary Safe Routes to School
# 13              Orange Family Friendly Street Project
# 27         Franklin Boulevard Complete Street Project
# 11  South Sacramento County Safe Routes to School ...
# 39  Sycamore Trail (Phase 2) Bicycle/Pedestrian Ov...
# 10                      7th Street Connection Project
# 2          West Texas Street Complete Streets Project
# 29   North Bailey Road Active Transportation Corridor
# 14        Active and Safe Routes to a Healthier City
# 32              East Oakland Neighborhood Bike Routes
# 18     Arcata Annie & Mary Trail Connectivity Project
# 12  Victor Ave & Cypress Ave Active Transportation...
# 37  Cottonwood Active Transportation Trunk Line Ex...
# 47      Siskiyou- Regional Active Transportation Plan
# 30      Turtle Bay to Downtown Gap Completion Project
# 0   Upper De La Vina Street Gap Closure and Safe C...
# 3   Santa Cruz Rail Trail Segment 7 Phase 2 Constr...
# 17              Broadway Ave Complete Street Corridor
# 7   San Luis Obispo County-Bob Jones Trail Gap Clo...
# 21  Dam Road Extension & South Center Drive Bike/P...
# 38           Jamestown Community Connectivity Project
# 6     Mariposa Elementary School Connectivity Project
# 28                             Mariposa Creek Parkway
# 1   South El Monte Safe Routes to School Pedestria...
# 15  SRTS Carver Middle, Ascot Avenue and Harmony E...
# 20         City of Maywood Active Transportation Plan
# 24    Stewart-Pennsylvania Safety Enhancement Project
# 31  Connecting Canoga Park Through Safety and Urba...
# 35  El Rio Pedestrian Improvement and Safe Route t...
# 36  SRTS Berendo Middle and 3 Feeder Elementary Sc...
# 40               Downtown Long Beach Walkable Corners
# 42      SRTS Panorama City Elementary School Project
# 44                         Pacific Avenue Cycle Track
# 46  Bell Gardens Complete Streets Improvements - P...
# 5   Kids Crossing: Safe Routes to School in South ...
# 9   ATP-5 SRTS Intersection Enhancement and NI Wor...
# 25  Butterfield Stage Corridor (W North Grand Ave ...
# 26                          Biola Community Sidewalks
# 41  City of Huron Bicyclist and Pedestrian Safety ...
# 48                     Corcoran Safe Routes to School
# 8                 Happy Camp Complete Streets Project
#
#                                    a2_info_proj_descr  \
# 33  Install pedestrian bridge, sidewalk, class IV ...
# 22  1.7 miles of class II bike lanes on both sides...
# 34  Class IV bike lanes with hardscape buffer and ...
# 45  Installation of pedestrian safety improvements...
# 16  Construction of bike boulevard, improvements i...
# 19  Safe Routes for All Program-San Jacinto: Pre-K...
# 43  1.3 miles of bicycle and pedestrian improvemen...
# 23  Construct Class IV and II bicycle facilities, ...
# 4   The Laurel Elementary SRTS includes infrastruc...
# 13  Buffered bike lanes; traffic calming and ped a...
# 27  A reduction in travel lanes from four to two; ...
# 11  Construct 12 curb extensions, 26 crosswalks, 3...
# 39  Sycamore Trail (Phase 2), constructing 1,940 f...
# 10  Complete Streets corridor project including pr...
# 2   Construct Class IV separated bikeways with Cla...
# 29  Construct two-way cycle track, ADA-compliant c...
# 14  Non-infrastructure 6 E’s project linking key c...
# 32  Neighborhood bike routes on four corridors in ...
# 18  PA&ED, PS&E, ROW and CON of 3.3 mile Class I t...
# 12  Along Victor Ave, Cypress Ave, and Alfreda Way...
# 37  In the unincorporated community of Cottonwood,...
# 47  The goal of this project is to create a compre...
# 30  Buffered 2-way cycle track; shared use path; r...
# 0   Design and construct buffered bike lanes on De...
# 3   Construction of .8 miles of Segment 7 of the R...
# 17  The Broadway Ave Complete Streets Corridor pro...
# 7   Completion of PS&E, ROW acquisition, and const...
# 21  Construct curb, gutter and sidewalk, and add b...
# 38  Project includes approximately 4,200 linear fe...
# 6   Construct new curb, gutter, sidewalks, ADA ram...
# 28  The Mariposa Creek Parkway provides an off-str...
# 1   This project focuses on school and pedestrian ...
# 15  Transform one of the City’s most disadvantaged...
# 20  The City of Maywood will develop an Active Tra...
# 24  Construction of Class IV separated bikeway, bu...
# 31  7 miles of pedestrian and cyclist improvements...
# 35  Install sidewalks, curbs, gutters, water-reten...
# 36  The one-quarter mile radius around Berendo Mid...
# 40  Transform Downtown Long Beach into a pedestria...
# 42  Transform one of the City’s most traffic-stres...
# 44  Transform Pacific Avenue into a complete stree...
# 46  Citywide ped, bike, & traffic calming improvem...
# 5   Amador & Trinity and Church & Waldby intersect...
# 9   Construct 68 curb ramps, 87 crosswalks, advanc...
# 25  Development of an active transportation corrid...
# 26  Construct concrete sidewalk, curb & gutter, AD...
# 41  The project will add Class II, III and IV bike...
# 48  Construct sidewalk along various school routes...
# 8   In Happy Camp on SR 96, install sidewalks, con...
#
#                                    a3_plan_other_desc  \
# 33  Safe Streets Save Lives Vision Zero Action Pla...
# 22                                                NaN
# 34                                 Trails Master Plan
# 45                                                NaN
# 16            Draft Active Transportation Master Plan
# 19                   WRCOG Active Transportation Plan
# 43                          Local Roadway Safety Plan
# 23                                                NaN
# 4                                                 NaN
# 13                                                NaN
# 27                                                NaN
# 11                                                NaN
# 39                                                NaN
# 10  West Oakland Spec. Plan, W. Oakland Climate Ac...
# 2                    Heart of Fairfield Specific Plan
# 29  Bailey Road Pedestrian and Bicycle Improvement...
# 14                                                NaN
# 32                                                NaN
# 18        Humboldt County Regional Trails Master Plan
# 12                                                NaN
# 37                                                NaN
# 47                       Regional Transportation Plan
# 30                                                NaN
# 0                                                 NaN
# 3                                                 NaN
# 17                                       General Plan
# 7   Parks and Recreation Element of the County's G...
# 21                                                NaN
# 38                                                NaN
# 6                        Regional Transportation Plan
# 28  Mariposa Creek Parkway MP, Act. Transp. Feasib...
# 1                                                 NaN
# 15  Mobility Plan 2035, Vision Zero LA, Green New ...
# 20                                                NaN
# 24  Land Use and Circulation Element, Bergamot Are...
# 31             City of Los Angeles Mobility Plan 2035
# 35                                                NaN
# 36  Mobility Plan 2035, Vision Zero LA, Green New ...
# 40                            Vision Zero Action Plan
# 42  Mobility Plan 2035, Vision Zero LA, Green New ...
# 44                            Vision Zero Action Plan
# 46                              Complete Streets Plan
# 5                        Regional Transportation Plan
# 9                           2018 Kern County ATP Plan
# 25  Porterville 2030 General Plan; TCAG Regional A...
# 26                                                NaN
# 41                                                NaN
# 48                                                NaN
# 8   Middle Klamath River Community Transportation ...
#
#                                     a2_output_outcome  \
# 33  Construction of 1 pedestrian bridge, 1 sidewal...
# 22  1.7 miles of class II bike lanes on both sides...
# 34  1.75 miles of Class IV buffered bike lanes con...
# 45  Construction of 7,290 feet of sidewalk, instal...
# 16  The traffic circle, curb extension, street lig...
# 19  Improve pedestrian and bicycle safety among st...
# 43  Constructing a road diet, green buffered bike ...
# 23  Addition of bicycle facilities on Highland Ave...
# 4   Infrastructure improvements of a mini roundabo...
# 13  Construction of 2.1-miles of buffered bike lan...
# 27  Reduction from four to two lanes, construction...
# 11  Construct 12 curb extensions, 26 crosswalks, 3...
# 39  Construction of 1,940 foot bicycle/pedestrian ...
# 10  Complete Streets corridor project implementing...
# 2   Road diet replacing travel lanes with Class IV...
# 29  Reconfiguring roadway with ADA-compliant, buff...
# 14  Increased knowledge and awareness of walking a...
# 32  Construction of four Class III bicycle bouleva...
# 18  Creation of 3.3 miles of Class I trail, walkwa...
# 12  Construct shared use paths (8’- to 10’-wide), ...
# 37  Construction of school frontage walking paths ...
# 47  A Regional Active Transportation Plan includin...
# 30  Installation of buffered 2-way cycle track; sh...
# 0   Install .65 miles of new Class II buffered bik...
# 3   Construction of .8 miles of Segment 7 of the R...
# 17  Design and construction of a road diet with en...
# 7   Construction of the 4.5-mile Bob Jones Gap Clo...
# 21  Construction of curb, gutter and sidewalk and ...
# 38  The construction of sidewalks, pathways, and c...
# 6   Construct approximately 3,200 linear feet of n...
# 28   .4-mile extension of existing multi-use activ...
# 1   Installation of pedestrian safety upgrades at ...
# 15  12 curb extensions, 3 raised crosswalks, 1 HAW...
# 20  The outcome will include the delivery of activ...
# 24  Construction of safety enhancements including ...
# 31  A network of pedestrian and cyclist improvemen...
# 35  Constructing Sidewalks and crosswalk improveme...
# 36  27 curb extensions, 2 traffic circles, 8,700 s...
# 40  Transform Downtown Long Beach into a pedestria...
# 42  23 curb extensions, 6 median extensions, 2 tra...
# 44  The Pacific Avenue Cycle Track project will ad...
# 46  Install or refresh 31 white or yellow high vis...
# 5   Construction of two traffic-signals, six upgra...
# 9   Construct 68 curb ramps, stripe 87 ladder-type...
# 25  Construction of a Class 1 multi-use path that ...
# 26  Construction of 1,975 feet of concrete sidewal...
# 41  After completion, this project will improve pe...
# 48  Construction of ADA ramps will increase access...
# 8   Project will provide complete street elements ...
#
#                   a3_proj_type_x                    a2_past_proj  \
# 33   Infrastructure + NI - Large  Yes
# 22                           NaN  No
# 34   Infrastructure + NI - Small  No
# 45  Infrastructure + NI - Medium  No
# 16       Infrastructure - Medium  Yes
# 19            Non-Infrastructure  Yes
# 43       Infrastructure - Medium  Yes
# 23        Infrastructure - Small  Yes
# 4    Infrastructure + NI - Small  No
# 13       Infrastructure - Medium  No
# 27        Infrastructure - Large  Yes
# 11   Infrastructure + NI - Small  Yes
# 39        Infrastructure - Large  Yes
# 10        Infrastructure - Large  Yes
# 2    Infrastructure + NI - Large  No
# 29       Infrastructure - Medium  Yes
# 14            Non-Infrastructure  Yes
# 32        Infrastructure - Large  No
# 18       Infrastructure - Medium  Yes
# 12   Infrastructure + NI - Large  Yes
# 37   Infrastructure + NI - Large  No
# 47                          Plan  No
# 30  Infrastructure + NI - Medium  Yes
# 0         Infrastructure - Small  No
# 3    Infrastructure + NI - Large  Yes
# 17   Infrastructure + NI - Large  Yes
# 7         Infrastructure - Large  No
# 21        Infrastructure - Small  Yes
# 38       Infrastructure - Medium  Yes
# 6         Infrastructure - Small  Yes
# 28       Infrastructure - Medium  No
# 1         Infrastructure - Small  No
# 15       Infrastructure - Medium  Yes
# 20                          Plan  No
# 24  Infrastructure + NI - Medium  No
# 31        Infrastructure - Large  Yes
# 35       Infrastructure - Medium  Yes
# 36        Infrastructure - Large  Yes
# 40   Infrastructure + NI - Large  No
# 42       Infrastructure - Medium  Yes
# 44   Infrastructure + NI - Large  No
# 46       Infrastructure - Medium  Yes
# 5    Infrastructure + NI - Small  Yes
# 9    Infrastructure + NI - Small  Yes
# 25        Infrastructure - Large  No
# 26        Infrastructure - Small  Yes
# 41        Infrastructure - Small  No
# 48        Infrastructure - Small  No
# 8         Infrastructure - Large  No
#
#    a2_past_proj_qty  total_project_cost  original_prog__amt___pa_ed_  \
# 33                1       15,823,000.00                          NaN
# 22                0                 NaN                          NaN
# 34                2        1,999,000.00                          NaN
# 45                0        2,355,000.00                   112,000.00
# 16                2        4,881,000.00                    45,000.00
# 19                2          600,000.00                          NaN
# 43                3        3,354,000.00                          NaN
# 23                1        1,897,000.00                    58,000.00
# 4                 0        1,535,000.00                   160,000.00
# 13                0        5,660,000.00                          NaN
# 27                3       16,265,000.00                          NaN
# 11                1        1,946,000.00                    95,000.00
# 39               11       11,538,000.00                          NaN
# 10                2       21,037,000.00                          NaN
# 2                 0       16,922,000.00                          NaN
# 29                1        6,845,000.00                   499,000.00
# 14                2        2,510,000.00                          NaN
# 32                0       21,859,000.00                          NaN
# 18                3        5,286,000.00                    67,000.00
# 12                5       10,409,000.00                 1,352,000.00
# 37                0       17,844,000.00                 1,197,000.00
# 47                0          212,000.00                          NaN
# 30                1        3,935,000.00                          NaN
# 0                 0        1,998,000.00                   290,000.00
# 3                 2       12,030,000.00                          NaN
# 17                2       14,001,000.00                          NaN
# 7                 0       23,414,000.00                          NaN
# 21                1          997,000.00                          NaN
# 38                1        2,300,000.00                   198,000.00
# 6                 2        1,900,000.00                   100,000.00
# 28                0        5,176,000.00                   200,000.00
# 1                 0        1,637,000.00                    10,000.00
# 15                2        6,700,000.00                   801,000.00
# 20                0          263,000.00                          NaN
# 24                0        4,000,000.00                          NaN
# 31                2       38,655,000.00                 3,567,000.00
# 35                6        6,960,000.00                   222,000.00
# 36                2       11,057,000.00                   188,000.00
# 40                0        8,771,000.00                   225,000.00
# 42                1        6,832,000.00                   756,000.00
# 44                1        8,332,000.00                   225,000.00
# 46                7        6,999,000.00                   200,000.00
# 5                 1        1,636,000.00                     3,000.00
# 9                11        1,178,000.00                          NaN
# 25                0        7,750,000.00                          NaN
# 26                2        1,498,000.00                          NaN
# 41                0        1,969,000.00                    25,000.00
# 48                0        1,998,000.00                    15,000.00
# 8                 0       12,221,000.00                   600,000.00
#
#     original_prog__amt___ps_e_  orignal_prog__amt___con_  \
# 33                         NaN             10,541,000.00
# 22                         NaN                       NaN
# 34                         NaN              1,896,000.00
# 45                  160,000.00              1,271,000.00
# 16                  468,000.00              3,879,000.00
# 19                         NaN                       NaN
# 43                  539,000.00              2,479,000.00
# 23                  260,000.00              1,025,000.00
# 4                   160,000.00              1,075,000.00
# 13                         NaN              4,317,000.00
# 27                         NaN              9,323,000.00
# 11                  190,000.00              1,381,000.00
# 39                         NaN              3,500,000.00
# 10                         NaN             14,180,000.00
# 2                   838,000.00              9,948,000.00
# 29                         NaN              5,660,000.00
# 14                         NaN                       NaN
# 32                         NaN             17,269,000.00
# 18                  240,000.00              3,658,000.00
# 12                  338,000.00              5,643,000.00
# 37                1,796,000.00              3,227,000.00
# 47                         NaN                       NaN
# 30                         NaN              2,462,000.00
# 0                    29,000.00              1,671,000.00
# 3                          NaN              8,634,000.00
# 17                1,576,000.00              9,450,000.00
# 7                   321,000.00             15,953,000.00
# 21                   82,000.00                915,000.00
# 38                  147,000.00              1,586,000.00
# 6                          NaN              1,800,000.00
# 28                  450,000.00              3,015,000.00
# 1                   130,000.00              1,497,000.00
# 15                  290,000.00              4,939,000.00
# 20                         NaN                       NaN
# 24                         NaN              3,171,000.00
# 31                1,921,000.00             25,243,000.00
# 35                  884,000.00              5,089,000.00
# 36                1,588,000.00              8,175,000.00
# 40                  450,000.00              6,675,000.00
# 42                  329,000.00              5,064,000.00
# 44                  675,000.00              5,740,000.00
# 46                         NaN              6,299,000.00
# 5                   138,000.00              1,441,000.00
# 9                   140,000.00                949,000.00
# 25                         NaN              7,100,000.00
# 26                         NaN              1,255,000.00
# 41                  100,000.00              1,644,000.00
# 48                  220,000.00              1,763,000.00
# 8                   800,000.00              7,470,000.00
#
#     original_prog__amt___con_ni_
# 33                    647,000.00
# 22                           NaN
# 34                     35,000.00
# 45                     35,000.00
# 16                           NaN
# 19                    600,000.00
# 43                           NaN
# 23                           NaN
# 4                     127,000.00
# 13                           NaN
# 27                           NaN
# 11                     80,000.00
# 39                           NaN
# 10                           NaN
# 2                     117,000.00
# 29                           NaN
# 14                  2,510,000.00
# 32                           NaN
# 18                           NaN
# 12                     87,000.00
# 37                     76,000.00
# 47                    202,000.00
# 30                    153,000.00
# 0                            NaN
# 3                     550,000.00
# 17                  1,015,000.00
# 7                            NaN
# 21                           NaN
# 38                           NaN
# 6                            NaN
# 28                           NaN
# 1                            NaN
# 15                           NaN
# 20                    263,000.00
# 24                     25,000.00
# 31                           NaN
# 35                           NaN
# 36                           NaN
# 40                    543,000.00
# 42                           NaN
# 44                    858,000.00
# 46                           NaN
# 5                      40,000.00
# 9                      75,000.00
# 25                           NaN
# 26                           NaN
# 41                           NaN
# 48                           NaN
# 8                            NaN

# %%
shopp>>filter(_.ppno==5860)
# Out:
#    rail_project_id  _10_year_plan ct_project_id  update_complete     ea  ppno  \
# 63            None              0    0318000336                1  4H580  5860
#
#                                          project_name  district county route  \
# 63  Sac-5 Corridor Improvement Project (Phase A)\n...         3    SAC   005
#
#                                   project_description current_phase  \
# 63  •Electric Vehicle Charging (EVC) stations at I...         PA&ED
#
#    con_existing_source_s__of_funds      con_anticipated_source_of_funds  \
# 63                            TCEP  Information currently not available
#
#    target_opening_year beg_pm end_pm primary_mode  \
# 63                2028  22.40  34.40      Highway
#
#                         previous_caltrans_nominations urban_rural  \
# 63  TCEP Cycle 3 Not Recommended\nSCCP Cycle 3 Not...       Urban
#
#                                                 notes lead_agency  \
# 63  ACCESS: From a policy standpoint, this project...    Caltrans
#
#    pid_approval_date__m010   target_pa_ed__m200       rtl_date__m460  \
# 63     2022-12-30 00:00:00  2023-11-01 00:00:00  2025-05-13 00:00:00
#
#    con_start_date__m500  funding_need_phase_s  pa_ed_cost__$1,000  \
# 63  2025-11-12 00:00:00                     0               11430
#
#     ps_e_cost__$1,000  row_cost__$1,000  con_support_cost__$1,000  \
# 63              12100               790                     26500
#
#     non_infrastructure___plan_cost__$1,000  total_unfunded_need__$1,000  \
# 63                                       0                   290,460.00
#
#    previous_funding_request_phase  last_scored csis_alignment  \
# 63                           None            0        Aligned
#
#     csis_total_score__out_of_45  mode_shift__csis__score  \
# 63                           27                        3
#
#                             mode_shift__csis__comment  vmt__csis__score  \
# 63  Highway project with potential to encourage gr...                 3
#
#                                    vmt__csis__comment  \
# 63  Project states it will reduce SOV and shift VM...
#
#     public_engagement__csis__score  \
# 63                               3
#
#                      public_engagement__csis__comment  \
# 63  Specific details about engagement strategy.\nI...
#
#     dac_local_community_needs__csis__score  \
# 63                                       3
#
#     dac_local_community_needs__csis__comment  safety__csis__score  \
# 63                                         0                    3
#
#                                 safety__csis__comment  zev__csis__score  \
# 63  Does not address all components of the project...                 3
#
#                                 zev__csis__comment  \
# 63  Plans to add ZEV charging and increase access.
#
#     climate_resiliency__csis__score  \
# 63                                3
#
#                     climate_resiliency__csis__comment  \
# 63  Includes message signs to aid in evaucation ev...
#
#     natural_resources_and_ecosystems__csis__score  \
# 63                                              3
#
#       natural_resources_and_ecosystems__csis__comment  \
# 63  Meets minimum requirements to mitigate environ...
#
#     infill_development_and_land_use__csis__score  \
# 63                                             3
#
#        infill_development_and_land_use__csis__comment  \
# 63  Project will support planned infill developmen...
#
#     benefits_to_dac_and_advancing_equity__atp__score  \
# 63                                                 0
#
#     community_need__atp__score  safety__atp__score  \
# 63                           0                   0
#
#     public_participation__atp__score  community_feedback__atp__score  \
# 63                                 0                               0
#
#     continued_engagement__atp__score  \
# 63                                 0
#
#     context_sensitive_and_innovation__atp__score  transformative__atp__score  \
# 63                                             0                           0
#
#     atp_total_score__out_of_100     atp_alignment  access_alignment  \
# 63                            0  Not Well-Aligned  Not Well-Aligned
#
#    previous_funding_request            modified             modified_by  \
# 63                     None 2022-12-30 12:26:36  larissa.lee@dot.ca.gov
#
#     purpose___need parcel_counts  total_project_cost__$1,000  \
# 63               0             0                  304,000.00
#
#     con_capital_cost__$1,000  hq_priority  district_priority  \
# 63                    302020            1                  0
#
#                           potential_funding_program_s located_in_dac  \
# 63  Chrg & Fuel\nInfrastructure For Rebuilding Ame...           None
#
#    shs_capacity_increase_detail  \
# 63    Express Lane (Conversion)
#
#                                    secondary_mode_s full_county_name  \
# 63  Bike/Pedestrian\nComplete Streets\nITS\nTransit       Sacramento
#
#                                detailed_project_title district_full_name  \
# 63  District 3-Sac-5 Corridor Improvement Project ...    03 - Marysville
#
#     increase_peak_person_throughput  reduction_in_peak_period_delay  \
# 63                            49.89                           33.22
#
#     reduction_in_fatal_and_injury_crashes  reduction_in_injury_rates  \
# 63                                  44.28                      26.36
#
#     increase_access_to_jobs  increase_access_jobs_to_dac  \
# 63                     3.81                        25.92
#
#     commercial_dev_developed  tons_of_goods_impacted  improve_air_quality  \
# 63                     24.59                   34.21                47.69
#
#     impact_natural_resources  support_of_transportation  fake_benefit_score  \
# 63                     27.21                      39.50                2.26
#
#     statewide_rank  district_rank fake_benefit_score_statewide_percentile  \
# 63           29.00              1                         25th percentile
#
#     district_district_median  total_project_cost__$1,000__district_median  \
# 63                         3                                    34,707.00
#
#     fake_benefit_score_district_median  \
# 63                                1.84
#
#     total_unfunded_need__$1,000__district_median  \
# 63                                             0
#
#     csis_total_score__out_of_45__district_median  \
# 63                                             0
#
#     atp_total_score__out_of_100__district_median
# 63                                             0

# %%
atp_funded_subset>>filter(_.ppno=='5860')
# Out:
#     ppno ppno1 project_cycle    a2_county a2_ct_dist  a1_imp_agcy_name  \
# 20  5860   NaN             5  Los Angeles          7  Maywood, City of
#
#    imp_agency_name_new                              a2_mop_uza_population  \
# 20     City of Maywood  Project is located within one of the ten large...
#
#                              a2_info_proj_name  \
# 20  City of Maywood Active Transportation Plan
#
#                                    a2_info_proj_descr a3_plan_other_desc  \
# 20  The City of Maywood will develop an Active Tra...                NaN
#
#                                     a2_output_outcome a3_proj_type_x  \
# 20  The outcome will include the delivery of activ...           Plan
#
#                       a2_past_proj a2_past_proj_qty  total_project_cost  \
# 20  No                                            0          263,000.00
#
#     original_prog__amt___pa_ed_  original_prog__amt___ps_e_  \
# 20                          NaN                         NaN
#
#     orignal_prog__amt___con_  original_prog__amt___con_ni_
# 20                       NaN                    263,000.00

# %%
# PPNO Matches Manual

## different districts
#shopp>>filter(_.ppno==5860) ## but not the same project

# %%
# atp_funded_subset>>filter(_.ppno=='5860')

# %%
# shopp['ppno'] = shopp['ppno'].map({'None': np.nan})

# %%
# shopp['ppno'] = shopp.ppno.astype('Int64')
#atp_funded_subset['ppno'] = atp_funded_subset.ppno.astype('Int64')

# %% [markdown]
# ### looking at specific districts

# %%
## starting with 7

dist7_shopp = shopp>>filter(_.district=='07 - Los Angeles')

# %%
dist7_atp = atp_funded_subset>>filter(_.a2_ct_dist=="7")

# %%
dist7_shopp>>filter(_.ppno!='None', _.ppno.notnull())
# Out:
# Empty DataFrame
# Columns: [rail_project_id, _10_year_plan, ct_project_id, update_complete, ea, ppno, project_name, district, county, route, project_description, current_phase, con_existing_source_s__of_funds, con_anticipated_source_of_funds, target_opening_year, beg_pm, end_pm, primary_mode, previous_caltrans_nominations, urban_rural, notes, lead_agency, pid_approval_date__m010, target_pa_ed__m200, rtl_date__m460, con_start_date__m500, funding_need_phase_s, pa_ed_cost__$1,000, ps_e_cost__$1,000, row_cost__$1,000, con_support_cost__$1,000, non_infrastructure___plan_cost__$1,000, total_unfunded_need__$1,000, previous_funding_request_phase, last_scored, csis_alignment, csis_total_score__out_of_45, mode_shift__csis__score, mode_shift__csis__comment, vmt__csis__score, vmt__csis__comment, public_engagement__csis__score, public_engagement__csis__comment, dac_local_community_needs__csis__score, dac_local_community_needs__csis__comment, safety__csis__score, safety__csis__comment, zev__csis__score, zev__csis__comment, climate_resiliency__csis__score, climate_resiliency__csis__comment, natural_resources_and_ecosystems__csis__score, natural_resources_and_ecosystems__csis__comment, infill_development_and_land_use__csis__score, infill_development_and_land_use__csis__comment, benefits_to_dac_and_advancing_equity__atp__score, community_need__atp__score, safety__atp__score, public_participation__atp__score, community_feedback__atp__score, continued_engagement__atp__score, context_sensitive_and_innovation__atp__score, transformative__atp__score, atp_total_score__out_of_100, atp_alignment, access_alignment, previous_funding_request, modified, modified_by, purpose___need, parcel_counts, total_project_cost__$1,000, con_capital_cost__$1,000, hq_priority, district_priority, potential_funding_program_s, located_in_dac, shs_capacity_increase_detail, secondary_mode_s, full_county_name, detailed_project_title, district_full_name, increase_peak_person_throughput, reduction_in_peak_period_delay, reduction_in_fatal_and_injury_crashes, reduction_in_injury_rates, increase_access_to_jobs, increase_access_jobs_to_dac, commercial_dev_developed, tons_of_goods_impacted, improve_air_quality, impact_natural_resources, support_of_transportation, fake_benefit_score, statewide_rank, district_rank, fake_benefit_score_statewide_percentile, district_district_median, total_project_cost__$1,000__district_median, fake_benefit_score_district_median, ...]
# Index: []

# %%
dist7_atp>>arrange(_.ppno)
# Out:
#      ppno  ppno1 project_cycle    a2_county a2_ct_dist  \
# 1    5858    NaN             5  Los Angeles          7
# 15   5859    NaN             5  Los Angeles          7
# 20   5860    NaN             5  Los Angeles          7
# 24  5861A  5861B             5  Los Angeles          7
# 31   5862    NaN             5  Los Angeles          7
# 35   5863    NaN             5      Ventura          7
# 36   5864    NaN             5  Los Angeles          7
# 40  5865A  5865B             5  Los Angeles          7
# 42   5866    NaN             5  Los Angeles          7
# 44  5867A  5867B             5  Los Angeles          7
# 46   5868    NaN             5  Los Angeles          7
#
#            a1_imp_agcy_name     imp_agency_name_new  \
# 1   South El Monte, City of  City of South El Monte
# 15     Los Angeles, City of     City of Los Angeles
# 20         Maywood, City of         City of Maywood
# 24    Santa Monica, City of    City of Santa Monica
# 31     Los Angeles, City of     City of Los Angeles
# 35           Ventura County          Ventura County
# 36     Los Angeles, City of     City of Los Angeles
# 40      Long Beach, City of      City of Long Beach
# 42     Los Angeles, City of     City of Los Angeles
# 44      Long Beach, City of      City of Long Beach
# 46    Bell Gardens, City of    City of Bell Gardens
#
#                                 a2_mop_uza_population  \
# 1   Project is located within one of the ten large...
# 15  Project is located within one of the ten large...
# 20  Project is located within one of the ten large...
# 24  Project is located within one of the ten large...
# 31  Project is located within one of the ten large...
# 35  Project is located within one of the ten large...
# 36  Project is located within one of the ten large...
# 40  Project is located within one of the ten large...
# 42  Project is located within one of the ten large...
# 44  Project is located within one of the ten large...
# 46  Project is located within one of the ten large...
#
#                                     a2_info_proj_name  \
# 1   South El Monte Safe Routes to School Pedestria...
# 15  SRTS Carver Middle, Ascot Avenue and Harmony E...
# 20         City of Maywood Active Transportation Plan
# 24    Stewart-Pennsylvania Safety Enhancement Project
# 31  Connecting Canoga Park Through Safety and Urba...
# 35  El Rio Pedestrian Improvement and Safe Route t...
# 36  SRTS Berendo Middle and 3 Feeder Elementary Sc...
# 40               Downtown Long Beach Walkable Corners
# 42      SRTS Panorama City Elementary School Project
# 44                         Pacific Avenue Cycle Track
# 46  Bell Gardens Complete Streets Improvements - P...
#
#                                    a2_info_proj_descr  \
# 1   This project focuses on school and pedestrian ...
# 15  Transform one of the City’s most disadvantaged...
# 20  The City of Maywood will develop an Active Tra...
# 24  Construction of Class IV separated bikeway, bu...
# 31  7 miles of pedestrian and cyclist improvements...
# 35  Install sidewalks, curbs, gutters, water-reten...
# 36  The one-quarter mile radius around Berendo Mid...
# 40  Transform Downtown Long Beach into a pedestria...
# 42  Transform one of the City’s most traffic-stres...
# 44  Transform Pacific Avenue into a complete stree...
# 46  Citywide ped, bike, & traffic calming improvem...
#
#                                    a3_plan_other_desc  \
# 1                                                 NaN
# 15  Mobility Plan 2035, Vision Zero LA, Green New ...
# 20                                                NaN
# 24  Land Use and Circulation Element, Bergamot Are...
# 31             City of Los Angeles Mobility Plan 2035
# 35                                                NaN
# 36  Mobility Plan 2035, Vision Zero LA, Green New ...
# 40                            Vision Zero Action Plan
# 42  Mobility Plan 2035, Vision Zero LA, Green New ...
# 44                            Vision Zero Action Plan
# 46                              Complete Streets Plan
#
#                                     a2_output_outcome  \
# 1   Installation of pedestrian safety upgrades at ...
# 15  12 curb extensions, 3 raised crosswalks, 1 HAW...
# 20  The outcome will include the delivery of activ...
# 24  Construction of safety enhancements including ...
# 31  A network of pedestrian and cyclist improvemen...
# 35  Constructing Sidewalks and crosswalk improveme...
# 36  27 curb extensions, 2 traffic circles, 8,700 s...
# 40  Transform Downtown Long Beach into a pedestria...
# 42  23 curb extensions, 6 median extensions, 2 tra...
# 44  The Pacific Avenue Cycle Track project will ad...
# 46  Install or refresh 31 white or yellow high vis...
#
#                   a3_proj_type_x                    a2_past_proj  \
# 1         Infrastructure - Small  No
# 15       Infrastructure - Medium  Yes
# 20                          Plan  No
# 24  Infrastructure + NI - Medium  No
# 31        Infrastructure - Large  Yes
# 35       Infrastructure - Medium  Yes
# 36        Infrastructure - Large  Yes
# 40   Infrastructure + NI - Large  No
# 42       Infrastructure - Medium  Yes
# 44   Infrastructure + NI - Large  No
# 46       Infrastructure - Medium  Yes
#
#    a2_past_proj_qty  total_project_cost  original_prog__amt___pa_ed_  \
# 1                 0        1,637,000.00                    10,000.00
# 15                2        6,700,000.00                   801,000.00
# 20                0          263,000.00                          NaN
# 24                0        4,000,000.00                          NaN
# 31                2       38,655,000.00                 3,567,000.00
# 35                6        6,960,000.00                   222,000.00
# 36                2       11,057,000.00                   188,000.00
# 40                0        8,771,000.00                   225,000.00
# 42                1        6,832,000.00                   756,000.00
# 44                1        8,332,000.00                   225,000.00
# 46                7        6,999,000.00                   200,000.00
#
#     original_prog__amt___ps_e_  orignal_prog__amt___con_  \
# 1                   130,000.00              1,497,000.00
# 15                  290,000.00              4,939,000.00
# 20                         NaN                       NaN
# 24                         NaN              3,171,000.00
# 31                1,921,000.00             25,243,000.00
# 35                  884,000.00              5,089,000.00
# 36                1,588,000.00              8,175,000.00
# 40                  450,000.00              6,675,000.00
# 42                  329,000.00              5,064,000.00
# 44                  675,000.00              5,740,000.00
# 46                         NaN              6,299,000.00
#
#     original_prog__amt___con_ni_
# 1                            NaN
# 15                           NaN
# 20                    263,000.00
# 24                     25,000.00
# 31                           NaN
# 35                           NaN
# 36                           NaN
# 40                    543,000.00
# 42                           NaN
# 44                    858,000.00
# 46                           NaN

# %%
atp_funded_subset['con_existing_source_s__of_funds'] = 'ATP Cycle ' + atp_funded_subset['project_cycle']
# Out:
# /tmp/ipykernel_2644/2486006027.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### Renaming cols to add ATP funded projects

# %%
atp_funded_subset.sample()
# Out:
#     ppno ppno1 project_cycle    a2_county a2_ct_dist      a1_imp_agcy_name  \
# 42  5866   NaN             5  Los Angeles          7  Los Angeles, City of
#
#     imp_agency_name_new                              a2_mop_uza_population  \
# 42  City of Los Angeles  Project is located within one of the ten large...
#
#                                 a2_info_proj_name  \
# 42  SRTS Panorama City Elementary School Project
#
#                                    a2_info_proj_descr  \
# 42  Transform one of the City’s most traffic-stres...
#
#                                    a3_plan_other_desc  \
# 42  Mobility Plan 2035, Vision Zero LA, Green New ...
#
#                                     a2_output_outcome  \
# 42  23 curb extensions, 6 median extensions, 2 tra...
#
#              a3_proj_type_x                    a2_past_proj a2_past_proj_qty  \
# 42  Infrastructure - Medium  Yes                                           1
#
#     total_project_cost  original_prog__amt___pa_ed_  \
# 42        6,832,000.00                   756,000.00
#
#     original_prog__amt___ps_e_  orignal_prog__amt___con_  \
# 42                  329,000.00              5,064,000.00
#
#     original_prog__amt___con_ni_ con_existing_source_s__of_funds
# 42                           NaN                     ATP Cycle 5

# %%
shopp.sample()
# Out:
#    rail_project_id  _10_year_plan ct_project_id  update_complete     ea  \
# 59            None              0    0315000138                1  0C931
#
#      ppno                          project_name  district county route  \
# 59  1520A  Kings Beach Western Approach Project         3    PLA   028
#
#                                   project_description current_phase  \
# 59  The project consists of pedestrian improvement...    REMOVE/END
#
#    con_existing_source_s__of_funds      con_anticipated_source_of_funds  \
# 59                            None  Information currently not available
#
#    target_opening_year beg_pm end_pm      primary_mode  \
# 59                2018   None   None  Complete Streets
#
#    previous_caltrans_nominations urban_rural  \
# 59         RAISE 2022 LOS Signed       Rural
#
#                                                 notes    lead_agency  \
# 59  ATP Cycle 5 Funded through Regional ATP (TMPO)...  Placer County
#
#    pid_approval_date__m010 target_pa_ed__m200       rtl_date__m460  \
# 59          datetime64[ns]               None  2016-01-12 00:00:00
#
#    con_start_date__m500  funding_need_phase_s  pa_ed_cost__$1,000  \
# 59  2018-04-01 00:00:00                     0                   0
#
#     ps_e_cost__$1,000  row_cost__$1,000  con_support_cost__$1,000  \
# 59                  0                 0                         0
#
#     non_infrastructure___plan_cost__$1,000  total_unfunded_need__$1,000  \
# 59                                       0                         0.00
#
#    previous_funding_request_phase  last_scored    csis_alignment  \
# 59                           None            0  Not Well-Aligned
#
#     csis_total_score__out_of_45  mode_shift__csis__score  \
# 59                            0                        0
#
#    mode_shift__csis__comment  vmt__csis__score vmt__csis__comment  \
# 59                      None                 0               None
#
#     public_engagement__csis__score public_engagement__csis__comment  \
# 59                               0                             None
#
#     dac_local_community_needs__csis__score  \
# 59                                       0
#
#     dac_local_community_needs__csis__comment  safety__csis__score  \
# 59                                         0                    0
#
#    safety__csis__comment  zev__csis__score zev__csis__comment  \
# 59                  None                 0               None
#
#     climate_resiliency__csis__score climate_resiliency__csis__comment  \
# 59                                0                              None
#
#     natural_resources_and_ecosystems__csis__score  \
# 59                                              0
#
#    natural_resources_and_ecosystems__csis__comment  \
# 59                                            None
#
#     infill_development_and_land_use__csis__score  \
# 59                                             0
#
#    infill_development_and_land_use__csis__comment  \
# 59                                           None
#
#     benefits_to_dac_and_advancing_equity__atp__score  \
# 59                                                 0
#
#     community_need__atp__score  safety__atp__score  \
# 59                           0                   0
#
#     public_participation__atp__score  community_feedback__atp__score  \
# 59                                 0                               0
#
#     continued_engagement__atp__score  \
# 59                                 0
#
#     context_sensitive_and_innovation__atp__score  transformative__atp__score  \
# 59                                             0                           0
#
#     atp_total_score__out_of_100     atp_alignment access_alignment  \
# 59                            0  Not Well-Aligned             None
#
#    previous_funding_request            modified                 modified_by  \
# 59                     5800 2022-12-30 09:25:32  madison.buccola@dot.ca.gov
#
#     purpose___need parcel_counts  total_project_cost__$1,000  \
# 59               0             0                    7,600.00
#
#     con_capital_cost__$1,000  hq_priority  district_priority  \
# 59                      7600            0                  0
#
#                           potential_funding_program_s located_in_dac  \
# 59  Atp\nActive Transportation Infrastructure Inve...           None
#
#    shs_capacity_increase_detail             secondary_mode_s full_county_name  \
# 59           New Connector Road  Bike/Pedestrian\nRoundabout           Placer
#
#                              detailed_project_title district_full_name  \
# 59  District 3-Kings Beach Western Approach Project    03 - Marysville
#
#     increase_peak_person_throughput  reduction_in_peak_period_delay  \
# 59                            42.57                           39.78
#
#     reduction_in_fatal_and_injury_crashes  reduction_in_injury_rates  \
# 59                                  29.68                      12.22
#
#     increase_access_to_jobs  increase_access_jobs_to_dac  \
# 59                     5.80                        45.90
#
#     commercial_dev_developed  tons_of_goods_impacted  improve_air_quality  \
# 59                     24.05                   14.17                42.83
#
#     impact_natural_resources  support_of_transportation  fake_benefit_score  \
# 59                     33.00                      44.42                2.12
#
#     statewide_rank  district_rank fake_benefit_score_statewide_percentile  \
# 59           75.00              2                         25th percentile
#
#     district_district_median  total_project_cost__$1,000__district_median  \
# 59                         3                                    34,707.00
#
#     fake_benefit_score_district_median  \
# 59                                1.84
#
#     total_unfunded_need__$1,000__district_median  \
# 59                                             0
#
#     csis_total_score__out_of_45__district_median  \
# 59                                             0
#
#     atp_total_score__out_of_100__district_median
# 59                                             0

# %%
atp_funded_subset = (atp_funded_subset.rename(columns={'a2_county':'full_county_name',
                                                      'a2_ct_dist':'district',
                                                      'imp_agency_name_new':'lead_agency',
                                                       'a2_info_proj_name':'project_name',
                                                      'a2_info_proj_descr':'project_description',
                                                      'original_prog__amt___pa_ed_':'pa_ed_cost__$1,000',
                                                      'original_prog__amt___ps_e_':'ps_e_cost__$1,000',
                                                      'original_prog__amt___con_ni_':'non_infrastructure___plan_cost__$1,000',
                                                      'total_project_cost':'total_project_cost__$1,000',
                                                       'a3_proj_type_x':'notes'
                                                      }))

# %%
atp_funded_subset.head()
# Out:
#     ppno ppno1 project_cycle full_county_name district       a1_imp_agcy_name  \
# 22  1228   NaN             5        El Dorado        3       El Dorado County
# 8    NaN   NaN             5         Siskiyou        2            Karuk Tribe
# 46  5868   NaN             5      Los Angeles        7  Bell Gardens, City of
# 30  2610   NaN             5           Shasta        2       Redding, City of
# 21  3204   NaN             5             Lake        1     Clearlake, City of
#
#              lead_agency                              a2_mop_uza_population  \
# 22                   NaN  Project is located within one of the ten large...
# 8            Karuk Tribe  Project is located outside one of the ten larg...
# 46  City of Bell Gardens  Project is located within one of the ten large...
# 30       City of Redding  Project is located outside one of the ten larg...
# 21     City of Clearlake  Project is located outside one of the ten larg...
#
#                                          project_name  \
# 22  Pollock Pines - Pony Express Trail Bicycle and...
# 8                 Happy Camp Complete Streets Project
# 46  Bell Gardens Complete Streets Improvements - P...
# 30      Turtle Bay to Downtown Gap Completion Project
# 21  Dam Road Extension & South Center Drive Bike/P...
#
#                                   project_description  \
# 22  1.7 miles of class II bike lanes on both sides...
# 8   In Happy Camp on SR 96, install sidewalks, con...
# 46  Citywide ped, bike, & traffic calming improvem...
# 30  Buffered 2-way cycle track; shared use path; r...
# 21  Construct curb, gutter and sidewalk, and add b...
#
#                                    a3_plan_other_desc  \
# 22                                                NaN
# 8   Middle Klamath River Community Transportation ...
# 46                              Complete Streets Plan
# 30                                                NaN
# 21                                                NaN
#
#                                     a2_output_outcome  \
# 22  1.7 miles of class II bike lanes on both sides...
# 8   Project will provide complete street elements ...
# 46  Install or refresh 31 white or yellow high vis...
# 30  Installation of buffered 2-way cycle track; sh...
# 21  Construction of curb, gutter and sidewalk and ...
#
#                            notes                    a2_past_proj  \
# 22                           NaN  No
# 8         Infrastructure - Large  No
# 46       Infrastructure - Medium  Yes
# 30  Infrastructure + NI - Medium  Yes
# 21        Infrastructure - Small  Yes
#
#    a2_past_proj_qty  total_project_cost__$1,000  pa_ed_cost__$1,000  \
# 22                0                         NaN                 NaN
# 8                 0               12,221,000.00          600,000.00
# 46                7                6,999,000.00          200,000.00
# 30                1                3,935,000.00                 NaN
# 21                1                  997,000.00                 NaN
#
#     ps_e_cost__$1,000  orignal_prog__amt___con_  \
# 22                NaN                       NaN
# 8          800,000.00              7,470,000.00
# 46                NaN              6,299,000.00
# 30                NaN              2,462,000.00
# 21          82,000.00                915,000.00
#
#     non_infrastructure___plan_cost__$1,000 con_existing_source_s__of_funds
# 22                                     NaN                     ATP Cycle 5
# 8                                      NaN                     ATP Cycle 5
# 46                                     NaN                     ATP Cycle 5
# 30                              153,000.00                     ATP Cycle 5
# 21                                     NaN                     ATP Cycle 5

# %%
cols_to_divide = ['total_project_cost__$1,000', 'pa_ed_cost__$1,000',
                  'ps_e_cost__$1,000', 'orignal_prog__amt___con_', 'non_infrastructure___plan_cost__$1,000']

# %%
def align_funding_numbers(df, list_of_cols):
    for col in list_of_cols:
       # df[col] = df[col].astype('Int64')
        df[col] = df[col]/1000
        
    return df

# %%
atp_funded_subset_funds = align_funding_numbers(atp_funded_subset, cols_to_divide)

# %%
atp_funded_subset_funds.head()
# Out:
#     ppno ppno1 project_cycle full_county_name district       a1_imp_agcy_name  \
# 22  1228   NaN             5        El Dorado        3       El Dorado County
# 8    NaN   NaN             5         Siskiyou        2            Karuk Tribe
# 46  5868   NaN             5      Los Angeles        7  Bell Gardens, City of
# 30  2610   NaN             5           Shasta        2       Redding, City of
# 21  3204   NaN             5             Lake        1     Clearlake, City of
#
#              lead_agency                              a2_mop_uza_population  \
# 22                   NaN  Project is located within one of the ten large...
# 8            Karuk Tribe  Project is located outside one of the ten larg...
# 46  City of Bell Gardens  Project is located within one of the ten large...
# 30       City of Redding  Project is located outside one of the ten larg...
# 21     City of Clearlake  Project is located outside one of the ten larg...
#
#                                          project_name  \
# 22  Pollock Pines - Pony Express Trail Bicycle and...
# 8                 Happy Camp Complete Streets Project
# 46  Bell Gardens Complete Streets Improvements - P...
# 30      Turtle Bay to Downtown Gap Completion Project
# 21  Dam Road Extension & South Center Drive Bike/P...
#
#                                   project_description  \
# 22  1.7 miles of class II bike lanes on both sides...
# 8   In Happy Camp on SR 96, install sidewalks, con...
# 46  Citywide ped, bike, & traffic calming improvem...
# 30  Buffered 2-way cycle track; shared use path; r...
# 21  Construct curb, gutter and sidewalk, and add b...
#
#                                    a3_plan_other_desc  \
# 22                                                NaN
# 8   Middle Klamath River Community Transportation ...
# 46                              Complete Streets Plan
# 30                                                NaN
# 21                                                NaN
#
#                                     a2_output_outcome  \
# 22  1.7 miles of class II bike lanes on both sides...
# 8   Project will provide complete street elements ...
# 46  Install or refresh 31 white or yellow high vis...
# 30  Installation of buffered 2-way cycle track; sh...
# 21  Construction of curb, gutter and sidewalk and ...
#
#                            notes                    a2_past_proj  \
# 22                           NaN  No
# 8         Infrastructure - Large  No
# 46       Infrastructure - Medium  Yes
# 30  Infrastructure + NI - Medium  Yes
# 21        Infrastructure - Small  Yes
#
#    a2_past_proj_qty  total_project_cost__$1,000  pa_ed_cost__$1,000  \
# 22                0                         NaN                 NaN
# 8                 0                   12,221.00              600.00
# 46                7                    6,999.00              200.00
# 30                1                    3,935.00                 NaN
# 21                1                      997.00                 NaN
#
#     ps_e_cost__$1,000  orignal_prog__amt___con_  \
# 22                NaN                       NaN
# 8              800.00                  7,470.00
# 46                NaN                  6,299.00
# 30                NaN                  2,462.00
# 21              82.00                    915.00
#
#     non_infrastructure___plan_cost__$1,000 con_existing_source_s__of_funds
# 22                                     NaN                     ATP Cycle 5
# 8                                      NaN                     ATP Cycle 5
# 46                                     NaN                     ATP Cycle 5
# 30                                  153.00                     ATP Cycle 5
# 21                                     NaN                     ATP Cycle 5

# %%
atp_funded_subset_funds['primary_mode'] = 'Active Transportation'

# %%
atp_funded_subset_funds['lead_agency'] = atp_funded_subset_funds['lead_agency'].fillna(atp_funded_subset_funds['a1_imp_agcy_name'])

# %%
def add_previous_funding_requests_col(df, col_name):
    ## code help: https://stackoverflow.com/questions/71173917/why-i-am-getting-error-str-object-has-no-attribute-str-i-simply-wanted-t
    def return_prev_proj(df):
        if ("Yes" in df[col_name]):
            return ("Active Transportation Program Previous Projects")
        
        elif ("No" in df[col_name]):
            return "No Previous ATP Projects"
        
        else:
            return "Unknown"

    df['previous_caltrans_nominations'] = df.apply(return_prev_proj, axis = 1)
    
    return df

# %%
atp_funded_subset_funds = add_previous_funding_requests_col(atp_funded_subset_funds, 'a2_past_proj')

# %%
atp_funded_subset_funds.a2_mop_uza_population.value_counts()
# Out:
# Project is located within one of the ten large MPOs                                                  33
# Project is located outside one of the ten large MPOs in a UZA with Pop <=200,000 and > than 5,000    13
# Project is located outside one of the ten large MPOs in a UZA with Pop <= 5,000                       3
# Name: a2_mop_uza_population, dtype: int64

# %%
def add_urban_rural(df, col_name):
    ## code help: https://stackoverflow.com/questions/71173917/why-i-am-getting-error-str-object-has-no-attribute-str-i-simply-wanted-t
    def return_urban_rural(df):
        if ("Project is located within one of the ten large MPOs" in df[col_name]):
            return ("Urban")
        elif ("Project is located outside one of the ten large MPOs in a UZA with Pop <=200,000 and > than 5,000" in df[col_name]):
            return ("Unknown")
        
        elif ("Project is located outside one of the ten large MPOs in a UZA with Pop <= 5,000" in df[col_name]):
            return "Rural"
        
        else:
            return "None"

    df['urban_rural'] = df.apply(return_urban_rural, axis = 1)
    
    return df

# %%
atp_funded_subset_funds = add_urban_rural(atp_funded_subset_funds, "a2_mop_uza_population")

# %%
shopp.sample()
# Out:
#     rail_project_id  _10_year_plan ct_project_id  update_complete     ea  \
# 521            None              0    1213000149                1  0K720
#
#      ppno                                       project_name  district county  \
# 521  3505  Sr 55 Increase Capacity & Improve Operations -...        12    ORA
#
#     route                                project_description current_phase  \
# 521   055  In Orange County in Tustin, Santa Ana, Orange ...      PS&E/ROW
#
#          con_existing_source_s__of_funds      con_anticipated_source_of_funds  \
# 521  Information currently not available  Information currently not available
#
#     target_opening_year beg_pm end_pm primary_mode  \
# 521                2028  10.50  17.80      Highway
#
#     previous_caltrans_nominations urban_rural  \
# 521           ACCESS Project List       Urban
#
#                                                  notes    lead_agency  \
# 521  ACCESS: Project is far in delivery but not sch...  Octa/Caltrans
#
#     pid_approval_date__m010   target_pa_ed__m200       rtl_date__m460  \
# 521     2014-02-15 00:00:00  2020-03-30 00:00:00  2025-05-06 00:00:00
#
#     con_start_date__m500  funding_need_phase_s  pa_ed_cost__$1,000  \
# 521  2025-12-05 00:00:00                     0                   0
#
#      ps_e_cost__$1,000  row_cost__$1,000  con_support_cost__$1,000  \
# 521                  0                 0                         0
#
#      non_infrastructure___plan_cost__$1,000  total_unfunded_need__$1,000  \
# 521                                       0                         0.00
#
#     previous_funding_request_phase  last_scored    csis_alignment  \
# 521                           None            0  Not Well-Aligned
#
#      csis_total_score__out_of_45  mode_shift__csis__score  \
# 521                            0                        0
#
#     mode_shift__csis__comment  vmt__csis__score vmt__csis__comment  \
# 521                      None                 0               None
#
#      public_engagement__csis__score public_engagement__csis__comment  \
# 521                               0                             None
#
#      dac_local_community_needs__csis__score  \
# 521                                       0
#
#      dac_local_community_needs__csis__comment  safety__csis__score  \
# 521                                         0                    0
#
#     safety__csis__comment  zev__csis__score zev__csis__comment  \
# 521                  None                 0               None
#
#      climate_resiliency__csis__score climate_resiliency__csis__comment  \
# 521                                0                              None
#
#      natural_resources_and_ecosystems__csis__score  \
# 521                                              0
#
#     natural_resources_and_ecosystems__csis__comment  \
# 521                                            None
#
#      infill_development_and_land_use__csis__score  \
# 521                                             0
#
#     infill_development_and_land_use__csis__comment  \
# 521                                           None
#
#      benefits_to_dac_and_advancing_equity__atp__score  \
# 521                                                 0
#
#      community_need__atp__score  safety__atp__score  \
# 521                           0                   0
#
#      public_participation__atp__score  community_feedback__atp__score  \
# 521                                 0                               0
#
#      continued_engagement__atp__score  \
# 521                                 0
#
#      context_sensitive_and_innovation__atp__score  transformative__atp__score  \
# 521                                             0                           0
#
#      atp_total_score__out_of_100     atp_alignment  access_alignment  \
# 521                            0  Not Well-Aligned  Not Well-Aligned
#
#     previous_funding_request            modified                 modified_by  \
# 521                     None 2022-12-30 09:09:15  madison.buccola@dot.ca.gov
#
#      purpose___need parcel_counts  total_project_cost__$1,000  \
# 521               0             0                        0.00
#
#      con_capital_cost__$1,000  hq_priority  district_priority  \
# 521                         0            0                  0
#
#        potential_funding_program_s located_in_dac  \
# 521  Congestion Relief\nSccp\nTcep           None
#
#     shs_capacity_increase_detail secondary_mode_s full_county_name  \
# 521         General Purpose Lane             None           Orange
#
#                                 detailed_project_title district_full_name  \
# 521  District 12-Sr 55 Increase Capacity & Improve ...        12 - Irvine
#
#      increase_peak_person_throughput  reduction_in_peak_period_delay  \
# 521                            17.60                            1.97
#
#      reduction_in_fatal_and_injury_crashes  reduction_in_injury_rates  \
# 521                                  33.86                      12.70
#
#      increase_access_to_jobs  increase_access_jobs_to_dac  \
# 521                    14.64                         4.34
#
#      commercial_dev_developed  tons_of_goods_impacted  improve_air_quality  \
# 521                     13.12                    2.60                15.05
#
#      impact_natural_resources  support_of_transportation  fake_benefit_score  \
# 521                     34.48                      35.21                1.18
#
#      statewide_rank  district_rank fake_benefit_score_statewide_percentile  \
# 521          744.00             38                         75th percentile
#
#      district_district_median  total_project_cost__$1,000__district_median  \
# 521                        12                                         0.00
#
#      fake_benefit_score_district_median  \
# 521                                1.66
#
#      total_unfunded_need__$1,000__district_median  \
# 521                                             0
#
#      csis_total_score__out_of_45__district_median  \
# 521                                             0
#
#      atp_total_score__out_of_100__district_median
# 521                                             0

# %%
atp_funded_subset_funds.drop(columns =['a1_imp_agcy_name', 'a2_past_proj', 'a2_past_proj_qty',
                                       'a2_mop_uza_population', 'a3_plan_other_desc',
                                      'a2_output_outcome', 'project_cycle', 'orignal_prog__amt___con_'], axis=1, inplace=True)

# %%
atp_funded_subset_funds
# Out:
#      ppno  ppno1 full_county_name district  \
# 22   1228    NaN        El Dorado        3
# 8     NaN    NaN         Siskiyou        2
# 46   5868    NaN      Los Angeles        7
# 30   2610    NaN           Shasta        2
# 21   3204    NaN             Lake        1
# 10   2342    NaN          Alameda        4
# 37   2607    NaN           Shasta        2
# 14   2345    NaN      Santa Clara        4
# 47   2608    NaN         Siskiyou        2
# 32   2346    NaN          Alameda        4
# 18   2548    NaN         Humboldt        1
# 45  1274A    NaN   San Bernardino        8
# 48   7080    NaN            Kings        6
# 6    3513    NaN         Mariposa       10
# 3   3058A    NaN       Santa Cruz        5
# 11   2214    NaN       Sacramento        3
# 26   7078    NaN           Fresno        6
# 17  3059A    NaN         Monterey        5
# 43   1440    NaN        San Diego       11
# 27   2213    NaN       Sacramento        3
# 20   5860    NaN      Los Angeles        7
# 33  0413A    NaN       Santa Cruz        5
# 12   2606    NaN           Shasta        2
# 23   1441    NaN        San Diego       11
# 24  5861A  5861B      Los Angeles        7
# 4    1442    NaN        San Diego       11
# 9    7075    NaN             Kern        6
# 13   1443    NaN        San Diego       11
# 39   2215    NaN             Yolo        3
# 5    7074    NaN           Fresno        6
# 0    3057    NaN    Santa Barbara        5
# 29   2344    NaN     Contra Costa        4
# 28   3514    NaN         Mariposa       10
# 19   1277    NaN        Riverside        8
# 44  5867A  5867B      Los Angeles        7
# 34  1273A    NaN        Riverside        8
# 25   7077    NaN           Tulare        6
# 16   1275    NaN   San Bernardino        8
# 2   2343A  2343B           Solano        4
# 1    5858    NaN      Los Angeles        7
# 31   5862    NaN      Los Angeles        7
# 7    3060    NaN  San Luis Obispo        5
# 15   5859    NaN      Los Angeles        7
# 36   5864    NaN      Los Angeles        7
# 42   5866    NaN      Los Angeles        7
# 41   7079    NaN           Fresno        6
# 38   3512    NaN         Tuolumne       10
# 40  5865A  5865B      Los Angeles        7
# 35   5863    NaN          Ventura        7
#
#                                       lead_agency  \
# 22                               El Dorado County
# 8                                     Karuk Tribe
# 46                           City of Bell Gardens
# 30                                City of Redding
# 21                              City of Clearlake
# 10                                City of Oakland
# 37                                  Shasta County
# 14                             Santa Clara County
# 47      Siskiyou County Transportation Commission
# 32                                City of Oakland
# 18                                 City of Arcata
# 45                          San Bernardino County
# 48                               City of Corcoran
# 6                                 Mariposa County
# 3                              City of Santa Cruz
# 11                              Sacramento County
# 26                                  Fresno County
# 17                                City of Seaside
# 43                         City of Imperial Beach
# 27                             City of Sacramento
# 20                                City of Maywood
# 33                            City of Watsonville
# 12                                City of Redding
# 23                          City of National City
# 24                           City of Santa Monica
# 4                               City of Oceanside
# 9                                  City of Delano
# 13  San Diego Association of Governments (SANDAG)
# 39                        City of West Sacramento
# 5                                  City of Fresno
# 0                           City of Santa Barbara
# 29                            Contra Costa County
# 28                                Mariposa County
# 19                               Riverside County
# 44                             City of Long Beach
# 34                                 City of Perris
# 25                            City of Porterville
# 16                                City of Ontario
# 2                               City of Fairfield
# 1                          City of South El Monte
# 31                            City of Los Angeles
# 7                          San Luis Obispo County
# 15                            City of Los Angeles
# 36                            City of Los Angeles
# 42                            City of Los Angeles
# 41                                  City of Huron
# 38                                Tuolumne County
# 40                             City of Long Beach
# 35                                 Ventura County
#
#                                          project_name  \
# 22  Pollock Pines - Pony Express Trail Bicycle and...
# 8                 Happy Camp Complete Streets Project
# 46  Bell Gardens Complete Streets Improvements - P...
# 30      Turtle Bay to Downtown Gap Completion Project
# 21  Dam Road Extension & South Center Drive Bike/P...
# 10                      7th Street Connection Project
# 37  Cottonwood Active Transportation Trunk Line Ex...
# 14        Active and Safe Routes to a Healthier City
# 47      Siskiyou- Regional Active Transportation Plan
# 32              East Oakland Neighborhood Bike Routes
# 18     Arcata Annie & Mary Trail Connectivity Project
# 45  Muscoy Area Safe Routes to School Pedestrian I...
# 48                     Corcoran Safe Routes to School
# 6     Mariposa Elementary School Connectivity Project
# 3   Santa Cruz Rail Trail Segment 7 Phase 2 Constr...
# 11  South Sacramento County Safe Routes to School ...
# 26                          Biola Community Sidewalks
# 17              Broadway Ave Complete Street Corridor
# 43              9th St Active Transportation Corridor
# 27         Franklin Boulevard Complete Street Project
# 20         City of Maywood Active Transportation Plan
# 33  Safer Access to Pajaro Valley High School and ...
# 12  Victor Ave & Cypress Ave Active Transportation...
# 23         Highland Avenue Inter-City Bike Connection
# 24    Stewart-Pennsylvania Safety Enhancement Project
# 4             Laurel Elementary Safe Routes to School
# 9   ATP-5 SRTS Intersection Enhancement and NI Wor...
# 13              Orange Family Friendly Street Project
# 39  Sycamore Trail (Phase 2) Bicycle/Pedestrian Ov...
# 5   Kids Crossing: Safe Routes to School in South ...
# 0   Upper De La Vina Street Gap Closure and Safe C...
# 29   North Bailey Road Active Transportation Corridor
# 28                             Mariposa Creek Parkway
# 19  Riverside County Safe Routes for All - San Jac...
# 44                         Pacific Avenue Cycle Track
# 34  City of Perris Bike and Pedestrian Network Pro...
# 25  Butterfield Stage Corridor (W North Grand Ave ...
# 16             Vine Ave & B St Bike Boulevard Project
# 2          West Texas Street Complete Streets Project
# 1   South El Monte Safe Routes to School Pedestria...
# 31  Connecting Canoga Park Through Safety and Urba...
# 7   San Luis Obispo County-Bob Jones Trail Gap Clo...
# 15  SRTS Carver Middle, Ascot Avenue and Harmony E...
# 36  SRTS Berendo Middle and 3 Feeder Elementary Sc...
# 42      SRTS Panorama City Elementary School Project
# 41  City of Huron Bicyclist and Pedestrian Safety ...
# 38           Jamestown Community Connectivity Project
# 40               Downtown Long Beach Walkable Corners
# 35  El Rio Pedestrian Improvement and Safe Route t...
#
#                                   project_description  \
# 22  1.7 miles of class II bike lanes on both sides...
# 8   In Happy Camp on SR 96, install sidewalks, con...
# 46  Citywide ped, bike, & traffic calming improvem...
# 30  Buffered 2-way cycle track; shared use path; r...
# 21  Construct curb, gutter and sidewalk, and add b...
# 10  Complete Streets corridor project including pr...
# 37  In the unincorporated community of Cottonwood,...
# 14  Non-infrastructure 6 E’s project linking key c...
# 47  The goal of this project is to create a compre...
# 32  Neighborhood bike routes on four corridors in ...
# 18  PA&ED, PS&E, ROW and CON of 3.3 mile Class I t...
# 45  Installation of pedestrian safety improvements...
# 48  Construct sidewalk along various school routes...
# 6   Construct new curb, gutter, sidewalks, ADA ram...
# 3   Construction of .8 miles of Segment 7 of the R...
# 11  Construct 12 curb extensions, 26 crosswalks, 3...
# 26  Construct concrete sidewalk, curb & gutter, AD...
# 17  The Broadway Ave Complete Streets Corridor pro...
# 43  1.3 miles of bicycle and pedestrian improvemen...
# 27  A reduction in travel lanes from four to two; ...
# 20  The City of Maywood will develop an Active Tra...
# 33  Install pedestrian bridge, sidewalk, class IV ...
# 12  Along Victor Ave, Cypress Ave, and Alfreda Way...
# 23  Construct Class IV and II bicycle facilities, ...
# 24  Construction of Class IV separated bikeway, bu...
# 4   The Laurel Elementary SRTS includes infrastruc...
# 9   Construct 68 curb ramps, 87 crosswalks, advanc...
# 13  Buffered bike lanes; traffic calming and ped a...
# 39  Sycamore Trail (Phase 2), constructing 1,940 f...
# 5   Amador & Trinity and Church & Waldby intersect...
# 0   Design and construct buffered bike lanes on De...
# 29  Construct two-way cycle track, ADA-compliant c...
# 28  The Mariposa Creek Parkway provides an off-str...
# 19  Safe Routes for All Program-San Jacinto: Pre-K...
# 44  Transform Pacific Avenue into a complete stree...
# 34  Class IV bike lanes with hardscape buffer and ...
# 25  Development of an active transportation corrid...
# 16  Construction of bike boulevard, improvements i...
# 2   Construct Class IV separated bikeways with Cla...
# 1   This project focuses on school and pedestrian ...
# 31  7 miles of pedestrian and cyclist improvements...
# 7   Completion of PS&E, ROW acquisition, and const...
# 15  Transform one of the City’s most disadvantaged...
# 36  The one-quarter mile radius around Berendo Mid...
# 42  Transform one of the City’s most traffic-stres...
# 41  The project will add Class II, III and IV bike...
# 38  Project includes approximately 4,200 linear fe...
# 40  Transform Downtown Long Beach into a pedestria...
# 35  Install sidewalks, curbs, gutters, water-reten...
#
#                            notes  total_project_cost__$1,000  \
# 22                           NaN                         NaN
# 8         Infrastructure - Large                   12,221.00
# 46       Infrastructure - Medium                    6,999.00
# 30  Infrastructure + NI - Medium                    3,935.00
# 21        Infrastructure - Small                      997.00
# 10        Infrastructure - Large                   21,037.00
# 37   Infrastructure + NI - Large                   17,844.00
# 14            Non-Infrastructure                    2,510.00
# 47                          Plan                      212.00
# 32        Infrastructure - Large                   21,859.00
# 18       Infrastructure - Medium                    5,286.00
# 45  Infrastructure + NI - Medium                    2,355.00
# 48        Infrastructure - Small                    1,998.00
# 6         Infrastructure - Small                    1,900.00
# 3    Infrastructure + NI - Large                   12,030.00
# 11   Infrastructure + NI - Small                    1,946.00
# 26        Infrastructure - Small                    1,498.00
# 17   Infrastructure + NI - Large                   14,001.00
# 43       Infrastructure - Medium                    3,354.00
# 27        Infrastructure - Large                   16,265.00
# 20                          Plan                      263.00
# 33   Infrastructure + NI - Large                   15,823.00
# 12   Infrastructure + NI - Large                   10,409.00
# 23        Infrastructure - Small                    1,897.00
# 24  Infrastructure + NI - Medium                    4,000.00
# 4    Infrastructure + NI - Small                    1,535.00
# 9    Infrastructure + NI - Small                    1,178.00
# 13       Infrastructure - Medium                    5,660.00
# 39        Infrastructure - Large                   11,538.00
# 5    Infrastructure + NI - Small                    1,636.00
# 0         Infrastructure - Small                    1,998.00
# 29       Infrastructure - Medium                    6,845.00
# 28       Infrastructure - Medium                    5,176.00
# 19            Non-Infrastructure                      600.00
# 44   Infrastructure + NI - Large                    8,332.00
# 34   Infrastructure + NI - Small                    1,999.00
# 25        Infrastructure - Large                    7,750.00
# 16       Infrastructure - Medium                    4,881.00
# 2    Infrastructure + NI - Large                   16,922.00
# 1         Infrastructure - Small                    1,637.00
# 31        Infrastructure - Large                   38,655.00
# 7         Infrastructure - Large                   23,414.00
# 15       Infrastructure - Medium                    6,700.00
# 36        Infrastructure - Large                   11,057.00
# 42       Infrastructure - Medium                    6,832.00
# 41        Infrastructure - Small                    1,969.00
# 38       Infrastructure - Medium                    2,300.00
# 40   Infrastructure + NI - Large                    8,771.00
# 35       Infrastructure - Medium                    6,960.00
#
#     pa_ed_cost__$1,000  ps_e_cost__$1,000  \
# 22                 NaN                NaN
# 8               600.00             800.00
# 46              200.00                NaN
# 30                 NaN                NaN
# 21                 NaN              82.00
# 10                 NaN                NaN
# 37            1,197.00           1,796.00
# 14                 NaN                NaN
# 47                 NaN                NaN
# 32                 NaN                NaN
# 18               67.00             240.00
# 45              112.00             160.00
# 48               15.00             220.00
# 6               100.00                NaN
# 3                  NaN                NaN
# 11               95.00             190.00
# 26                 NaN                NaN
# 17                 NaN           1,576.00
# 43                 NaN             539.00
# 27                 NaN                NaN
# 20                 NaN                NaN
# 33                 NaN                NaN
# 12            1,352.00             338.00
# 23               58.00             260.00
# 24                 NaN                NaN
# 4               160.00             160.00
# 9                  NaN             140.00
# 13                 NaN                NaN
# 39                 NaN                NaN
# 5                 3.00             138.00
# 0               290.00              29.00
# 29              499.00                NaN
# 28              200.00             450.00
# 19                 NaN                NaN
# 44              225.00             675.00
# 34                 NaN                NaN
# 25                 NaN                NaN
# 16               45.00             468.00
# 2                  NaN             838.00
# 1                10.00             130.00
# 31            3,567.00           1,921.00
# 7                  NaN             321.00
# 15              801.00             290.00
# 36              188.00           1,588.00
# 42              756.00             329.00
# 41               25.00             100.00
# 38              198.00             147.00
# 40              225.00             450.00
# 35              222.00             884.00
#
#     non_infrastructure___plan_cost__$1,000 con_existing_source_s__of_funds  \
# 22                                     NaN                     ATP Cycle 5
# 8                                      NaN                     ATP Cycle 5
# 46                                     NaN                     ATP Cycle 5
# 30                                  153.00                     ATP Cycle 5
# 21                                     NaN                     ATP Cycle 5
# 10                                     NaN                     ATP Cycle 5
# 37                                   76.00                     ATP Cycle 5
# 14                                2,510.00                     ATP Cycle 5
# 47                                  202.00                     ATP Cycle 5
# 32                                     NaN                     ATP Cycle 5
# 18                                     NaN                     ATP Cycle 5
# 45                                   35.00                     ATP Cycle 5
# 48                                     NaN                     ATP Cycle 5
# 6                                      NaN                     ATP Cycle 5
# 3                                   550.00                     ATP Cycle 5
# 11                                   80.00                     ATP Cycle 5
# 26                                     NaN                     ATP Cycle 5
# 17                                1,015.00                     ATP Cycle 5
# 43                                     NaN                     ATP Cycle 5
# 27                                     NaN                     ATP Cycle 5
# 20                                  263.00                     ATP Cycle 5
# 33                                  647.00                     ATP Cycle 5
# 12                                   87.00                     ATP Cycle 5
# 23                                     NaN                     ATP Cycle 5
# 24                                   25.00                     ATP Cycle 5
# 4                                   127.00                     ATP Cycle 5
# 9                                    75.00                     ATP Cycle 5
# 13                                     NaN                     ATP Cycle 5
# 39                                     NaN                     ATP Cycle 5
# 5                                    40.00                     ATP Cycle 5
# 0                                      NaN                     ATP Cycle 5
# 29                                     NaN                     ATP Cycle 5
# 28                                     NaN                     ATP Cycle 5
# 19                                  600.00                     ATP Cycle 5
# 44                                  858.00                     ATP Cycle 5
# 34                                   35.00                     ATP Cycle 5
# 25                                     NaN                     ATP Cycle 5
# 16                                     NaN                     ATP Cycle 5
# 2                                   117.00                     ATP Cycle 5
# 1                                      NaN                     ATP Cycle 5
# 31                                     NaN                     ATP Cycle 5
# 7                                      NaN                     ATP Cycle 5
# 15                                     NaN                     ATP Cycle 5
# 36                                     NaN                     ATP Cycle 5
# 42                                     NaN                     ATP Cycle 5
# 41                                     NaN                     ATP Cycle 5
# 38                                     NaN                     ATP Cycle 5
# 40                                  543.00                     ATP Cycle 5
# 35                                     NaN                     ATP Cycle 5
#
#              primary_mode                    previous_caltrans_nominations  \
# 22  Active Transportation                         No Previous ATP Projects
# 8   Active Transportation                         No Previous ATP Projects
# 46  Active Transportation  Active Transportation Program Previous Projects
# 30  Active Transportation  Active Transportation Program Previous Projects
# 21  Active Transportation  Active Transportation Program Previous Projects
# 10  Active Transportation  Active Transportation Program Previous Projects
# 37  Active Transportation                         No Previous ATP Projects
# 14  Active Transportation  Active Transportation Program Previous Projects
# 47  Active Transportation                         No Previous ATP Projects
# 32  Active Transportation                         No Previous ATP Projects
# 18  Active Transportation  Active Transportation Program Previous Projects
# 45  Active Transportation                         No Previous ATP Projects
# 48  Active Transportation                         No Previous ATP Projects
# 6   Active Transportation  Active Transportation Program Previous Projects
# 3   Active Transportation  Active Transportation Program Previous Projects
# 11  Active Transportation  Active Transportation Program Previous Projects
# 26  Active Transportation  Active Transportation Program Previous Projects
# 17  Active Transportation  Active Transportation Program Previous Projects
# 43  Active Transportation  Active Transportation Program Previous Projects
# 27  Active Transportation  Active Transportation Program Previous Projects
# 20  Active Transportation                         No Previous ATP Projects
# 33  Active Transportation  Active Transportation Program Previous Projects
# 12  Active Transportation  Active Transportation Program Previous Projects
# 23  Active Transportation  Active Transportation Program Previous Projects
# 24  Active Transportation                         No Previous ATP Projects
# 4   Active Transportation                         No Previous ATP Projects
# 9   Active Transportation  Active Transportation Program Previous Projects
# 13  Active Transportation                         No Previous ATP Projects
# 39  Active Transportation  Active Transportation Program Previous Projects
# 5   Active Transportation  Active Transportation Program Previous Projects
# 0   Active Transportation                         No Previous ATP Projects
# 29  Active Transportation  Active Transportation Program Previous Projects
# 28  Active Transportation                         No Previous ATP Projects
# 19  Active Transportation  Active Transportation Program Previous Projects
# 44  Active Transportation                         No Previous ATP Projects
# 34  Active Transportation                         No Previous ATP Projects
# 25  Active Transportation                         No Previous ATP Projects
# 16  Active Transportation  Active Transportation Program Previous Projects
# 2   Active Transportation                         No Previous ATP Projects
# 1   Active Transportation                         No Previous ATP Projects
# 31  Active Transportation  Active Transportation Program Previous Projects
# 7   Active Transportation                         No Previous ATP Projects
# 15  Active Transportation  Active Transportation Program Previous Projects
# 36  Active Transportation  Active Transportation Program Previous Projects
# 42  Active Transportation  Active Transportation Program Previous Projects
# 41  Active Transportation                         No Previous ATP Projects
# 38  Active Transportation  Active Transportation Program Previous Projects
# 40  Active Transportation                         No Previous ATP Projects
# 35  Active Transportation  Active Transportation Program Previous Projects
#
#    urban_rural
# 22       Urban
# 8        Rural
# 46       Urban
# 30     Unknown
# 21     Unknown
# 10       Urban
# 37       Rural
# 14       Urban
# 47     Unknown
# 32       Urban
# 18     Unknown
# 45       Urban
# 48     Unknown
# 6        Rural
# 3      Unknown
# 11       Urban
# 26       Urban
# 17     Unknown
# 43       Urban
# 27       Urban
# 20       Urban
# 33     Unknown
# 12     Unknown
# 23       Urban
# 24       Urban
# 4        Urban
# 9        Urban
# 13       Urban
# 39       Urban
# 5        Urban
# 0      Unknown
# 29       Urban
# 28     Unknown
# 19       Urban
# 44       Urban
# 34       Urban
# 25       Urban
# 16       Urban
# 2        Urban
# 1        Urban
# 31       Urban
# 7      Unknown
# 15       Urban
# 36       Urban
# 42       Urban
# 41       Urban
# 38     Unknown
# 40       Urban
# 35       Urban

# %%
# Official Caltrans District names
district_dictionary = {
    '7': "07 - Los Angeles",
    '4': "04 - Oakland",
    '2': "02 - Redding",
    '9': "09 - Bishop",
    '10': "10 - Stockton",
    '11': "11 - San Diego",
    '3': "03 - Marysville",
    '12': "12 - Irvine",
    '8': "08 - San Bernardino",
    '5': "05 - San Luis Obispo",
    '6': "06 - Fresno",
    '1': "01 - Eureka",
    '75': "75 - HQ",
    '74': "74 - HQ",
    '0': "None",
}

# %%
atp_funded_subset_funds['district_full_name'] = atp_funded_subset_funds.district.map(district_dictionary)

# %%
atp_funded_subset_funds.sample()
# Out:
#     ppno ppno1 full_county_name district        lead_agency  \
# 11  2214   NaN       Sacramento        3  Sacramento County
#
#                                          project_name  \
# 11  South Sacramento County Safe Routes to School ...
#
#                                   project_description  \
# 11  Construct 12 curb extensions, 26 crosswalks, 3...
#
#                           notes  total_project_cost__$1,000  \
# 11  Infrastructure + NI - Small                    1,946.00
#
#     pa_ed_cost__$1,000  ps_e_cost__$1,000  \
# 11               95.00             190.00
#
#     non_infrastructure___plan_cost__$1,000 con_existing_source_s__of_funds  \
# 11                                   80.00                     ATP Cycle 5
#
#              primary_mode                    previous_caltrans_nominations  \
# 11  Active Transportation  Active Transportation Program Previous Projects
#
#    urban_rural district_full_name
# 11       Urban    03 - Marysville

# %% [markdown]
# ## Concat and Export

# %%
shopp_atp = pd.concat([shopp, atp_funded_subset_funds])

# %%
# ! pip install wordcloud
# ! pip install nltk

# %%
import _utils

# %%
shopp_atp = _utils.clean_up_columns(shopp_atp)

# %%
shopp_atp.sample()
# Out:
#     Rail Project Id  10 Year Plan Ct Project Id  Update Complete     Ea  Ppno  \
# 265            None          0.00    0622000078             0.00  1E760  None
#
#                                           Project Name District County Route  \
# 265  Tulare Avenue And Divisadero Enhancement (Not ...        6    FRE   NaN
#
#                                    Project Description Current Phase  \
# 265  In Fresno, at Tulare Ave and Divisidero St, in...         PA&ED
#
#     Con Existing Source S  Of Funds Con Anticipated Source Of Funds  \
# 265                            None                            None
#
#     Target Opening Year  Beg Pm  End Pm Primary Mode  \
# 265                2023  R23.76  R23.76      Highway
#
#     Previous Caltrans Nominations Urban Rural         Notes     Lead Agency  \
# 265                          None        None  Not in CTIPS  City Of Fresno
#
#     Pid Approval Date  M010   Target Pa Ed  M200       Rtl Date  M460  \
# 265          datetime64[ns]  2022-09-30 00:00:00  2022-12-30 00:00:00
#
#     Con Start Date  M500  Funding Need Phase S  Pa Ed Cost  $1,000  \
# 265  2024-06-30 00:00:00                  0.00                0.00
#
#      Ps E Cost  $1,000  Row Cost  $1,000  Con Support Cost  $1,000  \
# 265               0.00              0.00                      0.00
#
#      Non Infrastructure   Plan Cost  $1,000  Total Unfunded Need  $1,000  \
# 265                                    0.00                         0.00
#
#     Previous Funding Request Phase  Last Scored    Csis Alignment  \
# 265                           None         0.00  Not Well-Aligned
#
#      Csis Total Score  Out Of 45  Mode Shift  Csis  Score  \
# 265                         0.00                     0.00
#
#     Mode Shift  Csis  Comment  Vmt  Csis  Score Vmt  Csis  Comment  \
# 265                      None              0.00               None
#
#      Public Engagement  Csis  Score Public Engagement  Csis  Comment  \
# 265                            0.00                             None
#
#      Dac Local Community Needs  Csis  Score  \
# 265                                    0.00
#
#      Dac Local Community Needs  Csis  Comment  Safety  Csis  Score  \
# 265                                      0.00                 0.00
#
#     Safety  Csis  Comment  Zev  Csis  Score Zev  Csis  Comment  \
# 265                  None              0.00               None
#
#      Climate Resiliency  Csis  Score Climate Resiliency  Csis  Comment  \
# 265                             0.00                              None
#
#      Natural Resources And Ecosystems  Csis  Score  \
# 265                                           0.00
#
#     Natural Resources And Ecosystems  Csis  Comment  \
# 265                                            None
#
#      Infill Development And Land Use  Csis  Score  \
# 265                                          0.00
#
#     Infill Development And Land Use  Csis  Comment  \
# 265                                           None
#
#      Benefits To Dac And Advancing Equity  Atp  Score  \
# 265                                              0.00
#
#      Community Need  Atp  Score  Safety  Atp  Score  \
# 265                        0.00                0.00
#
#      Public Participation  Atp  Score  Community Feedback  Atp  Score  \
# 265                              0.00                            0.00
#
#      Continued Engagement  Atp  Score  \
# 265                              0.00
#
#      Context Sensitive And Innovation  Atp  Score  Transformative  Atp  Score  \
# 265                                          0.00                        0.00
#
#      Atp Total Score  Out Of 100     Atp Alignment Access Alignment  \
# 265                         0.00  Not Well-Aligned             None
#
#     Previous Funding Request            Modified                 Modified By  \
# 265                     None 2022-12-29 09:48:50  madison.buccola@dot.ca.gov
#
#      Purpose   Need Parcel Counts  Total Project Cost  $1,000  \
# 265            0.00             0                    2,765.00
#
#      Con Capital Cost  $1,000  Hq Priority  District Priority  \
# 265                      0.00         0.00               0.00
#
#     Potential Funding Program S Located In Dac Shs Capacity Increase Detail  \
# 265                        None           None                         None
#
#     Secondary Mode S Full County Name  \
# 265             None           Fresno
#
#                                 Detailed Project Title District Full Name  \
# 265  District 6-Tulare Avenue And Divisadero Enhanc...        06 - Fresno
#
#      Increase Peak Person Throughput  Reduction In Peak Period Delay  \
# 265                            25.81                           42.80
#
#      Reduction In Fatal And Injury Crashes  Reduction In Injury Rates  \
# 265                                  44.65                      32.04
#
#      Increase Access To Jobs  Increase Access Jobs To Dac  \
# 265                     3.40                         3.85
#
#      Commercial Dev Developed  Tons Of Goods Impacted  Improve Air Quality  \
# 265                      5.09                   48.04                28.25
#
#      Impact Natural Resources  Support Of Transportation  Fake Benefit Score  \
# 265                     31.44                      49.10                2.00
#
#      Statewide Rank  District Rank Fake Benefit Score Statewide Percentile  \
# 265          158.00          16.00                         25th percentile
#
#      District District Median  Total Project Cost  $1,000  District Median  \
# 265                      6.00                                     2,500.00
#
#      Fake Benefit Score District Median  \
# 265                                1.71
#
#      Total Unfunded Need  $1,000  District Median  \
# 265                                          0.00
#
#      Csis Total Score  Out Of 45  District Median  \
# 265                                          0.00
#
#      Atp Total Score  Out Of 100  District Median Ppno1
# 265                                          0.00   NaN

# %%
# shopp_atp.to_excel('gs://calitp-analytics-data/data-analyses/project_prioritization/cleaned_data_with_fake_metrics_plus_atp.xlsx')

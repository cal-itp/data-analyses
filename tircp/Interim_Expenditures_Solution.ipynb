# %% [markdown]
# # Expenses in Highlands Sheet are incorrect
# * Using expenses from Data link to fill in expenditures for March 25 presentation

# %%
import numpy as np
import pandas as pd
import TIRCP_functions
from siuba import *
from calitp import *

GCS_FILE_PATH = "gs://calitp-analytics-data/data-analyses/tircp/"

pd.options.display.max_columns = 50
pd.options.display.max_rows = 120
pd.set_option('display.max_colwidth', None)
# Out:
# /opt/conda/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
# E0316 20:20:50.324598556    1219 fork_posix.cc:70]           Fork support is only compatible with the epoll1 and poll polling strategies
# E0316 20:20:50.840796541    1219 fork_posix.cc:70]           Fork support is only compatible with the epoll1 and poll polling strategies

# %% [markdown]
# ## Expenditure information from the Enterprise Data Link data Linda pulled.

# %%
enterprise = "Enterprise.xlsx"
enterprise_df = pd.read_excel(f"{GCS_FILE_PATH}{enterprise}")
enterprise_df = to_snakecase(enterprise_df)

# %%
enterprise_df.head(2)
# Out:
#      fy cycle  fund  appr_catg appr_unit      pec   project  \
# 0  2016   One  3228       1415     15101  3010070  16000007
# 1  2016   One  3228       1415     15101  3010070  16000008
#
#                                  project_name project_short_name phase  \
# 0  Refurbishment of Seven Light Rail Vehicles          64-R340GA     S
# 1   South Bay Bus Rapid Transit (BRT) Project          64-T339GA     S
#
#    old_ea  capital_exp   local_exp  support_exp  other_exp     tot_exp
# 0  R340GA            0  2182302.44            0          0  2182302.44
# 1  T339GA            0    30770.46            0          0    30770.46

# %%
enterprise_df = enterprise_df.rename(columns = {'project':'project_id'})

# %%
#keep only columns necessary.
enterprise_df = enterprise_df[['fy','cycle','project_id','project_name','tot_exp']]

# %%
#Looking at IDS by cycles.
enterprise_df.cycle.value_counts()
# Out:
# Three    152
# One       47
# Two       47
# Four       8
# Name: cycle, dtype: int64

# %%
enterprise_df.shape
# Out:
# (254, 5)

# %% [markdown]
# #### Aggregate by project ID and each cycle, so each project has only one record for total expenses

# %%
enterprise_df_project_id = enterprise_df.groupby(['project_id','cycle']).agg({'tot_exp':'sum'}).reset_index()

# %%
enterprise_df_project_id.shape
# Out:
# (106, 3)

# %%
enterprise_df_project_id.head(2)
# Out:
#    project_id cycle     tot_exp
# 0    16000007   One  6315208.89
# 1    16000008   One  4000000.00

# %% [markdown]
# ## Merge in with allocation sheet of Excel workbook
# * There are 191 unique project IDS in our allocation sheet compared to 106 project IDS in Data Link.

# %%
#read in allocation df because that's the sheet with project ids. 
allocation = TIRCP_functions.allocation()

# %%
#keep only columns that are relevant.
allocation_df = allocation[['Award_Year','Project_ID','PPNO']]

# %%
#checking NA values
allocation_df.isna().sum()
# Out:
# Award_Year    2
# Project_ID    7
# PPNO          2
# dtype: int64

# %%
f'There are {allocation_df.Project_ID.nunique()} unique project ids in allocation'
# Out:
# 'There are 191 unique project ids in allocation'

# %%
#only keep rows that have Project IDS filled in
allocation_df = allocation_df.loc[allocation_df['Project_ID'].notnull()]

# %%
allocation_df.shape
# Out:
# (208, 3)

# %%
joined_alloc = pd.merge(allocation_df, enterprise_df_project_id, 
                        left_on='Project_ID', right_on='project_id', 
                        how = 'outer', indicator = True)

# %%
joined_alloc._merge.value_counts()
# Out:
# both          119
# left_only      89
# right_only      1
# Name: _merge, dtype: int64

# %%
#only keep "both" results...
joined_alloc2 = joined_alloc.loc[joined_alloc['_merge'] == 'both'].drop(columns =['_merge'])

# %%
#group by so that only one row for each PPNO number & Year
joined_alloc3 = (joined_alloc2
                  .groupby(['PPNO', 'Award_Year'])
                  .agg({'tot_exp':'sum'})
                  .reset_index()
                 )

# %%
joined_alloc3.shape
# Out:
# (51, 3)

# %%
#rename cols before joining with "joined" df 
joined_alloc3 = joined_alloc3.add_prefix('from_joined_alloc_df_')

# %%
joined_alloc3
# Out:
#    from_joined_alloc_df_PPNO  from_joined_alloc_df_Award_Year  \
# 0                       1155                           2018.0
# 1                       1230                           2016.0
# 2                      2320B                           2018.0
# 3                      CP001                           2015.0
# 4                      CP002                           2015.0
# 5                      CP003                           2015.0
# 6                      CP004                           2015.0
# 7                      CP005                           2015.0
# 8                      CP006                           2015.0
# 9                      CP006                           2016.0
# 10                     CP006                           2018.0
# 11                     CP007                           2015.0
# 12                     CP008                           2015.0
# 13                     CP010                           2015.0
# 14                     CP011                           2015.0
# 15                     CP012                           2015.0
# 16                     CP013                           2015.0
# 17                     CP014                           2015.0
# 18                     CP015                           2015.0
# 19                     CP016                           2016.0
# 20                     CP017                           2016.0
# 21                     CP018                           2016.0
# 22                     CP019                           2016.0
# 23                     CP020                           2016.0
# 24                     CP021                           2016.0
# 25                     CP022                           2016.0
# 26                     CP023                           2016.0
# 27                     CP024                           2016.0
# 28                     CP025                           2016.0
# 29                     CP027                           2018.0
# 30                     CP028                           2018.0
# 31                     CP031                           2018.0
# 32                     CP032                           2018.0
# 33                     CP033                           2018.0
# 34                     CP034                           2018.0
# 35                     CP035                           2018.0
# 36                     CP036                           2018.0
# 37                     CP039                           2018.0
# 38                     CP041                           2018.0
# 39                     CP043                           2016.0
# 40                     CP046                           2018.0
# 41                     CP047                           2018.0
# 42                     CP048                           2018.0
# 43                     CP051                           2018.0
# 44                     CP053                           2018.0
# 45                     CP055                           2018.0
# 46                     CP061                           2020.0
# 47                     CP062                           2020.0
# 48                     CP069                           2020.0
# 49                     CP072                           2020.0
# 50                     CP079                           2018.0
#
#     from_joined_alloc_df_tot_exp
# 0                      486509.70
# 1                     9204000.00
# 2                      500000.00
# 3                     6315208.89
# 4                    38023039.68
# 5                     4000000.00
# 6                     2320000.00
# 7                    22284205.53
# 8                    41181000.00
# 9                    45092000.00
# 10                   26867000.00
# 11                     277840.47
# 12                   31936000.00
# 13                   11000000.00
# 14                    6841000.00
# 15                    4619999.90
# 16                   10000000.00
# 17                     200000.00
# 18                   38494000.00
# 19                    4083000.00
# 20                   17533049.35
# 21                    6481000.00
# 22                    2449000.00
# 23                   42555163.12
# 24                   72771000.00
# 25                   16100400.95
# 26                     435332.37
# 27                    4017000.00
# 28                     428492.45
# 29                   15829361.11
# 30                    6727853.61
# 31                   21165535.14
# 32                    1770549.59
# 33                   30688351.23
# 34                   23937070.02
# 35                   18344305.43
# 36                   30950402.20
# 37                   62705265.47
# 38                   19278743.87
# 39                     842756.08
# 40                    7244002.74
# 41                    1571222.84
# 42                    4144463.76
# 43                     382718.05
# 44                   31327612.58
# 45                   25010228.12
# 46                        981.93
# 47                   13321538.34
# 48                     644919.97
# 49                     589950.41
# 50                      63708.00

# %%
joined_alloc3.astype({'from_joined_alloc_df_Award_Year': 'int64'}).dtypes
# Out:
# from_joined_alloc_df_PPNO           object
# from_joined_alloc_df_Award_Year      int64
# from_joined_alloc_df_tot_exp       float64
# dtype: object

# %% [markdown]
# ## Joining project sheet on Award Year & PPNO

# %%
project = TIRCP_functions.project()

# %%
final_join = pd.merge(project, joined_alloc3, 
                      left_on = ['PPNO', 'Award_Year'], 
                      right_on = ['from_joined_alloc_df_PPNO', 'from_joined_alloc_df_Award_Year'],
                      how = 'left', indicator = True)

# %%
final_join._merge.value_counts()
# Out:
# both          50
# left_only     25
# right_only     0
# Name: _merge, dtype: int64

# %% [markdown]
# #### Check to see if PPNO matches  cross original project sheet & joined

# %%
final_join.shape
# Out:
# (75, 36)

# %%
final_join.PPNO.nunique()
# Out:
# 69

# %%
project.PPNO.nunique()
# Out:
# 69

# %%
PPNO_project = set(project.PPNO.unique().tolist())
PPNO_join = set(final_join.PPNO.unique().tolist())
PPNO_join - PPNO_project
# Out:
# set()

# %%
pd.options.display.float_format = '{:,}'.format
pd.options.display.float_format = "{:.2f}".format

# %% [markdown]
# ### Final Clean Up - per Linda, TIRCP isn't correct

# %%
#fill in with 0
final_join['from_joined_alloc_df_tot_exp'] = final_join['from_joined_alloc_df_tot_exp'].fillna(0)

# %%
final_join = final_join.drop_duplicates(subset=['PPNO','Award_Year', 'Project_Title'])

# %%
final_join.loc[(final_join['PPNO'] == 'CP028'), "TIRCP_project_sheet"] =  13156000 
final_join.loc[(final_join['PPNO'] == 'CP019'), "TIRCP_project_sheet"] =  8930000

# %% [markdown]
# #### Dropping a project that may or may not be considered TIRCP.

# %%
index = final_join[(final_join.PPNO == 'CP026') &( final_join.Award_Year == 2016)].index

# %%
final_join = final_join.drop(index)

# %%
final_join = final_join.reset_index()

# %% [markdown]
# ### Checking out our 2 columns of expended amounts to make sure Data Link information makes sense.
# * Expended_Amt_Project_sheet is from Highlands sheet.
# * from_joined_alloc_df_tot_exp from Data Link

# %%
final_join[['Award_Year','PPNO','Project_Title', 'TIRCP_project_sheet', 
            'Expended_Amt_project_sheet', 'from_joined_alloc_df_tot_exp', '_merge']]
# Out:
#     Award_Year   PPNO  \
# 0         2015  CP005
# 1         2015  CP012
# 2         2015  CP015
# 3         2015  CP007
# 4         2015  CP013
# 5         2015  CP004
# 6         2015  CP001
# 7         2015  CP003
# 8         2015  CP008
# 9         2015  CP006
# 10        2015  CP014
# 11        2015  CP011
# 12        2015  CP002
# 13        2015  CP010
# 14        2016  CP019
# 15        2016  CP023
# 16        2016  CP076
# 17        2016  CP016
# 18        2016  CP058
# 19        2016  CP020
# 20        2016  CP043
# 21        2016  CP017
# 22        2016  CP022
# 23        2016  CP080
# 24        2016   1230
# 25        2016  CP006
# 26        2016  CP025
# 27        2016  CP057
# 28        2018  2320B
# 29        2018  CP027
# 30        2018  CP028
# 31        2018  CP055
# 32        2018  CP036
# 33        2018  CP079
# 34        2018  CP029
# 35        2018  CP054
# 36        2018  CP051
# 37        2018  CP030
# 38        2018  CP031
# 39        2018  CP031
# 40        2018  CP039
# 41        2018  CP053
# 42        2018  CP034
# 43        2018  CP077
# 44        2018  CP034
# 45        2018  CP006
# 46        2018  CP035
# 47        2018  CP078
# 48        2018  CP048
# 49        2018  CP047
# 50        2018  CP057
# 51        2018  CP045
# 52        2018  CP046
# 53        2018  CP041
# 54        2018  CP033
# 55        2018   1155
# 56        2020  CP059
# 57        2020  CP060
# 58        2020  CP061
# 59        2020  CP062
# 60        2020  CP063
# 61        2020  CP064
# 62        2020  CP065
# 63        2020  CP066
# 64        2020  CP067
# 65        2020  CP068
# 66        2020  CP069
# 67        2020  CP070
# 68        2020  CP071
# 69        2020  CP072
# 70        2020  CP073
# 71        2020  CP074
# 72        2020  CP075
#
#                                                                                                            Project_Title  \
# 0                                                         Regional Transit Interconnectivity & Environmental Sustability
# 1                                                                                          Travel Time Reduction Project
# 2                                 Willowbrook/Rosa Parks Station & Blue Line Light Rail Operational Improvements Project
# 3                                                                             Pacific Surfliner Transit Transfer Program
# 4                                       Monterey Bay Operations and Maintenance Facility/Salinas Transit Service Project
# 5                                                                                           Bravo! Route 560 Rapid Buses
# 6                                                   Sacramento Regional Transit's Refurbishment of 7 Light Rail Vehicles
# 7                                                                                            South Bay Bus Rapid Transit
# 8                                                    San Diego Metropolitan Transit System Trolley Capacity Improvements
# 9                                                                               SFMTA Light Rail Vehicle Fleet Expansion
# 10                                                                                             ACE Wayside Power Project
# 11                                          Bus Rapid Transit – Martin Luther King Corridor and Crosstown Miner Corridor
# 12                                                         Purchase of Nine Fuel-Efficient Tier IV EMD F-125 Locomotives
# 13                                                                                       SMART Rail Car Capacity Project
# 14                  Zero Emission Bus and Vanpool Expansion in the Antelope Valley, Kern County and the Coachella Valley
# 15                               Increased Rail Service to Roseville, Service Optimization and Standby Power Investments
# 16                                  Transforming California: Bus Electrification, Service Expansion and Rail Integration
# 17                                                              Metropolitan Rapid Transit and Rail Connectivity Project
# 18                                         Airport Metro Connector 96th Street Station/Metro Green Line Extension to LAX
# 19                                                             Metro Red Line and Purple Line Core Capacity Improvements
# 20                                                              All Aboard: Transforming Southern California Rail Travel
# 21                                                                    OC Streetcar and OCTA System-Wide Mobile Ticketing
# 22                                                                            Peninsula Corridor Electrification Project
# 23                                                              Downtown/Riverfront Sacramento-West Sacramento Streetcar
# 24                                                                                       Redlands Passenger Rail Project
# 25                                                                        Light Rail Modernization and Expansion Program
# 26                                                                          ACE Near-Term Capacity Improvement Program\n
# 27                                                                                BART Silicon Valley Phase II Extension
# 28                      Purchase Zero Emission High Capacity Buses to Support Transbay Tomorrow and Clean Corridors Plan
# 29                                              #Electrify Anaheim: Changing the Transit Paradigm in Southern California
# 30     From the Desert to the Sea: Antelope Valley Transit Authority and Long Beach Transit Zero Emission Bus Initiative
# 31         The Transbay Corridor Core Capacity Program: Vehicle Acquistion and Communications-Based Train Control System
# 32                                                                  The Northern California Corridor Enhancement Program
# 33                                                                                  Southwest Fresno Community Connector
# 34                            Los Angeles City: Leading the Transformation to Zero-Emission Electric Bus Transit Service
# 35                                                 Electric Blue: Electrification of City of Santa Monica's Big Blue Bus
# 36                                               Dublin/Pleasanton Capacity Improvement and Congestion Reduction Program
# 37                                   Los Angeles Region Transit System Integration and Modernization Program of Projects
# 38                                                                       All Aboard 2018: Transforming SoCal Rail Travel
# 39                                                                         Building Up: LOSSAN North Improvement Program
# 40                                                                  Peninsula Corridor Electrification Expansion Project
# 41                                                   Accelerating Rail Modernization and Expansion in the Capital Region
# 42  Diesel Multiple Unit Vehicle to Zero- or Low-Emission Vehicle Conversion and West Valley Connector Bus Rapid Transit
# 43                                                       Ride Between the Line: Enhancing Access to Transit in San Diego
# 44                                                                          Blue Line Rail Corridor Transit Enhancements
# 45                                                                                    Transit Capacity Expansion Program
# 46                                                                                                           Valley Rail
# 47                                                                                            SamTrans Express Bus Pilot
# 48                                 Coastal Express/Pacific Surfliner Peak Hour Service Expansion and Integration Project
# 49                                                                                                    Goleta Train Depot
# 50                                                                         VTA’s BART Silicon Valley Extension, Phase II
# 51                                                                                      North State Intercity Bus System
# 52                                                                                  Solano Regional Transit Improvements
# 53                                                                                    SMART Larkspur to Windsor Corridor
# 54                                                                  Southern California Optimized Rail Expansion (SCORE)
# 55                                                                                Extend rail service to Monterey County
# 56                    Reaching the Most Transit-Vulnerable: AVTA's Zero Emission "Microtransit" & Bus Expansion Proposal
# 57                                                     The Transbaby Corridor Core Capacity Program: Vehicle Acquisition
# 58                                                                        Sacramento Valley Station (SVS) Transit Center
# 59                                                                                   Inglewood Transit Connector Project
# 60                                                                                      North State Intercity Bus System
# 61                                                                                    LBT/UCLA Electric Commuter Express
# 62                                                       Metrolink Antelope Valley Line Capital and Service Improvements
# 63                                                               Building Up Control: LOSSAN Service Enhancement Program
# 64                                                             Light Rail Modernization and Expansion of Low-Floor Fleet
# 65                                                      West Valley Connector Bus Rapid Transit Phase 1 & ZEB Initiative
# 66                                                                         SDConnect: San Diego Rail Improvement Program
# 67                                                                                                 Core Capacity Program
# 68                                          For People, Place and Planet: Connecting Inglewood to Regional Opportunities
# 69                                                                          Solano Regional Transit Improvements Phase 2
# 70                                                                      Torrance Transit Bus Service Enhancement Program
# 71                 Improving Air Quality & Economic Growth with Electric Buses in Merced County, the Gateway to Yosemite
# 72                                                                                      Expansion of WETA Ferry Services
#
#     TIRCP_project_sheet  Expended_Amt_project_sheet  \
# 0              24403000                 21714177.53
# 1               4620000                  4619999.90
# 2              38494000                 38494000.00
# 3               1675000                 38494000.00
# 4              10000000                        0.00
# 5               2320000                        0.00
# 6               6427000                        0.00
# 7               4000000                  4000000.00
# 8              31936000                 31936000.00
# 9              41181000                  3760000.00
# 10               200000                   200000.00
# 11              6841000                  1650000.00
# 12             41181000                 37583067.00
# 13             11000000                  1650000.00
# 14              8930000                  7874722.49
# 15              8999000                   269239.63
# 16              5000000                        0.00
# 17              8000000                  2856157.00
# 18             40000000                        0.00
# 19             69209000                  4220881.34
# 20             82000000                 66831938.80
# 21             28000000                 12705054.75
# 22             20000000                 16100400.95
# 23             30000000                        0.00
# 24              9204000                  9204000.00
# 25             45092000                        0.00
# 26             16459000                  7922840.39
# 27             20000000                        0.00
# 28             14000000                   500000.00
# 29             28617000                 15854026.86
# 30             13156000                  2641815.25
# 31            318600000                        0.00
# 32             80340000                 14726523.22
# 33              7798000                        0.00
# 34             36104000                        0.00
# 35              3050000                        0.00
# 36             20500000                   157092.40
# 37           1088499000                        0.00
# 38             40412000                  6382623.93
# 39            147930000                        0.00
# 40            164522000                 60769565.86
# 41             64350000                        0.00
# 42             30000000                 22194297.01
# 43              5763000                        0.00
# 44             40098000                  1398549.59
# 45             26867000                        0.00
# 46            500500000                 18051514.17
# 47             15000000                        0.00
# 48              9600000                  9600000.00
# 49             13009000                  1552456.00
# 50            730000000                        0.00
# 51              8641000                        0.00
# 52             10788000                  3090500.00
# 53             21000000                 11918142.74
# 54            875708000                 23748152.73
# 55             10148000                        0.00
# 56              6503000                        0.00
# 57            107100000                        0.00
# 58              3914000                        0.00
# 59             95200000                  1823462.51
# 60             12994000                        0.00
# 61              6451000                        0.00
# 62            107050000                        0.00
# 63             38743000                        0.00
# 64             23600000                        0.00
# 65             15000000                        0.00
# 66             12100000                        0.00
# 67             41668000                        0.00
# 68              1105000                        0.00
# 69             10400000                        0.00
# 70              6000000                        0.00
# 71              3112000                        0.00
# 72              9060000                        0.00
#
#     from_joined_alloc_df_tot_exp     _merge
# 0                    22284205.53       both
# 1                     4619999.90       both
# 2                    38494000.00       both
# 3                      277840.47       both
# 4                    10000000.00       both
# 5                     2320000.00       both
# 6                     6315208.89       both
# 7                     4000000.00       both
# 8                    31936000.00       both
# 9                    41181000.00       both
# 10                     200000.00       both
# 11                    6841000.00       both
# 12                   38023039.68       both
# 13                   11000000.00       both
# 14                    2449000.00       both
# 15                     435332.37       both
# 16                          0.00  left_only
# 17                    4083000.00       both
# 18                          0.00  left_only
# 19                   42555163.12       both
# 20                     842756.08       both
# 21                   17533049.35       both
# 22                   16100400.95       both
# 23                          0.00  left_only
# 24                    9204000.00       both
# 25                   45092000.00       both
# 26                     428492.45       both
# 27                          0.00  left_only
# 28                     500000.00       both
# 29                   15829361.11       both
# 30                    6727853.61       both
# 31                   25010228.12       both
# 32                   30950402.20       both
# 33                      63708.00       both
# 34                          0.00  left_only
# 35                          0.00  left_only
# 36                     382718.05       both
# 37                          0.00  left_only
# 38                   21165535.14       both
# 39                   21165535.14       both
# 40                   62705265.47       both
# 41                   31327612.58       both
# 42                   23937070.02       both
# 43                          0.00  left_only
# 44                   23937070.02       both
# 45                   26867000.00       both
# 46                   18344305.43       both
# 47                          0.00  left_only
# 48                    4144463.76       both
# 49                    1571222.84       both
# 50                          0.00  left_only
# 51                          0.00  left_only
# 52                    7244002.74       both
# 53                   19278743.87       both
# 54                   30688351.23       both
# 55                     486509.70       both
# 56                          0.00  left_only
# 57                          0.00  left_only
# 58                        981.93       both
# 59                   13321538.34       both
# 60                          0.00  left_only
# 61                          0.00  left_only
# 62                          0.00  left_only
# 63                          0.00  left_only
# 64                          0.00  left_only
# 65                          0.00  left_only
# 66                     644919.97       both
# 67                          0.00  left_only
# 68                          0.00  left_only
# 69                     589950.41       both
# 70                          0.00  left_only
# 71                          0.00  left_only
# 72                          0.00  left_only

# %% [markdown]
# ## Tableau

# %%
def tableau2(df):
    #Keeping only the columns we want
    df = (df[['PPNO','Award_Year', 'Project_#', 'Grant_Recipient', 
       'Project_Title', 'District', 'County', 'Project_Description',
       'Master_Agreement_Number', 'Master_Agreement_Expiration_Date',
       'Project_Manager', 'Regional_Coordinator', 'Technical_Assistance-Fleet_(Y/N)',
       'Technical_Assistance-Network_Integration_(Y/N)',
       'Technical_Assistance-Priority_Population_(Y/N)', 'Total_Project_Cost',
       'TIRCP_project_sheet', 'Allocated_Amount',
       'Percentage_Allocated',
       'from_joined_alloc_df_tot_exp', 'Other_Funds_Involved']]
                 )
    #Getting percentages & filling in with 0
    df['Expended_Percent'] = df['from_joined_alloc_df_tot_exp']/df['Allocated_Amount']
    df['Allocated_Percent'] = df['Allocated_Amount']/df['TIRCP_project_sheet']
    
    # Subtract TIRCP with Allocated Amount with Unallocated
    df['Unallocated_Amount'] = df["TIRCP_project_sheet"] - df["Allocated_Amount"]
    #filling in for 0's 
    df[['Expended_Percent','Allocated_Percent']] = df[['Expended_Percent','Allocated_Percent']].fillna(value=0)
   
    df[['Expended_Percent','Allocated_Percent']]  =  df[['Expended_Percent','Allocated_Percent']].replace(np.inf, 0)
    #Categorizing expended percentage into bins
    def expended_percent(row):
           
            if ((row.Expended_Percent > 0) and (row.Expended_Percent < .26)):
                return "1-25"
            elif ((row.Expended_Percent > .25) and (row.Expended_Percent < .51)):
                return "26-50"
            elif ((row.Expended_Percent > .50) and (row.Expended_Percent < .76)):
                return "51-75"
            elif ((row.Expended_Percent > .75) and (row.Expended_Percent < 1.0)):
                return "76-99"
            elif row.Expended_Percent == 0.0:
                return "0"
            else:
                return "100"
    df["Expended_Percent_Group"] = df.apply(lambda x: expended_percent(x), axis=1)
    
    # Categorize years and expended_percent_group into bins
    def progress(df):   
        ### 2015 ### 
        if (df['Award_Year'] == 2015) and (df['Expended_Percent_Group'] == "1-25") | (df['Expended_Percent_Group'] == "26-50"):
            return 'Behind'
        elif (df['Award_Year'] == 2015) and (df['Expended_Percent_Group'] == "76-99") | (df['Expended_Percent_Group'] == "51-75"):
            return 'On Track'
        
        ### 2016 ###
        elif (df['Award_Year'] == 2016) and (df['Expended_Percent_Group'] == "1-25") | (df['Expended_Percent_Group'] == "26-50"):
            return 'Behind'
        elif (df['Award_Year'] == 2016) and (df['Expended_Percent_Group'] == "51-75") | (df['Expended_Percent_Group'] == "76-99"):
            return 'On Track'
        
        ### 2018 ###
        elif (df['Award_Year'] == 2018) and (df['Expended_Percent_Group'] == "1-25"):
            return 'Behind'
        elif (df['Award_Year'] == 2018) and (df['Expended_Percent_Group'] == "26-50") | (df['Expended_Percent_Group'] == "51-75"):
            return 'On Track'
        elif (df['Award_Year'] == 2018) and (df['Expended_Percent_Group'] == "76-99"):
            return 'Ahead'
        
        ### 2020 ### 
        elif (df['Award_Year'] == 2020) and (df['Expended_Percent_Group'] == "1-25"):
            return 'Behind'
        elif (df['Award_Year'] == 2020) and (df['Expended_Percent_Group'] == "26-50"):
            return 'On Track'
        elif (df['Award_Year'] == 2020) and (df['Expended_Percent_Group'] == "51-75") | (df['Expended_Percent_Group'] == "76-99"):
            return 'Ahead'
        
        ### 0 Expenditures ### 
        elif df ['Expended_Percent_Group'] == "0":
            return "No expenditures recorded"
        
        ### Else ### 
        else: 
            return "100% of allocated funds spent"

    df['Progress'] = df.apply(progress, axis = 1)
    
    #Which projects are large,small, medium
    p75 = df.TIRCP_project_sheet.quantile(0.75).astype(float)
    p25 = df.TIRCP_project_sheet.quantile(0.25).astype(float)
    p50 = df.TIRCP_project_sheet.quantile(0.50).astype(float)
    
    def project_size (row):
        if ((row.TIRCP_project_sheet > 0) and (row.TIRCP_project_sheet < p25)):
            return "Small"
        elif ((row.TIRCP_project_sheet > p25) and (row.TIRCP_project_sheet < p75)):
            return "Medium"
        elif ((row.TIRCP_project_sheet > p50) and (row.TIRCP_project_sheet > p75 )):
            return "Large"
        else:
            return "$0 recorded for TIRCP"
        
    df["Project_Category"] = df.apply(lambda x: project_size(x), axis=1)
     #Rename cols to the right names
    df = (df.rename(columns = {'from_joined_alloc_df_tot_exp':'Expended_Amount', 
                                                'TIRCP_project_sheet': "TIRCP_Amount"}
                  ))
    ### GCS ###
    # df = df.to_excel(f'{GCS_FILE_PATH}INTERIM_EXPENDITURE_Tableau_Parquet.xlsx')
  
    return df

# %%
final_df = tableau2(final_join)
# Out:
# /tmp/ipykernel_1219/964883781.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /tmp/ipykernel_1219/964883781.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /tmp/ipykernel_1219/964883781.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /tmp/ipykernel_1219/964883781.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /tmp/ipykernel_1219/964883781.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /tmp/ipykernel_1219/964883781.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /tmp/ipykernel_1219/964883781.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /tmp/ipykernel_1219/964883781.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
final_df[['Award_Year','Project_#','PPNO','Project_Title', 'Allocated_Amount','TIRCP_Amount',
          'Expended_Amount','Expended_Percent','Progress']].sort_values( by = ['Award_Year', 'PPNO'])
# Out:
#     Award_Year  Project_#   PPNO  \
# 6         2015          7  CP001
# 12        2015         13  CP002
# 7         2015          8  CP003
# 5         2015          6  CP004
# 0         2015          1  CP005
# 9         2015         10  CP006
# 3         2015          4  CP007
# 8         2015          9  CP008
# 13        2015         14  CP010
# 11        2015         12  CP011
# 1         2015          2  CP012
# 4         2015          5  CP013
# 10        2015         11  CP014
# 2         2015          3  CP015
# 24        2016         11   1230
# 25        2016         12  CP006
# 17        2016          4  CP016
# 21        2016          8  CP017
# 14        2016          1  CP019
# 19        2016          6  CP020
# 22        2016          9  CP022
# 15        2016          2  CP023
# 26        2016         13  CP025
# 20        2016          7  CP043
# 27        2016         14  CP057
# 18        2016          5  CP058
# 16        2016          3  CP076
# 23        2016         10  CP080
# 55        2018         28   1155
# 28        2018          1  2320B
# 45        2018         18  CP006
# 29        2018          2  CP027
# 30        2018          3  CP028
# 34        2018          7  CP029
# 37        2018         10  CP030
# 38        2018         11  CP031
# 39        2018         12  CP031
# 54        2018         27  CP033
# 42        2018         15  CP034
# 44        2018         17  CP034
# 46        2018         19  CP035
# 32        2018          5  CP036
# 40        2018         13  CP039
# 53        2018         26  CP041
# 51        2018         24  CP045
# 52        2018         25  CP046
# 49        2018         22  CP047
# 48        2018         21  CP048
# 36        2018          9  CP051
# 41        2018         14  CP053
# 35        2018          8  CP054
# 31        2018          4  CP055
# 50        2018         23  CP057
# 43        2018         16  CP077
# 47        2018         20  CP078
# 33        2018          6  CP079
# 56        2020          1  CP059
# 57        2020          2  CP060
# 58        2020          3  CP061
# 59        2020          4  CP062
# 60        2020          5  CP063
# 61        2020          6  CP064
# 62        2020          7  CP065
# 63        2020          8  CP066
# 64        2020          9  CP067
# 65        2020         10  CP068
# 66        2020         11  CP069
# 67        2020         12  CP070
# 68        2020         13  CP071
# 69        2020         14  CP072
# 70        2020         15  CP073
# 71        2020         16  CP074
# 72        2020         17  CP075
#
#                                                                                                            Project_Title  \
# 6                                                   Sacramento Regional Transit's Refurbishment of 7 Light Rail Vehicles
# 12                                                         Purchase of Nine Fuel-Efficient Tier IV EMD F-125 Locomotives
# 7                                                                                            South Bay Bus Rapid Transit
# 5                                                                                           Bravo! Route 560 Rapid Buses
# 0                                                         Regional Transit Interconnectivity & Environmental Sustability
# 9                                                                               SFMTA Light Rail Vehicle Fleet Expansion
# 3                                                                             Pacific Surfliner Transit Transfer Program
# 8                                                    San Diego Metropolitan Transit System Trolley Capacity Improvements
# 13                                                                                       SMART Rail Car Capacity Project
# 11                                          Bus Rapid Transit – Martin Luther King Corridor and Crosstown Miner Corridor
# 1                                                                                          Travel Time Reduction Project
# 4                                       Monterey Bay Operations and Maintenance Facility/Salinas Transit Service Project
# 10                                                                                             ACE Wayside Power Project
# 2                                 Willowbrook/Rosa Parks Station & Blue Line Light Rail Operational Improvements Project
# 24                                                                                       Redlands Passenger Rail Project
# 25                                                                        Light Rail Modernization and Expansion Program
# 17                                                              Metropolitan Rapid Transit and Rail Connectivity Project
# 21                                                                    OC Streetcar and OCTA System-Wide Mobile Ticketing
# 14                  Zero Emission Bus and Vanpool Expansion in the Antelope Valley, Kern County and the Coachella Valley
# 19                                                             Metro Red Line and Purple Line Core Capacity Improvements
# 22                                                                            Peninsula Corridor Electrification Project
# 15                               Increased Rail Service to Roseville, Service Optimization and Standby Power Investments
# 26                                                                          ACE Near-Term Capacity Improvement Program\n
# 20                                                              All Aboard: Transforming Southern California Rail Travel
# 27                                                                                BART Silicon Valley Phase II Extension
# 18                                         Airport Metro Connector 96th Street Station/Metro Green Line Extension to LAX
# 16                                  Transforming California: Bus Electrification, Service Expansion and Rail Integration
# 23                                                              Downtown/Riverfront Sacramento-West Sacramento Streetcar
# 55                                                                                Extend rail service to Monterey County
# 28                      Purchase Zero Emission High Capacity Buses to Support Transbay Tomorrow and Clean Corridors Plan
# 45                                                                                    Transit Capacity Expansion Program
# 29                                              #Electrify Anaheim: Changing the Transit Paradigm in Southern California
# 30     From the Desert to the Sea: Antelope Valley Transit Authority and Long Beach Transit Zero Emission Bus Initiative
# 34                            Los Angeles City: Leading the Transformation to Zero-Emission Electric Bus Transit Service
# 37                                   Los Angeles Region Transit System Integration and Modernization Program of Projects
# 38                                                                       All Aboard 2018: Transforming SoCal Rail Travel
# 39                                                                         Building Up: LOSSAN North Improvement Program
# 54                                                                  Southern California Optimized Rail Expansion (SCORE)
# 42  Diesel Multiple Unit Vehicle to Zero- or Low-Emission Vehicle Conversion and West Valley Connector Bus Rapid Transit
# 44                                                                          Blue Line Rail Corridor Transit Enhancements
# 46                                                                                                           Valley Rail
# 32                                                                  The Northern California Corridor Enhancement Program
# 40                                                                  Peninsula Corridor Electrification Expansion Project
# 53                                                                                    SMART Larkspur to Windsor Corridor
# 51                                                                                      North State Intercity Bus System
# 52                                                                                  Solano Regional Transit Improvements
# 49                                                                                                    Goleta Train Depot
# 48                                 Coastal Express/Pacific Surfliner Peak Hour Service Expansion and Integration Project
# 36                                               Dublin/Pleasanton Capacity Improvement and Congestion Reduction Program
# 41                                                   Accelerating Rail Modernization and Expansion in the Capital Region
# 35                                                 Electric Blue: Electrification of City of Santa Monica's Big Blue Bus
# 31         The Transbay Corridor Core Capacity Program: Vehicle Acquistion and Communications-Based Train Control System
# 50                                                                         VTA’s BART Silicon Valley Extension, Phase II
# 43                                                       Ride Between the Line: Enhancing Access to Transit in San Diego
# 47                                                                                            SamTrans Express Bus Pilot
# 33                                                                                  Southwest Fresno Community Connector
# 56                    Reaching the Most Transit-Vulnerable: AVTA's Zero Emission "Microtransit" & Bus Expansion Proposal
# 57                                                     The Transbaby Corridor Core Capacity Program: Vehicle Acquisition
# 58                                                                        Sacramento Valley Station (SVS) Transit Center
# 59                                                                                   Inglewood Transit Connector Project
# 60                                                                                      North State Intercity Bus System
# 61                                                                                    LBT/UCLA Electric Commuter Express
# 62                                                       Metrolink Antelope Valley Line Capital and Service Improvements
# 63                                                               Building Up Control: LOSSAN Service Enhancement Program
# 64                                                             Light Rail Modernization and Expansion of Low-Floor Fleet
# 65                                                      West Valley Connector Bus Rapid Transit Phase 1 & ZEB Initiative
# 66                                                                         SDConnect: San Diego Rail Improvement Program
# 67                                                                                                 Core Capacity Program
# 68                                          For People, Place and Planet: Connecting Inglewood to Regional Opportunities
# 69                                                                          Solano Regional Transit Improvements Phase 2
# 70                                                                      Torrance Transit Bus Service Enhancement Program
# 71                 Improving Air Quality & Economic Growth with Electric Buses in Merced County, the Gateway to Yosemite
# 72                                                                                      Expansion of WETA Ferry Services
#
#     Allocated_Amount  TIRCP_Amount  Expended_Amount  Expended_Percent  \
# 6            6427000       6427000       6315208.89              0.98
# 12          41181000      41181000      38023039.68              0.92
# 7            4000000       4000000       4000000.00              1.00
# 5            2320000       2320000       2320000.00              1.00
# 0           24403000      24403000      22284205.53              0.91
# 9           41181000      41181000      41181000.00              1.00
# 3            1675000       1675000        277840.47              0.17
# 8           31936000      31936000      31936000.00              1.00
# 13          11000000      11000000      11000000.00              1.00
# 11           6841000       6841000       6841000.00              1.00
# 1            4620000       4620000       4619999.90              1.00
# 4           10000000      10000000      10000000.00              1.00
# 10            200000        200000        200000.00              1.00
# 2           38494000      38494000      38494000.00              1.00
# 24           9204000       9204000       9204000.00              1.00
# 25          45092000      45092000      45092000.00              1.00
# 17           8000000       8000000       4083000.00              0.51
# 21          28000000      28000000      17533049.35              0.63
# 14           8930000       8930000       2449000.00              0.27
# 19          69209000      69209000      42555163.12              0.61
# 22          20000000      20000000      16100400.95              0.81
# 15           3446000       8999000        435332.37              0.13
# 26           8000000      16459000        428492.45              0.05
# 20          73860000      82000000        842756.08              0.01
# 27                 0      20000000             0.00              0.00
# 18          40000000      40000000             0.00              0.00
# 16           5000000       5000000             0.00              0.00
# 23                 0      30000000             0.00              0.00
# 55            500000      10148000        486509.70              0.97
# 28           8000000      14000000        500000.00              0.06
# 45          26867000      26867000      26867000.00              1.00
# 29          28617000      28617000      15829361.11              0.55
# 30          17107000      13156000       6727853.61              0.39
# 34          36104000      36104000             0.00              0.00
# 37         261200000    1088499000             0.00              0.00
# 38          31858000      40412000      21165535.14              0.66
# 39          60820000     147930000      21165535.14              0.35
# 54         377728000     875708000      30688351.23              0.08
# 42          30000000      30000000      23937070.02              0.80
# 44          37263000      40098000      23937070.02              0.64
# 46          80280000     500500000      18344305.43              0.23
# 32          50040000      80340000      30950402.20              0.62
# 40         137657000     164522000      62705265.47              0.46
# 53          21000000      21000000      19278743.87              0.92
# 51           8641000       8641000             0.00              0.00
# 52           9225000      10788000       7244002.74              0.79
# 49           2200000      13009000       1571222.84              0.71
# 48           9600000       9600000       4144463.76              0.43
# 36          20500000      20500000        382718.05              0.02
# 41          64350000      64350000      31327612.58              0.49
# 35           3050000       3050000             0.00              0.00
# 31         318600000     318600000      25010228.12              0.08
# 50                 0     730000000             0.00              0.00
# 43                 0       5763000             0.00              0.00
# 47                 0      15000000             0.00              0.00
# 33           7798000       7798000         63708.00              0.01
# 56           6503000       6503000             0.00              0.00
# 57                 0     107100000             0.00              0.00
# 58            720000       3914000           981.93              0.00
# 59          20000000      95200000      13321538.34              0.67
# 60            250000      12994000             0.00              0.00
# 61           6451000       6451000             0.00              0.00
# 62                 0     107050000             0.00              0.00
# 63            748000      38743000             0.00              0.00
# 64          23600000      23600000             0.00              0.00
# 65                 0      15000000             0.00              0.00
# 66           4494000      12100000        644919.97              0.14
# 67                 0      41668000             0.00              0.00
# 68                 0       1105000             0.00              0.00
# 69           2500000      10400000        589950.41              0.24
# 70           6000000       6000000             0.00              0.00
# 71           3112000       3112000             0.00              0.00
# 72                 0       9060000             0.00              0.00
#
#                          Progress
# 6                        On Track
# 12                       On Track
# 7   100% of allocated funds spent
# 5   100% of allocated funds spent
# 0                        On Track
# 9   100% of allocated funds spent
# 3                          Behind
# 8   100% of allocated funds spent
# 13  100% of allocated funds spent
# 11  100% of allocated funds spent
# 1                        On Track
# 4   100% of allocated funds spent
# 10  100% of allocated funds spent
# 2   100% of allocated funds spent
# 24  100% of allocated funds spent
# 25  100% of allocated funds spent
# 17                       On Track
# 21                       On Track
# 14                         Behind
# 19                       On Track
# 22                       On Track
# 15                         Behind
# 26                         Behind
# 20                         Behind
# 27       No expenditures recorded
# 18       No expenditures recorded
# 16       No expenditures recorded
# 23       No expenditures recorded
# 55                          Ahead
# 28                         Behind
# 45  100% of allocated funds spent
# 29                       On Track
# 30                       On Track
# 34       No expenditures recorded
# 37       No expenditures recorded
# 38                       On Track
# 39                       On Track
# 54                         Behind
# 42                          Ahead
# 44                       On Track
# 46                         Behind
# 32                       On Track
# 40                       On Track
# 53                          Ahead
# 51       No expenditures recorded
# 52                          Ahead
# 49                       On Track
# 48                       On Track
# 36                         Behind
# 41                       On Track
# 35       No expenditures recorded
# 31                         Behind
# 50       No expenditures recorded
# 43       No expenditures recorded
# 47       No expenditures recorded
# 33                         Behind
# 56       No expenditures recorded
# 57       No expenditures recorded
# 58                         Behind
# 59                          Ahead
# 60       No expenditures recorded
# 61       No expenditures recorded
# 62       No expenditures recorded
# 63       No expenditures recorded
# 64       No expenditures recorded
# 65       No expenditures recorded
# 66                         Behind
# 67       No expenditures recorded
# 68       No expenditures recorded
# 69                         Behind
# 70       No expenditures recorded
# 71       No expenditures recorded
# 72       No expenditures recorded

# %%
final_df.Progress.value_counts()
# Out:
# No expenditures recorded         24
# On Track                         18
# Behind                           14
# 100% of allocated funds spent    12
# Ahead                             5
# Name: Progress, dtype: int64

# %%
final_df.Progress.value_counts().sum()
# Out:
# 73

# %%
TIRCP = final_df['TIRCP_Amount'].sum()
f'The total amount of TIRCP is {TIRCP}'
# Out:
# 'The total amount of TIRCP is 5440171000'

# %%
Alloc = final_df['Allocated_Amount'].sum()
f'The total amount of $ allocated is {Alloc}'
# Out:
# 'The total amount of $ allocated is 2266402000'

# %%
Exp = final_df['Expended_Amount'].sum()
f'Total amount of expenditures is {Exp}'
# Out:
# 'Total amount of expenditures is 743099838.47'

# %%
f'% of allocated money spent {(Alloc/TIRCP).round(2)}'
# Out:
# '% of allocated money spent 0.42'

# %%
f'% of expended  by allocation {(Exp/Alloc).round(2)}'
# Out:
# '% of expended  by allocation 0.33'

# %%
f'% of expended  by TIRCP {(Exp/TIRCP).round(2)}'
# Out:
# '% of expended  by TIRCP 0.14'

# %%
final_df.to_excel(f'{GCS_FILE_PATH}tableau_with_temporary_expenditure_sol.xlsx', index = False)

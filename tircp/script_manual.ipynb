# %% [markdown]
# # Manual Checks
# * Cleaning the "Project" and "Allocation" sheet have manual components.
#     * `clean_allocation_manual()` and `clean_project_manual()` respectively.
# * This notebook walks through each manual step and any changes.

# %%
import A1_data_prep
import A5_crosswalks as crosswalks
import A6_other
import numpy as np
import pandas as pd
from calitp import *

pd.options.display.max_columns = 100
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", None)

# %% [markdown]
# ## Project Sheet

# %%
# Loading in the original sheet that has not been manipulated
project = A1_data_prep.load_project()
# Out:
# /opt/conda/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed

# %%
# Check award cycles to ensure they are in the format of 1,2,3,4,5
project.award_cycle.value_counts()
# Out:
# 3           28
# 5           23
# 4           16
# 1           14
# 2           14
# FY 21/22     1
# Name: award_cycle, dtype: int64

# %%
# Check award years to ensure 
project.award_year.value_counts()
# Out:
# 2018    28
# 2022    23
# 2020    17
# 2015    14
# 2016    14
# Name: award_year, dtype: int64

# %% [markdown]
# ### Check PPNO - Project Relationship

# %%
f"There are {project.ppno.nunique()} PPNO numbers and {project.project_title.nunique()} project titles."
# Out:
# 'There are 90 PPNO numbers and 95 project titles.'

# %%
# Check PPNO with more than one value
# Make sure they make sense. 
ppno_df = (
    A6_other.value_counts_df(project, "ppno")
    .rename(columns={"ppno": "total projects", "index": "ppno"})
)

# %%
ppno_df = ppno_df.loc[ppno_df['total projects'] > 1]

# %%
ppno_more_than_1_project = ppno_df.ppno.tolist()

# %%
project[["award_year","ppno", "project_title", "grant_recipient", ]][
    project["ppno"].isin(ppno_more_than_1_project)
].sort_values('ppno')
# Out:
#     award_year   ppno  \
# 9         2015  CP006
# 25        2016  CP006
# 45        2018  CP006
# 38        2018  CP031
# 39        2018  CP031
# 42        2018  CP034
# 44        2018  CP034
# 27        2016  CP057
# 50        2018  CP057
#
#                                                                                                            project_title  \
# 9                                                                               SFMTA Light Rail Vehicle Fleet Expansion
# 25                                                                        Light Rail Modernization and Expansion Program
# 45                                                                                    Transit Capacity Expansion Program
# 38                                                                       All Aboard 2018: Transforming SoCal Rail Travel
# 39                                                                         Building Up: LOSSAN North Improvement Program
# 42  Diesel Multiple Unit Vehicle to Zero- or Low-Emission Vehicle Conversion and West Valley Connector Bus Rapid Transit
# 44                                                                          Blue Line Rail Corridor Transit Enhancements
# 27                                                                                BART Silicon Valley Phase II Extension
# 50                                                                         VTA’s BART Silicon Valley Extension, Phase II
#
#                                                         grant_recipient
# 9                 San Francisco Municipal Transportation Agency (SFMTA)
# 25                San Francisco Municipal Transportation Agency (SFMTA)
# 45                San Francisco Municipal Transportation Agency (SFMTA)
# 38  Los Angeles-San Diego-San Luis Obispo Rail Corridor Agency (LOSSAN)
# 39  Los Angeles-San Diego-San Luis Obispo Rail Corridor Agency (LOSSAN)
# 42               San Bernardino County Transportation Authority (SBCTA)
# 44                        San Diego Metropolitan Transit System (SDMTS)
# 27                          Santa Clara Valley Transportation Authority
# 50                  Santa Clara Valley Transportation Authority (SCVTA)

# %% [markdown]
# ## Allocation Sheet

# %%
# Load in sheets
allocation = A1_data_prep.load_allocation()

# %% [markdown]
# ### Dates
# * Correct any values that didn't read in correctly in `A5_crosswalks`.
# * String values without date information such as "pending" or "on hold" don't need to be corrected as they are coerced later on.
# * In contrast values such as "6/30/2021\n12/31/2021\n10/20/2022" should be corrected.

# %%
allocation._3rd_party_award_date.unique().tolist()
# Out:
# [datetime.datetime(2016, 3, 14, 0, 0),
#  datetime.datetime(2016, 6, 1, 0, 0),
#  datetime.datetime(2017, 6, 28, 0, 0),
#  datetime.datetime(2016, 11, 3, 0, 0),
#  datetime.datetime(2015, 11, 30, 0, 0),
#  datetime.datetime(2015, 10, 21, 0, 0),
#  datetime.datetime(2016, 1, 8, 0, 0),
#  '-',
#  datetime.datetime(2017, 5, 30, 0, 0),
#  datetime.datetime(2016, 11, 1, 0, 0),
#  datetime.datetime(2015, 1, 1, 0, 0),
#  datetime.datetime(2018, 2, 2, 0, 0),
#  datetime.datetime(2017, 6, 23, 0, 0),
#  datetime.datetime(2015, 10, 15, 0, 0),
#  datetime.datetime(2016, 4, 6, 0, 0),
#  datetime.datetime(2017, 3, 22, 0, 0),
#  datetime.datetime(2017, 5, 16, 0, 0),
#  datetime.datetime(2019, 2, 13, 0, 0),
#  nan,
#  datetime.datetime(2019, 7, 23, 0, 0),
#  datetime.datetime(2020, 4, 3, 0, 0),
#  datetime.datetime(2019, 1, 9, 0, 0),
#  datetime.datetime(2021, 8, 9, 0, 0),
#  datetime.datetime(2022, 2, 15, 0, 0),
#  datetime.datetime(2017, 1, 13, 0, 0),
#  datetime.datetime(2021, 9, 22, 0, 0),
#  datetime.datetime(2020, 3, 26, 0, 0),
#  datetime.datetime(2018, 2, 3, 0, 0),
#  datetime.datetime(2017, 2, 28, 0, 0),
#  datetime.datetime(2020, 2, 18, 0, 0),
#  datetime.datetime(2019, 1, 14, 0, 0),
#  datetime.datetime(2016, 11, 21, 0, 0),
#  datetime.datetime(2018, 11, 19, 0, 0),
#  datetime.datetime(2016, 8, 15, 0, 0),
#  datetime.datetime(2019, 5, 15, 0, 0),
#  datetime.datetime(2018, 4, 20, 0, 0),
#  datetime.datetime(2023, 12, 30, 0, 0),
#  datetime.datetime(2021, 3, 18, 0, 0),
#  datetime.datetime(2019, 4, 19, 0, 0),
#  datetime.datetime(2022, 7, 26, 0, 0),
#  datetime.datetime(2017, 6, 1, 0, 0),
#  datetime.datetime(2019, 12, 20, 0, 0),
#  datetime.datetime(2019, 7, 2, 0, 0),
#  datetime.datetime(2019, 1, 7, 0, 0),
#  datetime.datetime(2020, 7, 13, 0, 0),
#  datetime.datetime(2020, 9, 16, 0, 0),
#  datetime.datetime(2019, 1, 18, 0, 0),
#  datetime.datetime(2020, 5, 14, 0, 0),
#  datetime.datetime(2019, 3, 27, 0, 0),
#  datetime.datetime(2020, 12, 16, 0, 0),
#  datetime.datetime(2019, 10, 25, 0, 0),
#  datetime.datetime(2018, 8, 16, 0, 0),
#  datetime.datetime(2020, 2, 3, 0, 0),
#  datetime.datetime(2019, 6, 3, 0, 0),
#  datetime.datetime(2022, 3, 22, 0, 0),
#  datetime.datetime(2020, 2, 27, 0, 0),
#  datetime.datetime(2022, 6, 30, 0, 0),
#  datetime.datetime(2019, 2, 1, 0, 0),
#  datetime.datetime(2021, 1, 21, 0, 0),
#  datetime.datetime(2021, 8, 12, 0, 0),
#  datetime.datetime(2021, 9, 2, 0, 0),
#  datetime.datetime(2022, 4, 8, 0, 0),
#  'Pending',
#  '07/29/2020',
#  datetime.datetime(2021, 6, 30, 0, 0),
#  datetime.datetime(2021, 5, 13, 0, 0),
#  datetime.datetime(2021, 12, 5, 0, 0),
#  datetime.datetime(2021, 12, 6, 0, 0),
#  datetime.datetime(2021, 12, 1, 0, 0),
#  datetime.datetime(2021, 12, 21, 0, 0),
#  datetime.datetime(2021, 1, 29, 0, 0),
#  datetime.datetime(2018, 10, 10, 0, 0),
#  datetime.datetime(2018, 12, 14, 0, 0),
#  datetime.datetime(2019, 6, 27, 0, 0),
#  datetime.datetime(2020, 3, 31, 0, 0),
#  datetime.datetime(2019, 11, 13, 0, 0),
#  datetime.datetime(2019, 6, 13, 0, 0),
#  datetime.datetime(2019, 12, 27, 0, 0),
#  datetime.datetime(2020, 8, 11, 0, 0),
#  datetime.datetime(2021, 1, 13, 0, 0),
#  datetime.datetime(2022, 2, 16, 0, 0),
#  datetime.datetime(2022, 5, 3, 0, 0),
#  datetime.datetime(2018, 9, 7, 0, 0),
#  datetime.datetime(2022, 8, 1, 0, 0),
#  datetime.datetime(2020, 5, 4, 0, 0),
#  datetime.datetime(2018, 12, 1, 0, 0),
#  datetime.datetime(2020, 12, 31, 0, 0),
#  datetime.datetime(2018, 10, 18, 0, 0),
#  datetime.datetime(2024, 6, 3, 0, 0),
#  datetime.datetime(2018, 11, 15, 0, 0),
#  datetime.datetime(2019, 10, 8, 0, 0),
#  datetime.datetime(2021, 5, 24, 0, 0),
#  datetime.datetime(2018, 9, 19, 0, 0),
#  datetime.datetime(2022, 1, 18, 0, 0),
#  datetime.datetime(2022, 5, 20, 0, 0),
#  'Pending (on hold)',
#  datetime.datetime(2020, 9, 30, 0, 0),
#  datetime.datetime(2019, 4, 13, 0, 0),
#  datetime.datetime(2020, 8, 21, 0, 0),
#  datetime.datetime(2020, 10, 12, 0, 0),
#  datetime.datetime(2022, 1, 24, 0, 0),
#  datetime.datetime(2019, 8, 22, 0, 0),
#  datetime.datetime(2019, 4, 24, 0, 0),
#  datetime.datetime(2021, 7, 14, 0, 0),
#  datetime.datetime(2020, 8, 14, 0, 0),
#  datetime.datetime(2021, 4, 2, 0, 0),
#  datetime.datetime(2022, 3, 24, 0, 0),
#  datetime.datetime(2022, 6, 22, 0, 0),
#  datetime.datetime(2021, 11, 16, 0, 0),
#  datetime.datetime(2021, 8, 5, 0, 0),
#  datetime.datetime(2021, 6, 1, 0, 0)]

# %%
allocation.phase_completion_date.unique().tolist()
# Out:
# [datetime.datetime(2022, 3, 30, 0, 0),
#  'Complete\n6/1/2019',
#  datetime.datetime(2021, 6, 30, 0, 0),
#  'Complete 6/11/2018',
#  'Complete\n2/11/2018',
#  'Complete\n6/30/2020',
#  datetime.datetime(2020, 9, 30, 0, 0),
#  datetime.datetime(2018, 6, 30, 0, 0),
#  datetime.datetime(2020, 6, 29, 0, 0),
#  datetime.datetime(2019, 11, 1, 0, 0),
#  datetime.datetime(2018, 12, 10, 0, 0),
#  'Complete\n11/13/2019',
#  datetime.datetime(2020, 3, 30, 0, 0),
#  'Sep-22',
#  datetime.datetime(2021, 12, 30, 0, 0),
#  datetime.datetime(2021, 9, 30, 0, 0),
#  datetime.datetime(2020, 5, 16, 0, 0),
#  '6/30/2020\nComplete',
#  '-',
#  'Jun-23',
#  'Apr-23',
#  'Jun-24',
#  'Dec-25',
#  '6/30/2022\nComplete',
#  'Sep-24',
#  'Jul-24',
#  datetime.datetime(2018, 5, 26, 0, 0),
#  datetime.datetime(2019, 5, 21, 0, 0),
#  datetime.datetime(2022, 1, 16, 0, 0),
#  'Oct-22',
#  datetime.datetime(2021, 12, 31, 0, 0),
#  datetime.datetime(2018, 2, 1, 0, 0),
#  'Jan-24',
#  'Apr-24',
#  datetime.datetime(2021, 7, 7, 0, 0),
#  datetime.datetime(2020, 5, 7, 0, 0),
#  datetime.datetime(2021, 4, 20, 0, 0),
#  datetime.datetime(2022, 7, 31, 0, 0),
#  datetime.datetime(2030, 6, 1, 0, 0),
#  datetime.datetime(2020, 6, 30, 0, 0),
#  'Feb-24',
#  'Mar-22',
#  datetime.datetime(2022, 3, 22, 0, 0),
#  'Sep-23',
#  'Jul-23',
#  'Jan-30',
#  '12/25/2021\nComplete',
#  'Dec-23',
#  'Nov-24',
#  'Oct-22; June 30, 2024',
#  'Feb-23',
#  'Jul-22',
#  'Jan-25',
#  'Nov-23',
#  datetime.datetime(2019, 11, 12, 0, 0),
#  datetime.datetime(2022, 10, 9, 0, 0),
#  datetime.datetime(2023, 10, 22, 0, 0),
#  datetime.datetime(2024, 1, 21, 0, 0),
#  datetime.datetime(2024, 8, 12, 0, 0),
#  datetime.datetime(2024, 10, 14, 0, 0),
#  datetime.datetime(2021, 12, 6, 0, 0),
#  datetime.datetime(2022, 6, 30, 0, 0),
#  datetime.datetime(2023, 5, 23, 0, 0),
#  datetime.datetime(2024, 6, 1, 0, 0),
#  datetime.datetime(2024, 12, 1, 0, 0),
#  datetime.datetime(2023, 5, 1, 0, 0),
#  datetime.datetime(2023, 12, 23, 0, 0),
#  '6/30/2021\nComplete',
#  nan,
#  'Dec-24',
#  'Jun-22',
#  'Feb-26',
#  'Aug-25',
#  'Nov-22',
#  'Complete\n1/31/2020',
#  datetime.datetime(2022, 12, 27, 0, 0),
#  datetime.datetime(2023, 8, 11, 0, 0),
#  datetime.datetime(2021, 6, 25, 0, 0),
#  datetime.datetime(2024, 6, 24, 0, 0),
#  datetime.datetime(2024, 6, 30, 0, 0),
#  datetime.datetime(2020, 8, 30, 0, 0),
#  datetime.datetime(2023, 6, 30, 0, 0),
#  datetime.datetime(2024, 3, 25, 0, 0),
#  datetime.datetime(2023, 5, 4, 0, 0),
#  datetime.datetime(2022, 6, 25, 0, 0),
#  datetime.datetime(2021, 3, 30, 0, 0),
#  datetime.datetime(2031, 9, 22, 0, 0),
#  'May-24',
#  'Complete\n8/30/2020',
#  datetime.datetime(2023, 8, 31, 0, 0),
#  '10/28/2020',
#  '1/22/2021',
#  '2/26/2021',
#  'Oct-24',
#  '3/16/2021',
#  datetime.datetime(2024, 10, 31, 0, 0),
#  '12/31/21\nComplete',
#  '12/4/2020',
#  'Dec-27',
#  '2/8/2021',
#  '11/19/2021',
#  '6/16/2022',
#  '8/26/2021',
#  '4/24/2022',
#  datetime.datetime(2021, 11, 16, 0, 0),
#  datetime.datetime(2025, 6, 1, 0, 0),
#  '.']

# %%
allocation.allocation_date.unique().tolist()
# Out:
# [datetime.datetime(2015, 10, 22, 0, 0),
#  datetime.datetime(2016, 5, 19, 0, 0),
#  datetime.datetime(2016, 6, 30, 0, 0),
#  datetime.datetime(2015, 12, 10, 0, 0),
#  datetime.datetime(2015, 8, 27, 0, 0),
#  datetime.datetime(2016, 1, 21, 0, 0),
#  datetime.datetime(2017, 6, 29, 0, 0),
#  datetime.datetime(2016, 10, 20, 0, 0),
#  datetime.datetime(2017, 8, 17, 0, 0),
#  datetime.datetime(2018, 2, 1, 0, 0),
#  datetime.datetime(2016, 3, 16, 0, 0),
#  datetime.datetime(2016, 3, 17, 0, 0),
#  datetime.datetime(2017, 1, 19, 0, 0),
#  datetime.datetime(2018, 8, 16, 0, 0),
#  datetime.datetime(2022, 5, 19, 0, 0),
#  datetime.datetime(2018, 12, 6, 0, 0),
#  datetime.datetime(2019, 10, 9, 0, 0),
#  datetime.datetime(2017, 3, 16, 0, 0),
#  datetime.datetime(2021, 6, 24, 0, 0),
#  datetime.datetime(2020, 6, 25, 0, 0),
#  datetime.datetime(2016, 12, 8, 0, 0),
#  datetime.datetime(2020, 6, 24, 0, 0),
#  datetime.datetime(2019, 12, 5, 0, 0),
#  datetime.datetime(2018, 10, 18, 0, 0),
#  nan,
#  datetime.datetime(2021, 1, 28, 0, 0),
#  datetime.datetime(2018, 5, 17, 0, 0),
#  datetime.datetime(2019, 6, 27, 0, 0),
#  datetime.datetime(2017, 5, 18, 0, 0),
#  datetime.datetime(2018, 6, 28, 0, 0),
#  datetime.datetime(2020, 10, 22, 0, 0),
#  datetime.datetime(2022, 1, 27, 0, 0),
#  datetime.datetime(2017, 5, 17, 0, 0),
#  datetime.datetime(2020, 5, 14, 0, 0),
#  datetime.datetime(2021, 5, 13, 0, 0),
#  datetime.datetime(2020, 1, 30, 0, 0),
#  datetime.datetime(2021, 8, 19, 0, 0),
#  datetime.datetime(2021, 10, 14, 0, 0),
#  datetime.datetime(2022, 6, 30, 0, 0),
#  datetime.datetime(2019, 5, 16, 0, 0),
#  datetime.datetime(2020, 12, 3, 0, 0),
#  datetime.datetime(2020, 8, 13, 0, 0),
#  '8/16/2018\n12/5/2019',
#  datetime.datetime(2019, 3, 14, 0, 0),
#  datetime.datetime(2019, 1, 31, 0, 0),
#  datetime.datetime(2020, 3, 26, 0, 0),
#  datetime.datetime(2021, 3, 25, 0, 0),
#  datetime.datetime(2022, 8, 18, 0, 0),
#  datetime.datetime(2019, 8, 19, 0, 0),
#  datetime.datetime(2019, 10, 18, 0, 0),
#  datetime.datetime(2019, 8, 15, 0, 0),
#  datetime.datetime(2021, 3, 26, 0, 0),
#  datetime.datetime(2020, 3, 25, 0, 0),
#  datetime.datetime(2022, 4, 13, 0, 0),
#  datetime.datetime(2020, 8, 12, 0, 0),
#  datetime.datetime(2022, 3, 17, 0, 0)]

# %%
allocation.led.unique().tolist()
# Out:
# [datetime.datetime(2022, 3, 31, 0, 0),
#  datetime.datetime(2019, 6, 1, 0, 0),
#  datetime.datetime(2020, 6, 28, 0, 0),
#  datetime.datetime(2021, 6, 30, 0, 0),
#  datetime.datetime(2019, 11, 3, 0, 0),
#  datetime.datetime(2018, 11, 30, 0, 0),
#  datetime.datetime(2020, 6, 30, 0, 0),
#  datetime.datetime(2019, 1, 8, 0, 0),
#  datetime.datetime(2018, 6, 30, 0, 0),
#  datetime.datetime(2020, 6, 29, 0, 0),
#  datetime.datetime(2019, 11, 1, 0, 0),
#  datetime.datetime(2018, 12, 10, 0, 0),
#  datetime.datetime(2021, 2, 2, 0, 0),
#  datetime.datetime(2020, 6, 23, 0, 0),
#  datetime.datetime(2022, 9, 30, 0, 0),
#  'October 15, 2018\nSeptember 30, 2021',
#  datetime.datetime(2021, 9, 22, 0, 0),
#  datetime.datetime(2020, 5, 16, 0, 0),
#  nan,
#  datetime.datetime(2023, 6, 30, 0, 0),
#  datetime.datetime(2021, 6, 1, 0, 0),
#  datetime.datetime(2024, 6, 9, 0, 0),
#  datetime.datetime(2024, 6, 24, 0, 0),
#  datetime.datetime(2025, 2, 17, 0, 0),
#  datetime.datetime(2022, 12, 30, 0, 0),
#  datetime.datetime(2024, 9, 22, 0, 0),
#  datetime.datetime(2024, 7, 31, 0, 0),
#  datetime.datetime(2019, 6, 30, 0, 0),
#  'June 30, 2019\nSeptember 30, 2019',
#  datetime.datetime(2021, 2, 3, 0, 0),
#  datetime.datetime(2022, 1, 16, 0, 0),
#  datetime.datetime(2020, 3, 16, 0, 0),
#  '2/1/2021\n\n10/31/2022',
#  'Deallocated',
#  datetime.datetime(2024, 1, 28, 0, 0),
#  datetime.datetime(2021, 12, 31, 0, 0),
#  datetime.datetime(2019, 11, 21, 0, 0),
#  '02/28/2021\n5/31/2022',
#  datetime.datetime(2024, 4, 30, 0, 0),
#  datetime.datetime(2022, 6, 1, 0, 0),
#  datetime.datetime(2021, 4, 20, 0, 0),
#  datetime.datetime(2022, 7, 31, 0, 0),
#  datetime.datetime(2025, 5, 19, 0, 0),
#  datetime.datetime(2023, 10, 21, 0, 0),
#  datetime.datetime(2025, 1, 27, 0, 0),
#  datetime.datetime(2024, 2, 28, 0, 0),
#  datetime.datetime(2022, 3, 30, 0, 0),
#  datetime.datetime(2023, 3, 31, 0, 0),
#  'Sep-23',
#  datetime.datetime(2023, 7, 13, 0, 0),
#  datetime.datetime(2030, 12, 30, 0, 0),
#  datetime.datetime(2023, 12, 31, 0, 0),
#  datetime.datetime(2024, 12, 31, 0, 0),
#  datetime.datetime(2024, 11, 30, 0, 0),
#  datetime.datetime(2022, 6, 30, 0, 0),
#  datetime.datetime(2023, 6, 25, 0, 0),
#  '10/31/2022: 06/30/2024',
#  datetime.datetime(2023, 2, 3, 0, 0),
#  datetime.datetime(2021, 6, 16, 0, 0),
#  datetime.datetime(2025, 3, 30, 0, 0),
#  datetime.datetime(2023, 11, 30, 0, 0),
#  datetime.datetime(2021, 12, 5, 0, 0),
#  datetime.datetime(2022, 10, 9, 0, 0),
#  datetime.datetime(2023, 10, 22, 0, 0),
#  datetime.datetime(2024, 1, 21, 0, 0),
#  datetime.datetime(2024, 8, 12, 0, 0),
#  datetime.datetime(2024, 9, 2, 0, 0),
#  datetime.datetime(2024, 10, 14, 0, 0),
#  datetime.datetime(2022, 12, 31, 0, 0),
#  datetime.datetime(2023, 2, 18, 0, 0),
#  datetime.datetime(2024, 1, 31, 0, 0),
#  datetime.datetime(2025, 10, 14, 0, 0),
#  datetime.datetime(2020, 9, 30, 0, 0),
#  datetime.datetime(2021, 11, 30, 0, 0),
#  datetime.datetime(2026, 2, 28, 0, 0),
#  datetime.datetime(2025, 8, 31, 0, 0),
#  datetime.datetime(2022, 10, 31, 0, 0),
#  datetime.datetime(2022, 11, 30, 0, 0),
#  datetime.datetime(2026, 1, 31, 0, 0),
#  datetime.datetime(2020, 1, 31, 0, 0),
#  datetime.datetime(2022, 12, 27, 0, 0),
#  datetime.datetime(2023, 8, 11, 0, 0),
#  datetime.datetime(2024, 1, 13, 0, 0),
#  datetime.datetime(2025, 2, 16, 0, 0),
#  datetime.datetime(2024, 6, 30, 0, 0),
#  datetime.datetime(2021, 10, 14, 0, 0),
#  datetime.datetime(2021, 8, 7, 0, 0),
#  datetime.datetime(2024, 3, 25, 0, 0),
#  datetime.datetime(2022, 6, 25, 0, 0),
#  datetime.datetime(2021, 3, 30, 0, 0),
#  datetime.datetime(2019, 10, 18, 0, 0),
#  datetime.datetime(2023, 1, 1, 0, 0),
#  datetime.datetime(2020, 8, 30, 0, 0),
#  datetime.datetime(2024, 5, 23, 0, 0),
#  datetime.datetime(2022, 12, 1, 0, 0),
#  datetime.datetime(2025, 1, 18, 0, 0),
#  datetime.datetime(2020, 10, 28, 0, 0),
#  '1/22/2021',
#  datetime.datetime(2024, 11, 1, 0, 0),
#  datetime.datetime(2021, 2, 26, 0, 0),
#  datetime.datetime(2024, 10, 31, 0, 0),
#  datetime.datetime(2024, 10, 30, 0, 0),
#  '6/30/23\nPending',
#  datetime.datetime(2020, 12, 4, 0, 0),
#  datetime.datetime(2023, 6, 15, 0, 0),
#  datetime.datetime(2024, 2, 29, 0, 0),
#  datetime.datetime(2027, 12, 31, 0, 0),
#  datetime.datetime(2021, 3, 16, 0, 0),
#  datetime.datetime(2021, 2, 8, 0, 0),
#  datetime.datetime(2024, 7, 14, 0, 0),
#  datetime.datetime(2023, 8, 12, 0, 0),
#  '3/24/2025\nPending',
#  datetime.datetime(2025, 6, 22, 0, 0),
#  datetime.datetime(2024, 3, 1, 0, 0),
#  datetime.datetime(2024, 11, 16, 0, 0),
#  datetime.datetime(2024, 8, 5, 0, 0)]

# %% [markdown]
# ## Check PPNO between Allocation and Project Sheet
# * Use the PPNO off of "Project Sheet" as the source of truth.

# %%
# PPNO list for project
project_ppno_list = project.ppno.unique().tolist()

# %%
# PPNO list for allocation
allocation_ppno_list = allocation.ppno.unique().tolist()

# %%
# Check lengths 
len(project_ppno_list) == len(allocation_ppno_list)
# Out:
# False

# %%
# Check differences between allocation vs ppno list
ppno_unique_to_alloc = list(set(allocation_ppno_list) - set(project_ppno_list))

# %%
len(ppno_unique_to_alloc)
# Out:
# 9

# %%
# Check out the projects that appear in alloc sheet but not projects. 
projects_found_only_in_alloc = (allocation[["award_year", "grant_recipient", "ppno"]][
    allocation["ppno"].isin(ppno_unique_to_alloc)
]).drop_duplicates().reset_index(drop = True)

# %%
projects_found_only_in_alloc
# Out:
#    award_year  \
# 0      2015.0
# 1      2016.0
# 2      2016.0
# 3      2016.0
# 4      2018.0
# 5      2018.0
# 6      2018.0
# 7      2018.0
# 8      2018.0
#
#                                                        grant_recipient   ppno
# 0              Southern California Regional Rail Authority (Metrolink)  CP002
# 1                                   Antelope Valley Transit Authority   CP018
# 2  Los Angeles-San Diego-San Luis Obispo Rail Corridor Agency (LOSSAN)  CP024
# 3  Los Angeles-San Diego-San Luis Obispo Rail Corridor Agency (LOSSAN)  CP021
# 4  Los Angeles-San Diego-San Luis Obispo Rail Corridor Agency (LOSSAN)  CP301
# 5  Los Angeles-San Diego-San Luis Obispo Rail Corridor Agency (LOSSAN)  CP042
# 6                                Sacramento Regional Transit District   CP053
# 7                          San Diego Metropolitan Transit System (MTS)  CP032
# 8                            Transportation Agency for Monterey County  1155N

# %%
# Merge df above with a subset of the project df to figure out what's going on. 
project_subset = ['award_year','grant_recipient','project_title','ppno']
m1 = pd.merge(projects_found_only_in_alloc, project[project_subset], how="left", on = ['grant_recipient','award_year'], suffixes = ('_alloc','_project'))

# %%
# For projects that natched over, correct ppno_alloc values to ppno_project
m1[m1['project_title'].notnull()].drop_duplicates()
# Out:
#    award_year  \
# 2      2016.0
# 3      2016.0
# 4      2018.0
# 5      2018.0
# 6      2018.0
# 7      2018.0
#
#                                                        grant_recipient  \
# 2  Los Angeles-San Diego-San Luis Obispo Rail Corridor Agency (LOSSAN)
# 3  Los Angeles-San Diego-San Luis Obispo Rail Corridor Agency (LOSSAN)
# 4  Los Angeles-San Diego-San Luis Obispo Rail Corridor Agency (LOSSAN)
# 5  Los Angeles-San Diego-San Luis Obispo Rail Corridor Agency (LOSSAN)
# 6  Los Angeles-San Diego-San Luis Obispo Rail Corridor Agency (LOSSAN)
# 7  Los Angeles-San Diego-San Luis Obispo Rail Corridor Agency (LOSSAN)
#
#   ppno_alloc                                             project_title  \
# 2      CP024  All Aboard: Transforming Southern California Rail Travel
# 3      CP021  All Aboard: Transforming Southern California Rail Travel
# 4      CP301           All Aboard 2018: Transforming SoCal Rail Travel
# 5      CP301             Building Up: LOSSAN North Improvement Program
# 6      CP042           All Aboard 2018: Transforming SoCal Rail Travel
# 7      CP042             Building Up: LOSSAN North Improvement Program
#
#   ppno_project
# 2        CP043
# 3        CP043
# 4        CP031
# 5        CP031
# 6        CP031
# 7        CP031

# %%
# Find the ppno for the rows missing values from the Project sheet after merging
missing_m1 = m1[m1['project_title'].isnull()]
missing_m1
# Out:
#     award_year                                          grant_recipient  \
# 0       2015.0  Southern California Regional Rail Authority (Metrolink)
# 1       2016.0                       Antelope Valley Transit Authority
# 8       2018.0                    Sacramento Regional Transit District
# 9       2018.0              San Diego Metropolitan Transit System (MTS)
# 10      2018.0                Transportation Agency for Monterey County
#
#    ppno_alloc project_title ppno_project
# 0       CP002           NaN          NaN
# 1       CP018           NaN          NaN
# 8       CP053           NaN          NaN
# 9       CP032           NaN          NaN
# 10      1155N           NaN          NaN

# %%
# Grab years for filtering
missing_m1_years = (missing_m1.award_year.unique().tolist())

# %%
# Grab agencies for filtering
missing_m1_agencies = (missing_m1.grant_recipient.unique().tolist())

# %%
# Join agencies all into a list for string searching
missing_m1_agencies = f"({'|'.join(missing_m1_agencies)})"

# %%
# Filter
missing_m1_projects = project[project_subset][
    project["award_year"].isin(missing_m1_years)
]

# %%
missing_m1_projects[missing_m1_projects["grant_recipient"].str.contains(missing_m1_agencies)]
# Out:
# /tmp/ipykernel_1505/4260984405.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#     award_year                                                grant_recipient  \
# 0         2015                       Antelope Valley Transit Authority (AVTA)
# 6         2015                   Sacramento Regional Transit District (SacRT)
# 14        2016                       Antelope Valley Transit Authority (AVTA)
# 23        2016                   Sacramento Regional Transit District (SacRT)
# 30        2018  Antelope Valley Transit Authority (AVTA) & Long Beach Transit
# 41        2018                   Sacramento Regional Transit District (SacRT)
# 55        2018               Transportation Agency for Monterey County (TAMC)
#
#                                                                                                         project_title  \
# 0                                                      Regional Transit Interconnectivity & Environmental Sustability
# 6                                                Sacramento Regional Transit's Refurbishment of 7 Light Rail Vehicles
# 14               Zero Emission Bus and Vanpool Expansion in the Antelope Valley, Kern County and the Coachella Valley
# 23                                                           Downtown/Riverfront Sacramento-West Sacramento Streetcar
# 30  From the Desert to the Sea: Antelope Valley Transit Authority and Long Beach Transit Zero Emission Bus Initiative
# 41                                                Accelerating Rail Modernization and Expansion in the Capital Region
# 55                                                                             Extend rail service to Monterey County
#
#      ppno
# 0   CP005
# 6   CP001
# 14  CP019
# 23  CP080
# 30  CP028
# 41  CP052
# 55  1155A

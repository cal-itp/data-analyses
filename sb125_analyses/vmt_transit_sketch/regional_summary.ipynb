# %%
import pandas as pd
import geopandas as gpd
from siuba import *

# %%
results = gpd.read_parquet('outputs/new_trips_with_uza.parquet')

# %%
results >> head(3)
# Out:
#         GEOID                                           geometry  \
# 0  6029004402  POLYGON ((59906.842 -270407.558, 59906.948 -27...
# 1  6047000802  POLYGON ((-52727.332 -74888.681, -52723.908 -7...
# 2  6085501402  POLYGON ((-165759.786 -73091.934, -165741.347 ...
#
#    p50_mi_transit  p50_mi_auto  total_mi_transit  total_mi_auto  \
# 0            42.2          1.7              84.4       148755.4
# 1             NaN          4.0               NaN        90331.2
# 2             3.5          4.6             140.3        47341.1
#
#    p50_transit_longer  no_transit  total_mi  new_transit_mi  \
# 0                True       False  148839.8    45045.569679
# 1               False        True       NaN    27353.765738
# 2               False       False   47481.4    14335.659874
#
#    projected_new_transit_trips  index_right UACE10        NAME10  total_pop  \
# 0                       1067.0       2554.0  92161     Wasco, CA       4027
# 1                          NaN          8.0  56251    Merced, CA       4709
# 2                       4095.0       1694.0  79039  San Jose, CA       2962
#
#    new_trips_per_capita
# 0              0.264962
# 1                   NaN
# 2              1.382512

# %%
ntd_totals = pd.read_excel('census_ntd/2022 UZA Sums_0.xlsx')

# %%
ntd_totals >> head(3)
# Out:
#    UACE CD         UZA Name  UZA Population  Total Vehicle Revenue Miles  \
# 0        1  Alabama Non-UZA             NaN                      5191052
# 1        2   Alaska Non-UZA             NaN                      3135019
# 2        4  Arizona Non-UZA             NaN                      6917128
#
#    Total Vehicle Revenue Hours  Total Passenger Miles Traveled  \
# 0                       311767                         1657944
# 1                       181845                        25208661
# 2                       322764                        13610232
#
#    Total Unlinked Passenger Trips  Total Operating Expenses  \
# 0                          847168                  18285687
# 1                         1103868                  74591876
# 2                         1394405                  24844073
#
#    Fixed Guideway Directional Route Miles  \
# 0                                     0.0
# 1                                   891.3
# 2                                     0.0
#
#    Fixed Guideway Vehicle Revenue Miles  Fixed Guideway Passenger Miles  \
# 0                                     0                               0
# 1                               1032797                        25208661
# 2                                     0                               0
#
#    Fixed Guideway Operating Expenses  \
# 0                                  0
# 1                           52590936
# 2                                  0
#
#    Non-Fixed Guideway Vehicle Revenue Miles  \
# 0                                   2032430
# 1                                    526779
# 2                                   5011277
#
#    Non-Fixed Guideway Passenger Miles  Non-Fixed Guideway Operating Expenses  \
# 0                             1657944                                6989662
# 1                                   0                                3461538
# 2                            13610232                               16875708
#
#    Fixed Guideway Directional Route Miles >= 7 Years  \
# 0                                                0.0
# 1                                              891.3
# 2                                                0.0
#
#    Fixed Guideway Vehicle Revenue Miles >= 7 Years  \
# 0                                                0
# 1                                          1032797
# 2                                                0
#
#    High Intensity Bus Directional Route Miles >= 7 Years  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    High Intensity Bus Vehicle Revenue Miles >= 7 Years
# 0                                                  0
# 1                                                  0
# 2                                                  0

# %%
from calitp_data_analysis.sql import to_snakecase

# %%
ntd_totals = to_snakecase(ntd_totals)

# %%
ntd_totals.columns
# Out:
# Index(['uace_cd', 'uza_name', 'uza_population', 'total_vehicle_revenue_miles',
#        'total_vehicle_revenue_hours', 'total_passenger_miles_traveled',
#        'total_unlinked_passenger_trips', 'total_operating_expenses',
#        'fixed_guideway_directional_route_miles',
#        'fixed_guideway_vehicle_revenue_miles',
#        'fixed_guideway_passenger_miles', 'fixed_guideway_operating_expenses',
#        'non_fixed_guideway_vehicle_revenue_miles',
#        'non_fixed_guideway_passenger_miles',
#        'non_fixed_guideway_operating_expenses',
#        'fixed_guideway_directional_route_miles_>=_7_years',
#        'fixed_guideway_vehicle_revenue_miles_>=_7_years',
#        'high_intensity_bus_directional_route_miles_>=_7_years',
#        'high_intensity_bus_vehicle_revenue_miles_>=_7_years'],
#       dtype='object')

# %%
upt_df = ntd_totals >> select(_.uace_cd, _.uza_name, _.total_unlinked_passenger_trips, _.uza_population)

# %%
upt_df
# Out:
#      uace_cd                       uza_name  total_unlinked_passenger_trips  \
# 0          1                Alabama Non-UZA                          847168
# 1          2                 Alaska Non-UZA                         1103868
# 2          4                Arizona Non-UZA                         1394405
# 3          5               Arkansas Non-UZA                          799801
# 4          6             California Non-UZA                         7350357
# ..       ...                            ...                             ...
# 549    69517  Pinehurst--Southern Pines, NC                            9046
# 550    45262                   Kingston, NY                          161584
# 551    27631                       Enid, OK                           38411
# 552    15184               Chambersburg, PA                           39130
# 553    91405            Walla Walla, WA--OR                          327185
#
#      uza_population
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ..              ...
# 549         50319.0
# 550         50254.0
# 551         50194.0
# 552         50094.0
# 553         50013.0
#
# [554 rows x 4 columns]

# %%
upt_df.dtypes
# Out:
# uace_cd                             int64
# uza_name                           object
# total_unlinked_passenger_trips      int64
# uza_population                    float64
# dtype: object

# %%
results.UACE10 = results.UACE10.fillna(6).astype('int64') #  6 is CA non-UZA

# %%
uza_grouped = (results >> group_by(_.UACE10, _.NAME10)
    >> summarize(new_transit_mi_weekday = _.new_transit_mi.sum(),
                new_transit_trips_weekday = _.projected_new_transit_trips.sum(),
                 num_tracts = _.shape[0]
                )
)

# %%
df = (uza_grouped >> inner_join(_, upt_df, on = {'UACE10': 'uace_cd'})
      >> mutate(current_weekday_trips = _.total_unlinked_passenger_trips / (365 - 104))
      >> mutate(increase_ratio = _.new_transit_trips_weekday / _.current_weekday_trips,
               new_trips_per_capita = _.new_transit_trips_weekday / _.uza_population,
               )
      >> arrange(-_.new_transit_trips_weekday)
     ).round(2)

# %%
df.to_csv('vmt_to_transit_uza.csv', index = False)

# %%
## What happens if you compare to 2019/08?

# %%
df >> select(-_.UACE10, -_.NAME10, -_.uace_cd)
# Out:
#     new_transit_mi_weekday  new_transit_trips_weekday  num_tracts  \
# 17             110712768.0                 14290483.0        2974
# 33              32040713.0                  4362939.0         880
# 32              32163879.0                  3453169.0         714
# 29              23420137.0                  2520145.0         447
# 30              19727719.0                  2088535.0         452
# 34              17291692.0                  1891710.0         398
# 10               6927763.0                  1221046.0         166
# 24               3816946.0                   930334.0          95
# 43               4434710.0                   862825.0          99
# 3                5443369.0                   851355.0         156
# 14               5032674.0                   808714.0         105
# 36               2514748.0                   695872.0          54
# 22               3747691.0                   658142.0          86
# 40               3629748.0                   607717.0          83
# 21               6525878.0                   547544.0         124
# 6                7832929.0                   492687.0         151
# 38               2238110.0                   423368.0          50
# 13               2130776.0                   405238.0          48
# 7                 843887.0                   349353.0          20
# 52               1470489.0                   300762.0          30
# 35               1371095.0                   295676.0          17
# 23               1105649.0                   189015.0          28
# 9                1645801.0                   182802.0          36
# 8                1276211.0                   177492.0          19
# 50                932259.0                   164542.0          26
# 2                1196387.0                   147935.0          16
# 44               3137796.0                   142379.0          59
# 11               1598983.0                   139048.0          26
# 0               10223761.0                   128741.0         200
# 39               1438383.0                   128541.0          32
# 19               1569676.0                   123315.0          24
# 1                3188979.0                   116436.0          62
# 45               1196770.0                   110236.0          27
# 47               1870021.0                   107936.0          45
# 51                653703.0                    81968.0          15
# 46               1356136.0                    77033.0          24
# 15                880325.0                    74483.0          22
# 37               3484912.0                    63801.0          63
# 4                 941029.0                    56395.0          18
# 25                754703.0                    26673.0          16
# 12               1229625.0                    23981.0          20
# 18                943011.0                    21901.0          20
# 42               1473149.0                    20390.0          33
# 20               1599012.0                    17672.0          37
# 5                1335971.0                        0.0          27
# 16                542647.0                        0.0          13
# 26                725432.0                        0.0          19
# 27               1660924.0                        0.0          40
# 28                 63515.0                        0.0           1
# 31               2087074.0                        0.0          46
# 41               2023804.0                        0.0          40
# 48               4156076.0                        0.0          79
# 49               2684558.0                        0.0          56
# 53                 20493.0                        0.0           1
#
#                                            uza_name  \
# 17             Los Angeles--Long Beach--Anaheim, CA
# 33                       San Francisco--Oakland, CA
# 32                                    San Diego, CA
# 29                    Riverside--San Bernardino, CA
# 30                                   Sacramento, CA
# 34                                     San Jose, CA
# 10                                       Fresno, CA
# 24           Oxnard--San Buenaventura (Ventura), CA
# 43                                     Stockton, CA
# 3                                   Bakersfield, CA
# 14             Indio--Palm Desert--Palm Springs, CA
# 36                                Santa Barbara, CA
# 22                                      Modesto, CA
# 40                                   Santa Rosa, CA
# 21    Mission Viejo--Lake Forest--Laguna Niguel, CA
# 6                         Concord--Walnut Creek, CA
# 38                                   Santa Cruz, CA
# 13                                        Hemet, CA
# 7                                         Davis, CA
# 52                                    Yuba City, CA
# 35                              San Luis Obispo, CA
# 23                                         Napa, CA
# 9                                     Fairfield, CA
# 8   El Paso de Robles (Paso Robles)--Atascadero, CA
# 50                                  Watsonville, CA
# 2      Arroyo Grande--Grover Beach--Pismo Beach, CA
# 44                                Thousand Oaks, CA
# 11                          Gilroy--Morgan Hill, CA
# 0                                California Non-UZA
# 39                                  Santa Maria, CA
# 19                                      Manteca, CA
# 1                                       Antioch, CA
# 45                                      Turlock, CA
# 47                                      Vallejo, CA
# 51                                     Woodland, CA
# 46                                    Vacaville, CA
# 15                                         Lodi, CA
# 37                                Santa Clarita, CA
# 4                                     Camarillo, CA
# 25                                     Petaluma, CA
# 12                                      Hanford, CA
# 18                                       Madera, CA
# 42                                  Simi Valley, CA
# 20                                       Merced, CA
# 5                                         Chico, CA
# 16                                       Lompoc, CA
# 26                                  Porterville, CA
# 27                                      Redding, CA
# 28                                     Reno, NV--CA
# 31                                      Salinas, CA
# 41             Seaside--Monterey--Pacific Grove, CA
# 48          Victorville--Hesperia--Apple Valley, CA
# 49                                      Visalia, CA
# 53                                     Yuma, AZ--CA
#
#     total_unlinked_passenger_trips  uza_population  current_weekday_trips  \
# 17                       352876967      12237376.0              1352019.0
# 33                       174947309       3515933.0               670296.0
# 32                        63873516       3070300.0               244726.0
# 29                         7649513       2276703.0                29308.0
# 30                        11886782       1946618.0                45543.0
# 34                        22102814       1837446.0                84685.0
# 10                         7205414        717589.0                27607.0
# 24                         2795139        376117.0                10709.0
# 43                         2276298        414847.0                 8721.0
# 3                          3201508        570235.0                12266.0
# 14                         2087445        361075.0                 7998.0
# 36                         4292799        202197.0                16448.0
# 22                         1638903        357301.0                 6279.0
# 40                         1763224        297329.0                 6756.0
# 21                         3027974        646843.0                11601.0
# 6                          7508917        538583.0                28770.0
# 38                         2019665        169038.0                 7738.0
# 13                          466576        173194.0                 1788.0
# 7                          2129760         77034.0                 8160.0
# 52                          438904        125706.0                 1682.0
# 35                          740931         56904.0                 2839.0
# 23                          377272         84619.0                 1445.0
# 9                           371893        150122.0                 1425.0
# 8                           184534         67804.0                  707.0
# 50                         1263457         68668.0                 4841.0
# 2                           247369         50885.0                  948.0
# 44                          209157        213986.0                  801.0
# 11                           76517        114833.0                  293.0
# 0                          7350357             NaN                28162.0
# 39                          506498        143609.0                 1941.0
# 19                          247773         86674.0                  949.0
# 1                          3395022        326205.0                13008.0
# 45                          340324         79203.0                 1304.0
# 47                          582765        175132.0                 2233.0
# 51                          196091         61133.0                  751.0
# 46                          261055        101027.0                 1000.0
# 15                          207778         73090.0                  796.0
# 37                         2065119        278031.0                 7912.0
# 4                           198858         76338.0                  762.0
# 25                          255372         65227.0                  978.0
# 12                          415547         66638.0                 1592.0
# 18                           52164         81635.0                  200.0
# 42                          164630        127364.0                  631.0
# 20                          351235        150052.0                 1346.0
# 5                           485301        111411.0                 1859.0
# 16                          144899         54287.0                  555.0
# 26                          182082         69862.0                  698.0
# 27                          246884        120602.0                  946.0
# 28                         4316186        446529.0                16537.0
# 31                          706072        177532.0                 2705.0
# 41                         1002994        123495.0                 3843.0
# 48                          932423        355816.0                 3573.0
# 49                          572862        160578.0                 2195.0
# 53                         1601570        135717.0                 6136.0
#
#     increase_ratio
# 17       10.569735
# 33        6.508974
# 32       14.110348
# 29       85.988297
# 30       45.858529
# 34       22.338194
# 10       44.229579
# 24       86.874031
# 43       98.936475
# 3        69.407712
# 14      101.114529
# 36       42.307393
# 22      104.816372
# 40       89.952191
# 21       47.198000
# 6        17.125026
# 38       54.712846
# 13      226.643177
# 7        42.812868
# 52      178.812128
# 35      104.147939
# 23      130.806228
# 9       128.282105
# 8       251.049505
# 50       33.989258
# 2       156.049578
# 44      177.751561
# 11      474.566553
# 0         4.571444
# 39       66.224111
# 19      129.942044
# 1         8.951107
# 45       84.536810
# 47       48.336767
# 51      109.145140
# 46       77.033000
# 15       93.571608
# 37        8.063827
# 4        74.009186
# 25       27.273006
# 12       15.063442
# 18      109.505000
# 42       32.313788
# 20       13.129272
# 5         0.000000
# 16        0.000000
# 26        0.000000
# 27        0.000000
# 28        0.000000
# 31        0.000000
# 41        0.000000
# 48        0.000000
# 49        0.000000
# 53        0.000000

# %% [markdown]
# # Statewide

# %%
df.sum()
# Out:
# /tmp/ipykernel_410/1703867807.py:1: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.sum()
# UACE10                                                                      3281692
# new_transit_mi_weekday                                                  352314496.0
# new_transit_trips_weekday                                                40380329.0
# num_tracts                                                                     8339
# uace_cd                                                                     3281692
# uza_name                          Los Angeles--Long Beach--Anaheim, CASan Franci...
# total_unlinked_passenger_trips                                            704442418
# uza_population                                                           34366472.0
# current_weekday_trips                                                     2699011.0
# increase_ratio                                                          3748.628685
# dtype: object

# %%
df.sum()['new_transit_trips_weekday'] / df.sum()['current_weekday_trips']
# Out:
# /tmp/ipykernel_410/3999246341.py:1: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.sum()['new_transit_trips_weekday'] / df.sum()['current_weekday_trips']
# /tmp/ipykernel_410/3999246341.py:1: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.sum()['new_transit_trips_weekday'] / df.sum()['current_weekday_trips']
# 14.961157624033396

# %% [markdown]
# # By MPO

# %%
mpo = gpd.read_file('census_ntd/mpos.geojson')
# trips_by_tract = gpd.read_parquet('outputs/')

# %%
import shared_utils

# %%
mpo = mpo[['MPO', 'LABEL_MPO', 'geometry']]
mpo = mpo.to_crs(shared_utils.geography_utils.CA_NAD83Albers)

# %%
results = results >> select(-_.index_right)

# %%
mpo_joined = gpd.sjoin(results, mpo, how = 'left')

# %%
##  add population, per capita...

df2 = (mpo_joined >> group_by(_.MPO, _.LABEL_MPO)    
    >> summarize(new_transit_mi_weekday = _.new_transit_mi.sum(),
                new_transit_trips_weekday = _.projected_new_transit_trips.sum(),
                 num_tracts = _.shape[0],
                 population = _.total_pop.sum()
                )
      >> mutate(new_trips_per_capita = _.new_transit_trips_weekday / _.population)
      >> mutate(new_transit_mi_pct = _.new_transit_mi_weekday / _.new_transit_mi_weekday.sum())
      ).round(2) >> arrange(-_.new_transit_trips_weekday)

# %%
df2.to_csv('vmt_to_transit_mpo.csv', index = False)

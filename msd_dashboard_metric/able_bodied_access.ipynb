# %%
# import os
# os.environ["CALITP_BQ_MAX_BYTES"] = str(100_000_000_000)

import pandas as pd
import numpy as np
import geopandas as gpd
# import fiona
import datetime as dt

# from utils import *

import calitp
from calitp.tables import tbl
from siuba import *

# %%
static_stops = tbl.gtfs_schedule.stops()

# %%
static_stops
# Out:
# # Source: lazy query
# # DB Conn: Engine(bigquery://cal-itp-data-infra/?maximum_bytes_billed=5000000000)
# # Preview:
#    calitp_itp_id  calitp_url_number stop_id tts_stop_name   stop_lat  \
# 0              0                  0     589          None  34.038779
# 1              0                  0     678          None  34.049582
# 2              0                  0     740          None  34.055213
# 3              0                  0     995          None  34.032064
# 4              0                  0    1553          None  34.045375
#
#      stop_lon zone_id parent_station stop_code                    stop_name  \
# 0 -118.487155    None           None      1254         MONTANA WB & 22ND NS
# 1 -118.485261    None           None      2270  SAN VICENTE EB & BRISTOL NS
# 2 -118.386519    None           None      2305         PICO EB & LIVONIA NS
# 3 -118.494884    None           None      1007         14TH NB & MONTANA NS
# 4 -118.497003    None           None      3000     SAN VICENTE WB & 21ST FS
#
#                                 stop_desc stop_url location_type  \
# 0              2200 MONTANA AVE & 22ND ST     None          None
# 1  12700 SAN VICENTE BLVD & S BRISTOL AVE     None          None
# 2          8900 W PICO BLVD & LIVONIA AVE     None          None
# 3               800 14TH ST & MONTANA AVE     None          None
# 4              SAN VICENTE BLVD & 23RD ST     None          None
#
#   stop_timezone wheelchair_boarding level_id platform_code calitp_extracted_at
# 0          None                   0     None          None          2021-04-27
# 1          None                   0     None          None          2021-04-27
# 2          None                   0     None          None          2021-04-27
# 3          None                   0     None          None          2021-04-27
# 4          None                   0     None          None          2021-04-27
# # .. may have more rows

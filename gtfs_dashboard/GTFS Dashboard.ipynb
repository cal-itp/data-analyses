# %%
import numpy as np
import geopandas as gpd
import os
import pandas as pd

#raise limit
os.environ["CALITP_BQ_MAX_BYTES"] = str(50_000_000_000)

import calitp
from calitp.tables import tbls
from siuba import *
#import shared_utils

pd.set_option("display.max_rows", 10)
# Out:
# /opt/conda/lib/python3.9/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.10.3-CAPI-1.16.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
tbl_daily_feed = tbls.mart_gtfs_guidelines.fact_daily_guideline_checks() >> collect()
tbl_daily_feed.head()
# Out:
#          date  calitp_itp_id  calitp_url_number   calitp_agency_name  \
# 0  2021-04-26              0                  0         Big Blue Bus
# 1  2021-05-04              0                  0         Big Blue Bus
# 2  2021-04-27              0                  0         Big Blue Bus
# 3  2021-05-03              0                  0         Big Blue Bus
# 4  2021-08-13            256                  0  Porterville Transit
#
#                         check status                feature
# 0  Shapes.txt file is present   PASS  Accurate Service Data
# 1  Shapes.txt file is present   PASS  Accurate Service Data
# 2  Shapes.txt file is present   PASS  Accurate Service Data
# 3  Shapes.txt file is present   PASS  Accurate Service Data
# 4  Shapes.txt file is present   PASS  Accurate Service Data

# %%
pd.set_option('display.max_rows', None)
(tbl_daily_feed >> distinct(_.calitp_agency_name)).head()
# Out:
#              calitp_agency_name
# 0                  Big Blue Bus
# 1           Porterville Transit
# 2            Long Beach Transit
# 3  Fairfield and Suisun Transit
# 4              Glendale Beeline

# %%
(tbl_daily_feed >> arrange(_.calitp_agency_name, _.calitp_url_number)).head(50)
# Out:
#            date  calitp_itp_id  calitp_url_number calitp_agency_name  \
# 357  2021-07-22              4                  0         AC Transit
# 366  2022-03-21              4                  0         AC Transit
# 367  2021-08-22              4                  0         AC Transit
# 369  2022-06-24              4                  0         AC Transit
# 370  2021-09-09              4                  0         AC Transit
# 372  2021-09-01              4                  0         AC Transit
# 373  2022-02-12              4                  0         AC Transit
# 374  2022-02-13              4                  0         AC Transit
# 375  2021-10-21              4                  0         AC Transit
# 376  2022-01-21              4                  0         AC Transit
# 379  2022-08-10              4                  0         AC Transit
# 383  2022-11-08              4                  0         AC Transit
# 384  2022-06-01              4                  0         AC Transit
# ...

# %%
(tbl_daily_feed >> filter(_.calitp_itp_id == 200)).head(50)
# Out:
#              date  calitp_itp_id  calitp_url_number calitp_agency_name  \
# 18315  2022-12-02            200                  0            MTC 511
# 18316  2022-04-22            200                  0            MTC 511
# 18317  2022-01-21            200                  0            MTC 511
# 18318  2022-11-04            200                  0            MTC 511
# 18319  2022-04-07            200                  0            MTC 511
# 18320  2022-09-06            200                  0            MTC 511
# 18321  2022-08-24            200                  0            MTC 511
# 18322  2022-02-09            200                  0            MTC 511
# 18323  2022-12-07            200                  0            MTC 511
# 18324  2022-02-24            200                  0            MTC 511
# 18325  2021-12-29            200                  0            MTC 511
# 18326  2022-04-13            200                  0            MTC 511
# ...

# %%
tbl_providers_services = tbls.mart_transit_database.dim_provider_gtfs_data
#tbl_providers_services

# %% [markdown]
# # TIRCP Program Allocation Plan
# ----

# %%
import pandas as pd
import math
from siuba import * 
import numpy as np
pd.options.display.max_columns = 50
pd.options.display.float_format = "{:.2f}".format
import datetime

# %%
GCS_FILE_PATH = "gs://calitp-analytics-data/data-analyses/tircp/"
FILE_NAME1 = "Raw_Project_Tracking_Sheet.xlsx"
project = pd.read_excel(f"{GCS_FILE_PATH}{FILE_NAME1}")
FILE_NAME2 = "Allocation_Agreement.xlsx"
allocation = pd.read_excel(f"{GCS_FILE_PATH}{FILE_NAME2}")

# %%
#cleaning up spaces in columns
project.columns = project.columns.str.strip().str.replace(' ', '_')
allocation.columns = allocation.columns.str.strip().str.replace(' ', '_')

# %%
#strip spaces in columns
project.columns = project.columns.map(lambda x: x.strip())
allocation.columns = allocation.columns.map(lambda x: x.strip())

# %% [markdown]
# ## Keeping only relevant columns.

# %%
#subsetting for only columns of interest
df_project = project[['Award_Year', 'Project_#','Unallocated_Amount','Local_Agency','Project_Title','PPNO',
'TIRCP_Award_Amount_($)',]]

# %%
#subsetting for only columns of interest
df_allocation = allocation[['Award_Year','Award_Recipient', 'Implementing_Agency',
'Components', 'PPNO','Phase','Prior_Fiscal_Years_to_2020',
'Fiscal_Year_2020-2021', 'Fiscal_Year_2021-2022',
'Fiscal_Year_2022-2023', 'Fiscal_Year_2023-2024',
 'Fiscal_Year_2024-2025', 'Fiscal_Year_2025-2026',
'Fiscal_Year_2026-2027', 'Fiscal_Year_2027-2028',
'Fiscal_Year_2028-2029', 'Fiscal_Year_2029-2030','CTC_Financial_Resolution',
'Allocation_Date','Project_ID','SB1_Funding','GGRF_Funding','Allocation_Amount']]

# %% [markdown]
# # Cleaning Allocation Sheet

# %%
#Filtering out for 2021, since that entry is blank
df_allocation = df_allocation.query("Award_Year != 2021")

# %%
#clean up columns in a loop
for i in ["Allocation_Date"]:
    df_allocation[i] = df_allocation[i].replace('/', '-', regex = True).replace('Complete', '', regex = True).replace('\n', '', regex=True).replace('Pending','TBD',regex= True).fillna('TBD')

# %% [markdown]
# ## Clean up Dates

# %%
#changing some of the dates
df_allocation["Allocation_Date"].replace({'October 15, 2018\nSeptember 30, 2021': '2018-10-15 00:00:00',
 '2/1/2021\n\n10/31/2022':'2021-02-01 00:00:00', '45211':'2023-10-22', "FY 26/27": "2026-12-31", "08/12//20": '2020-08-12 00:00:00', 'FY 21/22': '2021-12-31',
'FY 22/23': '2022-12-31','FY 20/21': '2020-12-31', 'FY 23/24': '2023-12-31','FY 24/25': '2024-12-31','FY 25/26': '2025-12-31'}, inplace =True)

# %% [markdown]
# ## Cleaning up PPNO, can only be 5 characters.

# %%
#remove the extra characters in PPNO in allocation to match the PPNO in project data frame bc there should only be five characters and numbers in each PPNO value
df_allocation = df_allocation.assign(
    PPNO_New = df_allocation['PPNO'].str.slice(start=0, stop=5)
)

# %%
#CSV with PPNO & Award Recipients
FILE_NAME2 = "Allocation_PPNO_Crosswalk.csv"
allocation_ppno = pd.read_csv(f"{GCS_FILE_PATH}{FILE_NAME2}")

# %%
allocation_ppno #printing to make sure it makes sense.
# Out:
#    Award_Year PPNO_New2                                    Award_Recipient
# 0        2020     CP065  Los Angeles County Metropolitan Transportation...
# 1        2020     CP066  Los Angeles-San Diego-San Luis Obispo Rail Cor...
# 2        2016      1230  San Bernardino County Transportation Authority...
# 3        2018      1155          Transportation Agency for Monterey County

# %%
#Merge in Crosswalk 
df_allocation = pd.merge(df_allocation, allocation_ppno, on = ["Award_Year", "Award_Recipient"], how = "left")

# %%
#some values in PPNO and PPNO_New2 are strings, some are floats...so have to convert PPNO New 2 to strings
df_allocation.PPNO_New = df_allocation.apply(lambda x: x.PPNO_New if (str(x.PPNO_New2) == 'nan') else x.PPNO_New2, axis=1)

# %%
#drop old column
df_allocation = df_allocation.drop(['PPNO','PPNO_New2'], axis=1)

# %%
## Clean up TIRCP
df_allocation[['SB1_Funding','GGRF_Funding','Allocation_Amount']] = df_allocation[['SB1_Funding','GGRF_Funding','Allocation_Amount']].fillna(value=0)

# %% [markdown]
# # Cleaning Project Sheet

# %%
df_project.head(2)
# Out:
#    Award_Year  Project_#  Unallocated_Amount  \
# 0        2015          1                   0
# 1        2015          2                   0
#
#                                Local_Agency  \
# 0  Antelope Valley Transit Authority (AVTA)
# 1   Capitol Corridor Joint Powers Authority
#
#                                        Project_Title   PPNO  \
# 0  Regional Transit Interconnectivity & Environme...  CP005
# 1                      Travel Time Reduction Project  CP012
#
#    TIRCP_Award_Amount_($)
# 0             24403000.00
# 1              4620000.00

# %% [markdown]
# ## Filling NA for TIRCP and Expended Amounts

# %%
df_project[['TIRCP_Award_Amount_($)', 'Unallocated_Amount']] = df_project[['TIRCP_Award_Amount_($)', 'Unallocated_Amount']].fillna(value=0)
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %% [markdown]
# ## Cleaning up PPNO Numbers based on Allocation Sheet

# %%
#slicing PPNO to be 5 characters
df_project = df_project.assign(PPNO_New = df_project['PPNO'].str.slice(start=0, stop=5))

# %%
#importing Excel crosswalk sheet
FILE_NAME3 = "Projects_PPNO.xlsx"
project_ppno = pd.read_excel(f"{GCS_FILE_PATH}{FILE_NAME3}")

# %%
#Merge in Crosswalk 
df_project2 = pd.merge(df_project, project_ppno, on = ["Award_Year", "Local_Agency"], how = "left")

# %%
#some values in PPNO and PPNO_New2 are strings, some are floats...so have to convert PPNO New 2 to strings
df_project2.PPNO_New = df_project2.apply(lambda x: x.PPNO_New if (str(x.PPNO_New2) == 'nan') else x.PPNO_New2, axis=1)

# %%
#making sure PPNO_New is a string 
df_project2 = df_project2.astype({'PPNO_New': 'str'})

# %%
PPNO_project = set(df_project2.PPNO_New.unique().tolist())
PPNO_allocation = set(df_allocation.PPNO_New.unique().tolist())

# %%
#checking for differences - none. yay. 
PPNO_project - PPNO_allocation
# Out:
# set()

# %%
#drop old column
df_project2 = df_project2.drop(['PPNO', 'PPNO_New2'], axis=1)

# %% [markdown]
# # Merging Project & Allocations
# * Lots of missing values.
# * No difference when I tried to drop values

# %%
#merge on left for projects.
df_combined = df_allocation.merge(df_project2, how = "left", on = ["PPNO_New", "Award_Year"])

# %%
df_combined.shape
# Out:
# (319, 28)

# %%
df_combined.isna().sum()
# Out:
# Award_Year                      0
# Award_Recipient                 0
# Implementing_Agency             0
# Components                      0
# Phase                           1
# Prior_Fiscal_Years_to_2020    187
# Fiscal_Year_2020-2021         243
# Fiscal_Year_2021-2022         261
# Fiscal_Year_2022-2023         289
# Fiscal_Year_2023-2024         301
# Fiscal_Year_2024-2025         304
# Fiscal_Year_2025-2026         311
# Fiscal_Year_2026-2027         313
# Fiscal_Year_2027-2028         315
# Fiscal_Year_2028-2029         319
# Fiscal_Year_2029-2030         319
# CTC_Financial_Resolution      106
# Allocation_Date                 0
# Project_ID                    113
# SB1_Funding                     0
# GGRF_Funding                    0
# Allocation_Amount               0
# PPNO_New                        0
# Project_#                      33
# Unallocated_Amount             33
# Local_Agency                   33
# Project_Title                  33
# TIRCP_Award_Amount_($)         33
# dtype: int64

# %%
df_combined.dtypes
# Out:
# Award_Year                      int64
# Award_Recipient                object
# Implementing_Agency            object
# Components                     object
# Phase                          object
# Prior_Fiscal_Years_to_2020    float64
# Fiscal_Year_2020-2021         float64
# Fiscal_Year_2021-2022         float64
# Fiscal_Year_2022-2023         float64
# Fiscal_Year_2023-2024         float64
# Fiscal_Year_2024-2025         float64
# Fiscal_Year_2025-2026         float64
# Fiscal_Year_2026-2027         float64
# Fiscal_Year_2027-2028         float64
# Fiscal_Year_2028-2029         float64
# Fiscal_Year_2029-2030         float64
# CTC_Financial_Resolution       object
# Allocation_Date                object
# Project_ID                     object
# SB1_Funding                   float64
# GGRF_Funding                  float64
# Allocation_Amount             float64
# PPNO_New                       object
# Project_#                     float64
# Unallocated_Amount            float64
# Local_Agency                   object
# Project_Title                  object
# TIRCP_Award_Amount_($)        float64
# dtype: object

# %% [markdown]
# ### Filing in NA Project ID values & CTC Financial Resolution with TBD. Fill in Allocation Date with something random.

# %%
df_combined[['Project_ID','CTC_Financial_Resolution']] = df_combined[['Project_ID','CTC_Financial_Resolution']].fillna(value = 'TBD')

# %%
missing_date = pd.to_datetime('2100-01-01')
df_combined['Allocation_Date'] = df_combined['Allocation_Date'].fillna(missing_date)

# %% [markdown]
# # Breakout each year in own dataframe
# * Do it in a loop later

# %%
#Loop through the years to create separate data frames for each
Award_Year_List = [2015, 2016, 2018, 2020]

# %%
Award_Year_List
# Out:
# [2015, 2016, 2018, 2020]

# %%
#filtering out for year
df_2015 = df_combined.loc[df_combined['Award_Year'] == 2015]
df_2016 = df_combined.loc[df_combined['Award_Year'] == 2016]
df_2018 = df_combined.loc[df_combined['Award_Year'] == 2018]
df_2020 = df_combined.loc[df_combined['Award_Year'] == 2020]

# %% [markdown]
# # Mimic sheet

# %%
def pivot(df):
    df = df.groupby(['Award_Year','Project_#','TIRCP_Award_Amount_($)','PPNO_New','Award_Recipient','Implementing_Agency',
    'Project_Title', 'Components','Phase','Project_ID','CTC_Financial_Resolution','Allocation_Date']).agg({
    'Prior_Fiscal_Years_to_2020': 'max', 'Fiscal_Year_2020-2021': 'max',
    'Fiscal_Year_2021-2022': 'max', 'Fiscal_Year_2022-2023': 'max',
    'Fiscal_Year_2023-2024': 'max', 'Fiscal_Year_2024-2025': 'max',
    'Fiscal_Year_2025-2026': 'max', 'Fiscal_Year_2026-2027': 'max',
    'Fiscal_Year_2027-2028': 'max', 'Fiscal_Year_2028-2029': 'max',
    'Fiscal_Year_2029-2030': 'max', 'SB1_Funding': 'sum', 'GGRF_Funding':'sum', 'Allocation_Amount':'sum',
    'Unallocated_Amount':'sum'})
    return df

# %%
df_2015 = pivot(df_2015)
df_2016 = pivot(df_2016)
df_2018 = pivot(df_2018)
df_2020 = pivot(df_2020)

# %%
df_2020
# Out:
#                                                                                                                                                                                                                                                                                                                                 Prior_Fiscal_Years_to_2020  \
# Award_Year Project_# TIRCP_Award_Amount_($) PPNO_New Award_Recipient                                    Implementing_Agency                                Project_Title                                      Components                                         Phase Project_ID CTC_Financial_Resolution Allocation_Date
# 2020       1.00      6503000.00             CP059    Antelope Valley Transit Authority                  Antelope Valley Transit Authority                  Reaching the Most Transit-Vulnerable: AVTA's Ze... Network Integration                                CONST 20000277   TIRCP-1819-02            2020-08-12 00:00:00                         NaN
#                                                                                                                                                                                                               Purchase of 11 Zero-Emission Vehicles and Suppo... CONST 20000276   TIRCP-1819-02            2020-08-12 00:00:00                         NaN
#            2.00      107100000.00           CP060    Bay Area Rapid Transit District                    Bay Area Rapid Transit District                    The Transbaby Corridor Core Capacity Program: V... Acquisition of 34 rail vehicles to support serv... CONST TBD        TBD                      TBD                                         NaN
#            3.00      3914000.00             CP061    Capitol Corridor Joint Powers Authority            Capitol Corridor Joint Powers Authority            Sacramento Valley Station (SVS) Transit Center     Network Integration                                CONST 20000279   TIRCP-2021-02            2020-08-12 00:00:00                         NaN
#                                                                                                                                                                                                               New Northside station access                       CONST TBD        TBD                      FY 21-22                                    NaN
#            4.00      95200000.00            CP062    City of Inglewood                                  City of Inglewood                                  Inglewood Transit Connector Project                Automated People Mover                             CONST TBD        TBD                      FY 22-23                                    NaN
#                                                                                                                                                                                                                                                                  PA&ED 20000275   TIRCP-2021-02            2020-08-13 00:00:00                         NaN
#            5.00      12994000.00            CP063    Lake Transit Authority                             Lake Transit Authority                             North State Intercity Bus System                   New transit center, 4 new EV buses, expanded se... PA&ED 21000114   TIRCP-2021-09            FY 20-21                                    NaN
#            6.00      6451000.00             CP064    Long Beach Transit                                 Long Beach Transit                                 LBT/UCLA Electric Commuter Express                 Purchase 5 zero-emission battery electric coaches  CONST 0021000249 TIRCP-2021-25            2021-05-13 00:00:00                         NaN
#            7.00      107050000.00           CP065    Los Angeles County Metropolitan Transportation ... Los Angeles County Metropolitan Transportation ... Metrolink Antelope Valley Line Capital and Serv... Balboa Double Track Extension/Lancaster Termina... CONST TBD        TBD                      FY 25-26                                    NaN
#                                                                                                                                                                                                                                                                  R/W   TBD        TBD                      FY 23-24                                    NaN
#                                                                                                                                                                                                               Canyon Siding Extension/Brighton-McGinley Doubl... CONST TBD        TBD                      FY 25-26                                    NaN
#                                                                                                                                                                                                                                                                  R/W   TBD        TBD                      FY 22-23                                    NaN
#                                                                                                                                                                                                               Zero-Emission Multiple Units (Pilot)               CONST TBD        TBD                      FY 22-23                                    NaN
#            8.00      38743000.00            CP066    Los Angeles-San Diego-San Luis Obispo Rail Corr... Los Angeles-San Diego-San Luis Obispo Rail Corr... Building Up Control: LOSSAN Service Enhancement... Central Coast Layover Facility Expansion           CONST TBD        TBD                      FY 23-24                                    NaN
#                                                                                                                                                                                                                                                                  PS&E  TBD        TBD                      FY 21-22                                    NaN
#                                                                                                                                                                                                               San Diego County Maintenance and Layover Facility  CONST TBD        TBD                      FY 22-23                                    NaN
#                                                                                                                                                                                                                                                                  PA&ED TBD        TBD                      FY 20-21                                    NaN
#                                                                                                                                                                                                                                                                  PS&E  TBD        TBD                      FY 21-22                                    NaN
#            9.00      23600000.00            CP067    Sacramento Regional Transit District               Sacramento Regional Transit District               Light Rail Modernization and Expansion of Low-F... Acquisition of light rail vehicles                 CONST TBD        TIRCP-2122-01            2021-08-19 00:00:00                         NaN
#            10.00     15000000.00            CP068    San Bernardino County Transportation Authority ... San Bernardino County Transportation Authority ... West Valley Connector Bus Rapid Transit Phase 1... Acquisition of zero-emission buses                 CONST TBD        TBD                      FY 21-22                                    NaN
#            11.00     12100000.00            CP069    San Diego Association of Governments (SANDAG)      San Diego Association of Governments (SANDAG)      SDConnect: San Diego Rail Improvement Program      Del Mar Bluffs Stabilization                       CONST TBD        TBD                      FY 21-22                                    NaN
#                                                                                                                                                                                                                                                                  PS&E  20000278   TIRCP-2021-02            2020-08-13 00:00:00                         NaN
#                                                                                                         San Diego Metropolitan Transit System (MTS)        SDConnect: San Diego Rail Improvement Program      El Cajon Third Track                               CONST TBD        TBD                      FY 21-22                                    NaN
#                                                                                                                                                                                                                                                                  PS&E  21000084   TIRCP-2021-04            2020-10-22 00:00:00                         NaN
#            12.00     41668000.00            CP070    San Francisco Municipal Transportation Agency      San Francisco Municipal Transportation Agency      Core Capacity Program                              MUNI Forward J Line                                CONST TBD        TBD                      FY 24-25                                    NaN
#                                                                                                                                                                                                               MUNI Forward M Line                                CONST TBD        TBD                      FY 24-25                                    NaN
#            13.00     1105000.00             CP071    City of Santa Monica                               City of Santa Monica                               For People, Place and Planet: Connecting Inglew... Procurement of 7 zero-emission buses               CONST TBD        TBD                      TBD                                         NaN
#            14.00     10400000.00            CP072    Solano Transportation Authority                    Solano Transportation Authority                    Solano Regional Transit Improvements Phase 2       Access Improvements at Fairfield Transit Center    CONST TBD        TBD                      FY 21-22                                    NaN
#                                                                                                                                                                                                                                                                  PS&E  21000230   TIRCP-2021-25            2021-05-13 00:00:00                         NaN
#                                                                                                                                                                                                               Access Improvements at Fairfield-Vacaville Stat... CONST TBD        TIRCP-2021-25            FY 21-22                                    NaN
#                                                                                                                                                                                                               Access Improvements at Vacaville Transit Center    CONST TBD        TBD                      FY 21-22                                    NaN
#                                                                                                                                                                                                               Network Integration                                CONST 21000087   TIRCP-2021-05            2020-10-22 00:00:00                         NaN
#                                                                                                                                                                                                               Shared Inductive Charging Infrastructure           CONST TBD        TBD                      FY 21-22                                    NaN
#                                                                                                                                                                                                                                                                  PS&E  21000080   TIRCP-2021-05            2020-10-22 00:00:00                         NaN
#            15.00     6000000.00             CP073    Torrance Transit Department                        Torrance Transit Department                        Torrance Transit Bus Service Enhancement Program   Procurement of 7 zero-emission buses               CONST 21000038   TIRCP-2021-04            2020-10-22 00:00:00                         NaN
#            16.00     3112000.00             CP074    Transit Joint Powers Authority for Merced County   Transit Joint Powers Authority for Merced County   Improving Air Quality & Economic Growth with El... Procurement of 3 zero-emission buses               CONST 21000082   TIRCP-2021-06            2020-10-22 00:00:00                         NaN
#            17.00     9060000.00             CP075    San Francisco Bay Area Water Emergency Transpor... San Francisco Bay Area Water Emergency Transpor... Expansion of WETA Ferry Services                   Acquisition of a new all-electric vessels and s... CONST TBD        TBD                      FY 20-21                                    NaN
#
#                                                                                                                                                                                                                                                                                                                                 Fiscal_Year_2020-2021  \
# Award_Year Project_# TIRCP_Award_Amount_($) PPNO_New Award_Recipient                                    Implementing_Agency                                Project_Title                                      Components                                         Phase Project_ID CTC_Financial_Resolution Allocation_Date
# 2020       1.00      6503000.00             CP059    Antelope Valley Transit Authority                  Antelope Valley Transit Authority                  Reaching the Most Transit-Vulnerable: AVTA's Ze... Network Integration                                CONST 20000277   TIRCP-1819-02            2020-08-12 00:00:00              250000.00
#                                                                                                                                                                                                               Purchase of 11 Zero-Emission Vehicles and Suppo... CONST 20000276   TIRCP-1819-02            2020-08-12 00:00:00             6253000.00
#            2.00      107100000.00           CP060    Bay Area Rapid Transit District                    Bay Area Rapid Transit District                    The Transbaby Corridor Core Capacity Program: V... Acquisition of 34 rail vehicles to support serv... CONST TBD        TBD                      TBD                                    NaN
#            3.00      3914000.00             CP061    Capitol Corridor Joint Powers Authority            Capitol Corridor Joint Powers Authority            Sacramento Valley Station (SVS) Transit Center     Network Integration                                CONST 20000279   TIRCP-2021-02            2020-08-12 00:00:00              720000.00
#                                                                                                                                                                                                               New Northside station access                       CONST TBD        TBD                      FY 21-22                               NaN
#            4.00      95200000.00            CP062    City of Inglewood                                  City of Inglewood                                  Inglewood Transit Connector Project                Automated People Mover                             CONST TBD        TBD                      FY 22-23                               NaN
#                                                                                                                                                                                                                                                                  PA&ED 20000275   TIRCP-2021-02            2020-08-13 00:00:00            20000000.00
#            5.00      12994000.00            CP063    Lake Transit Authority                             Lake Transit Authority                             North State Intercity Bus System                   New transit center, 4 new EV buses, expanded se... PA&ED 21000114   TIRCP-2021-09            FY 20-21                         250000.00
#            6.00      6451000.00             CP064    Long Beach Transit                                 Long Beach Transit                                 LBT/UCLA Electric Commuter Express                 Purchase 5 zero-emission battery electric coaches  CONST 0021000249 TIRCP-2021-25            2021-05-13 00:00:00                    NaN
#            7.00      107050000.00           CP065    Los Angeles County Metropolitan Transportation ... Los Angeles County Metropolitan Transportation ... Metrolink Antelope Valley Line Capital and Serv... Balboa Double Track Extension/Lancaster Termina... CONST TBD        TBD                      FY 25-26                               NaN
#                                                                                                                                                                                                                                                                  R/W   TBD        TBD                      FY 23-24                               NaN
#                                                                                                                                                                                                               Canyon Siding Extension/Brighton-McGinley Doubl... CONST TBD        TBD                      FY 25-26                               NaN
#                                                                                                                                                                                                                                                                  R/W   TBD        TBD                      FY 22-23                               NaN
#                                                                                                                                                                                                               Zero-Emission Multiple Units (Pilot)               CONST TBD        TBD                      FY 22-23                               NaN
#            8.00      38743000.00            CP066    Los Angeles-San Diego-San Luis Obispo Rail Corr... Los Angeles-San Diego-San Luis Obispo Rail Corr... Building Up Control: LOSSAN Service Enhancement... Central Coast Layover Facility Expansion           CONST TBD        TBD                      FY 23-24                               NaN
#                                                                                                                                                                                                                                                                  PS&E  TBD        TBD                      FY 21-22                               NaN
#                                                                                                                                                                                                               San Diego County Maintenance and Layover Facility  CONST TBD        TBD                      FY 22-23                               NaN
#                                                                                                                                                                                                                                                                  PA&ED TBD        TBD                      FY 20-21                         748000.00
#                                                                                                                                                                                                                                                                  PS&E  TBD        TBD                      FY 21-22                               NaN
#            9.00      23600000.00            CP067    Sacramento Regional Transit District               Sacramento Regional Transit District               Light Rail Modernization and Expansion of Low-F... Acquisition of light rail vehicles                 CONST TBD        TIRCP-2122-01            2021-08-19 00:00:00                    NaN
#            10.00     15000000.00            CP068    San Bernardino County Transportation Authority ... San Bernardino County Transportation Authority ... West Valley Connector Bus Rapid Transit Phase 1... Acquisition of zero-emission buses                 CONST TBD        TBD                      FY 21-22                               NaN
#            11.00     12100000.00            CP069    San Diego Association of Governments (SANDAG)      San Diego Association of Governments (SANDAG)      SDConnect: San Diego Rail Improvement Program      Del Mar Bluffs Stabilization                       CONST TBD        TBD                      FY 21-22                               NaN
#                                                                                                                                                                                                                                                                  PS&E  20000278   TIRCP-2021-02            2020-08-13 00:00:00             3774000.00
#                                                                                                         San Diego Metropolitan Transit System (MTS)        SDConnect: San Diego Rail Improvement Program      El Cajon Third Track                               CONST TBD        TBD                      FY 21-22                               NaN
#                                                                                                                                                                                                                                                                  PS&E  21000084   TIRCP-2021-04            2020-10-22 00:00:00              720000.00
#            12.00     41668000.00            CP070    San Francisco Municipal Transportation Agency      San Francisco Municipal Transportation Agency      Core Capacity Program                              MUNI Forward J Line                                CONST TBD        TBD                      FY 24-25                               NaN
#                                                                                                                                                                                                               MUNI Forward M Line                                CONST TBD        TBD                      FY 24-25                               NaN
#            13.00     1105000.00             CP071    City of Santa Monica                               City of Santa Monica                               For People, Place and Planet: Connecting Inglew... Procurement of 7 zero-emission buses               CONST TBD        TBD                      TBD                                    NaN
#            14.00     10400000.00            CP072    Solano Transportation Authority                    Solano Transportation Authority                    Solano Regional Transit Improvements Phase 2       Access Improvements at Fairfield Transit Center    CONST TBD        TBD                      FY 21-22                               NaN
#                                                                                                                                                                                                                                                                  PS&E  21000230   TIRCP-2021-25            2021-05-13 00:00:00              400000.00
#                                                                                                                                                                                                               Access Improvements at Fairfield-Vacaville Stat... CONST TBD        TIRCP-2021-25            FY 21-22                               NaN
#                                                                                                                                                                                                               Access Improvements at Vacaville Transit Center    CONST TBD        TBD                      FY 21-22                               NaN
#                                                                                                                                                                                                               Network Integration                                CONST 21000087   TIRCP-2021-05            2020-10-22 00:00:00             1100000.00
#                                                                                                                                                                                                               Shared Inductive Charging Infrastructure           CONST TBD        TBD                      FY 21-22                               NaN
#                                                                                                                                                                                                                                                                  PS&E  21000080   TIRCP-2021-05            2020-10-22 00:00:00             1000000.00
#            15.00     6000000.00             CP073    Torrance Transit Department                        Torrance Transit Department                        Torrance Transit Bus Service Enhancement Program   Procurement of 7 zero-emission buses               CONST 21000038   TIRCP-2021-04            2020-10-22 00:00:00             6000000.00
#            16.00     3112000.00             CP074    Transit Joint Powers Authority for Merced County   Transit Joint Powers Authority for Merced County   Improving Air Quality & Economic Growth with El... Procurement of 3 zero-emission buses               CONST 21000082   TIRCP-2021-06            2020-10-22 00:00:00             3112000.00
#            17.00     9060000.00             CP075    San Francisco Bay Area Water Emergency Transpor... San Francisco Bay Area Water Emergency Transpor... Expansion of WETA Ferry Services                   Acquisition of a new all-electric vessels and s... CONST TBD        TBD                      FY 20-21                              0.00
#
#                                                                                                                                                                                                                                                                                                                                 Fiscal_Year_2021-2022  \
# Award_Year Project_# TIRCP_Award_Amount_($) PPNO_New Award_Recipient                                    Implementing_Agency                                Project_Title                                      Components                                         Phase Project_ID CTC_Financial_Resolution Allocation_Date
# 2020       1.00      6503000.00             CP059    Antelope Valley Transit Authority                  Antelope Valley Transit Authority                  Reaching the Most Transit-Vulnerable: AVTA's Ze... Network Integration                                CONST 20000277   TIRCP-1819-02            2020-08-12 00:00:00                    NaN
#                                                                                                                                                                                                               Purchase of 11 Zero-Emission Vehicles and Suppo... CONST 20000276   TIRCP-1819-02            2020-08-12 00:00:00                    NaN
#            2.00      107100000.00           CP060    Bay Area Rapid Transit District                    Bay Area Rapid Transit District                    The Transbaby Corridor Core Capacity Program: V... Acquisition of 34 rail vehicles to support serv... CONST TBD        TBD                      TBD                            49860000.00
#            3.00      3914000.00             CP061    Capitol Corridor Joint Powers Authority            Capitol Corridor Joint Powers Authority            Sacramento Valley Station (SVS) Transit Center     Network Integration                                CONST 20000279   TIRCP-2021-02            2020-08-12 00:00:00                    NaN
#                                                                                                                                                                                                               New Northside station access                       CONST TBD        TBD                      FY 21-22                        3194000.00
#            4.00      95200000.00            CP062    City of Inglewood                                  City of Inglewood                                  Inglewood Transit Connector Project                Automated People Mover                             CONST TBD        TBD                      FY 22-23                               NaN
#                                                                                                                                                                                                                                                                  PA&ED 20000275   TIRCP-2021-02            2020-08-13 00:00:00                    NaN
#            5.00      12994000.00            CP063    Lake Transit Authority                             Lake Transit Authority                             North State Intercity Bus System                   New transit center, 4 new EV buses, expanded se... PA&ED 21000114   TIRCP-2021-09            FY 20-21                         150000.00
#            6.00      6451000.00             CP064    Long Beach Transit                                 Long Beach Transit                                 LBT/UCLA Electric Commuter Express                 Purchase 5 zero-emission battery electric coaches  CONST 0021000249 TIRCP-2021-25            2021-05-13 00:00:00             6451000.00
#            7.00      107050000.00           CP065    Los Angeles County Metropolitan Transportation ... Los Angeles County Metropolitan Transportation ... Metrolink Antelope Valley Line Capital and Serv... Balboa Double Track Extension/Lancaster Termina... CONST TBD        TBD                      FY 25-26                               NaN
#                                                                                                                                                                                                                                                                  R/W   TBD        TBD                      FY 23-24                               NaN
#                                                                                                                                                                                                               Canyon Siding Extension/Brighton-McGinley Doubl... CONST TBD        TBD                      FY 25-26                               NaN
#                                                                                                                                                                                                                                                                  R/W   TBD        TBD                      FY 22-23                               NaN
#                                                                                                                                                                                                               Zero-Emission Multiple Units (Pilot)               CONST TBD        TBD                      FY 22-23                               NaN
#            8.00      38743000.00            CP066    Los Angeles-San Diego-San Luis Obispo Rail Corr... Los Angeles-San Diego-San Luis Obispo Rail Corr... Building Up Control: LOSSAN Service Enhancement... Central Coast Layover Facility Expansion           CONST TBD        TBD                      FY 23-24                               NaN
#                                                                                                                                                                                                                                                                  PS&E  TBD        TBD                      FY 21-22                        1314000.00
#                                                                                                                                                                                                               San Diego County Maintenance and Layover Facility  CONST TBD        TBD                      FY 22-23                               NaN
#                                                                                                                                                                                                                                                                  PA&ED TBD        TBD                      FY 20-21                               NaN
#                                                                                                                                                                                                                                                                  PS&E  TBD        TBD                      FY 21-22                        1940000.00
#            9.00      23600000.00            CP067    Sacramento Regional Transit District               Sacramento Regional Transit District               Light Rail Modernization and Expansion of Low-F... Acquisition of light rail vehicles                 CONST TBD        TIRCP-2122-01            2021-08-19 00:00:00            23600000.00
#            10.00     15000000.00            CP068    San Bernardino County Transportation Authority ... San Bernardino County Transportation Authority ... West Valley Connector Bus Rapid Transit Phase 1... Acquisition of zero-emission buses                 CONST TBD        TBD                      FY 21-22                       15000000.00
#            11.00     12100000.00            CP069    San Diego Association of Governments (SANDAG)      San Diego Association of Governments (SANDAG)      SDConnect: San Diego Rail Improvement Program      Del Mar Bluffs Stabilization                       CONST TBD        TBD                      FY 21-22                        1126000.00
#                                                                                                                                                                                                                                                                  PS&E  20000278   TIRCP-2021-02            2020-08-13 00:00:00                    NaN
#                                                                                                         San Diego Metropolitan Transit System (MTS)        SDConnect: San Diego Rail Improvement Program      El Cajon Third Track                               CONST TBD        TBD                      FY 21-22                        6480000.00
#                                                                                                                                                                                                                                                                  PS&E  21000084   TIRCP-2021-04            2020-10-22 00:00:00                    NaN
#            12.00     41668000.00            CP070    San Francisco Municipal Transportation Agency      San Francisco Municipal Transportation Agency      Core Capacity Program                              MUNI Forward J Line                                CONST TBD        TBD                      FY 24-25                               NaN
#                                                                                                                                                                                                               MUNI Forward M Line                                CONST TBD        TBD                      FY 24-25                               NaN
#            13.00     1105000.00             CP071    City of Santa Monica                               City of Santa Monica                               For People, Place and Planet: Connecting Inglew... Procurement of 7 zero-emission buses               CONST TBD        TBD                      TBD                             1105000.00
#            14.00     10400000.00            CP072    Solano Transportation Authority                    Solano Transportation Authority                    Solano Regional Transit Improvements Phase 2       Access Improvements at Fairfield Transit Center    CONST TBD        TBD                      FY 21-22                        2250000.00
#                                                                                                                                                                                                                                                                  PS&E  21000230   TIRCP-2021-25            2021-05-13 00:00:00                    NaN
#                                                                                                                                                                                                               Access Improvements at Fairfield-Vacaville Stat... CONST TBD        TIRCP-2021-25            FY 21-22                        2000000.00
#                                                                                                                                                                                                               Access Improvements at Vacaville Transit Center    CONST TBD        TBD                      FY 21-22                        2050000.00
#                                                                                                                                                                                                               Network Integration                                CONST 21000087   TIRCP-2021-05            2020-10-22 00:00:00                    NaN
#                                                                                                                                                                                                               Shared Inductive Charging Infrastructure           CONST TBD        TBD                      FY 21-22                        1700000.00
#                                                                                                                                                                                                                                                                  PS&E  21000080   TIRCP-2021-05            2020-10-22 00:00:00                    NaN
#            15.00     6000000.00             CP073    Torrance Transit Department                        Torrance Transit Department                        Torrance Transit Bus Service Enhancement Program   Procurement of 7 zero-emission buses               CONST 21000038   TIRCP-2021-04            2020-10-22 00:00:00                    NaN
#            16.00     3112000.00             CP074    Transit Joint Powers Authority for Merced County   Transit Joint Powers Authority for Merced County   Improving Air Quality & Economic Growth with El... Procurement of 3 zero-emission buses               CONST 21000082   TIRCP-2021-06            2020-10-22 00:00:00                    NaN
#            17.00     9060000.00             CP075    San Francisco Bay Area Water Emergency Transpor... San Francisco Bay Area Water Emergency Transpor... Expansion of WETA Ferry Services                   Acquisition of a new all-electric vessels and s... CONST TBD        TBD                      FY 20-21                        9060000.00
#
#                                                                                                                                                                                                                                                                                                                                 Fiscal_Year_2022-2023  \
# Award_Year Project_# TIRCP_Award_Amount_($) PPNO_New Award_Recipient                                    Implementing_Agency                                Project_Title                                      Components                                         Phase Project_ID CTC_Financial_Resolution Allocation_Date
# 2020       1.00      6503000.00             CP059    Antelope Valley Transit Authority                  Antelope Valley Transit Authority                  Reaching the Most Transit-Vulnerable: AVTA's Ze... Network Integration                                CONST 20000277   TIRCP-1819-02            2020-08-12 00:00:00                    NaN
#                                                                                                                                                                                                               Purchase of 11 Zero-Emission Vehicles and Suppo... CONST 20000276   TIRCP-1819-02            2020-08-12 00:00:00                    NaN
#            2.00      107100000.00           CP060    Bay Area Rapid Transit District                    Bay Area Rapid Transit District                    The Transbaby Corridor Core Capacity Program: V... Acquisition of 34 rail vehicles to support serv... CONST TBD        TBD                      TBD                            57240000.00
#            3.00      3914000.00             CP061    Capitol Corridor Joint Powers Authority            Capitol Corridor Joint Powers Authority            Sacramento Valley Station (SVS) Transit Center     Network Integration                                CONST 20000279   TIRCP-2021-02            2020-08-12 00:00:00                    NaN
#                                                                                                                                                                                                               New Northside station access                       CONST TBD        TBD                      FY 21-22                               NaN
#            4.00      95200000.00            CP062    City of Inglewood                                  City of Inglewood                                  Inglewood Transit Connector Project                Automated People Mover                             CONST TBD        TBD                      FY 22-23                       19000000.00
#                                                                                                                                                                                                                                                                  PA&ED 20000275   TIRCP-2021-02            2020-08-13 00:00:00                    NaN
#            5.00      12994000.00            CP063    Lake Transit Authority                             Lake Transit Authority                             North State Intercity Bus System                   New transit center, 4 new EV buses, expanded se... PA&ED 21000114   TIRCP-2021-09            FY 20-21                           8034.00
#            6.00      6451000.00             CP064    Long Beach Transit                                 Long Beach Transit                                 LBT/UCLA Electric Commuter Express                 Purchase 5 zero-emission battery electric coaches  CONST 0021000249 TIRCP-2021-25            2021-05-13 00:00:00                    NaN
#            7.00      107050000.00           CP065    Los Angeles County Metropolitan Transportation ... Los Angeles County Metropolitan Transportation ... Metrolink Antelope Valley Line Capital and Serv... Balboa Double Track Extension/Lancaster Termina... CONST TBD        TBD                      FY 25-26                               NaN
#                                                                                                                                                                                                                                                                  R/W   TBD        TBD                      FY 23-24                               NaN
#                                                                                                                                                                                                               Canyon Siding Extension/Brighton-McGinley Doubl... CONST TBD        TBD                      FY 25-26                               NaN
#                                                                                                                                                                                                                                                                  R/W   TBD        TBD                      FY 22-23                        1000000.00
#                                                                                                                                                                                                               Zero-Emission Multiple Units (Pilot)               CONST TBD        TBD                      FY 22-23                       10000000.00
#            8.00      38743000.00            CP066    Los Angeles-San Diego-San Luis Obispo Rail Corr... Los Angeles-San Diego-San Luis Obispo Rail Corr... Building Up Control: LOSSAN Service Enhancement... Central Coast Layover Facility Expansion           CONST TBD        TBD                      FY 23-24                               NaN
#                                                                                                                                                                                                                                                                  PS&E  TBD        TBD                      FY 21-22                               NaN
# ...
#                                                                                                                                                                                                               Network Integration                                CONST 21000087   TIRCP-2021-05            2020-10-22 00:00:00         1100000.00
#                                                                                                                                                                                                               Shared Inductive Charging Infrastructure           CONST TBD        TBD                      FY 21-22                          0.00
#                                                                                                                                                                                                                                                                  PS&E  21000080   TIRCP-2021-05            2020-10-22 00:00:00         1000000.00
#            15.00     6000000.00             CP073    Torrance Transit Department                        Torrance Transit Department                        Torrance Transit Bus Service Enhancement Program   Procurement of 7 zero-emission buses               CONST 21000038   TIRCP-2021-04            2020-10-22 00:00:00         6000000.00
#            16.00     3112000.00             CP074    Transit Joint Powers Authority for Merced County   Transit Joint Powers Authority for Merced County   Improving Air Quality & Economic Growth with El... Procurement of 3 zero-emission buses               CONST 21000082   TIRCP-2021-06            2020-10-22 00:00:00         3112000.00
#            17.00     9060000.00             CP075    San Francisco Bay Area Water Emergency Transpor... San Francisco Bay Area Water Emergency Transpor... Expansion of WETA Ferry Services                   Acquisition of a new all-electric vessels and s... CONST TBD        TBD                      FY 20-21                          0.00
#
#                                                                                                                                                                                                                                                                                                                                 Unallocated_Amount
# Award_Year Project_# TIRCP_Award_Amount_($) PPNO_New Award_Recipient                                    Implementing_Agency                                Project_Title                                      Components                                         Phase Project_ID CTC_Financial_Resolution Allocation_Date
# 2020       1.00      6503000.00             CP059    Antelope Valley Transit Authority                  Antelope Valley Transit Authority                  Reaching the Most Transit-Vulnerable: AVTA's Ze... Network Integration                                CONST 20000277   TIRCP-1819-02            2020-08-12 00:00:00                0.00
#                                                                                                                                                                                                               Purchase of 11 Zero-Emission Vehicles and Suppo... CONST 20000276   TIRCP-1819-02            2020-08-12 00:00:00                0.00
#            2.00      107100000.00           CP060    Bay Area Rapid Transit District                    Bay Area Rapid Transit District                    The Transbaby Corridor Core Capacity Program: V... Acquisition of 34 rail vehicles to support serv... CONST TBD        TBD                      TBD                        107100000.00
#            3.00      3914000.00             CP061    Capitol Corridor Joint Powers Authority            Capitol Corridor Joint Powers Authority            Sacramento Valley Station (SVS) Transit Center     Network Integration                                CONST 20000279   TIRCP-2021-02            2020-08-12 00:00:00          3194000.00
#                                                                                                                                                                                                               New Northside station access                       CONST TBD        TBD                      FY 21-22                     3194000.00
#            4.00      95200000.00            CP062    City of Inglewood                                  City of Inglewood                                  Inglewood Transit Connector Project                Automated People Mover                             CONST TBD        TBD                      FY 22-23                    75200000.00
#                                                                                                                                                                                                                                                                  PA&ED 20000275   TIRCP-2021-02            2020-08-13 00:00:00         75200000.00
#            5.00      12994000.00            CP063    Lake Transit Authority                             Lake Transit Authority                             North State Intercity Bus System                   New transit center, 4 new EV buses, expanded se... PA&ED 21000114   TIRCP-2021-09            FY 20-21                    12744000.00
#            6.00      6451000.00             CP064    Long Beach Transit                                 Long Beach Transit                                 LBT/UCLA Electric Commuter Express                 Purchase 5 zero-emission battery electric coaches  CONST 0021000249 TIRCP-2021-25            2021-05-13 00:00:00                0.00
#            7.00      107050000.00           CP065    Los Angeles County Metropolitan Transportation ... Los Angeles County Metropolitan Transportation ... Metrolink Antelope Valley Line Capital and Serv... Balboa Double Track Extension/Lancaster Termina... CONST TBD        TBD                      FY 25-26                   107050000.00
#                                                                                                                                                                                                                                                                  R/W   TBD        TBD                      FY 23-24                   107050000.00
#                                                                                                                                                                                                               Canyon Siding Extension/Brighton-McGinley Doubl... CONST TBD        TBD                      FY 25-26                   107050000.00
#                                                                                                                                                                                                                                                                  R/W   TBD        TBD                      FY 22-23                   107050000.00
#                                                                                                                                                                                                               Zero-Emission Multiple Units (Pilot)               CONST TBD        TBD                      FY 22-23                   107050000.00
#            8.00      38743000.00            CP066    Los Angeles-San Diego-San Luis Obispo Rail Corr... Los Angeles-San Diego-San Luis Obispo Rail Corr... Building Up Control: LOSSAN Service Enhancement... Central Coast Layover Facility Expansion           CONST TBD        TBD                      FY 23-24                    38743000.00
#                                                                                                                                                                                                                                                                  PS&E  TBD        TBD                      FY 21-22                    38743000.00
#                                                                                                                                                                                                               San Diego County Maintenance and Layover Facility  CONST TBD        TBD                      FY 22-23                    38743000.00
#                                                                                                                                                                                                                                                                  PA&ED TBD        TBD                      FY 20-21                    38743000.00
#                                                                                                                                                                                                                                                                  PS&E  TBD        TBD                      FY 21-22                    38743000.00
#            9.00      23600000.00            CP067    Sacramento Regional Transit District               Sacramento Regional Transit District               Light Rail Modernization and Expansion of Low-F... Acquisition of light rail vehicles                 CONST TBD        TIRCP-2122-01            2021-08-19 00:00:00                0.00
#            10.00     15000000.00            CP068    San Bernardino County Transportation Authority ... San Bernardino County Transportation Authority ... West Valley Connector Bus Rapid Transit Phase 1... Acquisition of zero-emission buses                 CONST TBD        TBD                      FY 21-22                    15000000.00
#            11.00     12100000.00            CP069    San Diego Association of Governments (SANDAG)      San Diego Association of Governments (SANDAG)      SDConnect: San Diego Rail Improvement Program      Del Mar Bluffs Stabilization                       CONST TBD        TBD                      FY 21-22                     7606000.00
#                                                                                                                                                                                                                                                                  PS&E  20000278   TIRCP-2021-02            2020-08-13 00:00:00          7606000.00
#                                                                                                         San Diego Metropolitan Transit System (MTS)        SDConnect: San Diego Rail Improvement Program      El Cajon Third Track                               CONST TBD        TBD                      FY 21-22                     7606000.00
#                                                                                                                                                                                                                                                                  PS&E  21000084   TIRCP-2021-04            2020-10-22 00:00:00          7606000.00
#            12.00     41668000.00            CP070    San Francisco Municipal Transportation Agency      San Francisco Municipal Transportation Agency      Core Capacity Program                              MUNI Forward J Line                                CONST TBD        TBD                      FY 24-25                    41668000.00
#                                                                                                                                                                                                               MUNI Forward M Line                                CONST TBD        TBD                      FY 24-25                    41668000.00
#            13.00     1105000.00             CP071    City of Santa Monica                               City of Santa Monica                               For People, Place and Planet: Connecting Inglew... Procurement of 7 zero-emission buses               CONST TBD        TBD                      TBD                          1105000.00
#            14.00     10400000.00            CP072    Solano Transportation Authority                    Solano Transportation Authority                    Solano Regional Transit Improvements Phase 2       Access Improvements at Fairfield Transit Center    CONST TBD        TBD                      FY 21-22                     7500000.00
#                                                                                                                                                                                                                                                                  PS&E  21000230   TIRCP-2021-25            2021-05-13 00:00:00          7500000.00
#                                                                                                                                                                                                               Access Improvements at Fairfield-Vacaville Stat... CONST TBD        TIRCP-2021-25            FY 21-22                     7500000.00
#                                                                                                                                                                                                               Access Improvements at Vacaville Transit Center    CONST TBD        TBD                      FY 21-22                     7500000.00
#                                                                                                                                                                                                               Network Integration                                CONST 21000087   TIRCP-2021-05            2020-10-22 00:00:00          7500000.00
#                                                                                                                                                                                                               Shared Inductive Charging Infrastructure           CONST TBD        TBD                      FY 21-22                     7500000.00
#                                                                                                                                                                                                                                                                  PS&E  21000080   TIRCP-2021-05            2020-10-22 00:00:00          7500000.00
#            15.00     6000000.00             CP073    Torrance Transit Department                        Torrance Transit Department                        Torrance Transit Bus Service Enhancement Program   Procurement of 7 zero-emission buses               CONST 21000038   TIRCP-2021-04            2020-10-22 00:00:00                0.00
#            16.00     3112000.00             CP074    Transit Joint Powers Authority for Merced County   Transit Joint Powers Authority for Merced County   Improving Air Quality & Economic Growth with El... Procurement of 3 zero-emission buses               CONST 21000082   TIRCP-2021-06            2020-10-22 00:00:00                0.00
#            17.00     9060000.00             CP075    San Francisco Bay Area Water Emergency Transpor... San Francisco Bay Area Water Emergency Transpor... Expansion of WETA Ferry Services                   Acquisition of a new all-electric vessels and s... CONST TBD        TBD                      FY 20-21                     9060000.00

# %% [markdown]
# # Export into Excel

# %%
with pd.ExcelWriter("gs://calitp-analytics-data/data-analyses/tircp/TIRCP_PAP_2022.xlsx") as writer:
    df_2015.to_excel(writer, sheet_name="2015 Cycle 1", index=True)
    df_2016.to_excel(writer, sheet_name="2015 Cycle 2", index=True)
    df_2018.to_excel(writer, sheet_name="2018 Cycle 3", index=True)
    df_2020.to_excel(writer, sheet_name="2020 Cycle 4", index=True)

# %% [markdown]
# # Add DLA to TIRCP and Blackcat Organizations

# %%
import pandas as pd
from siuba import *
import numpy as np
from calitp_data_analysis.sql import *

# %% [markdown]
# ## Read in Data & rename cols for easier merge

# %%
dla = pd.read_excel('gs://calitp-analytics-data/data-analyses/dla/e-76Obligated/locodes_updated7122021.xlsx')

# %%
dla = to_snakecase(dla)

# %%
dt = pd.read_parquet('gs://calitp-analytics-data/data-analyses/grants/BlackCat_TIRCP_Dec_2022.parquet')

# %%
dla = dla>>select(_.agency_locode, _.agency_name, _.district)

# %%
## changing string format to match dt
dla['agency_name'] = dla['agency_name'].str.title()

# %%
dla>>filter(_.agency_name.str.contains('Alameda'))
# Out:
#      agency_locode                                        agency_name  \
# 196           6002            Alameda - Contra Costa Transit District
# 197           5014                                            Alameda
# 198           5933                                     Alameda County
# 199           6068            Alameda County Transportation Authority
# 221           6380              Alameda County Social Services Agency
# 228           6430  Alameda County Transportation Improvement Auth...
# 238           6480           Alameda County Transportation Commission
# 239           6481          Alameda County Waste Management Authority
# 329           6273        Alameda County Congestion Management Agency
# 330           6017                    Alameda County Transit District
# 704           6246          Alameda Corridor Transportation Authority
#
#      district
# 196         4
# 197         4
# 198         4
# 199         4
# 221         4
# 228         4
# 238         4
# 239         4
# 329         4
# 330         4
# 704         7

# %%
dla['agency_name'] = dla['agency_name'].str.replace( "- ", "" )

# %%
dla['agency_name'] = dla['agency_name'].str.replace( " -", " " )

# %%
dla['agency_name'] = dla['agency_name'].str.replace( "-", " " )

# %%
dla = dla.rename(columns={"agency_locode":"locode","agency_name":"name", "district":"caltrans_district"})

# %%
## look at DT

# %%
dt>>filter(_.BC_TIRCP_merge =='Found in both TIRCP and BlackCat')
# Out:
#                                        BlackCat_Orgs  \
# 2                 Fresno County Rural Transit Agency
# 8              San Diego Metropolitan Transit System
# 9                         Humboldt Transit Authority
# 28                                     City Of Wasco
# 45                            Lake Transit Authority
# 47         Livermore Amador Valley Transit Authority
# 60             San Joaquin Regional Transit District
# 62                 San Mateo County Transit District
# 63       Santa Clara Valley Transportation Authority
# 71   Transit Joint Powers Authority Of Merced County
# 167    San Francisco Municipal Transportation Agency
# 169                  Solano Transportation Authority
# 188            Contra Costa Transportation Authority
# 208            Tulare County Regional Transit Agency
# 209            Tulare County Regional Transit Agency
#
#                                           TIRCP_Orgs  \
# 2                 Fresno County Rural Transit Agency
# 8              San Diego Metropolitan Transit System
# 9                         Humboldt Transit Authority
# 28                                     City Of Wasco
# 45                            Lake Transit Authority
# 47         Livermore Amador Valley Transit Authority
# 60             San Joaquin Regional Transit District
# 62                 San Mateo County Transit District
# 63       Santa Clara Valley Transportation Authority
# 71   Transit Joint Powers Authority Of Merced County
# 167    San Francisco Municipal Transportation Agency
# 169                  Solano Transportation Authority
# 188            Contra Costa Transportation Authority
# 208            Tulare County Regional Transit Agency
# 209            Tulare County Regional Transit Agency
#
#                        BC_TIRCP_merge  calitp_itp_id  \
# 2    Found in both TIRCP and BlackCat          117.0
# 8    Found in both TIRCP and BlackCat          278.0
# 9    Found in both TIRCP and BlackCat          135.0
# 28   Found in both TIRCP and BlackCat            NaN
# 45   Found in both TIRCP and BlackCat          159.0
# 47   Found in both TIRCP and BlackCat            NaN
# 60   Found in both TIRCP and BlackCat          284.0
# 62   Found in both TIRCP and BlackCat            NaN
# 63   Found in both TIRCP and BlackCat          294.0
# 71   Found in both TIRCP and BlackCat            NaN
# 167  Found in both TIRCP and BlackCat            NaN
# 169  Found in both TIRCP and BlackCat            NaN
# 188  Found in both TIRCP and BlackCat            NaN
# 208  Found in both TIRCP and BlackCat          346.0
# 209  Found in both TIRCP and BlackCat          474.0
#
#                     caltrans_district
# 2                         06 - Fresno
# 8                      11 - San Diego
# 9                         01 - Eureka
# 28   District 6: Fresno / Bakersfield
# 45                        01 - Eureka
# 47     District 4: Bay Area / Oakland
# 60                      10 - Stockton
# 62     District 4: Bay Area / Oakland
# 63                       04 - Oakland
# 71              District 10: Stockton
# 167    District 4: Bay Area / Oakland
# 169    District 4: Bay Area / Oakland
# 188    District 4: Bay Area / Oakland
# 208                       06 - Fresno
# 209                       06 - Fresno

# %% [markdown]
# ## Create new col for Blackcat and TIRCP org names

# %%
dt['name']= np.NaN

# %%
dt.name.fillna(dt['BlackCat_Orgs'], inplace=True)
dt.name.fillna(dt['TIRCP_Orgs'], inplace=True)

# %%
##filter down cols

# %%
dt2 = dt>>select(_.name, _.BC_TIRCP_merge, _.caltrans_district)

# %%
dt2.sample()
# Out:
#                                            name  BC_TIRCP_merge  \
# 35  County Of Shasta Department Of Public Works  Black Cat Only
#
#    caltrans_district
# 35              None

# %% [markdown]
# ## First Merge

# %%
merge = pd.merge(dla, dt2, on="name", how="outer", indicator=True)

# %%
merge
# Out:
#       locode                                               name  \
# 0     6302.0  Humboldt Bay Harbor Recreation & Conservation ...
# 1     6330.0           Willow Creek Community Services District
# 2     5036.0                                           Trinidad
# 3     5049.0                                              Ukiah
# 4     5082.0                                            Willits
# ...      ...                                                ...
# 1230     NaN  San Francisco Bay Area Water Emergency Transpo...
# 1231     NaN                                  City Of Cupertino
# 1232     NaN                                   City Of Glendale
# 1233     NaN                                    City Of Oakland
# 1234     NaN                                   City Of Torrance
#
#       caltrans_district_x BC_TIRCP_merge             caltrans_district_y  \
# 0                     1.0            NaN                             NaN
# 1                     1.0            NaN                             NaN
# 2                     1.0            NaN                             NaN
# 3                     1.0            NaN                             NaN
# 4                     1.0            NaN                             NaN
# ...                   ...            ...                             ...
# 1230                  NaN     TIRCP Only  District 4: Bay Area / Oakland
# 1231                  NaN     TIRCP Only  District 4: Bay Area / Oakland
# 1232                  NaN     TIRCP Only         District 7: Los Angeles
# 1233                  NaN     TIRCP Only  District 4: Bay Area / Oakland
# 1234                  NaN     TIRCP Only         District 7: Los Angeles
#
#           _merge
# 0      left_only
# 1      left_only
# 2      left_only
# 3      left_only
# 4      left_only
# ...          ...
# 1230  right_only
# 1231  right_only
# 1232  right_only
# 1233  right_only
# 1234  right_only
#
# [1235 rows x 6 columns]

# %%
merge._merge.value_counts()
# Out:
# left_only     988
# right_only    194
# both           53
# Name: _merge, dtype: int64

# %%
merge>>filter(_._merge=='both')
# Out:
#      locode                                              name  \
# 11   6241.0                       Mendocino Transit Authority
# 42   6428.0                   Redwood Coast Transit Authority
# 43   6436.0                            Lake Transit Authority
# 48   6162.0                        Humboldt Transit Authority
# 73   6147.0           Plumas County Transportation Commission
# 84   6427.0                     Lassen Transit Service Agency
# 90   6496.0             Shasta Regional Transportation Agency
# 112  6225.0                El Dorado County Transit Authority
# 125  6478.0                     Tahoe Transportation District
# 149  6195.0               Yolo County Transportation District
# 165  6150.0           Sierra County Transportation Commission
# 177  6005.0              Sacramento Regional Transit District
# 195  6132.0            Glenn County Transportation Commission
# 205  6002.0             Alameda Contra Costa Transit District
# 250  6084.0            Metropolitan Transportation Commission
# 254  6072.0             Contra Costa Transportation Authority
# 255  6497.0                             Solano County Transit
# 257  6510.0              Napa Valley Transportation Authority
# 298  6193.0         Livermore Amador Valley Transit Authority
# 325  6331.0                             Sonoma County Transit
# 329  6343.0                     Marin County Transit District
# 331  6364.0            Sonoma County Transportation Authority
# 335  6264.0       Santa Clara Valley Transportation Authority
# 347  6249.0                   Solano Transportation Authority
# 362  6014.0                 San Mateo County Transit District
# 402  6442.0  San Benito County Local Transportation Authority
# 406  6090.0   Santa Barbara County Association Of Governments
# 421  6143.0         Transportation Agency For Monterey County
# 423  6007.0       Santa Barbara Metropolitan Transit District
# 433  6004.0          Santa Cruz Metropolitan Transit District
# 439  6096.0            San Luis Obispo Council Of Governments
# 495  6504.0                     Fresno Council Of Governments
# 512  6285.0                             Kern Regional Transit
# 537  5941.0                                     Madera County
# 551  6198.0           Kings County Area Public Transit Agency
# 554  6194.0                Fresno County Rural Transit Agency
# 580  6155.0          Ventura County Transportation Commission
# 682  6166.0                 Antelope Valley Transit Authority
# 739  6261.0                   Victor Valley Transit Authority
# 743  6292.0          Mountain Area Regional Transit Authority
# 750  6507.0    San Bernardino County Transportation Authority
# 751  6165.0                          Riverside Transit Agency
# 757  6391.0                  Palo Verde Valley Transit Agency
# 784  6235.0                   Morongo Basin Transit Authority
# 788  6046.0                                         Omnitrans
# 871  6262.0              San Joaquin Regional Rail Commission
# 875  6245.0             San Joaquin Regional Transit District
# 878  7503.0             San Diego Metropolitan Transit System
# 889  6376.0                     North County Transit District
# 897  6471.0         Imperial County Transportation Commission
# 921  6066.0              San Diego Association Of Governments
# 962  6071.0            Orange County Transportation Authority
# 986  6052.0                            Sunline Transit Agency
#
#      caltrans_district_x                    BC_TIRCP_merge  \
# 11                   1.0                    Black Cat Only
# 42                   1.0                    Black Cat Only
# 43                   1.0  Found in both TIRCP and BlackCat
# 48                   1.0  Found in both TIRCP and BlackCat
# 73                   2.0                    Black Cat Only
# 84                   2.0                    Black Cat Only
# 90                   2.0                        TIRCP Only
# 112                  3.0                    Black Cat Only
# 125                  3.0                    Black Cat Only
# 149                  3.0                    Black Cat Only
# 165                  3.0                    Black Cat Only
# 177                  3.0                        TIRCP Only
# 195                  3.0                    Black Cat Only
# 205                  4.0                        TIRCP Only
# 250                  4.0                    Black Cat Only
# 254                  4.0  Found in both TIRCP and BlackCat
# 255                  4.0                    Black Cat Only
# 257                  4.0                    Black Cat Only
# 298                  4.0  Found in both TIRCP and BlackCat
# 325                  4.0                    Black Cat Only
# 329                  4.0                    Black Cat Only
# 331                  4.0                        TIRCP Only
# 335                  4.0  Found in both TIRCP and BlackCat
# 347                  4.0  Found in both TIRCP and BlackCat
# 362                  4.0  Found in both TIRCP and BlackCat
# 402                  5.0                    Black Cat Only
# 406                  5.0                        TIRCP Only
# 421                  5.0                        TIRCP Only
# 423                  5.0                        TIRCP Only
# 433                  5.0                    Black Cat Only
# 439                  5.0                    Black Cat Only
# 495                  6.0                    Black Cat Only
# 512                  6.0                    Black Cat Only
# 537                  6.0                    Black Cat Only
# 551                  6.0                    Black Cat Only
# 554                  6.0  Found in both TIRCP and BlackCat
# 580                  7.0                    Black Cat Only
# 682                  7.0                        TIRCP Only
# 739                  8.0                    Black Cat Only
# 743                  8.0                    Black Cat Only
# 750                  8.0                        TIRCP Only
# 751                  8.0                    Black Cat Only
# 757                  8.0                    Black Cat Only
# 784                  8.0                    Black Cat Only
# 788                  8.0                    Black Cat Only
# 871                 10.0                        TIRCP Only
# 875                 10.0  Found in both TIRCP and BlackCat
# 878                 11.0  Found in both TIRCP and BlackCat
# 889                 11.0                    Black Cat Only
# 897                 11.0                    Black Cat Only
# 921                 11.0                        TIRCP Only
# 962                 12.0                        TIRCP Only
# 986                 53.0                    Black Cat Only
#
#                              caltrans_district_y _merge
# 11                                   01 - Eureka   both
# 42                                          None   both
# 43                                   01 - Eureka   both
# 48                                   01 - Eureka   both
# 73                                          None   both
# 84                                  02 - Redding   both
# 90                            District 2:Redding   both
# 112                                         None   both
# 125                                         None   both
# 149                              03 - Marysville   both
# 165                                         None   both
# 177          District 3: Marysville / Sacramento   both
# 195                              03 - Marysville   both
# 205               District 4: Bay Area / Oakland   both
# 250                                         None   both
# 254               District 4: Bay Area / Oakland   both
# 255                                         None   both
# 257                                         None   both
# 298               District 4: Bay Area / Oakland   both
# 325                                 04 - Oakland   both
# 329                                         None   both
# 331               District 4: Bay Area / Oakland   both
# 335                                 04 - Oakland   both
# 347               District 4: Bay Area / Oakland   both
# 362               District 4: Bay Area / Oakland   both
# 402                                         None   both
# 406  District 5: San Luis Obispo / Santa Barbara   both
# 421                                      Various   both
# 423  District 5: San Luis Obispo / Santa Barbara   both
# 433                         05 - San Luis Obispo   both
# 439                                         None   both
# 495                                         None   both
# 512                                         None   both
# 537                                         None   both
# 551                                         None   both
# 554                                  06 - Fresno   both
# 580                             07 - Los Angeles   both
# 682                      District 7: Los Angeles   both
# 739                          08 - San Bernardino   both
# 743                                         None   both
# 750       District 8: San Bernardino / Riverside   both
# 751                          08 - San Bernardino   both
# 757                                         None   both
# 784                          08 - San Bernardino   both
# 788                          08 - San Bernardino   both
# 871                        District 10: Stockton   both
# 875                                10 - Stockton   both
# 878                               11 - San Diego   both
# 889                               11 - San Diego   both
# 897                                         None   both
# 921                       District 11: San Diego   both
# 962                   District 12: Orange County   both
# 986                          08 - San Bernardino   both

# %%
(merge>>filter(_._merge=='both')).BC_TIRCP_merge.value_counts()
# Out:
# Black Cat Only                      31
# TIRCP Only                          12
# Found in both TIRCP and BlackCat    10
# Name: BC_TIRCP_merge, dtype: int64

# %%
(merge>>filter(_._merge=='right_only')).BC_TIRCP_merge.value_counts()
# Out:
# Black Cat Only                      166
# TIRCP Only                           23
# Found in both TIRCP and BlackCat      5
# Name: BC_TIRCP_merge, dtype: int64

# %%
(merge>>filter(_._merge=='both')).BC_TIRCP_merge.value_counts()
# Out:
# Black Cat Only                      31
# TIRCP Only                          12
# Found in both TIRCP and BlackCat    10
# Name: BC_TIRCP_merge, dtype: int64

# %%
(merge>>filter(_._merge!='both')).sample(5)
# Out:
#      locode                                  name  caltrans_district_x  \
# 476  6189.0    Desert Tortoise Preserve Committee                  6.0
# 756  5384.0                    Desert Hot Springs                  8.0
# 624  5283.0                      Palos Verdes Est                  7.0
# 993  6383.0  Council For Tribal Employment Rights                 53.0
# 13   6140.0      Mendocino Council Of Governments                  1.0
#
#     BC_TIRCP_merge caltrans_district_y     _merge
# 476            NaN                 NaN  left_only
# 756            NaN                 NaN  left_only
# 624            NaN                 NaN  left_only
# 993            NaN                 NaN  left_only
# 13             NaN                 NaN  left_only

# %%
match = merge[(merge['_merge'] == 'both')]

# %%
nomatch = merge[(merge['_merge'] == 'right_only')]

# %%
nomatch_total = merge[(merge['_merge'] != 'both')]

# %% [markdown]
# ## Second Merge with other versions of same name
# * we have cities that have names entered as "City of X" and "X"

# %%
dla2 = pd.read_excel('gs://calitp-analytics-data/data-analyses/dla/lst_Agencies_20211208.xlsx')

# %%
dla2 = dla2>>select(_.AgencyID,
                    #_.Agency, 
                    _.Agency2, _.CT_Districts)

# %%
dla2= dla2.rename(columns={"AgencyID":"locode",
    "CT_Districts":"caltrans_district"})

# %%
dla2['Agency2'] = dla2['Agency2'].str.title()
#dla2['Agency'] = dla2['Agency'].str.title()

# %%
dla2.sample()
# Out:
#    locode Agency2 caltrans_district
# 24    115     NaN               NaN

# %%
#using nomatches from leftover first merge

# %%
nomatch = nomatch>>select(_.name, _.BC_TIRCP_merge, _.caltrans_district_y)

# %%
nomatch.sample()
# Out:
#                    name  BC_TIRCP_merge caltrans_district_y
# 1056  City Of Mcfarland  Black Cat Only                None

# %%
#merge2_1 = pd.merge(dla2, nomatch, left_on='Agency', right_on="name", how="outer", indicator='second_merge')

# %%
#merge2_1.second_merge.value_counts()

# %%
#merge2_1>>filter(_.second_merge=='both')

# %%
merge2_2 = pd.merge(dla2, nomatch, left_on='Agency2', right_on="name", how="outer", indicator='second_merge')

# %%
merge2_2.second_merge.value_counts()
# Out:
# left_only     930
# right_only    147
# both           47
# Name: second_merge, dtype: int64

# %%
merge2_match = merge2_2>>filter(_.second_merge=='both')

# %%
#merge2_match = pd.concat([merge2_match, (merge2_1>>filter(_.second_merge=='both'))])

# %%
merge2_match>>arrange(_.Agency2)
# Out:
#     locode                                            Agency2  \
# 976   M016                     Anaheim Transportation Network
# 327    998            Capitol Corridor Joint Powers Authority
# 15    5021                                     City Of Arcata
# 654   5370                                      City Of Arvin
# 380   5077                                     City Of Auburn
# 846   5399                            City Of California City
# 644   5258                                 City Of Chowchilla
# 505   5318                                  City Of Cupertino
# 627   5143                                     City Of Dinuba
# 455   5056                                      City Of Dixon
# 879   5337                                    City Of Escalon
# 474   5132                                  City Of Fairfield
# 802   5307                                    City Of Fontana
# 620   5060                                     City Of Fresno
# 687   5144                                   City Of Glendale
# 586   5292                                  City Of Guadalupe
# 693   5164                                  City Of Inglewood
# 669   5006                                City Of Los Angeles
# 652   5343                                  City Of Mcfarland
# 796   5220                                    City Of Needles
# 436   5012                                    City Of Oakland
# 710   5251                                       City Of Ojai
# 626   5122                                City Of Porterville
# 845   5385                                 City Of Ridgecrest
# 461   5099                                  City Of Rio Vista
# 389   5182                                  City Of Roseville
# 580   5138                                City Of Santa Maria
# 677   5107                               City Of Santa Monica
# 442   5028                                 City Of Santa Rosa
# 645   5281                                    City Of Shafter
# 599   5443                                    City Of Solvang
# 633   5193                                       City Of Taft
# 844   5184                                  City Of Tehachapi
# 708   5249                                   City Of Torrance
# 619   5044                                    City Of Visalia
# 923   5382                                      City Of Vista
# 648   5287                                      City Of Wasco
# 646   5284                                   City Of Woodlake
# 326    725                   Eastern Sierra Transit Authority
# 609   6011                           Monterey-Salinas Transit
# 552   6170              Peninsula Corridor Joint Powers Board
# 561   6365  San Francisco Bay Area Water Emergency Transpo...
# 547   6016      San Francisco Municipal Transportation Agency
# 931   6296                 San Joaquin Joint Powers Authority
# 402   5473                                    Town Of Truckee
# 900   6308    Transit Joint Powers Authority Of Merced County
# 933   6305       Yosemite Area Regional Transportation System
#
#     caltrans_district                                               name  \
# 976                12                     Anaheim Transportation Network
# 327            03, 04            Capitol Corridor Joint Powers Authority
# 15                  1                                     City Of Arcata
# 654                 6                                      City Of Arvin
# 380                 3                                     City Of Auburn
# 846                 9                            City Of California City
# 644                 6                                 City Of Chowchilla
# 505                 4                                  City Of Cupertino
# 627                 6                                     City Of Dinuba
# 455                 4                                      City Of Dixon
# 879                10                                    City Of Escalon
# 474                 4                                  City Of Fairfield
# 802                 8                                    City Of Fontana
# 620                 6                                     City Of Fresno
# 687                 7                                   City Of Glendale
# 586                 5                                  City Of Guadalupe
# 693                 7                                  City Of Inglewood
# 669                 7                                City Of Los Angeles
# 652                 6                                  City Of Mcfarland
# 796                 8                                    City Of Needles
# 436                 4                                    City Of Oakland
# 710                 7                                       City Of Ojai
# 626                 6                                City Of Porterville
# 845                 9                                 City Of Ridgecrest
# 461                 4                                  City Of Rio Vista
# 389                 3                                  City Of Roseville
# 580                 5                                City Of Santa Maria
# 677                 7                               City Of Santa Monica
# 442                 4                                 City Of Santa Rosa
# 645                 6                                    City Of Shafter
# 599                 5                                    City Of Solvang
# 633                 6                                       City Of Taft
# 844                 9                                  City Of Tehachapi
# 708                 7                                   City Of Torrance
# 619                 6                                    City Of Visalia
# 923                11                                      City Of Vista
# 648                 6                                      City Of Wasco
# 646                 6                                   City Of Woodlake
# 326            07, 09                   Eastern Sierra Transit Authority
# 609                 5                           Monterey-Salinas Transit
# 552                 4              Peninsula Corridor Joint Powers Board
# 561                 4  San Francisco Bay Area Water Emergency Transpo...
# 547                 4      San Francisco Municipal Transportation Agency
# 931    03, 04, 06, 10                 San Joaquin Joint Powers Authority
# 402                 3                                    Town Of Truckee
# 900                10    Transit Joint Powers Authority Of Merced County
# 933        06, 09, 10       Yosemite Area Regional Transportation System
#
#                        BC_TIRCP_merge               caltrans_district_y  \
# 976                        TIRCP Only        District 12: Orange County
# 327                        TIRCP Only    District 4: Bay Area / Oakland
# 15                     Black Cat Only                              None
# 654                    Black Cat Only                              None
# 380                    Black Cat Only                              None
# 846                    Black Cat Only                              None
# 644                    Black Cat Only                              None
# 505                        TIRCP Only    District 4: Bay Area / Oakland
# 627                    Black Cat Only                              None
# 455                    Black Cat Only                              None
# 879                    Black Cat Only                              None
# 474                    Black Cat Only                              None
# 802                    Black Cat Only                              None
# 620                        TIRCP Only  District 6: Fresno / Bakersfield
# 687                        TIRCP Only           District 7: Los Angeles
# 586                    Black Cat Only                              None
# 693                        TIRCP Only           District 7: Los Angeles
# 669                        TIRCP Only           District 7: Los Angeles
# 652                    Black Cat Only                              None
# 796                    Black Cat Only                              None
# 436                        TIRCP Only    District 4: Bay Area / Oakland
# 710                    Black Cat Only                              None
# 626                    Black Cat Only                              None
# 845                    Black Cat Only                              None
# 461                    Black Cat Only                              None
# 389                    Black Cat Only                              None
# 580                    Black Cat Only                              None
# 677                        TIRCP Only           District 7: Los Angeles
# 442                    Black Cat Only                      04 - Oakland
# 645                    Black Cat Only                              None
# 599                    Black Cat Only                              None
# 633                    Black Cat Only                              None
# 844                    Black Cat Only                              None
# 708                        TIRCP Only           District 7: Los Angeles
# 619                    Black Cat Only                              None
# 923                    Black Cat Only                              None
# 648  Found in both TIRCP and BlackCat  District 6: Fresno / Bakersfield
# 646                    Black Cat Only                              None
# 326                    Black Cat Only                       09 - Bishop
# 609                    Black Cat Only              05 - San Luis Obispo
# 552                        TIRCP Only    District 4: Bay Area / Oakland
# 561                        TIRCP Only    District 4: Bay Area / Oakland
# 547  Found in both TIRCP and BlackCat    District 4: Bay Area / Oakland
# 931                        TIRCP Only                           Various
# 402                    Black Cat Only                              None
# 900  Found in both TIRCP and BlackCat             District 10: Stockton
# 933                    Black Cat Only                     10 - Stockton
#
#     second_merge
# 976         both
# 327         both
# 15          both
# 654         both
# 380         both
# 846         both
# 644         both
# 505         both
# 627         both
# 455         both
# 879         both
# 474         both
# 802         both
# 620         both
# 687         both
# 586         both
# 693         both
# 669         both
# 652         both
# 796         both
# 436         both
# 710         both
# 626         both
# 845         both
# 461         both
# 389         both
# 580         both
# 677         both
# 442         both
# 645         both
# 599         both
# 633         both
# 844         both
# 708         both
# 619         both
# 923         both
# 648         both
# 646         both
# 326         both
# 609         both
# 552         both
# 561         both
# 547         both
# 931         both
# 402         both
# 900         both
# 933         both

# %% [markdown]
# ## Third Merge with CalSMART

# %%
nomatch2 = (merge2_2>>filter(_.second_merge=='right_only')>>select(_.name,
                                                                _.BC_TIRCP_merge,
                                                                _.caltrans_district_y))

# %%
#reread
dla3 = pd.read_excel('gs://calitp-analytics-data/data-analyses/dla/lst_Agencies_20211208.xlsx')

# %%
dla3 = dla3>>select(_.AgencyID, _.CalSMART_Agency, _.CT_Districts)

# %%
dla3= dla3.rename(columns={"AgencyID":"locode",
    "CT_Districts":"caltrans_district"})

# %%
dla3.sample()
# Out:
#     locode   CalSMART_Agency caltrans_district
# 259   5137  City of Richmond                 4

# %%
dla3['CalSMART_Agency'] = dla3['CalSMART_Agency'].str.title()

# %%
## merging

# %%
merge3 = pd.merge(dla3, nomatch2, left_on='CalSMART_Agency', right_on="name", how="outer", indicator='third_merge')

# %%
merge3.third_merge.value_counts()
# Out:
# left_only     970
# right_only    140
# both            7
# Name: third_merge, dtype: int64

# %%
merge3_match = merge3>>filter(_.third_merge=='both')

# %%
merge3>>filter(_.third_merge=='right_only')
# Out:
#      locode CalSMART_Agency caltrans_district  \
# 977     NaN             NaN               NaN
# 978     NaN             NaN               NaN
# 979     NaN             NaN               NaN
# 980     NaN             NaN               NaN
# 981     NaN             NaN               NaN
# ...     ...             ...               ...
# 1112    NaN             NaN               NaN
# 1113    NaN             NaN               NaN
# 1114    NaN             NaN               NaN
# 1115    NaN             NaN               NaN
# 1116    NaN             NaN               NaN
#
#                                                    name  BC_TIRCP_merge  \
# 977                       Yuba-Sutter Transit Authority  Black Cat Only
# 978   Butte County Association Of Governments Butte ...  Black Cat Only
# 979                       Calaveras County Public Works  Black Cat Only
# 980   County Of Los Angeles - Department Of Public W...  Black Cat Only
# 981                                  County Of Mariposa  Black Cat Only
# ...                                                 ...             ...
# 1112                                   Foothill Transit      TIRCP Only
# 1113                             Bay Area Rapid Transit      TIRCP Only
# 1114                                 Long Beach Transit      TIRCP Only
# 1115                          Santa Monica Big Blue Bus      TIRCP Only
# 1116                        Torrance Transit Department      TIRCP Only
#
#                  caltrans_district_y third_merge
# 977                  03 - Marysville  right_only
# 978                             None  right_only
# 979                             None  right_only
# 980                             None  right_only
# 981                             None  right_only
# ...                              ...         ...
# 1112         District 7: Los Angeles  right_only
# 1113  District 4: Bay Area / Oakland  right_only
# 1114         District 7: Los Angeles  right_only
# 1115         District 7: Los Angeles  right_only
# 1116         District 7: Los Angeles  right_only
#
# [140 rows x 7 columns]

# %% [markdown]
# ### fixing county names

# %%
nomatch3 = merge3>>filter(_.third_merge=='right_only')

# %%
nomatch3 = nomatch3>>select(_.name, _.BC_TIRCP_merge, _.caltrans_district_y)

# %%
nomatch_county_city = nomatch3[(nomatch3['name'].str.contains('County')) | (nomatch3['name'].str.contains('City'))]

# %%
nomatch_county_city.sample()
# Out:
#                                     name  BC_TIRCP_merge caltrans_district_y
# 993  Alpine County Community Development  Black Cat Only                None

# %%
df_copy = nomatch_county_city>>select(_['name'])

# %%
df_copy['str_len'] = df_copy['name'].str.split().str.len()

# %%
df_copy_fix = df_copy>>filter(_.str_len<=3)

# %%
df_copy_fix[['name_pt1', 'name_pt2']] = df_copy_fix['name'].str.split(' Of ', 1, expand=True)
# Out:
# /tmp/ipykernel_780/2525191858.py:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df_copy_fix[['name_pt1', 'name_pt2']] = df_copy_fix['name'].str.split(' Of ', 1, expand=True)
# /tmp/ipykernel_780/2525191858.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy_fix[['name_pt1', 'name_pt2']] = df_copy_fix['name'].str.split(' Of ', 1, expand=True)
# /tmp/ipykernel_780/2525191858.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy_fix[['name_pt1', 'name_pt2']] = df_copy_fix['name'].str.split(' Of ', 1, expand=True)

# %%
df_copy_fix['new_name'] = df_copy_fix['name_pt2'] + ' ' + df_copy_fix['name_pt1']
# Out:
# /tmp/ipykernel_780/1263993943.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy_fix['new_name'] = df_copy_fix['name_pt2'] + ' ' + df_copy_fix['name_pt1']

# %%
new_name_mapping = (dict(df_copy_fix[['name', 'new_name']].values))
    
nomatch_county_city['new_name'] = nomatch_county_city['name'].map(new_name_mapping)

nomatch_county_city['new_name'] = nomatch_county_city['new_name'].fillna(nomatch_county_city['name'])
# Out:
# /tmp/ipykernel_780/3684837436.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nomatch_county_city['new_name'] = nomatch_county_city['name'].map(new_name_mapping)
# /tmp/ipykernel_780/3684837436.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nomatch_county_city['new_name'] = nomatch_county_city['new_name'].fillna(nomatch_county_city['name'])

# %%
new_name_mapping
# Out:
# {'County Of Mariposa': 'Mariposa County',
#  'County Of Siskiyou': 'Siskiyou County',
#  'County Of Tulare': 'Tulare County',
#  'County Of Sonoma': 'Sonoma County',
#  'County Of Ventura': 'Ventura County'}

# %%
nomatch_county_city
# Out:
#                                                    name  \
# 978   Butte County Association Of Governments Butte ...
# 979                       Calaveras County Public Works
# 980   County Of Los Angeles - Department Of Public W...
# 981                                  County Of Mariposa
# 982                       County Of Nevada Public Works
# 983   County Of Sacramento Department Of Transportation
# 984         County Of Shasta Department Of Public Works
# 985                                  County Of Siskiyou
# 986                                    County Of Tulare
# 988                          Placer County Public Works
# 989   Stanislaus County Public Works - Transit Division
# 990                        Tehama County Transit Agency
# 991         Trinity County Department Of Transportation
# 992                      Tuolumne County Transit Agency
# 993                 Alpine County Community Development
# 995            City Of Corcoran - Corcoran Area Transit
# 1003     City Of Lafayette: Lamorinda Sprit Van Program
# 1008           County Of Sacramento Department Of Child
# 1009                                   County Of Sonoma
# 1010                                  County Of Ventura
# 1076    United Cerebral Palsy Of San Luis Obispo County
# 1100  United Cerebral Palsy Association Inc Of Stani...
# 1104              Tulare County Regional Transit Agency
# 1105              Tulare County Regional Transit Agency
# 1107     Los Angeles County Metropolitan Transportation
#
#                         BC_TIRCP_merge      caltrans_district_y  \
# 978                     Black Cat Only                     None
# 979                     Black Cat Only                     None
# 980                     Black Cat Only                     None
# 981                     Black Cat Only                     None
# 982                     Black Cat Only                     None
# 983                     Black Cat Only                     None
# 984                     Black Cat Only                     None
# 985                     Black Cat Only                     None
# 986                     Black Cat Only                     None
# 988                     Black Cat Only                     None
# 989                     Black Cat Only                     None
# 990                     Black Cat Only                     None
# 991                     Black Cat Only                     None
# 992                     Black Cat Only            10 - Stockton
# 993                     Black Cat Only                     None
# 995                     Black Cat Only                     None
# 1003                    Black Cat Only                     None
# 1008                    Black Cat Only                     None
# 1009                    Black Cat Only                     None
# 1010                    Black Cat Only                     None
# 1076                    Black Cat Only                     None
# 1100                    Black Cat Only                     None
# 1104  Found in both TIRCP and BlackCat              06 - Fresno
# 1105  Found in both TIRCP and BlackCat              06 - Fresno
# 1107                        TIRCP Only  District 7: Los Angeles
#
#                                                new_name
# 978   Butte County Association Of Governments Butte ...
# 979                       Calaveras County Public Works
# 980   County Of Los Angeles - Department Of Public W...
# 981                                     Mariposa County
# 982                       County Of Nevada Public Works
# 983   County Of Sacramento Department Of Transportation
# 984         County Of Shasta Department Of Public Works
# 985                                     Siskiyou County
# 986                                       Tulare County
# 988                          Placer County Public Works
# 989   Stanislaus County Public Works - Transit Division
# 990                        Tehama County Transit Agency
# 991         Trinity County Department Of Transportation
# 992                      Tuolumne County Transit Agency
# 993                 Alpine County Community Development
# 995            City Of Corcoran - Corcoran Area Transit
# 1003     City Of Lafayette: Lamorinda Sprit Van Program
# 1008           County Of Sacramento Department Of Child
# 1009                                      Sonoma County
# 1010                                     Ventura County
# 1076    United Cerebral Palsy Of San Luis Obispo County
# 1100  United Cerebral Palsy Association Inc Of Stani...
# 1104              Tulare County Regional Transit Agency
# 1105              Tulare County Regional Transit Agency
# 1107     Los Angeles County Metropolitan Transportation

# %%
nomatch_county_city = nomatch_county_city>>select(_.new_name, _.BC_TIRCP_merge, _.caltrans_district_y)

# %%
merge4 = pd.merge(dla2, nomatch_county_city, left_on='Agency2', right_on="new_name", how="outer", indicator='fourth_merge')

# %%
merge4.fourth_merge.value_counts()
# Out:
# left_only     972
# right_only     20
# both            5
# Name: fourth_merge, dtype: int64

# %%
merge4_match = merge4>>filter(_.fourth_merge=='both')

# %% [markdown]
# ## Concating Merge matches

# %%
matches = pd.concat([match, merge2_match, merge3_match, merge4_match])

# %%
matches
# Out:
#      locode                                     name  caltrans_district_x  \
# 11   6241.0              Mendocino Transit Authority                  1.0
# 42   6428.0          Redwood Coast Transit Authority                  1.0
# 43   6436.0                   Lake Transit Authority                  1.0
# 48   6162.0               Humboldt Transit Authority                  1.0
# 73   6147.0  Plumas County Transportation Commission                  2.0
# ..      ...                                      ...                  ...
# 355    5902                                      NaN                  NaN
# 534    5920                                      NaN                  NaN
# 659    5946                                      NaN                  NaN
# 767    5952                                      NaN                  NaN
# 890    5940                                      NaN                  NaN
#
#                        BC_TIRCP_merge caltrans_district_y _merge  \
# 11                     Black Cat Only         01 - Eureka   both
# 42                     Black Cat Only                None   both
# 43   Found in both TIRCP and BlackCat         01 - Eureka   both
# 48   Found in both TIRCP and BlackCat         01 - Eureka   both
# 73                     Black Cat Only                None   both
# ..                                ...                 ...    ...
# 355                    Black Cat Only                None    NaN
# 534                    Black Cat Only                None    NaN
# 659                    Black Cat Only                None    NaN
# 767                    Black Cat Only                None    NaN
# 890                    Black Cat Only                None    NaN
#
#              Agency2 caltrans_district second_merge CalSMART_Agency  \
# 11               NaN               NaN          NaN             NaN
# 42               NaN               NaN          NaN             NaN
# 43               NaN               NaN          NaN             NaN
# 48               NaN               NaN          NaN             NaN
# 73               NaN               NaN          NaN             NaN
# ..               ...               ...          ...             ...
# 355  Siskiyou County                 2          NaN             NaN
# 534    Sonoma County                 4          NaN             NaN
# 659    Tulare County                 6          NaN             NaN
# 767   Ventura County                 7          NaN             NaN
# 890  Mariposa County                10          NaN             NaN
#
#     third_merge         new_name fourth_merge
# 11          NaN              NaN          NaN
# 42          NaN              NaN          NaN
# 43          NaN              NaN          NaN
# 48          NaN              NaN          NaN
# 73          NaN              NaN          NaN
# ..          ...              ...          ...
# 355         NaN  Siskiyou County         both
# 534         NaN    Sonoma County         both
# 659         NaN    Tulare County         both
# 767         NaN   Ventura County         both
# 890         NaN  Mariposa County         both
#
# [112 rows x 13 columns]

# %%
matches._merge.fillna(matches['second_merge'], inplace=True)
matches._merge.fillna(matches['third_merge'], inplace=True)
matches._merge.fillna(matches['fourth_merge'], inplace=True)

# %%
matches.name.fillna(matches['new_name'], inplace=True)

# %%
matches.caltrans_district.fillna(matches['caltrans_district_x'], inplace=True)
matches.caltrans_district.fillna(matches['caltrans_district_y'], inplace=True)

# %%
matches = matches.drop(columns={'caltrans_district_x', 'caltrans_district_y', 'Agency2', 'second_merge', 'CalSMART_Agency', 'third_merge', 'fourth_merge', 'new_name'})

# %%
matches._merge.value_counts()
# Out:
# both          112
# left_only       0
# right_only      0
# Name: _merge, dtype: int64

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112 entries, 11 to 890
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   locode             112 non-null    object
#  1   name               112 non-null    object
#  2   BC_TIRCP_merge     112 non-null    object
#  3   _merge             112 non-null    category
#  4   caltrans_district  109 non-null    object
# dtypes: category(1), object(4)
# memory usage: 4.6+ KB

# %%
matches
# Out:
#      locode                                     name  \
# 11   6241.0              Mendocino Transit Authority
# 42   6428.0          Redwood Coast Transit Authority
# 43   6436.0                   Lake Transit Authority
# 48   6162.0               Humboldt Transit Authority
# 73   6147.0  Plumas County Transportation Commission
# ..      ...                                      ...
# 355    5902                          Siskiyou County
# 534    5920                            Sonoma County
# 659    5946                            Tulare County
# 767    5952                           Ventura County
# 890    5940                          Mariposa County
#
#                        BC_TIRCP_merge _merge caltrans_district
# 11                     Black Cat Only   both               1.0
# 42                     Black Cat Only   both               1.0
# 43   Found in both TIRCP and BlackCat   both               1.0
# 48   Found in both TIRCP and BlackCat   both               1.0
# 73                     Black Cat Only   both               2.0
# ..                                ...    ...               ...
# 355                    Black Cat Only   both                 2
# 534                    Black Cat Only   both                 4
# 659                    Black Cat Only   both                 6
# 767                    Black Cat Only   both                 7
# 890                    Black Cat Only   both                10
#
# [112 rows x 5 columns]

# %% [markdown]
# ## Concat with non-matches

# %%
##from first full merge
nomatch_total.sample()
# Out:
#      locode    name  caltrans_district_x BC_TIRCP_merge caltrans_district_y  \
# 459  5416.0  Marina                  5.0            NaN                 NaN
#
#         _merge
# 459  left_only

# %%
## add in the few name changes we used to get matches to the non_match_total so we dont have the originals in the final dataframe

##mapping to new column
nomatch_total['new_name'] = nomatch_total['name'].map(new_name_mapping)
## fill names from other column
nomatch_total['new_name'] = nomatch_total['new_name'].fillna(nomatch_total['name'])

## rename newname col and delete columns
nomatch_total = nomatch_total.drop(columns={'name'})
nomatch_total = nomatch_total.rename(columns= {'new_name':'name'})
# Out:
# /tmp/ipykernel_780/2998798198.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nomatch_total['new_name'] = nomatch_total['name'].map(new_name_mapping)
# /tmp/ipykernel_780/2998798198.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nomatch_total['new_name'] = nomatch_total['new_name'].fillna(nomatch_total['name'])

# %%
#concattt
test = pd.concat([nomatch_total, matches])

# %%
test>>arrange(_.name)
# Out:
#       locode  caltrans_district_x  BC_TIRCP_merge caltrans_district_y  \
# 1133     NaN                  NaN  Black Cat Only                None
# 89       736                  NaN  Black Cat Only                None
# 563   6312.0                  7.0             NaN                None
# 765   5408.0                  8.0             NaN                None
# 680   5435.0                  7.0             NaN                None
# ...      ...                  ...             ...                 ...
# 150   6224.0                  3.0             NaN                 NaN
# 1042     NaN                  NaN  Black Cat Only     03 - Marysville
# 744   5457.0                  8.0             NaN                 NaN
# 745   5466.0                  8.0             NaN                 NaN
# 1211     NaN                  NaN  Black Cat Only                None
#
#           _merge                           name caltrans_district
# 1133  right_only                Able Industries               NaN
# 89          both                Able Industries               NaN
# 563    left_only                Access Services               NaN
# 765    left_only                       Adelanto               NaN
# 680    left_only                   Agoura Hills               NaN
# ...          ...                            ...               ...
# 150    left_only  Yuba Sutter Transit Authority               NaN
# 1042  right_only  Yuba-Sutter Transit Authority               NaN
# 744    left_only                        Yucaipa               NaN
# 745    left_only                   Yucca Valley               NaN
# 1211  right_only            Yurok Tribe Transit               NaN
#
# [1294 rows x 7 columns]

# %%
len(test)
# Out:
# 1294

# %%
test.name.duplicated().sum()
# Out:
# 79

# %%
## get one district col instead of three
test.caltrans_district.fillna(test['caltrans_district_x'], inplace=True)
test.caltrans_district.fillna(test['caltrans_district_y'], inplace=True)

# %%
test = test.drop(columns={'caltrans_district_x', 'caltrans_district_y'})

# %% [markdown]
# ### Find and remove duplicates

# %%
duplicates= (test>>group_by(_.name)>>count(_.name)).rename(columns={"n":"n_name"})

# %%
test2 = pd.merge(test, duplicates, on='name')

# %%
## looking at the Caltrans entries
## we dont want to drop caltrans becasue opf the districts, but cannot group by district yet
(test2>>filter(_.n_name>1)>>arrange(_.name)).iloc[0:40]
# Out:
#       locode  BC_TIRCP_merge      _merge  \
# 1117     NaN  Black Cat Only  right_only
# 1118     736  Black Cat Only        both
# 1217     NaN      TIRCP Only  right_only
# 1218    M016      TIRCP Only        both
# 20    6201.0             NaN   left_only
# 21    6202.0             NaN   left_only
# 22    6203.0             NaN   left_only
# 23    6204.0             NaN   left_only
# 24    6205.0             NaN   left_only
# 25    6206.0             NaN   left_only
# 26    6207.0             NaN   left_only
# 27    6208.0             NaN   left_only
# 28    6209.0             NaN   left_only
# 29    6210.0             NaN   left_only
# 30    6211.0             NaN   left_only
# 31    6212.0             NaN   left_only
# 32    6200.0             NaN   left_only
# 1205     NaN      TIRCP Only  right_only
# 1206     998      TIRCP Only        both
# 1001     NaN  Black Cat Only  right_only
# 1002    5021  Black Cat Only        both
# 1011     NaN  Black Cat Only  right_only
# 1012    5370  Black Cat Only        both
# 1013     NaN  Black Cat Only  right_only
# 1014    5077  Black Cat Only        both
# 1015     NaN  Black Cat Only  right_only
# 1016    5399  Black Cat Only        both
# 998      NaN  Black Cat Only  right_only
# 999     5258  Black Cat Only        both
# 1233     NaN      TIRCP Only  right_only
# 1234    5318      TIRCP Only        both
# 1003     NaN  Black Cat Only  right_only
# 1004    5143  Black Cat Only        both
# 1017     NaN  Black Cat Only  right_only
# 1018    5056  Black Cat Only        both
# 1019     NaN  Black Cat Only  right_only
# 1020    5337  Black Cat Only        both
# 1021     NaN  Black Cat Only  right_only
# 1022    5132  Black Cat Only        both
# 1124     NaN  Black Cat Only  right_only
#
#                                          name               caltrans_district  \
# 1117                          Able Industries                            None
# 1118                          Able Industries                             NaN
# 1217           Anaheim Transportation Network      District 12: Orange County
# 1218           Anaheim Transportation Network                              12
# 20                                   Caltrans                             1.0
# 21                                   Caltrans                             2.0
# 22                                   Caltrans                             3.0
# 23                                   Caltrans                             4.0
# 24                                   Caltrans                             5.0
# 25                                   Caltrans                             6.0
# 26                                   Caltrans                             7.0
# 27                                   Caltrans                             8.0
# 28                                   Caltrans                             9.0
# 29                                   Caltrans                            10.0
# 30                                   Caltrans                            11.0
# 31                                   Caltrans                            12.0
# 32                                   Caltrans                            53.0
# 1205  Capitol Corridor Joint Powers Authority  District 4: Bay Area / Oakland
# 1206  Capitol Corridor Joint Powers Authority                          03, 04
# 1001                           City Of Arcata                            None
# 1002                           City Of Arcata                               1
# 1011                            City Of Arvin                            None
# 1012                            City Of Arvin                               6
# 1013                           City Of Auburn                            None
# 1014                           City Of Auburn                               3
# 1015                  City Of California City                            None
# 1016                  City Of California City                               9
# 998                        City Of Chowchilla                            None
# 999                        City Of Chowchilla                               6
# 1233                        City Of Cupertino  District 4: Bay Area / Oakland
# 1234                        City Of Cupertino                               4
# 1003                           City Of Dinuba                            None
# 1004                           City Of Dinuba                               6
# 1017                            City Of Dixon                            None
# 1018                            City Of Dixon                               4
# 1019                          City Of Escalon                            None
# 1020                          City Of Escalon                              10
# 1021                        City Of Fairfield                            None
# 1022                        City Of Fairfield                               4
# 1124                          City Of Fontana                            None
#
#       n_name
# 1117       2
# 1118       2
# 1217       2
# 1218       2
# 20        13
# 21        13
# 22        13
# 23        13
# 24        13
# 25        13
# 26        13
# 27        13
# 28        13
# 29        13
# 30        13
# 31        13
# 32        13
# 1205       2
# 1206       2
# 1001       2
# 1002       2
# 1011       2
# 1012       2
# 1013       2
# 1014       2
# 1015       2
# 1016       2
# 998        2
# 999        2
# 1233       2
# 1234       2
# 1003       2
# 1004       2
# 1017       2
# 1018       2
# 1019       2
# 1020       2
# 1021       2
# 1022       2
# 1124       2

# %%
def remove_duplicates(df):
    if (df['name'] == 'Caltrans'):
        return "keep"
    elif (df['name'] != 'Caltrans') & (df['n_name'] > 1) & (df['_merge']=='both'):
        return "keep"
    elif (df['name'] != 'Caltrans') & (df['n_name'] > 1) & (df['_merge']!='both'):
        return "drop"
    elif (df['name'] != 'Caltrans') & (df['n_name'] == 1):
        return "keep"

# %%
test2['keep_or_drop'] = test2.apply(remove_duplicates, axis = 1)

# %%
(test2>>filter(_.n_name>1)>>arrange(_.name)).iloc[0:40]
# Out:
#       locode  BC_TIRCP_merge      _merge  \
# 1117     NaN  Black Cat Only  right_only
# 1118     736  Black Cat Only        both
# 1217     NaN      TIRCP Only  right_only
# 1218    M016      TIRCP Only        both
# 20    6201.0             NaN   left_only
# 21    6202.0             NaN   left_only
# 22    6203.0             NaN   left_only
# 23    6204.0             NaN   left_only
# 24    6205.0             NaN   left_only
# 25    6206.0             NaN   left_only
# 26    6207.0             NaN   left_only
# 27    6208.0             NaN   left_only
# 28    6209.0             NaN   left_only
# 29    6210.0             NaN   left_only
# 30    6211.0             NaN   left_only
# 31    6212.0             NaN   left_only
# 32    6200.0             NaN   left_only
# 1205     NaN      TIRCP Only  right_only
# 1206     998      TIRCP Only        both
# 1001     NaN  Black Cat Only  right_only
# 1002    5021  Black Cat Only        both
# 1011     NaN  Black Cat Only  right_only
# 1012    5370  Black Cat Only        both
# 1013     NaN  Black Cat Only  right_only
# 1014    5077  Black Cat Only        both
# 1015     NaN  Black Cat Only  right_only
# 1016    5399  Black Cat Only        both
# 998      NaN  Black Cat Only  right_only
# 999     5258  Black Cat Only        both
# 1233     NaN      TIRCP Only  right_only
# 1234    5318      TIRCP Only        both
# 1003     NaN  Black Cat Only  right_only
# 1004    5143  Black Cat Only        both
# 1017     NaN  Black Cat Only  right_only
# 1018    5056  Black Cat Only        both
# 1019     NaN  Black Cat Only  right_only
# 1020    5337  Black Cat Only        both
# 1021     NaN  Black Cat Only  right_only
# 1022    5132  Black Cat Only        both
# 1124     NaN  Black Cat Only  right_only
#
#                                          name               caltrans_district  \
# 1117                          Able Industries                            None
# 1118                          Able Industries                             NaN
# 1217           Anaheim Transportation Network      District 12: Orange County
# 1218           Anaheim Transportation Network                              12
# 20                                   Caltrans                             1.0
# 21                                   Caltrans                             2.0
# 22                                   Caltrans                             3.0
# 23                                   Caltrans                             4.0
# 24                                   Caltrans                             5.0
# 25                                   Caltrans                             6.0
# 26                                   Caltrans                             7.0
# 27                                   Caltrans                             8.0
# 28                                   Caltrans                             9.0
# 29                                   Caltrans                            10.0
# 30                                   Caltrans                            11.0
# 31                                   Caltrans                            12.0
# 32                                   Caltrans                            53.0
# 1205  Capitol Corridor Joint Powers Authority  District 4: Bay Area / Oakland
# 1206  Capitol Corridor Joint Powers Authority                          03, 04
# 1001                           City Of Arcata                            None
# 1002                           City Of Arcata                               1
# 1011                            City Of Arvin                            None
# 1012                            City Of Arvin                               6
# 1013                           City Of Auburn                            None
# 1014                           City Of Auburn                               3
# 1015                  City Of California City                            None
# 1016                  City Of California City                               9
# 998                        City Of Chowchilla                            None
# 999                        City Of Chowchilla                               6
# 1233                        City Of Cupertino  District 4: Bay Area / Oakland
# 1234                        City Of Cupertino                               4
# 1003                           City Of Dinuba                            None
# 1004                           City Of Dinuba                               6
# 1017                            City Of Dixon                            None
# 1018                            City Of Dixon                               4
# 1019                          City Of Escalon                            None
# 1020                          City Of Escalon                              10
# 1021                        City Of Fairfield                            None
# 1022                        City Of Fairfield                               4
# 1124                          City Of Fontana                            None
#
#       n_name keep_or_drop
# 1117       2         drop
# 1118       2         keep
# 1217       2         drop
# 1218       2         keep
# 20        13         keep
# 21        13         keep
# 22        13         keep
# 23        13         keep
# 24        13         keep
# 25        13         keep
# 26        13         keep
# 27        13         keep
# 28        13         keep
# 29        13         keep
# 30        13         keep
# 31        13         keep
# 32        13         keep
# 1205       2         drop
# 1206       2         keep
# 1001       2         drop
# 1002       2         keep
# 1011       2         drop
# 1012       2         keep
# 1013       2         drop
# 1014       2         keep
# 1015       2         drop
# 1016       2         keep
# 998        2         drop
# 999        2         keep
# 1233       2         drop
# 1234       2         keep
# 1003       2         drop
# 1004       2         keep
# 1017       2         drop
# 1018       2         keep
# 1019       2         drop
# 1020       2         keep
# 1021       2         drop
# 1022       2         keep
# 1124       2         drop

# %%
finaldf = test2>>filter(_.keep_or_drop=='keep')

# %%
duplicates2= ((finaldf>>group_by(_.locode)>>count(_.locode))>>filter(_.n.notnull())).rename(columns={"n":"n_locode"})

# %%
finaldf2 = pd.merge(finaldf, duplicates2, on='locode')

# %%
(finaldf2>>filter(_.n_locode==2))>>arrange(_.locode)
# Out:
#      locode                    BC_TIRCP_merge     _merge  \
# 637  5006.0                               NaN  left_only
# 638    5006                        TIRCP Only       both
# 273  5012.0                               NaN  left_only
# 274    5012                        TIRCP Only       both
# 18   5021.0                               NaN  left_only
# ..      ...                               ...        ...
# 862    6305                    Black Cat Only       both
# 863  6308.0                               NaN  left_only
# 864    6308  Found in both TIRCP and BlackCat       both
# 320  6365.0                               NaN  left_only
# 321    6365                        TIRCP Only       both
#
#                                                   name caltrans_district  \
# 637                                        Los Angeles               7.0
# 638                                City Of Los Angeles                 7
# 273                                            Oakland               4.0
# 274                                    City Of Oakland                 4
# 18                                              Arcata               1.0
# ..                                                 ...               ...
# 862       Yosemite Area Regional Transportation System        06, 09, 10
# 863   Transit Joint Powers Authority For Merced County              10.0
# 864    Transit Joint Powers Authority Of Merced County                10
# 320     San Francisco Bay Area Water Transit Authority               4.0
# 321  San Francisco Bay Area Water Emergency Transpo...                 4
#
#      n_name keep_or_drop  n_locode
# 637       1         keep         2
# 638       2         keep         2
# 273       1         keep         2
# 274       2         keep         2
# 18        1         keep         2
# ..      ...          ...       ...
# 862       2         keep         2
# 863       1         keep         2
# 864       2         keep         2
# 320       1         keep         2
# 321       2         keep         2
#
# [90 rows x 8 columns]

# %%
def remove_duplicates2(df):
    if (df['n_locode'] != 2):
        return "keep"
    elif (df['n_locode'] == 2) & (df['_merge']=='both'):
        return "keep"
    elif (df['n_locode'] == 2) & (df['_merge'] == 'left_only'):
        return "drop"

# %%
finaldf2['keep_or_drop2'] = finaldf2.apply(remove_duplicates2, axis = 1)

# %%
finaldf2>>filter(_.n_locode==2)>>arrange(_.locode)
# Out:
#      locode                    BC_TIRCP_merge     _merge  \
# 637  5006.0                               NaN  left_only
# 638    5006                        TIRCP Only       both
# 273  5012.0                               NaN  left_only
# 274    5012                        TIRCP Only       both
# 18   5021.0                               NaN  left_only
# ..      ...                               ...        ...
# 862    6305                    Black Cat Only       both
# 863  6308.0                               NaN  left_only
# 864    6308  Found in both TIRCP and BlackCat       both
# 320  6365.0                               NaN  left_only
# 321    6365                        TIRCP Only       both
#
#                                                   name caltrans_district  \
# 637                                        Los Angeles               7.0
# 638                                City Of Los Angeles                 7
# 273                                            Oakland               4.0
# 274                                    City Of Oakland                 4
# 18                                              Arcata               1.0
# ..                                                 ...               ...
# 862       Yosemite Area Regional Transportation System        06, 09, 10
# 863   Transit Joint Powers Authority For Merced County              10.0
# 864    Transit Joint Powers Authority Of Merced County                10
# 320     San Francisco Bay Area Water Transit Authority               4.0
# 321  San Francisco Bay Area Water Emergency Transpo...                 4
#
#      n_name keep_or_drop  n_locode keep_or_drop2
# 637       1         keep         2          drop
# 638       2         keep         2          keep
# 273       1         keep         2          drop
# 274       2         keep         2          keep
# 18        1         keep         2          drop
# ..      ...          ...       ...           ...
# 862       2         keep         2          keep
# 863       1         keep         2          drop
# 864       2         keep         2          keep
# 320       1         keep         2          drop
# 321       2         keep         2          keep
#
# [90 rows x 9 columns]

# %%
finaldf3 = (finaldf2>>filter(_.keep_or_drop2=='keep'))

# %%
finaldf3
# Out:
#       locode  BC_TIRCP_merge     _merge  \
# 0     6302.0             NaN  left_only
# 1     6330.0             NaN  left_only
# 2     5036.0             NaN  left_only
# 3     5049.0             NaN  left_only
# 4     5082.0             NaN  left_only
# ...      ...             ...        ...
# 1219  6376.0  Black Cat Only       both
# 1220  6471.0  Black Cat Only       both
# 1221  6066.0      TIRCP Only       both
# 1222  6071.0      TIRCP Only       both
# 1223  6052.0  Black Cat Only       both
#
#                                                    name caltrans_district  \
# 0     Humboldt Bay Harbor Recreation & Conservation ...               1.0
# 1              Willow Creek Community Services District               1.0
# 2                                              Trinidad               1.0
# 3                                                 Ukiah               1.0
# 4                                               Willits               1.0
# ...                                                 ...               ...
# 1219                      North County Transit District              11.0
# 1220          Imperial County Transportation Commission              11.0
# 1221               San Diego Association Of Governments              11.0
# 1222             Orange County Transportation Authority              12.0
# 1223                             Sunline Transit Agency              53.0
#
#       n_name keep_or_drop  n_locode keep_or_drop2
# 0          1         keep         1          keep
# 1          1         keep         1          keep
# 2          1         keep         1          keep
# 3          1         keep         1          keep
# 4          1         keep         1          keep
# ...      ...          ...       ...           ...
# 1219       1         keep         1          keep
# 1220       1         keep         1          keep
# 1221       1         keep         1          keep
# 1222       1         keep         1          keep
# 1223       1         keep         1          keep
#
# [1179 rows x 9 columns]

# %%
finaldf3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1179 entries, 0 to 1223
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   locode             1046 non-null   object
#  1   BC_TIRCP_merge     245 non-null    object
#  2   _merge             1179 non-null   category
#  3   name               1179 non-null   object
#  4   caltrans_district  1057 non-null   object
#  5   n_name             1179 non-null   int64
#  6   keep_or_drop       1179 non-null   object
#  7   n_locode           1179 non-null   int64
#  8   keep_or_drop2      1179 non-null   object
# dtypes: category(1), int64(2), object(6)
# memory usage: 84.2+ KB

# %% [markdown]
# ## Add New Flag

# %%
def recategorize(df):   
    if (df['_merge']=='right_only') and (df['BC_TIRCP_merge'] == 'Black Cat Only'):
        return 'BlackCat Only'
    elif (df['_merge']=='right_only') and (df['BC_TIRCP_merge'] == 'TIRCP Only'):
        return 'TIRCP Only'
    elif (df['_merge']=='right_only') and (df['BC_TIRCP_merge'] == 'Found in both TIRCP and BlackCat'):
        return 'TIRCP and BlackCat'
    elif (df['_merge']=='left_only'):
        return 'DLA Only'
    elif (df['_merge']=='both') and (df['BC_TIRCP_merge'] == 'TIRCP Only'):
        return 'TIRCP and DLA'
    elif (df['_merge']=='both') and (df['BC_TIRCP_merge'] == 'Black Cat Only'):
        return 'BlackCat and DLA'
    elif (df['_merge']=='both') and (df['BC_TIRCP_merge'] == 'Found in both TIRCP and BlackCat'):
        return "TIRCP, BlackCat and DLA"
    else: 
        return ""

# %%
finaldf3['BC_TIRCP_DLA_merge'] = finaldf3.apply(recategorize, axis = 1)
# Out:
# /tmp/ipykernel_780/2895960549.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   finaldf3['BC_TIRCP_DLA_merge'] = finaldf3.apply(recategorize, axis = 1)

# %%
len(finaldf3)
# Out:
# 1179

# %%
finaldf3._merge.value_counts()
# Out:
# left_only     934
# right_only    133
# both          112
# Name: _merge, dtype: int64

# %%
finaldf3.BC_TIRCP_DLA_merge.value_counts()
# Out:
# DLA Only                   934
# BlackCat Only              123
# BlackCat and DLA            74
# TIRCP and DLA               25
# TIRCP, BlackCat and DLA     13
# TIRCP Only                  10
# Name: BC_TIRCP_DLA_merge, dtype: int64

# %%
(finaldf3>>filter(_._merge=='both'))
# Out:
#       locode  BC_TIRCP_merge _merge  \
# 19      5021  Black Cat Only   both
# 62      5902  Black Cat Only   both
# 92      5077  Black Cat Only   both
# 149     5473  Black Cat Only   both
# 162     5182  Black Cat Only   both
# ...      ...             ...    ...
# 1219  6376.0  Black Cat Only   both
# 1220  6471.0  Black Cat Only   both
# 1221  6066.0      TIRCP Only   both
# 1222  6071.0      TIRCP Only   both
# 1223  6052.0  Black Cat Only   both
#
#                                            name caltrans_district  n_name  \
# 19                               City Of Arcata                 1       2
# 62                              Siskiyou County                 2       3
# 92                               City Of Auburn                 3       2
# 149                             Town Of Truckee                 3       2
# 162                           City Of Roseville                 3       2
# ...                                         ...               ...     ...
# 1219              North County Transit District              11.0       1
# 1220  Imperial County Transportation Commission              11.0       1
# 1221       San Diego Association Of Governments              11.0       1
# 1222     Orange County Transportation Authority              12.0       1
# 1223                     Sunline Transit Agency              53.0       1
#
#      keep_or_drop  n_locode keep_or_drop2 BC_TIRCP_DLA_merge
# 19           keep         2          keep   BlackCat and DLA
# 62           keep         1          keep   BlackCat and DLA
# 92           keep         2          keep   BlackCat and DLA
# 149          keep         2          keep   BlackCat and DLA
# 162          keep         2          keep   BlackCat and DLA
# ...           ...       ...           ...                ...
# 1219         keep         1          keep   BlackCat and DLA
# 1220         keep         1          keep   BlackCat and DLA
# 1221         keep         1          keep      TIRCP and DLA
# 1222         keep         1          keep      TIRCP and DLA
# 1223         keep         1          keep   BlackCat and DLA
#
# [112 rows x 10 columns]

# %%
finaldf3>>filter(_._merge=='right_only')
# Out:
#      locode  BC_TIRCP_merge      _merge  \
# 1029    NaN  Black Cat Only  right_only
# 1030    NaN  Black Cat Only  right_only
# 1031    NaN  Black Cat Only  right_only
# 1032    NaN  Black Cat Only  right_only
# 1033    NaN  Black Cat Only  right_only
# ...     ...             ...         ...
# 1157    NaN      TIRCP Only  right_only
# 1158    NaN      TIRCP Only  right_only
# 1159    NaN      TIRCP Only  right_only
# 1160    NaN      TIRCP Only  right_only
# 1161    NaN      TIRCP Only  right_only
#
#                                                    name  \
# 1029                      Yuba-Sutter Transit Authority
# 1030  Butte County Association Of Governments Butte ...
# 1031                      Calaveras County Public Works
# 1032  County Of Los Angeles - Department Of Public W...
# 1033                      County Of Nevada Public Works
# ...                                                 ...
# 1157                                   Foothill Transit
# 1158                             Bay Area Rapid Transit
# 1159                                 Long Beach Transit
# 1160                          Santa Monica Big Blue Bus
# 1161                        Torrance Transit Department
#
#                    caltrans_district  n_name keep_or_drop  n_locode  \
# 1029                 03 - Marysville       1         keep       133
# 1030                            None       1         keep       133
# 1031                            None       1         keep       133
# 1032                            None       1         keep       133
# 1033                            None       1         keep       133
# ...                              ...     ...          ...       ...
# 1157         District 7: Los Angeles       1         keep       133
# 1158  District 4: Bay Area / Oakland       1         keep       133
# 1159         District 7: Los Angeles       1         keep       133
# 1160         District 7: Los Angeles       1         keep       133
# 1161         District 7: Los Angeles       1         keep       133
#
#      keep_or_drop2 BC_TIRCP_DLA_merge
# 1029          keep      BlackCat Only
# 1030          keep      BlackCat Only
# 1031          keep      BlackCat Only
# 1032          keep      BlackCat Only
# 1033          keep      BlackCat Only
# ...            ...                ...
# 1157          keep         TIRCP Only
# 1158          keep         TIRCP Only
# 1159          keep         TIRCP Only
# 1160          keep         TIRCP Only
# 1161          keep         TIRCP Only
#
# [133 rows x 10 columns]

# %%
finaldf3>>filter(_._merge=='left_only')
# Out:
#       locode BC_TIRCP_merge     _merge  \
# 0     6302.0            NaN  left_only
# 1     6330.0            NaN  left_only
# 2     5036.0            NaN  left_only
# 3     5049.0            NaN  left_only
# 4     5082.0            NaN  left_only
# ...      ...            ...        ...
# 1024  5465.0            NaN  left_only
# 1025  6250.0            NaN  left_only
# 1026  6031.0            NaN  left_only
# 1027  6176.0            NaN  left_only
# 1028  6185.0            NaN  left_only
#
#                                                    name caltrans_district  \
# 0     Humboldt Bay Harbor Recreation & Conservation ...               1.0
# 1              Willow Creek Community Services District               1.0
# 2                                              Trinidad               1.0
# 3                                                 Ukiah               1.0
# 4                                               Willits               1.0
# ...                                                 ...               ...
# 1024                                        Leave Blank              53.0
# 1025                     U.S. Fish And Wildlife Service              53.0
# 1026                 Tidewater Southern Railway Company              53.0
# 1027                   Tri Counties Regional Park Group              53.0
# 1028                              Trust For Public Land              59.0
#
#       n_name keep_or_drop  n_locode keep_or_drop2 BC_TIRCP_DLA_merge
# 0          1         keep         1          keep           DLA Only
# 1          1         keep         1          keep           DLA Only
# 2          1         keep         1          keep           DLA Only
# 3          1         keep         1          keep           DLA Only
# 4          1         keep         1          keep           DLA Only
# ...      ...          ...       ...           ...                ...
# 1024       1         keep         1          keep           DLA Only
# 1025       1         keep         1          keep           DLA Only
# 1026       1         keep         1          keep           DLA Only
# 1027       1         keep         1          keep           DLA Only
# 1028       1         keep         1          keep           DLA Only
#
# [934 rows x 10 columns]

# %%
finaldf3>>filter(_.name.str.contains("Los Angeles"))
# Out:
#       locode  BC_TIRCP_merge      _merge  \
# 636   5953.0             NaN   left_only
# 638     5006      TIRCP Only        both
# 639   6033.0             NaN   left_only
# 660   6065.0             NaN   left_only
# 661   6080.0             NaN   left_only
# 694   6384.0             NaN   left_only
# 709   6508.0             NaN   left_only
# 1032     NaN  Black Cat Only  right_only
# 1152     NaN      TIRCP Only  right_only
# 1153     NaN      TIRCP Only  right_only
#
#                                                    name  \
# 636                                  Los Angeles County
# 638                                 City Of Los Angeles
# 639                Los Angeles Junction Railway Company
# 660   Los Angeles County Metropolitan Transportation...
# 661                      Los Angeles Conservation Corps
# 694   Cal State Univeristy Los Angeles, Auxillary Se...
# 709                 Los Angeles Unified School District
# 1032  County Of Los Angeles - Department Of Public W...
# 1152     Los Angeles County Metropolitan Transportation
# 1153  Los Angeles-San Diego-San Luis Obispo Rail Cor...
#
#             caltrans_district  n_name keep_or_drop  n_locode keep_or_drop2  \
# 636                       7.0       1         keep         1          keep
# 638                         7       2         keep         2          keep
# 639                       7.0       1         keep         1          keep
# 660                       7.0       1         keep         1          keep
# 661                       7.0       1         keep         1          keep
# 694                       7.0       1         keep         1          keep
# 709                       7.0       1         keep         1          keep
# 1032                     None       1         keep       133          keep
# 1152  District 7: Los Angeles       1         keep       133          keep
# 1153                  Various       1         keep       133          keep
#
#      BC_TIRCP_DLA_merge
# 636            DLA Only
# 638       TIRCP and DLA
# 639            DLA Only
# 660            DLA Only
# 661            DLA Only
# 694            DLA Only
# 709            DLA Only
# 1032      BlackCat Only
# 1152         TIRCP Only
# 1153         TIRCP Only

# %% [markdown]
# * still some that are duplicates
#     * first because of hyphens - but now that we took out hyphens, they are still not merging
#     * one we know:
#         * Los Angeles County Metropolitan District
#
#     * manually changing this for now after export

# %% [markdown]
# ### Fix district number to name

# %%
district_dictionary = {
    1: "District 1: Eureka",
    2: "District 2: Redding",
    3: "District 3: Marysville",
    4: "District 4: Oakland",
    5: "District 5: San Luis Obispo",
    6: "District 6: Fresno",
    7: "District 7: Los Angeles",
    8: "District 8: San Bernardino",
    9: "District 9: Bishop",
    10: "District 10: Stockton",
    11: "District 11: San Diego",
    12: "District 12: Orange County",
    "District 4: Bay Area / Oakland" : "District 4: Oakland",
    "10 - Stockton":"District 10: Stockton", 
    "01 - Eureka" : "District 1: Eureka", 
    "03 - Marysville" : "District 3: Marysville",
    "04 - Oakland" : "District 4: Oakland", 
    "District 5: San Luis Obispo / Santa Barbara" : "District 5: San Luis Obispo"
}

# %%
finaldf3["caltrans_district"] = finaldf3["caltrans_district"].replace(district_dictionary)
# Out:
# /tmp/ipykernel_780/3422740427.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   finaldf3["caltrans_district"] = finaldf3["caltrans_district"].replace(district_dictionary)

# %%
finaldf3>>filter( _.caltrans_district.isnull())
# Out:
#      locode  BC_TIRCP_merge      _merge  \
# 1030    NaN  Black Cat Only  right_only
# 1031    NaN  Black Cat Only  right_only
# 1032    NaN  Black Cat Only  right_only
# 1033    NaN  Black Cat Only  right_only
# 1034    NaN  Black Cat Only  right_only
# ...     ...             ...         ...
# 1150    NaN  Black Cat Only  right_only
# 1151    NaN  Black Cat Only  right_only
# 1163   6905  Black Cat Only        both
# 1165    709  Black Cat Only        both
# 1166    736  Black Cat Only        both
#
#                                                    name caltrans_district  \
# 1030  Butte County Association Of Governments Butte ...              None
# 1031                      Calaveras County Public Works              None
# 1032  County Of Los Angeles - Department Of Public W...              None
# 1033                      County Of Nevada Public Works              None
# 1034  County Of Sacramento Department Of Transportation              None
# ...                                                 ...               ...
# 1150           Roderick Hayfork Senior Nutrition Center              None
# 1151                                Yurok Tribe Transit              None
# 1163                       Colusa County Transit Agency               NaN
# 1165                                              Oparc               NaN
# 1166                                    Able Industries               NaN
#
#       n_name keep_or_drop  n_locode keep_or_drop2 BC_TIRCP_DLA_merge
# 1030       1         keep       133          keep      BlackCat Only
# 1031       1         keep       133          keep      BlackCat Only
# 1032       1         keep       133          keep      BlackCat Only
# 1033       1         keep       133          keep      BlackCat Only
# 1034       1         keep       133          keep      BlackCat Only
# ...      ...          ...       ...           ...                ...
# 1150       1         keep       133          keep      BlackCat Only
# 1151       1         keep       133          keep      BlackCat Only
# 1163       2         keep         1          keep   BlackCat and DLA
# 1165       2         keep         1          keep   BlackCat and DLA
# 1166       2         keep         1          keep   BlackCat and DLA
#
# [122 rows x 10 columns]

# %%
## check to see if the name change worked
## if check is successful,there will be only a Mariposa County 
## if check is NOT successful, there will be a Mariposa County and a County of Mariposa
# finaldf3>>filter(_.name.str.contains('Mariposa'))

# %%
finaldf3.sample(5)
# Out:
#       locode  BC_TIRCP_merge      _merge  \
# 887   6445.0             NaN   left_only
# 403   6254.0             NaN   left_only
# 1033     NaN  Black Cat Only  right_only
# 826   6127.0             NaN   left_only
# 438   5289.0             NaN   left_only
#
#                                          name            caltrans_district  \
# 887    Chula Vista Elementary School District       District 11: San Diego
# 403   California State University,Montery Bay  District 5: San Luis Obispo
# 1033            County Of Nevada Public Works                         None
# 826   Amador County Transportation Commission        District 10: Stockton
# 438                               Pismo Beach  District 5: San Luis Obispo
#
#       n_name keep_or_drop  n_locode keep_or_drop2 BC_TIRCP_DLA_merge
# 887        1         keep         1          keep           DLA Only
# 403        1         keep         1          keep           DLA Only
# 1033       1         keep       133          keep      BlackCat Only
# 826        1         keep         1          keep           DLA Only
# 438        1         keep         1          keep           DLA Only

# %%
finaldf3 = finaldf3>>select(_.locode, _.name, _.caltrans_district, _.BC_TIRCP_DLA_merge)

# %%
finaldf3
# Out:
#       locode                                               name  \
# 0     6302.0  Humboldt Bay Harbor Recreation & Conservation ...
# 1     6330.0           Willow Creek Community Services District
# 2     5036.0                                           Trinidad
# 3     5049.0                                              Ukiah
# 4     5082.0                                            Willits
# ...      ...                                                ...
# 1219  6376.0                      North County Transit District
# 1220  6471.0          Imperial County Transportation Commission
# 1221  6066.0               San Diego Association Of Governments
# 1222  6071.0             Orange County Transportation Authority
# 1223  6052.0                             Sunline Transit Agency
#
#                caltrans_district BC_TIRCP_DLA_merge
# 0             District 1: Eureka           DLA Only
# 1             District 1: Eureka           DLA Only
# 2             District 1: Eureka           DLA Only
# 3             District 1: Eureka           DLA Only
# 4             District 1: Eureka           DLA Only
# ...                          ...                ...
# 1219      District 11: San Diego   BlackCat and DLA
# 1220      District 11: San Diego   BlackCat and DLA
# 1221      District 11: San Diego      TIRCP and DLA
# 1222  District 12: Orange County      TIRCP and DLA
# 1223                        53.0   BlackCat and DLA
#
# [1179 rows x 4 columns]

# %% [markdown]
# ## Save final

# %%
# finaldf3.info()

# %%
## converting locode to string so that parquet will work
# finaldf3['caltrans_district']= finaldf3['caltrans_district'].astype(str)
# finaldf3['locode']= finaldf3['locode'].astype(str)

# %%
## find what row was creating the problem
# finaldf3[(finaldf3 == 'M016').any(axis=1)]

# %%
# finaldf3.to_parquet('gs://calitp-analytics-data/data-analyses/grants/BlackCat_TIRCP_DLA.parquet')

# %%
# finaldf3.to_csv('gs://calitp-analytics-data/data-analyses/grants/BlackCat_TIRCP_DLA.csv')

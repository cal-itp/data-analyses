# %%
import pandas as pd
import geopandas as gpd

from update_vars import ANALYSIS_DATE, GCS_PATH, BORDER_BUFFER_METERS, GEOM_SUBFOLDER

from calitp_data_analysis.gcs_pandas import GCSPandas
from calitp_data_analysis.gcs_geopandas import GCSGeoPandas
from calitp_data_analysis.geography_utils import CA_NAD83Albers_m
from functools import cache
from segment_speed_utils import helpers
import importlib
import utils

@cache
def gcs_pandas():
    return GCSPandas()

@cache
def gcs_geopandas():
    return GCSGeoPandas()

# %% [markdown]
# # Refactor scripts to accept other geometries

# %% [markdown]
# ## `prepare_tracts_borders`

# %% [markdown]
# ### uza geoms

# %%
uza = utils.read_uzas()

# %%
uza.head(3)
# Out:
#                                            name uace20  \
# 0                                   Antioch, CA  02683
# 1                             McKinleyville, CA  52672
# 2  Arroyo Grande--Grover Beach--Pismo Beach, CA  03196
#
#                                             geometry
# 0  MULTIPOLYGON (((-145644.487 -4256.439, -145802...
# 1  POLYGON ((-341313.118 329954.224, -341407.902 ...
# 2  POLYGON ((-50334.547 -325887.744, -50347.534 -...

# %%
import importlib
import prepare_tracts_borders
importlib.reload(prepare_tracts_borders)
# Out:
# <module 'prepare_tracts_borders' from '/home/jovyan/data-analyses/transit_service_intensity/prepare_tracts_borders.py'>

# %%
borders = prepare_tracts_borders.find_borders(uza, id_col='uace20')

# %%
borders.shape
# Out:
# (58, 7)

# %%
borders.to_parquet(f'uza_borders_{ANALYSIS_DATE}.parquet')

# %%
gcs_geopandas().geo_data_frame_to_parquet(borders, f"{GCS_PATH}{GEOM_SUBFOLDER}borders_{ANALYSIS_DATE}.parquet")

# %% [markdown]
# ### with transit routes

# %%
shapes = helpers.import_scheduled_shapes(ANALYSIS_DATE)
st = helpers.import_scheduled_stop_times(analysis_date=ANALYSIS_DATE,
                                         columns=['feed_key', 'trip_id', 'stop_id'],
                                         get_pandas=True)
trips = helpers.import_scheduled_trips(ANALYSIS_DATE, columns=['shape_array_key', 'trip_id', 'feed_key'])
stops = helpers.import_scheduled_stops(ANALYSIS_DATE, columns=['feed_key', 'stop_id', 'geometry'])

shape_stops = (stops.merge(st, on = ['feed_key', 'stop_id'])
 .merge(trips, on = ['feed_key', 'trip_id'])
 .drop_duplicates(subset=['feed_key', 'shape_array_key', 'stop_id'])
 .dropna()
)

# %%
shape_stops_areas_borders = prepare_tracts_borders.find_shapes_in_areas_borders(shape_stops, uza, borders, id_col='uace20')

# %%
keep_cols = ['shape_array_key', 'tsi_segment_id']

# %%
shape_stops_areas_borders = shape_stops_areas_borders[keep_cols].drop_duplicates()

# %%
shape_stops_areas_borders.to_parquet(f'shape_stops_areas_borders_{ANALYSIS_DATE}.parquet')

# %%
gcs_pandas().data_frame_to_parquet(shape_stops_areas_borders, f"{GCS_PATH}{GEOM_SUBFOLDER}shape_stops_areas_borders_{ANALYSIS_DATE}.parquet")

# %% [markdown]
# ## `define_tsi_segments`
#
# * need option to group or not by shape
# *

# %%
# tract_segments = gcs_geopandas().read_parquet(f'{GCS_PATH}tsi_segments_{ANALYSIS_DATE}.parquet')

# %%
# tract_segments.head(10000).explore(column='tsi_segment_id')

# %%
shapes = helpers.import_scheduled_shapes(ANALYSIS_DATE)
trip_cols = ['gtfs_dataset_key', 'name', 'trip_id',
    'shape_id', 'shape_array_key', 'route_id',
    'route_key', 'direction_id', 'route_short_name',
    'trip_instance_key', 'feed_key']

trips = (helpers.import_scheduled_trips(ANALYSIS_DATE, columns=trip_cols)
    .dropna(subset=['shape_id'])
    )

# %%
from tqdm import tqdm
tqdm.pandas(desc=f"TSI Segments Progress {ANALYSIS_DATE}")

# %%
import define_tsi_segments
importlib.reload(define_tsi_segments)

# %%
# tsi_segs = (shapes
#        .groupby('shape_array_key')
#        .progress_apply(define_tsi_segments.overlay_areas_borders, areas_gdf=uza, border_gdf=borders,
#                       id_col='uace20')
#        .reset_index(drop=True)
#       )

# %%
tsi_segs = define_tsi_segments.overlay_areas_borders(shape_gdf=shapes, areas_gdf=uza, border_gdf=borders, id_col='uace20')

# %%
# m = uza.explore()

# %%
# tsi_segs.explore(column='tsi_segment_id', m=m) # too big

# %%
tsi_segs.to_parquet(f'uza_tsi_segs_{ANALYSIS_DATE}.parquet')

# %%
tsi_segs = gpd.read_parquet('uza_tsi_segs_2025-07-16.parquet')

# %%
path = f'{GCS_PATH}{GEOM_SUBFOLDER}tsi_segs_{ANALYSIS_DATE}.parquet'

# %%
gcs_geopandas().geo_data_frame_to_parquet(tsi_segs, path)

# %% [markdown]
# ## `time_distance_in_segments`

# %%
import time_distance_in_segments
importlib.reload(time_distance_in_segments)

# %%
def read_tsi_segs(tsi_segs, shapes):
    # tsi_segs = gpd.read_parquet(f'tsi_segments_{analysis_date}.parquet')
    tsi_segs = tsi_segs.drop(columns=['geometry'])

    shape_merged = (shapes.merge(tsi_segs, on='shape_array_key')
                         .rename(columns={'geometry': 'shape_geometry'}))

    shape_merged = shape_merged.assign(
        start_meters = shape_merged.shape_geometry.project(shape_merged.start)
    )
    shape_merged = shape_merged.sort_values('start_meters').reset_index(drop=True)
    cols = ['shape_array_key', 'tsi_segment_id', 'start_meters', 'tsi_segment_meters']
    shape_merged = shape_merged[cols]
    return shape_merged

# %%
shapes = helpers.import_scheduled_shapes(ANALYSIS_DATE, crs=CA_NAD83Albers_m)
st_proj = time_distance_in_segments.attach_projected_stop_times(ANALYSIS_DATE)

# %%
shape_merged = read_tsi_segs(gpd.read_parquet('./uza_tsi_segs_2025-07-16.parquet'), shapes)
# shape_merged = time_distance_in_segments.read_tsi_segs(ANALYSIS_DATE, shapes)
tsi_segments_trips = shape_merged.merge(st_proj[['shape_array_key', 'trip_instance_key']].drop_duplicates(), on='shape_array_key')

# %%
from dask.diagnostics import ProgressBar
ProgressBar().register()

import dask.dataframe as dd
import dask_geopandas as dg

# %%
many_trip_test =(tsi_segments_trips.head(10)
            .groupby('trip_instance_key', group_keys=False)
            .apply(time_distance_in_segments.tract_border_time_by_trip, st_proj_df = st_proj))
meta = many_trip_test[:0]
time_distance_in_segments.dask_calculate_batch(tsi_segments_trips,
                     st_proj, meta).to_parquet(f'tsi_uza_{ANALYSIS_DATE}.parquet')

# %% [markdown]
# ## results

# %%
path = f'{GCS_PATH}urbanized_areas/tsi_uza_2025-07-16.parquet'

# %%
df = gcs_pandas().read_parquet(path)

# %%
df

# %%
df = df.groupby('tsi_segment_id')[['tsi_segment_meters', 'segment_seconds']].sum().reset_index()

# %%
df

# %%
draft = uza.merge(df, left_on='uace20', right_on = 'tsi_segment_id')

# %%
draft.explore(column = 'segment_seconds', scheme = 'FisherJenks', tiles='CartoDBPositron', k=8)

# %% [markdown]
# ## aggregations

# %%
import borders_stops_aggregation
importlib.reload(borders_stops_aggregation)
# Out:
# <module 'borders_stops_aggregation' from '/home/jovyan/data-analyses/transit_service_intensity/borders_stops_aggregation.py'>

# %%
sstb = borders_stops_aggregation.read_shapes_stopping_in_seg(ANALYSIS_DATE)

# %%
sstb.head(3)
# Out:
#                     shape_array_key tsi_segment_id  has_stop
# 0  a66e6c6c1aaa8f579f48a7912d68a594          02683      True
# 0  41ed37b9a26ffe2ad724e4247c2d4a0a          02683      True
# 0  d2fe16b0b3ff388bfab976575f248026          02683      True

# %%
path = f'{GCS_PATH}{GEOM_SUBFOLDER}trip_tsi_segments_{ANALYSIS_DATE}.parquet'

# %%
trip_tsi_segments = gcs_pandas().read_parquet(path)

# %%
joined = borders_stops_aggregation.attach_stopping_info(trip_segment_df=trip_tsi_segments, shape_stopping_df=sstb)

# %%
joined.head(3)
# Out:
#                     shape_array_key                        tsi_segment_id  \
# 0  59b80ec04501eaaffeedf142ae468bac  3323a4c3-c718-4dfb-8d1f-b80711810763
# 1  9087d981ca93ccc12d566eaa0389e20a                                 51445
# 2  fe80f6e976b9373b46360c006f305a2a                                 78661
#
#    start_meters  tsi_segment_meters                 trip_instance_key  \
# 0  68224.295195         2515.768806  2a591130c1edeac89e62db5c22cb2805
# 1  68277.486823          178.134082  12a1749348fae282c28dd007025868fd
# 2  68621.298056          163.178124  98064cfe0042bce07ee76615190399ba
#
#     arrival_sec  arrival_sec_next  segment_seconds  has_stop
# 0  28424.575398      28519.424101        94.848704     False
# 1  26700.000000      26700.000000         0.000000      True
# 2  25376.086859      25394.733445        18.646587      True

# %%
stopping_sequences_df = borders_stops_aggregation.assign_stopping_sequences(joined)
# Out:
# Progress:  99%|█████████▉| 5703/5764 [00:17<00:00, 477.05it/s]/opt/conda/lib/python3.11/site-packages/tqdm/std.py:917: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return getattr(df, df_function)(wrapper, **kwargs)
# Progress: 100%|██████████| 5764/5764 [00:18<00:00, 305.44it/s]
# 0 segments out of 26734 can not be matched to a stop

# %%
stopping_sequences_df.head(3)
# Out:
#                     shape_array_key tsi_segment_id  tsi_segment_meters  \
# 0  59b80ec04501eaaffeedf142ae468bac          78904         1257.884403
# 0  59b80ec04501eaaffeedf142ae468bac          79039         1257.884403
# 1  9087d981ca93ccc12d566eaa0389e20a          51445          178.134082
#
#                   trip_instance_key  segment_seconds
# 0  2a591130c1edeac89e62db5c22cb2805        47.424352
# 0  2a591130c1edeac89e62db5c22cb2805        47.424352
# 1  12a1749348fae282c28dd007025868fd         0.000000

# %%
path = f'{GCS_PATH}{GEOM_SUBFOLDER}tsi_segs_{ANALYSIS_DATE}.parquet'
tsi_segs = gcs_geopandas().read_parquet(path)

# %%
tsi_segs.head(3)
# Out:
#                     shape_array_key uace20 name_1 uace20_1 name_2 uace20_2  \
# 0  5d23e7f673d20a805fc1e2375b8f0989  51445   None     None   None     None
# 1  3fbc2c25ca0c39e05c3d1999ae1dbdee  98020   None     None   None     None
# 2  3fbc2c25ca0c39e05c3d1999ae1dbdee  98020   None     None   None     None
#
#   intersection_id  length                                           geometry  \
# 0            None     NaN  LINESTRING (143090.838 -438138.600, 143084.377...
# 1            None     NaN  LINESTRING (502349.254 -580267.307, 502329.217...
# 2            None     NaN  LINESTRING (502294.081 -579459.977, 502293.858...
#
#    border                           start tsi_segment_id  tsi_segment_meters
# 0   False  POINT (143090.838 -438138.600)          51445         5832.806871
# 1   False  POINT (502349.254 -580267.307)          98020          721.023224
# 2   False  POINT (502294.081 -579459.977)          98020        10452.301272

# %%
border_assigned_df = borders_stops_aggregation.assign_borders(stopping_sequences_df=stopping_sequences_df, border_df=tsi_segs, id_col='uace20')
# Out:
# /home/jovyan/data-analyses/transit_service_intensity/borders_stops_aggregation.py:95: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   border_merged['border_divide'] = border_merged.border.replace({True: 2, False: 1})

# %%
border_assigned_df.head(3)
# Out:
#                     shape_array_key tsi_segment_id  tsi_segment_meters  \
# 0  59b80ec04501eaaffeedf142ae468bac          78904         1257.884403
# 1  59b80ec04501eaaffeedf142ae468bac          79039         1257.884403
# 2  9087d981ca93ccc12d566eaa0389e20a          51445          178.134082
#
#                   trip_instance_key  segment_seconds  border uace20
# 0  2a591130c1edeac89e62db5c22cb2805        47.424352   False  78904
# 1  2a591130c1edeac89e62db5c22cb2805        47.424352   False  79039
# 2  12a1749348fae282c28dd007025868fd         0.000000   False  51445

# %%
trips = helpers.import_scheduled_trips(analysis_date=ANALYSIS_DATE, columns=['shape_array_key', 'gtfs_dataset_key'])

# %%
border_assigned_df = border_assigned_df.merge(trips, on='shape_array_key')

# %%
border_assigned_df.head(3)
# Out:
#                     shape_array_key tsi_segment_id  tsi_segment_meters  \
# 0  59b80ec04501eaaffeedf142ae468bac          78904         1257.884403
# 1  59b80ec04501eaaffeedf142ae468bac          79039         1257.884403
# 2  9087d981ca93ccc12d566eaa0389e20a          51445          178.134082
#
#                   trip_instance_key  segment_seconds  border uace20  \
# 0  2a591130c1edeac89e62db5c22cb2805        47.424352   False  78904
# 1  2a591130c1edeac89e62db5c22cb2805        47.424352   False  79039
# 2  12a1749348fae282c28dd007025868fd         0.000000   False  51445
#
#           schedule_gtfs_dataset_key
# 0  8a1405af8da1379acc062e346187ac98
# 1  8a1405af8da1379acc062e346187ac98
# 2  2f1c266fc20f9875777fb752af32a66e

# %%
borders_stops_aggregation.aggregate_to_area?
# Out:
# Signature:
# borders_stops_aggregation.aggregate_to_area(
#     border_assigned_df,
#     group_cols=['tract'],
# )
# Docstring:
# File:      ~/data-analyses/transit_service_intensity/borders_stops_aggregation.py
# Type:      function

# %%
uza_tsi_agency = borders_stops_aggregation.aggregate_to_area(border_assigned_df=border_assigned_df, group_cols=['uace20', 'schedule_gtfs_dataset_key'])

# %%
uza = utils.read_uzas()

# %%
from calitp_data_analysis.sql import query_sql

# %% [markdown]
# ## analysis_name
#
# * better to use

# %%
#  ideally add schedule_gtfs_dataset_key to bridge table, avoid the join and date query here

query = f'''

with t1 as (select * from cal-itp-data-infra.mart_transit_database.bridge_gtfs_analysis_name_x_ntd),
t2 as (select schedule_source_record_id, schedule_gtfs_dataset_key, organization_name
from cal-itp-data-infra.mart_transit_database.dim_provider_gtfs_data
where _valid_from <= "{ANALYSIS_DATE}" and _valid_to >= "{ANALYSIS_DATE}"
)
select distinct t1.schedule_gtfs_dataset_name,
t1.analysis_name, t2.schedule_gtfs_dataset_key
from t1
inner join t2 on t1.organization_name = t2.organization_name

'''

# %%
analysis_name_bridge = query_sql(query)

# %%
analysis_name_bridge
# Out:
#     schedule_gtfs_dataset_name                             analysis_name  \
# 0             Maywood Schedule                           City of Maywood
# 1             Maywood Schedule                           City of Maywood
# 2    Mountain Transit Schedule  Mountain Area Regional Transit Authority
# 3    Mountain Transit Schedule  Mountain Area Regional Transit Authority
# 4    Mountain Transit Schedule  Mountain Area Regional Transit Authority
# ..                         ...                                       ...
# 528         Calabasas Schedule                         City of Calabasas
# 529         Calabasas Schedule                         City of Calabasas
# 530             TCRTA Schedule     Tulare County Regional Transit Agency
# 531             TCRTA Schedule     Tulare County Regional Transit Agency
# 532             TCRTA Schedule     Tulare County Regional Transit Agency
#
#             schedule_gtfs_dataset_key
# 0                                None
# 1    85bcef5ab0e4d4e108d0e54d559a0994
# 2    5ca5d244836397b178993c9bdc4dfb00
# 3                                None
# 4    0c092a514e4b9ad1427bdacdc67a0091
# ..                                ...
# 528                              None
# 529  907a502754757f897cef1409d297a397
# 530                              None
# 531  b16ecb67f0c7b702488e1ceb8966df4a
# 532  0139b1253130b33adcd4b3a4490530d2
#
# [533 rows x 3 columns]

# %%
uza_tsi_agency = uza_tsi_agency.merge(analysis_name_bridge, on='schedule_gtfs_dataset_key', how='left')
uza_tsi_agency
# Out:
#     uace20         schedule_gtfs_dataset_key  daily_vrm_miles  \
# 0    01701  3364ec074ca85001da3abd78be2ae521            190.2
# 1    01701  3364ec074ca85001da3abd78be2ae521            190.2
# 2    02683  55a01ef72af21906934ae8ffb4786e86           5383.0
# 3    02683  587e730fac4db21d54037e0f12b0dd5d            110.1
# 4    02683  8a1405af8da1379acc062e346187ac98           1793.3
# ..     ...                               ...              ...
# 576  97966  b0760015c9fcd0500c4fddd5b9bb115b            503.1
# 577  98020  17712ec68e3869e3c53525426e38cadd           1280.6
# 578  98020  48e137bc977da88970393f629c18432c            152.7
# 579  98020  48e137bc977da88970393f629c18432c            152.7
# 580  98020  a37760dde6b9fdcb76b82e57afab7274             23.1
#
#      daily_vrh_hours                         schedule_gtfs_dataset_name  \
# 0                9.1  San Diego International Airport Shuttles Schedule
# 1                9.1                                 San Diego Schedule
# 2              251.9                    Bay Area 511 Tri Delta Schedule
# 3                3.4            Bay Area 511 County Connection Schedule
# 4               57.4                         Bay Area 511 BART Schedule
# ..               ...                                                ...
# 576             36.8                                                NaN
# 577             71.7                                      Yuma Schedule
# 578            101.3                                    Amtrak Schedule
# 579            101.3                       Amtrak San Joaquins Schedule
# 580              3.8                                   Flixbus Schedule
#
#                                          analysis_name
# 0                      San Diego International Airport
# 1    San Diego Metropolitan Transit System, Airport...
# 2               Eastern Contra Costa Transit Authority
# 3               Central Contra Costa Transit Authority
# 4        San Francisco Bay Area Rapid Transit District
# ..                                                 ...
# 576                                                NaN
# 577  Yuma County Intergovernmental Public Transport...
# 578                                             Amtrak
# 579                 San Joaquin Joint Powers Authority
# 580                              FlixBus and Greyhound
#
# [581 rows x 6 columns]

# %%
no_match = uza_tsi_agency[uza_tsi_agency.analysis_name.isna()]

# %%
no_match
# Out:
#     uace20         schedule_gtfs_dataset_key  daily_vrm_miles  \
# 138  35839  711004f97e690bb62264e3456a87a4f0            170.7
# 151  41347  a7f5522d7690161fc2be75857d7e2f79             47.7
# 152  41347  b0760015c9fcd0500c4fddd5b9bb115b             52.4
# 331  74179  0d65d96d07115e28313f207d5ed0d3b2             33.2
# 389  78904  09ff99ecac281cec96e67a0890b17d39             57.4
# 465  79417  711004f97e690bb62264e3456a87a4f0             57.1
# 504  85870  0d65d96d07115e28313f207d5ed0d3b2              4.1
# 540  89191  a7f5522d7690161fc2be75857d7e2f79            639.7
# 541  89191  b0760015c9fcd0500c4fddd5b9bb115b            549.9
# 542  89218  a7f5522d7690161fc2be75857d7e2f79            150.8
# 543  89218  b0760015c9fcd0500c4fddd5b9bb115b             90.7
# 575  97966  a7f5522d7690161fc2be75857d7e2f79            638.3
# 576  97966  b0760015c9fcd0500c4fddd5b9bb115b            503.1
#
#      daily_vrh_hours schedule_gtfs_dataset_name analysis_name
# 138             17.7                        NaN           NaN
# 151              3.0                        NaN           NaN
# 152              2.5                        NaN           NaN
# 331              0.8                        NaN           NaN
# 389              7.2                        NaN           NaN
# 465              8.3                        NaN           NaN
# 504              5.4                        NaN           NaN
# 540             30.8                        NaN           NaN
# 541             26.3                        NaN           NaN
# 542              2.5                        NaN           NaN
# 543              1.6                        NaN           NaN
# 575             33.9                        NaN           NaN
# 576             36.8                        NaN           NaN

# %%
query = f'''

select *
from cal-itp-data-infra.mart_transit_database.dim_provider_gtfs_data
where _valid_from <= "{ANALYSIS_DATE}"
and _valid_to >= "{ANALYSIS_DATE}"
and schedule_gtfs_dataset_key in {tuple(x for x in no_match.schedule_gtfs_dataset_key.to_list())}


'''

# %%
query
# Out:
# '\n\nselect *\nfrom cal-itp-data-infra.mart_transit_database.dim_provider_gtfs_data\nwhere _valid_from <= "2025-07-16"\nand _valid_to >= "2025-07-16"\nand schedule_gtfs_dataset_key in (\'711004f97e690bb62264e3456a87a4f0\', \'a7f5522d7690161fc2be75857d7e2f79\', \'b0760015c9fcd0500c4fddd5b9bb115b\', \'0d65d96d07115e28313f207d5ed0d3b2\', \'09ff99ecac281cec96e67a0890b17d39\', \'711004f97e690bb62264e3456a87a4f0\', \'0d65d96d07115e28313f207d5ed0d3b2\', \'a7f5522d7690161fc2be75857d7e2f79\', \'b0760015c9fcd0500c4fddd5b9bb115b\', \'a7f5522d7690161fc2be75857d7e2f79\', \'b0760015c9fcd0500c4fddd5b9bb115b\', \'a7f5522d7690161fc2be75857d7e2f79\', \'b0760015c9fcd0500c4fddd5b9bb115b\')\n\n\n'

# %%
query_sql(query) # no match -- likely either no longer operating or changed feeds
# Out:
#                                 key  public_customer_facing_fixed_route  \
# 0  d421d79501c46ce5dfd34fabdb9dd9d1                               False
# 1  6b97439498124b86209a53d8c2cbd7ce                                True
# 2  5b1490684867f65b2f9256cc3c3ad35b                                True
# 3  b00d059e56dd545dadc8b63ccad20b9c                                True
# 4  4d65c7bbdda0e9920344a917c3669a31                               False
#
#    public_customer_facing_or_regional_subfeed_fixed_route  \
# 0                                              False
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                              False
#
#                    organization_key            organization_name  \
# 0  5b5950793dd6b992b08deee2233c86f9                Basin Transit
# 1  e9a4a3161951cd2a725151b644212e96            City of Guadalupe
# 2  f790a1680764b204736e3ae5ecd86391  Modoc Transportation Agency
# 3  5b5950793dd6b992b08deee2233c86f9                Basin Transit
# 4  52eeb25fc4be13024e9079d4d3fa879a         Quarterra Living Inc
#
#    organization_itp_id organization_hubspot_company_record_id  \
# 0                212.0                             1880784470
# 1                129.0                             9608934542
# 2                204.0                             1880607709
# 3                212.0                             1880784470
# 4                  NaN                                   None
#
#   organization_ntd_id organization_source_record_id  \
# 0          9R02-91090             recniaSbsXcRSLsWe
# 1          9R02-91043             recVdB3dpp3VhC1bd
# 2          9R02-91008             rec5Q3mEXcHPpQ8bn
# 3          9R02-91090             recniaSbsXcRSLsWe
# 4                None             recMC4gsvf7C5bgx2
#
#                         service_key  ... vehicle_positions_source_record_id  \
# 0  cd5cff96c3d8037f90806049001fce98  ...                               None
# 1  ef5e069012d5e4a3c4fa43db6445d838  ...                               None
# 2  50436431f03e5abfbb13b942c84494eb  ...                               None
# 3  cd5cff96c3d8037f90806049001fce98  ...                  recspVPAEPZITy5pm
# 4  11cf5a6dee725cba65b904abf898754a  ...                  reczmCalmBJtOTnfk
#
#             trip_updates_gtfs_dataset_name  trip_updates_source_record_id  \
# 0                                     None                           None
# 1                                     None                           None
# 2                                     None                           None
# 3           Basin Transit GMV Trip Updates              recA1r48yGZ6Ad63C
# 4  Bay Area 511 Emery Express Trip Updates              recQjYOlty19nBNmq
#
#           schedule_gtfs_dataset_key   service_alerts_gtfs_dataset_key  \
# 0  b0760015c9fcd0500c4fddd5b9bb115b                              None
# 1  711004f97e690bb62264e3456a87a4f0                              None
# 2  0d65d96d07115e28313f207d5ed0d3b2                              None
# 3  a7f5522d7690161fc2be75857d7e2f79  d0d775cb927f76276d52cc16fa92ac32
# 4  09ff99ecac281cec96e67a0890b17d39  191299dc657257f66c71cfa9fc3d3549
#
#   vehicle_positions_gtfs_dataset_key     trip_updates_gtfs_dataset_key  \
# 0                               None                              None
# 1                               None                              None
# 2                               None                              None
# 3   acf2b9df4777f003385e794e8b542968  d7f5167a6e0adb73e147e57d229af5c4
# 4   b300d7c3cfbe527f3251429c3eacc5d7  e1b5d1020a70bb335aceebb3b96da3f1
#
#                 _valid_from                        _valid_to _is_current
# 0 2025-03-06 00:00:00+00:00 2025-08-25 23:59:59.999999+00:00       False
# 1 2025-03-06 00:00:00+00:00 2025-08-14 23:59:59.999999+00:00       False
# 2 2025-03-06 00:00:00+00:00 2025-08-25 23:59:59.999999+00:00       False
# 3 2025-03-06 00:00:00+00:00 2098-12-31 23:59:59.999999+00:00        True
# 4 2025-02-08 00:00:00+00:00 2098-12-31 23:59:59.999999+00:00        True
#
# [5 rows x 30 columns]

# %% [markdown]
# Exploration on using airtable for transit data quality issues table

# %%
from dotenv import load_dotenv
import os

import numpy as np
import pandas as pd
from pyairtable import Api
load_dotenv()
api = Api(os.getenv('AIRTABLE_TOKEN'))

# %% [markdown]
# https://airtable.com/appmBGOFTvsDv4jdJ/api/docs#curl/table:transit%20data%20quality%20issues

# %%
# Trying to stay consistent with 
# https://github.com/cal-itp/data-infra/blob/main/airflow/plugins/operators/airtable_to_gcs.py
def all_rows_as_df(base_id, table_name):
    all_rows = api.table(base_id=base_id, table_name=table_name).all(return_fields_by_field_id=False)

    df = pd.DataFrame(
        [
            {"id":row["id"], **row["fields"]}
            for row in all_rows
        ]
    )
    return df

def takeout_list(x):
    if x is not np.nan:
        return x[0]

# %% [markdown]
# For reference for ids:
# https://airtable.com/appmBGOFTvsDv4jdJ/api/docs#curl/table:transit%20data%20quality%20issues

# %%
TABLE_TRANSIT_DATA_QUALITY_ISSUES_ID = 'appmBGOFTvsDv4jdJ'

# %%
issues_df = all_rows_as_df(TABLE_TRANSIT_DATA_QUALITY_ISSUES_ID, 'tblEv7QTfEmypU6gg')
issue_types = all_rows_as_df(TABLE_TRANSIT_DATA_QUALITY_ISSUES_ID, 'tblupkIe04LxEPWSR')
services_df = all_rows_as_df(TABLE_TRANSIT_DATA_QUALITY_ISSUES_ID, 'tblBZtbuntv4D0i1u')

# %%
#Clean up columns where data is a bunch of single item lists
issues_df['Issue Type'] = issues_df['Issue Type'].apply(takeout_list)
issues_df['Services'] = issues_df['Services'].apply(takeout_list)

# %%
issues_df.head()
# Out:
#                   id                                        Description  \
# 0  rec0MW4aKpcpJDMXv  Palo Verde Valley Transit Agency: GTFS Schedul...
# 1  rec0WcOlUWYE7hcpv     City of Auburn: GTFS Schedule Feed has Expired
# 2  rec0wKHGW5JrGSQ7Y  The GTFS schedule feed is about to expire on 1...
# 3  rec21OAguvM0dcDHk  Los Angeles County Metropolitan Transportation...
# 4  rec2hy3Jy9BtpJ2J9  City of Bell: Los Angeles Metro feed to transi...
#
#           Issue Type        GTFS Datasets                     Status  Issue #  \
# 0  recXHbaInR8Uebp5D  [recnCtfmZcTSsrJh7]  Fixed - with Cal-ITP help       21
# 1  recXHbaInR8Uebp5D  [recqOFeSKMAP6tcGp]  Fixed - with Cal-ITP help       11
# 2  recEmZkgNkfKgYe6N  [recoOHimkMbZlH3vV]         Fixed - on its own      143
# 3  recXHbaInR8Uebp5D  [recVvXBJDgsRqVLy6]  Fixed - with Cal-ITP help       47
# 4  rec9hb7KmcQCvR5BG  [recfPwQA6XD8SN2gR]                   Outreach       96
#
#             Services Resolution Date  \
# 0  recVmX1bV8LrzyGl7      2023-05-19
# 1  recAk8l02ipaRB34a      2023-04-13
# 2  reczR85P0abN3zb3n      2024-01-03
# 3  recEEI0Hoj2x3HTTJ      2023-06-29
# 4  recQIV7c2LReySeYp             NaN
#
#                                             Assignee  \
# 0  {'id': 'usr2fo9oGEjsugXf0', 'email': 'evan@cal...
# 1  {'id': 'usr2fo9oGEjsugXf0', 'email': 'evan@cal...
# 2  {'id': 'usrnOT3BlbNIbiG9v', 'email': 'md.islam...
# 3  {'id': 'usr2fo9oGEjsugXf0', 'email': 'evan@cal...
# 4  {'id': 'usr2fo9oGEjsugXf0', 'email': 'evan@cal...
#
#         Issue Creation Time  ...  \
# 0  2023-05-25T00:16:26.000Z  ...
# 1  2023-05-25T00:16:26.000Z  ...
# 2  2023-12-29T00:28:14.000Z  ...
# 3  2023-05-25T00:16:26.000Z  ...
# 4  2023-09-16T00:18:07.000Z  ...
#
#   Caltrans District (from Operating County Geographies) (from Services)  \
# 0                                                [8]
# 1                                                [3]
# 2                                                [2]
# 3                                                [7]
# 4                                                [7]
#
#   Is Open             Last Modified  Last Update Month Last Update Year  \
# 0      No  2023-05-30T17:21:48.000Z                  5             2023
# 1      No  2023-05-30T17:21:48.000Z                  5             2023
# 2      No  2024-01-05T00:06:41.000Z                  1             2024
# 3      No  2023-09-15T23:35:09.000Z                  9             2023
# 4     Yes  2024-01-08T23:42:57.000Z                  1             2024
#
#                                     Last Modified By  \
# 0  {'id': 'usr2fo9oGEjsugXf0', 'email': 'evan@cal...
# 1  {'id': 'usr2fo9oGEjsugXf0', 'email': 'evan@cal...
# 2  {'id': 'usrnOT3BlbNIbiG9v', 'email': 'md.islam...
# 3  {'id': 'usrBwrVsyUiZ7jCq8', 'email': 'evan.sir...
# 4  {'id': 'usrnOT3BlbNIbiG9v', 'email': 'md.islam...
#
#                                         Status Notes Should wait until  \
# 0                                                NaN               NaN
# 1                                                NaN               NaN
# 2  As of 12/28: The GTFS schedule feed is about t...               NaN
# 3  I reached out to Nina Kin about various feeds....               NaN
# 4  As of 9/14: Sent kickoff email to district rep...        2024-01-19
#
#            Outreach Status  Waiting Since
# 0                      NaN            NaN
# 1                      NaN            NaN
# 2                      NaN            NaN
# 3                      NaN            NaN
# 4  Waiting on District Rep            NaN
#
# [5 rows x 26 columns]

# %%
df = pd.merge(left=issues_df,right=issue_types[['Name']],how="left", left_on=['Issue Type'], right_on=issue_types['id'])

df = pd.merge(df, services_df[['Operator','Name']], how="left", left_on=['Services'], right_on=services_df['id'])
# df.head()
df = df.rename(columns={"Name_x":"Issue_Type","Name_y":"Service_Name"})

# %%
df = df.drop(axis=1, columns=["Last Modified By","Assignee","Services","GTFS Datasets","Issue Type","Created By"])

# %%
# find all unresolved issues
df = df.loc[~df['Resolution Date'].notnull()]

# %%
df.loc[df['Issue_Type']=="GTFS Realtime Completeness Problem",]
# Out:
#                     id                                        Description  \
# 16   rec9Iz2deWxPxWE5B  In the past 14 days, GTFS-RT Vehicle Positions...
# 40   recGKVXr5d3F3Hs88  Since May 4, Sunline's Trip Updates and Vehicl...
# 48   recJ7n1lBE4M2gOkb  As of December 15, Bay Area 511 Emery Go-Round...
# 57   recLBkzI5I1xPwAVA  Transit Joint Powers Authority for Merced Coun...
# 65   recOuR2jF8O9E2yXS  As of January 5, Desert Roadrunner GMV Schedul...
# 72   recRH2FM76ubHMf4w  As of December 6, Bay Area 511 ACE GTFS-RT has...
# 87   recVkEuYMgDH0PNVW  As of 9/29: only 15.74% of trips have trip upd...
# 93   recYF4t5SnYCtQ0pJ  GTFS-Realtime Vehicle Position data production...
# 99   reca5nOucWflhCnHz  As of 11/16: Only 39% of trips have vehicle po...
# 117  reckFE1qICQWONhDN  Since July 3 there have been zero trips accoun...
#
#              Status  Issue # Resolution Date       Issue Creation Time  \
# 16         Outreach       87             NaN  2023-09-08T20:20:38.000Z
# 40         Outreach       72             NaN  2023-07-20T19:55:41.000Z
# 48         Outreach      136             NaN  2023-12-15T20:01:32.000Z
# 57         Outreach       19             NaN  2023-05-25T00:16:26.000Z
# 65         Outreach      153             NaN  2024-01-05T20:44:25.000Z
# 72          On Hold      135             NaN  2023-12-15T19:56:43.000Z
# 87   False Positive      115             NaN  2023-09-29T15:56:12.000Z
# 93         Outreach      131             NaN  2023-12-01T18:53:40.000Z
# 99         Outreach      125             NaN  2023-11-16T18:32:30.000Z
# 117        Outreach       68             NaN  2023-07-20T16:25:32.000Z
#
#     Waiting over a week?  QC: Num services  QC: Num Issue Types  \
# 16                    No                 1                    1
# 40                   Yes                 1                    1
# 48                    No                 1                    1
# 57                    No                 1                    1
# 65                    No                 1                    1
# 72                   N/A                 1                    1
# 87                   N/A                 1                    1
# 93                    No                 1                    1
# 99                    No                 1                    1
# 117                   No                 1                    1
#
#                                              QC Checks  ...  \
# 16                                                  OK  ...
# 40                                                  OK  ...
# 48                                                  OK  ...
# 57                                                  OK  ...
# 65                                                  OK  ...
# 72   INVALID: Should Wait Until must be non-empty f...  ...
# 87                                                  OK  ...
# 93                                                  OK  ...
# 99                                                  OK  ...
# 117                                                 OK  ...
#
#                 Last Modified Last Update Month Last Update Year  \
# 16   2024-01-25T19:59:45.000Z                 1             2024
# 40   2024-01-18T01:17:37.000Z                 1             2024
# 48   2024-01-25T20:02:39.000Z                 1             2024
# 57   2023-12-20T21:04:55.000Z                12             2023
# 65   2024-01-17T19:06:07.000Z                 1             2024
# 72   2023-12-29T00:19:59.000Z                12             2023
# 87   2023-10-11T20:48:58.000Z                10             2023
# 93   2024-01-25T20:00:33.000Z                 1             2024
# 99   2024-01-16T21:53:58.000Z                 1             2024
# 117  2024-01-25T19:59:22.000Z                 1             2024
#
#                                           Status Notes  Should wait until  \
# 16   As of 9/8, ticket created for Customer Success...                NaN
# 40   As of 7/20: Sent email to transit agency.\n\nA...                NaN
# 48   As of 12/19: Customer success sent an email to...                NaN
# 57   Agency says they're working on resolving issue...         2024-01-18
# 65   As of 1/9: Laney sent an email and they replie...         2024-01-23
# 72   As of 12/15: Evan said the data might not be p...                NaN
# 87                                                 NaN                NaN
# 93   As of 12/1: only 39.86% of trips are producing...                NaN
# 99   As of 12/5: Amanda initially forgot, but now c...         2024-01-23
# 117  As of 7/20: Sent email to Nisar Ahmed\n\nAs of...                NaN
#
#                           Outreach Status Waiting Since  \
# 16                     Waiting on MTC 511    2024-01-25
# 40              Waiting on Transit Agency    2024-01-17
# 48                     Waiting on MTC 511    2024-01-25
# 57            Waiting on Customer Success           NaN
# 65              Waiting on Transit Agency           NaN
# 72                                    NaN           NaN
# 87                                    NaN           NaN
# 93                     Waiting on MTC 511    2024-01-25
# 99   Waiting on Transit Data Quality Team           NaN
# 117                    Waiting on MTC 511    2024-01-25
#
#                              Issue_Type  \
# 16   GTFS Realtime Completeness Problem
# 40   GTFS Realtime Completeness Problem
# 48   GTFS Realtime Completeness Problem
# 57   GTFS Realtime Completeness Problem
# 65   GTFS Realtime Completeness Problem
# 72   GTFS Realtime Completeness Problem
# 87   GTFS Realtime Completeness Problem
# 93   GTFS Realtime Completeness Problem
# 99   GTFS Realtime Completeness Problem
# 117  GTFS Realtime Completeness Problem
#
#                                               Operator  \
# 16                                  City of Union City
# 40                              SunLine Transit Agency
# 48         Emeryville Transportation Management Agency
# 57    Transit Joint Powers Authority for Merced County
# 65                    Palo Verde Valley Transit Agency
# 72                San Joaquin Regional Rail Commission
# 87                             City of San Luis Obispo
# 93                Napa Valley Transportation Authority
# 99                                     City of Solvang
# 117  Mountain View Transportation Management Associ...
#
#                   Service_Name
# 16          Union City Transit
# 40             SunLine Transit
# 48              Emery Go-Round
# 57              Merced The Bus
# 65           Desert Roadrunner
# 72   Altamont Corridor Express
# 87                 SLO Transit
# 93                Vine Transit
# 99   Santa Ynez Valley Transit
# 117                       MVGO
#
# [10 rows x 23 columns]

# %%
df['Issue_Type'].value_counts()
# Out:
# Los Angeles Metro feed transition                20
# GTFS Realtime Completeness Problem               10
# About to Expire Schedule Feed                     6
# Trip Planner GTFS Schedule Assistance             4
# Missing GTFS Schedule Feed (non-NTD Reporter)     3
# New GTFS Realtime System Setup                    3
# Unstable URL (GTFS Schedule)                      1
# GTFS Realtime API Access                          1
# Expiring feed maintained by Cal-ITP               1
# Service Accuracy                                  1
# Other GTFS Realtime issue                         1
# Trip Planner GTFS Realtime Assistance             1
# Missing GTFS Schedule Feed (NTD Reporter)         1
# Name: Issue_Type, dtype: int64

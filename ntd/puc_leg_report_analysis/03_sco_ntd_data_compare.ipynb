# %% [markdown]
# # Comparing ridership metrics between SCO and NTD
# There are instances of ridership and vehicle revenue hours values do not match between the SCO `Operator Data` tabs and equivilent NTD metrics.
#
# Explore the difference betwen the SCO data and NTD data.
# - what agencies appear just in SCO, just in NTD, both?
# - is there a crosswalk between sco entity ID and ntd id?
# - perform a t-test against the mean upt and mean vrh?

# %%
from functools import cache

import altair as alt
import pandas as pd
from calitp_data_analysis.gcs_pandas import GCSPandas
from calitp_data_analysis.sql import get_engine, query_sql, to_snakecase

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.options.display.float_format = "{:,.2f}".format


@cache
def gcs_pandas():
    return GCSPandas()


gcs_path = "gs://calitp-analytics-data/data-analyses/ntd/"

# %% [markdown]
# # Query warehouse data...again

# %%
metric_list = [
    "vrm",
    "upt",
    "vrh",
    # "opexp_total" # not needed for this project
]

# empty list for appending DFs
df_list = []

# loop to query pmt, upt and vrh from 2018 to 2024
for metric in metric_list:
    query = f"""
        SELECT
          ntd_id,
          source_agency,
          agency_status,
          primary_uza_name,
          uza_population,
          uza_area_sq_miles,
          year,
          mode,
          type_of_service,
          reporter_type,
          SUM({metric}) AS total_{metric},
        FROM
          `cal-itp-data-infra.mart_ntd_funding_and_expenses.fct_service_data_and_operating_expenses_time_series_by_mode_{metric}`
        WHERE
          source_state = "CA"
          AND year BETWEEN 2018 AND 2024
        GROUP BY
          ntd_id,
          source_agency,
          agency_status,
          primary_uza_name,
          uza_population,
          uza_area_sq_miles,
          year,
          mode,
          type_of_service,
          reporter_type
        """
    # create df
    metric = query_sql(query, as_df=True)

    # append df to list
    df_list.append(metric)

# unpack list into separate DFs
ntd_pmt, ntd_upt, ntd_vrh = df_list

display(ntd_upt.head(3))

merge_on_col = [
    "ntd_id",
    "year",
    "source_agency",
    "agency_status",
    "primary_uza_name",
    "uza_population",
    "uza_area_sq_miles",
    "mode",
    "type_of_service",
    "reporter_type",
]

merge_1 = ntd_vrh.merge(ntd_upt, on=merge_on_col, how="inner")
# merge_2 = merge_1.merge(ntd_vrh, on=merge_on_col, how = "inner")

ntd_metrics_merge = merge_1.merge(ntd_pmt, on=merge_on_col, how="inner")

ntd_metrics_merge.head(3)
# Out:
#   ntd_id                                      source_agency agency_status  \
# 0  90003  San Francisco Bay Area Rapid Transit District ...        Active
# 1  90003  San Francisco Bay Area Rapid Transit District ...        Active
# 2  90003  San Francisco Bay Area Rapid Transit District ...        Active
#
#              primary_uza_name  uza_population  uza_area_sq_miles  year mode  \
# 0  San Francisco--Oakland, CA         3515933             513.80  2020   HR
# 1  San Francisco--Oakland, CA         3515933             513.80  2019   MG
# 2  San Francisco--Oakland, CA         3515933             513.80  2018   MB
#
#   type_of_service  reporter_type     total_upt
# 0              DO  Full Reporter 88,698,878.00
# 1              PT  Full Reporter    886,515.00
# 2              PT  Full Reporter           NaN
#   ntd_id                                      source_agency agency_status  \
# 0  90003  San Francisco Bay Area Rapid Transit District ...        Active
# 1  90003  San Francisco Bay Area Rapid Transit District ...        Active
# 2  90003  San Francisco Bay Area Rapid Transit District ...        Active
#
#              primary_uza_name  uza_population  uza_area_sq_miles  year mode  \
# 0  San Francisco--Oakland, CA         3515933             513.80  2021   DR
# 1  San Francisco--Oakland, CA         3515933             513.80  2021   MB
# 2  San Francisco--Oakland, CA         3515933             513.80  2020   MG
#
#   type_of_service  reporter_type  total_vrh  total_upt  total_vrm
# 0              PT  Full Reporter        NaN        NaN        NaN
# 1              PT  Full Reporter        NaN        NaN        NaN
# 2              PT  Full Reporter  19,172.00 573,123.00 325,053.00

# %% [markdown]
# # read in latest SCO/NTD data from 02_puc_exempt_analysis
#
# ~~dont need this anymore. this data set contains FBR and local funding data, so agencies/rows may be duplicated.~~
#
# Can use to get crosswalk of sco entity id to ntd_id

# %%
yes_no_merge_filname = "ntd_yes_no_data_2026-02-02.parquet"

ntd_yes_no_merge = gcs_pandas().read_parquet(f"{gcs_path}{yes_no_merge_filname}")

sco_x_ntd_id = ntd_yes_no_merge[
    ["ntd_id", "source_agency", "sco_entity_id", "sco_entity_name"]
].drop_duplicates()

sco_x_ntd_id.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 154 entries, 0 to 2212
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ntd_id           154 non-null    object
#  1   source_agency    154 non-null    object
#  2   sco_entity_id    154 non-null    int64
#  3   sco_entity_name  154 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 6.0+ KB

# %% [markdown]
# # Read in compiled "TO_OPERATING_DATA" data

# %%
sco_data_path = "consolidated_sco_ to_operating_data_02-04-2026.csv"

sco_data = gcs_pandas().read_csv(f"{gcs_path}{sco_data_path}")

display(sco_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1961 entries, 0 to 1960
# Columns: 107 entries, Entity Name to Date Service Began Operations (MM/DD/YYYY)_Other Transportation Mode (Specify)
# dtypes: float64(96), int64(2), object(9)
# memory usage: 1.6+ MB
# None

# %%
# sco_columns = list(sco_data.columns)

sco_keep_cols = [
    "Entity Name",
    "Fiscal Year",
    "Entity ID",
    "Total Actual Vehicle Revenue Hours — Annual_Demand Response Vehicles_Actual Vehicle Revenue Hours — Annual",
    "Total Actual Vehicle Revenue Hours — Annual_Ferry Boat_Actual Vehicle Revenue Hours — Annual",
    "Total Actual Vehicle Revenue Hours — Annual_Heavy Rail_Actual Vehicle Revenue Hours — Annual",
    "Total Actual Vehicle Revenue Hours — Annual_Light Rail_Actual Vehicle Revenue Hours — Annual",
    "Total Actual Vehicle Revenue Hours — Annual_Motor Bus_Actual Vehicle Revenue Hours — Annual",
    "Total Actual Vehicle Revenue Hours — Annual_Other Transportation Mode (Specify)_Actual Vehicle Revenue Hours — Annual",
    "Total Actual Vehicle Revenue Hours — Annual_Trolley Bus_Actual Vehicle Revenue Hours — Annual",
    "Total Actual Vehicle Revenue Hours — Annual_Vanpool_Actual Vehicle Revenue Hours — Annual",
    "Total Actual Vehicle Revenue Miles_Demand Response Vehicles",
    "Total Actual Vehicle Revenue Miles_Ferry Boat",
    "Total Actual Vehicle Revenue Miles_Heavy Rail",
    "Total Actual Vehicle Revenue Miles_Light Rail",
    "Total Actual Vehicle Revenue Miles_Motor Bus",
    "Total Actual Vehicle Revenue Miles_Other Transportation Mode (Specify)",
    "Total Actual Vehicle Revenue Miles_Trolley Bus",
    "Total Actual Vehicle Revenue Miles_Vanpool",
    "Total Passengers — Annual_Demand Response Vehicles",
    "Total Passengers — Annual_Ferry Boat",
    "Total Passengers — Annual_Heavy Rail",
    "Total Passengers — Annual_Light Rail",
    "Total Passengers — Annual_Motor Bus",
    "Total Passengers — Annual_Other Transportation Mode (Specify)",
    "Total Passengers — Annual_Trolley Bus",
    "Total Passengers — Annual_Vanpool",
]

sco_data = sco_data[sco_keep_cols]

sco_data.columns = sco_data.columns.str.lower()

# %%
# What happens i if melt the dataframe THEN sum the rows?
value_vars_list = [
    "total passengers — annual_motor bus",
    "total passengers — annual_heavy rail",
    "total passengers — annual_light rail",
    "total passengers — annual_trolley bus",
    "total passengers — annual_ferry boat",
    "total passengers — annual_demand response vehicles",
    "total passengers — annual_vanpool",
    "total actual vehicle revenue hours — annual_motor bus_actual vehicle revenue hours — annual",
    "total actual vehicle revenue hours — annual_heavy rail_actual vehicle revenue hours — annual",
    "total actual vehicle revenue hours — annual_light rail_actual vehicle revenue hours — annual",
    "total actual vehicle revenue hours — annual_trolley bus_actual vehicle revenue hours — annual",
    "total actual vehicle revenue hours — annual_ferry boat_actual vehicle revenue hours — annual",
    "total actual vehicle revenue miles_motor bus",
    "total actual vehicle revenue miles_heavy rail",
    "total actual vehicle revenue miles_light rail",
    "total actual vehicle revenue miles_trolley bus",
    "total actual vehicle revenue miles_ferry boat",
    "total actual vehicle revenue hours — annual_other transportation mode (specify)_actual vehicle revenue hours — annual",
    "total actual vehicle revenue miles_other transportation mode (specify)",
    "total passengers — annual_other transportation mode (specify)",
]
sco_data_melt = pd.melt(
    sco_data,
    id_vars=[
        "entity name",
        "fiscal year",
        "entity id",
    ],
    var_name="sco_metrics",
    value_vars=value_vars_list,
    value_name="sco_metric_values",
)

sco_data_melt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39220 entries, 0 to 39219
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   entity name        39220 non-null  object
#  1   fiscal year        39220 non-null  int64
#  2   entity id          39220 non-null  int64
#  3   sco_metrics        39220 non-null  object
#  4   sco_metric_values  4980 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.5+ MB

# %%
sco_data_melt["sco_metrics"].unique()
# Out:
# array(['total passengers — annual_motor bus',
#        'total passengers — annual_heavy rail',
#        'total passengers — annual_light rail',
#        'total passengers — annual_trolley bus',
#        'total passengers — annual_ferry boat',
#        'total passengers — annual_demand response vehicles',
#        'total passengers — annual_vanpool',
#        'total actual vehicle revenue hours — annual_motor bus_actual vehicle revenue hours — annual',
#        'total actual vehicle revenue hours — annual_heavy rail_actual vehicle revenue hours — annual',
#        'total actual vehicle revenue hours — annual_light rail_actual vehicle revenue hours — annual',
#        'total actual vehicle revenue hours — annual_trolley bus_actual vehicle revenue hours — annual',
#        'total actual vehicle revenue hours — annual_ferry boat_actual vehicle revenue hours — annual',
#        'total actual vehicle revenue miles_motor bus',
#        'total actual vehicle revenue miles_heavy rail',
#        'total actual vehicle revenue miles_light rail',
#        'total actual vehicle revenue miles_trolley bus',
#        'total actual vehicle revenue miles_ferry boat',
#        'total actual vehicle revenue hours — annual_other transportation mode (specify)_actual vehicle revenue hours — annual',
#        'total actual vehicle revenue miles_other transportation mode (specify)',
#        'total passengers — annual_other transportation mode (specify)'],
#       dtype=object)

# %%
group_cols = ["entity name", "fiscal year", "entity id", "sco_metrics"]

# dictionary to map sco metrics to a shorter name and mode. uses .map() to create the map crosswalk against the reference row. then .apply() to apply the map to create the new columns
dict_tuple = {
    "total passengers — annual_motor bus": ("total_passengers", "motor bus"),
    "total passengers — annual_heavy rail": ("total_passengers", "heavy rail"),
    "total passengers — annual_light rail": ("total_passengers", "light rail"),
    "total passengers — annual_trolley bus": ("total_passengers", "trolley bus"),
    "total passengers — annual_ferry boat": ("total_passengers", "ferry boat"),
    "total passengers — annual_demand response vehicles": (
        "total_passengers",
        "demand response",
    ),
    "total passengers — annual_vanpool": ("total_passengers", "vanpool"),
    "total passengers — annual_other transportation mode (specify)": (
        "total_passengers",
        "other",
    ),
    "total actual vehicle revenue hours — annual_motor bus_actual vehicle revenue hours — annual": (
        "total_vrh",
        "motor bus",
    ),
    "total actual vehicle revenue hours — annual_heavy rail_actual vehicle revenue hours — annual": (
        "total_vrh",
        "heavy rail",
    ),
    "total actual vehicle revenue hours — annual_light rail_actual vehicle revenue hours — annual": (
        "total_vrh",
        "light rail",
    ),
    "total actual vehicle revenue hours — annual_trolley bus_actual vehicle revenue hours — annual": (
        "total_vrh",
        "trolley bus",
    ),
    "total actual vehicle revenue hours — annual_ferry boat_actual vehicle revenue hours — annual": (
        "total_vrh",
        "ferry boat",
    ),
    "total actual vehicle revenue hours — annual_other transportation mode (specify)_actual vehicle revenue hours — annual": (
        "total_vrh",
        "other",
    ),
    "total actual vehicle revenue miles_motor bus": ("total_vrm", "motor bus"),
    "total actual vehicle revenue miles_heavy rail": ("total_vrm", "heavy rail"),
    "total actual vehicle revenue miles_light rail": ("total_vrm", "light rail"),
    "total actual vehicle revenue miles_trolley bus": ("total_vrm", "trolley bus"),
    "total actual vehicle revenue miles_ferry boat": ("total_vrm", "ferry bus"),
    "total actual vehicle revenue miles_other transportation mode (specify)": (
        "total_vrm",
        "other",
    ),
}

agg_tuple = ("sco_metric_values", "sum")

# creates crosswalk map against each row in sco_data_melt.
# mapped is same length (~3,500 rows )
mapped = sco_data_melt["sco_metrics"].map(dict_tuple)


sco_data_melt[["sco_metric_short", "sco_mode"]] = mapped.apply(pd.Series)

# %%
# sanity check
sco_data_melt[
    (sco_data_melt["entity id"] == 566)
    # & (sco_data_melt["fiscal year"]==2021)
    # & (sco_data_melt["sco_metric_short"].str.contains("vrh"))
].sort_values(by="sco_metrics")
# Out:
#                                              entity name  fiscal year  \
# 23380  Mendocino Transit Authority - Specialized Service         2018
# 23105  Mendocino Transit Authority - Specialized Service         2019
# 22825  Mendocino Transit Authority - Specialized Service         2020
# 22538  Mendocino Transit Authority - Specialized Service         2021
# 22254  Mendocino Transit Authority - Specialized Service         2022
# 21974  Mendocino Transit Authority - Specialized Service         2023
# 21697  Mendocino Transit Authority - Specialized Service         2024
# 15814  Mendocino Transit Authority - Specialized Service         2024
# 16091  Mendocino Transit Authority - Specialized Service         2023
# 16371  Mendocino Transit Authority - Specialized Service         2022
# 16655  Mendocino Transit Authority - Specialized Service         2021
# 16942  Mendocino Transit Authority - Specialized Service         2020
# 17222  Mendocino Transit Authority - Specialized Service         2019
# 17497  Mendocino Transit Authority - Specialized Service         2018
# 19458  Mendocino Transit Authority - Specialized Service         2018
# 17775  Mendocino Transit Authority - Specialized Service         2024
# 18052  Mendocino Transit Authority - Specialized Service         2023
# 18332  Mendocino Transit Authority - Specialized Service         2022
# 18616  Mendocino Transit Authority - Specialized Service         2021
# 18903  Mendocino Transit Authority - Specialized Service         2020
# 19183  Mendocino Transit Authority - Specialized Service         2019
# 15261  Mendocino Transit Authority - Specialized Service         2019
# 14981  Mendocino Transit Authority - Specialized Service         2020
# 14694  Mendocino Transit Authority - Specialized Service         2021
# 14410  Mendocino Transit Authority - Specialized Service         2022
# 14130  Mendocino Transit Authority - Specialized Service         2023
# 13853  Mendocino Transit Authority - Specialized Service         2024
# 15536  Mendocino Transit Authority - Specialized Service         2018
# 34304  Mendocino Transit Authority - Specialized Service         2021
# 33740  Mendocino Transit Authority - Specialized Service         2023
# 35146  Mendocino Transit Authority - Specialized Service         2018
# 34871  Mendocino Transit Authority - Specialized Service         2019
# 34591  Mendocino Transit Authority - Specialized Service         2020
# 34020  Mendocino Transit Authority - Specialized Service         2022
# 33463  Mendocino Transit Authority - Specialized Service         2024
# 19736  Mendocino Transit Authority - Specialized Service         2024
# 20577  Mendocino Transit Authority - Specialized Service         2021
# 20864  Mendocino Transit Authority - Specialized Service         2020
# 20013  Mendocino Transit Authority - Specialized Service         2023
# 20293  Mendocino Transit Authority - Specialized Service         2022
# 21419  Mendocino Transit Authority - Specialized Service         2018
# 21144  Mendocino Transit Authority - Specialized Service         2019
# 31502  Mendocino Transit Authority - Specialized Service         2024
# 33185  Mendocino Transit Authority - Specialized Service         2018
# 32910  Mendocino Transit Authority - Specialized Service         2019
# 32630  Mendocino Transit Authority - Specialized Service         2020
# 32343  Mendocino Transit Authority - Specialized Service         2021
# 32059  Mendocino Transit Authority - Specialized Service         2022
# 31779  Mendocino Transit Authority - Specialized Service         2023
# 25619  Mendocino Transit Authority - Specialized Service         2024
# 25896  Mendocino Transit Authority - Specialized Service         2023
# 26176  Mendocino Transit Authority - Specialized Service         2022
# 26460  Mendocino Transit Authority - Specialized Service         2021
# 27027  Mendocino Transit Authority - Specialized Service         2019
# 26747  Mendocino Transit Authority - Specialized Service         2020
# 27302  Mendocino Transit Authority - Specialized Service         2018
# 28988  Mendocino Transit Authority - Specialized Service         2019
# 29263  Mendocino Transit Authority - Specialized Service         2018
# 28137  Mendocino Transit Authority - Specialized Service         2022
# 27580  Mendocino Transit Authority - Specialized Service         2024
# 28708  Mendocino Transit Authority - Specialized Service         2020
# 27857  Mendocino Transit Authority - Specialized Service         2023
# 28421  Mendocino Transit Authority - Specialized Service         2021
# 25341  Mendocino Transit Authority - Specialized Service         2018
# 25066  Mendocino Transit Authority - Specialized Service         2019
# 24499  Mendocino Transit Authority - Specialized Service         2021
# 24215  Mendocino Transit Authority - Specialized Service         2022
# 23935  Mendocino Transit Authority - Specialized Service         2023
# 23658  Mendocino Transit Authority - Specialized Service         2024
# 24786  Mendocino Transit Authority - Specialized Service         2020
# 36832  Mendocino Transit Authority - Specialized Service         2019
# 35701  Mendocino Transit Authority - Specialized Service         2023
# 35981  Mendocino Transit Authority - Specialized Service         2022
# 35424  Mendocino Transit Authority - Specialized Service         2024
# 36265  Mendocino Transit Authority - Specialized Service         2021
# 37107  Mendocino Transit Authority - Specialized Service         2018
# 36552  Mendocino Transit Authority - Specialized Service         2020
# 29541  Mendocino Transit Authority - Specialized Service         2024
# 29818  Mendocino Transit Authority - Specialized Service         2023
# 30098  Mendocino Transit Authority - Specialized Service         2022
# 30382  Mendocino Transit Authority - Specialized Service         2021
# 30669  Mendocino Transit Authority - Specialized Service         2020
# 31224  Mendocino Transit Authority - Specialized Service         2018
# 30949  Mendocino Transit Authority - Specialized Service         2019
# 11614  Mendocino Transit Authority - Specialized Service         2018
# 9931   Mendocino Transit Authority - Specialized Service         2024
# 10208  Mendocino Transit Authority - Specialized Service         2023
# 10488  Mendocino Transit Authority - Specialized Service         2022
# 10772  Mendocino Transit Authority - Specialized Service         2021
# 11059  Mendocino Transit Authority - Specialized Service         2020
# 11339  Mendocino Transit Authority - Specialized Service         2019
# 8247   Mendocino Transit Authority - Specialized Service         2023
# 8527   Mendocino Transit Authority - Specialized Service         2022
# 8811   Mendocino Transit Authority - Specialized Service         2021
# 9098   Mendocino Transit Authority - Specialized Service         2020
# 9378   Mendocino Transit Authority - Specialized Service         2019
# 9653   Mendocino Transit Authority - Specialized Service         2018
# 7970   Mendocino Transit Authority - Specialized Service         2024
# 3770   Mendocino Transit Authority - Specialized Service         2018
# 3495   Mendocino Transit Authority - Specialized Service         2019
# 3215   Mendocino Transit Authority - Specialized Service         2020
# 2928   Mendocino Transit Authority - Specialized Service         2021
# 2644   Mendocino Transit Authority - Specialized Service         2022
# 2087   Mendocino Transit Authority - Specialized Service         2024
# 2364   Mendocino Transit Authority - Specialized Service         2023
# 5731   Mendocino Transit Authority - Specialized Service         2018
# 5456   Mendocino Transit Authority - Specialized Service         2019
# 5176   Mendocino Transit Authority - Specialized Service         2020
# 4889   Mendocino Transit Authority - Specialized Service         2021
# 4605   Mendocino Transit Authority - Specialized Service         2022
# 4325   Mendocino Transit Authority - Specialized Service         2023
# 4048   Mendocino Transit Authority - Specialized Service         2024
# 126    Mendocino Transit Authority - Specialized Service         2024
# 403    Mendocino Transit Authority - Specialized Service         2023
# 683    Mendocino Transit Authority - Specialized Service         2022
# 967    Mendocino Transit Authority - Specialized Service         2021
# 1254   Mendocino Transit Authority - Specialized Service         2020
# 1534   Mendocino Transit Authority - Specialized Service         2019
# 1809   Mendocino Transit Authority - Specialized Service         2018
# 39068  Mendocino Transit Authority - Specialized Service         2018
# 38513  Mendocino Transit Authority - Specialized Service         2020
# 38226  Mendocino Transit Authority - Specialized Service         2021
# 37942  Mendocino Transit Authority - Specialized Service         2022
# 37662  Mendocino Transit Authority - Specialized Service         2023
# 37385  Mendocino Transit Authority - Specialized Service         2024
# 38793  Mendocino Transit Authority - Specialized Service         2019
# 6009   Mendocino Transit Authority - Specialized Service         2024
# 6566   Mendocino Transit Authority - Specialized Service         2022
# 6850   Mendocino Transit Authority - Specialized Service         2021
# 7137   Mendocino Transit Authority - Specialized Service         2020
# 7417   Mendocino Transit Authority - Specialized Service         2019
# 7692   Mendocino Transit Authority - Specialized Service         2018
# 6286   Mendocino Transit Authority - Specialized Service         2023
# 11892  Mendocino Transit Authority - Specialized Service         2024
# 12169  Mendocino Transit Authority - Specialized Service         2023
# 12449  Mendocino Transit Authority - Specialized Service         2022
# 12733  Mendocino Transit Authority - Specialized Service         2021
# 13020  Mendocino Transit Authority - Specialized Service         2020
# 13300  Mendocino Transit Authority - Specialized Service         2019
# 13575  Mendocino Transit Authority - Specialized Service         2018
#
#        entity id                                        sco_metrics  \
# 23380        566  total actual vehicle revenue hours — annual_fe...
# 23105        566  total actual vehicle revenue hours — annual_fe...
# 22825        566  total actual vehicle revenue hours — annual_fe...
# 22538        566  total actual vehicle revenue hours — annual_fe...
# 22254        566  total actual vehicle revenue hours — annual_fe...
# 21974        566  total actual vehicle revenue hours — annual_fe...
# 21697        566  total actual vehicle revenue hours — annual_fe...
# 15814        566  total actual vehicle revenue hours — annual_he...
# 16091        566  total actual vehicle revenue hours — annual_he...
# 16371        566  total actual vehicle revenue hours — annual_he...
# 16655        566  total actual vehicle revenue hours — annual_he...
# 16942        566  total actual vehicle revenue hours — annual_he...
# 17222        566  total actual vehicle revenue hours — annual_he...
# 17497        566  total actual vehicle revenue hours — annual_he...
# 19458        566  total actual vehicle revenue hours — annual_li...
# 17775        566  total actual vehicle revenue hours — annual_li...
# 18052        566  total actual vehicle revenue hours — annual_li...
# 18332        566  total actual vehicle revenue hours — annual_li...
# 18616        566  total actual vehicle revenue hours — annual_li...
# 18903        566  total actual vehicle revenue hours — annual_li...
# 19183        566  total actual vehicle revenue hours — annual_li...
# 15261        566  total actual vehicle revenue hours — annual_mo...
# 14981        566  total actual vehicle revenue hours — annual_mo...
# 14694        566  total actual vehicle revenue hours — annual_mo...
# 14410        566  total actual vehicle revenue hours — annual_mo...
# 14130        566  total actual vehicle revenue hours — annual_mo...
# 13853        566  total actual vehicle revenue hours — annual_mo...
# 15536        566  total actual vehicle revenue hours — annual_mo...
# 34304        566  total actual vehicle revenue hours — annual_ot...
# 33740        566  total actual vehicle revenue hours — annual_ot...
# 35146        566  total actual vehicle revenue hours — annual_ot...
# 34871        566  total actual vehicle revenue hours — annual_ot...
# 34591        566  total actual vehicle revenue hours — annual_ot...
# 34020        566  total actual vehicle revenue hours — annual_ot...
# 33463        566  total actual vehicle revenue hours — annual_ot...
# 19736        566  total actual vehicle revenue hours — annual_tr...
# 20577        566  total actual vehicle revenue hours — annual_tr...
# 20864        566  total actual vehicle revenue hours — annual_tr...
# 20013        566  total actual vehicle revenue hours — annual_tr...
# 20293        566  total actual vehicle revenue hours — annual_tr...
# 21419        566  total actual vehicle revenue hours — annual_tr...
# 21144        566  total actual vehicle revenue hours — annual_tr...
# 31502        566      total actual vehicle revenue miles_ferry boat
# 33185        566      total actual vehicle revenue miles_ferry boat
# 32910        566      total actual vehicle revenue miles_ferry boat
# 32630        566      total actual vehicle revenue miles_ferry boat
# 32343        566      total actual vehicle revenue miles_ferry boat
# 32059        566      total actual vehicle revenue miles_ferry boat
# 31779        566      total actual vehicle revenue miles_ferry boat
# 25619        566      total actual vehicle revenue miles_heavy rail
# 25896        566      total actual vehicle revenue miles_heavy rail
# 26176        566      total actual vehicle revenue miles_heavy rail
# 26460        566      total actual vehicle revenue miles_heavy rail
# 27027        566      total actual vehicle revenue miles_heavy rail
# 26747        566      total actual vehicle revenue miles_heavy rail
# 27302        566      total actual vehicle revenue miles_heavy rail
# 28988        566      total actual vehicle revenue miles_light rail
# 29263        566      total actual vehicle revenue miles_light rail
# 28137        566      total actual vehicle revenue miles_light rail
# 27580        566      total actual vehicle revenue miles_light rail
# 28708        566      total actual vehicle revenue miles_light rail
# 27857        566      total actual vehicle revenue miles_light rail
# 28421        566      total actual vehicle revenue miles_light rail
# 25341        566       total actual vehicle revenue miles_motor bus
# 25066        566       total actual vehicle revenue miles_motor bus
# 24499        566       total actual vehicle revenue miles_motor bus
# 24215        566       total actual vehicle revenue miles_motor bus
# 23935        566       total actual vehicle revenue miles_motor bus
# 23658        566       total actual vehicle revenue miles_motor bus
# 24786        566       total actual vehicle revenue miles_motor bus
# 36832        566  total actual vehicle revenue miles_other trans...
# 35701        566  total actual vehicle revenue miles_other trans...
# 35981        566  total actual vehicle revenue miles_other trans...
# 35424        566  total actual vehicle revenue miles_other trans...
# 36265        566  total actual vehicle revenue miles_other trans...
# 37107        566  total actual vehicle revenue miles_other trans...
# 36552        566  total actual vehicle revenue miles_other trans...
# 29541        566     total actual vehicle revenue miles_trolley bus
# 29818        566     total actual vehicle revenue miles_trolley bus
# 30098        566     total actual vehicle revenue miles_trolley bus
# 30382        566     total actual vehicle revenue miles_trolley bus
# 30669        566     total actual vehicle revenue miles_trolley bus
# 31224        566     total actual vehicle revenue miles_trolley bus
# 30949        566     total actual vehicle revenue miles_trolley bus
# 11614        566  total passengers — annual_demand response vehi...
# 9931         566  total passengers — annual_demand response vehi...
# 10208        566  total passengers — annual_demand response vehi...
# 10488        566  total passengers — annual_demand response vehi...
# 10772        566  total passengers — annual_demand response vehi...
# 11059        566  total passengers — annual_demand response vehi...
# 11339        566  total passengers — annual_demand response vehi...
# 8247         566               total passengers — annual_ferry boat
# 8527         566               total passengers — annual_ferry boat
# 8811         566               total passengers — annual_ferry boat
# 9098         566               total passengers — annual_ferry boat
# 9378         566               total passengers — annual_ferry boat
# 9653         566               total passengers — annual_ferry boat
# 7970         566               total passengers — annual_ferry boat
# 3770         566               total passengers — annual_heavy rail
# 3495         566               total passengers — annual_heavy rail
# 3215         566               total passengers — annual_heavy rail
# 2928         566               total passengers — annual_heavy rail
# 2644         566               total passengers — annual_heavy rail
# 2087         566               total passengers — annual_heavy rail
# 2364         566               total passengers — annual_heavy rail
# 5731         566               total passengers — annual_light rail
# 5456         566               total passengers — annual_light rail
# 5176         566               total passengers — annual_light rail
# 4889         566               total passengers — annual_light rail
# 4605         566               total passengers — annual_light rail
# 4325         566               total passengers — annual_light rail
# 4048         566               total passengers — annual_light rail
# 126          566                total passengers — annual_motor bus
# 403          566                total passengers — annual_motor bus
# 683          566                total passengers — annual_motor bus
# 967          566                total passengers — annual_motor bus
# 1254         566                total passengers — annual_motor bus
# 1534         566                total passengers — annual_motor bus
# 1809         566                total passengers — annual_motor bus
# 39068        566  total passengers — annual_other transportation...
# 38513        566  total passengers — annual_other transportation...
# 38226        566  total passengers — annual_other transportation...
# 37942        566  total passengers — annual_other transportation...
# 37662        566  total passengers — annual_other transportation...
# 37385        566  total passengers — annual_other transportation...
# 38793        566  total passengers — annual_other transportation...
# 6009         566              total passengers — annual_trolley bus
# 6566         566              total passengers — annual_trolley bus
# 6850         566              total passengers — annual_trolley bus
# 7137         566              total passengers — annual_trolley bus
# 7417         566              total passengers — annual_trolley bus
# 7692         566              total passengers — annual_trolley bus
# 6286         566              total passengers — annual_trolley bus
# 11892        566                  total passengers — annual_vanpool
# 12169        566                  total passengers — annual_vanpool
# 12449        566                  total passengers — annual_vanpool
# 12733        566                  total passengers — annual_vanpool
# 13020        566                  total passengers — annual_vanpool
# 13300        566                  total passengers — annual_vanpool
# 13575        566                  total passengers — annual_vanpool
#
#        sco_metric_values  sco_metric_short         sco_mode
# 23380                NaN         total_vrh       ferry boat
# 23105                NaN         total_vrh       ferry boat
# 22825                NaN         total_vrh       ferry boat
# 22538                NaN         total_vrh       ferry boat
# 22254                NaN         total_vrh       ferry boat
# 21974                NaN         total_vrh       ferry boat
# 21697                NaN         total_vrh       ferry boat
# 15814                NaN         total_vrh       heavy rail
# 16091                NaN         total_vrh       heavy rail
# 16371                NaN         total_vrh       heavy rail
# 16655                NaN         total_vrh       heavy rail
# 16942                NaN         total_vrh       heavy rail
# 17222                NaN         total_vrh       heavy rail
# 17497                NaN         total_vrh       heavy rail
# 19458                NaN         total_vrh       light rail
# 17775                NaN         total_vrh       light rail
# 18052                NaN         total_vrh       light rail
# 18332                NaN         total_vrh       light rail
# 18616                NaN         total_vrh       light rail
# 18903                NaN         total_vrh       light rail
# 19183                NaN         total_vrh       light rail
# 15261                NaN         total_vrh        motor bus
# 14981                NaN         total_vrh        motor bus
# 14694                NaN         total_vrh        motor bus
# 14410                NaN         total_vrh        motor bus
# 14130                NaN         total_vrh        motor bus
# 13853                NaN         total_vrh        motor bus
# 15536                NaN         total_vrh        motor bus
# 34304                NaN         total_vrh            other
# 33740                NaN         total_vrh            other
# 35146                NaN         total_vrh            other
# 34871                NaN         total_vrh            other
# 34591                NaN         total_vrh            other
# 34020                NaN         total_vrh            other
# 33463                NaN         total_vrh            other
# 19736                NaN         total_vrh      trolley bus
# 20577                NaN         total_vrh      trolley bus
# 20864                NaN         total_vrh      trolley bus
# 20013                NaN         total_vrh      trolley bus
# 20293                NaN         total_vrh      trolley bus
# 21419                NaN         total_vrh      trolley bus
# 21144                NaN         total_vrh      trolley bus
# 31502                NaN         total_vrm        ferry bus
# 33185                NaN         total_vrm        ferry bus
# 32910                NaN         total_vrm        ferry bus
# 32630                NaN         total_vrm        ferry bus
# 32343                NaN         total_vrm        ferry bus
# 32059                NaN         total_vrm        ferry bus
# 31779                NaN         total_vrm        ferry bus
# 25619                NaN         total_vrm       heavy rail
# 25896                NaN         total_vrm       heavy rail
# 26176                NaN         total_vrm       heavy rail
# 26460                NaN         total_vrm       heavy rail
# 27027                NaN         total_vrm       heavy rail
# 26747                NaN         total_vrm       heavy rail
# 27302                NaN         total_vrm       heavy rail
# 28988                NaN         total_vrm       light rail
# 29263                NaN         total_vrm       light rail
# 28137                NaN         total_vrm       light rail
# 27580                NaN         total_vrm       light rail
# 28708                NaN         total_vrm       light rail
# 27857                NaN         total_vrm       light rail
# 28421                NaN         total_vrm       light rail
# 25341                NaN         total_vrm        motor bus
# 25066                NaN         total_vrm        motor bus
# 24499                NaN         total_vrm        motor bus
# 24215                NaN         total_vrm        motor bus
# 23935                NaN         total_vrm        motor bus
# 23658                NaN         total_vrm        motor bus
# 24786                NaN         total_vrm        motor bus
# 36832                NaN         total_vrm            other
# 35701                NaN         total_vrm            other
# 35981                NaN         total_vrm            other
# 35424                NaN         total_vrm            other
# 36265                NaN         total_vrm            other
# 37107                NaN         total_vrm            other
# 36552                NaN         total_vrm            other
# 29541                NaN         total_vrm      trolley bus
# 29818                NaN         total_vrm      trolley bus
# 30098                NaN         total_vrm      trolley bus
# 30382                NaN         total_vrm      trolley bus
# 30669                NaN         total_vrm      trolley bus
# 31224                NaN         total_vrm      trolley bus
# 30949                NaN         total_vrm      trolley bus
# 11614          27,250.00  total_passengers  demand response
# 9931           25,442.00  total_passengers  demand response
# 10208          22,492.00  total_passengers  demand response
# 10488          18,636.00  total_passengers  demand response
# 10772          15,944.00  total_passengers  demand response
# 11059          22,517.00  total_passengers  demand response
# 11339          31,454.00  total_passengers  demand response
# 8247                 NaN  total_passengers       ferry boat
# 8527                 NaN  total_passengers       ferry boat
# 8811                 NaN  total_passengers       ferry boat
# 9098                 NaN  total_passengers       ferry boat
# 9378                 NaN  total_passengers       ferry boat
# 9653                 NaN  total_passengers       ferry boat
# 7970                 NaN  total_passengers       ferry boat
# 3770                 NaN  total_passengers       heavy rail
# 3495                 NaN  total_passengers       heavy rail
# 3215                 NaN  total_passengers       heavy rail
# 2928                 NaN  total_passengers       heavy rail
# 2644                 NaN  total_passengers       heavy rail
# 2087                 NaN  total_passengers       heavy rail
# 2364                 NaN  total_passengers       heavy rail
# 5731                 NaN  total_passengers       light rail
# 5456                 NaN  total_passengers       light rail
# 5176                 NaN  total_passengers       light rail
# 4889                 NaN  total_passengers       light rail
# 4605                 NaN  total_passengers       light rail
# 4325                 NaN  total_passengers       light rail
# 4048                 NaN  total_passengers       light rail
# 126                  NaN  total_passengers        motor bus
# 403                  NaN  total_passengers        motor bus
# 683                  NaN  total_passengers        motor bus
# 967                  NaN  total_passengers        motor bus
# 1254                 NaN  total_passengers        motor bus
# 1534                 NaN  total_passengers        motor bus
# 1809                 NaN  total_passengers        motor bus
# 39068                NaN  total_passengers            other
# 38513                NaN  total_passengers            other
# 38226                NaN  total_passengers            other
# 37942                NaN  total_passengers            other
# 37662                NaN  total_passengers            other
# 37385                NaN  total_passengers            other
# 38793                NaN  total_passengers            other
# 6009                 NaN  total_passengers      trolley bus
# 6566                 NaN  total_passengers      trolley bus
# 6850                 NaN  total_passengers      trolley bus
# 7137                 NaN  total_passengers      trolley bus
# 7417                 NaN  total_passengers      trolley bus
# 7692                 NaN  total_passengers      trolley bus
# 6286                 NaN  total_passengers      trolley bus
# 11892                NaN  total_passengers          vanpool
# 12169                NaN  total_passengers          vanpool
# 12449                NaN  total_passengers          vanpool
# 12733                NaN  total_passengers          vanpool
# 13020                NaN  total_passengers          vanpool
# 13300                NaN  total_passengers          vanpool
# 13575                NaN  total_passengers          vanpool

# %% [markdown]
# # Save out melted data frame

# %%
sco_data_melt_filename = "sco_compiled_data_melt.parquet"

# gcs_pandas().data_frame_to_parquet(sco_data_melt, f"{gcs_path}{sco_data_melt_filename}")

# %% [markdown]
# # Read in melted data frame

# %%
sco_melt = gcs_pandas().read_parquet(f"{gcs_path}{sco_data_melt_filename}")

# %%
sco_melt.equals(sco_data_melt)
# Out:
# True

# %% [markdown]
# # Compare melted sco data to ntd data

# %%
display(sco_melt.columns, ntd_metrics_merge.columns)
# Out:
# Index(['entity name', 'fiscal year', 'entity id', 'sco_metrics',
#        'sco_metric_values', 'sco_metric_short', 'sco_mode'],
#       dtype='object')
# Index(['ntd_id', 'source_agency', 'agency_status', 'primary_uza_name',
#        'uza_population', 'uza_area_sq_miles', 'year', 'mode',
#        'type_of_service', 'reporter_type', 'total_vrh', 'total_upt',
#        'total_vrm'],
#       dtype='object')

# %% [markdown]
# # merge sco and ntd merge data to find any matches
# - merging just based on name
# - we know that some names dont match 1:1

# %% [markdown]
# ## Crosswalk of ntd id to sco entity id
# - see if we can use the crosswalk to merge on?
# - We know some sco entities changed names/numbers, so expect unmerged rows or something like "Monterey Salinas Transit" vs "Monterey-Salinas Transit"

# %% [markdown]
# merge 1 table to crosswalk, then merge in last table
# - marge `sco_melt_agg_###` with `sco_x_ntd_id` on `entity_id`. then merge `ntd_metrics_agg_###`

# %%
sco_xwalk_ntd = sco_melt.merge(
    sco_x_ntd_id,
    how="left",
    left_on=["entity id"],
    right_on=["sco_entity_id"],
    indicator=True,
)

display(
    sco_xwalk_ntd.info(),
    sco_xwalk_ntd["_merge"].value_counts()
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39220 entries, 0 to 39219
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   entity name        39220 non-null  object
#  1   fiscal year        39220 non-null  int64
#  2   entity id          39220 non-null  int64
#  3   sco_metrics        39220 non-null  object
#  4   sco_metric_values  4980 non-null   float64
#  5   sco_metric_short   39220 non-null  object
#  6   sco_mode           39220 non-null  object
#  7   ntd_id             21180 non-null  object
#  8   source_agency      21180 non-null  object
#  9   sco_entity_id      21180 non-null  float64
#  10  sco_entity_name    21180 non-null  object
#  11  _merge             39220 non-null  category
# dtypes: category(1), float64(2), int64(2), object(7)
# memory usage: 3.3+ MB
# None
# _merge
# both          21180
# left_only     18040
# right_only        0
# Name: count, dtype: int64

# %%
sco_xwalk_ntd = sco_xwalk_ntd.drop(columns="_merge").merge(
    ntd_metrics_merge,
    how = "left",
    left_on = ["ntd_id"],
    right_on = ["ntd_id"],
    indicator = True
)
display(
    sco_xwalk_ntd.info(),
    sco_xwalk_ntd["_merge"].value_counts() # samr 
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 425020 entries, 0 to 425019
# Data columns (total 24 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   entity name        425020 non-null  object
#  1   fiscal year        425020 non-null  int64
#  2   entity id          425020 non-null  int64
#  3   sco_metrics        425020 non-null  object
#  4   sco_metric_values  82447 non-null   float64
#  5   sco_metric_short   425020 non-null  object
#  6   sco_mode           425020 non-null  object
#  7   ntd_id             406980 non-null  object
#  8   source_agency_x    406980 non-null  object
#  9   sco_entity_id      406980 non-null  float64
#  10  sco_entity_name    406980 non-null  object
#  11  source_agency_y    406980 non-null  object
#  12  agency_status      406980 non-null  object
#  13  primary_uza_name   306460 non-null  object
#  14  uza_population     406980 non-null  float64
#  15  uza_area_sq_miles  406980 non-null  float64
#  16  year               406980 non-null  float64
#  17  mode               406980 non-null  object
#  18  type_of_service    406980 non-null  object
#  19  reporter_type      406980 non-null  object
#  20  total_vrh          319840 non-null  float64
#  21  total_upt          319840 non-null  float64
#  22  total_vrm          319840 non-null  float64
#  23  _merge             425020 non-null  category
# dtypes: category(1), float64(8), int64(2), object(13)
# memory usage: 75.0+ MB
# None
# _merge
# both          406980
# left_only      18040
# right_only         0
# Name: count, dtype: int64

# %% [markdown]
# ### What if i merge ntd_metrics -> xwalk -> sco?

# %%
ntd_xwalk_sco = ntd_metrics_merge.merge(
    sco_x_ntd_id,
    how = "left",
    left_on = "ntd_id",
    right_on = "ntd_id",
    indicator = True
)

display(
    ntd_xwalk_sco.info(),
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3899 entries, 0 to 3898
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ntd_id             3899 non-null   object
#  1   source_agency_x    3899 non-null   object
#  2   agency_status      3899 non-null   object
#  3   primary_uza_name   3080 non-null   object
#  4   uza_population     3899 non-null   int64
#  5   uza_area_sq_miles  3899 non-null   float64
#  6   year               3899 non-null   int64
#  7   mode               3899 non-null   object
#  8   type_of_service    3899 non-null   object
#  9   reporter_type      3899 non-null   object
#  10  total_vrh          3013 non-null   float64
#  11  total_upt          3013 non-null   float64
#  12  total_vrm          3013 non-null   float64
#  13  source_agency_y    2968 non-null   object
#  14  sco_entity_id      2968 non-null   float64
#  15  sco_entity_name    2968 non-null   object
#  16  _merge             3899 non-null   category
# dtypes: category(1), float64(5), int64(2), object(9)
# memory usage: 491.4+ KB
# None
# _merge
# both          2968
# left_only      931
# right_only       0
# Name: count, dtype: int64

# %%
ntd_xwalk_sco = ntd_xwalk_sco.drop(columns ="_merge").merge(
    sco_melt,
    how = "left",
    left_on = "sco_entity_id",
    right_on = "entity id",
    indicator = True
)

display(
    ntd_xwalk_sco.info(),
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 407911 entries, 0 to 407910
# Data columns (total 24 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ntd_id             407911 non-null  object
#  1   source_agency_x    407911 non-null  object
#  2   agency_status      407911 non-null  object
#  3   primary_uza_name   307314 non-null  object
#  4   uza_population     407911 non-null  int64
#  5   uza_area_sq_miles  407911 non-null  float64
#  6   year               407911 non-null  int64
#  7   mode               407911 non-null  object
#  8   type_of_service    407911 non-null  object
#  9   reporter_type      407911 non-null  object
#  10  total_vrh          320533 non-null  float64
#  11  total_upt          320533 non-null  float64
#  12  total_vrm          320533 non-null  float64
#  13  source_agency_y    406980 non-null  object
#  14  sco_entity_id      406980 non-null  float64
#  15  sco_entity_name    406980 non-null  object
#  16  entity name        406980 non-null  object
#  17  fiscal year        406980 non-null  float64
#  18  entity id          406980 non-null  float64
#  19  sco_metrics        406980 non-null  object
#  20  sco_metric_values  81144 non-null   float64
#  21  sco_metric_short   406980 non-null  object
#  22  sco_mode           406980 non-null  object
#  23  _merge             407911 non-null  category
# dtypes: category(1), float64(8), int64(2), object(13)
# memory usage: 72.0+ MB
# None
# _merge
# both          406980
# left_only        931
# right_only         0
# Name: count, dtype: int64

# %% [markdown]
# ### Are there any unmerged rows between the sco data and crosswalk?

# %%
display(
    ntd_xwalk_sco["_merge"].value_counts(),
    sco_xwalk_ntd["_merge"].value_counts()
)
# Out:
# _merge
# both          406980
# left_only        931
# right_only         0
# Name: count, dtype: int64
# _merge
# both          406980
# left_only      18040
# right_only         0
# Name: count, dtype: int64

# %%
ntd_xwalk_sco.head(3)
# Out:
#   ntd_id                                    source_agency_x agency_status  \
# 0  90003  San Francisco Bay Area Rapid Transit District ...        Active
# 1  90003  San Francisco Bay Area Rapid Transit District ...        Active
# 2  90003  San Francisco Bay Area Rapid Transit District ...        Active
#
#              primary_uza_name  uza_population  uza_area_sq_miles  year mode  \
# 0  San Francisco--Oakland, CA         3515933             513.80  2021   DR
# 1  San Francisco--Oakland, CA         3515933             513.80  2021   DR
# 2  San Francisco--Oakland, CA         3515933             513.80  2021   DR
#
#   type_of_service  reporter_type  total_vrh  total_upt  total_vrm  \
# 0              PT  Full Reporter        NaN        NaN        NaN
# 1              PT  Full Reporter        NaN        NaN        NaN
# 2              PT  Full Reporter        NaN        NaN        NaN
#
#                                      source_agency_y  sco_entity_id  \
# 0  San Francisco Bay Area Rapid Transit District ...         638.00
# 1  San Francisco Bay Area Rapid Transit District ...         638.00
# 2  San Francisco Bay Area Rapid Transit District ...         638.00
#
#                                  sco_entity_name  \
# 0  San Francisco Bay Area Rapid Transit District
# 1  San Francisco Bay Area Rapid Transit District
# 2  San Francisco Bay Area Rapid Transit District
#
#                                      entity name  fiscal year  entity id  \
# 0  San Francisco Bay Area Rapid Transit District     2,024.00     638.00
# 1  San Francisco Bay Area Rapid Transit District     2,023.00     638.00
# 2  San Francisco Bay Area Rapid Transit District     2,022.00     638.00
#
#                            sco_metrics  sco_metric_values  sco_metric_short  \
# 0  total passengers — annual_motor bus                NaN  total_passengers
# 1  total passengers — annual_motor bus                NaN  total_passengers
# 2  total passengers — annual_motor bus                NaN  total_passengers
#
#     sco_mode _merge
# 0  motor bus   both
# 1  motor bus   both
# 2  motor bus   both

# %%
ntd_xwalk_sco[
    (ntd_xwalk_sco["_merge"] == "left_only")
    # & (~ntd_xwalk_sco["entity name"].str.contains("- Specialized"))
][["ntd_id","source_agency_x"]].drop_duplicates() 

# These NTD_ID did not xwalk to an SCO entity
# Out:
#        ntd_id                                    source_agency_x
# 75700   90086  City of Riverside - Parks, Recreation & Commun...
# 86344   90094  Metropolitan Transportation Commission (MTC) -...
# 86348   90095  San Diego Association of Governments (SANDAG) ...
# 115472  90166                  LACMTA - Small Operators (LACMTA)
# 115493  90167  City of Davis (DCT) - Transit/Parks and Commun...
# 121657  90193                          Chula Vista Transit (CVT)
# 137764  90211               Anaheim Transportation Network (ATN)
# 143292  90220                               City of Folsom (FSL)
# 143306  90223                                  Paratransit, Inc.
# 148362  90231                               City of Irvine (COI)
# 153409  90236                          Stanislaus County (StaRT)
# 155110  90243                           Easy Lift Transportation
# 157074  90246  City of Agoura Hills - Department of Community...
# 157078  90247              City of Alhambra (ACT) - Public Works
# 157086  90249                                     City of Avalon
# 157098  90250                   City of Azusa - Transit Division
# 157102  90251  City of Baldwin Park - Department of Public Works
# 157110  90252       City of Bell - Community Services Department
# 157122  90253                City of Bell Gardens - public works
# 157130  90254          City of Bellflower - Parks and Recreation
# 157138  90255  City of Beverly Hills - Public Works - Transpo...
# 158102  90257  City of Calabasas (COC) - Public Works Departm...
# 158110  90258  City of Carson - Transportation Services Division
# 158126  90259  City of Cerritos - Department of Community Dev...
# 158138  90260                              City of Compton (CRT)
# 158146  90261  City of Covina - Public Works Department, Tran...
# 158150  90262                               City of Cudahy (COC)
# 159838  90264                                     City of Duarte
# 159845  90265         City of El Monte - Transportation Services
# 159861  90266         City of Glendora - Transportation Division
# 159869  90267  City of Huntington Park (HPCA) - Fixed Route T...
# 159877  90268                 City of Inglewood - Human Services
# 160449  90270  Los Angeles County (LACDPW) - Department of Pu...
# 160453  90271  Los Angeles County - Department of Public Work...
# 160461  90272  Los Angeles County (LACDPW) - Department of Pu...
# 160465  90273  Los Angeles County (LACDPW) - Department of Pu...
# 160469  90274  Los Angeles County - Department of Public Work...
# 160473  90275  Los Angeles County - Department of Public Work...
# 160477  90276  Los Angeles County (LACDPW) - Department of Pu...
# 160481  90277  Los Angeles County - Department of Public Work...
# 160485  90278  Los Angeles County - Department of Public Work...
# 160489  90279  Los Angeles County - Department of Public Work...
# 160493  90280                                   City of Lawndale
# 160500  90281          City of Lynwood - Public Works Department
# 160504  90282     City of Malibu - Community Services Department
# 160512  90283  City of Manhattan Beach (CMB DAR) - Community ...
# 160516  90284        City of Maywood (COM) - City Manager Office
# 160524  90285                    City of Monrovia - Public Works
# 160528  90286    City of Monterey Park - Public Works Department
# 161656  90288  City of Pico Rivera - Transit Division/Parks a...
# 161660  90289                    City of Rosemead - Public Works
# 161668  90290  City of Santa Fe Springs (SFS) - Community Ser...
# 161672  90291     City of South Gate - Transportation Department
# 161680  90292  City of South Pasadena - Transit / Community S...
# 161684  90293  City of West Covina - Community Services Depar...
# 161692  90294  City of West Hollywood (WEHO) - Business Devel...
# 161700  90295                         City of Whittier - Transit
# 163384  90297    San Luis Obispo Council of Governments (SLOCOG)
# 166191  90300          City of Artesia - Transportation Division
# 166199  90301  City of Lakewood (DASH) - Recreation and Commu...
# 166203  90302  San Bernardino County Transportation Authority...
# 166767  90306              Stanislaus Regional Transit Authority
# 166779  90310      Tulare County Regional Transit Agency (TCRTA)
# 166787  90311  Stanislaus Council of Governments (StanCOG) - ...
# 168472  90314                       Attentive Transportation LLC
# 176318  91008                  Modoc Transportation Agency (MTA)
# 188654  91038       Sierra County - Department of Transportation
# 206182  91063        Calaveras County Department of Public Works
# 220329  91093                               City of Eureka (ETS)
# 232664  99256                  Susanville Indian Rancheria (SIR)
# 232678  99262            Yurok Tribe - Transportation Department
# 232690  99292       Blue Lake Rancheria (BLRTS) - Transportation
# 232698  99316  Chemehuevi Indian Tribe (CTA) - Reality and Pl...
# 232702  99358  Morongo Band of Mission Indians - Public Works...
# 232706  99364  North Fork Rancheria of Mono Indians of Califo...
# 232710  99422                        San Joaquin Council (SJCOG)
# 236874  99432                                 Amador Stage Lines
# 236881  99438        County of Shasta Department of Public Works
# 237845  99452                         Elk Valley Rancheria (EVR)

# %%
sco_xwalk_ntd[
    (sco_xwalk_ntd["_merge"] == "left_only")
    & (~sco_xwalk_ntd["entity name"].str.contains("- Specialized"))
][["entity id","entity name"]].drop_duplicates() 

# Thse sco entities did not xwalk to a ntd id
# Out:
#        entity id                                        entity name
# 93         13355                                            Anaheim
# 179          456                                            Banning
# 181          458                                           Beaumont
# 183         7318                                          Blue Lake
# 256         9379            Capitol Corridor Joint Powers Authority
# 279          472                                              Ceres
# 382          491                            County Service Area M-1
# 383        11244                            County Service Area T-1
# 435          496                              Delta Ferry Authority
# 760         9375                         Great Redwood Trail Agency
# 792        12745                    Heritage Valley Transit Service
# 793         8617                  Hermosa Beach Specialized Service
# 831        13347  Inglewood Transit Connector Joint Powers Autho...
# 1263       13223                        Modoc Transportation Agency
# 1364         579                                          Morro Bay
# 1757       12817                               Quechan Indian Tribe
# 1844         622                                              Ripon
# 1896         626                                            Rocklin
# 2060         633                      San Diego Transit Corporation
# 2061         634                             San Diego Trolley Inc.
# 2162       12750                 San Joaquin Joint Powers Authority
# 2271         648                               Santa Barbara County
# 2566       13211              Stanislaus Regional Transit Authority
# 2611         682                      Tahoe Transportation District
# 2694        9755                    Transbay Joint Powers Authority
# 2787       13213              Tulare County Regional Transit Agency
# 2955       13348                                    West Sacramento
# 2977       10378  Western Placer Consolidated Transportation Ser...
# 7539        9375                     North Coast Railroad Authority
# 8676         678                                  Stanislaus County
# 10500        576                           Monterey-Salinas Transit
# 11768        675                               South County Transit
# 11998        697                                    Tuolumne County

# %% [markdown]
# ### checking some of the familiar names to see if they even partial exist in other sources

# %%
agency = "Santa Barbara"
display(
    "initial SCO compiled data",
    sco_melt[
        (sco_melt["entity name"].str.contains(agency))
        & (~sco_melt["entity name"].str.contains("- Specialized"))
    ][
        [
            "entity id",
            "entity name",
        ]
    ].drop_duplicates(),
    "Crosswalk",
    sco_x_ntd_id[
        (sco_x_ntd_id["source_agency"].str.contains(agency))
        | (sco_x_ntd_id["sco_entity_name"].str.contains(agency))
    ],
    "initial NTD data",
    ntd_metrics_merge[ntd_metrics_merge["source_agency"].str.contains(agency)][
        [
            "ntd_id",
            "source_agency",
        ]
    ].drop_duplicates(),
)
# Out:
# 'initial SCO compiled data'
#      entity id                                        entity name
# 203        648                               Santa Barbara County
# 204      13023  Santa Barbara County Association of Government...
# 205        649        Santa Barbara Metropolitan Transit District
# 'Crosswalk'
#      ntd_id                                      source_agency  sco_entity_id  \
# 333   90020  Santa Barbara Metropolitan Transit District (S...            649
# 1528  90303  Santa Barbara County Association of Government...          13023
#
#                                         sco_entity_name
# 333         Santa Barbara Metropolitan Transit District
# 1528  Santa Barbara County Association of Government...
# 'initial NTD data'
#      ntd_id                                      source_agency
# 261   90020  Santa Barbara Metropolitan Transit District (S...
# 1655  90303  Santa Barbara County Association of Government...

# %% [markdown]
# ### Notes of mis-matched SCO entities, NTD agencies, entity ID and NTD IDs
# Looks like a lot of SCO ID changed between 21/22. Which is causing some mis-match
#
# 1. Tuolumne
#     - SCO -> 2 similar entities
#         - 13214 Tuolumne County Transit Agency,
#         - 697 Tuolumne County
#     - NTD - > 1 agency
#        - 91057 Tuolumne County Transit Agency (TCT, TCTA)
#
# 2. Monterey-Salinas Transit
#     - SCO -> 2 similar entities
#         - 13209 Monterey-Salinas Transit District
#         - 576 Monterey-Salinas Transit
#     - NTD -> 1 agency
#         - 90062	Monterey-Salinas Transit (MST)
# 3. Santa Barbara
#     - SCO -> 3
#         - 648	Santa Barbara County
#         - 13023	Santa Barbara County Association of Government...
#         - 649	Santa Barbara Metropolitan Transit District
#     - NTD -> 2
#         - 90020	Santa Barbara Metropolitan Transit District (S...
#         - 90303	Santa Barbara County Association of Government...
#
#
# Looks like a lot of time the SCO woudld have "...County" in entiry name. Where as NTD have the more official/legal sounding name.

# %% [markdown]
# # Of the Agencies that do exist in both dataset, how do their metrics match?
# - we know from a previous research that some agencies match 1:1 with sco and NTD
#   - SacRT
# - some agencies have to add their `specialized services` rows to match with NTD
#   - 2022 SacRT
# - some agencies partial match some years
#   - Alpine County
# - some just dont match at all
#   - San Diego MTS

# %%
# what is the total passengers, vrm, vrh  for all modes, for each sco entity
group_by_list = ["entity id", "entity name", "fiscal year"]

sco_melt_agg_passengers = (
    sco_melt[sco_melt["sco_metric_short"] == "total_passengers"]
    .groupby(group_by_list)
    .agg({"sco_metric_values": "sum"})
    .reset_index()
)

sco_melt_agg_vrh = (
    sco_melt[sco_melt["sco_metric_short"] == "total_vrh"]
    .groupby(group_by_list)
    .agg({"sco_metric_values": "sum"})
    .reset_index()
)

sco_melt_agg_vrm = (
    sco_melt[sco_melt["sco_metric_short"] == "total_vrm"]
    .groupby(group_by_list)
    .agg({"sco_metric_values": "sum"})
    .reset_index()
)

display(
    sco_melt_agg_passengers.info(), sco_melt_agg_vrh.info(), sco_melt_agg_vrm.info()
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1961 entries, 0 to 1960
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   entity id          1961 non-null   int64
#  1   entity name        1961 non-null   object
#  2   fiscal year        1961 non-null   int64
#  3   sco_metric_values  1961 non-null   float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 61.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1961 entries, 0 to 1960
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   entity id          1961 non-null   int64
#  1   entity name        1961 non-null   object
#  2   fiscal year        1961 non-null   int64
#  3   sco_metric_values  1961 non-null   float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 61.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1961 entries, 0 to 1960
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   entity id          1961 non-null   int64
#  1   entity name        1961 non-null   object
#  2   fiscal year        1961 non-null   int64
#  3   sco_metric_values  1961 non-null   float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 61.4+ KB
# None
# None
# None

# %%
# group by NTD data to total the metrics
ntd_metrics_agg_upt = (
    ntd_metrics_merge.groupby(["source_agency", "ntd_id", "year"])
    .agg({"total_upt": "sum"})
    .reset_index()
)
ntd_metrics_agg_vrm = (
    ntd_metrics_merge.groupby(["source_agency", "ntd_id", "year"])
    .agg({"total_vrm": "sum"})
    .reset_index()
)
ntd_metrics_agg_vrh = (
    ntd_metrics_merge.groupby(["source_agency", "ntd_id", "year"])
    .agg({"total_vrh": "sum"})
    .reset_index()
)

# %%
display(
    ntd_metrics_agg_upt.head(), ntd_metrics_agg_vrm.head(), ntd_metrics_agg_vrh.head()
)
# Out:
#           source_agency ntd_id  year    total_upt
# 0  Access Services (AS)  90157  2018 4,383,256.00
# 1  Access Services (AS)  90157  2019 4,458,330.00
# 2  Access Services (AS)  90157  2020 3,649,482.00
# 3  Access Services (AS)  90157  2021 2,136,786.00
# 4  Access Services (AS)  90157  2022 2,927,484.00
#           source_agency ntd_id  year     total_vrm
# 0  Access Services (AS)  90157  2018 37,903,473.00
# 1  Access Services (AS)  90157  2019 38,418,373.00
# 2  Access Services (AS)  90157  2020 33,095,070.00
# 3  Access Services (AS)  90157  2021 25,881,834.00
# 4  Access Services (AS)  90157  2022 28,077,169.00
#           source_agency ntd_id  year    total_vrh
# 0  Access Services (AS)  90157  2018 2,204,098.00
# 1  Access Services (AS)  90157  2019 2,171,933.00
# 2  Access Services (AS)  90157  2020 1,894,684.00
# 3  Access Services (AS)  90157  2021 1,298,283.00
# 4  Access Services (AS)  90157  2022 1,575,462.00

# %% [markdown]
# ## how much difference in metrics are there between sco and ntd
#
# The following merges just based on names

# %%
passenger_diff = sco_melt_agg_passengers.merge(
    ntd_metrics_agg_upt,
    how="inner",
    left_on=["entity name", "fiscal year"],
    right_on=["source_agency", "year"],
    indicator=True,
)

vrm_diff = sco_melt_agg_vrm.merge(
    ntd_metrics_agg_vrm,
    how="inner",
    left_on=["entity name", "fiscal year"],
    right_on=["source_agency", "year"],
    indicator=True,
)

vrh_diff = sco_melt_agg_vrh.merge(
    ntd_metrics_agg_vrh,
    how="inner",
    left_on=["entity name", "fiscal year"],
    right_on=["source_agency", "year"],
    indicator=True,
)


display(
    passenger_diff["_merge"].value_counts(),  # 46 matches
    vrh_diff["_merge"].value_counts(),  # 46 matches
    vrm_diff["_merge"].value_counts(),  # 46 matches
)
# Out:
# _merge
# both          46
# left_only      0
# right_only     0
# Name: count, dtype: int64
# _merge
# both          46
# left_only      0
# right_only     0
# Name: count, dtype: int64
# _merge
# both          46
# left_only      0
# right_only     0
# Name: count, dtype: int64

# %%
# calculate difference between value columns

passenger_diff["passenger_value_diff"] = (passenger_diff["sco_metric_values"] - passenger_diff["total_upt"])
vrh_diff["vrh_value_diff"] = vrh_diff["sco_metric_values"] - vrh_diff["total_vrh"]
vrm_diff["vrm_value_diff"] = vrm_diff["sco_metric_values"] - vrm_diff["total_vrm"]

# %%
# What agencies report the same passenger numbers between SCO and NTD?
display(
    passenger_diff[passenger_diff["passenger_value_diff"] == 0][
        "source_agency"
    ].unique(),
    vrh_diff[vrh_diff["vrh_value_diff"] == 0]["source_agency"].unique(),
    vrm_diff[vrm_diff["vrm_value_diff"] == 0]["source_agency"].unique(),
)  # the same: Foot
# Out:
# array(['Foothill Transit',
#        'San Francisco Bay Area Water Emergency Transportation Authority (WETA)',
#        'Yosemite Area Regional Transportation System (YARTS)',
#        'Stanislaus Regional Transit Authority'], dtype=object)
# array(['Foothill Transit',
#        'San Francisco Bay Area Water Emergency Transportation Authority (WETA)',
#        'Yosemite Area Regional Transportation System (YARTS)',
#        'Stanislaus Regional Transit Authority'], dtype=object)
# array(['Foothill Transit',
#        'San Francisco Bay Area Water Emergency Transportation Authority (WETA)',
#        'Yosemite Area Regional Transportation System (YARTS)',
#        'Stanislaus Regional Transit Authority'], dtype=object)

# %%
display(
    passenger_diff[passenger_diff["passenger_value_diff"] != 0][
        "source_agency"
    ].unique().tolist(),
    vrh_diff[vrh_diff["vrh_value_diff"] != 0]["source_agency"].unique().tolist(),
    vrm_diff[vrm_diff["vrm_value_diff"] != 0]["source_agency"].unique().tolist(),
)
# Out:
# ['Alameda-Contra Costa Transit District',
#  'Omnitrans',
#  'Imperial County Transportation Commission (ICTC)',
#  'Yosemite Area Regional Transportation System (YARTS)',
#  'Stanislaus Regional Transit Authority']
# ['Alameda-Contra Costa Transit District',
#  'Foothill Transit',
#  'Omnitrans',
#  'Imperial County Transportation Commission (ICTC)',
#  'San Francisco Bay Area Water Emergency Transportation Authority (WETA)',
#  'Yosemite Area Regional Transportation System (YARTS)',
#  'Stanislaus Regional Transit Authority']
# ['Alameda-Contra Costa Transit District',
#  'Foothill Transit',
#  'Omnitrans',
#  'Imperial County Transportation Commission (ICTC)',
#  'San Francisco Bay Area Water Emergency Transportation Authority (WETA)',
#  'Yosemite Area Regional Transportation System (YARTS)',
#  'Stanislaus Regional Transit Authority']

# %% [markdown]
# ## Try to use xwalk first then merge, then find diff

# %%
#### DRAFT ####
def sco_ntd_metric_diff(
    sco_data = pd.DataFrame,
    ntd_data = pd.DataFrame,
    xwalk = pd.DataFrame,
    metric = str
) -> pd.DataFrame:
    """
    Inner merges sco -> xwalk -> ntd data. then calculates the difference of the metric.
    Meant to be run in this notebook using the dataframes and columns names.
    """
    merge1 = sco_data.merge(
        xwalk,
        how = "inner",
        left_on=["entity id"],
        right_on=["sco_entity_id"],
    )

    merge2 = merge1.merge(
        ntd_data,
        left_on = ["ntd_id","fiscal year"],
        right_on = ["ntd_id", "year"],
    )

    merge2[f"{metric}_diff"] = merge2["sco_metric_values"] - merge2[f"total_{metric}"]

    return merge2

#### END ####

# %%
new_upt_xwalk_diff = sco_ntd_metric_diff(
    sco_data = sco_melt_agg_passengers,
    ntd_data = ntd_metrics_agg_upt,
    xwalk = sco_x_ntd_id,
    metric = "upt"
)
display(
    "Number of agencies with matching UPT values:",
    len(new_upt_xwalk_diff[new_upt_xwalk_diff["upt_diff"]==0]["source_agency_x"].unique()),
    "Number of agencies that did not match UPT values",
    len(new_upt_xwalk_diff[new_upt_xwalk_diff["upt_diff"]!=0]["source_agency_x"].unique())
)
# Out:
# 'Number of agencies with matches UPT values:'
# 83
# 'Number of agencies that did not match UPT values'
# 138

# %%
vrm_xwalk_diff = sco_ntd_metric_diff(
    sco_data = sco_melt_agg_vrm,
    ntd_data = ntd_metrics_agg_vrm,
    xwalk = sco_x_ntd_id,
    metric = "vrm"
)
display(
    "Number of agencies with matching vrm values:",
    len(vrm_xwalk_diff[vrm_xwalk_diff["vrm_diff"]==0]["source_agency_x"].unique()),
    "Number of agencies that did not match vrm values:",
    len(vrm_xwalk_diff[vrm_xwalk_diff["vrm_diff"]!=0]["source_agency_x"].unique())
)
# Out:
# 'Number of agencies with matching vrm values:'
# 37
# 'Number of agencies that did not match vrm values:'
# 152

# %%
vrh_xwalk_diff = sco_ntd_metric_diff(
    sco_data = sco_melt_agg_vrh,
    ntd_data = ntd_metrics_agg_vrh,
    xwalk = sco_x_ntd_id,
    metric = "vrh"
)
display(
    "Number of agencies with matching vrh values:",
    len(vrh_xwalk_diff[vrh_xwalk_diff["vrh_diff"]==0]["source_agency_x"].unique()),
    "Number of agencies that did not match vrh values",
    len(vrh_xwalk_diff[vrh_xwalk_diff["vrh_diff"]!=0]["source_agency_x"].unique())
)
# Out:
# 'Number of agencies with matching vrh values:'
# 36
# 'Number of agencies that did not match vrh values'
# 151

# %% [markdown]
# # These dont account for SCO entites that have similar NTD names, or SCO entites that have a `- specialized serivice` row.
# Additional analysis work wouldbe needed to reconcile these.

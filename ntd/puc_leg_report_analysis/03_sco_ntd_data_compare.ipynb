# %% [markdown]
# # Comparing ridership metrics between SCO and NTD
# There are instances of ridership and vehicle revenue hours values do not match between the SCO `Operator Data` tabs and equivilent NTD metrics.
#
# Explore the difference betwen the SCO data and NTD data.
# - what agencies appear just in SCO, just in NTD, both?
# - is there a crosswalk between sco entity ID and ntd id?
# - perform a t-test against the mean upt and mean vrh?

# %%
from functools import cache

import altair as alt
import pandas as pd
from calitp_data_analysis.gcs_pandas import GCSPandas
from calitp_data_analysis.sql import get_engine, query_sql, to_snakecase

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.options.display.float_format = "{:,.2f}".format


@cache
def gcs_pandas():
    return GCSPandas()


gcs_path = "gs://calitp-analytics-data/data-analyses/ntd/"

# %% [markdown]
# # read in latest SCO/NTD data from 02_puc_exempt_analysis

# %%
yes_no_merge_filname = "ntd_yes_no_data_2026-02-02.parquet"

ntd_yes_no_merge = gcs_pandas().read_parquet(f"{gcs_path}{yes_no_merge_filname}")

display(ntd_yes_no_merge.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4664 entries, 0 to 4663
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ntd_id               4664 non-null   object
#  1   source_agency        4664 non-null   object
#  2   agency_status        4664 non-null   object
#  3   primary_uza_name     3498 non-null   object
#  4   uza_population       4664 non-null   int64
#  5   uza_area_sq_miles    4664 non-null   float64
#  6   year                 4664 non-null   object
#  7   mode                 4664 non-null   object
#  8   type_of_service      4664 non-null   object
#  9   reporter_type        4664 non-null   object
#  10  total_vrh            3646 non-null   float64
#  11  total_upt            3646 non-null   float64
#  12  total_pmt            2194 non-null   float64
#  13  sco_entity_id        4664 non-null   int64
#  14  sco_entity_name      4664 non-null   object
#  15  operator_name        4664 non-null   object
#  16  ntd_agency_name      4664 non-null   object
#  17  area_type            4664 non-null   object
#  18  requirement          4664 non-null   object
#  19  was_requirement_met  4664 non-null   bool
#  20  _merge               4664 non-null   category
# dtypes: bool(1), category(1), float64(4), int64(2), object(13)
# memory usage: 701.7+ KB
# None

# %% [markdown]
# # Read in compiled "TO_OPERATING_DATA" data

# %%
sco_data_path = "consolidated_sco_ to_operating_data_02-04-2026.csv"

sco_data = gcs_pandas().read_csv(f"{gcs_path}{sco_data_path}")

display(sco_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1961 entries, 0 to 1960
# Columns: 107 entries, Entity Name to Date Service Began Operations (MM/DD/YYYY)_Other Transportation Mode (Specify)
# dtypes: float64(96), int64(2), object(9)
# memory usage: 1.6+ MB
# None

# %%
sco_columns = list(sco_data.columns)

sco_keep_cols = [
    "Entity Name",
    "Fiscal Year",
    "Entity ID",
    "Total Actual Vehicle Revenue Hours — Annual_Demand Response Vehicles_Actual Vehicle Revenue Hours — Annual",
    "Total Actual Vehicle Revenue Hours — Annual_Ferry Boat_Actual Vehicle Revenue Hours — Annual",
    "Total Actual Vehicle Revenue Hours — Annual_Heavy Rail_Actual Vehicle Revenue Hours — Annual",
    "Total Actual Vehicle Revenue Hours — Annual_Light Rail_Actual Vehicle Revenue Hours — Annual",
    "Total Actual Vehicle Revenue Hours — Annual_Motor Bus_Actual Vehicle Revenue Hours — Annual",
    "Total Actual Vehicle Revenue Hours — Annual_Other Transportation Mode (Specify)_Actual Vehicle Revenue Hours — Annual",
    "Total Actual Vehicle Revenue Hours — Annual_Trolley Bus_Actual Vehicle Revenue Hours — Annual",
    "Total Actual Vehicle Revenue Hours — Annual_Vanpool_Actual Vehicle Revenue Hours — Annual",
    "Total Actual Vehicle Revenue Miles_Demand Response Vehicles",
    "Total Actual Vehicle Revenue Miles_Ferry Boat",
    "Total Actual Vehicle Revenue Miles_Heavy Rail",
    "Total Actual Vehicle Revenue Miles_Light Rail",
    "Total Actual Vehicle Revenue Miles_Motor Bus",
    "Total Actual Vehicle Revenue Miles_Other Transportation Mode (Specify)",
    "Total Actual Vehicle Revenue Miles_Trolley Bus",
    "Total Actual Vehicle Revenue Miles_Vanpool",
    "Total Passengers — Annual_Demand Response Vehicles",
    "Total Passengers — Annual_Ferry Boat",
    "Total Passengers — Annual_Heavy Rail",
    "Total Passengers — Annual_Light Rail",
    "Total Passengers — Annual_Motor Bus",
    "Total Passengers — Annual_Other Transportation Mode (Specify)",
    "Total Passengers — Annual_Trolley Bus",
    "Total Passengers — Annual_Vanpool",
]
sorted(sco_columns)
# Out:
# ['Date Service Began Operations (MM/DD/YYYY)_Demand Response Vehicles',
#  'Date Service Began Operations (MM/DD/YYYY)_Ferry Boat',
#  'Date Service Began Operations (MM/DD/YYYY)_Heavy Rail',
#  'Date Service Began Operations (MM/DD/YYYY)_Light Rail',
#  'Date Service Began Operations (MM/DD/YYYY)_Motor Bus',
#  'Date Service Began Operations (MM/DD/YYYY)_Other Transportation Mode (Specify)',
#  'Date Service Began Operations (MM/DD/YYYY)_Trolley Bus',
#  'Date Service Began Operations (MM/DD/YYYY)_Vanpool',
#  'Entity ID',
#  'Entity Name',
#  'Fiscal Year',
#  'Revenue Vehicle Inventory_Demand Response Vehicles',
#  'Revenue Vehicle Inventory_Ferry Boat',
#  'Revenue Vehicle Inventory_Heavy Rail',
#  'Revenue Vehicle Inventory_Light Rail',
#  'Revenue Vehicle Inventory_Motor Bus',
#  'Revenue Vehicle Inventory_Other Transportation Mode (Specify)',
#  'Revenue Vehicle Inventory_Trolley Bus',
#  'Revenue Vehicle Inventory_Vanpool',
#  'Saturday_Demand Response Vehicles_Vehicles in Operation — Weekly',
#  'Saturday_Ferry Boat_Vehicles in Operation — Weekly',
#  'Saturday_Heavy Rail_Vehicles in Operation — Weekly',
#  'Saturday_Light Rail_Vehicles in Operation — Weekly',
#  'Saturday_Motor Bus_Vehicles in Operation — Weekly',
#  'Saturday_Other Transportation Mode (Specify)_Vehicles in Operation — Weekly',
#  'Saturday_Trolley Bus_Vehicles in Operation — Weekly',
#  'Saturday_Vanpool_Vehicles in Operation — Weekly',
#  'Saturdays_Demand Response Vehicles_Actual Vehicle Revenue Hours — Annual',
#  'Saturdays_Ferry Boat_Actual Vehicle Revenue Hours — Annual',
#  'Saturdays_Heavy Rail_Actual Vehicle Revenue Hours — Annual',
#  'Saturdays_Light Rail_Actual Vehicle Revenue Hours — Annual',
#  'Saturdays_Motor Bus_Actual Vehicle Revenue Hours — Annual',
#  'Saturdays_Other Transportation Mode (Specify)_Actual Vehicle Revenue Hours — Annual',
#  'Saturdays_Trolley Bus_Actual Vehicle Revenue Hours — Annual',
#  'Saturdays_Vanpool_Actual Vehicle Revenue Hours — Annual',
#  'Sunday_Demand Response Vehicles_Vehicles in Operation — Weekly',
#  'Sunday_Ferry Boat_Vehicles in Operation — Weekly',
#  'Sunday_Heavy Rail_Vehicles in Operation — Weekly',
#  'Sunday_Light Rail_Vehicles in Operation — Weekly',
#  'Sunday_Motor Bus_Vehicles in Operation — Weekly',
#  'Sunday_Other Transportation Mode (Specify)_Vehicles in Operation — Weekly',
#  'Sunday_Trolley Bus_Vehicles in Operation — Weekly',
#  'Sunday_Vanpool_Vehicles in Operation — Weekly',
#  'Sundays_Demand Response Vehicles_Actual Vehicle Revenue Hours — Annual',
#  'Sundays_Ferry Boat_Actual Vehicle Revenue Hours — Annual',
#  'Sundays_Heavy Rail_Actual Vehicle Revenue Hours — Annual',
#  'Sundays_Light Rail_Actual Vehicle Revenue Hours — Annual',
#  'Sundays_Motor Bus_Actual Vehicle Revenue Hours — Annual',
#  'Sundays_Other Transportation Mode (Specify)_Actual Vehicle Revenue Hours — Annual',
#  'Sundays_Trolley Bus_Actual Vehicle Revenue Hours — Annual',
#  'Sundays_Vanpool_Actual Vehicle Revenue Hours — Annual',
#  'Total Actual Vehicle Revenue Hours — Annual_Demand Response Vehicles_Actual Vehicle Revenue Hours — Annual',
#  'Total Actual Vehicle Revenue Hours — Annual_Ferry Boat_Actual Vehicle Revenue Hours — Annual',
#  'Total Actual Vehicle Revenue Hours — Annual_Heavy Rail_Actual Vehicle Revenue Hours — Annual',
#  'Total Actual Vehicle Revenue Hours — Annual_Light Rail_Actual Vehicle Revenue Hours — Annual',
#  'Total Actual Vehicle Revenue Hours — Annual_Motor Bus_Actual Vehicle Revenue Hours — Annual',
#  'Total Actual Vehicle Revenue Hours — Annual_Other Transportation Mode (Specify)_Actual Vehicle Revenue Hours — Annual',
#  'Total Actual Vehicle Revenue Hours — Annual_Trolley Bus_Actual Vehicle Revenue Hours — Annual',
#  'Total Actual Vehicle Revenue Hours — Annual_Vanpool_Actual Vehicle Revenue Hours — Annual',
#  'Total Actual Vehicle Revenue Miles_Demand Response Vehicles',
#  'Total Actual Vehicle Revenue Miles_Ferry Boat',
#  'Total Actual Vehicle Revenue Miles_Heavy Rail',
#  'Total Actual Vehicle Revenue Miles_Light Rail',
#  'Total Actual Vehicle Revenue Miles_Motor Bus',
#  'Total Actual Vehicle Revenue Miles_Other Transportation Mode (Specify)',
#  'Total Actual Vehicle Revenue Miles_Trolley Bus',
#  'Total Actual Vehicle Revenue Miles_Vanpool',
#  'Total Employees — Public and Contract_Demand Response Vehicles',
#  'Total Employees — Public and Contract_Ferry Boat',
#  'Total Employees — Public and Contract_Heavy Rail',
#  'Total Employees — Public and Contract_Light Rail',
#  'Total Employees — Public and Contract_Motor Bus',
#  'Total Employees — Public and Contract_Other Transportation Mode (Specify)',
#  'Total Employees — Public and Contract_Trolley Bus',
#  'Total Employees — Public and Contract_Vanpool',
#  'Total Passengers — Annual_Demand Response Vehicles',
#  'Total Passengers — Annual_Ferry Boat',
#  'Total Passengers — Annual_Heavy Rail',
#  'Total Passengers — Annual_Light Rail',
#  'Total Passengers — Annual_Motor Bus',
#  'Total Passengers — Annual_Other Transportation Mode (Specify)',
#  'Total Passengers — Annual_Trolley Bus',
#  'Total Passengers — Annual_Vanpool',
#  'Weekdays - Middays_Demand Response Vehicles_Vehicles in Operation — Weekly',
#  'Weekdays - Middays_Ferry Boat_Vehicles in Operation — Weekly',
#  'Weekdays - Middays_Heavy Rail_Vehicles in Operation — Weekly',
#  'Weekdays - Middays_Light Rail_Vehicles in Operation — Weekly',
#  'Weekdays - Middays_Motor Bus_Vehicles in Operation — Weekly',
#  'Weekdays - Middays_Other Transportation Mode (Specify)_Vehicles in Operation — Weekly',
#  'Weekdays - Middays_Trolley Bus_Vehicles in Operation — Weekly',
#  'Weekdays - Middays_Vanpool_Vehicles in Operation — Weekly',
#  'Weekdays - Peak_Demand Response Vehicles_Vehicles in Operation — Weekly',
#  'Weekdays - Peak_Ferry Boat_Vehicles in Operation — Weekly',
#  'Weekdays - Peak_Heavy Rail_Vehicles in Operation — Weekly',
#  'Weekdays - Peak_Light Rail_Vehicles in Operation — Weekly',
#  'Weekdays - Peak_Motor Bus_Vehicles in Operation — Weekly',
#  'Weekdays - Peak_Other Transportation Mode (Specify)_Vehicles in Operation — Weekly',
#  'Weekdays - Peak_Trolley Bus_Vehicles in Operation — Weekly',
#  'Weekdays - Peak_Vanpool_Vehicles in Operation — Weekly',
#  'Weekdays_Demand Response Vehicles_Actual Vehicle Revenue Hours — Annual',
#  'Weekdays_Ferry Boat_Actual Vehicle Revenue Hours — Annual',
#  'Weekdays_Heavy Rail_Actual Vehicle Revenue Hours — Annual',
#  'Weekdays_Light Rail_Actual Vehicle Revenue Hours — Annual',
#  'Weekdays_Motor Bus_Actual Vehicle Revenue Hours — Annual',
#  'Weekdays_Other Transportation Mode (Specify)_Actual Vehicle Revenue Hours — Annual',
#  'Weekdays_Trolley Bus_Actual Vehicle Revenue Hours — Annual',
#  'Weekdays_Vanpool_Actual Vehicle Revenue Hours — Annual']

# %%
sco_data = sco_data[sco_keep_cols]

sco_data.columns = sco_data.columns.str.lower()

# %%
sco_data.columns
# Out:
# Index(['entity name', 'fiscal year', 'entity id',
#        'total passengers — annual_motor bus',
#        'total passengers — annual_heavy rail',
#        'total passengers — annual_light rail',
#        'total passengers — annual_trolley bus',
#        'total passengers — annual_ferry boat',
#        'total passengers — annual_demand response vehicles',
#        'total passengers — annual_vanpool',
#        'total passengers — annual_other transportation mode (specify)',
#        'total actual vehicle revenue hours — annual_motor bus_actual vehicle revenue hours — annual',
#        'total actual vehicle revenue hours — annual_heavy rail_actual vehicle revenue hours — annual',
#        'total actual vehicle revenue hours — annual_light rail_actual vehicle revenue hours — annual',
#        'total actual vehicle revenue hours — annual_trolley bus_actual vehicle revenue hours — annual',
#        'total actual vehicle revenue hours — annual_ferry boat_actual vehicle revenue hours — annual',
#        'total actual vehicle revenue miles_motor bus',
#        'total actual vehicle revenue miles_heavy rail',
#        'total actual vehicle revenue miles_light rail',
#        'total actual vehicle revenue miles_trolley bus',
#        'total actual vehicle revenue miles_ferry boat'],
#       dtype='object')

# %%
# What happens i if melt the dataframe THEN sum the rows?

sco_data_melt = pd.melt(
    sco_data,
    id_vars=[
        "entity name",
        "fiscal year",
        "entity id",
    ],
    var_name="sco_metrics",
    value_vars=[
        "total passengers — annual_motor bus",
        "total passengers — annual_heavy rail",
        "total passengers — annual_light rail",
        "total passengers — annual_trolley bus",
        "total passengers — annual_ferry boat",
        "total passengers — annual_demand response vehicles",
        "total passengers — annual_vanpool",
        "total passengers — annual_other transportation mode (specify)",
        "total actual vehicle revenue hours — annual_motor bus_actual vehicle revenue hours — annual",
        "total actual vehicle revenue hours — annual_heavy rail_actual vehicle revenue hours — annual",
        "total actual vehicle revenue hours — annual_light rail_actual vehicle revenue hours — annual",
        "total actual vehicle revenue hours — annual_trolley bus_actual vehicle revenue hours — annual",
        "total actual vehicle revenue hours — annual_ferry boat_actual vehicle revenue hours — annual",
        "total actual vehicle revenue miles_motor bus",
        "total actual vehicle revenue miles_heavy rail",
        "total actual vehicle revenue miles_light rail",
        "total actual vehicle revenue miles_trolley bus",
        "total actual vehicle revenue miles_ferry boat",
    ],
    value_name="sco_metric_values",
)

sco_data_melt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35298 entries, 0 to 35297
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   entity name        35298 non-null  object
#  1   fiscal year        35298 non-null  int64
#  2   entity id          35298 non-null  int64
#  3   sco_metrics        35298 non-null  object
#  4   sco_metric_values  4800 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.3+ MB

# %%
sco_data_melt[sco_data_melt["entity name"].str.contains("Sacramento")][
    "entity name"
].unique()
# Out:
# array(['Sacramento County', 'Sacramento Regional Transit System',
#        'Sacramento Regional Transit System - Specialized Service',
#        'West Sacramento'], dtype=object)

# %%
sco_data_melt[sco_data_melt["entity id"] == 629].sort_values(
    by=["sco_metrics", "fiscal year"]
)
# Out:
#                               entity name  fiscal year  entity id  \
# 25399  Sacramento Regional Transit System         2018        629
# 25127  Sacramento Regional Transit System         2019        629
# 24847  Sacramento Regional Transit System         2020        629
# 24562  Sacramento Regional Transit System         2021        629
# 24276  Sacramento Regional Transit System         2022        629
# 23993  Sacramento Regional Transit System         2023        629
# 23715  Sacramento Regional Transit System         2024        629
# 19516  Sacramento Regional Transit System         2018        629
# 19244  Sacramento Regional Transit System         2019        629
# 18964  Sacramento Regional Transit System         2020        629
# 18679  Sacramento Regional Transit System         2021        629
# 18393  Sacramento Regional Transit System         2022        629
# 18110  Sacramento Regional Transit System         2023        629
# 17832  Sacramento Regional Transit System         2024        629
# 21477  Sacramento Regional Transit System         2018        629
# 21205  Sacramento Regional Transit System         2019        629
# 20925  Sacramento Regional Transit System         2020        629
# 20640  Sacramento Regional Transit System         2021        629
# 20354  Sacramento Regional Transit System         2022        629
# 20071  Sacramento Regional Transit System         2023        629
# 19793  Sacramento Regional Transit System         2024        629
# 17555  Sacramento Regional Transit System         2018        629
# 17283  Sacramento Regional Transit System         2019        629
# 17003  Sacramento Regional Transit System         2020        629
# 16718  Sacramento Regional Transit System         2021        629
# 16432  Sacramento Regional Transit System         2022        629
# 16149  Sacramento Regional Transit System         2023        629
# 15871  Sacramento Regional Transit System         2024        629
# 23438  Sacramento Regional Transit System         2018        629
# 23166  Sacramento Regional Transit System         2019        629
# 22886  Sacramento Regional Transit System         2020        629
# 22601  Sacramento Regional Transit System         2021        629
# 22315  Sacramento Regional Transit System         2022        629
# 22032  Sacramento Regional Transit System         2023        629
# 21754  Sacramento Regional Transit System         2024        629
# 35204  Sacramento Regional Transit System         2018        629
# 34932  Sacramento Regional Transit System         2019        629
# 34652  Sacramento Regional Transit System         2020        629
# 34367  Sacramento Regional Transit System         2021        629
# 34081  Sacramento Regional Transit System         2022        629
# 33798  Sacramento Regional Transit System         2023        629
# 33520  Sacramento Regional Transit System         2024        629
# 29321  Sacramento Regional Transit System         2018        629
# 29049  Sacramento Regional Transit System         2019        629
# 28769  Sacramento Regional Transit System         2020        629
# 28484  Sacramento Regional Transit System         2021        629
# 28198  Sacramento Regional Transit System         2022        629
# 27915  Sacramento Regional Transit System         2023        629
# 27637  Sacramento Regional Transit System         2024        629
# 31282  Sacramento Regional Transit System         2018        629
# 31010  Sacramento Regional Transit System         2019        629
# 30730  Sacramento Regional Transit System         2020        629
# 30445  Sacramento Regional Transit System         2021        629
# 30159  Sacramento Regional Transit System         2022        629
# 29876  Sacramento Regional Transit System         2023        629
# 29598  Sacramento Regional Transit System         2024        629
# 27360  Sacramento Regional Transit System         2018        629
# 27088  Sacramento Regional Transit System         2019        629
# 26808  Sacramento Regional Transit System         2020        629
# 26523  Sacramento Regional Transit System         2021        629
# 26237  Sacramento Regional Transit System         2022        629
# 25954  Sacramento Regional Transit System         2023        629
# 25676  Sacramento Regional Transit System         2024        629
# 33243  Sacramento Regional Transit System         2018        629
# 32971  Sacramento Regional Transit System         2019        629
# 32691  Sacramento Regional Transit System         2020        629
# 32406  Sacramento Regional Transit System         2021        629
# 32120  Sacramento Regional Transit System         2022        629
# 31837  Sacramento Regional Transit System         2023        629
# 31559  Sacramento Regional Transit System         2024        629
# 11672  Sacramento Regional Transit System         2018        629
# 11400  Sacramento Regional Transit System         2019        629
# 11120  Sacramento Regional Transit System         2020        629
# 10835  Sacramento Regional Transit System         2021        629
# 10549  Sacramento Regional Transit System         2022        629
# 10266  Sacramento Regional Transit System         2023        629
# 9988   Sacramento Regional Transit System         2024        629
# 9711   Sacramento Regional Transit System         2018        629
# 9439   Sacramento Regional Transit System         2019        629
# 9159   Sacramento Regional Transit System         2020        629
# 8874   Sacramento Regional Transit System         2021        629
# 8588   Sacramento Regional Transit System         2022        629
# 8305   Sacramento Regional Transit System         2023        629
# 8027   Sacramento Regional Transit System         2024        629
# 3828   Sacramento Regional Transit System         2018        629
# 3556   Sacramento Regional Transit System         2019        629
# 3276   Sacramento Regional Transit System         2020        629
# 2991   Sacramento Regional Transit System         2021        629
# 2705   Sacramento Regional Transit System         2022        629
# 2422   Sacramento Regional Transit System         2023        629
# 2144   Sacramento Regional Transit System         2024        629
# 5789   Sacramento Regional Transit System         2018        629
# 5517   Sacramento Regional Transit System         2019        629
# 5237   Sacramento Regional Transit System         2020        629
# 4952   Sacramento Regional Transit System         2021        629
# 4666   Sacramento Regional Transit System         2022        629
# 4383   Sacramento Regional Transit System         2023        629
# 4105   Sacramento Regional Transit System         2024        629
# 1867   Sacramento Regional Transit System         2018        629
# 1595   Sacramento Regional Transit System         2019        629
# 1315   Sacramento Regional Transit System         2020        629
# 1030   Sacramento Regional Transit System         2021        629
# 744    Sacramento Regional Transit System         2022        629
# 461    Sacramento Regional Transit System         2023        629
# 183    Sacramento Regional Transit System         2024        629
# 15594  Sacramento Regional Transit System         2018        629
# 15322  Sacramento Regional Transit System         2019        629
# 15042  Sacramento Regional Transit System         2020        629
# 14757  Sacramento Regional Transit System         2021        629
# 14471  Sacramento Regional Transit System         2022        629
# 14188  Sacramento Regional Transit System         2023        629
# 13910  Sacramento Regional Transit System         2024        629
# 7750   Sacramento Regional Transit System         2018        629
# 7478   Sacramento Regional Transit System         2019        629
# 7198   Sacramento Regional Transit System         2020        629
# 6913   Sacramento Regional Transit System         2021        629
# 6627   Sacramento Regional Transit System         2022        629
# 6344   Sacramento Regional Transit System         2023        629
# 6066   Sacramento Regional Transit System         2024        629
# 13633  Sacramento Regional Transit System         2018        629
# 13361  Sacramento Regional Transit System         2019        629
# 13081  Sacramento Regional Transit System         2020        629
# 12796  Sacramento Regional Transit System         2021        629
# 12510  Sacramento Regional Transit System         2022        629
# 12227  Sacramento Regional Transit System         2023        629
# 11949  Sacramento Regional Transit System         2024        629
#
#                                              sco_metrics  sco_metric_values
# 25399  total actual vehicle revenue hours — annual_fe...                NaN
# 25127  total actual vehicle revenue hours — annual_fe...                NaN
# 24847  total actual vehicle revenue hours — annual_fe...                NaN
# 24562  total actual vehicle revenue hours — annual_fe...                NaN
# 24276  total actual vehicle revenue hours — annual_fe...                NaN
# 23993  total actual vehicle revenue hours — annual_fe...                NaN
# 23715  total actual vehicle revenue hours — annual_fe...                NaN
# 19516  total actual vehicle revenue hours — annual_he...                NaN
# 19244  total actual vehicle revenue hours — annual_he...                NaN
# 18964  total actual vehicle revenue hours — annual_he...                NaN
# 18679  total actual vehicle revenue hours — annual_he...                NaN
# 18393  total actual vehicle revenue hours — annual_he...                NaN
# 18110  total actual vehicle revenue hours — annual_he...                NaN
# 17832  total actual vehicle revenue hours — annual_he...                NaN
# 21477  total actual vehicle revenue hours — annual_li...         248,656.00
# 21205  total actual vehicle revenue hours — annual_li...         243,341.00
# 20925  total actual vehicle revenue hours — annual_li...         206,957.00
# 20640  total actual vehicle revenue hours — annual_li...         198,439.00
# 20354  total actual vehicle revenue hours — annual_li...         200,698.00
# 20071  total actual vehicle revenue hours — annual_li...         200,390.00
# 19793  total actual vehicle revenue hours — annual_li...         200,768.00
# 17555  total actual vehicle revenue hours — annual_mo...         552,703.00
# 17283  total actual vehicle revenue hours — annual_mo...         551,871.00
# 17003  total actual vehicle revenue hours — annual_mo...         521,451.00
# 16718  total actual vehicle revenue hours — annual_mo...         558,865.00
# 16432  total actual vehicle revenue hours — annual_mo...         627,088.00
# 16149  total actual vehicle revenue hours — annual_mo...         618,702.00
# 15871  total actual vehicle revenue hours — annual_mo...         628,617.00
# 23438  total actual vehicle revenue hours — annual_tr...                NaN
# 23166  total actual vehicle revenue hours — annual_tr...                NaN
# 22886  total actual vehicle revenue hours — annual_tr...                NaN
# 22601  total actual vehicle revenue hours — annual_tr...                NaN
# 22315  total actual vehicle revenue hours — annual_tr...                NaN
# 22032  total actual vehicle revenue hours — annual_tr...                NaN
# 21754  total actual vehicle revenue hours — annual_tr...                NaN
# 35204      total actual vehicle revenue miles_ferry boat                NaN
# 34932      total actual vehicle revenue miles_ferry boat                NaN
# 34652      total actual vehicle revenue miles_ferry boat                NaN
# 34367      total actual vehicle revenue miles_ferry boat                NaN
# 34081      total actual vehicle revenue miles_ferry boat                NaN
# 33798      total actual vehicle revenue miles_ferry boat                NaN
# 33520      total actual vehicle revenue miles_ferry boat                NaN
# 29321      total actual vehicle revenue miles_heavy rail                NaN
# 29049      total actual vehicle revenue miles_heavy rail                NaN
# 28769      total actual vehicle revenue miles_heavy rail                NaN
# 28484      total actual vehicle revenue miles_heavy rail                NaN
# 28198      total actual vehicle revenue miles_heavy rail                NaN
# 27915      total actual vehicle revenue miles_heavy rail                NaN
# 27637      total actual vehicle revenue miles_heavy rail                NaN
# 31282      total actual vehicle revenue miles_light rail       4,418,237.00
# 31010      total actual vehicle revenue miles_light rail       4,343,974.00
# 30730      total actual vehicle revenue miles_light rail       3,610,107.00
# 30445      total actual vehicle revenue miles_light rail       3,540,687.00
# 30159      total actual vehicle revenue miles_light rail       3,606,132.00
# 29876      total actual vehicle revenue miles_light rail       3,606,132.00
# 29598      total actual vehicle revenue miles_light rail       3,605,817.00
# 27360       total actual vehicle revenue miles_motor bus       6,214,397.00
# 27088       total actual vehicle revenue miles_motor bus       6,234,944.00
# 26808       total actual vehicle revenue miles_motor bus       5,907,222.00
# 26523       total actual vehicle revenue miles_motor bus       6,345,763.00
# 26237       total actual vehicle revenue miles_motor bus       7,320,594.00
# 25954       total actual vehicle revenue miles_motor bus       7,219,695.00
# 25676       total actual vehicle revenue miles_motor bus       7,328,995.00
# 33243     total actual vehicle revenue miles_trolley bus                NaN
# 32971     total actual vehicle revenue miles_trolley bus                NaN
# 32691     total actual vehicle revenue miles_trolley bus                NaN
# 32406     total actual vehicle revenue miles_trolley bus                NaN
# 32120     total actual vehicle revenue miles_trolley bus                NaN
# 31837     total actual vehicle revenue miles_trolley bus                NaN
# 31559     total actual vehicle revenue miles_trolley bus                NaN
# 11672  total passengers — annual_demand response vehi...          16,065.00
# 11400  total passengers — annual_demand response vehi...          98,590.00
# 11120  total passengers — annual_demand response vehi...         126,099.00
# 10835  total passengers — annual_demand response vehi...         305,377.00
# 10549  total passengers — annual_demand response vehi...         194,321.00
# 10266  total passengers — annual_demand response vehi...         200,126.00
# 9988   total passengers — annual_demand response vehi...         184,669.00
# 9711                total passengers — annual_ferry boat                NaN
# 9439                total passengers — annual_ferry boat                NaN
# 9159                total passengers — annual_ferry boat                NaN
# 8874                total passengers — annual_ferry boat                NaN
# 8588                total passengers — annual_ferry boat                NaN
# 8305                total passengers — annual_ferry boat                NaN
# 8027                total passengers — annual_ferry boat                NaN
# 3828                total passengers — annual_heavy rail                NaN
# 3556                total passengers — annual_heavy rail                NaN
# 3276                total passengers — annual_heavy rail                NaN
# 2991                total passengers — annual_heavy rail                NaN
# 2705                total passengers — annual_heavy rail                NaN
# 2422                total passengers — annual_heavy rail                NaN
# 2144                total passengers — annual_heavy rail                NaN
# 5789                total passengers — annual_light rail      10,372,688.00
# 5517                total passengers — annual_light rail       9,980,850.00
# 5237                total passengers — annual_light rail       8,988,806.00
# 4952                total passengers — annual_light rail       3,846,697.00
# 4666                total passengers — annual_light rail       4,631,772.00
# 4383                total passengers — annual_light rail       4,631,772.00
# 4105                total passengers — annual_light rail       6,783,370.00
# 1867                 total passengers — annual_motor bus      10,501,555.00
# 1595                 total passengers — annual_motor bus       9,909,691.00
# 1315                 total passengers — annual_motor bus       8,448,833.00
# 1030                 total passengers — annual_motor bus       3,935,860.00
# 744                  total passengers — annual_motor bus       6,275,461.00
# 461                  total passengers — annual_motor bus       7,690,492.00
# 183                  total passengers — annual_motor bus       9,026,468.00
# 15594  total passengers — annual_other transportation...                NaN
# 15322  total passengers — annual_other transportation...                NaN
# 15042  total passengers — annual_other transportation...                NaN
# 14757  total passengers — annual_other transportation...                NaN
# 14471  total passengers — annual_other transportation...                NaN
# 14188  total passengers — annual_other transportation...                NaN
# 13910  total passengers — annual_other transportation...                NaN
# 7750               total passengers — annual_trolley bus                NaN
# 7478               total passengers — annual_trolley bus                NaN
# 7198               total passengers — annual_trolley bus                NaN
# 6913               total passengers — annual_trolley bus                NaN
# 6627               total passengers — annual_trolley bus                NaN
# 6344               total passengers — annual_trolley bus                NaN
# 6066               total passengers — annual_trolley bus                NaN
# 13633                  total passengers — annual_vanpool                NaN
# 13361                  total passengers — annual_vanpool                NaN
# 13081                  total passengers — annual_vanpool                NaN
# 12796                  total passengers — annual_vanpool                NaN
# 12510                  total passengers — annual_vanpool                NaN
# 12227                  total passengers — annual_vanpool                NaN
# 11949                  total passengers — annual_vanpool                NaN

# %%
sco_data_melt.columns
# Out:
# Index(['entity name', 'fiscal year', 'entity id', 'sco_metrics',
#        'sco_metric_values'],
#       dtype='object')

# %%
sco_data_melt["sco_metrics"].unique()
# Out:
# array(['total passengers — annual_motor bus',
#        'total passengers — annual_heavy rail',
#        'total passengers — annual_light rail',
#        'total passengers — annual_trolley bus',
#        'total passengers — annual_ferry boat',
#        'total passengers — annual_demand response vehicles',
#        'total passengers — annual_vanpool',
#        'total passengers — annual_other transportation mode (specify)',
#        'total actual vehicle revenue hours — annual_motor bus_actual vehicle revenue hours — annual',
#        'total actual vehicle revenue hours — annual_heavy rail_actual vehicle revenue hours — annual',
#        'total actual vehicle revenue hours — annual_light rail_actual vehicle revenue hours — annual',
#        'total actual vehicle revenue hours — annual_trolley bus_actual vehicle revenue hours — annual',
#        'total actual vehicle revenue hours — annual_ferry boat_actual vehicle revenue hours — annual',
#        'total actual vehicle revenue miles_motor bus',
#        'total actual vehicle revenue miles_heavy rail',
#        'total actual vehicle revenue miles_light rail',
#        'total actual vehicle revenue miles_trolley bus',
#        'total actual vehicle revenue miles_ferry boat'], dtype=object)

# %%
group_cols = ["entity name", "fiscal year", "entity id",]

passenger_cols = [
    "total passengers — annual_motor bus",
    "total passengers — annual_heavy rail",
    "total passengers — annual_light rail",
    "total passengers — annual_trolley bus",
    "total passengers — annual_ferry boat",
    "total passengers — annual_demand response vehicles",
    "total passengers — annual_vanpool",
    "total passengers — annual_other transportation mode (specify)",
]

vrh_cols = [
    "total actual vehicle revenue hours — annual_motor bus_actual vehicle revenue hours — annual",
    "total actual vehicle revenue hours — annual_heavy rail_actual vehicle revenue hours — annual",
    "total actual vehicle revenue hours — annual_light rail_actual vehicle revenue hours — annual",
    "total actual vehicle revenue hours — annual_trolley bus_actual vehicle revenue hours — annual",
    "total actual vehicle revenue hours — annual_ferry boat_actual vehicle revenue hours — annual",
]

vrm_cols = [
    "total actual vehicle revenue miles_motor bus",
    "total actual vehicle revenue miles_heavy rail",
    "total actual vehicle revenue miles_light rail",
    "total actual vehicle revenue miles_trolley bus",
    "total actual vehicle revenue miles_ferry boat",
]


value_vars = [
    "total passengers — annual_motor bus",
    "total passengers — annual_heavy rail",
    "total passengers — annual_light rail",
    "total passengers — annual_trolley bus",
    "total passengers — annual_ferry boat",
    "total passengers — annual_demand response vehicles",
    "total passengers — annual_vanpool",
    "total passengers — annual_other transportation mode (specify)",
    "total actual vehicle revenue hours — annual_motor bus_actual vehicle revenue hours — annual",
    "total actual vehicle revenue hours — annual_heavy rail_actual vehicle revenue hours — annual",
    "total actual vehicle revenue hours — annual_light rail_actual vehicle revenue hours — annual",
    "total actual vehicle revenue hours — annual_trolley bus_actual vehicle revenue hours — annual",
    "total actual vehicle revenue hours — annual_ferry boat_actual vehicle revenue hours — annual",
    "total actual vehicle revenue miles_motor bus",
    "total actual vehicle revenue miles_heavy rail",
    "total actual vehicle revenue miles_light rail",
    "total actual vehicle revenue miles_trolley bus",
    "total actual vehicle revenue miles_ferry boat",
]
agg_tuple = ("sco_metric_values", "sum")

# %%
metric_list = [
    passenger_cols,
    vrh_cols,
    vrm_cols
]

# sco_data_passenger_agg = (
#     sco_data_melt[sco_data_melt["sco_metrics"].isin(passenger_cols)].groupby(group_cols).agg(
#         total_passenger = agg_tuple).reset_index()
# )

test_append=[]

for i in metric_list:

    agg = (
        sco_data_melt[sco_data_melt["sco_metrics"].isin(i)].groupby(group_cols).agg(
        total_passenger = agg_tuple).reset_index()
    )

    test_append.append(agg)

# %%
type(test_append)
# Out:
# list

# %%
len(test_append)
# Out:
# 3

# %%
type(test_append[1])
# Out:
# pandas.core.frame.DataFrame

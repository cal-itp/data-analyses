# %% [markdown]
# # Confirming the operators under `El Dorado County Transportation Commission` and `Placer County Transportation Planning Agency`

# %% [markdown]
# El Dorado and Placer County inquired us asking where is the "published data" Caltrans is promised to deliver to RTPAs, via sb125. as of 10/17, the monthly ridership site did not have a separate tab for these RTPAs. Further investigation shows that though these RTPAs did not have separate tabs, some (if not all) the associated transit operators were showing under the SACOG tab. (City of Placer, El Dorado County Transit Authority)
#
# Before splitting out the these operatos and RTPAs into separate tabs, need to confirm if any other transit operators are under these RTPAs, then update the rtpa ntd id crosswalk file.

# %% [markdown]
# Per Tiffany
# >This crosswalk you use is `ntd_id to RTPA`. You can combine that with several warehouse tables:
# >
# >- `dim_organizations` and `dim_gtfs_datasets` and `dim_provider_gtfs_data`
# >
# >- since the above is a fairly complicated traversal, in `shared_utils`, there's a function that wraps this and gets you from a starting poitn of  a `schedule_gtfs_dataset_key` (operator) to `ntd_id`. It is used and created here.
# >
# >- Operators (based on GTFS schedule) are subject to a date. If you know which date you want, you can use the crosswalk created and saved >out here in `gtfs_analytics_data.yml` find the GCS path. This will get you the operator's `schedule_gtfs_dataset_key` + `ntd_id` + other ntd columns and you can connect that to your `ntd_id - RTPA` crosswalk."

# %%
import pandas as pd
import shutil
import sys
import os
import gcsfs
from calitp_data_analysis.tables import tbls
from siuba import _, collect, count, filter, show_query
from shared_utils.rt_dates import MONTH_DICT
from segment_speed_utils import helpers

from update_vars import NTD_MODES, NTD_TOS, YEAR, MONTH

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
from shared_utils.schedule_rt_utils import sample_gtfs_dataset_key_to_organization_crosswalk

# %% [markdown]
# ---

# %% [markdown]
# ## testing the `create_gtfs_dataset_key_to_organization_crosswalk` function
# uses the `sample_schedule_feed_key_to_organization_crosswalk` function. this should give us gtfs `schedule feed`, `org name` and `ntd ID`

# %%
def create_gtfs_dataset_key_to_organization_crosswalk(
    analysis_date: str
) -> pd.DataFrame:
    """
    For every operator that appears in schedule data, 
    create a crosswalk that links to organization_source_record_id.
    For all our downstream outputs, at various aggregations,
    we need to attach these over and over again.
    """
    df = helpers.import_scheduled_trips(
        analysis_date,
        columns = ["gtfs_dataset_key", "name"],
        get_pandas = True
    ).rename(columns = {"schedule_gtfs_dataset_key": "gtfs_dataset_key"})
    # rename columns because we must use simply gtfs_dataset_key in schedule_rt_utils function
    
    # Get base64_url, organization_source_record_id and organization_name
    crosswalk = sample_gtfs_dataset_key_to_organization_crosswalk(
        df,
        analysis_date,
        quartet_data = "schedule",
        dim_gtfs_dataset_cols = ["key", "source_record_id", "base64_url"],
        dim_organization_cols = ["source_record_id", "name", 
                                 "itp_id", "caltrans_district",
                                  "ntd_id_2022"]
    )

    df_with_org = pd.merge(
        df.rename(columns = {"gtfs_dataset_key": "schedule_gtfs_dataset_key"}),
        crosswalk,
        on = "schedule_gtfs_dataset_key",
        how = "inner"
    )
    
    return df_with_org

# %%
gtfs_to_org = create_gtfs_dataset_key_to_organization_crosswalk(
            "2024-08-14"
        )

# %%
gtfs_to_org.shape
# Out:
# (206, 9)

# %%
gtfs_to_org.head()
# Out:
#           schedule_gtfs_dataset_key               name  \
# 0  1770249a5a2e770ca90628434d4934b1  VCTC GMV Schedule
# 1  1770249a5a2e770ca90628434d4934b1  VCTC GMV Schedule
# 2  1770249a5a2e770ca90628434d4934b1  VCTC GMV Schedule
# 3  1770249a5a2e770ca90628434d4934b1  VCTC GMV Schedule
# 4  1770249a5a2e770ca90628434d4934b1  VCTC GMV Schedule
#
#   schedule_source_record_id                        base64_url  \
# 0         recrAG7e0oOiR6FiP  aHR0cHM6Ly9nb3ZjYnVzLmNvbS9ndGZz
# 1         recrAG7e0oOiR6FiP  aHR0cHM6Ly9nb3ZjYnVzLmNvbS9ndGZz
# 2         recrAG7e0oOiR6FiP  aHR0cHM6Ly9nb3ZjYnVzLmNvbS9ndGZz
# 3         recrAG7e0oOiR6FiP  aHR0cHM6Ly9nb3ZjYnVzLmNvbS9ndGZz
# 4         recrAG7e0oOiR6FiP  aHR0cHM6Ly9nb3ZjYnVzLmNvbS9ndGZz
#
#   organization_source_record_id                         organization_name  \
# 0             reckQmUdXUzHFmlVf                              City of Ojai
# 1             rec7EN71rsZxDFxZd  Ventura County Transportation Commission
# 2             recS7GnKTcQVX20HE               Gold Coast Transit District
# 3             rec1ErIn9gG1Isk5W                       City of Simi Valley
# 4             recojKzQsBzE1hjVu                          City of Moorpark
#
#    itp_id caltrans_district ntd_id_2022
# 0   231.0  07 - Los Angeles       91058
# 1   380.0  07 - Los Angeles       90164
# 2   123.0  07 - Los Angeles       90035
# 3   308.0  07 - Los Angeles       90050
# 4   210.0  07 - Los Angeles       90227

# %% [markdown]
# ---

# %% [markdown]
# ##  If you know which date you want, you can use the crosswalk created and saved out here in `gtfs_analytics_data.yml` find the GCS path.
#
# should also give us `gtfs schedule feed`, `org name` and `ntd id`

# %%
aug_crosswalk = pd.read_parquet(
    "gs://calitp-analytics-data/data-analyses/gtfs_schedule/crosswalk/gtfs_key_organization_2024-08-14.parquet"
)

# %%
display(
    aug_crosswalk.shape,
    list(aug_crosswalk.columns.sort_values())

)
# Out:
# (206, 31)
# ['base64_url',
#  'caltrans_district',
#  'counties_served',
#  'density',
#  'funding_sources',
#  'hq_city',
#  'hq_county',
#  'is_public_entity',
#  'is_publicly_operating',
#  'itp_id',
#  'name',
#  'number_of_counties_with_service',
#  'number_of_state_counties',
#  'on_demand_vehicles_at_max_service',
#  'organization_name',
#  'organization_source_record_id',
#  'organization_type',
#  'population',
#  'primary_uza',
#  'reporter_type',
#  'schedule_gtfs_dataset_key',
#  'schedule_source_record_id',
#  'service_area_pop',
#  'service_area_sq_miles',
#  'state_admin_funds_expended',
#  'subrecipient_type',
#  'uza_name',
#  'vehicles_at_max_service',
#  'voms_do',
#  'voms_pt',
#  'year']

# %%
aug_crosswalk.head()
# Out:
#           schedule_gtfs_dataset_key               name  \
# 0  1770249a5a2e770ca90628434d4934b1  VCTC GMV Schedule
# 1  1770249a5a2e770ca90628434d4934b1  VCTC GMV Schedule
# 2  1770249a5a2e770ca90628434d4934b1  VCTC GMV Schedule
# 3  1770249a5a2e770ca90628434d4934b1  VCTC GMV Schedule
# 4  1770249a5a2e770ca90628434d4934b1  VCTC GMV Schedule
#
#   schedule_source_record_id                        base64_url  \
# 0         recrAG7e0oOiR6FiP  aHR0cHM6Ly9nb3ZjYnVzLmNvbS9ndGZz
# 1         recrAG7e0oOiR6FiP  aHR0cHM6Ly9nb3ZjYnVzLmNvbS9ndGZz
# 2         recrAG7e0oOiR6FiP  aHR0cHM6Ly9nb3ZjYnVzLmNvbS9ndGZz
# 3         recrAG7e0oOiR6FiP  aHR0cHM6Ly9nb3ZjYnVzLmNvbS9ndGZz
# 4         recrAG7e0oOiR6FiP  aHR0cHM6Ly9nb3ZjYnVzLmNvbS9ndGZz
#
#   organization_source_record_id                         organization_name  \
# 0             reckQmUdXUzHFmlVf                              City of Ojai
# 1             rec7EN71rsZxDFxZd  Ventura County Transportation Commission
# 2             recS7GnKTcQVX20HE               Gold Coast Transit District
# 3             rec1ErIn9gG1Isk5W                       City of Simi Valley
# 4             recojKzQsBzE1hjVu                          City of Moorpark
#
#    itp_id caltrans_district      counties_served      hq_city hq_county  \
# 0   231.0  07 - Los Angeles                 None         Ojai      None
# 1   380.0  07 - Los Angeles  Santa Clara;Ventura    Camarillo   Ventura
# 2   123.0  07 - Los Angeles              Ventura       Oxnard   Ventura
# 3   308.0  07 - Los Angeles              Ventura  Simi Valley   Ventura
# 4   210.0  07 - Los Angeles              Ventura         None   Ventura
#
#   is_public_entity is_publicly_operating funding_sources  \
# 0             None                  None            None
# 1             True                  True  5307;5311;5339
# 2             True                  True  5307;5310;5339
# 3             True                  True            5307
# 4             True                  True            5307
#
#    on_demand_vehicles_at_max_service  vehicles_at_max_service  \
# 0                                  2                        2
# 1                               <NA>                       45
# 2                                 49                       71
# 3                                 17                       17
# 4                               <NA>                        2
#
#    number_of_state_counties                                uza_name  density  \
# 0                      <NA>                                    None      NaN
# 1                      <NA>  Oxnard--San Buenaventura (Ventura), CA   4910.0
# 2                      <NA>  Oxnard--San Buenaventura (Ventura), CA   4910.0
# 3                      <NA>                         Simi Valley, CA   4027.0
# 4                      <NA>                       Thousand Oaks, CA   2668.0
#
#    number_of_counties_with_service  state_admin_funds_expended  \
# 0                             <NA>                         NaN
# 1                             <NA>                         NaN
# 2                             <NA>                         NaN
# 3                             <NA>                         NaN
# 4                             <NA>                         NaN
#
#    service_area_sq_miles  population  service_area_pop  \
# 0                   <NA>         NaN              <NA>
# 1                     28    376117.0            209877
# 2                     84    376117.0            374827
# 3                     50    127364.0            126356
# 4                     12    213986.0             35975
#
#               subrecipient_type primary_uza     reporter_type  \
# 0  Rural General Public Transit        None    Rural Reporter
# 1                          None        None     Full Reporter
# 2                          None        None     Full Reporter
# 3                          None        None  Reduced Reporter
# 4                          None        None  Reduced Reporter
#
#                                    organization_type  voms_pt  voms_do  year
# 0  County or Local Government Unit or Department ...     <NA>        2  2022
# 1      Public Agency or Authority of Transit Service       45     <NA>  2022
# 2      Public Agency or Authority of Transit Service       22       49  2022
# 3  County or Local Government Unit or Department ...     <NA>       17  2022
# 4  County or Local Government Unit or Department ...        2     <NA>  2022

# %%
aug_crosswalk["name"].value_counts()
# Out:
# VCTC GMV Schedule                                       7
# San Diego Schedule                                      4
# Humboldt Schedule                                       3
# North County Schedule                                   2
# TART, North Lake Tahoe Schedule                         2
# Tehama Schedule                                         2
# Foothill Schedule                                       2
# Redding Schedule                                        2
# Bay Area 511 SolTrans Schedule                          2
# Bay Area 511 Sonoma County Transit Schedule             2
# Bay Area 511 Muni Schedule                              2
# Bay Area 511 Santa Clara Transit Schedule               2
# Bay Area 511 Commute.org Schedule                       2
# Flixbus Schedule                                        2
# UCSC Schedule                                           2
# Metrolink Schedule                                      2
# Roseville Transit GMV Schedule                          1
# eTrans Schedule                                         1
# Needles Schedule                                        1
# Plumas Schedule                                         1
# Arcadia Schedule                                        1
# Spirit Bus Passio Schedule                              1
# B-Line Schedule                                         1
# Alhambra Schedule                                       1
# LAX FlyAway Schedule                                    1
# YARTS Schedule                                          1
# Beaumont Pass Schedule                                  1
# Redwood Coast Schedule                                  1
# Siskiyou Schedule                                       1
# South County Transit Link Schedule                      1
# Yuba-Sutter Schedule                                    1
# Calaveras Schedule                                      1
# Kern Schedule                                           1
# Desert Roadrunner GMV Schedule                          1
# Madera County Connection Schedule                       1
# Lassen Schedule                                         1
# El Monte Schedule                                       1
# Sage Stage Schedule                                     1
# Delano Schedule                                         1
# Victor Valley GMV Schedule                              1
# Lynwood Schedule IPS                                    1
# Monterey Salinas Schedule                               1
# Mountain Transit GMV Schedule                           1
# OCTA Schedule                                           1
# San Joaquin Schedule                                    1
# Yolobus Schedule                                        1
# Yuma Schedule                                           1
# Big Blue Bus Swiftly Schedule                           1
# Arvin Schedule                                          1
# DowneyLINK GMV Schedule                                 1
# Bay Area 511 Caltrain Schedule                          1
# Bay Area 511 Dumbarton Express Schedule                 1
# Bay Area 511 Emery Go-Round Schedule                    1
# Bay Area 511 Vacaville City Coach Schedule              1
# Bay Area 511 Vine Transit Schedule                      1
# Bay Area 511 WestCAT Schedule                           1
# Bay Area 511 Tri-Valley Wheels Schedule                 1
# Bellflower Bus Schedule                                 1
# SunLine Avail Schedule                                  1
# Cerritos on Wheels Website Schedule                     1
# Torrance Schedule                                       1
# Unitrans Schedule                                       1
# Clean Air Express Schedule                              1
# Visalia Schedule                                        1
# Merced GMV Schedule                                     1
# SLORTA Schedule                                         1
# StanRTA Schedule                                        1
# Grapeline Schedule                                      1
# PresidiGo Schedule                                      1
# LA Metro Bus Schedule                                   1
# Bay Area 511 Union City Transit Schedule                1
# Bay Area 511 Treasure Island Ferry Schedule             1
# Elk Grove Schedule                                      1
# Bay Area 511 Rio Vista Delta Breeze Schedule            1
# Bay Area 511 Fairfield and Suisun Transit Schedule      1
# Bay Area 511 Golden Gate Ferry Schedule                 1
# Bay Area 511 Golden Gate Transit Schedule               1
# Bay Area 511 Marin Schedule                             1
# Bay Area 511 Mission Bay Schedule                       1
# Bay Area 511 MVGO Schedule                              1
# Bay Area 511 Petaluma Schedule                          1
# Bay Area 511 Sonoma-Marin Area Rail Transit Schedule    1
# Bay Area 511 South San Francisco Shuttle Schedule       1
# Bay Area 511 San Francisco Bay Ferry Schedule           1
# G Trans Schedule                                        1
# Burbank Schedule                                        1
# Bay Area 511 SFO AirTrain Schedule                      1
# Bay Area 511 SamTrans Schedule                          1
# Beach Cities GMV Schedule                               1
# Bay Area 511 Santa Rosa CityBus Schedule                1
# Kings Schedule                                          1
# Name: name, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# Compare the dataframes in both methods to compare the values. they may be the same things but the initiald DF has ntd id

# %%
display(
    gtfs_to_org.columns,
    aug_crosswalk.columns
)
# Out:
# Index(['schedule_gtfs_dataset_key', 'name', 'schedule_source_record_id',
#        'base64_url', 'organization_source_record_id', 'organization_name',
#        'itp_id', 'caltrans_district', 'ntd_id_2022'],
#       dtype='object')
# Index(['schedule_gtfs_dataset_key', 'name', 'schedule_source_record_id',
#        'base64_url', 'organization_source_record_id', 'organization_name',
#        'itp_id', 'caltrans_district', 'counties_served', 'hq_city',
#        'hq_county', 'is_public_entity', 'is_publicly_operating',
#        'funding_sources', 'on_demand_vehicles_at_max_service',
#        'vehicles_at_max_service', 'number_of_state_counties', 'uza_name',
#        'density', 'number_of_counties_with_service',
#        'state_admin_funds_expended', 'service_area_sq_miles', 'population',
#        'service_area_pop', 'subrecipient_type', 'primary_uza', 'reporter_type',
#        'organization_type', 'voms_pt', 'voms_do', 'year'],
#       dtype='object')

# %%
col = [
    "schedule_gtfs_dataset_key",
    "name",
    "schedule_source_record_id",
    "organization_source_record_id",
    "itp_id"
]

for i in col:
    print(
        gtfs_to_org[i].unique() == aug_crosswalk[i].unique()
    )

# looks good! move forward with gtfs_to_org
# Out:
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True False  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True]

# %% [markdown]
# ---

# %% [markdown]
# - analyze the gtfs_to_org df
# - what agencies are in in

# %%
list(gtfs_to_org.columns)
# Out:
# ['schedule_gtfs_dataset_key',
#  'name',
#  'schedule_source_record_id',
#  'base64_url',
#  'organization_source_record_id',
#  'organization_name',
#  'itp_id',
#  'caltrans_district',
#  'ntd_id_2022']

# %%
gtfs_to_org.describe(include=object)
# Out:
#                schedule_gtfs_dataset_key               name  \
# count                                206                206
# unique                               182                182
# top     1770249a5a2e770ca90628434d4934b1  VCTC GMV Schedule
# freq                                   7                  7
#
#        schedule_source_record_id                        base64_url  \
# count                        206                               206
# unique                       182                               182
# top            recrAG7e0oOiR6FiP  aHR0cHM6Ly9nb3ZjYnVzLmNvbS9ndGZz
# freq                           7                                 7
#
#        organization_source_record_id       organization_name  \
# count                            206                     206
# unique                           189                     189
# top                recg58MziBRsVfavn  Yosemite National Park
# freq                               2                       2
#
#        caltrans_district ntd_id_2022
# count                204         168
# unique                12         153
# top     07 - Los Angeles       90030
# freq                  59           2

# %%
gtfs_to_org[gtfs_to_org["organization_name"].str.contains("Roseville")]
# Out:
#             schedule_gtfs_dataset_key                            name  \
# 22   bef2e7553d6d7fb3789f3b081e66365a  Roseville Transit GMV Schedule
# 114  13ff8c918cc62f49169d93a04864d8e7              Roseville Schedule
#
#     schedule_source_record_id  \
# 22          recuSnC10vPfhAAs9
# 114         rec90jC43naXJz9lr
#
#                                             base64_url  \
# 22    aHR0cHM6Ly9yb3NldmlsbGVidXN0cmFja2VyLmNvbS9ndGZz
# 114  aHR0cHM6Ly9pcG9ydGFsLnNhY3J0LmNvbS9HVEZTL1Jvc2...
#
#     organization_source_record_id  organization_name  itp_id  \
# 22              recUdTq5QiUjJRiAe  City of Roseville   271.0
# 114             recUdTq5QiUjJRiAe  City of Roseville   271.0
#
#     caltrans_district ntd_id_2022
# 22    03 - Marysville       90168
# 114   03 - Marysville       90168

# %%
# see which scheduel feeds these operators are in
city=[
    "Roseville",
    "Auburn",
    "Placer",
    "El Dorado",
    "Shingle Springs",
    "Placerville",
    "Cameron Park",
    "Pollock Pines",
    "Colfax",
    "Lincoln",
    "Rocklin",
    "alpine"
]

city_2 = "|".join(city)

display(
    gtfs_to_org[gtfs_to_org["organization_name"].str.contains(city_2, case=False)].sort_values(by="organization_name"),

    aug_crosswalk[
        aug_crosswalk["counties_served"].str.contains(city_2, case=False, na=False)].sort_values(by="counties_served"),
    
    aug_crosswalk[
        aug_crosswalk["organization_name"].str.contains("auburn", case=False, na=False)].sort_values(by="organization_name"),
    aug_crosswalk[
        aug_crosswalk["counties_served"].str.contains("none", case=False, na=False)].sort_values(by="counties_served")
)
# Out:
#             schedule_gtfs_dataset_key                            name  \
# 46   020467a276c12a9fe4b0a2332e393f2c                 Auburn Schedule
# 22   bef2e7553d6d7fb3789f3b081e66365a  Roseville Transit GMV Schedule
# 114  13ff8c918cc62f49169d93a04864d8e7              Roseville Schedule
# 186  7228eba069f2a0fad0ed8552410a544d              El Dorado Schedule
# 175  8de1f1a3b9ae172c6b8255b1c82c340f                 Placer Schedule
#
#     schedule_source_record_id  \
# 46          recPN6fJseWncWhDZ
# 22          recuSnC10vPfhAAs9
# 114         rec90jC43naXJz9lr
# 186         recX4LuyZsMBVngah
# 175         reclUxmuws84qZ0n7
#
#                                             base64_url  \
# 46   aHR0cHM6Ly93d3cuYXVidXJuLmNhLmdvdi9Eb2N1bWVudE...
# 22    aHR0cHM6Ly9yb3NldmlsbGVidXN0cmFja2VyLmNvbS9ndGZz
# 114  aHR0cHM6Ly9pcG9ydGFsLnNhY3J0LmNvbS9HVEZTL1Jvc2...
# 186  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...
# 175  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...
#
#     organization_source_record_id                   organization_name  itp_id  \
# 46              recbW86Xrtuw8PhiU                      City of Auburn    23.0
# 22              recUdTq5QiUjJRiAe                   City of Roseville   271.0
# 114             recUdTq5QiUjJRiAe                   City of Roseville   271.0
# 186             recEDVdKwYUSkGBRd  El Dorado County Transit Authority   101.0
# 175             recDD2rnkl2m7IV8u                       Placer County   251.0
#
#     caltrans_district ntd_id_2022
# 46    03 - Marysville       91032
# 22    03 - Marysville       90168
# 114   03 - Marysville       90168
# 186   03 - Marysville       90229
# 175   03 - Marysville       90196
#             schedule_gtfs_dataset_key                            name  \
# 186  7228eba069f2a0fad0ed8552410a544d              El Dorado Schedule
# 22   bef2e7553d6d7fb3789f3b081e66365a  Roseville Transit GMV Schedule
# 114  13ff8c918cc62f49169d93a04864d8e7              Roseville Schedule
# 175  8de1f1a3b9ae172c6b8255b1c82c340f                 Placer Schedule
#
#     schedule_source_record_id  \
# 186         recX4LuyZsMBVngah
# 22          recuSnC10vPfhAAs9
# 114         rec90jC43naXJz9lr
# 175         reclUxmuws84qZ0n7
#
#                                             base64_url  \
# 186  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...
# 22    aHR0cHM6Ly9yb3NldmlsbGVidXN0cmFja2VyLmNvbS9ndGZz
# 114  aHR0cHM6Ly9pcG9ydGFsLnNhY3J0LmNvbS9HVEZTL1Jvc2...
# 175  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...
#
#     organization_source_record_id                   organization_name  itp_id  \
# 186             recEDVdKwYUSkGBRd  El Dorado County Transit Authority   101.0
# 22              recUdTq5QiUjJRiAe                   City of Roseville   271.0
# 114             recUdTq5QiUjJRiAe                   City of Roseville   271.0
# 175             recDD2rnkl2m7IV8u                       Placer County   251.0
#
#     caltrans_district counties_served          hq_city  hq_county  \
# 186   03 - Marysville       El Dorado  Diamond Springs  El Dorado
# 22    03 - Marysville          Placer        Roseville     Placer
# 114   03 - Marysville          Placer        Roseville     Placer
# 175   03 - Marysville          Placer           Auburn     Placer
#
#     is_public_entity is_publicly_operating      funding_sources  \
# 186             True                  True  5307;5310;5311;5339
# 22              True                  True                 5307
# 114             True                  True                 5307
# 175             True                  True       5307;5311;5339
#
#      on_demand_vehicles_at_max_service  vehicles_at_max_service  \
# 186                                 16                       16
# 22                                <NA>                       24
# 114                               <NA>                       24
# 175                                 17                       45
#
#      number_of_state_counties        uza_name  density  \
# 186                      <NA>  Sacramento, CA   4163.0
# 22                       <NA>  Sacramento, CA   4163.0
# 114                      <NA>  Sacramento, CA   4163.0
# 175                      <NA>  Sacramento, CA   4163.0
#
#      number_of_counties_with_service  state_admin_funds_expended  \
# 186                             <NA>                         NaN
# 22                              <NA>                         NaN
# 114                             <NA>                         NaN
# 175                             <NA>                         NaN
#
#      service_area_sq_miles  population  service_area_pop subrecipient_type  \
# 186                   1719   1946618.0            148614              None
# 22                      43   1946618.0            153300              None
# 114                     43   1946618.0            153300              None
# 175                    169   1946618.0            392258              None
#
#     primary_uza     reporter_type  \
# 186        None  Reduced Reporter
# 22         None  Reduced Reporter
# 114        None  Reduced Reporter
# 175        None     Full Reporter
#
#                                      organization_type  voms_pt  voms_do  year
# 186      Public Agency or Authority of Transit Service     <NA>       16  2022
# 22   County or Local Government Unit or Department ...       24     <NA>  2022
# 114  County or Local Government Unit or Department ...       24     <NA>  2022
# 175  County or Local Government Unit or Department ...       28       17  2022
#            schedule_gtfs_dataset_key             name  \
# 46  020467a276c12a9fe4b0a2332e393f2c  Auburn Schedule
#
#    schedule_source_record_id  \
# 46         recPN6fJseWncWhDZ
#
#                                            base64_url  \
# 46  aHR0cHM6Ly93d3cuYXVidXJuLmNhLmdvdi9Eb2N1bWVudE...
#
#    organization_source_record_id organization_name  itp_id caltrans_district  \
# 46             recbW86Xrtuw8PhiU    City of Auburn    23.0   03 - Marysville
#
#    counties_served hq_city hq_county is_public_entity is_publicly_operating  \
# 46            None  Auburn      None             None                  None
#
#    funding_sources  on_demand_vehicles_at_max_service  \
# 46            None                                  6
#
#     vehicles_at_max_service  number_of_state_counties uza_name  density  \
# 46                        6                      <NA>     None      NaN
#
#     number_of_counties_with_service  state_admin_funds_expended  \
# 46                             <NA>                         NaN
#
#     service_area_sq_miles  population  service_area_pop  \
# 46                   <NA>         NaN              <NA>
#
#                subrecipient_type primary_uza   reporter_type  \
# 46  Rural General Public Transit        None  Rural Reporter
#
#                                     organization_type  voms_pt  voms_do  year
# 46  County or Local Government Unit or Department ...     <NA>        6  2022
# Empty DataFrame
# Columns: [schedule_gtfs_dataset_key, name, schedule_source_record_id, base64_url, organization_source_record_id, organization_name, itp_id, caltrans_district, counties_served, hq_city, hq_county, is_public_entity, is_publicly_operating, funding_sources, on_demand_vehicles_at_max_service, vehicles_at_max_service, number_of_state_counties, uza_name, density, number_of_counties_with_service, state_admin_funds_expended, service_area_sq_miles, population, service_area_pop, subrecipient_type, primary_uza, reporter_type, organization_type, voms_pt, voms_do, year]
# Index: []

# %%
# see if there are any other operators in these schedule feeds
# looks like this is the only one
sched_list = [
    "Roseville Transit GMV Schedule",
    "Roseville Schedule",
    "Placer Schedule",
    "El Dorado Schedule",
    "Auburn Schedule",
]
sched_list_2 = "|".join(sched_list)

gtfs_to_org[gtfs_to_org["name"].str.contains(sched_list_2, case=False)].sort_values(by="name")
# Out:
#             schedule_gtfs_dataset_key                            name  \
# 46   020467a276c12a9fe4b0a2332e393f2c                 Auburn Schedule
# 186  7228eba069f2a0fad0ed8552410a544d              El Dorado Schedule
# 175  8de1f1a3b9ae172c6b8255b1c82c340f                 Placer Schedule
# 114  13ff8c918cc62f49169d93a04864d8e7              Roseville Schedule
# 22   bef2e7553d6d7fb3789f3b081e66365a  Roseville Transit GMV Schedule
#
#     schedule_source_record_id  \
# 46          recPN6fJseWncWhDZ
# 186         recX4LuyZsMBVngah
# 175         reclUxmuws84qZ0n7
# 114         rec90jC43naXJz9lr
# 22          recuSnC10vPfhAAs9
#
#                                             base64_url  \
# 46   aHR0cHM6Ly93d3cuYXVidXJuLmNhLmdvdi9Eb2N1bWVudE...
# 186  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...
# 175  aHR0cHM6Ly9kYXRhLnRyaWxsaXVtdHJhbnNpdC5jb20vZ3...
# 114  aHR0cHM6Ly9pcG9ydGFsLnNhY3J0LmNvbS9HVEZTL1Jvc2...
# 22    aHR0cHM6Ly9yb3NldmlsbGVidXN0cmFja2VyLmNvbS9ndGZz
#
#     organization_source_record_id                   organization_name  itp_id  \
# 46              recbW86Xrtuw8PhiU                      City of Auburn    23.0
# 186             recEDVdKwYUSkGBRd  El Dorado County Transit Authority   101.0
# 175             recDD2rnkl2m7IV8u                       Placer County   251.0
# 114             recUdTq5QiUjJRiAe                   City of Roseville   271.0
# 22              recUdTq5QiUjJRiAe                   City of Roseville   271.0
#
#     caltrans_district ntd_id_2022
# 46    03 - Marysville       91032
# 186   03 - Marysville       90229
# 175   03 - Marysville       90196
# 114   03 - Marysville       90168
# 22    03 - Marysville       90168

# %%
# sanity check 
# example of schedle feed key, with multiple operators 
display(
    gtfs_to_org[gtfs_to_org["organization_name"].str.contains("Ojai")],
    gtfs_to_org[gtfs_to_org["name"].str.contains("VCTC GMV Schedule")]
)
# Out:
#           schedule_gtfs_dataset_key               name  \
# 0  1770249a5a2e770ca90628434d4934b1  VCTC GMV Schedule
#
#   schedule_source_record_id                        base64_url  \
# 0         recrAG7e0oOiR6FiP  aHR0cHM6Ly9nb3ZjYnVzLmNvbS9ndGZz
#
#   organization_source_record_id organization_name  itp_id caltrans_district  \
# 0             reckQmUdXUzHFmlVf      City of Ojai   231.0  07 - Los Angeles
#
#   ntd_id_2022
# 0       91058
#           schedule_gtfs_dataset_key               name  \
# 0  1770249a5a2e770ca90628434d4934b1  VCTC GMV Schedule
# 1  1770249a5a2e770ca90628434d4934b1  VCTC GMV Schedule
# 2  1770249a5a2e770ca90628434d4934b1  VCTC GMV Schedule
# 3  1770249a5a2e770ca90628434d4934b1  VCTC GMV Schedule
# 4  1770249a5a2e770ca90628434d4934b1  VCTC GMV Schedule
# 5  1770249a5a2e770ca90628434d4934b1  VCTC GMV Schedule
# 6  1770249a5a2e770ca90628434d4934b1  VCTC GMV Schedule
#
#   schedule_source_record_id                        base64_url  \
# 0         recrAG7e0oOiR6FiP  aHR0cHM6Ly9nb3ZjYnVzLmNvbS9ndGZz
# 1         recrAG7e0oOiR6FiP  aHR0cHM6Ly9nb3ZjYnVzLmNvbS9ndGZz
# 2         recrAG7e0oOiR6FiP  aHR0cHM6Ly9nb3ZjYnVzLmNvbS9ndGZz
# 3         recrAG7e0oOiR6FiP  aHR0cHM6Ly9nb3ZjYnVzLmNvbS9ndGZz
# 4         recrAG7e0oOiR6FiP  aHR0cHM6Ly9nb3ZjYnVzLmNvbS9ndGZz
# 5         recrAG7e0oOiR6FiP  aHR0cHM6Ly9nb3ZjYnVzLmNvbS9ndGZz
# 6         recrAG7e0oOiR6FiP  aHR0cHM6Ly9nb3ZjYnVzLmNvbS9ndGZz
#
#   organization_source_record_id                         organization_name  \
# 0             reckQmUdXUzHFmlVf                              City of Ojai
# 1             rec7EN71rsZxDFxZd  Ventura County Transportation Commission
# 2             recS7GnKTcQVX20HE               Gold Coast Transit District
# 3             rec1ErIn9gG1Isk5W                       City of Simi Valley
# 4             recojKzQsBzE1hjVu                          City of Moorpark
# 5             recPJULRJk1Yn824N                     City of Thousand Oaks
# 6             recD4Vzt0EDC3VY7I                         City of Camarillo
#
#    itp_id caltrans_district ntd_id_2022
# 0   231.0  07 - Los Angeles       91058
# 1   380.0  07 - Los Angeles       90164
# 2   123.0  07 - Los Angeles       90035
# 3   308.0  07 - Los Angeles       90050
# 4   210.0  07 - Los Angeles       90227
# 5   337.0  07 - Los Angeles       90165
# 6    54.0  07 - Los Angeles       90163

# %% [markdown]
# ## Read in ntd_id_rtpa_crosswalk

# %%
crosswalk = pd.read_csv(
        f"gs://calitp-analytics-data/data-analyses/ntd/ntd_id_rtpa_crosswalk.csv", 
        dtype = {"NTD ID": "str"}
    #have to rename NTD ID col to match the dim table
    ).rename(columns={"NTD ID": "ntd_id"})

# %%
display(
    crosswalk["RTPA"].nunique(),
    crosswalk["RTPA_open_data"].nunique()
)
# Out:
# 26
# 20

# %%
## do the operators found in the previous, exist in the crosswalk?

# %%
crosswalk[crosswalk["Agency"].str.contains(city_2)]
# Out:
#      ntd_id Legacy NTD ID                              Agency        UZA Name  \
# 60    90168          9168                   City of Roseville  Sacramento, CA
# 61    90196          9196                    County of Placer  Sacramento, CA
# 63    90229          9229  El Dorado County Transit Authority  Sacramento, CA
# 117   91032         91032                      City of Auburn   Sacramento,CA
# 118   91032         91032                      City of Auburn   Sacramento,CA
#
#                                    RTPA_open_data  \
# 60         Sacramento Area Council of Governments
# 61         Sacramento Area Council of Governments
# 63         Sacramento Area Council of Governments
# 117  Placer County Transportation Planning Agency
# 118  Placer County Transportation Planning Agency
#
#                                              RTPA
# 60   Placer County Transportation Planning Agency
# 61   Placer County Transportation Planning Agency
# 63     El Dorado County Transportation Commission
# 117  Placer County Transportation Planning Agency
# 118  Placer County Transportation Planning Agency

# %% [markdown]
# ---

# %% [markdown]
# ## Read in ntd ridership data

# %%
# query the warehouse
full_upt = (
    tbls.mart_ntd.dim_monthly_ntd_ridership_with_adjustments() 
    >> filter(#_.uza_name.str.contains(" ,CA"),
              #_.period_year_month.str.contains("2024-")
             )
    >> collect()
).rename(columns = {"mode_type_of_service_status": "Status"}
       )

# %%
full_upt.columns
# Out:
# Index(['uza_name', 'uace_cd', '_dt', 'ts', 'ntd_id', 'year', 'reporter_type',
#        'agency', 'Status', 'mode', 'mode_full_name', 'service_type', '_3_mode',
#        'tos', 'legacy_ntd_id', 'period_year_month', 'period_year',
#        'period_month', 'upt', 'vrm', 'vrh', 'voms'],
#       dtype='object')

# %%
ca = full_upt[full_upt["uza_name"].str.contains(", CA") & full_upt["period_year_month"].str.contains("2024-")]

# %% [markdown]
# ## do any of the operators found in the previous, exist in the ntd data?

# %%
ca[ca["agency"].str.contains(city_2)]["agency"].value_counts()
# Out:
# County of Placer                      56
# El Dorado County Transit Authority    21
# City of Roseville                     14
# Name: agency, dtype: int64

# %%
## do all the operators in the crosswalk exist in the ntd data?

crosswalk_agency = crosswalk["Agency"].unique().tolist()
crosswalk_agency_2 = "|".join(crosswalk_agency)

display(
    len(ca[ca["agency"].str.contains(crosswalk_agency_2)]["agency"].unique()),
    len(crosswalk_agency)
)

#yes they do
# Out:
# 116
# 118

# %% [markdown]
# ---

# %% [markdown]
# # Conclusion

# %% [markdown]
# **Update the following to `ntd_id_rtpa` crosswalk**
#
# County of placer
# - RTPA: Placer County Transportation Planning Agency
#
# City of Roseville
# - RTPA: Placer County Transportation Planning Agency
#
# El Dorado County Transit Authority
# - RTPA: El Dorado County Transportation Commission
#
# **Add to the ntd_id_rtpa crosswalk**
#
# City of Auburn
# - RTPA: Placer County Transportation Planning Agency
# - NTD ID: 91032
# - UZA Name: Sacramento, CA

# %%
display(
    crosswalk[crosswalk["Agency"].str.contains("Roseville")],
    crosswalk[crosswalk["Agency"].str.contains("El Dorado")]
)
# Out:
#     ntd_id Legacy NTD ID             Agency        UZA Name  \
# 60   90168          9168  City of Roseville  Sacramento, CA
#
#                             RTPA_open_data  \
# 60  Sacramento Area Council of Governments
#
#                                             RTPA
# 60  Placer County Transportation Planning Agency
#     ntd_id Legacy NTD ID                              Agency        UZA Name  \
# 63   90229          9229  El Dorado County Transit Authority  Sacramento, CA
#
#                             RTPA_open_data  \
# 63  Sacramento Area Council of Governments
#
#                                           RTPA
# 63  El Dorado County Transportation Commission

# %%
crosswalk.loc[crosswalk["Agency"].str.contains("Placer"), "RTPA"] = "Placer County Transportation Planning Agency"

# %%
crosswalk.loc[crosswalk["Agency"].str.contains("Roseville"), "RTPA"] = "Placer County Transportation Planning Agency"
crosswalk.loc[crosswalk["Agency"].str.contains("El Dorado"), "RTPA"] = "El Dorado County Transportation Commission"

# %%
display(
    crosswalk[crosswalk["Agency"].str.contains("Placer")],
    crosswalk[crosswalk["Agency"].str.contains("Roseville")],
    crosswalk[crosswalk["Agency"].str.contains("El Dorado")]
)
# Out:
#     ntd_id Legacy NTD ID            Agency        UZA Name  \
# 61   90196          9196  County of Placer  Sacramento, CA
#
#                             RTPA_open_data  \
# 61  Sacramento Area Council of Governments
#
#                                             RTPA
# 61  Placer County Transportation Planning Agency
#     ntd_id Legacy NTD ID             Agency        UZA Name  \
# 60   90168          9168  City of Roseville  Sacramento, CA
#
#                             RTPA_open_data  \
# 60  Sacramento Area Council of Governments
#
#                                             RTPA
# 60  Placer County Transportation Planning Agency
#     ntd_id Legacy NTD ID                              Agency        UZA Name  \
# 63   90229          9229  El Dorado County Transit Authority  Sacramento, CA
#
#                             RTPA_open_data  \
# 63  Sacramento Area Council of Governments
#
#                                           RTPA
# 63  El Dorado County Transportation Commission

# %%
columns = crosswalk.columns

auburn = pd.DataFrame([["91032","91032","City of Auburn","Sacramento,CA","Placer County Transportation Planning Agency", "Placer County Transportation Planning Agency"]], columns=columns)

crosswalk_2 = pd.concat([crosswalk, auburn], ignore_index=True)

display(
    crosswalk.shape,
    crosswalk_2.shape
)
# Out:
# (119, 6)
# (120, 6)

# %%
crosswalk_2["ntd_id"] = crosswalk_2["ntd_id"].astype("str")

# %%
crosswalk_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ntd_id          120 non-null    object
#  1   Legacy NTD ID   110 non-null    object
#  2   Agency          120 non-null    object
#  3   UZA Name        120 non-null    object
#  4   RTPA_open_data  120 non-null    object
#  5   RTPA            120 non-null    object
# dtypes: object(6)
# memory usage: 5.8+ KB

# %%
# save updated crosswalk back to GCS
crosswalk_2.to_csv(f"gs://calitp-analytics-data/data-analyses/ntd/ntd_id_rtpa_crosswalk.csv", index=False)

# %%
crosswalk_2.to_parquet(f"gs://calitp-analytics-data/data-analyses/ntd/ntd_id_rtpa_crosswalk.parquet")

# %% [markdown]
# ---

# %%
# addressing merge issue from monthly_ridership_by_rtpa.py script

full_upt = (tbls.mart_ntd.dim_monthly_ntd_ridership_with_adjustments() >> collect()).rename(columns = {"mode_type_of_service_status": "Status"})
    
full_upt = full_upt[full_upt.agency.notna()].reset_index(drop=True)
    
#full_upt.to_parquet(
#        f"{GCS_FILE_PATH}ntd_monthly_ridership_{year}_{month}.parquet"
#    )
    
ca = full_upt[(full_upt["uza_name"].str.contains(", CA")) & 
            (full_upt.agency.notna())].reset_index(drop=True)
    
crosswalk = pd.read_csv(
        f"gs://calitp-analytics-data/data-analyses/ntd/ntd_id_rtpa_crosswalk.csv", 
        dtype = {"ntd_id": "str"}
    #have to rename NTD ID col to match the dim table
    )#.rename(columns={"NTD ID": "ntd_id"})
    
df = pd.merge(
        ca,
        # Merging on too many columns can create problems 
        # because csvs and dtypes aren't stable / consistent 
        # for NTD ID, Legacy NTD ID, and UZA
        crosswalk[["ntd_id", "RTPA"]],
        on = "ntd_id",
        how = "left",
        indicator = True
    )
    
print(df._merge.value_counts())
# Out:
# both          92953
# left_only         0
# right_only        0
# Name: _merge, dtype: int64

# %%
df[df["RTPA"].str.contains("El Dor")]
# Out:
#              uza_name uace_cd         _dt                               ts  \
# 35230  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35231  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35232  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35233  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35234  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35235  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35236  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35237  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35238  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35239  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35240  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35241  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35242  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35243  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35244  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35245  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35246  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35247  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35248  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35249  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35250  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35251  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35252  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35253  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35254  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35255  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35256  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35257  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35258  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35259  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35260  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35261  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35262  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35263  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35264  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35265  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35266  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35267  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35268  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35269  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35270  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35271  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35272  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35273  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35274  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35275  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35276  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35277  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35278  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35279  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35280  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35281  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35282  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35283  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35284  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35285  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35286  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35287  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35288  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35289  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35290  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35291  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35292  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35293  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35294  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35295  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35296  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35297  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35298  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35299  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35300  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35301  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35302  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35303  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35304  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35305  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35306  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35307  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35308  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35309  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35310  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35311  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35312  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35313  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35314  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35315  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35316  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35317  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35318  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35319  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35320  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35321  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35322  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35323  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35324  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35325  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35326  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35327  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35328  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35329  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35330  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35331  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35332  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35333  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35334  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35335  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35336  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35337  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35338  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35339  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35340  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35341  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35342  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35343  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35344  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35345  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35346  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35347  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35348  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35349  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35350  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35351  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35352  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35353  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35354  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35355  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35356  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35357  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35358  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35359  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35360  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35361  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35362  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35363  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35364  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35365  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35366  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35367  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35368  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35369  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35370  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35371  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35372  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35373  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35374  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35375  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35376  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35377  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35378  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35379  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35380  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35381  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35382  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35383  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35384  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35385  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35386  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35387  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35388  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35389  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35390  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35391  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 35392  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 
Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 49591  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 49592  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88075  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88076  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88077  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88078  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88079  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88080  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88081  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88082  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88083  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88084  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88085  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88086  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88087  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88088  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88089  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88090  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88091  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88092  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88093  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88094  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88095  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88096  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88097  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88098  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88099  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88100  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88101  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88102  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88103  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88104  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88105  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88106  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88107  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88108  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88109  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88110  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88111  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88112  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88113  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88114  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88115  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88116  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88117  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88118  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88119  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88120  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88121  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88122  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88123  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88124  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88125  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88126  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88127  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88128  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88129  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88130  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88131  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88132  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88133  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88134  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88135  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88136  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88137  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88138  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88139  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88140  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88141  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88142  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88143  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88144  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88145  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# 88146  Sacramento, CA   77068  2024-09-06 2024-09-06 20:49:05.015238+00:00
# ...
# 88075  El Dorado County Transportation Commission   both
# 88076  El Dorado County Transportation Commission   both
# 88077  El Dorado County Transportation Commission   both
# 88078  El Dorado County Transportation Commission   both
# 88079  El Dorado County Transportation Commission   both
# 88080  El Dorado County Transportation Commission   both
# 88081  El Dorado County Transportation Commission   both
# 88082  El Dorado County Transportation Commission   both
# 88083  El Dorado County Transportation Commission   both
# 88084  El Dorado County Transportation Commission   both
# 88085  El Dorado County Transportation Commission   both
# 88086  El Dorado County Transportation Commission   both
# 88087  El Dorado County Transportation Commission   both
# 88088  El Dorado County Transportation Commission   both
# 88089  El Dorado County Transportation Commission   both
# 88090  El Dorado County Transportation Commission   both
# 88091  El Dorado County Transportation Commission   both
# 88092  El Dorado County Transportation Commission   both
# 88093  El Dorado County Transportation Commission   both
# 88094  El Dorado County Transportation Commission   both
# 88095  El Dorado County Transportation Commission   both
# 88096  El Dorado County Transportation Commission   both
# 88097  El Dorado County Transportation Commission   both
# 88098  El Dorado County Transportation Commission   both
# 88099  El Dorado County Transportation Commission   both
# 88100  El Dorado County Transportation Commission   both
# 88101  El Dorado County Transportation Commission   both
# 88102  El Dorado County Transportation Commission   both
# 88103  El Dorado County Transportation Commission   both
# 88104  El Dorado County Transportation Commission   both
# 88105  El Dorado County Transportation Commission   both
# 88106  El Dorado County Transportation Commission   both
# 88107  El Dorado County Transportation Commission   both
# 88108  El Dorado County Transportation Commission   both
# 88109  El Dorado County Transportation Commission   both
# 88110  El Dorado County Transportation Commission   both
# 88111  El Dorado County Transportation Commission   both
# 88112  El Dorado County Transportation Commission   both
# 88113  El Dorado County Transportation Commission   both
# 88114  El Dorado County Transportation Commission   both
# 88115  El Dorado County Transportation Commission   both
# 88116  El Dorado County Transportation Commission   both
# 88117  El Dorado County Transportation Commission   both
# 88118  El Dorado County Transportation Commission   both
# 88119  El Dorado County Transportation Commission   both
# 88120  El Dorado County Transportation Commission   both
# 88121  El Dorado County Transportation Commission   both
# 88122  El Dorado County Transportation Commission   both
# 88123  El Dorado County Transportation Commission   both
# 88124  El Dorado County Transportation Commission   both
# 88125  El Dorado County Transportation Commission   both
# 88126  El Dorado County Transportation Commission   both
# 88127  El Dorado County Transportation Commission   both
# 88128  El Dorado County Transportation Commission   both
# 88129  El Dorado County Transportation Commission   both
# 88130  El Dorado County Transportation Commission   both
# 88274  El Dorado County Transportation Commission   both
# 88275  El Dorado County Transportation Commission   both
# 88276  El Dorado County Transportation Commission   both
# 88277  El Dorado County Transportation Commission   both
# 88278  El Dorado County Transportation Commission   both
# 88279  El Dorado County Transportation Commission   both
# 88280  El Dorado County Transportation Commission   both
# 88281  El Dorado County Transportation Commission   both
# 88282  El Dorado County Transportation Commission   both
# 88283  El Dorado County Transportation Commission   both
# 88284  El Dorado County Transportation Commission   both
# 88285  El Dorado County Transportation Commission   both
# 88286  El Dorado County Transportation Commission   both
# 88287  El Dorado County Transportation Commission   both
# 88288  El Dorado County Transportation Commission   both
# 88289  El Dorado County Transportation Commission   both
# 88290  El Dorado County Transportation Commission   both
# 88291  El Dorado County Transportation Commission   both
# 88292  El Dorado County Transportation Commission   both
# 88293  El Dorado County Transportation Commission   both
# 88294  El Dorado County Transportation Commission   both
# 88295  El Dorado County Transportation Commission   both
# 88296  El Dorado County Transportation Commission   both
# 88297  El Dorado County Transportation Commission   both
# 88298  El Dorado County Transportation Commission   both
# 88299  El Dorado County Transportation Commission   both
# 88300  El Dorado County Transportation Commission   both
# 88301  El Dorado County Transportation Commission   both
# 88302  El Dorado County Transportation Commission   both
# 88303  El Dorado County Transportation Commission   both
# 88304  El Dorado County Transportation Commission   both
# 88305  El Dorado County Transportation Commission   both
# 88306  El Dorado County Transportation Commission   both
# 88307  El Dorado County Transportation Commission   both
# 88308  El Dorado County Transportation Commission   both
# 88309  El Dorado County Transportation Commission   both
# 88310  El Dorado County Transportation Commission   both
# 88311  El Dorado County Transportation Commission   both
# 88312  El Dorado County Transportation Commission   both
# 88313  El Dorado County Transportation Commission   both
# 88314  El Dorado County Transportation Commission   both
# 88315  El Dorado County Transportation Commission   both
# 88316  El Dorado County Transportation Commission   both
# 88317  El Dorado County Transportation Commission   both
# 88318  El Dorado County Transportation Commission   both
# 88319  El Dorado County Transportation Commission   both
# 88320  El Dorado County Transportation Commission   both
# 88321  El Dorado County Transportation Commission   both
# 88322  El Dorado County Transportation Commission   both
# 88323  El Dorado County Transportation Commission   both
# 88324  El Dorado County Transportation Commission   both
# 88325  El Dorado County Transportation Commission   both
# 88326  El Dorado County Transportation Commission   both
# 88327  El Dorado County Transportation Commission   both
# 88328  El Dorado County Transportation Commission   both
# 88329  El Dorado County Transportation Commission   both
# 88330  El Dorado County Transportation Commission   both
# 88331  El Dorado County Transportation Commission   both
# 88332  El Dorado County Transportation Commission   both
# 88333  El Dorado County Transportation Commission   both
# 88334  El Dorado County Transportation Commission   both
# 88335  El Dorado County Transportation Commission   both
# 88336  El Dorado County Transportation Commission   both
# 88337  El Dorado County Transportation Commission   both
# 88338  El Dorado County Transportation Commission   both
# 88339  El Dorado County Transportation Commission   both
# 88340  El Dorado County Transportation Commission   both
# 88341  El Dorado County Transportation Commission   both
# 88342  El Dorado County Transportation Commission   both
# 88343  El Dorado County Transportation Commission   both
# 88344  El Dorado County Transportation Commission   both
# 88345  El Dorado County Transportation Commission   both

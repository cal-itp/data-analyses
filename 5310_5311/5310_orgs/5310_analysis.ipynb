# %%
import pandas as pd
from siuba import *
import numpy as np

import altair as alt

from shared_utils import altair_utils
from shared_utils import geography_utils
from shared_utils import calitp_color_palette as cp
from shared_utils import styleguide

from calitp import to_snakecase
# Out:
# /opt/conda/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(
# /opt/conda/lib/python3.9/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /opt/conda/lib/python3.9/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /opt/conda/lib/python3.9/site-packages/google/auth/_default.py:79: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/

# %%
df=pd.read_csv('gs://calitp-analytics-data/data-analyses/5310/5310_org_info_manualfill.csv')

# %%
df.sample(5)
# Out:
#                  organization_name ntd_id  itp_id        name_NTD_Airtable  \
# 132                 Lake Links Inc    NaN     NaN                      NaN
# 79             Humboldt Medi-Trans    NaN     NaN  Humboldt Medi-Trans Inc
# 10              City of Santa Rosa  90017   301.0       City of Santa Rosa
# 64          Sunline Transit Agency  90079   327.0   SunLine Transit Agency
# 119  Calaveras County Public Works    NaN     NaN                      NaN
#
#     doing_business_as reporter_acronym  \
# 132               NaN              NaN
# 79                NaN              NaN
# 10                NaN              NaN
# 64                NaN              NaN
# 119               NaN              NaN
#
#                                      organization_type  reporter_type  \
# 132                            Non-Profit Organization            NaN
# 79                             Non-Profit Organization            NaN
# 10   City, County or Local Government Unit or Depar...  Full Reporter
# 64   Independent Public Agency or Authority of Tran...  Full Reporter
# 119  City, County or Local Government Unit or Depar...            NaN
#
#                city     county  \
# 132       Clearlake       Lake
# 79    McKinleyville   Humboldt
# 10       Santa Rosa     Sonoma
# 64   Thousand Palms  Riverside
# 119     San Andreas  Calaveras
#
#                             mobility_services_operated            merge_status
# 132                                                NaN                No Match
# 79                                 Humboldt Medi-Trans  Manual Match, Airtable
# 10    Santa Rosa CityBus,Santa Rosa Call Ahead Service         Name Match; NTD
# 64   SunLine Transit,SunLine School Tripper,SunDial...       Manual Match, NTD
# 119                                                NaN                No Match

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   organization_name           147 non-null    object
#  1   ntd_id                      37 non-null     object
#  2   itp_id                      78 non-null     float64
#  3   name_NTD_Airtable           108 non-null    object
#  4   doing_business_as           7 non-null      object
#  5   reporter_acronym            28 non-null     object
#  6   organization_type           147 non-null    object
#  7   reporter_type               37 non-null     object
#  8   city                        146 non-null    object
#  9   county                      146 non-null    object
#  10  mobility_services_operated  90 non-null     object
#  11  merge_status                147 non-null    object
# dtypes: float64(1), object(11)
# memory usage: 13.9+ KB

# %%
df>>count(_.county)>>arrange(-_.n)
# Out:
#                                                county   n
# 32                                          Riverside  10
# 0                                             Alameda   9
# 35                                     San Bernardino   9
# 9                                        Contra Costa   8
# 38                                      San Francisco   7
# 19                                               Kern   6
# 24                                          Mendocino   5
# 51                                             Solano   5
# 33                                         Sacramento   4
# 37                                          San Diego   4
# 44                                      Santa Barbara   4
# 46                                        Santa Clara   4
# 14                                           Humboldt   3
# 23                                              Marin   3
# 41                                        San Joaquin   3
# 42                                    San Luis Obispo   3
# 43                                          San Mateo   3
# 53                                         Stanislaus   3
# 54                                             Tehama   3
# 55                                             Tulare   3
# 4                                               Butte   2
# 16                                           Imperial   2
# 21                                               Lake   2
# 28                                             Nevada   2
# 31                                             Placer   2
# 48                                         Santa Cruz   2
# 52                                             Sonoma   2
# 58                                               Yolo   2
# 1                               Alameda, Contra Costa   1
# 2                                              Amador   1
# 3                                   Amador, Calaveras   1
# 5                                         Butte, Glen   1
# 6                                           Calaveras   1
# 7                         Calaveras, Amador, Tuolumne   1
# 8                                              Colusa   1
# 10             Contra Costa, Napa, Solano, Sacramento   1
# 11                                          Del Norte   1
# 12               Douglas, Placer, Washoe, Carson City   1
# 13                                          El Dorado   1
# 15                                 Humboldt, De Norte   1
# 17                                               Inyo   1
# 18                                         Inyo, Mono   1
# 20                                              Kings   1
# 22                                      Lassen, Modoc   1
# 25                                           Monterey   1
# 26  Monterey, San Mateo, San Benito, Santa Clara, ...   1
# 27                                               Napa   1
# 29                                     Nevada, Sierra   1
# 30  Orange, Los Angeles, Riverside, San Bernardino...   1
# 34                                         San Benito   1
# 36             San Bernardino, Riverside, Los Angeles   1
# 39     San Francisco, Alameda, San Mateo, Santa Clara   1
# 40              San Francisco, San Mateo, Santa Clara   1
# 45           Santa Barbara, Monterey, San Luis Obispo   1
# 47                               Santa Clara, Alameda   1
# 49      Santa Cruz, San Benito, Santa Clara, Monterey   1
# 50                                             Shasta   1
# 56                                           Tuolumne   1
# 57                                            Ventura   1

# %%
df>>filter(_.county.str.contains(", "))
# Out:
#                                      organization_name ntd_id  itp_id  \
# 2                               Area 1 Agency on Aging    NaN   399.0
# 3                                   Big Valley 50 Plus    NaN   404.0
# 13                       Common Ground Senior Services    NaN   419.0
# 19              Friends of Children with Special Needs    NaN     NaN
# 24           Inyo-Mono Association for the Handicapped    NaN   434.0
# 51                           Self-Help for the Elderly    NaN     NaN
# 52                       Tahoe Transportation District  91092   331.0
# 53                     The Arc of Amador and Calaveras    NaN   461.0
# 74                          Community Bridges Liftline    NaN   420.0
# 80     Lutheran Social Services of Southern California    NaN   439.0
# 86                    Center for Elders' Independence     NaN   409.0
# 90                                 Institute on Aging     NaN     NaN
# 106                                    Choice in Aging    NaN     NaN
# 112                              Foothill AIDS Project    NaN     NaN
# 114                                     NCI Affiliates    NaN     NaN
# 116  Seniors Council of Santa Cruz and San Benito C...    NaN     NaN
# 123                                   Help Central Inc    NaN     NaN
# 129    Nevada-Sierra Connecting Point Public Authority    NaN     NaN
#
#                              name_NTD_Airtable doing_business_as  \
# 2                       Area 1 Agency on Aging               NaN
# 3                           Big Valley 50 Plus               NaN
# 13               Common Ground Senior Services               NaN
# 19      Friends of Children with Special Needs               NaN
# 24   Inyo-Mono Association for the Handicapped               NaN
# 51                   Self-Help for the Elderly               NaN
# 52               Tahoe Transportation District               NaN
# 53             The Arc of Amador and Calaveras               NaN
# 74                       Community Bridges Inc               NaN
# 80                    Lutheran Social Services               NaN
# 86             Center for Elders' Independence               NaN
# 90                          Institute on Aging               NaN
# 106                                        NaN               NaN
# 112                                        NaN               NaN
# 114                                        NaN               NaN
# 116                                        NaN               NaN
# 123                                        NaN               NaN
# 129                                        NaN               NaN
#
#     reporter_acronym                                  organization_type  \
# 2                NaN                            Non-Profit Organization
# 3                NaN                            Non-Profit Organization
# 13               NaN                            Non-Profit Organization
# 19               NaN                            Non-Profit Organization
# 24               NaN                            Non-Profit Organization
# 51               NaN                            Non-Profit Organization
# 52               TTD  Independent Public Agency or Authority of Tran...
# 53               NaN                            Non-Profit Organization
# 74               NaN                            Non-Profit Organization
# 80               NaN                            Non-Profit Organization
# 86               NaN                            Non-Profit Organization
# 90               NaN                            Non-Profit Organization
# 106              NaN                            Non-Profit Organization
# 112              NaN                            Non-Profit Organization
# 114              NaN                            Non-Profit Organization
# 116              NaN                            Non-Profit Organization
# 123              NaN                            Non-Profit Organization
# 129              NaN                            Non-Profit Organization
#
#      reporter_type           city  \
# 2              NaN         Eureka
# 3              NaN         Beiber
# 13             NaN    San Andreas
# 19             NaN        Fremont
# 24             NaN         Bishop
# 51             NaN  San Francisco
# 52   Full Reporter    Zephyr Cove
# 53             NaN   Sutter Creek
# 74             NaN    Watsonville
# 80             NaN         Orange
# 86             NaN        Oakland
# 90             NaN  San Francisco
# 106            NaN  Pleasant Hill
# 112            NaN      Riverside
# 114            NaN    Paso Robles
# 116            NaN          Aptos
# 123            NaN          Chico
# 129            NaN   Grass Valley
#
#                                                 county  \
# 2                                   Humboldt, De Norte
# 3                                        Lassen, Modoc
# 13                         Calaveras, Amador, Tuolumne
# 19                                Santa Clara, Alameda
# 24                                          Inyo, Mono
# 51      San Francisco, Alameda, San Mateo, Santa Clara
# 52                Douglas, Placer, Washoe, Carson City
# 53                                   Amador, Calaveras
# 74   Monterey, San Mateo, San Benito, Santa Clara, ...
# 80   Orange, Los Angeles, Riverside, San Bernardino...
# 86                               Alameda, Contra Costa
# 90               San Francisco, San Mateo, Santa Clara
# 106             Contra Costa, Napa, Solano, Sacramento
# 112             San Bernardino, Riverside, Los Angeles
# 114           Santa Barbara, Monterey, San Luis Obispo
# 116      Santa Cruz, San Benito, Santa Clara, Monterey
# 123                                        Butte, Glen
# 129                                     Nevada, Sierra
#
#                             mobility_services_operated            merge_status
# 2                                                  NaN    Name Match; Airtable
# 3                                   Big Valley 50 Plus    Name Match; Airtable
# 13                             Silver Streak Transport    Name Match; Airtable
# 19                                                 NaN    Name Match; Airtable
# 24           Inyo-Mono Association for the Handicapped    Name Match; Airtable
# 51                           Self-Help for the Elderly    Name Match; Airtable
# 52   Tahoe Truckee Area Regional Transportation,Tah...    Name Match; Airtable
# 53                     The Arc of Amador and Calaveras    Name Match; Airtable
# 74                                           Lift Line  Manual Match, Airtable
# 80                                                 NaN  Manual Match, Airtable
# 86                                                 NaN  Manual Match, Airtable
# 90                                  Institute on Aging  Manual Match, Airtable
# 106                                                NaN                No Match
# 112                                                NaN                No Match
# 114                                                NaN                No Match
# 116                                                NaN                No Match
# 123                                                NaN                No Match
# 129                                                NaN                No Match

# %%
df>>count(_.organization_type)>>arrange(-_.n)
# Out:
#                                    organization_type   n
# 5                            Non-Profit Organization  90
# 3  Independent Public Agency or Authority of Tran...  28
# 0  City, County or Local Government Unit or Depar...  12
# 2                                 Independent Agency   5
# 1                                            Company   4
# 4                                           MPO/RTPA   3
# 6                                              Other   3
# 7                     Private-Non-Profit Corporation   1
# 8                                         University   1

# %% [markdown]
# ## Charts

# %%
df.sample()
# Out:
#                          organization_name      ntd_id  itp_id  \
# 135  Tuolumne County Transit Agency (TCTA)  9R02-91057     NaN
#
#            name_NTD_Airtable doing_business_as reporter_acronym  \
# 135  Tuolumne County Transit               NaN              TCT
#
#                                      organization_type   reporter_type  \
# 135  Independent Public Agency or Authority of Tran...  Rural Reporter
#
#        city    county mobility_services_operated       merge_status
# 135  Sonora  Tuolumne                        NaN  Manual Match, NTD

# %%
def labeling(word):
    LABEL_DICT = {
        "dist": "District",
        "nunique": "Number of Unique",
        "n":"Count",
        "name_NTD_Airtable":"Organization Name"
    }

    if (word == "mpo") or (word == "rtpa"):
        word = word.upper()
    elif word in LABEL_DICT.keys():
        word = LABEL_DICT[word]
    else:
        #word = word.replace("n_", "Number of ").title()
        word = word.replace("unique_", "Number of Unique ").title()
        word = word.replace("_", " ").title()

    return word

# %%
def bar_chart(df, x_col, y_col, color_col, chart_title=""):

    bar = (
        alt.Chart(df)
        .mark_bar()
        .encode(
            x=alt.X(x_col, title=labeling(x_col), sort=("-y")),
            y=alt.Y(y_col, title=labeling(y_col)),
            color=alt.Color(
                color_col,
                scale=alt.Scale(range=altair_utils.CALITP_CATEGORY_BRIGHT_COLORS),
                legend=alt.Legend(title=(labeling(color_col)), symbolLimit=10)
            )
        ).properties(title=chart_title))
    
    chart = styleguide.preset_chart_config(bar)
    
    return chart

# %%
org_counts = df>>count(_.organization_type)

# %%
org_counts>>arrange(-_.n)
# Out:
#                                    organization_type   n
# 5                            Non-Profit Organization  90
# 3  Independent Public Agency or Authority of Tran...  28
# 0  City, County or Local Government Unit or Depar...  12
# 2                                 Independent Agency   5
# 1                                            Company   4
# 4                                           MPO/RTPA   3
# 6                                              Other   3
# 7                     Private-Non-Profit Corporation   1
# 8                                         University   1

# %%
bar_chart(org_counts,
    "organization_type",
    "n",
    "organization_type",
    "5310 Organization Types"
)
# Out:
# alt.Chart(...)

# %%
def charttext(df, x_col, y_col, color_col):
    bars = alt.Chart(df).mark_bar().encode(
            x=alt.X(x_col, title=labeling(x_col), sort=("-y")),
            y=alt.Y(y_col, title=labeling(y_col)),
            color=alt.Color(
                color_col,
                scale=alt.Scale(range=altair_utils.CALITP_CATEGORY_BRIGHT_COLORS),
                legend=alt.Legend(title=(labeling(color_col)), symbolLimit=10)
    ))

    text = bars.mark_text(
        align="left", baseline="middle", color="black", dy=3
    ).encode(
        text= y_col, color=alt.value("black")
    )
    
    display(styleguide.preset_chart_config(bars + text))

# %%
charttext(org_counts, "organization_type", "n", "organization_type")
# Out:
# alt.LayerChart(...)

# %%
## create long df for county counts

# %%
df.sample(5)
# Out:
#                                      organization_name      ntd_id  itp_id  \
# 44                     Redwood Coast Transit Authority  9R02-91097   261.0
# 10                                  City of Santa Rosa       90017   301.0
# 100  United Cerebral Palsy Association of Greater S...         NaN   464.0
# 109  County of Sonoma Human Services Department Adu...         NaN     NaN
# 78                                     Faith in Action         NaN     NaN
#
#                                      name_NTD_Airtable doing_business_as  \
# 44                     Redwood Coast Transit Authority               NaN
# 10                                  City of Santa Rosa               NaN
# 100  United Cerebral Palsy Association of Greater S...               NaN
# 109                                                NaN               NaN
# 78                                 Faith in Action Inc               NaN
#
#     reporter_acronym                                  organization_type  \
# 44              RCTA  Independent Public Agency or Authority of Tran...
# 10               NaN  City, County or Local Government Unit or Depar...
# 100              NaN                            Non-Profit Organization
# 109              NaN                                 Independent Agency
# 78               NaN                            Non-Profit Organization
#
#       reporter_type           city      county  \
# 44   Rural Reporter  Crescent City   Del Norte
# 10    Full Reporter     Santa Rosa      Sonoma
# 100             NaN     Sacramento  Sacramento
# 109             NaN         Sonoma      Sonoma
# 78              NaN      Vacaville      Solano
#
#                            mobility_services_operated            merge_status
# 44    Redwood Coast Transit,Redwood Coast Dial-A-Ride         Name Match; NTD
# 10   Santa Rosa CityBus,Santa Rosa Call Ahead Service         Name Match; NTD
# 100                                     UCP Safe Trip  Manual Match, Airtable
# 109                                               NaN                No Match
# 78                                    Ride with Pride  Manual Match, Airtable

# %%
single_county = df[~df["county"].str.contains(",", na=False)]

# %%
single_county>>count(_.county)>>arrange(-_.n)
# Out:
#              county   n
# 20        Riverside  10
# 0           Alameda   9
# 23   San Bernardino   9
# 5      Contra Costa   8
# 25    San Francisco   7
# 11             Kern   6
# 15        Mendocino   5
# 33           Solano   5
# 21       Sacramento   4
# 24        San Diego   4
# 29    Santa Barbara   4
# 30      Santa Clara   4
# 8          Humboldt   3
# 14            Marin   3
# 26      San Joaquin   3
# 27  San Luis Obispo   3
# 28        San Mateo   3
# 35       Stanislaus   3
# 36           Tehama   3
# 37           Tulare   3
# 2             Butte   2
# 9          Imperial   2
# 13             Lake   2
# 18           Nevada   2
# 19           Placer   2
# 31       Santa Cruz   2
# 34           Sonoma   2
# 40             Yolo   2
# 1            Amador   1
# 3         Calaveras   1
# 4            Colusa   1
# 6         Del Norte   1
# 7         El Dorado   1
# 10             Inyo   1
# 12            Kings   1
# 16         Monterey   1
# 17             Napa   1
# 22       San Benito   1
# 32           Shasta   1
# 38         Tuolumne   1
# 39          Ventura   1

# %%
bar_chart((single_county>>count(_.county)),
    "county",
    "n",
    "county",
    "Counties with 5310 Organizations (Single County)"
)
# Out:
# alt.Chart(...)

# %%
df1 = df>>select(_.organization_name, _.ntd_id, _.itp_id, _.organization_type, _.city, _.county, _.merge_status)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   organization_name  147 non-null    object
#  1   ntd_id             37 non-null     object
#  2   itp_id             78 non-null     float64
#  3   organization_type  147 non-null    object
#  4   city               146 non-null    object
#  5   county             146 non-null    object
#  6   merge_status       147 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 8.2+ KB

# %%
df1.explode('county')
# Out:
#                                      organization_name ntd_id  itp_id  \
# 0                                       Angel View Inc    NaN     NaN
# 1                                  ARC Imperial Valley    NaN   398.0
# 2                               Area 1 Agency on Aging    NaN   399.0
# 3                                   Big Valley 50 Plus    NaN   404.0
# 4                       Care-A-Van Transit Systems Inc    NaN   407.0
# ..                                                 ...    ...     ...
# 142                       Loma Linda University Health    NaN     NaN
# 143          New Advances for People with Disabilities    NaN     NaN
# 144         Pomeroy Recreation & Rehabilitation Center    NaN     NaN
# 145  Regents of the University of California Santa ...    NaN     NaN
# 146  United Cerebral Palsy Association Inc of Stani...    NaN     NaN
#
#            organization_type            city              county  \
# 0    Non-Profit Organization  Cathedral City           Riverside
# 1    Non-Profit Organization       El Centro            Imperial
# 2    Non-Profit Organization          Eureka  Humboldt, De Norte
# 3    Non-Profit Organization          Beiber       Lassen, Modoc
# 4                    Company           Hemet           Riverside
# ..                       ...             ...                 ...
# 142                    Other      Loma Linda      San Bernardino
# 143  Non-Profit Organization     Bakersfield                Kern
# 144  Non-Profit Organization   San Francisco       San Francisco
# 145               University      Santa Cruz          Santa Cruz
# 146  Non-Profit Organization         Modesto          Stanislaus
#
#              merge_status
# 0    Name Match; Airtable
# 1    Name Match; Airtable
# 2    Name Match; Airtable
# 3    Name Match; Airtable
# 4    Name Match; Airtable
# ..                    ...
# 142              No Match
# 143              No Match
# 144              No Match
# 145              No Match
# 146              No Match
#
# [147 rows x 7 columns]

# %%
## from https://medium.com/swlh/three-routes-convert-comma-separated-column-to-rows-c17c85079ecf

df2 = df1.assign(county_split = df['county'].str.split(', ')).drop("county", axis=1)\
    .rename(columns = {"county_split": "county"})

# %%
df2
# Out:
#                                      organization_name ntd_id  itp_id  \
# 0                                       Angel View Inc    NaN     NaN
# 1                                  ARC Imperial Valley    NaN   398.0
# 2                               Area 1 Agency on Aging    NaN   399.0
# 3                                   Big Valley 50 Plus    NaN   404.0
# 4                       Care-A-Van Transit Systems Inc    NaN   407.0
# ..                                                 ...    ...     ...
# 142                       Loma Linda University Health    NaN     NaN
# 143          New Advances for People with Disabilities    NaN     NaN
# 144         Pomeroy Recreation & Rehabilitation Center    NaN     NaN
# 145  Regents of the University of California Santa ...    NaN     NaN
# 146  United Cerebral Palsy Association Inc of Stani...    NaN     NaN
#
#            organization_type            city          merge_status  \
# 0    Non-Profit Organization  Cathedral City  Name Match; Airtable
# 1    Non-Profit Organization       El Centro  Name Match; Airtable
# 2    Non-Profit Organization          Eureka  Name Match; Airtable
# 3    Non-Profit Organization          Beiber  Name Match; Airtable
# 4                    Company           Hemet  Name Match; Airtable
# ..                       ...             ...                   ...
# 142                    Other      Loma Linda              No Match
# 143  Non-Profit Organization     Bakersfield              No Match
# 144  Non-Profit Organization   San Francisco              No Match
# 145               University      Santa Cruz              No Match
# 146  Non-Profit Organization         Modesto              No Match
#
#                    county
# 0             [Riverside]
# 1              [Imperial]
# 2    [Humboldt, De Norte]
# 3         [Lassen, Modoc]
# 4             [Riverside]
# ..                    ...
# 142      [San Bernardino]
# 143                [Kern]
# 144       [San Francisco]
# 145          [Santa Cruz]
# 146          [Stanislaus]
#
# [147 rows x 7 columns]

# %%
df2 = df2.explode('county')

# %%
df2>>count(_.county)>>arrange(-_.n)
# Out:
#              county   n
# 0           Alameda  12
# 29        Riverside  12
# 32   San Bernardino  11
# 6      Contra Costa  10
# 34    San Francisco  10
# 39      Santa Clara   9
# 15             Kern   6
# 37        San Mateo   6
# 43           Solano   6
# 21        Mendocino   5
# 30       Sacramento   5
# 38    Santa Barbara   5
# 12         Humboldt   4
# 24         Monterey   4
# 33        San Diego   4
# 36  San Luis Obispo   4
# 1            Amador   3
# 2             Butte   3
# 3         Calaveras   3
# 20            Marin   3
# 26           Nevada   3
# 28           Placer   3
# 31       San Benito   3
# 35      San Joaquin   3
# 40       Santa Cruz   3
# 45       Stanislaus   3
# 46           Tehama   3
# 47           Tulare   3
# 13         Imperial   2
# 14             Inyo   2
# 17             Lake   2
# 19      Los Angeles   2
# 25             Napa   2
# 44           Sonoma   2
# 48         Tuolumne   2
# 49          Ventura   2
# 51             Yolo   2
# 4       Carson City   1
# 5            Colusa   1
# 7          De Norte   1
# 8         Del Norte   1
# 9           Douglas   1
# 10        El Dorado   1
# 11             Glen   1
# 16            Kings   1
# 18           Lassen   1
# 22            Modoc   1
# 23             Mono   1
# 27           Orange   1
# 41           Shasta   1
# 42           Sierra   1
# 50           Washoe   1

# %%
bar_chart((df2>>count(_.county)),
    "county",
    "n",
    "county",
    "Counties with 5310 Organizations Operating"
)
# Out:
# alt.Chart(...)

# %%
(df2>>count(_.county)).mean()
# Out:
# /tmp/ipykernel_1084/1613865003.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# n    3.5
# dtype: float64

# %%
(df2>>group_by(_.organization_type)>>count(_.county)>>arrange(-_.n)).head(20)
# Out:
#                                     organization_type           county   n
# 51                            Non-Profit Organization          Alameda  11
# 55                            Non-Profit Organization     Contra Costa   8
# 79                            Non-Profit Organization    San Francisco   8
# 84                            Non-Profit Organization      Santa Clara   8
# 74                            Non-Profit Organization        Riverside   7
# 77                            Non-Profit Organization   San Bernardino   6
# 61                            Non-Profit Organization             Kern   5
# 82                            Non-Profit Organization        San Mateo   5
# 67                            Non-Profit Organization        Mendocino   4
# 75                            Non-Profit Organization       Sacramento   4
# 88                            Non-Profit Organization           Solano   4
# 38  Independent Public Agency or Authority of Tran...        Riverside   3
# 40  Independent Public Agency or Authority of Tran...   San Bernardino   3
# 58                            Non-Profit Organization         Humboldt   3
# 70                            Non-Profit Organization         Monterey   3
# 78                            Non-Profit Organization        San Diego   3
# 81                            Non-Profit Organization  San Luis Obispo   3
# 83                            Non-Profit Organization    Santa Barbara   3
# 89                            Non-Profit Organization       Stanislaus   3
# 52                            Non-Profit Organization           Amador   2

# %% [markdown]
# ### Counts

# %%
len(df1>>filter(_.ntd_id.notnull()))
# Out:
# 37

# %%
(df1>>filter(_.ntd_id.notnull())).organization_type.value_counts()
# Out:
# Independent Public Agency or Authority of Transit Service                25
# City, County or Local Government Unit or Department of Transportation     8
# MPO/RTPA                                                                  3
# Private-Non-Profit Corporation                                            1
# Name: organization_type, dtype: int64

# %%
(df1>>filter(_.ntd_id.notnull())>>filter(_.organization_type=="Private-Non-Profit Corporation"))
# Out:
#                organization_name ntd_id  itp_id  \
# 66  Easy Lift Transportation Inc  90243   100.0
#
#                  organization_type    city         county       merge_status
# 66  Private-Non-Profit Corporation  Goleta  Santa Barbara  Manual Match, NTD

# %%
df1.organization_type.value_counts()
# Out:
# Non-Profit Organization                                                  90
# Independent Public Agency or Authority of Transit Service                28
# City, County or Local Government Unit or Department of Transportation    12
# Independent Agency                                                        5
# Company                                                                   4
# MPO/RTPA                                                                  3
# Other                                                                     3
# Private-Non-Profit Corporation                                            1
# University                                                                1
# Name: organization_type, dtype: int64

# %%
print(len(df1.query("organization_type==('Independent Public Agency or Authority of Transit Service') or organization_type==('City, County or Local Government Unit or Department of Transportation')")))


df1.query("organization_type==('Independent Public Agency or Authority of Transit Service') or organization_type==('City, County or Local Government Unit or Department of Transportation')")
# Out:
# 40
#                                      organization_name      ntd_id  itp_id  \
# 7                                      City of Fontana         NaN   414.0
# 8                                    City of Rio Vista  9R02-91014   264.0
# 9                                    City of Roseville       90168   271.0
# 10                                  City of Santa Rosa       90017   301.0
# 11                                     City of Visalia       90091   361.0
# 12                        Colusa County Transit Agency  9R02-91112    74.0
# 16                    Eastern Sierra Transit Authority  9R02-91062    99.0
# 17                  El Dorado County Transit Authority       90229   101.0
# 21                          Humboldt Transit Authority  9R02-91036   135.0
# 22           Imperial County Transportation Commission       90226   138.0
# 25                              Lake Transit Authority  9R02-91053   159.0
# 27                       Marin County Transit District       90234   194.0
# 28                         Mendocino Transit Authority  9R02-91047   198.0
# 31                            Monterey-Salinas Transit       90062   208.0
# 32                     Morongo Basin Transit Authority  9R02-91090   212.0
# 34                Napa Valley Transportation Authority       90088   218.0
# 37                                           Omnitrans       90029   232.0
# 39                    Palo Verde Valley Transit Agency  9R02-99454   238.0
# 44                     Redwood Coast Transit Authority  9R02-91097   261.0
# 45                            Riverside Transit Agency       90031   269.0
# 46    San Benito County Local Transportation Authority  9R02-91009   274.0
# 47               San Joaquin Regional Transit District       90012   284.0
# 49                   San Mateo County Transit District       90009   290.0
# 50         Santa Clara Valley Transportation Authority       90013   294.0
# 52                       Tahoe Transportation District       91092   331.0
# 55                                     Town of Truckee  9R02-91101   340.0
# 58                     Victor Valley Transit Authority       90148   360.0
# 62                 Yolo County Transportation District       90090   372.0
# 63                                      Amador Transit  9R02-91000    11.0
# 64                              Sunline Transit Agency       90079   327.0
# 67           Livermore Amador Valley Transit Authority       90144   167.0
# 68       San Francisco Municipal Transportation Agency       90015   282.0
# 71      City of Lafayette: Lamorinda Sprit Van Program         NaN   416.0
# 72                                      City of Vista          NaN     NaN
# 99                     Solano Tranportation Authority          NaN     NaN
# 119                      Calaveras County Public Works         NaN     NaN
# 134                       Tehama County Transit Agency  9R02-91089     NaN
# 135              Tuolumne County Transit Agency (TCTA)  9R02-91057     NaN
# 137       Contra Costa Transportation Authority (CCTA)         NaN     NaN
# 138  County of Nevada Public Works Transit Services...         NaN     NaN
#
#                                      organization_type             city  \
# 7    City, County or Local Government Unit or Depar...          Fontana
# 8    City, County or Local Government Unit or Depar...        Rio Vista
# 9    City, County or Local Government Unit or Depar...        Roseville
# 10   City, County or Local Government Unit or Depar...       Santa Rosa
# 11   City, County or Local Government Unit or Depar...          Visalia
# 12   City, County or Local Government Unit or Depar...           Colusa
# 16   Independent Public Agency or Authority of Tran...           Bishop
# 17   Independent Public Agency or Authority of Tran...  Diamond Springs
# 21   Independent Public Agency or Authority of Tran...           Eureka
# 22   Independent Public Agency or Authority of Tran...        El Centro
# 25   Independent Public Agency or Authority of Tran...       Lower Lake
# 27   Independent Public Agency or Authority of Tran...       San Rafael
# 28   Independent Public Agency or Authority of Tran...            Ukiah
# 31   Independent Public Agency or Authority of Tran...         Monterey
# 32   Independent Public Agency or Authority of Tran...      Joshua Tree
# 34   Independent Public Agency or Authority of Tran...             Napa
# 37   Independent Public Agency or Authority of Tran...   San Bernardino
# 39   Independent Public Agency or Authority of Tran...           Blythe
# 44   Independent Public Agency or Authority of Tran...    Crescent City
# 45   Independent Public Agency or Authority of Tran...        Riverside
# 46   Independent Public Agency or Authority of Tran...        Hollister
# 47   Independent Public Agency or Authority of Tran...         Stockton
# 49   Independent Public Agency or Authority of Tran...       San Carlos
# 50   Independent Public Agency or Authority of Tran...         San Jose
# 52   Independent Public Agency or Authority of Tran...      Zephyr Cove
# 55   City, County or Local Government Unit or Depar...          Truckee
# 58   Independent Public Agency or Authority of Tran...         Hesperia
# 62   Independent Public Agency or Authority of Tran...         Woodland
# 63   Independent Public Agency or Authority of Tran...          Jackson
# 64   Independent Public Agency or Authority of Tran...   Thousand Palms
# 67   Independent Public Agency or Authority of Tran...        Livermore
# 68   City, County or Local Government Unit or Depar...    San Francisco
# 71   City, County or Local Government Unit or Depar...        Lafayette
# 72   City, County or Local Government Unit or Depar...            Vista
# 99   Independent Public Agency or Authority of Tran...      Suisun City
# 119  City, County or Local Government Unit or Depar...      San Andreas
# 134  City, County or Local Government Unit or Depar...           Gerber
# 135  Independent Public Agency or Authority of Tran...           Sonora
# 137  Independent Public Agency or Authority of Tran...     Walnut Creek
# 138  Independent Public Agency or Authority of Tran...     Grass Valley
#
#                                    county            merge_status
# 7                          San Bernardino    Name Match; Airtable
# 8                                  Solano         Name Match; NTD
# 9                                  Placer         Name Match; NTD
# 10                                 Sonoma         Name Match; NTD
# 11                                 Tulare         Name Match; NTD
# 12                                 Colusa         Name Match; NTD
# 16                                   Inyo         Name Match; NTD
# 17                              El Dorado         Name Match; NTD
# 21                               Humboldt         Name Match; NTD
# 22                               Imperial         Name Match; NTD
# 25                                   Lake         Name Match; NTD
# 27                                  Marin         Name Match; NTD
# 28                              Mendocino         Name Match; NTD
# 31                               Monterey         Name Match; NTD
# 32                         San Bernardino         Name Match; NTD
# 34                                   Napa         Name Match; NTD
# 37                         San Bernardino         Name Match; NTD
# 39                              Riverside         Name Match; NTD
# 44                              Del Norte         Name Match; NTD
# 45                              Riverside         Name Match; NTD
# 46                             San Benito    Name Match; Airtable
# 47                            San Joaquin         Name Match; NTD
# 49                              San Mateo         Name Match; NTD
# 50                            Santa Clara         Name Match; NTD
# 52   Douglas, Placer, Washoe, Carson City    Name Match; Airtable
# 55                                 Nevada         Name Match; NTD
# 58                         San Bernardino         Name Match; NTD
# 62                                   Yolo         Name Match; NTD
# 63                                 Amador       Manual Match, NTD
# 64                              Riverside       Manual Match, NTD
# 67                                Alameda       Manual Match, NTD
# 68                          San Francisco       Manual Match, NTD
# 71                           Contra Costa  Manual Match, Airtable
# 72                              San Diego  Manual Match, Airtable
# 99                                 Solano  Manual Match, Airtable
# 119                             Calaveras                No Match
# 134                                Tehama       Manual Match, NTD
# 135                              Tuolumne       Manual Match, NTD
# 137                          Contra Costa                No Match
# 138                                Nevada                No Match

# %%
print(len(df1.query("organization_name.str.contains('Transit Authority') or organization_name.str.contains('Transit Agency') or organization_name.str.contains('Transportation Authority') or organization_name.str.contains('Transportation Agency') or organization_name.str.contains('Transportation District') or organization_name.str.contains('Transit District')")
))

df1.query("organization_name.str.contains('Transit Authority') or organization_name.str.contains('Transit Agency') or organization_name.str.contains('Transportation Authority') or organization_name.str.contains('Transportation Agency') or organization_name.str.contains('Transportation District') or organization_name.str.contains('Transit District')")
# Out:
# 25
#                                     organization_name      ntd_id  itp_id  \
# 12                       Colusa County Transit Agency  9R02-91112    74.0
# 16                   Eastern Sierra Transit Authority  9R02-91062    99.0
# 17                 El Dorado County Transit Authority       90229   101.0
# 21                         Humboldt Transit Authority  9R02-91036   135.0
# 25                             Lake Transit Authority  9R02-91053   159.0
# 27                      Marin County Transit District       90234   194.0
# 28                        Mendocino Transit Authority  9R02-91047   198.0
# 32                    Morongo Basin Transit Authority  9R02-91090   212.0
# 34               Napa Valley Transportation Authority       90088   218.0
# 39                   Palo Verde Valley Transit Agency  9R02-99454   238.0
# 44                    Redwood Coast Transit Authority  9R02-91097   261.0
# 45                           Riverside Transit Agency       90031   269.0
# 46   San Benito County Local Transportation Authority  9R02-91009   274.0
# 47              San Joaquin Regional Transit District       90012   284.0
# 49                  San Mateo County Transit District       90009   290.0
# 50        Santa Clara Valley Transportation Authority       90013   294.0
# 52                      Tahoe Transportation District       91092   331.0
# 58                    Victor Valley Transit Authority       90148   360.0
# 62                Yolo County Transportation District       90090   372.0
# 64                             Sunline Transit Agency       90079   327.0
# 67          Livermore Amador Valley Transit Authority       90144   167.0
# 68      San Francisco Municipal Transportation Agency       90015   282.0
# 134                      Tehama County Transit Agency  9R02-91089     NaN
# 135             Tuolumne County Transit Agency (TCTA)  9R02-91057     NaN
# 137      Contra Costa Transportation Authority (CCTA)         NaN     NaN
#
#                                      organization_type             city  \
# 12   City, County or Local Government Unit or Depar...           Colusa
# 16   Independent Public Agency or Authority of Tran...           Bishop
# 17   Independent Public Agency or Authority of Tran...  Diamond Springs
# 21   Independent Public Agency or Authority of Tran...           Eureka
# 25   Independent Public Agency or Authority of Tran...       Lower Lake
# 27   Independent Public Agency or Authority of Tran...       San Rafael
# 28   Independent Public Agency or Authority of Tran...            Ukiah
# 32   Independent Public Agency or Authority of Tran...      Joshua Tree
# 34   Independent Public Agency or Authority of Tran...             Napa
# 39   Independent Public Agency or Authority of Tran...           Blythe
# 44   Independent Public Agency or Authority of Tran...    Crescent City
# 45   Independent Public Agency or Authority of Tran...        Riverside
# 46   Independent Public Agency or Authority of Tran...        Hollister
# 47   Independent Public Agency or Authority of Tran...         Stockton
# 49   Independent Public Agency or Authority of Tran...       San Carlos
# 50   Independent Public Agency or Authority of Tran...         San Jose
# 52   Independent Public Agency or Authority of Tran...      Zephyr Cove
# 58   Independent Public Agency or Authority of Tran...         Hesperia
# 62   Independent Public Agency or Authority of Tran...         Woodland
# 64   Independent Public Agency or Authority of Tran...   Thousand Palms
# 67   Independent Public Agency or Authority of Tran...        Livermore
# 68   City, County or Local Government Unit or Depar...    San Francisco
# 134  City, County or Local Government Unit or Depar...           Gerber
# 135  Independent Public Agency or Authority of Tran...           Sonora
# 137  Independent Public Agency or Authority of Tran...     Walnut Creek
#
#                                    county          merge_status
# 12                                 Colusa       Name Match; NTD
# 16                                   Inyo       Name Match; NTD
# 17                              El Dorado       Name Match; NTD
# 21                               Humboldt       Name Match; NTD
# 25                                   Lake       Name Match; NTD
# 27                                  Marin       Name Match; NTD
# 28                              Mendocino       Name Match; NTD
# 32                         San Bernardino       Name Match; NTD
# 34                                   Napa       Name Match; NTD
# 39                              Riverside       Name Match; NTD
# 44                              Del Norte       Name Match; NTD
# 45                              Riverside       Name Match; NTD
# 46                             San Benito  Name Match; Airtable
# 47                            San Joaquin       Name Match; NTD
# 49                              San Mateo       Name Match; NTD
# 50                            Santa Clara       Name Match; NTD
# 52   Douglas, Placer, Washoe, Carson City  Name Match; Airtable
# 58                         San Bernardino       Name Match; NTD
# 62                                   Yolo       Name Match; NTD
# 64                              Riverside     Manual Match, NTD
# 67                                Alameda     Manual Match, NTD
# 68                          San Francisco     Manual Match, NTD
# 134                                Tehama     Manual Match, NTD
# 135                              Tuolumne     Manual Match, NTD
# 137                          Contra Costa              No Match

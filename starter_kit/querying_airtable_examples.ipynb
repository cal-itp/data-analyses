# %% [markdown]
# # Querying the Warehouse

# %% [markdown]
# This notebook goes through the few ways you can connect to tables in the warehouse, whether it be tables orginating from Airtable or those being generated from GTFS feeds.
#
# To see what tables are available to query, check out the [DBT docs](https://dbt-docs.calitp.org/#!/overview), and go to `calitp_warehouse`>>`models`>>`mart`.
#
# The tables from Airtable are located in `transit_database` or `mart_transit_database`
#
#
# This is also detailed in the [Cal-ITP Docs](https://docs.calitp.org/data-infra/analytics_tools/python_libraries.html?highlight=tbls).

# %%
import pandas as pd

import shared_utils
# Out:
# /opt/conda/lib/python3.9/site-packages/geopandas/_compat.py:124: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
import os
os.environ["CALITP_BQ_MAX_BYTES"] = str(800_000_000_000) ## 800GB?

# %%
pd.options.display.max_columns = 100

# %% [markdown]
# ## Using Query_Sql
#
# You can use the same sql syntax you would use in Big Query to query a table. This function takes the sql query and allows you to work directly with the output as a pandas dataframe.

# %%
## import the package that has the query_sql function

from calitp_data_analysis import sql, magics

# %%
dim_orgs_sql = sql.query_sql(f'''
SELECT * FROM `cal-itp-data-infra.mart_transit_database.dim_organizations`
''')

# %%
dim_orgs_sql.head()
# Out:
#                                 key   source_record_id  name  \
# 0  c94c49e21a8ee2e6716fb0194f64cde0  recaBKK3NlO5CMsyD  None
# 1  c82f1f1a872cda2ba3ceb0e9228d6dbb  recQQo6hAZWEs5y0h  None
# 2  728c79b2b4f30f00fab2d1809dc7eaae  recFwTA2CJkcSZBUU  None
# 3  e4524bd70b6a3c768976441b281f3b06  recFwTA2CJkcSZBUU  None
# 4  536256e13e6a90d0ab5a72a17484d756  reci6D14cTTXA4GsG  None
#
#   organization_type roles  itp_id details caltrans_district website  \
# 0              None    []     NaN    None              None    None
# 1              None    []     NaN    None              None    None
# 2              None    []     NaN    None              None    None
# 3              None    []     NaN    None              None    None
# 4              None    []     NaN    None              None    None
#
#   reporting_category hubspot_company_record_id gtfs_static_status  \
# 0               None                      None          Static OK
# 1               None                      None          Static OK
# 2               None                      None          Static OK
# 3               None                      None          Static OK
# 4               None                      None          Static OK
#
#   gtfs_realtime_status _deprecated__assessment_status  \
# 0        RT Incomplete                           None
# 1        RT Incomplete                          False
# 2        RT Incomplete                           None
# 3        RT Incomplete                           None
# 4        RT Incomplete                           None
#
#   manual_check__contact_on_website alias is_public_entity ntd_id  \
# 0                             None    []             None   None
# 1                             None    []             None   None
# 2                             None    []             None   None
# 3                          Unknown    []             None   None
# 4                             None    []             None   None
#
#   public_currently_operating public_currently_operating_fixed_route  \
# 0                       None                                   None
# 1                       None                                   None
# 2                       None                                   None
# 3                       None                                   None
# 4                       None                                   None
#
#    _is_current               _valid_from                        _valid_to
# 0        False 2022-07-08 00:00:00+00:00 2022-07-08 23:59:59.999999+00:00
# 1        False 2023-04-13 00:00:00+00:00 2023-04-27 23:59:59.999999+00:00
# 2        False 2022-09-23 00:00:00+00:00 2022-10-17 23:59:59.999999+00:00
# 3        False 2022-10-18 00:00:00+00:00 2022-10-24 23:59:59.999999+00:00
# 4        False 2022-09-29 00:00:00+00:00 2022-10-17 23:59:59.999999+00:00

# %% [markdown]
# ## Using Tbls
#
# This function allows you to query tables from the warehouse as pandas dataframe.

# %%
## import the package for querying tables directly from the warehouse, tbls
## also import Siuba for Option 2

from siuba import *
from calitp_data_analysis.tables import tbls

# %% [markdown]
# ### Option 1: Using tbls
#
# hint: hit `tab` after the period to see what options you have. example: tbls.`tab`

# %%
tbls.mart_transit_database.dim_services()
# Out:
# # Source: lazy query
# # DB Conn: Engine(bigquery://cal-itp-data-infra/?maximum_bytes_billed=5000000000)
# # Preview:
#                                 key   source_record_id  name   service_type  \
# 0  f6fa8daf4fac9b46443d4786503d0edc  recbJtVSGpX9Ojz2j  None             []
# 1  e6d6347b6fa61ff42f8ebed41a983c07  recx7nz3W3RRkBRIq   Yes             []
# 2  c357000a17918580514a9205d7a36ec3  recZi8sngoKH9jqKZ  DASH  [fixed-route]
# 3  46f3d92a28bef0b3e0cbac24fda3b79a  recZi8sngoKH9jqKZ  DASH  [fixed-route]
# 4  892d779fc8e06b2a305484d3ba098849  recWExeJgJw1wa7AV  FRAN    [on-demand]
#
#     mode operating_counties gtfs_schedule_status  \
# 0     []                 []                 None
# 1     []                 []                 None
# 2  [bus]      [Los Angeles]                   ok
# 3  [bus]      [Los Angeles]                   ok
# 4  [bus]           [Orange]               needed
#
#               gtfs_schedule_quality  \
# 0                              None
# 1                              None
# 2  2 - GTFS data has active service
# 3  2 - GTFS data has active service
# 4                              None
#
#   manual_check__gtfs_realtime_data_ingested_in_trip_planner  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#   manual_check__gtfs_schedule_data_ingested_in_trip_planner deprecated_date  \
# 0                                               None                   None
# 1                                               None                   None
# 2                                               None                   None
# 3                                               None                   None
# 4                                               None                   None
#
#   fixed_route is_public public_currently_operating  \
# 0        None        No                       None
# 1        None        No                       None
# 2        None      None                       None
# 3        None      None                       None
# 4        None      None                       None
#
#   public_currently_operating_fixed_route start_date operational_status  \
# 0                                   None       None               None
# 1                                   None       None               None
# 2                                   None       None               None
# 3                                   None       None               None
# 4                                   None       None               None
#
#   _deprecated__currently_operating _deprecated__assessment_status  \
# 0                             None                          False
# 1                             None                          False
# 2                             True                           True
# 3                             True                           None
# 4                             True                           None
#
#                 _valid_from                        _valid_to  _is_current
# 0 2023-04-06 00:00:00+00:00 2023-04-06 23:59:59.999999+00:00        False
# 1 2023-05-03 00:00:00+00:00 2023-05-04 23:59:59.999999+00:00        False
# 2 2022-12-02 00:00:00+00:00 2023-01-13 23:59:59.999999+00:00        False
# 3 2022-06-29 00:00:00+00:00 2022-12-01 23:59:59.999999+00:00        False
# 4 2022-06-29 00:00:00+00:00 2022-12-01 23:59:59.999999+00:00        False
# # .. may have more rows

# %% [markdown]
# ### Option 2: Using Siuba
#
# [Siuba Reference Guide](https://siuba.org/api/)

# %%
tbls_services = (
    tbls.mart_transit_database.dim_services()
     >> collect() 
)
## the collect is needed to save the results as a pandas dataframe

# %%
tbls_services.head()
# Out:
#                                 key   source_record_id  name   service_type  \
# 0  f6fa8daf4fac9b46443d4786503d0edc  recbJtVSGpX9Ojz2j  None             []
# 1  e6d6347b6fa61ff42f8ebed41a983c07  recx7nz3W3RRkBRIq   Yes             []
# 2  c357000a17918580514a9205d7a36ec3  recZi8sngoKH9jqKZ  DASH  [fixed-route]
# 3  46f3d92a28bef0b3e0cbac24fda3b79a  recZi8sngoKH9jqKZ  DASH  [fixed-route]
# 4  892d779fc8e06b2a305484d3ba098849  recWExeJgJw1wa7AV  FRAN    [on-demand]
#
#     mode operating_counties gtfs_schedule_status  \
# 0     []                 []                 None
# 1     []                 []                 None
# 2  [bus]      [Los Angeles]                   ok
# 3  [bus]      [Los Angeles]                   ok
# 4  [bus]           [Orange]               needed
#
#               gtfs_schedule_quality  \
# 0                              None
# 1                              None
# 2  2 - GTFS data has active service
# 3  2 - GTFS data has active service
# 4                              None
#
#   manual_check__gtfs_realtime_data_ingested_in_trip_planner  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#   manual_check__gtfs_schedule_data_ingested_in_trip_planner deprecated_date  \
# 0                                               None                   None
# 1                                               None                   None
# 2                                               None                   None
# 3                                               None                   None
# 4                                               None                   None
#
#   fixed_route is_public public_currently_operating  \
# 0        None        No                       None
# 1        None        No                       None
# 2        None      None                       None
# 3        None      None                       None
# 4        None      None                       None
#
#   public_currently_operating_fixed_route start_date operational_status  \
# 0                                   None       None               None
# 1                                   None       None               None
# 2                                   None       None               None
# 3                                   None       None               None
# 4                                   None       None               None
#
#   _deprecated__currently_operating _deprecated__assessment_status  \
# 0                             None                          False
# 1                             None                          False
# 2                             True                           True
# 3                             True                           None
# 4                             True                           None
#
#                 _valid_from                        _valid_to  _is_current
# 0 2023-04-06 00:00:00+00:00 2023-04-06 23:59:59.999999+00:00        False
# 1 2023-05-03 00:00:00+00:00 2023-05-04 23:59:59.999999+00:00        False
# 2 2022-12-02 00:00:00+00:00 2023-01-13 23:59:59.999999+00:00        False
# 3 2022-06-29 00:00:00+00:00 2022-12-01 23:59:59.999999+00:00        False
# 4 2022-06-29 00:00:00+00:00 2022-12-01 23:59:59.999999+00:00        False

# %%
## another example table query

# %%
bridge_table_tbls = ( 
    tbls.mart_transit_database.bridge_organizations_x_services_managed()
    >> filter(_._is_current == True)
    >> collect() 
)

# %%
bridge_table_tbls.sample()
# Out:
#                      organization_key                       service_key  \
# 212  f3dea1b508e56ee099602255b43cedfb  4ecee70c463fd9458720c664e233844e
#
#      organization_name                          service_name  \
# 212  City of Hawthorne  Hawthorne Dial-A-Ride Transportation
#
#                   _valid_from                        _valid_to  _is_current
# 212 2023-05-25 00:00:00+00:00 2098-12-31 23:59:59.999999+00:00         True

# %% [markdown]
# ## Joining tables with QuerySQL and dataframes from tbls

# %% [markdown]
# ### Using pandas to join

# %%
tbs_join = pd.merge(dim_orgs_sql, bridge_table_tbls, left_on="key", right_on="organization_key", indicator=True)

# %%
tbs_join.sample()
# Out:
#                                   key   source_record_id  \
# 540  432ebdfde54e5d6fe2f39fb78d6277c0  reclbzT9trIiGwjBB
#
#                                name   organization_type roles  itp_id details  \
# 540  Tuolumne County Transit Agency  Independent Agency    []   482.0    None
#
#     caltrans_district                                 website  \
# 540     10 - Stockton  https://www.tuolumnecountytransit.com/
#
#     reporting_category hubspot_company_record_id gtfs_static_status  \
# 540               Core                1880690880  Static Incomplete
#
#     gtfs_realtime_status _deprecated__assessment_status  \
# 540        RT Incomplete                           True
#
#     manual_check__contact_on_website alias is_public_entity      ntd_id  \
# 540                               No    []             True  9R02-91057
#
#     public_currently_operating public_currently_operating_fixed_route  \
# 540                       True                                   True
#
#      _is_current_x             _valid_from_x                      _valid_to_x  \
# 540           True 2023-06-17 00:00:00+00:00 2098-12-31 23:59:59.999999+00:00
#
#                      organization_key                       service_key  \
# 540  432ebdfde54e5d6fe2f39fb78d6277c0  29d5b46d370b915eba9a25548ecf26ae
#
#                   organization_name             service_name  \
# 540  Tuolumne County Transit Agency  Tuolumne County Transit
#
#                 _valid_from_y                      _valid_to_y  _is_current_y  \
# 540 2023-06-17 00:00:00+00:00 2098-12-31 23:59:59.999999+00:00           True
#
#     _merge
# 540   both

# %% [markdown]
# ### Adding the join into the sql query

# %%
# test join using sql as an example of a larger sql query

sql_join = (
    sql.query_sql(f'''
WITH orgs AS (
    SELECT * 
    FROM `cal-itp-data-infra.mart_transit_database.dim_organizations`
    WHERE _is_current = True
    ),
    
bridge AS (
    SELECT * 
    FROM `cal-itp-data-infra.mart_transit_database.bridge_organizations_x_services_managed`
    WHERE _is_current = True
    ), 
    
services AS (
    SELECT *
    FROM `cal-itp-data-infra.mart_transit_database.dim_services`
    WHERE _is_current = True
    ),

join1 AS (
    SELECT * 
    FROM orgs AS T1
    LEFT JOIN bridge AS T2
        ON 
            T1.key = T2.organization_key
    LEFT JOIN services as T3
        ON
            T2.service_key = T3.key
    ) 

SELECT * FROM join1 
'''
                 )
)

# %%
sql_join.sample(5)
# Out:
#                                    key   source_record_id  \
# 989   b740efd508952645b48c2b882555f726  recI6rQVkFzLOV2yY
# 1040  51866b562b8ae2243def7d4adf333c32  recgOcejLwLyXyUGr
# 719   3592db816df3254dc076fb815c783e2a  reczF5Y8R9CUJmfSy
# 525   d8bf13cbee98a8cceeb41520a6f23b0a  recRfiIeNE7hyQ5h3
# 964   a896ecc2a4b19a32d7b54d0d3c6039f2  rec8XA7qMoBtd0Vef
#
#                                        name        organization_type roles  \
# 989                                Avenidas  Non-Profit Organization    []
# 1040  Tule River Indian Health Center, Inc.                  Company    []
# 719                        City of Pasadena                City/Town    []
# 525                 American Cancer Society  Non-Profit Organization    []
# 964                  Scripps Mercy Hospital  Non-Profit Organization    []
#
#       itp_id details caltrans_district  \
# 989    401.0    None      04 - Oakland
# 1040     NaN    None       06 - Fresno
# 719    243.0    None  07 - Los Angeles
# 525    396.0    None              None
# 964      NaN    None    11 - San Diego
#
#                                                 website reporting_category  \
# 989                           https://www.avenidas.org/               #N/A
# 1040                    http://www.trihci.org/outreach/               None
# 719      https://www.cityofpasadena.net/transportation/               Core
# 525                             https://www.cancer.org/               #N/A
# 964   https://www.scripps.org/locations/hospitals/sc...               None
#
#      hubspot_company_record_id gtfs_static_status gtfs_realtime_status  \
# 989                 8567080963          Static OK        RT Incomplete
# 1040                      None          Static OK        RT Incomplete
# 719                 1880531805          Static OK                RT OK
# 525                 8567108020          Static OK        RT Incomplete
# 964                       None          Static OK        RT Incomplete
#
#       _deprecated__assessment_status manual_check__contact_on_website alias  \
# 989                            False                          Unknown    []
# 1040                           False                          Unknown    []
# 719                             True                              Yes    []
# 525                            False                          Unknown    []
# 964                            False                          Unknown    []
#
#       is_public_entity ntd_id  public_currently_operating  \
# 989              False   None                       False
# 1040             False   None                       False
# 719               True  99424                        True
# 525              False   None                       False
# 964              False   None                       False
#
#       public_currently_operating_fixed_route  _is_current  \
# 989                                    False         True
# 1040                                   False         True
# 719                                     True         True
# 525                                    False         True
# 964                                    False         True
#
#                    _valid_from                        _valid_to  \
# 989  2023-05-05 00:00:00+00:00 2098-12-31 23:59:59.999999+00:00
# 1040 2023-05-05 00:00:00+00:00 2098-12-31 23:59:59.999999+00:00
# 719  2023-05-23 00:00:00+00:00 2098-12-31 23:59:59.999999+00:00
# 525  2023-05-25 00:00:00+00:00 2098-12-31 23:59:59.999999+00:00
# 964  2023-05-27 00:00:00+00:00 2098-12-31 23:59:59.999999+00:00
#
#                       organization_key                       service_key  \
# 989   b740efd508952645b48c2b882555f726  4af2caa4936b690bfcff381ea5543833
# 1040  51866b562b8ae2243def7d4adf333c32  56f69699b45fd5ab9279b238aedeb5ef
# 719   3592db816df3254dc076fb815c783e2a  05c306338b9c363e41018c9b5e695437
# 525   d8bf13cbee98a8cceeb41520a6f23b0a  a225be17cda56b7197a0a02347a89440
# 964   a896ecc2a4b19a32d7b54d0d3c6039f2  73321ecc080ba5baf5a01b109b36fd7d
#
#                           organization_name                     service_name  \
# 989                                Avenidas            Avenidas Door-to-Door
# 1040  Tule River Indian Health Center, Inc.  Tule River Indian Health Center
# 719                        City of Pasadena             Pasadena Dial-A-Ride
# 525                 American Cancer Society          American Cancer Society
# 964                  Scripps Mercy Hospital           Scripps Mercy Hospital
#
#                  _valid_from_1                      _valid_to_1 _is_current_1  \
# 989  2023-05-16 00:00:00+00:00 2098-12-31 23:59:59.999999+00:00          True
# 1040 2023-05-16 00:00:00+00:00 2098-12-31 23:59:59.999999+00:00          True
# 719  2023-05-23 00:00:00+00:00 2098-12-31 23:59:59.999999+00:00          True
# 525  2023-05-25 00:00:00+00:00 2098-12-31 23:59:59.999999+00:00          True
# 964  2023-06-03 00:00:00+00:00 2098-12-31 23:59:59.999999+00:00          True
#
#                                  key_1 source_record_id_1  \
# 989   4af2caa4936b690bfcff381ea5543833  recsK6NbG9okIQxVe
# 1040  56f69699b45fd5ab9279b238aedeb5ef  receq3UBiYoEvPhoy
# 719   05c306338b9c363e41018c9b5e695437  rec3B8poy9I1MxbDu
# 525   a225be17cda56b7197a0a02347a89440  recVd6dDU5KInfB60
# 964   73321ecc080ba5baf5a01b109b36fd7d  recE4pyc8hxRvfi06
#
#                                name_1                  service_type  \
# 989             Avenidas Door-to-Door             [NEMT, on-demand]
# 1040  Tule River Indian Health Center             [NEMT, on-demand]
# 719              Pasadena Dial-A-Ride  [ADA paratransit, on-demand]
# 525           American Cancer Society             [ADA paratransit]
# 964            Scripps Mercy Hospital                        [NEMT]
#
#            mode operating_counties gtfs_schedule_status gtfs_schedule_quality  \
# 989   [car/van]        [San Mateo]               needed                  None
# 1040  [car/van]           [Tulare]               needed                  None
# 719       [bus]      [Los Angeles]               needed                  None
# 525   [car/van]                 []               needed                  None
# 964   [car/van]        [San Diego]                 None                  None
#
#      manual_check__gtfs_realtime_data_ingested_in_trip_planner  \
# 989                        N/A - no fixed-route service
# 1040                       N/A - no fixed-route service
# 719                        N/A - no fixed-route service
# 525                        N/A - no fixed-route service
# 964                        N/A - no fixed-route service
#
#      manual_check__gtfs_schedule_data_ingested_in_trip_planner  \
# 989                        N/A - no fixed-route service
# 1040                       N/A - no fixed-route service
# 719                        N/A - no fixed-route service
# 525                        N/A - no fixed-route service
# 964                        N/A - no fixed-route service
#
#      deprecated_date fixed_route is_public public_currently_operating_1  \
# 989             None        None       Yes                        False
# 1040            None        None       Yes                        False
# 719             None        None        No                        False
# 525             None        None        No                        False
# 964             None        None        No                        False
#
#      public_currently_operating_fixed_route_1 start_date operational_status  \
# 989                                     False       None          Operating
# 1040                                    False       None          Operating
# 719                                     False       None          Operating
# 525                                     False       None          Operating
# 964                                     False       None          Operating
#
#      _deprecated__currently_operating _deprecated__assessment_status_1  \
# 989                              True                            False
# 1040                             True                            False
# 719                              True                            False
# 525                              True                            False
# 964                              True                            False
#
#                  _valid_from_2                      _valid_to_2 _is_current_2
# 989  2023-05-16 00:00:00+00:00 2098-12-31 23:59:59.999999+00:00          True
# 1040 2023-05-16 00:00:00+00:00 2098-12-31 23:59:59.999999+00:00          True
# 719  2023-05-16 00:00:00+00:00 2098-12-31 23:59:59.999999+00:00          True
# 525  2023-05-17 00:00:00+00:00 2098-12-31 23:59:59.999999+00:00          True
# 964  2023-06-03 00:00:00+00:00 2098-12-31 23:59:59.999999+00:00          True

# %%
pip install --upgrade gtfs-realtime-bindings
# Out:
# ...
#   Using cached gtfs_realtime_bindings-1.0.0-py3-none-any.whl
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from google.transit import gtfs_realtime_pb2
import requests
import datetime

# %%
ts_epoch = 1718312918
datetime.datetime.fromtimestamp(ts_epoch).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2024-06-13 21:08:38'

# %%
feed = gtfs_realtime_pb2.FeedMessage()
response = requests.get('https://infopoint.sunline.org/InfoPoint/GTFS-Realtime.ashx?Type=VehiclePosition')
feed.ParseFromString(response.content)
# for entity in feed.entity:
#    print(entity.vehicle)
feed
# Out:
# header {
#   gtfs_realtime_version: "2.0"
#   incrementality: FULL_DATASET
#   timestamp: 1738874530
# }
# entity {
#   id: "576"
#   vehicle {
#     trip {
#       trip_id: "t4B0-b15-sl2"
#       schedule_relationship: SCHEDULED
#       route_id: "2"
#     }
#     position {
#       latitude: 33.8230934
#       longitude: -116.546715
#       bearing: 270
#       speed: 2.68224
#     }
#     current_stop_sequence: 2400
#     current_status: INCOMING_AT
#     timestamp: 1738874521
#     congestion_level: UNKNOWN_CONGESTION_LEVEL
#     stop_id: "127"
#     vehicle {
#       id: "576"
#       label: "576"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "588"
#   vehicle {
#     trip {
#       trip_id: "t45B-b2B-sl2"
#       schedule_relationship: SCHEDULED
#       route_id: "4"
#     }
#     position {
#       latitude: 33.7639809
#       longitude: -116.40831
#       bearing: 180
#       speed: 18.32864
#     }
#     current_stop_sequence: 0
# ...

# %%
feed = gtfs_realtime_pb2.FeedMessage()
response = requests.get('https://laxflyaway.transloc.com/subscriptions/gtfsrt/vehicles.ashx')
feed.ParseFromString(response.content)
# for entity in feed.entity:
#    print(entity.vehicle)
feed
# Out:
# header {
#   gtfs_realtime_version: "2.0"
#   timestamp: 1739564730
# }
# entity {
#   id: "36"
#   vehicle {
#     trip {
#       trip_id: "1643"
#       route_id: "1"
#     }
#     position {
#       latitude: 33.9433098
#       longitude: -118.39856
#     }
#     current_stop_sequence: 80
#     current_status: INCOMING_AT
#     timestamp: 1739564747
#     stop_id: "9"
#     vehicle {
#       id: "36"
#       label: "9905"
#     }
#   }
# }
# entity {
#   id: "45"
#   vehicle {
#     trip {
#       trip_id: "1739"
#       route_id: "2"
#     }
#     position {
#       latitude: 33.9450188
#       longitude: -118.39447
#     }
#     current_stop_sequence: 20
#     current_status: INCOMING_AT
#     timestamp: 1739564745
#     stop_id: "2"
#     vehicle {
#       id: "45"
#       label: "9808"
#     }
#   }
# }
# entity {
#   id: "53"
#   vehicle {
#     trip {
#       trip_id: "1662"
#       route_id: "5"
#     }
#     position {
#       latitude: 34.0308914
# ...

# %%
feed = gtfs_realtime_pb2.FeedMessage()
response = requests.get('https://lbtgtfs.lbtransit.com/TMGTFSRealTimeWebService/Vehicle/VehiclePositions.pb')
feed.ParseFromString(response.content)
# for entity in feed.entity:
#    print(entity.vehicle)
feed
# Out:
# header {
#   gtfs_realtime_version: "2.0"
#   timestamp: 1739564365
# }
# entity {
#   id: "2402"
#   vehicle {
#     trip {
#       trip_id: "10222620"
#       start_date: "20250214"
#       route_id: "172"
#     }
#     position {
#       latitude: 33.77388
#       longitude: -118.193848
#       bearing: 180
#       speed: 6.7056
#     }
#     timestamp: 1739564358
#     vehicle {
#       id: "2522"
#       label: "2402"
#     }
#   }
# }
# entity {
#   id: "2403"
#   vehicle {
#     trip {
#       trip_id: "10223306"
#       start_date: "20250214"
#       route_id: "22"
#     }
#     position {
#       latitude: 33.9132309
#       longitude: -118.140366
#       bearing: 45
#     }
#     timestamp: 1739564347
#     vehicle {
#       id: "2523"
#       label: "2403"
#     }
#   }
# }
# entity {
#   id: "2404"
#   vehicle {
#     trip {
#       trip_id: "10222945"
#       start_date: "20250214"
#       route_id: "41"
#     }
#     position {
#       latitude: 33.7826691
# ...

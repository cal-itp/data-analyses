# %%
from calitp_data_analysis.tables import tbls

# %%
import calitp_data_analysis.magics

# %%
import pandas as pd
from siuba import collect
from calitp_data_analysis.sql import query_sql
from siuba.data import mtcars

# %%
# %%sql
#
# SELECT
#     COUNT(*)
# FROM `mart_gtfs.dim_schedule_feeds`
# WHERE
#     key = "db58891de4281f965b4e7745675415ab"
# LIMIT 10
# Out:
#    f0_
# 0    1

# %%
tbls.mart_gtfs.dim_agency()
# Out:
# # Source: lazy query
# # DB Conn: Engine(bigquery://cal-itp-data-infra/?maximum_bytes_billed=5000000000)
# # Preview:
#                                 key                         _gtfs_key  \
# 0  56112d81d62d71d408ea0247309178e4  090343c89ab8fe1d5e3b79e5687bbcca
# 1  033d018b031002914fbfa48c872d4a65  8f5e204872e6b7034479a6d11502547b
# 2  1d48492cd90930d6612fc70ef18bf8d4  93c44e614219c41696a8148018c1d83b
# 3  a196a8996bb74b7bd6d92f0cc2802620  00e77c29f2ce1986407cb93f53936dff
# 4  282b4e07171c48ac08162e0dc8749066  18fcf47148228c7b56c19726c854054b
#
#                            feed_key    agency_id agency_name  \
# 0  21fa0b125d801eb5058da2ec5d748bda  LAX FlyAway        None
# 1  3d30b02b9008f788eb89c41c137786c1           MT        None
# 2  f87ac9abe81a7548325423ede69c3b86  LAX FlyAway        None
# 3  25915c089571c49be33b59e10c25d2ac  LAX FlyAway        None
# 4  9b8e9b8befe560293a6c5b38dc19ffbb           MT        None
#
# ...

# %%
df1 = tbls.mart_gtfs.dim_agency()

# %%
type(df1)
# Out:
# siuba.sql.backend.LazyTbl

# %%
df1['feed_key']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df1['feed_key']
#
# TypeError: 'LazyTbl' object is not subscriptable

# %%
df2 = pd.DataFrame(df1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_157/1213180909.py in ?()
# ----> 1 df2 = pd.DataFrame(df1)
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py in ?(self, data, index, columns, dtype, copy)
#     777                 )
#     778         # For data is scalar
#     779         else:
#     780             if index is None or columns is None:
# --> 781                 raise ValueError("DataFrame constructor not properly called!")
#     782
#     783             index = ensure_index(index)
#     784             columns = ensure_index(columns)
#
# ValueError: DataFrame constructor not properly called!

# %%
tbls.mart_gtfs.dim_agency() >> collect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 tbls.mart_gtfs.dim_agency() >> collect()
#
# NameError: name 'collect' is not defined

# %%
from siuba import collect

# %%
df2 = tbls.mart_gtfs.dim_agency() >> collect()

# %%
df2['key']
# Out:
# 0        56112d81d62d71d408ea0247309178e4
# 1        033d018b031002914fbfa48c872d4a65
# 2        1d48492cd90930d6612fc70ef18bf8d4
# 3        a196a8996bb74b7bd6d92f0cc2802620
# 4        282b4e07171c48ac08162e0dc8749066
#                        ...
# 64250    4b3a0475f412b43b2193162af67b6d5e
# 64251    8036aa61601f9639e38e5badc9e695e5
# 64252    d68573068cee2b62d39d4ec2984cfe4b
# 64253    d6be150d01ed7bf9ad331b36bac61b30
# 64254    280057e38f45d53dbf28a93696cf4bee
# Name: key, Length: 64255, dtype: object

# %%
df2.head()
# Out:
#                                 key                         _gtfs_key  \
# 0  56112d81d62d71d408ea0247309178e4  090343c89ab8fe1d5e3b79e5687bbcca
# 1  033d018b031002914fbfa48c872d4a65  8f5e204872e6b7034479a6d11502547b
# 2  1d48492cd90930d6612fc70ef18bf8d4  93c44e614219c41696a8148018c1d83b
# 3  a196a8996bb74b7bd6d92f0cc2802620  00e77c29f2ce1986407cb93f53936dff
# 4  282b4e07171c48ac08162e0dc8749066  18fcf47148228c7b56c19726c854054b
#
#                            feed_key    agency_id agency_name  \
# 0  21fa0b125d801eb5058da2ec5d748bda  LAX FlyAway        None
# 1  3d30b02b9008f788eb89c41c137786c1           MT        None
# 2  f87ac9abe81a7548325423ede69c3b86  LAX FlyAway        None
# 3  25915c089571c49be33b59e10c25d2ac  LAX FlyAway        None
# 4  9b8e9b8befe560293a6c5b38dc19ffbb           MT        None
#
#                       agency_url      agency_timezone agency_lang  \
# 0      http://www.LAXFlyAway.org  America/Los_Angeles          en
# ...

# %%
df2.dtypes
# Out:
# key                              object
# _gtfs_key                        object
# feed_key                         object
# agency_id                        object
# agency_name                      object
# agency_url                       object
# agency_timezone                  object
# agency_lang                      object
# agency_phone                     object
# agency_fare_url                  object
# agency_email                     object
# base64_url                       object
# _dt                              object
# _feed_valid_from    datetime64[ns, UTC]
# _line_number                      int64
# feed_timezone                    object
# dtype: object

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df2['key'])
# Out:
# pandas.core.series.Series

# %%
# %%sql
#
# select * from `mart_gtfs.dim_agency`
# Out:
#                                     key                         _gtfs_key  \
# 0      56112d81d62d71d408ea0247309178e4  090343c89ab8fe1d5e3b79e5687bbcca
# 1      033d018b031002914fbfa48c872d4a65  8f5e204872e6b7034479a6d11502547b
# 2      1d48492cd90930d6612fc70ef18bf8d4  93c44e614219c41696a8148018c1d83b
# 3      a196a8996bb74b7bd6d92f0cc2802620  00e77c29f2ce1986407cb93f53936dff
# 4      282b4e07171c48ac08162e0dc8749066  18fcf47148228c7b56c19726c854054b
# ...                                 ...                               ...
# 64250  4b3a0475f412b43b2193162af67b6d5e  53614dfeecf131052270c150f758385d
# 64251  8036aa61601f9639e38e5badc9e695e5  0460c4af1cff0625899b79263efb4de9
# 64252  d68573068cee2b62d39d4ec2984cfe4b  d4658c02796555dd0d7c2eb7e4591a72
# 64253  d6be150d01ed7bf9ad331b36bac61b30  4778fc73f3171660f3e238fee43d2cd3
# 64254  280057e38f45d53dbf28a93696cf4bee  baa4244fdd157a9af14e7d38469252eb
#
#                                feed_key    agency_id agency_name  \
# ...

# %%
tbls.mart_gtfs.dim_agency() >> collect()
# Out:
#                                     key                         _gtfs_key  \
# 0      56112d81d62d71d408ea0247309178e4  090343c89ab8fe1d5e3b79e5687bbcca
# 1      033d018b031002914fbfa48c872d4a65  8f5e204872e6b7034479a6d11502547b
# 2      1d48492cd90930d6612fc70ef18bf8d4  93c44e614219c41696a8148018c1d83b
# 3      a196a8996bb74b7bd6d92f0cc2802620  00e77c29f2ce1986407cb93f53936dff
# 4      282b4e07171c48ac08162e0dc8749066  18fcf47148228c7b56c19726c854054b
# ...                                 ...                               ...
# 64250  4b3a0475f412b43b2193162af67b6d5e  53614dfeecf131052270c150f758385d
# 64251  8036aa61601f9639e38e5badc9e695e5  0460c4af1cff0625899b79263efb4de9
# 64252  d68573068cee2b62d39d4ec2984cfe4b  d4658c02796555dd0d7c2eb7e4591a72
# 64253  d6be150d01ed7bf9ad331b36bac61b30  4778fc73f3171660f3e238fee43d2cd3
# 64254  280057e38f45d53dbf28a93696cf4bee  baa4244fdd157a9af14e7d38469252eb
#
#                                feed_key    agency_id agency_name  \
# ...

# %%
from calitp_data_analysis.sql import query_sql

# %%
df_dim_agency = query_sql("""

select * 
from `mart_gtfs.dim_agency`

""", as_df = True)

# %%
df_dim_agency
# Out:
#                                     key                         _gtfs_key  \
# 0      56112d81d62d71d408ea0247309178e4  090343c89ab8fe1d5e3b79e5687bbcca
# 1      033d018b031002914fbfa48c872d4a65  8f5e204872e6b7034479a6d11502547b
# 2      1d48492cd90930d6612fc70ef18bf8d4  93c44e614219c41696a8148018c1d83b
# 3      a196a8996bb74b7bd6d92f0cc2802620  00e77c29f2ce1986407cb93f53936dff
# 4      282b4e07171c48ac08162e0dc8749066  18fcf47148228c7b56c19726c854054b
# ...                                 ...                               ...
# 64250  4b3a0475f412b43b2193162af67b6d5e  53614dfeecf131052270c150f758385d
# 64251  8036aa61601f9639e38e5badc9e695e5  0460c4af1cff0625899b79263efb4de9
# 64252  d68573068cee2b62d39d4ec2984cfe4b  d4658c02796555dd0d7c2eb7e4591a72
# 64253  d6be150d01ed7bf9ad331b36bac61b30  4778fc73f3171660f3e238fee43d2cd3
# 64254  280057e38f45d53dbf28a93696cf4bee  baa4244fdd157a9af14e7d38469252eb
#
#                                feed_key    agency_id agency_name  \
# ...

# %%
df_dim_agency.groupby('agency_id').size().sort_index()
# Out:
# agency_id
# 0                                        156
# 01                                        18
# 05f0da90-7acf-491d-936c-5ee848a0e941      33
# 1                                       1224
# 100                                       21
#                                         ...
# samtrans-ca-us                            41
# ucb                                        1
# unitrans                                  77
# wasco                                      2
# west-hollywood                             4
# Length: 332, dtype: int64

# %%
df_dim_agency.groupby('agency_id').last('agency_phone')
# Out:
#                                       _line_number
# agency_id
# 0                                                1
# 01                                               1
# 05f0da90-7acf-491d-936c-5ee848a0e941             1
# 1                                                6
# 100                                              1
# ...                                            ...
# samtrans-ca-us                                   1
# ucb                                              1
# unitrans                                         1
# wasco                                            1
# west-hollywood                                   1
#
# [332 rows x 1 columns]

# %%
df_dim_agency.groupby('agency_id').mean()
# Out:
# /tmp/ipykernel_157/861259891.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_dim_agency.groupby('agency_id').mean()
#                                       _line_number
# agency_id
# 0                                         1.000000
# 01                                        1.000000
# 05f0da90-7acf-491d-936c-5ee848a0e941      1.000000
# 1                                         1.240196
# 100                                       1.000000
# ...                                            ...
# samtrans-ca-us                            1.000000
# ucb                                       1.000000
# unitrans                                  1.000000
# wasco                                     1.000000
# west-hollywood                            1.000000
#
# [332 rows x 1 columns]

# %%
mtcars
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# ...

# %%
type(mtcars)
# Out:
# pandas.core.frame.DataFrame

# %%
mtcars.groupby("cyl").mean()[["hp"]]
# Out:
#              hp
# cyl
# 4     82.636364
# 6    122.285714
# 8    209.214286

# %%
mtcars.groupby("cyl").mean()["hp"]
# Out:
# cyl
# 4     82.636364
# 6    122.285714
# 8    209.214286
# Name: hp, dtype: float64

# %%
mtcars['hp']
# Out:
# 0     110
# 1     110
# 2      93
# 3     110
# 4     175
# 5     105
# 6     245
# 7      62
# 8      95
# 9     123
# 10    123
# 11    180
# 12    180
# 13    180
# 14    205
# 15    215
# 16    230
# 17     66
# 18     52
# 19     65
# 20     97
# 21    150
# 22    150
# 23    245
# 24    175
# 25     66
# 26     91
# 27    113
# 28    264
# 29    175
# 30    335
# 31    109
# Name: hp, dtype: int64

# %%
mtcars.hp
# Out:
# 0     110
# 1     110
# 2      93
# 3     110
# 4     175
# 5     105
# 6     245
# 7      62
# 8      95
# 9     123
# 10    123
# 11    180
# 12    180
# 13    180
# 14    205
# 15    215
# 16    230
# 17     66
# 18     52
# 19     65
# 20     97
# 21    150
# 22    150
# 23    245
# 24    175
# 25     66
# 26     91
# 27    113
# 28    264
# 29    175
# 30    335
# 31    109
# Name: hp, dtype: int64

# %%
mtcars.hp.mean()
# Out:
# 146.6875

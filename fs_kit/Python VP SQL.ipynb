# %%
from calitp_data_analysis.sql import query_sql

# %%
df1 = query_sql("""

with cte1 as(
  select distinct gtfs_dataset_key
  from `cal-itp-data-infra.mart_transit_database.dim_gtfs_service_data`
  where customer_facing is true
),
cte2 as(
SELECT 
position_latitude,
position_longitude,
_header_message_age, 
_vehicle_message_age,
_vehicle_message_age_vs_header,
from `cal-itp-data-infra.mart_gtfs.fct_vehicle_positions_messages` vpm
inner join cte1 c1
on vpm.gtfs_dataset_key = c1.gtfs_dataset_key
where 
gtfs_dataset_name not like 'Bay Area 511%'
and trip_id is not null
and dt between '2024-06-11' and '2024-06-12'
and date(datetime(_extract_ts, 'America/Los_Angeles')) = '2024-06-12'
and time(datetime(_extract_ts, 'America/Los_Angeles')) between '00:00:00' and '00:30:00'

),

cte3 as(
select distinct
position_latitude,
position_longitude,
_header_message_age, 
_vehicle_message_age,
_vehicle_message_age_vs_header
from cte2
where position_latitude != 0
and position_longitude != 0
and position_latitude is not null
and position_longitude is not null
),
cte4 as(
select *,
  PERCENTILE_CONT(_vehicle_message_age, .5) OVER(PARTITION BY cast(position_latitude as string), cast(position_longitude as string)) AS median_vehicle_message_age
from cte3
)

select distinct position_latitude, position_longitude, median_vehicle_message_age
from cte4
where median_vehicle_message_age is not null
and median_vehicle_message_age > 0 
order by median_vehicle_message_age

""", as_df = True)
# Out:
# ---------------------------------------------------------------------------
# InternalServerError                       Traceback (most recent call last)
# File /opt/conda/lib/python3.9/site-packages/google/cloud/bigquery/dbapi/cursor.py:213, in Cursor._execute(self, formatted_operation, parameters, job_id, job_config, parameter_types)
#     212 try:
# --> 213     self._query_job.result()
#     214 except google.cloud.exceptions.GoogleCloudError as exc:
#
# File /opt/conda/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py:1520, in QueryJob.result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1518         do_get_result = job_retry(do_get_result)
# -> 1520     do_get_result()
#    1522 except exceptions.GoogleAPICallError as exc:
#
# File /opt/conda/lib/python3.9/site-packages/google/api_core/retry.py:349, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     346 sleep_generator = exponential_sleep_generator(
# ...

# %%
from calitp_data_analysis.tables import tbls

# %%
import calitp_data_analysis.magics

# %%
# %%sql
#
# with cte1 as(
#   select distinct gtfs_dataset_key
#   from `cal-itp-data-infra.mart_transit_database.dim_gtfs_service_data`
#   where customer_facing is true
# ),
# cte2 as(
# SELECT
# position_latitude,
# position_longitude,
# _header_message_age,
# _vehicle_message_age,
# _vehicle_message_age_vs_header,
# from `cal-itp-data-infra.mart_gtfs.fct_vehicle_positions_messages` vpm
# inner join cte1 c1
# on vpm.gtfs_dataset_key = c1.gtfs_dataset_key
# where
# gtfs_dataset_name not like 'Bay Area 511%'
# and trip_id is not null
# and dt between '2024-06-11' and '2024-06-12'
# and date(datetime(_extract_ts, 'America/Los_Angeles')) = '2024-06-12'
# and time(datetime(_extract_ts, 'America/Los_Angeles')) between '00:00:00' and '00:30:00'
#
# ),
#
# cte3 as(
# select distinct
# position_latitude,
# position_longitude,
# _header_message_age,
# _vehicle_message_age,
# _vehicle_message_age_vs_header
# from cte2
# where position_latitude != 0
# and position_longitude != 0
# and position_latitude is not null
# and position_longitude is not null
# ),
# cte4 as(
# select *,
#   PERCENTILE_CONT(_vehicle_message_age, .5) OVER(PARTITION BY cast(position_latitude as string), cast(position_longitude as string)) AS median_vehicle_message_age
# from cte3
# )
#
# select distinct position_latitude, position_longitude, median_vehicle_message_age
# from cte4
# where median_vehicle_message_age is not null
# and median_vehicle_message_age > 0
# order by median_vehicle_message_age
# Out:
# ---------------------------------------------------------------------------
# InternalServerError                       Traceback (most recent call last)
# File /opt/conda/lib/python3.9/site-packages/google/cloud/bigquery/dbapi/cursor.py:213, in Cursor._execute(self, formatted_operation, parameters, job_id, job_config, parameter_types)
#     212 try:
# --> 213     self._query_job.result()
#     214 except google.cloud.exceptions.GoogleCloudError as exc:
#
# File /opt/conda/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py:1520, in QueryJob.result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1518         do_get_result = job_retry(do_get_result)
# -> 1520     do_get_result()
#    1522 except exceptions.GoogleAPICallError as exc:
#
# File /opt/conda/lib/python3.9/site-packages/google/api_core/retry.py:349, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     346 sleep_generator = exponential_sleep_generator(
# ...

# %%
pip install --upgrade gtfs-realtime-bindings
# Out:
# Collecting gtfs-realtime-bindings
#   Using cached gtfs_realtime_bindings-1.0.0-py3-none-any.whl
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.9/site-packages (from gtfs-realtime-bindings) (4.23.4)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.9/site-packages (from gtfs-realtime-bindings) (68.0.0)
# Installing collected packages: gtfs-realtime-bindings
# Successfully installed gtfs-realtime-bindings-1.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from google.transit import gtfs_realtime_pb2
import requests
import datetime

# %%
ts_epoch = 1718312918
datetime.datetime.fromtimestamp(ts_epoch).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2024-06-13 21:08:38'

# %%
feed = gtfs_realtime_pb2.FeedMessage()
response = requests.get('https://infopoint.sunline.org/InfoPoint/GTFS-Realtime.ashx?Type=VehiclePosition')
feed.ParseFromString(response.content)
# for entity in feed.entity:
#    print(entity.vehicle)
feed
# Out:
# header {
#   gtfs_realtime_version: "2.0"
#   incrementality: FULL_DATASET
#   timestamp: 1718312918
# }
# entity {
#   id: "559"
#   vehicle {
#     trip {
#       trip_id: "t578-b40-sl2"
#       route_id: "6"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "559"
#       label: "FC9"
#     }
#     position {
#       latitude: 33.6855965
#       longitude: -116.198601
#       bearing: 270
#       speed: 0
#     }
#     current_stop_sequence: 422
#     stop_id: "453"
#     current_status: INCOMING_AT
#     timestamp: 1718312905
#     congestion_level: UNKNOWN_CONGESTION_LEVEL
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "575"
#   vehicle {
#     trip {
#       trip_id: "t523-b13-sl2"
#       route_id: "1"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "575"
#       label: "575"
#     }
#     position {
#       latitude: 33.8173981
#       longitude: -116.545509
#       bearing: 0
#       speed: 9.83488
#     }
#     current_stop_sequence: 3264
#     stop_id: "245"
#     current_status: INCOMING_AT
#     timestamp: 1718312894
#     congestion_level: UNKNOWN_CONGESTION_LEVEL
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "576"
#   vehicle {
#     trip {
#       trip_id: "t537-b47-sl2"
#       route_id: "7"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "576"
#       label: "576"
#     }
#     position {
#       latitude: 33.6659317
#       longitude: -116.308113
#       bearing: 180
#       speed: 11.6230402
#     }
#     current_stop_sequence: 2124
#     stop_id: "284"
#     current_status: INCOMING_AT
#     timestamp: 1718312884
#     congestion_level: UNKNOWN_CONGESTION_LEVEL
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "578"
#   vehicle {
#     trip {
#       trip_id: "t541-bB-sl2"
#       route_id: "1"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "578"
#       label: "578"
#     }
#     position {
#       latitude: 33.7790642
#       longitude: -116.464607
#       bearing: 0
#       speed: 8.9408
#     }
#     current_stop_sequence: 1518
#     stop_id: "19"
#     current_status: IN_TRANSIT_TO
#     timestamp: 1718312903
#     congestion_level: UNKNOWN_CONGESTION_LEVEL
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "584"
#   vehicle {
#     trip {
#       trip_id: "t582-b2A-sl2"
#       route_id: "4"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "584"
#       label: "584"
#     }
#     position {
#       latitude: 33.724659
#       longitude: -116.398186
#       bearing: 0
#       speed: 0
#     }
#     current_stop_sequence: 0
#     stop_id: "65"
#     current_status: STOPPED_AT
#     timestamp: 1718312908
#     congestion_level: UNKNOWN_CONGESTION_LEVEL
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "586"
#   vehicle {
#     trip {
#       trip_id: "t57D-b6E-sl2"
#       route_id: "11"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "586"
#       label: "586"
#     }
#     position {
#       latitude: 33.7282372
#       longitude: -116.391312
#       bearing: 180
#       speed: 0
#     }
#     current_stop_sequence: 180
#     stop_id: "62"
#     current_status: INCOMING_AT
#     timestamp: 1718312884
#     congestion_level: UNKNOWN_CONGESTION_LEVEL
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "588"
#   vehicle {
#     trip {
#       trip_id: "t587-b17-sl2"
#       route_id: "2"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "588"
#       label: "588"
#     }
#     position {
#       latitude: 33.7782707
#       longitude: -116.464203
#       bearing: 272
#       speed: 0
#     }
#     current_stop_sequence: 0
#     stop_id: "147"
#     current_status: STOPPED_AT
#     timestamp: 1718312893
#     congestion_level: UNKNOWN_CONGESTION_LEVEL
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "601"
#   vehicle {
#     trip {
#       trip_id: "t546-b20-sl2"
#       route_id: "3"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "601"
#       label: "601"
#     }
#     position {
#       latitude: 33.9539
#       longitude: -116.510071
#       bearing: 358
#       speed: 7.15264
#     }
#     current_stop_sequence: 1634
#     stop_id: "136"
#     current_status: INCOMING_AT
#     timestamp: 1718312893
#     congestion_level: UNKNOWN_CONGESTION_LEVEL
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "603"
#   vehicle {
#     trip {
#       trip_id: "t578-b5D-sl2"
#       route_id: "9"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "603"
#       label: "603"
#     }
#     position {
#       latitude: 33.5692062
#       longitude: -116.123543
#       bearing: 268
#       speed: 22.352
#     }
#     current_stop_sequence: 461
#     stop_id: "382"
#     current_status: INCOMING_AT
#     timestamp: 1718312891
#     congestion_level: UNKNOWN_CONGESTION_LEVEL
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "606"
#   vehicle {
#     trip {
#       trip_id: "t578-b5E-sl2"
#       route_id: "9"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "606"
#       label: "606"
#     }
#     position {
#       latitude: 33.5400887
#       longitude: -115.99115
#       bearing: 88
#       speed: 23.2460804
#     }
#     current_stop_sequence: 747
#     stop_id: "477"
#     current_status: IN_TRANSIT_TO
#     timestamp: 1718312887
#     congestion_level: UNKNOWN_CONGESTION_LEVEL
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "607"
#   vehicle {
#     trip {
#       trip_id: "t532-b52-sl2"
#       route_id: "8"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "607"
#       label: "607"
#     }
#     position {
#       latitude: 33.6803513
#       longitude: -116.175911
#       bearing: 0
#       speed: 0
#     }
#     current_stop_sequence: 2280
#     stop_id: "678"
#     current_status: INCOMING_AT
#     timestamp: 1718312886
#     congestion_level: UNKNOWN_CONGESTION_LEVEL
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "610"
#   vehicle {
#     trip {
#       trip_id: "t51E-b2C-sl2"
#       route_id: "4"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "610"
#       label: "610"
#     }
#     position {
#       latitude: 33.8161392
#       longitude: -116.422356
#       bearing: 88
#       speed: 26.3753605
#     }
#     current_stop_sequence: 3778
#     stop_id: "945"
#     current_status: IN_TRANSIT_TO
#     timestamp: 1718312886
#     congestion_level: UNKNOWN_CONGESTION_LEVEL
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "612"
#   vehicle {
#     trip {
#       trip_id: "t4DD-b18-sl2"
#       route_id: "2"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "612"
#       label: "612"
#     }
#     position {
#       latitude: 33.9474449
#       longitude: -116.501205
#       bearing: 0
#       speed: 0
#     }
#     current_stop_sequence: 4760
#     stop_id: "1"
#     current_status: INCOMING_AT
#     timestamp: 1718312898
#     congestion_level: UNKNOWN_CONGESTION_LEVEL
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "614"
#   vehicle {
#     trip {
#       trip_id: "t541-b15-sl2"
#       route_id: "2"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "614"
#       label: "614"
#     }
#     position {
#       latitude: 33.8160362
#       longitude: -116.466408
#       bearing: 266
#       speed: 0
#     }
#     current_stop_sequence: 748
#     stop_id: "595"
#     current_status: INCOMING_AT
#     timestamp: 1718312909
#     congestion_level: UNKNOWN_CONGESTION_LEVEL
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "617"
#   vehicle {
#     trip {
#       trip_id: "t578-b1F-sl2"
#       route_id: "3"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "617"
#       label: "617"
#     }
#     position {
#       latitude: 33.9524803
#       longitude: -116.466614
#       bearing: 118
#       speed: 18.32864
#     }
#     current_stop_sequence: 592
#     stop_id: "454"
#     current_status: INCOMING_AT
#     timestamp: 1718312892
#     congestion_level: UNKNOWN_CONGESTION_LEVEL
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "619"
#   vehicle {
#     trip {
#       trip_id: "t519-bE-sl2"
#       route_id: "11"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "619"
#       label: "619"
#     }
#     position {
#       latitude: 33.6807785
#       longitude: -116.176811
#       bearing: 54
#       speed: 4.91744
#     }
#     current_stop_sequence: 0
#     stop_id: "678"
#     current_status: STOPPED_AT
#     timestamp: 1718312885
#     congestion_level: UNKNOWN_CONGESTION_LEVEL
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "621"
#   vehicle {
#     trip {
#       trip_id: "t532-b48-sl2"
#       route_id: "7"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "621"
#       label: "621"
#     }
#     position {
#       latitude: 33.7239685
#       longitude: -116.300224
#       bearing: 314
#       speed: 14.7523203
#     }
#     current_stop_sequence: 1860
#     stop_id: "872"
#     current_status: IN_TRANSIT_TO
#     timestamp: 1718312882
#     congestion_level: UNKNOWN_CONGESTION_LEVEL
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "622"
#   vehicle {
#     trip {
#       trip_id: "t514-bD-sl2"
#       route_id: "1"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "622"
#       label: "622"
#     }
#     position {
#       latitude: 33.7244759
#       longitude: -116.398201
#       bearing: 0
#       speed: 0
#     }
#     current_stop_sequence: 0
#     stop_id: "65"
#     current_status: STOPPED_AT
#     timestamp: 1718312904
#     congestion_level: UNKNOWN_CONGESTION_LEVEL
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "624"
#   vehicle {
#     trip {
#       trip_id: "t578-b16-sl2"
#       route_id: "2"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "624"
#       label: "624"
#     }
#     position {
#       latitude: 33.9504547
#       longitude: -116.501526
#       bearing: 0
#       speed: 0
#     }
#     current_stop_sequence: 218
#     stop_id: "6"
#     current_status: INCOMING_AT
#     timestamp: 1718312886
#     congestion_level: UNKNOWN_CONGESTION_LEVEL
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "626"
#   vehicle {
#     trip {
#       trip_id: "t523-b1A-sl2"
#       route_id: "2"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "626"
#       label: "626"
#     }
#     position {
#       latitude: 0
#       longitude: 0
#       bearing: 0
#       speed: 0
#     }
#     timestamp: 1718312900
#     congestion_level: UNKNOWN_CONGESTION_LEVEL
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "630"
#   vehicle {
#     trip {
#       trip_id: "t578-bC-sl2"
#       route_id: "11"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "630"
#       label: "630"
#     }
#     position {
#       latitude: 33.6886902
#       longitude: -116.181778
#       bearing: 342
#       speed: 10.72896
#     }
#     current_stop_sequence: 660
#     stop_id: "843"
#     current_status: IN_TRANSIT_TO
#     timestamp: 1718312909
#     congestion_level: UNKNOWN_CONGESTION_LEVEL
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "631"
#   vehicle {
#     trip {
#       trip_id: "t532-b1B-sl2"
#       route_id: "2"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "631"
#       label: "631"
#     }
#     position {
#       latitude: 33.8157539
#       longitude: -116.545891
#       bearing: 90
#       speed: 0
#     }
#     current_stop_sequence: 2580
#     stop_id: "129"
#     current_status: STOPPED_AT
#     timestamp: 1718312898
#     congestion_level: UNKNOWN_CONGESTION_LEVEL
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "632"
#   vehicle {
#     trip {
#       trip_id: "t514-b19-sl2"
#       route_id: "2"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "632"
#       label: "632"
#     }
#     position {
#       latitude: 33.8158264
#       longitude: -116.464371
#       bearing: 90
#       speed: 9.83488
#     }
#     current_stop_sequence: 4320
#     stop_id: "517"
#     current_status: IN_TRANSIT_TO
#     timestamp: 1718312863
#     congestion_level: UNKNOWN_CONGESTION_LEVEL
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "634"
#   vehicle {
#     trip {
#       trip_id: "t546-b53-sl2"
#       route_id: "8"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "634"
#       label: "634"
#     }
#     position {
#       latitude: 33.6596
#       longitude: -116.181671
#       bearing: 0
#       speed: 18.7756805
#     }
#     current_stop_sequence: 1618
#     stop_id: "961"
#     current_status: STOPPED_AT
#     timestamp: 1718312880
#     congestion_level: UNKNOWN_CONGESTION_LEVEL
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "635"
#   vehicle {
#     trip {
#       trip_id: "t532-bF-sl2"
#       route_id: "1"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "635"
#       label: "635"
#     }
#     position {
#       latitude: 33.7782402
#       longitude: -116.463867
#       bearing: 274
#       speed: 0
#     }
#     current_stop_sequence: 2280
#     stop_id: "147"
#     current_status: STOPPED_AT
#     timestamp: 1718312913
#     congestion_level: UNKNOWN_CONGESTION_LEVEL
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "712"
#   vehicle {
#     trip {
#       trip_id: "t582-b35-sl2"
#       route_id: "5"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "712"
#       label: "712"
#     }
#     position {
#       latitude: 33.72575
#       longitude: -116.398468
#       bearing: 0
#       speed: 0
#     }
#     current_stop_sequence: 0
#     stop_id: "67"
#     current_status: STOPPED_AT
#     timestamp: 1718312893
#     congestion_level: UNKNOWN_CONGESTION_LEVEL
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "927"
#   vehicle {
#     vehicle {
#       id: "927"
#       label: "FC27"
#     }
#     position {
#       latitude: 33.8200684
#       longitude: -116.510529
#       bearing: 358
#       speed: 0
#     }
#     timestamp: 1718312888
#     congestion_level: UNKNOWN_CONGESTION_LEVEL
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "929"
#   vehicle {
#     trip {
#       trip_id: "t514-b70-sl2"
#       route_id: "11"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "929"
#       label: "FC29"
#     }
#     position {
#       latitude: 33.7243462
#       longitude: -116.398193
#       bearing: 4
#       speed: 0
#     }
#     current_stop_sequence: 0
#     stop_id: "65"
#     current_status: INCOMING_AT
#     timestamp: 1718312904
#     congestion_level: UNKNOWN_CONGESTION_LEVEL
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "1007"
#   vehicle {
#     trip {
#       trip_id: "t4E2-b67-sl2"
#       route_id: "10"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "1007"
#       label: "2007"
#     }
#     position {
#       latitude: 33.9267578
#       longitude: -116.946861
#       bearing: 354
#       speed: 0
#     }
#     current_stop_sequence: 6900
#     stop_id: "920"
#     current_status: IN_TRANSIT_TO
#     timestamp: 1718312905
#     congestion_level: UNKNOWN_CONGESTION_LEVEL
#     occupancy_status: EMPTY
#   }
# }

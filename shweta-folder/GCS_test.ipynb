# %%
GCS_FILE_PATH  = 'gs://calitp-analytics-data/data-analyses/shweta_folder'

# %%
from calitp_data_analysis.tables import tbls
# Out:
# /opt/conda/lib/python3.9/site-packages/google/auth/_default.py:78: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
import pandas as pd

# %%
from calitp_data_analysis.sql import to_snakecase

# %%
from siuba import *

# %%
df = (tbls.mart_transit_database.dim_organizations()>>filter(_._is_current== True, _.organization_type == ("Company"))>>collect())

# %%
df
# Out:
#                                   key   source_record_id  \
# 0    3769538de955e0b01204e955ef6929f9  recmCZYY7aXn5MS9b
# 1    8a644e497439d25c01619c8ec6c85c44  recEN9M5vpVOk2JRI
# 2    fa22729bf0698cc6d2ac4f4a41e861b0  recIAaOHjseoeNpTx
# 3    3fd4d81306c49cb718c37b48fcbe585c  recveQ8PTsiKdT7RU
# 4    825e38e861054960083797eccfabf976  recqNWhsEzv1aN2hr
# ..                                ...                ...
# 251  f3d0107e92a5ec5128e28841085cc267  reczdQfpujA5mctN4
# 252  e106b4bd533c26eca51b570584e59edb  recrPELUN7XjdWJDh
# 253  6d98290cb076b5258dc87fd544eb96c0  recXwWoQB6RDKyDBE
# 254  a8550c0239334818f80a4052c5d32f54  recXgg8Je7BhRTXnX
# 255  f79e6c6d2247ad16dcd34868ccd33b6c  reczFByCgzevHZ5ct
#
#                                                   name organization_type  \
# 0                                                  IBI           Company
# 1                                                  SAP           Company
# ...

# %%
df.to_csv(f"{GCS_FILE_PATH}/GCS_testexport.csv")
# Out:
# /opt/conda/lib/python3.9/site-packages/google/auth/_default.py:78: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df.to_csv(f"{GCS_FILE_PATH}/GCS_testexport.csv")
#
# File /opt/conda/lib/python3.9/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# ## Attempt to read file from GCS

# %%
df2 = pd.read_parquet("gs://calitp-analytics-data/data-analyses/shared_data/ca_county_centroids.parquet")

# %%
df2.head()
# Out:
#   county_name          centroid  zoom
# 0     Alameda  [37.65, -121.92]    11
# 1      Alpine   [38.6, -119.82]    11
# 2      Amador  [38.45, -120.65]    11
# 3       Butte   [39.67, -121.6]    11
# 4   Calaveras  [38.21, -120.55]    11

# %%
df2.sample(5)
# Out:
#    county_name          centroid  zoom
# 55     Ventura  [34.47, -119.08]    11
# 13        Inyo  [36.51, -117.41]    11
# 11    Humboldt   [40.7, -123.88]    11
# 0      Alameda  [37.65, -121.92]    11
# 10       Glenn   [39.6, -122.39]    11

# %% [markdown]
# # Highways with No Parallel Transit Routes to SHN
#
# These highway corridors have a dearth of bus transit service. These highway corridors may have the presence of transit routes, but none of the routes fit the definition of **[parallel](https://analysis.calitp.org/parallel_corridors/README.html)**.
#
# Highway corridors with zero parallel transit routes are sorted in descending order by number of bus routes and length of highway corridor.
#
# The top 25 are selected and plotted by district. Not every district would have highway corridors. These corridors represent opportunities for investment in **creating parallel routes** where none currently exist, though there are transit routes nearby.

# %%
# %%capture
import warnings
warnings.filterwarnings('ignore')

import geopandas as gpd
import intake
import pandas as pd

from IPython.display import Markdown, HTML

import setup_corridors_stats
import parallel_corridors_utils
from shared_utils import geography_utils 

catalog = intake.open_catalog("./*.yml")

# %%
operator_stats, hwy_stats = setup_corridors_stats.aggregated_transit_hwy_stats()
gdf = setup_corridors_stats.process_hwy_stats(hwy_stats).to_crs(geography_utils.WGS84)

# %%
zero_parallel = (gdf[gdf.pct_parallel==0]
                 .sort_values(["count_route_id", "highway_length_routetype"], 
                              ascending = [False, False])
                )

def unique_districts(df, x):
    return df.head(x).District.nunique()

# %%
TOP_CUTOFF = 25
zero_parallel2 = (zero_parallel
                 .head(TOP_CUTOFF)
                ).reset_index(drop=True)

display(
    Markdown(
        "Note: "
        f"The top {TOP_CUTOFF} are chosen because provided the most district coverage "
        "without recommending far too many highway corridors per district."
        f"<br>Top 20: {unique_districts(zero_parallel, 20)} districts"
        f"<br>Top 25: {unique_districts(zero_parallel, 25)} districts"
        f"<br>Top 30: {unique_districts(zero_parallel, 30)} districts"
        f"<br>Top 35: {unique_districts(zero_parallel, 35)} districts"
    )
)
# Out:
# Note: The top 25 are chosen because provided the most district coverage without recommending far too many highway corridors per district.<br>Top 20: 9 districts<br>Top 25: 11 districts<br>Top 30: 11 districts<br>Top 35: 12 districts

# %% [markdown]
# <a id="top"></a>

# %% [markdown]
# #### [District Maps](#district-maps)
# * [District 1](#district-1)
# * [District 2](#district-2)
# * [District 3](#district-3)
# * [District 4](#district-4)
# * [District 5](#district-5)
# * [District 6](#district-6)
# * [District 7](#district-7)
# * [District 8](#district-8)
# * [District 9](#district-9)
# * [District 10](#district-10)
# * [District 11](#district-11)
# * [District 12](#district-12)

# %%
plot_df = zero_parallel2.copy()
districts = sorted(list(gdf.District.unique()))

def sentence_no_corridors(district):
    sentence = (
        f"District {district} does not contain any of the "
        f"top {TOP_CUTOFF} highway corridors with no "
        "parallel bus routes to the SHN."
    )
    return sentence

def district_output(gdf, district):
    district_df = gdf[gdf.District==district]
    if len(district_df) > 0:
        # Show a table of stats for entire district
        # Not working in utils, is working in notebook
        table = parallel_corridors_utils.district_stats(district_df, district)
        display(HTML(table.to_html()))
        
        parallel_corridors_utils.show_district_analysis(district_df, district)
    else:
        print(sentence_no_corridors(district))

# %% [markdown]
# ## District Maps

# %%
for i in districts:
    # Set the HTML id_anchor
    id_anchor = f"district-{i}"
    display(HTML(f"<a id={id_anchor}></a>"))
    display(Markdown(f"### District {i}"))
    
    district_output(plot_df, i)
    
    display(HTML(
        "<br>"
        "<a href=#top>Return to top</a><br>"
    ))
# Out:
# <a id=district-1></a>
# ### District 1
# <style type="text/css">
# #T_01108 th {
#   text-align: center;
# }
# #T_01108_row0_col0, #T_01108_row0_col1, #T_01108_row0_col2, #T_01108_row0_col3, #T_01108_row0_col4, #T_01108_row1_col0, #T_01108_row1_col1, #T_01108_row1_col2, #T_01108_row1_col3, #T_01108_row1_col4 {
#   text-align: center;
# }
# </style>
# <table id="T_01108">
#   <thead>
#     <tr>
#       <th id="T_01108_level0_col0" class="col_heading level0 col0" >Hwy Route</th>
#       <th id="T_01108_level0_col1" class="col_heading level0 col1" >County</th>
#       <th id="T_01108_level0_col2" class="col_heading level0 col2" >Route Type</th>
#       <th id="T_01108_level0_col3" class="col_heading level0 col3" ># transit routes</th>
#       <th id="T_01108_level0_col4" class="col_heading level0 col4" >Hwy Length (mi)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_01108_row0_col0" class="data row0 col0" >200</td>
#       <td id="T_01108_row0_col1" class="data row0 col1" >HUM</td>
#       <td id="T_01108_row0_col2" class="data row0 col2" >State</td>
#       <td id="T_01108_row0_col3" class="data row0 col3" >17</td>
#       <td id="T_01108_row0_col4" class="data row0 col4" >2.66</td>
#     </tr>
#     <tr>
#       <td id="T_01108_row1_col0" class="data row1 col0" >36</td>
#       <td id="T_01108_row1_col1" class="data row1 col1" >HUM</td>
#       <td id="T_01108_row1_col2" class="data row1 col2" >State</td>
#       <td id="T_01108_row1_col3" class="data row1 col3" >9</td>
#       <td id="T_01108_row1_col4" class="data row1 col4" >45.89</td>
#     </tr>
#   </tbody>
# </table>
#     <iframe srcdoc="<!DOCTYPE html>
# <head>
#     <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#
#         <script>
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         </script>
#
#     <style>html, body {width: 100%;height: 100%;margin: 0;padding: 0;}</style>
#     <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>
#     <script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;></script>
#     <script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;></script>
#     <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;></script>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/>
#
#             <meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; />
#             <style>
#                 #map_e9e7046f94564eb895313b23231bc65c {
#                     position: relative;
#                     width: 300.0px;
#                     height: 320.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             </style>
#
#
#                     <style>
#                         .foliumtooltip {
#
#             background-color: &quot;gray&quot;;
#             border: 0px #FFFFFF;
#             border-radius: 0px;
#             box-shadow: 0px;
#             font-size: 12px;
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     </style>
#
#
#                     <style>
#                         .foliumpopup {
#                             background-color: light_gray;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     </style>
#
# </head>
# <body>
#
#              <h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;><b>State Hwy 200</b></h3>
#
#
#             <div class=&quot;folium-map&quot; id=&quot;map_e9e7046f94564eb895313b23231bc65c&quot; ></div>
#
# </body>
# <script>
#
#             var map_e9e7046f94564eb895313b23231bc65c = L.map(
#                 &quot;map_e9e7046f94564eb895313b23231bc65c&quot;,
#                 {
#                     center: [40.91624017729721, -124.07875049140877],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_451e9cbc06474f07b8424d46bbb51cf6 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e9e7046f94564eb895313b23231bc65c);
#
#
#         function geo_json_9bbbaed0d3174374915eeff6dc3fea13_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#FFFFFF&quot;, &quot;fillColor&quot;: &quot;#5b559cff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 0.2};
#             }
#         }
#
#         function geo_json_9bbbaed0d3174374915eeff6dc3fea13_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_9bbbaed0d3174374915eeff6dc3fea13 = L.geoJson(null, {
#                 onEachFeature: geo_json_9bbbaed0d3174374915eeff6dc3fea13_onEachFeature,
#
#                 style: geo_json_9bbbaed0d3174374915eeff6dc3fea13_styler,
#         });
#
#         function geo_json_9bbbaed0d3174374915eeff6dc3fea13_add (data) {
#             geo_json_9bbbaed0d3174374915eeff6dc3fea13
#                 .addData(data)
#                 .addTo(map_e9e7046f94564eb895313b23231bc65c);
#         }
#             geo_json_9bbbaed0d3174374915eeff6dc3fea13_add({&quot;bbox&quot;: [-124.10072327935764, 40.908886213977375, -124.05648625304619, 40.92396858975315], &quot;features&quot;: [{&quot;bbox&quot;: [-124.10072327935764, 40.908886213977375, -124.05648625304619, 40.92396858975315], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-124.10020878077823, 40.920788843404075], [-124.10021199791164, 40.92079597108421], [-124.10021987821233, 40.92081383154422], [-124.10022296531952, 40.92082099223216], [-124.10052754945723, 40.921544345263555], [-124.10053225849069, 40.9215559742228], [-124.10054360244321, 40.92158514253045], [-124.10054796857163, 40.921596848217355], [-124.10059556110193, 40.921730096747375], [-124.10060049549405, 40.921744709141215], [-124.10061216358429, 40.921781362449984], [-124.10061656366418, 40.92179607270316], [-124.10064342316907, 40.9218919937425], [-124.10066912188961, 40.921969083624575], [-124.10067726027184, 40.92199643522572], [-124.10069527762593, 40.92206516542782], [-124.10070594915948, 40.92212063856502], [-124.10071457541197, 40.922190408147735], [-124.10071708037839, 40.92221838323752], [-124.10072184019234, 40.922304045188866], [-124.10072231848427, 40.92231552149074], [-124.10072311617974, 40.92234421860976], [-124.10072327604405, 40.92235570000311], [-124.10072327935764, 40.92241756500311], [-124.10072238510097, 40.92244478760779], [-124.1007179129509, 40.922512759453596], [-124.10071076349526, 40.92256693385496], [-124.10069738424731, 40.92263422939895], [-124.1006911468384, 40.922661046304555], [-124.100672990456, 40.922729131782305], [-124.1006722027116, 40.92273209007246], [-124.10066483476179, 40.92275679136198], [-124.10064453615774, 40.92281818722495], [-124.10062531042065, 40.922866679558915], [-124.10059759643164, 40.922926383984006], [-124.10057252753037, 40.922973315862315], [-124.10053763674728, 40.92303081478656], [-124.10050694050565, 40.92307578211875], [-124.10046517331621, 40.92313058046711], [-124.10044779569033, 40.923152205680644], [-124.10039544634047, 40.92321407313141], [-124.10037548630719, 40.923
# <br><a href=#top>Return to top</a><br>
# <a id=district-2></a>
# ### District 2
# <style type="text/css">
# #T_ea4ff th {
#   text-align: center;
# }
# #T_ea4ff_row0_col0, #T_ea4ff_row0_col1, #T_ea4ff_row0_col2, #T_ea4ff_row0_col3, #T_ea4ff_row0_col4 {
#   text-align: center;
# }
# </style>
# <table id="T_ea4ff">
#   <thead>
#     <tr>
#       <th id="T_ea4ff_level0_col0" class="col_heading level0 col0" >Hwy Route</th>
#       <th id="T_ea4ff_level0_col1" class="col_heading level0 col1" >County</th>
#       <th id="T_ea4ff_level0_col2" class="col_heading level0 col2" >Route Type</th>
#       <th id="T_ea4ff_level0_col3" class="col_heading level0 col3" ># transit routes</th>
#       <th id="T_ea4ff_level0_col4" class="col_heading level0 col4" >Hwy Length (mi)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ea4ff_row0_col0" class="data row0 col0" >395</td>
#       <td id="T_ea4ff_row0_col1" class="data row0 col1" >MOD</td>
#       <td id="T_ea4ff_row0_col2" class="data row0 col2" >US</td>
#       <td id="T_ea4ff_row0_col3" class="data row0 col3" >9</td>
#       <td id="T_ea4ff_row0_col4" class="data row0 col4" >61.29</td>
#     </tr>
#   </tbody>
# </table>
#     <iframe srcdoc="<!DOCTYPE html>
# <head>
#     <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#
#         <script>
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         </script>
#
#     <style>html, body {width: 100%;height: 100%;margin: 0;padding: 0;}</style>
#     <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>
#     <script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;></script>
#     <script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;></script>
#     <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;></script>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/>
#
#             <meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; />
#             <style>
#                 #map_cb4b99b1002447fc8b7e44bcad101184 {
#                     position: relative;
#                     width: 300.0px;
#                     height: 320.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             </style>
#
#
#                     <style>
#                         .foliumtooltip {
#
#             background-color: &quot;gray&quot;;
#             border: 0px #FFFFFF;
#             border-radius: 0px;
#             box-shadow: 0px;
#             font-size: 12px;
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     </style>
#
#
#                     <style>
#                         .foliumpopup {
#                             background-color: light_gray;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     </style>
#
# </head>
# <body>
#
#              <h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;><b>US Hwy 395</b></h3>
#
#
#             <div class=&quot;folium-map&quot; id=&quot;map_cb4b99b1002447fc8b7e44bcad101184&quot; ></div>
#
# </body>
# <script>
#
#             var map_cb4b99b1002447fc8b7e44bcad101184 = L.map(
#                 &quot;map_cb4b99b1002447fc8b7e44bcad101184&quot;,
#                 {
#                     center: [41.58812369232783, -120.43748698666032],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3b1959d6f1654c02a2f6d27991f6c19c = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cb4b99b1002447fc8b7e44bcad101184);
#
#
#         function geo_json_bc707568ce73412782ada220ccd32abd_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#FFFFFF&quot;, &quot;fillColor&quot;: &quot;#5b559cff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 0.2};
#             }
#         }
#
#         function geo_json_bc707568ce73412782ada220ccd32abd_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_bc707568ce73412782ada220ccd32abd = L.geoJson(null, {
#                 onEachFeature: geo_json_bc707568ce73412782ada220ccd32abd_onEachFeature,
#
#                 style: geo_json_bc707568ce73412782ada220ccd32abd_styler,
#         });
#
#         function geo_json_bc707568ce73412782ada220ccd32abd_add (data) {
#             geo_json_bc707568ce73412782ada220ccd32abd
#                 .addData(data)
#                 .addTo(map_cb4b99b1002447fc8b7e44bcad101184);
#         }
#             geo_json_bc707568ce73412782ada220ccd32abd_add({&quot;bbox&quot;: [-120.55191634648645, 41.18290791250604, -120.29643149499373, 41.9942277220555], &quot;features&quot;: [{&quot;bbox&quot;: [-120.55191634648645, 41.18290791250604, -120.29643149499373, 41.9942277220555], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-120.54374187298427, 41.397257990481414], [-120.54377840865789, 41.39749817871328], [-120.543779307361, 41.397504402756475], [-120.54378143538541, 41.39751997205444], [-120.54378223910247, 41.397526203453985], [-120.5439139776018, 41.39861237696709], [-120.54401814485385, 41.399312928618144], [-120.54401877384409, 41.39931731947001], [-120.54402028724307, 41.39932830121518], [-120.544020868972, 41.39933269575943], [-120.54420149702757, 41.40075555711602], [-120.5456317526917, 41.41144026748376], [-120.54580518672185, 41.41265312763888], [-120.5458054641136, 41.41265510121494], [-120.54580614566039, 41.41266003608833], [-120.54580641350607, 41.41266201041101], [-120.54621268318354, 41.41571144933545], [-120.54636381057114, 41.41684579742438], [-120.54647607326257, 41.4176215869053], [-120.54647634706346, 41.4176235106878], [-120.5464770202251, 41.41762832104292], [-120.54647728495353, 41.41763024554453], [-120.5502018721559, 41.44517321020522], [-120.55157396209412, 41.455414927223664], [-120.55185064283607, 41.45740573626559], [-120.5518519524956, 41.45741611891556], [-120.55185489626905, 41.45744209672662], [-120.55185594162819, 41.45745249632551], [-120.55187974143824, 41.45772375508637], [-120.55188021970501, 41.4577297001955], [-120.55188130739668, 41.457744567438525], [-120.55188169928323, 41.45775051612384], [-120.55191502450833, 41.45831920778864], [-120.55191568260797, 41.458337143766705], [-120.55191634648645, 41.45838199192972], [-120.55191621948914, 41.45839993448206], [-120.55189719863829, 41.459056665673614], [-120.5518968020426, 41.45906638056308], [-120.55189552279361, 41.45909065920551], [-120.55189489599, 41.45910036723001], [-120.55186397066821, 41.459504876540926], [-120.55186286373369, 41.45951699720552], [-120.5518
# <br><a href=#top>Return to top</a><br>
# <a id=district-3></a>
# ### District 3
# <style type="text/css">
# #T_dcae2 th {
#   text-align: center;
# }
# #T_dcae2_row0_col0, #T_dcae2_row0_col1, #T_dcae2_row0_col2, #T_dcae2_row0_col3, #T_dcae2_row0_col4 {
#   text-align: center;
# }
# </style>
# <table id="T_dcae2">
#   <thead>
#     <tr>
#       <th id="T_dcae2_level0_col0" class="col_heading level0 col0" >Hwy Route</th>
#       <th id="T_dcae2_level0_col1" class="col_heading level0 col1" >County</th>
#       <th id="T_dcae2_level0_col2" class="col_heading level0 col2" >Route Type</th>
#       <th id="T_dcae2_level0_col3" class="col_heading level0 col3" ># transit routes</th>
#       <th id="T_dcae2_level0_col4" class="col_heading level0 col4" >Hwy Length (mi)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_dcae2_row0_col0" class="data row0 col0" >160</td>
#       <td id="T_dcae2_row0_col1" class="data row0 col1" >SAC</td>
#       <td id="T_dcae2_row0_col2" class="data row0 col2" >State</td>
#       <td id="T_dcae2_row0_col3" class="data row0 col3" >41</td>
#       <td id="T_dcae2_row0_col4" class="data row0 col4" >48.25</td>
#     </tr>
#   </tbody>
# </table>
#     <iframe srcdoc="<!DOCTYPE html>
# <head>
#     <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#
#         <script>
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         </script>
#
#     <style>html, body {width: 100%;height: 100%;margin: 0;padding: 0;}</style>
#     <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>
#     <script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;></script>
#     <script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;></script>
#     <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;></script>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/>
#
#             <meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; />
#             <style>
#                 #map_a43442389138499db87ec63ef5ed6ece {
#                     position: relative;
#                     width: 300.0px;
#                     height: 320.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             </style>
#
#
#                     <style>
#                         .foliumtooltip {
#
#             background-color: &quot;gray&quot;;
#             border: 0px #FFFFFF;
#             border-radius: 0px;
#             box-shadow: 0px;
#             font-size: 12px;
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     </style>
#
#
#                     <style>
#                         .foliumpopup {
#                             background-color: light_gray;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     </style>
#
# </head>
# <body>
#
#              <h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;><b>State Hwy 160</b></h3>
#
#
#             <div class=&quot;folium-map&quot; id=&quot;map_a43442389138499db87ec63ef5ed6ece&quot; ></div>
#
# </body>
# <script>
#
#             var map_a43442389138499db87ec63ef5ed6ece = L.map(
#                 &quot;map_a43442389138499db87ec63ef5ed6ece&quot;,
#                 {
#                     center: [38.26491489788143, -121.58608229589788],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0a2fe91c5a90462b802573aa1a0c5197 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a43442389138499db87ec63ef5ed6ece);
#
#
#         function geo_json_d0be3734306c4763a09ec67e77a90330_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#FFFFFF&quot;, &quot;fillColor&quot;: &quot;#5b559cff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 0.2};
#             }
#         }
#
#         function geo_json_d0be3734306c4763a09ec67e77a90330_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_d0be3734306c4763a09ec67e77a90330 = L.geoJson(null, {
#                 onEachFeature: geo_json_d0be3734306c4763a09ec67e77a90330_onEachFeature,
#
#                 style: geo_json_d0be3734306c4763a09ec67e77a90330_styler,
#         });
#
#         function geo_json_d0be3734306c4763a09ec67e77a90330_add (data) {
#             geo_json_d0be3734306c4763a09ec67e77a90330
#                 .addData(data)
#                 .addTo(map_a43442389138499db87ec63ef5ed6ece);
#         }
#             geo_json_d0be3734306c4763a09ec67e77a90330_add({&quot;bbox&quot;: [-121.75322980341056, 38.022937166739744, -121.43254820894113, 38.605708488841536], &quot;features&quot;: [{&quot;bbox&quot;: [-121.75322980341056, 38.022937166739744, -121.43254820894113, 38.605708488841536], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-121.47859265119057, 38.59507334605332], [-121.47862128800482, 38.59509977524942], [-121.47867350259905, 38.59515305580861], [-121.47871255899045, 38.595197237434654], [-121.47875786775833, 38.59525427789709], [-121.4787912180701, 38.59530125108095], [-121.47882918464649, 38.595361502127915], [-121.47885650768063, 38.595410814501264], [-121.47888676640328, 38.59547369589296], [-121.47890779900305, 38.59552487255863], [-121.47893005843498, 38.59558977872183], [-121.47894459801992, 38.59564232682682], [-121.47895864375732, 38.595708632686396], [-121.47896655027526, 38.59576204616826], [-121.47897224701356, 38.595829113166914], [-121.47897344429038, 38.59588287762705], [-121.47897073712869, 38.59595005987473], [-121.47896521360316, 38.59600365753239], [-121.47895412857444, 38.59607030802647], [-121.47894193741072, 38.59612322270519], [-121.47892258123267, 38.59618869956153], [-121.47890383980945, 38.59624042166019], [-121.47887639885803, 38.59630409429491], [-121.47885128763924, 38.596354125695825], [-121.47881602615523, 38.596415380898456], [-121.47878478695307, 38.596463239764496], [-121.47874204449835, 38.59652148760386], [-121.47870497814546, 38.59656671301921], [-121.47865516633388, 38.59662139252506], [-121.47861262978668, 38.59666354893447], [-121.47855622832077, 38.59671413350055], [-121.4785086312224, 38.5967528149042], [-121.47844618327399, 38.596798817360124], [-121.4784206284699, 38.59681673710666], [-121.47783684454491, 38.59720630724436], [-121.47783179761322, 38.59720964301059], [-121.47781913035196, 38.59721793545233], [-121.47781404347462, 38.597221233639544], [-121.47662359160242, 38.5979856766768], [-121.47653386917784, 38.598043290698676], [-121.47571852189814, 38.598566700220154], [-121.47570350884016, 38.59
# <br><a href=#top>Return to top</a><br>
# <a id=district-4></a>
# ### District 4
# <style type="text/css">
# #T_07c0f th {
#   text-align: center;
# }
# #T_07c0f_row0_col0, #T_07c0f_row0_col1, #T_07c0f_row0_col2, #T_07c0f_row0_col3, #T_07c0f_row0_col4, #T_07c0f_row1_col0, #T_07c0f_row1_col1, #T_07c0f_row1_col2, #T_07c0f_row1_col3, #T_07c0f_row1_col4, #T_07c0f_row2_col0, #T_07c0f_row2_col1, #T_07c0f_row2_col2, #T_07c0f_row2_col3, #T_07c0f_row2_col4, #T_07c0f_row3_col0, #T_07c0f_row3_col1, #T_07c0f_row3_col2, #T_07c0f_row3_col3, #T_07c0f_row3_col4, #T_07c0f_row4_col0, #T_07c0f_row4_col1, #T_07c0f_row4_col2, #T_07c0f_row4_col3, #T_07c0f_row4_col4 {
#   text-align: center;
# }
# </style>
# <table id="T_07c0f">
#   <thead>
#     <tr>
#       <th id="T_07c0f_level0_col0" class="col_heading level0 col0" >Hwy Route</th>
#       <th id="T_07c0f_level0_col1" class="col_heading level0 col1" >County</th>
#       <th id="T_07c0f_level0_col2" class="col_heading level0 col2" >Route Type</th>
#       <th id="T_07c0f_level0_col3" class="col_heading level0 col3" ># transit routes</th>
#       <th id="T_07c0f_level0_col4" class="col_heading level0 col4" >Hwy Length (mi)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_07c0f_row0_col0" class="data row0 col0" >130</td>
#       <td id="T_07c0f_row0_col1" class="data row0 col1" >SCL</td>
#       <td id="T_07c0f_row0_col2" class="data row0 col2" >State</td>
#       <td id="T_07c0f_row0_col3" class="data row0 col3" >30</td>
#       <td id="T_07c0f_row0_col4" class="data row0 col4" >19.89</td>
#     </tr>
#     <tr>
#       <td id="T_07c0f_row1_col0" class="data row1 col0" >37</td>
#       <td id="T_07c0f_row1_col1" class="data row1 col1" >MRN</td>
#       <td id="T_07c0f_row1_col2" class="data row1 col2" >State</td>
#       <td id="T_07c0f_row1_col3" class="data row1 col3" >30</td>
#       <td id="T_07c0f_row1_col4" class="data row1 col4" >3.39</td>
#     </tr>
#     <tr>
#       <td id="T_07c0f_row2_col0" class="data row2 col0" >109</td>
#       <td id="T_07c0f_row2_col1" class="data row2 col1" >SM</td>
#       <td id="T_07c0f_row2_col2" class="data row2 col2" >State</td>
#       <td id="T_07c0f_row2_col3" class="data row2 col3" >28</td>
#       <td id="T_07c0f_row2_col4" class="data row2 col4" >0.77</td>
#     </tr>
#     <tr>
#       <td id="T_07c0f_row3_col0" class="data row3 col0" >113</td>
#       <td id="T_07c0f_row3_col1" class="data row3 col1" >SOL</td>
#       <td id="T_07c0f_row3_col2" class="data row3 col2" >State</td>
#       <td id="T_07c0f_row3_col3" class="data row3 col3" >22</td>
#       <td id="T_07c0f_row3_col4" class="data row3 col4" >22.20</td>
#     </tr>
#     <tr>
#       <td id="T_07c0f_row4_col0" class="data row4 col0" >12</td>
#       <td id="T_07c0f_row4_col1" class="data row4 col1" >NAP</td>
#       <td id="T_07c0f_row4_col2" class="data row4 col2" >State</td>
#       <td id="T_07c0f_row4_col3" class="data row4 col3" >9</td>
#       <td id="T_07c0f_row4_col4" class="data row4 col4" >3.30</td>
#     </tr>
#   </tbody>
# </table>
#     <iframe srcdoc="<!DOCTYPE html>
# <head>
#     <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#
#         <script>
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         </script>
#
#     <style>html, body {width: 100%;height: 100%;margin: 0;padding: 0;}</style>
#     <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>
#     <script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;></script>
#     <script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;></script>
#     <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;></script>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/>
#
#             <meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; />
#             <style>
#                 #map_cccb8f733bc9440b9533f3bdb5224cbc {
#                     position: relative;
#                     width: 300.0px;
#                     height: 320.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             </style>
#
#
#                     <style>
#                         .foliumtooltip {
#
#             background-color: &quot;gray&quot;;
#             border: 0px #FFFFFF;
#             border-radius: 0px;
#             box-shadow: 0px;
#             font-size: 12px;
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     </style>
#
#
#                     <style>
#                         .foliumpopup {
#                             background-color: light_gray;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     </style>
#
# </head>
# <body>
#
#              <h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;><b>State Hwy 130</b></h3>
#
#
#             <div class=&quot;folium-map&quot; id=&quot;map_cccb8f733bc9440b9533f3bdb5224cbc&quot; ></div>
#
# </body>
# <script>
#
#             var map_cccb8f733bc9440b9533f3bdb5224cbc = L.map(
#                 &quot;map_cccb8f733bc9440b9533f3bdb5224cbc&quot;,
#                 {
#                     center: [37.35154111279928, -121.72935603561352],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ee45b321558646f187b3d9718d779988 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cccb8f733bc9440b9533f3bdb5224cbc);
#
#
#         function geo_json_ea7a9c9f32014ade92c7bba88ef6f1a7_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#FFFFFF&quot;, &quot;fillColor&quot;: &quot;#5b559cff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 0.2};
#             }
#         }
#
#         function geo_json_ea7a9c9f32014ade92c7bba88ef6f1a7_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_ea7a9c9f32014ade92c7bba88ef6f1a7 = L.geoJson(null, {
#                 onEachFeature: geo_json_ea7a9c9f32014ade92c7bba88ef6f1a7_onEachFeature,
#
#                 style: geo_json_ea7a9c9f32014ade92c7bba88ef6f1a7_styler,
#         });
#
#         function geo_json_ea7a9c9f32014ade92c7bba88ef6f1a7_add (data) {
#             geo_json_ea7a9c9f32014ade92c7bba88ef6f1a7
#                 .addData(data)
#                 .addTo(map_cccb8f733bc9440b9533f3bdb5224cbc);
#         }
#             geo_json_ea7a9c9f32014ade92c7bba88ef6f1a7_add({&quot;bbox&quot;: [-121.86321112172591, 37.32221332279144, -121.64004115045074, 37.38531323192708], &quot;features&quot;: [{&quot;bbox&quot;: [-121.86321112172591, 37.32221332279144, -121.64004115045074, 37.38531323192708], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-121.82749890811748, 37.36865740098637], [-121.82680937381795, 37.36976578613929], [-121.82622745182954, 37.37070116668975], [-121.82621755350591, 37.37071707607186], [-121.82592776684884, 37.37118552456192], [-121.825920797496, 37.371196788238], [-121.82548651441675, 37.371898831103195], [-121.82547851802703, 37.3719117543791], [-121.8254764198113, 37.37191511635388], [-121.82547113847048, 37.37192350657923], [-121.82546901154264, 37.371926856899286], [-121.82531592957642, 37.37216595644233], [-121.82514423704879, 37.372434115362296], [-121.8249048930849, 37.3728148666933], [-121.8248667108507, 37.37287560792609], [-121.82484380297474, 37.37291204907137], [-121.82440128358994, 37.37361601283565], [-121.82438617946157, 37.373640042186196], [-121.82424000267521, 37.37387258095899], [-121.82423941482547, 37.37387351389425], [-121.82423794242246, 37.37387584511305], [-121.82423735234953, 37.373876777153214], [-121.82399849916395, 37.37425316156506], [-121.82388218782141, 37.3744364432374], [-121.8235866421078, 37.37491699408518], [-121.82357246557754, 37.37494005288606], [-121.82357173081097, 37.374941244370454], [-121.82356988938079, 37.374944221303046], [-121.82356915100324, 37.37494541136474], [-121.82337788200203, 37.37525274730363], [-121.82337606838324, 37.375255640027525], [-121.8233715076667, 37.37526286110969], [-121.82336967271227, 37.3752657452515], [-121.8227292963806, 37.37626495370436], [-121.82260875117333, 37.376453040623055], [-121.82198676741095, 37.37743258085724], [-121.82197098271524, 37.377456012587544], [-121.82192976527232, 37.377513794319455], [-121.82189402261521, 37.37755868998448], [-121.8218459884253, 37.377613015506086], [-121.82180496669756, 37.37765493852194], [-121.82176596316106, 37.377691044911856]
#     <iframe srcdoc="<!DOCTYPE html>
# <head>
#     <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#
#         <script>
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         </script>
#
#     <style>html, body {width: 100%;height: 100%;margin: 0;padding: 0;}</style>
#     <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>
#     <script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;></script>
#     <script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;></script>
#     <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;></script>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/>
#
#             <meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; />
#             <style>
#                 #map_ed06f330bbfc4bdbac2390924e384de1 {
#                     position: relative;
#                     width: 300.0px;
#                     height: 320.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             </style>
#
#
#                     <style>
#                         .foliumtooltip {
#
#             background-color: &quot;gray&quot;;
#             border: 0px #FFFFFF;
#             border-radius: 0px;
#             box-shadow: 0px;
#             font-size: 12px;
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     </style>
#
#
#                     <style>
#                         .foliumpopup {
#                             background-color: light_gray;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     </style>
#
# </head>
# <body>
#
#              <h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;><b>State Hwy 109</b></h3>
#
#
#             <div class=&quot;folium-map&quot; id=&quot;map_ed06f330bbfc4bdbac2390924e384de1&quot; ></div>
#
# </body>
# <script>
#
#             var map_ed06f330bbfc4bdbac2390924e384de1 = L.map(
#                 &quot;map_ed06f330bbfc4bdbac2390924e384de1&quot;,
#                 {
#                     center: [37.48135827358612, -122.14045850552911],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2105f05d1bb249538c20fa3e25a68187 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ed06f330bbfc4bdbac2390924e384de1);
#
#
#         function geo_json_ccdafa8a7baa48969ee554fccef632f1_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#FFFFFF&quot;, &quot;fillColor&quot;: &quot;#5b559cff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 0.2};
#             }
#         }
#
#         function geo_json_ccdafa8a7baa48969ee554fccef632f1_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_ccdafa8a7baa48969ee554fccef632f1 = L.geoJson(null, {
#                 onEachFeature: geo_json_ccdafa8a7baa48969ee554fccef632f1_onEachFeature,
#
#                 style: geo_json_ccdafa8a7baa48969ee554fccef632f1_styler,
#         });
#
#         function geo_json_ccdafa8a7baa48969ee554fccef632f1_add (data) {
#             geo_json_ccdafa8a7baa48969ee554fccef632f1
#                 .addData(data)
#                 .addTo(map_ed06f330bbfc4bdbac2390924e384de1);
#         }
#             geo_json_ccdafa8a7baa48969ee554fccef632f1_add({&quot;bbox&quot;: [-122.14427016911274, 37.474682383279664, -122.13799233127283, 37.487711237349046], &quot;features&quot;: [{&quot;bbox&quot;: [-122.14427016911274, 37.474682383279664, -122.13799233127283, 37.487711237349046], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-122.14372118153804, 37.48734161347901], [-122.14366686233446, 37.487383837150674], [-122.14361623693459, 37.48741949864754], [-122.14355028644997, 37.48746154748903], [-122.14349551818042, 37.48749308309648], [-122.14342471292116, 37.487529778305195], [-122.14336632923971, 37.487556884307665], [-122.14329135111439, 37.487587872476155], [-122.14322991430261, 37.487610287818484], [-122.14315148541313, 37.48763527050251], [-122.14308758716065, 37.487652779304405], [-122.14300646284723, 37.4876715158976], [-122.14294071855285, 37.48768394953297], [-122.14285768011868, 37.4876962595844], [-122.14279072296257, 37.48770349830559], [-122.14270657014806, 37.48770926325779], [-122.14263904499326, 37.487711237349046], [-122.14255458827296, 37.487710401680026], [-122.14248714545343, 37.48770709212897], [-122.14240319822916, 37.48769966388703], [-122.1423364872859, 37.48769110256778], [-122.14225385805189, 37.487677153293944], [-122.1421885214762, 37.48766342266016], [-122.1421080060314, 37.487643086699116], [-122.14204467307631, 37.4876243189897], [-122.1419670468591, 37.4875977921958], [-122.14190632747824, 37.48757416816121], [-122.14183233809732, 37.48754170601191], [-122.14177481707002, 37.48751345317317], [-122.14170517710363, 37.48747536830828], [-122.14165140840228, 37.487442758765496], [-122.1415867885348, 37.48739941797588], [-122.14156147468609, 37.48738157602152], [-122.1415084646044, 37.48734232361433], [-122.14147213626914, 37.48731542174939], [-122.14091650270971, 37.486924514160876], [-122.140890118676, 37.48690494923085], [-122.14082580975425, 37.48685469522978], [-122.1407770731151, 37.48681240191101], [-122.1407197073549, 37.48675706746881], [-122.14069748828196, 37.486734454964115], [-122.14041682039024, 37.48643287642
#     <iframe srcdoc="<!DOCTYPE html>
# <head>
#     <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#
#         <script>
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         </script>
#
#     <style>html, body {width: 100%;height: 100%;margin: 0;padding: 0;}</style>
#     <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>
#     <script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;></script>
#     <script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;></script>
#     <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;></script>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/>
# ...
#     <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#
#         <script>
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         </script>
#
#     <style>html, body {width: 100%;height: 100%;margin: 0;padding: 0;}</style>
#     <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>
#     <script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;></script>
#     <script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;></script>
#     <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;></script>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/>
#
#             <meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; />
#             <style>
#                 #map_3208118c595c414e8922e9a696637d20 {
#                     position: relative;
#                     width: 300.0px;
#                     height: 320.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             </style>
#
#
#                     <style>
#                         .foliumtooltip {
#
#             background-color: &quot;gray&quot;;
#             border: 0px #FFFFFF;
#             border-radius: 0px;
#             box-shadow: 0px;
#             font-size: 12px;
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     </style>
#
#
#                     <style>
#                         .foliumpopup {
#                             background-color: light_gray;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     </style>
#
# </head>
# <body>
#
#              <h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;><b>State Hwy 261</b></h3>
#
#
#             <div class=&quot;folium-map&quot; id=&quot;map_3208118c595c414e8922e9a696637d20&quot; ></div>
#
# </body>
# <script>
#
#             var map_3208118c595c414e8922e9a696637d20 = L.map(
#                 &quot;map_3208118c595c414e8922e9a696637d20&quot;,
#                 {
#                     center: [33.74683014523823, -117.77012479601206],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_307d283af1874a35a7bb080ae423d064 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3208118c595c414e8922e9a696637d20);
#
#
#         function geo_json_f903bbce4896405085d8904a20f1c428_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#FFFFFF&quot;, &quot;fillColor&quot;: &quot;#5b559cff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 0.2};
#             }
#         }
#
#         function geo_json_f903bbce4896405085d8904a20f1c428_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f903bbce4896405085d8904a20f1c428 = L.geoJson(null, {
#                 onEachFeature: geo_json_f903bbce4896405085d8904a20f1c428_onEachFeature,
#
#                 style: geo_json_f903bbce4896405085d8904a20f1c428_styler,
#         });
#
#         function geo_json_f903bbce4896405085d8904a20f1c428_add (data) {
#             geo_json_f903bbce4896405085d8904a20f1c428
#                 .addData(data)
#                 .addTo(map_3208118c595c414e8922e9a696637d20);
#         }
#             geo_json_f903bbce4896405085d8904a20f1c428_add({&quot;bbox&quot;: [-117.80247192921584, 33.7104561653343, -117.74532037710956, 33.78557746111354], &quot;features&quot;: [{&quot;bbox&quot;: [-117.80247192921584, 33.7104561653343, -117.74532037710956, 33.78557746111354], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-117.80160641019508, 33.710687726648025], [-117.80161603208305, 33.710691251444686], [-117.80168823227729, 33.71072131222373], [-117.80174451094558, 33.7107477004385], [-117.80181283795137, 33.7107835307352], [-117.80186575081063, 33.71081440194294], [-117.80192954661648, 33.710855656704915], [-117.80197858409643, 33.710890713609935], [-117.80203723432237, 33.71093699554527], [-117.80208192416949, 33.71097590054181], [-117.80213486398375, 33.71102676394462], [-117.80217477580923, 33.711069142367855], [-117.80222149536779, 33.711124097410085], [-117.80225624479255, 33.7111695411439], [-117.80229629414919, 33.7112280585921], [-117.80232554650578, 33.71127612999895], [-117.80235853994604, 33.711337646310604], [-117.80238201350217, 33.71138788244593], [-117.80240763325841, 33.71145180519609], [-117.8024251019308, 33.71150372226631], [-117.80244310124348, 33.71156943585268], [-117.80245439677594, 33.711622533874], [-117.8024646022711, 33.71168940544509], [-117.80246961585578, 33.71174317305858], [-117.80247192921584, 33.71181055860822], [-117.80247061254221, 33.711864478004145], [-117.80246501145412, 33.71193172857353], [-117.8024573771751, 33.71198528047819], [-117.8024439155466, 33.71205174840553], [-117.80243003715793, 33.71210441708204], [-117.80240884459953, 33.71216946224012], [-117.80238885573287, 33.7122207404555], [-117.80236013631107, 33.71228373641651], [-117.80234790834227, 33.71230869912008], [-117.80228604787929, 33.71242664182592], [-117.8022545128429, 33.71248676565553], [-117.80211287913275, 33.71275679542766], [-117.802106166966, 33.71276917381066], [-117.80208893128349, 33.71279994165233], [-117.80208185490416, 33.712812177542624], [-117.80183075288775, 33.71323299834194], [-117.80182326505106, 33.7132451654474], [-117
#     <iframe srcdoc="<!DOCTYPE html>
# <head>
#     <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#
#         <script>
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         </script>
#
#     <style>html, body {width: 100%;height: 100%;margin: 0;padding: 0;}</style>
#     <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>
#     <script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;></script>
#     <script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;></script>
#     <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;></script>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/>
#
#             <meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; />
#             <style>
#                 #map_6ad2c9eeecd94680a2712359fc853cab {
#                     position: relative;
#                     width: 300.0px;
#                     height: 320.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             </style>
#
#
#                     <style>
#                         .foliumtooltip {
#
#             background-color: &quot;gray&quot;;
#             border: 0px #FFFFFF;
#             border-radius: 0px;
#             box-shadow: 0px;
#             font-size: 12px;
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     </style>
#
#
#                     <style>
#                         .foliumpopup {
#                             background-color: light_gray;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     </style>
#
# </head>
# <body>
#
#              <h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;><b>Interstate 605</b></h3>
#
#
#             <div class=&quot;folium-map&quot; id=&quot;map_6ad2c9eeecd94680a2712359fc853cab&quot; ></div>
#
# </body>
# <script>
#
#             var map_6ad2c9eeecd94680a2712359fc853cab = L.map(
#                 &quot;map_6ad2c9eeecd94680a2712359fc853cab&quot;,
#                 {
#                     center: [33.792342067815326, -118.08742087042961],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3c9fda42d806484f88649c687ad24ea3 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6ad2c9eeecd94680a2712359fc853cab);
#
#
#         function geo_json_06f10b35604b4d6ab3fc036ccdb5968a_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#FFFFFF&quot;, &quot;fillColor&quot;: &quot;#5b559cff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 0.2};
#             }
#         }
#
#         function geo_json_06f10b35604b4d6ab3fc036ccdb5968a_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_06f10b35604b4d6ab3fc036ccdb5968a = L.geoJson(null, {
#                 onEachFeature: geo_json_06f10b35604b4d6ab3fc036ccdb5968a_onEachFeature,
#
#                 style: geo_json_06f10b35604b4d6ab3fc036ccdb5968a_styler,
#         });
#
#         function geo_json_06f10b35604b4d6ab3fc036ccdb5968a_add (data) {
#             geo_json_06f10b35604b4d6ab3fc036ccdb5968a
#                 .addData(data)
#                 .addTo(map_6ad2c9eeecd94680a2712359fc853cab);
#         }
#             geo_json_06f10b35604b4d6ab3fc036ccdb5968a_add({&quot;bbox&quot;: [-118.09369831746218, 33.77736871113356, -118.07979695183884, 33.80767041484693], &quot;features&quot;: [{&quot;bbox&quot;: [-118.09369831746218, 33.77736871113356, -118.07979695183884, 33.80767041484693], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-118.09316342316896, 33.784859358196954], [-118.09316300257416, 33.78486028766922], [-118.09312003791219, 33.7849549761688], [-118.09311521224656, 33.78496529611046], [-118.0931028378782, 33.784990991809906], [-118.09309776404912, 33.78500122842778], [-118.09299432732523, 33.785204103090265], [-118.09284812394688, 33.78549651940258], [-118.09271144750014, 33.7857812716216], [-118.09270651993513, 33.785791538481696], [-118.09248088101829, 33.78626163396027], [-118.09247869236236, 33.78626613603448], [-118.09247316124087, 33.786277370802516], [-118.09247092499953, 33.78628185654291], [-118.0922187076808, 33.78678154543288], [-118.09221626749289, 33.786786316804644], [-118.09221009972465, 33.78679822092398], [-118.09220760569795, 33.78680297284768], [-118.09213036984167, 33.78694826235095], [-118.09205953259628, 33.787081516220375], [-118.0920316784345, 33.787133913117536], [-118.09157387430977, 33.78799508553916], [-118.0909931027644, 33.7891526736088], [-118.09098682041562, 33.78916519565306], [-118.09084272303403, 33.789480420838], [-118.08989898533191, 33.791721885847714], [-118.08890244074942, 33.794425504826606], [-118.08832096345446, 33.79613643927061], [-118.08831138403015, 33.79616220007365], [-118.08828555736605, 33.79622607275079], [-118.08826191777801, 33.79627626292446], [-118.08822871665281, 33.796337714538275], [-118.0881992984237, 33.796385728510764], [-118.08815904255975, 33.796444167237816], [-118.08812412898716, 33.796489542598955], [-118.08807720605321, 33.796544405629824], [-118.08803713336249, 33.796586705379625], [-118.08798399524092, 33.79663746433973], [-118.08793914934776, 33.79667628109715], [-118.08789439197268, 33.7967113969398], [-118.0879043446486, 33.79676015250138], [-118.08791398849769, 33.79682708
# <br><a href=#top>Return to top</a><br>

# %%
import pandas as pd
import geopandas as gpd
from shared_utils import geo_utils
from calitp_data_analysis.sql import get_engine
db_engine = get_engine()
import gcsfs
import google.auth
credentials, project = google.auth.default()
fs = gcsfs.GCSFileSystem()
import os

pd.set_option('display.max_columns', None)

# %%
GCS_FILE_PATH  = 'gs://calitp-analytics-data/data-analyses'

# %%
# Querying unique GTFS stops (lightweight)
with db_engine.connect() as connection:
    query = """
        SELECT
            name,
            stop_id,
            stop_key,
            stop_code,
            stop_name,
            location_type,
            ANY_VALUE(pt_geom) AS pt_geom
        FROM
            cal-itp-data-infra.mart_gtfs_rollup.fct_monthly_scheduled_stops
        WHERE(
        month_first_day BETWEEN DATE('2025-01-01') AND DATE('2025-12-01') 
        OR month_first_day BETWEEN DATE('2026-03-01') AND DATE('2026-06-01')
        )
        GROUP BY
            name,
            stop_id,
            stop_key,
            stop_code,
            stop_name,
            location_type
    """
    stops_unique = pd.read_sql(query, connection)
# Out:
# /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages/google/cloud/bigquery/client.py:613: UserWarning: Cannot create BigQuery Storage client, the dependency google-cloud-bigquery-storage is not installed.
#   warnings.warn(

# %%
# # Querying unique GTFS stops (lightweight)
# with db_engine.connect() as connection:
#     query = """
#         SELECT
#             name,
#             stop_id,
#             stop_key,
#             stop_code,
#             stop_name,
#             location_type,
#             ANY_VALUE(pt_geom) AS pt_geom
#         FROM
#             cal-itp-data-infra.mart_gtfs_rollup.fct_monthly_scheduled_stops
#         WHERE
#             month_first_day BETWEEN DATE('2025-01-01') AND DATE('2025-12-01')
#         GROUP BY
#             name,
#             stop_id,
#             stop_key,
#             stop_code,
#             stop_name,
#             location_type
#     """
#     stops_unique = pd.read_sql(query, connection)

# %%
with db_engine.connect() as connection:
    query_bridge = """
        SELECT *
        FROM cal-itp-data-infra-staging.mart_transit_database.bridge_gtfs_analysis_name_x_ntd
    """
    bridge_gtfs = pd.read_sql(query_bridge, connection)

# save as parquet
bridge_gtfs.to_parquet("bridge_gtfs_analysis_name_x_ntd.parquet", engine="pyarrow", index=False)

# %%
rancho_rows = bridge_gtfs[
    bridge_gtfs["organization_name"].str.contains("Sacramento", case=False, na=False)
]

# %%
rancho_rows
# Out:
#     organization_name organization_source_record_id schedule_source_record_id  \
# 92  Sacramento County             recsrpnpj2oZXBvE6         recKYQPnCKuxQQ1B9
#
#             schedule_gtfs_dataset_name      analysis_name regional_feed_type  \
# 92  South County Transit Link Schedule  Sacramento County               None
#
#    county_name  caltrans_district   caltrans_district_name  \
# 92  Sacramento                  3  Marysville / Sacramento
#
#            caltrans_district_full      ntd_id ntd_id_2022  \
# 92   03 - Marysville / Sacramento  9R02-90216       90216
#
#                                  rtpa_name  \
# 92  Sacramento Area Council of Governments
#
#                                   mpo_name
# 92  Sacramento Area Council of Governments

# %%
from shared_utils import geo_utils

# %%
stops_unique_gdf = (
    stops_unique
    .pipe(
        geo_utils.convert_to_gdf,
        geom_col="pt_geom",
        geom_type="point"
    )
)

# %%
print(type(stops_unique_gdf))
print(stops_unique_gdf.geometry.head())
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# 0    POINT (-119.55984 37.73242)
# 1    POINT (-122.57252 38.10369)
# 2    POINT (-118.29912 33.85891)
# 3    POINT (-119.81637 34.43514)
# 4    POINT (-122.67652 38.01642)
# Name: geometry, dtype: geometry

# %%
stops_unique_gdf = stops_unique_gdf.drop_duplicates(subset=["stop_id", "stop_name"])

# %%
stops_unique_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 134974 entries, 0 to 2057045
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   name           134974 non-null  object
#  1   stop_id        134974 non-null  object
#  2   stop_key       134974 non-null  object
#  3   stop_code      113187 non-null  object
#  4   stop_name      134974 non-null  object
#  5   location_type  76157 non-null   float64
#  6   geometry       134974 non-null  geometry
# dtypes: float64(1), geometry(1), object(5)
# memory usage: 8.2+ MB

# %%
stops_unique_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 134974 entries, 0 to 2057045
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   name           134974 non-null  object
#  1   stop_id        134974 non-null  object
#  2   stop_key       134974 non-null  object
#  3   stop_code      113187 non-null  object
#  4   stop_name      134974 non-null  object
#  5   location_type  76157 non-null   float64
#  6   geometry       134974 non-null  geometry
# dtypes: float64(1), geometry(1), object(5)
# memory usage: 8.2+ MB

# %%
stops_unique_gdf.name.nunique()
# Out:
# 278

# %%
bridge_gtfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217 entries, 0 to 216
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   organization_name              217 non-null    object
#  1   organization_source_record_id  217 non-null    object
#  2   schedule_source_record_id      217 non-null    object
#  3   schedule_gtfs_dataset_name     217 non-null    object
#  4   analysis_name                  217 non-null    object
#  5   regional_feed_type             45 non-null     object
#  6   county_name                    217 non-null    object
#  7   caltrans_district              217 non-null    int64
#  8   caltrans_district_name         217 non-null    object
#  9   caltrans_district_full         217 non-null    object
#  10  ntd_id                         171 non-null    object
#  11  ntd_id_2022                    174 non-null    object
#  12  rtpa_name                      210 non-null    object
#  13  mpo_name                       172 non-null    object
# dtypes: int64(1), object(13)
# memory usage: 23.9+ KB

# %%
bridge_gtfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217 entries, 0 to 216
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   organization_name              217 non-null    object
#  1   organization_source_record_id  217 non-null    object
#  2   schedule_source_record_id      217 non-null    object
#  3   schedule_gtfs_dataset_name     217 non-null    object
#  4   analysis_name                  217 non-null    object
#  5   regional_feed_type             45 non-null     object
#  6   county_name                    217 non-null    object
#  7   caltrans_district              217 non-null    int64
#  8   caltrans_district_name         217 non-null    object
#  9   caltrans_district_full         217 non-null    object
#  10  ntd_id                         171 non-null    object
#  11  ntd_id_2022                    174 non-null    object
#  12  rtpa_name                      210 non-null    object
#  13  mpo_name                       172 non-null    object
# dtypes: int64(1), object(13)
# memory usage: 23.9+ KB

# %%
bridge_gtfs.head(5)
# Out:
#                                  organization_name  \
# 0                                      Kern County
# 1                       Redding Area Bus Authority
# 2                  Redwood Coast Transit Authority
# 3      Emeryville Transportation Management Agency
# 4  Santa Barbara County Association of Governments
#
#   organization_source_record_id schedule_source_record_id  \
# 0             reczIiFqdL5AXTpm1         recQiWHhvE6MxozGV
# 1             recI1fuNpr306H0hw         recxufF6TZdmF33uv
# 2             recOnKhqF25crJt4q         recWJJ4dRk4lHXaWX
# 3             rec75nESVRqpwNiLv         rec933E2xjOAUudsw
# 4             recBiunkSvSVhXa6J         recLhUJUDjFXcmOte
#
#              schedule_gtfs_dataset_name  \
# 0                         Kern Schedule
# 1                          Redding Flex
# 2                Redwood Coast Schedule
# 3  Bay Area 511 Emery Go-Round Schedule
# 4            Clean Air Express Schedule
#
#                                      analysis_name regional_feed_type  \
# 0                                      Kern County               None
# 1                       Redding Area Bus Authority               None
# 2                  Redwood Coast Transit Authority               None
# 3      Emeryville Transportation Management Agency   Regional Subfeed
# 4  Santa Barbara County Association of Governments               None
#
#      county_name  caltrans_district           caltrans_district_name  \
# 0           Kern                  6             Fresno / Bakersfield
# 1         Shasta                  2                          Redding
# 2      Del Norte                  1                           Eureka
# 3        Alameda                  4               Bay Area / Oakland
# 4  Santa Barbara                  5  San Luis Obispo / Santa Barbara
#
#                   caltrans_district_full      ntd_id ntd_id_2022  \
# 0              06 - Fresno / Bakersfield  9R02-91059       91059
# 1                           02 - Redding       90093       90093
# 2                            01 - Eureka  9R02-91097       91097
# 3                04 - Bay Area / Oakland        None        None
# 4   05 - San Luis Obispo / Santa Barbara       90303       90303
#
#                                          rtpa_name  \
# 0                      Kern Council of Governments
# 1            Shasta Regional Transportation Agency
# 2        Del Norte Local Transportation Commission
# 3           Metropolitan Transportation Commission
# 4  Santa Barbara County Association of Governments
#
#                                           mpo_name
# 0                      Kern Council of Governments
# 1            Shasta Regional Transportation Agency
# 2                                             None
# 3                                             None
# 4  Santa Barbara County Association of Governments

# %%
stops_with_crosswalk = stops_unique_gdf.merge(
    bridge_gtfs,
    left_on="name",       
    right_on="schedule_gtfs_dataset_name",  
    how="left"             
)

# %%
stops_with_crosswalk.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 134974 entries, 0 to 134973
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   name                           134974 non-null  object
#  1   stop_id                        134974 non-null  object
#  2   stop_key                       134974 non-null  object
#  3   stop_code                      113187 non-null  object
#  4   stop_name                      134974 non-null  object
#  5   location_type                  76157 non-null   float64
#  6   geometry                       134974 non-null  geometry
#  7   organization_name              97261 non-null   object
#  8   organization_source_record_id  97261 non-null   object
#  9   schedule_source_record_id      97261 non-null   object
#  10  schedule_gtfs_dataset_name     97261 non-null   object
#  11  analysis_name                  97261 non-null   object
#  12  regional_feed_type             14629 non-null   object
#  13  county_name                    97261 non-null   object
#  14  caltrans_district              97261 non-null   float64
#  15  caltrans_district_name         97261 non-null   object
#  16  caltrans_district_full         97261 non-null   object
#  17  ntd_id                         85939 non-null   object
#  18  ntd_id_2022                    86193 non-null   object
#  19  rtpa_name                      95676 non-null   object
#  20  mpo_name                       88365 non-null   object
# dtypes: float64(2), geometry(1), object(18)
# memory usage: 21.6+ MB

# %%
rancho_rows = stops_with_crosswalk[
    stops_with_crosswalk["analysis_name"].str.contains("Sacramento", case=False, na=False)
]

rancho_rows
# Out:
#                                       name stop_id  \
# 2207    South County Transit Link Schedule   10011
# 6925    South County Transit Link Schedule   10013
# 8220    South County Transit Link Schedule   10002
# 8603    South County Transit Link Schedule   10016
# 17301   South County Transit Link Schedule   10017
# ...                                    ...     ...
# 132663                 Sacramento Schedule    1794
# 132664                 Sacramento Schedule    1067
# 132665                 Sacramento Schedule    9922
# 132666                 Sacramento Schedule    1802
# 132667                 Sacramento Schedule    1760
#
#                                 stop_key stop_code  \
# 2207    2f8c48d6c1aa6b40864d5ffbda594150     10011
# 6925    0cc6dee647d76122ff165125473cc47c     10013
# 8220    fc22d7b22d1688792afb11337df0246e     10002
# 8603    4f06b6c114e87f652db14cda5fb274c3     10016
# 17301   e253effbd5530540684a07afd696c76b     10017
# ...                                  ...       ...
# 132663  8882393cbde9c9eb3da89dbdc02ab786      1794
# 132664  a0b8650faad2f7cde2e24e89c81f5ffe      1067
# 132665  1bbfe388e2dff2e65b68d1739aac570f      9922
# 132666  d2d499754cb95a373a366eb801d39d5c      1802
# 132667  ee96b50b30b5225ccd3dd1addb427fb7      1760
#
#                                          stop_name  location_type  \
# 2207                           I St & 12th St (WB)            NaN
# 6925                              Q St & 11th (EB)            NaN
# 8220                          Civic St & C St (NB)            NaN
# 8603              Fermoy Way & Twin Cities Rd (SB)            NaN
# 17301              River Rd & Locke Boat Dock (SB)            NaN
# ...                                            ...            ...
# 132663  RANCHO CORDOVA PKWY & CHRYSANTHY BLVD (NB)            NaN
# 132664                         16TH ST & H ST (NB)            NaN
# 132665              BLECKLEY ST & SCHIRRA AVE (SB)            NaN
# 132666                    WATT AVE & I-80 LRT (SB)            NaN
# 132667              SUNRISE BLVD & DOUGLAS RD (SB)            NaN
#
#                            geometry       organization_name  \
# 2207    POINT (-121.49019 38.58074)       Sacramento County
# 6925    POINT (-121.49572 38.57221)       Sacramento County
# 8220    POINT (-121.29612 38.25257)       Sacramento County
# 8603    POINT (-121.30631 38.29009)       Sacramento County
# 17301   POINT (-121.51101 38.25239)       Sacramento County
# ...                             ...                     ...
# 132663  POINT (-121.22417 38.55086)  City of Rancho Cordova
# 132664  POINT (-121.48407 38.58059)  City of Rancho Cordova
# 132665  POINT (-121.29408 38.57139)  City of Rancho Cordova
# 132666  POINT (-121.38327 38.64563)  City of Rancho Cordova
# 132667  POINT (-121.24330 38.55877)  City of Rancho Cordova
#
#        organization_source_record_id schedule_source_record_id  \
# 2207               recsrpnpj2oZXBvE6         recKYQPnCKuxQQ1B9
# 6925               recsrpnpj2oZXBvE6         recKYQPnCKuxQQ1B9
# 8220               recsrpnpj2oZXBvE6         recKYQPnCKuxQQ1B9
# 8603               recsrpnpj2oZXBvE6         recKYQPnCKuxQQ1B9
# 17301              recsrpnpj2oZXBvE6         recKYQPnCKuxQQ1B9
# ...                              ...                       ...
# 132663             rec43oyrfhtPDdRHj         recbzZQUIdMmFvm1r
# 132664             rec43oyrfhtPDdRHj         recbzZQUIdMmFvm1r
# 132665             rec43oyrfhtPDdRHj         recbzZQUIdMmFvm1r
# 132666             rec43oyrfhtPDdRHj         recbzZQUIdMmFvm1r
# 132667             rec43oyrfhtPDdRHj         recbzZQUIdMmFvm1r
#
#                 schedule_gtfs_dataset_name  \
# 2207    South County Transit Link Schedule
# 6925    South County Transit Link Schedule
# 8220    South County Transit Link Schedule
# 8603    South County Transit Link Schedule
# 17301   South County Transit Link Schedule
# ...                                    ...
# 132663                 Sacramento Schedule
# 132664                 Sacramento Schedule
# 132665                 Sacramento Schedule
# 132666                 Sacramento Schedule
# 132667                 Sacramento Schedule
#
#                                analysis_name regional_feed_type county_name  \
# 2207                       Sacramento County               None  Sacramento
# 6925                       Sacramento County               None  Sacramento
# 8220                       Sacramento County               None  Sacramento
# 8603                       Sacramento County               None  Sacramento
# 17301                      Sacramento County               None  Sacramento
# ...                                      ...                ...         ...
# 132663  Sacramento Regional Transit District               None  Sacramento
# 132664  Sacramento Regional Transit District               None  Sacramento
# 132665  Sacramento Regional Transit District               None  Sacramento
# 132666  Sacramento Regional Transit District               None  Sacramento
# 132667  Sacramento Regional Transit District               None  Sacramento
#
#         caltrans_district   caltrans_district_name  \
# 2207                  3.0  Marysville / Sacramento
# 6925                  3.0  Marysville / Sacramento
# 8220                  3.0  Marysville / Sacramento
# 8603                  3.0  Marysville / Sacramento
# 17301                 3.0  Marysville / Sacramento
# ...                   ...                      ...
# 132663                3.0  Marysville / Sacramento
# 132664                3.0  Marysville / Sacramento
# 132665                3.0  Marysville / Sacramento
# 132666                3.0  Marysville / Sacramento
# 132667                3.0  Marysville / Sacramento
#
#                caltrans_district_full      ntd_id ntd_id_2022  \
# 2207     03 - Marysville / Sacramento  9R02-90216       90216
# 6925     03 - Marysville / Sacramento  9R02-90216       90216
# 8220     03 - Marysville / Sacramento  9R02-90216       90216
# 8603     03 - Marysville / Sacramento  9R02-90216       90216
# 17301    03 - Marysville / Sacramento  9R02-90216       90216
# ...                               ...         ...         ...
# 132663   03 - Marysville / Sacramento        None        None
# 132664   03 - Marysville / Sacramento        None        None
# 132665   03 - Marysville / Sacramento        None        None
# 132666   03 - Marysville / Sacramento        None        None
# 132667   03 - Marysville / Sacramento        None        None
#
#                                      rtpa_name  \
# 2207    Sacramento Area Council of Governments
# 6925    Sacramento Area Council of Governments
# 8220    Sacramento Area Council of Governments
# 8603    Sacramento Area Council of Governments
# 17301   Sacramento Area Council of Governments
# ...                                        ...
# 132663  Sacramento Area Council of Governments
# 132664  Sacramento Area Council of Governments
# 132665  Sacramento Area Council of Governments
# 132666  Sacramento Area Council of Governments
# 132667  Sacramento Area Council of Governments
#
#                                       mpo_name
# 2207    Sacramento Area Council of Governments
# 6925    Sacramento Area Council of Governments
# 8220    Sacramento Area Council of Governments
# 8603    Sacramento Area Council of Governments
# 17301   Sacramento Area Council of Governments
# ...                                        ...
# 132663  Sacramento Area Council of Governments
# 132664  Sacramento Area Council of Governments
# 132665  Sacramento Area Council of Governments
# 132666  Sacramento Area Council of Governments
# 132667  Sacramento Area Council of Governments
#
# [2849 rows x 21 columns]

# %%
# List of variant rows to drop (no org info, but other variants in group have org info)
drop_names = [
    'Anaheim Resort Schedule v2', 'Tri-Valley Wheels Schedule', 'Lynwood Schedule',
    'Mountain Transit GMV Schedule', 'Nevada County Remix Schedule',
    'Roseville Transit GMV Schedule', 'Roseville Transit TripShot Schedule',
    'TCRTA Schedule Historic 2', 'Tahoe Transportation District GMV Schedule',
    'Victor Valley GMV Schedule', 'eTrans Schedule Remix',
    'eTrans Schedule Trillium', 'Bellflower Remix Schedule',
    'Capitol Corridor Schedule', 'Commute.org Schedules',
    'El Monte RTAP Schedule', 'Vacaville Schedule', 'Marin GMV Schedule',
    'Petaluma GMV Schedule', 'Union City GMV Schedule',
    'South San Francisco Schedule', 'Basin Transit GMV Schedule',
    'Vine GMV Schedule', 'Caltrain Schedule',
    'Big Blue Bus Swiftly Schedule', 'Emery Go-Round TripShot Schedule',
    'Santa Rosa CityBus GMV Schedule', 'Merced GMV Schedule',
    'SolTrans Schedule', 'eTrans Schedule', 'WestCAT Schedule', 'MVGO Schedule',
    'Cerritos on Wheels Schedule', 'San Francisco Bay Ferry Schedule',
    'SMART Schedule', 'Lawndale Beat GMV Schedule',
    'Mountain View Community Shuttle Schedule', 'Desert Roadrunner GMV Schedule',
    'ACE Schedule', 'AC Transit Schedule', 'SCVTA Schedule', 'SamTrans Schedule',
    'Amtrak San Joaquins Schedule', 'Fairfield Schedule', 'Rio Vista Schedule',
    'County Connection Schedule', 'TCRTA TripShot Schedule'
]
# Drop these rows
stops_with_crosswalk_cleaned = stops_with_crosswalk[~stops_with_crosswalk['name'].isin(drop_names)].reset_index(drop=True)

# %%
def export_gdf(gdf, filename: str):
    # Save GeoParquet locally
    gdf.to_parquet(f"{filename}.parquet", engine="pyarrow", index=False)

    # Full GCS path including folder
    gcs_path = f"{GCS_FILE_PATH}/transit_provider_dashboard/{filename}.parquet"

    # Upload to GCS
    fs.put(
        f"{filename}.parquet",
        gcs_path,
        token=credentials.token
    )

    # Remove local file
    os.remove(f"{filename}.parquet")
    print(f"saved {gcs_path}")

# %%
# Store data in warehouse
export_gdf(stops_with_crosswalk_cleaned, "stop_data_cleaned")
# Out:
# saved gs://calitp-analytics-data/data-analyses/transit_provider_dashboard/stop_data_cleaned.parquet

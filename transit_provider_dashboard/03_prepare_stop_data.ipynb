# %%
import pandas as pd
import geopandas as gpd
from shared_utils import geo_utils
from calitp_data_analysis.sql import get_engine
db_engine = get_engine()
import gcsfs
import google.auth
credentials, project = google.auth.default()
fs = gcsfs.GCSFileSystem()
import os

pd.set_option('display.max_columns', None)

# %%
GCS_FILE_PATH  = 'gs://calitp-analytics-data/data-analyses'

# %%
# Querying unique GTFS stops (lightweight)
with db_engine.connect() as connection:
    query = """
        SELECT
            name,
            stop_id,
            stop_key,
            stop_code,
            stop_name,
            location_type,
            ANY_VALUE(pt_geom) AS pt_geom
        FROM
            cal-itp-data-infra.mart_gtfs_rollup.fct_monthly_scheduled_stops
        WHERE(
        month_first_day BETWEEN DATE('2025-01-01') AND DATE('2025-12-01') 
        OR month_first_day BETWEEN DATE('2026-03-01') AND DATE('2026-06-01')
        )
        GROUP BY
            name,
            stop_id,
            stop_key,
            stop_code,
            stop_name,
            location_type
    """
    stops_unique = pd.read_sql(query, connection)
# Out:
# /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages/google/cloud/bigquery/client.py:613: UserWarning: Cannot create BigQuery Storage client, the dependency google-cloud-bigquery-storage is not installed.
#   warnings.warn(

# %%
# # Querying unique GTFS stops (lightweight)
# with db_engine.connect() as connection:
#     query = """
#         SELECT
#             name,
#             stop_id,
#             stop_key,
#             stop_code,
#             stop_name,
#             location_type,
#             ANY_VALUE(pt_geom) AS pt_geom
#         FROM
#             cal-itp-data-infra.mart_gtfs_rollup.fct_monthly_scheduled_stops
#         WHERE
#             month_first_day BETWEEN DATE('2025-01-01') AND DATE('2025-12-01')
#         GROUP BY
#             name,
#             stop_id,
#             stop_key,
#             stop_code,
#             stop_name,
#             location_type
#     """
#     stops_unique = pd.read_sql(query, connection)

# %%
with db_engine.connect() as connection:
    query_bridge = """
        SELECT *
        FROM cal-itp-data-infra-staging.mart_transit_database.bridge_gtfs_analysis_name_x_ntd
    """
    bridge_gtfs = pd.read_sql(query_bridge, connection)

# save as parquet
bridge_gtfs.to_parquet("bridge_gtfs_analysis_name_x_ntd.parquet", engine="pyarrow", index=False)
# Out:
# /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages/google/cloud/bigquery/client.py:613: UserWarning: Cannot create BigQuery Storage client, the dependency google-cloud-bigquery-storage is not installed.
#   warnings.warn(

# %%
rancho_rows = bridge_gtfs[
    bridge_gtfs["organization_name"].str.contains("Sacramento", case=False, na=False)
]

# %%
rancho_rows
# Out:
#      organization_name organization_source_record_id  \
# 157  Sacramento County             recsrpnpj2oZXBvE6
#
#     schedule_source_record_id          schedule_gtfs_dataset_name  \
# 157         recKYQPnCKuxQQ1B9  South County Transit Link Schedule
#
#          analysis_name regional_feed_type county_name  caltrans_district  \
# 157  Sacramento County               None  Sacramento                  3
#
#       caltrans_district_name         caltrans_district_full      ntd_id  \
# 157  Marysville / Sacramento   03 - Marysville / Sacramento  9R02-90216
#
#     ntd_id_2022                               rtpa_name  \
# 157       90216  Sacramento Area Council of Governments
#
#                                    mpo_name
# 157  Sacramento Area Council of Governments

# %%
from shared_utils import geo_utils

# %%
stops_unique_gdf = (
    stops_unique
    .pipe(
        geo_utils.convert_to_gdf,
        geom_col="pt_geom",
        geom_type="point"
    )
)

# %%
print(type(stops_unique_gdf))
print(stops_unique_gdf.geometry.head())
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# 0    POINT (-122.51895 37.92522)
# 1    POINT (-120.21773 39.19920)
# 2    POINT (-121.55045 39.48217)
# 3    POINT (-117.37635 33.19790)
# 4    POINT (-119.99161 38.92194)
# Name: geometry, dtype: geometry

# %%
stops_unique_gdf = stops_unique_gdf.drop_duplicates(subset=["stop_id", "stop_name"])

# %%
stops_unique_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 133560 entries, 0 to 1899936
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   name           133560 non-null  object
#  1   stop_id        133560 non-null  object
#  2   stop_key       133560 non-null  object
#  3   stop_code      111856 non-null  object
#  4   stop_name      133560 non-null  object
#  5   location_type  77066 non-null   float64
#  6   geometry       133560 non-null  geometry
# dtypes: float64(1), geometry(1), object(5)
# memory usage: 8.2+ MB

# %%
stops_unique_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 133560 entries, 0 to 1899936
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   name           133560 non-null  object
#  1   stop_id        133560 non-null  object
#  2   stop_key       133560 non-null  object
#  3   stop_code      111856 non-null  object
#  4   stop_name      133560 non-null  object
#  5   location_type  77066 non-null   float64
#  6   geometry       133560 non-null  geometry
# dtypes: float64(1), geometry(1), object(5)
# memory usage: 8.2+ MB

# %%
stops_unique_gdf.name.nunique()
# Out:
# 275

# %%
bridge_gtfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219 entries, 0 to 218
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   organization_name              219 non-null    object
#  1   organization_source_record_id  219 non-null    object
#  2   schedule_source_record_id      219 non-null    object
#  3   schedule_gtfs_dataset_name     219 non-null    object
#  4   analysis_name                  219 non-null    object
#  5   regional_feed_type             46 non-null     object
#  6   county_name                    219 non-null    object
#  7   caltrans_district              219 non-null    int64
#  8   caltrans_district_name         219 non-null    object
#  9   caltrans_district_full         219 non-null    object
#  10  ntd_id                         174 non-null    object
#  11  ntd_id_2022                    177 non-null    object
#  12  rtpa_name                      212 non-null    object
#  13  mpo_name                       174 non-null    object
# dtypes: int64(1), object(13)
# memory usage: 24.1+ KB

# %%
bridge_gtfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219 entries, 0 to 218
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   organization_name              219 non-null    object
#  1   organization_source_record_id  219 non-null    object
#  2   schedule_source_record_id      219 non-null    object
#  3   schedule_gtfs_dataset_name     219 non-null    object
#  4   analysis_name                  219 non-null    object
#  5   regional_feed_type             46 non-null     object
#  6   county_name                    219 non-null    object
#  7   caltrans_district              219 non-null    int64
#  8   caltrans_district_name         219 non-null    object
#  9   caltrans_district_full         219 non-null    object
#  10  ntd_id                         174 non-null    object
#  11  ntd_id_2022                    177 non-null    object
#  12  rtpa_name                      212 non-null    object
#  13  mpo_name                       174 non-null    object
# dtypes: int64(1), object(13)
# memory usage: 24.1+ KB

# %%
bridge_gtfs.head(5)
# Out:
#                     organization_name organization_source_record_id  \
# 0                      Presidio Trust             recsBfXgev9ICDCY1
# 1  San Joaquin Joint Powers Authority             recvUlrKS1N2mvAwk
# 2             City of Huntington Park             rec0mPaKPAdemkyOV
# 3                City of Laguna Beach             rec6Z3DnERm3OwFzw
# 4                     City of Turlock             recmQVsPDG6sLtD6j
#
#   schedule_source_record_id       schedule_gtfs_dataset_name  \
# 0         recIc6H6QCvQrBQxl  Bay Area 511 PresidiGo Schedule
# 1         rec7vVlnDHHfMjzoO             Gold Runner Schedule
# 2         recyga5EW8Ly3EJTk         Huntington Park Schedule
# 3         recXPyi9Uiudn74nX                Laguna Beach Flex
# 4         rec8p8aIgJ66XnuqS                 Turlock Schedule
#
#                         analysis_name regional_feed_type    county_name  \
# 0                      Presidio Trust   Regional Subfeed  San Francisco
# 1  San Joaquin Joint Powers Authority               None    San Joaquin
# 2             City of Huntington Park               None    Los Angeles
# 3                City of Laguna Beach               None         Orange
# 4                     City of Turlock               None     Stanislaus
#
#    caltrans_district caltrans_district_name       caltrans_district_full  \
# 0                  4     Bay Area / Oakland      04 - Bay Area / Oakland
# 1                 10               Stockton                10 - Stockton
# 2                  7  Los Angeles / Ventura   07 - Los Angeles / Ventura
# 3                 12          Orange County           12 - Orange County
# 4                 10               Stockton                10 - Stockton
#
#   ntd_id ntd_id_2022                                       rtpa_name  \
# 0   None        None          Metropolitan Transportation Commission
# 1   None        None              San Joaquin Council of Governments
# 2  90267       90267  Southern California Association of Governments
# 3  90119       90119  Southern California Association of Governments
# 4  90201       90201               Stanislaus Council of Governments
#
#                                          mpo_name
# 0          Metropolitan Transportation Commission
# 1              San Joaquin Council of Governments
# 2  Southern California Association of Governments
# 3  Southern California Association of Governments
# 4               Stanislaus Council of Governments

# %%
stops_with_crosswalk = stops_unique_gdf.merge(
    bridge_gtfs,
    left_on="name",       
    right_on="schedule_gtfs_dataset_name",  
    how="left"             
)

# %%
stops_with_crosswalk.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 133560 entries, 0 to 133559
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   name                           133560 non-null  object
#  1   stop_id                        133560 non-null  object
#  2   stop_key                       133560 non-null  object
#  3   stop_code                      111856 non-null  object
#  4   stop_name                      133560 non-null  object
#  5   location_type                  77066 non-null   float64
#  6   geometry                       133560 non-null  geometry
#  7   organization_name              96362 non-null   object
#  8   organization_source_record_id  96362 non-null   object
#  9   schedule_source_record_id      96362 non-null   object
#  10  schedule_gtfs_dataset_name     96362 non-null   object
#  11  analysis_name                  96362 non-null   object
#  12  regional_feed_type             14726 non-null   object
#  13  county_name                    96362 non-null   object
#  14  caltrans_district              96362 non-null   float64
#  15  caltrans_district_name         96362 non-null   object
#  16  caltrans_district_full         96362 non-null   object
#  17  ntd_id                         85100 non-null   object
#  18  ntd_id_2022                    85358 non-null   object
#  19  rtpa_name                      94806 non-null   object
#  20  mpo_name                       87517 non-null   object
# dtypes: float64(2), geometry(1), object(18)
# memory usage: 21.4+ MB

# %%
rancho_rows = stops_with_crosswalk[
    stops_with_crosswalk["analysis_name"].str.contains("Sacramento", case=False, na=False)
]

rancho_rows
# Out:
#                                       name stop_id  \
# 7913    South County Transit Link Schedule   10014
# 11881   South County Transit Link Schedule   10008
# 11955   South County Transit Link Schedule   10018
# 18152   South County Transit Link Schedule   10005
# 22059   South County Transit Link Schedule   10001
# ...                                    ...     ...
# 131212                 Sacramento Schedule    1134
# 131213                 Sacramento Schedule    1722
# 133545                 Sacramento Schedule    1066
# 133546                 Sacramento Schedule   11217
# 133547                 Sacramento Schedule    1135
#
#                                 stop_key stop_code  \
# 7913    325ae58eadfbd24ec9b5416fea2af6a0     10014
# 11881   f5e48d1ba10c3c28454648a5201a02bd     10008
# 11955   b686577269982631331fac783f19239b     10018
# 18152   fef2d17ced5edadfc669837edf03b64a     10005
# 22059   73d2efa73f8963ab7248b7f3a32a1918     10001
# ...                                  ...       ...
# 131212  58ed18c4f46a5f78f52c5a07d13641f5      1134
# 131213  461e99f1af7461d0ce312252f5fd6ed1      1722
# 133545  f4db9d8526497efca8163849a4901b54      1066
# 133546  11e7f7604d1924c4765931a213224e63     11217
# 133547  d6ed31c8793280c438053ce2eacdf86a      1135
#
#                                  stop_name  location_type  \
# 7913                      Q St & 16th (EB)            NaN
# 11881                  30th St & R St (NB)            NaN
# 11955   North South St & Warehouse St (NB)            NaN
# 18152      Wyhdham Dr & Lindbrock Way (WB)            NaN
# 22059     Sacramento St & West Oak St (NB)            NaN
# ...                                    ...            ...
# 131212                 12TH ST & E ST (SB)            NaN
# 131213                 J ST & 27TH ST (EB)            NaN
# 133545                 H ST & 14TH ST (EB)            NaN
# 133546      EAST BIDWELL & ORCHARD DR (WB)            NaN
# 133547                 12TH ST & H ST (SB)            NaN
#
#                            geometry       organization_name  \
# 7913    POINT (-121.48881 38.57036)       Sacramento County
# 11881   POINT (-121.47034 38.56409)       Sacramento County
# 11955   POINT (-121.51314 38.24084)       Sacramento County
# 18152   POINT (-121.42303 38.46869)       Sacramento County
# 22059   POINT (-121.27221 38.13312)       Sacramento County
# ...                             ...                     ...
# 131212  POINT (-121.48867 38.58487)  City of Rancho Cordova
# 131213  POINT (-121.47029 38.57405)  City of Rancho Cordova
# 133545  POINT (-121.48654 38.58090)  City of Rancho Cordova
# 133546  POINT (-121.15804 38.67095)  City of Rancho Cordova
# 133547  POINT (-121.48978 38.58227)  City of Rancho Cordova
#
#        organization_source_record_id schedule_source_record_id  \
# 7913               recsrpnpj2oZXBvE6         recKYQPnCKuxQQ1B9
# 11881              recsrpnpj2oZXBvE6         recKYQPnCKuxQQ1B9
# 11955              recsrpnpj2oZXBvE6         recKYQPnCKuxQQ1B9
# 18152              recsrpnpj2oZXBvE6         recKYQPnCKuxQQ1B9
# 22059              recsrpnpj2oZXBvE6         recKYQPnCKuxQQ1B9
# ...                              ...                       ...
# 131212             rec43oyrfhtPDdRHj         recbzZQUIdMmFvm1r
# 131213             rec43oyrfhtPDdRHj         recbzZQUIdMmFvm1r
# 133545             rec43oyrfhtPDdRHj         recbzZQUIdMmFvm1r
# 133546             rec43oyrfhtPDdRHj         recbzZQUIdMmFvm1r
# 133547             rec43oyrfhtPDdRHj         recbzZQUIdMmFvm1r
#
#                 schedule_gtfs_dataset_name  \
# 7913    South County Transit Link Schedule
# 11881   South County Transit Link Schedule
# 11955   South County Transit Link Schedule
# 18152   South County Transit Link Schedule
# 22059   South County Transit Link Schedule
# ...                                    ...
# 131212                 Sacramento Schedule
# 131213                 Sacramento Schedule
# 133545                 Sacramento Schedule
# 133546                 Sacramento Schedule
# 133547                 Sacramento Schedule
#
#                                analysis_name regional_feed_type county_name  \
# 7913                       Sacramento County               None  Sacramento
# 11881                      Sacramento County               None  Sacramento
# 11955                      Sacramento County               None  Sacramento
# 18152                      Sacramento County               None  Sacramento
# 22059                      Sacramento County               None  Sacramento
# ...                                      ...                ...         ...
# 131212  Sacramento Regional Transit District               None  Sacramento
# 131213  Sacramento Regional Transit District               None  Sacramento
# 133545  Sacramento Regional Transit District               None  Sacramento
# 133546  Sacramento Regional Transit District               None  Sacramento
# 133547  Sacramento Regional Transit District               None  Sacramento
#
#         caltrans_district   caltrans_district_name  \
# 7913                  3.0  Marysville / Sacramento
# 11881                 3.0  Marysville / Sacramento
# 11955                 3.0  Marysville / Sacramento
# 18152                 3.0  Marysville / Sacramento
# 22059                 3.0  Marysville / Sacramento
# ...                   ...                      ...
# 131212                3.0  Marysville / Sacramento
# 131213                3.0  Marysville / Sacramento
# 133545                3.0  Marysville / Sacramento
# 133546                3.0  Marysville / Sacramento
# 133547                3.0  Marysville / Sacramento
#
#                caltrans_district_full      ntd_id ntd_id_2022  \
# 7913     03 - Marysville / Sacramento  9R02-90216       90216
# 11881    03 - Marysville / Sacramento  9R02-90216       90216
# 11955    03 - Marysville / Sacramento  9R02-90216       90216
# 18152    03 - Marysville / Sacramento  9R02-90216       90216
# 22059    03 - Marysville / Sacramento  9R02-90216       90216
# ...                               ...         ...         ...
# 131212   03 - Marysville / Sacramento        None        None
# 131213   03 - Marysville / Sacramento        None        None
# 133545   03 - Marysville / Sacramento        None        None
# 133546   03 - Marysville / Sacramento        None        None
# 133547   03 - Marysville / Sacramento        None        None
#
#                                      rtpa_name  \
# 7913    Sacramento Area Council of Governments
# 11881   Sacramento Area Council of Governments
# 11955   Sacramento Area Council of Governments
# 18152   Sacramento Area Council of Governments
# 22059   Sacramento Area Council of Governments
# ...                                        ...
# 131212  Sacramento Area Council of Governments
# 131213  Sacramento Area Council of Governments
# 133545  Sacramento Area Council of Governments
# 133546  Sacramento Area Council of Governments
# 133547  Sacramento Area Council of Governments
#
#                                       mpo_name
# 7913    Sacramento Area Council of Governments
# 11881   Sacramento Area Council of Governments
# 11955   Sacramento Area Council of Governments
# 18152   Sacramento Area Council of Governments
# 22059   Sacramento Area Council of Governments
# ...                                        ...
# 131212  Sacramento Area Council of Governments
# 131213  Sacramento Area Council of Governments
# 133545  Sacramento Area Council of Governments
# 133546  Sacramento Area Council of Governments
# 133547  Sacramento Area Council of Governments
#
# [2849 rows x 21 columns]

# %%
# List of variant rows to drop (no org info, but other variants in group have org info)
drop_names = [
    'Anaheim Resort Schedule v2', 'Tri-Valley Wheels Schedule', 'Lynwood Schedule',
    'Mountain Transit GMV Schedule', 'Nevada County Remix Schedule',
    'Roseville Transit GMV Schedule', 'Roseville Transit TripShot Schedule',
    'TCRTA Schedule Historic 2', 'Tahoe Transportation District GMV Schedule',
    'Victor Valley GMV Schedule', 'eTrans Schedule Remix',
    'eTrans Schedule Trillium', 'Bellflower Remix Schedule',
    'Capitol Corridor Schedule', 'Commute.org Schedules',
    'El Monte RTAP Schedule', 'Vacaville Schedule', 'Marin GMV Schedule',
    'Petaluma GMV Schedule', 'Union City GMV Schedule',
    'South San Francisco Schedule', 'Basin Transit GMV Schedule',
    'Vine GMV Schedule', 'Caltrain Schedule',
    'Big Blue Bus Swiftly Schedule', 'Emery Go-Round TripShot Schedule',
    'Santa Rosa CityBus GMV Schedule', 'Merced GMV Schedule',
    'SolTrans Schedule', 'eTrans Schedule', 'WestCAT Schedule', 'MVGO Schedule',
    'Cerritos on Wheels Schedule', 'San Francisco Bay Ferry Schedule',
    'SMART Schedule', 'Lawndale Beat GMV Schedule',
    'Mountain View Community Shuttle Schedule', 'Desert Roadrunner GMV Schedule',
    'ACE Schedule', 'AC Transit Schedule', 'SCVTA Schedule', 'SamTrans Schedule',
    'Amtrak San Joaquins Schedule', 'Fairfield Schedule', 'Rio Vista Schedule',
    'County Connection Schedule', 'TCRTA TripShot Schedule'
]
# Drop these rows
stops_with_crosswalk_cleaned = stops_with_crosswalk[~stops_with_crosswalk['name'].isin(drop_names)].reset_index(drop=True)

# %%
def export_gdf(gdf, filename: str):
    # Save GeoParquet locally
    gdf.to_parquet(f"{filename}.parquet", engine="pyarrow", index=False)

    # Full GCS path including folder
    gcs_path = f"{GCS_FILE_PATH}/transit_provider_dashboard/{filename}.parquet"

    # Upload to GCS
    fs.put(
        f"{filename}.parquet",
        gcs_path,
        token=credentials.token
    )

    # Remove local file
    os.remove(f"{filename}.parquet")
    print(f"saved {gcs_path}")

# %%
# Store data in warehouse
export_gdf(stops_with_crosswalk_cleaned, "stop_data_cleaned")
# Out:
# saved gs://calitp-analytics-data/data-analyses/transit_provider_dashboard/stop_data_cleaned.parquet

# %%
pip install shared_utils
# Out:
# Requirement already satisfied: shared_utils in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (5.0.5)
# Requirement already satisfied: altair-transform==0.2.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from shared_utils) (0.2.0)
# Requirement already satisfied: altair==6.0.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from shared_utils) (6.0.0)
# Requirement already satisfied: branca>=0.7.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from shared_utils) (0.8.2)
# Requirement already satisfied: calitp-data-analysis in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from shared_utils) (2026.4.0)
# Requirement already satisfied: dask-geopandas>=0.5.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from shared_utils) (0.5.0)
# Requirement already satisfied: dask<2025.4.0,>=2024.10.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from shared_utils) (2025.3.1)
# Requirement already satisfied: folium<0.21.0,>=0.20.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from shared_utils) (0.20.0)
# Requirement already satisfied: gcsfs==2024.5.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from shared_utils) (2024.5.0)
# Requirement already satisfied: great-tables==0.20.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from shared_utils) (0.20.0)
# Requirement already satisfied: gt-extras==0.0.8 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from shared_utils) (0.0.8)
# Requirement already satisfied: intake-geopandas>=0.3.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from shared_utils) (0.4.0)
# Requirement already satisfied: intake==0.6.4 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from shared_utils) (0.6.4)
# Requirement already satisfied: itables==2.7.3 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from shared_utils) (2.7.3)
# Requirement already satisfied: loguru<0.7,>=0.6.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from shared_utils) (0.6.0)
# Requirement already satisfied: mapclassify<3,>=2.8.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from shared_utils) (2.10.0)
# Requirement already satisfied: matplotlib<4.0.0,>=3.10.5 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from shared_utils) (3.10.8)
# Requirement already satisfied: movingpandas==0.22.4 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from shared_utils) (0.22.4)
# Requirement already satisfied: msgpack>=1.1.2 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from shared_utils) (1.1.2)
# Requirement already satisfied: numba<0.63.0,>=0.62.1 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from shared_utils) (0.62.1)
# Requirement already satisfied: numpy<2.0.0,>=1.26.4 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from shared_utils) (1.26.4)
# Requirement already satisfied: omegaconf==2.3.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from shared_utils) (2.3.0)
# Requirement already satisfied: openpyxl>=3.1.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from shared_utils) (3.1.5)
# Requirement already satisfied: polars==1.22.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from shared_utils) (1.22.0)
# Requirement already satisfied: python-slugify>=8.0.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from shared_utils) (8.0.4)
# Requirement already satisfied: pyyaml>=6.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from shared_utils) (6.0.3)
# Requirement already satisfied: quarto-cli==1.6.40 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from shared_utils) (1.6.40)
# Requirement already satisfied: quarto==0.1.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from shared_utils) (0.1.0)
# Requirement already satisfied: scipy>=1.11.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from shared_utils) (1.17.1)
# Requirement already satisfied: seaborn<0.12.0,>=0.11.2 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from shared_utils) (0.11.2)
# Requirement already satisfied: stonesoup==1.8 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from shared_utils) (1.8)
# Requirement already satisfied: tqdm>=4.66.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from shared_utils) (4.67.3)
# Requirement already satisfied: xmltodict<0.14,>=0.13.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from shared_utils) (0.13.0)
# Requirement already satisfied: jinja2 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from altair==6.0.0->shared_utils) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from altair==6.0.0->shared_utils) (4.26.0)
# Requirement already satisfied: narwhals>=1.27.1 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from altair==6.0.0->shared_utils) (2.18.0)
# Requirement already satisfied: packaging in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from altair==6.0.0->shared_utils) (26.0)
# Requirement already satisfied: typing-extensions>=4.12.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from altair==6.0.0->shared_utils) (4.15.0)
# Requirement already satisfied: ply in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from altair-transform==0.2.0->shared_utils) (3.11)
# Requirement already satisfied: pandas in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from altair-transform==0.2.0->shared_utils) (2.3.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from gcsfs==2024.5.0->shared_utils) (3.13.3)
# Requirement already satisfied: decorator>4.1.2 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from gcsfs==2024.5.0->shared_utils) (5.2.1)
# Requirement already satisfied: fsspec==2024.5.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from gcsfs==2024.5.0->shared_utils) (2024.5.0)
# Requirement already satisfied: google-auth>=1.2 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from gcsfs==2024.5.0->shared_utils) (2.49.0)
# Requirement already satisfied: google-auth-oauthlib in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from gcsfs==2024.5.0->shared_utils) (1.3.0)
# Requirement already satisfied: google-cloud-storage in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from gcsfs==2024.5.0->shared_utils) (3.9.0)
# Requirement already satisfied: requests in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from gcsfs==2024.5.0->shared_utils) (2.32.5)
# Requirement already satisfied: commonmark>=0.9.1 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from great-tables==0.20.0->shared_utils) (0.9.1)
# Requirement already satisfied: faicons>=0.2.2 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from great-tables==0.20.0->shared_utils) (0.2.2)
# Requirement already satisfied: htmltools>=0.4.1 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from great-tables==0.20.0->shared_utils) (0.6.0)
# Requirement already satisfied: importlib-metadata in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from great-tables==0.20.0->shared_utils) (8.7.1)
# Requirement already satisfied: Babel>=2.13.1 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from great-tables==0.20.0->shared_utils) (2.18.0)
# Requirement already satisfied: importlib-resources in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from great-tables==0.20.0->shared_utils) (6.5.2)
# Requirement already satisfied: svg-py>=1.6.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from gt-extras==0.0.8->shared_utils) (1.10.0)
# Requirement already satisfied: appdirs in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from intake==0.6.4->shared_utils) (1.4.4)
# Requirement already satisfied: entrypoints in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from intake==0.6.4->shared_utils) (0.4)
# Requirement already satisfied: geopandas in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from movingpandas==0.22.4->shared_utils) (0.14.4)
# Requirement already satisfied: geopy in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from movingpandas==0.22.4->shared_utils) (2.4.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from omegaconf==2.3.0->shared_utils) (4.9.3)
# Requirement already satisfied: jupyter-core in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from quarto==0.1.0->shared_utils) (5.9.1)
# Requirement already satisfied: nbformat in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from quarto==0.1.0->shared_utils) (5.10.4)
# Requirement already satisfied: nbclient in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from quarto==0.1.0->shared_utils) (0.10.4)
# Requirement already satisfied: ipykernel in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from quarto==0.1.0->shared_utils) (7.2.0)
# Requirement already satisfied: jupyter in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from quarto-cli==1.6.40->shared_utils) (1.1.1)
# Requirement already satisfied: wheel in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from quarto-cli==1.6.40->shared_utils) (0.46.3)
# Requirement already satisfied: ordered-set in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from stonesoup==1.8->shared_utils) (4.1.0)
# Requirement already satisfied: plotly>=5.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from stonesoup==1.8->shared_utils) (6.6.0)
# Requirement already satisfied: pymap3d in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from stonesoup==1.8->shared_utils) (3.2.0)
# Requirement already satisfied: rtree in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from stonesoup==1.8->shared_utils) (1.4.1)
# Requirement already satisfied: ruamel.yaml>=0.16.5 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from stonesoup==1.8->shared_utils) (0.19.1)
# Requirement already satisfied: utm in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from stonesoup==1.8->shared_utils) (0.8.1)
# Requirement already satisfied: click>=8.1 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from dask<2025.4.0,>=2024.10.0->shared_utils) (8.2.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from dask<2025.4.0,>=2024.10.0->shared_utils) (3.1.2)
# Requirement already satisfied: partd>=1.4.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from dask<2025.4.0,>=2024.10.0->shared_utils) (1.4.2)
# Requirement already satisfied: toolz>=0.10.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from dask<2025.4.0,>=2024.10.0->shared_utils) (1.1.0)
# Requirement already satisfied: shapely>=2.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from dask-geopandas>=0.5.0->shared_utils) (2.1.2)
# Requirement already satisfied: xyzservices in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from folium<0.21.0,>=0.20.0->shared_utils) (2025.11.0)
# Requirement already satisfied: networkx>=3.2 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from mapclassify<3,>=2.8.0->shared_utils) (3.6.1)
# Requirement already satisfied: scikit-learn>=1.4 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from mapclassify<3,>=2.8.0->shared_utils) (1.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.10.5->shared_utils) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.10.5->shared_utils) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.10.5->shared_utils) (4.62.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.10.5->shared_utils) (1.5.0)
# Requirement already satisfied: pillow>=8 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.10.5->shared_utils) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.10.5->shared_utils) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.10.5->shared_utils) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from numba<0.63.0,>=0.62.1->shared_utils) (0.45.1)
# Requirement already satisfied: et-xmlfile in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from openpyxl>=3.1.0->shared_utils) (2.0.0)
# Requirement already satisfied: text-unidecode>=1.3 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from python-slugify>=8.0.0->shared_utils) (1.3)
# Requirement already satisfied: ipython<9.0.0,>=8.9.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from calitp-data-analysis->shared_utils) (8.38.0)
# Requirement already satisfied: pandas-gbq>=0.23.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from calitp-data-analysis->shared_utils) (0.35.0)
# Requirement already satisfied: sqlalchemy-bigquery<2.0.0,>=1.6.1 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from calitp-data-analysis->shared_utils) (1.16.0)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from calitp-data-analysis->shared_utils) (2.0.48)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2024.5.0->shared_utils) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2024.5.0->shared_utils) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2024.5.0->shared_utils) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2024.5.0->shared_utils) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2024.5.0->shared_utils) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2024.5.0->shared_utils) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2024.5.0->shared_utils) (1.23.0)
# Requirement already satisfied: pyarrow>=14.0.1 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from dask[dataframe]>=2025.1.0->dask-geopandas>=0.5.0->shared_utils) (23.0.1)
# Requirement already satisfied: fiona>=1.8.21 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from geopandas->movingpandas==0.22.4->shared_utils) (1.10.1)
# Requirement already satisfied: pyproj>=3.3.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from geopandas->movingpandas==0.22.4->shared_utils) (3.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from google-auth>=1.2->gcsfs==2024.5.0->shared_utils) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from google-auth>=1.2->gcsfs==2024.5.0->shared_utils) (46.0.5)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from google-auth>=1.2->gcsfs==2024.5.0->shared_utils) (4.9.1)
# Requirement already satisfied: zipp>=3.20 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from importlib-metadata->great-tables==0.20.0->shared_utils) (3.23.0)
# Requirement already satisfied: jedi>=0.16 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from ipython<9.0.0,>=8.9.0->calitp-data-analysis->shared_utils) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from ipython<9.0.0,>=8.9.0->calitp-data-analysis->shared_utils) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from ipython<9.0.0,>=8.9.0->calitp-data-analysis->shared_utils) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from ipython<9.0.0,>=8.9.0->calitp-data-analysis->shared_utils) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from ipython<9.0.0,>=8.9.0->calitp-data-analysis->shared_utils) (2.19.2)
# Requirement already satisfied: stack_data in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from ipython<9.0.0,>=8.9.0->calitp-data-analysis->shared_utils) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from ipython<9.0.0,>=8.9.0->calitp-data-analysis->shared_utils) (5.14.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jinja2->altair==6.0.0->shared_utils) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jsonschema>=3.0->altair==6.0.0->shared_utils) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jsonschema>=3.0->altair==6.0.0->shared_utils) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jsonschema>=3.0->altair==6.0.0->shared_utils) (0.30.0)
# Requirement already satisfied: pytz>=2020.1 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from pandas->altair-transform==0.2.0->shared_utils) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from pandas->altair-transform==0.2.0->shared_utils) (2025.3)
# Requirement already satisfied: setuptools in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from pandas-gbq>=0.23.0->calitp-data-analysis->shared_utils) (82.0.1)
# Requirement already satisfied: db-dtypes<2.0.0,>=1.1.1 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from pandas-gbq>=0.23.0->calitp-data-analysis->shared_utils) (1.5.0)
# Requirement already satisfied: pydata-google-auth>=1.5.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from pandas-gbq>=0.23.0->calitp-data-analysis->shared_utils) (1.9.1)
# Requirement already satisfied: psutil>=5.9.8 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from pandas-gbq>=0.23.0->calitp-data-analysis->shared_utils) (7.2.2)
# Requirement already satisfied: google-api-core<3.0.0,>=2.15.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from pandas-gbq>=0.23.0->calitp-data-analysis->shared_utils) (2.30.0)
# Requirement already satisfied: google-cloud-bigquery<4.0.0,>=3.20.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from pandas-gbq>=0.23.0->calitp-data-analysis->shared_utils) (3.40.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from google-auth-oauthlib->gcsfs==2024.5.0->shared_utils) (2.0.0)
# Requirement already satisfied: locket in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from partd>=1.4.0->dask<2025.4.0,>=2024.10.0->shared_utils) (1.0.0)
# Requirement already satisfied: six>=1.5 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.10.5->shared_utils) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from requests->gcsfs==2024.5.0->shared_utils) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from requests->gcsfs==2024.5.0->shared_utils) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from requests->gcsfs==2024.5.0->shared_utils) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from requests->gcsfs==2024.5.0->shared_utils) (2026.2.25)
# Requirement already satisfied: joblib>=1.3.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from scikit-learn>=1.4->mapclassify<3,>=2.8.0->shared_utils) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from scikit-learn>=1.4->mapclassify<3,>=2.8.0->shared_utils) (3.6.0)
# Requirement already satisfied: greenlet>=1 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from sqlalchemy<3.0.0,>=2.0.0->calitp-data-analysis->shared_utils) (3.3.2)
# Requirement already satisfied: geographiclib<3,>=1.52 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from geopy->movingpandas==0.22.4->shared_utils) (2.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from google-cloud-storage->gcsfs==2024.5.0->shared_utils) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from google-cloud-storage->gcsfs==2024.5.0->shared_utils) (2.8.0)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from google-cloud-storage->gcsfs==2024.5.0->shared_utils) (1.8.0)
# Requirement already satisfied: comm>=0.1.1 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from ipykernel->quarto==0.1.0->shared_utils) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from ipykernel->quarto==0.1.0->shared_utils) (1.8.20)
# Requirement already satisfied: jupyter-client>=8.8.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from ipykernel->quarto==0.1.0->shared_utils) (8.8.0)
# Requirement already satisfied: nest-asyncio>=1.4 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from ipykernel->quarto==0.1.0->shared_utils) (1.6.0)
# Requirement already satisfied: pyzmq>=25 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from ipykernel->quarto==0.1.0->shared_utils) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from ipykernel->quarto==0.1.0->shared_utils) (6.5.5)
# Requirement already satisfied: platformdirs>=2.5 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jupyter-core->quarto==0.1.0->shared_utils) (4.9.4)
# Requirement already satisfied: notebook in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jupyter->quarto-cli==1.6.40->shared_utils) (7.5.4)
# Requirement already satisfied: jupyter-console in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jupyter->quarto-cli==1.6.40->shared_utils) (6.6.3)
# Requirement already satisfied: nbconvert in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jupyter->quarto-cli==1.6.40->shared_utils) (7.17.0)
# Requirement already satisfied: ipywidgets in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jupyter->quarto-cli==1.6.40->shared_utils) (8.1.8)
# Requirement already satisfied: jupyterlab in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jupyter->quarto-cli==1.6.40->shared_utils) (4.5.5)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from nbformat->quarto==0.1.0->shared_utils) (2.21.2)
# Requirement already satisfied: cffi>=2.0.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from cryptography>=38.0.3->google-auth>=1.2->gcsfs==2024.5.0->shared_utils) (2.0.0)
# Requirement already satisfied: click-plugins>=1.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas->movingpandas==0.22.4->shared_utils) (1.1.1.2)
# Requirement already satisfied: cligj>=0.5 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas->movingpandas==0.22.4->shared_utils) (0.7.2)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.3 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from google-api-core<3.0.0,>=2.15.0->pandas-gbq>=0.23.0->calitp-data-analysis->shared_utils) (1.73.0)
# Requirement already satisfied: protobuf<7.0.0,>=4.25.8 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from google-api-core<3.0.0,>=2.15.0->pandas-gbq>=0.23.0->calitp-data-analysis->shared_utils) (6.33.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from google-api-core<3.0.0,>=2.15.0->pandas-gbq>=0.23.0->calitp-data-analysis->shared_utils) (1.27.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jedi>=0.16->ipython<9.0.0,>=8.9.0->calitp-data-analysis->shared_utils) (0.8.6)
# Requirement already satisfied: ptyprocess>=0.5 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from pexpect>4.3->ipython<9.0.0,>=8.9.0->calitp-data-analysis->shared_utils) (0.7.0)
# Requirement already satisfied: wcwidth in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython<9.0.0,>=8.9.0->calitp-data-analysis->shared_utils) (0.6.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs==2024.5.0->shared_utils) (0.6.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs==2024.5.0->shared_utils) (3.3.1)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from ipywidgets->jupyter->quarto-cli==1.6.40->shared_utils) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from ipywidgets->jupyter->quarto-cli==1.6.40->shared_utils) (3.0.16)
# Requirement already satisfied: async-lru>=1.0.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jupyterlab->jupyter->quarto-cli==1.6.40->shared_utils) (2.2.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jupyterlab->jupyter->quarto-cli==1.6.40->shared_utils) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jupyterlab->jupyter->quarto-cli==1.6.40->shared_utils) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jupyterlab->jupyter->quarto-cli==1.6.40->shared_utils) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jupyterlab->jupyter->quarto-cli==1.6.40->shared_utils) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jupyterlab->jupyter->quarto-cli==1.6.40->shared_utils) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from nbconvert->jupyter->quarto-cli==1.6.40->shared_utils) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->quarto-cli==1.6.40->shared_utils) (6.3.0)
# Requirement already satisfied: defusedxml in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from nbconvert->jupyter->quarto-cli==1.6.40->shared_utils) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from nbconvert->jupyter->quarto-cli==1.6.40->shared_utils) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from nbconvert->jupyter->quarto-cli==1.6.40->shared_utils) (3.2.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from nbconvert->jupyter->quarto-cli==1.6.40->shared_utils) (1.5.1)
# Requirement already satisfied: executing>=1.2.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from stack_data->ipython<9.0.0,>=8.9.0->calitp-data-analysis->shared_utils) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from stack_data->ipython<9.0.0,>=8.9.0->calitp-data-analysis->shared_utils) (3.0.1)
# Requirement already satisfied: pure-eval in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from stack_data->ipython<9.0.0,>=8.9.0->calitp-data-analysis->shared_utils) (0.2.3)
# Requirement already satisfied: webencodings in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->quarto-cli==1.6.40->shared_utils) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->quarto-cli==1.6.40->shared_utils) (1.4.0)
# Requirement already satisfied: pycparser in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth>=1.2->gcsfs==2024.5.0->shared_utils) (3.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery<4.0.0,>=3.20.0->pandas-gbq>=0.23.0->calitp-data-analysis->shared_utils) (1.78.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery<4.0.0,>=3.20.0->pandas-gbq>=0.23.0->calitp-data-analysis->shared_utils) (1.78.0)
# Requirement already satisfied: anyio in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->quarto-cli==1.6.40->shared_utils) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->quarto-cli==1.6.40->shared_utils) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter->quarto-cli==1.6.40->shared_utils) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli==1.6.40->shared_utils) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli==1.6.40->shared_utils) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli==1.6.40->shared_utils) (0.5.4)
# Requirement already satisfied: overrides>=5.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli==1.6.40->shared_utils) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli==1.6.40->shared_utils) (0.24.1)
# Requirement already satisfied: send2trash>=1.8.2 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli==1.6.40->shared_utils) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli==1.6.40->shared_utils) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli==1.6.40->shared_utils) (1.9.0)
# Requirement already satisfied: json5>=0.9.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->quarto-cli==1.6.40->shared_utils) (0.13.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from beautifulsoup4->nbconvert->jupyter->quarto-cli==1.6.40->shared_utils) (2.8.3)
# Requirement already satisfied: argon2-cffi-bindings in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli==1.6.40->shared_utils) (25.1.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli==1.6.40->shared_utils) (4.0.0)
# Requirement already satisfied: rfc3339-validator in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli==1.6.40->shared_utils) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli==1.6.40->shared_utils) (0.1.1)
# Requirement already satisfied: fqdn in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli==1.6.40->shared_utils) (1.5.1)
# Requirement already satisfied: isoduration in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli==1.6.40->shared_utils) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli==1.6.40->shared_utils) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli==1.6.40->shared_utils) (1.1.0)
# Requirement already satisfied: uri-template in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli==1.6.40->shared_utils) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli==1.6.40->shared_utils) (25.10.0)
# Requirement already satisfied: lark>=1.2.2 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli==1.6.40->shared_utils) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli==1.6.40->shared_utils) (1.4.0)
#
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install rapidfuzz
# Out:
# Requirement already satisfied: rapidfuzz in /home/jovyan/data-analyses/.venv/lib/python3.11/site-packages (3.14.5)
#
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importing necessary package 
import pandas as pd 
import geopandas as gpd
import google.auth
import os
import gcsfs
import requests
import fsspec
from rapidfuzz import process, fuzz
import re
from calitp_data_analysis.sql import get_engine
db_engine = get_engine()
credentials, project = google.auth.default()
fs = gcsfs.GCSFileSystem()
from segment_speed_utils.project_vars import PUBLIC_GCS
from pandas import ExcelWriter

pd.set_option('display.max_columns', None)

# %%
GCS_FILE_PATH  = 'gs://calitp-analytics-data/data-analyses'

# %%
# Load the stored ACS dataset from the specified GCS file path.
with fs.open(f"{GCS_FILE_PATH}/transit_provider_dashboard/census_tracts_data_2024.parquet", "rb") as f:
    tracts_ca_acs = gpd.read_parquet(f)

# %%
# Load the stored organization dataset from the specified GCS file path.
with fs.open(f"{GCS_FILE_PATH}/transit_provider_dashboard/organization_data_2025_10_16.parquet", "rb") as f:
    valid_organization_full = pd.read_parquet(f)

# %%
with fs.open(f"{GCS_FILE_PATH}/transit_provider_dashboard/ridership_data_2024.parquet", "rb") as f:
    ridership_data_grouped = pd.read_parquet(f)

# %%
with fs.open(f"{GCS_FILE_PATH}/transit_provider_dashboard/stop_data_cleaned.parquet", "rb") as f:
    orgs_stops_clean = gpd.read_parquet(f)

# %%
with fs.open(f"{GCS_FILE_PATH}/transit_provider_dashboard/census_ca_data_2024.parquet", "rb") as f:
    ca_totals_acs = gpd.read_parquet(f)

# %% [markdown]
# ## Spatial Analysis: Stop Buffers and Census Tract Intersections

# %%
sac_unique_rows = (
    orgs_stops_clean[
        orgs_stops_clean['rtpa_name'].str.contains('sac', case=False, na=False)
    ]
    .drop_duplicates(subset=['rtpa_name'])
)

sac_unique_rows
# Out:
#                 name stop_id                          stop_key stop_code  \
# 4  Unitrans Schedule   22045  a512ff742babcf71a49dfdb44b2b6aab     22045
#
#                           stop_name  location_type  \
# 4  Cowell Blvd & Halsey Circle (WB)            NaN
#
#                       geometry                organization_name  \
# 4  POINT (-121.72253 38.54324)  University of California, Davis
#
#   organization_source_record_id schedule_source_record_id  \
# 4             recS1JKEz73Hev8pJ         recpwl8uJU04SPbWS
#
#   schedule_gtfs_dataset_name                    analysis_name  \
# 4          Unitrans Schedule  University of California, Davis
#
#   regional_feed_type county_name  caltrans_district   caltrans_district_name  \
# 4               None        Yolo                3.0  Marysville / Sacramento
#
#           caltrans_district_full ntd_id ntd_id_2022  \
# 4   03 - Marysville / Sacramento  90142       90142
#
#                                 rtpa_name  \
# 4  Sacramento Area Council of Governments
#
#                                  mpo_name
# 4  Sacramento Area Council of Governments

# %%
orgs_stops_clean.head(5)
# Out:
#                                      name  stop_id  \
# 0         TART, North Lake Tahoe Schedule     2462
# 1                         B-Line Schedule      485
# 2                   North County Schedule    20540
# 3  Tahoe Transportation District Schedule  6732397
# 4                       Unitrans Schedule    22045
#
#                            stop_key stop_code  \
# 0  4aba9cdb71ee191fea9935a150d75cfa      None
# 1  5bb70e07bb93d12d20bd2781af4ef37d       485
# 2  21e6ba2ea9cc6d5758ad3e08b5fa6941     20540
# 3  9b9a9ea90cb9cb97ee3ac3c5d663521f      2036
# 4  a512ff742babcf71a49dfdb44b2b6aab     22045
#
#                           stop_name  location_type  \
# 0                   Everline Resort            0.0
# 1        Lincoln Blvd & Virginia St            0.0
# 2        Mission Av & Clementine St            0.0
# 3        US 50/Truckee Dr (Motel 6)            0.0
# 4  Cowell Blvd & Halsey Circle (WB)            NaN
#
#                       geometry                        organization_name  \
# 0  POINT (-120.21773 39.19920)                 North Lake Tahoe Express
# 1  POINT (-121.55045 39.48217)  Butte County Association of Governments
# 2  POINT (-117.37635 33.19790)            North County Transit District
# 3  POINT (-119.99161 38.92194)            Tahoe Transportation District
# 4  POINT (-121.72253 38.54324)          University of California, Davis
#
#   organization_source_record_id schedule_source_record_id  \
# 0             reckjhbXRQIr4k50W         rectpGbo8b7ThDd5h
# 1             recf7l9tozKXOmqqZ         recm6LcXTquVutuAW
# 2             recRBcrX4ZvTyvSnm         recltDJn10nOSilgD
# 3             rec3u4aMplqObcoTR         recgyP2nm59f3KKXo
# 4             recS1JKEz73Hev8pJ         recpwl8uJU04SPbWS
#
#                schedule_gtfs_dataset_name  \
# 0         TART, North Lake Tahoe Schedule
# 1                         B-Line Schedule
# 2                   North County Schedule
# 3  Tahoe Transportation District Schedule
# 4                       Unitrans Schedule
#
#                                        analysis_name regional_feed_type  \
# 0  Tahoe Truckee Area Regional Transportation, No...               None
# 1            Butte County Association of Governments               None
# 2                      North County Transit District               None
# 3                      Tahoe Transportation District               None
# 4                    University of California, Davis               None
#
#   county_name  caltrans_district   caltrans_district_name  \
# 0   El Dorado                3.0  Marysville / Sacramento
# 1       Butte                3.0  Marysville / Sacramento
# 2   San Diego               11.0                San Diego
# 3   El Dorado                3.0  Marysville / Sacramento
# 4        Yolo                3.0  Marysville / Sacramento
#
#           caltrans_district_full ntd_id ntd_id_2022  \
# 0   03 - Marysville / Sacramento   None        None
# 1   03 - Marysville / Sacramento  90208       90208
# 2                 11 - San Diego  90030       90030
# 3   03 - Marysville / Sacramento  91092       91092
# 4   03 - Marysville / Sacramento  90142       90142
#
#                                  rtpa_name  \
# 0                                     None
# 1  Butte County Association of Governments
# 2     San Diego Association of Governments
# 3           Tahoe Regional Planning Agency
# 4   Sacramento Area Council of Governments
#
#                                   mpo_name
# 0                                     None
# 1  Butte County Association of Governments
# 2     San Diego Association of Governments
# 3           Tahoe Regional Planning Agency
# 4   Sacramento Area Council of Governments

# %%
columns_to_keep = [
    "name", "ntd_id", "ntd_id_2022", "stop_id", "stop_name", 
    "schedule_gtfs_dataset_name", "organization_source_record_id", 
    "geometry", "analysis_name", "organization_name"
]

stops_clean_subset = orgs_stops_clean[columns_to_keep].copy()

# %%
# Clean names to remove noise words
remove_words = ['Schedule', 'GMV', 'TripShot', 'Remix', 'v2', 'Historic', 'Cal-ITP', 'RTAP']

def clean_name(name):
    for w in remove_words:
        name = re.sub(rf'\b{w}\b', '', name, flags=re.IGNORECASE)
    name = re.sub(r'\s+', ' ', name).strip()
    return name

# %%
# Add cleaned columns
stops_clean_subset['name_clean'] = stops_clean_subset['name'].apply(clean_name)
valid_organization_full['name_clean'] = valid_organization_full['name'].apply(clean_name)

# %%
# Fill missing organization_source_record_id using fuzzy match on cleaned names
missing_org_idx = stops_clean_subset['organization_source_record_id'].isna()
missing_stops = stops_clean_subset[missing_org_idx].copy()

valid_names_clean = valid_organization_full['name_clean'].tolist()

def fuzzy_match_org(name, valid_names, threshold=90):
    match = process.extractOne(name, valid_names, scorer=fuzz.WRatio)

    if match and match[1] >= threshold:
        matched_name_clean = match[0]

        idx = valid_organization_full.index[
            valid_organization_full["name_clean"] == matched_name_clean
        ][0]

        return (
            valid_organization_full.loc[idx, "source_record_id"],
            valid_organization_full.loc[idx, "name"],
            match[1]   # score (IMPORTANT for debugging)
        )

    return None, None, None

# %%
matches = stops_clean_subset.loc[missing_org_idx, "name_clean"].apply(
    lambda x: fuzzy_match_org(x, valid_names_clean)
)

stops_clean_subset.loc[missing_org_idx, "organization_source_record_id"] = [m[0] for m in matches]
stops_clean_subset.loc[missing_org_idx, "organization_name"] = [m[1] for m in matches]

# %%
stops_clean_subset.loc[missing_org_idx, "analysis_name"] = stops_clean_subset.loc[
    missing_org_idx, "organization_name"
]

# %%
# # Apply fuzzy match
# filled_matches = missing_stops['name_clean'].apply(lambda x: fuzzy_match_org(x, valid_names_clean))
# missing_stops['organization_source_record_id'], missing_stops['organization_name'] = zip(*filled_matches)

# %%
# Combine back with rows that already had source_record_id
stops_filled = pd.concat([
    stops_clean_subset[~missing_org_idx],
    missing_stops
], ignore_index=True)

# %%
# Merge with valid_organization_full to pull additional columns
orgs_stops_merged = stops_filled.merge(
    valid_organization_full[['source_record_id', 'key', 'organization_type', 'ntd_id', 'ntd_id_2022']],
    left_on="organization_source_record_id",
    right_on="source_record_id",
    how="left"
)

# %%
orgs_stops_merged.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 112781 entries, 0 to 112780
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   name                           112781 non-null  object
#  1   ntd_id_x                       84251 non-null   object
#  2   ntd_id_2022_x                  84509 non-null   object
#  3   stop_id                        112781 non-null  object
#  4   stop_name                      112781 non-null  object
#  5   schedule_gtfs_dataset_name     95513 non-null   object
#  6   organization_source_record_id  95513 non-null   object
#  7   geometry                       112781 non-null  geometry
#  8   analysis_name                  95513 non-null   object
#  9   organization_name              95513 non-null   object
#  10  name_clean                     112781 non-null  object
#  11  source_record_id               85103 non-null   object
#  12  key                            85103 non-null   object
#  13  organization_type              85103 non-null   object
#  14  ntd_id_y                       80602 non-null   object
#  15  ntd_id_2022_y                  80707 non-null   object
# dtypes: geometry(1), object(15)
# memory usage: 13.8+ MB

# %%
orgs_stops_merged.head(5)
# Out:
#                                      name ntd_id_x ntd_id_2022_x  stop_id  \
# 0         TART, North Lake Tahoe Schedule     None          None     2462
# 1                         B-Line Schedule    90208         90208      485
# 2                   North County Schedule    90030         90030    20540
# 3  Tahoe Transportation District Schedule    91092         91092  6732397
# 4                       Unitrans Schedule    90142         90142    22045
#
#                           stop_name              schedule_gtfs_dataset_name  \
# 0                   Everline Resort         TART, North Lake Tahoe Schedule
# 1        Lincoln Blvd & Virginia St                         B-Line Schedule
# 2        Mission Av & Clementine St                   North County Schedule
# 3        US 50/Truckee Dr (Motel 6)  Tahoe Transportation District Schedule
# 4  Cowell Blvd & Halsey Circle (WB)                       Unitrans Schedule
#
#   organization_source_record_id                     geometry  \
# 0             reckjhbXRQIr4k50W  POINT (-120.21773 39.19920)
# 1             recf7l9tozKXOmqqZ  POINT (-121.55045 39.48217)
# 2             recRBcrX4ZvTyvSnm  POINT (-117.37635 33.19790)
# 3             rec3u4aMplqObcoTR  POINT (-119.99161 38.92194)
# 4             recS1JKEz73Hev8pJ  POINT (-121.72253 38.54324)
#
#                                        analysis_name  \
# 0  Tahoe Truckee Area Regional Transportation, No...
# 1            Butte County Association of Governments
# 2                      North County Transit District
# 3                      Tahoe Transportation District
# 4                    University of California, Davis
#
#                          organization_name                     name_clean  \
# 0                 North Lake Tahoe Express         TART, North Lake Tahoe
# 1  Butte County Association of Governments                         B-Line
# 2            North County Transit District                   North County
# 3            Tahoe Transportation District  Tahoe Transportation District
# 4          University of California, Davis                       Unitrans
#
#     source_record_id                               key    organization_type  \
# 0                NaN                               NaN                  NaN
# 1  recf7l9tozKXOmqqZ  8ba736645cf9016bd129181068a9bc7b             MPO/RTPA
# 2  recRBcrX4ZvTyvSnm  4294d8b64a24b7f0ce0d82863191fa00   Independent Agency
# 3  rec3u4aMplqObcoTR  bf1dc4f532561452972eacf15648469c   Independent Agency
# 4  recS1JKEz73Hev8pJ  2187e3477518a6f92b2fcbc1c3c3d077  University - Public
#
#   ntd_id_y ntd_id_2022_y
# 0      NaN           NaN
# 1    90208         90208
# 2    90030         90030
# 3    91092         91092
# 4    90142         90142

# %%
# Rows that were filled by fuzzy match
filled_rows = missing_stops[missing_stops['organization_source_record_id'].notna()].copy()

# Show unique combinations of schedule name, organization name, and source_record_id
filled_unique = filled_rows[['name', 'organization_name', 'organization_source_record_id', 'analysis_name']].drop_duplicates()

# Sort by schedule name for readability
filled_unique = filled_unique.sort_values('name').reset_index(drop=True)

# Summary
print(f"Total unique names filled by fuzzy match: {filled_unique['name'].nunique()}")

# Display the table
filled_unique
# Out:
# Total unique names filled by fuzzy match: 0
# Empty DataFrame
# Columns: [name, organization_name, organization_source_record_id, analysis_name]
# Index: []

# %%
# Find rows where organization_source_record_id is still missing
still_missing = orgs_stops_merged[orgs_stops_merged['organization_source_record_id'].isna()]

# Get unique names
unique_missing_names = still_missing['name'].unique()

print(f"Total unique names still missing: {len(unique_missing_names)}")
print(unique_missing_names)
# Out:
# Total unique names still missing: 37
# ['Rosemead Passio Schedule' 'Gold Coast Schedule' 'Marin Optibus Schedule'
#  'Dana Point Trolley Schedule' 'Cerritos on Wheels Website Schedule'
#  'Vine Schedule' 'Sonoma County Transit Schedule' 'Trinity Remix Schedule'
#  'Simi Valley Schedule' 'Nevada County Schedule'
#  'Golden Gate Bridge Schedule' 'VCTC Schedule' 'BART Schedule'
#  'Thousand Oaks Schedule' 'Yuba-Sutter PassioGo Schedule'
#  'Clovis PassioGo Schedule' 'Beaumont Pass Schedule'
#  'Peppedine University Shuttles Schedule' 'Anaheim Resort Schedule'
#  'CSULB Shuttle PassioGo Schedule' 'Trinity Schedule'
#  'Dana Point Trolley PassioGo Schedule' 'Ridgecrest Schedule'
#  'Fric and Frac Schedule' 'Moorpark Schedule' 'Morro Bay Cal-ITP Schedule'
#  'LAX Shuttles Schedule' 'Guadalupe Flyer Schedule'
#  'University of San Diego Tram Services Schedule' 'Laguna Niguel Schedule'
#  'LAX FlyAway Schedule' 'Bellflower Bus Schedule' 'Auburn Schedule'
#  'Bulldog Express PassioGo Schedule' 'Bay Area 511 Regional Schedule'
#  'Sonoma Schedule' 'Bay Area 511 Emery Express Schedule']

# %%
# Manual mapping for remaining unmatched
manual_matches = {
    "BART Schedule": "San Francisco Bay Area Rapid Transit District",
    "Vine Schedule": "Napa Valley Transportation Authority",
    "VCTC Schedule": "Ventura County Transportation Commission",
}

# Loop over manual matches and update orgs_stops_merged
for gtfs_name, org_name in manual_matches.items():
    # Get valid_organization_full row
    org_row = valid_organization_full[valid_organization_full['name'] == org_name]
    
    if not org_row.empty:
        source_id = org_row['source_record_id'].values[0]
        key = org_row['key'].values[0]
        org_type = org_row['organization_type'].values[0]
        
        # Update orgs_stops_merged where the GTFS name matches
        mask = orgs_stops_merged['name'] == gtfs_name
        orgs_stops_merged.loc[mask, 'organization_source_record_id'] = source_id
        orgs_stops_merged.loc[mask, 'organization_name'] = org_name
        orgs_stops_merged.loc[mask, 'key'] = key
        orgs_stops_merged.loc[mask, 'organization_type'] = org_type

# %%
orgs_stops_merged.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 112781 entries, 0 to 112780
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   name                           112781 non-null  object
#  1   ntd_id_x                       84251 non-null   object
#  2   ntd_id_2022_x                  84509 non-null   object
#  3   stop_id                        112781 non-null  object
#  4   stop_name                      112781 non-null  object
#  5   schedule_gtfs_dataset_name     95513 non-null   object
#  6   organization_source_record_id  95919 non-null   object
#  7   geometry                       112781 non-null  geometry
#  8   analysis_name                  95513 non-null   object
#  9   organization_name              95919 non-null   object
#  10  name_clean                     112781 non-null  object
#  11  source_record_id               85103 non-null   object
#  12  key                            85509 non-null   object
#  13  organization_type              85509 non-null   object
#  14  ntd_id_y                       80602 non-null   object
#  15  ntd_id_2022_y                  80707 non-null   object
# dtypes: geometry(1), object(15)
# memory usage: 13.8+ MB

# %%
orgs_stops_merged.name.nunique()
# Out:
# 229

# %%
combined_names_dict = {
    "Sacramento Regional Transit District": "Sacramento Schedule",
    "City of Rancho Cordova": "Sacramento Schedule",
    "San Diego Metropolitan Transit System": "San Diego Schedule",
    "Flagship Cruises and Events Inc.": "San Diego Schedule",
    "San Diego International Airport": "San Diego Schedule",
    "City of Arcata": "Humboldt Schedule",
    "City of Eureka": "Humboldt Schedule",
    "San Francisco Bay Area Water Emergency Transit Authority": "San Francisco Bay Ferry and Oakland Alameda Water Shuttle Schedule",
    "City of Alameda": "San Francisco Bay Ferry and Oakland Alameda Water Shuttle Schedule",
}

# %%
orgs_stops_merged['name'] = (
    orgs_stops_merged['organization_name']
    .map(combined_names_dict)
    .fillna(orgs_stops_merged['name'])
)

# %%
# Reproject to match census tracts CRS
orgs_stops_merged = orgs_stops_merged.to_crs(tracts_ca_acs.crs)

# %%
orgs_stop_buffered = orgs_stops_merged.copy()
orgs_stop_buffered["geometry"] = orgs_stop_buffered.geometry.buffer(804.672)

# %%
orgs_stop_dissolved = orgs_stop_buffered.dissolve(by='name')

# %%
orgs_stop_buffered.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 112781 entries, 0 to 112780
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   name                           112781 non-null  object
#  1   ntd_id_x                       84251 non-null   object
#  2   ntd_id_2022_x                  84509 non-null   object
#  3   stop_id                        112781 non-null  object
#  4   stop_name                      112781 non-null  object
#  5   schedule_gtfs_dataset_name     95513 non-null   object
#  6   organization_source_record_id  95919 non-null   object
#  7   geometry                       112781 non-null  geometry
#  8   analysis_name                  95513 non-null   object
#  9   organization_name              95919 non-null   object
#  10  name_clean                     112781 non-null  object
#  11  source_record_id               85103 non-null   object
#  12  key                            85509 non-null   object
#  13  organization_type              85509 non-null   object
#  14  ntd_id_y                       80602 non-null   object
#  15  ntd_id_2022_y                  80707 non-null   object
# dtypes: geometry(1), object(15)
# memory usage: 13.8+ MB

# %%
orgs_stop_dissolved = orgs_stop_dissolved.reset_index()

# %%
orgs_stop_dissolved.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 228 entries, 0 to 227
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   name                           228 non-null    object
#  1   geometry                       228 non-null    geometry
#  2   ntd_id_x                       150 non-null    object
#  3   ntd_id_2022_x                  153 non-null    object
#  4   stop_id                        228 non-null    object
#  5   stop_name                      228 non-null    object
#  6   schedule_gtfs_dataset_name     191 non-null    object
#  7   organization_source_record_id  194 non-null    object
#  8   analysis_name                  191 non-null    object
#  9   organization_name              194 non-null    object
#  10  name_clean                     228 non-null    object
#  11  source_record_id               154 non-null    object
#  12  key                            157 non-null    object
#  13  organization_type              157 non-null    object
#  14  ntd_id_y                       132 non-null    object
#  15  ntd_id_2022_y                  134 non-null    object
# dtypes: geometry(1), object(15)
# memory usage: 28.6+ KB

# %%
orgs_stop_dissolved.head(5)
# Out:
#                                          name  \
# 0                           Alhambra Schedule
# 1                             Amador Schedule
# 2                             Amtrak Schedule
# 3                     Anaheim Resort Schedule
# 4  Antelope Valley Transit Authority Schedule
#
#                                             geometry    ntd_id_x  \
# 0  POLYGON ((169677.509 -438033.424, 169624.478 -...       90247
# 1  MULTIPOLYGON (((-79576.548 30778.572, -79623.5...  9R02-91000
# 2  MULTIPOLYGON (((-170145.246 -163121.073, -1702...        None
# 3  MULTIPOLYGON (((192208.082 -466785.206, 192161...        None
# 4  MULTIPOLYGON (((143232.265 -439728.624, 143168...       90121
#
#   ntd_id_2022_x  stop_id                           stop_name  \
# 0         90247  2619820           Commonwealth Ave & 4th St
# 1         91000    27811  Hwy 124 (S. Church St.) & Main St.
# 2          None      KEE              Kewanee Amtrak Station
# 3          None     5016        Courtyard Anaheim Theme Park
# 4         90121     1234              60th St. W. & Ave. K-9
#
#                    schedule_gtfs_dataset_name organization_source_record_id  \
# 0                           Alhambra Schedule             recNaKvzVQhGX1puu
# 1                             Amador Schedule             recSBFiK95hJnJuYx
# 2                             Amtrak Schedule             recKsb5FnJy70up78
# 3                                        None                          None
# 4  Antelope Valley Transit Authority Schedule             recxsWR0KRrQTdjmg
#
#                        analysis_name                  organization_name  \
# 0                   City of Alhambra                   City of Alhambra
# 1     Amador Regional Transit System     Amador Regional Transit System
# 2                             Amtrak                             Amtrak
# 3                               None                               None
# 4  Antelope Valley Transit Authority  Antelope Valley Transit Authority
#
#                           name_clean   source_record_id  \
# 0                           Alhambra  recNaKvzVQhGX1puu
# 1                             Amador  recSBFiK95hJnJuYx
# 2                             Amtrak  recKsb5FnJy70up78
# 3                     Anaheim Resort               None
# 4  Antelope Valley Transit Authority  recxsWR0KRrQTdjmg
#
#                                 key   organization_type    ntd_id_y  \
# 0  897ce086b03388bc914f5c239298fb85           City/Town       90247
# 1  71b58e792726688aef31d4712480d350  Independent Agency  9R02-91000
# 2  7225e6e33a67f74bc42fe137d9f9be23  Federal Government        None
# 3                              None                None        None
# 4  86e23a9a896696a1d14e026b3f17843b  Independent Agency       90121
#
#   ntd_id_2022_y
# 0         90247
# 1         91000
# 2          None
# 3          None
# 4         90121

# %%
# Compute the intersection between buffered stops and census tracts.
geometry_intersect = gpd.overlay(
    orgs_stop_dissolved, 
    tracts_ca_acs, 
    how = 'intersection', 
    keep_geom_type=True)

# %%
# Calculate the area of each intersected geometry in square meters.
geometry_intersect['area_2'] = geometry_intersect.geometry.area

# %%
geometry_intersect.head(2)
# Out:
#                 name ntd_id_x ntd_id_2022_x  stop_id  \
# 0  Alhambra Schedule    90247         90247  2619820
# 1  Alhambra Schedule    90247         90247  2619820
#
#                    stop_name schedule_gtfs_dataset_name  \
# 0  Commonwealth Ave & 4th St          Alhambra Schedule
# 1  Commonwealth Ave & 4th St          Alhambra Schedule
#
#   organization_source_record_id     analysis_name organization_name  \
# 0             recNaKvzVQhGX1puu  City of Alhambra  City of Alhambra
# 1             recNaKvzVQhGX1puu  City of Alhambra  City of Alhambra
#
#   name_clean   source_record_id                               key  \
# 0   Alhambra  recNaKvzVQhGX1puu  897ce086b03388bc914f5c239298fb85
# 1   Alhambra  recNaKvzVQhGX1puu  897ce086b03388bc914f5c239298fb85
#
#   organization_type ntd_id_y ntd_id_2022_y STATEFP COUNTYFP TRACTCE  \
# 0         City/Town    90247         90247      06      037  481103
# 1         City/Town    90247         90247      06      037  482301
#
#                 GEOIDFQ        GEOID     NAME              NAMELSAD STUSPS  \
# 0  1400000US06037481103  06037481103  4811.03  Census Tract 4811.03     CA
# 1  1400000US06037482301  06037482301  4823.01  Census Tract 4823.01     CA
#
#            NAMELSADCO  STATE_NAME LSAD    ALAND  AWATER  total_pop  \
# 0  Los Angeles County  California   CT  1413607       0       5489
# 1  Los Angeles County  California   CT   873603       0       4974
#
#    poverty_pop  non_us_citizen  male_65_to_66  male_67_to_69  male_70_to_74  \
# 0          779             921             23             46             69
# 1          698            1085             80            123             11
#
#    male_75_to_79  male_80_to_84  male_85_and_over  female_65_to_66  \
# 0             33            115                65               67
# 1             71             15                37               36
#
#    female_67_to_69  female_70_to_74  female_75_to_79  female_80_to_84  \
# 0               62               59               86               97
# 1              106               85               24               86
#
#    female_85_and_over  male_15_17  male_18_19  male_20  male_21  male_22_24  \
# 0                 221         165           8       12        9          48
# 1                 200         151          72       11       49          92
#
#    female_15_17  female_18_19  female_20  female_21  female_22_24  \
# 0            73           126         16          0            85
# 1           118            23          0         19            50
#
#    median_household_income  income_less_10000  income_10000_14999  \
# 0                    77565                523                 395
# 1                    85720                474                 701
#
#    income_15000_24999  income_25000_34999  income_35000_49999  \
# 0                 653                 486                 740
# 1                 649                 461                 292
#
#    income_50000_64999  income_65000_74999  workers_with_no_car  \
# 0                 424                 178                  126
# 1                 279                 170                   55
#
#    households_with_no_cars  public_asst_pop  veteran_pop  county_name  \
# 0                      185              123           66  Los Angeles
# 1                      134              332          119  Los Angeles
#
#    inc_extremelylow  inc_verylow  inc_low  male_seniors  female_seniors  \
# 0              1571         1226      602           351             592
# 1              1824          753      449           337             537
#
#    male_youth  female_youth  disabled_pop       area_m2  \
# 0         242           300           618  1.406019e+06
# 1         375           210           445  8.743129e+05
#
#                                             geometry         area_2
# 0  POLYGON ((174546.535 -434262.136, 174543.285 -...      23.630888
# 1  POLYGON ((175016.153 -436000.911, 174975.556 -...  122884.944234

# %%
geometry_intersect.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 22063 entries, 0 to 22062
# Data columns (total 77 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   name                           22063 non-null  object
#  1   ntd_id_x                       15453 non-null  object
#  2   ntd_id_2022_x                  15556 non-null  object
#  3   stop_id                        22063 non-null  object
#  4   stop_name                      22063 non-null  object
#  5   schedule_gtfs_dataset_name     18728 non-null  object
#  6   organization_source_record_id  19238 non-null  object
#  7   analysis_name                  18728 non-null  object
#  8   organization_name              19238 non-null  object
#  9   name_clean                     22063 non-null  object
#  10  source_record_id               17014 non-null  object
#  11  key                            17524 non-null  object
#  12  organization_type              17524 non-null  object
#  13  ntd_id_y                       14730 non-null  object
#  14  ntd_id_2022_y                  14796 non-null  object
#  15  STATEFP                        22063 non-null  object
#  16  COUNTYFP                       22063 non-null  object
#  17  TRACTCE                        22063 non-null  object
#  18  GEOIDFQ                        22063 non-null  object
#  19  GEOID                          22063 non-null  object
#  20  NAME                           22063 non-null  object
#  21  NAMELSAD                       22063 non-null  object
#  22  STUSPS                         22063 non-null  object
#  23  NAMELSADCO                     22063 non-null  object
#  24  STATE_NAME                     22063 non-null  object
#  25  LSAD                           22063 non-null  object
#  26  ALAND                          22063 non-null  int64
#  27  AWATER                         22063 non-null  int64
#  28  total_pop                      22063 non-null  int64
#  29  poverty_pop                    22063 non-null  int64
#  30  non_us_citizen                 22063 non-null  int64
#  31  male_65_to_66                  22063 non-null  int64
#  32  male_67_to_69                  22063 non-null  int64
#  33  male_70_to_74                  22063 non-null  int64
#  34  male_75_to_79                  22063 non-null  int64
#  35  male_80_to_84                  22063 non-null  int64
#  36  male_85_and_over               22063 non-null  int64
#  37  female_65_to_66                22063 non-null  int64
#  38  female_67_to_69                22063 non-null  int64
#  39  female_70_to_74                22063 non-null  int64
#  40  female_75_to_79                22063 non-null  int64
#  41  female_80_to_84                22063 non-null  int64
#  42  female_85_and_over             22063 non-null  int64
#  43  male_15_17                     22063 non-null  int64
#  44  male_18_19                     22063 non-null  int64
#  45  male_20                        22063 non-null  int64
#  46  male_21                        22063 non-null  int64
#  47  male_22_24                     22063 non-null  int64
#  48  female_15_17                   22063 non-null  int64
#  49  female_18_19                   22063 non-null  int64
#  50  female_20                      22063 non-null  int64
#  51  female_21                      22063 non-null  int64
#  52  female_22_24                   22063 non-null  int64
#  53  median_household_income        22063 non-null  int64
#  54  income_less_10000              22063 non-null  int64
#  55  income_10000_14999             22063 non-null  int64
#  56  income_15000_24999             22063 non-null  int64
#  57  income_25000_34999             22063 non-null  int64
#  58  income_35000_49999             22063 non-null  int64
#  59  income_50000_64999             22063 non-null  int64
#  60  income_65000_74999             22063 non-null  int64
#  61  workers_with_no_car            22063 non-null  int64
#  62  households_with_no_cars        22063 non-null  int64
#  63  public_asst_pop                22063 non-null  int64
#  64  veteran_pop                    22063 non-null  int64
#  65  county_name                    22063 non-null  object
#  66  inc_extremelylow               22063 non-null  int64
#  67  inc_verylow                    22063 non-null  int64
#  68  inc_low                        22063 non-null  int64
#  69  male_seniors                   22063 non-null  int64
#  70  female_seniors                 22063 non-null  int64
#  71  male_youth                     22063 non-null  int64
#  72  female_youth                   22063 non-null  int64
#  73  disabled_pop                   22063 non-null  int64
#  74  area_m2                        22063 non-null  float64
#  75  geometry                       22063 non-null  geometry
#  76  area_2                         22063 non-null  float64
# dtypes: float64(2), geometry(1), int64(47), object(27)
# memory usage: 13.0+ MB

# %% [markdown]
# ## Adjusting Population and Demographic Metrics for Stop Service Areas

# %%
# Adjust total population by the proportion of the tract area that intersects the stop buffer.
# Calculate the proportion of each tract's area that intersects the stop buffer
geometry_intersect['area_ratio'] = geometry_intersect['area_2'] / geometry_intersect['area_m2']

# %%
# Define demographic and socioeconomic columns to be adjusted by area ratio
cols_to_weight = [
    'total_pop', 'poverty_pop', 'non_us_citizen', 'workers_with_no_car', 
    'households_with_no_cars', 'disabled_pop', 'public_asst_pop', 
    'inc_extremelylow', 'inc_verylow', 'inc_low', 
    'male_seniors', 'female_seniors', 'veteran_pop', 'male_youth',  'female_youth'
]

# Apply area ratio to create adjusted metrics
geometry_intersect[[f'{col}_adj' for col in cols_to_weight]] = (
    geometry_intersect[cols_to_weight].multiply(geometry_intersect['area_ratio'], axis=0)
)

# %%
# Stop level demography data 
filtered_final_data = geometry_intersect[['name', 'organization_type', 'organization_name',  'analysis_name', 'ntd_id_y', 'ntd_id_2022_y', 'stop_id', 'stop_name', 
                                         'GEOIDFQ', 'geometry', 'area_2',	'total_pop_adj',	'poverty_pop_adj',	
                                          'non_us_citizen_adj',	'workers_with_no_car_adj',	'households_with_no_cars_adj',	'disabled_pop_adj',	
                                          'public_asst_pop_adj', 'inc_extremelylow_adj', 'inc_verylow_adj',	'inc_low_adj',	'male_seniors_adj',	
                                          'female_seniors_adj', 'male_youth_adj',  'female_youth_adj', 'veteran_pop_adj']]

filtered_final_data.head(2)
# Out:
#                 name organization_type organization_name     analysis_name  \
# 0  Alhambra Schedule         City/Town  City of Alhambra  City of Alhambra
# 1  Alhambra Schedule         City/Town  City of Alhambra  City of Alhambra
#
#   ntd_id_y ntd_id_2022_y  stop_id                  stop_name  \
# 0    90247         90247  2619820  Commonwealth Ave & 4th St
# 1    90247         90247  2619820  Commonwealth Ave & 4th St
#
#                 GEOIDFQ                                           geometry  \
# 0  1400000US06037481103  POLYGON ((174546.535 -434262.136, 174543.285 -...
# 1  1400000US06037482301  POLYGON ((175016.153 -436000.911, 174975.556 -...
#
#           area_2  total_pop_adj  poverty_pop_adj  non_us_citizen_adj  \
# 0      23.630888       0.092253         0.013093            0.015479
# 1  122884.944234     699.097229        98.104115          152.497084
#
#    workers_with_no_car_adj  households_with_no_cars_adj  disabled_pop_adj  \
# 0                 0.002118                     0.003109          0.010387
# 1                 7.730267                    18.833741         62.544887
#
#    public_asst_pop_adj  inc_extremelylow_adj  inc_verylow_adj  inc_low_adj  \
# 0             0.002067              0.026404         0.020605     0.010118
# 1            46.662702            256.363761       105.834381    63.107088
#
#    male_seniors_adj  female_seniors_adj  male_youth_adj  female_youth_adj  \
# 0          0.005899            0.009950        0.004067          0.005042
# 1         47.365454           75.475515       52.706365         29.515565
#
#    veteran_pop_adj
# 0         0.001109
# 1        16.725487

# %% [markdown]
# ## Agency Level Demography Data

# %%
group_key = ['name']

# Identify adjusted demographic columns
adj_cols = [col for col in geometry_intersect.columns if col.endswith('_adj')]

# Extra non-demographic attributes to keep (take first occurrence per agency)
extra_cols = ['organization_type', 'ntd_id_y', 'ntd_id_2022_y', 'key']

# Dissolve stop buffers to get agency shapes
agency_geometry = orgs_stop_dissolved.dissolve(by=group_key, as_index=False)

# --- DROP overlapping extra columns from agency_geometry ---
agency_geometry = agency_geometry.drop(columns=extra_cols, errors='ignore')

# Aggregate population metrics
agency_demo = geometry_intersect.groupby(group_key, as_index=False)[adj_cols].sum()

# Merge demographics with geometry
agency_summary = agency_geometry.merge(agency_demo, on=group_key, how='left')

# Merge extra attributes (take first)
extra_attrs = orgs_stop_dissolved[group_key + extra_cols].drop_duplicates(subset=group_key)
agency_summary = agency_summary.merge(extra_attrs, on=group_key, how='left')

# %%
agency_summary = gpd.GeoDataFrame(
    agency_summary,
    geometry='geometry',
    crs=tracts_ca_acs.crs
).to_crs(epsg=4326)

# %%
agency_summary = agency_summary.drop(columns=["ntd_id_x", "ntd_id_2022_x"])

agency_summary = agency_summary.rename(
    columns={
        "ntd_id_y": "ntd_id",
        "ntd_id_2022_y": "ntd_id_2022"
    }
)

# %%
agency_summary.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 228 entries, 0 to 227
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   name                           228 non-null    object
#  1   geometry                       228 non-null    geometry
#  2   stop_id                        228 non-null    object
#  3   stop_name                      228 non-null    object
#  4   schedule_gtfs_dataset_name     191 non-null    object
#  5   organization_source_record_id  194 non-null    object
#  6   analysis_name                  191 non-null    object
#  7   organization_name              194 non-null    object
#  8   name_clean                     228 non-null    object
#  9   source_record_id               154 non-null    object
#  10  total_pop_adj                  228 non-null    float64
#  11  poverty_pop_adj                228 non-null    float64
#  12  non_us_citizen_adj             228 non-null    float64
#  13  workers_with_no_car_adj        228 non-null    float64
#  14  households_with_no_cars_adj    228 non-null    float64
#  15  disabled_pop_adj               228 non-null    float64
#  16  public_asst_pop_adj            228 non-null    float64
#  17  inc_extremelylow_adj           228 non-null    float64
#  18  inc_verylow_adj                228 non-null    float64
#  19  inc_low_adj                    228 non-null    float64
#  20  male_seniors_adj               228 non-null    float64
#  21  female_seniors_adj             228 non-null    float64
#  22  veteran_pop_adj                228 non-null    float64
#  23  male_youth_adj                 228 non-null    float64
#  24  female_youth_adj               228 non-null    float64
#  25  organization_type              157 non-null    object
#  26  ntd_id                         132 non-null    object
#  27  ntd_id_2022                    134 non-null    object
#  28  key                            157 non-null    object
# dtypes: float64(15), geometry(1), object(13)
# memory usage: 51.8+ KB

# %%
# Merge acs and ntd data 
merged_agency_ntd = (
    pd.merge(
        agency_summary,
        ridership_data_grouped,
        how='left',
        left_on='ntd_id_2022',
        right_on='ntd_id'
    )
    .sort_values(by='agency')
)

# %%
merged_agency_ntd = gpd.GeoDataFrame(
    merged_agency_ntd, 
    geometry='geometry', 
    crs=agency_summary.crs
)

# %%
merged_agency_ntd = merged_agency_ntd[['key', 'name', 'organization_type', 'organization_name', 'analysis_name', 'ntd_id_2022', 'agency', 'total_pop_adj', 'poverty_pop_adj', 'non_us_citizen_adj', 'workers_with_no_car_adj',
        'households_with_no_cars_adj', 'disabled_pop_adj',
       'public_asst_pop_adj', 'inc_extremelylow_adj', 'inc_verylow_adj',
       'inc_low_adj', 'male_seniors_adj', 'female_seniors_adj', 'male_youth_adj', 'female_youth_adj',
       'veteran_pop_adj',  'unlinked_passenger_trips_upt', 'agency_voms']]

# %%
#Store data in warehouse
with fs.open(f"{GCS_FILE_PATH}/transit_provider_dashboard/merged_agency_ntd.parquet", "wb") as f:
    merged_agency_ntd.to_parquet(f, index=False)

# %%
def export_gdf(gdf, filename: str, export_csv: bool = True):
    # Update the path
    gcs_target_path = f"{GCS_FILE_PATH}/transit_provider_dashboard/"

    # Export as Parquet
    parquet_file = f"{filename}.parquet"
    gdf.to_parquet(parquet_file, engine="pyarrow", index=False)
    
    fs.put(
        parquet_file,
        f"{gcs_target_path}{parquet_file}",
        token=credentials.token
    )
    os.remove(parquet_file)
    print(f"Saved Parquet: {gcs_target_path}{parquet_file}")
    
    if export_csv:
        # Export as CSV
        csv_file = f"{filename}.csv"
        gdf.to_csv(csv_file, index=False)
        
        fs.put(
            csv_file,
            f"{gcs_target_path}{csv_file}",
            token=credentials.token
        )
        os.remove(csv_file)
        print(f"Saved CSV: {gcs_target_path}{csv_file}")

# %%
# Store data in warehouse
export_gdf(merged_agency_ntd, "merged_agency_ntd")
# Out:
# Saved Parquet: gs://calitp-analytics-data/data-analyses/transit_provider_dashboard/merged_agency_ntd.parquet
# Saved CSV: gs://calitp-analytics-data/data-analyses/transit_provider_dashboard/merged_agency_ntd.csv

# %%
# Store data in warehouse
export_gdf(orgs_stop_buffered, "organization_stops_buffered")
# Out:
# Saved Parquet: gs://calitp-analytics-data/data-analyses/transit_provider_dashboard/organization_stops_buffered.parquet
# Saved CSV: gs://calitp-analytics-data/data-analyses/transit_provider_dashboard/organization_stops_buffered.csv

# %%
GCS__PUBLIC_FILE_PATH = f"{PUBLIC_GCS}transit_provider_dashboard/"

def export_gdf_public(gdf, filename: str, export_csv: bool = True, export_parquet: bool = True):
    # --- GeoJSON ---
    geojson_file = f"{GCS__PUBLIC_FILE_PATH}{filename}.geojson"
    geojson_str = gdf.to_json()
    with fsspec.open(geojson_file, 'w') as f_out:
        f_out.write(geojson_str)
    print(f"Saved GeoJSON: {geojson_file}")

    # --- Parquet ---
    if export_parquet:
        parquet_file = f"{filename}.parquet"
        gdf.to_parquet(parquet_file, engine="pyarrow", index=False)
        with fsspec.open(f"{GCS__PUBLIC_FILE_PATH}{filename}.parquet", 'wb') as f_out:
            with open(parquet_file, 'rb') as f_in:
                f_out.write(f_in.read())
        os.remove(parquet_file)
        print(f"Saved Parquet: {GCS__PUBLIC_FILE_PATH}{filename}.parquet")

# %%
def export_gdf_public_with_metadata(gdf, filename: str):
    """
    Export GeoDataFrame to a single XLSX file that includes:
    - Main data sheet
    - Metadata sheet describing the columns
    """
    
    # ---- Metadata dictionary ----
    metadata = {
        "key": "Unique identifier for the agency record.",
        "name": "Organization name.",
        "organization_type": "Type of organization (e.g., transit agency, nonprofit).",
        "geometry": "Spatial geometry for the agency boundary or location.",
        "ntd_id_2022": "National Transit Database ID for 2022 reporting.",
        "agency": "Transit agency name.",
        "gtfs_dataset_key": "Identifier linking to the GTFS dataset.",
        "total_pop_adj": "Adjusted total population.",
        "poverty_pop_adj": "Adjusted population living below the poverty level.",
        "non_us_citizen_adj": "Adjusted count of non-U.S. citizens.",
        "workers_with_no_car_adj": "Adjusted count of workers without access to a vehicle.",
        "households_with_no_cars_adj": "Adjusted number of households without a vehicle.",
        "disabled_pop_adj": "Adjusted population with disabilities.",
        "public_asst_pop_adj": "Adjusted population receiving public assistance.",
        "inc_extremelylow_adj": "Adjusted number of extremely low-income households.",
        "inc_verylow_adj": "Adjusted number of very low-income households.",
        "inc_low_adj": "Adjusted number of low-income households.",
        "male_seniors_adj": "Adjusted male senior population (65+).",
        "female_seniors_adj": "Adjusted female senior population (65+).",
        "male_youth_adj": "Adjusted male youth population (15-24).", 
        "female_youth_adj": "Adjusted female youth population (15-24).",
        "veteran_pop_adj": "Adjusted veteran population.",
        "unlinked_passenger_trips_upt": "Annual number of unlinked passenger trips.",
        "agency_voms": "Vehicles operated in maximum service (peak vehicles)."
    }



    metadata_df = pd.DataFrame(
        [(col, metadata.get(col, "")) for col in gdf.columns],
        columns=["column", "description"]
    )

    # ---- Local temporary file ----
    xlsx_file = f"{filename}.xlsx"

    # ---- Write XLSX with data + metadata ----
    with ExcelWriter(xlsx_file, engine="openpyxl") as writer:
        gdf.to_excel(writer, sheet_name="data", index=False)
        metadata_df.to_excel(writer, sheet_name="metadata", index=False)

    # ---- Upload to GCS ----
    gcs_path = f"{GCS__PUBLIC_FILE_PATH}{filename}.xlsx"

    with fsspec.open(gcs_path, "wb") as f_out:
        with open(xlsx_file, "rb") as f_in:
            f_out.write(f_in.read())

    os.remove(xlsx_file)

    print(f"Saved XLSX with metadata: {gcs_path}")

# %%
export_gdf_public(merged_agency_ntd, "transitprovider_acs_ridership_2024_data")
# Out:
# Saved GeoJSON: gs://calitp-publish-data-analysis/transit_provider_dashboard/transitprovider_acs_ridership_2024_data.geojson
# Saved Parquet: gs://calitp-publish-data-analysis/transit_provider_dashboard/transitprovider_acs_ridership_2024_data.parquet

# %%
export_gdf_public_with_metadata(merged_agency_ntd, "transitprovider_acs_ridership_2024_data")
# Out:
# Saved XLSX with metadata: gs://calitp-publish-data-analysis/transit_provider_dashboard/transitprovider_acs_ridership_2024_data.xlsx
